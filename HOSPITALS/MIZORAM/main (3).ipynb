# %%
import time
import random
import pandas as pd

from datetime import datetime

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.service import Service

from webdriver_manager.chrome import ChromeDriverManager

districts = [

    "Aizawl",
    "Champhai",
    "Hnahthial",
    "Khawzawl",
    "Kolasib",
    "Lawngtlai",
    "Lunglei",
    "Mamit",
    "Saitual",
    "Serchhip"

]


search_types = [
    "hospitals"
]



options = webdriver.ChromeOptions()

options.add_argument("--start-maximized")

options.add_argument(
    "--disable-blink-features=AutomationControlled"
)

options.add_argument("--disable-notifications")

driver = webdriver.Chrome(

    service=Service(
        ChromeDriverManager().install()
    ),

    options=options
)



driver.get("https://www.google.com/maps")

print("Opening Google Maps...")

time.sleep(15)

print("Google Maps Loaded")



all_data = []

visited_links = set()


def get_search_box():

    selectors = [

        '//input[@id="searchboxinput"]',
        '//input[contains(@placeholder,"Search")]',
        '//input[contains(@aria-label,"Search")]',
        '//input'

    ]

    for selector in selectors:

        try:

            box = driver.find_element(
                By.XPATH,
                selector
            )

            return box

        except:
            pass

    return None


def extract_school_data():

    try:

        try:
            name = driver.find_element(
                By.TAG_NAME,
                "h1"
            ).text
        except:
            name = ""

        try:
            address = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"address")]'
            ).text
        except:
            address = ""

        try:
            phone = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"phone")]'
            ).text
        except:
            phone = ""

    
        try:
            website = driver.find_element(
                By.XPATH,
                '//a[contains(@data-item-id,"authority")]'
            ).get_attribute("href")
        except:
            website = ""

        try:
            rating = driver.find_element(
                By.XPATH,
                '//div[@role="img"]'
            ).get_attribute("aria-label")
        except:
            rating = ""

        return {

            "Hospital Name": name,
            "Address": address,
            "Phone": phone,
            "Website": website,
            "Rating": rating,
            "Google Maps URL": driver.current_url

        }

    except:

        return None



for district in districts:

    for search_type in search_types:

        try:

            query = (
                f"{search_type} "
                f"in {district} Mizoram"
            )

            print(f"\nSearching: {query}")



            search_box = get_search_box()

            if not search_box:

                print("Search Box Not Found")

                continue

            ActionChains(driver).move_to_element(
                search_box
            ).click().perform()

            time.sleep(1)

            search_box.send_keys(
                Keys.CONTROL + "a"
            )

            time.sleep(1)

            search_box.send_keys(Keys.DELETE)

            time.sleep(1)

 
            for char in query:

                search_box.send_keys(char)

                time.sleep(0.03)

            search_box.send_keys(Keys.ENTER)

            print("Search Submitted")

            time.sleep(8)


            try:

                scrollable_div = driver.find_element(
                    By.XPATH,
                    '//div[@role="feed"]'
                )

                previous_count = 0

                stagnant = 0

                for i in range(100):

                    driver.execute_script(
                        """
                        arguments[0].scrollTop =
                        arguments[0].scrollHeight
                        """,
                        scrollable_div
                    )

                    time.sleep(4)

                    listings = driver.find_elements(
                        By.XPATH,
                        '//a[contains(@href,"/maps/place/")]'
                    )

                    current_count = len(listings)

                    print(
                        f"{district} | "
                        f"{search_type} | "
                        f"Scroll {i+1} -> "
                        f"{current_count}"
                    )

                    if current_count == previous_count:

                        stagnant += 1

                    else:

                        stagnant = 0

                  
                    if stagnant >= 4:

                        break

                    previous_count = current_count

            except Exception as e:

                print(f"Scrolling Error: {e}")

            listings = driver.find_elements(
                By.XPATH,
                '//a[contains(@href,"/maps/place/")]'
            )

            links = []

            for listing in listings:

                try:

                    link = listing.get_attribute("href")

                    if (
                        link
                        and link not in visited_links
                    ):

                        links.append(link)

                        visited_links.add(link)

                except:
                    pass

            print(f"Collected {len(links)} links")

    

            for index, link in enumerate(links):

                try:

                    print(
                        f"{district} | "
                        f"{index+1}/{len(links)}"
                    )

                    driver.get(link)

                    time.sleep(
                        random.uniform(2, 4)
                    )

                    data = extract_school_data()

                    if data:

                        data["District"] = district

                        data["Search Type"] = search_type

                        all_data.append(data)

                        print(data["Hospital Name"])

      

                    if len(all_data) % 100 == 0:

                        backup_df = pd.DataFrame(
                            all_data
                        )

                        backup_df.drop_duplicates(
                            subset=[
                                "Hospital Name",
                                "Google Maps URL"
                            ],
                            inplace=True
                        )

                        backup_filename = (
                            "mizoram_backup.csv"
                        )

                        backup_df.to_csv(
                            backup_filename,
                            index=False
                        )

                        print("Backup Saved")

                except Exception as e:

                    print(
                        f"School Error: {e}"
                    )

        except Exception as e:

            print(
                f"District Error: {e}"
            )



df = pd.DataFrame(all_data)

df.drop_duplicates(

    subset=[
        "Hospital Name",
        "Google Maps URL"
    ],

    inplace=True
)


filename = (
    "mizoram_hospitals.csv"
)

df.to_csv(
    filename,
    index=False
)

print("\nExtraction Completed")

print(
    f"Total Schools Extracted: {len(df)}"
)

print(f"\nSaved File: {filename}")

driver.quit()
# Out:
# Opening Google Maps...
# Google Maps Loaded
#
# Searching: hospitals in Aizawl Mizoram
# Search Submitted
# Aizawl | hospitals | Scroll 1 -> 16
# Aizawl | hospitals | Scroll 2 -> 20
# Aizawl | hospitals | Scroll 3 -> 25
# Aizawl | hospitals | Scroll 4 -> 25
# Aizawl | hospitals | Scroll 5 -> 25
# Aizawl | hospitals | Scroll 6 -> 25
# Aizawl | hospitals | Scroll 7 -> 25
# Collected 25 links
# Aizawl | 1/25
# Civil Hospital, Aizawl
# Aizawl | 2/25
#
# Aizawl | 3/25
# Greenwood Hospital Pvt Ltd
# Aizawl | 4/25
# Trinity Hospital
# Aizawl | 5/25
# Ebenezer Medical Center
# Aizawl | 6/25
# LRM Hospital Aizawl in Mizoram
# Aizawl | 7/25
# Adventist Hospital
# Aizawl | 8/25
# BN Hospital & Research Centre
# Aizawl | 9/25
# Nazareth Hospital
# Aizawl | 10/25
# Synod Hospital Durtlang
# Aizawl | 11/25
# City Hospital, Mission Veng
# Aizawl | 12/25
# Alpha Hospital
# Aizawl | 13/25
# Kulikawn Hospital
# Aizawl | 14/25
# Rosewood Hospital
# Aizawl | 15/25
# Agape Multispeciality Hospital
# Aizawl | 16/25
# Redeem Hospital
# Aizawl | 17/25
# Care Hospital
# Aizawl | 18/25
# Mizoram Health Care
# Aizawl | 19/25
# Mizoram State Cancer Institute
# Aizawl | 20/25
# Civil Hospital OPD
# Aizawl | 21/25
# Hi-tech hospital
# Aizawl | 22/25
# Millennium Centre
# Aizawl | 23/25
# John Williams Hospital
# Aizawl | 24/25
# Medical Superintendent Office, Civil Hospital Lunglei
# Aizawl | 25/25
# Fari Pute In
#
# Searching: hospitals in Champhai Mizoram
# Search Submitted
# Champhai | hospitals | Scroll 1 -> 4
# Champhai | hospitals | Scroll 2 -> 4
# Champhai | hospitals | Scroll 3 -> 4
# Champhai | hospitals | Scroll 4 -> 4
# Champhai | hospitals | Scroll 5 -> 4
# Collected 4 links
# Champhai | 1/4
# Champhai District Hospital
# Champhai | 2/4
# Med-Aim Hospital
# Champhai | 3/4
# DM Hospital
# Champhai | 4/4
# Champhai Ayush Health and Wellness Centre
#
# Searching: hospitals in Hnahthial Mizoram
# Search Submitted
# Scrolling Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@role="feed"]"}
#   (Session info: chrome=148.0.7778.167); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 	chromedriver!GetHandleVerifier [0x10d7123+10a23]
# 	chromedriver!GetHandleVerifier [0x10d7254+10b54]
# 	chromedriver!(No symbol) [0xef1e90]
# 	chromedriver!(No symbol) [0xf3b28a]
# 	chromedriver!(No symbol) [0xf3b52b]
# 	chromedriver!(No symbol) [0xf7d062]
# 	chromedriver!(No symbol) [0xf5d7d4]
# 	chromedriver!(No symbol) [0xf7a936]
# 	chromedriver!(No symbol) [0xf5d526]
# 	chromedriver!(No symbol) [0xf308f9]
# 	chromedriver!(No symbol) [0xf316b4]
# 	chromedriver!GetHandleVerifier [0x1371ac4+2ab3c4]
# 	chromedriver!GetHandleVerifier [0x136d0ed+2a69ed]
# 	chromedriver!GetHandleVerifier [0x138e4f5+2c7df5]
# 	chromedriver!GetHandleVerifier [0x10f1128+2aa28]
# 	chromedriver!GetHandleVerifier [0x10f8bbd+324bd]
# 	chromedriver!GetHandleVerifier [0x10dfb28+19428]
# 	chromedriver!GetHandleVerifier [0x10dfcd5+195d5]
# 	chromedriver!GetHandleVerifier [0x10c91cf+2acf]
# 	KERNEL32!BaseThreadInitThunk [0x75defcc9+19]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x779982ae+11e]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x7799827e+ee]
#
# Collected 0 links
#
# Searching: hospitals in Khawzawl Mizoram
# Search Submitted
# Scrolling Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@role="feed"]"}
#   (Session info: chrome=148.0.7778.167); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 	chromedriver!GetHandleVerifier [0x10d7123+10a23]
# 	chromedriver!GetHandleVerifier [0x10d7254+10b54]
# 	chromedriver!(No symbol) [0xef1e90]
# 	chromedriver!(No symbol) [0xf3b28a]
# 	chromedriver!(No symbol) [0xf3b52b]
# 	chromedriver!(No symbol) [0xf7d062]
# 	chromedriver!(No symbol) [0xf5d7d4]
# 	chromedriver!(No symbol) [0xf7a936]
# 	chromedriver!(No symbol) [0xf5d526]
# 	chromedriver!(No symbol) [0xf308f9]
# 	chromedriver!(No symbol) [0xf316b4]
# 	chromedriver!GetHandleVerifier [0x1371ac4+2ab3c4]
# 	chromedriver!GetHandleVerifier [0x136d0ed+2a69ed]
# 	chromedriver!GetHandleVerifier [0x138e4f5+2c7df5]
# 	chromedriver!GetHandleVerifier [0x10f1128+2aa28]
# 	chromedriver!GetHandleVerifier [0x10f8bbd+324bd]
# 	chromedriver!GetHandleVerifier [0x10dfb28+19428]
# 	chromedriver!GetHandleVerifier [0x10dfcd5+195d5]
# 	chromedriver!GetHandleVerifier [0x10c91cf+2acf]
# 	KERNEL32!BaseThreadInitThunk [0x75defcc9+19]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x779982ae+11e]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x7799827e+ee]
#
# Collected 0 links
#
# Searching: hospitals in Kolasib Mizoram
# Search Submitted
# Kolasib | hospitals | Scroll 1 -> 9
# Kolasib | hospitals | Scroll 2 -> 9
# Kolasib | hospitals | Scroll 3 -> 9
# Kolasib | hospitals | Scroll 4 -> 9
# Kolasib | hospitals | Scroll 5 -> 9
# Collected 9 links
# Kolasib | 1/9
#
# Kolasib | 2/9
# Nazareth Hospital
# Kolasib | 3/9
# Kolasib Hospital Canteen
# Kolasib | 4/9
# OST Centre, District Hospital, Kolasib, Mizoram
# Kolasib | 5/9
# Female Ward/ICTC/ARTC
# Kolasib | 6/9
#
# Kolasib | 7/9
# District Hospital Blood Bank Kolasib
# Kolasib | 8/9
# Casualty and Trauma Center
# Kolasib | 9/9
# Animal health center
#
# Searching: hospitals in Lawngtlai Mizoram
# Search Submitted
# Lawngtlai | hospitals | Scroll 1 -> 5
# Lawngtlai | hospitals | Scroll 2 -> 5
# Lawngtlai | hospitals | Scroll 3 -> 5
# Lawngtlai | hospitals | Scroll 4 -> 5
# Lawngtlai | hospitals | Scroll 5 -> 5
# Collected 5 links
# Lawngtlai | 1/5
# Christian Hospital — Lawngtlai Vengpui
# Lawngtlai | 2/5
# Lairam Christian Medical Centre
# Lawngtlai | 3/5
# Lawngtlai District Hospital
# Lawngtlai | 4/5
# Not anymore
# Lawngtlai | 5/5
# AH&vety Lti(losa)
#
# Searching: hospitals in Lunglei Mizoram
# Search Submitted
# Lunglei | hospitals | Scroll 1 -> 7
# Lunglei | hospitals | Scroll 2 -> 7
# Lunglei | hospitals | Scroll 3 -> 7
# Lunglei | hospitals | Scroll 4 -> 7
# Lunglei | hospitals | Scroll 5 -> 7
# Collected 5 links
# Lunglei | 1/5
# HOPE HOSPITAL
# Lunglei | 2/5
# Civil Hospital Lunglei
# Lunglei | 3/5
# Christian Hospital Serkawn
# Lunglei | 4/5
# Urban Primary Health Centre
# Lunglei | 5/5
# Health Sub-Centre, Electric Veng, Lunglei
#
# Searching: hospitals in Mamit Mizoram
# Search Submitted
# Scrolling Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@role="feed"]"}
#   (Session info: chrome=148.0.7778.167); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 	chromedriver!GetHandleVerifier [0x10d7123+10a23]
# 	chromedriver!GetHandleVerifier [0x10d7254+10b54]
# 	chromedriver!(No symbol) [0xef1e90]
# 	chromedriver!(No symbol) [0xf3b28a]
# 	chromedriver!(No symbol) [0xf3b52b]
# 	chromedriver!(No symbol) [0xf7d062]
# 	chromedriver!(No symbol) [0xf5d7d4]
# 	chromedriver!(No symbol) [0xf7a936]
# 	chromedriver!(No symbol) [0xf5d526]
# 	chromedriver!(No symbol) [0xf308f9]
# 	chromedriver!(No symbol) [0xf316b4]
# 	chromedriver!GetHandleVerifier [0x1371ac4+2ab3c4]
# 	chromedriver!GetHandleVerifier [0x136d0ed+2a69ed]
# 	chromedriver!GetHandleVerifier [0x138e4f5+2c7df5]
# 	chromedriver!GetHandleVerifier [0x10f1128+2aa28]
# 	chromedriver!GetHandleVerifier [0x10f8bbd+324bd]
# 	chromedriver!GetHandleVerifier [0x10dfb28+19428]
# 	chromedriver!GetHandleVerifier [0x10dfcd5+195d5]
# 	chromedriver!GetHandleVerifier [0x10c91cf+2acf]
# 	KERNEL32!BaseThreadInitThunk [0x75defcc9+19]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x779982ae+11e]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x7799827e+ee]
#
# Collected 0 links
#
# Searching: hospitals in Saitual Mizoram
# Search Submitted
# Saitual | hospitals | Scroll 1 -> 4
# Saitual | hospitals | Scroll 2 -> 4
# Saitual | hospitals | Scroll 3 -> 4
# Saitual | hospitals | Scroll 4 -> 4
# Saitual | hospitals | Scroll 5 -> 4
# Collected 3 links
# Saitual | 1/3
# District Hospital Saitual
# Saitual | 2/3
# District Hospital Saitual Pharmacy
# Saitual | 3/3
# Health Sub-Centre
#
# Searching: hospitals in Serchhip Mizoram
# Search Submitted
# Serchhip | hospitals | Scroll 1 -> 5
# Serchhip | hospitals | Scroll 2 -> 5
# Serchhip | hospitals | Scroll 3 -> 5
# Serchhip | hospitals | Scroll 4 -> 5
# Serchhip | hospitals | Scroll 5 -> 5
# Collected 5 links
# Serchhip | 1/5
# District Hospital, Serchhip.
# Serchhip | 2/5
# Mercy Hospital(Rural Diagnostic And Research Centre)
# Serchhip | 3/5
# JN Hospital
# Serchhip | 4/5
# Hospital Quarter Area
# Serchhip | 5/5
# Trauma Center, Serchhip
#
# Extraction Completed
# Total Schools Extracted: 56
#
# Saved File: mizoram_hospitals.csv
