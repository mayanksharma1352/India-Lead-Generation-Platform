# %%
import pandas as pd

# %%
df = pd.read_csv("mizoram_hospitals.csv")

# %%
df.shape
# Out:
# (56, 8)

# %%
df = df[
    df["Phone"].notna() &
    (df["Phone"].astype(str).str.strip() != "")
]

# %%
df.shape
# Out:
# (20, 8)

# %%
df = df[
    df["Hospital Name"].notna()
]

df = df[
    df["Hospital Name"].str.strip() != ""
]

# %%
df.shape
# Out:
# (20, 8)

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]", "", regex=True)  # remove symbols/icons
    .str.strip()
)


display(df[["Phone"]].head())
# Out:
#            Phone
# 0  0389 232 2318
# 2  0389 234 1397
# 3   094367 43416
# 4   081189 00590
# 5   084130 28542

# %%
df.to_csv(
    "mizoram_hospitals_cleaned.csv",
    index=False
)
