# %%
import pandas as pd

# %%
df = pd.read_csv("jharkhand_hospitals.csv")

# %%
df.shape
# Out:
# (533, 8)

# %%
df = df[
    df["Phone"].notna() & 
    (df["Phone"].astype(str).str.strip() != "")
    ]
df.shape
# Out:
# (338, 8)

# %%
df = df[
    df["Hospital Name"].notna()
    ]

df = df[
    df["Hospital Name"].str.strip() != ""
    ]
df.shape
# Out:
# (338, 8)

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]","",regex=True)
    .str.strip()
)

display(df[["Phone"]].head())
# Out:
#            Phone
# 1   082529 14539
# 2   1800 11 1565
# 3   093869 36795
# 4  06542 236 188
# 5  06542 361 636

# %%
df.to_csv(
    "jharkhand_hospitals_cleaned.csv",
    index=False
)
