# %%
import time
import random
import pandas as pd

from datetime import datetime

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.service import Service

from webdriver_manager.chrome import ChromeDriverManager


districts = [
    "Bokaro",
    "Chatra",
    "Deoghar",
    "Dhanbad",
    "Dumka",
    "East Singhbhum",
    "Garhwa",
    "Giridih",
    "Godda",
    "Gumla",
    "Hazaribagh",
    "Jamtara",
    "Khunti",
    "Koderma",
    "Latehar",
    "Lohardaga",
    "Pakur",
    "Palamu",
    "Ramgarh",
    "Ranchi",
    "Sahebganj",
    "Seraikela Kharsawan",
    "Simdega",
    "West Singhbhum"
]
 

search_types = [
    "hospitals"
]

options = webdriver.ChromeOptions()

options.add_argument("--start-maximized")

options.add_argument(
    "--disable-blink-features=AutomationControlled"
)

options.add_argument("--disable-notifications")


driver = webdriver.Chrome(

    service=Service(
        ChromeDriverManager().install()
    ),

    options=options
)


driver.get("https://www.google.com/maps")

print("Opening Google Maps...")

time.sleep(15)

print("Google Maps Loaded")


all_data = []

visited_links = set()


def get_search_box():

    selectors = [

        '//input[@id="searchboxinput"]',
        '//input[contains(@placeholder,"Search")]',
        '//input[contains(@aria-label,"Search")]',
        '//input'

    ]

    for selector in selectors:

        try:

            box = driver.find_element(
                By.XPATH,
                selector
            )

            return box

        except:
            pass

    return None


def extract_school_data():

    try:

        try:
            name = driver.find_element(
                By.TAG_NAME,
                "h1"
            ).text
        except:
            name = ""

        try:
            address = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"address")]'
            ).text
        except:
            address = ""

        try:
            phone = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"phone")]'
            ).text
        except:
            phone = ""

        try:
            website = driver.find_element(
                By.XPATH,
                '//a[contains(@data-item-id,"authority")]'
            ).get_attribute("href")
        except:
            website = ""

        try:
            rating = driver.find_element(
                By.XPATH,
                '//div[@role="img"]'
            ).get_attribute("aria-label")
        except:
            rating = ""

        return {

            "Hospital Name": name,
            "Address": address,
            "Phone": phone,
            "Website": website,
            "Rating": rating,
            "Google Maps URL": driver.current_url

        }

    except:

        return None

for district in districts:

    for search_type in search_types:

        try:

            query = (
                f"{search_type} "
                f"in {district} Jharkhand"
            )

            print(f"\nSearching: {query}")

            search_box = get_search_box()

            if not search_box:

                print("Search Box Not Found")

                continue

            ActionChains(driver).move_to_element(
                search_box
            ).click().perform()

            time.sleep(1)

            search_box.send_keys(
                Keys.CONTROL + "a"
            )

            time.sleep(1)

            search_box.send_keys(Keys.DELETE)

            time.sleep(1)

            # TYPE SLOWLY
            for char in query:

                search_box.send_keys(char)

                time.sleep(0.03)

            search_box.send_keys(Keys.ENTER)

            print("Search Submitted")

            time.sleep(8)


            try:

                scrollable_div = driver.find_element(
                    By.XPATH,
                    '//div[@role="feed"]'
                )

                previous_count = 0

                stagnant = 0

                for i in range(100):

                    driver.execute_script(
                        """
                        arguments[0].scrollTop =
                        arguments[0].scrollHeight
                        """,
                        scrollable_div
                    )

        
                    time.sleep(4)

                    listings = driver.find_elements(
                        By.XPATH,
                        '//a[contains(@href,"/maps/place/")]'
                    )

                    current_count = len(listings)

                    print(
                        f"{district} | "
                        f"{search_type} | "
                        f"Scroll {i+1} -> "
                        f"{current_count}"
                    )

                    if current_count == previous_count:

                        stagnant += 1

                    else:

                        stagnant = 0

                    # STOP AFTER 4 SAME COUNTS
                    if stagnant >= 4:

                        break

                    previous_count = current_count

            except Exception as e:

                print(f"Scrolling Error: {e}")


            listings = driver.find_elements(
                By.XPATH,
                '//a[contains(@href,"/maps/place/")]'
            )

            links = []

            for listing in listings:

                try:

                    link = listing.get_attribute("href")

                    if (
                        link
                        and link not in visited_links
                    ):

                        links.append(link)

                        visited_links.add(link)

                except:
                    pass

            print(f"Collected {len(links)} links")


            for index, link in enumerate(links):

                try:

                    print(
                        f"{district} | "
                        f"{index+1}/{len(links)}"
                    )

                    driver.get(link)

                    time.sleep(
                        random.uniform(2, 4)
                    )

                    data = extract_school_data()

                    if data:

                        data["District"] = district

                        data["Search Type"] = search_type

                        all_data.append(data)

                        print(data["Hospital Name"])


                    if len(all_data) % 100 == 0:

                        backup_df = pd.DataFrame(
                            all_data
                        )

                        backup_df.drop_duplicates(
                            subset=[
                                "Hospital Name",
                                "Google Maps URL"
                            ],
                            inplace=True
                        )

                        backup_filename = (
                            "jharkhand_backup.csv"
                        )

                        backup_df.to_csv(
                            backup_filename,
                            index=False
                        )

                        print("Backup Saved")

                except Exception as e:

                    print(
                        f"School Error: {e}"
                    )

        except Exception as e:

            print(
                f"District Error: {e}"
            )


df = pd.DataFrame(all_data)

df.drop_duplicates(

    subset=[
        "Hospital Name",
        "Google Maps URL"
    ],

    inplace=True
)

filename = (
    "jharkhand_hospitals.csv"
)

df.to_csv(
    filename,
    index=False
)

print("\nExtraction Completed")

print(
    f"Total Hospitals Extracted: {len(df)}"
)

print(f"\nSaved File: {filename}")

driver.quit()
# Out:
# Opening Google Maps...
# Google Maps Loaded
#
# Searching: hospitals in Bokaro Jharkhand
# Search Submitted
# Bokaro | hospitals | Scroll 1 -> 14
# Bokaro | hospitals | Scroll 2 -> 20
# Bokaro | hospitals | Scroll 3 -> 27
# Bokaro | hospitals | Scroll 4 -> 34
# Bokaro | hospitals | Scroll 5 -> 40
# Bokaro | hospitals | Scroll 6 -> 40
# Bokaro | hospitals | Scroll 7 -> 40
# Bokaro | hospitals | Scroll 8 -> 40
# Bokaro | hospitals | Scroll 9 -> 40
# Collected 40 links
# Bokaro | 1/40
# Medicant Hospital & Research Centre
# Bokaro | 2/40
# Wellmark Hospital (वेलमार्क हॉस्पिटल)
# Bokaro | 3/40
# Bokaro General Hospital (BGH)
# Bokaro | 4/40
# Ashadeep multi-speciality hospital
# Bokaro | 5/40
# K.M Memorial Hospital
# Bokaro | 6/40
# Panda Multispeciality Care hospital and research center
# Bokaro | 7/40
# Neelam Hospital & Research Centre-Multispecialty Hospital in Bokaro
# Bokaro | 8/40
# Shiv Shakti Hospital & Research Centre - Best Hospital in Chas Bokaro | Hip Replacement Surgeon in Bokaro
# Bokaro | 9/40
# R.N.B. Hospital
# Bokaro | 10/40
# Sadar Hospital Bokaro
# Bokaro | 11/40
# Medicant hospital BOKARO
# Chatra | 19/19
# Chatra Eye And General Hospital
#
# Searching: hospitals in Deoghar Jharkhand
# Search Submitted
# Deoghar | hospitals | Scroll 1 -> 14
# Deoghar | hospitals | Scroll 2 -> 20
# Deoghar | hospitals | Scroll 3 -> 25
# Deoghar | hospitals | Scroll 4 -> 25
# Deoghar | hospitals | Scroll 5 -> 25
# Deoghar | hospitals | Scroll 6 -> 25
# Deoghar | hospitals | Scroll 7 -> 25
# Collected 25 links
# Deoghar | 1/25
# Sudha Hospital and Trauma center
# Deoghar | 2/25
# THE HOSPITAL PLUS
# Deoghar | 3/25
# Tridev hospital
# Deoghar | 4/25
# Vinayak hospital,saint Francis school road,castair town,deoghar
# Deoghar | 5/25
# Maa Lalita Superspeciality Hospital & Trauma Centre
# Deoghar | 6/25
# Shree hospital
# Deoghar | 7/25
# Vinayak Hospital
# Deoghar | 8/25
# Shivay Hospital
# Deoghar | 9/25
# Neelkanth Hospital
# Deoghar | 10/25
# OM SHIV SAI HOSPITAL. (Dr. Priyanka)
# Deoghar | 11/25
# deoghar hospital
# Deoghar | 12/25
# Sundaram Hospital
# Deoghar | 13/25
# सदर अस्पताल देवघर
# Deoghar | 14/25
# Sudhir Hospital
# Deoghar | 15/25
# Kidney and Dialysis centre Deoghar
# Deoghar | 16/25
# Apollo Clinic Deoghar
# Deoghar | 17/25
# APARNA MULTI SPECIALITY HOSPITAL - Best Laparoscopy Surgeon in Deoghar/General Surgeon in Deoghar
# Deoghar | 18/25
# Aria healthcare
# Deoghar | 19/25
# HEAL MAX HOSPITAL & REHABILITATION CENTRE
# Deoghar | 20/25
# City Care Hospital
# Deoghar | 21/25
# District Hospital Deoghar
# Deoghar | 22/25
# Medha Health Care Private Ltd.
# Deoghar | 23/25
# Dr. Amit Kumar Keshri
# Deoghar | 24/25
# Maa Durga Memorial Hospital
# Deoghar | 25/25
# Govt Hospital
#
# Searching: hospitals in Dhanbad Jharkhand
# Search Submitted
# Dhanbad | hospitals | Scroll 1 -> 14
# Dhanbad | hospitals | Scroll 2 -> 20
# Dhanbad | hospitals | Scroll 3 -> 27
# Dhanbad | hospitals | Scroll 4 -> 34
# Dhanbad | hospitals | Scroll 5 -> 37
# Dhanbad | hospitals | Scroll 6 -> 37
# Dhanbad | hospitals | Scroll 7 -> 37
# Dhanbad | hospitals | Scroll 8 -> 37
# Dhanbad | hospitals | Scroll 9 -> 37
# Collected 37 links
# Dhanbad | 1/37
# Asian Hospital - Best Hospital in Dhanbad
# Dhanbad | 2/37
# Patliputra Hospital | Best Hospital in Dhanbad
# Dhanbad | 3/37
# Asarfi Hospital
# Dhanbad | 4/37
# Sjas Super Specialty Hospital
# Dhanbad | 5/37
# SENGAR HOSPITAL DHANBAD JHARKHAND
# Dhanbad | 6/37
# Alkari Devi Hospital - Obstetrics & Gynecologist "IVF & Fertility Centre"
# Dhanbad | 7/37
# District Hospital Dhanbad
# Dhanbad | 8/37
# Gynica City Hospital ( Dr M A R Noon & Dr Zeenat Parveen)- Maternity Hospital in Dhanbad/ Hospital in Wassepur Dhanbad
# Garhwa | 1/18
# Jharkhand Hospital Garhwa
# Garhwa | 2/18
# Sadar Hospital Garhwa
# Garhwa | 3/18
# Durga Medicare Hospital
# Garhwa | 4/18
# Hayaat ENT Hospital
# Garhwa | 5/18
# CIPACA - Parmeshwari Medical Centre - 24 Hrs Emergency & ICU Care Hospital
# Garhwa | 6/18
# Parmeshwari Medical Centre
# Garhwa | 7/18
# Milaap Medical Centre
# Garhwa | 8/18
# MAA GAYTRI HOSPITAL
# Garhwa | 9/18
# Taiba Hospital
# Garhwa | 10/18
# Arogyam hospital Best and Top nursing/Paramedical/Pharmacy/medical College
# Garhwa | 11/18
# Garhwa sewa Sadan hospital
# Garhwa | 12/18
# Fatima child care
# Garhwa | 13/18
# Sanjeevani Hospital
# Garhwa | 14/18
# Sri laxmi surgery &MediCare Clinic Chiniya More Garhwa - Medicare & Surgery hospital in Garhwa
# Garhwa | 15/18
# CITY HOSPITAL
# Garhwa | 16/18
# Yashoda hospital 🏥
# Garhwa | 17/18
# PRABHAT MEDICAL CENTRE
# Garhwa | 18/18
# Arogyam Hospital And Research Center
#
# Searching: hospitals in Giridih Jharkhand
# Search Submitted
# Giridih | hospitals | Scroll 1 -> 14
# Giridih | hospitals | Scroll 2 -> 20
# Giridih | hospitals | Scroll 3 -> 20
# Giridih | hospitals | Scroll 4 -> 20
# Giridih | hospitals | Scroll 5 -> 20
# Giridih | hospitals | Scroll 6 -> 20
# Collected 20 links
# Giridih | 1/20
# Navjeevan Nursing Home – ICU, Dialysis & Multispeciality Hospital in Giridih
# Giridih | 2/20
# Sri Sai Hospital - Giridih
# Giridih | 3/20
# Gobardhan Lal Nursing Home
# Giridih | 4/20
# Mercy Hospital Giridih
# Giridih | 5/20
# Sadar Hospital
# Giridih | 6/20
# Vishwanath Nursing Home
# Giridih | 7/20
# GD Bagaria Hospital
# Giridih | 8/20
# Parwati Foundation Multi Speciality Hospital Giridih
# Giridih | 9/20
# Pavitri Hospital
# Giridih | 10/20
# CIPACA - Navjeevan Nursing Home - 24 Hrs Emergency & ICU Care Hospital
# Backup Saved
# Giridih | 11/20
# Sai Parmeshwar Hospital
# Giridih | 12/20
# City Care Hospital Giridih
# Giridih | 13/20
# Sahyog hospital
# Giridih | 14/20
# Aftab Hospital, Giridih
# Giridih | 15/20
# V.CITY HOSPITAL GIRIDIH
# Giridih | 16/20
# I.M. HEALTH CARE
# Giridih | 17/20
# Jeevan Dhara Nursing Home
# Giridih | 18/20
# Rotary Eye Hospital
# Giridih | 19/20
# DISTRICT HOSPITAL GIRIDIH
# Giridih | 20/20
# Dr.N K singh
#
# Searching: hospitals in Godda Jharkhand
# Search Submitted
# Godda | hospitals | Scroll 1 -> 14
# Godda | hospitals | Scroll 2 -> 14
# Godda | hospitals | Scroll 3 -> 14
# Godda | hospitals | Scroll 4 -> 14
# Godda | hospitals | Scroll 5 -> 14
# Collected 14 links
# Godda | 1/14
# New City hospital Godda
# Godda | 2/14
# Krist Raja Hospital
# Godda | 3/14
# Sadar Hospital, Godda
# Godda | 4/14
# Sunrise Hospital Godda (सनराइज हॉस्पिटल गोड्डा)
# Godda | 5/14
# SANJEEVANI HOSPITAL
# Godda | 6/14
# Hayat Hospital & Diagnostic Centre
# Godda | 7/14
# Visifert Eye Hospital
# Godda | 8/14
# GMC (GRAND MEDICARE HOSPITAL)
# Godda | 9/14
# Life Care Hospital
# Godda | 10/14
# Aryans Hospital
# Godda | 11/14
# DIALYSIS CENTER SADAR HOSPITAL
# Godda | 12/14
# Urjanagar Hospital
# Godda | 13/14
# Dr. Rajan's Clinic
# Godda | 14/14
# Godda Nidan Ultrasound
#
# Searching: hospitals in Gumla Jharkhand
# Search Submitted
# Gumla | hospitals | Scroll 1 -> 14
# Gumla | hospitals | Scroll 2 -> 16
# Gumla | hospitals | Scroll 3 -> 16
# Gumla | hospitals | Scroll 4 -> 16
# Gumla | hospitals | Scroll 5 -> 16
# Gumla | hospitals | Scroll 6 -> 16
# Collected 16 links
# Gumla | 1/16
# Kare Advanced Multispeciality Hospital
# Gumla | 2/16
# SADAR HOSPITAL
# Gumla | 3/16
# ANITA SEVA SADAN HOSPITAL GUMLA
# Gumla | 4/16
# Namrta Hospital
# Gumla | 5/16
# Nirala Eye Hospital
# Gumla | 6/16
# Manipal HealthMap (CT Scan/Ultrasound/ECG/X-Ray Center)
# Gumla | 7/16
# Hospital
# Gumla | 8/16
# Referral Hospital Basia
# Gumla | 9/16
# Tej Orthopedic and Surgical Hospital Gumla
# Gumla | 10/16
# St. Joseph Hospital
# Gumla | 11/16
# Dr Krishna Prasad Clinic
# Gumla | 12/16
# Sahu narsing home
# Gumla | 13/16
# Jagriti hospital sisai
# Gumla | 14/16
# Bhagwan Mahavir Manipal Hospital
# Gumla | 15/16
# Sneha Health Point
# Gumla | 16/16
# Bhagwati Health Care
#
# Searching: hospitals in Hazaribagh Jharkhand
# Search Submitted
# Hazaribagh | hospitals | Scroll 1 -> 14
# Hazaribagh | hospitals | Scroll 2 -> 20
# Hazaribagh | hospitals | Scroll 3 -> 27
# Hazaribagh | hospitals | Scroll 4 -> 27
# Hazaribagh | hospitals | Scroll 5 -> 27
# Hazaribagh | hospitals | Scroll 6 -> 27
# Hazaribagh | hospitals | Scroll 7 -> 27
# Collected 27 links
# Hazaribagh | 1/27
# HZB AROGYAM MULTISPECIALITY HOSPITAL
# Hazaribagh | 2/27
# Aaash children Hospital A unit of Aaash neonatal hospital
# Hazaribagh | 3/27
# St. Columba's (Mission) Hospital
# Hazaribagh | 4/27
# Sadar Hospital Hazaribagh
# Hazaribagh | 5/27
# Godavari Hospitals Hazaribagh
# Hazaribagh | 6/27
# New Life Line Nursing Home & Maternity centre
# Hazaribagh | 7/27
# Apex hospital, Ekram Enclave, lohsingna hazaribagh
# Hazaribagh | 8/27
# Jaipuriar Hospital
# Hazaribagh | 9/27
# Veena General Hospital & Research Centre
# Hazaribagh | 10/27
# DVC Hospital Hazaribag
# Hazaribagh | 11/27
# Eshan Hospital and research centre
# Hazaribagh | 12/27
# Kshitij Hospital & Research centre
# Hazaribagh | 13/27
# HZB AROGYAM KUNAL WOMEN AND CHILDREN HOSPITAL
# Hazaribagh | 14/27
# Mahabir Hospital
# Hazaribagh | 15/27
# Aayushman Hospital
# Hazaribagh | 16/27
# Lifecare Hospital And Healthcare PVT LTD
# Hazaribagh | 17/27
# Raj Hospital
# Hazaribagh | 18/27
# Care Hospital
# Hazaribagh | 19/27
# Max Hospital
# Hazaribagh | 20/27
# Jpm Hospital
# Hazaribagh | 21/27
# City Child Hospital
# Hazaribagh | 22/27
# Hazaribagh Sadar Hospital Blood Bank
# Hazaribagh | 23/27
# Om Sunrises Hospital
# Hazaribagh | 24/27
# Orchid Medical Centre
# Hazaribagh | 25/27
# PHC Jarba
# Hazaribagh | 26/27
# Navjeevan Hospital
# Hazaribagh | 27/27
# Jeevan Anmol Hospital
#
# Searching: hospitals in Jamtara Jharkhand
# Search Submitted
# Jamtara | hospitals | Scroll 1 -> 14
# Jamtara | hospitals | Scroll 2 -> 20
# Jamtara | hospitals | Scroll 3 -> 20
# Jamtara | hospitals | Scroll 4 -> 20
# Jamtara | hospitals | Scroll 5 -> 20
# Jamtara | hospitals | Scroll 6 -> 20
# Collected 20 links
# Jamtara | 1/20
# Parmanand Hospital
# Jamtara | 2/20
# SADAR HOSPITAL (JAMTARA)
# Jamtara | 3/20
# Medisha Hospital
# Jamtara | 4/20
# JAMTARA MEMORIAL HOSPITAL
# Jamtara | 5/20
# City hospital
# Jamtara | 6/20
# PARAS HOSPITAL JAMTARA
# Jamtara | 7/20
# COMPLETE CARE HOSPITAL
# Jamtara | 8/20
# Sarita Clinic
# Jamtara | 9/20
# SHALIGRAM HOSPITAL , JAMTARA ( Dr. Vinod Kumar Saha)
# Jamtara | 10/20
# Sanjeevni Medicare
# Jamtara | 11/20
# S. S HOSPITAL, JAMTARA
# Jamtara | 12/20
# Sabina Hospital
# Jamtara | 13/20
# JAMTARA SEVA SADAN (NURSING HOME)
# Jamtara | 14/20
# Chikitsa Seva Sadan
# Jamtara | 15/20
# Popular Nursing Home
# Jamtara | 16/20
# Manglam Netralaya
# Jamtara | 17/20
# Sarita Medical
# Jamtara | 18/20
# PRIMARY HEALTH CENTER
# Jamtara | 19/20
# Govt. Hospital
# Jamtara | 20/20
# आयुष्मान हॉस्पिटल
#
# Searching: hospitals in Khunti Jharkhand
# Search Submitted
# Khunti | hospitals | Scroll 1 -> 12
# Khunti | hospitals | Scroll 2 -> 12
# Khunti | hospitals | Scroll 3 -> 12
# Khunti | hospitals | Scroll 4 -> 12
# Khunti | hospitals | Scroll 5 -> 12
# Collected 12 links
# Khunti | 1/12
# K S GANGA HOSPITAL AND RESEARCH CENTRE
# Khunti | 2/12
# Paradoc Hospital
# Khunti | 3/12
# Sadar Hospital
# Khunti | 4/12
# Rane Hospital
# Khunti | 5/12
# New Sadar Hospital, Khunti
# Khunti | 6/12
# S.G.V.S HOSPITAL AND RESEARCH CENTER
# Khunti | 7/12
# Nirmala Devi Trust Hospital
# Khunti | 8/12
# Aradhna Hospital
# Khunti | 9/12
# Summer Hospital & Research Centre Pvt Ltd.
# Khunti | 10/12
# Sgvs Hospital And Research Centre
# Khunti | 11/12
# Khunti CS Office
# Khunti | 12/12
# Faith & Felix Nursing Home
#
# Searching: hospitals in Koderma Jharkhand
# Search Submitted
# Koderma | hospitals | Scroll 1 -> 14
# Koderma | hospitals | Scroll 2 -> 14
# Koderma | hospitals | Scroll 3 -> 14
# Koderma | hospitals | Scroll 4 -> 14
# Koderma | hospitals | Scroll 5 -> 14
# Collected 14 links
# Koderma | 1/14
# Sadar Hospital Koderma
# Backup Saved
# Koderma | 2/14
# PEARL HOSPITAL
# Koderma | 3/14
# P G Hospital
# Koderma | 4/14
# Government Hospital
# Koderma | 5/14
# Bhagirathi Matri Sadan Hospital (BMS)
# Koderma | 6/14
# ARYAN HOSPITAL
# Koderma | 7/14
# JAY PRAKASH HOSPITAL
# Koderma | 8/14
# Care Hospital
# Koderma | 9/14
# District Tuberculosis Center, Koderma
# Koderma | 10/14
# MANGALAM HOSPITAL A MULTISPECIALITY UNIT
# Koderma | 11/14
# HOLY FAMILY HOSPITAL
# Koderma | 12/14
# Jeevan Jyoti Multispecialty Hospital & Maternity Centre
# Koderma | 13/14
# Manilal Memorial Hospital
# Koderma | 14/14
# Progressive Paramedical College & Hospital ,Koderma
#
# Searching: hospitals in Latehar Jharkhand
# Search Submitted
# Latehar | hospitals | Scroll 1 -> 3
# Latehar | hospitals | Scroll 2 -> 3
# Latehar | hospitals | Scroll 3 -> 3
# Latehar | hospitals | Scroll 4 -> 3
# Latehar | hospitals | Scroll 5 -> 3
# Collected 3 links
# Latehar | 1/3
# Sadar Hospital
# Latehar | 2/3
# CITY HOSPITAL
# Latehar | 3/3
# CHC LATEHAR
#
# Searching: hospitals in Lohardaga Jharkhand
# Search Submitted
# Lohardaga | hospitals | Scroll 1 -> 14
# Lohardaga | hospitals | Scroll 2 -> 20
# Lohardaga | hospitals | Scroll 3 -> 25
# Lohardaga | hospitals | Scroll 4 -> 25
# Lohardaga | hospitals | Scroll 5 -> 25
# Lohardaga | hospitals | Scroll 6 -> 25
# Lohardaga | hospitals | Scroll 7 -> 25
# Collected 23 links
# Lohardaga | 1/23
# MADHUR MEDICARE Trauma centre and Multispeciality Hospital
# Lohardaga | 2/23
# Lohardaga Nursing Home
# Lohardaga | 3/23
# Sai Nursing Home Lohardaga
# Lohardaga | 4/23
# Azad Hospital Lohardaga
# Lohardaga | 5/23
# Sanjeevni Hospital
# Lohardaga | 6/23
# Sadar Hospital Lohardaga
# Lohardaga | 7/23
# SUNRISE HOSPITAL LOHARDGA
# Lohardaga | 8/23
# JHARKHAND MULTICARE HOSPITAL ,🏥
# Lohardaga | 9/23
# RIVER VIEW HOSPITAL
# Lohardaga | 10/23
# Gautam Nursing Home Ortho & Trauma Centre
# Lohardaga | 11/23
# Neel Kamal Hospital, Lohardaga
# Lohardaga | 12/23
# Hannah Clinic Station Road Lohardaga
# Lohardaga | 13/23
# NEW SANJEEVANI HOSPITAL
# Lohardaga | 14/23
# JANTA HOSPITAL
# Lohardaga | 15/23
# Laxmi Nursing Home
# Lohardaga | 16/23
# VIJETA HOSPITAL LOHARDAGA
# Lohardaga | 17/23
# St Ursaline Hospital
# Lohardaga | 18/23
# Dutika Savitri Hospital
# Lohardaga | 19/23
# SURYA CLINIC
# Lohardaga | 20/23
# Ganesh Prasad Nursing Home
# Lohardaga | 21/23
# Gautam Nursing Home
# Lohardaga | 22/23
# Pesrar Sewa Sadan
# Lohardaga | 23/23
# Maa Nursing Home
#
# Searching: hospitals in Pakur Jharkhand
# Search Submitted
# Pakur | hospitals | Scroll 1 -> 10
# Pakur | hospitals | Scroll 2 -> 10
# Pakur | hospitals | Scroll 3 -> 10
# Pakur | hospitals | Scroll 4 -> 10
# Pakur | hospitals | Scroll 5 -> 10
# Collected 10 links
# Pakur | 1/10
# Pakur Nursing Home & Maternity Centre
# Pakur | 2/10
# KHUSHI HOSPITAL
# Pakur | 3/10
# P K Pathak Memorial HOSPITAL and DIAGNOASTIC
# Pakur | 4/10
# Global Health Care Hospital Pakur
# Pakur | 5/10
# LIFELINE HOSPITAL, SHAHARKOL, PAKUR
# Pakur | 6/10
# Sadar Hospital
# Pakur | 7/10
# Wellness Plus Medicals
# Pakur | 8/10
# SNEHA DRISHTI EYE HOSPITAL
# Pakur | 9/10
# R.A.M HEALTH CARE
# Pakur | 10/10
# Dr. S. N. Saha,Anand Clinic,Tantipara,Pakur
#
# Searching: hospitals in Palamu Jharkhand
# Search Submitted
# Palamu | hospitals | Scroll 1 -> 14
# Palamu | hospitals | Scroll 2 -> 20
# Palamu | hospitals | Scroll 3 -> 27
# Palamu | hospitals | Scroll 4 -> 28
# Palamu | hospitals | Scroll 5 -> 28
# Palamu | hospitals | Scroll 6 -> 28
# Palamu | hospitals | Scroll 7 -> 28
# Palamu | hospitals | Scroll 8 -> 28
# Collected 28 links
# Palamu | 1/28
# Dr.Rajesh Kumar (GAYATRI HOSPITAL)
# Palamu | 2/28
# Nav Jivan Hospital
# Palamu | 3/28
# PMCH (Palamu Medical College & Hospital)
# Palamu | 4/28
# Aashi Care Multi-Speciality Hospital
# Palamu | 5/28
# MEDNIRAI MEDICAL COLLEGE & HOSPITAL
# Palamu | 6/28
# Shri Narayan Multi-speciality Hospital
# Palamu | 7/28
# FS hospital
# Palamu | 8/28
# Palamu Medical College and Hospital
# Palamu | 9/28
# Maiya Babu Hospital
# Palamu | 10/28
# SH HOSPITAL
# Palamu | 11/28
# Shri Lilawati Hospital
# Palamu | 12/28
# Long Life Care Hospital
# Palamu | 13/28
# OPD Complex, MMCH Palamu
# Palamu | 14/28
# Vindhyachal Hospital
# Palamu | 15/28
# K K Hospital
# Palamu | 16/28
# Sanjeevani Hospital
# Palamu | 17/28
# Sadar Hospital
# Palamu | 18/28
# Sub Divisional Hospital, Husainabad
# Palamu | 19/28
# National health care hospital
# Palamu | 20/28
# New sunrise hospital & trauma centre
# Palamu | 21/28
# Dr Kiran Singh Clinic
# Palamu | 22/28
# Community Health Center,Chainpur
# Palamu | 23/28
# BTPS HOSPITAL,BOKARO THERMAL
# Palamu | 24/28
# Surya Sewa Sadan
# Palamu | 25/28
# Prakash eye care Rehla
# Palamu | 26/28
# Santevita Hospital
# Nagar Nigam Devkamal Hospital
# Ranchi | 40/47
# Rani Children Hospital & Research Centre
# Ranchi | 41/47
# City hospital piskaore
# Ranchi | 42/47
# Maa Ram Pyari Hospital
# Ranchi | 43/47
# S M MEMORIAL HOSPITAL
# Ranchi | 44/47
# Central Institute of Psychiatry
# Ranchi | 45/47
# Darbhanga hospital
# Ranchi | 46/47
# Manipal Hospital Oncology - Ranchi
# Ranchi | 47/47
# City Trust Hospital & Research Centre
#
# Searching: hospitals in Sahebganj Jharkhand
# Search Submitted
# Sahebganj | hospitals | Scroll 1 -> 14
# Sahebganj | hospitals | Scroll 2 -> 20
# Sahebganj | hospitals | Scroll 3 -> 20
# Sahebganj | hospitals | Scroll 4 -> 20
# Sahebganj | hospitals | Scroll 5 -> 20
# Sahebganj | hospitals | Scroll 6 -> 20
# Collected 20 links
# Sahebganj | 1/20
# SURYA SUPER SPECIALITY HOSPITAL
# Sahebganj | 2/20
# Siddhivinayak Multispeciality Hospital(SVMH)
# Sahebganj | 3/20
# SPARSH HOSPITAL
# Sahebganj | 4/20
# Jhumawati Hospital
# Sahebganj | 5/20
# Sadar Hospital
# Sahebganj | 6/20
# Ramaiyaa Care Hospital
# Sahebganj | 7/20
# Deep Hospital
# Sahebganj | 8/20
# Sehat Multi-speciality Clinic
# Sahebganj | 9/20
# Sadar Hospital
# Sahebganj | 10/20
# EYE HOSPITAL SAHIBGANJ
# Sahebganj | 11/20
# Manipal HealthMap (X-Ray Centre)
# Sahebganj | 12/20
# Railway Hospital Sahibganj
# Sahebganj | 13/20
# SURAJ HOSPITAL
# Sahebganj | 14/20
# Neo Child Clinic
# Sahebganj | 15/20
# VERMA EYE & EAR CLINIC
# Sahebganj | 16/20
# DR N.R ROY
# Sahebganj | 17/20
# Sahibganj Railway Health Unit Hospital Road
# Sahebganj | 18/20
# Dr C Lal
# Sahebganj | 19/20
# ADIBA CLINIC
# Sahebganj | 20/20
# Dr Bharati Pushpam Maternity Clinic
#
# Searching: hospitals in Seraikela Kharsawan Jharkhand
# Search Submitted
# Seraikela Kharsawan | hospitals | Scroll 1 -> 9
# Seraikela Kharsawan | hospitals | Scroll 2 -> 9
# Seraikela Kharsawan | hospitals | Scroll 3 -> 9
# Seraikela Kharsawan | hospitals | Scroll 4 -> 9
# Seraikela Kharsawan | hospitals | Scroll 5 -> 9
# Collected 8 links
# Seraikela Kharsawan | 1/8
# Sadar Hospital Saraikela Kharsawan (District Hospital)
# Seraikela Kharsawan | 2/8
# Vetenary Hospital Seraikela
# Seraikela Kharsawan | 3/8
# Govt Hospital Kharsawan
# Seraikela Kharsawan | 4/8
# Civil Surgeon Office Saraikela Kharsawan
# Seraikela Kharsawan | 5/8
# Dr.M.Das, Hospital
# Seraikela Kharsawan | 6/8
# Nutan Seva Sudan Hospital
# Seraikela Kharsawan | 7/8
# NUTAN SEVA SADAN NURSING HOME
# Seraikela Kharsawan | 8/8
# Hospital
#
# Searching: hospitals in Simdega Jharkhand
# Search Submitted
# Simdega | hospitals | Scroll 1 -> 11
# Simdega | hospitals | Scroll 2 -> 11
# Simdega | hospitals | Scroll 3 -> 11
# Simdega | hospitals | Scroll 4 -> 11
# Simdega | hospitals | Scroll 5 -> 11
# Collected 11 links
# Simdega | 1/11
# RAJ HOSPITAL SIMDEGA
# Simdega | 2/11
# Shanti Bhavan Medical Center - Best Hospital in Jharkhand
# Simdega | 3/11
# Sadar Hospital
# Simdega | 4/11
# SMS HOSPITAL
# Simdega | 5/11
# Sarwada Hospital
# Backup Saved
# Simdega | 6/11
# Aastha Hospital Multi-speciality Hospital,Khairantoli
# Simdega | 7/11
# Manipal HealthMap (CT-Scan/Ultrasound/ECG/X-Ray Center)
# Simdega | 8/11
# CHC SIMDEGA
# Simdega | 9/11
# Shivam hospital and research centre
# Simdega | 10/11
# Simdega Sadar Hospital Blood Bank
# Simdega | 11/11
# MISSION HOSPITAL
#
# Searching: hospitals in West Singhbhum Jharkhand
# Search Submitted
# West Singhbhum | hospitals | Scroll 1 -> 14
# West Singhbhum | hospitals | Scroll 2 -> 20
# West Singhbhum | hospitals | Scroll 3 -> 27
# West Singhbhum | hospitals | Scroll 4 -> 31
# West Singhbhum | hospitals | Scroll 5 -> 31
# West Singhbhum | hospitals | Scroll 6 -> 31
# West Singhbhum | hospitals | Scroll 7 -> 31
# West Singhbhum | hospitals | Scroll 8 -> 31
# Collected 27 links
# West Singhbhum | 1/27
# Community Health Center Chaibasa, Sadar (Sadar Hospital Campus)
# West Singhbhum | 2/27
# Mundhra Hospital
# West Singhbhum | 3/27
# Sunrise Hospital Advance Multi-speciality Care center
# West Singhbhum | 4/27
# Life hospital
# West Singhbhum | 5/27
# M B MEMORIAL HOSPITAL
# West Singhbhum | 6/27
# Gayatri Seva Sadan
# West Singhbhum | 7/27
# Life Line Nursingh Home
# West Singhbhum | 8/27
# St. Angela Hospital
# West Singhbhum | 9/27
# Sanjeev Netralaya Eyecare Private Limited
# West Singhbhum | 10/27
# Hospital In Chaibasa
# West Singhbhum | 11/27
# Srishti ultrasound and eye clinic Pump Road
# West Singhbhum | 12/27
# Ayushman Arogya Mandir Rugud pancho (Chaibasa Sadar)
# West Singhbhum | 13/27
# Dr. V.K.Mundra
# West Singhbhum | 14/27
# TATA MAIN HOSPITAL, JODA
# West Singhbhum | 15/27
# Sub divisional Hospital Chakradharpur
# West Singhbhum | 16/27
# Railway Hospital
# West Singhbhum | 17/27
# 111 SaveLife Hospital
# West Singhbhum | 18/27
# Ayushman Arogya Mandir AAM Gurasai
# West Singhbhum | 19/27
# Health Sub Center Baihatu
# West Singhbhum | 20/27
# Health Sub Center (HSC) Dumuria
# West Singhbhum | 21/27
# Chakradharpur Children Clinic
# West Singhbhum | 22/27
# Ayushman Arogya Mandir Toklo
# West Singhbhum | 23/27
# New Oxford Hospital
# West Singhbhum | 24/27
# Anganwadi Centre Jaipur
# West Singhbhum | 25/27
# Hospital 🏥
# West Singhbhum | 26/27
# HEALTH SUB CENTRE (HSC) PARSA
# West Singhbhum | 27/27
# partha sarathi roy
#
# Extraction Completed
# Total Hospitals Extracted: 533
#
# Saved File: jharkhand_hospitals.csv
