# %%
import time
import random
import pandas as pd

from datetime import datetime

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.service import Service

from webdriver_manager.chrome import ChromeDriverManager


districts = [
    "Almora",
    "Bageshwar",
    "Chamoli",
    "Champawat",
    "Dehradun",
    "Haridwar",
    "Nainital",
    "Pauri Garhwal",
    "Pithoragarh",
    "Rudraprayag",
    "Tehri Garhwal",
    "Udham Singh Nagar",
    "Uttarkashi"
]


search_types = [
    "hospitals"
]


options = webdriver.ChromeOptions()

options.add_argument("--start-maximized")

options.add_argument(
    "--disable-blink-features=AutomationControlled"
)

options.add_argument("--disable-notifications")


driver = webdriver.Chrome(

    service=Service(
        ChromeDriverManager().install()
    ),

    options=options
)


driver.get("https://www.google.com/maps")

print("Opening Google Maps...")

time.sleep(15)

print("Google Maps Loaded")


all_data = []

visited_links = set()


def get_search_box():

    selectors = [

        '//input[@id="searchboxinput"]',
        '//input[contains(@placeholder,"Search")]',
        '//input[contains(@aria-label,"Search")]',
        '//input'

    ]

    for selector in selectors:

        try:

            box = driver.find_element(
                By.XPATH,
                selector
            )

            return box

        except:
            pass

    return None

def extract_school_data():

    try:


        try:
            name = driver.find_element(
                By.TAG_NAME,
                "h1"
            ).text
        except:
            name = ""

        try:
            address = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"address")]'
            ).text
        except:
            address = ""


        try:
            phone = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"phone")]'
            ).text
        except:
            phone = ""

        try:
            website = driver.find_element(
                By.XPATH,
                '//a[contains(@data-item-id,"authority")]'
            ).get_attribute("href")
        except:
            website = ""

        try:
            rating = driver.find_element(
                By.XPATH,
                '//div[@role="img"]'
            ).get_attribute("aria-label")
        except:
            rating = ""

        return {

            "Hospital Name": name,
            "Address": address,
            "Phone": phone,
            "Website": website,
            "Rating": rating,
            "Google Maps URL": driver.current_url

        }

    except:

        return None

for district in districts:

    for search_type in search_types:

        try:

            query = (
                f"{search_type} "
                f"in {district} Uttarakhand"
            )

            print(f"\nSearching: {query}")


            search_box = get_search_box()

            if not search_box:

                print("Search Box Not Found")

                continue

            ActionChains(driver).move_to_element(
                search_box
            ).click().perform()

            time.sleep(1)

            search_box.send_keys(
                Keys.CONTROL + "a"
            )

            time.sleep(1)

            search_box.send_keys(Keys.DELETE)

            time.sleep(1)

            # TYPE SLOWLY
            for char in query:

                search_box.send_keys(char)

                time.sleep(0.03)

            search_box.send_keys(Keys.ENTER)

            print("Search Submitted")

            time.sleep(8)


            try:

                scrollable_div = driver.find_element(
                    By.XPATH,
                    '//div[@role="feed"]'
                )

                previous_count = 0

                stagnant = 0

                for i in range(100):

                    driver.execute_script(
                        """
                        arguments[0].scrollTop =
                        arguments[0].scrollHeight
                        """,
                        scrollable_div
                    )


                    time.sleep(4)

                    listings = driver.find_elements(
                        By.XPATH,
                        '//a[contains(@href,"/maps/place/")]'
                    )

                    current_count = len(listings)

                    print(
                        f"{district} | "
                        f"{search_type} | "
                        f"Scroll {i+1} -> "
                        f"{current_count}"
                    )

                    if current_count == previous_count:

                        stagnant += 1

                    else:

                        stagnant = 0

                    if stagnant >= 4:

                        break

                    previous_count = current_count

            except Exception as e:

                print(f"Scrolling Error: {e}")



            listings = driver.find_elements(
                By.XPATH,
                '//a[contains(@href,"/maps/place/")]'
            )

            links = []

            for listing in listings:

                try:

                    link = listing.get_attribute("href")

                    if (
                        link
                        and link not in visited_links
                    ):

                        links.append(link)

                        visited_links.add(link)

                except:
                    pass

            print(f"Collected {len(links)} links")


            for index, link in enumerate(links):

                try:

                    print(
                        f"{district} | "
                        f"{index+1}/{len(links)}"
                    )

                    driver.get(link)

                    time.sleep(
                        random.uniform(2, 4)
                    )

                    data = extract_school_data()

                    if data:

                        data["District"] = district

                        data["Search Type"] = search_type

                        all_data.append(data)

                        print(data["Hospital Name"])


                    if len(all_data) % 100 == 0:

                        backup_df = pd.DataFrame(
                            all_data
                        )

                        backup_df.drop_duplicates(
                            subset=[
                                "Hospital Name",
                                "Google Maps URL"
                            ],
                            inplace=True
                        )

                        backup_filename = (
                            "uttarakhand_backup.csv"
                        )

                        backup_df.to_csv(
                            backup_filename,
                            index=False
                        )

                        print("Backup Saved")

                except Exception as e:

                    print(
                        f"School Error: {e}"
                    )

        except Exception as e:

            print(
                f"District Error: {e}"
            )


df = pd.DataFrame(all_data)

df.drop_duplicates(

    subset=[
        "Hospital Name",
        "Google Maps URL"
    ],

    inplace=True
)


filename = (
    "uttarakhand_hospitals.csv"
)

df.to_csv(
    filename,
    index=False
)

print("\nExtraction Completed")

print(
    f"Total Hospitals Extracted: {len(df)}"
)

print(f"\nSaved File: {filename}")

driver.quit()
# Out:
# Opening Google Maps...
# Google Maps Loaded
#
# Searching: hospitals in Almora Uttarakhand
# Search Submitted
# Almora | hospitals | Scroll 1 -> 14
# Almora | hospitals | Scroll 2 -> 14
# Almora | hospitals | Scroll 3 -> 14
# Almora | hospitals | Scroll 4 -> 14
# Almora | hospitals | Scroll 5 -> 14
# Collected 14 links
# Almora | 1/14
# District Hospital Almora
# Almora | 2/14
# Jeevan Jyoti Hospital and Laparoscopy center , Almora
# Almora | 3/14
# Goverdhan Tiwari Government Base Hospital
# Almora | 4/14
# M N Srivastava Hospital
# Almora | 5/14
# Idbo
# Almora | 6/14
# AyurVAID Kalmatia - Centre of Healing in Almora, Uttrakhand
# Almora | 7/14
# District hospital
# Almora | 8/14
# The Leprosy Mission Hospital & Home
# Almora | 9/14
# Dr gusain Hospital and Dev medical store
# Almora | 10/14
# Govind Singh Mehra Government Hospital
# Almora | 11/14
# ANJALI HOSPITAL MATERNITY & CHILD CARE CENTRE
# Almora | 12/14
# Soban Singh Jeena Government Institute of Medical Science & Research
# Almora | 13/14
# Civil Hospital Ranikhet
# Almora | 14/14
# CMO ALMORA
#
# Searching: hospitals in Bageshwar Uttarakhand
# Search Submitted
# Bageshwar | hospitals | Scroll 1 -> 8
# Bageshwar | hospitals | Scroll 2 -> 8
# Bageshwar | hospitals | Scroll 3 -> 8
# Bageshwar | hospitals | Scroll 4 -> 8
# Bageshwar | hospitals | Scroll 5 -> 8
# Collected 8 links
# Bageshwar | 1/8
#
# Bageshwar | 2/8
#
# Bageshwar | 3/8
#
# Bageshwar | 4/8
#
# Bageshwar | 5/8
#
# Bageshwar | 6/8
#
# Bageshwar | 7/8
#
# Bageshwar | 8/8
#
#
# Searching: hospitals in Chamoli Uttarakhand
# Search Submitted
# Chamoli | hospitals | Scroll 1 -> 6
# Chamoli | hospitals | Scroll 2 -> 6
# Chamoli | hospitals | Scroll 3 -> 6
# Chamoli | hospitals | Scroll 4 -> 6
# Chamoli | hospitals | Scroll 5 -> 6
# Collected 6 links
# Chamoli | 1/6
#
# Chamoli | 2/6
#
# Chamoli | 3/6
# Primary Health Centre, Chamoli
# Chamoli | 4/6
# Government Allopathic Hospital
# Chamoli | 5/6
# The Hans Foundation General Hospital (THFGH), Satpuli
# Chamoli | 6/6
# Shriram gireel centre near pashu plan hospital chamoli
#
# Searching: hospitals in Champawat Uttarakhand
# Search Submitted
# Champawat | hospitals | Scroll 1 -> 3
# Champawat | hospitals | Scroll 2 -> 3
# Champawat | hospitals | Scroll 3 -> 3
# Champawat | hospitals | Scroll 4 -> 3
# Champawat | hospitals | Scroll 5 -> 3
# Collected 3 links
# Champawat | 1/3
# Jeevan Anmol Multi Speciality Hospital
# Champawat | 2/3
# District Hospital champawat
# Champawat | 3/3
# Karnatic Hospital
#
# Searching: hospitals in Dehradun Uttarakhand
# Search Submitted
# Dehradun | hospitals | Scroll 1 -> 14
# Dehradun | hospitals | Scroll 2 -> 20
# Dehradun | hospitals | Scroll 3 -> 27
# Dehradun | hospitals | Scroll 4 -> 34
# Dehradun | hospitals | Scroll 5 -> 40
# Dehradun | hospitals | Scroll 6 -> 47
# Dehradun | hospitals | Scroll 7 -> 54
# Dehradun | hospitals | Scroll 8 -> 60
# Dehradun | hospitals | Scroll 9 -> 62
# Dehradun | hospitals | Scroll 10 -> 62
# Dehradun | hospitals | Scroll 11 -> 62
# Dehradun | hospitals | Scroll 12 -> 62
# Dehradun | hospitals | Scroll 13 -> 62
# Collected 62 links
# Dehradun | 1/62
# Max Super Speciality Hospital, Dehradun
# Dehradun | 2/62
# Shri Mahant Indiresh Hospital
# Dehradun | 3/62
# Kanishk Surgical & Super Specialty Hospital
# Dehradun | 4/62
# Synergy Institute of Medical Sciences
# Dehradun | 5/62
# Velmed Hospital
# Dehradun | 6/62
# 𝗡𝗮𝗻𝗱𝗮 𝗛𝗼𝘀𝗽𝗶𝘁𝗮𝗹 - Nursing Home/Best Hospital/Physician/Obs Gynae Hospital in Dehradun
# Dehradun | 7/62
# Medilife Superspeciality Hospital: Premier Multispeciality Hospital and Private Hospital
# Dehradun | 8/62
# Panacea Super Speciality Hospital Dehradun | Best Hospital in Dehradun
# Dehradun | 9/62
# Dehradun Superspeciality Hospital
# Dehradun | 10/62
# Baluni Hospital
# Dehradun | 11/62
# Kailash Hospital
# Dehradun | 12/62
# Vibhuti Super Speciality Hospital
# Dehradun | 13/62
# 𝗖𝗶𝘁𝘆 𝗛𝗲𝗮𝗿𝘁 𝗖𝗲𝗻𝘁𝗿𝗲- Emergency/Heart/Best Cardiac Doctor/Best Hospital in Dehradun
# Dehradun | 14/62
# Government Doon Medical College Hospital
# Dehradun | 15/62
# Aarogyadham Super Speciality Hospital & Research Center
# Dehradun | 16/62
# Graphic Era Hospital
# Dehradun | 17/62
# Blue Mountains Hospital - Best Multispeciality Hospital in Dehradun
# Ramsay Hospital
# Nainital | 2/8
# B.D Pandey Hospital Nainital
# Nainital | 3/8
# B.D Pandey District Hospital
# Nainital | 4/8
# City Hospital Haldwani
# Nainital | 5/8
# Krishna Hospital & Research Centre
# Nainital | 6/8
# Ujala Cygnus Central Hospital
# Nainital | 7/8
# Brij Lal Hospital Haldwani
# Nainital | 8/8
# Aries Dispensary
#
# Searching: hospitals in Pauri Garhwal Uttarakhand
# Search Submitted
# Pauri Garhwal | hospitals | Scroll 1 -> 4
# Pauri Garhwal | hospitals | Scroll 2 -> 4
# Pauri Garhwal | hospitals | Scroll 3 -> 4
# Pauri Garhwal | hospitals | Scroll 4 -> 4
# Pauri Garhwal | hospitals | Scroll 5 -> 4
# Collected 4 links
# Pauri Garhwal | 1/4
# District Hospital Pauri
# Pauri Garhwal | 2/4
# Hemwati Nandan Bahuguna Base Hospital, Srinagar
# Pauri Garhwal | 3/4
# Government Women Hospital
# Pauri Garhwal | 4/4
# CHC,SATPULI
#
# Searching: hospitals in Pithoragarh Uttarakhand
# Search Submitted
# Pithoragarh | hospitals | Scroll 1 -> 14
# Pithoragarh | hospitals | Scroll 2 -> 20
# Pithoragarh | hospitals | Scroll 3 -> 20
# Pithoragarh | hospitals | Scroll 4 -> 20
# Pithoragarh | hospitals | Scroll 5 -> 20
# Pithoragarh | hospitals | Scroll 6 -> 20
# Collected 20 links
# Pithoragarh | 1/20
# BISHT HOSPITAL
# Pithoragarh | 2/20
# City hospital
# Pithoragarh | 3/20
# Sanjeevani hospital
# Pithoragarh | 4/20
# Healing Touch Hospital
# Pithoragarh | 5/20
# BISHT DIAGNOSTICS AND HOSPITAL
# Pithoragarh | 6/20
# B. D. Pandey District Hospital Blood Bank
# Pithoragarh | 7/20
# Sri Narayan Hospital
# Pithoragarh | 8/20
# Basera Hospital
# Pithoragarh | 9/20
# Kharkwal Hospital
# Pithoragarh | 10/20
# Base Hospital, Pithoragarh
# Pithoragarh | 11/20
# Kilkari Hospital
# Pithoragarh | 12/20
# Renu Jagdish Diagnostic & Trauma Centre
# Pithoragarh | 13/20
# Tuberculosis Hospital
# Pithoragarh | 14/20
# Sanwal Nursing Home
# Pithoragarh | 15/20
# TB Hospital
# Pithoragarh | 16/20
# Uttarakhand
# Pithoragarh | 17/20
# Zila Mahila Chikitsalaya (District Lady's Hospital)
# Pithoragarh | 18/20
# Seemant Hospital
# Pithoragarh | 19/20
# Get Well Hospital
# Pithoragarh | 20/20
# Mangal Murti Dental Clinic
#
# Searching: hospitals in Rudraprayag Uttarakhand
# Search Submitted
# Rudraprayag | hospitals | Scroll 1 -> 4
# Rudraprayag | hospitals | Scroll 2 -> 4
# Rudraprayag | hospitals | Scroll 3 -> 4
# Rudraprayag | hospitals | Scroll 4 -> 4
# Rudraprayag | hospitals | Scroll 5 -> 4
# Collected 4 links
# Rudraprayag | 1/4
# Jankalyan hospital Rudraprayag
# Rudraprayag | 2/4
# District Hospital Rudraprayag
# Rudraprayag | 3/4
# Government Hospital, Rudraprayag
# Rudraprayag | 4/4
# Hospital
#
# Searching: hospitals in Tehri Garhwal Uttarakhand
# Search Submitted
# Tehri Garhwal | hospitals | Scroll 1 -> 4
# Tehri Garhwal | hospitals | Scroll 2 -> 4
# Tehri Garhwal | hospitals | Scroll 3 -> 4
# Tehri Garhwal | hospitals | Scroll 4 -> 4
# Tehri Garhwal | hospitals | Scroll 5 -> 4
# Collected 4 links
# Tehri Garhwal | 1/4
# District Hospital
# Tehri Garhwal | 2/4
# Primary Health Centre - Hospital
# Tehri Garhwal | 3/4
# Hospital Prapnagar Tehri Garhwal Uttarakhand
# Tehri Garhwal | 4/4
# Masiha Hospital, Chamba, Tehri Garhwal, Uttarkhand
#
# Searching: hospitals in Udham Singh Nagar Uttarakhand
# Search Submitted
# Udham Singh Nagar | hospitals | Scroll 1 -> 14
# Udham Singh Nagar | hospitals | Scroll 2 -> 20
# Udham Singh Nagar | hospitals | Scroll 3 -> 27
# Udham Singh Nagar | hospitals | Scroll 4 -> 34
# Udham Singh Nagar | hospitals | Scroll 5 -> 40
# Udham Singh Nagar | hospitals | Scroll 6 -> 47
# Udham Singh Nagar | hospitals | Scroll 7 -> 54
# Udham Singh Nagar | hospitals | Scroll 8 -> 59
# Udham Singh Nagar | hospitals | Scroll 9 -> 59
# Udham Singh Nagar | hospitals | Scroll 10 -> 59
# Udham Singh Nagar | hospitals | Scroll 11 -> 59
# Udham Singh Nagar | hospitals | Scroll 12 -> 59
# Collected 57 links
# Udham Singh Nagar | 1/57
# The Medicity Hospital Rudrapur
# Udham Singh Nagar | 2/57
# HB SPECIALITY HOSPITAL & RESEARCH INSTITUTE
# Udham Singh Nagar | 3/57
# Ahan Hospital and Diagnostic Centre
# Udham Singh Nagar | 4/57
# Gautam Hospital
# Udham Singh Nagar | 5/57
# Futela Hospital, Rudrapur
# Udham Singh Nagar | 6/57
# Anand Hospital and Research Center || Best Hospital | Multispeciality Hospital
# Udham Singh Nagar | 7/57
# District Hospital
# Udham Singh Nagar | 8/57
# Guru Ramdas Hospital
# Udham Singh Nagar | 9/57
# Ujala Cygnus SH Multi speciality hospital
# Udham Singh Nagar | 10/57
# Jeevan jyoti multispeciality hospital
# Udham Singh Nagar | 11/57
# Narayan Hospital And Trauma Centre
# Udham Singh Nagar | 12/57
# Arora Hospital - Dr Jitesh Arora
# Udham Singh Nagar | 13/57
# Dr Pande Hospital
# Udham Singh Nagar | 14/57
# Prayas Hospital & Research Centre
# Udham Singh Nagar | 15/57
# Surabhi Hospital - Laparoscopy/Ultrasound - TA/TVS/Doppler Scan/Phototherapy/Hysteroscopy/ICSI/IVF/IUI
# Udham Singh Nagar | 16/57
# Government Hospital
# Udham Singh Nagar | 17/57
# RUDRA HOSPITAL AND MATERNITY HOME
# Udham Singh Nagar | 18/57
# Nanak Hospital | Best Dentist in Khatima | Dental Clinic in Khatima| Skin hair and laser clinic in Khatima
# Udham Singh Nagar | 19/57
# Sparsh Hospital
# Udham Singh Nagar | 20/57
