# %%
import pandas as pd

# %%
df = pd.read_csv("uttarakhand_hospitals.csv")

# %%
df.shape
# Out:
# (227, 8)

# %%
duplicate_count = df.duplicated(
    subset=["Hospital Name", "Google Maps URL"]
).sum()
duplicate_count
# Out:
# np.int64(0)

# %%
df = df[
    df["Phone"].notna() & 
    (df["Phone"].astype(str).str.strip() != "")
    ]
df.shape
# Out:
# (9, 8)

# %%
df = df[
    df["Hospital Name"].notna()
    ]

df = df[
    df["Hospital Name"].str.strip() != ""
    ]
df.shape
# Out:
# (9, 8)

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]","",regex=True)
    .str.strip()
)

display(df[["Phone"]].head())
# Out:
#            Phone
# 3   099276 88806
# 5   096112 02918
# 8   094565 45366
# 11  094124 10759
# 88  097593 70795

# %%
# SAVE CLEANED FILE
df.to_csv(
    "uttrakhand_hospitals_cleaned.csv",
    index=False
)
