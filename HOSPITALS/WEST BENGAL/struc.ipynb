# %%
import pandas as pd

# %%
df = pd.read_csv("west_bengal_hospitals.csv")

# %%
df.shape
# Out:
# (896, 8)

# %%
df = df[
    df["Phone"].notna() &
    (df["Phone"].astype(str).str.strip() != "")
]
df.shape
# Out:
# (433, 8)

# %%
df = df[
    df["Hospital Name"].notna()
]

df = df[
    df["Hospital Name"].str.strip() != ""
]
df.shape
# Out:
# (432, 8)

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]", "", regex=True)  # remove symbols/icons
    .str.strip()
)

display(df[["Phone"]].head())
# Out:
#            Phone
# 3   096144 34655
# 5   081700 27777
# 6  03564 255 938
# 7  03564 356 542
# 9  03564 255 668

# %%
df.to_csv(
    "west_bengal_hospitals_cleaned.csv",
    index=False
)
