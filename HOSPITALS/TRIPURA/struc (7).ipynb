# %%
import pandas as pd

# %%
df = pd.read_csv("tripura_hospitals.csv")

# %%
df.shape
# Out:
# (102, 8)

# %%
df = df[
    df["Phone"].notna() &
    (df["Phone"].astype(str).str.strip() != "")
]

# %%
df.shape
# Out:
# (30, 8)

# %%
df = df[
    df["Hospital Name"].notna()
]

df = df[
    df["Hospital Name"].str.strip() != ""
]

# %%
df.shape
# Out:
# (30, 8)

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]", "", regex=True)  # remove symbols/icons
    .str.strip()
)


display(df[["Phone"]].head())
# Out:
#            Phone
# 4   088370 47007
# 7   087986 11275
# 8   089740 50300
# 15  089746 12683
# 20  082590 20486

# %%
df.to_csv(
    "tripura_hospitals_cleaned.csv",
    index=False
)
