# %%
import time
import random
import pandas as pd

from datetime import datetime

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.service import Service

from webdriver_manager.chrome import ChromeDriverManager


districts = [

    "Dhalai",
    "Gomati",
    "Khowai",
    "North Tripura",
    "Sepahijala",
    "South Tripura",
    "Unakoti",
    "West Tripura"

]



search_types = [
    "hospitals"
]



options = webdriver.ChromeOptions()

options.add_argument("--start-maximized")

options.add_argument(
    "--disable-blink-features=AutomationControlled"
)

options.add_argument("--disable-notifications")



driver = webdriver.Chrome(

    service=Service(
        ChromeDriverManager().install()
    ),

    options=options
)


driver.get("https://www.google.com/maps")

print("Opening Google Maps...")

time.sleep(15)

print("Google Maps Loaded")


all_data = []

visited_links = set()



def get_search_box():

    selectors = [

        '//input[@id="searchboxinput"]',
        '//input[contains(@placeholder,"Search")]',
        '//input[contains(@aria-label,"Search")]',
        '//input'

    ]

    for selector in selectors:

        try:

            box = driver.find_element(
                By.XPATH,
                selector
            )

            return box

        except:
            pass

    return None



def extract_school_data():

    try:

        try:
            name = driver.find_element(
                By.TAG_NAME,
                "h1"
            ).text
        except:
            name = ""

   
        try:
            address = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"address")]'
            ).text
        except:
            address = ""

        try:
            phone = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"phone")]'
            ).text
        except:
            phone = ""


        try:
            website = driver.find_element(
                By.XPATH,
                '//a[contains(@data-item-id,"authority")]'
            ).get_attribute("href")
        except:
            website = ""


        try:
            rating = driver.find_element(
                By.XPATH,
                '//div[@role="img"]'
            ).get_attribute("aria-label")
        except:
            rating = ""

        return {

            "Hospital Name": name,
            "Address": address,
            "Phone": phone,
            "Website": website,
            "Rating": rating,
            "Google Maps URL": driver.current_url

        }

    except:

        return None


for district in districts:

    for search_type in search_types:

        try:

            query = (
                f"{search_type} "
                f"in {district} Tripura"
            )

            print(f"\nSearching: {query}")


            search_box = get_search_box()

            if not search_box:

                print("Search Box Not Found")

                continue

            ActionChains(driver).move_to_element(
                search_box
            ).click().perform()

            time.sleep(1)

            search_box.send_keys(
                Keys.CONTROL + "a"
            )

            time.sleep(1)

            search_box.send_keys(Keys.DELETE)

            time.sleep(1)


            for char in query:

                search_box.send_keys(char)

                time.sleep(0.03)

            search_box.send_keys(Keys.ENTER)

            print("Search Submitted")

            time.sleep(8)

            try:

                scrollable_div = driver.find_element(
                    By.XPATH,
                    '//div[@role="feed"]'
                )

                previous_count = 0

                stagnant = 0

                for i in range(100):

                    driver.execute_script(
                        """
                        arguments[0].scrollTop =
                        arguments[0].scrollHeight
                        """,
                        scrollable_div

                    time.sleep(4)

                    listings = driver.find_elements(
                        By.XPATH,
                        '//a[contains(@href,"/maps/place/")]'
                    )

                    current_count = len(listings)

                    print(
                        f"{district} | "
                        f"{search_type} | "
                        f"Scroll {i+1} -> "
                        f"{current_count}"
                    )

                    if current_count == previous_count:

                        stagnant += 1

                    else:

                        stagnant = 0


                    if stagnant >= 4:

                        break

                    previous_count = current_count

            except Exception as e:

                print(f"Scrolling Error: {e}")



            listings = driver.find_elements(
                By.XPATH,
                '//a[contains(@href,"/maps/place/")]'
            )

            links = []

            for listing in listings:

                try:

                    link = listing.get_attribute("href")

                    if (
                        link
                        and link not in visited_links
                    ):

                        links.append(link)

                        visited_links.add(link)

                except:
                    pass

            print(f"Collected {len(links)} links")


            for index, link in enumerate(links):

                try:

                    print(
                        f"{district} | "
                        f"{index+1}/{len(links)}"
                    )

                    driver.get(link)

                    time.sleep(
                        random.uniform(2, 4)
                    )

                    data = extract_school_data()

                    if data:

                        data["District"] = district

                        data["Search Type"] = search_type

                        all_data.append(data)

                        print(data["Hospital Name"])

   
         

                    if len(all_data) % 100 == 0:

                        backup_df = pd.DataFrame(
                            all_data
                        )

                        backup_df.drop_duplicates(
                            subset=[
                                "Hospital Name",
                                "Google Maps URL"
                            ],
                            inplace=True
                        )

                        backup_filename = (
                            "tripura_backup.csv"
                        )

                        backup_df.to_csv(
                            backup_filename,
                            index=False
                        )

                        print("Backup Saved")

                except Exception as e:

                    print(
                        f"School Error: {e}"
                    )

        except Exception as e:

            print(
                f"District Error: {e}"
            )


df = pd.DataFrame(all_data)

df.drop_duplicates(

    subset=[
        "Hospital Name",
        "Google Maps URL"
    ],

    inplace=True
)



filename = (
    "tripura_hospitals.csv"
)

df.to_csv(
    filename,
    index=False
)

print("\nExtraction Completed")

print(
    f"Total Schools Extracted: {len(df)}"
)

print(f"\nSaved File: {filename}")

driver.quit()
# Out:
# Opening Google Maps...
# Google Maps Loaded
#
# Searching: hospitals in Dhalai Tripura
# Search Submitted
# Dhalai | hospitals | Scroll 1 -> 16
# Dhalai | hospitals | Scroll 2 -> 20
# Dhalai | hospitals | Scroll 3 -> 22
# Dhalai | hospitals | Scroll 4 -> 22
# Dhalai | hospitals | Scroll 5 -> 22
# Dhalai | hospitals | Scroll 6 -> 22
# Dhalai | hospitals | Scroll 7 -> 22
# Collected 22 links
# Dhalai | 1/22
# Dhalai District Hospital,Kulai
# Dhalai | 2/22
# Bimal Sinha Memorial Hospital
# Dhalai | 3/22
# Longtharai Valley Sub-Divisional Hospital, Chailengta
# Dhalai | 4/22
# Dhalai District Hospital Emergency Cum Trauma Centre
# Dhalai | 5/22
# Dhalai Nursing Home and Heath Care
# Dhalai | 6/22
# 82 Mile Hospital PHC
# Dhalai | 7/22
# Kanchanbari Hospital
# Dhalai | 8/22
# Marachara Phc
# Dhalai | 9/22
# ILS Hospitals, Agartala
# Dhalai | 10/22
# Daluchara Ayorbedik Hospital
# Dhalai | 11/22
# Makunda Christian Leprosy & General Hospital
# Dhalai | 12/22
# Nepaltilla PHC
# Dhalai | 13/22
# Manikpur Primary Health Center
# Dhalai | 14/22
# Kherengbar Hospital, Khumulwng
# Dhalai | 15/22
# Chief Medical Officer, Dhalai
# Dhalai | 16/22
# Kalachara Hospital
# Dhalai | 17/22
# Lalcherra PHC
# Dhalai | 18/22
# Jagabandhu Para Primary Health Centre
# Dhalai | 19/22
# Sub Health And Wellness Center
# Dhalai | 20/22
# Salema PHC
# Dhalai | 21/22
# New Laxminarayan Medical Hall
# Dhalai | 22/22
# Jagannathpur Health SUb Centre Dhalai
#
# Searching: hospitals in Gomati Tripura
# Search Submitted
# Gomati | hospitals | Scroll 1 -> 13
# Gomati | hospitals | Scroll 2 -> 13
# Gomati | hospitals | Scroll 3 -> 13
# Gomati | hospitals | Scroll 4 -> 13
# Gomati | hospitals | Scroll 5 -> 13
# Collected 12 links
# Gomati | 1/12
# Gomati District Hospital, Udaipur
# Gomati | 2/12
# Tripura Sundari Hospital
# Gomati | 3/12
# Amarpur Sub-Divisional Hospital
# Gomati | 4/12
# Tulamura PHC Hospital
# Gomati | 5/12
# Chief Medical Officer - Gomati District
# Gomati | 6/12
# IGM Hospital
# Gomati | 7/12
# Agartala Government Medical College & Govind Ballabh Pant Hospital
# Gomati | 8/12
# Telkajla Health Center
# Gomati | 9/12
# Karbook Hospital
# Gomati | 10/12
# Gomati Hospital
# Gomati | 11/12
# Ghorakappa PHC
# Gomati | 12/12
# Atharabhola PHC
#
# Searching: hospitals in Khowai Tripura
# Search Submitted
# Khowai | hospitals | Scroll 1 -> 3
# Khowai | hospitals | Scroll 2 -> 3
# Khowai | hospitals | Scroll 3 -> 3
# Khowai | hospitals | Scroll 4 -> 3
# Khowai | hospitals | Scroll 5 -> 3
# Collected 3 links
# Khowai | 1/3
# Old Hospital Khowai.
# Khowai | 2/3
# District Hospital Khowai
# Khowai | 3/3
# Hospital road khowai
#
# Searching: hospitals in North Tripura Tripura
# Search Submitted
# North Tripura | hospitals | Scroll 1 -> 16
# North Tripura | hospitals | Scroll 2 -> 20
# North Tripura | hospitals | Scroll 3 -> 25
# North Tripura | hospitals | Scroll 4 -> 25
# North Tripura | hospitals | Scroll 5 -> 25
# North Tripura | hospitals | Scroll 6 -> 25
# North Tripura | hospitals | Scroll 7 -> 25
# Collected 19 links
# North Tripura | 1/19
# District Hospital, North Tripura
# North Tripura | 2/19
# Unakoti Hospital
# North Tripura | 3/19
# SANICHERRA PHC
# North Tripura | 4/19
# Unakoti Hospital, Tripura
# North Tripura | 5/19
# Takshashila Nursing Home
# North Tripura | 6/19
# TILTHAI HOSPITAL
# North Tripura | 7/19
# Shrestha Eye Hospital
# North Tripura | 8/19
# Integrated AYUSH Hospital
# North Tripura | 9/19
# The North Tripura Clinic
# North Tripura | 10/19
# Jalabasa Hospital
# North Tripura | 11/19
# District Hospital Unakoti
# North Tripura | 12/19
# St. Joseph's Hospital
# North Tripura | 13/19
# Irani Hospital
# North Tripura | 14/19
# P.C Chatterjee Memorial Eye Hospital
# North Tripura | 15/19
# Sub Divisional Hospital Gonda Twisa
# North Tripura | 16/19
# District Hospital, Santirbazar
# North Tripura | 17/19
# Hrishyamukh Hospital
# North Tripura | 18/19
# Health Cure Nursing Home
# North Tripura | 19/19
# CMO NORTH
#
# Searching: hospitals in Sepahijala Tripura
# Search Submitted
# Sepahijala | hospitals | Scroll 1 -> 2
# Sepahijala | hospitals | Scroll 2 -> 2
# Sepahijala | hospitals | Scroll 3 -> 2
# Sepahijala | hospitals | Scroll 4 -> 2
# Sepahijala | hospitals | Scroll 5 -> 2
# Collected 1 links
# Sepahijala | 1/1
# Sepahijala District Hospital
#
# Searching: hospitals in South Tripura Tripura
# Search Submitted
# South Tripura | hospitals | Scroll 1 -> 16
# South Tripura | hospitals | Scroll 2 -> 20
# South Tripura | hospitals | Scroll 3 -> 28
# South Tripura | hospitals | Scroll 4 -> 36
# South Tripura | hospitals | Scroll 5 -> 38
# South Tripura | hospitals | Scroll 6 -> 38
# South Tripura | hospitals | Scroll 7 -> 38
# South Tripura | hospitals | Scroll 8 -> 38
# South Tripura | hospitals | Scroll 9 -> 38
# Collected 22 links
# South Tripura | 1/22
# Sabroom Sub-Divisional Hospital
# South Tripura | 2/22
# Manu Bazar Rural Hospital
# South Tripura | 3/22
# Melaghar Hospital
# South Tripura | 4/22
# CHELLAGANG HOSPITAL
# South Tripura | 5/22
# Jolaibari CHC
# South Tripura | 6/22
# Bishalgarh Sub-Divisional Hospital
# South Tripura | 7/22
# Tripura Medical College and Dr. BRAM Teaching Hospital
# South Tripura | 8/22
# Sonamura Gramin Hospital
# South Tripura | 9/22
# Bairagi Bazar Hospital
# South Tripura | 10/22
# Unity Gastro & Liver Hospital | Gastroenterologist, Hematology, Liver Transplant, Kidney Care | Agartala, Tripura
# South Tripura | 11/22
# Hospital
# South Tripura | 12/22
# Govind Ballabh Pant Hospital
# South Tripura | 13/22
# INTEGRATED AYUSH HOSPITAL
# South Tripura | 14/22
# Devlok Hospital
# South Tripura | 15/22
# Rajnagar CHC
# South Tripura | 16/22
# Hospital
# South Tripura | 17/22
# Sub-Division Hospital
# South Tripura | 18/22
# AOD Hospital
# South Tripura | 19/22
# URMILA HOME NURSING CARE
# South Tripura | 20/22
# St. Joseph Hospital
# South Tripura | 21/22
# Tripura Santiniketan Medical College
# South Tripura | 22/22
# South City Diagnostics
#
# Searching: hospitals in Unakoti Tripura
# Search Submitted
# Unakoti | hospitals | Scroll 1 -> 3
# Unakoti | hospitals | Scroll 2 -> 3
# Unakoti | hospitals | Scroll 3 -> 3
# Unakoti | hospitals | Scroll 4 -> 3
# Unakoti | hospitals | Scroll 5 -> 3
# Collected 0 links
#
# Searching: hospitals in West Tripura Tripura
# Search Submitted
# West Tripura | hospitals | Scroll 1 -> 16
# West Tripura | hospitals | Scroll 2 -> 20
# West Tripura | hospitals | Scroll 3 -> 28
# West Tripura | hospitals | Scroll 4 -> 36
# West Tripura | hospitals | Scroll 5 -> 40
# West Tripura | hospitals | Scroll 6 -> 48
# West Tripura | hospitals | Scroll 7 -> 48
# West Tripura | hospitals | Scroll 8 -> 48
# West Tripura | hospitals | Scroll 9 -> 48
# West Tripura | hospitals | Scroll 10 -> 48
# Collected 23 links
# West Tripura | 1/23
# Apollo Multispeciality Hospital Information Centre
# West Tripura | 2/23
# Hospital Chowmuhani
# West Tripura | 3/23
# THE HOPE
# West Tripura | 4/23
# MODERN PSYCHIATRIC HOSPITAL
# West Tripura | 5/23
# Agartala Hospital & Research Centre Pvt Ltd
# West Tripura | 6/23
# Mohanpur Hospital
# West Tripura | 7/23
# Office Of the Medical Superintendent, IGM Hospital
# West Tripura | 8/23
# Plasma Diagnostic Centre
# West Tripura | 9/23
# Paschim Bhubanban Urban Primary Health Centre
# West Tripura | 10/23
# Chachubazar PHC
# West Tripura | 11/23
# Hospital
# West Tripura | 12/23
# Harina Sub Hospital
# West Tripura | 13/23
# East Jogendranagar UPHC
# West Tripura | 14/23
# Jirania Community Health Centre
# West Tripura | 15/23
# Gandhigram Primary Health Centre
# West Tripura | 16/23
# Ishanpur Sub Center
# West Tripura | 17/23
# Kailashahar
# West Tripura | 18/23
# Directorate Of Health Services
# West Tripura | 19/23
# Indira Gandhi Memorial Hospital Blood Bank
# West Tripura | 20/23
# Hathimatha Hospital
# West Tripura | 21/23
# Tropical Nursing Home
# Backup Saved
# West Tripura | 22/23
# Sipai Kami Dispensary Hospital (KAMI KWTAL)
# West Tripura | 23/23
# Charipara Sub center
#
# Extraction Completed
# Total Schools Extracted: 102
#
# Saved File: tripura_hospitals.csv
