# %%
import time
import random
import pandas as pd

from datetime import datetime

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.service import Service

from webdriver_manager.chrome import ChromeDriverManager


districts = [
    "Angul",
    "Balangir",
    "Balasore",
    "Bargarh",
    "Bhadrak",
    "Boudh",
    "Cuttack",
    "Deogarh",
    "Dhenkanal",
    "Gajapati",
    "Ganjam",
    "Jagatsinghpur",
    "Jajpur",
    "Jharsuguda",
    "Kalahandi",
    "Kandhamal",
    "Kendrapara",
    "Kendujhar",
    "Khordha",
    "Koraput",
    "Malkangiri",
    "Mayurbhanj",
    "Nabarangpur",
    "Nayagarh",
    "Nuapada",
    "Puri",
    "Rayagada",
    "Sambalpur",
    "Subarnapur",
    "Sundargarh"
]


search_types = [
    "hospitals"
]


options = webdriver.ChromeOptions()

options.add_argument("--start-maximized")

options.add_argument(
    "--disable-blink-features=AutomationControlled"
)

options.add_argument("--disable-notifications")


driver = webdriver.Chrome(

    service=Service(
        ChromeDriverManager().install()
    ),

    options=options
)


driver.get("https://www.google.com/maps")

print("Opening Google Maps...")

time.sleep(15)

print("Google Maps Loaded")


all_data = []

visited_links = set()


def get_search_box():

    selectors = [

        '//input[@id="searchboxinput"]',
        '//input[contains(@placeholder,"Search")]',
        '//input[contains(@aria-label,"Search")]',
        '//input'

    ]

    for selector in selectors:

        try:

            box = driver.find_element(
                By.XPATH,
                selector
            )

            return box

        except:
            pass

    return None


def extract_school_data():

    try:

        try:
            name = driver.find_element(
                By.TAG_NAME,
                "h1"
            ).text
        except:
            name = ""

        try:
            address = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"address")]'
            ).text
        except:
            address = ""

        try:
            phone = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"phone")]'
            ).text
        except:
            phone = ""

        try:
            website = driver.find_element(
                By.XPATH,
                '//a[contains(@data-item-id,"authority")]'
            ).get_attribute("href")
        except:
            website = ""

        try:
            rating = driver.find_element(
                By.XPATH,
                '//div[@role="img"]'
            ).get_attribute("aria-label")
        except:
            rating = ""

        return {

            "Hospital Name": name,
            "Address": address,
            "Phone": phone,
            "Website": website,
            "Rating": rating,
            "Google Maps URL": driver.current_url

        }

    except:

        return None


for district in districts:

    for search_type in search_types:

        try:

            query = (
                f"{search_type} "
                f"in {district} Odisha"
            )

            print(f"\nSearching: {query}")


            search_box = get_search_box()

            if not search_box:

                print("Search Box Not Found")

                continue

            ActionChains(driver).move_to_element(
                search_box
            ).click().perform()

            time.sleep(1)

            search_box.send_keys(
                Keys.CONTROL + "a"
            )

            time.sleep(1)

            search_box.send_keys(Keys.DELETE)

            time.sleep(1)

            for char in query:

                search_box.send_keys(char)

                time.sleep(0.03)

            search_box.send_keys(Keys.ENTER)

            print("Search Submitted")

            time.sleep(8)

            try:

                scrollable_div = driver.find_element(
                    By.XPATH,
                    '//div[@role="feed"]'
                )

                previous_count = 0

                stagnant = 0

                for i in range(100):

                    driver.execute_script(
                        """
                        arguments[0].scrollTop =
                        arguments[0].scrollHeight
                        """,
                        scrollable_div
                    )

                    time.sleep(4)

                    listings = driver.find_elements(
                        By.XPATH,
                        '//a[contains(@href,"/maps/place/")]'
                    )

                    current_count = len(listings)

                    print(
                        f"{district} | "
                        f"{search_type} | "
                        f"Scroll {i+1} -> "
                        f"{current_count}"
                    )

                    if current_count == previous_count:

                        stagnant += 1

                    else:

                        stagnant = 0

                    if stagnant >= 4:

                        break

                    previous_count = current_count

            except Exception as e:

                print(f"Scrolling Error: {e}")


            listings = driver.find_elements(
                By.XPATH,
                '//a[contains(@href,"/maps/place/")]'
            )

            links = []

            for listing in listings:

                try:

                    link = listing.get_attribute("href")

                    if (
                        link
                        and link not in visited_links
                    ):

                        links.append(link)

                        visited_links.add(link)

                except:
                    pass

            print(f"Collected {len(links)} links")

            for index, link in enumerate(links):

                try:

                    print(
                        f"{district} | "
                        f"{index+1}/{len(links)}"
                    )

                    driver.get(link)

                    time.sleep(
                        random.uniform(2, 4)
                    )

                    data = extract_school_data()

                    if data:

                        data["District"] = district

                        data["Search Type"] = search_type

                        all_data.append(data)

                        print(data["Hospital Name"])


                    if len(all_data) % 100 == 0:

                        backup_df = pd.DataFrame(
                            all_data
                        )

                        backup_df.drop_duplicates(
                            subset=[
                                "Hospital Name",
                                "Google Maps URL"
                            ],
                            inplace=True
                        )

                        backup_filename = (
                            "odisha_backup.csv"
                        )

                        backup_df.to_csv(
                            backup_filename,
                            index=False
                        )

                        print("Backup Saved")

                except Exception as e:

                    print(
                        f"School Error: {e}"
                    )

        except Exception as e:

            print(
                f"District Error: {e}"
            )


df = pd.DataFrame(all_data)

df.drop_duplicates(

    subset=[
        "Hospital Name",
        "Google Maps URL"
    ],

    inplace=True
)


filename = (
    "odisha_hospitals.csv"
)

df.to_csv(
    filename,
    index=False
)

print("\nExtraction Completed")

print(
    f"Total Hospitals Extracted: {len(df)}"
)

print(f"\nSaved File: {filename}")

driver.quit()
# Out:
# Opening Google Maps...
# Google Maps Loaded
#
# Searching: hospitals in Angul Odisha
# Search Submitted
# Angul | hospitals | Scroll 1 -> 14
# Angul | hospitals | Scroll 2 -> 17
# Angul | hospitals | Scroll 3 -> 17
# Angul | hospitals | Scroll 4 -> 17
# Angul | hospitals | Scroll 5 -> 17
# Angul | hospitals | Scroll 6 -> 17
# Collected 17 links
# Angul | 1/17
# District Headquarters Hospital(DHH), Angul
# Angul | 2/17
# Arete Care Hospital
# Angul | 3/17
# Nalco Hospital
# Angul | 4/17
# YESS HOSPITAL
# Angul | 5/17
# JASODA MOTHER AND CHILD CARE
# Angul | 6/17
# Surendra Hospital
# Angul | 7/17
# SAROJINI HEALTH CARE
# Angul | 8/17
# Samal Care Multispeciality Hospital Angul
# Angul | 9/17
# Premalata Speciality Clinic, Angul
# Angul | 10/17
# Kalyani Nursing Home
# Angul | 11/17
# Omm Life Care
# Angul | 12/17
# Curewell Health care
# Angul | 13/17
# PTC Hospital
# Angul | 14/17
# MCH BUILDING ANGUL
# Angul | 15/17
# Chandan Nursing Home
# Angul | 16/17
# Angul Hospital Registration Center
# Angul | 17/17
# Sai Sanjibanee Medicine Store Busstand Angul
#
# Searching: hospitals in Balangir Odisha
# Search Submitted
# Balangir | hospitals | Scroll 1 -> 14
# Balangir | hospitals | Scroll 2 -> 20
# Balangir | hospitals | Scroll 3 -> 22
# Balangir | hospitals | Scroll 4 -> 22
# Balangir | hospitals | Scroll 5 -> 22
# Balangir | hospitals | Scroll 6 -> 22
# Balangir | hospitals | Scroll 7 -> 22
# Collected 22 links
# Balangir | 1/22
# SWARAJ HOSPITAL AND RESEARCH INSTITUTE
# Balangir | 2/22
# BIMS HOSPITAL, BALANGIR
# Balangir | 3/22
# Government Hospital
# Balangir | 4/22
# NEW LIFE HOSPITAL
# Balangir | 5/22
# Harihar Hospital
# Balangir | 6/22
# New Life Hospital UNIT-2
# Balangir | 7/22
# Samaleswari Multispeciality Hospital
# Balangir | 8/22
# Bhima Bhoi Medical College and Hospital, Balangir
# Balangir | 9/22
# DEEP CARE HOSPITAL
# Balangir | 10/22
# Swaraj Hospital
# Balangir | 11/22
# Old Samaleswari Hospital
# Balangir | 12/22
# Supreme Task General Hospital
# Balangir | 13/22
# Krishna Healthcare & Diagnostics
# Balangir | 14/22
# Patel Nursing Home
# Balangir | 15/22
# Police Hospital
# Balangir | 16/22
# Dr Madhusudan Meher Piles care clinic
# Balangir | 17/22
# BIMS Nephrology Department
# Balangir | 18/22
# Govt. Ayurveda College & Hospital, Bolangir
# Balangir | 19/22
# Axon Neuro Care
# Balangir | 20/22
# Dr. Soumya Ranjan Naik
# Balangir | 21/22
# Registration Counter DHH Balangir
# Balangir | 22/22
# DR SRINIVAS SAHU CLINIC
#
# Searching: hospitals in Balasore Odisha
# Search Submitted
# Balasore | hospitals | Scroll 1 -> 14
# Balasore | hospitals | Scroll 2 -> 20
# Balasore | hospitals | Scroll 3 -> 27
# Balasore | hospitals | Scroll 4 -> 28
# Balasore | hospitals | Scroll 5 -> 28
# Balasore | hospitals | Scroll 6 -> 28
# Balasore | hospitals | Scroll 7 -> 28
# Balasore | hospitals | Scroll 8 -> 28
# Collected 28 links
# Balasore | 1/28
# SRI RAJ MEMORIAL HOSPITAL
# Balasore | 2/28
# Govt. Medical College & Hospital
# Balasore | 3/28
# Jyothi Hospital
# Balasore | 4/28
# Kalyan Healthcare Hospital
# Balasore | 5/28
# କୌଶଲ୍ୟା ମେମୋରିଆଲ ହସ୍ପିଟାଲ KM Hospital
# Balasore | 6/28
# Laxmikanta Health Care
# Balasore | 7/28
# CURE AND CARE MultiSpeciality Clinic
# Balasore | 8/28
# JAYASHRI HEALTH CARE & RESEARCH CENTRE
# Balasore | 9/28
# Durga Nursing Home & Research Center
# Balasore | 10/28
# ଶ୍ରୀରାମ ହସ୍ପିଟାଲ୍ Sriram Hospital
# Balasore | 11/28
# Fakir Mohan Medical College & Hospital, Balasore
# Balasore | 12/28
# BALASORE ENT & ALLERGY CLINIC( Dr Ashutosh Pradhan )
# Balasore | 13/28
# Life care hospital
# Balasore | 14/28
# Maa Tarini Nursing Home
# Balasore | 15/28
# Aum Hospital
# Balasore | 16/28
# Matrushakti Hospital
# Balasore | 17/28
# ESI HOSPITAL BALASORE
# Balasore | 18/28
# A.R.T. Centre D.H.H. Balasore
# Balasore | 19/28
# LIFE CARE HOSPITAL & DIALYSIS CENTER
# Balasore | 20/28
# Swaasthya Care : Polyclinic, Diagnostics, Pathology, Pharmacy - Balasore
# Balasore | 21/28
# CHANDI NURSING HOME
# Balasore | 22/28
# The Health Zone
# Balasore | 23/28
# Nilagiri Government Hospital
# Balasore | 24/28
# Ananda Health Care Balasore Main Unit
# Balasore | 25/28
# TEACHING HOSPITAL BALASORE
# Balasore | 26/28
# UPHC Sunhat
# Balasore | 27/28
# Rotary Eye And Dental Hospital, Balasore
# Balasore | 28/28
# Life Care Hospita.
#
# Searching: hospitals in Bargarh Odisha
# Search Submitted
# Bargarh | hospitals | Scroll 1 -> 13
# Bargarh | hospitals | Scroll 2 -> 13
# Bargarh | hospitals | Scroll 3 -> 13
# Bargarh | hospitals | Scroll 4 -> 13
# Bargarh | hospitals | Scroll 5 -> 13
# Collected 13 links
# Bargarh | 1/13
# Krishna Vikash Multi Speciality Hospital
# Bargarh | 2/13
# Kishori Hospital - Multispeciality Hospital
# Bargarh | 3/13
# Sai MultiSpeciality Hospital Bargarh
# Bargarh | 4/13
# SHRI Hospital ( General and Laparoscopic )
# Bargarh | 5/13
# Purohit General Hospital & Research Centre
# Bargarh | 6/13
# District Headquarters Hospital, khedapali Bargarh
# Bargarh | 7/13
# Catholic Mission Hospital, Bargarh
# Bargarh | 8/13
# Sai Krupa Polyclinic
# Bargarh | 9/13
# UPHC-AAM, Stationpada, Bargarh
# Bargarh | 10/13
# Sai Krupa Nursing Home
# Bargarh | 11/13
# District Head Quarters Hospital Old Building, Baragarh
# Bargarh | 12/13
# UPHC (Urban Primary Health Centre), MMC, Hatapada, Bargarh ସହରାଞ୍ଚଳ ପ୍ରାଥମିକ ସ୍ୱାସ୍ଥ୍ୟ କେନ୍ଦ୍ର
# Bargarh | 13/13
# Behera Nursing Home
#
# Searching: hospitals in Bhadrak Odisha
# Search Submitted
# Bhadrak | hospitals | Scroll 1 -> 14
# Bhadrak | hospitals | Scroll 2 -> 20
# Bhadrak | hospitals | Scroll 3 -> 27
# Bhadrak | hospitals | Scroll 4 -> 33
# Bhadrak | hospitals | Scroll 5 -> 33
# Bhadrak | hospitals | Scroll 6 -> 33
# Bhadrak | hospitals | Scroll 7 -> 33
# Bhadrak | hospitals | Scroll 8 -> 33
# Collected 33 links
# Bhadrak | 1/33
# Shradha Hospital
# Bhadrak | 2/33
# District Headquarters Hospital Bhadrak
# Bhadrak | 3/33
# Sai Bharadwaj Hospital
# Bhadrak | 4/33
# Salandi Hospital
# Bhadrak | 5/33
# ZASS MIDTOWN HOSPITAL
# Bhadrak | 6/33
# MOHANTY MEDICARE (ମହାନ୍ତି ମେଡିକେୟାର୍) | Best Medicare at Your Service, One Stop for All your's Health Needs |
# Bhadrak | 7/33
# District Headquarter Hospital,Bhadrak
# Bhadrak | 8/33
# Padhi Health Care
# Bhadrak | 9/33
# Behera Help Centre
# Bhadrak | 10/33
# Omm Sai Hospital
# Bhadrak | 11/33
# Subham Hospital,Bhadrak
# Bhadrak | 12/33
# Unani Hospital
# Bhadrak | 13/33
# Sriram Hospital
# Bhadrak | 14/33
# Aarogyam Rajeev Medicare Bhadrak ଆରୋଗ୍ୟମ ରାଜୀବ ମେଡିକେୟର ଭଦ୍ରକ
# Bhadrak | 15/33
# CHIRAG HOSPITAL
# Bhadrak | 16/33
# Bhoomika Eye Hospital
# Bhadrak | 17/33
# Satyabhama Health Care
# Bhadrak | 18/33
# SRG Hospital (Kshyama Parhy Hospital)
# Bhadrak | 19/33
# NEW DAY MEDICARE
# Bhadrak | 20/33
# R.N. Govt. Eye Hospital Bhadrak
# Backup Saved
# Bhadrak | 21/33
# Bhadrak new government medical
# Bhadrak | 22/33
# Panigrahi Health Care
# Bhadrak | 23/33
# Sai hospital
# Bhadrak | 24/33
# Sri Ram Nursing Home
# Bhadrak | 25/33
# Padhi Nurshing Home
# Bhadrak | 26/33
# Bilana Government Hospital
# Bhadrak | 27/33
# Dr satrughna hati clinik
# Bhadrak | 28/33
# Railway Hospital
# Bhadrak | 29/33
# Dr.KANISKA KUMAR MALLICK
# Bhadrak | 30/33
# Dr U K Jena Bhadrak
# Bhadrak | 31/33
# Odisha Red Cross Blood Bank Bhadrak
# Bhadrak | 32/33
# Star Health & Allied Insurance - Bhadrak, Odisha
# Bhadrak | 33/33
# Barsa
#
# Searching: hospitals in Boudh Odisha
# Search Submitted
# Boudh | hospitals | Scroll 1 -> 9
# Boudh | hospitals | Scroll 2 -> 9
# Boudh | hospitals | Scroll 3 -> 9
# Boudh | hospitals | Scroll 4 -> 9
# Boudh | hospitals | Scroll 5 -> 9
# Collected 9 links
# Boudh | 1/9
# District Headquarter Hospital
# Boudh | 2/9
# physiotherapy center, DHH Boudh
# Boudh | 3/9
# Arogyam Medicare and Polyclinic
# Boudh | 4/9
# NRC, DHH Boudh
# Boudh | 5/9
# SKPL HOSPITAL
# Boudh | 6/9
# Government Hospital
# Boudh | 7/9
# Urban Health and Wellness Centre, Boudh. Urban PHC BOUDH
# Boudh | 8/9
# Odisha Red Cross Blood Bank Boudh
# Boudh | 9/9
# CDVO, Office
#
# Searching: hospitals in Cuttack Odisha
# Search Submitted
# Cuttack | hospitals | Scroll 1 -> 14
# Cuttack | hospitals | Scroll 2 -> 21
# Cuttack | hospitals | Scroll 3 -> 28
# Cuttack | hospitals | Scroll 4 -> 35
# Cuttack | hospitals | Scroll 5 -> 41
# Cuttack | hospitals | Scroll 6 -> 48
# Cuttack | hospitals | Scroll 7 -> 55
# Cuttack | hospitals | Scroll 8 -> 61
# Cuttack | hospitals | Scroll 9 -> 68
# Cuttack | hospitals | Scroll 10 -> 73
# Cuttack | hospitals | Scroll 11 -> 73
# Cuttack | hospitals | Scroll 12 -> 73
# Cuttack | hospitals | Scroll 13 -> 73
# Cuttack | hospitals | Scroll 14 -> 73
# Collected 73 links
# Cuttack | 1/73
# Shanti Memorial Hospital
# Cuttack | 2/73
# Sun Hospital Pvt Ltd
# Cuttack | 3/73
# Ashwini Hospital
# Cuttack | 4/73
# SHREEJA HOSPITAL
# Cuttack | 5/73
# Blue Line Hospital
# Cuttack | 6/73
# Swapna Superspeciality Hospital
# Cuttack | 7/73
# Budha Baba Multispeciality Hospital (BBMH)
# Cuttack | 8/73
# District Head Quarter Hospital, Cuttack (City Hospital)
# Cuttack | 9/73
# Sarthak Hospital
# Cuttack | 10/73
# S.C.B. Medical College and Hospital cuttack
# Cuttack | 11/73
# Add Hospital Pvt Ltd
# Cuttack | 12/73
# Srushti Multispeciality Hospital
# Cuttack | 13/73
# Star Hospital( CUTTACK,ODISHA)
# Cuttack | 14/73
# 4S CARE HOSPITAL
# Cuttack | 15/73
# Sweta Hospital
# Cuttack | 16/73
# Silvercity Hospital and Research center
# Cuttack | 17/73
# ROYAL HOSPITAL AND RESEARCH
# Cuttack | 18/73
# Prime multispeciality Hospital
# Cuttack | 19/73
# Rudra Hospital - Best Multispeciality Hospital in Cuttack
# Cuttack | 20/73
# Chanakya Hospital
# Cuttack | 21/73
# Mahapatra Hospital Pvt. Ltd.
# Cuttack | 22/73
# Shakti Hospital
# Cuttack | 23/73
# South Point Hospital
# Cuttack | 24/73
# POLY HOSPITAL
# Cuttack | 25/73
# Heritage healthcare Hospital
# Cuttack | 26/73
# Srusti Hospital
# Cuttack | 27/73
# Relax Hospitals
# Cuttack | 28/73
# SWASTHYA MULTISPECIALITY HOSPITAL, DWIJA SUDHA COMPLEX
# Cuttack | 29/73
# Cuttack Laparoscopic Hospital
# Cuttack | 30/73
# Nigam Hospital
# Cuttack | 31/73
# Trisha Hospital
# Cuttack | 32/73
# Medcure Hospital
# Cuttack | 33/73
# Riverine Hospital
# Cuttack | 34/73
# Shifa Hospital. Cuttack
# Cuttack | 35/73
# Adoreasia Hospital
# Cuttack | 36/73
# Jeevan Jyoti Hospital
# Cuttack | 37/73
# Hope Hospital
# Cuttack | 38/73
# Rohan Hospital
# Cuttack | 39/73
# OMM MULTYSPECILITY HOSPITAL
# Cuttack | 40/73
# Ashwini Trauma Centre
# Cuttack | 41/73
# Cuttack hospital
# Cuttack | 42/73
# Sai hospital purighat
# Cuttack | 43/73
# Susruta Hospital
# Cuttack | 44/73
# Moon Hospital
# Cuttack | 45/73
# Daivik Hospital
# Cuttack | 46/73
# Sabarmati General Hospital
# Cuttack | 47/73
# Ratna Hospital
# Cuttack | 48/73
# Anantaram Memorial Cuttack Nursing Home
# Cuttack | 49/73
# Om Suvam Hospital
# Cuttack | 50/73
# S S HOSPITAL
# Cuttack | 51/73
# Goodluck Hospital
# Cuttack | 52/73
# TULIP CARE HOSPITAL
# Cuttack | 53/73
# SRIRAM HOSPITAL
# Cuttack | 54/73
# Mediera Hospitals
# Cuttack | 55/73
# Tarini Superspeciality Ent Hospital
# Cuttack | 56/73
# Bishakha Hospital
# Cuttack | 57/73
# Sadguru Hospital
# Cuttack | 58/73
# Radharaman Eye Hospital
# Cuttack | 59/73
# Ratna Hospital
# Cuttack | 60/73
# Tulasi Hospital
# Cuttack | 61/73
# ASG Eye Hospital - Cuttack
# Cuttack | 62/73
# UTKAL HOSPITAL, KATHAGOLA LANE
# Cuttack | 63/73
# SAHARA NURSING HOME
# Cuttack | 64/73
# Geeta Memorial Hospital
# Cuttack | 65/73
# Bada Medical Cuttack
# Cuttack | 66/73
# Welfare Nursing Home And Diagnostic Research Centre
# Cuttack | 67/73
# RR CHILD CARE HOSPITAL
# Cuttack | 68/73
# Neeladri Hospital
# Cuttack | 69/73
# Carcinova Cancer Hospital
# Cuttack | 70/73
# Health Care Nurshing Home - Dr.Anand Garabadu | Best Multispeciality Hospital In Cuttack
# Cuttack | 71/73
# Life Institute of Gastroenterology and Gynecology | Best 24/7 Surgical Hospital | Cuttack, Odisha
# Cuttack | 72/73
# Swastik hospital
# Cuttack | 73/73
# Nishamani Nursing Home
#
# Searching: hospitals in Deogarh Odisha
# Search Submitted
# Deogarh | hospitals | Scroll 1 -> 10
# Deogarh | hospitals | Scroll 2 -> 10
# Deogarh | hospitals | Scroll 3 -> 10
# Deogarh | hospitals | Scroll 4 -> 10
# Deogarh | hospitals | Scroll 5 -> 10
# Collected 10 links
# Deogarh | 1/10
# District Headquarter Hospital New, Deogarh
# Deogarh | 2/10
# Premanand Hospital
# Deogarh | 3/10
# U H W C Deogarh Govt. Hospital
# Deogarh | 4/10
# Maa Durga Enterprises.Nerolac
# Deogarh | 5/10
# Jharna medicine hole
# Backup Saved
# Deogarh | 6/10
# New Life Diagnostic Centre
# Deogarh | 7/10
# Community Health Center, Chhatabar, Deogarh
# Deogarh | 8/10
# GOVERNMENT HOSPITAL DEOGARH
# Deogarh | 9/10
# PANDA MEDICAL HALL
# Deogarh | 10/10
# District Headquarters Hospital, Deogarh
#
# Searching: hospitals in Dhenkanal Odisha
# Search Submitted
# Dhenkanal | hospitals | Scroll 1 -> 14
# Dhenkanal | hospitals | Scroll 2 -> 18
# Dhenkanal | hospitals | Scroll 3 -> 18
# Dhenkanal | hospitals | Scroll 4 -> 18
# Dhenkanal | hospitals | Scroll 5 -> 18
# Dhenkanal | hospitals | Scroll 6 -> 18
# Collected 18 links
# Dhenkanal | 1/18
# DEBIDURGA HOSPITAL
# Dhenkanal | 2/18
# Shree Jagannath Hospital
# Dhenkanal | 3/18
# District Hospital Dhenkanal
# Dhenkanal | 4/18
# SIYARAM HEALTH CARE , DHENKANAL
# Dhenkanal | 5/18
# Saishree Eye Hospital
# Dhenkanal | 6/18
# SUN HOSPITAL DHENKANAL
# Dhenkanal | 7/18
# Disha Hospital
# Dhenkanal | 8/18
# Lifeline Medical Center
# Dhenkanal | 9/18
# Sai Nursing Home
# Dhenkanal | 10/18
# SARBESWAR MEMORIAL HOSPITAL, Dhenkanal
# Dhenkanal | 11/18
# Kalinga Eye Hospital & Research Centre
# Dhenkanal | 12/18
# COVID HEALTH CENTRE, DHENKANAL
# Dhenkanal | 13/18
# Panda Nursing Home
# Dhenkanal | 14/18
# Rekula Hadajoda Hospital
# Dhenkanal | 15/18
# APPOLO DIAGNOSTiC
# Dhenkanal | 16/18
# Kedia Poly Clinic, Dhenkanal
# Dhenkanal | 17/18
# SRI SRI AYUSH HEALTH CARE (SSAHC) Clinic & Research Centre (CRC) ଶ୍ରୀ ଶ୍ରୀ ଆୟୁଷ୍ ହେଲ୍ଥ କେୟାର କ୍ଲିନିକ୍ ଏବଂ ଅନୁସନ୍ଧାନ କେନ୍ଦ୍ର
# Dhenkanal | 18/18
# Mahalaxmi health care 24 X 7
#
# Searching: hospitals in Gajapati Odisha
# Search Submitted
# Gajapati | hospitals | Scroll 1 -> 14
# Gajapati | hospitals | Scroll 2 -> 16
# Gajapati | hospitals | Scroll 3 -> 16
# Gajapati | hospitals | Scroll 4 -> 16
# Gajapati | hospitals | Scroll 5 -> 16
# Gajapati | hospitals | Scroll 6 -> 16
# Collected 16 links
# Gajapati | 1/16
# District Govt. Hospital
# Gajapati | 2/16
# SOUMYA NURSING HOME
# Gajapati | 3/16
# MITRA EYE HOSPITAL- PARALAKHEMUNDI
# Gajapati | 4/16
# Dr. Ravi' Nurshing Home
# Gajapati | 5/16
# VVL NURSING HOME
# Gajapati | 6/16
# Babu Health Care
# Gajapati | 7/16
# Community Health Center,Mohana
# Gajapati | 8/16
# SRI RAMA DENTAL CLINIC AND IMPLANT CENTER
# Gajapati | 9/16
# SARA Eye care
# Gajapati | 10/16
# Sri satya sai Day and night hospital🩺
# Gajapati | 11/16
# Syam Prabha Multispeciality Hospital
# Gajapati | 12/16
# EYE Ward DHH Parlakhemundi
# Gajapati | 13/16
# Laxmi Nursing Home
# Gajapati | 14/16
# ARUNA SCAN CENTRE,PARALAKHEMUNDI
# Gajapati | 15/16
# CDMO Office Gajapati
# Gajapati | 16/16
# Primary health Center
#
# Searching: hospitals in Ganjam Odisha
# Search Submitted
# Ganjam | hospitals | Scroll 1 -> 10
# Ganjam | hospitals | Scroll 2 -> 10
# Ganjam | hospitals | Scroll 3 -> 10
# Ganjam | hospitals | Scroll 4 -> 10
# Ganjam | hospitals | Scroll 5 -> 10
# Collected 10 links
# Ganjam | 1/10
# PHC New Ganjam
# Ganjam | 2/10
# B.N.PUR HOSPITAL,GANJAM
# Ganjam | 3/10
# SUM HOSPITAL
# Ganjam | 4/10
# CHC, Bhatakumarada
# Ganjam | 5/10
# MKCG Medical College And Hospital , Brahmapur
# Ganjam | 6/10
# City Hospital
# Ganjam | 7/10
# AMIT HOSPITAL
# Ganjam | 8/10
# Gurudev Hospital
# Ganjam | 9/10
# Aastha Hospital
# Ganjam | 10/10
# Primary Health Centre,Saru
#
# Searching: hospitals in Jagatsinghpur Odisha
# Search Submitted
# Jagatsinghpur | hospitals | Scroll 1 -> 14
# Jagatsinghpur | hospitals | Scroll 2 -> 20
# Jagatsinghpur | hospitals | Scroll 3 -> 23
# Jagatsinghpur | hospitals | Scroll 4 -> 23
# Jagatsinghpur | hospitals | Scroll 5 -> 23
# Jagatsinghpur | hospitals | Scroll 6 -> 23
# Jagatsinghpur | hospitals | Scroll 7 -> 23
# Collected 23 links
# Jagatsinghpur | 1/23
# District Headquarters Hospital
# Jagatsinghpur | 2/23
# Sakti Clinic
# Jagatsinghpur | 3/23
# Shree Hospital Jagatsinghpur
# Jagatsinghpur | 4/23
# Sukanya Hospital
# Jagatsinghpur | 5/23
# Sun Clinic & Hospital
# Jagatsinghpur | 6/23
# Cure-well Hospital
# Jagatsinghpur | 7/23
# ମାତୃ ଶିଶୁ ମଙ୍ଗଳ କେନ୍ଦ୍ର
# Jagatsinghpur | 8/23
# Hospital
# Jagatsinghpur | 9/23
# Khan Nursing Home and Diagnostic Center
# Jagatsinghpur | 10/23
# Arogya Hospital ,Jagatsinghpur.
# Jagatsinghpur | 11/23
# ICU ଆଇସିୟୁ ଜଗତସିଂପୁର ଜିଲ୍ଲା ମୁଖ୍ୟ ଚିକତ୍ସାଳୟ
# Jagatsinghpur | 12/23
# Life Line Clinic and Nursing home
# Jagatsinghpur | 13/23
# UHWC, MAKUNDAPUR, JAGATSINGHPUR
# Jagatsinghpur | 14/23
# ଆହାର କେନ୍ଦ୍ର , ଜଗତସିଂହପୁର ମୁଖ୍ୟ ଚିକିତ୍ସାଳୟ
# Jagatsinghpur | 15/23
# Bhoomika Eye Hospital Jagatsinghpur
# Jagatsinghpur | 16/23
# Emergency OPD
# Jagatsinghpur | 17/23
# SAI SRADHA NURSING HOME
# Jagatsinghpur | 18/23
# R.H.T.C ଜଗତସିଂହପୁର
# Jagatsinghpur | 19/23
# 108 ଆମ୍ବୁଲାନ୍ସ ସେବା, ଜଗତସିଂହପୁର
# Jagatsinghpur | 20/23
# Trilochan Netralaya
# Jagatsinghpur | 21/23
# Brahmanadehi Govt. Hospital
# Jagatsinghpur | 22/23
# CENTRAL STORE(D.H.H)JAGATSINGHPUR
# Jagatsinghpur | 23/23
# Cure well blood collection centre
#
# Searching: hospitals in Jajpur Odisha
# Search Submitted
# Jajpur | hospitals | Scroll 1 -> 14
# Jajpur | hospitals | Scroll 2 -> 18
# Jajpur | hospitals | Scroll 3 -> 18
# Jajpur | hospitals | Scroll 4 -> 18
# Jajpur | hospitals | Scroll 5 -> 18
# Jajpur | hospitals | Scroll 6 -> 18
# Collected 18 links
# Jajpur | 1/18
# Jajpur Govt. Hospital
# Jajpur | 2/18
# MAHARAJA JAJATI KESHARI MEDICAL COLLEGE AND HOSPITAL
# Jajpur | 3/18
# Apollo Clinic Jajpur Town
# Jajpur | 4/18
# Sai Manorama Hospital
# Jajpur | 5/18
# Divine Health Care
# Jajpur | 6/18
# Gov. Hospital Jajpur Road
# Jajpur | 7/18
# METERNITY AND CHILD HEALTH CENTER, DHO. JAJPUR
# Jajpur | 8/18
# Laxmi Hospital
# Jajpur | 9/18
# Prava care Hospital
# Jajpur | 10/18
# Jeeban Jyoti hospital & diagnostics
# Jajpur | 11/18
# Tata Steel Medica Hospital
# Jajpur | 12/18
# AKMS Hospital
# Jajpur | 13/18
# DISTRICT HEADQUARTER, JAJPUR
# Jajpur | 14/18
# Shree maa Hospital
# Jajpur | 15/18
# CHC Jajpur Road
# Jajpur | 16/18
# Bhoomika Hospital
# Jajpur | 17/18
# Dharmasala Community Health Center
# Jajpur | 18/18
# Maa Diagnostic
#
# Searching: hospitals in Jharsuguda Odisha
# Search Submitted
# Jharsuguda | hospitals | Scroll 1 -> 12
# Jharsuguda | hospitals | Scroll 2 -> 12
# Jharsuguda | hospitals | Scroll 3 -> 12
# Jharsuguda | hospitals | Scroll 4 -> 12
# Jharsuguda | hospitals | Scroll 5 -> 12
# Collected 12 links
# Jharsuguda | 1/12
# Satellite Hospital, Old District Headquarter Hospital, Jharsuguda
# Jharsuguda | 2/12
# Sanjivani Hospital
# Jharsuguda | 3/12
# St.Mary's Hospital
# Jharsuguda | 4/12
# Jagnyaseni Hospital
# Jharsuguda | 5/12
# JDS Multi Super Speciality Homoeopathic Hospital & Research Centre
# Jharsuguda | 6/12
# Govt. Hospital,Jharsuguda
# Jharsuguda | 7/12
# Motilal Yadav Memorial Samleswari Hospital
# Jharsuguda | 8/12
# A Square Hospital
# Jharsuguda | 9/12
# Govt Hospital, Jharsuguda
# Jharsuguda | 10/12
# ESI Dispensary
# Backup Saved
# Jharsuguda | 11/12
# Mousumi Memorial Hospital Dr. Rohit Patel
# Jharsuguda | 12/12
# Dr.Prabhat Jain
#
# Searching: hospitals in Kalahandi Odisha
# Search Submitted
# Kalahandi | hospitals | Scroll 1 -> 14
# Kalahandi | hospitals | Scroll 2 -> 17
# Kalahandi | hospitals | Scroll 3 -> 17
# Kalahandi | hospitals | Scroll 4 -> 17
# Kalahandi | hospitals | Scroll 5 -> 17
# Kalahandi | hospitals | Scroll 6 -> 17
# Collected 17 links
# Kalahandi | 1/17
# District Headquarter Hospital, Kalahandi Bhawanipatna
# Kalahandi | 2/17
# MS Medaax Multi-Speciality Hospital
# Kalahandi | 3/17
# Sun Hospital
# Kalahandi | 4/17
# New Life Mission Hospital
# Kalahandi | 5/17
# S R M M C H & D H H, KALAHANDI
# Kalahandi | 6/17
# CDMO Office
# Kalahandi | 7/17
# Maa Manikeswari Multispeciality Hospital
# Kalahandi | 8/17
# Shree Balaji Nursing Home
# Kalahandi | 9/17
# Swasthya Swaraj Community Hospital
# Kalahandi | 10/17
# District Headquarters Hospital Blood Bank Bhawanipatna
# Kalahandi | 11/17
# Titilagarh Govt Hospital
# Kalahandi | 12/17
# Hospital Chowk
# Kalahandi | 13/17
# Primary Government Hospital,Uchhala
# Kalahandi | 14/17
# Dr. M.M. Mund M.S.(Ortho-Surgery)
# Kalahandi | 15/17
# Agrawal nursing Home
# Kalahandi | 16/17
# Borda CHC Hospital
# Kalahandi | 17/17
# Teresinga Govt Hospital,Teresinga
#
# Searching: hospitals in Kandhamal Odisha
# Search Submitted
# Kandhamal | hospitals | Scroll 1 -> 6
# Kandhamal | hospitals | Scroll 2 -> 6
# Kandhamal | hospitals | Scroll 3 -> 6
# Kandhamal | hospitals | Scroll 4 -> 6
# Kandhamal | hospitals | Scroll 5 -> 6
# Collected 6 links
# Kandhamal | 1/6
# OTTET NODE, DHH PHULBANI
# Kandhamal | 2/6
# DASH EYE HOSPITAL
# Kandhamal | 3/6
# Phulbani Medical College and Hospital
# Kandhamal | 4/6
# Government Medical College, Tilakpada
# Kandhamal | 5/6
# Community Health Center
# Kandhamal | 6/6
# Medicle Simonbadi
#
# Searching: hospitals in Kendrapara Odisha
# Search Submitted
# Kendrapara | hospitals | Scroll 1 -> 14
# Kendrapara | hospitals | Scroll 2 -> 20
# Kendrapara | hospitals | Scroll 3 -> 26
# Kendrapara | hospitals | Scroll 4 -> 26
# Kendrapara | hospitals | Scroll 5 -> 26
# Kendrapara | hospitals | Scroll 6 -> 26
# Kendrapara | hospitals | Scroll 7 -> 26
# Collected 26 links
# Kendrapara | 1/26
# Sun Hospital
# Kendrapara | 2/26
# District Headquarters Hospital, Kendrapara
# Kendrapara | 3/26
# New District Headquarters Hospital, Kendrapara (ଜିଲ୍ଲା ମୁଖ୍ୟ ଚିକିତ୍ସାଳୟ, କେନ୍ଦ୍ରାପଡ଼ା)
# Kendrapara | 4/26
# DHH AND MCH HOSPITAL
# Kendrapara | 5/26
# J.B.S Hospital
# Kendrapara | 6/26
# VR Hospital, Kendrapara
# Kendrapara | 7/26
# Durga nursing home
# Kendrapara | 8/26
# Shree Sai Care Hospital
# Kendrapara | 9/26
# SURYA NURSING HOME
# Kendrapara | 10/26
# Sai Rudra Hospital
# Kendrapara | 11/26
# Bhoomika Eye Hospital
# Kendrapara | 12/26
# Aahan hospital and research centre
# Kendrapara | 13/26
# DDH Hospital
# Kendrapara | 14/26
# District Headquarters Hospital Blood Bank Kendrapara
# Kendrapara | 15/26
# Sai Hospital
# Kendrapara | 16/26
# BASANTA KUMARI RURAL EYE HOSPITAL
# Kendrapara | 17/26
# DHRUBA ENT & DENTAL CARE HOSPITAL
# Kendrapara | 18/26
# Urban hospital kendrapara
# Kendrapara | 19/26
# Bhagabati hospital and dialysis
# Kendrapara | 20/26
# SUN HOSPITAL
# Kendrapara | 21/26
# Casualty Kendrapara Medical
# Kendrapara | 22/26
# C.H.C Mahakalpada
# Kendrapara | 23/26
# BCure
# Kendrapara | 24/26
# Popular Nursing Home, Mankarpur, Kendrapara
# Kendrapara | 25/26
# Health care hospital sapanpur
# Kendrapara | 26/26
# Seva Sadan
#
# Searching: hospitals in Kendujhar Odisha
# Search Submitted
# Kendujhar | hospitals | Scroll 1 -> 14
# Kendujhar | hospitals | Scroll 2 -> 14
# Kendujhar | hospitals | Scroll 3 -> 14
# Kendujhar | hospitals | Scroll 4 -> 14
# Kendujhar | hospitals | Scroll 5 -> 14
# Collected 14 links
# Kendujhar | 1/14
# Maa Tarini Super Speciality Hospital
# Kendujhar | 2/14
# HIMA HOSPITAL
# Kendujhar | 3/14
# District Headquarter Hospital, Keonjhar
# Kendujhar | 4/14
# Keonjhar Hospital
# Kendujhar | 5/14
# LIFE CARE HOSPITAL
# Kendujhar | 6/14
# SANJIVANI HOSPITAL KEONJHAR
# Kendujhar | 7/14
# Dharanidhar Medical College and Hospital, Keonjhar.
# Kendujhar | 8/14
# Govt. Medical
# Kendujhar | 9/14
# Swasthi Health Care
# Kendujhar | 10/14
# Dipali Nursing Home - General Surgeon | Laparoscopy and Orthopaedic Surgeon | Urology Specialist in Keonjhar
# Kendujhar | 11/14
# Hospital
# Kendujhar | 12/14
# HEALTHSCOPE
# Kendujhar | 13/14
# Pahi Keonjhar Hospital
# Kendujhar | 14/14
# SUNRISE HOSPITAL & KIDNEY CARE DIALYSIS
#
# Searching: hospitals in Khordha Odisha
# Search Submitted
# Khordha | hospitals | Scroll 1 -> 14
# Khordha | hospitals | Scroll 2 -> 20
# Khordha | hospitals | Scroll 3 -> 27
# Khordha | hospitals | Scroll 4 -> 31
# Khordha | hospitals | Scroll 5 -> 31
# Khordha | hospitals | Scroll 6 -> 31
# Khordha | hospitals | Scroll 7 -> 31
# Khordha | hospitals | Scroll 8 -> 31
# Collected 31 links
# Khordha | 1/31
# Shine Hospital khordha
# Khordha | 2/31
# PARKLAND HOSPITAL
# Khordha | 3/31
# New Arogya Hospital
# Khordha | 4/31
# District Headquarter Hospital, Khordha
# Khordha | 5/31
# STAR HOSPITAL| Best Orthopedic Hospital |
# Khordha | 6/31
# Sahajog Hospital
# Khordha | 7/31
# JENA MANI HOSPITAL, KHURDA
# Khordha | 8/31
# District Govt. Medical,Khordha
# Khordha | 9/31
# SHREE CARE HOSPITAL
# Khordha | 10/31
# SHISHU HOSPITAL
# Khordha | 11/31
# Divisional Railway Hospital, Khurda Road
# Khordha | 12/31
# South city hospital
# Khordha | 13/31
# Community Health Centre
# Khordha | 14/31
# Shine Diagnostic Centre
# Khordha | 15/31
# Jeevan Jyoti Hospital
# Khordha | 16/31
# Nandighosha Hospital
# Khordha | 17/31
# SURAKHYA HOSPITAL
# Khordha | 18/31
# C.J.M. Hospital
# Khordha | 19/31
# Eye Department, DHH, Khordha
# Khordha | 20/31
# Uphc Mukundaprasad
# Khordha | 21/31
# Sayeed Memorial Hospital
# Khordha | 22/31
# Nature Tech Hospital
# Khordha | 23/31
# E.s.i Dispensary Khordha
# Khordha | 24/31
# SASMITA MEMORIAL HOSPITAL
# Khordha | 25/31
# CHC Balakati Hospital
# Khordha | 26/31
# SUM Ultimate Medicare Hospital bhubaneswar
# Khordha | 27/31
# Bankoi CHC Hospital
# Khordha | 28/31
# Dalatola, Government Hospital
# Khordha | 29/31
# Maa Shakti Hospital
# Khordha | 30/31
# Mendhasal Community Health Center
# Khordha | 31/31
# Sanjay Das Hospital
#
# Searching: hospitals in Koraput Odisha
# Search Submitted
# Koraput | hospitals | Scroll 1 -> 10
# Koraput | hospitals | Scroll 2 -> 10
# Koraput | hospitals | Scroll 3 -> 10
# Koraput | hospitals | Scroll 4 -> 10
# Koraput | hospitals | Scroll 5 -> 10
# Collected 10 links
# Koraput | 1/10
# S L N Medical College & Hospital, Koraput
# Koraput | 2/10
# Koraput Govt Medical
# Koraput | 3/10
# Bikash Diagnostic Centre and Hospital Koraput
# Koraput | 4/10
# Vijaya Lifeline Hospital
# Backup Saved
# Koraput | 5/10
# City Hospital
# Koraput | 6/10
# Koraput government hospital
# Koraput | 7/10
# SLN MEDICAL COLLEGE
# Koraput | 8/10
# District Headquarter Hospital(Koraput)
# Koraput | 9/10
# Handicap Hospital
# Koraput | 10/10
# New Government Medical College Koraput
#
# Searching: hospitals in Malkangiri Odisha
# Search Submitted
# Malkangiri | hospitals | Scroll 1 -> 7
# Malkangiri | hospitals | Scroll 2 -> 7
# Malkangiri | hospitals | Scroll 3 -> 7
# Malkangiri | hospitals | Scroll 4 -> 7
# Malkangiri | hospitals | Scroll 5 -> 7
# Collected 7 links
# Malkangiri | 1/7
# District Headquarters Hospital Malkangiri
# Malkangiri | 2/7
# St Luke Temple Hospital
# Malkangiri | 3/7
# Malkangiri Old Hospital
# Malkangiri | 4/7
# DHH MALKANGIRI
# Malkangiri | 5/7
# UPHC MALKANGIRI
# Malkangiri | 6/7
# Kudumulugumma Chc Hospital
# Malkangiri | 7/7
# Hospital malkangiri
#
# Searching: hospitals in Mayurbhanj Odisha
# Search Submitted
# Mayurbhanj | hospitals | Scroll 1 -> 3
# Mayurbhanj | hospitals | Scroll 2 -> 3
# Mayurbhanj | hospitals | Scroll 3 -> 3
# Mayurbhanj | hospitals | Scroll 4 -> 3
# Mayurbhanj | hospitals | Scroll 5 -> 3
# Collected 3 links
# Mayurbhanj | 1/3
# PRM Medical College & Hospital
# Mayurbhanj | 2/3
# Dukura C.H.C. Hospital
# Mayurbhanj | 3/3
# Jaya Hospital
#
# Searching: hospitals in Nabarangpur Odisha
# Search Submitted
# Nabarangpur | hospitals | Scroll 1 -> 3
# Nabarangpur | hospitals | Scroll 2 -> 3
# Nabarangpur | hospitals | Scroll 3 -> 3
# Nabarangpur | hospitals | Scroll 4 -> 3
# Nabarangpur | hospitals | Scroll 5 -> 3
# Collected 3 links
# Nabarangpur | 1/3
# Christian Hospital, Nabarangpur
# Nabarangpur | 2/3
# District HQ Hospital
# Nabarangpur | 3/3
# Nabarangpur civil Hospital
#
# Searching: hospitals in Nayagarh Odisha
# Search Submitted
# Nayagarh | hospitals | Scroll 1 -> 14
# Nayagarh | hospitals | Scroll 2 -> 17
# Nayagarh | hospitals | Scroll 3 -> 17
# Nayagarh | hospitals | Scroll 4 -> 17
# Nayagarh | hospitals | Scroll 5 -> 17
# Nayagarh | hospitals | Scroll 6 -> 17
# Collected 17 links
# Nayagarh | 1/17
# Chidananda hospital pvt. Ltd.
# Nayagarh | 2/17
# Health and wealthhos
# Nayagarh | 3/17
# MCH building, DHH, Nayagarh
# Nayagarh | 4/17
# Nabajeeban Seva Sadan Hospital
# Nayagarh | 5/17
# Sunrise Hospital
# Nayagarh | 6/17
# Ramakrishna Memorial Hospital,Nayagarh
# Nayagarh | 7/17
# New Sri Ram Hospital
# Nayagarh | 8/17
# DHH, Nayagarh
# Nayagarh | 9/17
# Rasmi Hospital
# Nayagarh | 10/17
# Bhoomika Eye Hospital
# Nayagarh | 11/17
# SUN APOLO DIAGNOSTIC, NAYAGARH
# Nayagarh | 12/17
# Kailash Hospital Nayagarh
# Nayagarh | 13/17
# LAINA'S EYE HOSPITAL AND RESEARCH CENTER
# Nayagarh | 14/17
# Nava jeevan seva sadan private hospital
# Nayagarh | 15/17
# PRAMILA NOURISHING HOME, NAYAGARH
# Nayagarh | 16/17
# Sahaya free dlalysis services
# Nayagarh | 17/17
# DTC NAYAGARH
#
# Searching: hospitals in Nuapada Odisha
# Search Submitted
# Nuapada | hospitals | Scroll 1 -> 6
# Nuapada | hospitals | Scroll 2 -> 6
# Nuapada | hospitals | Scroll 3 -> 6
# Nuapada | hospitals | Scroll 4 -> 6
# Nuapada | hospitals | Scroll 5 -> 6
# Collected 6 links
# Nuapada | 1/6
# District Headquarters Hospital, Nuapada
# Nuapada | 2/6
# GRROSS HOSPITAL
# Nuapada | 3/6
# Nuapada Govt Hospital
# Nuapada | 4/6
# Prahallad Dental Hospital
# Nuapada | 5/6
# Nuapada Govt Hospital
# Nuapada | 6/6
# Nuapada pathak
#
# Searching: hospitals in Puri Odisha
# Search Submitted
# Puri | hospitals | Scroll 1 -> 14
# Puri | hospitals | Scroll 2 -> 16
# Puri | hospitals | Scroll 3 -> 16
# Puri | hospitals | Scroll 4 -> 16
# Puri | hospitals | Scroll 5 -> 16
# Puri | hospitals | Scroll 6 -> 16
# Collected 16 links
# Puri | 1/16
# E-24 Hospital
# Puri | 2/16
# Shymashree Multispeciality Hospital.Pvt.Ltd | Best Multispeciality hospital in Puri
# Puri | 3/16
# District Headquarter Hospital, Puri
# Puri | 4/16
# Shree Jagannath Hospital
# Puri | 5/16
# Sanjeevani Hospital
# Puri | 6/16
# Shri Jagannath Medical College and Hospital, Puri
# Puri | 7/16
# Sunrise Hospital
# Puri | 8/16
# Shri Jagannath Medical College Hospital
# Puri | 9/16
# Cholera Hospital
# Puri | 10/16
# RASHMI AYUSH HOSPITAL
# Puri | 11/16
# NILACHAL NURSING HOME
# Puri | 12/16
# Saradha Nursing Home
# Puri | 13/16
# Hospital
# Puri | 14/16
# Charichhak Primary Hospital
# Puri | 15/16
# Sunshine Hospital
# Puri | 16/16
# Shiba Sankar Hospital
#
# Searching: hospitals in Rayagada Odisha
# Search Submitted
# Rayagada | hospitals | Scroll 1 -> 5
# Rayagada | hospitals | Scroll 2 -> 5
# Rayagada | hospitals | Scroll 3 -> 5
# Rayagada | hospitals | Scroll 4 -> 5
# Rayagada | hospitals | Scroll 5 -> 5
# Collected 5 links
# Rayagada | 1/5
# District Head Quarter Hospital, Rayagada
# Rayagada | 2/5
# Government hospital rayagada
# Rayagada | 3/5
# Govt Hospital
# Rayagada | 4/5
# Naba Jeeban Nursing Home
# Rayagada | 5/5
# Railway Health Unit
#
# Searching: hospitals in Sambalpur Odisha
# Search Submitted
# Sambalpur | hospitals | Scroll 1 -> 14
# Sambalpur | hospitals | Scroll 2 -> 20
# Sambalpur | hospitals | Scroll 3 -> 22
# Sambalpur | hospitals | Scroll 4 -> 22
# Sambalpur | hospitals | Scroll 5 -> 22
# Sambalpur | hospitals | Scroll 6 -> 22
# Sambalpur | hospitals | Scroll 7 -> 22
# Collected 22 links
# Sambalpur | 1/22
# Vaidya Vikash Hospitals
# Sambalpur | 2/22
# Sanjivani Hospital
# Sambalpur | 3/22
# Life Care Multispeciality Hospital
# Sambalpur | 4/22
# Aruna Shakti Hospital
# Sambalpur | 5/22
# Vikash City Hospital
# Sambalpur | 6/22
# District Head Quarter Hospital
# Sambalpur | 7/22
# Krishna Vikash Super Speciality Hospital
# Sambalpur | 8/22
# Life care hospital
# Sambalpur | 9/22
# DY MEDICAL CARE
# Sambalpur | 10/22
# Seva Nursing Home
# Sambalpur | 11/22
# Srusti Maternity & Nursing Home
# Sambalpur | 12/22
# Samarpan Children Hospital
# Sambalpur | 13/22
# Jesus Mary Joseph Hospital
# Sambalpur | 14/22
# Krishna Vikash Binayak Hospital, Burla
# Sambalpur | 15/22
# Regional HEALTH &FAMILY WELFARE Training Centre,Sambalpur
# Sambalpur | 16/22
# Hari Om Health Home
# Sambalpur | 17/22
# Ashirwad Nursing Home
# Sambalpur | 18/22
# Government Hospital
# Sambalpur | 19/22
# Basundhara Maternity Home
# Sambalpur | 20/22
# BALAJI NURSING HOME
# Sambalpur | 21/22
# Trilochan Netralaya
# Sambalpur | 22/22
# Sanjivani Test Tube Baby Centre | Best IVF Centre
#
# Searching: hospitals in Subarnapur Odisha
# Search Submitted
# Subarnapur | hospitals | Scroll 1 -> 14
# Subarnapur | hospitals | Scroll 2 -> 18
# Subarnapur | hospitals | Scroll 3 -> 18
# Subarnapur | hospitals | Scroll 4 -> 18
# Subarnapur | hospitals | Scroll 5 -> 18
# Subarnapur | hospitals | Scroll 6 -> 18
# Collected 18 links
# Subarnapur | 1/18
# New District Headquarters Hospital, Subarnapur
# Subarnapur | 2/18
# District MOTHER AND CHILD HOSPITAL
# Subarnapur | 3/18
# SOBHA CARE HOSPITAL
# Subarnapur | 4/18
# SAMALESWARI NURSING HOME, SONEPUR
# Subarnapur | 5/18
# New DHH sonepur
# Subarnapur | 6/18
# HITECH POLYCLINIC
# Subarnapur | 7/18
# Ramchandi Medical, Sonepur
# Subarnapur | 8/18
# Siddharth Medical Store
# Subarnapur | 9/18
# ANM TRAINING CENTER, SUBARNAPUR, ODISHA
# Subarnapur | 10/18
# District Headquarter Hospital, sonepur
# Subarnapur | 11/18
# ଜିଲ୍ଲା ମୁଖ୍ୟାଳୟ ଡାକ୍ତରଖାନା, ସବର୍ଣ୍ଣପୁର (DHH, Subarnapur)
# Subarnapur | 12/18
# Hrusikesh Medical Store
# Subarnapur | 13/18
# NIKI HEALTHCARE POLYCLINIC
# Subarnapur | 14/18
# Arogyadham Medical Store and Health Care
# Subarnapur | 15/18
# Subarnapur Hospital
# Backup Saved
# Subarnapur | 16/18
# Community Health Center
# Subarnapur | 17/18
# Asha Nursing Home-2
# Subarnapur | 18/18
# District Headquarters Hospital, Subarnapur
#
# Searching: hospitals in Sundargarh Odisha
# Search Submitted
# Sundargarh | hospitals | Scroll 1 -> 14
# Sundargarh | hospitals | Scroll 2 -> 15
# Sundargarh | hospitals | Scroll 3 -> 15
# Sundargarh | hospitals | Scroll 4 -> 15
# Sundargarh | hospitals | Scroll 5 -> 15
# Sundargarh | hospitals | Scroll 6 -> 15
# Collected 15 links
# Sundargarh | 1/15
# District Headquarters Hospital, Sundargarh
# Sundargarh | 2/15
# Government Medical College & Hospital, Sundargarh
# Sundargarh | 3/15
# MAA SAMALEI FAMILY HOSPITAL
# Sundargarh | 4/15
# Shantilata hospital and research center
# Sundargarh | 5/15
# AMARJYOTI HOSPITALS PVT LTD
# Sundargarh | 6/15
# NTPC Medical College and Hospital
# Sundargarh | 7/15
# NEW AAROGYA NURSING HOME
# Sundargarh | 8/15
# Disha hospitals
# Sundargarh | 9/15
# MOTHER AND CHILD CARE GOV HOSPITAL
# Sundargarh | 10/15
# Teaching Hospital, Government Medical College & Hospital, Sundargarh
# Sundargarh | 11/15
# RP Line Hospital
# Sundargarh | 12/15
# Amarjyoti Poly Clinic
# Sundargarh | 13/15
# Newlife multispeciality hospital
# Sundargarh | 14/15
# Urban Primary Health Centre Sundargarh
# Sundargarh | 15/15
# UHWC SUNDARGARH
#
# Extraction Completed
# Total Hospitals Extracted: 518
#
# Saved File: odisha_hospitals.csv
