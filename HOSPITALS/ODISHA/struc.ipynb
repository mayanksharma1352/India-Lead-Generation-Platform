# %%
import pandas as pd

# %%
df = pd.read_csv("odisha_hospitals.csv")

# %%
df.shape
# Out:
# (518, 8)

# %%
df = df[
    df["Phone"].notna() & 
    (df["Phone"].astype(str).str.strip() != "")
    ]
df.shape
# Out:
# (282, 8)

# %%
df = df[
    df["Hospital Name"].notna()
    ]

df = df[
    df["Hospital Name"].str.strip() != ""
    ]
df.shape
# Out:
# (282, 8)

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]","",regex=True)
    .str.strip()
)

display(df[["Phone"]].head())
# Out:
#            Phone
# 0  06764 232 507
# 1   085990 73003
# 3   094370 32221
# 4   091786 05515
# 5   085990 04450

# %%
df.to_csv(
    "odisha_hospitals_cleaned.csv",
    index=False
)
