# %%
import pandas as pd

# %%
df = pd.read_csv("madhya_pradesh_backup.csv")

# %%
df.shape
# Out:
# (1400, 8)

# %%
df = df[
    df["Phone"].notna() & 
    (df["Phone"].astype(str).str.strip() != "")
    ]
df.shape
# Out:
# (868, 8)

# %%
df = df[
    df["Hospital Name"].notna()
    ]

df = df[
    df["Hospital Name"].str.strip() != ""
    ]
df.shape
# Out:
# (868, 8)

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]","",regex=True)
    .str.strip()
)

display(df[["Phone"]].head())
# Out:
#            Phone
# 2   089622 26934
# 4   094254 28404
# 7   062646 78369
# 9   073622 58967
# 11  089890 74647

# %%
df.to_csv(
    "madhya_pradesh_hospitals_cleaned.csv",
    index=False
)
