# %%
import pandas as pd

# %%
df = pd.read_csv("haryana_hospitals.csv")

# %%
df.shape
# Out:
# (1181, 8)

# %%
df = df[
    df["Phone"].notna() & 
    (df["Phone"].astype(str).str.strip() != "")
    ]
df.shape
# Out:
# (27, 8)

# %%
df = df[
    df["Hospital Name"].notna()
    ]

df = df[
    df["Hospital Name"].str.strip() != ""
    ]
df.shape
# Out:
# (27, 8)

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]","",regex=True)
    .str.strip()
)

display(df[["Phone"]].head())
# Out:
#            Phone
# 1   097293 93193
# 2  0171 255 3703
# 3  0171 255 3240
# 4   093065 47394
# 5  1800 180 1234

# %%
df.to_csv(
    "haryana_hospitals_cleaned.csv",
    index=False
)
