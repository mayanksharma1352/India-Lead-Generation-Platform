# %%
import time
import random
import pandas as pd

from datetime import datetime

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.service import Service

from webdriver_manager.chrome import ChromeDriverManager


districts = [
    "Alappuzha",
    "Ernakulam",
    "Idukki",
    "Kannur",
    "Kasaragod",
    "Kollam",
    "Kottayam",
    "Kozhikode",
    "Malappuram",
    "Palakkad",
    "Pathanamthitta",
    "Thiruvananthapuram",
    "Thrissur",
    "Wayanad"
]



search_types = [
    "hospitals"
]


options = webdriver.ChromeOptions()

options.add_argument("--start-maximized")

options.add_argument(
    "--disable-blink-features=AutomationControlled"
)

options.add_argument("--disable-notifications")

driver = webdriver.Chrome(

    service=Service(
        ChromeDriverManager().install()
    ),

    options=options
)


driver.get("https://www.google.com/maps")

print("Opening Google Maps...")

time.sleep(15)

print("Google Maps Loaded")

all_data = []

visited_links = set()


def get_search_box():

    selectors = [

        '//input[@id="searchboxinput"]',
        '//input[contains(@placeholder,"Search")]',
        '//input[contains(@aria-label,"Search")]',
        '//input'

    ]

    for selector in selectors:

        try:

            box = driver.find_element(
                By.XPATH,
                selector
            )

            return box

        except:
            pass

    return None


def extract_school_data():

    try:

        # SCHOOL NAME
        try:
            name = driver.find_element(
                By.TAG_NAME,
                "h1"
            ).text
        except:
            name = ""

        # ADDRESS
        try:
            address = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"address")]'
            ).text
        except:
            address = ""

        # PHONE
        try:
            phone = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"phone")]'
            ).text
        except:
            phone = ""

        # WEBSITE
        try:
            website = driver.find_element(
                By.XPATH,
                '//a[contains(@data-item-id,"authority")]'
            ).get_attribute("href")
        except:
            website = ""

        # RATING
        try:
            rating = driver.find_element(
                By.XPATH,
                '//div[@role="img"]'
            ).get_attribute("aria-label")
        except:
            rating = ""

        return {

            "Hospital Name": name,
            "Address": address,
            "Phone": phone,
            "Website": website,
            "Rating": rating,
            "Google Maps URL": driver.current_url

        }

    except:

        return None


for district in districts:

    for search_type in search_types:

        try:

            query = (
                f"{search_type} "
                f"in {district} Kerala"
            )

            print(f"\nSearching: {query}")


            search_box = get_search_box()

            if not search_box:

                print("Search Box Not Found")

                continue

            ActionChains(driver).move_to_element(
                search_box
            ).click().perform()

            time.sleep(1)

            search_box.send_keys(
                Keys.CONTROL + "a"
            )

            time.sleep(1)

            search_box.send_keys(Keys.DELETE)

            time.sleep(1)


            for char in query:

                search_box.send_keys(char)

                time.sleep(0.03)

            search_box.send_keys(Keys.ENTER)

            print("Search Submitted")

            time.sleep(8)


            try:

                scrollable_div = driver.find_element(
                    By.XPATH,
                    '//div[@role="feed"]'
                )

                previous_count = 0

                stagnant = 0

                for i in range(100):

                    driver.execute_script(
                        """
                        arguments[0].scrollTop =
                        arguments[0].scrollHeight
                        """,
                        scrollable_div
                    )

                    time.sleep(4)

                    listings = driver.find_elements(
                        By.XPATH,
                        '//a[contains(@href,"/maps/place/")]'
                    )

                    current_count = len(listings)

                    print(
                        f"{district} | "
                        f"{search_type} | "
                        f"Scroll {i+1} -> "
                        f"{current_count}"
                    )

                    if current_count == previous_count:

                        stagnant += 1

                    else:

                        stagnant = 0

                    if stagnant >= 4:

                        break

                    previous_count = current_count

            except Exception as e:

                print(f"Scrolling Error: {e}")


            listings = driver.find_elements(
                By.XPATH,
                '//a[contains(@href,"/maps/place/")]'
            )

            links = []

            for listing in listings:

                try:

                    link = listing.get_attribute("href")

                    if (
                        link
                        and link not in visited_links
                    ):

                        links.append(link)

                        visited_links.add(link)

                except:
                    pass

            print(f"Collected {len(links)} links")


            for index, link in enumerate(links):

                try:

                    print(
                        f"{district} | "
                        f"{index+1}/{len(links)}"
                    )

                    driver.get(link)

                    time.sleep(
                        random.uniform(2, 4)
                    )

                    data = extract_school_data()

                    if data:

                        data["District"] = district

                        data["Search Type"] = search_type

                        all_data.append(data)

                        print(data["Hospital Name"])


                    if len(all_data) % 100 == 0:

                        backup_df = pd.DataFrame(
                            all_data
                        )

                        backup_df.drop_duplicates(
                            subset=[
                                "Hospital Name",
                                "Google Maps URL"
                            ],
                            inplace=True
                        )

                        backup_filename = (
                            "kerala_backup.csv"
                        )

                        backup_df.to_csv(
                            backup_filename,
                            index=False
                        )

                        print("Backup Saved")

                except Exception as e:

                    print(
                        f"School Error: {e}"
                    )

        except Exception as e:

            print(
                f"District Error: {e}"
            )


df = pd.DataFrame(all_data)

df.drop_duplicates(

    subset=[
        "Hospital Name",
        "Google Maps URL"
    ],

    inplace=True
)


filename = (
    "kerala_hospitals.csv"
)

df.to_csv(
    filename,
    index=False
)

print("\nExtraction Completed")

print(
    f"Total Hospitals Extracted: {len(df)}"
)

print(f"\nSaved File: {filename}")

driver.quit()
# Out:
# Opening Google Maps...
# Google Maps Loaded
#
# Searching: hospitals in Alappuzha Kerala
# Search Submitted
# Alappuzha | hospitals | Scroll 1 -> 14
# Alappuzha | hospitals | Scroll 2 -> 20
# Alappuzha | hospitals | Scroll 3 -> 20
# Alappuzha | hospitals | Scroll 4 -> 20
# Alappuzha | hospitals | Scroll 5 -> 20
# Alappuzha | hospitals | Scroll 6 -> 20
# Collected 20 links
# Alappuzha | 1/20
# Sanjos Hospital
# Alappuzha | 2/20
# Providence Hospital, Thumpoly, Alappuzha
# Alappuzha | 3/20
# General Hospital Alappuzha
# Alappuzha | 4/20
# ALLEPPEY MEDICAL CENTER
# Alappuzha | 5/20
# Sahrudaya Hospital, Alappuzha
# Alappuzha | 6/20
# SAGARA Hospital
# Alappuzha | 7/20
# T.D. Medical College Hospital
# Alappuzha | 8/20
# Pazhaveedu Medical Care - PMC
# Alappuzha | 9/20
# Mathery Trust Hospital
# Alappuzha | 10/20
# E S I Hospital
# Alappuzha | 11/20
# Women & Children Hospital Alappuzha
# Alappuzha | 12/20
# Believers Medical Centre Alappuzha
# Alappuzha | 13/20
# ECHS Polyclinic Alappuzha
# Alappuzha | 14/20
# Taluk Hospital RHTC
# Alappuzha | 15/20
# We One Hospital
# Alappuzha | 16/20
# Lith Speciality Medical Centre
# Alappuzha | 17/20
# St Michael's hospital
# Alappuzha | 18/20
# Idukki | hospitals | Scroll 11 -> 63
# Idukki | hospitals | Scroll 12 -> 63
# Idukki | hospitals | Scroll 13 -> 63
# Collected 63 links
# Idukki | 1/63
# Baby Memorial Hospital, Thodupuzha
# Idukki | 2/63
# Holy Family Hospital Muthalakodam, Thodupuzha
# Backup Saved
# Idukki | 3/63
# IDUKKI District Co-Operative Hospital, Thodupuzha (IDCH)
# Idukki | 4/63
# Government Medical College, Idukki - New Building
# Idukki | 5/63
# ST. MARY'S HOSPITAL, THODUPUZHA
# Idukki | 6/63
# Al Azhar Medical College & Super Speciality Hospital
# Idukki | 7/63
# Alphonsa Hospital Murickassery
# Idukki | 8/63
# St.George Hospital
# Idukki | 9/63
# District Ayurveda Hospital (Annex)
# Idukki | 10/63
# ST JOHNS HOSPITAL, KATTAPPANA
# Idukki | 11/63
# Medical Trust Hospital, Nedumkandam
# Idukki | 12/63
# Operation Theatre Complex,District Hospital,Idukki
# Idukki | 13/63
# Smita Memorial Hospital and Research Center
# Idukki | 14/63
# MERCY HOSPITAL
# Idukki | 15/63
# District Hospital (Thodupuzha)
# Idukki | 16/63
# Lifeblooms Hospital
# Idukki | 17/63
# S.H. Hospital Paynkulam
# Idukki | 18/63
# Government Medical College, Idukki
# Idukki | 19/63
# Archana Hospital, Thodupuzha
# Idukki | 20/63
# M G M Hospital
# Idukki | 21/63
# Kaalimadom Ayurvedics| Hospital for Piles Fistula Fissure in Thodupuzha, Idukki.
# Idukki | 22/63
# Hospital
# Idukki | 23/63
# C.S.I Hospital Chelachuvadu
# Idukki | 24/63
# മൃഗാശുപത്രി
# Idukki | 25/63
# Morning Star Medical Centre
# Idukki | 26/63
# Bala Hospital Kattappana
# Idukki | 27/63
# Ranigiri Hospital Trust
# Idukki | 28/63
# Taluk Government Hospital, Kattappana
# Idukki | 29/63
# Subansiri Hospital
# Idukki | 30/63
# St. Xavier's Hospital Ellakkal
# Idukki | 31/63
# Nirmala Hospital Kambilikandam
# Idukki | 32/63
# Arpana Hospital
# Idukki | 33/63
# St. Mary's Hospital, Karimannoor
# Idukki | 34/63
# Karuna Hospital
# Idukki | 35/63
# Cooperative Hospital Kattappana
# Idukki | 36/63
# Alphonsa Hospital
# Idukki | 37/63
# Mercy Hospital
# Idukki | 38/63
# Mother's Care Hospital - Karimban
# Idukki | 39/63
# St. John’s Medical Centre
# Idukki | 40/63
# Govt.Hospital Kamakshi
# Idukki | 41/63
# Nedumkandam Taluk Hospital
# Idukki | 42/63
# Global Cardiac Centre
# Idukki | 43/63
# Taluk Head Quarters Hospital, Peermade (Azhutha)
# Idukki | 44/63
# THALUK HOSPITAL, Adimali
# Idukki | 45/63
# LifeCare Hospital & Diagnostic Centre
# Idukki | 46/63
# National Health Mission Idukki - Arogyakeralam
# Idukki | 47/63
# Vijayaraja Hospital
# Idukki | 48/63
# Co-Operative Hospital Thankamany
# Idukki | 49/63
# MSS Iqraa medical centre adimali
# Idukki | 50/63
# Angel Hospital
# Idukki | 51/63
# SIRIDI SAI HOSPITAL
# Idukki | 52/63
# Saro Hospital
# Kasaragod | hospitals | Scroll 5 -> 27
# Kasaragod | hospitals | Scroll 6 -> 27
# Kasaragod | hospitals | Scroll 7 -> 27
# Collected 27 links
# Kasaragod | 1/27
# Wintouch Multi Speciality Hospital
# Kasaragod | 2/27
# KIMS Hospital , Kasaragod
# Kasaragod | 3/27
# Aramana Hospital & Heart Centre
# Kasaragod | 4/27
# Janardan Hospital
# Kasaragod | 5/27
# Aster MIMS Hospital - Best Multispeciality Hospital in Kasaragod, Chengala
# Kasaragod | 6/27
# Carewell Hospital & Research Centre Pvt Ltd
# Kasaragod | 7/27
# Govt General Hospital Kasaragod
# Kasaragod | 8/27
# UNITED MEDICAL CENTRE
# Backup Saved
# Kasaragod | 9/27
# K S Abdulla Hospital
# Kasaragod | 10/27
# Chaitra Medical Centre
# Kasaragod | 11/27
# Mallya City Hospital
# Kasaragod | 12/27
# Kamath Medical Centre
# Kasaragod | 13/27
# DIALIFE HOSPITAL KASARAGOD
# Kasaragod | 14/27
# Kerala Ayurveda Hospital
# Kasaragod | 15/27
# Krishna Hospital
# Kasaragod | 16/27
# EK Nayanar Memorial Co-Operative Hospital
# Kasaragod | 17/27
# CM Multi Speciality Hospital, Cherkala
# Kasaragod | 18/27
# Urban Family Health Center Kasaragod
# Kasaragod | 19/27
# hnc Hospital Deli
# Kasaragod | 20/27
# Doctors Hospital Kumbla
# Kasaragod | 21/27
# The Kasaragod District Co operative Hospital Society Ltd. Kumbla
# Kasaragod | 22/27
# Meitra United Heart Centre
# Kasaragod | 23/27
# Malik Deenar Globe Med Healthcare Centre
# Kasaragod | 24/27
# K A H M Hospital Cheruvathur
# Kasaragod | 25/27
# Manzoor Hospital
# Kasaragod | 26/27
# Government District Hospital, Chemmattamvayal
# Kasaragod | 27/27
# ESI DISPENSARY kasaragod
#
# Searching: hospitals in Kollam Kerala
# Search Submitted
# Kollam | hospitals | Scroll 1 -> 14
# Kollam | hospitals | Scroll 2 -> 20
# Kollam | hospitals | Scroll 3 -> 22
# Kollam | hospitals | Scroll 4 -> 22
# Kollam | hospitals | Scroll 5 -> 22
# Kollam | hospitals | Scroll 6 -> 22
# Kollam | hospitals | Scroll 7 -> 22
# Collected 22 links
# Kollam | 1/22
# Travancore Medicity Hospital Kollam
# Kollam | 2/22
# N. S. Memorial Institute of Medical Sciences
# Kollam | 3/22
# Meditrina Hospitals Pvt. Ltd.
# Kollam | 4/22
# Bishop Benziger Hospital
# Kollam | 5/22
# KIMSHEALTH Multispeciality Hospital
# Kollam | 6/22
# Kollam District Hospital
# Kollam | 7/22
# Upasana Hospital
# Kollam | 8/22
# Dr. Nair's Hospital
# Kollam | 9/22
# Matha Medical Centre
# Kollam | 10/22
# Aster PMF Hospital - Best Multispeciality Hospital in Kollam, Bharanikavu
# Kollam | 11/22
# Government Victoria Hospital
# Kollam | 12/22
# Ashtamudi Hospital
# Kollam | 13/22
# Holy Cross Hospital
# Kollam | 14/22
# Sankers Hospital
# Kollam | 15/22
# ESI Model & Super Specialty Hospital
# Kollam | 16/22
# Dr. Kumaradas Hospital
# Kollam | 17/22
# Devans Hospital
# Kollam | 18/22
# Kollam Medical Mission Hospital
# Kollam | 19/22
# A.A Rahim Memorial District Hospital , Kollam
# Kollam | 20/22
# Vijaya Hospital, Kottarakkara
# Kollam | 21/22
# RCPM Hospital
# Kollam | 22/22
# C Achuthamenon Co-Operative Hospital
#
# Searching: hospitals in Kottayam Kerala
# Search Submitted
# Kottayam | hospitals | Scroll 1 -> 14
# Kottayam | hospitals | Scroll 2 -> 20
# Kottayam | hospitals | Scroll 3 -> 27
# Kottayam | hospitals | Scroll 4 -> 34
# Kottayam | hospitals | Scroll 5 -> 34
# Kottayam | hospitals | Scroll 6 -> 34
# Kottayam | hospitals | Scroll 7 -> 34
# Kottayam | hospitals | Scroll 8 -> 34
# Collected 31 links
# Kottayam | 1/31
# Caritas Hospital - Multispeciality Hospital, Kottayam
# Kottayam | 2/31
# Kottayam General Hospital
# Kottayam | 3/31
# Caritas Matha Hospital
# Kottayam | 4/31
# Mitera Hospital
# Kottayam | 5/31
# CARITAS KMM
# Kottayam | 6/31
# Caritas Family Hospital, Kalathipady
# Kottayam | 7/31
# Welfast Hospital
# Kottayam | 8/31
# CMC Hospital
# Kottayam | 9/31
# Mandiram Hospital
# Kottayam | 10/31
# Dr Agarwals Eye Hospital
# Kottayam | 11/31
# Govt Medical College Hospital Kottayam
# Kottayam | 12/31
# Susrusha Hospital
# Kottayam | 13/31
# City Hospital, Kottayam
# Kottayam | 14/31
# Holy Ghost Mission Hospital
# Kottayam | 15/31
# E. S. I. Hospital, Kottayam
# Kottayam | 16/31
# Mary Queens Mission Hospital, Kanjirappally
# Kottayam | 17/31
# Medicorn Hospital Solutions Private Limited
# Kottayam | 18/31
# Chaithanya Eye Hospital & Research Institute
# Kottayam | 19/31
# Institute of Child Health, ICH Medical College Hospital
# Kottayam | 20/31
# Ahalia Foundation Eye Hospital kottayam
# Kottayam | 21/31
# St. Thomas Hospital Chethipuzha, Changanassery
# Kottayam | 22/31
# K. M. Mani Memorial Government General Hospital Pala
# Kottayam | 23/31
# Bishop Jacob Memorial Hospital
# Kottayam | 24/31
# St. Mary's Hospital
# Kottayam | 25/31
# District Ayurveda Hospital, Kottayam
# Kottayam | 26/31
# Mar Sleeva Medicity Palai
# Kottayam | 27/31
# Immaculate Heart of Mary Hospital
# Kottayam | 28/31
# General Hospital Changanassery
# Kottayam | 29/31
# Indo American Hospital
# Kottayam | 30/31
# NEW CASUALTY BLOCK, GOVERNMENT MEDICAL COLLEGE HOSPITAL KOTTAYAM
# Kottayam | 31/31
# JK Medicare & Diabetes Centre
#
# Searching: hospitals in Kozhikode Kerala
# Search Submitted
# Kozhikode | hospitals | Scroll 1 -> 14
# Kozhikode | hospitals | Scroll 2 -> 20
# Kozhikode | hospitals | Scroll 3 -> 27
# Kozhikode | hospitals | Scroll 4 -> 34
# Kozhikode | hospitals | Scroll 5 -> 40
# Kozhikode | hospitals | Scroll 6 -> 41
# Kozhikode | hospitals | Scroll 7 -> 41
# Kozhikode | hospitals | Scroll 8 -> 41
# Kozhikode | hospitals | Scroll 9 -> 41
# Kozhikode | hospitals | Scroll 10 -> 41
# Collected 41 links
# Kozhikode | 1/41
# Aster MIMS Hospital - Best Multispeciality Hospital in Calicut, Kozhikode
# Kozhikode | 2/41
# Starcare Hospital Kozhikode
# Kozhikode | 3/41
# Meitra Hospital
# Kozhikode | 4/41
# IQRAA International Hospital & Research Centre
# Kozhikode | 5/41
# Fathima Hospital
# Kozhikode | 6/41
# Malabar Hospitals
# Kozhikode | 7/41
# Baby Memorial Hospital
# Kozhikode | 8/41
# Calicut Hospital & Nursing Home.GCC Approved Medical Centre
# Kozhikode | 9/41
# Kozhikode District Co-Operative Hospital Ltd
# Kozhikode | 10/41
# Nirmala Hospital
# Kozhikode | 11/41
# National Hospital
# Kozhikode | 12/41
# Government General Hospital
# Kozhikode | 13/41
# PVS Sunrise Hospital Calicut
# Kozhikode | 14/41
# Rajendra Hospital
# Kozhikode | 15/41
# KMCT Medical College Hospital
# Kozhikode | 16/41
# Ascent ENT Hospital, Kozhikode
# Kozhikode | 17/41
# Red Crescent Hospital
# Kozhikode | 18/41
# Metromed International Cardiac Centre
# Kozhikode | 19/41
# Government Women and Children Hospital
# Kozhikode | 20/41
# Koyas Hospital
# Kozhikode | 21/41
# CHEST HOSPITAL
# Kozhikode | 22/41
# Beach hospital
# Kozhikode | 23/41
# Shiba Hospital
# Kozhikode | 24/41
# Manohar Hospital
# Kozhikode | 25/41
# Comtrust Charitable Trust Eye Hospital
# Kozhikode | 26/41
# IQRAA Community Clinic Kallai
# Kozhikode | 27/41
# AstenOrtho
# Kozhikode | 28/41
# STAR CARE HOSPITAL PARKING
# Backup Saved
# Kozhikode | 29/41
# Puthalath Eye Hospital
# Kozhikode | 30/41
# Santhi Hospital
# Kozhikode | 31/41
# TMH Hospital
# Kozhikode | 32/41
# Govt: hospital
# Kozhikode | 33/41
# Govt Medical College, Kozhikode
# Kozhikode | 34/41
# Dr.Sreekanth Eye Care & Research Centre
# Kozhikode | 35/41
# Baby Memorial Hospital Department of Neonatology
# Kozhikode | 36/41
# KIMS Trust Hospital
# Kozhikode | 37/41
# ആയുഷ്മാൻ ആരോഗ്യമന്ദിർ
# Kozhikode | 38/41
# MPC Hospital
# Kozhikode | 39/41
# Medico Speciality Clinic
# Kozhikode | 40/41
# Vathiad Hospital And Medical Centre
# Kozhikode | 41/41
# Hospital
#
# Searching: hospitals in Malappuram Kerala
# Search Submitted
# Malappuram | hospitals | Scroll 1 -> 14
# Malappuram | hospitals | Scroll 2 -> 20
# Malappuram | hospitals | Scroll 3 -> 24
# Malappuram | hospitals | Scroll 4 -> 24
# Malappuram | hospitals | Scroll 5 -> 24
# Malappuram | hospitals | Scroll 6 -> 24
# Malappuram | hospitals | Scroll 7 -> 24
# Collected 24 links
# Malappuram | 1/24
# M.B. Hospital
# Malappuram | 2/24
# ORCHID MEDICITY
# Malappuram | 3/24
# Ithis Hospital
# Malappuram | 4/24
# PMSA Memorial Malappuram District Co-Op Hospital
# Malappuram | 5/24
# NIMS Hospital
# Malappuram | 6/24
# Govt. Taluk Hospital Malappuram
# Malappuram | 7/24
# ithis women and children hospital
# Malappuram | 8/24
# Medimall Malappuram
# Malappuram | 9/24
# Almas Hospital
# Malappuram | 10/24
# Maanu Memorial Hospital Manjeri
# Malappuram | 11/24
# Christian mission hospital, American hospital
# Malappuram | 12/24
# MSP Hospital
# Malappuram | 13/24
# QUEENS MATERNITY HOSPITAL
# Malappuram | 14/24
# Karunya Hrudayalaya@ Malappuram
# Malappuram | 15/24
# The Eye Foundation
# Malappuram | 16/24
# ESI hospital uphill malappuram
# Malappuram | 17/24
# Nizar Hospital
# Malappuram | 18/24
# Nadakkavil Hospital
# Malappuram | 19/24
# KIMS Alshifa Super Speciality Hospital കിംസ് അൽശിഫ ആശുപത്രി
# Malappuram | 20/24
# Prasanthi Hospital
# Malappuram | 21/24
# Moulana Hospital
# Malappuram | 22/24
# Nahas Hospital
# Malappuram | 23/24
# PKM Hospital
# Malappuram | 24/24
# DMS Hospital LLP
#
# Searching: hospitals in Palakkad Kerala
# Search Submitted
# Palakkad | hospitals | Scroll 1 -> 14
# Palakkad | hospitals | Scroll 2 -> 20
# Palakkad | hospitals | Scroll 3 -> 27
# Palakkad | hospitals | Scroll 4 -> 34
# Palakkad | hospitals | Scroll 5 -> 37
# Palakkad | hospitals | Scroll 6 -> 37
# Palakkad | hospitals | Scroll 7 -> 37
# Palakkad | hospitals | Scroll 8 -> 37
# Palakkad | hospitals | Scroll 9 -> 37
# Collected 37 links
# Palakkad | 1/37
# Eumed Superspeciality Hospital - Best Hospital in Palakkad
# Palakkad | 2/37
# Thangam Hospital of PMRC
# Palakkad | 3/37
# Lakshmi Hospital
# Palakkad | 4/37
# Meditrina Hospital
# Palakkad | 5/37
# District Hospital, Palakkad
# Palakkad | 6/37
# Karuna Hospital
# Palakkad | 7/37
# Rajiv Gandhi Co-operative Hospital
# Palakkad | 8/37
# Ascent ENT Hospital & Medical Centre
# Palakkad | 9/37
# Daya Hospital, Palakkad
# Palakkad | 10/37
# SAI HOSPITAL OLAVAKKODE
# Palakkad | 11/37
# Paalana Hospital
# Palakkad | 12/37
# KIMS AVITIS Hospital, Palakkad
# Palakkad | 13/37
# Malabar Hospitals
# Palakkad | 14/37
# The Palakkad District Cooperative Hospital And Research Centre Ltd P No. 878
# Palakkad | 15/37
# Athani Hospital
# Palakkad | 16/37
# Palghat Poly Clinic Hospital Palakkad
# Palakkad | 17/37
# ESI Hospital,Palakkad
# Palakkad | 18/37
# Ahalia Foundation Eye Hospital Palakkad
# Palakkad | 19/37
# Dr. Menon's Hospital
# Palakkad | 20/37
# Valluvanad Hospital
# Palakkad | 21/37
# Prasanthi Hospital
# Palakkad | 22/37
# Ayur Palana
# Palakkad | 23/37
# Divisional Railway Hospital
# Palakkad | 24/37
# Trinity Super Speciality Eye Hospital
# Palakkad | 25/37
# Ahalia Ayurveda Medical College Hospital
# Palakkad | 26/37
# Govt Medical College Main block, Palakkad
# Palakkad | 27/37
# Palghat Poly Clinic
# Palakkad | 28/37
# CRESCENT HOSPITAL ALATHUR
# Palakkad | 29/37
# Mother Care Hospital
# Palakkad | 30/37
# Government Taluk Hospital Chittur
# Palakkad | 31/37
# Nila Hospital Pvt Ltd
# Palakkad | 32/37
# Puthuppariyaram co-operative Hospital & Research Centre (PCHRC)
# Palakkad | 33/37
# Aswini Speciality Hospital
# Palakkad | 34/37
# Seventh Day Adventist Hospital
# Palakkad | 35/37
# Ninans psychiatric hospital
# Palakkad | 36/37
# Thangam Hospital
# Palakkad | 37/37
# Rishi Hospital
#
# Searching: hospitals in Pathanamthitta Kerala
# Search Submitted
# Pathanamthitta | hospitals | Scroll 1 -> 14
# Pathanamthitta | hospitals | Scroll 2 -> 20
# Pathanamthitta | hospitals | Scroll 3 -> 27
# Pathanamthitta | hospitals | Scroll 4 -> 32
# Pathanamthitta | hospitals | Scroll 5 -> 32
# Pathanamthitta | hospitals | Scroll 6 -> 32
# Pathanamthitta | hospitals | Scroll 7 -> 32
# Pathanamthitta | hospitals | Scroll 8 -> 32
# Collected 31 links
# Pathanamthitta | 1/31
# Muthoot Medical Centre
# Pathanamthitta | 2/31
# St Luke Hospital
# Pathanamthitta | 3/31
# St.Thomas Hospital
# Pathanamthitta | 4/31
# District Hospital Pathanamthitta.
# Pathanamthitta | 5/31
# GEO Hospital
# Pathanamthitta | 6/31
# Vedagram Hospital
# Pathanamthitta | 7/31
# Poyanil Hospital
# Pathanamthitta | 8/31
# CHRISTIAN MISSION HOSPITAL PANDALAM, PATHANAMTHITTA (C M HOSPITAL)
# Pathanamthitta | 9/31
# Sunrise Hospital, Kulanada
# Pathanamthitta | 10/31
# Ahalia Foundation Eye Hospital, Pathanamthitta
# Pathanamthitta | 11/31
# Changethu Bhaskaran Nair Memorial Hospital
# Pathanamthitta | 12/31
# Aravind medicals Pathanamthita
# Pathanamthitta | 13/31
# The Lifeline Multi Speciality Hospital (Kerala)
# Pathanamthitta | 14/31
# GOOD SAMARITAN HOSPITAL
# Pathanamthitta | 15/31
# Muthoot Hospitals Kozhencherry
# Pathanamthitta | 16/31
# Ayurveda Dispensary Pathanamthitta Municipality
# Pathanamthitta | 17/31
# Sabitha Eye Care Hospital
# Pathanamthitta | 18/31
# Government Ayurveda Hospital Omalloor Pathanamthitta
# Pathanamthitta | 19/31
# District Hospital - Kozhencherry
# Pathanamthitta | 20/31
# Government General Hospital,Pathanamthitta
# Pathanamthitta | 21/31
# CHITRA MULTI SPECIALITY HOSPITAL
# Pathanamthitta | 22/31
# Pushpagiri Medical College Hospital Thiruvalla
# Pathanamthitta | 23/31
# Pathanamthitta Co-Operative (Group) Hospital Kulanada
# Pathanamthitta | 24/31
# Holy Cross Multi Speciality Hospital, Adoor
# Pathanamthitta | 25/31
# Government General Hospital, Adoor
# Pathanamthitta | 26/31
# Government Hospital
# Backup Saved
# Pathanamthitta | 27/31
# Believers Church Medical College Hospital
# Pathanamthitta | 28/31
# Govt.Taluk Hospital Ranny
# Pathanamthitta | 29/31
# Mar Chrysostom Fellowship Mission Hospital, Kumbanad
# Pathanamthitta | 30/31
# Blood Bank Pathanamthitta
# Pathanamthitta | 31/31
# Health Centre, Chenneerkara
#
# Searching: hospitals in Thiruvananthapuram Kerala
# Search Submitted
# Thiruvananthapuram | hospitals | Scroll 1 -> 14
# Thiruvananthapuram | hospitals | Scroll 2 -> 20
# Thiruvananthapuram | hospitals | Scroll 3 -> 27
# Thiruvananthapuram | hospitals | Scroll 4 -> 34
# Thiruvananthapuram | hospitals | Scroll 5 -> 40
# Thiruvananthapuram | hospitals | Scroll 6 -> 47
# Thiruvananthapuram | hospitals | Scroll 7 -> 54
# Thiruvananthapuram | hospitals | Scroll 8 -> 59
# Thiruvananthapuram | hospitals | Scroll 9 -> 59
# Thiruvananthapuram | hospitals | Scroll 10 -> 59
# Thiruvananthapuram | hospitals | Scroll 11 -> 59
# Thiruvananthapuram | hospitals | Scroll 12 -> 59
# Collected 59 links
# Thiruvananthapuram | 1/59
# SP Medifort Hospital
# Thiruvananthapuram | 2/59
# Sree Uthradom Thirunal (SUT) Hospital
# Thiruvananthapuram | 3/59
# GG Hospital
# Thiruvananthapuram | 4/59
# PRS Hospital
# Thiruvananthapuram | 5/59
# GENERAL HOSPITAL THIRUVANANTHAPURAM
# Thiruvananthapuram | 6/59
# Jubilee Memorial Hospital
# Thiruvananthapuram | 7/59
# Cosmopolitan Hospital Pvt.Ltd
# Thiruvananthapuram | 8/59
# Ananthapuri Hospitals and Research Institute (AHRI)
# Thiruvananthapuram | 9/59
# KIMSHEALTH Hospital Trivandrum
# Thiruvananthapuram | 10/59
# TSC Hospital
# Thiruvananthapuram | 11/59
# India Hospital
# Thiruvananthapuram | 12/59
# SP Fort Hospital
# Thiruvananthapuram | 13/59
# PULSE MEDICARE HOSPITAL PVT LTD
# Thiruvananthapuram | 14/59
# Sabine Hospitals - Trivandrum
# Thiruvananthapuram | 15/59
# Sree Avittam Thirunal Hospital(SAT)
# Thiruvananthapuram | 16/59
# SK Hospital
# Thiruvananthapuram | 17/59
# Sabine Hospitals Advanced Fertility Women Children
# Thiruvananthapuram | 18/59
# Al Arif Hospital
# Thiruvananthapuram | 19/59
# NIMS MICRO HOSPITALS
# Thiruvananthapuram | 20/59
# Sree Chitra Tirunal Institute for Medical Sciences & Technology
# Thiruvananthapuram | 21/59
# AJ Hospital
# Thiruvananthapuram | 22/59
# Government Medical College, Thiruvananthapuram
# Thiruvananthapuram | 23/59
# Royal medicity hospital shangumugham
# Thiruvananthapuram | 24/59
# Meditrina Hospital
# Thiruvananthapuram | 25/59
# NIMS Hospital
# Thiruvananthapuram | 26/59
# Pran Hospital
# Thiruvananthapuram | 27/59
# District Model Hospital
# Thiruvananthapuram | 28/59
# KIMSHEALTH East Block
# Thiruvananthapuram | 29/59
# Chaithanya Eye Hospital & Research Institute
# Thiruvananthapuram | 30/59
# Holy Cross Hospital
# Thiruvananthapuram | 31/59
# Govt. Medical College Hospital In-patient Block
# Thiruvananthapuram | 32/59
# Nirmala Hospital
# Metropolitan Hospital (Trichur Metropolitan Health Care Pvt Ltd )
# Thrissur | 17/32
# Thrissur General Hospital
# Thrissur | 18/32
# iVision Eye Hospital
# Thrissur | 19/32
# Aarya Eye Care Super Speciality Eye Hospital
# Thrissur | 20/32
# ST. VINCENT DE PAUL HOSPITAL
# Thrissur | 21/32
# Drs.GEM (GM) HOSPITAL
# Thrissur | 22/32
# Max Care Hospital (A Unit Of Divine Medical Centre Ltd)
# Thrissur | 23/32
# Drishyam Eye Care Hospital
# Thrissur | 24/32
# TRIVES Hospital (Thrissur Institute Of Vascular & Endovascular Surgery)
# Thrissur | 25/32
# Vasan Eye Care Hospital - (Shakthan Thampuran Nagar, Thrissur)
# Thrissur | 26/32
# Ansar Hospital
# Thrissur | 27/32
# Govt. Medical College Hospital Casualty
# Thrissur | 28/32
# Raji Nursing Home Hospital
# Thrissur | 29/32
# I Vision Eye Hospital
# Thrissur | 30/32
# Hayath Hospital
# Thrissur | 31/32
# TM Hospital (MES)
# Thrissur | 32/32
# MAR TIMOTHEUS CHARITABLE HOSPITAL
#
# Searching: hospitals in Wayanad Kerala
# Search Submitted
# Wayanad | hospitals | Scroll 1 -> 14
# Wayanad | hospitals | Scroll 2 -> 20
# Wayanad | hospitals | Scroll 3 -> 27
# Wayanad | hospitals | Scroll 4 -> 27
# Wayanad | hospitals | Scroll 5 -> 27
# Wayanad | hospitals | Scroll 6 -> 27
# Wayanad | hospitals | Scroll 7 -> 27
# Collected 27 links
# Wayanad | 1/27
# Vinayaka Hospital
# Wayanad | 2/27
# Aster Wayand Speciality Hospital
# Wayanad | 3/27
# IQRAA Hospital Sulthan Bathery
# Wayanad | 4/27
# Leo Hospital
# Backup Saved
# Wayanad | 5/27
# St.Joseph's Mission Hospital
# Wayanad | 6/27
# Fatima Mata Mission Hospital
# Wayanad | 7/27
# K J Medical Trust Hospital
# Wayanad | 8/27
# Swami Vivekananda Medical Mission Hospital
# Wayanad | 9/27
# Dr.Appukuttan Memorial Hospital
# Wayanad | 10/27
# Dr.Moopen's Medical College
# Wayanad | 11/27
# KARUNA EYE HOSPITAL
# Wayanad | 12/27
# Government General Hospital
# Wayanad | 13/27
# Victory Hospital
# Wayanad | 14/27
# Assumption Hospital
# Wayanad | 15/27
# MES Hospital, Sulthan Bathery
# Wayanad | 16/27
# Louise Mount Hospital
# Wayanad | 17/27
# St Martin's Hospital, Ambalavayal
# Wayanad | 18/27
# Arogya Hospital
# Wayanad | 19/27
# AROGYA HOSPITAL MEENANGADI
# Wayanad | 20/27
# Good Shepherd Hospital
# Wayanad | 21/27
# PBM Hospital
# Wayanad | 22/27
# Government Medical College Wayanad Mananthavady
# Wayanad | 23/27
# Santhi Hospital
# Wayanad | 24/27
# SHANTHA HOSPITAL
# Wayanad | 25/27
# Thaluk Head Quarters Hospital (THQH )Vythiri
# Wayanad | 26/27
# Vinayaka's Jyothi Hospital
# Wayanad | 27/27
# St Anns Hospital
#
# Extraction Completed
# Total Hospitals Extracted: 523
#
# Saved File: kerala_hospitals.csv
