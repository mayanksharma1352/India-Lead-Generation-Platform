# %%
import pandas as pd

# %%
df = pd.read_csv("kerala_hospitals.csv")

# %%
df.shape
# Out:
# (523, 8)

# %%
df = df[
    df["Phone"].notna() & 
    (df["Phone"].astype(str).str.strip() != "")
    ]
df.shape
# Out:
# (113, 8)

# %%
df = df[
    df["Hospital Name"].notna()
    ]

df = df[
    df["Hospital Name"].str.strip() != ""
    ]
df.shape
# Out:
# (113, 8)

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]","",regex=True)
    .str.strip()
)

display(df[["Phone"]].head())
# Out:
#            Phone
# 1  0477 225 0100
# 2  0477 225 3324
# 3   095266 16853
# 4  0477 224 7000
# 5  0477 226 7676

# %%
df.to_csv(
    "kerala_hospitals_cleaned.csv",
    index=False
)
