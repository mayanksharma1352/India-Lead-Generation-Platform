# %%
import pandas as pd

# %%
df = pd.read_csv("tamil_nadu_hospitals.csv")

# %%
df.shape
# Out:
# (2019, 8)

# %%
df = df[
    df["Phone"].notna() & 
    (df["Phone"].astype(str).str.strip() != "")
    ]
df.shape
# Out:
# (808, 8)

# %%
df = df[
    df["Hospital Name"].notna()
    ]

df = df[
    df["Hospital Name"].str.strip() != ""
    ]
df.shape
# Out:
# (807, 8)

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]","",regex=True)
    .str.strip()
)

display(df[["Phone"]].head())
# Out:
#            Phone
# 0   094875 76493
# 1   097100 60070
# 2   089254 22425
# 4   095971 19439
# 6  04329 222 199

# %%
df.to_csv(
    "tamil_nadu_hospitals_cleaned.csv",
    index=False
)
