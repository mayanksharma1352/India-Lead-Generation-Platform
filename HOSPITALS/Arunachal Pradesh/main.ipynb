# %%
import time
import random
import pandas as pd

from datetime import datetime

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.service import Service

from webdriver_manager.chrome import ChromeDriverManager


districts = [
    "Anjaw",
    "Bichom",
    "Changlang",
    "Dibang Valley",
    "East Kameng",
    "East Siang",
    "Kamle",
    "Kra Daadi",
    "Kurung Kumey",
    "Leparada",
    "Lohit",
    "Longding",
    "Lower Dibang Valley",
    "Lower Siang",
    "Lower Subansiri",
    "Namsai",
    "Pakke-Kessang",
    "Papum Pare",
    "Shi Yomi",
    "Siang",
    "Tawang",
    "Tirap",
    "Upper Siang",
    "Upper Subansiri",
    "West Kameng",
    "West Siang"
]



search_types = [
    "hospitals"
]


options = webdriver.ChromeOptions()

options.add_argument("--start-maximized")

options.add_argument(
    "--disable-blink-features=AutomationControlled"
)

options.add_argument("--disable-notifications")


driver = webdriver.Chrome(

    service=Service(
        ChromeDriverManager().install()
    ),

    options=options
)


driver.get("https://www.google.com/maps")

print("Opening Google Maps...")

time.sleep(15)

print("Google Maps Loaded")


all_data = []

visited_links = set()



def get_search_box():

    selectors = [

        '//input[@id="searchboxinput"]',
        '//input[contains(@placeholder,"Search")]',
        '//input[contains(@aria-label,"Search")]',
        '//input'

    ]

    for selector in selectors:

        try:

            box = driver.find_element(
                By.XPATH,
                selector
            )

            return box

        except:
            pass

    return None



def extract_school_data():

    try:

        try:
            name = driver.find_element(
                By.TAG_NAME,
                "h1"
            ).text
        except:
            name = ""

        
        try:
            address = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"address")]'
            ).text
        except:
            address = ""

        try:
            phone = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"phone")]'
            ).text
        except:
            phone = ""

        try:
            website = driver.find_element(
                By.XPATH,
                '//a[contains(@data-item-id,"authority")]'
            ).get_attribute("href")
        except:
            website = ""

        try:
            rating = driver.find_element(
                By.XPATH,
                '//div[@role="img"]'
            ).get_attribute("aria-label")
        except:
            rating = ""

        return {

            "Hospital Name": name,
            "Address": address,
            "Phone": phone,
            "Website": website,
            "Rating": rating,
            "Google Maps URL": driver.current_url

        }

    except:

        return None



for district in districts:

    for search_type in search_types:

        try:

            query = (
                f"{search_type} "
                f"in {district} Arunachal Pradesh"
            )

            print(f"\nSearching: {query}")



            search_box = get_search_box()

            if not search_box:

                print("Search Box Not Found")

                continue

            ActionChains(driver).move_to_element(
                search_box
            ).click().perform()

            time.sleep(1)

            search_box.send_keys(
                Keys.CONTROL + "a"
            )

            time.sleep(1)

            search_box.send_keys(Keys.DELETE)

            time.sleep(1)

            for char in query:

                search_box.send_keys(char)

                time.sleep(0.03)

            search_box.send_keys(Keys.ENTER)

            print("Search Submitted")

            time.sleep(8)

          

            try:

                scrollable_div = driver.find_element(
                    By.XPATH,
                    '//div[@role="feed"]'
                )

                previous_count = 0

                stagnant = 0

                for i in range(100):

                    driver.execute_script(
                        """
                        arguments[0].scrollTop =
                        arguments[0].scrollHeight
                        """,
                        scrollable_div
                    )

                    time.sleep(4)

                    listings = driver.find_elements(
                        By.XPATH,
                        '//a[contains(@href,"/maps/place/")]'
                    )

                    current_count = len(listings)

                    print(
                        f"{district} | "
                        f"{search_type} | "
                        f"Scroll {i+1} -> "
                        f"{current_count}"
                    )

                    if current_count == previous_count:

                        stagnant += 1

                    else:

                        stagnant = 0

                    if stagnant >= 4:

                        break

                    previous_count = current_count

            except Exception as e:

                print(f"Scrolling Error: {e}")

      

            listings = driver.find_elements(
                By.XPATH,
                '//a[contains(@href,"/maps/place/")]'
            )

            links = []

            for listing in listings:

                try:

                    link = listing.get_attribute("href")

                    if (
                        link
                        and link not in visited_links
                    ):

                        links.append(link)

                        visited_links.add(link)

                except:
                    pass

            print(f"Collected {len(links)} links")


            for index, link in enumerate(links):

                try:

                    print(
                        f"{district} | "
                        f"{index+1}/{len(links)}"
                    )

                    driver.get(link)

                    time.sleep(
                        random.uniform(2, 4)
                    )

                    data = extract_school_data()

                    if data:

                        data["District"] = district

                        data["Search Type"] = search_type

                        all_data.append(data)

                        print(data["Hospital Name"])

        

                    if len(all_data) % 100 == 0:

                        backup_df = pd.DataFrame(
                            all_data
                        )

                        backup_df.drop_duplicates(
                            subset=[
                                "Hospital Name",
                                "Google Maps URL"
                            ],
                            inplace=True
                        )

                        backup_filename = (
                            "arunachal_pradesh_backup.csv"
                        )

                        backup_df.to_csv(
                            backup_filename,
                            index=False
                        )

                        print("Backup Saved")

                except Exception as e:

                    print(
                        f"School Error: {e}"
                    )

        except Exception as e:

            print(
                f"District Error: {e}"
            )



df = pd.DataFrame(all_data)

df.drop_duplicates(

    subset=[
        "Hospital Name",
        "Google Maps URL"
    ],

    inplace=True
)



filename = (
    "arunachal_pradesh_hospitals.csv"
)

df.to_csv(
    filename,
    index=False
)

print("\nExtraction Completed")

print(
    f"Total Schools Extracted: {len(df)}"
)

print(f"\nSaved File: {filename}")

driver.quit()
# Out:
# Opening Google Maps...
# Google Maps Loaded
#
# Searching: hospitals in Anjaw Arunachal Pradesh
# Search Submitted
# Scrolling Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@role="feed"]"}
#   (Session info: chrome=148.0.7778.167); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 	chromedriver!GetHandleVerifier [0xd17123+10a23]
# 	chromedriver!GetHandleVerifier [0xd17254+10b54]
# 	chromedriver!(No symbol) [0xb31e90]
# 	chromedriver!(No symbol) [0xb7b28a]
# 	chromedriver!(No symbol) [0xb7b52b]
# 	chromedriver!(No symbol) [0xbbd062]
# 	chromedriver!(No symbol) [0xb9d7d4]
# 	chromedriver!(No symbol) [0xbba936]
# 	chromedriver!(No symbol) [0xb9d526]
# 	chromedriver!(No symbol) [0xb708f9]
# 	chromedriver!(No symbol) [0xb716b4]
# 	chromedriver!GetHandleVerifier [0xfb1ac4+2ab3c4]
# 	chromedriver!GetHandleVerifier [0xfad0ed+2a69ed]
# 	chromedriver!GetHandleVerifier [0xfce4f5+2c7df5]
# 	chromedriver!GetHandleVerifier [0xd31128+2aa28]
# 	chromedriver!GetHandleVerifier [0xd38bbd+324bd]
# 	chromedriver!GetHandleVerifier [0xd1fb28+19428]
# 	chromedriver!GetHandleVerifier [0xd1fcd5+195d5]
# 	chromedriver!GetHandleVerifier [0xd091cf+2acf]
# 	KERNEL32!BaseThreadInitThunk [0x75defcc9+19]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x779982ae+11e]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x7799827e+ee]
#
# Collected 2 links
# Anjaw | 1/2
# District Hospital
# Anjaw | 2/2
# Community Health Centre, Hawai
#
# Searching: hospitals in Bichom Arunachal Pradesh
# Search Submitted
# Scrolling Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@role="feed"]"}
#   (Session info: chrome=148.0.7778.167); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 	chromedriver!GetHandleVerifier [0xd17123+10a23]
# 	chromedriver!GetHandleVerifier [0xd17254+10b54]
# 	chromedriver!(No symbol) [0xb31e90]
# 	chromedriver!(No symbol) [0xb7b28a]
# 	chromedriver!(No symbol) [0xb7b52b]
# 	chromedriver!(No symbol) [0xbbd062]
# 	chromedriver!(No symbol) [0xb9d7d4]
# 	chromedriver!(No symbol) [0xbba936]
# 	chromedriver!(No symbol) [0xb9d526]
# 	chromedriver!(No symbol) [0xb708f9]
# 	chromedriver!(No symbol) [0xb716b4]
# 	chromedriver!GetHandleVerifier [0xfb1ac4+2ab3c4]
# 	chromedriver!GetHandleVerifier [0xfad0ed+2a69ed]
# 	chromedriver!GetHandleVerifier [0xfce4f5+2c7df5]
# 	chromedriver!GetHandleVerifier [0xd31128+2aa28]
# 	chromedriver!GetHandleVerifier [0xd38bbd+324bd]
# 	chromedriver!GetHandleVerifier [0xd1fb28+19428]
# 	chromedriver!GetHandleVerifier [0xd1fcd5+195d5]
# 	chromedriver!GetHandleVerifier [0xd091cf+2acf]
# 	KERNEL32!BaseThreadInitThunk [0x75defcc9+19]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x779982ae+11e]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x7799827e+ee]
#
# Collected 0 links
#
# Searching: hospitals in Changlang Arunachal Pradesh
# Search Submitted
# Changlang | hospitals | Scroll 1 -> 2
# Changlang | hospitals | Scroll 2 -> 2
# Changlang | hospitals | Scroll 3 -> 2
# Changlang | hospitals | Scroll 4 -> 2
# Changlang | hospitals | Scroll 5 -> 2
# Collected 2 links
# Changlang | 1/2
# District Hospital
# Changlang | 2/2
# Veterinary Dispensary Changlang
#
# Searching: hospitals in Dibang Valley Arunachal Pradesh
# Search Submitted
# Dibang Valley | hospitals | Scroll 1 -> 3
# Dibang Valley | hospitals | Scroll 2 -> 3
# Dibang Valley | hospitals | Scroll 3 -> 3
# Dibang Valley | hospitals | Scroll 4 -> 3
# Dibang Valley | hospitals | Scroll 5 -> 3
# Collected 2 links
# Dibang Valley | 1/2
# Arunachal Vet medical
# Dibang Valley | 2/2
# Veterinary Dispensary itanagar
#
# Searching: hospitals in East Kameng Arunachal Pradesh
# Search Submitted
# East Kameng | hospitals | Scroll 1 -> 2
# East Kameng | hospitals | Scroll 2 -> 2
# East Kameng | hospitals | Scroll 3 -> 2
# East Kameng | hospitals | Scroll 4 -> 2
# East Kameng | hospitals | Scroll 5 -> 2
# Collected 2 links
# East Kameng | 1/2
# DISTRICT HOSPITAL SEPPA
# East Kameng | 2/2
# Hope Health Centre
#
# Searching: hospitals in East Siang Arunachal Pradesh
# Search Submitted
# East Siang | hospitals | Scroll 1 -> 8
# East Siang | hospitals | Scroll 2 -> 8
# East Siang | hospitals | Scroll 3 -> 8
# East Siang | hospitals | Scroll 4 -> 8
# East Siang | hospitals | Scroll 5 -> 8
# Collected 8 links
# East Siang | 1/8
# Health Care Hospital
# East Siang | 2/8
# Bakin Pertin General Hospital
# East Siang | 3/8
# ASSA DIAGNOSTIC and NURSING HOME
# East Siang | 4/8
# I.S Diagnostic Centre and Hospital
# East Siang | 5/8
# TB Hospital
# East Siang | 6/8
# Pasighat
# East Siang | 7/8
# Alpha Clinic and Diagnostic Centre
# East Siang | 8/8
# Eskag Sanjeevani Dialysis Center Pasighat
#
# Searching: hospitals in Kamle Arunachal Pradesh
# Search Submitted
# Kamle | hospitals | Scroll 1 -> 14
# Kamle | hospitals | Scroll 2 -> 14
# Kamle | hospitals | Scroll 3 -> 14
# Kamle | hospitals | Scroll 4 -> 14
# Kamle | hospitals | Scroll 5 -> 14
# Collected 12 links
# Kamle | 1/12
# KBM Hospital, Injan
# Kamle | 2/12
# Community health center, Raga
# Kamle | 3/12
# Tadak Dulom District Hospital, Daporijo
# Kamle | 4/12
# Tago Memorial Hospital
# Kamle | 5/12
# Gyati Takka General Hospital, Ziro
# Kamle | 6/12
# General Hospital, Aalo
# Kamle | 7/12
# Ramakrishna Mission Hospital, Itanagar
# Kamle | 8/12
# Heema Hospital
# Kamle | 9/12
# Peelomai Tayang Memorial Hospital
# Kamle | 10/12
# Niba Multispecialty Hospital
# Kamle | 11/12
# M/S NIGLA HEALTH CARE HOSPITAL
# Kamle | 12/12
# Taliha General Hospital
#
# Searching: hospitals in Kra Daadi Arunachal Pradesh
# Search Submitted
# Kra Daadi | hospitals | Scroll 1 -> 9
# Kra Daadi | hospitals | Scroll 2 -> 9
# Kra Daadi | hospitals | Scroll 3 -> 9
# Kra Daadi | hospitals | Scroll 4 -> 9
# Kra Daadi | hospitals | Scroll 5 -> 9
# Collected 5 links
# Kra Daadi | 1/5
# District Hospital
# Kra Daadi | 2/5
# CHC- Palin, 50-Bedded Hospital Jorung
# Kra Daadi | 3/5
# Khando Drowa Sangmo District Hospital Tawang
# Kra Daadi | 4/5
# District Hospital
# Kra Daadi | 5/5
# Kra daadi lodge
#
# Searching: hospitals in Kurung Kumey Arunachal Pradesh
# Search Submitted
# Kurung Kumey | hospitals | Scroll 1 -> 2
# Kurung Kumey | hospitals | Scroll 2 -> 2
# Kurung Kumey | hospitals | Scroll 3 -> 2
# Kurung Kumey | hospitals | Scroll 4 -> 2
# Kurung Kumey | hospitals | Scroll 5 -> 2
# Collected 2 links
# Kurung Kumey | 1/2
# Damin Hospital
# Kurung Kumey | 2/2
# Primary Health Centre, Sangram
#
# Searching: hospitals in Leparada Arunachal Pradesh
# Search Submitted
# Leparada | hospitals | Scroll 1 -> 2
# Leparada | hospitals | Scroll 2 -> 2
# Leparada | hospitals | Scroll 3 -> 2
# Leparada | hospitals | Scroll 4 -> 2
# Leparada | hospitals | Scroll 5 -> 2
# Collected 1 links
# Leparada | 1/1
# District Hospital
#
# Searching: hospitals in Lohit Arunachal Pradesh
# Search Submitted
# Lohit | hospitals | Scroll 1 -> 8
# Lohit | hospitals | Scroll 2 -> 8
# Lohit | hospitals | Scroll 3 -> 8
# Lohit | hospitals | Scroll 4 -> 8
# Lohit | hospitals | Scroll 5 -> 8
# Collected 6 links
# Lohit | 1/6
# Zonal General Hospital, Tezu
# Lohit | 2/6
# District Hospital Namsai
# Lohit | 3/6
# District Hospital
# Lohit | 4/6
# PHC Loiliang
# Lohit | 5/6
# Jivaka Hospital, Namsai
# Lohit | 6/6
# District Hospital
#
# Searching: hospitals in Longding Arunachal Pradesh
# Search Submitted
# Scrolling Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@role="feed"]"}
#   (Session info: chrome=148.0.7778.167); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 	chromedriver!GetHandleVerifier [0xd17123+10a23]
# 	chromedriver!GetHandleVerifier [0xd17254+10b54]
# 	chromedriver!(No symbol) [0xb31e90]
# 	chromedriver!(No symbol) [0xb7b28a]
# 	chromedriver!(No symbol) [0xb7b52b]
# 	chromedriver!(No symbol) [0xbbd062]
# 	chromedriver!(No symbol) [0xb9d7d4]
# 	chromedriver!(No symbol) [0xbba936]
# 	chromedriver!(No symbol) [0xb9d526]
# 	chromedriver!(No symbol) [0xb708f9]
# 	chromedriver!(No symbol) [0xb716b4]
# 	chromedriver!GetHandleVerifier [0xfb1ac4+2ab3c4]
# 	chromedriver!GetHandleVerifier [0xfad0ed+2a69ed]
# 	chromedriver!GetHandleVerifier [0xfce4f5+2c7df5]
# 	chromedriver!GetHandleVerifier [0xd31128+2aa28]
# 	chromedriver!GetHandleVerifier [0xd38bbd+324bd]
# 	chromedriver!GetHandleVerifier [0xd1fb28+19428]
# 	chromedriver!GetHandleVerifier [0xd1fcd5+195d5]
# 	chromedriver!GetHandleVerifier [0xd091cf+2acf]
# 	KERNEL32!BaseThreadInitThunk [0x75defcc9+19]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x779982ae+11e]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x7799827e+ee]
#
# Collected 0 links
#
# Searching: hospitals in Lower Dibang Valley Arunachal Pradesh
# Search Submitted
# Lower Dibang Valley | hospitals | Scroll 1 -> 6
# Lower Dibang Valley | hospitals | Scroll 2 -> 6
# Lower Dibang Valley | hospitals | Scroll 3 -> 6
# Lower Dibang Valley | hospitals | Scroll 4 -> 6
# Lower Dibang Valley | hospitals | Scroll 5 -> 6
# Collected 5 links
# Lower Dibang Valley | 1/5
# DIBANG MEDICARE ROING
# Lower Dibang Valley | 2/5
# Ista Pulu Health Center
# Lower Dibang Valley | 3/5
# Civil Hospital
# Lower Dibang Valley | 4/5
# Apollo Clinic - Roing
# Lower Dibang Valley | 5/5
# AMR IBEX VENTURE
#
# Searching: hospitals in Lower Siang Arunachal Pradesh
# Search Submitted
# Lower Siang | hospitals | Scroll 1 -> 12
# Lower Siang | hospitals | Scroll 2 -> 12
# Lower Siang | hospitals | Scroll 3 -> 12
# Lower Siang | hospitals | Scroll 4 -> 12
# Lower Siang | hospitals | Scroll 5 -> 12
# Collected 4 links
# Lower Siang | 1/4
# District Hospital, Likabali
# Lower Siang | 2/4
# District Hospital
# Lower Siang | 3/4
# 356 Field Hospital
# Lower Siang | 4/4
# HOSPITAL
#
# Searching: hospitals in Lower Subansiri Arunachal Pradesh
# Search Submitted
# Lower Subansiri | hospitals | Scroll 1 -> 2
# Lower Subansiri | hospitals | Scroll 2 -> 2
# Lower Subansiri | hospitals | Scroll 3 -> 2
# Lower Subansiri | hospitals | Scroll 4 -> 2
# Lower Subansiri | hospitals | Scroll 5 -> 2
# Collected 2 links
# Lower Subansiri | 1/2
# Community Health Center, Ziro
# Lower Subansiri | 2/2
# Medical colony (Padu Dolley)
#
# Searching: hospitals in Namsai Arunachal Pradesh
# Search Submitted
# Namsai | hospitals | Scroll 1 -> 8
# Namsai | hospitals | Scroll 2 -> 8
# Namsai | hospitals | Scroll 3 -> 8
# Namsai | hospitals | Scroll 4 -> 8
# Namsai | hospitals | Scroll 5 -> 8
# Collected 5 links
# Namsai | 1/5
# Eskag Sanjeevani Dialysis Center Namsai
# Namsai | 2/5
# Apil Medical
# Namsai | 3/5
# Ayurvedic Health centre, Namsai
# Namsai | 4/5
# Medical Health Centre
# Namsai | 5/5
# Padma Health Care
#
# Searching: hospitals in Pakke-Kessang Arunachal Pradesh
# Search Submitted
# Pakke-Kessang | hospitals | Scroll 1 -> 15
# Pakke-Kessang | hospitals | Scroll 2 -> 15
# Pakke-Kessang | hospitals | Scroll 3 -> 15
# Pakke-Kessang | hospitals | Scroll 4 -> 15
# Pakke-Kessang | hospitals | Scroll 5 -> 15
# Collected 6 links
# Pakke-Kessang | 1/6
# Jullai mossang
# Pakke-Kessang | 2/6
# Community Health Centre, Siejosa
# Pakke-Kessang | 3/6
# SAMARITAN HORMIN HOSPITAL
# Pakke-Kessang | 4/6
# M/S Niting Enterprises medical colony
# Pakke-Kessang | 5/6
# August Women's Clinic and IVF Centre
# Pakke-Kessang | 6/6
# M/S Sumi health centre
#
# Searching: hospitals in Papum Pare Arunachal Pradesh
# Search Submitted
# Papum Pare | hospitals | Scroll 1 -> 12
# Papum Pare | hospitals | Scroll 2 -> 12
# Papum Pare | hospitals | Scroll 3 -> 12
# Papum Pare | hospitals | Scroll 4 -> 12
# Papum Pare | hospitals | Scroll 5 -> 12
# Collected 6 links
# Papum Pare | 1/6
# Emmanuel BTM Hospital
# Papum Pare | 2/6
# Polo Hospital
# Papum Pare | 3/6
# Tomo Riba Institute of Health and Medical Sciences
# Papum Pare | 4/6
# Urban Primary Health Centre, Itafort
# Papum Pare | 5/6
# M/S NIGLA HEALTH CARE HOSPITAL
# Papum Pare | 6/6
# YJD NURSING HOME
#
# Searching: hospitals in Shi Yomi Arunachal Pradesh
# Search Submitted
# Shi Yomi | hospitals | Scroll 1 -> 16
# Shi Yomi | hospitals | Scroll 2 -> 20
# Shi Yomi | hospitals | Scroll 3 -> 20
# Shi Yomi | hospitals | Scroll 4 -> 20
# Shi Yomi | hospitals | Scroll 5 -> 20
# Shi Yomi | hospitals | Scroll 6 -> 20
# Collected 2 links
# Shi Yomi | 1/2
# District Hospital Yingkiong
# Shi Yomi | 2/2
# CHC Miao
#
# Searching: hospitals in Siang Arunachal Pradesh
# Search Submitted
# Siang | hospitals | Scroll 1 -> 16
# Siang | hospitals | Scroll 2 -> 20
# Siang | hospitals | Scroll 3 -> 20
# Siang | hospitals | Scroll 4 -> 20
# Siang | hospitals | Scroll 5 -> 20
# Siang | hospitals | Scroll 6 -> 20
# Collected 2 links
# Siang | 1/2
# District Hospital, Bomdila
# Siang | 2/2
# Upper colony
#
# Searching: hospitals in Tawang Arunachal Pradesh
# Search Submitted
# Scrolling Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@role="feed"]"}
#   (Session info: chrome=148.0.7778.167); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 	chromedriver!GetHandleVerifier [0xd17123+10a23]
# 	chromedriver!GetHandleVerifier [0xd17254+10b54]
# 	chromedriver!(No symbol) [0xb31e90]
# 	chromedriver!(No symbol) [0xb7b28a]
# 	chromedriver!(No symbol) [0xb7b52b]
# 	chromedriver!(No symbol) [0xbbd062]
# 	chromedriver!(No symbol) [0xb9d7d4]
# 	chromedriver!(No symbol) [0xbba936]
# 	chromedriver!(No symbol) [0xb9d526]
# 	chromedriver!(No symbol) [0xb708f9]
# 	chromedriver!(No symbol) [0xb716b4]
# 	chromedriver!GetHandleVerifier [0xfb1ac4+2ab3c4]
# 	chromedriver!GetHandleVerifier [0xfad0ed+2a69ed]
# 	chromedriver!GetHandleVerifier [0xfce4f5+2c7df5]
# 	chromedriver!GetHandleVerifier [0xd31128+2aa28]
# 	chromedriver!GetHandleVerifier [0xd38bbd+324bd]
# 	chromedriver!GetHandleVerifier [0xd1fb28+19428]
# 	chromedriver!GetHandleVerifier [0xd1fcd5+195d5]
# 	chromedriver!GetHandleVerifier [0xd091cf+2acf]
# 	KERNEL32!BaseThreadInitThunk [0x75defcc9+19]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x779982ae+11e]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x7799827e+ee]
#
# Collected 0 links
#
# Searching: hospitals in Tirap Arunachal Pradesh
# Search Submitted
# Tirap | hospitals | Scroll 1 -> 4
# Tirap | hospitals | Scroll 2 -> 4
# Tirap | hospitals | Scroll 3 -> 4
# Tirap | hospitals | Scroll 4 -> 4
# Tirap | hospitals | Scroll 5 -> 4
# Collected 2 links
# Tirap | 1/2
# PHC Borduria
# Tirap | 2/2
# Hospital
#
# Searching: hospitals in Upper Siang Arunachal Pradesh
# Search Submitted
# Upper Siang | hospitals | Scroll 1 -> 8
# Upper Siang | hospitals | Scroll 2 -> 8
# Upper Siang | hospitals | Scroll 3 -> 8
# Upper Siang | hospitals | Scroll 4 -> 8
# Upper Siang | hospitals | Scroll 5 -> 8
# Collected 0 links
#
# Searching: hospitals in Upper Subansiri Arunachal Pradesh
# Search Submitted
# Upper Subansiri | hospitals | Scroll 1 -> 2
# Upper Subansiri | hospitals | Scroll 2 -> 2
# Upper Subansiri | hospitals | Scroll 3 -> 2
# Upper Subansiri | hospitals | Scroll 4 -> 2
# Upper Subansiri | hospitals | Scroll 5 -> 2
# Collected 1 links
# Upper Subansiri | 1/1
# Upper Subansiri District Hospital Blood Bank
#
# Searching: hospitals in West Kameng Arunachal Pradesh
# Search Submitted
# West Kameng | hospitals | Scroll 1 -> 6
# West Kameng | hospitals | Scroll 2 -> 6
# West Kameng | hospitals | Scroll 3 -> 6
# West Kameng | hospitals | Scroll 4 -> 6
# West Kameng | hospitals | Scroll 5 -> 6
# Collected 3 links
# West Kameng | 1/3
# Unit Hospital 4BN ITBP DIRANG
# West Kameng | 2/3
# General Hospital Bomdila
# West Kameng | 3/3
# CHC Dirang
#
# Searching: hospitals in West Siang Arunachal Pradesh
# Search Submitted
# West Siang | hospitals | Scroll 1 -> 13
# West Siang | hospitals | Scroll 2 -> 13
# West Siang | hospitals | Scroll 3 -> 13
# West Siang | hospitals | Scroll 4 -> 13
# West Siang | hospitals | Scroll 5 -> 13
# Collected 3 links
# West Siang | 1/3
# West Siang District Hospital Blood Bank
# West Siang | 2/3
# GG hotel
# West Siang | 3/3
# ANE HEALTH CARE AND DIAGNOSTIC CENTRE AALO
#
# Extraction Completed
# Total Schools Extracted: 83
#
# Saved File: arunachal_pradesh_hospitals.csv
