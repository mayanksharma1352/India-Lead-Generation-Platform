# %%
import pandas as pd

# %%
df = pd.read_csv("chhattisgarh_hospitals.csv")

# %%
df.shape
# Out:
# (562, 8)

# %%
df = df[
    df["Phone"].notna() & 
    (df["Phone"].astype(str).str.strip() != "")
    ]
df.shape
# Out:
# (34, 8)

# %%
df = df[
    df["Hospital Name"].notna()
    ]

df = df[
    df["Hospital Name"].str.strip() != ""
    ]
df.shape
# Out:
# (34, 8)

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]","",regex=True)
    .str.strip()
)

display(df[["Phone"]].head())
# Out:
#           Phone
# 1  090986 47794
# 3  077492 23924
# 4  087708 87307
# 5  077492 22600
# 7  097707 21340

# %%
df.to_csv(
    "chhattisgarh_hospitals_cleaned.csv",
    index=False
)
