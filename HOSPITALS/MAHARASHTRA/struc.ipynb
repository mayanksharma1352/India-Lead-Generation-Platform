# %%
import pandas as pd

# %%
df = pd.read_csv("maharashtra_hospitals.csv")

# %%
df.shape
# Out:
# (2128, 8)

# %%
df = df[
    df["Phone"].notna() & 
    (df["Phone"].astype(str).str.strip() != "")
    ]
df.shape
# Out:
# (1060, 8)

# %%
df = df[
    df["Hospital Name"].notna()
    ]

df = df[
    df["Hospital Name"].str.strip() != ""
    ]
df.shape
# Out:
# (1060, 8)

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]","",regex=True)
    .str.strip()
)

display(df[["Phone"]].head())
# Out:
#            Phone
# 1   062629 00900
# 2  0241 242 1290
# 3  0241 242 2411
# 4   093250 04040
# 5  0241 243 0530

# %%
df.to_csv(
    "maharashtra_hospitals_cleaned.csv",
    index=False
)
