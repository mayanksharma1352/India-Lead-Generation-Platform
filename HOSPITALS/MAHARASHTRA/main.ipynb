# %%
import time
import random
import pandas as pd

from datetime import datetime

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.service import Service

from webdriver_manager.chrome import ChromeDriverManager

# ==========================================
# MAHARASHTRA DISTRICTS
# ==========================================

districts = [

    "Osmanabad",
    "Palghar",
    "Parbhani",
    "Pune",
    "Raigad",
    "Ratnagiri",
    "Sangli",
    "Satara",
    "Sindhudurg",
    "Solapur",
    "Thane",
    "Wardha",
    "Washim",
    "Yavatmal"
]


search_types = [
    "hospitals"
]


options = webdriver.ChromeOptions()

options.add_argument("--start-maximized")

options.add_argument(
    "--disable-blink-features=AutomationControlled"
)

options.add_argument("--disable-notifications")


driver = webdriver.Chrome(

    service=Service(
        ChromeDriverManager().install()
    ),

    options=options
)


driver.get("https://www.google.com/maps")

print("Opening Google Maps...")

time.sleep(15)

print("Google Maps Loaded")


all_data = []

visited_links = set()


def get_search_box():

    selectors = [

        '//input[@id="searchboxinput"]',
        '//input[contains(@placeholder,"Search")]',
        '//input[contains(@aria-label,"Search")]',
        '//input'

    ]

    for selector in selectors:

        try:

            box = driver.find_element(
                By.XPATH,
                selector
            )

            return box

        except:
            pass

    return None


def extract_school_data():

    try:

        try:
            name = driver.find_element(
                By.TAG_NAME,
                "h1"
            ).text
        except:
            name = ""

        try:
            address = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"address")]'
            ).text
        except:
            address = ""

        try:
            phone = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"phone")]'
            ).text
        except:
            phone = ""

        try:
            website = driver.find_element(
                By.XPATH,
                '//a[contains(@data-item-id,"authority")]'
            ).get_attribute("href")
        except:
            website = ""

        try:
            rating = driver.find_element(
                By.XPATH,
                '//div[@role="img"]'
            ).get_attribute("aria-label")
        except:
            rating = ""

        return {

            "Hospital Name": name,
            "Address": address,
            "Phone": phone,
            "Website": website,
            "Rating": rating,
            "Google Maps URL": driver.current_url

        }

    except:

        return None


for district in districts:

    for search_type in search_types:

        try:

            query = (
                f"{search_type} "
                f"in {district} Maharashtra"
            )

            print(f"\nSearching: {query}")

            search_box = get_search_box()

            if not search_box:

                print("Search Box Not Found")

                continue

            ActionChains(driver).move_to_element(
                search_box
            ).click().perform()

            time.sleep(1)

            search_box.send_keys(
                Keys.CONTROL + "a"
            )

            time.sleep(1)

            search_box.send_keys(Keys.DELETE)

            time.sleep(1)

    
            for char in query:

                search_box.send_keys(char)

                time.sleep(0.03)

            search_box.send_keys(Keys.ENTER)

            print("Search Submitted")

            time.sleep(8)


            try:

                scrollable_div = driver.find_element(
                    By.XPATH,
                    '//div[@role="feed"]'
                )

                previous_count = 0

                stagnant = 0

                for i in range(100):

                    driver.execute_script(
                        """
                        arguments[0].scrollTop =
                        arguments[0].scrollHeight
                        """,
                        scrollable_div
                    )

                    time.sleep(4)

                    listings = driver.find_elements(
                        By.XPATH,
                        '//a[contains(@href,"/maps/place/")]'
                    )

                    current_count = len(listings)

                    print(
                        f"{district} | "
                        f"{search_type} | "
                        f"Scroll {i+1} -> "
                        f"{current_count}"
                    )

                    if current_count == previous_count:

                        stagnant += 1

                    else:

                        stagnant = 0

                    if stagnant >= 4:

                        break

                    previous_count = current_count

            except Exception as e:

                print(f"Scrolling Error: {e}")


            listings = driver.find_elements(
                By.XPATH,
                '//a[contains(@href,"/maps/place/")]'
            )

            links = []

            for listing in listings:

                try:

                    link = listing.get_attribute("href")

                    if (
                        link
                        and link not in visited_links
                    ):

                        links.append(link)

                        visited_links.add(link)

                except:
                    pass

            print(f"Collected {len(links)} links")


            for index, link in enumerate(links):

                try:

                    print(
                        f"{district} | "
                        f"{index+1}/{len(links)}"
                    )

                    driver.get(link)

                    time.sleep(
                        random.uniform(2, 4)
                    )

                    data = extract_school_data()

                    if data:

                        data["District"] = district

                        data["Search Type"] = search_type

                        all_data.append(data)

                        print(data["Hospital Name"])


                    if len(all_data) % 100 == 0:

                        backup_df = pd.DataFrame(
                            all_data
                        )

                        backup_df.drop_duplicates(
                            subset=[
                                "Hospital Name",
                                "Google Maps URL"
                            ],
                            inplace=True
                        )

                        backup_filename = (
                            "maharashtra_backup.csv"
                        )

                        backup_df.to_csv(
                            backup_filename,
                            index=False
                        )

                        print("Backup Saved")

                except Exception as e:

                    print(
                        f"School Error: {e}"
                    )

        except Exception as e:

            print(
                f"District Error: {e}"
            )


new_df = pd.DataFrame(all_data)

new_df.drop_duplicates(

    subset=[
        "Hospital Name",
        "Google Maps URL"
    ],

    inplace=True
)


old_file = (
    f"maharashtra_hospitals.csv"
)

try:
    old_df = pd.read_csv(old_file)

    final_df = pd.concat(
        [old_df, new_df],
        ignore_index=True
    )

    final_df.drop_duplicates(
        subset=[
            "Hospital Name",
            "Google Maps URL"
        ],
        inplace=True
    )
except:
    final_df = new_df
            

final_df.to_csv(
    old_file,
    index=False
)

print("\nExtraction Completed")

print(
    f"Total Hospitals Extracted: {len(final_df)}"
)

print(f"\nSaved File: {filename}")

driver.quit()
# Out:
# Opening Google Maps...
# Google Maps Loaded
#
# Searching: hospitals in Osmanabad Maharashtra
# Search Submitted
# Osmanabad | hospitals | Scroll 1 -> 14
# Osmanabad | hospitals | Scroll 2 -> 20
# Osmanabad | hospitals | Scroll 3 -> 27
# Osmanabad | hospitals | Scroll 4 -> 34
# Osmanabad | hospitals | Scroll 5 -> 40
# Osmanabad | hospitals | Scroll 6 -> 42
# Osmanabad | hospitals | Scroll 7 -> 42
# Osmanabad | hospitals | Scroll 8 -> 42
# Osmanabad | hospitals | Scroll 9 -> 42
# Osmanabad | hospitals | Scroll 10 -> 42
# Collected 42 links
# Osmanabad | 1/42
# District Women Hospital Osmanabad
# Osmanabad | 2/42
# Kranti Multi-speciality Hospital & ICU(Dr.AJINKYA WADGANE)....VERY SOON NABH
# Osmanabad | 3/42
# Navodaya Multispeciality Hospital
# Osmanabad | 4/42
# Noble Superspeciality Hospital
# Osmanabad | 5/42
# District Civil Hospital Osmanabad
# Osmanabad | 6/42
# Rural Hospital, Palghar
# Palghar | 8/38
# Dhada Hospital
# Palghar | 9/38
# Naniwadekar Hospital
# Palghar | 10/38
# SHARDA HOSPITAL
# Palghar | 11/38
# New Life care hospital
# Palghar | 12/38
# Kanta Hospital & Sonography Centre
# Palghar | 13/38
# Adhikari Lifeline Hospital Betegaon
# Palghar | 14/38
# Adhikari Lifeline Hospital Nagzari
# Palghar | 15/38
# Varad Multispeciality Hospital-Boisar
# Palghar | 16/38
# RELIEEF HOSPITALS - (Private Hospital & Best Hospital In Boisar)
# Palghar | 17/38
# Primary Health Center Kelva Mahim
# Palghar | 18/38
# Metro Phoenix Multyspeciality Hospital
# Palghar | 19/38
# Health Unit (Temporary)
# Palghar | 20/38
# Thunga Hospital
# Palghar | 21/38
# Sanjivani Hospital
# Palghar | 22/38
# Chinmaya Hospital
# Palghar | 23/38
# Anand Hospital - Orthopaedics, and Obstetrics & Gynaecology | Best Hospital in Boisar
# Palghar | 24/38
# Rural Hospital, Manor
# Palghar | 25/38
# varad hospital and critical care center
# Palghar | 26/38
# Sushrusha Hospital & Medical
# Palghar | 27/38
# Vikas Hospital
# Palghar | 28/38
# Alhad Hospital
# Palghar | 29/38
# Star Hospital
# Palghar | 30/38
# TIMA Hospital
# Palghar | 31/38
# WestCoast Multispeciality Hospital And Diagnostic Centre
# Palghar | 32/38
# Rural Hospital, Wada
# Palghar | 33/38
# Chaitanya Hospital | Dr. Amit Samant | Dr. Anamika Samant | virar
# Palghar | 34/38
# Sub District Hospital Dahanu
# Palghar | 35/38
# Mahavir Hospital
# Palghar | 36/38
# K&K SUPERSPECIALITY HOSPITAL
# Palghar | 37/38
# Shree Balaji Hospital
# Palghar | 38/38
# Sanjari Clinic, Manor
#
# Searching: hospitals in Parbhani Maharashtra
# Search Submitted
# Parbhani | hospitals | Scroll 1 -> 14
# Parbhani | hospitals | Scroll 2 -> 20
# Parbhani | hospitals | Scroll 3 -> 27
# Parbhani | hospitals | Scroll 4 -> 34
# Parbhani | hospitals | Scroll 5 -> 40
# Parbhani | hospitals | Scroll 6 -> 47
# Parbhani | hospitals | Scroll 7 -> 54
# Parbhani | hospitals | Scroll 8 -> 60
# Parbhani | hospitals | Scroll 9 -> 67
# Parbhani | hospitals | Scroll 10 -> 68
# Parbhani | hospitals | Scroll 11 -> 68
# Parbhani | hospitals | Scroll 12 -> 68
# Parbhani | hospitals | Scroll 13 -> 68
# Parbhani | hospitals | Scroll 14 -> 68
# Collected 68 links
# Parbhani | 1/68
# Devgiri Superspeciality Hospital
# Parbhani | 2/68
# District Hospital, Parbhani
# Parbhani | 3/68
# Lifeline Multispeciality Hospital & ICU
# Parbhani | 4/68
# Sangle Hospital, Parbhani
# Parbhani | 5/68
# Vighnaharta Multispecialty Hospital - Best Multispeciality Hospital In Parbhani | Best chest Hospital In Parbhani
# Parbhani | 6/68
# RIMS Multisuperspeciality Hospital parbhani
# Parbhani | 7/68
# Pandurang Superspeciality Hospital
# Parbhani | 8/68
# Parbhani ICU & Trauma Care Centre
# Parbhani | 9/68
# Sahyadri Hospital Parbhani
# Parbhani | 10/68
# Spandan Hospital ,
# Parbhani | 11/68
# Parbhani ICU And Trauma Care - Best ICU and Trauma Centre In Parbhani | Superspeciality Hopital | Best Specialist Doctor
# Parbhani | 12/68
# Ashok Hospital
# Parbhani | 13/68
# Surwase Hospital Parbhani
# Parbhani | 14/68
# Dr. Katneshwarkar Hospital
# Parbhani | 15/68
# Morya Hospital
# Parbhani | 16/68
# Kausar Hospital
# Parbhani | 17/68
# Yashwant Multi-speciality Hospital
# Parbhani | 18/68
# Deshmukh Hospital (Multi Specialty Hospital & Maternity Home)
# Parbhani | 19/68
# Shivneri Super Speciality and Surya ICU Hospital, Parbhani
# Parbhani | 20/68
# Civil Hospital
# Backup Saved
# Parbhani | 21/68
# Chandak Hospital- Laparoscopic Surgeon | General Surgeon | Gynecologist | Infertility Specialist in Parbhani
# Parbhani | 22/68
# Navjeevan Hospital
# Parbhani | 23/68
# Deshpande Hospital
# Parbhani | 24/68
# Chirayu Hospital
# Parbhani | 25/68
# Aboli Hospital
# Parbhani | 26/68
# PATIL HOSPITAL
# Parbhani | 27/68
# Tamboli Hospital
# Parbhani | 28/68
# Godawari Hospital
# Parbhani | 29/68
# Navandar Hospital
# Parbhani | 30/68
# Manwat Multi-Speciality Hospital
# Parbhani | 31/68
# Muskan Children's Hospital
# Parbhani | 32/68
# Akanksha Hospital,Parbhani.
# Parbhani | 33/68
# YAMUNA MULTI SPECIALITY HOSPITAL
# Parbhani | 34/68
# Ananya Hospital
# Parbhani | 35/68
# Kalani Hospital
# Parbhani | 36/68
# Sparsh Multispeciality Hospital
# Parbhani | 37/68
# Dr. Narwade Hospital
# Parbhani | 38/68
# Partani hospital
# Parbhani | 39/68
# SWASTHYA PILES HOSPITAL - Best Piles Doctor In Parbhani | Best Piles Laser Centre | Best Proctologist In Parbhani
# Parbhani | 40/68
# Swati Criticare Icu Hospital - Best Critical Care Center in Parbhani | Best ICU in Parbhani | Best Vertigo treatment
# Parbhani | 41/68
# More Multispecialty Hospital
# Parbhani | 42/68
# Rahat hospital
# Parbhani | 43/68
# Sahara Hospital
# Parbhani | 44/68
# Dhanorkar Hospital
# Parbhani | 45/68
# Vasundhara Hospital and IVF Centre
# Parbhani | 46/68
# Hayat Hospital
# Parbhani | 47/68
# Manashanti Hospital
# Parbhani | 48/68
# Pole Multispeciality Hospital
# Parbhani | 49/68
# Sabu Hospital Parbhani
# Parbhani | 50/68
# Surya I.C.U. Hospital
# Parbhani | 51/68
# Jethliya Hospital
# Parbhani | 52/68
# Shree Siddhivinayak Bal Rugnalaya & Critical Care Centre
# Parbhani | 53/68
# G-One Multispeciality Hospital
# Parbhani | 54/68
# Korde Hospital Shivaji Nagar
# Parbhani | 55/68
# AIMS HOSPITAL
# Parbhani | 56/68
# Bhavna Hospital
# Parbhani | 57/68
# Tejas Hospital
# Parbhani | 58/68
# Ankur Balrugnalay Parbhani
# Parbhani | 59/68
# New Kshirsagar Multispeciality hospital (ICU)
# Parbhani | 60/68
# Sahara Multi Speciality Hospital
# Parbhani | 61/68
# Parvati ambhore hospital - Best Trauma Centre in Parbhani | Best Neurologist in Parbhani | Best ICU Centre in Parbhani
# Parbhani | 62/68
# SANE HOSPITAL
# Parbhani | 63/68
# Tejas Hospital
# Parbhani | 64/68
# seva hospital
# Parbhani | 65/68
# Maternity Hospital
# Parbhani | 66/68
# Yashodeep ICU and Critical Care | Dr.Mahesh Balkishan Soni | Physician | Parbhani
# Parbhani | 67/68
# KADAM HOSPITAL (Burns Care, Wound Care, Trauma & Plastic Surgery Center)
# Parbhani | 68/68
# parbhani ICU
#
# Searching: hospitals in Pune Maharashtra
# Search Submitted
# Pune | hospitals | Scroll 1 -> 14
# Pune | hospitals | Scroll 2 -> 20
# Pune | hospitals | Scroll 3 -> 27
# Pune | hospitals | Scroll 4 -> 34
# Pune | hospitals | Scroll 5 -> 40
# Pune | hospitals | Scroll 6 -> 47
# Pune | hospitals | Scroll 7 -> 54
# Pune | hospitals | Scroll 8 -> 60
# Pune | hospitals | Scroll 9 -> 67
# Pune | hospitals | Scroll 10 -> 74
# Pune | hospitals | Scroll 11 -> 80
# Pune | hospitals | Scroll 12 -> 87
# Pune | hospitals | Scroll 13 -> 94
# Pune | hospitals | Scroll 14 -> 100
# Pune | hospitals | Scroll 15 -> 107
# Pune | hospitals | Scroll 16 -> 114
# Pune | hospitals | Scroll 17 -> 120
# Pune | hospitals | Scroll 18 -> 120
# Pune | hospitals | Scroll 19 -> 120
# Pune | hospitals | Scroll 20 -> 120
# Pune | hospitals | Scroll 21 -> 120
# Collected 120 links
# Pune | 1/120
# Jupiter Hospital
# Pune | 2/120
# Jehangir Hospital
# Pune | 3/120
# Sahyadri Super Speciality Hospital, Deccan Gymkhana, Pune
# Pune | 4/120
# Manipal Hospital, Kharadi - Pune
# Pune | 5/120
# Inamdar Multispeciality Hospital
# Pune | 6/120
# Apollo Spectra Hospitals - Pune
# Pune | 7/120
# MJM Hospital
# Pune | 8/120
# Noble Hospitals & Research Centre
# Pune | 9/120
# Ranka Hospital - Multispecialty | Best Orthopedic Hospital |24x7 Emergency | Trauma Care |Urology Hospital in Swargate, Pune
# Pune | 10/120
# WEST VALLEY MULTISPECIALITY HOSPITAL PVT LTD - Hospital in Sangamvadi Pune
# Pune | 11/120
# Sahyadri Super Speciality Hospital Hadapsar
# Pune | 12/120
# Orchid Speciality Hospital
# Pune | 13/120
# Manipal Hospitals Baner
# Pune | 14/120
# Sahyadri Super Speciality Hospital Nagar Road
# Pune | 15/120
# Atharv Hospital - Piles, Fissure, Fistula Hospital in Pune, Maharashtra | Piles Surgery
# Pune | 16/120
# Deenanath Mangeshkar Hospital and Research Center
# Pune | 17/120
# Poona Hospital And Research Centre
# Pune | 18/120
# Phoenix Hospital
# Pune | 19/120
# Aadhar icu and multispeciality hospital satara
# Satara | 13/32
# Yashwant Hospital
# Satara | 14/32
# Ajinkyatara Hospital
# Satara | 15/32
# Yashashree Hospital
# Satara | 16/32
# Morya Hospital & Research Center, Satara
# Satara | 17/32
# Samarth Hospital Private Limited
# Satara | 18/32
# Shri Mangalmurti Clinic
# Satara | 19/32
# Civil hospital Satara
# Backup Saved
# Satara | 20/32
# Nandadeep Hospital
# Satara | 21/32
# Pratiba Hospital And Heart Care Center
# Satara | 22/32
# Dhanvantari Hospital
# Satara | 23/32
# Geetanjali Multispeciality Hospital Wai | Top General & Laparoscopic Surgeon in Satara District
# Satara | 24/32
# Onco-Life Cancer Centre – Shendre Satara
# Satara | 25/32
# Gorad Hospital & I. C. U
# Satara | 26/32
# Sadhana Hospital
# Satara | 27/32
# TOTAL FAMILY HEALTH CARE CENTRE SATARA
# Satara | 28/32
# Dr. Aishwarya More
# Satara | 29/32
# Vital Health Clinic
# Satara | 30/32
# Sahyadri Super Speciality Hospital Karad
# Satara | 31/32
# Doltade Hospital
# Satara | 32/32
# Pratapsinha Hospital
#
# Searching: hospitals in Sindhudurg Maharashtra
# Search Submitted
# Sindhudurg | hospitals | Scroll 1 -> 14
# Sindhudurg | hospitals | Scroll 2 -> 20
# Sindhudurg | hospitals | Scroll 3 -> 27
# Sindhudurg | hospitals | Scroll 4 -> 28
# Sindhudurg | hospitals | Scroll 5 -> 28
# Sindhudurg | hospitals | Scroll 6 -> 28
# Sindhudurg | hospitals | Scroll 7 -> 28
# Sindhudurg | hospitals | Scroll 8 -> 28
# Collected 28 links
# Sindhudurg | 1/28
# District Hospital, Sindhudurg
# Sindhudurg | 2/28
# SSPM Medical College& Lifetime Hospital, Sindhudurg
# Sindhudurg | 3/28
# SINDHUCARE HOSPITAL
# Sindhudurg | 4/28
# Dr. Birmole's Gurukrupa Hospital
# Sindhudurg | 5/28
# Suyash hospital
# Sindhudurg | 6/28
# Navare Hospital
# Sindhudurg | 7/28
# Nagvekar Hospital
# Sindhudurg | 8/28
# Rural Hospital, Kudal
# Sindhudurg | 9/28
# RANE HOSPITAL AND MEDICAL RESEARCH CENTRE
# Sindhudurg | 10/28
# Aabu Tayshete Memorial Hospital Kankavli & S.S STONE
# Sindhudurg | 11/28
# Sarita Hospital
# Sindhudurg | 12/28
# Kolte hospital
# Sindhudurg | 13/28
# Sub District Hospital
# Sindhudurg | 14/28
# Government Hospital
# Sindhudurg | 15/28
# Shree Ganesh Hospital
# Sindhudurg | 16/28
# Konkan Cancer and Multispeciality Hospital
# Sindhudurg | 17/28
# Getwell Hospital
# Sindhudurg | 18/28
# Sub District Hospital, Kankavali
# Sindhudurg | 19/28
# Sumati Hospital Dr Yogesh Navangul
# Sindhudurg | 20/28
# Sub District Hospital, Sawantwadi
# Sindhudurg | 21/28
# Aanadi Hospital
# Sindhudurg | 22/28
# Redkar Hospital Research Center
# Sindhudurg | 23/28
# Marathe Hospital
# Kamal Medicare Cancer & Super-Speciality HOSPITAL | Dr. Yogesh Bung - Best Cancer Doctor in Solapur.
# Solapur | 37/47
# Dhanraj Girji Charitable Trust Hospital
# Solapur | 38/47
# S S Baldawa Neurosciences & Women's care Hospital
# Solapur | 39/47
# Ambika Hospital
# Solapur | 40/47
# ✅Valvekar Eye Hospital - Best Eye Hospital | Eye Care Center | Eye Specialist | Eye Doctor
# Solapur | 41/47
# Raghoji ENT & Maternity Hospital
# Solapur | 42/47
# Ashwini Rural Medical College, Hospital & Research Centre, Kumbhari Tal South Solapur District Solapur
# Solapur | 43/47
# Suyog Netralaya
# Solapur | 44/47
# Dr. Valsangkar Hospital - SP INSTITUTE OF NEUROSCIENCES | Best Cardiologist in Solapur | Heart Specialist in solapur
# Solapur | 45/47
# Matoshri Nursing Home
# Solapur | 46/47
# Suratkal Nursing Home
# Solapur | 47/47
# District Hospital Solapur
#
# Searching: hospitals in Thane Maharashtra
# Search Submitted
# Thane | hospitals | Scroll 1 -> 14
# Thane | hospitals | Scroll 2 -> 21
# Thane | hospitals | Scroll 3 -> 28
# Thane | hospitals | Scroll 4 -> 35
# Thane | hospitals | Scroll 5 -> 41
# Thane | hospitals | Scroll 6 -> 48
# Thane | hospitals | Scroll 7 -> 55
# Thane | hospitals | Scroll 8 -> 61
# Thane | hospitals | Scroll 9 -> 68
# Thane | hospitals | Scroll 10 -> 75
# Thane | hospitals | Scroll 11 -> 81
# Thane | hospitals | Scroll 12 -> 88
# Thane | hospitals | Scroll 13 -> 95
# Thane | hospitals | Scroll 14 -> 101
# Thane | hospitals | Scroll 15 -> 102
# Thane | hospitals | Scroll 16 -> 102
# Thane | hospitals | Scroll 17 -> 102
# Thane | hospitals | Scroll 18 -> 102
# Thane | hospitals | Scroll 19 -> 102
# Collected 102 links
# Thane | 1/102
# Jupiter Hospital, Thane
# Thane | 2/102
# Horizon Prime Hospital in Thane
# Thane | 3/102
# Tieten Medicity Hospital Thane | Best Multi-Speciality Hospital in Thane
# Thane | 4/102
# Tieten Medicity Hospital - Best Hospital in Thane - Expert Cardiac, Oncology, ENT & Ortho Care
# Thane | 5/102
# Siddhivinayak Hospital
# Thane | 6/102
# THANE NOBLE HOSPITAL : Multispeciality Hospital, Super Speciality Hospital, Criticare Hospital in Thane, Ghodbunder Road
# Thane | 7/102
# Aayush Multispecialty Hospital - Laser Laparoscopic Surgery, Gynecologist, Appendix, Hernia, Gallbladder, Hospital in Thane
# Thane | 8/102
# HIGHWAY HOSPITAL
# Thane | 9/102
# Dr. Bhanushali Hospital
# Thane | 10/102
# Vasant Vihar Hospital
# Thane | 11/102
# THC -THANEHEALTHCARE HOSPITAL
# Thane | 12/102
# Lakecity Hospital - Best Hospital in Thane - Multispeciality Hospital & ICU
# Backup Saved
# Thane | 13/102
# Kaushalya Medical Foundation Trust Hospital
# Thane | 14/102
# Bethany Hospital
# Thane | 15/102
# Metropol
# Thane | 16/102
# GHC Hospitals
# Thane | 70/102
# Chandraganga Spandan Hospital
# Thane | 71/102
# AJWA GENERAL HOSPITAL
# Thane | 72/102
# TejVedaant Hospitals
# Thane | 73/102
# ShivShree
# Thane | 74/102
# Apex Hospital
# Thane | 75/102
# Saarthi Hospital
# Thane | 76/102
# Dr. Sujata Rathod – Gynecologist in Hiranandani Estate
# Thane | 77/102
# Hambarde Hospital
# Thane | 78/102
# SRV Hospitals - Goregaon
# Thane | 79/102
# Lotus Multispeciality Hospital Borivali W
# Thane | 80/102
# Central Hospital, Ulhasnagar
# Thane | 81/102
# ASG Eye Hospital - Dombivli
# Thane | 82/102
# Orbit Super Speciality Hospital - Cashless Hospital in Mira Road East l Neurology l Brain & Spinal cord injury Mira Road East
# Thane | 83/102
# Sai Kripa Hospital & ICU
# Thane | 84/102
# The Peoples Multispeciality Hospital
# Thane | 85/102
# Indira Gandhi Municipal Hospital
# Thane | 86/102
# Prime Hospital Bhiwandi
# Thane | 87/102
# Life Care Hospital
# Thane | 88/102
# Lifeline Medicare Hospitals
# Thane | 89/102
# Phoenix Hospitals Pvt. Ltd.
# Thane | 90/102
# Divine Multispeciality Hospital
# Thane | 91/102
# Gavali Hospital and parag polyclinic
# Thane | 92/102
# Indira Gandhi Memorial Hospital
# Thane | 93/102
# MGM New Bombay Hospital, Vashi
# Thane | 94/102
# Shree Krishnakripa Hospital
# Thane | 95/102
# GLOBAL HOSPITAL
# Thane | 96/102
# Swatantryaveer V.D.Sawarkar BMC Hospital - Veer Savarkar Hospital
# Thane | 97/102
# Sanjivani Health Care
# Thane | 98/102
# Kalasiddhi Anorectal Hospital
# Thane | 99/102
# Shah Lifeline Hospital in Malad
# Thane | 100/102
# MM Hospital - Hospital In IC COLONY, Borivali (W)
# Thane | 101/102
# Family Physician
# Thane | 102/102
# TMC Hospital
#
# Searching: hospitals in Wardha Maharashtra
# Search Submitted
# Wardha | hospitals | Scroll 1 -> 14
# Wardha | hospitals | Scroll 2 -> 20
# Wardha | hospitals | Scroll 3 -> 27
# Wardha | hospitals | Scroll 4 -> 34
# Wardha | hospitals | Scroll 5 -> 40
# Wardha | hospitals | Scroll 6 -> 40
# Wardha | hospitals | Scroll 7 -> 40
# Wardha | hospitals | Scroll 8 -> 40
# Wardha | hospitals | Scroll 9 -> 40
# Collected 40 links
# Wardha | 1/40
# Patil Superspeciality Hospital
# Wardha | 2/40
# Acharya Vinoba Bhave Rural Hospital
# Wardha | 3/40
# District General Hospital, Wardha
# Wardha | 4/40
# Aaradhya Hospital and Laparoscopy Centre - an ISO Certified Hospital
# Wardha | 5/40
# Golhar Hospital & Diagnostic Centre Wardha
# Wardha | 6/40
# Aas Hospital & Pathology
# Wardha | 7/40
# DR.TOTE. SHREE MULTISPECIALITY HOSPITAL.
# Wardha | 8/40
# R.R Healthcare
# Wardha | 9/40
# Shvaas Multispeciality Hospital
# Wardha | 10/40
# Sushrut Hospital
# Backup Saved
# Wardha | 11/40
# Sanjeevan Multispecialty Hospital & Research Institute
# Yavatmal | 3/43
# New cotton city hospital - Best Surgical Hospital In Yavatmal | Best Child Care Hospital | Best Gynecologist Doctors
# Yavatmal | 4/43
# Shantineel Surgery Hospital | Best Surgical Hospital & Medical Treatment Centre in Yavatmal | Dr. Ajonish Kamble
# Yavatmal | 5/43
# Rathod Hospital
# Yavatmal | 6/43
# Aarogyam Speciality Hospital
# Yavatmal | 7/43
# Phadke Hospital
# Yavatmal | 8/43
# Yavatmal Piles Hospital
# Yavatmal | 9/43
# Chavan hospital
# Yavatmal | 10/43
# Muktai Gastro & Liver Care Hospital- Best Gastrologists In Yavatmal | Multispeciality Hospital In Yavatmal
# Yavatmal | 11/43
# Dr. Yelnare Orthopedic Hospital
# Yavatmal | 12/43
# MAHALAXMI MULTISPECIALITY HOSPITAL
# Yavatmal | 13/43
# Vinayaka Multispeciality Hospital
# Yavatmal | 14/43
# MANE HOSPITAL
# Yavatmal | 15/43
# government Hospital Yavatmal
# Yavatmal | 16/43
# SAISHRADHA MULTISPECIALITY HOSPITAL AND RESEARCH INSTITUTE
# Yavatmal | 17/43
# Shri Datta Hospital and Research Center
# Yavatmal | 18/43
# Sukhkarta Hospital
# Yavatmal | 19/43
# Shraddha suman Hospital
# Yavatmal | 20/43
# CHAUDHARI HOSPITAL
# Yavatmal | 21/43
# Priti Maternity and Surgical Hospital - Best Maternity Hospital In Yavatmal | Best Sonography Center
# Yavatmal | 22/43
# Shah Hospital
# Yavatmal | 23/43
# Tawde Hospital
# Yavatmal | 24/43
# Ranade Hospital and Ashwini Nursing home
# Backup Saved
# Yavatmal | 25/43
# Sewa Hospital
# Yavatmal | 26/43
# Dhawane Hospital & Critical Care Center
# Yavatmal | 27/43
# Pote Hospital
# Yavatmal | 28/43
# Kasare Hospital | Orthopedic, Joint & Knee Replacement, Dental Care | Yavatmal
# Yavatmal | 29/43
# First step hospital
# Yavatmal | 30/43
# Loya Hospital
# Yavatmal | 31/43
# Kulkarni Hospital For Children
# Yavatmal | 32/43
# Smith Hospital
# Yavatmal | 33/43
# Padmavati Hospital( Dr Dipak Agrawal)
# Yavatmal | 34/43
# Shri Vasantrao Naik Govt. Medical Hospital Yavatmal
# Yavatmal | 35/43
# Ujwane Hospital
# Yavatmal | 36/43
# Keshwani Hospital
# Yavatmal | 37/43
# Dr. Vedant Lakhe Urologist
# Yavatmal | 38/43
# Drushti Eye Care
# Yavatmal | 39/43
# Baraskar Ayurvedic Clinic
# Yavatmal | 40/43
# Vibha’s hospital
# Yavatmal | 41/43
# H.I.N Hospital
# Yavatmal | 42/43
# Datta Netralaya
# Yavatmal | 43/43
# Surgical
#
# Extraction Completed
# Total Hospitals Extracted: 2128
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 467
#     461 print("\nExtraction Completed")
#     463 print(
#     464     f"Total Hospitals Extracted: {len(final_df)}"
#     465 )
# --> 467 print(f"\nSaved File: {filename}")
#     469 driver.quit()
#
# NameError: name 'filename' is not defined
