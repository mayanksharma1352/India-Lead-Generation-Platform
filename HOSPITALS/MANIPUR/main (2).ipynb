# %%
import time
import random
import pandas as pd

from datetime import datetime

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.service import Service

from webdriver_manager.chrome import ChromeDriverManager

districts = [

    "Bishnupur",
    "Chandel",
    "Churachandpur",
    "Imphal East",
    "Imphal West",
    "Jiribam",
    "Kakching",
    "Kamjong",
    "Kangpokpi",
    "Noney",
    "Pherzawl",
    "Senapati",
    "Tamenglong",
    "Tengnoupal",
    "Thoubal",
    "Ukhrul"

]

search_types = [
    "hospitals"
]



options = webdriver.ChromeOptions()

options.add_argument("--start-maximized")

options.add_argument(
    "--disable-blink-features=AutomationControlled"
)

options.add_argument("--disable-notifications")


driver = webdriver.Chrome(

    service=Service(
        ChromeDriverManager().install()
    ),

    options=options
)


driver.get("https://www.google.com/maps")

print("Opening Google Maps...")

time.sleep(15)

print("Google Maps Loaded")


all_data = []

visited_links = set()



def get_search_box():

    selectors = [

        '//input[@id="searchboxinput"]',
        '//input[contains(@placeholder,"Search")]',
        '//input[contains(@aria-label,"Search")]',
        '//input'

    ]

    for selector in selectors:

        try:

            box = driver.find_element(
                By.XPATH,
                selector
            )

            return box

        except:
            pass

    return None



def extract_school_data():

    try:


        try:
            name = driver.find_element(
                By.TAG_NAME,
                "h1"
            ).text
        except:
            name = ""


        try:
            address = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"address")]'
            ).text
        except:
            address = ""


        try:
            phone = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"phone")]'
            ).text
        except:
            phone = ""


        try:
            website = driver.find_element(
                By.XPATH,
                '//a[contains(@data-item-id,"authority")]'
            ).get_attribute("href")
        except:
            website = ""

        try:
            rating = driver.find_element(
                By.XPATH,
                '//div[@role="img"]'
            ).get_attribute("aria-label")
        except:
            rating = ""

        return {

            "Hospital Name": name,
            "Address": address,
            "Phone": phone,
            "Website": website,
            "Rating": rating,
            "Google Maps URL": driver.current_url

        }

    except:

        return None


for district in districts:

    for search_type in search_types:

        try:

            query = (
                f"{search_type} "
                f"in {district} Manipur"
            )

            print(f"\nSearching: {query}")

 
            search_box = get_search_box()

            if not search_box:

                print("Search Box Not Found")

                continue

            ActionChains(driver).move_to_element(
                search_box
            ).click().perform()

            time.sleep(1)

            search_box.send_keys(
                Keys.CONTROL + "a"
            )

            time.sleep(1)

            search_box.send_keys(Keys.DELETE)

            time.sleep(1)


            for char in query:

                search_box.send_keys(char)

                time.sleep(0.03)

            search_box.send_keys(Keys.ENTER)

            print("Search Submitted")

            time.sleep(8)


            try:

                scrollable_div = driver.find_element(
                    By.XPATH,
                    '//div[@role="feed"]'
                )

                previous_count = 0

                stagnant = 0

                for i in range(100):

                    driver.execute_script(
                        """
                        arguments[0].scrollTop =
                        arguments[0].scrollHeight
                        """,
                        scrollable_div
                    )

       
                    time.sleep(4)

                    listings = driver.find_elements(
                        By.XPATH,
                        '//a[contains(@href,"/maps/place/")]'
                    )

                    current_count = len(listings)

                    print(
                        f"{district} | "
                        f"{search_type} | "
                        f"Scroll {i+1} -> "
                        f"{current_count}"
                    )

                    if current_count == previous_count:

                        stagnant += 1

                    else:

                        stagnant = 0

                    if stagnant >= 4:

                        break

                    previous_count = current_count

            except Exception as e:

                print(f"Scrolling Error: {e}")


            listings = driver.find_elements(
                By.XPATH,
                '//a[contains(@href,"/maps/place/")]'
            )

            links = []

            for listing in listings:

                try:

                    link = listing.get_attribute("href")

                    if (
                        link
                        and link not in visited_links
                    ):

                        links.append(link)

                        visited_links.add(link)

                except:
                    pass

            print(f"Collected {len(links)} links")


            for index, link in enumerate(links):

                try:

                    print(
                        f"{district} | "
                        f"{index+1}/{len(links)}"
                    )

                    driver.get(link)

                    time.sleep(
                        random.uniform(2, 4)
                    )

                    data = extract_school_data()

                    if data:

                        data["District"] = district

                        data["Search Type"] = search_type

                        all_data.append(data)

                        print(data["Hospital Name"])


                    if len(all_data) % 100 == 0:

                        backup_df = pd.DataFrame(
                            all_data
                        )

                        backup_df.drop_duplicates(
                            subset=[
                                "Hospital Name",
                                "Google Maps URL"
                            ],
                            inplace=True
                        )

                        backup_filename = (
                            "manipur_backup.csv"
                        )

                        backup_df.to_csv(
                            backup_filename,
                            index=False
                        )

                        print("Backup Saved")

                except Exception as e:

                    print(
                        f"School Error: {e}"
                    )

        except Exception as e:

            print(
                f"District Error: {e}"
            )



df = pd.DataFrame(all_data)

df.drop_duplicates(

    subset=[
        "Hospital Name",
        "Google Maps URL"
    ],

    inplace=True
)



filename = (
    "manipur_hospitals.csv"
)

df.to_csv(
    filename,
    index=False
)

print("\nExtraction Completed")

print(
    f"Total Schools Extracted: {len(df)}"
)

print(f"\nSaved File: {filename}")

driver.quit()
# Out:
# Opening Google Maps...
# Google Maps Loaded
#
# Searching: hospitals in Bishnupur Manipur
# Search Submitted
# Scrolling Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@role="feed"]"}
#   (Session info: chrome=148.0.7778.167); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 	chromedriver!GetHandleVerifier [0x10d7123+10a23]
# 	chromedriver!GetHandleVerifier [0x10d7254+10b54]
# 	chromedriver!(No symbol) [0xef1e90]
# 	chromedriver!(No symbol) [0xf3b28a]
# 	chromedriver!(No symbol) [0xf3b52b]
# 	chromedriver!(No symbol) [0xf7d062]
# 	chromedriver!(No symbol) [0xf5d7d4]
# 	chromedriver!(No symbol) [0xf7a936]
# 	chromedriver!(No symbol) [0xf5d526]
# 	chromedriver!(No symbol) [0xf308f9]
# 	chromedriver!(No symbol) [0xf316b4]
# 	chromedriver!GetHandleVerifier [0x1371ac4+2ab3c4]
# 	chromedriver!GetHandleVerifier [0x136d0ed+2a69ed]
# 	chromedriver!GetHandleVerifier [0x138e4f5+2c7df5]
# 	chromedriver!GetHandleVerifier [0x10f1128+2aa28]
# 	chromedriver!GetHandleVerifier [0x10f8bbd+324bd]
# 	chromedriver!GetHandleVerifier [0x10dfb28+19428]
# 	chromedriver!GetHandleVerifier [0x10dfcd5+195d5]
# 	chromedriver!GetHandleVerifier [0x10c91cf+2acf]
# 	KERNEL32!BaseThreadInitThunk [0x75defcc9+19]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x779982ae+11e]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x7799827e+ee]
#
# Collected 0 links
#
# Searching: hospitals in Chandel Manipur
# Search Submitted
# Scrolling Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@role="feed"]"}
#   (Session info: chrome=148.0.7778.167); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 	chromedriver!GetHandleVerifier [0x10d7123+10a23]
# 	chromedriver!GetHandleVerifier [0x10d7254+10b54]
# 	chromedriver!(No symbol) [0xef1e90]
# 	chromedriver!(No symbol) [0xf3b28a]
# 	chromedriver!(No symbol) [0xf3b52b]
# 	chromedriver!(No symbol) [0xf7d062]
# 	chromedriver!(No symbol) [0xf5d7d4]
# 	chromedriver!(No symbol) [0xf7a936]
# 	chromedriver!(No symbol) [0xf5d526]
# 	chromedriver!(No symbol) [0xf308f9]
# 	chromedriver!(No symbol) [0xf316b4]
# 	chromedriver!GetHandleVerifier [0x1371ac4+2ab3c4]
# 	chromedriver!GetHandleVerifier [0x136d0ed+2a69ed]
# 	chromedriver!GetHandleVerifier [0x138e4f5+2c7df5]
# 	chromedriver!GetHandleVerifier [0x10f1128+2aa28]
# 	chromedriver!GetHandleVerifier [0x10f8bbd+324bd]
# 	chromedriver!GetHandleVerifier [0x10dfb28+19428]
# 	chromedriver!GetHandleVerifier [0x10dfcd5+195d5]
# 	chromedriver!GetHandleVerifier [0x10c91cf+2acf]
# 	KERNEL32!BaseThreadInitThunk [0x75defcc9+19]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x779982ae+11e]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x7799827e+ee]
#
# Collected 0 links
#
# Searching: hospitals in Churachandpur Manipur
# Search Submitted
# Churachandpur | hospitals | Scroll 1 -> 11
# Churachandpur | hospitals | Scroll 2 -> 11
# Churachandpur | hospitals | Scroll 3 -> 11
# Churachandpur | hospitals | Scroll 4 -> 11
# Churachandpur | hospitals | Scroll 5 -> 11
# Collected 11 links
# Churachandpur | 1/11
# Churachandpur District Hospital
# Churachandpur | 2/11
# Samaritan Nursing Home
# Churachandpur | 3/11
# Ideal Nursing Home, Lamka
# Churachandpur | 4/11
# Nazaret Hospital, Churachandpur
# Churachandpur | 5/11
# Sielmat hospital
# Churachandpur | 6/11
# Nazareth Nursing Home, Ccpur
# Churachandpur | 7/11
# Lamka Nursing Home
# Churachandpur | 8/11
# District Hospital Cafeteria
# Churachandpur | 9/11
# People's Health Foundation
# Churachandpur | 10/11
# PHSC Pearsonmun
# Churachandpur | 11/11
# Ideal Health Foundation
#
# Searching: hospitals in Imphal East Manipur
# Search Submitted
# Imphal East | hospitals | Scroll 1 -> 16
# Imphal East | hospitals | Scroll 2 -> 20
# Imphal East | hospitals | Scroll 3 -> 28
# Imphal East | hospitals | Scroll 4 -> 33
# Imphal East | hospitals | Scroll 5 -> 33
# Imphal East | hospitals | Scroll 6 -> 33
# Imphal East | hospitals | Scroll 7 -> 33
# Imphal East | hospitals | Scroll 8 -> 33
# Collected 33 links
# Imphal East | 1/33
# Shija Hospitals and Research Institute (SHRI)
# Imphal East | 2/33
# Imphal Hospital & Research Centre
# Imphal East | 3/33
# Sky Hospital & Research Centre
# Imphal East | 4/33
# BABINA HOSPITAL
# Imphal East | 5/33
# ASIAN HOSPITAL AND RESEARCH INSTITUTE
# Imphal East | 6/33
# Public Hospital And Research Institute
# Imphal East | 7/33
# Catholic Medical Centre (CMC Hospital)
# Imphal East | 8/33
# Kripadashini Advanced Hospital & Research Institute (KAHRI)
# Imphal East | 9/33
# Hillside Charitable Hospital & Research Institute
# Imphal East | 10/33
# Raj Medicity
# Imphal East | 11/33
# City Hospital & Research Centre
# Imphal East | 12/33
# American Oncology Institute, Imphal, Manipur
# Imphal East | 13/33
# Rajmoni Hospital & Research Institute Pvt. Ltd.
# Imphal East | 14/33
# iGASTROCARE HOSPITAL
# Imphal East | 15/33
# AB Institute
# Imphal East | 16/33
# ILand Hospital and research Institute
# Imphal East | 17/33
# Langol View Hospital And Research Institute Pvt. Ltd
# Imphal East | 18/33
# Mother's Care Children Hospital & Research Centre
# Imphal East | 19/33
# Advanced hospital, new location
# Imphal East | 20/33
# Afi Multispeciality Hospital
# Imphal East | 21/33
# Chamber Hospital
# Imphal East | 22/33
# Advanced Speciality Hospital & Research Institute
# Imphal East | 23/33
# JNIMS Hospital OPD Block
# Imphal East | 24/33
# Wangkhei Eye Hospital
# Imphal East | 25/33
# SHARC (Suba Hospital & Assisted Reproductive Centre)
# Imphal East | 26/33
# IBOYAIMA HOSPITAL & RESEARCH CENTRE
# Imphal East | 27/33
# Yaima Eye Hospital
# Imphal East | 28/33
# Maipakpi Maternity and Child Hospital
# Imphal East | 29/33
# Institute of Liver & Digestive Sciences
# Imphal East | 30/33
# Shija Urban OPD
# Imphal East | 31/33
# Shija City Dental Hospital
# Imphal East | 32/33
# Mangal Life Care
# Imphal East | 33/33
# AdvancedHospitalImphal
#
# Searching: hospitals in Imphal West Manipur
# Search Submitted
# Imphal West | hospitals | Scroll 1 -> 16
# Imphal West | hospitals | Scroll 2 -> 20
# Imphal West | hospitals | Scroll 3 -> 28
# Imphal West | hospitals | Scroll 4 -> 30
# Imphal West | hospitals | Scroll 5 -> 30
# Imphal West | hospitals | Scroll 6 -> 30
# Imphal West | hospitals | Scroll 7 -> 30
# Imphal West | hospitals | Scroll 8 -> 30
# Collected 6 links
# Imphal West | 1/6
# TREVI HOSPITAL & RESEARCH INSTITUTE
# Imphal West | 2/6
# Regional Institute of Medical Sciences
# Imphal West | 3/6
# District Hospital, Imphal West
# Imphal West | 4/6
# Itd Nursing and Health Care Reseach Institute
# Imphal West | 5/6
# Community Health Centre (CHC), Wangoi
# Imphal West | 6/6
# Urban Primary Health Centre, Singjamei
#
# Searching: hospitals in Jiribam Manipur
# Search Submitted
# Jiribam | hospitals | Scroll 1 -> 2
# Jiribam | hospitals | Scroll 2 -> 2
# Jiribam | hospitals | Scroll 3 -> 2
# Jiribam | hospitals | Scroll 4 -> 2
# Jiribam | hospitals | Scroll 5 -> 2
# Collected 2 links
# Jiribam | 1/2
# Ningshingkhul District Hospital
# Jiribam | 2/2
# Jiribam Hospital Quarter
#
# Searching: hospitals in Kakching Manipur
# Search Submitted
# Kakching | hospitals | Scroll 1 -> 7
# Kakching | hospitals | Scroll 2 -> 7
# Kakching | hospitals | Scroll 3 -> 7
# Kakching | hospitals | Scroll 4 -> 7
# Kakching | hospitals | Scroll 5 -> 7
# Collected 7 links
# Kakching | 1/7
# Jivan Hospital
# Kakching | 2/7
# EMA Hospital
# Kakching | 3/7
# District Hospital
# Kakching | 4/7
# OST centre Chc kakching
# Kakching | 5/7
# Govt Hospital
# Kakching | 6/7
# Health and Wellness Centre UPHC Kakching
# Kakching | 7/7
# Kakching Eye Hospital
#
# Searching: hospitals in Kamjong Manipur
# Search Submitted
# Kamjong | hospitals | Scroll 1 -> 2
# Kamjong | hospitals | Scroll 2 -> 2
# Kamjong | hospitals | Scroll 3 -> 2
# Kamjong | hospitals | Scroll 4 -> 2
# Kamjong | hospitals | Scroll 5 -> 2
# Collected 2 links
# Kamjong | 1/2
# Community Health Center
# Kamjong | 2/2
# District Hospital
#
# Searching: hospitals in Kangpokpi Manipur
# Search Submitted
# Kangpokpi | hospitals | Scroll 1 -> 5
# Kangpokpi | hospitals | Scroll 2 -> 5
# Kangpokpi | hospitals | Scroll 3 -> 5
# Kangpokpi | hospitals | Scroll 4 -> 5
# Kangpokpi | hospitals | Scroll 5 -> 5
# Collected 4 links
# Kangpokpi | 1/4
# Kangpokpi Christian Hospital
# Kangpokpi | 2/4
# Kangpokpi Mission Hospital
# Kangpokpi | 3/4
# District Hospital Kangpokpi
# Kangpokpi | 4/4
# OPD Mission Hospital
#
# Searching: hospitals in Noney Manipur
# Search Submitted
# Noney | hospitals | Scroll 1 -> 3
# Noney | hospitals | Scroll 2 -> 3
# Noney | hospitals | Scroll 3 -> 3
# Noney | hospitals | Scroll 4 -> 3
# Noney | hospitals | Scroll 5 -> 3
# Collected 2 links
# Noney | 1/2
# Primary Health Centre
# Noney | 2/2
# Makaam Hospital and Research Institute
#
# Searching: hospitals in Pherzawl Manipur
# Search Submitted
# Pherzawl | hospitals | Scroll 1 -> 16
# Pherzawl | hospitals | Scroll 2 -> 20
# Pherzawl | hospitals | Scroll 3 -> 28
# Pherzawl | hospitals | Scroll 4 -> 30
# Pherzawl | hospitals | Scroll 5 -> 31
# Pherzawl | hospitals | Scroll 6 -> 31
# Pherzawl | hospitals | Scroll 7 -> 31
# Pherzawl | hospitals | Scroll 8 -> 31
# Pherzawl | hospitals | Scroll 9 -> 31
# Collected 14 links
# Pherzawl | 1/14
# AMINA HOSPITAL AND RESEARCH INSTITUTE
# Pherzawl | 2/14
# Primary Health Centre
# Pherzawl | 3/14
# PIIMA Health Care
# Pherzawl | 4/14
# Thoubal District Hospital, Khangabok
# Pherzawl | 5/14
# Noor Hospital and Research Institute
# Pherzawl | 6/14
# SUR Hospital, Khangabok
# Pherzawl | 7/14
# District Hospital, Bishnupur
# Pherzawl | 8/14
# District Hospital Chandel
# Pherzawl | 9/14
# Meehul Clinic
# Pherzawl | 10/14
# PHSC Thoubal Wangmataba
# Pherzawl | 11/14
# PHC Mekola
# Pherzawl | 12/14
# Rangini Hospital
# Pherzawl | 13/14
# Pherzawl DC Office Complex
# Pherzawl | 14/14
# P.H.C. Senvon
#
# Searching: hospitals in Senapati Manipur
# Search Submitted
# Senapati | hospitals | Scroll 1 -> 6
# Senapati | hospitals | Scroll 2 -> 6
# Senapati | hospitals | Scroll 3 -> 6
# Senapati | hospitals | Scroll 4 -> 6
# Senapati | hospitals | Scroll 5 -> 6
# Collected 6 links
# Senapati | 1/6
# District Hospital
# Senapati | 2/6
# GETWELL HEALTHCARE AND DIAGNOSTIC CENTRE
# Senapati | 3/6
# BLATH Clinic
# Senapati | 4/6
# OST CENTRE District hospital Senapati
# Senapati | 5/6
# Hospital Quarter
# Senapati | 6/6
# Old district hospital senapati
#
# Searching: hospitals in Tamenglong Manipur
# Search Submitted
# Tamenglong | hospitals | Scroll 1 -> 6
# Tamenglong | hospitals | Scroll 2 -> 6
# Tamenglong | hospitals | Scroll 3 -> 6
# Tamenglong | hospitals | Scroll 4 -> 6
# Tamenglong | hospitals | Scroll 5 -> 6
# Collected 6 links
# Tamenglong | 1/6
# Tamenglong District Hospital
# Tamenglong | 2/6
# Tamenglong District Hospital
# Tamenglong | 3/6
# Old District Hospital Tamenglong
# Tamenglong | 4/6
# Tamenglong district hospital DRP quarter
# Tamenglong | 5/6
# Atipu Hospital
# Tamenglong | 6/6
# Hospital
#
# Searching: hospitals in Tengnoupal Manipur
# Search Submitted
# Scrolling Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@role="feed"]"}
#   (Session info: chrome=148.0.7778.167); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 	chromedriver!GetHandleVerifier [0x10d7123+10a23]
# 	chromedriver!GetHandleVerifier [0x10d7254+10b54]
# 	chromedriver!(No symbol) [0xef1e90]
# 	chromedriver!(No symbol) [0xf3b28a]
# 	chromedriver!(No symbol) [0xf3b52b]
# 	chromedriver!(No symbol) [0xf7d062]
# 	chromedriver!(No symbol) [0xf5d7d4]
# 	chromedriver!(No symbol) [0xf7a936]
# 	chromedriver!(No symbol) [0xf5d526]
# 	chromedriver!(No symbol) [0xf308f9]
# 	chromedriver!(No symbol) [0xf316b4]
# 	chromedriver!GetHandleVerifier [0x1371ac4+2ab3c4]
# 	chromedriver!GetHandleVerifier [0x136d0ed+2a69ed]
# 	chromedriver!GetHandleVerifier [0x138e4f5+2c7df5]
# 	chromedriver!GetHandleVerifier [0x10f1128+2aa28]
# 	chromedriver!GetHandleVerifier [0x10f8bbd+324bd]
# 	chromedriver!GetHandleVerifier [0x10dfb28+19428]
# 	chromedriver!GetHandleVerifier [0x10dfcd5+195d5]
# 	chromedriver!GetHandleVerifier [0x10c91cf+2acf]
# 	KERNEL32!BaseThreadInitThunk [0x75defcc9+19]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x779982ae+11e]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x7799827e+ee]
#
# Collected 0 links
#
# Searching: hospitals in Thoubal Manipur
# Search Submitted
# Thoubal | hospitals | Scroll 1 -> 10
# Thoubal | hospitals | Scroll 2 -> 10
# Thoubal | hospitals | Scroll 3 -> 10
# Thoubal | hospitals | Scroll 4 -> 10
# Thoubal | hospitals | Scroll 5 -> 10
# Collected 5 links
# Thoubal | 1/5
# Dr Ranjan Clinic Thoubal
# Thoubal | 2/5
# Shija Clinic
# Thoubal | 3/5
# Shija Hospitals Info. Centre Thoubal
# Thoubal | 4/5
# CMO OFFICE THOUBAL
# Thoubal | 5/5
# PHSC_Thoubal Khunou
#
# Searching: hospitals in Ukhrul Manipur
# Search Submitted
# Ukhrul | hospitals | Scroll 1 -> 5
# Ukhrul | hospitals | Scroll 2 -> 5
# Ukhrul | hospitals | Scroll 3 -> 5
# Ukhrul | hospitals | Scroll 4 -> 5
# Ukhrul | hospitals | Scroll 5 -> 5
# Collected 5 links
# Ukhrul | 1/5
# DISTRICT HOSPITAL UKHRUL, HUNGPUNG
# Ukhrul | 2/5
# Old District Hospital
# Backup Saved
# Ukhrul | 3/5
# Leishiphung Christian Hospital
# Ukhrul | 4/5
# District Tuberculosis Centre (DTC), Ukhrul
# Ukhrul | 5/5
# CHSRC
#
# Extraction Completed
# Total Schools Extracted: 103
#
# Saved File: manipur_hospitals.csv
