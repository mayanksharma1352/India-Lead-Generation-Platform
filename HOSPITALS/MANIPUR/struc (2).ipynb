# %%
import pandas as pd

# %%
df = pd.read_csv("manipur_hospitals.csv")

# %%
df.shape
# Out:
# (103, 8)

# %%
df = df[
    df["Phone"].notna() &
    (df["Phone"].astype(str).str.strip() != "")
]
df.shape
# Out:
# (30, 8)

# %%
df = df[
    df["Hospital Name"].notna()
]

df = df[
    df["Hospital Name"].str.strip() != ""
]
df.shape
# Out:
# (30, 8)

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]", "", regex=True)  # remove symbols/icons
    .str.strip()
)

display(df[["Phone"]].head())
# Out:
#             Phone
# 11  0385 205 5584
# 12   070852 33242
# 13   084159 38207
# 14   069093 90666
# 16   087309 10355

# %%
df.to_csv(
    "manipur_hospitals_cleaned.csv",
    index=False
)
