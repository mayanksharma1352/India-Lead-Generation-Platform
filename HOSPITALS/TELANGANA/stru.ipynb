# %%
import pandas as pd

# %%
df = pd.read_csv("telangana_hospitals.csv")

# %%
df.shape
# Out:
# (1464, 8)

# %%
df = df[
    df["Phone"].notna() &
    (df["Phone"].astype(str).str.strip() != "")
]
df.shape
# Out:
# (1035, 8)

# %%
df = df[
    df["Hospital Name"].notna()
]

df = df[
    df["Hospital Name"].str.strip() != ""
]
df.shape
# Out:
# (1035, 8)

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]", "", regex=True)  # remove symbols/icons
    .str.strip()
)

display(df[["Phone"]].head())
# Out:
#           Phone
# 0  095052 53453
# 1  090636 46464
# 3  088899 88352
# 4  090638 05454
# 5  094943 27151

# %%
df.to_csv(
    "telangana_hospitals_cleaned.csv",
    index=False
)
