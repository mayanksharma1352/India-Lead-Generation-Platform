# %%
import pandas as pd

# %%
df = pd.read_csv("meghalaya_hospitals.csv")

# %%
df.shape
# Out:
# (126, 8)

# %%
df = df[
    df["Phone"].notna() & 
    (df["Phone"].astype(str).str.strip() != "")
    ]
df.shape
# Out:
# (36, 8)

# %%
df = df[
    df["Hospital Name"].notna()
    ]

df = df[
    df["Hospital Name"].str.strip() != ""
    ]
df.shape
# Out:
# (36, 8)

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]","",regex=True)
    .str.strip()
)

display(df[["Phone"]].head())
# Out:
#             Phone
# 3   03651 291 634
# 4   03651 223 855
# 10   093627 62938
# 15  0364 253 8045
# 17  0364 224 2198

# %%
df.to_csv(
    "meghalaya_hospitals_cleaned.csv",
    index=False
)
