# %%
import time
import random
import pandas as pd

from datetime import datetime

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.service import Service

from webdriver_manager.chrome import ChromeDriverManager


districts = [
    "East Garo Hills",
    "East Jaintia Hills",
    "East Khasi Hills",
    "Eastern West Khasi Hills",
    "North Garo Hills",
    "Ri Bhoi",
    "South Garo Hills",
    "South West Garo Hills",
    "South West Khasi Hills",
    "West Garo Hills",
    "West Jaintia Hills",
    "West Khasi Hills"
]


search_types = [
    "hospitals"
]


options = webdriver.ChromeOptions()

options.add_argument("--start-maximized")

options.add_argument(
    "--disable-blink-features=AutomationControlled"
)

options.add_argument("--disable-notifications")


driver = webdriver.Chrome(

    service=Service(
        ChromeDriverManager().install()
    ),

    options=options
)


driver.get("https://www.google.com/maps")

print("Opening Google Maps...")

time.sleep(15)

print("Google Maps Loaded")


all_data = []

visited_links = set()


def get_search_box():

    selectors = [

        '//input[@id="searchboxinput"]',
        '//input[contains(@placeholder,"Search")]',
        '//input[contains(@aria-label,"Search")]',
        '//input'

    ]

    for selector in selectors:

        try:

            box = driver.find_element(
                By.XPATH,
                selector
            )

            return box

        except:
            pass

    return None


def extract_school_data():

    try:

        try:
            name = driver.find_element(
                By.TAG_NAME,
                "h1"
            ).text
        except:
            name = ""

        try:
            address = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"address")]'
            ).text
        except:
            address = ""

        try:
            phone = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"phone")]'
            ).text
        except:
            phone = ""

        try:
            website = driver.find_element(
                By.XPATH,
                '//a[contains(@data-item-id,"authority")]'
            ).get_attribute("href")
        except:
            website = ""

        try:
            rating = driver.find_element(
                By.XPATH,
                '//div[@role="img"]'
            ).get_attribute("aria-label")
        except:
            rating = ""

        return {

            "Hospital Name": name,
            "Address": address,
            "Phone": phone,
            "Website": website,
            "Rating": rating,
            "Google Maps URL": driver.current_url

        }

    except:

        return None

for district in districts:

    for search_type in search_types:

        try:

            query = (
                f"{search_type} "
                f"in {district} Meghalaya"
            )

            print(f"\nSearching: {query}")


            search_box = get_search_box()

            if not search_box:

                print("Search Box Not Found")

                continue

            ActionChains(driver).move_to_element(
                search_box
            ).click().perform()

            time.sleep(1)

            search_box.send_keys(
                Keys.CONTROL + "a"
            )

            time.sleep(1)

            search_box.send_keys(Keys.DELETE)

            time.sleep(1)

            for char in query:

                search_box.send_keys(char)

                time.sleep(0.03)

            search_box.send_keys(Keys.ENTER)

            print("Search Submitted")

            time.sleep(8)


            try:

                scrollable_div = driver.find_element(
                    By.XPATH,
                    '//div[@role="feed"]'
                )

                previous_count = 0

                stagnant = 0

                for i in range(100):

                    driver.execute_script(
                        """
                        arguments[0].scrollTop =
                        arguments[0].scrollHeight
                        """,
                        scrollable_div
                    )

    
                    time.sleep(4)

                    listings = driver.find_elements(
                        By.XPATH,
                        '//a[contains(@href,"/maps/place/")]'
                    )

                    current_count = len(listings)

                    print(
                        f"{district} | "
                        f"{search_type} | "
                        f"Scroll {i+1} -> "
                        f"{current_count}"
                    )

                    if current_count == previous_count:

                        stagnant += 1

                    else:

                        stagnant = 0

                    if stagnant >= 4:

                        break

                    previous_count = current_count

            except Exception as e:

                print(f"Scrolling Error: {e}")


            listings = driver.find_elements(
                By.XPATH,
                '//a[contains(@href,"/maps/place/")]'
            )

            links = []

            for listing in listings:

                try:

                    link = listing.get_attribute("href")

                    if (
                        link
                        and link not in visited_links
                    ):

                        links.append(link)

                        visited_links.add(link)

                except:
                    pass

            print(f"Collected {len(links)} links")


            for index, link in enumerate(links):

                try:

                    print(
                        f"{district} | "
                        f"{index+1}/{len(links)}"
                    )

                    driver.get(link)

                    time.sleep(
                        random.uniform(2, 4)
                    )

                    data = extract_school_data()

                    if data:

                        data["District"] = district

                        data["Search Type"] = search_type

                        all_data.append(data)

                        print(data["Hospital Name"])


                    if len(all_data) % 100 == 0:

                        backup_df = pd.DataFrame(
                            all_data
                        )

                        backup_df.drop_duplicates(
                            subset=[
                                "Hospital Name",
                                "Google Maps URL"
                            ],
                            inplace=True
                        )

                        backup_filename = (
                            "meghalaya_backup.csv"
                        )

                        backup_df.to_csv(
                            backup_filename,
                            index=False
                        )

                        print("Backup Saved")

                except Exception as e:

                    print(
                        f"School Error: {e}"
                    )

        except Exception as e:

            print(
                f"District Error: {e}"
            )


df = pd.DataFrame(all_data)

df.drop_duplicates(

    subset=[
        "Hospital Name",
        "Google Maps URL"
    ],

    inplace=True
)


filename = (
    "meghalaya_hospitals.csv"
)

df.to_csv(
    filename,
    index=False
)

print("\nExtraction Completed")

print(
    f"Total Hospitals Extracted: {len(df)}"
)

print(f"\nSaved File: {filename}")

driver.quit()
# Out:
# Opening Google Maps...
# Google Maps Loaded
#
# Searching: hospitals in East Garo Hills Meghalaya
# Search Submitted
# East Garo Hills | hospitals | Scroll 1 -> 14
# East Garo Hills | hospitals | Scroll 2 -> 20
# East Garo Hills | hospitals | Scroll 3 -> 23
# East Garo Hills | hospitals | Scroll 4 -> 23
# East Garo Hills | hospitals | Scroll 5 -> 23
# East Garo Hills | hospitals | Scroll 6 -> 23
# East Garo Hills | hospitals | Scroll 7 -> 23
# Collected 23 links
# East Garo Hills | 1/23
# Civil Hospital Williamnagar
# East Garo Hills | 2/23
# Civil Hospital
# East Garo Hills | 3/23
# Jengjal Sub-Divisional Hospital
# East Garo Hills | 4/23
# Holy Cross Hospital
# East Garo Hills | 5/23
# Tura Christian Hospital
# East Garo Hills | 6/23
# Civil Hospital
# East Garo Hills | 7/23
# Nongpoh Civil Hospital
# East Garo Hills | 8/23
# Sualmeri P H C North Garo Hills
# East Garo Hills | 9/23
# District Maternity & Child Hospital
# East Garo Hills | 10/23
# Civil Hospital Mairang
# East Garo Hills | 11/23
# Supercare Hospital
# East Garo Hills | 12/23
# Nongstoiñ Civil Hospital
# East Garo Hills | 13/23
# Selsella CHC
# East Garo Hills | 14/23
# Civil Hospital, Shillong
# East Garo Hills | 15/23
# Tirot Singh Memorial Hospital
# East Garo Hills | 16/23
# Neigrihms Hospital
# East Garo Hills | 17/23
# Ampati Civil Hospital
# East Garo Hills | 18/23
# Dr. H.G. Roberts Hospital
# East Garo Hills | 19/23
# Nazareth Hospital
# East Garo Hills | 20/23
# Bethany Hospital, Shillong
# East Garo Hills | 21/23
# Misson Hospital
# East Garo Hills | 22/23
# Marakgre Health Sub Centre
# East Garo Hills | 23/23
# Garo Hills Adventist Mission Hospital
#
# Searching: hospitals in East Jaintia Hills Meghalaya
# Search Submitted
# East Jaintia Hills | hospitals | Scroll 1 -> 14
# East Jaintia Hills | hospitals | Scroll 2 -> 19
# East Jaintia Hills | hospitals | Scroll 3 -> 19
# East Jaintia Hills | hospitals | Scroll 4 -> 19
# East Jaintia Hills | hospitals | Scroll 5 -> 19
# East Jaintia Hills | hospitals | Scroll 6 -> 19
# Collected 17 links
# East Jaintia Hills | 1/17
# CIVIL HOSPITAL KHLIEHRIAT
# East Jaintia Hills | 2/17
# Dr Norman Tunnel Hospital.
# East Jaintia Hills | 3/17
# Woodland WK Hospital
# East Jaintia Hills | 4/17
# Maia Multispeciality Clinic, Khliehriat
# East Jaintia Hills | 5/17
# District Civil Hospital Ialong
# East Jaintia Hills | 6/17
# MCH HOSPITAL JOWAI PANALIAR
# East Jaintia Hills | 7/17
# Nongtalang Community Health Centre (CHC)
# East Jaintia Hills | 8/17
# Jowai Civil Hospital Ialong
# East Jaintia Hills | 9/17
# Sahsniang PHC
# East Jaintia Hills | 10/17
# CHC WARD
# East Jaintia Hills | 11/17
# Iooksi PHC
# East Jaintia Hills | 12/17
# Jarain PHC
# East Jaintia Hills | 13/17
# Shangpung PHC
# East Jaintia Hills | 14/17
# Office of the DM&HO, Khliehriat
# East Jaintia Hills | 15/17
# Jordan Poly clinic
# East Jaintia Hills | 16/17
# Nartiang PHC
# East Jaintia Hills | 17/17
# Pamra Paithlu PHC
#
# Searching: hospitals in East Khasi Hills Meghalaya
# Search Submitted
# East Khasi Hills | hospitals | Scroll 1 -> 14
# East Khasi Hills | hospitals | Scroll 2 -> 20
# East Khasi Hills | hospitals | Scroll 3 -> 27
# East Khasi Hills | hospitals | Scroll 4 -> 34
# East Khasi Hills | hospitals | Scroll 5 -> 35
# East Khasi Hills | hospitals | Scroll 6 -> 35
# East Khasi Hills | hospitals | Scroll 7 -> 35
# East Khasi Hills | hospitals | Scroll 8 -> 35
# East Khasi Hills | hospitals | Scroll 9 -> 35
# Collected 20 links
# East Khasi Hills | 1/20
# Woodland Hospital
# East Khasi Hills | 2/20
# NEIGRIHMS Emergency Unit
# East Khasi Hills | 3/20
# Ganesh Das Hospital
# East Khasi Hills | 4/20
# North Eastern Indira Gandhi Regional Institute of Health & Medical Sciences
# East Khasi Hills | 5/20
# The Children’s Hospital
# East Khasi Hills | 6/20
# Reid Provincial Chest Hospital
# East Khasi Hills | 7/20
# Police Hospital Reserve
# East Khasi Hills | 8/20
# John Roberts Hospital Shillong
# East Khasi Hills | 9/20
# Bethany Hospital
# East Khasi Hills | 10/20
# Jiban Ram Goenka Hospital
# East Khasi Hills | 11/20
# Civil Hospital Mawkyrwat
# East Khasi Hills | 12/20
# T.B. Hospital
# South West Garo Hills | 6/6
# Zikzak Primary Health Center
#
# Searching: hospitals in South West Khasi Hills Meghalaya
# Search Submitted
# South West Khasi Hills | hospitals | Scroll 1 -> 14
# South West Khasi Hills | hospitals | Scroll 2 -> 19
# South West Khasi Hills | hospitals | Scroll 3 -> 19
# South West Khasi Hills | hospitals | Scroll 4 -> 19
# South West Khasi Hills | hospitals | Scroll 5 -> 19
# South West Khasi Hills | hospitals | Scroll 6 -> 19
# Collected 2 links
# South West Khasi Hills | 1/2
# Wahkaji PHC
# South West Khasi Hills | 2/2
# Ranikor CHC
#
# Searching: hospitals in West Garo Hills Meghalaya
# Search Submitted
# West Garo Hills | hospitals | Scroll 1 -> 14
# West Garo Hills | hospitals | Scroll 2 -> 20
# West Garo Hills | hospitals | Scroll 3 -> 22
# West Garo Hills | hospitals | Scroll 4 -> 22
# West Garo Hills | hospitals | Scroll 5 -> 22
# West Garo Hills | hospitals | Scroll 6 -> 22
# West Garo Hills | hospitals | Scroll 7 -> 22
# Collected 3 links
# West Garo Hills | 1/3
# Tura Medical College
# West Garo Hills | 2/3
# PURAKHASIA PHC
# West Garo Hills | 3/3
# LIFE LINE HOSPITAL Hatsingimari
#
# Searching: hospitals in West Jaintia Hills Meghalaya
# Search Submitted
# West Jaintia Hills | hospitals | Scroll 1 -> 14
# West Jaintia Hills | hospitals | Scroll 2 -> 20
# West Jaintia Hills | hospitals | Scroll 3 -> 27
# West Jaintia Hills | hospitals | Scroll 4 -> 29
# West Jaintia Hills | hospitals | Scroll 5 -> 29
# West Jaintia Hills | hospitals | Scroll 6 -> 29
# West Jaintia Hills | hospitals | Scroll 7 -> 29
# West Jaintia Hills | hospitals | Scroll 8 -> 29
# Collected 7 links
# West Jaintia Hills | 1/7
# Barato PHC
# West Jaintia Hills | 2/7
# C.H.C Ummulong
# West Jaintia Hills | 3/7
# DMHO Office
# West Jaintia Hills | 4/7
# KHLIEHTYRSHI,PHC
# West Jaintia Hills | 5/7
# Dawki PHC
# West Jaintia Hills | 6/7
# Namdong PHC
# West Jaintia Hills | 7/7
# Diengpasoh PHC
#
# Searching: hospitals in West Khasi Hills Meghalaya
# Search Submitted
# West Khasi Hills | hospitals | Scroll 1 -> 14
# West Khasi Hills | hospitals | Scroll 2 -> 16
# West Khasi Hills | hospitals | Scroll 3 -> 16
# West Khasi Hills | hospitals | Scroll 4 -> 16
# West Khasi Hills | hospitals | Scroll 5 -> 16
# West Khasi Hills | hospitals | Scroll 6 -> 16
# Collected 4 links
# West Khasi Hills | 1/4
# District Medical And Health Office
# West Khasi Hills | 2/4
# Riangdo Community Health Centre
# West Khasi Hills | 3/4
# Shallang PHC
# West Khasi Hills | 4/4
# Rambrai PHC
#
# Extraction Completed
# Total Hospitals Extracted: 126
#
# Saved File: meghalaya_hospitals.csv
