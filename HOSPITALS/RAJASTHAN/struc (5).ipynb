# %%
import pandas as pd

# %%
df = pd.read_csv("rajasthan_hospitals.csv")

# %%
df.shape
# Out:
# (1226, 8)

# %%
df = df[
    df["Phone"].notna() &
    (df["Phone"].astype(str).str.strip() != "")
]
df.shape
# Out:
# (888, 8)

# %%
df = df[
    df["Hospital Name"].notna()
]

df = df[
    df["Hospital Name"].str.strip() != ""
]
df.shape
# Out:
# (888, 8)

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]", "", regex=True)  # remove symbols/icons
    .str.strip()
)

display(df[["Phone"]].head())
# Out:
#            Phone
# 1  0145 260 3603
# 2   095218 25626
# 3   080942 21221
# 4   088756 66689
# 5  0145 268 0241

# %%
df.to_csv(
    "rajasthan_hospitals_cleaned.csv",
    index=False
)
