# %%
import time
import random
import pandas as pd

from datetime import datetime

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.service import Service

from webdriver_manager.chrome import ChromeDriverManager



districts = [

    "Dudu",
    "Dungarpur",
    "Gangapur City",
    "Hanumangarh",
    "Jaipur",
    "Jaipur Rural",

]



search_types = [
    "hospitals"
]



options = webdriver.ChromeOptions()

options.add_argument("--start-maximized")

options.add_argument(
    "--disable-blink-features=AutomationControlled"
)

options.add_argument("--disable-notifications")



driver = webdriver.Chrome(

    service=Service(
        ChromeDriverManager().install()
    ),

    options=options
)



driver.get("https://www.google.com/maps")

print("Opening Google Maps...")

time.sleep(15)

print("Google Maps Loaded")



all_data = []

visited_links = set()



def get_search_box():

    selectors = [

        '//input[@id="searchboxinput"]',
        '//input[contains(@placeholder,"Search")]',
        '//input[contains(@aria-label,"Search")]',
        '//input'

    ]

    for selector in selectors:

        try:

            box = driver.find_element(
                By.XPATH,
                selector
            )

            return box

        except:
            pass

    return None


def extract_school_data():

    try:


        try:
            name = driver.find_element(
                By.TAG_NAME,
                "h1"
            ).text
        except:
            name = ""


        try:
            address = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"address")]'
            ).text
        except:
            address = ""

   
        try:
            phone = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"phone")]'
            ).text
        except:
            phone = ""


        try:
            website = driver.find_element(
                By.XPATH,
                '//a[contains(@data-item-id,"authority")]'
            ).get_attribute("href")
        except:
            website = ""


        try:
            rating = driver.find_element(
                By.XPATH,
                '//div[@role="img"]'
            ).get_attribute("aria-label")
        except:
            rating = ""

        return {

            "Hospital Name": name,
            "Address": address,
            "Phone": phone,
            "Website": website,
            "Rating": rating,
            "Google Maps URL": driver.current_url

        }

    except:

        return None


for district in districts:

    for search_type in search_types:

        try:

            query = (
                f"{search_type} "
                f"in {district} Rajasthan"
            )

            print(f"\nSearching: {query}")



            search_box = get_search_box()

            if not search_box:

                print("Search Box Not Found")

                continue

            ActionChains(driver).move_to_element(
                search_box
            ).click().perform()

            time.sleep(1)

            search_box.send_keys(
                Keys.CONTROL + "a"
            )

            time.sleep(1)

            search_box.send_keys(Keys.DELETE)

            time.sleep(1)

            for char in query:

                search_box.send_keys(char)

                time.sleep(0.03)

            search_box.send_keys(Keys.ENTER)

            print("Search Submitted")

            time.sleep(8)

            try:

                scrollable_div = driver.find_element(
                    By.XPATH,
                    '//div[@role="feed"]'
                )

                previous_count = 0

                stagnant = 0

                for i in range(100):

                    driver.execute_script(
                        """
                        arguments[0].scrollTop =
                        arguments[0].scrollHeight
                        """,
                        scrollable_div
                    )

            
                    time.sleep(4)

                    listings = driver.find_elements(
                        By.XPATH,
                        '//a[contains(@href,"/maps/place/")]'
                    )

                    current_count = len(listings)

                    print(
                        f"{district} | "
                        f"{search_type} | "
                        f"Scroll {i+1} -> "
                        f"{current_count}"
                    )

                    if current_count == previous_count:

                        stagnant += 1

                    else:

                        stagnant = 0

       
                    if stagnant >= 4:

                        break

                    previous_count = current_count

            except Exception as e:

                print(f"Scrolling Error: {e}")


            listings = driver.find_elements(
                By.XPATH,
                '//a[contains(@href,"/maps/place/")]'
            )

            links = []

            for listing in listings:

                try:

                    link = listing.get_attribute("href")

                    if (
                        link
                        and link not in visited_links
                    ):

                        links.append(link)

                        visited_links.add(link)

                except:
                    pass

            print(f"Collected {len(links)} links")

            for index, link in enumerate(links):

                try:

                    print(
                        f"{district} | "
                        f"{index+1}/{len(links)}"
                    )

                    driver.get(link)

                    time.sleep(
                        random.uniform(2, 4)
                    )

                    data = extract_school_data()

                    if data:

                        data["District"] = district

                        data["Search Type"] = search_type

                        all_data.append(data)

                        print(data["Hospital Name"])



                    if len(all_data) % 100 == 0:

                        backup_df = pd.DataFrame(
                            all_data
                        )

                        backup_df.drop_duplicates(
                            subset=[
                                "Hospital Name",
                                "Google Maps URL"
                            ],
                            inplace=True
                        )

                        backup_filename = (
                            "rajasthan_backup.csv"
                        )

                        backup_df.to_csv(
                            backup_filename,
                            index=False
                        )

                        print("Backup Saved")

                except Exception as e:

                    print(
                        f"School Error: {e}"
                    )

        except Exception as e:

            print(
                f"District Error: {e}"
            )



new_df = pd.DataFrame(all_data)

new_df.drop_duplicates(

    subset=[
        "Hospital Name",
        "Google Maps URL"
    ],

    inplace=True
)

old_file = "rajasthan_hospitals.csv"

try:

    old_df = pd.read_csv(old_file)

    final_df = pd.concat(
        [old_df, new_df],
        ignore_index=True
    )

    final_df.drop_duplicates(

        subset=[
            "Hospital Name",
            "Google Maps URL"
        ],

        inplace=True
    )

except:

    final_df = new_df

final_df.to_csv(
    old_file,
    index=False
)

print("\nExtraction Completed")

print(
    f"Total Hospitals Extracted: {len(final_df)}"
)

print(
    f"\nUpdated Existing File: {old_file}"
)

driver.quit()
# Out:
# Opening Google Maps...
# Google Maps Loaded
#
# Searching: hospitals in Dudu Rajasthan
# Search Submitted
# Dudu | hospitals | Scroll 1 -> 11
# Dudu | hospitals | Scroll 2 -> 11
# Dudu | hospitals | Scroll 3 -> 11
# Dudu | hospitals | Scroll 4 -> 11
# Dudu | hospitals | Scroll 5 -> 11
# Collected 11 links
# Dudu | 1/11
# Dr S Kumar Multi Specialty Hospital
# Dudu | 2/11
# Dr. Nirbheek Sharma
# Dudu | 3/11
# Shree Narayan Das Hospital
# Dudu | 4/11
# Dudu durbeen hospital and trauma centre Jaipur -ajmer highway road
# Dudu | 5/11
# Govt Hospital Dudu
# Dudu | 6/11
# ABS HOSPITAL
# Dudu | 7/11
# National Hospital
# Dudu | 8/11
# Janta care hospital
# Dudu | 9/11
# राजकीय उपजिला अस्पताल, गैजी,दूदू, जिला- जयपुर
# Dudu | 10/11
# Health care medical center dudu
# Dudu | 11/11
# Kaswan dental hospital
#
# Searching: hospitals in Dungarpur Rajasthan
# Search Submitted
# Dungarpur | hospitals | Scroll 1 -> 14
# Dungarpur | hospitals | Scroll 2 -> 14
# Dungarpur | hospitals | Scroll 3 -> 14
# Dungarpur | hospitals | Scroll 4 -> 14
# Dungarpur | hospitals | Scroll 5 -> 14
# Collected 14 links
# Dungarpur | 1/14
# Smart Care Multispeciality hospital - Best Multispeciality Hospital
# Dungarpur | 2/14
# Upasna Jeevan Raksha Hospital || Best Hospital | Emergency Hospital | Multispeciality Hospital
# Dungarpur | 3/14
# Aashirvad hospital
# Dungarpur | 4/14
# Jeevan Raksha Hospital Private Limited
# Dungarpur | 5/14
# Shree mangalam hospital | Best Physician | Gastrology | Urology | Surgery | Endoscopy
# Dungarpur | 6/14
# Chirag Hospital
# Dungarpur | 7/14
# Sabka Group Of Hospitals - Best Hospital, Private Hospital, Emergency Hospital, Multispeciality Hospital In Dungarpur
# Dungarpur | 8/14
# Jivan Jyoti Hospital Dungarpur
# Dungarpur | 9/14
# Zeel Multispeciality Hospital
# Dungarpur | 10/14
# HOSPITAL GSS, AVVNL DUNGARPUR
# Dungarpur | 11/14
# Navjeevan Dental Hospital
# Dungarpur | 12/14
# M M Patidar Hospital Sagwara
# Dungarpur | 13/14
# UPASANA SONOGRAPHY CENTER
# Dungarpur | 14/14
# Mewar Hospital Dungarpur
#
# Searching: hospitals in Gangapur City Rajasthan
# Search Submitted
# Gangapur City | hospitals | Scroll 1 -> 16
# Gangapur City | hospitals | Scroll 2 -> 20
# Gangapur City | hospitals | Scroll 3 -> 24
# Gangapur City | hospitals | Scroll 4 -> 24
# Gangapur City | hospitals | Scroll 5 -> 24
# Gangapur City | hospitals | Scroll 6 -> 24
# Gangapur City | hospitals | Scroll 7 -> 24
# Collected 24 links
# Gangapur City | 1/24
# CP Hospital (top multispeciality hospital,multispeciality & emergency hospital,best general hospital)
# Gangapur City | 2/24
# Govt. Hospital Gangapur city
# Gangapur City | 3/24
# Gulab Devi Memorial Hospital
# Gangapur City | 4/24
# Riddhi Siddhi hospital
# Gangapur City | 5/24
# Vardhman Hospital and Infertility Center
# Gangapur City | 6/24
# Garg Hospital
# Gangapur City | 7/24
# Apex laproScopy hospital
# Gangapur City | 8/24
# Sub District Hospital Gangapur City
# Gangapur City | 9/24
# R.K. MEHTA HOSPITAL GANGAPUR CITY
# Gangapur City | 10/24
# govt. hospital
# Gangapur City | 11/24
# S K Hospital - Best General Hospital
# Gangapur City | 12/24
# Mittal Hospital
# Gangapur City | 13/24
# Sevanjali E.H. Clinic, Gangapur City.
# Gangapur City | 14/24
# Avantika Fetal medicine centre
# Gangapur City | 15/24
# Railway Hospital
# Gangapur City | 16/24
# Akash Home Care Centre
# Gangapur City | 17/24
# Akash Hospital
# Gangapur City | 18/24
# R C MEENA HOSPITAL
# Gangapur City | 19/24
# Kamla Hospital
# Gangapur City | 20/24
# Gupta Hospital
# Gangapur City | 21/24
# SHASTRI MULTI SPECIALITY HOSPITAL
# Gangapur City | 22/24
# RGM HOSPITAL
# Gangapur City | 23/24
# Damoder Dentel Hospital
# Gangapur City | 24/24
# Shastri Nursing Home
#
# Searching: hospitals in Hanumangarh Rajasthan
# Search Submitted
# Hanumangarh | hospitals | Scroll 1 -> 16
# Hanumangarh | hospitals | Scroll 2 -> 20
# Hanumangarh | hospitals | Scroll 3 -> 28
# Hanumangarh | hospitals | Scroll 4 -> 35
# Hanumangarh | hospitals | Scroll 5 -> 35
# Hanumangarh | hospitals | Scroll 6 -> 35
# Raj Hospital
# Jaipur | 88/115
# Orthopedic Hospital in Pratap Nagar: Vishwanath Hospital
# Jaipur | 89/115
# Dr. Vaibhav Agrawal, M.S. (Orthopaedics)
# Jaipur | 90/115
# Bansal Hospital (Shyam Nagar)
# Jaipur | 91/115
# Krishna Hospital
# Jaipur | 92/115
# Chandra Hospital
# Jaipur | 93/115
# Metropolitan Hospital
# Jaipur | 94/115
# Shri Nidaan Hospital
# Jaipur | 95/115
# Rawal Hospital
# Jaipur | 96/115
# Purple Heron Hospital - Plastic & Cosmetic Surgery Hospital | Pain Treatment | Hair Transplant - Gender Reassignment Jaipur
# Jaipur | 97/115
# University Hospital
# Jaipur | 98/115
# Monika Hospital
# Jaipur | 99/115
#
# Jaipur | 100/115
# Dulet Hospital
# Jaipur | 101/115
# Vedansh Hospital
# Jaipur | 102/115
# Nahar Hospital
# Jaipur | 103/115
# Srk Hospital
# Jaipur | 104/115
# Paras Hospital
# Jaipur | 105/115
# K.C.Memorial Eye Hospital
# Jaipur | 106/115
# BARALA HOSPITAL & RESEARCH CENTER
# Jaipur | 107/115
# Mohan Hospital
# Jaipur | 108/115
# Maharaja Agrasen
# Jaipur | 109/115
# Suraksha Hospital and Orthopedic center
# Jaipur | 110/115
# Tilak hospital
# Jaipur | 111/115
# Sharda Hospital
# Jaipur | 112/115
# Govt. Hospital Mahesh Nagar
# Jaipur | 113/115
# Radha Nursing home & General Hospital
# Jaipur | 114/115
# Apex Hospitals Corporate Office
# Jaipur | 115/115
# Care Nursing Home
#
# Searching: hospitals in Jaipur Rural Rajasthan
# Search Submitted
# Jaipur Rural | hospitals | Scroll 1 -> 16
# Jaipur Rural | hospitals | Scroll 2 -> 20
# Jaipur Rural | hospitals | Scroll 3 -> 28
# Jaipur Rural | hospitals | Scroll 4 -> 36
# Jaipur Rural | hospitals | Scroll 5 -> 40
# Jaipur Rural | hospitals | Scroll 6 -> 48
# Jaipur Rural | hospitals | Scroll 7 -> 56
# Jaipur Rural | hospitals | Scroll 8 -> 60
# Jaipur Rural | hospitals | Scroll 9 -> 68
# Jaipur Rural | hospitals | Scroll 10 -> 76
# Jaipur Rural | hospitals | Scroll 11 -> 80
# Jaipur Rural | hospitals | Scroll 12 -> 88
# Jaipur Rural | hospitals | Scroll 13 -> 96
# Jaipur Rural | hospitals | Scroll 14 -> 100
# Jaipur Rural | hospitals | Scroll 15 -> 108
# Jaipur Rural | hospitals | Scroll 16 -> 116
# Jaipur Rural | hospitals | Scroll 17 -> 116
# Jaipur Rural | hospitals | Scroll 18 -> 116
# Jaipur Rural | hospitals | Scroll 19 -> 116
# Jaipur Rural | hospitals | Scroll 20 -> 116
# Collected 44 links
# Jaipur Rural | 1/44
# Rajasthan University of Health Sciences Hospital, Jaipur
# Backup Saved
# Jaipur Rural | 2/44
# Akhila Hospital
# Jaipur Rural | 3/44
# SRM Hospital
