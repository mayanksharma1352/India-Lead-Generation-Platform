# %%
import pandas as pd

# %%
df = pd.read_csv("goa_hospitals.csv")

# %%
df.shape
# Out:
# (55, 8)

# %%
df = df[
    df["Phone"].notna() & 
    (df["Phone"].astype(str).str.strip() != "")
    ]
df.shape
# Out:
# (1, 8)

# %%
df = df[
    df["Hospital Name"].notna()
    ]

df = df[
    df["Hospital Name"].str.strip() != ""
    ]
df.shape
# Out:
# (1, 8)

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]","",regex=True)
    .str.strip()
)

display(df[["Phone"]].head())
# Out:
#            Phone
# 41  093261 20019

# %%
df.to_csv(
    "goa_hospitals_cleaned.csv",
    index=False
)
