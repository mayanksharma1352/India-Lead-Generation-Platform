# %%
import time
import random
import pandas as pd

from datetime import datetime

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.service import Service

from webdriver_manager.chrome import ChromeDriverManager

districts = [
    "North Goa",
    "South Goa"
]


search_types = [
    "hospitals"
]

options = webdriver.ChromeOptions()

options.add_argument("--start-maximized")

options.add_argument(
    "--disable-blink-features=AutomationControlled"
)

options.add_argument("--disable-notifications")


driver = webdriver.Chrome(

    service=Service(
        ChromeDriverManager().install()
    ),

    options=options
)


driver.get("https://www.google.com/maps")

print("Opening Google Maps...")

time.sleep(15)

print("Google Maps Loaded")



all_data = []

visited_links = set()


def get_search_box():

    selectors = [

        '//input[@id="searchboxinput"]',
        '//input[contains(@placeholder,"Search")]',
        '//input[contains(@aria-label,"Search")]',
        '//input'

    ]

    for selector in selectors:

        try:

            box = driver.find_element(
                By.XPATH,
                selector
            )

            return box

        except:
            pass

    return None


def extract_school_data():

    try:


        try:
            name = driver.find_element(
                By.TAG_NAME,
                "h1"
            ).text
        except:
            name = ""

        try:
            address = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"address")]'
            ).text
        except:
            address = ""

        try:
            phone = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"phone")]'
            ).text
        except:
            phone = ""

        try:
            website = driver.find_element(
                By.XPATH,
                '//a[contains(@data-item-id,"authority")]'
            ).get_attribute("href")
        except:
            website = ""

        try:
            rating = driver.find_element(
                By.XPATH,
                '//div[@role="img"]'
            ).get_attribute("aria-label")
        except:
            rating = ""

        return {

            "Hospital Name": name,
            "Address": address,
            "Phone": phone,
            "Website": website,
            "Rating": rating,
            "Google Maps URL": driver.current_url

        }

    except:

        return None


for district in districts:

    for search_type in search_types:

        try:

            query = (
                f"{search_type} "
                f"in {district} Goa"
            )

            print(f"\nSearching: {query}")


            search_box = get_search_box()

            if not search_box:

                print("Search Box Not Found")

                continue

            ActionChains(driver).move_to_element(
                search_box
            ).click().perform()

            time.sleep(1)

            search_box.send_keys(
                Keys.CONTROL + "a"
            )

            time.sleep(1)

            search_box.send_keys(Keys.DELETE)

            time.sleep(1)

            # TYPE SLOWLY
            for char in query:

                search_box.send_keys(char)

                time.sleep(0.03)

            search_box.send_keys(Keys.ENTER)

            print("Search Submitted")

            time.sleep(8)

            try:

                scrollable_div = driver.find_element(
                    By.XPATH,
                    '//div[@role="feed"]'
                )

                previous_count = 0

                stagnant = 0

                for i in range(100):

                    driver.execute_script(
                        """
                        arguments[0].scrollTop =
                        arguments[0].scrollHeight
                        """,
                        scrollable_div
                    )

                    time.sleep(4)

                    listings = driver.find_elements(
                        By.XPATH,
                        '//a[contains(@href,"/maps/place/")]'
                    )

                    current_count = len(listings)

                    print(
                        f"{district} | "
                        f"{search_type} | "
                        f"Scroll {i+1} -> "
                        f"{current_count}"
                    )

                    if current_count == previous_count:

                        stagnant += 1

                    else:

                        stagnant = 0

                    # STOP AFTER 4 SAME COUNTS
                    if stagnant >= 4:

                        break

                    previous_count = current_count

            except Exception as e:

                print(f"Scrolling Error: {e}")


            listings = driver.find_elements(
                By.XPATH,
                '//a[contains(@href,"/maps/place/")]'
            )

            links = []

            for listing in listings:

                try:

                    link = listing.get_attribute("href")

                    if (
                        link
                        and link not in visited_links
                    ):

                        links.append(link)

                        visited_links.add(link)

                except:
                    pass

            print(f"Collected {len(links)} links")


            for index, link in enumerate(links):

                try:

                    print(
                        f"{district} | "
                        f"{index+1}/{len(links)}"
                    )

                    driver.get(link)

                    time.sleep(
                        random.uniform(2, 4)
                    )

                    data = extract_school_data()

                    if data:

                        data["District"] = district

                        data["Search Type"] = search_type

                        all_data.append(data)

                        print(data["Hospital Name"])


                    if len(all_data) % 100 == 0:

                        backup_df = pd.DataFrame(
                            all_data
                        )

                        backup_df.drop_duplicates(
                            subset=[
                                "Hospital Name",
                                "Google Maps URL"
                            ],
                            inplace=True
                        )

                        backup_filename = (
                            "goa_backup.csv"
                        )

                        backup_df.to_csv(
                            backup_filename,
                            index=False
                        )

                        print("Backup Saved")

                except Exception as e:

                    print(
                        f"School Error: {e}"
                    )

        except Exception as e:

            print(
                f"District Error: {e}"
            )


df = pd.DataFrame(all_data)

df.drop_duplicates(

    subset=[
        "Hospital Name",
        "Google Maps URL"
    ],

    inplace=True
)


filename = (
    "goa_hospitals.csv"
)

df.to_csv(
    filename,
    index=False
)

print("\nExtraction Completed")

print(
    f"Total Schools Extracted: {len(df)}"
)

print(f"\nSaved File: {filename}")

driver.quit()
# Out:
# Opening Google Maps...
# Google Maps Loaded
#
# Searching: hospitals in North Goa Goa
# Search Submitted
# North Goa | hospitals | Scroll 1 -> 14
# North Goa | hospitals | Scroll 2 -> 20
# North Goa | hospitals | Scroll 3 -> 27
# North Goa | hospitals | Scroll 4 -> 34
# North Goa | hospitals | Scroll 5 -> 40
# North Goa | hospitals | Scroll 6 -> 42
# North Goa | hospitals | Scroll 7 -> 42
# North Goa | hospitals | Scroll 8 -> 42
# North Goa | hospitals | Scroll 9 -> 42
# North Goa | hospitals | Scroll 10 -> 42
# Collected 42 links
# North Goa | 1/42
# Manipal Hospitals Goa
# North Goa | 2/42
# Niramaya Medical Hospital
# North Goa | 3/42
# St. Anthony's Hospital
# North Goa | 4/42
# Healthway Hospital Old Goa
# North Goa | 5/42
# Savaikar Hospital
# North Goa | 6/42
# District Hospital
# North Goa | 7/42
# Galaxy Hospital Mapusa Goa
# North Goa | 8/42
# Mathew Braganza Hospital
# North Goa | 9/42
# Goa Medical College
# North Goa | 10/42
# Daffodils Multi-Speciality Hospital
# North Goa | 11/42
# Victor Hospital
# North Goa | 12/42
# Vision Hospital Goa
# North Goa | 13/42
# Redkar Hospital and Research Center.
# North Goa | 14/42
# Dr. Dukle's Hospital & Research Centre - Candolim
# North Goa | 15/42
# Vision General Hospital and Emergency
# North Goa | 16/42
# V. M. Salgaocar Hospital
# North Goa | 17/42
# Dr.Olavo Ribeiro Hospital
# North Goa | 18/42
# Super Speciality Block Goa Medical College
# North Goa | 19/42
# North Goa District Hospital (Asilo)
# North Goa | 20/42
# Trinity Healthcare And Medical Research, Esperança Hospital
# North Goa | 21/42
# Classic Hospital
# North Goa | 22/42
# Holy Cross General Remanso Hospital
# North Goa | 23/42
# Healthway Hospital
# North Goa | 24/42
# Aster Hospital
# North Goa | 25/42
# Dr Milind Colvalcar's Mapusa Clinic Medical Centre
# North Goa | 26/42
# Bhagyoday Hospital Dr Pushker Neogi
# North Goa | 27/42
# Dr Prabhu Hospital
# North Goa | 28/42
# Hospicio
# North Goa | 29/42
# Grace Intensive Cardiac Care Centre
# North Goa | 30/42
# Mahatme Nursing Home | Dr. Mithun Mahatme | Best Gynecologist in Goa
# North Goa | 31/42
#
# North Goa | 32/42
# Royal Hospital
# North Goa | 33/42
# Trimurti General Hospital
# North Goa | 34/42
# Community Health Centre, Valpoi
# North Goa | 35/42
# Chodankar Hospital
# North Goa | 36/42
# Pai Hospital
# North Goa | 37/42
# A. V. Da Costa Memorial Clinic
# North Goa | 38/42
# Urban Health Centre
# North Goa | 39/42
# Yashodhan Hospital
# North Goa | 40/42
# Campal Clinic
# North Goa | 41/42
# Sub District Hospital Chicalim
# North Goa | 42/42
# Dr Rekha S. Kamat Tarcar Clinic
#
# Searching: hospitals in South Goa Goa
# Search Submitted
# South Goa | hospitals | Scroll 1 -> 14
# South Goa | hospitals | Scroll 2 -> 20
# South Goa | hospitals | Scroll 3 -> 27
# South Goa | hospitals | Scroll 4 -> 34
# South Goa | hospitals | Scroll 5 -> 40
# South Goa | hospitals | Scroll 6 -> 40
# South Goa | hospitals | Scroll 7 -> 40
# South Goa | hospitals | Scroll 8 -> 40
# South Goa | hospitals | Scroll 9 -> 40
# Collected 13 links
# South Goa | 1/13
# IMPERIAL PLUS HOSPITAL LLP
# South Goa | 2/13
# Horizon ICU & Hospital
# South Goa | 3/13
# Gracias Maternity Hospital
# South Goa | 4/13
# MotherCare Hospital
# South Goa | 5/13
# Government Hospital, Canacona
# South Goa | 6/13
# Baracho Hospital and Maternity Home
# South Goa | 7/13
# Primary Health Centre, Cansaulim
# South Goa | 8/13
# Sonu Kamat Hospital
# South Goa | 9/13
# Platicare Hospital
# South Goa | 10/13
# Victor Hospitals OPD Clinic
# South Goa | 11/13
# Dr. Batra's Positive Health Clinic Private Limited
# South Goa | 12/13
# AIS Clinic - Homeopathy Clinic | Gastro, Acidity, Asthma, Skin Specialist, Allergy, Joint & Bone Pain | Margao, Goa
# South Goa | 13/13
# Santhigiri Ayurveda And Siddha Healthcare Centre
#
# Extraction Completed
# Total Schools Extracted: 55
#
# Saved File: goa_hospitals.csv
