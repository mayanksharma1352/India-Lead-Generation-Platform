# %%
import pandas as pd

# %%
df = pd.read_csv("karnataka_hospitals.csv")

# %%
df.shape
# Out:
# (1190, 8)

# %%
duplicate_count = df.duplicated(
    subset=["Hospital Name", "Google Maps URL"]
).sum()
duplicate_count
# Out:
# np.int64(0)

# %%
df = df[
    df["Phone"].notna() & 
    (df["Phone"].astype(str).str.strip() != "")
    ]
df.shape
# Out:
# (230, 8)

# %%
df = df[
    df["Hospital Name"].notna()
    ]

df = df[
    df["Hospital Name"].str.strip() != ""
    ]
df.shape
# Out:
# (230, 8)

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]","",regex=True)
    .str.strip()
)

display(df[["Phone"]].head())
# Out:
#           Phone
# 2  083542 26055
# 3  072772 07786
# 4  088671 20078
# 7  083542 25131
# 9  079969 80222

# %%
df.to_csv(
    "karnataka_hospitals_cleaned.csv",
    index=False
)
