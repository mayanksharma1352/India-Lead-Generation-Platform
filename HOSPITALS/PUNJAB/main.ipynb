# %%
import time
import random
import pandas as pd

from datetime import datetime

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.service import Service

from webdriver_manager.chrome import ChromeDriverManager


districts = [
    "Amritsar",
    "Barnala",
    "Bathinda",
    "Faridkot",
    "Fatehgarh Sahib",
    "Fazilka",
    "Ferozepur",
    "Gurdaspur",
    "Hoshiarpur",
    "Jalandhar",
    "Kapurthala",
    "Ludhiana",
    "Malerkotla",
    "Mansa",
    "Moga",
    "Mohali",
    "Muktsar",
    "Pathankot",
    "Patiala",
    "Rupnagar",
    "Sangrur",
    "Shaheed Bhagat Singh Nagar",
    "Tarn Taran"
]


search_types = [
    "hospitals"
]


options = webdriver.ChromeOptions()

options.add_argument("--start-maximized")

options.add_argument(
    "--disable-blink-features=AutomationControlled"
)

options.add_argument("--disable-notifications")


driver = webdriver.Chrome(

    service=Service(
        ChromeDriverManager().install()
    ),

    options=options
)

driver.get("https://www.google.com/maps")

print("Opening Google Maps...")

time.sleep(15)

print("Google Maps Loaded")


all_data = []

visited_links = set()


def get_search_box():

    selectors = [

        '//input[@id="searchboxinput"]',
        '//input[contains(@placeholder,"Search")]',
        '//input[contains(@aria-label,"Search")]',
        '//input'

    ]

    for selector in selectors:

        try:

            box = driver.find_element(
                By.XPATH,
                selector
            )

            return box

        except:
            pass

    return None


def extract_school_data():

    try:

        try:
            name = driver.find_element(
                By.TAG_NAME,
                "h1"
            ).text
        except:
            name = ""

        try:
            address = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"address")]'
            ).text
        except:
            address = ""

        try:
            phone = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"phone")]'
            ).text
        except:
            phone = ""

        try:
            website = driver.find_element(
                By.XPATH,
                '//a[contains(@data-item-id,"authority")]'
            ).get_attribute("href")
        except:
            website = ""

        try:
            rating = driver.find_element(
                By.XPATH,
                '//div[@role="img"]'
            ).get_attribute("aria-label")
        except:
            rating = ""

        return {

            "Hospital Name": name,
            "Address": address,
            "Phone": phone,
            "Website": website,
            "Rating": rating,
            "Google Maps URL": driver.current_url

        }

    except:

        return None


for district in districts:

    for search_type in search_types:

        try:

            query = (
                f"{search_type} "
                f"in {district} Punjab"
            )

            print(f"\nSearching: {query}")


            search_box = get_search_box()

            if not search_box:

                print("Search Box Not Found")

                continue

            ActionChains(driver).move_to_element(
                search_box
            ).click().perform()

            time.sleep(1)

            search_box.send_keys(
                Keys.CONTROL + "a"
            )

            time.sleep(1)

            search_box.send_keys(Keys.DELETE)

            time.sleep(1)

            for char in query:

                search_box.send_keys(char)

                time.sleep(0.03)

            search_box.send_keys(Keys.ENTER)

            print("Search Submitted")

            time.sleep(8)


            try:

                scrollable_div = driver.find_element(
                    By.XPATH,
                    '//div[@role="feed"]'
                )

                previous_count = 0

                stagnant = 0

                for i in range(100):

                    driver.execute_script(
                        """
                        arguments[0].scrollTop =
                        arguments[0].scrollHeight
                        """,
                        scrollable_div
                    )

                
                    time.sleep(4)

                    listings = driver.find_elements(
                        By.XPATH,
                        '//a[contains(@href,"/maps/place/")]'
                    )

                    current_count = len(listings)

                    print(
                        f"{district} | "
                        f"{search_type} | "
                        f"Scroll {i+1} -> "
                        f"{current_count}"
                    )

                    if current_count == previous_count:

                        stagnant += 1

                    else:

                        stagnant = 0

                    if stagnant >= 4:

                        break

                    previous_count = current_count

            except Exception as e:

                print(f"Scrolling Error: {e}")


            listings = driver.find_elements(
                By.XPATH,
                '//a[contains(@href,"/maps/place/")]'
            )

            links = []

            for listing in listings:

                try:

                    link = listing.get_attribute("href")

                    if (
                        link
                        and link not in visited_links
                    ):

                        links.append(link)

                        visited_links.add(link)

                except:
                    pass

            print(f"Collected {len(links)} links")


            for index, link in enumerate(links):

                try:

                    print(
                        f"{district} | "
                        f"{index+1}/{len(links)}"
                    )

                    driver.get(link)

                    time.sleep(
                        random.uniform(2, 4)
                    )

                    data = extract_school_data()

                    if data:

                        data["District"] = district

                        data["Search Type"] = search_type

                        all_data.append(data)

                        print(data["Hospital Name"])


                    if len(all_data) % 100 == 0:

                        backup_df = pd.DataFrame(
                            all_data
                        )

                        backup_df.drop_duplicates(
                            subset=[
                                "Hospital Name",
                                "Google Maps URL"
                            ],
                            inplace=True
                        )

                        backup_filename = (
                            "punjab_backup.csv"
                        )

                        backup_df.to_csv(
                            backup_filename,
                            index=False
                        )

                        print("Backup Saved")

                except Exception as e:

                    print(
                        f"School Error: {e}"
                    )

        except Exception as e:

            print(
                f"District Error: {e}"
            )


df = pd.DataFrame(all_data)

df.drop_duplicates(

    subset=[
        "Hospital Name",
        "Google Maps URL"
    ],

    inplace=True
)


filename = (
    "punjab_hospitals.csv"
)

df.to_csv(
    filename,
    index=False
)

print("\nExtraction Completed")

print(
    f"Total Hospitals Extracted: {len(df)}"
)

print(f"\nSaved File: {filename}")

driver.quit()
# Out:
# Opening Google Maps...
# Google Maps Loaded
#
# Searching: hospitals in Amritsar Punjab
# Search Submitted
# Amritsar | hospitals | Scroll 1 -> 14
# Amritsar | hospitals | Scroll 2 -> 20
# Amritsar | hospitals | Scroll 3 -> 27
# Amritsar | hospitals | Scroll 4 -> 34
# Amritsar | hospitals | Scroll 5 -> 40
# Amritsar | hospitals | Scroll 6 -> 47
# Amritsar | hospitals | Scroll 7 -> 54
# Amritsar | hospitals | Scroll 8 -> 60
# Amritsar | hospitals | Scroll 9 -> 67
# Amritsar | hospitals | Scroll 10 -> 70
# Amritsar | hospitals | Scroll 11 -> 70
# Amritsar | hospitals | Scroll 12 -> 70
# Amritsar | hospitals | Scroll 13 -> 70
# Amritsar | hospitals | Scroll 14 -> 70
# Collected 70 links
# Amritsar | 1/70
# EMC Super Speciality Hospital, Amritsar | Best Hospital in Amritsar
# Amritsar | 2/70
# Fortis Escorts Hospital, Amritsar - Best Hospital in Amritsar
# Amritsar | 3/70
# Amandeep Multispeciality Medicity, Amritsar | Best Hospital in Amritsar
# Amritsar | 4/70
# Amandeep Super Speciality Hospital, Amritsar | Best Hospital in Amritsar, Punjab
# Amritsar | 5/70
# Livasa Hospital Amritsar
# Amritsar | 6/70
# Akashdeep Hospital
# Amritsar | 7/70
# Ranjit hospital - Multispeciality & Orthopedic Hospital in Amritsar
# Amritsar | 8/70
# Altec Hospital
# Amritsar | 9/70
# Sukh Sagar Hospital
# Amritsar | 10/70
# Pulse Hospital (A unit of EMC Hospitals)
# Amritsar | 11/70
# Apex Hospital
# Amritsar | 12/70
# Smt. Paarvati Devi Hospital
# Amritsar | 13/70
# Florem Hospital
# Amritsar | 14/70
# Randhawa Hospital
# Amritsar | 15/70
# Grace Super Speciality Hospital I Children's Hospital in Amritsar
# Amritsar | 16/70
# Nayyar Hospital
# Amritsar | 17/70
# 𝐌𝐞𝐝𝐢𝐜𝐀𝐢𝐝 Hospital & Critical Care Center In Amritsar
# Amritsar | 18/70
# Dukh Niwaran Hospital | Best Hospital for Ortho | Neuro | Poison | Accident | Critical Care | Hip Replacement in Amritsar
# Amritsar | 19/70
# Guru Nanak Dev Hospital, Amritsar
# Amritsar | 20/70
# Hartej Hospital
# Amritsar | 21/70
# Surjit Hospital
# Amritsar | 22/70
# Apollo Cradle & Children's Hospital in Amritsar
# Amritsar | 23/70
# New Life Hospital
# Amritsar | 24/70
# Dr. Adarsh Heart & Superspeciality Hospital
# Amritsar | 25/70
# Mahajan Hospital
# Amritsar | 26/70
# Jallianwala Bagh Martyr's Memorial Civil Hospital
# Amritsar | 27/70
# Ajit Hospital
# Amritsar | 28/70
# The Shiva Neuro & Multispeciality Centre
# Amritsar | 29/70
# Gupta Hospital
# Amritsar | 30/70
# NOVA MEDICITY HOSPITAL - Best Heart Care Cardiology Centre |Best Critical Care Centre in Amritsar
# Amritsar | 31/70
# Dhaliwal Hospital | Best Surgery Superspeciality Centre
# Amritsar | 32/70
# Sareen Hospital
# Amritsar | 33/70
# SIFTI HOSPITAL
# Amritsar | 34/70
# Mokha Hospital
# Amritsar | 35/70
# Care & Cure Medicity Hospital
# Amritsar | 36/70
# Dr. Punj's Hospital
# Amritsar | 37/70
# Mundh Hospital
# Amritsar | 38/70
# Adlakha Hospital
# Amritsar | 39/70
# Pasricha Medicare Centre
# Amritsar | 40/70
# Biala Orthopaedic Hospital
# Amritsar | 41/70
# Dr. KARAM SINGH MEMORIAL MULTISPECIALITY HOSPITAL
# Amritsar | 42/70
# Dhingra Hospital
# Amritsar | 43/70
# Nulife Hospital
# Amritsar | 44/70
# Swift Hospital
# Amritsar | 45/70
# Sandhu Lifecare Hospital
# Amritsar | 46/70
# ESI Hospital
# Amritsar | 47/70
# Life Kare Hospital
# Amritsar | 48/70
# Nirmal Swami Hospital,Amritsar
# Amritsar | 49/70
# Medicaid Hospital
# Amritsar | 50/70
# ENT Hospital
# Amritsar | 51/70
# Bhandari Ear,Nose and Throat Hospital
# Amritsar | 52/70
# Nirmaljot Eye Hospital - Eye Hospital in amritsar
# Amritsar | 53/70
# Nanda Hospital
# Amritsar | 54/70
# Gupta Multispeciality Hospital- General and laparoscopic Surgery, Urology, Obstetrics and Gynaecology and other fields.
# Amritsar | 55/70
# PARVEEN SAINI ROBOTIC BEST KNEE ,HIP & SHOULDER ADVANCED AI ORTHOPAEDIC & ARTHROSCOPIC CENTER
# Amritsar | 56/70
# CHC Majitha
# Amritsar | 57/70
# Dhruv Nursing & Maternity Home
# Amritsar | 58/70
# Gupta multispeciality hospital
# Amritsar | 59/70
# Dr. Daljit Singh Eye Hospital Amritsar
# Amritsar | 60/70
# Lifeline Hospital
# Amritsar | 61/70
# Dr. Bajwa's BIRINDER HOSPITAL & MATERNITY CENTRE
# Amritsar | 62/70
# Bhatia Neuropsychiatric Hospital
# Amritsar | 63/70
# EMC Hospital
# Amritsar | 64/70
# Dr. Kunal Mahajan Children Hospital
# Amritsar | 65/70
# Institute Of Mental Health (Government Mental Hospital)
# Amritsar | 66/70
# Bakhshish Medical Care Hospital
# Amritsar | 67/70
# Swami Hospital
# Amritsar | 68/70
# Darshan Charitable Hospital
# Amritsar | 69/70
# NA
# Amritsar | 70/70
# District Hospital, Amritsar
#
# Searching: hospitals in Barnala Punjab
# Search Submitted
# Barnala | hospitals | Scroll 1 -> 14
# Barnala | hospitals | Scroll 2 -> 20
# Barnala | hospitals | Scroll 3 -> 25
# Barnala | hospitals | Scroll 4 -> 25
# Barnala | hospitals | Scroll 5 -> 25
# Barnala | hospitals | Scroll 6 -> 25
# Barnala | hospitals | Scroll 7 -> 25
# Collected 25 links
# Barnala | 1/25
# BMC Superspeciality Hospital Barnala
# Barnala | 2/25
# Guru Nanak Manorog Hospital
# Barnala | 3/25
# Sanjivani Hospital
# Barnala | 4/25
# Tathgur Hospital Psychiatry & E.N.T Specialist
# Barnala | 5/25
# Lifeline Multispeciality Hospital
# Barnala | 6/25
# Deep Nursing Home - Best Children Hospital in Barnala, Best Pediatrician in Barnala, Child Specialist in Barnala
# Barnala | 7/25
# Sidana Hospital
# Barnala | 8/25
# Manodisha Hospital - Consultant Dr. Himanshu Singla
# Barnala | 9/25
# Sidhu Hospital, Barnala
# Barnala | 10/25
# Bhim Nursing Home
# Barnala | 11/25
# Punjab Eye Hospital, a unit of Dr Agarwals Eye Hospital
# Barnala | 12/25
# Prem eye & maternity hospital
# Barnala | 13/25
# Dr. Pardeep Sharma Multispeciality Hospital
# Barnala | 14/25
# Singla Hospital
# Barnala | 15/25
# PABBY HOSPITAL
# Barnala | 16/25
# Civil Hospital.
# Barnala | 17/25
# ST Hospital & Critical Care Centre
# Barnala | 18/25
# Barnala Manorog Hospital
# Barnala | 19/25
# Sandhu Nursing Home & Surgical Centre-LAPAROSCOPIC Surgery/Nursing Home/General Surgeon/Gynaecologist/
# Barnala | 20/25
# Sood Nursing Home
# Barnala | 21/25
# Grover Ent And Allergy Hospital
# Barnala | 22/25
# Aastha Hospital
# Barnala | 23/25
# Noor Multispeciality Hospital
# Barnala | 24/25
# J K Dental Hospital ( Orthodontic & Multispeciality care )
# Barnala | 25/25
# Dr. Hans Raj Multispeciality Hospital
# Ferozepur | 21/24
# ✅𝗦𝗦𝗞 𝗡𝗲𝘂𝗿𝗼 𝗣𝘀𝘆𝗰𝗵𝗶𝗮𝘁𝗿𝘆 𝗛𝗼𝘀𝗽𝗶𝘁𝗮𝗹 - Neuro Psychiatrist| Mind Doctor| Best Brain Doctor| Psychiatrist Hospital in Ferozepur Cantt
# Ferozepur | 22/24
# GURMAT HOSPITAL
# Ferozepur | 23/24
# Global Hospital Zira
# Ferozepur | 24/24
# Asija Eye And Child Care
#
# Searching: hospitals in Gurdaspur Punjab
# Search Submitted
# Gurdaspur | hospitals | Scroll 1 -> 14
# Gurdaspur | hospitals | Scroll 2 -> 20
# Gurdaspur | hospitals | Scroll 3 -> 27
# Gurdaspur | hospitals | Scroll 4 -> 28
# Gurdaspur | hospitals | Scroll 5 -> 28
# Gurdaspur | hospitals | Scroll 6 -> 28
# Gurdaspur | hospitals | Scroll 7 -> 28
# Gurdaspur | hospitals | Scroll 8 -> 28
# Collected 28 links
# Gurdaspur | 1/28
# Abrol Hospital (A Unit of EMC Hospitals)
# Gurdaspur | 2/28
# Gurdaspur Medicity | A multi super speciality hospital
# Gurdaspur | 3/28
# City Hospital (A Unit Of EMC Hospitals)
# Gurdaspur | 4/28
# SRSM Babbar Multispeciality Hospital- Best Multispeciality Hospital in Gurdaspur
# Gurdaspur | 5/28
# DEOL MULTI-SPECIALITY HOSPITAL
# Gurdaspur | 6/28
# Simran Hospital ( Best Orthopaedic Hospital In Gurdaspur )
# Gurdaspur | 7/28
# MAHAJAN HOSPITAL AND EYE CARE CENTRE
# Gurdaspur | 8/28
# Mahajan Children Hospital - Gurdaspur
# Gurdaspur | 9/28
# Sukhmani Surgical Hospital-Best Orthopedics Hospital in Gurdaspur/Surgical & Gynae/Spine Care & Trauma Centre/Skin Specialist
# Gurdaspur | 10/28
# RP Arora Hospital medicity
# Gurdaspur | 11/28
# Deep Multispeciality Hospital
# Gurdaspur | 12/28
# S.S. MEMORIAL LAKHANPAL HOSPITAL
# Gurdaspur | 13/28
# Civil Hospital
# Gurdaspur | 14/28
# Badwal hospital
# Gurdaspur | 15/28
# JC NANDA HOSPITAL
# Gurdaspur | 16/28
# Civil Hospital Gurdaspur
# Gurdaspur | 17/28
# Mehak Hospital - Best Gynae and Surgery & Infertility Centre In Gurdaspur Punjab India
# Gurdaspur | 18/28
# Babbar Multi Speciality Hospital
# Gurdaspur | 19/28
# Dr. Kashyap ENT Hospital
# Gurdaspur | 20/28
# Arora Hospital
# Gurdaspur | 21/28
# Jyoti Parkash Eye & IVF Hospital Gurdaspur
# Gurdaspur | 22/28
# Kaushal Hospital
# Gurdaspur | 23/28
# 𝗞𝗮𝗹𝗲𝗿 𝗛𝗼𝘀𝗽𝗶𝘁𝗮𝗹 - Laparoscopy Surgery/Heart/Diabetes/Best Gynae/Best Gynaecologist Gurdaspur
# Gurdaspur | 24/28
# Kohli Hospital (A Unit of EMC Hospitals) - Best Hospital in Dhariwal
# Gurdaspur | 25/28
# Ummeed Neuro Psychiatric And De- addiction speciality Hospital-Counseling Therapy Hospital in Gurdaspur
# Gurdaspur | 26/28
# Bahri Hospital
# Gurdaspur | 27/28
# Saini Hospital
# Gurdaspur | 28/28
# GURDASPUR MEDICITY PHYSIOTHERAPY CENTRE
#
# Searching: hospitals in Hoshiarpur Punjab
# Search Submitted
# Hoshiarpur | hospitals | Scroll 1 -> 14
# Hoshiarpur | hospitals | Scroll 2 -> 20
# Hoshiarpur | hospitals | Scroll 3 -> 27
# Hoshiarpur | hospitals | Scroll 4 -> 34
# Hoshiarpur | hospitals | Scroll 5 -> 40
# Hoshiarpur | hospitals | Scroll 6 -> 40
# Hoshiarpur | hospitals | Scroll 7 -> 40
# Hoshiarpur | hospitals | Scroll 8 -> 40
# Hoshiarpur | hospitals | Scroll 9 -> 40
# Collected 40 links
# Hoshiarpur | 1/40
# Livasa Hospital Hoshiarpur
# Hoshiarpur | 2/40
# Narad Hospital
# Hoshiarpur | 3/40
# Shivam Hospital
# Hoshiarpur | 4/40
# Kanwar Multi-Speciality Hospital, GuruNanak Avenue, Hoshiarpur - Best Hospital in the city
# Hoshiarpur | 5/40
# Gurukirpa Multispeciality Hospital - General Surgery/Hospital/Best Multispecialty hospital/Best Hospital in Hoshiarpur
# Hoshiarpur | 6/40
# BALI HOSPITAL
# Hoshiarpur | 7/40
# Gur Simran Hospital
# Hoshiarpur | 8/40
# Civil Hospital Hoshiarpur
# Hoshiarpur | 9/40
# St Joseph's Hospital - Specialist in snake bite
# Hoshiarpur | 10/40
# PRKM Modern Hospital
# Hoshiarpur | 11/40
# Hoshiarpur Nursing Home
# Hoshiarpur | 12/40
# Gur Charan Kanwal Hospital
# Hoshiarpur | 13/40
# RRM CENTRAL HOSPITAL
# Hoshiarpur | 14/40
# CHILDCARE HOSPITAL- BEST CHILDREN HOSPITAL
# Hoshiarpur | 15/40
# Saini Hospital & Test Tube Baby Centre
# Hoshiarpur | 16/40
# 𝗞𝗮𝗽𝗶𝗹𝗮 𝗛𝗼𝘀𝗽𝗶𝘁𝗮𝗹 - Child specialist in Hoshiarpur/Punjab/Pediatrician in Hoshiarpur/Vaccination in Hoshiarpur
# Hoshiarpur | 17/40
# Parmanand Hospital
# Hoshiarpur | 18/40
# DEEPAK HOSPITAL (Family Care since 1992)
# Hoshiarpur | 19/40
# 𝗕𝗵𝗮𝗿𝗮𝗷 𝗟𝗶𝗳𝗲 𝗖𝗮𝗿𝗲 𝗛𝗼𝘀𝗽𝗶𝘁𝗮𝗹 & 𝗧𝗿𝗮𝘂𝗺𝗮 𝗖𝗲𝗻𝘁𝗿𝗲-Orthopaedics Hospital/Joint replacement surgery/Sports Injury & Spine Surgery
# Hoshiarpur | 20/40
# Aman Hospital
# Hoshiarpur | 21/40
# Universal Hospital and Trauma Center { Dr. Navdeep Bains- Orthopedic surgeon}
# Hoshiarpur | 22/40
# Nova Hospital Hoshiarpur
# Kapurthala | 13/23
# 𝗦𝗮𝗵𝗮𝗿𝗮 𝗦𝘂𝗿𝗴𝗶𝗰𝗮𝗹 & 𝗠𝗮𝘁𝗲𝗿𝗻𝗶𝘁𝘆 𝗛𝗼𝗺𝗲-Endoscopic Surgeon| Gynae Hospital| Laser and General Laparoscopic surgeon in Kapurthala
# Kapurthala | 14/23
# District Hospital Kapurthala, Punjab
# Kapurthala | 15/23
# JP Nursing Home Orthopedic & Surgical Centre
# Kapurthala | 16/23
# Blue Hospital
# Kapurthala | 17/23
# momi children and general hospital
# Kapurthala | 18/23
# Dogra Eye Hospital
# Kapurthala | 19/23
# Dasmesh hospital
# Kapurthala | 20/23
# Gupta Maternity Hospital
# Kapurthala | 21/23
# Govt Hospital Kapurthla
# Kapurthala | 22/23
# Dhawan Eye & General Hospital
# Kapurthala | 23/23
# BV/84 Old Hospital Kapurthala
#
# Searching: hospitals in Ludhiana Punjab
# Search Submitted
# Ludhiana | hospitals | Scroll 1 -> 14
# Ludhiana | hospitals | Scroll 2 -> 20
# Ludhiana | hospitals | Scroll 3 -> 27
# Ludhiana | hospitals | Scroll 4 -> 34
# Ludhiana | hospitals | Scroll 5 -> 40
# Ludhiana | hospitals | Scroll 6 -> 47
# Ludhiana | hospitals | Scroll 7 -> 54
# Ludhiana | hospitals | Scroll 8 -> 56
# Ludhiana | hospitals | Scroll 9 -> 56
# Ludhiana | hospitals | Scroll 10 -> 56
# Ludhiana | hospitals | Scroll 11 -> 56
# Ludhiana | hospitals | Scroll 12 -> 56
# Collected 56 links
# Ludhiana | 1/56
# Fortis Hospital Mall Road Ludhiana - Best Hospital in Ludhiana
# Ludhiana | 2/56
# Fortis Hospital Ludhiana - Best Hospital in Ludhiana
# Ludhiana | 3/56
# Satguru Partap Singh (SPS) Hospital
# Ludhiana | 4/56
# Pancham Hospital - Best Heart Hospital in Ludhiana | Cardiologist Hospital | Heart Specialist Doctor | Gynaecologist Hospital
# Ludhiana | 5/56
# Deep Hospital
# Ludhiana | 6/56
# MASSH PROLIFE Hospitals Ludhiana
# Ludhiana | 7/56
# Raman Multi Speciality Hospital
# Ludhiana | 8/56
# 𝗟𝗶𝗳𝗲 𝗟𝗶𝗻𝗲 𝗛𝗼𝘀𝗽𝗶𝘁𝗮l - Best Hospital in Ludhiana | Paramedical Institute | Gastroentrologist | pediatrician
# Ludhiana | 9/56
# Healthmax Multispecialty Hospital – Medical, Surgical & Gynae Obstetrics Centre in Ludhiana
# Ludhiana | 10/56
# SATYAM HOSPITAL - Best Pregnancy Care & Children Hospital in Ludhiana
# Ludhiana | 11/56
# Civil Hospital Ludhiana
# Ludhiana | 12/56
# Shilpy Hospital
# Ludhiana | 13/56
# DMC Hospital ludhiana
# Ludhiana | 14/56
# Mediways Hospital Ludhiana
# Ludhiana | 15/56
# Suman Hospital Multi-Specialty Hospital in Ludhiana
# Ludhiana | 16/56
# Bawa Hospital Private Limited
# Ludhiana | 17/56
# Global Heart & Super Speciality Hospital
# Malerkotla | hospitals | Scroll 4 -> 34
# Malerkotla | hospitals | Scroll 5 -> 36
# Malerkotla | hospitals | Scroll 6 -> 36
# Malerkotla | hospitals | Scroll 7 -> 36
# Malerkotla | hospitals | Scroll 8 -> 36
# Malerkotla | hospitals | Scroll 9 -> 36
# Collected 36 links
# Malerkotla | 1/36
# Gulzar Hospital - Best Hospital in Malerkotla
# Malerkotla | 2/36
# Gurprem hospital
# Malerkotla | 3/36
# Karanvir Maternity and Infertility Hospital Pvt Ltd
# Malerkotla | 4/36
# 𝗦𝗶𝗻𝗴𝗹𝗮 𝗛𝗼𝘀𝗽𝗶𝘁𝗮𝗹 𝗠𝗮𝗹𝗲𝗿𝗸𝗼𝘁𝗹𝗮 -Best hospital in Malerkotla /Best orthopedic/Gynaecologist/Gynae hospital in malerkotla
# Malerkotla | 5/36
# Hazrat Haleema Hospital
# Malerkotla | 6/36
# Birring Multispeciality Hospital
# Malerkotla | 7/36
# Patiala Hospital - Child Specialist in Malerkotla
# Malerkotla | 8/36
# Civil Hospital
# Malerkotla | 9/36
# AL-DUA HOSPITAL
# Malerkotla | 10/36
# Gurmukh Hospital
# Malerkotla | 11/36
# SALIM ORTHOPEDIC AND GENERAL HOSPITAL
# Malerkotla | 12/36
# ABHISHEK HOSPITAL
# Malerkotla | 13/36
# Al-Hayat Hospital
# Malerkotla | 14/36
# Ambala Eye Hospital - Best Eye Hospital in Malerkotla
# Malerkotla | 15/36
# Gurvinder Hospital
# Malerkotla | 16/36
# Pehalwan Hospital
# Malerkotla | 17/36
# Dr Karnail Hospital
# Malerkotla | 18/36
# Kakkar Hospital
# Malerkotla | 19/36
# Malerkotla Medicity Hospital
# Malerkotla | 20/36
# malerkotla psychaitry hospital and de addiction centre
# Malerkotla | 21/36
# Dr. Charanjit Hospital
# Malerkotla | 22/36
# N.S. Memorial Hospital, Malerkotla (PB)
# Malerkotla | 23/36
# Subhan Hospital Malerkotla
# Malerkotla | 24/36
# SARAO CHILDREN HOSPITAL
# Malerkotla | 25/36
# Nizam Bone & Joint Hospital
# Malerkotla | 26/36
# 𝘽𝙝𝙖𝙧𝙩𝙞 𝙃𝙤𝙨𝙥𝙞𝙩𝙖𝙡-Best Children Hospital/Child Care Hospital/Pediatrician/Child Specialist
# Malerkotla | 27/36
# DAV hospital (Dr. Das hospital)
# Malerkotla | 28/36
# MALERKOTLA HOSPITAL
# Malerkotla | 29/36
# Khan Hospital
# Malerkotla | 30/36
# Rattan Hospital
# Malerkotla | 31/36
# Public Hospital
# Malerkotla | 32/36
# DR SHABBIR'S ADVANCE DIAGNOSTIC AND SCAN CENTRE
# Backup Saved
# Malerkotla | 33/36
# 𝗛𝗜𝗡𝗗 𝗠𝗨𝗟𝗧𝗜𝗦𝗣𝗘𝗖𝗜𝗔𝗟𝗜𝗧𝗬 𝗛𝗢𝗦𝗣𝗜𝗧𝗔𝗟 - Gynecologist in Ahmedgarh/Pediatrician/Multispeciality Hospitals in Malerkotla
# Malerkotla | 34/36
# malerkotla hospital (Dr boota)
# Malerkotla | 35/36
# Umeed Multi-Speciality Hospital
# Malerkotla | 36/36
# Satinder kamal hospital
#
# Searching: hospitals in Mansa Punjab
# Search Submitted
# Mansa | hospitals | Scroll 1 -> 14
# Mansa | hospitals | Scroll 2 -> 20
# Mansa | hospitals | Scroll 3 -> 27
# Mansa | hospitals | Scroll 4 -> 27
# Mansa | hospitals | Scroll 5 -> 27
# Mansa | hospitals | Scroll 6 -> 27
# Mansa | hospitals | Scroll 7 -> 27
# Collected 27 links
# Mansa | 1/27
# 𝗞𝘂𝗹𝘄𝗮𝗻𝘁 𝗡𝘂𝗿𝘀𝗶𝗻𝗴 𝗛𝗼𝗺𝗲, Mansa
# Mansa | 2/27
# Bansal Hospital & Nursing Home
# Mansa | 3/27
# District Hospital Mansa
# Mansa | 4/27
# Raikhy Nursing Home - Cashless Hospital in Mansa
# Mansa | 5/27
# Dr. Vivek Heart & Multispeciality Hospital
# Mansa | 6/27
# Singhal Stars Hospital
# Mansa | 7/27
# Brar Hospital
# Mansa | 8/27
# Deepika Maternity Center & Hospital, Mansa
# Mansa | 9/27
# Ankush Hospital
# Mansa | 10/27
# Mansa Medicity
# Mansa | 11/27
# Maan Hospital Mansa
# Mansa | 12/27
# K.P. Hospital Mansa
# Mansa | 13/27
# Janak Raj Hospital
# Mansa | 14/27
# Domeli Hospital and surgical centre
# Mansa | 15/27
# Guru Nanak Hospital
# Mansa | 16/27
# Guru Nanak Mission Hospital
# Mansa | 17/27
# Dr. Rajneesh Sidhu Child Care Hospital
# Mansa | 18/27
# JIWAN HOSPITAL MULTISPECIALITY & DIALYSIS CENTRE MANSA
# Mansa | 19/27
# Jindal Ortho Care Hospital
# Mansa | 20/27
# Singla Hospital & Dialysis Center
# Mansa | 21/27
# Katodia Children Hospital
# Mansa | 22/27
# Pankaj Nursing Home
# Mansa | 23/27
# Dr Parshotam Goyal Skin And Eye Clinic
# Mansa | 24/27
# Hospital
# Mansa | 25/27
# Sanjeevni Hospital
# Mansa | 26/27
# Advanced Eye Care Center
# Mansa | 27/27
# Orthopedic Dr manav jindal
#
# Searching: hospitals in Moga Punjab
# Search Submitted
# Moga | hospitals | Scroll 1 -> 14
# Moga | hospitals | Scroll 2 -> 20
# Moga | hospitals | Scroll 3 -> 23
# Moga | hospitals | Scroll 4 -> 23
# Moga | hospitals | Scroll 5 -> 23
# Moga | hospitals | Scroll 6 -> 23
# Moga | hospitals | Scroll 7 -> 23
# Collected 23 links
# Moga | 1/23
# Gomti Thapar Hospital - Ivf Centre in Moga/ Kidney & Urine Problem Hospital in Moga
# Moga | 2/23
# G.S. Memorial Prem Hospital Moga - Orthopedics/General Surgery/Psychiatry/General Medicine/X-ray/Physiotherapy/ICU in Moga
# Moga | 3/23
# 𝗠𝗢𝗚𝗔 𝗠𝗘𝗗𝗜𝗖𝗜𝗧𝗬 𝗦𝗨𝗣𝗘𝗥𝗦𝗣𝗘𝗖𝗜𝗔𝗟𝗧𝗬 𝗛𝗢𝗦𝗣𝗜𝗧𝗔𝗟
# Civil Hospital Mohali
# Mohali | 20/31
# Healing Hospital - Best Hospital in Chandigarh
# Mohali | 21/31
# Kamboj Multi-Speciality Hospital | Best Hospital in Kharar | Maternity Hospital in Kharar
# Mohali | 22/31
# MAX MedCenter
# Mohali | 23/31
# Shivalik Hospital
# Mohali | 24/31
# ACE Heart & Vascular Institute
# Mohali | 25/31
# Civil Hospital
# Mohali | 26/31
# Fortis Medcentre Hospital in Chandigarh, Punjab - Best Hospital in Chandigarh
# Mohali | 27/31
# Amcare Hospital - Hospitals in Zirakpur
# Mohali | 28/31
# Chhabra Hospital is Open
# Mohali | 29/31
# Bahra Hospital
# Mohali | 30/31
# Kaushal Hospital
# Mohali | 31/31
# Sharma Multispeciality Hospital
#
# Searching: hospitals in Muktsar Punjab
# Search Submitted
# Muktsar | hospitals | Scroll 1 -> 14
# Muktsar | hospitals | Scroll 2 -> 20
# Muktsar | hospitals | Scroll 3 -> 27
# Muktsar | hospitals | Scroll 4 -> 28
# Muktsar | hospitals | Scroll 5 -> 28
# Muktsar | hospitals | Scroll 6 -> 28
# Muktsar | hospitals | Scroll 7 -> 28
# Muktsar | hospitals | Scroll 8 -> 28
# Collected 28 links
# Muktsar | 1/28
# Aashirwad Hospital
# Muktsar | 2/28
# MUKTSAR MEDICITY HOSPITAL - DR. BALDEV RAJ HOSPITAL
# Muktsar | 3/28
# Usha Bansal Nursing Home - Best Hospital|Best Urology|Laparoscopic|Obs & Gynae|Joint Replacement Center in Sri Muktsar Sahib
# Muktsar | 4/28
# Sandhu hospital
# Muktsar | 5/28
# Bhullar multispeciality hospital
# Muktsar | 6/28
# Civil Hospital
# Muktsar | 7/28
# Wadhwa Ortho Hospital
# Muktsar | 8/28
# New Delhi Hospital & Nursing Home
# Muktsar | 9/28
# Ludhiana Child Hospital Mukatsar
# Muktsar | 10/28
# Immaculate Mission Hospital
# Muktsar | 11/28
# New Shyam Narayan Hospital and Adishakti IVF center
# Muktsar | 12/28
# Malwa Ortho Hospital- Best Ortho Hospital/Best Ortho Surgeon/Best Knee replacement Surgeon in Muktsar
# Muktsar | 13/28
# Guru Nanak Hospital
# Muktsar | 14/28
# Anand Hospital - Best Multispeciality Hospital | General & Laparoscopic Surgical Centre
# Muktsar | 15/28
# Araadh Hospital
# Backup Saved
# Muktsar | 16/28
# Kamara Hospital
# Muktsar | 17/28
# Darshan Memorial Ortho and General Hospital
# Muktsar | 18/28
# Jindal Hospital and Heart Centre
# Muktsar | 19/28
# Madho Hospital
# Muktsar | 20/28
# Bharti Hospital
# Muktsar | 21/28
# Atulaya Healthcare
# Muktsar | 22/28
# Sri Muktsar Sahib
# Muktsar | 23/28
# District Hospital Muktsar Sahib, Punjab
# Muktsar | 24/28
# Goyal Hospital
# Muktsar | 25/28
# Platinum Nursing Home
# Muktsar | 26/28
# Usha Bansal Nursing Home Pvt Ltd
# Muktsar | 27/28
# ਪਟਿਆਲਾ ਅੱਖਾਂ ਦਾ ਹਸਪਤਾਲ Patiala Eyes Hospital
# Muktsar | 28/28
# Aman Hospital muktsar
#
# Searching: hospitals in Pathankot Punjab
# Search Submitted
# Pathankot | hospitals | Scroll 1 -> 14
# Pathankot | hospitals | Scroll 2 -> 20
# Pathankot | hospitals | Scroll 3 -> 27
# Pathankot | hospitals | Scroll 4 -> 34
# Pathankot | hospitals | Scroll 5 -> 40
# Pathankot | hospitals | Scroll 6 -> 47
# Pathankot | hospitals | Scroll 7 -> 50
# Pathankot | hospitals | Scroll 8 -> 50
# Pathankot | hospitals | Scroll 9 -> 50
# Pathankot | hospitals | Scroll 10 -> 50
# Pathankot | hospitals | Scroll 11 -> 50
# Collected 50 links
# Pathankot | 1/50
# Amandeep Hospital | Best Hospital in Pathankot
# Pathankot | 2/50
# Raj Hospital
# Pathankot | 3/50
# Navchetan Multispeciality Hospital
# Pathankot | 4/50
# S.K.R Hospital & Trauma Center Private Limited
# Pathankot | 5/50
# Randhawa Hospital
# Pathankot | 6/50
# Galaxy Hospital - Urologist/Gastroenterologist/Stone disease Hospital in Pathankot
# Pathankot | 7/50
# Sukh Sadan Hospital & Trauma Centre
# Pathankot | 8/50
# Shri Parbodh Chander District Hospital
# Pathankot | 9/50
# Aarogya Hospital - Trauma and Lifecare center
# Pathankot | 10/50
# Chikitsa Multispeciality Hospital Pvt. Ltd.
# Pathankot | 11/50
# North Central Hospital
# Pathankot | 12/50
# Salhotra Healthcare Pvt Ltd Multispeciality Hospital & Trauma Centre
# Pathankot | 13/50
# Mahajan Medicity
# Pathankot | 14/50
# Mission Hospital
# Pathankot | 15/50
# Military Hospital
# Pathankot | 16/50
# Kalyani Hospital
# Pathankot | 17/50
# Ajay Heart Care & Multispecialty Hospital
# Pathankot | 18/50
# Gandotra Hospital
# Pathankot | 19/50
# Oberoi Nursing Home & Surgical Center
# Pathankot | 20/50
# Max Care Hospital
# Pathankot | 21/50
# Sri Sai Hospital
# Pathankot | 22/50
# Randeep Multi Speciality Hospital
# Pathankot | 23/50
# Bhinder Hospital
# Pathankot | 24/50
#
# Pathankot | 25/50
# Pathankot Kidney Hospital & Stone Clinic
# Pathankot | 26/50
# Satyam Hospital
# Pathankot | 27/50
# Shiv Vardaan Hospital
# Pathankot | 28/50
# Arya Hospital
# Pathankot | 29/50
# Chaitanya Hospital
# Pathankot | 30/50
# Thakur Heal Care Hospital
# Pathankot | 31/50
# Kukreja Hospital
# Pathankot | 32/50
# Sri Nangali Hospital
# Pathankot | 33/50
# Chauhan Medicity
# Pathankot | 34/50
# PMC Hospital | A Unit of EMC Hospitals
# Pathankot | 35/50
# Raswan Surgical Neuro Spine Hospital
# Pathankot | 36/50
# Balaji Hospital - Laparoscopic Surgery, Kidney & Dialysis Centre
# Pathankot | 37/50
# Dr. K.D Eye Hospital & Lasik Centre
# Pathankot | 38/50
# Tilak Hospital
# Pathankot | 39/50
# Ghai Nursing Home
# Pathankot | 40/50
# Dr. Surjit Singh Eye Hospital
# Pathankot | 41/50
# Dr. Rajpal's Neuro-Psychiatric & De-Addiction Hospital
# Pathankot | 42/50
# Sukiran ENT Hospital
# Pathankot | 43/50
# Mahavir Medical Mission
# Pathankot | 44/50
# Gupta ENT Hospital
# Pathankot | 45/50
# Civil hospital pathankot milk bar
# Pathankot | 46/50
# Saini Eye Hospital
# Pathankot | 47/50
# Dr. Beena Misra Nursing Home & Skin Laser Centre
# Pathankot | 48/50
# Northern Railway Health Unit Grade I
# Pathankot | 49/50
# Dr. Baldev Raj
# Pathankot | 50/50
# Mahesh Mahajan Hospital
#
# Searching: hospitals in Patiala Punjab
# Search Submitted
# Patiala | hospitals | Scroll 1 -> 14
# Patiala | hospitals | Scroll 2 -> 20
# Patiala | hospitals | Scroll 3 -> 27
# Patiala | hospitals | Scroll 4 -> 34
# Patiala | hospitals | Scroll 5 -> 34
# Patiala | hospitals | Scroll 6 -> 34
# Patiala | hospitals | Scroll 7 -> 34
# Patiala | hospitals | Scroll 8 -> 34
# Collected 33 links
# Patiala | 1/33
# Manipal Hospitals, Patiala
# Patiala | 2/33
# Amar Hospital Patiala
# Patiala | 3/33
# Park Hospital Patiala
# Patiala | 4/33
# Prime Multispeciality Hospital & Trauma Centre
# Patiala | 5/33
# Gurmeet Multispeciality Hospital in Patiala | Quality Healthcare Services
# Patiala | 6/33
# Rajindra Hospital Patiala
# Patiala | 7/33
# Patiala Heart Institute and Multispeciality Hospital
# Patiala | 8/33
# Phull Neuro And Multispeciality Hospital - Neurologist/Stroke Specialist/Brain Specialist/Best Trauma Centre in Patiala
# Patiala | 9/33
# Jeevan Multispeciality Hospital and Trauma Centre
# Patiala | 10/33
# Bhatia Hospital Neuro and Multispeciality
# Patiala | 11/33
# Nitin Hospital
# Patiala | 12/33
# Mata Kaushalya Hospital
# Patiala | 13/33
# Sant Clinic & Maternity Home & Child Care Hospital
# Patiala | 14/33
# SP Hospital by Dr.Surinder Pal Singh
# Patiala | 15/33
# A.P Healthcare & Trauma Centre
# Patiala | 16/33
# Mehar Hospital
# Patiala | 17/33
# Garg Mission Hospital
# Patiala | 18/33
# Aggarwal Hospital
# Patiala | 19/33
# Dr.Ajmer Singh Hospital
# Patiala | 20/33
# T.B Hospital
# Patiala | 21/33
# GUPTA HOSPITAL
# Patiala | 22/33
# Gursharan Hospital
# Patiala | 23/33
# Aggarsain Hospital Patiala
# Patiala | 24/33
# Patiala Hospital
# Patiala | 25/33
# 𝗘𝘅𝗰𝗲𝗹 𝗛𝗲𝗮𝗹𝘁𝗵 𝗖𝗮𝗿𝗲
# Patiala | 26/33
# Healthy Baby (A Multispecialty Hospital)
# Patiala | 27/33
# Bansal Eye Hospital And Laser Centre - Eye Care Center in Patiala
# Patiala | 28/33
# Rama Atray Memorial Eye Hospital
# Patiala | 29/33
# Garg Eye Hospital | Best LASIK Laser Eye Surgery | Best Cataract Surgery | Patiala
# Patiala | 30/33
# Anand Ayurvedic Hospital
# Patiala | 31/33
# Simran E.N.T Hospital
# Patiala | 32/33
# Brain Hospital
# Patiala | 33/33
# District Hospital, Patiala
#
# Searching: hospitals in Rupnagar Punjab
# Search Submitted
# Rupnagar | hospitals | Scroll 1 -> 14
# Rupnagar | hospitals | Scroll 2 -> 20
# Rupnagar | hospitals | Scroll 3 -> 21
# Rupnagar | hospitals | Scroll 4 -> 21
# Rupnagar | hospitals | Scroll 5 -> 21
# Rupnagar | hospitals | Scroll 6 -> 21
# Rupnagar | hospitals | Scroll 7 -> 21
# Collected 21 links
# Rupnagar | 1/21
# Sangha Multispeciality Hospital
# Rupnagar | 2/21
# 𝗕𝗶𝗷𝗲𝗻𝗱𝗿𝗮 𝗠𝘂𝗹𝘁𝗶 𝗦𝗽𝗲𝗰𝗶𝗮𝗹𝗶𝘁𝘆 𝗛𝗼𝘀𝗽𝗶𝘁𝗮𝗹-Best Trauma Centre in Ropar-Best Gynaecology Doctor in Ropar/Best Neuro Surgeon in Ropar
# Rupnagar | 3/21
# Civil Hospital
# Rupnagar | 4/21
# Aggarwal Hospital
# Backup Saved
# Rupnagar | 5/21
# SND Foundation Hospital - Best Hospital | T.M.T Test in Ropar
# Rupnagar | 6/21
# Baweja Multispeciality Hospital:Neuro Psychiatry/Skin & Cosmetology/Gynecology/Eye & Lasik Specialty Hospital In Rupnagar
# Rupnagar | 7/21
# Dr Surjit Singh Super Speciality Hospital - ORTHOPAEDICS/ NEUROSURGERY/ GYNAECOLOGY/ GENERAL SURGERY/ DERMATOLOGY
# Rupnagar | 8/21
# District Hospital Rupnagar, Punjab
# Rupnagar | 9/21
# PARMAR HOSPITAL
# Rupnagar | 10/21
# 𝐃𝐚𝐬𝐦𝐞𝐬𝐡 Healthcare 𝗛𝗼𝘀𝗽𝗶𝘁𝗮𝗹 𝐑𝐨𝐩𝐚𝐫 - Best Hospital in Ropar | ECHS Hospital in Ropar
# Rupnagar | 11/21
# Divanta Heart Centre & Superspeciality Hospital
# Rupnagar | 12/21
# Pannu Eye Hospital
# Rupnagar | 13/21
# Gill Hospital Ropar
# Rupnagar | 14/21
# Prime Hospital
# Rupnagar | 15/21
# Sadiq Hospital
# Rupnagar | 16/21
# LAUNGIA DENTAL HOSPITAL
# Rupnagar | 17/21
# Chandigarh Hospital
# Rupnagar | 18/21
# SHARMA EYE HOSPITAL & LASER CENTRE
# Rupnagar | 19/21
# SD Multispeciality health care hospital
# Rupnagar | 20/21
# Gurdev Hospital - Super Speciality Hospital
# Rupnagar | 21/21
# Grewal Cure Centre
#
# Searching: hospitals in Sangrur Punjab
# Search Submitted
# Sangrur | hospitals | Scroll 1 -> 14
# Sangrur | hospitals | Scroll 2 -> 20
# Sangrur | hospitals | Scroll 3 -> 20
# Sangrur | hospitals | Scroll 4 -> 20
# Sangrur | hospitals | Scroll 5 -> 20
# Sangrur | hospitals | Scroll 6 -> 20
# Collected 19 links
# Sangrur | 1/19
# SANGRUR MEDICITY HOSPITAL
# Sangrur | 2/19
# Delhi Multispeciality Hospital
# Sangrur | 3/19
# Kansal Hospital
# Sangrur | 4/19
# Professor R D Aggarwal Memorial Hospital
# Sangrur | 5/19
# Sibia Healthcare Pvt Ltd - Best Multispecialty Hospital/General and Laparoscopic Surgeries/Urology/Cardiology in Sangrur
# Sangrur | 6/19
# Civil Hospital, Sangrur
# Sangrur | 7/19
# Mittal Health Care Multispeciality Hospital & Blood Centre
# Sangrur | 8/19
# Bansal Hospital & Heart Centre/Laparoscopic Surgeon/Internal Medical Specialist/Gynaecologist/Multispeciality Hospital
# Sangrur | 9/19
# Sukhmani Healthcare
# Sangrur | 10/19
# Singla Surgical Hospital
# Sangrur | 11/19
# Karuna Neuro Psychiatry Hospital
# Sangrur | 12/19
# Sodhi Eye Hospital (Dr Sodhi Eye Hospital)
# Sangrur | 13/19
# Mittal Eye Hospital - Eye hospital in Sangrur
# Sangrur | 14/19
# Dr D P Singla Child Hospital
# Sangrur | 15/19
# Raikhy Maternity & Ortho-paedic Centre
# Sangrur | 16/19
#
# Sangrur | 17/19
# Kashmiri Hospital
# Sangrur | 18/19
# Civil Surgeon Office
# Sangrur | 19/19
# S M O Health Centre
#
# Searching: hospitals in Shaheed Bhagat Singh Nagar Punjab
# Search Submitted
# Shaheed Bhagat Singh Nagar | hospitals | Scroll 1 -> 14
# Shaheed Bhagat Singh Nagar | hospitals | Scroll 2 -> 20
# Shaheed Bhagat Singh Nagar | hospitals | Scroll 3 -> 27
# Shaheed Bhagat Singh Nagar | hospitals | Scroll 4 -> 34
# Shaheed Bhagat Singh Nagar | hospitals | Scroll 5 -> 40
# Shaheed Bhagat Singh Nagar | hospitals | Scroll 6 -> 47
# Shaheed Bhagat Singh Nagar | hospitals | Scroll 7 -> 54
# Shaheed Bhagat Singh Nagar | hospitals | Scroll 8 -> 60
# Shaheed Bhagat Singh Nagar | hospitals | Scroll 9 -> 67
# Shaheed Bhagat Singh Nagar | hospitals | Scroll 10 -> 69
# Shaheed Bhagat Singh Nagar | hospitals | Scroll 11 -> 69
# Shaheed Bhagat Singh Nagar | hospitals | Scroll 12 -> 69
# Shaheed Bhagat Singh Nagar | hospitals | Scroll 13 -> 69
# Shaheed Bhagat Singh Nagar | hospitals | Scroll 14 -> 69
# Collected 54 links
# Shaheed Bhagat Singh Nagar | 1/54
# Civil Hospital Nawanshahr
# Shaheed Bhagat Singh Nagar | 2/54
# Ivy Hospital Nawanshahr
# Shaheed Bhagat Singh Nagar | 3/54
# Raja Hospital | Nawanshahr (Punjab)
# Shaheed Bhagat Singh Nagar | 4/54
# S.L. Hospital
# Shaheed Bhagat Singh Nagar | 5/54
# Livasa Hospital Nawanshahr
# Shaheed Bhagat Singh Nagar | 6/54
# CareVista Hospital
# Shaheed Bhagat Singh Nagar | 7/54
# Pahwa multi-speciality Hospital Nawanshahr
# Shaheed Bhagat Singh Nagar | 8/54
# 𝗥𝗔𝗝𝗣𝗔𝗟 𝗛𝗢𝗦𝗣𝗜𝗧𝗔𝗟
# Shaheed Bhagat Singh Nagar | 45/54
# MAAN & ARORA HOSPITAL ( Dr Karan Arora): Best Neonatologist | Best Child Specialist Hospital | Best Pediatrics in Nawanshahr
# Shaheed Bhagat Singh Nagar | 46/54
# Hansraj charitable hospital
# Shaheed Bhagat Singh Nagar | 47/54
# Shri Guru Ramdas Charitable Hospital Banga
# Shaheed Bhagat Singh Nagar | 48/54
# Parveen clinic and Nursing home
# Shaheed Bhagat Singh Nagar | 49/54
# SAAOL Heart Center Nawanshahr
# Shaheed Bhagat Singh Nagar | 50/54
# NARINDERA HOSPITAL. GENERAL HOSPITAL AND MATERNITY HOME
# Shaheed Bhagat Singh Nagar | 51/54
# Community Health Centre
# Shaheed Bhagat Singh Nagar | 52/54
# Blood Bank Raja Hospital Nawanshahr
# Shaheed Bhagat Singh Nagar | 53/54
# Civil Hospital
# Shaheed Bhagat Singh Nagar | 54/54
# Balbir Healthcare Clinic
#
# Searching: hospitals in Tarn Taran Punjab
# Search Submitted
# Tarn Taran | hospitals | Scroll 1 -> 14
# Tarn Taran | hospitals | Scroll 2 -> 20
# Tarn Taran | hospitals | Scroll 3 -> 24
# Tarn Taran | hospitals | Scroll 4 -> 24
# Tarn Taran | hospitals | Scroll 5 -> 24
# Tarn Taran | hospitals | Scroll 6 -> 24
# Tarn Taran | hospitals | Scroll 7 -> 24
# Collected 24 links
# Tarn Taran | 1/24
# Amandeep Kamal | Best Hospital in Tarn Taran
# Tarn Taran | 2/24
# Guru Nanak Dev Super Speciality Hospital
# Tarn Taran | 3/24
# Civil Hospital
# Tarn Taran | 4/24
# City Hospital
# Tarn Taran | 5/24
# Preet Hospital - Best General Surgery Hospital in Tarn Taran
# Tarn Taran | 6/24
# Gupta Nursing Home
# Tarn Taran | 7/24
# Arjun Hospital
# Tarn Taran | 8/24
# NEW LIFE HOSPITAL
# Tarn Taran | 9/24
# Aulakh Hospital
# Tarn Taran | 10/24
# Cherish Children Hospital - Newborn ICU/ Child Specialist/ICU for Premature New Born/Best Child Care Hospital in Tarn Taran
# Backup Saved
# Tarn Taran | 11/24
# MITTAL HOSPITAL
# Tarn Taran | 12/24
# District Hospital, TaranTaran
# Tarn Taran | 13/24
# Satkartar Hospital : Best Hospital in Goindwal Sahib | Best Hospital in Tarn Taran
# Tarn Taran | 14/24
# Sahib nursing home
# Tarn Taran | 15/24
# Dr. Rajneesh Medicare Heart Centre-Best Hospital/Heart Center in Taran Taran
# Tarn Taran | 16/24
# Harsukhman Hospital
# Tarn Taran | 17/24
# Sandhu Hospital
# Tarn Taran | 18/24
# Nav Medicity Hospital
# Tarn Taran | 19/24
# Government Hospital
# Tarn Taran | 20/24
# Khushman hospital
# Tarn Taran | 21/24
# Sukhman hospital
# Tarn Taran | 22/24
# CHHIBBER HEALTH CARE CENTRE
# Tarn Taran | 23/24
# S B S Memorial General and eye hospital
# Tarn Taran | 24/24
# y hospital
#
# Extraction Completed
# Total Hospitals Extracted: 814
#
# Saved File: punjab_hospitals.csv
