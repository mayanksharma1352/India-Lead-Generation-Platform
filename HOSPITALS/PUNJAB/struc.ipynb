# %%
import pandas as pd

# %%
df = pd.read_csv("punjab_hospitals.csv")

# %%
df.shape
# Out:
# (814, 8)

# %%
df = df[
    df["Phone"].notna() & 
    (df["Phone"].astype(str).str.strip() != "")
    ]
df.shape
# Out:
# (644, 8)

# %%
df = df[
    df["Hospital Name"].notna()
    ]

df = df[
    df["Hospital Name"].str.strip() != ""
    ]
df.shape
# Out:
# (642, 8)

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]","",regex=True)
    .str.strip()
)

display(df[["Phone"]].head())
# Out:
#           Phone
# 1  081461 61008
# 2  075270 00036
# 3  075270 00036
# 4  080788 80788
# 5  085910 18820

# %%
df.to_csv(
    "punjab_hospitals_cleaned.csv",
    index=False
)
