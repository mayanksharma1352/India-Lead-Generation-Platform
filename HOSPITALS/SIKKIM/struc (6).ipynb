# %%
import pandas as pd

# %%
df = pd.read_csv("sikkim_hospitals.csv")

# %%
df.shape
# Out:
# (28, 8)

# %%
df = df[
    df["Phone"].notna() &
    (df["Phone"].astype(str).str.strip() != "")
]

# %%
df.shape
# Out:
# (11, 8)

# %%
df = df[
    df["Hospital Name"].notna()
]

df = df[
    df["Hospital Name"].str.strip() != ""
]

# %%
df.shape
# Out:
# (11, 8)

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]", "", regex=True)  # remove symbols/icons
    .str.strip()
)

display(df[["Phone"]].head())
# Out:
#            Phone
# 0  1800 120 2114
# 1   092393 91085
# 3  03592 204 876
# 5   098323 76307
# 7   088044 24922

# %%
df.to_csv(
    "sikkim_hospitals_cleaned.csv",
    index=False
)
