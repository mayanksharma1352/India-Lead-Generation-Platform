# %%
import time
import random
import pandas as pd

from datetime import datetime

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.service import Service

from webdriver_manager.chrome import ChromeDriverManager


districts = [

    "Gangtok",
    "Gyalshing",
    "Mangan",
    "Namchi",
    "Pakyong",
    "Soreng"

]


search_types = [
    "hospitals"
]


options = webdriver.ChromeOptions()

options.add_argument("--start-maximized")

options.add_argument(
    "--disable-blink-features=AutomationControlled"
)

options.add_argument("--disable-notifications")



driver = webdriver.Chrome(

    service=Service(
        ChromeDriverManager().install()
    ),

    options=options
)



driver.get("https://www.google.com/maps")

print("Opening Google Maps...")

time.sleep(15)

print("Google Maps Loaded")


all_data = []

visited_links = set()


def get_search_box():

    selectors = [

        '//input[@id="searchboxinput"]',
        '//input[contains(@placeholder,"Search")]',
        '//input[contains(@aria-label,"Search")]',
        '//input'

    ]

    for selector in selectors:

        try:

            box = driver.find_element(
                By.XPATH,
                selector
            )

            return box

        except:
            pass

    return None


def extract_school_data():

    try:

        try:
            name = driver.find_element(
                By.TAG_NAME,
                "h1"
            ).text
        except:
            name = ""

        try:
            address = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"address")]'
            ).text
        except:
            address = ""

 
        try:
            phone = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"phone")]'
            ).text
        except:
            phone = ""

    
        try:
            website = driver.find_element(
                By.XPATH,
                '//a[contains(@data-item-id,"authority")]'
            ).get_attribute("href")
        except:
            website = ""

        # RATING
        try:
            rating = driver.find_element(
                By.XPATH,
                '//div[@role="img"]'
            ).get_attribute("aria-label")
        except:
            rating = ""

        return {

            "Hospital Name": name,
            "Address": address,
            "Phone": phone,
            "Website": website,
            "Rating": rating,
            "Google Maps URL": driver.current_url

        }

    except:

        return None



for district in districts:

    for search_type in search_types:

        try:

            query = (
                f"{search_type} "
                f"in {district} Sikkim"
            )

            print(f"\nSearching: {query}")


            search_box = get_search_box()

            if not search_box:

                print("Search Box Not Found")

                continue

            ActionChains(driver).move_to_element(
                search_box
            ).click().perform()

            time.sleep(1)

            search_box.send_keys(
                Keys.CONTROL + "a"
            )

            time.sleep(1)

            search_box.send_keys(Keys.DELETE)

            time.sleep(1)

   
            for char in query:

                search_box.send_keys(char)

                time.sleep(0.03)

            search_box.send_keys(Keys.ENTER)

            print("Search Submitted")

            time.sleep(8)

      

            try:

                scrollable_div = driver.find_element(
                    By.XPATH,
                    '//div[@role="feed"]'
                )

                previous_count = 0

                stagnant = 0

                for i in range(100):

                    driver.execute_script(
                        """
                        arguments[0].scrollTop =
                        arguments[0].scrollHeight
                        """,
                        scrollable_div
                    )

      
                    time.sleep(4)

                    listings = driver.find_elements(
                        By.XPATH,
                        '//a[contains(@href,"/maps/place/")]'
                    )

                    current_count = len(listings)

                    print(
                        f"{district} | "
                        f"{search_type} | "
                        f"Scroll {i+1} -> "
                        f"{current_count}"
                    )

                    if current_count == previous_count:

                        stagnant += 1

                    else:

                        stagnant = 0

            
                    if stagnant >= 4:

                        break

                    previous_count = current_count

            except Exception as e:

                print(f"Scrolling Error: {e}")



            listings = driver.find_elements(
                By.XPATH,
                '//a[contains(@href,"/maps/place/")]'
            )

            links = []

            for listing in listings:

                try:

                    link = listing.get_attribute("href")

                    if (
                        link
                        and link not in visited_links
                    ):

                        links.append(link)

                        visited_links.add(link)

                except:
                    pass

            print(f"Collected {len(links)} links")

    

            for index, link in enumerate(links):

                try:

                    print(
                        f"{district} | "
                        f"{index+1}/{len(links)}"
                    )

                    driver.get(link)

                    time.sleep(
                        random.uniform(2, 4)
                    )

                    data = extract_school_data()

                    if data:

                        data["District"] = district

                        data["Search Type"] = search_type

                        all_data.append(data)

                        print(data["Hospital Name"])


                    if len(all_data) % 100 == 0:

                        backup_df = pd.DataFrame(
                            all_data
                        )

                        backup_df.drop_duplicates(
                            subset=[
                                "Hospital Name",
                                "Google Maps URL"
                            ],
                            inplace=True
                        )

                        backup_filename = (
                            "sikkim_backup.csv"
                        )

                        backup_df.to_csv(
                            backup_filename,
                            index=False
                        )

                        print("Backup Saved")

                except Exception as e:

                    print(
                        f"School Error: {e}"
                    )

        except Exception as e:

            print(
                f"District Error: {e}"
            )


df = pd.DataFrame(all_data)

df.drop_duplicates(

    subset=[
        "Hospital Name",
        "Google Maps URL"
    ],

    inplace=True
)



filename = (
    "sikkim_hospitals.csv"
)

df.to_csv(
    filename,
    index=False
)

print("\nExtraction Completed")

print(
    f"Total Schools Extracted: {len(df)}"
)

print(f"\nSaved File: {filename}")

driver.quit()
# Out:
# Opening Google Maps...
# Google Maps Loaded
#
# Searching: hospitals in Gangtok Sikkim
# Search Submitted
# Gangtok | hospitals | Scroll 1 -> 5
# Gangtok | hospitals | Scroll 2 -> 5
# Gangtok | hospitals | Scroll 3 -> 5
# Gangtok | hospitals | Scroll 4 -> 5
# Gangtok | hospitals | Scroll 5 -> 5
# Collected 5 links
# Gangtok | 1/5
# Central Referral Hospital
# Gangtok | 2/5
# STNM Hospital
# Gangtok | 3/5
# New STNM Multispeciality Hospital
# Gangtok | 4/5
# Ruchi Diagnostic Clinic
# Gangtok | 5/5
# CGHS Gangtok
#
# Searching: hospitals in Gyalshing Sikkim
# Search Submitted
# Gyalshing | hospitals | Scroll 1 -> 3
# Gyalshing | hospitals | Scroll 2 -> 3
# Gyalshing | hospitals | Scroll 3 -> 3
# Gyalshing | hospitals | Scroll 4 -> 3
# Gyalshing | hospitals | Scroll 5 -> 3
# Collected 3 links
# Gyalshing | 1/3
# District Hospital Gyalshing
# Gyalshing | 2/3
# AYUSH HOSPITAL KYONGSHA GYALSHING WEST SIKKIM
# Gyalshing | 3/3
# Human Health Care Center Gayzing
#
# Searching: hospitals in Mangan Sikkim
# Search Submitted
# Scrolling Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@role="feed"]"}
#   (Session info: chrome=148.0.7778.167); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 	chromedriver!GetHandleVerifier [0x10d7123+10a23]
# 	chromedriver!GetHandleVerifier [0x10d7254+10b54]
# 	chromedriver!(No symbol) [0xef1e90]
# 	chromedriver!(No symbol) [0xf3b28a]
# 	chromedriver!(No symbol) [0xf3b52b]
# 	chromedriver!(No symbol) [0xf7d062]
# 	chromedriver!(No symbol) [0xf5d7d4]
# 	chromedriver!(No symbol) [0xf7a936]
# 	chromedriver!(No symbol) [0xf5d526]
# 	chromedriver!(No symbol) [0xf308f9]
# 	chromedriver!(No symbol) [0xf316b4]
# 	chromedriver!GetHandleVerifier [0x1371ac4+2ab3c4]
# 	chromedriver!GetHandleVerifier [0x136d0ed+2a69ed]
# 	chromedriver!GetHandleVerifier [0x138e4f5+2c7df5]
# 	chromedriver!GetHandleVerifier [0x10f1128+2aa28]
# 	chromedriver!GetHandleVerifier [0x10f8bbd+324bd]
# 	chromedriver!GetHandleVerifier [0x10dfb28+19428]
# 	chromedriver!GetHandleVerifier [0x10dfcd5+195d5]
# 	chromedriver!GetHandleVerifier [0x10c91cf+2acf]
# 	KERNEL32!BaseThreadInitThunk [0x75defcc9+19]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x779982ae+11e]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x7799827e+ee]
#
# Collected 0 links
#
# Searching: hospitals in Namchi Sikkim
# Search Submitted
# Namchi | hospitals | Scroll 1 -> 9
# Namchi | hospitals | Scroll 2 -> 9
# Namchi | hospitals | Scroll 3 -> 9
# Namchi | hospitals | Scroll 4 -> 9
# Namchi | hospitals | Scroll 5 -> 9
# Collected 8 links
# Namchi | 1/8
# District Hospital Namchi
# Namchi | 2/8
# 500 BEDDED DISTRICT HOSPITAL
# Namchi | 3/8
# Namchi Health Clinic
# Namchi | 4/8
# Anukul Diagnostic Centre
# Namchi | 5/8
# Sister and Sisters Diagnostic centre Namchi
# Namchi | 6/8
# District Hospital Singtam
# Namchi | 7/8
# Denzong Healthcare
# Namchi | 8/8
# HWC Boomtar Namchi
#
# Searching: hospitals in Pakyong Sikkim
# Search Submitted
# Pakyong | hospitals | Scroll 1 -> 11
# Pakyong | hospitals | Scroll 2 -> 11
# Pakyong | hospitals | Scroll 3 -> 11
# Pakyong | hospitals | Scroll 4 -> 11
# Pakyong | hospitals | Scroll 5 -> 11
# Collected 8 links
# Pakyong | 1/8
# Pakyong District Hospital (site)
# Pakyong | 2/8
# Pakyong Primary Health Center
# Pakyong | 3/8
# Pakyong diagnostic centre
# Pakyong | 4/8
# NewLife clinic and diagnostics
# Pakyong | 5/8
# NEW ZION MM MEMORIAL DIAGNOSTIC LAB
# Pakyong | 6/8
# MedX Pharmacy and Greenfield diagnostic(medical shop ,diagnostic and clinic)
# Pakyong | 7/8
# AG MEDICAL SHOP
# Pakyong | 8/8
# Pakyong District veterinary hospital
#
# Searching: hospitals in Soreng Sikkim
# Search Submitted
# Soreng | hospitals | Scroll 1 -> 4
# Soreng | hospitals | Scroll 2 -> 4
# Soreng | hospitals | Scroll 3 -> 4
# Soreng | hospitals | Scroll 4 -> 4
# Soreng | hospitals | Scroll 5 -> 4
# Collected 4 links
# Soreng | 1/4
# District Hospital, Soreng
# Soreng | 2/4
# soreng phc
# Soreng | 3/4
# New Sikkim Diagnostic Center
# Soreng | 4/4
# Ayurvedic Health Center
#
# Extraction Completed
# Total Schools Extracted: 28
#
# Saved File: sikkim_hospitals.csv
