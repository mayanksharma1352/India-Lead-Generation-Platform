# %%
import time
import random
import pandas as pd

from datetime import datetime

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.service import Service

from webdriver_manager.chrome import ChromeDriverManager



districts = [
    "Bilaspur",
    "Chamba",
    "Hamirpur",
    "Kangra",
    "Kinnaur",
    "Kullu",
    "Lahaul and Spiti",
    "Mandi",
    "Shimla",
    "Sirmaur",
    "Solan",
    "Una"
]
 

search_types = [
    "hospitals"
]


options = webdriver.ChromeOptions()

options.add_argument("--start-maximized")

options.add_argument(
    "--disable-blink-features=AutomationControlled"
)

options.add_argument("--disable-notifications")


driver = webdriver.Chrome(

    service=Service(
        ChromeDriverManager().install()
    ),

    options=options
)


driver.get("https://www.google.com/maps")

print("Opening Google Maps...")

time.sleep(15)

print("Google Maps Loaded")


all_data = []

visited_links = set()


def get_search_box():

    selectors = [

        '//input[@id="searchboxinput"]',
        '//input[contains(@placeholder,"Search")]',
        '//input[contains(@aria-label,"Search")]',
        '//input'

    ]

    for selector in selectors:

        try:

            box = driver.find_element(
                By.XPATH,
                selector
            )

            return box

        except:
            pass

    return None


def extract_school_data():

    try:

        try:
            name = driver.find_element(
                By.TAG_NAME,
                "h1"
            ).text
        except:
            name = ""

        try:
            address = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"address")]'
            ).text
        except:
            address = ""

        try:
            phone = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"phone")]'
            ).text
        except:
            phone = ""

        try:
            website = driver.find_element(
                By.XPATH,
                '//a[contains(@data-item-id,"authority")]'
            ).get_attribute("href")
        except:
            website = ""

        try:
            rating = driver.find_element(
                By.XPATH,
                '//div[@role="img"]'
            ).get_attribute("aria-label")
        except:
            rating = ""

        return {

            "Hospital Name": name,
            "Address": address,
            "Phone": phone,
            "Website": website,
            "Rating": rating,
            "Google Maps URL": driver.current_url

        }

    except:

        return None


for district in districts:

    for search_type in search_types:

        try:

            query = (
                f"{search_type} "
                f"in {district} Himachal Pradesh"
            )

            print(f"\nSearching: {query}")


            search_box = get_search_box()

            if not search_box:

                print("Search Box Not Found")

                continue

            ActionChains(driver).move_to_element(
                search_box
            ).click().perform()

            time.sleep(1)

            search_box.send_keys(
                Keys.CONTROL + "a"
            )

            time.sleep(1)

            search_box.send_keys(Keys.DELETE)

            time.sleep(1)

            # TYPE SLOWLY
            for char in query:

                search_box.send_keys(char)

                time.sleep(0.03)

            search_box.send_keys(Keys.ENTER)

            print("Search Submitted")

            time.sleep(8)


            try:

                scrollable_div = driver.find_element(
                    By.XPATH,
                    '//div[@role="feed"]'
                )

                previous_count = 0

                stagnant = 0

                for i in range(100):

                    driver.execute_script(
                        """
                        arguments[0].scrollTop =
                        arguments[0].scrollHeight
                        """,
                        scrollable_div
                    )

                    time.sleep(4)

                    listings = driver.find_elements(
                        By.XPATH,
                        '//a[contains(@href,"/maps/place/")]'
                    )

                    current_count = len(listings)

                    print(
                        f"{district} | "
                        f"{search_type} | "
                        f"Scroll {i+1} -> "
                        f"{current_count}"
                    )

                    if current_count == previous_count:

                        stagnant += 1

                    else:

                        stagnant = 0

                    if stagnant >= 4:

                        break

                    previous_count = current_count

            except Exception as e:

                print(f"Scrolling Error: {e}")

            listings = driver.find_elements(
                By.XPATH,
                '//a[contains(@href,"/maps/place/")]'
            )

            links = []

            for listing in listings:

                try:

                    link = listing.get_attribute("href")

                    if (
                        link
                        and link not in visited_links
                    ):

                        links.append(link)

                        visited_links.add(link)

                except:
                    pass

            print(f"Collected {len(links)} links")

            for index, link in enumerate(links):

                try:

                    print(
                        f"{district} | "
                        f"{index+1}/{len(links)}"
                    )

                    driver.get(link)

                    time.sleep(
                        random.uniform(2, 4)
                    )

                    data = extract_school_data()

                    if data:

                        data["District"] = district

                        data["Search Type"] = search_type

                        all_data.append(data)

                        print(data["Hospital Name"])


                    if len(all_data) % 100 == 0:

                        backup_df = pd.DataFrame(
                            all_data
                        )

                        backup_df.drop_duplicates(
                            subset=[
                                "Hospital Name",
                                "Google Maps URL"
                            ],
                            inplace=True
                        )

                        backup_filename = (
                            "himachal_pradesh_backup.csv"
                        )

                        backup_df.to_csv(
                            backup_filename,
                            index=False
                        )

                        print("Backup Saved")

                except Exception as e:

                    print(
                        f"School Error: {e}"
                    )

        except Exception as e:

            print(
                f"District Error: {e}"
            )


df = pd.DataFrame(all_data)

df.drop_duplicates(

    subset=[
        "Hospital Name",
        "Google Maps URL"
    ],

    inplace=True
)


filename = (
    "himachal_pradesh_hospitals.csv"
)

df.to_csv(
    filename,
    index=False
)

print("\nExtraction Completed")

print(
    f"Total Hospitals Extracted: {len(df)}"
)

print(f"\nSaved File: {filename}")

driver.quit()
# Out:
# Opening Google Maps...
# Google Maps Loaded
#
# Searching: hospitals in Bilaspur Himachal Pradesh
# Search Submitted
# Bilaspur | hospitals | Scroll 1 -> 14
# Bilaspur | hospitals | Scroll 2 -> 19
# Bilaspur | hospitals | Scroll 3 -> 19
# Bilaspur | hospitals | Scroll 4 -> 19
# Bilaspur | hospitals | Scroll 5 -> 19
# Bilaspur | hospitals | Scroll 6 -> 19
# Collected 19 links
# Bilaspur | 1/19
# N.R. Hospital
# Bilaspur | 2/19
# Vyas Hospital-a unit of Sonjay Hospitals Private Limited
# Bilaspur | 3/19
# Anant Hospital
# Bilaspur | 4/19
# Regional Hospital Bilaspur
# Bilaspur | 5/19
# Sia Ram Hospital
# Bilaspur | 6/19
# Sehgal hospital | Dental Clinic
# Bilaspur | 7/19
# Pulse Hospital
# Bilaspur | 8/19
# AIIMS Bilaspur OPD
# Bilaspur | 9/19
# AIIMS Bilaspur
# Bilaspur | 10/19
# Bilaspur Medical Centre
# Bilaspur | 11/19
# Kamakshi Hospital
# Bilaspur | 12/19
# Civil Hospital Ghumarwin
# Bilaspur | 13/19
# Apollo Hospitals | Best Hospital in Bilaspur
# Bilaspur | 14/19
# ACC HOSPITAL
# Bilaspur | 15/19
# PREET EYE HOSPITAL
# Bilaspur | 16/19
# Apna Hospital
# Bilaspur | 17/19
# Sehgal hospital
# Bilaspur | 18/19
# A. H. W. C Bum ghumarwin Disst Bilaspur
# Bilaspur | 19/19
# Taskar - India's 1st Healthcare Mall
#
# Searching: hospitals in Chamba Himachal Pradesh
# Search Submitted
# Chamba | hospitals | Scroll 1 -> 10
# Chamba | hospitals | Scroll 2 -> 10
# Chamba | hospitals | Scroll 3 -> 10
# Chamba | hospitals | Scroll 4 -> 10
# Chamba | hospitals | Scroll 5 -> 10
# Collected 10 links
# Chamba | 1/10
# Satyam Hospital
# Chamba | 2/10
# Rana Hospital
# Chamba | 3/10
# Sukhmani Hospital
# Chamba | 4/10
# Swami Shri Hari Giri Hospital Cum Research Center
# Chamba | 5/10
# Pt. jawaharlal nehru govt medical college and hospital
# Chamba | 6/10
# Regional 24 HOURS hospital
# Chamba | 7/10
# NHPC Chamera 2 Hospital
# Chamba | 8/10
# Hospital
# Chamba | 9/10
# Chief Medical Officer Office
# Chamba | 10/10
# Pandit Jawahar Lal Nehru Govt Medical College Chamba
#
# Searching: hospitals in Hamirpur Himachal Pradesh
# Search Submitted
# Hamirpur | hospitals | Scroll 1 -> 14
# Hamirpur | hospitals | Scroll 2 -> 20
# Hamirpur | hospitals | Scroll 3 -> 21
# Hamirpur | hospitals | Scroll 4 -> 21
# Hamirpur | hospitals | Scroll 5 -> 21
# Hamirpur | hospitals | Scroll 6 -> 21
# Hamirpur | hospitals | Scroll 7 -> 21
# Collected 21 links
# Hamirpur | 1/21
# City Hospital Hamirpur - Best Surgeon Hospital in Hamirpur| Best Laparoscopic Hospital in Hamirpur
# Hamirpur | 2/21
# Sai Hospital & IVF Center
# Hamirpur | 3/21
#
# Hamirpur | 4/21
# Hamir Hospital
# Hamirpur | 5/21
# Bhandari Hospital
# Hamirpur | 6/21
# Dr. A.S.Thakur Memorial Multispeciality Hospital Hamirpur
# Hamirpur | 7/21
#
# Hamirpur | 8/21
# Glodha Hospital
# Hamirpur | 9/21
# Cityheart Superspeciality Hospital
# Hamirpur | 10/21
# Dr Satish - The Children's Hospital In Hamirpur
# Hamirpur | 11/21
# Krishana Hospital
# Hamirpur | 12/21
# param hospital barsar
# Hamirpur | 13/21
# AWAHDEVI MULTISPECIALITY HOSPITAL
# Hamirpur | 14/21
# Regional Ayurvedic Hospital Hamirpur
# Hamirpur | 15/21
# RGG Ayurvedic Hospital Hamirpur
# Hamirpur | 16/21
# DR Arvind Sharma - Hamir Hospital Hamirpur/Hospital In Hamirpur
# Hamirpur | 17/21
# Parvati Hospital
# Hamirpur | 18/21
# Ayushman hospital
# Hamirpur | 19/21
# Civil Hospital
# Hamirpur | 20/21
# Civil Hospital, Bhoranj
# Hamirpur | 21/21
# Thakur nursing home Hamirpur
#
# Searching: hospitals in Kangra Himachal Pradesh
# Search Submitted
# Kangra | hospitals | Scroll 1 -> 9
# Kangra | hospitals | Scroll 2 -> 9
# Kangra | hospitals | Scroll 3 -> 9
# Kangra | hospitals | Scroll 4 -> 9
# Kangra | hospitals | Scroll 5 -> 9
# Collected 9 links
# Kangra | 1/9
# Fortis Hospital, Kangra - Best Hospital in Kangra
# Kangra | 2/9
# Shree Balaji Hospital
# Kangra | 3/9
# Motherkraft hospital
# Kangra | 4/9
# City Superspeciality Hospital
# Kangra | 5/9
# Dr Neena Pahwa Hospital
# Kangra | 6/9
# S.M. Eye Hospital (Ghurkari- Kangra)
# Kangra | 7/9
# Civil hospital kangra
# Kangra | 8/9
# Kangra Valley Hospital
# Kangra | 9/9
# Maple Leaf Hospital, Kangra
#
# Searching: hospitals in Kinnaur Himachal Pradesh
# Search Submitted
# Kinnaur | hospitals | Scroll 1 -> 9
# Kinnaur | hospitals | Scroll 2 -> 9
# Kinnaur | hospitals | Scroll 3 -> 9
# Kinnaur | hospitals | Scroll 4 -> 9
# Kinnaur | hospitals | Scroll 5 -> 9
# Collected 9 links
# Kinnaur | 1/9
# Regional Hospital
# Kinnaur | 2/9
# Jindal Sanjeevani Hospital
# Kinnaur | 3/9
# District ayurvedic hospital
# Kinnaur | 4/9
# Shrikhand Hospital
# Kinnaur | 5/9
# Life Line Clinic , Dr. Santosh Negi
# Kinnaur | 6/9
# Reckong Peo Regional Hospital
# Kinnaur | 7/9
# C.H.C. Hospital Pooh
# Kinnaur | 8/9
# Mediwin Hospital Rohru
# Kinnaur | 9/9
# Health Post
#
# Searching: hospitals in Kullu Himachal Pradesh
# Search Submitted
# Kullu | hospitals | Scroll 1 -> 13
# Kullu | hospitals | Scroll 2 -> 13
# Kullu | hospitals | Scroll 3 -> 13
# Kullu | hospitals | Scroll 4 -> 13
# Kullu | hospitals | Scroll 5 -> 13
# Collected 13 links
# Kullu | 1/13
# Kullu Valley Hospital
# Kullu | 2/13
# Raghunath Hospital
# Kullu | 3/13
# Bhanoo Hospital
# Kullu | 4/13
# Regional Hospital Kullu
# Kullu | 5/13
# kullu valley banga diagnostics
# Kullu | 6/13
# Getwell Hospital & Advanced Endoscopy Centre-Private Hospital/Lab/Endoscopy Centre/Diabetes Doctor
# Kullu | 7/13
# City Hospital
# Kullu | 8/13
# Sri Harihar Hospital
# Kullu | 9/13
# Civil Hospital Kullu
# Kullu | 10/13
# ब्यास हस्पताल
# Kullu | 11/13
# Life Line Care Hospital & Dialysis Centre (nephroplus dialysis centre)
# Kullu | 12/13
# District Ayurvedic Hospital Kullu
# Kullu | 13/13
# Viva Care Hospital
#
# Searching: hospitals in Lahaul and Spiti Himachal Pradesh
# Search Submitted
# Lahaul and Spiti | hospitals | Scroll 1 -> 14
# Lahaul and Spiti | hospitals | Scroll 2 -> 20
# Lahaul and Spiti | hospitals | Scroll 3 -> 24
# Lahaul and Spiti | hospitals | Scroll 4 -> 24
# Lahaul and Spiti | hospitals | Scroll 5 -> 24
# Lahaul and Spiti | hospitals | Scroll 6 -> 24
# Lahaul and Spiti | hospitals | Scroll 7 -> 24
# Collected 17 links
# Lahaul and Spiti | 1/17
# COMMUNITY HEALTH CENTRE, KAZA
# Lahaul and Spiti | 2/17
# Lady Willingdon Hospital (Mission Hospital)
# Lahaul and Spiti | 3/17
# True Care Hospital
# Lahaul and Spiti | 4/17
# Capt Saurabh Kalia Memorial KayDee Hospital
# Lahaul and Spiti | 5/17
# Community Health Centre
# Lahaul and Spiti | 6/17
# Ayurvedic Hospital
# Lahaul and Spiti | 7/17
# RH Keylong
# Lahaul and Spiti | 8/17
# City hospital
# Lahaul and Spiti | 9/17
# Ayurvedic Hospital
# Lahaul and Spiti | 10/17
# Sri Harihar Hospital Pvt. Ltd
# Lahaul and Spiti | 11/17
# Karan Hospital
# Lahaul and Spiti | 12/17
# Mannat Hospital - Institute of Endoscopic & Minimal Invasive Spine Surgery
# Lahaul and Spiti | 13/17
# Aastha Multispeciality Hospital
# Lahaul and Spiti | 14/17
# CIVIL HOSPITAL PALAMPUR
# Lahaul and Spiti | 15/17
# Civil Hospital, Nurpur
# Lahaul and Spiti | 16/17
# Neelkanth Hospital
# Lahaul and Spiti | 17/17
# Dr.negi Clinic
#
# Searching: hospitals in Mandi Himachal Pradesh
# Search Submitted
# Mandi | hospitals | Scroll 1 -> 14
# Mandi | hospitals | Scroll 2 -> 15
# Mandi | hospitals | Scroll 3 -> 15
# Mandi | hospitals | Scroll 4 -> 15
# Mandi | hospitals | Scroll 5 -> 15
# Mandi | hospitals | Scroll 6 -> 15
# Collected 12 links
# Mandi | 1/12
# Mandav Hospital
# Mandi | 2/12
# Netaji Subhash Chandra Bose Zonal Hospital
# Backup Saved
# Mandi | 3/12
# JAGRITI MULTISPECIALITY HOSPITAL
# Mandi | 4/12
# Sri Harihar Hospital - Best Cardiology in Gutkar Mandi | Gastroenternology | Urology | Laproscopy Surgery | Neurology
# Mandi | 5/12
# K.S Hospital - Best Diagnostic Centre in Mandi/Ultrasound Centre/Hearing Aid Centre/Ent and Eye Doctor/Orthopedic Specialist
# Mandi | 6/12
# Malhotra Hospital & Trauma Centre
# Mandi | 7/12
# Bhanoo Hospital
# Mandi | 8/12
# District Ayurvedic Hospital Mandi
# Mandi | 9/12
# Mandav Hospital ,Gutkar
# Mandi | 10/12
# MANDI SANJEEVAN HOSPITAL
# Mandi | 11/12
# Govt Hospital
# Mandi | 12/12
# ZONAL HOSPITAL MANDI (HP)
#
# Searching: hospitals in Shimla Himachal Pradesh
# Search Submitted
# Shimla | hospitals | Scroll 1 -> 14
# Shimla | hospitals | Scroll 2 -> 20
# Shimla | hospitals | Scroll 3 -> 24
# Shimla | hospitals | Scroll 4 -> 24
# Shimla | hospitals | Scroll 5 -> 24
# Shimla | hospitals | Scroll 6 -> 24
# Shimla | hospitals | Scroll 7 -> 24
# Collected 23 links
# Shimla | 1/23
# SPARSH MULTI-SPECIALITY HOSPITAL
# Shimla | 2/23
# Deendyal Upadhyay Zonal Hospital
# Shimla | 3/23
# Kamla Nehru Hospital
# Shimla | 4/23
# Tenzin Hospital
# Shimla | 5/23
# Indira Gandhi Medical College & Hospital
# Shimla | 6/23
# Sanitarium Hospital
# Shimla | 7/23
# SAI HOSPITAL
# Shimla | 8/23
# Shimla Multispeciality Centre
# Shimla | 9/23
# Tara Hospital - A Multispeciality hospital
# Shimla | 10/23
# Aastha Hospital & Pediatric Centre
# Shimla | 11/23
# Himachal Hospital of Mental Health and Rehabilitation
# Shimla | 12/23
# Haritara hospital and pediatric centre, Sanjauli - Pediatric Centre/Children Hospital/Pediatrician/Child specialist In Shimla
# Shimla | 13/23
# AIMSS Chamiana
# Shimla | 14/23
# IGMC Shimla - BLOCK D
# Shimla | 15/23
# Central Government Health Scheme ( CGHS)
# Shimla | 16/23
# New OPD Building IGMC Shimla
# Shimla | 17/23
# Regional Ayurvedic Hospital Shimla
# Shimla | 18/23
# Jatoli Hospital
# Shimla | 19/23
# Government Homeopathic Hospital
# Shimla | 20/23
# Civil Hospital
# Shimla | 21/23
# HP Government Dental College & Hospital
# Shimla | 22/23
# Shiva Hospital
# Shimla | 23/23
# Malyana health clinic
#
# Searching: hospitals in Sirmaur Himachal Pradesh
# Search Submitted
# Sirmaur | hospitals | Scroll 1 -> 14
# Sirmaur | hospitals | Scroll 2 -> 20
# Sirmaur | hospitals | Scroll 3 -> 27
# Sirmaur | hospitals | Scroll 4 -> 30
# Sirmaur | hospitals | Scroll 5 -> 30
# Sirmaur | hospitals | Scroll 6 -> 30
# Sirmaur | hospitals | Scroll 7 -> 30
# Sirmaur | hospitals | Scroll 8 -> 30
# Collected 28 links
# Sirmaur | 1/28
# SHRI SAI CARDIAC &CRITICAL CARE CENTRE, BADRIPUR, PAONTA SAHIB, DISTT SIRMOUR (HP)
# Sirmaur | 2/28
# Shri Sai Multispeciality Hospital & Trauma Centre
# Sirmaur | 3/28
# Civil Hospital Paonta Sahib
# Sirmaur | 4/28
# Sneh Hospital
# Sirmaur | 5/28
# Shri Siddhivinayak Hospital
# Sirmaur | 6/28
# Zonal Hospital
# Sirmaur | 7/28
# JAGDISH CHAND JUNEJA HOSPITAL
# Sirmaur | 8/28
# Civil Hospital
# Sirmaur | 9/28
# Prriyanshi Hospital
# Sirmaur | 10/28
# Government Regional Hospital, Solan
# Sirmaur | 11/28
# Nimbus Hospital - Medicine Department in Solan (Himachal Pradesh)
# Sirmaur | 12/28
# Vohra Hospital
# Sirmaur | 13/28
# City hospital
# Sirmaur | 14/28
# Akal Charitable Hospital
# Sirmaur | 15/28
# Cantonment Hospital
# Sirmaur | 16/28
# Baba Mod Chail Road Solan Himachal Pradesh
# Sirmaur | 17/28
# Sanjivni Eye Health Care
# Sirmaur | 18/28
# Shi Sai multispecialty Dental Clinic
# Sirmaur | 19/28
# CIVIL HOSPITAL SARAHAN
# Sirmaur | 20/28
# Kalindi Hospital and Research Institute
# Sirmaur | 21/28
# Sanjivni Vision Care
# Sirmaur | 22/28
# Govt. Ayurvedic Hospital
# Sirmaur | 23/28
# dispensary
# Sirmaur | 24/28
# Civil Hospital
# Sirmaur | 25/28
# Shri Sai MSH-Physiotherapy clinic, Nahan
# Sirmaur | 26/28
# Desouza Clinic & Nursing Home
# Sirmaur | 27/28
# ESI Jabli
# Sirmaur | 28/28
# Raushan raaz
#
# Searching: hospitals in Solan Himachal Pradesh
# Search Submitted
# Solan | hospitals | Scroll 1 -> 14
# Solan | hospitals | Scroll 2 -> 19
# Solan | hospitals | Scroll 3 -> 19
# Solan | hospitals | Scroll 4 -> 19
# Solan | hospitals | Scroll 5 -> 19
# Solan | hospitals | Scroll 6 -> 19
# Collected 15 links
# Solan | 1/15
# Shri Balmukand Apex Hospital | Best Private Hospital in Solan, Himachal Pradesh Hospital | Near Shimla Sirmaur
# Solan | 2/15
# JP Hospital Solan
# Solan | 3/15
# Elcura Healthcare | Urologist | Laparoscopic and Endoscopic surgery | Best laser Surgeon | MD- Med | Best hospital in Solan |
# Solan | 4/15
# Nimbus Hospital in Solan (Himachal Pradesh)
# Solan | 5/15
# Sai Sanjivni Hospital
# Solan | 6/15
# 𝗡𝗮𝘃 𝗝𝗲𝗲𝘃𝗮𝗻 𝗛𝗼𝘀𝗽𝗶𝘁𝗮𝗹
# Solan | 7/15
# Apex Diagnostics | MRI CT in Solan |Diagnostic center Hospital in Solan, Himachal Pradesh
# Solan | 8/15
# CIPACA - JP HOSPITAL - 24 Hrs Emergency & ICU Hospital
# Solan | 9/15
# Panacea, Urocare
# Solan | 10/15
# Aastha Hospital
# Solan | 11/15
# Maharishi Markandeshwar Hospital
# Solan | 12/15
# Abhinam Eye Care & Retina Care Center Solan
# Solan | 13/15
# Ayurvedic Hospital Solan
# Solan | 14/15
# Aastha Hospital and Surgical Centre
# Solan | 15/15
# Nav Jeevan Nursing Home
#
# Searching: hospitals in Una Himachal Pradesh
# Search Submitted
# Una | hospitals | Scroll 1 -> 14
# Una | hospitals | Scroll 2 -> 20
# Una | hospitals | Scroll 3 -> 27
# Una | hospitals | Scroll 4 -> 30
# Una | hospitals | Scroll 5 -> 30
# Una | hospitals | Scroll 6 -> 30
# Una | hospitals | Scroll 7 -> 30
# Una | hospitals | Scroll 8 -> 30
# Collected 30 links
# Una | 1/30
# Nanda Multi specialty Hospital
# Una | 2/30
# Sunrise Hospital & Advanced Laparoscopic Center
# Una | 3/30
# Altis Hospital, Una
# Una | 4/30
# Harjinder Hospital
# Una | 5/30
# Kanwar Multispeciality Hospital
# Una | 6/30
# Shivam orthocare
# Una | 7/30
# Regional Hospital Una
# Una | 8/30
# Grace Megacare Hospital
# Una | 9/30
# Jagat Hospital & Kshar Sutra Centre
# Una | 10/30
# Civil Hospital Haroli, Una Himachal Pradesh
# Una | 11/30
# Seva 24x7
# Una | 12/30
# Mukesh Hospital
# Una | 13/30
# Sri krishna children hospital
# Una | 14/30
# Agnihotri Hospital
# Una | 15/30
# Dr Angra's Mother Care Hospital
# Una | 16/30
# AMC HOSPITAL & DIAGNOSTIC CENTRE
# Una | 17/30
#
# Una | 18/30
# Maatri Medicity & Orthocare Hospital- Best Orthopedic Surgeon/Best Gynecologists/Best Physiotherapist In Una
# Una | 19/30
# Dr Satinder Chauhan Megacare Hospital
# Una | 20/30
# Navneet Urology & General Surgery Hospital
# Una | 21/30
# Rajendra Hospital
# Una | 22/30
# Health Wave Neuropsychiatry and De-addiction Hospital
# Una | 23/30
# Shri Bankey Bihari Healthcare
# Una | 24/30
# DEVBHOOMI ADVAITA HEART INSTITUTE UNA
# Backup Saved
# Una | 25/30
# Rotary Eye Hospital Dhussara
# Una | 26/30
# District Ayurvedic Hospital Una
# Una | 27/30
# Chauhan Eye Hospital
# Una | 28/30
# Sahni Eye Hospital
# Una | 29/30
# ANANDRAJ MALIK HOSPITAL AND PARAMEDICAL INSTITUTE
# Una | 30/30
# Vishal Eye Hospital
#
# Extraction Completed
# Total Hospitals Extracted: 206
#
# Saved File: himachal_pradesh_hospitals.csv
