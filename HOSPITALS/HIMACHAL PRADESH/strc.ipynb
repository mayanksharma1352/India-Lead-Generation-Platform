# %%
import pandas as pd

# %%
df = pd.read_csv("himachal_pradesh_hospitals.csv")

# %%
df.shape
# Out:
# (206, 8)

# %%
df = df[
    df["Phone"].notna() & 
    (df["Phone"].astype(str).str.strip() != "")
    ]
df.shape
# Out:
# (140, 8)

# %%
df = df[
    df["Hospital Name"].notna()
    ]

df = df[
    df["Hospital Name"].str.strip() != ""
    ]
df.shape
# Out:
# (140, 8)

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]","",regex=True)
    .str.strip()
)

display(df[["Phone"]].head())
# Out:
#           Phone
# 0  097365 14253
# 1  082787 75120
# 2  062304 02530
# 4  082199 44305
# 5  094181 46611

# %%
df.to_csv(
    "himachal_pradesh_hospitals_cleaned.csv",
    index=False
)
