# %%
import pandas as pd

# %%
df = pd.read_csv("nagaland_hospitals.csv")

# %%
df.shape
# Out:
# (84, 8)

# %%
df = df[
    df["Phone"].notna() &
    (df["Phone"].astype(str).str.strip() != "")
]

# %%
df.shape
# Out:
# (23, 8)

# %%
df = df[
    df["Hospital Name"].notna()
]

df = df[
    df["Hospital Name"].str.strip() != ""
]

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]", "", regex=True)  # remove symbols/icons
    .str.strip()
)

display(df[["Phone"]].head())
# Out:
#            Phone
# 3   090777 47777
# 5  03862 242 555
# 6  03862 248 285
# 7   098560 06026
# 8   087942 89192

# %%
df.to_csv(
    "nagaland_hospitals_cleaned.csv",
    index=False
)
