# %%
import time
import random
import pandas as pd

from datetime import datetime

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.service import Service

from webdriver_manager.chrome import ChromeDriverManager

districts = [

    "Chümoukedima",
    "Dimapur",
    "Kiphire",
    "Kohima",
    "Longleng",
    "Mokokchung",
    "Mon",
    "Niuland",
    "Noklak",
    "Peren",
    "Phek",
    "Shamator",
    "Tseminyu",
    "Tuensang",
    "Wokha",
    "Zunheboto"

]


search_types = [
    "hospitals"
]


options = webdriver.ChromeOptions()

options.add_argument("--start-maximized")

options.add_argument(
    "--disable-blink-features=AutomationControlled"
)

options.add_argument("--disable-notifications")


driver = webdriver.Chrome(

    service=Service(
        ChromeDriverManager().install()
    ),

    options=options
)


driver.get("https://www.google.com/maps")

print("Opening Google Maps...")

time.sleep(15)

print("Google Maps Loaded")


all_data = []

visited_links = set()


def get_search_box():

    selectors = [

        '//input[@id="searchboxinput"]',
        '//input[contains(@placeholder,"Search")]',
        '//input[contains(@aria-label,"Search")]',
        '//input'

    ]

    for selector in selectors:

        try:

            box = driver.find_element(
                By.XPATH,
                selector
            )

            return box

        except:
            pass

    return None



def extract_school_data():

    try:

        try:
            name = driver.find_element(
                By.TAG_NAME,
                "h1"
            ).text
        except:
            name = ""


        try:
            address = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"address")]'
            ).text
        except:
            address = ""

        try:
            phone = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"phone")]'
            ).text
        except:
            phone = ""

 
        try:
            website = driver.find_element(
                By.XPATH,
                '//a[contains(@data-item-id,"authority")]'
            ).get_attribute("href")
        except:
            website = ""

   
        try:
            rating = driver.find_element(
                By.XPATH,
                '//div[@role="img"]'
            ).get_attribute("aria-label")
        except:
            rating = ""

        return {

            "Hospital Name": name,
            "Address": address,
            "Phone": phone,
            "Website": website,
            "Rating": rating,
            "Google Maps URL": driver.current_url

        }

    except:

        return None



for district in districts:

    for search_type in search_types:

        try:

            query = (
                f"{search_type} "
                f"in {district} Nagaland"
            )

            print(f"\nSearching: {query}")


            search_box = get_search_box()

            if not search_box:

                print("Search Box Not Found")

                continue

            ActionChains(driver).move_to_element(
                search_box
            ).click().perform()

            time.sleep(1)

            search_box.send_keys(
                Keys.CONTROL + "a"
            )

            time.sleep(1)

            search_box.send_keys(Keys.DELETE)

            time.sleep(1)


            for char in query:

                search_box.send_keys(char)

                time.sleep(0.03)

            search_box.send_keys(Keys.ENTER)

            print("Search Submitted")

            time.sleep(8)

   

            try:

                scrollable_div = driver.find_element(
                    By.XPATH,
                    '//div[@role="feed"]'
                )

                previous_count = 0

                stagnant = 0

                for i in range(100):

                    driver.execute_script(
                        """
                        arguments[0].scrollTop =
                        arguments[0].scrollHeight
                        """,
                        scrollable_div
                    )

     
                    time.sleep(4)

                    listings = driver.find_elements(
                        By.XPATH,
                        '//a[contains(@href,"/maps/place/")]'
                    )

                    current_count = len(listings)

                    print(
                        f"{district} | "
                        f"{search_type} | "
                        f"Scroll {i+1} -> "
                        f"{current_count}"
                    )

                    if current_count == previous_count:

                        stagnant += 1

                    else:

                        stagnant = 0

                    if stagnant >= 4:

                        break

                    previous_count = current_count

            except Exception as e:

                print(f"Scrolling Error: {e}")

  

            listings = driver.find_elements(
                By.XPATH,
                '//a[contains(@href,"/maps/place/")]'
            )

            links = []

            for listing in listings:

                try:

                    link = listing.get_attribute("href")

                    if (
                        link
                        and link not in visited_links
                    ):

                        links.append(link)

                        visited_links.add(link)

                except:
                    pass

            print(f"Collected {len(links)} links")



            for index, link in enumerate(links):

                try:

                    print(
                        f"{district} | "
                        f"{index+1}/{len(links)}"
                    )

                    driver.get(link)

                    time.sleep(
                        random.uniform(2, 4)
                    )

                    data = extract_school_data()

                    if data:

                        data["District"] = district

                        data["Search Type"] = search_type

                        all_data.append(data)

                        print(data["Hospital Name"])


                    if len(all_data) % 100 == 0:

                        backup_df = pd.DataFrame(
                            all_data
                        )

                        backup_df.drop_duplicates(
                            subset=[
                                "Hospital Name",
                                "Google Maps URL"
                            ],
                            inplace=True
                        )

                        backup_filename = (
                            "nagaland_backup.csv"
                        )

                        backup_df.to_csv(
                            backup_filename,
                            index=False
                        )

                        print("Backup Saved")

                except Exception as e:

                    print(
                        f"School Error: {e}"
                    )

        except Exception as e:

            print(
                f"District Error: {e}"
            )



df = pd.DataFrame(all_data)

df.drop_duplicates(

    subset=[
        "Hospital Name",
        "Google Maps URL"
    ],

    inplace=True
)


filename = (
    "nagaland_hospitals.csv"
)

df.to_csv(
    filename,
    index=False
)

print("\nExtraction Completed")

print(
    f"Total Hospitals Extracted: {len(df)}"
)

print(f"\nSaved File: {filename}")

driver.quit()
# Out:
# Opening Google Maps...
# Google Maps Loaded
#
# Searching: hospitals in Chümoukedima Nagaland
# Search Submitted
# Chümoukedima | hospitals | Scroll 1 -> 16
# Chümoukedima | hospitals | Scroll 2 -> 17
# Chümoukedima | hospitals | Scroll 3 -> 17
# Chümoukedima | hospitals | Scroll 4 -> 17
# Chümoukedima | hospitals | Scroll 5 -> 17
# Chümoukedima | hospitals | Scroll 6 -> 17
# Collected 17 links
# Chümoukedima | 1/17
# HK Hospital
# Chümoukedima | 2/17
# Rev. Zhaviu Khro Memorial Hospital
# Chümoukedima | 3/17
# Police Refferral Hospital
# Chümoukedima | 4/17
# Faith Hospital and Institute of Medical Sciences
# Chümoukedima | 5/17
# Holy Redeemer Health Centre
# Chümoukedima | 6/17
# Christian Institute Of Health Sciences & Research
# Chümoukedima | 7/17
# Nikos Hospital
# Chümoukedima | 8/17
# Nagaland Multispeciality Health & Research Centre
# Chümoukedima | 9/17
# Eden Medical Centre
# Chümoukedima | 10/17
# Olive Christian Hospital and Research Centre
# Chümoukedima | 11/17
# District Hospital Dimapur
# Chümoukedima | 12/17
# Zion hospital and Research Centre
# Chümoukedima | 13/17
# Dimapur hospital and research centre
# Chümoukedima | 14/17
# MH Hospital
# Chümoukedima | 15/17
# Assam Rifles Composite Hospital
# Chümoukedima | 16/17
# Nagaland Pain Management Centre
# Chümoukedima | 17/17
# 15IR MAHILLA HOSPITAL
#
# Searching: hospitals in Dimapur Nagaland
# Search Submitted
# Dimapur | hospitals | Scroll 1 -> 16
# Dimapur | hospitals | Scroll 2 -> 20
# Dimapur | hospitals | Scroll 3 -> 20
# Dimapur | hospitals | Scroll 4 -> 20
# Dimapur | hospitals | Scroll 5 -> 20
# Dimapur | hospitals | Scroll 6 -> 20
# Collected 6 links
# Dimapur | 1/6
# CIHSR Hospital
# Dimapur | 2/6
# City Hospital
# Dimapur | 3/6
# dimapur hospital
# Dimapur | 4/6
# Fellowship Nursing Home
# Dimapur | 5/6
# City Medical Centre
# Dimapur | 6/6
# Urban Primary Health Centre
#
# Searching: hospitals in Kiphire Nagaland
# Search Submitted
# Scrolling Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@role="feed"]"}
#   (Session info: chrome=148.0.7778.167); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 	chromedriver!GetHandleVerifier [0x10d7123+10a23]
# 	chromedriver!GetHandleVerifier [0x10d7254+10b54]
# 	chromedriver!(No symbol) [0xef1e90]
# 	chromedriver!(No symbol) [0xf3b28a]
# 	chromedriver!(No symbol) [0xf3b52b]
# 	chromedriver!(No symbol) [0xf7d062]
# 	chromedriver!(No symbol) [0xf5d7d4]
# 	chromedriver!(No symbol) [0xf7a936]
# 	chromedriver!(No symbol) [0xf5d526]
# 	chromedriver!(No symbol) [0xf308f9]
# 	chromedriver!(No symbol) [0xf316b4]
# 	chromedriver!GetHandleVerifier [0x1371ac4+2ab3c4]
# 	chromedriver!GetHandleVerifier [0x136d0ed+2a69ed]
# 	chromedriver!GetHandleVerifier [0x138e4f5+2c7df5]
# 	chromedriver!GetHandleVerifier [0x10f1128+2aa28]
# 	chromedriver!GetHandleVerifier [0x10f8bbd+324bd]
# 	chromedriver!GetHandleVerifier [0x10dfb28+19428]
# 	chromedriver!GetHandleVerifier [0x10dfcd5+195d5]
# 	chromedriver!GetHandleVerifier [0x10c91cf+2acf]
# 	KERNEL32!BaseThreadInitThunk [0x75defcc9+19]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x779982ae+11e]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x7799827e+ee]
#
# Collected 0 links
#
# Searching: hospitals in Kohima Nagaland
# Search Submitted
# Kohima | hospitals | Scroll 1 -> 10
# Kohima | hospitals | Scroll 2 -> 10
# Kohima | hospitals | Scroll 3 -> 10
# Kohima | hospitals | Scroll 4 -> 10
# Kohima | hospitals | Scroll 5 -> 10
# Collected 10 links
# Kohima | 1/10
# Naga Hospital Authority
# Kohima | 2/10
# PUTUONUO HOSPITAL
# Kohima | 3/10
# Oking Hospital
# Kohima | 4/10
# Kohimas Hospital
# Kohima | 5/10
# K. P. Bethesda Hospital
# Kohima | 6/10
# Bethel Medical Center
# Kohima | 7/10
# GIVF Hospital
# Kohima | 8/10
# Kohima Operational Hospital And Institute Of Minimal Access Surgery Kohimas
# Kohima | 9/10
# State Mental Health Institute, Kohima
# Kohima | 10/10
# Oking Daycare Hospital
#
# Searching: hospitals in Longleng Nagaland
# Search Submitted
# Scrolling Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@role="feed"]"}
#   (Session info: chrome=148.0.7778.167); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 	chromedriver!GetHandleVerifier [0x10d7123+10a23]
# 	chromedriver!GetHandleVerifier [0x10d7254+10b54]
# 	chromedriver!(No symbol) [0xef1e90]
# 	chromedriver!(No symbol) [0xf3b28a]
# 	chromedriver!(No symbol) [0xf3b52b]
# 	chromedriver!(No symbol) [0xf7d062]
# 	chromedriver!(No symbol) [0xf5d7d4]
# 	chromedriver!(No symbol) [0xf7a936]
# 	chromedriver!(No symbol) [0xf5d526]
# 	chromedriver!(No symbol) [0xf308f9]
# 	chromedriver!(No symbol) [0xf316b4]
# 	chromedriver!GetHandleVerifier [0x1371ac4+2ab3c4]
# 	chromedriver!GetHandleVerifier [0x136d0ed+2a69ed]
# 	chromedriver!GetHandleVerifier [0x138e4f5+2c7df5]
# 	chromedriver!GetHandleVerifier [0x10f1128+2aa28]
# 	chromedriver!GetHandleVerifier [0x10f8bbd+324bd]
# 	chromedriver!GetHandleVerifier [0x10dfb28+19428]
# 	chromedriver!GetHandleVerifier [0x10dfcd5+195d5]
# 	chromedriver!GetHandleVerifier [0x10c91cf+2acf]
# 	KERNEL32!BaseThreadInitThunk [0x75defcc9+19]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x779982ae+11e]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x7799827e+ee]
#
# Collected 0 links
#
# Searching: hospitals in Mokokchung Nagaland
# Search Submitted
# Mokokchung | hospitals | Scroll 1 -> 5
# Mokokchung | hospitals | Scroll 2 -> 5
# Mokokchung | hospitals | Scroll 3 -> 5
# Mokokchung | hospitals | Scroll 4 -> 5
# Mokokchung | hospitals | Scroll 5 -> 5
# Collected 5 links
# Mokokchung | 1/5
# Lenjem Hospital
# Mokokchung | 2/5
# Imkongliba Memorial District Hospital Mokokchung
# Mokokchung | 3/5
# TB Hospital Mokokchung
# Mokokchung | 4/5
# Woodland Nursing Home
# Mokokchung | 5/5
# Dr. Tongpang Hospital
#
# Searching: hospitals in Mon Nagaland
# Search Submitted
# Mon | hospitals | Scroll 1 -> 3
# Mon | hospitals | Scroll 2 -> 3
# Mon | hospitals | Scroll 3 -> 3
# Mon | hospitals | Scroll 4 -> 3
# Mon | hospitals | Scroll 5 -> 3
# Collected 3 links
# Mon | 1/3
# District Hospital Mon
# Mon | 2/3
# Rapha Hospital
# Mon | 3/3
# Mon Medical College
#
# Searching: hospitals in Niuland Nagaland
# Search Submitted
# Niuland | hospitals | Scroll 1 -> 16
# Niuland | hospitals | Scroll 2 -> 20
# Niuland | hospitals | Scroll 3 -> 20
# Niuland | hospitals | Scroll 4 -> 20
# Niuland | hospitals | Scroll 5 -> 20
# Niuland | hospitals | Scroll 6 -> 20
# Collected 2 links
# Niuland | 1/2
# Y. Rochill Hospital
# Niuland | 2/2
# Nagaland Medical College
#
# Searching: hospitals in Noklak Nagaland
# Search Submitted
# Noklak | hospitals | Scroll 1 -> 6
# Noklak | hospitals | Scroll 2 -> 6
# Noklak | hospitals | Scroll 3 -> 6
# Noklak | hospitals | Scroll 4 -> 6
# Noklak | hospitals | Scroll 5 -> 6
# Collected 6 links
# Noklak | 1/6
# Integrated Ayush Hospital Noklak
# Noklak | 2/6
#
# Noklak | 3/6
# Hospital
# Noklak | 4/6
# Nokhu PHC
# Noklak | 5/6
# Sub-Health center
# Noklak | 6/6
# PHC
#
# Searching: hospitals in Peren Nagaland
# Search Submitted
# Scrolling Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@role="feed"]"}
#   (Session info: chrome=148.0.7778.167); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 	chromedriver!GetHandleVerifier [0x10d7123+10a23]
# 	chromedriver!GetHandleVerifier [0x10d7254+10b54]
# 	chromedriver!(No symbol) [0xef1e90]
# 	chromedriver!(No symbol) [0xf3b28a]
# 	chromedriver!(No symbol) [0xf3b52b]
# 	chromedriver!(No symbol) [0xf7d062]
# 	chromedriver!(No symbol) [0xf5d7d4]
# 	chromedriver!(No symbol) [0xf7a936]
# 	chromedriver!(No symbol) [0xf5d526]
# 	chromedriver!(No symbol) [0xf308f9]
# 	chromedriver!(No symbol) [0xf316b4]
# 	chromedriver!GetHandleVerifier [0x1371ac4+2ab3c4]
# 	chromedriver!GetHandleVerifier [0x136d0ed+2a69ed]
# 	chromedriver!GetHandleVerifier [0x138e4f5+2c7df5]
# 	chromedriver!GetHandleVerifier [0x10f1128+2aa28]
# 	chromedriver!GetHandleVerifier [0x10f8bbd+324bd]
# 	chromedriver!GetHandleVerifier [0x10dfb28+19428]
# 	chromedriver!GetHandleVerifier [0x10dfcd5+195d5]
# 	chromedriver!GetHandleVerifier [0x10c91cf+2acf]
# 	KERNEL32!BaseThreadInitThunk [0x75defcc9+19]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x779982ae+11e]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x7799827e+ee]
#
# Collected 0 links
#
# Searching: hospitals in Phek Nagaland
# Search Submitted
# Phek | hospitals | Scroll 1 -> 8
# Phek | hospitals | Scroll 2 -> 8
# Phek | hospitals | Scroll 3 -> 8
# Phek | hospitals | Scroll 4 -> 8
# Phek | hospitals | Scroll 5 -> 8
# Collected 8 links
# Phek | 1/8
# District Hospital
# Phek | 2/8
# Civil Hospital
# Phek | 3/8
# VESE CLINIC
# Phek | 4/8
# Public Health Care
# Phek | 5/8
# Primary Health Centre, Rüzazho
# Phek | 6/8
# P.H.C Thetsumi
# Phek | 7/8
# PHC Panso (Hospital)
# Phek | 8/8
# Ayush Health and Wellness centre sohomi village
#
# Searching: hospitals in Shamator Nagaland
# Search Submitted
# Scrolling Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@role="feed"]"}
#   (Session info: chrome=148.0.7778.167); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 	chromedriver!GetHandleVerifier [0x10d7123+10a23]
# 	chromedriver!GetHandleVerifier [0x10d7254+10b54]
# 	chromedriver!(No symbol) [0xef1e90]
# 	chromedriver!(No symbol) [0xf3b28a]
# 	chromedriver!(No symbol) [0xf3b52b]
# 	chromedriver!(No symbol) [0xf7d062]
# 	chromedriver!(No symbol) [0xf5d7d4]
# 	chromedriver!(No symbol) [0xf7a936]
# 	chromedriver!(No symbol) [0xf5d526]
# 	chromedriver!(No symbol) [0xf308f9]
# 	chromedriver!(No symbol) [0xf316b4]
# 	chromedriver!GetHandleVerifier [0x1371ac4+2ab3c4]
# 	chromedriver!GetHandleVerifier [0x136d0ed+2a69ed]
# 	chromedriver!GetHandleVerifier [0x138e4f5+2c7df5]
# 	chromedriver!GetHandleVerifier [0x10f1128+2aa28]
# 	chromedriver!GetHandleVerifier [0x10f8bbd+324bd]
# 	chromedriver!GetHandleVerifier [0x10dfb28+19428]
# 	chromedriver!GetHandleVerifier [0x10dfcd5+195d5]
# 	chromedriver!GetHandleVerifier [0x10c91cf+2acf]
# 	KERNEL32!BaseThreadInitThunk [0x75defcc9+19]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x779982ae+11e]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x7799827e+ee]
#
# Collected 0 links
#
# Searching: hospitals in Tseminyu Nagaland
# Search Submitted
# Tseminyu | hospitals | Scroll 1 -> 3
# Tseminyu | hospitals | Scroll 2 -> 3
# Tseminyu | hospitals | Scroll 3 -> 3
# Tseminyu | hospitals | Scroll 4 -> 3
# Tseminyu | hospitals | Scroll 5 -> 3
# Collected 3 links
# Tseminyu | 1/3
# CHC Tseminyu Old town
# Tseminyu | 2/3
# Care Pharmacy
# Tseminyu | 3/3
# Tseminyu Primary Health Centre
#
# Searching: hospitals in Tuensang Nagaland
# Search Submitted
# Tuensang | hospitals | Scroll 1 -> 7
# Tuensang | hospitals | Scroll 2 -> 7
# Tuensang | hospitals | Scroll 3 -> 7
# Tuensang | hospitals | Scroll 4 -> 7
# Tuensang | hospitals | Scroll 5 -> 7
# Collected 7 links
# Tuensang | 1/7
# Civil Hospital, Tuensang
# Tuensang | 2/7
# Primary Health Centre
# Tuensang | 3/7
# Urban Primary Health Center Tuensang
# Tuensang | 4/7
# House Of Hope
# Tuensang | 5/7
# TB Hospital
# Tuensang | 6/7
# St John tuensang nagaland
# Tuensang | 7/7
# District Hospital Tuensang
#
# Searching: hospitals in Wokha Nagaland
# Search Submitted
# Wokha | hospitals | Scroll 1 -> 13
# Wokha | hospitals | Scroll 2 -> 13
# Wokha | hospitals | Scroll 3 -> 13
# Wokha | hospitals | Scroll 4 -> 13
# Wokha | hospitals | Scroll 5 -> 13
# Collected 13 links
# Wokha | 1/13
# District Hospital Wokha, Nagaland
# Wokha | 2/13
# Wokha Civil Hospital
# Wokha | 3/13
# Mhondamo Memorial Hospital
# Wokha | 4/13
# Panacea Nursing Home
# Wokha | 5/13
# N.Ezung Hospital
# Wokha | 6/13
# Veterinary Hospital Wokha
# Wokha | 7/13
# UPHC WOKHA
# Wokha | 8/13
# Christian Medical Centre
# Wokha | 9/13
# Medicare Pharmacy
# Wokha | 10/13
# MM Nursing Home
# Wokha | 11/13
# Panacea Nursing Clinic
# Wokha | 12/13
# Yikhüm Health & Wellness Centre
# Wokha | 13/13
# Riphyim Health & Wellness Centre
#
# Searching: hospitals in Zunheboto Nagaland
# Search Submitted
# Zunheboto | hospitals | Scroll 1 -> 6
# Zunheboto | hospitals | Scroll 2 -> 6
# Zunheboto | hospitals | Scroll 3 -> 6
# Zunheboto | hospitals | Scroll 4 -> 6
# Zunheboto | hospitals | Scroll 5 -> 6
# Collected 4 links
# Zunheboto | 1/4
# Hezukhu Memorial Zunheboto Civil Hospital
# Zunheboto | 2/4
# Hongkong
# Zunheboto | 3/4
# Sub Center AGHUYITO Town
# Zunheboto | 4/4
# OPD Center
#
# Extraction Completed
# Total Hospitals Extracted: 84
#
# Saved File: nagaland_hospitals.csv
