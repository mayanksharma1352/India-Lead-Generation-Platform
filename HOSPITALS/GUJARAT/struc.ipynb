# %%
import pandas as pd

# %%
df = pd.read_csv("gujarat_hospitals.csv")

# %%
df.shape
# Out:
# (1376, 8)

# %%
df = df[
    df["Phone"].notna() & 
    (df["Phone"].astype(str).str.strip() != "")
    ]
df.shape
# Out:
# (62, 8)

# %%
df = df[
    df["Hospital Name"].notna()
    ]

df = df[
    df["Hospital Name"].str.strip() != ""
    ]
df.shape
# Out:
# (62, 8)

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]","",regex=True)
    .str.strip()
)

display(df[["Phone"]].head())
# Out:
#            Phone
# 1  080 6215 4048
# 2   070690 01001
# 3  080 6904 9761
# 4  080 6904 9761
# 5   095122 60059

# %%
df.to_csv(
    "gujarat_hospitals_cleaned.csv",
    index=False
)
