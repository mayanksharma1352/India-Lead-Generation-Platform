# %%
import time
import random
import pandas as pd

from datetime import datetime

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.service import Service

from webdriver_manager.chrome import ChromeDriverManager

districts = [

    "Baksa",
    "Bajali",
    "Barpeta",
    "Biswanath",
    "Bongaigaon",
    "Cachar",
    "Charaideo",
    "Chirang",
    "Darrang",
    "Dhemaji",
    "Dhubri",
    "Dibrugarh",
    "Dima Hasao",
    "Goalpara",
    "Golaghat",
    "Hailakandi",
    "Hojai",
    "Jorhat",
    "Kamrup",
    "Kamrup Metropolitan",
    "Karbi Anglong",
    "Kokrajhar",
    "Lakhimpur",
    "Majuli",
    "Morigaon",
    "Nagaon",
    "Nalbari",
    "Sivasagar",
    "Sonitpur",
    "South Salmara-Mankachar",
    "Tamulpur",
    "Tinsukia",
    "Udalguri",
    "West Karbi Anglong"

]



search_types = [
    "hospitals"
]

options = webdriver.ChromeOptions()

options.add_argument("--start-maximized")

options.add_argument(
    "--disable-blink-features=AutomationControlled"
)

options.add_argument("--disable-notifications")



driver = webdriver.Chrome(

    service=Service(
        ChromeDriverManager().install()
    ),

    options=options
)


driver.get("https://www.google.com/maps")

print("Opening Google Maps...")

time.sleep(15)

print("Google Maps Loaded")



all_data = []

visited_links = set()


def get_search_box():

    selectors = [

        '//input[@id="searchboxinput"]',
        '//input[contains(@placeholder,"Search")]',
        '//input[contains(@aria-label,"Search")]',
        '//input'

    ]

    for selector in selectors:

        try:

            box = driver.find_element(
                By.XPATH,
                selector
            )

            return box

        except:
            pass

    return None



def extract_school_data():

    try:


        try:
            name = driver.find_element(
                By.TAG_NAME,
                "h1"
            ).text
        except:
            name = ""


        try:
            address = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"address")]'
            ).text
        except:
            address = ""


        try:
            phone = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"phone")]'
            ).text
        except:
            phone = ""


        try:
            website = driver.find_element(
                By.XPATH,
                '//a[contains(@data-item-id,"authority")]'
            ).get_attribute("href")
        except:
            website = ""

        try:
            rating = driver.find_element(
                By.XPATH,
                '//div[@role="img"]'
            ).get_attribute("aria-label")
        except:
            rating = ""

        return {

            "Hospital Name": name,
            "Address": address,
            "Phone": phone,
            "Website": website,
            "Rating": rating,
            "Google Maps URL": driver.current_url

        }

    except:

        return None



for district in districts:

    for search_type in search_types:

        try:

            query = (
                f"{search_type} "
                f"in {district} Assam"
            )

            print(f"\nSearching: {query}")


            search_box = get_search_box()

            if not search_box:

                print("Search Box Not Found")

                continue

            ActionChains(driver).move_to_element(
                search_box
            ).click().perform()

            time.sleep(1)

            search_box.send_keys(
                Keys.CONTROL + "a"
            )

            time.sleep(1)

            search_box.send_keys(Keys.DELETE)

            time.sleep(1)

        
            for char in query:

                search_box.send_keys(char)

                time.sleep(0.03)

            search_box.send_keys(Keys.ENTER)

            print("Search Submitted")

            time.sleep(8)



            try:

                scrollable_div = driver.find_element(
                    By.XPATH,
                    '//div[@role="feed"]'
                )

                previous_count = 0

                stagnant = 0

                for i in range(100):

                    driver.execute_script(
                        """
                        arguments[0].scrollTop =
                        arguments[0].scrollHeight
                        """,
                        scrollable_div
                    )

         
                    time.sleep(4)

                    listings = driver.find_elements(
                        By.XPATH,
                        '//a[contains(@href,"/maps/place/")]'
                    )

                    current_count = len(listings)

                    print(
                        f"{district} | "
                        f"{search_type} | "
                        f"Scroll {i+1} -> "
                        f"{current_count}"
                    )

                    if current_count == previous_count:

                        stagnant += 1

                    else:

                        stagnant = 0

 
                    if stagnant >= 4:

                        break

                    previous_count = current_count

            except Exception as e:

                print(f"Scrolling Error: {e}")



            listings = driver.find_elements(
                By.XPATH,
                '//a[contains(@href,"/maps/place/")]'
            )

            links = []

            for listing in listings:

                try:

                    link = listing.get_attribute("href")

                    if (
                        link
                        and link not in visited_links
                    ):

                        links.append(link)

                        visited_links.add(link)

                except:
                    pass

            print(f"Collected {len(links)} links")



            for index, link in enumerate(links):

                try:

                    print(
                        f"{district} | "
                        f"{index+1}/{len(links)}"
                    )

                    driver.get(link)

                    time.sleep(
                        random.uniform(2, 4)
                    )

                    data = extract_school_data()

                    if data:

                        data["District"] = district

                        data["Search Type"] = search_type

                        all_data.append(data)

                        print(data["Hospital Name"])


                    if len(all_data) % 100 == 0:

                        backup_df = pd.DataFrame(
                            all_data
                        )

                        backup_df.drop_duplicates(
                            subset=[
                                "Hospital Name",
                                "Google Maps URL"
                            ],
                            inplace=True
                        )

                        backup_filename = (
                            "assam_backup.csv"
                        )

                        backup_df.to_csv(
                            backup_filename,
                            index=False
                        )

                        print("Backup Saved")

                except Exception as e:

                    print(
                        f"School Error: {e}"
                    )

        except Exception as e:

            print(
                f"District Error: {e}"
            )


df = pd.DataFrame(all_data)

df.drop_duplicates(

    subset=[
        "Hospital Name",
        "Google Maps URL"
    ],

    inplace=True
)


filename = (
    "assam_hospitals.csv"
)

df.to_csv(
    filename,
    index=False
)

print("\nExtraction Completed")

print(
    f"Total Schools Extracted: {len(df)}"
)

print(f"\nSaved File: {filename}")

driver.quit()
# Out:
# Opening Google Maps...
# Google Maps Loaded
#
# Searching: hospitals in Baksa Assam
# Search Submitted
# Scrolling Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@role="feed"]"}
#   (Session info: chrome=148.0.7778.167); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 	chromedriver!GetHandleVerifier [0xd17123+10a23]
# 	chromedriver!GetHandleVerifier [0xd17254+10b54]
# 	chromedriver!(No symbol) [0xb31e90]
# 	chromedriver!(No symbol) [0xb7b28a]
# 	chromedriver!(No symbol) [0xb7b52b]
# 	chromedriver!(No symbol) [0xbbd062]
# 	chromedriver!(No symbol) [0xb9d7d4]
# 	chromedriver!(No symbol) [0xbba936]
# 	chromedriver!(No symbol) [0xb9d526]
# 	chromedriver!(No symbol) [0xb708f9]
# 	chromedriver!(No symbol) [0xb716b4]
# 	chromedriver!GetHandleVerifier [0xfb1ac4+2ab3c4]
# 	chromedriver!GetHandleVerifier [0xfad0ed+2a69ed]
# 	chromedriver!GetHandleVerifier [0xfce4f5+2c7df5]
# 	chromedriver!GetHandleVerifier [0xd31128+2aa28]
# 	chromedriver!GetHandleVerifier [0xd38bbd+324bd]
# 	chromedriver!GetHandleVerifier [0xd1fb28+19428]
# 	chromedriver!GetHandleVerifier [0xd1fcd5+195d5]
# 	chromedriver!GetHandleVerifier [0xd091cf+2acf]
# 	KERNEL32!BaseThreadInitThunk [0x75defcc9+19]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x779982ae+11e]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x7799827e+ee]
#
# Collected 0 links
#
# Searching: hospitals in Bajali Assam
# Search Submitted
# Bajali | hospitals | Scroll 1 -> 16
# Bajali | hospitals | Scroll 2 -> 20
# Bajali | hospitals | Scroll 3 -> 28
# Bajali | hospitals | Scroll 4 -> 31
# Bajali | hospitals | Scroll 5 -> 31
# Bajali | hospitals | Scroll 6 -> 31
# Bajali | hospitals | Scroll 7 -> 31
# Bajali | hospitals | Scroll 8 -> 31
# Collected 31 links
# Bajali | 1/31
# Sub-Divisional Civil Hospital, Pathsala.
# Bajali | 2/31
# SATISH SARMA MEMORIAL HOSPITAL
# Bajali | 3/31
# SARATHI HOSPITAL, NALBARI
# Bajali | 4/31
# DR. RAVI BORO CIVIL HOSPITAL ডাক্তৰ ৰবি বড়ো অসামৰিক চিকিৎসালয়
# Bajali | 5/31
# BARBANG MINI PHC
# Bajali | 6/31
# Barpeta Medical College and Hospital, Barpeta
# Bajali | 7/31
# JSB CIVIL Hospital, Kajalgaon.
# Bajali | 8/31
# Pathsala Maternity cum Polyclinic & Research Center
# Bajali | 9/31
# Lower Assam Hospital & Research Centre
# Bajali | 10/31
# NIRC & Hospital
# Bajali | 11/31
# Barpeta Civil Hospital,Kalgachia
# Bajali | 12/31
# Sanjivani Hospital
# Bajali | 13/31
# Angkuram Hospital
# Bajali | 14/31
# Hospital
# Bajali | 15/31
# Balijan Hospital 🏥
# Bajali | 16/31
# Sparsh Hospital,Rangia
# Bajali | 17/31
# Swasti Hospital
# Bajali | 18/31
# Kalgachia BPHC
# Bajali | 19/31
# Barpeta Road FRU
# Bajali | 20/31
# Solace Hospital, BOC Goalpara Town
# Bajali | 21/31
# Salabila Sub-Health Centre ছালাবিলা উপ- স্বাস্থ্য কেন্দ্র
# Bajali | 22/31
#
# Bajali | 23/31
#
# Bajali | 24/31
#
# Bajali | 25/31
#
# Bajali | 26/31
#
# Bajali | 27/31
# Hayat Hospital
# Bajali | 28/31
# ভায়োলিনা মেডিক'জ
# Bajali | 29/31
# Bashbari 4 Health Sub Center
# Bajali | 30/31
# Sialmari PHC
# Bajali | 31/31
# Hathinapur Sub Center
#
# Searching: hospitals in Barpeta Assam
# Search Submitted
# Barpeta | hospitals | Scroll 1 -> 8
# Barpeta | hospitals | Scroll 2 -> 8
# Barpeta | hospitals | Scroll 3 -> 8
# Barpeta | hospitals | Scroll 4 -> 8
# Barpeta | hospitals | Scroll 5 -> 8
# Collected 3 links
# Barpeta | 1/3
#
# Barpeta | 2/3
#
# Barpeta | 3/3
#
#
# Searching: hospitals in Biswanath Assam
# Search Submitted
# Biswanath | hospitals | Scroll 1 -> 13
# Biswanath | hospitals | Scroll 2 -> 13
# Biswanath | hospitals | Scroll 3 -> 13
# Biswanath | hospitals | Scroll 4 -> 13
# Biswanath | hospitals | Scroll 5 -> 13
# Collected 13 links
# Biswanath | 1/13
# Biswanath District Hospital
# Biswanath | 2/13
# J. K. HOSPITAL
# Biswanath | 3/13
# Sanjivani Hospital and Research Centre
# Biswanath | 4/13
# K P Memorial Hospital
# Biswanath | 5/13
# BORA'S Nursing Home
# Biswanath | 6/13
# Biswanath Polyclinic pharmacy
# Biswanath | 7/13
# Good Health Polyclinic
# Biswanath | 8/13
# Biswanath Chariali Sub - Divisional Hospital
# Biswanath | 9/13
# Aarogya ENT clinic
# Biswanath | 10/13
# Hospital Kitna
# Biswanath | 11/13
# Dr Dhrubajyoti Phukan
# Biswanath | 12/13
# ENT specialist ( Dr . DJ borgohain ) biswanath polyclinic
# Biswanath | 13/13
# Biswanath Chariali Civil Hospital
#
# Searching: hospitals in Bongaigaon Assam
# Search Submitted
# Bongaigaon | hospitals | Scroll 1 -> 16
# Bongaigaon | hospitals | Scroll 2 -> 20
# Bongaigaon | hospitals | Scroll 3 -> 24
# Bongaigaon | hospitals | Scroll 4 -> 24
# Bongaigaon | hospitals | Scroll 5 -> 24
# Bongaigaon | hospitals | Scroll 6 -> 24
# Bongaigaon | hospitals | Scroll 7 -> 24
# Collected 20 links
# Bongaigaon | 1/20
# Bongaigaon Civil Hospital
# Bongaigaon | 2/20
# ST. Augustine Hospital Bongaigaon
# Bongaigaon | 3/20
# AROGYA HOSPITAL AND RESEARCH CENTRE, BONGAIGAON
# Bongaigaon | 4/20
# Swagat Hospital & Research Centre
# Bongaigaon | 5/20
# SM Hospital and Diagnostics Center( Agarwala Hospital)
# Bongaigaon | 6/20
# ST. AUGUSTINE HOSPITAL
# Bongaigaon | 7/20
# Bongaigaon Refinery Hospital
# Bongaigaon | 8/20
# Chilaray Hospital & Research Centre
# Bongaigaon | 9/20
# BONGAIGAON EYE HOSPITAL
# Bongaigaon | 10/20
# Bongaigaon BPHC
# Bongaigaon | 11/20
# Narmada International Hospital and Research Centre Bongaigaon
# Bongaigaon | 12/20
# Bongaigaon Medical College & Hospital
# Bongaigaon | 13/20
# Medcare – Dr. Tamoghna Das | Echocardiography, Diabetes, Thyroid & Obesity Clinic in Gurunanak Nagar, Bongaigaon, Assam
# Bongaigaon | 14/20
# NEW BONGAIGAON DIVISIONAL RAILWAY HOSPITAL
# Bongaigaon | 15/20
# Arogya neocare and childhood care hospital
# Bongaigaon | 16/20
# Maternity Cabin (Lower Assam Hospital)
# Bongaigaon | 17/20
# ECHS POLYCLINIC BONGAIGAON
# Bongaigaon | 18/20
# Hospital
# Bongaigaon | 19/20
# Harsh Medical Bongaigaon Ent doctor ,Ortho doctor ,skin Clinic
# Bongaigaon | 20/20
# Bhawlaguri Urban Primary Health Centre
#
# Searching: hospitals in Cachar Assam
# Search Submitted
# Cachar | hospitals | Scroll 1 -> 16
# Cachar | hospitals | Scroll 2 -> 20
# Cachar | hospitals | Scroll 3 -> 28
# Cachar | hospitals | Scroll 4 -> 35
# Cachar | hospitals | Scroll 5 -> 35
# Cachar | hospitals | Scroll 6 -> 35
# Cachar | hospitals | Scroll 7 -> 35
# Cachar | hospitals | Scroll 8 -> 35
# Collected 35 links
# Cachar | 1/35
# Cachar Cancer Hospital and Research Centre
# Cachar | 2/35
# Civil Hospital
# Cachar | 3/35
# Gracewell Hospital
# Cachar | 4/35
# Green Heals Hospital Pvt Ltd
# Cachar | 5/35
# South City Hospital
# Cachar | 6/35
# Superb Hospital & Research Institute
# Cachar | 7/35
# Jeevan Jyoti Institute of Medical Sciences
# Cachar | 8/35
# Mediland Hospital and Research centre
# Cachar | 9/35
# Valley Hospital
# Cachar | 10/35
# RJ MEDICITY A Multi-speciality Hospital
# Cachar | 11/35
# Life Line Hospital
# Cachar | 12/35
# Silchar Medical College and Hospital
# Cachar | 13/35
# R E HOSPITAL
# Cachar | 14/35
# MEDINOVA HOSPITAL
# Cachar | 15/35
# Labac Hospital
# Cachar | 16/35
# Apollo Clinic Silchar
# Cachar | 17/35
# LAMINA HOSPITAL
# Cachar | 18/35
# Prime Health Care (PHC)
# Cachar | 19/35
# Nightingale Hospital
# Cachar | 20/35
# Silchar Medical Centre
# Cachar | 21/35
# HIGHLAND COMMUNITY HOSPITAL UJAN TARAPUR POILAPOOL ROAD CACHAR ASSAM 788098
# Cachar | 22/35
# Kachudaram Model Hospital
# Cachar | 23/35
# SILCHAR CANCER CENTRE,ASSAM CANCER CARE FOUNDATION
# Cachar | 24/35
# Burrows Memorial Christian Hospital (BMCH) Alipur
# Cachar | 25/35
# Regional Research Institute of Unani Medicine RRIUM,Silchar
# Cachar | 26/35
# Silchar Health Care
# Cachar | 27/35
# SUDIPTA NURSING HOME
# Cachar | 28/35
# Silchar Cancer Centre
# Cachar | 29/35
# CGHS Wellness Center Silchar
# Cachar | 30/35
# Medinova
# Cachar | 31/35
# Kalakhal Hospital
# Cachar | 32/35
# Kelma Rural Sub Hospital
# Cachar | 33/35
# Quickobook- Book Doctor Appointment Online
# Backup Saved
# Cachar | 34/35
# Dr. Bhaskar Gupta
# Cachar | 35/35
# Narainpur Grant Arogya Mandir
#
# Searching: hospitals in Charaideo Assam
# Search Submitted
# Charaideo | hospitals | Scroll 1 -> 16
# Charaideo | hospitals | Scroll 2 -> 18
# Charaideo | hospitals | Scroll 3 -> 18
# Charaideo | hospitals | Scroll 4 -> 18
# Charaideo | hospitals | Scroll 5 -> 18
# Charaideo | hospitals | Scroll 6 -> 18
# Collected 18 links
# Charaideo | 1/18
# Charaideo hospital
# Charaideo | 2/18
# Sonari Civil Hospital
# Charaideo | 3/18
# Siu-Ka-Pha Multispeciality Hospital
# Charaideo | 4/18
# P.B. Hospital & Diagnostic Research Centre
# Charaideo | 5/18
# Rajapukhuri Hospital
# Charaideo | 6/18
# Sonari Town Hospital
# Charaideo | 7/18
# Sivasagar Civil Hospital
# Charaideo | 8/18
# Borhat Te Hospital
# Charaideo | 9/18
# Pragati Hospital and Research Centre
# Charaideo | 10/18
# Joint Director of Health Services Charaideo
# Charaideo | 11/18
# SM Diagnostic Centre & Hospital
# Charaideo | 12/18
# Sapekhati Hospital
# Charaideo | 13/18
# Moran Tiloi C.H.C
# Charaideo | 14/18
# Brahmaputra Hospital
# Charaideo | 15/18
# Chanakya Diagnostic Clinic | Dr. Biraj Kr Gogoi | Best Diagnostic Clinic in Sonari, Assam | Hypertension, Diabetes Mellitus
# Charaideo | 16/18
# Charaideo Medical College
# Charaideo | 17/18
# Charaibahi Hospital
# Charaideo | 18/18
# New Towkok hospital
#
# Searching: hospitals in Chirang Assam
# Search Submitted
# Chirang | hospitals | Scroll 1 -> 16
# Chirang | hospitals | Scroll 2 -> 18
# Chirang | hospitals | Scroll 3 -> 18
# Chirang | hospitals | Scroll 4 -> 18
# Chirang | hospitals | Scroll 5 -> 18
# Chirang | hospitals | Scroll 6 -> 18
# Collected 12 links
# Chirang | 1/12
# Bijni sub divisonal civil hospital
# Chirang | 2/12
# Aastha Multispeciality Hospital Bongaigaon,Dhaligaon
# Chirang | 3/12
# Ballamguri BPHC
# Chirang | 4/12
# Joint director of health services, Chirang
# Chirang | 5/12
# Gargaon PHC
# Chirang | 6/12
# Indian Oil Corporation Ltd Bongaigaon Refinery
# Chirang | 7/12
# Joint Director of Health Services Chirang
# Chirang | 8/12
# Basugaon MPHC
# Chirang | 9/12
# Ulubari Subsidiary Health Centre
# Chirang | 10/12
# Dr. S. Kumar Clinic
# Chirang | 11/12
# DR. NIRDESH TIWARI
# Chirang | 12/12
# Enamul Haque Home 🏡
#
# Searching: hospitals in Darrang Assam
# Search Submitted
# Darrang | hospitals | Scroll 1 -> 16
# Darrang | hospitals | Scroll 2 -> 20
# Darrang | hospitals | Scroll 3 -> 28
# Darrang | hospitals | Scroll 4 -> 35
# Darrang | hospitals | Scroll 5 -> 35
# Darrang | hospitals | Scroll 6 -> 35
# Darrang | hospitals | Scroll 7 -> 35
# Darrang | hospitals | Scroll 8 -> 35
# Collected 34 links
# Darrang | 1/34
# Mangaldai civil hospital
# Darrang | 2/34
# Deomornoi Hospital
# Darrang | 3/34
# Assam cancer care, Darrang, Mangaldoi
# Darrang | 4/34
# GNRC Hospitals, Dispur Unit
# Darrang | 5/34
# Dew Care Hospital LLP
# Darrang | 6/34
# GATE Hospital
# Darrang | 7/34
# Apollo Hospitals | Best Hospital in Guwahati
# Darrang | 8/34
# Mangaldai civil maternity and child hospital
# Darrang | 9/34
# Child Health Hospital Mangaldai
# Darrang | 10/34
# Sun Valley Hospital
# Darrang | 11/34
# Debsons Nursing Home
# Darrang | 12/34
# Dreamlight Hospital and reasearch center Pvt Ltd
# Darrang | 13/34
# Ramesh Deka Memorial Hospital, Deuduar
# Darrang | 14/34
# Global Hospital of Surgery
# Darrang | 15/34
# Jaljali PHC
# Darrang | 16/34
# DARRANG CANCER CENTRE
# Darrang | 17/34
# St. John's Hospital
# Darrang | 18/34
# Dr Debabrat Moran
# Darrang | 19/34
# Govt Hospital
# Darrang | 20/34
# Red Cross Hospital
# Darrang | 21/34
# Bluebird Healthcare
# Darrang | 22/34
# Dr. Kaustav Saharia - Consultant Orthopaedic Surgeon & Complex trauma specialist(AO TRAUMA FELLOW)| 24*7 Emergency Services |
# Darrang | 23/34
# Dr. Prasanta Goswami
# Darrang | 24/34
# Sub..Hospital...
# Darrang | 25/34
# Daroga Khat Primary Health Sub Center
# Darrang | 26/34
# Sub Centre
# Darrang | 27/34
# East End Nursing Home & Research Institute
# Darrang | 28/34
# Assam Cancer Care Foundation
# Darrang | 29/34
# Tarabari SHC AAM
# Darrang | 30/34
# Khandahkhaity Char P.H.C.
# Darrang | 31/34
# Pragjyoti Eye Care & Research Centre Pvt. Ltd.
# Darrang | 32/34
# MAKARAPARA SUB CENTRE
# Darrang | 33/34
# Dr. Iftikar Hussain | MD | Psychiatry | Deaddiction specialist | Sexologist
# Darrang | 34/34
# Dr. Bipul Ch. Kalita
#
# Searching: hospitals in Dhemaji Assam
# Search Submitted
# Dhemaji | hospitals | Scroll 1 -> 4
# Dhemaji | hospitals | Scroll 2 -> 4
# Dhemaji | hospitals | Scroll 3 -> 4
# Dhemaji | hospitals | Scroll 4 -> 4
# Dhemaji | hospitals | Scroll 5 -> 4
# Collected 4 links
# Dhemaji | 1/4
# Dhemaji Civil Hospital
# Dhemaji | 2/4
# Bcb care hospital Pvt Ltd
# Dhemaji | 3/4
# Mili Nursing Home
# Dhemaji | 4/4
# Dhemaji MCH
#
# Searching: hospitals in Dhubri Assam
# Search Submitted
# Dhubri | hospitals | Scroll 1 -> 9
# Dhubri | hospitals | Scroll 2 -> 9
# Dhubri | hospitals | Scroll 3 -> 9
# Dhubri | hospitals | Scroll 4 -> 9
# Dhubri | hospitals | Scroll 5 -> 9
# Collected 9 links
# Dhubri | 1/9
# Dhubri Medical College and Hospital
# Dhubri | 2/9
# Chilarai Multispeciality Hospital
# Dhubri | 3/9
# Dhubri City Hospital
# Dhubri | 4/9
# T.B Hospital, Dhubri
# Dhubri | 5/9
# Gauripur Hospital Pvt Ltd
# Dhubri | 6/9
# Popular Hospital Gauripur | Dhubri
# Dhubri | 7/9
# Hatsingimari Global Hospital
# Dhubri | 8/9
# Chilarai Eye Hospital
# Dhubri | 9/9
# Dr. JOYNAL ABEDIN
#
# Searching: hospitals in Dibrugarh Assam
# Search Submitted
# Dibrugarh | hospitals | Scroll 1 -> 16
# Dibrugarh | hospitals | Scroll 2 -> 20
# Dibrugarh | hospitals | Scroll 3 -> 27
# Dibrugarh | hospitals | Scroll 4 -> 27
# Dibrugarh | hospitals | Scroll 5 -> 27
# Dibrugarh | hospitals | Scroll 6 -> 27
# Dibrugarh | hospitals | Scroll 7 -> 27
# Collected 27 links
# Dibrugarh | 1/27
# SWASTHA HOSPITAL
# Dibrugarh | 2/27
# Srimanta Sankardeva Hospital (SSHRI)- Best Hospital In Dibrugarh.
# Dibrugarh | 3/27
# Srishti Hospitals & Research Centre
# Dibrugarh | 4/27
# MAGPINS MULTI SPECIALITY HOSPITAL
# Dibrugarh | 5/27
# APEKSHA HOSPITAL- Top Multi Speciality Hospital in Dibrugarh
# Dibrugarh | 6/27
# Aditya Superspeciality Hospital
# Dibrugarh | 7/27
# M.F. Hospital & Research Centre
# Dibrugarh | 8/27
# Dibrugarh Medicity
# Dibrugarh | 9/27
# UROVISION HOSPITAL
# Dibrugarh | 10/27
# Sanjivani Diagnostics & Hospital ( Superspeciality Hospital)
# Dibrugarh | 11/27
# H.M.Hospital & Diagnostic Centre
# Dibrugarh | 12/27
# Aditya Diagnostics & Hospitals
# Dibrugarh | 13/27
# Brahmaputra Diagnostics & Hospital Ltd.
# Dibrugarh | 14/27
# G.M. Hospital Private Limited
# Dibrugarh | 15/27
# Marwari Arogya Bhawan Hospital
# Dibrugarh | 16/27
# Ayush Hospital
# Dibrugarh | 17/27
# MGM Hospital
# Dibrugarh | 18/27
# Archana Trauma & Orthopaedics Hospital & Research Centre
# Dibrugarh | 19/27
# Medicare Hospitals
# Dibrugarh | 20/27
# JJM Hospital Dibrugarh
# Dibrugarh | 21/27
# Pooja Hospital & Diagnostic Center
# Backup Saved
# Dibrugarh | 22/27
# Astha Hospital
# Dibrugarh | 23/27
# V.G. Hospital
# Dibrugarh | 24/27
# Dibrugarh State Hospital (Civil Hospital)
# Dibrugarh | 25/27
# Dr. Damani's Nursing Home
# Dibrugarh | 26/27
# 11
# Dibrugarh | 27/27
# Aziz Diagnostic & Hospital
#
# Searching: hospitals in Dima Hasao Assam
# Search Submitted
# Dima Hasao | hospitals | Scroll 1 -> 4
# Dima Hasao | hospitals | Scroll 2 -> 4
# Dima Hasao | hospitals | Scroll 3 -> 4
# Dima Hasao | hospitals | Scroll 4 -> 4
# Dima Hasao | hospitals | Scroll 5 -> 4
# Collected 4 links
# Dima Hasao | 1/4
# Joint Director of Health Services, Haflong
# Dima Hasao | 2/4
# Holy Spirit Hospital Haflong
# Dima Hasao | 3/4
# Lumding Railway Hospital
# Dima Hasao | 4/4
# Harangajao P.H.C.
#
# Searching: hospitals in Goalpara Assam
# Search Submitted
# Goalpara | hospitals | Scroll 1 -> 12
# Goalpara | hospitals | Scroll 2 -> 12
# Goalpara | hospitals | Scroll 3 -> 12
# Goalpara | hospitals | Scroll 4 -> 12
# Goalpara | hospitals | Scroll 5 -> 12
# Collected 11 links
# Goalpara | 1/11
# Seven Sisters Hospital & Research Centre
# Goalpara | 2/11
# Florence Hospital
# Goalpara | 3/11
# Al-Salam Hospital, Goalpara Town
# Goalpara | 4/11
# Goalpara Civil Hospital
# Goalpara | 5/11
# Heal Care
# Goalpara | 6/11
# Life Care Hospital & RCS Ltd.
# Goalpara | 7/11
# NORTHEAST HIGHER MEDICAL SCIENCE AND HOSPITAL
# Goalpara | 8/11
#
# Goalpara | 9/11
# Critical care hospitals
# Goalpara | 10/11
#
# Goalpara | 11/11
# Medimax Polyclinic & Diagnostic Centre
#
# Searching: hospitals in Golaghat Assam
# Search Submitted
# Golaghat | hospitals | Scroll 1 -> 12
# Golaghat | hospitals | Scroll 2 -> 12
# Golaghat | hospitals | Scroll 3 -> 12
# Golaghat | hospitals | Scroll 4 -> 12
# Golaghat | hospitals | Scroll 5 -> 12
# Collected 12 links
# Golaghat | 1/12
# Kushal Konwar Civil Hospital স্বহীদ কুশল কোঁৱৰ অসামৰিক চিকিৎসালয়
# Golaghat | 2/12
# GOLAGHAT MEDICAL COLLEGE AND HOSPITAL
# Golaghat | 3/12
# LIFE LINE HOSPITAL & RESEARCH CENTRE
# Golaghat | 4/12
# Golaghat Nursing Home Pvt Ltd
# Golaghat | 5/12
# MediTree Clinic and Diagnostic Centre LLP
# Golaghat | 6/12
# GBM NURSING HOME
# Golaghat | 7/12
# Dr.Nayan Dutta ,s clinic ,Golaghat | Best physician
# Golaghat | 8/12
# Golaghat Medical College`
# Golaghat | 9/12
# Bengenakhowa Jallan Tea Estate Hospital.Golaghat Assam
# Golaghat | 10/12
# KKC Hospital
# Golaghat | 11/12
# Eye Department,K.K.Civil Hospital
# Golaghat | 12/12
# HGM Nursing Home
#
# Searching: hospitals in Hailakandi Assam
# Search Submitted
# Hailakandi | hospitals | Scroll 1 -> 9
# Hailakandi | hospitals | Scroll 2 -> 9
# Hailakandi | hospitals | Scroll 3 -> 9
# Hailakandi | hospitals | Scroll 4 -> 9
# Hailakandi | hospitals | Scroll 5 -> 9
# Collected 9 links
# Hailakandi | 1/9
# Hailakandi Civil Hospital
# Hailakandi | 2/9
# AROTI HOSPITAL AND DIAGNOSTICS
# Hailakandi | 3/9
# Shifa Hospital & Reasearch Centre
# Hailakandi | 4/9
# S.K.Roy Civil Hospital
# Hailakandi | 5/9
# Old Hospital Point Hailakandi
# Hailakandi | 6/9
# Pacific Healthcare
# Hailakandi | 7/9
# Shifa Hospital Bus Stand Hailakandi
# Hailakandi | 8/9
# Assam X-Ray Clinic(Assam Diagnostics)
# Hailakandi | 9/9
# ASTHA HEALTH CARE
#
# Searching: hospitals in Hojai Assam
# Search Submitted
# Hojai | hospitals | Scroll 1 -> 16
# Hojai | hospitals | Scroll 2 -> 20
# Hojai | hospitals | Scroll 3 -> 20
# Hojai | hospitals | Scroll 4 -> 20
# Hojai | hospitals | Scroll 5 -> 20
# Hojai | hospitals | Scroll 6 -> 20
# Collected 20 links
# Hojai | 1/20
# HAMM Hospital & Research Centre
# Hojai | 2/20
# Star Health Care Hospital & Research Centre
# Hojai | 3/20
# Hojai FRU
# Hojai | 4/20
# MIDTOWN HOSPITAL
# Hojai | 5/20
# Prime Medical Centre
# Hojai | 6/20
# District Civil Hospital Hojai
# Hojai | 7/20
# HAMM hospital Dialysis Unit
# Hojai | 8/20
# DR N L BHAGAT, GLOBAL HOSPITAL, Nerve and Joint pain specialist, Rheumatologic pain.
# Hojai | 9/20
# BNB Medicare - Polyclinic & Diagnostics
# Hojai | 10/20
# Prime
# Hojai | 11/20
# Gate Dey's Multi-speciality Hospital
# Hojai | 12/20
# Starline Travels
# Hojai | 13/20
# Dr. A Khair Hospital
# Hojai | 14/20
# Global Hospital, Tumpreng road, Hojai
# Hojai | 15/20
# Dr Himmat Singh Rathore (Pulmonologist)
# Hojai | 16/20
# Dr. Smita Bhowmik
# Hojai | 17/20
# Mr Injum Hussain ( HAMM HOSPITAL & RESEARCH CENTRE
# Hojai | 18/20
# Brahmaputra Medicos
# Hojai | 19/20
# Dr Neeraj Sharma Child Specialist
# Hojai | 20/20
# Medimax Health Clinic
#
# Searching: hospitals in Jorhat Assam
# Search Submitted
# Jorhat | hospitals | Scroll 1 -> 16
# Jorhat | hospitals | Scroll 2 -> 20
# Jorhat | hospitals | Scroll 3 -> 21
# Jorhat | hospitals | Scroll 4 -> 21
# Jorhat | hospitals | Scroll 5 -> 21
# Jorhat | hospitals | Scroll 6 -> 21
# Jorhat | hospitals | Scroll 7 -> 21
# Collected 21 links
# Jorhat | 1/21
# Sanjivani Hospital
# Jorhat | 2/21
# Mission Hospital
# Jorhat | 3/21
# Niramoy Hospital and Research Centre
# Jorhat | 4/21
# Jorhat Christian Medical Centre
# Jorhat | 5/21
# Satyam Hospital And Research Centre
# Jorhat | 6/21
# Jorhat Lions Eye Hospital
# Jorhat | 7/21
# Chandraprabha Eye Hospital
# Jorhat | 8/21
# Jorhat Medical College OPD Complex
# Jorhat | 9/21
# Imsr Hospital
# Jorhat | 10/21
# Jorhat Medical College & Hospital
# Jorhat | 11/21
# 5 Air Force Hospital Jorhat
# Jorhat | 12/21
# A. G. Nursing Home
# Jorhat | 13/21
# KG Nursing Home
# Jorhat | 14/21
# Jorhat Cancer Centre ACCF
# Jorhat | 15/21
# Malpani Nursing Home
# Jorhat | 16/21
# Barua Surgical Centre
# Jorhat | 17/21
# Ayursundra One Stop Medical Centre
# Jorhat | 18/21
# Civil Hospital
# Jorhat | 19/21
# Apollo Hospitals Information Centre
# Jorhat | 20/21
# Dr Devojit Sharma (Medical Specialist)
# Jorhat | 21/21
# Sanjibani Hospitel
#
# Searching: hospitals in Kamrup Assam
# Search Submitted
# Kamrup | hospitals | Scroll 1 -> 16
# Kamrup | hospitals | Scroll 2 -> 21
# Kamrup | hospitals | Scroll 3 -> 29
# Kamrup | hospitals | Scroll 4 -> 37
# Kamrup | hospitals | Scroll 5 -> 37
# Kamrup | hospitals | Scroll 6 -> 37
# Kamrup | hospitals | Scroll 7 -> 37
# Kamrup | hospitals | Scroll 8 -> 37
# Collected 30 links
# Kamrup | 1/30
# Narayana Hospital, Guwahati
# Kamrup | 2/30
# GNRC Medical, North Guwahati
# Kamrup | 3/30
# Mirza Multispeciality Hospital
# Kamrup | 4/30
# North Guwahati Multi-speciality Hospital
# Kamrup | 5/30
# SYGNUS HOSPITALS
# Kamrup | 6/30
# Kamrup Civil Hospital
# Kamrup | 7/30
# Nemcare Super Speciality Hospital
# Kamrup | 8/30
# LIFE SAVE HOSPITAL, Haligaon Batarhat
# Kamrup | 9/30
# New 100-Bed District hospital, Azara
# Kamrup | 10/30
# Aruna Memorial Hospital
# Kamrup | 11/30
# Sanjevani Hospital
# Kamrup | 12/30
# Guwahati Metro Hospital
# Kamrup | 13/30
# Akanksha Hospital
# Kamrup | 14/30
# Kokrajhar | hospitals | Scroll 3 -> 12
# Kokrajhar | hospitals | Scroll 4 -> 12
# Kokrajhar | hospitals | Scroll 5 -> 12
# Collected 12 links
# Kokrajhar | 1/12
# Kokrajhar Medical College and Hospital
# Kokrajhar | 2/12
# Rupnath Brahma Civil Hospital, Kokrajhar
# Kokrajhar | 3/12
# M.R.M. Memorial Hospital
# Kokrajhar | 4/12
# Nilachal Hospital & Research Centre
# Kokrajhar | 5/12
# Rnb civil hospital kokrajhar
# Kokrajhar | 6/12
# Kokrajhar Cancer Care Hospital
# Kokrajhar | 7/12
# Rnb Civil Hospital kokrajhar
# Kokrajhar | 8/12
# R.N.B Hospital Quarter Complex
# Kokrajhar | 9/12
# Health Center (CIT, Kokrajhar)
# Kokrajhar | 10/12
# Apollo Diagnostics - Blood Tests - Home Collection & Full Body Checkups Kokrajhar
# Kokrajhar | 11/12
# Dr D Sharma's Clinic
# Kokrajhar | 12/12
# City Clinic, Kokrajhar
#
# Searching: hospitals in Lakhimpur Assam
# Search Submitted
# Lakhimpur | hospitals | Scroll 1 -> 16
# Lakhimpur | hospitals | Scroll 2 -> 20
# Lakhimpur | hospitals | Scroll 3 -> 21
# Lakhimpur | hospitals | Scroll 4 -> 21
# Lakhimpur | hospitals | Scroll 5 -> 21
# Lakhimpur | hospitals | Scroll 6 -> 21
# Lakhimpur | hospitals | Scroll 7 -> 21
# Collected 21 links
# Lakhimpur | 1/21
# MidTown Hospital & Research Institute
# Lakhimpur | 2/21
# Dr. Das Hospital & Diagnostic Center
# Lakhimpur | 3/21
# Royal Treat Hospital
# Lakhimpur | 4/21
# DR DAS MULTISPECIALITY HOSPITAL
# Lakhimpur | 5/21
# Silvercrest Multi-Speciality Hospital
# Lakhimpur | 6/21
# DM Hospital
# Lakhimpur | 7/21
# Avaneesh Hospital
# Lakhimpur | 8/21
# Barnil Polyclinic And Hospital, North Lakhimpur
# Lakhimpur | 9/21
# Holy City Clinic and Diagnostic Centre
# Lakhimpur | 10/21
# Dr. Amiya's Maternity & Infertility Research Centre
# Lakhimpur | 11/21
# Saumerpith Hospital
# Lakhimpur | 12/21
# North,Lakhimpur,/ RAJDHANI / AIR ? Ambulance Service 24x7 Day/Night Service /& DEAD BODY/Freezer Box & Coffin Box available
# Lakhimpur | 13/21
# Saumerpith Nursing | Medical Center | North Lakhimpur
# Lakhimpur | 14/21
# Srajan Hospital Pvt Ltd
# Lakhimpur | 15/21
# Lakhimpur Eye Hospital
# Lakhimpur | 16/21
# Lakhimpur Medical College
# Lakhimpur | 17/21
# Apollo Diagnostics &Teleclinic Apollo Information Centre North Lakhimpur
# Lakhimpur | 18/21
# Tulsi memorial hospital
# Backup Saved
# Lakhimpur | 19/21
# Chandrani Hospital
# Lakhimpur | 20/21
# Laluk Hospital Chariali
# Lakhimpur | 21/21
# Lakhimpur Cancer Centre
#
# Searching: hospitals in Majuli Assam
# Search Submitted
# Majuli | hospitals | Scroll 1 -> 2
# Majuli | hospitals | Scroll 2 -> 2
# Majuli | hospitals | Scroll 3 -> 2
# Breathe Wellness Centre
# Nagaon | 26/35
# Chennai Apollo Hospitals Information Centre,Nagaon
# Nagaon | 27/35
# Global Healthcare
# Nagaon | 28/35
# SIMS Multi-speciality Hospital
# Nagaon | 29/35
# G D Hospital
# Nagaon | 30/35
# MSN CATARACT AND IOL HOSPITAL
# Nagaon | 31/35
# Sausaria Nursing Home
# Nagaon | 32/35
# Dr. Naba Krishna Gohain | Top orthopaedic surgeon in Nagaon | Orthopaedic Specialist | Orthopaedic Doctor
# Nagaon | 33/35
# Dr. Gautam’s Brahmaputra Eye Care
# Nagaon | 34/35
# Nagaon Nursing & Meternity Home
# Nagaon | 35/35
# ESIC DIAPENSARY NAGAON
#
# Searching: hospitals in Nalbari Assam
# Search Submitted
# Nalbari | hospitals | Scroll 1 -> 14
# Nalbari | hospitals | Scroll 2 -> 14
# Nalbari | hospitals | Scroll 3 -> 14
# Nalbari | hospitals | Scroll 4 -> 14
# Nalbari | hospitals | Scroll 5 -> 14
# Collected 13 links
# Nalbari | 1/13
# Nalbari Maternity Hospital
# Nalbari | 2/13
# UNITED HOSPITAL
# Nalbari | 3/13
# Sushrusa Hospital, Nalbari
# Nalbari | 4/13
# SMK Civil Hospital, Nalbari
# Nalbari | 5/13
# Medinova Hospital
# Nalbari | 6/13
# NAVADWEEP HOSPITAL
# Nalbari | 7/13
#
# Nalbari | 8/13
# Tapan Deka's Sarathi Hospital
# Nalbari | 9/13
# Nalbari Super Speciality Clinic
# Nalbari | 10/13
#
# Nalbari | 11/13
#
# Nalbari | 12/13
# AROGYA DIAGNOSTICS & HEALTH CHECK-UP CENTRE
# Nalbari | 13/13
# Vatenery hospital, Nalbari
#
# Searching: hospitals in Sivasagar Assam
# Search Submitted
# Sivasagar | hospitals | Scroll 1 -> 14
# Sivasagar | hospitals | Scroll 2 -> 14
# Sivasagar | hospitals | Scroll 3 -> 14
# Sivasagar | hospitals | Scroll 4 -> 14
# Sivasagar | hospitals | Scroll 5 -> 14
# Collected 11 links
# Sivasagar | 1/11
# Sampreeti Hospital
# Sivasagar | 2/11
# East Point Hospital & Research Centre
# Sivasagar | 3/11
# ERC Eye Care Hub Hospital, Sivasagar
# Sivasagar | 4/11
# ONGC Hospital
# Sivasagar | 5/11
# Aditya Diagnostics and Hospital (Sivasagar)
# Sivasagar | 6/11
# Sarma Nursing Home
# Sivasagar | 7/11
# Sivasagar Netralay
# Sivasagar | 8/11
# Sibsagar
# Sivasagar | 9/11
# Demow Model Hospital cum CHC
# Sivasagar | 10/11
# Swargadew Siu Ka Pha Multispecialty Hospital
# Sivasagar | 11/11
# Pragati Hospital And Research Center
#
# Searching: hospitals in Sonitpur Assam
# Search Submitted
# Sonitpur | hospitals | Scroll 1 -> 16
# Sonitpur | hospitals | Scroll 2 -> 20
# Sonitpur | hospitals | Scroll 3 -> 27
# Sonitpur | hospitals | Scroll 4 -> 27
# Sonitpur | hospitals | Scroll 5 -> 27
# Sonitpur | hospitals | Scroll 6 -> 27
# Sonitpur | hospitals | Scroll 7 -> 27
# Collected 24 links
# Sonitpur | 1/24
# Nemcare Hospital Tezpur Pvt. Ltd.
# Sonitpur | 2/24
# Dorika Hospital
# Sonitpur | 3/24
# TIMeS Hospital
# Sonitpur | 4/24
# NARAYANA HEALTH CARE SUPER SPECIALITY HOSPITAL
# Sonitpur | 5/24
# Kanaklata Civil Hospital TEZPUR
# Sonitpur | 6/24
# B-J Hospital
# Sonitpur | 7/24
# B. K. Memorial Hospital
# Sonitpur | 8/24
# EMM Hospital
# Sonitpur | 9/24
# EMM HOSPITAL & RESEARCH CENTER - Gynaecology Hospital In Tezpur/Laparoscopic/Medical Specialist/Ivf Centre Hospital In Tezpur
# Sonitpur | 10/24
# Baptist Christian Hospital
# Sonitpur | 11/24
# Ananta Memorial Hospital
# Sonitpur | 12/24
# Dhekiajuli CHC
# Sonitpur | 13/24
# Shankara Cancer & Research Institute
# Sonitpur | 14/24
# Bishnujyoti Super Speciality Hospital
# Sonitpur | 15/24
# C.L.M. Chest Hospital Tezpur
# Sonitpur | 16/24
# SEVA NIVAS HOSPITAL
# Sonitpur | 17/24
# ERC Eye Care Hub Hospital, Tezpur
# Sonitpur | 18/24
# LGB Regional Institute of Mental Health
# Sonitpur | 19/24
# Star Health & Allied Insurance - Sonitpur, Assam
# Sonitpur | 20/24
# JJ Hospital
# Sonitpur | 21/24
# Dr. Subrata Kakoti (Child Specialist)
# Sonitpur | 22/24
# Dr. Tanuj Nayyar MBBS, DNB (Neurosurgery)
# Sonitpur | 23/24
# Dhekiajuli Eye Hospital
# Sonitpur | 24/24
# dr.m.mirdha
#
# Searching: hospitals in South Salmara-Mankachar Assam
# Search Submitted
# South Salmara-Mankachar | hospitals | Scroll 1 -> 11
# South Salmara-Mankachar | hospitals | Scroll 2 -> 11
# South Salmara-Mankachar | hospitals | Scroll 3 -> 11
# South Salmara-Mankachar | hospitals | Scroll 4 -> 11
# South Salmara-Mankachar | hospitals | Scroll 5 -> 11
# Collected 9 links
# South Salmara-Mankachar | 1/9
# South Salmara mankachar Hatsingimari district Ambulance association (ASSAM)
# South Salmara-Mankachar | 2/9
# S.M. Hospital, kharuabandha
# South Salmara-Mankachar | 3/9
# Hatsingimari Civil Hospital
# Backup Saved
# South Salmara-Mankachar | 4/9
# Salmara HWC & sub-center
# South Salmara-Mankachar | 5/9
# Salmara Hospital
# South Salmara-Mankachar | 6/9
# SHYAMGURI HOSPITAL
# South Salmara-Mankachar | 7/9
# Joint Director of Health Services, South Salmara Mankachar
# South Salmara-Mankachar | 8/9
# LIFE LINE HOSPITAL Hatsingimari
# South Salmara-Mankachar | 9/9
# SRS Polyclinic
#
# Searching: hospitals in Tamulpur Assam
# Search Submitted
# Tamulpur | hospitals | Scroll 1 -> 9
# Tamulpur | hospitals | Scroll 2 -> 9
# Tamulpur | hospitals | Scroll 3 -> 9
# Tamulpur | hospitals | Scroll 4 -> 9
# Tamulpur | hospitals | Scroll 5 -> 9
# Collected 9 links
# Tamulpur | 1/9
# Tamulpur Medical College & Hospital
