# %%
import pandas as pd

# %%
df = pd.read_csv("assam_hospitals.csv")

# %%
df.shape
# Out:
# (541, 8)

# %%
df = df[
    df["Phone"].notna() &
    (df["Phone"].astype(str).str.strip() != "")
]

# %%
df.shape
# Out:
# (251, 8)

# %%
df = df[
    df["Hospital Name"].notna()
]

df = df[
    df["Hospital Name"].str.strip() != ""
]

# %%
df.shape
# Out:
# (251, 8)

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]", "", regex=True)  # remove symbols/icons
    .str.strip()
)

display(df[["Phone"]].head())
# Out:
#            Phone
# 1   070864 02700
# 2   070868 80554
# 7   078966 25220
# 8   094357 20622
# 10  070023 95360

# %%
df.to_csv(
    "assam_hospitals_cleaned.csv",
    index=False
)
