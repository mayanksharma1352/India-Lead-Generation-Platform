# %%
import time
import random
import pandas as pd

from datetime import datetime

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.service import Service

from webdriver_manager.chrome import ChromeDriverManager


# Odisha DISTRICTS

districts = [
    "Angul",
    "Balangir",
    "Balasore",
    "Bargarh",
    "Bhadrak",
    "Boudh",
    "Cuttack",
    "Deogarh",
    "Dhenkanal",
    "Gajapati",
    "Ganjam",
    "Jagatsinghpur",
    "Jajpur",
    "Jharsuguda",
    "Kalahandi",
    "Kandhamal",
    "Kendrapara",
    "Kendujhar",
    "Khordha",
    "Koraput",
    "Malkangiri",
    "Mayurbhanj",
    "Nabarangpur",
    "Nayagarh",
    "Nuapada",
    "Puri",
    "Rayagada",
    "Sambalpur",
    "Subarnapur",
    "Sundargarh"
]


# SEARCH TYPES

search_types = [
    "schools"
]

# CHROME OPTIONS

options = webdriver.ChromeOptions()

options.add_argument("--start-maximized")

options.add_argument(
    "--disable-blink-features=AutomationControlled"
)

options.add_argument("--disable-notifications")

# START DRIVER

driver = webdriver.Chrome(

    service=Service(
        ChromeDriverManager().install()
    ),

    options=options
)


# OPEN GOOGLE MAPS

driver.get("https://www.google.com/maps")

print("Opening Google Maps...")

time.sleep(15)

print("Google Maps Loaded")


# STORAGE


all_data = []

visited_links = set()


# SEARCH BOX FUNCTION


def get_search_box():

    selectors = [

        '//input[@id="searchboxinput"]',
        '//input[contains(@placeholder,"Search")]',
        '//input[contains(@aria-label,"Search")]',
        '//input'

    ]

    for selector in selectors:

        try:

            box = driver.find_element(
                By.XPATH,
                selector
            )

            return box

        except:
            pass

    return None

# EXTRACT SCHOOL DATA

def extract_school_data():

    try:

        # SCHOOL NAME
        try:
            name = driver.find_element(
                By.TAG_NAME,
                "h1"
            ).text
        except:
            name = ""

        # ADDRESS
        try:
            address = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"address")]'
            ).text
        except:
            address = ""

        # PHONE
        try:
            phone = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"phone")]'
            ).text
        except:
            phone = ""

        # WEBSITE
        try:
            website = driver.find_element(
                By.XPATH,
                '//a[contains(@data-item-id,"authority")]'
            ).get_attribute("href")
        except:
            website = ""

        # RATING
        try:
            rating = driver.find_element(
                By.XPATH,
                '//div[@role="img"]'
            ).get_attribute("aria-label")
        except:
            rating = ""

        return {

            "School Name": name,
            "Address": address,
            "Phone": phone,
            "Website": website,
            "Rating": rating,
            "Google Maps URL": driver.current_url

        }

    except:

        return None


# START EXTRACTION

for district in districts:

    for search_type in search_types:

        try:

            query = (
                f"{search_type} "
                f"in {district} Odisha"
            )

            print(f"\nSearching: {query}")

   
            # SEARCH

            search_box = get_search_box()

            if not search_box:

                print("Search Box Not Found")

                continue

            ActionChains(driver).move_to_element(
                search_box
            ).click().perform()

            time.sleep(1)

            search_box.send_keys(
                Keys.CONTROL + "a"
            )

            time.sleep(1)

            search_box.send_keys(Keys.DELETE)

            time.sleep(1)

            # TYPE SLOWLY
            for char in query:

                search_box.send_keys(char)

                time.sleep(0.03)

            search_box.send_keys(Keys.ENTER)

            print("Search Submitted")

            time.sleep(8)

            # SCROLL RESULTS

            try:

                scrollable_div = driver.find_element(
                    By.XPATH,
                    '//div[@role="feed"]'
                )

                previous_count = 0

                stagnant = 0

                for i in range(100):

                    driver.execute_script(
                        """
                        arguments[0].scrollTop =
                        arguments[0].scrollHeight
                        """,
                        scrollable_div
                    )

                    time.sleep(4)

                    listings = driver.find_elements(
                        By.XPATH,
                        '//a[contains(@href,"/maps/place/")]'
                    )

                    current_count = len(listings)

                    print(
                        f"{district} | "
                        f"{search_type} | "
                        f"Scroll {i+1} -> "
                        f"{current_count}"
                    )

                    if current_count == previous_count:

                        stagnant += 1

                    else:

                        stagnant = 0

                    if stagnant >= 4:

                        break

                    previous_count = current_count

            except Exception as e:

                print(f"Scrolling Error: {e}")

            # GET LINK

            listings = driver.find_elements(
                By.XPATH,
                '//a[contains(@href,"/maps/place/")]'
            )

            links = []

            for listing in listings:

                try:

                    link = listing.get_attribute("href")

                    if (
                        link
                        and link not in visited_links
                    ):

                        links.append(link)

                        visited_links.add(link)

                except:
                    pass

            print(f"Collected {len(links)} links")

            # VISIT EACH SCHOOL

            for index, link in enumerate(links):

                try:

                    print(
                        f"{district} | "
                        f"{index+1}/{len(links)}"
                    )

                    driver.get(link)

                    time.sleep(
                        random.uniform(2, 3)
                    )

                    data = extract_school_data()

                    if data:

                        data["District"] = district

                        data["Search Type"] = search_type

                        all_data.append(data)

                        print(data["School Name"])

   
                    # BACKUP SAVE

                    if len(all_data) % 100 == 0:

                        backup_df = pd.DataFrame(
                            all_data
                        )

                        backup_df.drop_duplicates(
                            subset=[
                                "School Name",
                                "Google Maps URL"
                            ],
                            inplace=True
                        )

                        backup_df.to_csv(
                            "odisha_schools_backup.csv",
                            index=False
                        )

                        print("Backup Saved")

                except Exception as e:

                    print(
                        f"School Error: {e}"
                    )

        except Exception as e:

            print(
                f"District Error: {e}"
            )

# FINAL SAVE


df = pd.DataFrame(all_data)

df.drop_duplicates(

    subset=[
        "School Name",
        "Google Maps URL"
    ],

    inplace=True
)

# UNIQUE FILE NAME

filename = (
    f"odisha_schools.csv"
)

df.to_csv(
    filename,
    index=False
)

print("\nExtraction Completed")

print(
    f"Total Schools Extracted: {len(df)}"
)

print(f"\nSaved File: {filename}")

driver.quit()
# Out:
# Opening Google Maps...
# Google Maps Loaded
#
# Searching: schools in Angul Odisha
# Search Submitted
# Angul | schools | Scroll 1 -> 14
# Angul | schools | Scroll 2 -> 20
# Angul | schools | Scroll 3 -> 27
# Angul | schools | Scroll 4 -> 34
# Angul | schools | Scroll 5 -> 40
# Angul | schools | Scroll 6 -> 47
# Angul | schools | Scroll 7 -> 54
# Angul | schools | Scroll 8 -> 60
# Angul | schools | Scroll 9 -> 67
# Angul | schools | Scroll 10 -> 74
# Angul | schools | Scroll 11 -> 80
# Angul | schools | Scroll 12 -> 85
# Angul | schools | Scroll 13 -> 85
# Angul | schools | Scroll 14 -> 85
# Angul | schools | Scroll 15 -> 85
# Angul | schools | Scroll 16 -> 85
# Collected 85 links
# Angul | 1/85
# Adarsha International School,Angul
# Angul | 2/85
# Tapovanam International School, Turanga, Angul, Odisha
# Angul | 3/85
# ODM International School Angul - Kids World
# Angul | 4/85
# Amarvani Convent School
# Angul | 5/85
# Angul High School
# Angul | 6/85
# Saint Lawrence School, Tentoloi
# Angul | 7/85
# St.Xavier's High School
# Angul | 8/85
# Saiantika Global School Angul, A1 Academy Angul
# Angul | 9/85
# PM Shri Kendriya Vidyalaya No.1, Angul
# Angul | 10/85
# Odisha Brigade School
# Angul | 11/85
# Maharishi Vidya Mandir
# Angul | 12/85
# Blooming Buds School, Angul
# Angul | 13/85
# EuroKids PreSchool in Matiasahi, Angul
# Angul | 14/85
# ODM International School Angul
# Angul | 15/85
# Delhi Public School, Nalco Nagar, Angul, Odisha
# Angul | 16/85
# DAV Public School
# Angul | 17/85
# Rotary Public School
# Angul | 18/85
# Sri Chaitanya Techno School
# Angul | 19/85
# ANGEL WINGS PUBLIC SCHOOL, ANGUL
# Angul | 20/85
# Vidya Bharati Academy
# Angul | 21/85
# BLUEMONT ENGLISH SCHOOL
# Angul | 22/85
# Little Champs Play School
# Angul | 23/85
# INFINITY ACADEMY
# Angul | 24/85
# Khalari High School
# Angul | 25/85
# SAMARPANA ACADEMY
# Angul | 26/85
# My Chhota School
# Angul | 27/85
# Delhi Public School (Junior School Campus)
# Angul | 28/85
# Kendriya Vidyalaya No.2 Angul
# Angul | 29/85
# P.M. S.H.R.I. Jawahar Navodaya Vidyalaya , Champatimunda, Angul
# Angul | 30/85
# Kidzee - Best playschool
# Angul | 31/85
# Alphabetz Preschool Amalapada, Angul, Odisha
# Angul | 32/85
# Delhi public school banarpal
# Angul | 33/85
# GOLDY VIDYALOKA PUBLIC SCHOOL
# Angul | 34/85
# Ideal Public School
# Angul | 35/85
# Adarsha school of engineering & International polytechnic,Angul
# Angul | 36/85
# Bachpan Play School in Hakim Pada | Best Preschool Near Me | Nursery School & Kindergarten for Your Child’s Bright Start
# Angul | 37/85
# JUNIOR GEMS PUBLIC SCHOOL
# Angul | 38/85
# PTC high School
# Angul | 39/85
# DAV Public School, MCL, Kalinga Area
# Angul | 40/85
# Omm bidya bharati residential college sikhyakapada
# Angul | 41/85
# Angul Mahila Mahavidyalaya
# Angul | 42/85
# Saraswati Vidya Mandir
# Angul | 43/85
# Kids Express Play School(KEPS)
# Angul | 44/85
# Omm Bidya Bharati Higher secondary school.
# Angul | 45/85
# DAV SAVITRI JINDAL HIGH SCHOOL
# Angul | 46/85
# SSVM, Angul
# Angul | 47/85
# DAV Public School, MCL Jagannath Area,Talcher
# Angul | 48/85
# NLS Public school
# Angul | 49/85
# D.A.V Talcher Thermal High school
# Angul | 50/85
# SPOKEN ENGLISH POINT
# Angul | 51/85
# NAC High School
# Angul | 52/85
# Kangula U.P School
# Angul | 53/85
# Aryavat Institute
# Angul | 54/85
# Brilliant study Centre,DIC Chhak Angul
# Angul | 55/85
# DISTRICT EDUCATION OFFICE
# Angul | 56/85
# St.John's School,Talcher
# Angul | 57/85
# Government Girls' High School
# Angul | 58/85
# SCIENCE STUDY CENTRE
# Angul | 59/85
# D.A.V. Public School, NTPC/TTPS
# Angul | 60/85
# SHREE VINAYAKA ABASIKA VIDYAPITHA
# Angul | 61/85
# Saint Xavier High School
# Angul | 62/85
# Nigamananda Little Star School
# Angul | 63/85
# Aluminium High School
# Angul | 64/85
# Sankha-Jyoti Public School
# Angul | 65/85
# Obbrc College
# Angul | 66/85
# Sura Saptak Kala Niketan
# Angul | 67/85
# Mother Teresa School of Nursing
# Angul | 68/85
# Focus College of Science
# Angul | 69/85
# Niyatee foundation
# Angul | 70/85
# KAUTILYA ACADEMY
# Angul | 71/85
# Genius Brain Institution
# Angul | 72/85
# PSSJ COLLEGE, BANARPAL
# Angul | 73/85
# Vivekanand Tutorial
# Angul | 74/85
# Tarun Mathematics Classes
# Angul | 75/85
# Saint Lawrence School
# Angul | 76/85
# Xavior children school
# Angul | 77/85
# Shreedhruti ITI
# Angul | 78/85
# OM VIDYA MANDIR SCHOOL
# Angul | 79/85
# Angul
# Angul | 80/85
# Binayak Science College
# Angul | 81/85
# 27th ALPHABET CLASSES
# Angul | 82/85
# COMPETITIVE SUCCESS ACADEMY
# Angul | 83/85
# Nalco Nagar Community Center
# Angul | 84/85
# Bachpan Play School in Banarpal | Best Preschool Near Me | Nursery School & Kindergarten for Your Child’s Bright Start
# Angul | 85/85
# M/S ANGUL MINES AND MINERALS DRIVING TRAINING SCHOOL
#
# Searching: schools in Balangir Odisha
# Search Submitted
# Balangir | schools | Scroll 1 -> 14
# Balangir | schools | Scroll 2 -> 20
# Balangir | schools | Scroll 3 -> 27
# Balangir | schools | Scroll 4 -> 34
# Balangir | schools | Scroll 5 -> 40
# Balangir | schools | Scroll 6 -> 47
# Balangir | schools | Scroll 7 -> 54
# Balangir | schools | Scroll 8 -> 60
# Balangir | schools | Scroll 9 -> 67
# Balangir | schools | Scroll 10 -> 67
# Balangir | schools | Scroll 11 -> 67
# Balangir | schools | Scroll 12 -> 67
# Balangir | schools | Scroll 13 -> 67
# Collected 67 links
# Balangir | 1/67
# Balangir Public School
# Balangir | 2/67
# KIDZEE BALANGIR
# Balangir | 3/67
# Blossoms Concept School | Best School in Balangir
# Balangir | 4/67
# Kendriya Vidyalaya No.2 Shastri Nagar, Bolangir
# Balangir | 5/67
# Gyanodaya Academy
# Balangir | 6/67
# Montessori Public School Balangir
# Balangir | 7/67
# My Chhota school Bolangir
# Balangir | 8/67
# Hatisal Para Up school
# Balangir | 9/67
# Genius English Medium School
# Balangir | 10/67
# AIMS Public School, Balangir
# Balangir | 11/67
# Little Flower Nursery School,
# Balangir | 12/67
# Yuvodaya Public School,Balangir
# Balangir | 13/67
# Vikas Valley Vidyalaya
# Balangir | 14/67
# KISS CAMPUS BALANGIR
# Balangir | 15/67
# IPSUM INTERNATIONAL SCHOOL
# Backup Saved
# Balangir | 16/67
# BIDYA BHARATI RESIDENTIAL HIGHSCHOOL BALANGIR
# Balangir | 17/67
# IAE, Balangir
# Balangir | 18/67
# Little Flower School, Bolangir
# Balangir | 19/67
# IDM PUBLIC SCHOOL BAGBHADI BALANGIR
# Balangir | 20/67
# Xavier International School Balangir
# Balangir | 21/67
# Gyan Vihar School
# Balangir | 22/67
# Phoenix International School ( PIS )
# Balangir | 23/67
# New Wings Public School
# Balangir | 24/67
# OAV Patharchepa,Balangir
# Balangir | 25/67
# P.R High School
# Balangir | 26/67
# Centurion Public School
# Balangir | 27/67
# Oriental Public School
# Balangir | 28/67
# Bachpan play school
# Balangir | 29/67
# Narayan Play School, Balangir
# Balangir | 30/67
# Dream India School
# Balangir | 31/67
# Shemford Little Stars - Chandra Shekhar Nagar
# Balangir | 32/67
# Shemford Futuristic School
# Balangir | 33/67
# Town Girls High School
# Balangir | 34/67
# Academic Heights Public School (AHPS) - Best School in bishnumunda I Best CBSE School in bishnumunda I Top School
# Balangir | 35/67
# JITM Higher Secondary School
# Balangir | 36/67
# Dream India Schools Bolangir Odisha
# Balangir | 37/67
# Town boys high school
# Balangir | 38/67
# KITE ACADEMY
# Balangir | 39/67
# Roshni Public School
# Balangir | 40/67
# Thikadar Para Primary School
# Balangir | 41/67
# P.M. S.H.R.I. Jawahar Navodaya Vidyalaya , Belpada, Bolangir
# Balangir | 42/67
# AUM VALLEY SCHOOL
# Balangir | 43/67
# Vidya Bharati Residential School
# Balangir | 44/67
# Spardha Eduventures
# Balangir | 45/67
# Sunday art and craft class
# Balangir | 46/67
# My carrer Academy
# Balangir | 47/67
# Edutickle
# Balangir | 48/67
# Padmanbham Model School
# Balangir | 49/67
# St. Stephen's Model School
# Balangir | 50/67
# CMDTI Driving Training,Balangir
# Balangir | 51/67
# Delhi Public Primary School
# Balangir | 52/67
# Vidvaan Academy
# Balangir | 53/67
# BIDYARTHI INSTITUTE
# Balangir | 54/67
# ShreeJi Institute for B.Ed
# Balangir | 55/67
# Gandhi Institute for B.Ed.
# Balangir | 56/67
# Kendriya Vidyalaya, Badmal, Bolangir No.1
# Balangir | 57/67
# ST.XAVIER'S PUBLIC SCHOOL
# Balangir | 58/67
# Gayatri +2 Science College,Balangir
# Balangir | 59/67
# Sahu Classes
# Balangir | 60/67
# Aastha public school,Belpada
# Balangir | 61/67
# Raj Driving Training School (R.D.T.S)
# Balangir | 62/67
# Viswatma Vidya Mandir
# Balangir | 63/67
# Ipsum Coaching Classes
# Balangir | 64/67
# RICH Distance College, Balangir
# Balangir | 65/67
# Mishra Coaching
# Balangir | 66/67
# SWARA JHANKAR
# Balangir | 67/67
# Saraswati Shishu Vidya Mandir,Kadampada
#
# Searching: schools in Balasore Odisha
# Search Submitted
# Balasore | schools | Scroll 1 -> 14
# Balasore | schools | Scroll 2 -> 20
# Balasore | schools | Scroll 3 -> 27
# Balasore | schools | Scroll 4 -> 34
# Balasore | schools | Scroll 5 -> 40
# Balasore | schools | Scroll 6 -> 47
# Balasore | schools | Scroll 7 -> 54
# Balasore | schools | Scroll 8 -> 60
# Balasore | schools | Scroll 9 -> 67
# Balasore | schools | Scroll 10 -> 74
# Balasore | schools | Scroll 11 -> 80
# Balasore | schools | Scroll 12 -> 87
# Balasore | schools | Scroll 13 -> 94
# Balasore | schools | Scroll 14 -> 100
# Balasore | schools | Scroll 15 -> 107
# Balasore | schools | Scroll 16 -> 114
# Balasore | schools | Scroll 17 -> 120
# Balasore | schools | Scroll 18 -> 120
# Balasore | schools | Scroll 19 -> 120
# Balasore | schools | Scroll 20 -> 120
# Balasore | schools | Scroll 21 -> 120
# Collected 120 links
# Balasore | 1/120
# ✅Shree Jagannath Residential School - Best Odia Medium School in Balasore
# Balasore | 2/120
# EuroKids PreSchool in Baleswar, Balasore
# Balasore | 3/120
# Jhadeswar International School
# Balasore | 4/120
# ✅PURNIMA ENGLISH MEDIUM PLAY SCHOOL & DAYCARE, 1ST BRANCH - BEST PLAYSCHOOL IN BALESWAR
# Balasore | 5/120
# Kendriya Vidyalaya Balasore No.1
# Balasore | 6/120
# Siddhi Vinayak Public School
# Balasore | 7/120
# DAV PUBLIC SCHOOL
# Balasore | 8/120
# Balasore Zilla School
# Balasore | 9/120
# KIDZEE BALASORE
# Balasore | 10/120
# St. Vincent's Convent Senior Secondary School
# Balasore | 11/120
# BRIGHT HORIZON SCHOOL Balasore
# Balasore | 12/120
# Saint Thomas Convent School
# Balasore | 13/120
# Swastik Higher Secondary School, Balasore 【Arts, Science & Commerce】
# Balasore | 14/120
# Vyasakabi Higher Secondary School
# Balasore | 15/120
# CBSE POINT (XI & XII )
# Balasore | 16/120
# The Welfare School For the Blind
# Balasore | 17/120
# Sulagna higher Secondary school
# Balasore | 18/120
# Hello Kidz Sai Kreeshna School
# Balasore | 19/120
# Balasore Technical School
# Balasore | 20/120
# eduMETA THE i-SCHOOL Kalidaspur Balasore
# Balasore | 21/120
# Kidzee Remuna
# Balasore | 22/120
# London Kids Preschool Balasore, Odisha | Best Preschool In Balasore
# Balasore | 23/120
# Tokyo advanced higher secondary school (+2 sc. Day-com-residential)
# Balasore | 24/120
# Modern Public School
# Balasore | 25/120
# Maharishi Vidya Mandir
# Balasore | 26/120
# Guru Krupa Higher Secondary School
# Balasore | 27/120
# Lakshya Academy Balasore (LAB)
# Balasore | 28/120
# Dream India Schools Balasore Odisha
# Balasore | 29/120
# Jawahar Navodaya Vidyalaya
# Balasore | 30/120
# Delhi Public International School
# Balasore | 31/120
# WISDOM HIGHER SECONDARY SCHOOL BALASORE
# Balasore | 32/120
# Haripriya English Medium School
# Balasore | 33/120
# Public High School
# Balasore | 34/120
# Netaji English Medium School
# Balasore | 35/120
# United Public School
# Balasore | 36/120
# Bhavani School
# Balasore | 37/120
# St. Xavier's Public School, Remuna
# Balasore | 38/120
# ✅PURNIMA ENGLISH MEDIUM PLAY SCHOOL & DAYCARE, 2ND BRANCH_ BEST PLAY SCHOOL IN BALESWAR
# Balasore | 39/120
# Police High School
# Balasore | 40/120
# St. Xavier's International School
# Balasore | 41/120
# Sri Aurobindo Centre Of Integral Education, Rajabagicha,Balasore
# Balasore | 42/120
# Swastik Residential College, Balasore
# Balasore | 43/120
# St. Xavier's High School
# Balasore | 44/120
# Rich Look Kids Play School,Balasore
# Balasore | 45/120
# Balasore | 104/120
# MATA DRIVING TRAINING SCHOOL
# Balasore | 105/120
# Janata High School
# Balasore | 106/120
# Hi-tech senior secondary school
# Balasore | 107/120
# ଅନ୍ତର୍ଯ୍ୟାମୀ କମ୍ପିଟେଟିଭ ଏକାଡେମୀ Antaryami Competitive Academy
# Balasore | 108/120
# VERTEX CLASSES
# Balasore | 109/120
# Utkal Vani Kala Kendra
# Balasore | 110/120
# IRODOV CLASESS
# Balasore | 111/120
# B D M Public School
# Balasore | 112/120
# Kailash Chandra High School
# Balasore | 113/120
# MODERN INDUSTRIAL TRAINING CENTRE
# Balasore | 114/120
# Pragyan Bharati Shikshya Kendra, Balasore
# Balasore | 115/120
# jagannath mess
# Balasore | 116/120
# Shree Jagannath B.Ed. Institute
# Balasore | 117/120
# Makalpur Primary School, Balasore
# Balasore | 118/120
# St. James' Convent School
# Balasore | 119/120
# Mallikashpur Nursery School
# Balasore | 120/120
# K.C.A PUBLIC SCHOOL
#
# Searching: schools in Bargarh Odisha
# Search Submitted
# Bargarh | schools | Scroll 1 -> 14
# Bargarh | schools | Scroll 2 -> 20
# Bargarh | schools | Scroll 3 -> 27
# Bargarh | schools | Scroll 4 -> 34
# Bargarh | schools | Scroll 5 -> 40
# Bargarh | schools | Scroll 6 -> 47
# Bargarh | schools | Scroll 7 -> 54
# Bargarh | schools | Scroll 8 -> 60
# Bargarh | schools | Scroll 9 -> 67
# Bargarh | schools | Scroll 10 -> 74
# Bargarh | schools | Scroll 11 -> 80
# Bargarh | schools | Scroll 12 -> 80
# Bargarh | schools | Scroll 13 -> 80
# Bargarh | schools | Scroll 14 -> 80
# Bargarh | schools | Scroll 15 -> 80
# Collected 80 links
# Bargarh | 1/80
# Vedic International School, Bargarh
# Bargarh | 2/80
# George High School Field, Bargarh
# Bargarh | 3/80
# Vikash Higher Secondary School, Bargarh
# Bargarh | 4/80
# Vikash First Step School
# Bargarh | 5/80
# Shemrock School Bargarh (Odisha)
# Bargarh | 6/80
# School Time
# Bargarh | 7/80
# Rotary Public School
# Bargarh | 8/80
# Krishna Vikash Group of Institutions
# Bargarh | 9/80
# Hello Kids - Pink Preschool, Bargarh, Odisha
# Bargarh | 10/80
# Bachpan Play School, Near Ram Mandir,CWC 1,Master Tikra Bargarh 768028
# Bargarh | 11/80
# Bethany Convent School
# Bargarh | 12/80
# Sanskar International School
# Bargarh | 13/80
# Gandhi Public School, Bargarh
# Bargarh | 14/80
# Suryashree Trinity School
# Bargarh | 15/80
# FLORA INSTITUTE OF SCIENCE AND TECHNOLOGY
# Bargarh | 16/80
# Sai Driving Training School, Bargarh
# Bargarh | 17/80
# Kendriya Vidyalaya, Bargarh
# Bargarh | 18/80
# Kids Kamp, Bargarh, Odisha
# Bargarh | 19/80
# George High School, Bargarh
# Bargarh | 20/80
# Shemrock School Govindpali Branch
# Bargarh | 21/80
# Jawahar Navodaya Vidyalaya, Paikmal, Bargarh
# Bargarh | 22/80
# Cement Nagar English Medium School
# Bargarh | 23/80
# RAINBOW PUBLIC SCHOOL
# Bargarh | 24/80
# The Learning Heaven Play School
# Bargarh | 25/80
# Tora Higher Secondary School, Tora
# Bargarh | 26/80
# Smart Kid Abacus Learning Centre
# Bargarh | 27/80
# A.E.Mission English Medium School
# Bargarh | 28/80
# Kautilya Global School, Bargarh
# Backup Saved
# Bargarh | 29/80
# Sri Aurobindo Institute of Integral Education & Research, Bargarh
# Bargarh | 30/80
# The Kosala School,Nuakhirpali , Larasara Bargarh
# Bargarh | 31/80
# Angels Academy
# Bargarh | 32/80
# Gurukul Academy Bargarh
# Bargarh | 33/80
# Brahmachari Primary School
# Bargarh | 34/80
# Shri Chaitanya School
# Bargarh | 35/80
# Panchayat College, Bargarh
# Bargarh | 36/80
# AIESS Computer Education
# Bargarh | 37/80
# Bargarh Science Institute
# Bargarh | 38/80
# Arti kidz school
# Bargarh | 39/80
# Vikash Junior College
# Bargarh | 40/80
# SCHOOL LIFE
# Bargarh | 41/80
# AET ACADEMY Bargarh
# Bargarh | 42/80
# Sai Public School Bargarh
# Bargarh | 43/80
# Eklavya Model Residential School,
# Bargarh | 44/80
# Dream India School
# Bargarh | 45/80
# DISTRICT EDUCATION OFFICE, BARGARH
# Bargarh | 46/80
# MIIT Computer Education
# Bargarh | 47/80
# SCHOOL UNIFORMS X CALCUTTA DRESSES
# Bargarh | 48/80
# Vikash Institute for Social Welfare
# Bargarh | 49/80
# Vikash Degree College
# Bargarh | 50/80
# Cement Nagar High School
# Bargarh | 51/80
# Hindi Girls School
# Bargarh | 52/80
# Success point coaching classes
# Bargarh | 53/80
# Siddhartha Public School
# Bargarh | 54/80
# Government Girls High School
# Bargarh | 55/80
# Bhubana Bhoi's Sst Classes
# Bargarh | 56/80
# COSMIC cbse Coaching
# Bargarh | 57/80
# Aims international school
# Bargarh | 58/80
# ELITE TUTORIAL
# Bargarh | 59/80
# Government Upper Primary School, Govindpali
# Bargarh | 60/80
# Ramkrushna Nagar Ambasada Bargarh
# Bargarh | 61/80
# Odisha Adarsha Vidyalaya, Gobindpur, Bargarh
# Bargarh | 62/80
# CricKingdom Cricket Academy
# Bargarh | 63/80
# Lengu Mishra Mini Stadium
# Bargarh | 64/80
# Rangapada U. P. School, Bargarh
# Bargarh | 65/80
# Sarada Devi Public School
# Bargarh | 66/80
# Krishna Vikash Residential School, Bargarh
# Bargarh | 67/80
# My Computer Institute
# Bargarh | 68/80
# Saraswati Shishu Vidya Mandir (Odia Vibhag) ସରସ୍ବତୀ ଶିଶୁ ବିଦ୍ୟା ମନ୍ଦିର
# Bargarh | 69/80
# Saraswati Sishu Vidya Mandir (Hindi Vibhag) ସରସ୍ବତୀ ଶିଶୁ ବିଦ୍ୟା ମନ୍ଦିର
# Bargarh | 70/80
# Badriprasad Apartments
# Bargarh | 71/80
# NEW RAINBOW KIDS PLAY SCHOOL
# Bargarh | 72/80
# Sai Play School & Nursery, Bargarh
# Bargarh | 73/80
# Tora Degree College
# Bargarh | 74/80
# PADAMPUR PUBLIC SCHOOL
# Bargarh | 75/80
# Jist College
# Bargarh | 76/80
# Samaleshwari Nodal High School, Ambapali
# Boudh | schools | Scroll 2 -> 10
# Boudh | schools | Scroll 3 -> 10
# Boudh | schools | Scroll 4 -> 10
# Boudh | schools | Scroll 5 -> 10
# Collected 10 links
# Boudh | 1/10
# Kendriya Vidyalaya, Boudh
# Boudh | 2/10
# BRIGHT MINDS DIMENSION SCHOOL,BOUDH
# Boudh | 3/10
# St.Xavier's Public School,Boudh
# Boudh | 4/10
# PM SHRI School Jawahar Navodaya Vidyalaya, Paljhar, Boudh
# Boudh | 5/10
# TINY N TOTS PLAY SCHOOL
# Boudh | 6/10
# Bhabani Classes
# Boudh | 7/10
# K.B HIST COLLEGE, BOUDH
# Boudh | 8/10
# Odisha Adarsha Vidyalaya ,Tetelenga ,Boudh
# Boudh | 9/10
# Gouri Shankar Public School
# Boudh | 10/10
# BUDDHADEV ACADEMY, BOUDH
#
# Searching: schools in Cuttack Odisha
# Search Submitted
# Cuttack | schools | Scroll 1 -> 14
# Cuttack | schools | Scroll 2 -> 20
# Cuttack | schools | Scroll 3 -> 27
# Cuttack | schools | Scroll 4 -> 34
# Cuttack | schools | Scroll 5 -> 40
# Cuttack | schools | Scroll 6 -> 47
# Cuttack | schools | Scroll 7 -> 54
# Cuttack | schools | Scroll 8 -> 60
# Cuttack | schools | Scroll 9 -> 67
# Cuttack | schools | Scroll 10 -> 74
# Cuttack | schools | Scroll 11 -> 80
# Cuttack | schools | Scroll 12 -> 87
# Cuttack | schools | Scroll 13 -> 94
# Cuttack | schools | Scroll 14 -> 100
# Cuttack | schools | Scroll 15 -> 107
# Cuttack | schools | Scroll 16 -> 114
# Cuttack | schools | Scroll 17 -> 120
# Cuttack | schools | Scroll 18 -> 120
# Cuttack | schools | Scroll 19 -> 120
# Cuttack | schools | Scroll 20 -> 120
# Cuttack | schools | Scroll 21 -> 120
# Collected 120 links
# Cuttack | 1/120
# Narayana eTechno (CBSE) School - Cuttack
# Cuttack | 2/120
# Stewart School
# Cuttack | 3/120
# Krishnamurty World School
# Cuttack | 4/120
# St Antony School
# Cuttack | 5/120
# MAMATA PUBLIC SCHOOL | RESIDENTIAL COLLEGE | SCHOOL | CBSE | ICSE | NEET | JEE | Best CBSE Residential School in Cuttack
# Cuttack | 6/120
# Cambridge School
# Cuttack | 7/120
# Sandeepani Play School
# Cuttack | 8/120
# Secondary Board High School, Cuttack
# Cuttack | 9/120
# Ashelles Public School
# Cuttack | 10/120
# D.A.V. Public School
# Cuttack | 11/120
# Abhipsa International School
# Cuttack | 12/120
# St. Joseph's Girls' High School
# Cuttack | 13/120
# SANDEEPANI Play School Campus 2
# Cuttack | 14/120
# AALPEE HIGHER SECONDARY SCHOOL(+2 SCIENCE)CHSE & CBSE
# Cuttack | 15/120
# SGVN Gurukul
# Cuttack | 16/120
# Nalanda Public School
# Cuttack | 17/120
# Joharimall High School
# Cuttack | 18/120
# Lajpat Rai DAV Public School
# Cuttack | 19/120
# Tinsel Garden English Medium School
# Cuttack | 20/120
# Amritprabha Smart School
# Cuttack | 21/120
# Guru Nanak Public School
# Cuttack | 22/120
# SAI International Residential School
# Cuttack | 23/120
# Ravenshaw Collegiate School
# Cuttack | 24/120
# Sri Sathya Sai School
# Cuttack | 25/120
# Shakti Higher Secondary School
# Cuttack | 26/120
# Modern Public School, Cuttack
# Cuttack | 27/120
# Arihant Gurukulam International School
# Cuttack | 28/120
# Our Saplings Playschool and Day Care(Creche)
# Cuttack | 29/120
# New Stewart School
# Cuttack | 30/120
# Kidzee - Sector 8, CDA
# Cuttack | 31/120
# DNA Junior Pre-School
# Cuttack | 32/120
# St. Xavier's High School, Mission Road
# Cuttack | 33/120
# Sai Shraddha International School
# Cuttack | 34/120
# THE TENSOR PUBLIC SCHOOL
# Cuttack | 35/120
# EuroKids PreSchool in CDA Sector 6-Markat Nagar, Cuttack
# Cuttack | 36/120
# Happy Days Play School
# Cuttack | 37/120
# St. Xavier's High School, Main Block
# Cuttack | 38/120
# Fairyland Play School
# Cuttack | 39/120
# Global Indian Model School
# Cuttack | 40/120
# Ravenshaw Girl's High School, Cuttack, Odisha
# Cuttack | 41/120
# Future Kidz School
# Cuttack | 42/120
# Cuttack Public School Jagatpur
# Cuttack | 43/120
# St Xaviers Senior Secondary School (CBSE)
# Cuttack | 44/120
# Badambadi New Colony High School
# Cuttack | 45/120
# CBSE ACADEMY
# Cuttack | 46/120
# Nalanda public school block 2
# Cuttack | 47/120
# Dream India Schools Madhupatna Cuttack
# Cuttack | 48/120
# Matrubhaban School & College
# Cuttack | 49/120
# AB'S OXFORD INTERNATIONAL SCHOOL
# Cuttack | 50/120
# PM Shri Kendriya Vidyalaya No.1 Cuttack
# Cuttack | 51/120
# DAV Public School Cuttack
# Cuttack | 52/120
# P. M. Academy
# Cuttack | 53/120
# The Educators Cuttack
# Cuttack | 54/120
# Bright Future School
# Backup Saved
# Cuttack | 55/120
# St. Xavier's High School
# Cuttack | 56/120
# Kendriya Vidyalaya No.2 Cuttack
# Cuttack | 57/120
# Moonlight School
# Cuttack | 58/120
# Queen Mary's High School
# Cuttack | 59/120
# Eurokids Jobra
# Cuttack | 60/120
# St. Xavier Public School, Jobra
# Cuttack | 61/120
# SAISIKSHYA PUBLIC SCHOOL
# Cuttack | 62/120
# St. Xavier's School (Block 1)
# Cuttack | 63/120
# DAV S.C.B. Medical Public School
# Cuttack | 64/120
# EuroKids PreSchool in Ganesh Ghat, Cuttack
# Cuttack | 65/120
# Little Stuart School
# Cuttack | 66/120
# Adarsh Gurukul Public School
# Cuttack | 67/120
# Woodlands School
# Cuttack | 68/120
# Imarat Public school
# Cuttack | 69/120
# Ravenshaw Higher Secondary School, Cuttack
# Cuttack | 70/120
# Sri Aurobindo School Of New Thought
# Cuttack | 71/120
# Bachpan Play School in Buxi Bazar | Best Preschool Near Me | Nursery School & Kindergarten for Your Child’s Bright Start
# Cuttack | 72/120
# Railway Settlement High School
# Cuttack | 73/120
# Future Public School
# Cuttack | 74/120
# FUN n LEARN PLAY SCHOOL
# Cuttack | 75/120
# Madhusudan Nodal & Girls' High School
# Cuttack | 76/120
# Kidzee Playschool Tulasipur, Cuttack
# Cuttack | 77/120
# BharatBaba English medium school Mahima ashram
# Cuttack | 78/120
# Saraswati Shishu Vidya Mandir College Square Cuttack
# Cuttack | 79/120
# KHANNAGAR GOVT. HIGH SCHOOL. (OFFICIAL)
# Cuttack | 80/120
# Macaulay International School
# Cuttack | 81/120
# Abp International School
# Cuttack | 82/120
# Modern Public School
# Cuttack | 83/120
# ST. XAVIER'S INTERNATIONAL MODEL PUBLIC SCHOOL
# Cuttack | 84/120
# Odisha Police High School
# Cuttack | 85/120
# SIP ABACUS
# Cuttack | 86/120
# Ranihat High School CUTTACK
# Cuttack | 87/120
# Mother's Public School, Cuttack
# Cuttack | 88/120
# Nua Bazar High School Play Ground
# Cuttack | 89/120
# Sanat Nalini Girls' High School
# Cuttack | 90/120
# Xavier's Play School
# Cuttack | 91/120
# LUVNA MILK PARLOUR
# Cuttack | 92/120
# Swami Sivananda Vidya Mandir
# Cuttack | 93/120
# Chatra Bazar High School
# Cuttack | 94/120
# Venkateswara Play School & Sai Bharath School
# Cuttack | 95/120
# Buckley Girls' High School
# Cuttack | 96/120
# SHARMA ACADEMY (COMMERCE)
# Cuttack | 97/120
# Satsang High School
# Cuttack | 98/120
# Bhubanananda Orissa School of Engineering
# Cuttack | 99/120
# KIDS MORNING PLAY SCHOOL
# Cuttack | 100/120
# MY CHILD PUBLIC School
# Cuttack | 101/120
# My Child English Medium School
# Cuttack | 102/120
# Netaji Public School Dagarpara
# Cuttack | 103/120
# Maharishi Vidya Mandir
# Cuttack | 104/120
# Little Millennium - Mahanadi Vihar - Cuttack
# Cuttack | 105/120
# Dominic Public School
# Cuttack | 106/120
# DAV Gurukul
# Cuttack | 107/120
# EuroKids Preschool in Naranpur, Cuttack
# Cuttack | 108/120
# Tiny Tot Kindergarten School
# Cuttack | 109/120
# Shree Bharati School
# Cuttack | 110/120
# Apex Academy Educational Institute
# Cuttack | 111/120
# Mother's Grace
# Cuttack | 112/120
# New Disney Play School
# Cuttack | 113/120
# Arihant Gurukul
# Cuttack | 114/120
# Shishu Bharati High School
# Cuttack | 115/120
# Unique little stars play school
# Cuttack | 116/120
# S.B International school
# Cuttack | 117/120
# St. Xavier Public School
# Cuttack | 118/120
# Aradhana Classes
# Cuttack | 119/120
# Buckley Primary School
# Cuttack | 120/120
# Xavier College of Film & Television India (XCFTI)
#
# Searching: schools in Deogarh Odisha
# Search Submitted
# Deogarh | schools | Scroll 1 -> 13
# Deogarh | schools | Scroll 2 -> 13
# Deogarh | schools | Scroll 3 -> 13
# Deogarh | schools | Scroll 4 -> 13
# Deogarh | schools | Scroll 5 -> 13
# Collected 13 links
# Deogarh | 1/13
# Subhrajyoti Abasika Bidyalaya, Deogarh
# Deogarh | 2/13
# Notre Dame Academy
# Deogarh | 3/13
# R B D High School
# Deogarh | 4/13
# Kendriya Vidyalaya Deogarh
# Deogarh | 5/13
# Chinmaya Vidyalaya
# Deogarh | 6/13
# Government Girls High School
# Deogarh | 7/13
# Jawahar Navodaya Vidyalaya, Sunamunda, Deogarh,
# Deogarh | 8/13
# Bidya Vikas English Medium School
# Deogarh | 9/13
# Mahuldhipa Sahi Aaganbadi School
# Deogarh | 10/13
# SRI AUROBINDO PATHACHAKRA & PURNANGA SHIKSHA KENDRA, Deogarh
# Deogarh | 11/13
# Divine Public School,Deogarh
# Deogarh | 12/13
# purunagarh primary school(Anarya school)
# Deogarh | 13/13
# Deoghar
#
# Searching: schools in Dhenkanal Odisha
# Search Submitted
# Dhenkanal | schools | Scroll 1 -> 14
# Dhenkanal | schools | Scroll 2 -> 20
# Dhenkanal | schools | Scroll 3 -> 27
# Dhenkanal | schools | Scroll 4 -> 34
# Dhenkanal | schools | Scroll 5 -> 40
# Dhenkanal | schools | Scroll 6 -> 47
# Dhenkanal | schools | Scroll 7 -> 54
# Dhenkanal | schools | Scroll 8 -> 57
# Dhenkanal | schools | Scroll 9 -> 57
# Dhenkanal | schools | Scroll 10 -> 57
# Dhenkanal | schools | Scroll 11 -> 57
# Dhenkanal | schools | Scroll 12 -> 57
# Collected 57 links
# Dhenkanal | 1/57
# St. Xavier's High School, Dhenkanal
# Dhenkanal | 2/57
# MontFort School
# Dhenkanal | 3/57
# Delhi Public School DHENKANAL
# Dhenkanal | 4/57
# Bhargabi Higher Secondary School, Dhenkanal
# Dhenkanal | 5/57
# Kendriya Vidyalaya
# Dhenkanal | 6/57
# Bachpan Play School in Dhenkanal | Best Preschool Near Me | Nursery School for Your Child’s Bright Start
# Dhenkanal | 7/57
# Brajnath Badjena High School
# Dhenkanal | 8/57
# Satyam International School
# Dhenkanal | 9/57
# Dream India Schools Dhenkanal Odisha
# Dhenkanal | 10/57
# St Xavier Public School
# Dhenkanal | 11/57
# Kidzee Dhenkanal
# Dhenkanal | 12/57
# ICS ACADEMY
# Dhenkanal | 13/57
# Odisha adarsha vidyalaya Mahisapat, Dhenkanal
# Dhenkanal | 14/57
# Sri Aurobindo Integeral Education Centre Dhenkanal
# Dhenkanal | 15/57
# ST XAVIERS MONTESSORI SCHOOL
# Dhenkanal | 16/57
# Sri Chaitanya Techno School
# Dhenkanal | 17/57
# B.B. High School Play Ground
# Dhenkanal | 18/57
# Bhargabi +2 Science Residential College
# Dhenkanal | 19/57
# Amrita Pre-Primary School, Dhenkanal
# Dhenkanal | 20/57
# Ananda Marga Public School, Dhenkanal
# Dhenkanal | 21/57
# Jibanjyoti MR Special School
# Backup Saved
# Dhenkanal | 22/57
# St. Xavier's High School
# Dhenkanal | 23/57
# Sure success coaching center
# Dhenkanal | 24/57
# e-Tech Higher Secondary Residential School
# Dhenkanal | 25/57
# Balaram High School
# Dhenkanal | 26/57
# Sri Sri Ravishankar Vidya Mandir (SSRVM), Dhenkanal
# Dhenkanal | 27/57
# GMR VARALAKSHMI DAV PUBLIC SCHOOL
# Dhenkanal | 28/57
# Venkateshwar School
# Dhenkanal | 29/57
# ION Digital Zone iDZ Banamaliprasad
# Dhenkanal | 30/57
# Synergy Institute of Engineering and Technology, Dhenkanal
# Dhenkanal | 31/57
# Adruta Children Home Dhenkanal
# Dhenkanal | 32/57
# Office of the District Education Officer
# Dhenkanal | 33/57
# Saikrupa Residential College
# Dhenkanal | 34/57
# e-Tech Residential Degree College
# Dhenkanal | 35/57
# DIET, Dhenkanal
# Dhenkanal | 36/57
# Brahmani Public School
# Dhenkanal | 37/57
# BIET +2 Science
# Dhenkanal | 38/57
# Government ITI College
# Dhenkanal | 39/57
# Ak Dance studio
# Dhenkanal | 40/57
# Sanskar Public School
# Dhenkanal | 41/57
# Utkalam Typing Institute
# Dhenkanal | 42/57
# Knowledge Icon Coaching Classes (Arts)
# Dhenkanal | 43/57
# Shantilata Driving school
# Dhenkanal | 44/57
# District Sainik Board Dhenkanal
# Dhenkanal | 45/57
# Dhenkanal Evening College
# Dhenkanal | 46/57
# Oxford Book Store
# Dhenkanal | 47/57
# Nandini Devi School for Deaf , Dumb and Blind.
# Dhenkanal | 48/57
# P.M. S.H.R.I. Jawahar Navodaya Vidyalaya , Sarang, Dhenkanal
# Dhenkanal | 49/57
# Cambridge School
# Dhenkanal | 50/57
# Indian Institute Of Mass Communication
# Dhenkanal | 51/57
# VaniVihar Computer Centre
# Dhenkanal | 52/57
# Dhenkanal Orissa
# Dhenkanal | 53/57
# Sarangdhar High School
# Dhenkanal | 54/57
# Joranda High School
# Dhenkanal | 55/57
# B.P. Hydraulics & Pneumatics
# Dhenkanal | 56/57
# Rasol High School
# Dhenkanal | 57/57
# Saudamini Smruti Bidyapitha
#
# Searching: schools in Gajapati Odisha
# Search Submitted
# Gajapati | schools | Scroll 1 -> 14
# Gajapati | schools | Scroll 2 -> 20
# Gajapati | schools | Scroll 3 -> 27
# Gajapati | schools | Scroll 4 -> 34
# Gajapati | schools | Scroll 5 -> 40
# Gajapati | schools | Scroll 6 -> 41
# Gajapati | schools | Scroll 7 -> 41
# Gajapati | schools | Scroll 8 -> 41
# Gajapati | schools | Scroll 9 -> 41
# Gajapati | schools | Scroll 10 -> 41
# Collected 41 links
# Gajapati | 1/41
# SSD HIGHER SECONDARY SCHOOL,MOHANA,GAJAPATI,ODISHA
# Gajapati | 2/41
# PM SHRI Jawahar Navodaya Vidyalaya, Betaguda, Paralakhemundi, Gajapati
# Gajapati | 3/41
# PM SHRI Kendriya Vidyalaya, Betaguda, Gajapati
# Gajapati | 4/41
# Ekalavya Model Residential School, Chandragiri
# Gajapati | 5/41
# GOVT. U.P SCHOOL, KERADANGO, GAJAPATI,ODISHA
# Gajapati | 6/41
# Odisha Adarsha Vidyalaya, Gundima, Mohana, Gajapati
# Gajapati | 7/41
# Centurion Public School
# Gajapati | 8/41
# M.R. Girls' High School
# Gajapati | 9/41
# ODISHA ADARSHA VIDYALAYA, ALLADA
# Gajapati | 10/41
# High School
# Gajapati | 11/41
# St. Andrew's English Medium School
# Gajapati | 12/41
# Priyadarshini Convent School
# Gajapati | 13/41
# Goura Chandra Gajapati Upper Primary School
# Gajapati | 14/41
# M K C G Special School for the Blind,Deaf,MR & CP
# Gajapati | 15/41
# Prakalpa Upper Primary School, New Lenge
# Gajapati | 16/41
# Prakalpa Upper Primary School
# Gajapati | 17/41
# M.R. Boys High School
# Gajapati | 18/41
# Government Upper Primary School
# Gajapati | 19/41
# Primary School
# Gajapati | 20/41
# Centurion public School
# Gajapati | 21/41
# Government Girls High School
# Gajapati | 22/41
# Govt. High School, Gumma
# Gajapati | 23/41
# Odisha Adarsha Vidyalaya, Chheligada, R.Udayagiri, Gajapati
# Gajapati | 24/41
# Maharshi Gurukul Science Higher Secondary school,Gunupur (Old campus)
# Gajapati | 25/41
# U.P.SCHOOL LILIGUDA,GAJAPATI
# Gajapati | 26/41
# VARANASI GOVT. HIGH SCHOOL
# Gajapati | 27/41
# Women's Higher Secondary School
# Gajapati | 28/41
# Gajapati Stadium
# Gajapati | 29/41
# Govt girls high school (sialiloti) gajapati
# Gajapati | 30/41
# Odisha Adarsha Vidyalaya, Kaithapadar
# Gajapati | 31/41
# Vocational Lab, Varanasi Govt. High School, Kashinagar, Gajapati.
# Gajapati | 32/41
# SSD Girl's High School, Chandragiri
# Gajapati | 33/41
# St Joseph Convent
# Gajapati | 34/41
# L.N.BIDYAPITHA , HIGH SCHOOL, NUAGADA
# Gajapati | 35/41
# Chadragiri Boys High School
# Gajapati | 36/41
# Government High School
# Gajapati | 37/41
# Government High School
# Gajapati | 38/41
# Government Upper Primary School, Khajuripada
# Gajapati | 39/41
# OAV Lingipur Gosani Gajapati
# Gajapati | 40/41
# Primary School
# Gajapati | 41/41
# Ashram School
#
# Searching: schools in Ganjam Odisha
# Search Submitted
# Ganjam | schools | Scroll 1 -> 14
# Ganjam | schools | Scroll 2 -> 19
# Ganjam | schools | Scroll 3 -> 19
# Ganjam | schools | Scroll 4 -> 19
# Ganjam | schools | Scroll 5 -> 19
# Ganjam | schools | Scroll 6 -> 19
# Collected 19 links
# Ganjam | 1/19
# Bachpan Play School in Ganjam | Best Preschool Near Me | Nursery School & Kindergarten for Your Child’s Bright Start
# Ganjam | 2/19
# Nodal U.P School, Ganjam
# Ganjam | 3/19
# Jayshree Chemicals School
# Ganjam | 4/19
# Saraswati Shishu Vidya Mandir , Ganjam
# Ganjam | 5/19
# Domodarpur U.P School , Ganjam
# Ganjam | 6/19
# Girls' High School,Ganjam
# Ganjam | 7/19
# Gram Vikas Residential School, Kankia
# Ganjam | 8/19
# Bharati Bidya Peetha
# Ganjam | 9/19
# Ganjam College
# Ganjam | 10/19
# Up School
# Ganjam | 11/19
# Gyana Vikash English Medium School, Berhampur
# Ganjam | 12/19
# ONSLOW INSTITUTION (ଓଁସ୍ଲୋ ଅନୁଷ୍ଠାନ)
# Ganjam | 13/19
# Kalyanpur primary school
# Ganjam | 14/19
# K C Public School
# Ganjam | 15/19
# St. Xavier's High School
# Ganjam | 16/19
# DE PAUL SCHOOL
# Ganjam | 17/19
# GOVT.U.G HIGH SCHOOL JHARAPARI
# Ganjam | 18/19
# Matrushree Anglo Vedic School
# Ganjam | 19/19
# Puintola Primary School
#
# Searching: schools in Jagatsinghpur Odisha
# Search Submitted
# Jagatsinghpur | schools | Scroll 1 -> 14
# Jagatsinghpur | schools | Scroll 2 -> 20
# Usthi Foundation School
# Puri | 64/69
# Talenters Education
# Puri | 65/69
# NIITS
# Puri | 66/69
# Indradyumna Adarsha Vidyaniketan
# Puri | 67/69
# CSU Puri Campus
# Backup Saved
# Puri | 68/69
# Betrix School
# Puri | 69/69
# Satya Sai Bal Bhawan
#
# Searching: schools in Rayagada Odisha
# Search Submitted
# Rayagada | schools | Scroll 1 -> 14
# Rayagada | schools | Scroll 2 -> 20
# Rayagada | schools | Scroll 3 -> 27
# Rayagada | schools | Scroll 4 -> 34
# Rayagada | schools | Scroll 5 -> 40
# Rayagada | schools | Scroll 6 -> 47
# Rayagada | schools | Scroll 7 -> 49
# Rayagada | schools | Scroll 8 -> 49
# Rayagada | schools | Scroll 9 -> 49
# Rayagada | schools | Scroll 10 -> 49
# Rayagada | schools | Scroll 11 -> 49
# Collected 49 links
# Rayagada | 1/49
# Academic Heights Public School (AHPS) - Best School in Rayagada I Best CBSE School in Rayagada I Top School in Rayagada
# Rayagada | 2/49
# CENTURION PUBLIC SCHOOL, IDCO RAYAGADA
# Rayagada | 3/49
# GCD High School, Rayagada
# Rayagada | 4/49
# Swami VIVEKANANDA School
# Rayagada | 5/49
# The Cambridge School
# Rayagada | 6/49
# Divine Public School
# Rayagada | 7/49
# Jupiter International School/ +2 science College
# Rayagada | 8/49
# Prasad Techno School
# Rayagada | 9/49
# Old Dream India Schools Rayagada
# Rayagada | 10/49
# Aditya Birla Public School old campus
# Rayagada | 11/49
# Vignan Vidyalaya
# Rayagada | 12/49
# Maharshi Vidya Mandir School
# Rayagada | 13/49
#
# Rayagada | 14/49
# Sacred Heart School
# Rayagada | 15/49
# Gayatri Model School
# Rayagada | 16/49
# Bachpan Play School, Rayagada
# Rayagada | 17/49
# Sri Chaitanya Techno School
# Rayagada | 18/49
# N V R Educational Institution
# Rayagada | 19/49
# Wheaton Kids
# Rayagada | 20/49
# Adarsh Academy ( Science Tution)
# Rayagada | 21/49
# PRERANA SCHOOL
# Rayagada | 22/49
# Eklavya Model Residential School
# Rayagada | 23/49
# St.Xaviers Senior Secondary School
# Rayagada | 24/49
# Deepti Convent School,Rayagada
# Rayagada | 25/49
# G.B.M High School, Rayagada
# Rayagada | 26/49
# Sacred heart school
# Rayagada | 27/49
# R.S.E.W.C High School
# Rayagada | 28/49
#
# Rayagada | 29/49
# odisa state brigade school
# Rayagada | 30/49
# Rayagada Autonomous College
# Rayagada | 31/49
# LPS High School, Jaykaypur
# Rayagada | 32/49
# Lakshmipat Singhania Public School
# Rayagada | 33/49
# Oritech Computer Education
# Rayagada | 34/49
# District Education Office, Rayagada
# Rayagada | 35/49
# Odisha Adarsha vidyalaya Tadama Rayagada
# Rayagada | 36/49
# CAREER BUILDER (CB)
# Rayagada | 37/49
# NEW DREAMS INDIA SCHOOL
# Rayagada | 38/49
# GCD High School Playground
# Rayagada | 39/49
# Music Gaalaxy
# Rayagada | 40/49
# Samarpana Driving Training School
# Rayagada | 41/49
# Siriguda
# Rayagada | 42/49
# MB COMPETITIVE CLASSES
# Rayagada | 43/49
# UGMIT, Government Polytechnic
# Rayagada | 44/49
# GEETA EDUCATION ACADEMY
# Rayagada | 45/49
# MGM COACHING CENTRE
# Rayagada | 46/49
# Aryan English Medium School
# Rayagada | 47/49
# Gandhi Public School
# Rayagada | 48/49
# Dream India Schools Rayagada Odisha
# Rayagada | 49/49
# ADDICTIONS
#
# Searching: schools in Sambalpur Odisha
# Search Submitted
# Sambalpur | schools | Scroll 1 -> 14
# Sambalpur | schools | Scroll 2 -> 20
# Sambalpur | schools | Scroll 3 -> 27
# Sambalpur | schools | Scroll 4 -> 34
# Sambalpur | schools | Scroll 5 -> 40
# Sambalpur | schools | Scroll 6 -> 47
# Sambalpur | schools | Scroll 7 -> 54
# Sambalpur | schools | Scroll 8 -> 60
# Sambalpur | schools | Scroll 9 -> 67
# Sambalpur | schools | Scroll 10 -> 74
# Sambalpur | schools | Scroll 11 -> 80
# Sambalpur | schools | Scroll 12 -> 87
# Sambalpur | schools | Scroll 13 -> 94
# Sambalpur | schools | Scroll 14 -> 100
# Sambalpur | schools | Scroll 15 -> 107
# Sambalpur | schools | Scroll 16 -> 114
# Sambalpur | schools | Scroll 17 -> 120
# Sambalpur | schools | Scroll 18 -> 120
# Sambalpur | schools | Scroll 19 -> 120
# Sambalpur | schools | Scroll 20 -> 120
# Sambalpur | schools | Scroll 21 -> 120
# Collected 120 links
# Sambalpur | 1/120
# Vedic International School,Sambalpur,Odisha
# Sambalpur | 2/120
# Indian Public School, Sambalpur
# Sambalpur | 3/120
# Delhi Public School Sambalpur
# Sambalpur | 4/120
# Guru Nanak Public School
# Sambalpur | 5/120
# St. Joseph's Convent Higher Secondary School
# Sambalpur | 6/120
# Seven Hills Residential School
# Sambalpur | 7/120
# Balika Vidyalaya Co-educational CBSE School
# Sambalpur | 8/120
# Madnawati Public School
# Sambalpur | 9/120
#
# Sambalpur | 10/120
# Kendriya Vidyalaya No.1 Sambalpur
# Sambalpur | 11/120
#
# Sambalpur | 12/120
# Aditya Residential School
# Sambalpur | 13/120
# SHEMROCK PUPILAGE
# Sambalpur | 14/120
# Advik Daycare And Playschool, ADVIK INTERNATIONAL SCHOOL
# Sambalpur | 15/120
# Veer Surendra Sai English Medium School
# Sambalpur | 16/120
# Pupilage A 21st Century Gurukul
# Sambalpur | 17/120
# Samaleswari Public School
# Sambalpur | 18/120
# Ankana School
# Sambalpur | 19/120
# St. Xavier's School, Sambalpur
# Sambalpur | 20/120
# Rashtriya Gopal Vidya Mandir
# Sambalpur | 21/120
# Delhi Public School
# Sambalpur | 22/120
# Vedic Munchkins
# Sambalpur | 23/120
# Apprize Higher Secondary School (Science,Commerce)
# Sambalpur | 24/120
#
# Sambalpur | 25/120
# Curious Cubs Preschool (Sambalpur)
# Sambalpur | 26/120
# Kesari Nandan Vidyaniketan School
# Sambalpur | 27/120
# Vikash The Concept School, Sambalpur
# Sambalpur | 28/120
# Sambalpur Junior Science College
# Sambalpur | 29/120
# G M higher secondary school
# Sambalpur | 30/120
# Dream India Schools
# Sambalpur | 31/120
# St. Joseph's Kindergarten School
# Modern Public School
# Sambalpur | 86/120
# Brilliant Stars Montessori School
# Sambalpur | 87/120
# Ashapali School
# Sambalpur | 88/120
# Hirakud Colony Primary School
# Sambalpur | 89/120
# Swara Sourav Academy
# Sambalpur | 90/120
# Gayatri Residential English Medium School
# Sambalpur | 91/120
# Vivitsa World School
# Sambalpur | 92/120
# Curious Cubs Preschool (Sambalpur 2)
# Sambalpur | 93/120
# Budharaja girls high school
# Sambalpur | 94/120
# ARYAN DANCE CLASSES
# Sambalpur | 95/120
# S3 Academy of Science and Technology
# Sambalpur | 96/120
# Chitrashala Drawing School
# Sambalpur | 97/120
# Kidzee - Dhanupali
# Sambalpur | 98/120
# Pratibha's Junior Coaching Center
# Sambalpur | 99/120
# Nag & Sons Motor Driving Training Academy
# Sambalpur | 100/120
# Dynamic dance studio
# Sambalpur | 101/120
# Gurukul Classes Sambalpur (Art's & Commerce)
# Sambalpur | 102/120
# Pandia Mathematics Centre
# Sambalpur | 103/120
# Upper Primary School
# Sambalpur | 104/120
# Big dance Academy
# Sambalpur | 105/120
# KOSHAL COMPUTER ACADEMY
# Sambalpur | 106/120
# Kshitish English Medium School
# Sambalpur | 107/120
# Sumati Behera High School
# Sambalpur | 108/120
# Dream Land Play School..
# Sambalpur | 109/120
# Stewart Public School
# Sambalpur | 110/120
# Dhankauda M.E School
# Sambalpur | 111/120
# HOPE-SCOPE DRIVING SCHOOL BUDHARAJA
# Sambalpur | 112/120
# UNITE LEARNING (Commerce Coaching)
# Sambalpur | 113/120
# BRIGHT FUTURE COACHING CENTRE
# Sambalpur | 114/120
# Rashtriya Swayamsevak Sangh(RSS),District Headquarter Office ,Sambalpur
# Sambalpur | 115/120
# Sri Shakti Pustak Bhandar
# Sambalpur | 116/120
# Raghavendra distance education
# Sambalpur | 117/120
# PRATIBHA INSTITUTE
# Sambalpur | 118/120
# Naveen Tutorials Commerce coaching Sambalpur | Best commerce coaching in sambalpur | CA | CS | Commerce Classes
# Sambalpur | 119/120
# Siba Commerce Classes
# Sambalpur | 120/120
# Sambalpur
#
# Searching: schools in Subarnapur Odisha
# Search Submitted
# Subarnapur | schools | Scroll 1 -> 14
# Subarnapur | schools | Scroll 2 -> 20
# Subarnapur | schools | Scroll 3 -> 27
# Subarnapur | schools | Scroll 4 -> 34
# Subarnapur | schools | Scroll 5 -> 40
# Subarnapur | schools | Scroll 6 -> 47
# Subarnapur | schools | Scroll 7 -> 54
# Subarnapur | schools | Scroll 8 -> 60
# Subarnapur | schools | Scroll 9 -> 67
# Subarnapur | schools | Scroll 10 -> 72
# Subarnapur | schools | Scroll 11 -> 72
# Subarnapur | schools | Scroll 12 -> 72
# Subarnapur | schools | Scroll 13 -> 72
# Subarnapur | schools | Scroll 14 -> 72
# Collected 72 links
# Subarnapur | 1/72
# Star youngachievers school
# Subarnapur | 2/72
# Ideal Public School, Sonepur
# Subarnapur | 3/72
# Sahara Trust High School
# Subarnapur | 4/72
# Dayananda Play/public School
# Subarnapur | 5/72
# Alpha Edu Hub
# Subarnapur | 6/72
# Saraswati Shishu Vidya Mandir Playground
# Subarnapur | 61/72
# Nicet Computer Center
# Subarnapur | 62/72
# Jawahar Navodaya Vidyalaya, Tarabha, Sonepur
# Subarnapur | 63/72
# Do not exist
# Subarnapur | 64/72
# GRAMOTHHAN
# Subarnapur | 65/72
# M/S Kanakdharaa Enterprises-AsianPaints
# Subarnapur | 66/72
# Royal Field
# Subarnapur | 67/72
# Dayanand play school, unit 2
# Subarnapur | 68/72
# Patabhadi Primary School
# Subarnapur | 69/72
# Baghiamunda
# Subarnapur | 70/72
# Koshal abashika bidyalaya
# Subarnapur | 71/72
# Spinning Mill Sonepur
# Subarnapur | 72/72
# Anganwadi , ward no -3
#
# Searching: schools in Sundargarh Odisha
# Search Submitted
# Sundargarh | schools | Scroll 1 -> 14
# Sundargarh | schools | Scroll 2 -> 20
# Sundargarh | schools | Scroll 3 -> 27
# Sundargarh | schools | Scroll 4 -> 33
# Sundargarh | schools | Scroll 5 -> 33
# Sundargarh | schools | Scroll 6 -> 33
# Sundargarh | schools | Scroll 7 -> 33
# Sundargarh | schools | Scroll 8 -> 33
# Collected 32 links
# Sundargarh | 1/32
# Eurokids Sundargarh
# Sundargarh | 2/32
# Sri Aurobindo School, Matruvihar, Sundargarh
# Sundargarh | 3/32
# Kendriya Vidyalaya, Sundargarh
# Sundargarh | 4/32
# Sundargarh Public School
# Sundargarh | 5/32
# Hello Kids - Kramnds Preschool, Sundergarh, Odisha
# Sundargarh | 6/32
# KIDZEE-SUNDARGARH
# Sundargarh | 7/32
# BS High School
# Sundargarh | 8/32
# Darshan Academy
# Sundargarh | 9/32
# Mother's Public School
# Sundargarh | 10/32
# Eklavya Model Residential School, Bhawanipur
# Sundargarh | 11/32
# St Theresa English School Sundargarh
# Sundargarh | 12/32
# Wisdom international School
# Sundargarh | 13/32
# Xavier International School Sundargarh
# Sundargarh | 14/32
# Global discovery school
# Sundargarh | 15/32
# Odisha Public School(New Complex)
# Sundargarh | 16/32
# Odisha Adarsha Vidyalaya, Talsankara, Sundargarh
# Sundargarh | 17/32
# Deepika Model School
# Sundargarh | 18/32
# Sarat Basanti Xavier School
# Sundargarh | 19/32
# St. Joseph's Convent School
# Sundargarh | 20/32
# The Assembly Of God School
# Sundargarh | 21/32
# Zeal Commerce Classes
# Sundargarh | 22/32
# Shakti Tutorial
# Sundargarh | 23/32
# District Education Office,Sundargarh
# Sundargarh | 24/32
# Municipal High School
# Sundargarh | 25/32
# Ratha Nodal U. P. School
# Sundargarh | 26/32
# Reserve Police High School
# Sundargarh | 27/32
# DAV Public School, Kansbahal
# Sundargarh | 28/32
# St. Mary girls School Sundargarh ସେନ୍ଟ ମେରୀ ବିଦ୍ୟାଳୟ
# Sundargarh | 29/32
# Adruta Children Home
# Sundargarh | 30/32
# Regional Driving and Mechanical Training Institute
# Sundargarh | 31/32
# Dream Light Home(For girls)
# Sundargarh | 32/32
# ଆର୍ଶ ବିଦ୍ୟା ପିଠ
#
# Extraction Completed
# Total Schools Extracted: 1975
#
# Saved File: odisha_schools.csv
