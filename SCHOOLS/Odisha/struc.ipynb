# %%
import pandas as pd

# %%
df = pd.read_csv("odisha_schools.csv")

# %%
df.shape
# Out:
# (1975, 8)

# %%
duplicate_count = df.duplicated(
    subset=["School Name", "Google Maps URL"]
).sum()
duplicate_count
# Out:
# np.int64(0)

# %%
df = df[
    df["Phone"].notna() & 
    (df["Phone"].astype(str).str.strip() != "")
    ]
df.shape
# Out:
# (552, 8)

# %%
df = df[
    df["School Name"].notna()
    ]

df = df[
    df["School Name"].str.strip() != ""
    ]
df.shape
# Out:
# (552, 8)

# %%
# CLEAN PHONE COLUMNS
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]","",regex=True)
    .str.strip()
)

display(df[["Phone"]].head())
# Out:
#            Phone
# 0   094380 68336
# 1   086588 53185
# 2  1800 120 2316
# 3  06764 233 166
# 5   093388 57445

# %%
# SAVE CLEANED FILE
df.to_csv(
    "odisha_schools_cleaned.csv",
    index=False
)
