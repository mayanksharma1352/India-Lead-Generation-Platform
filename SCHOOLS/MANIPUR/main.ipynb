# %%
import time
import random
import pandas as pd

from datetime import datetime

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.service import Service

from webdriver_manager.chrome import ChromeDriverManager


districts = [
        "Bishnupur",
        "Chandel",
        "Churachandpur",
        "Imphal East",
        "Imphal West",
        "Jiribam",
        "Kakching",
        "Kamjong",
        "Kangpokpi",
        "Noney",
        "Pherzawl",
        "Senapati",
        "Tamenglong",
        "Tengnoupal",
        "Thoubal",
        "Ukhrul"
]


search_types = [
    "schools"
]



options = webdriver.ChromeOptions()

options.add_argument("--start-maximized")

options.add_argument(
    "--disable-blink-features=AutomationControlled"
)

options.add_argument("--disable-notifications")


driver = webdriver.Chrome(

    service=Service(
        ChromeDriverManager().install()
    ),

    options=options
)



driver.get("https://www.google.com/maps")

print("Opening Google Maps...")

time.sleep(15)

print("Google Maps Loaded")



all_data = []

visited_links = set()


def get_search_box():

    selectors = [

        '//input[@id="searchboxinput"]',
        '//input[contains(@placeholder,"Search")]',
        '//input[contains(@aria-label,"Search")]',
        '//input'

    ]

    for selector in selectors:

        try:

            box = driver.find_element(
                By.XPATH,
                selector
            )

            return box

        except:
            pass

    return None



def extract_school_data():

    try:


        try:
            name = driver.find_element(
                By.TAG_NAME,
                "h1"
            ).text
        except:
            name = ""


        try:
            address = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"address")]'
            ).text
        except:
            address = ""

       
        try:
            phone = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"phone")]'
            ).text
        except:
            phone = ""


        try:
            website = driver.find_element(
                By.XPATH,
                '//a[contains(@data-item-id,"authority")]'
            ).get_attribute("href")
        except:
            website = ""


        try:
            rating = driver.find_element(
                By.XPATH,
                '//div[@role="img"]'
            ).get_attribute("aria-label")
        except:
            rating = ""

        return {

            "School Name": name,
            "Address": address,
            "Phone": phone,
            "Website": website,
            "Rating": rating,
            "Google Maps URL": driver.current_url

        }

    except:

        return None




for district in districts:

    for search_type in search_types:

        try:

            query = (
                f"{search_type} "
                f"in {district} Manipur"
            )

            print(f"\nSearching: {query}")

   

            search_box = get_search_box()

            if not search_box:

                print("Search Box Not Found")

                continue

            ActionChains(driver).move_to_element(
                search_box
            ).click().perform()

            time.sleep(1)

            search_box.send_keys(
                Keys.CONTROL + "a"
            )

            time.sleep(1)

            search_box.send_keys(Keys.DELETE)

            time.sleep(1)

        
            for char in query:

                search_box.send_keys(char)

                time.sleep(0.03)

            search_box.send_keys(Keys.ENTER)

            print("Search Submitted")

            time.sleep(8)



            try:

                scrollable_div = driver.find_element(
                    By.XPATH,
                    '//div[@role="feed"]'
                )

                previous_count = 0

                stagnant = 0

                for i in range(100):

                    driver.execute_script(
                        """
                        arguments[0].scrollTop =
                        arguments[0].scrollHeight
                        """,
                        scrollable_div
                    )

                    time.sleep(4)

                    listings = driver.find_elements(
                        By.XPATH,
                        '//a[contains(@href,"/maps/place/")]'
                    )

                    current_count = len(listings)

                    print(
                        f"{district} | "
                        f"{search_type} | "
                        f"Scroll {i+1} -> "
                        f"{current_count}"
                    )

                    if current_count == previous_count:

                        stagnant += 1

                    else:

                        stagnant = 0

                    if stagnant >= 4:

                        break

                    previous_count = current_count

            except Exception as e:

                print(f"Scrolling Error: {e}")

     

            listings = driver.find_elements(
                By.XPATH,
                '//a[contains(@href,"/maps/place/")]'
            )

            links = []

            for listing in listings:

                try:

                    link = listing.get_attribute("href")

                    if (
                        link
                        and link not in visited_links
                    ):

                        links.append(link)

                        visited_links.add(link)

                except:
                    pass

            print(f"Collected {len(links)} links")



            for index, link in enumerate(links):

                try:

                    print(
                        f"{district} | "
                        f"{index+1}/{len(links)}"
                    )

                    driver.get(link)

                    time.sleep(
                        random.uniform(2, 3)
                    )

                    data = extract_school_data()

                    if data:

                        data["District"] = district

                        data["Search Type"] = search_type

                        all_data.append(data)

                        print(data["School Name"])

   

                    if len(all_data) % 100 == 0:

                        backup_df = pd.DataFrame(
                            all_data
                        )

                        backup_df.drop_duplicates(
                            subset=[
                                "School Name",
                                "Google Maps URL"
                            ],
                            inplace=True
                        )

                        backup_df.to_csv(
                            "manipur_schools_backup.csv",
                            index=False
                        )

                        print("Backup Saved")

                except Exception as e:

                    print(
                        f"School Error: {e}"
                    )

        except Exception as e:

            print(
                f"District Error: {e}"
            )



df = pd.DataFrame(all_data)

df.drop_duplicates(

    subset=[
        "School Name",
        "Google Maps URL"
    ],

    inplace=True
)



filename = (
    f"manipur_schools.csv"
)

df.to_csv(
    filename,
    index=False
)

print("\nExtraction Completed")

print(
    f"Total Schools Extracted: {len(df)}"
)

print(f"\nSaved File: {filename}")

driver.quit()
# Out:
# Opening Google Maps...
# Google Maps Loaded
#
# Searching: schools in Bishnupur Manipur
# Search Submitted
# Bishnupur | schools | Scroll 1 -> 4
# Bishnupur | schools | Scroll 2 -> 4
# Bishnupur | schools | Scroll 3 -> 4
# Bishnupur | schools | Scroll 4 -> 4
# Bishnupur | schools | Scroll 5 -> 4
# Collected 4 links
# Bishnupur | 1/4
# Loyola School
# Bishnupur | 2/4
# Bishnupur High School
# Bishnupur | 3/4
# Bishnupur Higher Secondary School
# Bishnupur | 4/4
# JAWAHAR NAVODAYA VIDYALAYA
#
# Searching: schools in Chandel Manipur
# Search Submitted
# Chandel | schools | Scroll 1 -> 14
# Chandel | schools | Scroll 2 -> 15
# Chandel | schools | Scroll 3 -> 15
# Chandel | schools | Scroll 4 -> 15
# Chandel | schools | Scroll 5 -> 15
# Chandel | schools | Scroll 6 -> 15
# Collected 15 links
# Chandel | 1/15
# New Hope Academy
# Chandel | 2/15
# Maha Union Govt.Higher Secondary School
# Chandel | 3/15
# St. Peter's higher secondary school, chandel
# Chandel | 4/15
# St. Peter's School, Japhou
# Chandel | 5/15
# Jawahar Navodaya Vidyalaya
# Chandel | 6/15
# Cheengkhu Primary school
# Chandel | 7/15
# St. Paul's High School
# Chandel | 8/15
# Immanuel School
# Chandel | 9/15
# Anallon Christian Institute
# Chandel | 10/15
# Oak Hill Cristian Academy
# Chandel | 11/15
# Duthang Primary School
# Chandel | 12/15
# Shantal Bhavan Convent
# Chandel | 13/15
# Little Ones Kindergarten
# Chandel | 14/15
# DKS Coaching Centre
# Chandel | 15/15
# St Joseph's School, Chandel Hqtrs
#
# Searching: schools in Churachandpur Manipur
# Search Submitted
# Churachandpur | schools | Scroll 1 -> 14
# Churachandpur | schools | Scroll 2 -> 20
# Churachandpur | schools | Scroll 3 -> 27
# Churachandpur | schools | Scroll 4 -> 34
# Churachandpur | schools | Scroll 5 -> 40
# Churachandpur | schools | Scroll 6 -> 47
# Churachandpur | schools | Scroll 7 -> 54
# Churachandpur | schools | Scroll 8 -> 60
# Churachandpur | schools | Scroll 9 -> 67
# Churachandpur | schools | Scroll 10 -> 74
# Churachandpur | schools | Scroll 11 -> 80
# Churachandpur | schools | Scroll 12 -> 87
# Churachandpur | schools | Scroll 13 -> 94
# Churachandpur | schools | Scroll 14 -> 100
# Churachandpur | schools | Scroll 15 -> 107
# Churachandpur | schools | Scroll 16 -> 114
# Churachandpur | schools | Scroll 17 -> 118
# Churachandpur | schools | Scroll 18 -> 118
# Churachandpur | schools | Scroll 19 -> 118
# Churachandpur | schools | Scroll 20 -> 118
# Churachandpur | schools | Scroll 21 -> 118
# Collected 118 links
# Churachandpur | 1/118
# St. Mary's Higher Secondary School
# Churachandpur | 2/118
#
# Churachandpur | 3/118
# Lalpuithluaii Foundation School,
# Churachandpur | 4/118
# Don Bosco Hr. Sec. School
# Churachandpur | 5/118
# Mount Carmel School
# Churachandpur | 6/118
# Hidden Valley School
# Churachandpur | 7/118
#
# Churachandpur | 8/118
# Young Learners School
# Churachandpur | 9/118
# Soikholal Ideal High School
# Churachandpur | 10/118
# Horeb Educational Academy
# Churachandpur | 11/118
# Rayburn High School
# Churachandpur | 12/118
# Arcadia School, Churachandpur
# Churachandpur | 13/118
# Rostad Memorial High School
# Churachandpur | 14/118
# EuroKids PreSchool in Molnom, Churachandpur
# Churachandpur | 15/118
# The Dawn School,
# Churachandpur | 16/118
# New Churachandpur JB School
# Churachandpur | 17/118
# Jawahar Navodaya Vidyalaya,Churachandpur,Manipur
# Churachandpur | 18/118
# St. Stephen English School
# Churachandpur | 19/118
# St.Paul's Institute
# Churachandpur | 20/118
# Conflate Academy
# Churachandpur | 21/118
# St. John High School, Lamka
# Churachandpur | 22/118
# Chinkham Modern High School, Hiangtam Churachandpur
# Churachandpur | 23/118
# Sielmat Christian Higher Sec. School
# Churachandpur | 24/118
# St. Peter's School, Vengnuam
# Churachandpur | 25/118
# Legacy Faith Academy, Lamka
# Churachandpur | 26/118
# Ebenezer Academy
# Churachandpur | 27/118
# Dr. S. Radhakrishnan Foundation School
# Churachandpur | 28/118
# Genesis Learners' School, Zogam
# Churachandpur | 29/118
# WeDance Academy
# Churachandpur | 30/118
# Happy Heart School
# Churachandpur | 31/118
# Young Pillars College
# Churachandpur | 32/118
# Hope Baptist Academy
# Churachandpur | 33/118
# Salt Brook School, Tuibong
# Churachandpur | 34/118
# EuroKids Preschool in Lamka, Churachandpur
# Churachandpur | 35/118
# Bliss International School
# Churachandpur | 36/118
# Ad Campaign Academy
# Churachandpur | 37/118
# Lamka Central School
# Churachandpur | 38/118
# Obadiyah School
# Churachandpur | 39/118
# Rav Avichail memorial School
# Churachandpur | 40/118
# North Eastern Children's Academy
# Churachandpur | 41/118
# Don Bosco School, Churachandpur
# Churachandpur | 42/118
# St. Joseph's School
# Churachandpur | 43/118
# Tunnu Academy
# Churachandpur | 44/118
# The Dawn School
# Churachandpur | 45/118
# Saviour's Public School
# Churachandpur | 46/118
# Gandhi Memorial High School, Churachanpur
# Churachandpur | 47/118
# AEVITAS LEARNERS' SCHOOL
# Churachandpur | 48/118
# C.MUNKOT VILLAGE,T.LALOIPHAI ENGLISH HIGH SCHOOL
# Churachandpur | 49/118
# Upper Primary School, Churachandpur
# Churachandpur | 50/118
# Legacy Prime School
# Churachandpur | 51/118
# Rengkai hr sec school Canteen
# Churachandpur | 52/118
# Grace Boarding
# Churachandpur | 53/118
# Blue Star Academy, Lamka
# Churachandpur | 54/118
# E L Scism High School
# Churachandpur | 55/118
# Siamsinpawlpi Residential School, Lamka
# Churachandpur | 56/118
# MEDHA, Melodious Education Housing Academy
# Churachandpur | 57/118
# Young Pillar School
# Churachandpur | 58/118
# Heritage Day School
# Churachandpur | 59/118
# Emmanuel Residential School, Churachandpur
# Churachandpur | 60/118
# V.K. Montessori School
# Churachandpur | 61/118
# Sophia
# Churachandpur | 62/118
# GRACE ACADEMY, TUIBONG
# Churachandpur | 63/118
# Sangai International University
# Churachandpur | 64/118
# Douglas Memorial High School
# Churachandpur | 65/118
# Churachanpur NIOS Study Centre, Churachanpur
# Churachandpur | 66/118
# AG High School
# Churachandpur | 67/118
# NSCBAV (Residential School)
# Churachandpur | 68/118
# Easton Hall School
# Churachandpur | 69/118
# Martin Luther Academy
# Churachandpur | 70/118
# Kinship High School, Kamdou Veng, Lamka
# Churachandpur | 71/118
# Salvah High School
# Churachandpur | 72/118
# Trinity College & Seminary
# Churachandpur | 73/118
# School Playground
# Churachandpur | 74/118
# Bethesda School Of Nursing
# Churachandpur | 75/118
# Phungkhothang Govt. High School
# Churachandpur | 76/118
# EFCI NSSD Sunday School
# Churachandpur | 77/118
# Megha Boarding
# Churachandpur | 78/118
# Logos School,B.Aijalon
# Churachandpur | 79/118
# Cornerstone Academy (Christian School)
# Churachandpur | 80/118
# NKT HIGH SCHOOL
# Churachandpur | 81/118
# New Lamka Upper Primary School
# Backup Saved
# Churachandpur | 82/118
# Bethany Christian College
# Churachandpur | 83/118
# Rengkai Govt Higher Secondary School
# Churachandpur | 84/118
# Don Bosco School Ground
# Churachandpur | 85/118
# Saidan Sunshine School
# Churachandpur | 86/118
# Mount Olive School, Tangmual
# Churachandpur | 87/118
# Sielmat Bible College
# Churachandpur | 88/118
# ICI Naupang Sunday School
# Churachandpur | 89/118
# Pangzawl Primary School
# Churachandpur | 90/118
# Ebenezer Music Home
# Churachandpur | 91/118
# Tuibuang High School
# Churachandpur | 92/118
# J.P SELECTION, CCPur
# Churachandpur | 93/118
# C.Munkot Sunday school chapel🏫
# Churachandpur | 94/118
# KCC Mission School, D. Kangjam
# Churachandpur | 95/118
# St. Dominic' School, Molnom
# Churachandpur | 96/118
# Churachandpur
# Churachandpur | 97/118
# Gulson Rai housh
# Churachandpur | 98/118
# VK Tawna Shopping Complex
# Churachandpur | 99/118
# Ngulthawng Bazaar, Churachandpur
# Churachandpur | 100/118
# Family lane, Bijang
# Churachandpur | 101/118
# M Songgel ECA Sunday School Building
# Churachandpur | 102/118
# Hermon English School
# Churachandpur | 103/118
# BCSS (Baptist Children Sunday School)
# Churachandpur | 104/118
# Cambridge School
# Churachandpur | 105/118
# L.X Kids Foundation School
# Churachandpur | 106/118
# Bethany Christian Higher Sec. School
# Churachandpur | 107/118
# GNM School of nursing Churachandpur
# Churachandpur | 108/118
# Children Training High School
# Churachandpur | 109/118
# Prime Academy
# Churachandpur | 110/118
# Prime Academy, churachandpur
# Churachandpur | 111/118
# Donbosco school convent
# Churachandpur | 112/118
# Bijang Loubuk JB School
# Churachandpur | 113/118
# Vimala Raina Governement High School
# Churachandpur | 114/118
# Wesleyan Children's Sunday School.
# Churachandpur | 115/118
# Shoute Music School SMS
# Churachandpur | 116/118
# Lalpuithluaii Foundation School Boarding and Preparatory Section
# Churachandpur | 117/118
# Mount Olive Elementary
# Churachandpur | 118/118
# Zamminlun Singson Art Studio
#
# Searching: schools in Imphal East Manipur
# Search Submitted
# Imphal East | schools | Scroll 1 -> 14
# Imphal East | schools | Scroll 2 -> 20
# Imphal East | schools | Scroll 3 -> 27
# Imphal East | schools | Scroll 4 -> 34
# Imphal East | schools | Scroll 5 -> 40
# Imphal East | schools | Scroll 6 -> 47
# Imphal East | schools | Scroll 7 -> 54
# Imphal East | schools | Scroll 8 -> 60
# Imphal East | schools | Scroll 9 -> 67
# Imphal East | schools | Scroll 10 -> 74
# Imphal East | schools | Scroll 11 -> 80
# Imphal East | schools | Scroll 12 -> 87
# Imphal East | schools | Scroll 13 -> 94
# Imphal East | schools | Scroll 14 -> 100
# Imphal East | schools | Scroll 15 -> 107
# Imphal East | schools | Scroll 16 -> 114
# Imphal East | schools | Scroll 17 -> 120
# Imphal East | schools | Scroll 18 -> 120
# Imphal East | schools | Scroll 19 -> 120
# Imphal East | schools | Scroll 20 -> 120
# Imphal East | schools | Scroll 21 -> 120
# Collected 120 links
# Imphal East | 1/120
# Manipur Creative School
# Imphal East | 2/120
# St. Joseph's Hr. Sec School, Imphal
# Imphal East | 3/120
# St Anthony's School
# Imphal East | 4/120
# Eden Public School, Imphal
# Imphal East | 5/120
# Alpha Omega School
# Imphal East | 6/120
# Johnstone Higher Secondary School, Imphal
# Imphal East | 7/120
# CC Higher Secondary School, Imphal
# Imphal East | 8/120
# Sainik School, Imphal
# Imphal East | 9/120
# Mega Manipur School
# Imphal East | 10/120
# Kanan Devi Memorial School Lamphel
# Imphal East | 11/120
# Tiny Tots' Unique School
# Imphal East | 12/120
# Tamphasana Girls' Higher Secondary School
# Imphal East | 13/120
# Shemrock Kids Garden
# Imphal East | 14/120
# Manipur Public School
# Imphal East | 15/120
# Herbert School
# Imphal East | 16/120
# Nirmalabas High School
# Imphal East | 17/120
# The Ushus School
# Imphal East | 18/120
# City Montessori Higher Secondary School
# Imphal East | 19/120
# Ananda Singh Higher Secondary Academy
# Imphal East | 20/120
# Eastern Point Academy neyar
# Imphal East | 21/120
# Little Flower School
# Imphal East | 22/120
# Kids’ Foundation School | Manipur
# Imphal East | 23/120
# Netaji Subhash Chandra Bose Awasiya Vidyalaya, Chingkhei Ching, Imphal-East
# Imphal East | 24/120
# Shishu Nistha Niketan School
# Imphal East | 25/120
# Comet School , Imphal
# Imphal East | 26/120
# Pitambara English School
# Imphal East | 27/120
# MARIA MONTESSORI SCHOOL
# Imphal East | 28/120
# Christ Jyoti English School
# Imphal East | 29/120
# Mount Princeton School
# Imphal East | 30/120
# Don Bosco School
# Imphal East | 31/120
# Guru Nanak Public School
# Imphal East | 32/120
# S V GETWELL SCHOOL PLAYGROUND
# Imphal East | 33/120
# Ramakrishna Mission School
# Imphal East | 34/120
# Hundred Flower's Higher Secondary School
# Imphal East | 35/120
# R M School
# Imphal East | 36/120
# D And D Store
# Imphal East | 37/120
# DAV Public School
# Imphal East | 38/120
# SL Arena of learning
# Imphal East | 39/120
# Little Millennium Preschool - Imphal, Wangkhei
# Imphal East | 40/120
# Alpha BCI Memorial Academy
# Imphal East | 41/120
# D'Regina English High School
# Imphal East | 42/120
# North Point Higher Secondary School
# Imphal East | 43/120
# Rahmania High School
# Imphal East | 44/120
# Little Millennium Preschool - Imphal, Lamphel
# Imphal East | 45/120
# Mangoljao English School
# Imphal East | 46/120
# Hafiz Brighter Academy
# Imphal East | 47/120
# Manipur Creative School Hostel
# Imphal East | 48/120
# Prim Rose English School
# Imphal East | 49/120
# Shantilata Memorial School
# Imphal East | 50/120
# The Imphal Valley School
# Imphal East | 51/120
# Sanfort school imphal
# Imphal East | 52/120
# Mannu English School
# Imphal East | 53/120
# Maibam Priyadarshini Memorial Educational Institute, (School), Kairang.. Imphal East..
# Imphal East | 54/120
# Regular English High School
# Imphal East | 55/120
# KIDS' HIGH SCHOOL
# Imphal East | 56/120
# Little Rose Higher Secondary School
# Imphal East | 57/120
# Eastern Ideal High School
# Imphal East | 58/120
# Sacred Heart School
# Imphal East | 59/120
# Shemrock Woodstock
# Imphal East | 60/120
# Kokil Boarding School, Khurai Ningthoubung Leikai
# Imphal East | 61/120
# Princeton International School
# Imphal East | 62/120
# JNV Yaralpat
# Imphal East | 63/120
# Kidzee Imphal Branch
# Backup Saved
# Imphal East | 64/120
# Assam Rifles Public School, Mantripukhri
# Imphal East | 65/120
# The Imphal English School
# Imphal East | 66/120
# Jawaharlal Nehru Institute of Medical Sciences, Imphal.
# Imphal East | 67/120
# Rohini Northern school
# Imphal East | 68/120
# Aim School
# Imphal East | 69/120
# Twinkle Star Academy
# Imphal East | 70/120
# Leishemba Maheikol
# Imphal East | 71/120
# Unacco School Khongman
# Imphal East | 72/120
# Nongpok Maheikol
# Imphal East | 73/120
# Srivan Higher Secondary School
# Imphal East | 74/120
# Concept School, Imphal
# Imphal East | 75/120
# THE M M HIGHER SECONDARY SCHOOL
# Imphal East | 76/120
# Heingang High School
# Imphal East | 77/120
# Pioneer Academy
# Imphal East | 78/120
# Khurai Popular High School
# Imphal East | 79/120
# Friendship Educational Academy
# Imphal East | 80/120
# Covenant English School
# Imphal East | 81/120
# Catholic School
# Imphal East | 82/120
# Sherwood School
# Imphal East | 83/120
# Sapling Pre-School
# Imphal East | 84/120
# Zenith Academy
# Imphal East | 85/120
# Areca brick's industry. (A.B.I)
# Imphal East | 86/120
# NORTH EASTERN ENGLISH SCHOOL
# Imphal East | 87/120
# Success Schooll
# Imphal East | 88/120
# Kendriya Vidyalaya No.2 CRPF Langjing
# Imphal East | 89/120
# Bal Vidya Mandir Higher Secondary School
# Imphal East | 90/120
# Thiyam Konjin High School, Imphal East
# Imphal East | 91/120
# Lodestar Public School
# Imphal East | 92/120
# Kongpal Imphal Morning High School
# Imphal East | 93/120
# Chanung Primary School, Imphal East
# Imphal East | 94/120
# NEST BOARDING &DAY BOARDING SCHOOL
# Imphal East | 95/120
# Top Primary High School
# Imphal East | 96/120
# Shishu Nistha Niketan
# Imphal East | 97/120
# Nungaipokpi Primary School, Imphal East
# Imphal East | 98/120
# Human Resource Development Academy
# Imphal East | 99/120
# Halleey English School
# Imphal East | 100/120
# International Modernised Academy
# Imphal East | 101/120
# Tulihal Mayai Leikai Primary School, Imphal East
# Imphal East | 102/120
# Nongmeibung Thamchet primary school
# Imphal East | 103/120
# Jawahar Navodaya Vidyalaya, Khumbong, Imphal West
# Imphal East | 104/120
# UNACCO SCHOOL CHANUNG
# Imphal East | 105/120
# Chingkhei Lokmang Primary School, Imphal East
# Imphal East | 106/120
# Pangong Makhong Upper Primary School
# Imphal East | 107/120
# RK Sanatombi Devi Vidyalaya
# Imphal East | 108/120
# Sagolmang Primary School, Imphal East
# Imphal East | 109/120
# Top Dushara High School
# Imphal East | 110/120
# Irilbung High School
# Imphal East | 111/120
# Kindergarten Montessori School
# Imphal East | 112/120
# Master Sankey English School
# Imphal East | 113/120
# Brighter Academy Imphal, new chekon
# Imphal East | 114/120
# Kshetri Top Primary School (Madrassa)
# Imphal East | 115/120
# KTS Khurai (Konsam Tomba & Sachi School)
# Imphal East | 116/120
# Laikon Upper Primary School
# Imphal East | 117/120
# Little Master English Hr. Secondary School
# Imphal East | 118/120
# SL KIDZ ARENA MAHEIKOL
# Imphal East | 119/120
# SAINIK SCHOOL Imphal
# Imphal East | 120/120
# ZEO Zone-II, Porompat Imphal East
#
# Searching: schools in Imphal West Manipur
# Search Submitted
# Imphal West | schools | Scroll 1 -> 14
# Imphal West | schools | Scroll 2 -> 20
# Imphal West | schools | Scroll 3 -> 27
# Imphal West | schools | Scroll 4 -> 34
# Imphal West | schools | Scroll 5 -> 40
# Imphal West | schools | Scroll 6 -> 47
# Imphal West | schools | Scroll 7 -> 54
# Imphal West | schools | Scroll 8 -> 60
# Imphal West | schools | Scroll 9 -> 67
# Imphal West | schools | Scroll 10 -> 74
# Imphal West | schools | Scroll 11 -> 80
# Imphal West | schools | Scroll 12 -> 87
# Imphal West | schools | Scroll 13 -> 94
# Imphal West | schools | Scroll 14 -> 100
# Imphal West | schools | Scroll 15 -> 107
# Imphal West | schools | Scroll 16 -> 114
# Imphal West | schools | Scroll 17 -> 120
# Imphal West | schools | Scroll 18 -> 120
# Imphal West | schools | Scroll 19 -> 120
# Imphal West | schools | Scroll 20 -> 120
# Imphal West | schools | Scroll 21 -> 120
# Collected 58 links
# Imphal West | 1/58
# Imphal West Central School
# Imphal West | 2/58
# Heritage Convent
# Imphal West | 3/58
# Photon School
# Imphal West | 4/58
# Ramlal Paul Higher Secondary School
# Imphal West | 5/58
# Bachpan Play School in Imphal Manipur | Best Preschool Near Me | Nursery School for Your Child’s Bright Start
# Imphal West | 6/58
# Lalambung High School
# Imphal West | 7/58
# Lee Faith School
# Imphal West | 8/58
# Mekola Gulap Higher Secondary School
# Imphal West | 9/58
# SDJM Higher Secondary School
# Imphal West | 10/58
# Kunje Preschool
# Imphal West | 11/58
# Kendriya Vidyalaya No.1 Imphal
# Imphal West | 12/58
# Ibotonsana Girls Higher Secondary School
# Imphal West | 13/58
# Holy Kingdom School
# Imphal West | 14/58
# Keishamthong High School
# Imphal West | 15/58
# DAS (Delta Advance School) a Govt. recognised Hr. Sec. for COHSEM (Science & Arts)
# Imphal West | 16/58
# NSCBAV, Imphal West
# Imphal West | 17/58
# St. Peter's High School
# Imphal West | 18/58
# New Light Public School
# Imphal West | 19/58
# Ajad English School
# Imphal West | 20/58
# Ideal Blind School
# Imphal West | 21/58
# Don Bosco School Langjing
# Imphal West | 22/58
# Sunrise Public School
# Imphal West | 23/58
# The Imphal Valley Academy
# Imphal West | 24/58
# ERUDIO ACADEMY
# Imphal West | 25/58
# Thangmeiband Khoyathong Tombisana High School
# Imphal West | 26/58
# Budhimanjuri High School
# Imphal West | 27/58
# Brajalal Institute of Sciences (BIS)
# Imphal West | 28/58
# MALOM MEGHA HIGH SCHOOL,
# Imphal West | 29/58
# Trinity Public School
# Imphal West | 30/58
# THE PARAMOUNT ENGLISH SCHOOL
# Imphal West | 31/58
# Unacco School , Meitram
# Imphal West | 32/58
# Hello Kids Pre-School
# Imphal West | 33/58
# Manipur University
# Imphal West | 34/58
# King's way English School
# Imphal West | 35/58
# UNACCO School, Chanura, Utlou, Imphal
# Imphal West | 36/58
# Pole Star Public School
# Imphal West | 37/58
# Takyel Khongbal High School
# Imphal West | 38/58
# St.Meera's School
# Imphal West | 39/58
# Active English School
# Imphal West | 40/58
# GoAviator Academy
# Imphal West | 41/58
# BYS Higher Secondary School
# Imphal West | 42/58
# KANGLEIPAK ENGLISH SCHOOL
# Imphal West | 43/58
# Praja Higher Secondary School,Lamshang
# Backup Saved
# Imphal West | 44/58
# Comprehensive Concept School
# Imphal West | 45/58
# Board of Secondary Education manipur
# Imphal West | 46/58
# D. M. College of Science
# Imphal West | 47/58
# Takyel Mapal Upper Primary School
# Imphal West | 48/58
# Baby Seikam English High School
# Imphal West | 49/58
# Lilashing Khongnangkhong
# Imphal West | 50/58
# Nongmeibung Junior High School
# Imphal West | 51/58
# SI Academy
# Imphal West | 52/58
# The School Of Nursing
# Imphal West | 53/58
# Kanglei Driving School
# Imphal West | 54/58
# Hello Kids
# Imphal West | 55/58
# Leichil online exam centre
# Imphal West | 56/58
# Taobungkhok High School
# Imphal West | 57/58
# Diana English School
# Imphal West | 58/58
# Petals Preschool Nongmeibung
#
# Searching: schools in Jiribam Manipur
# Search Submitted
# Jiribam | schools | Scroll 1 -> 14
# Jiribam | schools | Scroll 2 -> 20
# Jiribam | schools | Scroll 3 -> 27
# Jiribam | schools | Scroll 4 -> 34
# Jiribam | schools | Scroll 5 -> 36
# Jiribam | schools | Scroll 6 -> 36
# Jiribam | schools | Scroll 7 -> 36
# Jiribam | schools | Scroll 8 -> 36
# Jiribam | schools | Scroll 9 -> 36
# Collected 36 links
# Jiribam | 1/36
# Jiribam Higher Secondary School
# Jiribam | 2/36
# The pebble Stone International School
# Jiribam | 3/36
# Jiribam Model High School
# Jiribam | 4/36
# RK Sanatombi Vidyalaya
# Jiribam | 5/36
# Cambridge English School
# Jiribam | 6/36
# St Joseph School
# Jiribam | 7/36
# HIGHWAY ENG. SCHOOL
# Jiribam | 8/36
# leirikhombi lower primary school
# Jiribam | 9/36
# Blooming Flower Children's Foundation School
# Jiribam | 10/36
# R K Sanatombi Devi Vidyalaya
# Jiribam | 11/36
# Hill Cross School
# Jiribam | 12/36
# New life Academy
# Jiribam | 13/36
# Kamranga Lamkhai Jiribam Near Govt LP School
# Jiribam | 14/36
# Jiri College Jiribam
# Jiribam | 15/36
# Lamba Sorok Junior High School
# Jiribam | 16/36
# Al-Ameen School
# Jiribam | 17/36
# EBC Sunday school
# Jiribam | 18/36
# SSA Primary School, Ngahmunphai
# Jiribam | 19/36
# Tatbung Primary School
# Jiribam | 20/36
# Lalpani Govt High School
# Jiribam | 21/36
# PHAITOL CATHOLIC SCHOOL
# Jiribam | 22/36
# Bidyanagar L.P. School
# Jiribam | 23/36
# Chingdong leikai Government Upper Primary School
# Jiribam | 24/36
# Sonapur Part 1 Primary school
# Jiribam | 25/36
# Kasturba Girls High School
# Jiribam | 26/36
# Govt. L.P School Kamrangkha Khasi
# Jiribam | 27/36
# Kadamtala Primary School
# Jiribam | 28/36
# Aglapur Govt Primary School
# Jiribam | 29/36
# Azhar Uddin Home
# Jiribam | 30/36
# Lower Primary Scool (L.P School)
# Jiribam | 31/36
# Alimnagar LP School
# Jiribam | 32/36
# Lalpani School Playground
# Jiribam | 33/36
# Jiribam Helipad
# Jiribam | 34/36
# Kashimpur Jr. High School
# Jiribam | 35/36
# Swaise Lai yam leibane
# Jiribam | 36/36
# Jiri Public English School (JPES)
#
# Searching: schools in Kakching Manipur
# Search Submitted
# Kakching | schools | Scroll 1 -> 14
# Kakching | schools | Scroll 2 -> 20
# Kakching | schools | Scroll 3 -> 27
# Kakching | schools | Scroll 4 -> 34
# Kakching | schools | Scroll 5 -> 40
# Kakching | schools | Scroll 6 -> 47
# Kakching | schools | Scroll 7 -> 54
# Kakching | schools | Scroll 8 -> 56
# Kakching | schools | Scroll 9 -> 56
# Kakching | schools | Scroll 10 -> 56
# Kakching | schools | Scroll 11 -> 56
# Kakching | schools | Scroll 12 -> 56
# Collected 56 links
# Kakching | 1/56
# Kakching Public School
# Kakching | 2/56
# Kakching Life School
# Kakching | 3/56
# Kakching Valley School
# Kakching | 4/56
# Model High School
# Kakching | 5/56
# Grace Cottage Academy, kakching
# Kakching | 6/56
# Mms Genius Academy, Kakching, Manipur
# Kakching | 7/56
# Padma Ratna English School & Padma Ratna College Of Advance Learning
# Kakching | 8/56
# Kakching Wairi Junior High School
# Kakching | 9/56
# Good Shepherd School
# Kakching | 10/56
# Martin Grammar School
# Kakching | 11/56
# kakching khunyai primary school
# Kakching | 12/56
# J.C DIGITAL ACADEMY
# Kakching | 13/56
# Assam Rifles School
# Kakching | 14/56
# Countryside Knowledge Park
# Kakching | 15/56
# Victory High School,Kakching.
# Kakching | 16/56
# Kakching Turel Wangma Junior School
# Kakching | 17/56
# L.P. School
# Kakching | 18/56
# Practising Junior High School
# Kakching | 19/56
# Kakching Girls High School
# Kakching | 20/56
# Kakching Garden - Kakching District
# Kakching | 21/56
# Khangshim Primary School
# Kakching | 22/56
# U.F.O. Kakching Branch
# Kakching | 23/56
# Modern Progressive Academy (MPA), Kakching
# Kakching | 24/56
# YM High school Hall
# Kakching | 25/56
# L.P School, Moirangthem Leikai
# Kakching | 26/56
# JRD Pathseeker Academy
# Kakching | 27/56
# Makha leikai high school
# Kakching | 28/56
# Library PR SCHOOL
# Kakching | 29/56
# Lamjao Primary School
# Kakching | 30/56
# Kakching Bazar
# Kakching | 31/56
# Mayai Leikai Upper Primary School
# Kakching | 32/56
# Mayai Leikai L.P. School
# Kakching | 33/56
# The Sanatombi High School Keirak
# Kakching | 34/56
# Langmeidong Hr. Sec. School
# Kakching | 35/56
# Government Primary Madrasha, Keirak Muslim
# Kakching | 36/56
# MangamBoarding
# Kakching | 37/56
# DSA ground
# Kakching | 38/56
# Kakching Phosupat Leikai
# Kakching | 39/56
# Lamjao High School
# Kakching | 40/56
# The H.Keinahal Memorial English School
# Kakching | 41/56
# AL FIQAR INTERNATIONAL SCHOOL (AFIS) SORA MAYAI LEIKAI IRENGBAND, PALEL. Kakching District
# Kakching | 42/56
# The Royal Brighter Academy Hr.Sec, Sora
# Kakching | 43/56
# Indoor stadium, kakching
# Kakching | 44/56
# Usha Driving School, Kakching Lamkhai(Khangshim). Manipur
# Kakching | 45/56
# Slopeland Public School
# Kakching | 46/56
# XpressBees Kakching Branch
# Kakching | 47/56
# MG Evergreen Hr. Sec. School
# Kakching | 48/56
# Kha Manipur,College
# Kakching | 49/56
# Little Ones Daycare
# Backup Saved
# Kakching | 50/56
# Shyamjai residence
# Kakching | 51/56
# Vishal Mega Mart
# Kakching | 52/56
# KAKCHING CHUMNANG COMMUNITY HALL
# Kakching | 53/56
# IACT Kakching, Computer Training Institute
# Kakching | 54/56
# KMC Rd Way
# Kakching | 55/56
# GREEN LIGHT BABY SCHOOL
# Kakching | 56/56
# Good Tidings Kids Centre
#
# Searching: schools in Kamjong Manipur
# Search Submitted
# Kamjong | schools | Scroll 1 -> 7
# Kamjong | schools | Scroll 2 -> 7
# Kamjong | schools | Scroll 3 -> 7
# Kamjong | schools | Scroll 4 -> 7
# Kamjong | schools | Scroll 5 -> 7
# Collected 7 links
# Kamjong | 1/7
# Kamjong Higher Secondary School
# Kamjong | 2/7
# Phungyar Hr. Sec. School
# Kamjong | 3/7
# UJB SCHOOL CHASSAD
# Kamjong | 4/7
# NK NEW HAVENG KAJONG RD UKHRUL MANIPUR
# Kamjong | 5/7
# Kamjong Baptist Church Sunday School
# Kamjong | 6/7
# LEGACY ACADEMY, CHASSAD
# Kamjong | 7/7
# Compassion Christian English School
#
# Searching: schools in Kangpokpi Manipur
# Search Submitted
# Kangpokpi | schools | Scroll 1 -> 14
# Kangpokpi | schools | Scroll 2 -> 20
# Kangpokpi | schools | Scroll 3 -> 23
# Kangpokpi | schools | Scroll 4 -> 23
# Kangpokpi | schools | Scroll 5 -> 23
# Kangpokpi | schools | Scroll 6 -> 23
# Kangpokpi | schools | Scroll 7 -> 23
# Collected 23 links
# Kangpokpi | 1/23
# Elite Hr Sec School
# Kangpokpi | 2/23
# Eurokids PreSchool Kangpokpi
# Kangpokpi | 3/23
# K.T. Higher Secondary School
# Kangpokpi | 4/23
# Good Shepherd School
# Kangpokpi | 5/23
# MBC Hr Sec School
# Kangpokpi | 6/23
# PMA SCHOOL
# Kangpokpi | 7/23
# JN PUBLIC SCHOOL
# Kangpokpi | 8/23
# Lighthouse School, Lighthouse School Arena
# Kangpokpi | 9/23
# Parizeau Maranatha Academy
# Kangpokpi | 10/23
# Kangpokpi Public School, Zogam
# Kangpokpi | 11/23
# Diamond English High School
# Kangpokpi | 12/23
# Genbiyang Primary School
# Kangpokpi | 13/23
# Kanggui Christian College
# Kangpokpi | 14/23
# Elite School Stationary
# Kangpokpi | 15/23
# Manipur Theological College
# Kangpokpi | 16/23
# Timsena aided primary school
# Kangpokpi | 17/23
# H.Laikot
# Kangpokpi | 18/23
# Rousang Computer Institute of Technology (RCIT) office Manipur
# Kangpokpi | 19/23
# Paangkriang Friendship School
# Kangpokpi | 20/23
# Chil Chil Asian Mission School
# Kangpokpi | 21/23
# Needy Home Academy
# Kangpokpi | 22/23
# St. Francis De Sales Higher Secondary School, Daili (Naga)
# Kangpokpi | 23/23
# Zalenveng Anganwadi Centre
#
# Searching: schools in Noney Manipur
# Search Submitted
# Noney | schools | Scroll 1 -> 14
# Noney | schools | Scroll 2 -> 17
# Noney | schools | Scroll 3 -> 17
# Noney | schools | Scroll 4 -> 17
# Noney | schools | Scroll 5 -> 17
# Noney | schools | Scroll 6 -> 17
# Collected 17 links
# Noney | 1/17
# Shemrock, Noney
# Noney | 2/17
# Sharon English High School
# Noney | 3/17
# CTS School, Longmai, Noney District, Manipur
# Noney | 4/17
# CGC SPECIAL SCHOOL NONEY
# Noney | 5/17
# Tengkonjang Hr.Secondary School
# Noney | 6/17
# TENTMAKER ACADEMY
# Noney | 7/17
# Tazei Public Higher Secondary school
# Noney | 8/17
# Domini English School
# Noney | 9/17
# Sungcham Friendship School
# Noney | 10/17
# Alphabetz International
# Noney | 11/17
# Upper primary school
# Noney | 12/17
# Namduanjang primary school
# Noney | 13/17
# Rangkhung 1 Primary School
# Noney | 14/17
# BEREAN BAPTIST ACADEMY
# Noney | 15/17
# LT Computer Institute
# Noney | 16/17
# Nungnang Heritage School
# Noney | 17/17
# Excellent Education Virtue High School Longmai 2
#
# Searching: schools in Pherzawl Manipur
# Search Submitted
# Pherzawl | schools | Scroll 1 -> 3
# Pherzawl | schools | Scroll 2 -> 3
# Pherzawl | schools | Scroll 3 -> 3
# Pherzawl | schools | Scroll 4 -> 3
# Pherzawl | schools | Scroll 5 -> 3
# Collected 3 links
# Pherzawl | 1/3
# PMS Pherzawl School
# Pherzawl | 2/3
# Pherzawl govt school
# Pherzawl | 3/3
# Pherzawl Govt. High School, Pherzawl, Mizoram
#
# Searching: schools in Senapati Manipur
# Search Submitted
# Senapati | schools | Scroll 1 -> 14
# Senapati | schools | Scroll 2 -> 18
# Senapati | schools | Scroll 3 -> 18
# Senapati | schools | Scroll 4 -> 18
# Senapati | schools | Scroll 5 -> 18
# Senapati | schools | Scroll 6 -> 18
# Collected 18 links
# Senapati | 1/18
# Mave School
# Senapati | 2/18
# MOUNT EVEREST HIGHER SECONDARY SCHOOL
# Senapati | 3/18
# St. Anthony's School
# Senapati | 4/18
# Bethany Higher Secondary School, Senapati, Manipur
# Senapati | 5/18
# St. Anthony School
# Senapati | 6/18
# Auxilium School, Senapati
# Senapati | 7/18
# MT.Zion Sr. Sec School
# Senapati | 8/18
# Mt. Pisgah College
# Senapati | 9/18
# Don Bosco Hr.sec. School Senapati
# Senapati | 10/18
# Jawahar Navodaya Vidyalaya Senapati-1, Pfukhro Mao Senapati Manipur
# Senapati | 11/18
# Star Sign School
# Senapati | 12/18
# Mount Everest College
# Senapati | 13/18
# St. Xavier College, Senapati
# Senapati | 14/18
# Thaye Play School
# Senapati | 15/18
# Little Explorer Pre School
# Senapati | 16/18
# P.P. Christian English High School
# Senapati | 17/18
# Mount Everest College of Teacher Education
# Senapati | 18/18
# Brook Dale school
#
# Searching: schools in Tamenglong Manipur
# Search Submitted
# Tamenglong | schools | Scroll 1 -> 14
# Tamenglong | schools | Scroll 2 -> 20
# Tamenglong | schools | Scroll 3 -> 26
# Tamenglong | schools | Scroll 4 -> 26
# Tamenglong | schools | Scroll 5 -> 26
# Tamenglong | schools | Scroll 6 -> 26
# Tamenglong | schools | Scroll 7 -> 26
# Collected 26 links
# Tamenglong | 1/26
# Don Bosco High School
# Tamenglong | 2/26
# Little Millennium Preschool - Tamenglong, Green Hills
# Tamenglong | 3/26
# Little Millennium - Tamenglong - Manipur
# Tamenglong | 4/26
# Tamenglong Govt. Hr. Sec. School
# Tamenglong | 5/26
# Christian Heritage Institute
# Tamenglong | 6/26
# Mt. Gibeon School
# Tamenglong | 7/26
# Jawahar Navodaya Vidyalaya
# Tamenglong | 8/26
# EKLAVYA MODEL RESIDENTIAL SCHOOL
# Tamenglong | 9/26
# Christian Model English Higher Sec. School, Tamenglong, Namlalong
# Tamenglong | 10/26
# Primary School
# Tamenglong | 11/26
# Trinity Public School
# Tamenglong | 12/26
# UBS Tamenglong
# Tamenglong | 13/26
# Khongjaron primary school
# Tamenglong | 14/26
# Hello Kids - Tamenglong Preschool
# Tamenglong | 15/26
# India Manipur Tamenglong
# Tamenglong | 16/26
# Don Bosco School
# Tamenglong | 17/26
# Gadailong Primary School
# Tamenglong | 18/26
# Christian Grammar School
# Tamenglong | 19/26
# Old Tamenglong Junior high School
# Tamenglong | 20/26
# Kendriya Vidyalaya
# Tamenglong | 21/26
# Chiuluan Sunday School
# Tamenglong | 22/26
# Tamenglong College, Tamenglong
# Tamenglong | 23/26
# Teguaram Primary School
# Tamenglong | 24/26
# Pou Shankar Kane Vidyalaya
# Tamenglong | 25/26
# Chiuluan chakadai Primary School
# Backup Saved
# Tamenglong | 26/26
# Little Angels' School
#
# Searching: schools in Tengnoupal Manipur
# Search Submitted
# Tengnoupal | schools | Scroll 1 -> 5
# Tengnoupal | schools | Scroll 2 -> 5
# Tengnoupal | schools | Scroll 3 -> 5
# Tengnoupal | schools | Scroll 4 -> 5
# Tengnoupal | schools | Scroll 5 -> 5
# Collected 5 links
# Tengnoupal | 1/5
# St. Peter School
# Tengnoupal | 2/5
# Tengnoupal Govt High School
# Tengnoupal | 3/5
# SCHOOL
# Tengnoupal | 4/5
# D. Zalenbung village
# Tengnoupal | 5/5
# Bongli Junior High School
#
# Searching: schools in Thoubal Manipur
# Search Submitted
# Thoubal | schools | Scroll 1 -> 14
# Thoubal | schools | Scroll 2 -> 18
# Thoubal | schools | Scroll 3 -> 18
# Thoubal | schools | Scroll 4 -> 18
# Thoubal | schools | Scroll 5 -> 18
# Thoubal | schools | Scroll 6 -> 18
# Collected 17 links
# Thoubal | 1/17
# Bright Foundation School Thoubal Manipur (INDIA) Affiliated to CBSE, New Delhi
# Thoubal | 2/17
# NEW ERA HIGHER SECONDARY SCHOOL
# Thoubal | 3/17
# Ananda Purna School of Sciences , Thoubal
# Thoubal | 4/17
# VISION CREATIVE SCHOOL OF SCIENCE
# Thoubal | 5/17
# Ruda Academy
# Thoubal | 6/17
# MY CHHOTA SCHOOL THOUBAL
# Thoubal | 7/17
# Evergreen Flowers' School
# Thoubal | 8/17
# Chaoyaima Higher Secondary School
# Thoubal | 9/17
# Brilliant Academy
# Thoubal | 10/17
# Somorendra Sana Royal Higher Secondary School
# Thoubal | 11/17
# Thoubal College
# Thoubal | 12/17
# Thoubal wangmataba
# Thoubal | 13/17
# Jawahar Navodaya Vidyalaya, Thoubal District
# Thoubal | 14/17
# Eureka High School
# Thoubal | 15/17
# Nimaichand and Keinya High school
# Thoubal | 16/17
# Thoubal Wangmataba Sorok Makha
# Thoubal | 17/17
# Nongangkhong Primary School
#
# Searching: schools in Ukhrul Manipur
# Search Submitted
# Ukhrul | schools | Scroll 1 -> 14
# Ukhrul | schools | Scroll 2 -> 20
# Ukhrul | schools | Scroll 3 -> 27
# Ukhrul | schools | Scroll 4 -> 34
# Ukhrul | schools | Scroll 5 -> 40
# Ukhrul | schools | Scroll 6 -> 47
# Ukhrul | schools | Scroll 7 -> 54
# Ukhrul | schools | Scroll 8 -> 55
# Ukhrul | schools | Scroll 9 -> 55
# Ukhrul | schools | Scroll 10 -> 55
# Ukhrul | schools | Scroll 11 -> 55
# Ukhrul | schools | Scroll 12 -> 55
# Collected 54 links
# Ukhrul | 1/54
# Kendriya Vidyalaya Ukhrul
# Ukhrul | 2/54
# Ukhrul Central School
# Ukhrul | 3/54
# Model High School, Ukhrul
# Ukhrul | 4/54
# Junior's Academy
# Ukhrul | 5/54
# KTL Hr Sec School
# Ukhrul | 6/54
# Ukhrul Higher Secondary School Ground
# Ukhrul | 7/54
# Ukhrul Higher Secondary School
# Ukhrul | 8/54
# Scholar Pakshimi High School
# Ukhrul | 9/54
# Little Angels' English School (Old Campus)
# Ukhrul | 10/54
# St.George School
# Ukhrul | 11/54
# Edify Children Foundation School
# Ukhrul | 12/54
# Sacred Heart Higher Secondary School
# Ukhrul | 13/54
# Assam Rifles School
# Ukhrul | 14/54
# Alice Christian Higher Secondary School
# Ukhrul | 15/54
# Savio Higher Secondary School, Ukhrul
# Ukhrul | 16/54
# Early Education Centre
# Ukhrul | 17/54
# Rayotang Near Scholar School
# Ukhrul | 18/54
# Woodstock Play school
# Ukhrul | 19/54
# Greenland Primary School, Ukhrul
# Ukhrul | 20/54
# Pams Kindergarden
# Ukhrul | 21/54
# Sacred Heart High School
# Ukhrul | 22/54
# ST. MARY'S SCHOOL
# Ukhrul | 23/54
# Happy Feet preschool
# Ukhrul | 24/54
# Maringmi Memorial School
# Ukhrul | 25/54
# Viewland Primary School
# Ukhrul | 26/54
# Oriental Naga Academy
# Ukhrul | 27/54
# Little Angels' English School New Campus
# Ukhrul | 28/54
# IKRA PRE SCHOOL
# Ukhrul | 29/54
# SAIL Academy
# Ukhrul | 30/54
# Accelerando Paino School
# Ukhrul | 31/54
# LaUrShim Music Academy
# Ukhrul | 32/54
# Ngachonmi Fund Primary School
# Ukhrul | 33/54
# Jesus Goodwill School
# Ukhrul | 34/54
# Happy Trails Pre Nursery School
# Ukhrul | 35/54
# Oldest Govt. high school in manipur
# Ukhrul | 36/54
# Homi
# Ukhrul | 37/54
# Echoes-School of Music Tuning Arts Ukhrul Centre
# Ukhrul | 38/54
# Infant Jesus English School
# Ukhrul | 39/54
# Pineview preschool
# Ukhrul | 40/54
# Iwui Book store
# Ukhrul | 41/54
# Sentinel College
# Ukhrul | 42/54
# Vicielps Tutorial Centre Hungpung
# Ukhrul | 43/54
# T.M Kasom Primary School
# Ukhrul | 44/54
# Zonal Education Officer , Ukhrul District, Manipur
# Ukhrul | 45/54
# Shemrock Prime Primary School
# Ukhrul | 46/54
# Ukhrul Parish
# Ukhrul | 47/54
# Shimm's cafe
# Ukhrul | 48/54
# Hungpung, kazipphung Government School
# Ukhrul | 49/54
# Laakhon Music Academy
# Ukhrul | 50/54
# Crossroads Services
# Ukhrul | 51/54
# North East Foundation for Education & Culture
# Ukhrul | 52/54
# Calvary United school of music & worship
# Ukhrul | 53/54
# Tangkhul Katamnao Saklong
# Ukhrul | 54/54
# Zaishin Dance Studio
#
# Extraction Completed
# Total Schools Extracted: 577
#
# Saved File: manipur_schools.csv
