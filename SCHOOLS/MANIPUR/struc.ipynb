# %%
import pandas as pd

# %%
df = pd.read_csv("manipur_schools.csv")

# %%
df.shape
# Out:
# (577, 8)

# %%
duplicate_count = df.duplicated(
    subset=["School Name", "Google Maps URL"]
).sum()
duplicate_count
# Out:
# np.int64(0)

# %%
df = df[
    df["Phone"].notna() & 
    (df["Phone"].astype(str).str.strip() != "")
    ]
df.shape
# Out:
# (56, 8)

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]","",regex=True)
    .str.strip()
)

display(df[["Phone"]].head())
# Out:
#             Phone
# 8   03848 202 960
# 17   098562 46673
# 42   084149 97994
# 45   096128 73023
# 48  03874 233 724

# %%
df.to_csv(
    "manipur_schools_cleaned.csv",
    index=False
)
