# %%
import time
import random
import pandas as pd

from datetime import datetime

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.service import Service

from webdriver_manager.chrome import ChromeDriverManager

districts = [
    "North Goa",
    "South Goa"
]



search_types = [
    "schools"
]


options = webdriver.ChromeOptions()

options.add_argument("--start-maximized")

options.add_argument(
    "--disable-blink-features=AutomationControlled"
)

options.add_argument("--disable-notifications")



driver = webdriver.Chrome(

    service=Service(
        ChromeDriverManager().install()
    ),

    options=options
)



driver.get("https://www.google.com/maps")

print("Opening Google Maps...")

time.sleep(15)

print("Google Maps Loaded")



all_data = []

visited_links = set()



def get_search_box():

    selectors = [

        '//input[@id="searchboxinput"]',
        '//input[contains(@placeholder,"Search")]',
        '//input[contains(@aria-label,"Search")]',
        '//input'

    ]

    for selector in selectors:

        try:

            box = driver.find_element(
                By.XPATH,
                selector
            )

            return box

        except:
            pass

    return None


def extract_school_data():

    try:


        try:
            name = driver.find_element(
                By.TAG_NAME,
                "h1"
            ).text
        except:
            name = ""


        try:
            address = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"address")]'
            ).text
        except:
            address = ""

     
        try:
            phone = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"phone")]'
            ).text
        except:
            phone = ""

        try:
            website = driver.find_element(
                By.XPATH,
                '//a[contains(@data-item-id,"authority")]'
            ).get_attribute("href")
        except:
            website = ""

        
        try:
            rating = driver.find_element(
                By.XPATH,
                '//div[@role="img"]'
            ).get_attribute("aria-label")
        except:
            rating = ""

        return {

            "School Name": name,
            "Address": address,
            "Phone": phone,
            "Website": website,
            "Rating": rating,
            "Google Maps URL": driver.current_url

        }

    except:

        return None



for district in districts:

    for search_type in search_types:

        try:

            query = (
                f"{search_type} "
                f"in {district} Goa"
            )

            print(f"\nSearching: {query}")

  

            search_box = get_search_box()

            if not search_box:

                print("Search Box Not Found")

                continue

            ActionChains(driver).move_to_element(
                search_box
            ).click().perform()

            time.sleep(1)

            search_box.send_keys(
                Keys.CONTROL + "a"
            )

            time.sleep(1)

            search_box.send_keys(Keys.DELETE)

            time.sleep(1)


            for char in query:

                search_box.send_keys(char)

                time.sleep(0.03)

            search_box.send_keys(Keys.ENTER)

            print("Search Submitted")

            time.sleep(8)



            try:

                scrollable_div = driver.find_element(
                    By.XPATH,
                    '//div[@role="feed"]'
                )

                previous_count = 0

                stagnant = 0

                for i in range(100):

                    driver.execute_script(
                        """
                        arguments[0].scrollTop =
                        arguments[0].scrollHeight
                        """,
                        scrollable_div
                    )

                    time.sleep(4)

                    listings = driver.find_elements(
                        By.XPATH,
                        '//a[contains(@href,"/maps/place/")]'
                    )

                    current_count = len(listings)

                    print(
                        f"{district} | "
                        f"{search_type} | "
                        f"Scroll {i+1} -> "
                        f"{current_count}"
                    )

                    if current_count == previous_count:

                        stagnant += 1

                    else:

                        stagnant = 0

                    if stagnant >= 4:

                        break

                    previous_count = current_count

            except Exception as e:

                print(f"Scrolling Error: {e}")

            listings = driver.find_elements(
                By.XPATH,
                '//a[contains(@href,"/maps/place/")]'
            )

            links = []

            for listing in listings:

                try:

                    link = listing.get_attribute("href")

                    if (
                        link
                        and link not in visited_links
                    ):

                        links.append(link)

                        visited_links.add(link)

                except:
                    pass

            print(f"Collected {len(links)} links")



            for index, link in enumerate(links):

                try:

                    print(
                        f"{district} | "
                        f"{index+1}/{len(links)}"
                    )

                    driver.get(link)

                    time.sleep(
                        random.uniform(2, 3)
                    )

                    data = extract_school_data()

                    if data:

                        data["District"] = district

                        data["Search Type"] = search_type

                        all_data.append(data)

                        print(data["School Name"])

   
   

                    if len(all_data) % 100 == 0:

                        backup_df = pd.DataFrame(
                            all_data
                        )

                        backup_df.drop_duplicates(
                            subset=[
                                "School Name",
                                "Google Maps URL"
                            ],
                            inplace=True
                        )

                        backup_df.to_csv(
                            "goa_schools_backup.csv",
                            index=False
                        )

                        print("Backup Saved")

                except Exception as e:

                    print(
                        f"School Error: {e}"
                    )

        except Exception as e:

            print(
                f"District Error: {e}"
            )



df = pd.DataFrame(all_data)

df.drop_duplicates(

    subset=[
        "School Name",
        "Google Maps URL"
    ],

    inplace=True
)



filename = (
    f"goa_schools.csv"
)

df.to_csv(
    filename,
    index=False
)

print("\nExtraction Completed")

print(
    f"Total Schools Extracted: {len(df)}"
)

print(f"\nSaved File: {filename}")

driver.quit()
# Out:
# Opening Google Maps...
# Google Maps Loaded
#
# Searching: schools in North Goa Goa
# Search Submitted
# North Goa | schools | Scroll 1 -> 14
# North Goa | schools | Scroll 2 -> 20
# North Goa | schools | Scroll 3 -> 27
# North Goa | schools | Scroll 4 -> 34
# North Goa | schools | Scroll 5 -> 40
# North Goa | schools | Scroll 6 -> 47
# North Goa | schools | Scroll 7 -> 54
# North Goa | schools | Scroll 8 -> 60
# North Goa | schools | Scroll 9 -> 67
# North Goa | schools | Scroll 10 -> 74
# North Goa | schools | Scroll 11 -> 80
# North Goa | schools | Scroll 12 -> 87
# North Goa | schools | Scroll 13 -> 94
# North Goa | schools | Scroll 14 -> 100
# North Goa | schools | Scroll 15 -> 107
# North Goa | schools | Scroll 16 -> 114
# North Goa | schools | Scroll 17 -> 120
# North Goa | schools | Scroll 18 -> 120
# North Goa | schools | Scroll 19 -> 120
# North Goa | schools | Scroll 20 -> 120
# North Goa | schools | Scroll 21 -> 120
# Collected 120 links
# North Goa | 1/120
# The Gera School
# North Goa | 2/120
# Sunshine Worldwide School
# North Goa | 3/120
# Green Meadows School
# North Goa | 4/120
# European School Of Goa
# North Goa | 5/120
# St. Francis Xavier High School
# North Goa | 6/120
# Bloomz International School
# North Goa | 7/120
# Jawahar Navodaya Vidyalaya(JNV)- North Goa
# North Goa | 8/120
# Assagao Union High School
# North Goa | 9/120
# Vidya Prabodhini High School
# North Goa | 10/120
# St. Mary's Convent High School
# North Goa | 11/120
# St Elizabeth High School
# North Goa | 12/120
# Holy Family High School
# North Goa | 13/120
# St. Xavier's Academy
# North Goa | 14/120
# Don Bosco Higher Secondary School, Panjim
# North Goa | 15/120
# New Goa’s G.S. Amonkar Vidya Mandir
# North Goa | 16/120
# Progress High School
# North Goa | 17/120
# St. Xaviers Higher Secondary School
# North Goa | 18/120
# Our Lady Of Grace High School
# North Goa | 19/120
# Mushtifund High School
# North Goa | 20/120
# St. Michael's Convent High School
# North Goa | 21/120
# The Rosary High School
# North Goa | 22/120
# Fr. Agnel Central School,Pilar.
# North Goa | 23/120
# Dr. K.B. Hedgewar Higher secondary School
# North Goa | 24/120
# Ameeniya High school
# North Goa | 25/120
# St. Theresa High School
# Government High School, JunaBazar - Ponda
# North Goa | 86/120
# Government High School, Amona
# North Goa | 87/120
# Adarsh V.V. High School
# North Goa | 88/120
# Old Goa Educational Institute
# North Goa | 89/120
# Directorate Of Education
# North Goa | 90/120
# Miracles High School
# North Goa | 91/120
# Fr. Agnel School Hall, Pilar, Goa
# North Goa | 92/120
# Little Angels Primary School
# North Goa | 93/120
# Government High School, Navelim
# North Goa | 94/120
# Mahalaxmi High School
# North Goa | 95/120
# Shiksha Sadan High School
# North Goa | 96/120
# Rose Bud Pre School And Montessori
# North Goa | 97/120
# Modern School Furniture - School Bench Manufacturer in Goa
# North Goa | 98/120
# S.E.S.A technical school
# North Goa | 99/120
# Mahanandu Naik High School
# North Goa | 100/120
# Government High School, Bicholim
# Backup Saved
# North Goa | 101/120
# GVM's Dr. Dada Vaidya College Of Education
# North Goa | 102/120
# Houses of Goa Museum
# North Goa | 103/120
# Bambolim Army Camp, North Goa, Goa
# North Goa | 104/120
# KRSS HIGH SCHOOL VOLVOI
# North Goa | 105/120
# Govt High School, Cumbarjua
# North Goa | 106/120
# Funskool India Limited
# North Goa | 107/120
# Govt. Primary School, Karekhajan Virdi
# North Goa | 108/120
# Government School, Tivrem
# North Goa | 109/120
# Government Primary school
# North Goa | 110/120
# Government Primary School Bhandarwada
# North Goa | 111/120
# Government Primary School, Pali
# North Goa | 112/120
# Little Caps Preschool Marcel
# North Goa | 113/120
# Our Lady Of Health High School
# North Goa | 114/120
# Government Primary School
# North Goa | 115/120
# Savoi Plantation
# North Goa | 116/120
# ShriKrishna Shishu Mandir
# North Goa | 117/120
# Government Primary School
# North Goa | 118/120
# Government Primary School Dhulapi Corlim
# North Goa | 119/120
# Government primary school Gonkar wada
# North Goa | 120/120
# Government Primary school
#
# Searching: schools in South Goa Goa
# Search Submitted
# South Goa | schools | Scroll 1 -> 14
# South Goa | schools | Scroll 2 -> 20
# South Goa | schools | Scroll 3 -> 27
# South Goa | schools | Scroll 4 -> 34
# South Goa | schools | Scroll 5 -> 40
# South Goa | schools | Scroll 6 -> 47
# South Goa | schools | Scroll 7 -> 54
# South Goa | schools | Scroll 8 -> 60
# South Goa | schools | Scroll 9 -> 67
# South Goa | schools | Scroll 10 -> 74
# South Goa | schools | Scroll 11 -> 80
# South Goa | schools | Scroll 12 -> 87
# South Goa | schools | Scroll 13 -> 94
# South Goa | schools | Scroll 14 -> 94
# South Goa | schools | Scroll 15 -> 94
# South Goa | schools | Scroll 16 -> 94
# South Goa | schools | Scroll 17 -> 94
# Collected 68 links
# South Goa | 1/68
# River House Academy
# South Goa | 2/68
# National Academy
# South Goa | 3/68
# Pope John XXIII higher Secondary School
# South Goa | 4/68
# Bethany Convent High School
# South Goa | 5/68
# The King's School
# South Goa | 6/68
# Mount Litera Zee School (MLZS) - Goa
# South Goa | 7/68
# Jawahar Navodaya Vidyalaya Canacona
# South Goa | 8/68
# Saviour of the World High School
# South Goa | 9/68
# Fatima Convent High School
# South Goa | 10/68
# Holy Rosary Convent High School
