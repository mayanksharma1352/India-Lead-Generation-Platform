# %%
import pandas as pd

# %%
df = pd.read_csv("tripura_schools.csv")

# %%
df.shape
# Out:
# (698, 8)

# %%
duplicate_count = df.duplicated(
    subset=["School Name", "Google Maps URL"]
).sum()
duplicate_count
# Out:
# np.int64(0)

# %%
df = df[
    df["Phone"].notna() & 
    (df["Phone"].astype(str).str.strip() != "")
    ]
df.shape
# Out:
# (162, 8)

# %%
df = df[
    df["School Name"].notna()
    ]

df = df[
    df["School Name"].str.strip() != ""
    ]

# %%
df.shape
# Out:
# (162, 8)

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]","",regex=True)
    .str.strip()
)

display(df[["Phone"]].head())
# Out:
#             Phone
# 0   03824 266 210
# 6    086602 44381
# 9   03826 267 221
# 18   088372 61050
# 20   070052 95841

# %%
df.to_csv(
    "tripura_schools_cleaned.csv",
    index=False
)
