# %%
import time
import random
import pandas as pd

from datetime import datetime

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.service import Service

from webdriver_manager.chrome import ChromeDriverManager


districts = [
        "Dhalai",
        "Gomati",
        "Khowai",
        "North Tripura",
        "Sepahijala",
        "South Tripura",
        "Unakoti",
        "West Tripura"
]


search_types = [
    "schools"
]


options = webdriver.ChromeOptions()

options.add_argument("--start-maximized")

options.add_argument(
    "--disable-blink-features=AutomationControlled"
)

options.add_argument("--disable-notifications")



driver = webdriver.Chrome(

    service=Service(
        ChromeDriverManager().install()
    ),

    options=options
)



driver.get("https://www.google.com/maps")

print("Opening Google Maps...")

time.sleep(15)

print("Google Maps Loaded")



all_data = []

visited_links = set()


def get_search_box():

    selectors = [

        '//input[@id="searchboxinput"]',
        '//input[contains(@placeholder,"Search")]',
        '//input[contains(@aria-label,"Search")]',
        '//input'

    ]

    for selector in selectors:

        try:

            box = driver.find_element(
                By.XPATH,
                selector
            )

            return box

        except:
            pass

    return None


def extract_school_data():

    try:


        try:
            name = driver.find_element(
                By.TAG_NAME,
                "h1"
            ).text
        except:
            name = ""


        try:
            address = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"address")]'
            ).text
        except:
            address = ""


        try:
            phone = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"phone")]'
            ).text
        except:
            phone = ""

        try:
            website = driver.find_element(
                By.XPATH,
                '//a[contains(@data-item-id,"authority")]'
            ).get_attribute("href")
        except:
            website = ""


        try:
            rating = driver.find_element(
                By.XPATH,
                '//div[@role="img"]'
            ).get_attribute("aria-label")
        except:
            rating = ""

        return {

            "School Name": name,
            "Address": address,
            "Phone": phone,
            "Website": website,
            "Rating": rating,
            "Google Maps URL": driver.current_url

        }

    except:

        return None


for district in districts:

    for search_type in search_types:

        try:

            query = (
                f"{search_type} "
                f"in {district} Tripura"
            )

            print(f"\nSearching: {query}")


            search_box = get_search_box()

            if not search_box:

                print("Search Box Not Found")

                continue

            ActionChains(driver).move_to_element(
                search_box
            ).click().perform()

            time.sleep(1)

            search_box.send_keys(
                Keys.CONTROL + "a"
            )

            time.sleep(1)

            search_box.send_keys(Keys.DELETE)

            time.sleep(1)

  
            for char in query:

                search_box.send_keys(char)

                time.sleep(0.03)

            search_box.send_keys(Keys.ENTER)

            print("Search Submitted")

            time.sleep(8)


            try:

                scrollable_div = driver.find_element(
                    By.XPATH,
                    '//div[@role="feed"]'
                )

                previous_count = 0

                stagnant = 0

                for i in range(100):

                    driver.execute_script(
                        """
                        arguments[0].scrollTop =
                        arguments[0].scrollHeight
                        """,
                        scrollable_div
                    )

                    time.sleep(4)

                    listings = driver.find_elements(
                        By.XPATH,
                        '//a[contains(@href,"/maps/place/")]'
                    )

                    current_count = len(listings)

                    print(
                        f"{district} | "
                        f"{search_type} | "
                        f"Scroll {i+1} -> "
                        f"{current_count}"
                    )

                    if current_count == previous_count:

                        stagnant += 1

                    else:

                        stagnant = 0

                    if stagnant >= 4:

                        break

                    previous_count = current_count

            except Exception as e:

                print(f"Scrolling Error: {e}")


            listings = driver.find_elements(
                By.XPATH,
                '//a[contains(@href,"/maps/place/")]'
            )

            links = []

            for listing in listings:

                try:

                    link = listing.get_attribute("href")

                    if (
                        link
                        and link not in visited_links
                    ):

                        links.append(link)

                        visited_links.add(link)

                except:
                    pass

            print(f"Collected {len(links)} links")

     

            for index, link in enumerate(links):

                try:

                    print(
                        f"{district} | "
                        f"{index+1}/{len(links)}"
                    )

                    driver.get(link)

                    time.sleep(
                        random.uniform(2, 3)
                    )

                    data = extract_school_data()

                    if data:

                        data["District"] = district

                        data["Search Type"] = search_type

                        all_data.append(data)

                        print(data["School Name"])

   

                    if len(all_data) % 100 == 0:

                        backup_df = pd.DataFrame(
                            all_data
                        )

                        backup_df.drop_duplicates(
                            subset=[
                                "School Name",
                                "Google Maps URL"
                            ],
                            inplace=True
                        )

                        backup_df.to_csv(
                            "tripura_schools_backup.csv",
                            index=False
                        )

                        print("Backup Saved")

                except Exception as e:

                    print(
                        f"School Error: {e}"
                    )

        except Exception as e:

            print(
                f"District Error: {e}"
            )


df = pd.DataFrame(all_data)

df.drop_duplicates(

    subset=[
        "School Name",
        "Google Maps URL"
    ],

    inplace=True
)


filename = (
    f"tripura_schools.csv"
)

df.to_csv(
    filename,
    index=False
)

print("\nExtraction Completed")

print(
    f"Total Schools Extracted: {len(df)}"
)

print(f"\nSaved File: {filename}")

driver.quit()
# Out:
# Opening Google Maps...
# Google Maps Loaded
#
# Searching: schools in Dhalai Tripura
# Search Submitted
# Dhalai | schools | Scroll 1 -> 14
# Dhalai | schools | Scroll 2 -> 20
# Dhalai | schools | Scroll 3 -> 27
# Dhalai | schools | Scroll 4 -> 34
# Dhalai | schools | Scroll 5 -> 40
# Dhalai | schools | Scroll 6 -> 47
# Dhalai | schools | Scroll 7 -> 54
# Dhalai | schools | Scroll 8 -> 58
# Dhalai | schools | Scroll 9 -> 58
# Dhalai | schools | Scroll 10 -> 58
# Dhalai | schools | Scroll 11 -> 58
# Dhalai | schools | Scroll 12 -> 58
# Collected 58 links
# Dhalai | 1/58
# Jawahar Navodaya Vidyalaya, Dhalai
# Dhalai | 2/58
# Chandraipara Higher Secondary School
# Dhalai | 3/58
# DHALAI PUBLIC SCHOOL
# Dhalai | 4/58
# Marachara Class XII School
# Dhalai | 5/58
# Kulai Colony High School
# Dhalai | 6/58
# Balaram High School
# Dhalai | 7/58
# 82 miles proper H/S school
# Dhalai | 8/58
# Saint Arnold's School
# Dhalai | 9/58
# Kulai Class XII School
# Dhalai | 10/58
# Kendriya Vidyalaya Ambassa
# Dhalai | 11/58
# Takhirai Debbarma Para JB School
# Dhalai | 12/58
# Halahali Class XII School
# Dhalai | 13/58
# Kamalpur Class XII School
# Dhalai | 14/58
# Dalubari Gate Class XII School Ground
# Dhalai | 15/58
# Dhalai tripura
# Dhalai | 16/58
# Maranatha English School.Bhowlia Basti Ambassa
# Dhalai | 17/58
# Ambassa English Medium Model School
# Dhalai | 18/58
# Radhamohan Memorial Ashram School
# Dhalai | 19/58
# Dreamline Study centre
# Dhalai | 20/58
# T D Guitar school
# Dhalai | 21/58
# Sumchongram Memorial School
# Dhalai | 22/58
# Pohor English Medium School
# Dhalai | 23/58
# Rseti Dhalai Ambassa
# Dhalai | 24/58
# DOLUBARI class XII School
# Dhalai | 25/58
# Ambassabari SB School
# Dhalai | 26/58
# Baralutma Class XII School
# Dhalai | 27/58
# Nailaha Bari S.B School
# Dhalai | 28/58
# Dhalai District Polytechnic
# Dhalai | 29/58
# Jawaharnagar SB School
# Dhalai | 30/58
# Ambassa English Medium Model School
# Dhalai | 31/58
# Brikshada Reang Para SB school
# Dhalai | 32/58
# Sishu Bharati Pre-School Ambassa
# Dhalai | 33/58
# Kulai School Play Ground
# Dhalai | 34/58
# SKY LINE ENGLISH MEDIUM NURSERY SCHOOL
# Dhalai | 35/58
# Netaji Vidyapith English Medium H.S. School
# Dhalai | 36/58
# Ganganagar Dhalai Tripura Bata Para JB School
# Dhalai | 37/58
# Chailengta Government English Medium HS School
# Dhalai | 38/58
# Dhancherra SB School
# Dhalai | 39/58
# Uttar Lalchari High School
# Dhalai | 40/58
# ORIGIN PRATIBHA (an institute of success)
# Dhalai | 41/58
# Office of the Inspector of School
# Dhalai | 42/58
# St. John's School
# Dhalai | 43/58
# Megazine Para SB School
# Dhalai | 44/58
# Ramnagar Bazar High School
# Dhalai | 45/58
# Gopal Sardar Para High School
# Dhalai | 46/58
# I.T.I Ambassa
# Dhalai | 47/58
# Shri Krishna Vidhyamandir ( English Medium)
# Dhalai | 48/58
# Dhancherra SB School (jackson)
# Dhalai | 49/58
# Lalchari SB School
# Dhalai | 50/58
# North Nalichara High School
# Dhalai | 51/58
# Praniya Debbarma Para JB School
# Dhalai | 52/58
# Segun Para JB School
# Dhalai | 53/58
# Hatimaracherra SB School
# Dhalai | 54/58
# Purnajoy RP SB School
# Dhalai | 55/58
# আনন্দমার্গ বিদ্যালয়, আমবাসা ️Ananda Marga School, Ambassa
# Dhalai | 56/58
# Kulai SB School
# Dhalai | 57/58
# Kekmachara S B School
# Dhalai | 58/58
# Ambassa Colony
#
# Searching: schools in Gomati Tripura
# Search Submitted
# Gomati | schools | Scroll 1 -> 14
# Gomati | schools | Scroll 2 -> 20
# Gomati | schools | Scroll 3 -> 27
# Gomati | schools | Scroll 4 -> 34
# Gomati | schools | Scroll 5 -> 40
# Gomati | schools | Scroll 6 -> 47
# Gomati | schools | Scroll 7 -> 54
# Gomati | schools | Scroll 8 -> 60
# Gomati | schools | Scroll 9 -> 67
# Gomati | schools | Scroll 10 -> 74
# Gomati | schools | Scroll 11 -> 80
# Gomati | schools | Scroll 12 -> 87
# Gomati | schools | Scroll 13 -> 94
# Gomati | schools | Scroll 14 -> 100
# Gomati | schools | Scroll 15 -> 107
# Gomati | schools | Scroll 16 -> 114
# Gomati | schools | Scroll 17 -> 120
# Gomati | schools | Scroll 18 -> 120
# Gomati | schools | Scroll 19 -> 120
# Gomati | schools | Scroll 20 -> 120
# Gomati | schools | Scroll 21 -> 120
# Collected 96 links
# Gomati | 1/96
# Udaipur English Medium Higher Secondary School
# Gomati | 2/96
# Jawahar Navodaya Vidyalaya, Gomati
# Gomati | 3/96
# Hariananda English Medium HS School
# Gomati | 4/96
# Don Bosco School Udaipur
# Gomati | 5/96
# Udaipur Ramesh English Medium H.S. School
# Gomati | 6/96
# Gamaria Higher Secondary School
# Gomati | 7/96
# Ampinagar H.S School
# Gomati | 8/96
# KIDZEE UDAIPUR TRIPURA
# Gomati | 9/96
# Amarpur English Medium School
# Gomati | 10/96
# Garia Academy (Model)
# Gomati | 11/96
# Jamjuri HS School
# Gomati | 12/96
# Coloring Birds drawing school
# Gomati | 13/96
# Education Office
# Gomati | 14/96
# Bhagini Nivedita Girls' H.S. School
# Gomati | 15/96
# Teliamura Higher Secondary School
# Gomati | 16/96
# Chandrapur Colony H.S. School
# Gomati | 17/96
# G. M. ACADEMY
# Gomati | 18/96
# My Chhota School - Udaipur Tripura
# Gomati | 19/96
# Brilliant Stars' School
# Gomati | 20/96
# Vivekananda Vidyapith Higher secondary School
# Gomati | 21/96
# Udaipur Girl's Higher Secondary School
# Gomati | 22/96
# Gakulpur High School
# Gomati | 23/96
# Shishu Bihar Higher Secondary School
# Gomati | 24/96
# East Fotamati High school
# Gomati | 25/96
# Amarpur H. S. School
# Gomati | 26/96
# Garia Academy
# Gomati | 27/96
# Tingharia High School
# Gomati | 28/96
# P.M Shri Rajnagar Higher secondary School
# Gomati | 29/96
# Office of the Inspector of Schools, Udaipur
# Gomati | 30/96
# New Garden Bahai School, Udaipur.
# Gomati | 31/96
# Fulkumari High School
# Gomati | 32/96
# Silachari Higher Secondary School
# Gomati | 33/96
# Matangini Hazra Balika Vidyalaya
# Gomati | 34/96
# Sataria High School
# Gomati | 35/96
# KIRIT BIKRAM INSTITUTION (KBI)
# Gomati | 36/96
# Umakanta Academy (English Medium)
# Gomati | 37/96
# Eklavya Model Residential School Killa (EMRS Killa)
# Gomati | 38/96
# Tripura Sundari HS School Playground
# Gomati | 39/96
# INSPECTOR OF SCHOOLS, AMPINAGAR, GOMATI TRIPURA
# Gomati | 40/96
# Henry Derozio Academy HS(+Stage) School
# Gomati | 41/96
# উচ্চতর মাধ্যমিক বিদ্যালয়/ गंगाछड़ा उच्चतर माध्यमिक विद्यालय
# Gomati | 42/96
# Nanuya Dighir Par J.B.School
# Backup Saved
# Gomati | 43/96
# Tripura Sundari Higher Secondary School
# Gomati | 44/96
# Noabari H.S School (English medium)
# Gomati | 45/96
# Pallimangal H.S. School
# Gomati | 46/96
# Tentuibari High School
# Gomati | 47/96
# Nandan Nagar HS School,
# Gomati | 48/96
# Victory English Medium School
# Gomati | 49/96
# Durjoynagar High School
# Gomati | 50/96
# Bodhjung Higher Secondary School
# Gomati | 51/96
# Udaipur tripura
# Gomati | 52/96
# Pitra Kami JB School
# Gomati | 53/96
# East RK pur Hs School
# Gomati | 54/96
# Belbari High School
# Gomati | 55/96
# Matabari English Medium School
# Gomati | 56/96
# Amtali High School
# Gomati | 57/96
# Matabari Higher Secondary School
# Gomati | 58/96
# Fulkumari S.B.School
# Gomati | 59/96
# Dropgate Bazar FULKUMARI
# Gomati | 60/96
# Prachya Bharati Higher Secondary School
# Gomati | 61/96
# Amit House 🏠🏡
# Gomati | 62/96
# East R K Pur Girls Higher Secondary School
# Gomati | 63/96
# National advanced computer institute
# Gomati | 64/96
# Netaji Vidyaniketan
# Gomati | 65/96
# Kurban Ail
# Gomati | 66/96
# Netaji Subhash Vidyaniketan
# Gomati | 67/96
# Office Tila H.S. School
# Gomati | 68/96
# Gomati
# Gomati | 69/96
# Amit Sarkar
# Gomati | 70/96
# Belonia Girls HS School
# Gomati | 71/96
# Bani Vidyapith Girl's HS School
# Gomati | 72/96
# Tripurasundari Nursery School
# Gomati | 73/96
# EAST. R. K.Pur Girl`s High School P/U
# Gomati | 74/96
# Netaji Subhash Sangh
# Gomati | 75/96
# Ramthakore medical Hall
# Gomati | 76/96
# Tripura state Rifles 7 battalion company headquarter
# Gomati | 77/96
# Vivekananda Nagar SB School
# Gomati | 78/96
# Pre-Primary Udaipur English Medium Higher secondary school
# Gomati | 79/96
# Kakraban RD Block
# Gomati | 80/96
# Till Eternity - By Joyanta Sir
# Gomati | 81/96
# Electric Business
# Gomati | 82/96
# The Gym
# Gomati | 83/96
# Amarpur RD Block
# Gomati | 84/96
# Vidyanagar H.S School Playground
# Gomati | 85/96
# Kamala Chara High School
# Gomati | 86/96
# Sukanta Sarkar
# Gomati | 87/96
# Daija ram Reang House village DISTARAM para
# Gomati | 88/96
# MAA TARA FLOWERS & NURSEY
# Gomati | 89/96
# PANISAGAR HS(+2STAGE) SCHOOL
# Gomati | 90/96
# Digang
# Gomati | 91/96
# ASHU TOSH SHIL HOME
# Gomati | 92/96
# Kendriya Vidyalaya Lalchari
# Gomati | 93/96
# Fulkumari
# Gomati | 94/96
# Datta House
# Gomati | 95/96
# COVENANT ENGLISH SCHOOL
# Gomati | 96/96
# Killa BLOCK
#
# Searching: schools in Khowai Tripura
# Search Submitted
# Khowai | schools | Scroll 1 -> 14
# Khowai | schools | Scroll 2 -> 20
# Khowai | schools | Scroll 3 -> 27
# Khowai | schools | Scroll 4 -> 34
# Khowai | schools | Scroll 5 -> 40
# Khowai | schools | Scroll 6 -> 47
# Khowai | schools | Scroll 7 -> 54
# Khowai | schools | Scroll 8 -> 60
# Khowai | schools | Scroll 9 -> 64
# Khowai | schools | Scroll 10 -> 64
# Khowai | schools | Scroll 11 -> 64
# Khowai | schools | Scroll 12 -> 64
# Khowai | schools | Scroll 13 -> 64
# Collected 63 links
# Khowai | 1/63
# Khowai Goverment English Medium H/S School
# Khowai | 2/63
# Khowai Govt Hr Sec School Tripura
# Khowai | 3/63
# Sarat Chandra Class XII School
# Khowai | 4/63
# Derozeo Mission School
# Khowai | 5/63
# G-Next Model School
# Khowai | 6/63
# Khowai Govt. HS School Playground
# Khowai | 7/63
# Kidzee Khowai
# Khowai | 8/63
# Cherma H.S school
# Khowai | 9/63
# Ananda Marga School
# Khowai | 10/63
# Jawahar Navodaya Vidyalaya, Khowai, Tripura
# Khowai | 11/63
# Khowai Govt Girls' Class XII School
# Khowai | 12/63
# District Education Office,Khowai
# Khowai | 13/63
# Office tilla High School
# Bloom Adventist English Medium School
# North Tripura | 106/107
# Dakshin Daincherra SB School
# North Tripura | 107/107
# Rajarai CP school kanchanpur
#
# Searching: schools in Sepahijala Tripura
# Search Submitted
# Sepahijala | schools | Scroll 1 -> 14
# Sepahijala | schools | Scroll 2 -> 20
# Sepahijala | schools | Scroll 3 -> 27
# Sepahijala | schools | Scroll 4 -> 34
# Sepahijala | schools | Scroll 5 -> 40
# Sepahijala | schools | Scroll 6 -> 47
# Sepahijala | schools | Scroll 7 -> 54
# Sepahijala | schools | Scroll 8 -> 60
# Sepahijala | schools | Scroll 9 -> 67
# Sepahijala | schools | Scroll 10 -> 74
# Sepahijala | schools | Scroll 11 -> 80
# Sepahijala | schools | Scroll 12 -> 87
# Sepahijala | schools | Scroll 13 -> 94
# Sepahijala | schools | Scroll 14 -> 100
# Sepahijala | schools | Scroll 15 -> 107
# Sepahijala | schools | Scroll 16 -> 114
# Sepahijala | schools | Scroll 17 -> 120
# Sepahijala | schools | Scroll 18 -> 120
# Sepahijala | schools | Scroll 19 -> 120
# Sepahijala | schools | Scroll 20 -> 120
# Sepahijala | schools | Scroll 21 -> 120
# Collected 112 links
# Sepahijala | 1/112
# Nalchar H.S. School
# Sepahijala | 2/112
# Boxanagar H.S. School
# Sepahijala | 3/112
# Charilam H.S School
# Sepahijala | 4/112
# Thakurmura High School
# Sepahijala | 5/112
# Bishalgarh English Medium Higher Secondary School
# Sepahijala | 6/112
# Bishalgarh H.S. School
# Sepahijala | 7/112
# the applied school of grammatica, sonamura, sepahijala (a spoken english academy)
# Sepahijala | 8/112
# BISHRAMGANJ HIGHER SECONDARY SCHOOL
# Sepahijala | 9/112
# Karaimura Class XII School
# Sepahijala | 10/112
# Molsombar SB School, Sepahijala, Tripura [Bijoynandi)
# Sepahijala | 11/112
# Bishalghar Class Xii School
# Sepahijala | 12/112
# Urmai Class XII School
# Sepahijala | 13/112
# Taibandal H.S School
# Sepahijala | 14/112
# Ghaniamara HS School
# Sepahijala | 15/112
# Durlav Narayan H.S. School
# Sepahijala | 16/112
# Lalsingmura Higher Secondary School
# Sepahijala | 17/112
# St. Xavier's H. S.School
# Sepahijala | 18/112
# Sonamura English Medium HS School
# Sepahijala | 19/112
# Latiachara High school
# Sepahijala | 20/112
# WARENGBARI R.P.C S.B. SCHOOL, BISHALGARH INSPECTOR ,SEPAHIJALA TRIPURA
# Sepahijala | 21/112
# Ratanpur High School
# Sepahijala | 22/112
# Evergreen Institute
# Sepahijala | 23/112
# B.S.F. GOKULNAGAR
# Sepahijala | 24/112
# Baluachari S B School
# Sepahijala | 25/112
# SAINT JOSEPH SCHOOL
# Sepahijala | 26/112
# St. James School, Gongrai
# Sepahijala | 27/112
# Sarkar Tilla High School
# Sepahijala | 28/112
# JNV Takarjala Sepahijala Tripura
# Sepahijala | 29/112
# Berean English Medium School
# Sepahijala | 30/112
# Sophia SMS School, Hirapur
# Sepahijala | 31/112
# Pramodenagar Higher Secondary School
# Sepahijala | 32/112
# Arjun Thakur High School
# Sepahijala | 33/112
# Melaghar Girls H.S. School
# Ananda Marga School
# Sepahijala | 91/112
# O/o THE INSPECTOR OF SCHOOLS, CHARILAM
# Sepahijala | 92/112
# Ananda Marg School
# Sepahijala | 93/112
# South Charilam English Medium High School.
# Sepahijala | 94/112
# কৃষ্ণ সংঘ প্রাথমিক বিদ্যালয়
# Sepahijala | 95/112
# Sepahijala
# Sepahijala | 96/112
# Gayaram kabra para Anganwadi school
# Sepahijala | 97/112
# EDENTHAR ENGLISH MEDIUM SCHOOL
# Sepahijala | 98/112
# Swapan Debnath House
# Sepahijala | 99/112
# Barjala s.b shcool
# Sepahijala | 100/112
# Langa Public School
# Sepahijala | 101/112
# Banshtali s.b school
# Sepahijala | 102/112
# Paharpur
# Sepahijala | 103/112
# Anganwadi School
# Sepahijala | 104/112
# Adhibasi Colony School
# Sepahijala | 105/112
# Das House
# Sepahijala | 106/112
# JOORPUKUR JUNIOR BASIC SCHOOL
# Sepahijala | 107/112
# Dhariathal High School
# Sepahijala | 108/112
# Dulal sarkar house (Nandalal sarkar)
# Sepahijala | 109/112
# Lakhiram
# Sepahijala | 110/112
# Akash home
# Sepahijala | 111/112
# Bishramganj School Canteen
# Sepahijala | 112/112
# কলোনী অঙ্গওয়ারী সেন্টার রাজঘাট
#
# Searching: schools in South Tripura Tripura
# Search Submitted
# South Tripura | schools | Scroll 1 -> 14
# South Tripura | schools | Scroll 2 -> 20
# South Tripura | schools | Scroll 3 -> 27
# South Tripura | schools | Scroll 4 -> 34
# South Tripura | schools | Scroll 5 -> 40
# South Tripura | schools | Scroll 6 -> 47
# South Tripura | schools | Scroll 7 -> 54
# South Tripura | schools | Scroll 8 -> 60
# South Tripura | schools | Scroll 9 -> 67
# South Tripura | schools | Scroll 10 -> 74
# South Tripura | schools | Scroll 11 -> 80
# South Tripura | schools | Scroll 12 -> 87
# South Tripura | schools | Scroll 13 -> 94
# South Tripura | schools | Scroll 14 -> 100
# South Tripura | schools | Scroll 15 -> 107
# South Tripura | schools | Scroll 16 -> 110
# South Tripura | schools | Scroll 17 -> 110
# South Tripura | schools | Scroll 18 -> 110
# South Tripura | schools | Scroll 19 -> 110
# South Tripura | schools | Scroll 20 -> 110
# Collected 89 links
# South Tripura | 1/89
# Jawahar Navodaya Vidyalaya, South Tripura
# South Tripura | 2/89
# Betaga H.S School
# South Tripura | 3/89
# South Sonaichari H.S School
# South Tripura | 4/89
# Wow Kids Future Stars
# South Tripura | 5/89
# Belonia Vidyapith H.S. School
# South Tripura | 6/89
# Sabroom H/S School
# South Tripura | 7/89
# Dhamma Dipa School
# South Tripura | 8/89
# Sarashima HS school
# South Tripura | 9/89
# Aryya Colony H.S School
# South Tripura | 10/89
# Rajnagar colony H.S school
# South Tripura | 11/89
# Sunflower English Medium Academy
# South Tripura | 12/89
# Holy Spirit School
# South Tripura | 13/89
# B.K. Institution
# South Tripura | 14/89
# Kendriya Vidyalaya Bagafa
# South Tripura | 15/89
# I.C Nagar H.S School
# South Tripura | 16/89
# Ridvan Academy
# South Tripura | 17/89
# West Bokafa Hs School
# South Tripura | 18/89
# South Tripura | 77/89
# Amosa English Medium School
# South Tripura | 78/89
# Abhijit Bhowmik
# South Tripura | 79/89
# Fulchari High School
# South Tripura | 80/89
# District Inspector Of Social Education
# South Tripura | 81/89
# South Tripura
# South Tripura | 82/89
# Prishan Mani Banik
# South Tripura | 83/89
# Sanjoy Bhowmik's house
# South Tripura | 84/89
# CHANDRANAGAR J.B SCHOOL
# South Tripura | 85/89
# Holy Spirit School
# South Tripura | 86/89
# Eklavya Model Residential School
# South Tripura | 87/89
# SIP ABACUS BELONIA
# South Tripura | 88/89
# জীববিজ্ঞান পাঠশালা
# South Tripura | 89/89
# BINAPANI SANGEET VIDYAPITH
#
# Searching: schools in Unakoti Tripura
# Search Submitted
# Unakoti | schools | Scroll 1 -> 14
# Unakoti | schools | Scroll 2 -> 20
# Unakoti | schools | Scroll 3 -> 27
# Unakoti | schools | Scroll 4 -> 34
# Unakoti | schools | Scroll 5 -> 40
# Unakoti | schools | Scroll 6 -> 47
# Unakoti | schools | Scroll 7 -> 54
# Unakoti | schools | Scroll 8 -> 60
# Unakoti | schools | Scroll 9 -> 67
# Unakoti | schools | Scroll 10 -> 74
# Unakoti | schools | Scroll 11 -> 80
# Unakoti | schools | Scroll 12 -> 87
# Unakoti | schools | Scroll 13 -> 94
# Unakoti | schools | Scroll 14 -> 100
# Unakoti | schools | Scroll 15 -> 100
# Unakoti | schools | Scroll 16 -> 100
# Unakoti | schools | Scroll 17 -> 100
# Unakoti | schools | Scroll 18 -> 100
# Collected 84 links
# Unakoti | 1/84
# Saint Xavier's High School
# Unakoti | 2/84
# Taraninagar unakoti tripura
# Unakoti | 3/84
# Radhakishore Institution (RKI)
# Unakoti | 4/84
# Srirampur SM HS School
# Unakoti | 5/84
# Fatikroy Class XII School ( Unofficial )
# Unakoti | 6/84
# Unakoti Rock Carvings Tripura
# Unakoti | 7/84
# Fatikroy H.S. School
# Unakoti | 8/84
# Bimal Singha Academy
# Unakoti | 9/84
# Bhagini Nivedita Higher Secondary School
# Unakoti | 10/84
# Sonaimuri H.S School
# Unakoti | 11/84
# JOYGANTI HIGHER SECONDARY SCHOOL
# Unakoti | 12/84
# Kajirgaon School Playground
# Unakoti | 13/84
# Little Flower School
# Unakoti | 14/84
# EuroKids Preschool in Unakoti, Kumarghat
# Unakoti | 15/84
# Kumarghat Girls H.S. School
# Unakoti | 16/84
# Jarailtali H.S School
# Unakoti | 17/84
# Darchawi Christian Higher Secondary School
# Unakoti | 18/84
# Santipur PTL High School
# Unakoti | 19/84
# Ideal School ..Fatikroy
# Unakoti | 20/84
# Ramkrishna Siksha Pratisthan
# Unakoti | 21/84
# Kumarghat Govt. English Medium HS School
# Unakoti | 22/84
# MRS COMPUTER EDUCATION
# Unakoti | 23/84
# Indira colony JB School
# Unakoti | 24/84
# Bhaktivedanta National School
# Unakoti | 25/84
# District Education Office, Unakoti
# Unakoti | 26/84
# Chantail High School
# Unakoti | 27/84
# NBCESI
# Unakoti | 28/84
# Gakulnagar High School
# Unakoti | 29/84
# Gopesh dey memorial Tripureswari vidyamandir
# Unakoti | 30/84
# Anganwadi School Halaimura
# Unakoti | 31/84
# KRISHNANAGAR B.M. HIGH SCHOOL
# Unakoti | 32/84
# Noydrone High School, Kumarghat
# Unakoti | 33/84
# Ledrai Dewan HS School
# Unakoti | 34/84
# VIVEKANANDA INTERNATIONAL SCHOOL - A PERFECT FUTURE MAKING SCHOOL, SONAIMURI, KUMARGHAT.
# Unakoti | 35/84
# ST (BOYS) HOSTEL,
# Unakoti | 36/84
# Railway Colony S.B School
# Unakoti | 37/84
# Eklavya Model Residential School
# Unakoti | 38/84
# ICT COMPUTER ACADEMY
# Unakoti | 39/84
# Harijan colony JB School
# Unakoti | 40/84
# ABACUS Kumarghat
# Unakoti | 41/84
# Fatikroy Girl's High School
# Unakoti | 42/84
# The Institute of Computer Language
# Unakoti | 43/84
# Sri Sringeri Sharada Vidyamandir
# Unakoti | 44/84
# LALDAHAR SB SCHOOL লালডহর উচ্চ বুনিয়াদি বিদ্যালয়
# Unakoti | 45/84
# Sonaimuri,SISHU UDDYAN ENGLISH MEDIUM school
# Unakoti | 46/84
# 82 MILE English medium S.B SCHOOL
# Unakoti | 47/84
# Saidarpar Katatilla JB School
# Unakoti | 48/84
# S.B SCHOOL
# Unakoti | 49/84
# 60 Ghar Para JB SCHOOL
# Unakoti | 50/84
# Bhagaban Nagar High School
# Unakoti | 51/84
# Tution/school
# Unakoti | 52/84
# Sukanta Nagar School Rabia
# Unakoti | 53/84
# Chandanir
# Unakoti | 54/84
# Anganwari School
# Unakoti | 55/84
# Ramkrishna Mahavidyalaya
# Unakoti | 56/84
# Rajnagar High School
# Unakoti | 57/84
# EMRS.kgt High Secondary
# Unakoti | 58/84
# IICTC
# Unakoti | 59/84
# F.H.S.S. Playground
# Unakoti | 60/84
# Kumarghat Halam Basti Senior Basic School
# Unakoti | 61/84
# Unakoti
# Unakoti | 62/84
# Kidzee Kumarghat
# Unakoti | 63/84
# Radhanagar S.B School
# Unakoti | 64/84
# SIDONGMUKH AWC CENTRE
# Unakoti | 65/84
# Papiya Deb nath
# Unakoti | 66/84
# Archana Teil
# Unakoti | 67/84
# Industry para J.R.B school
# Unakoti | 68/84
# Sidongmukh Harendra Chakma Para J.B School
# Unakoti | 69/84
# Rupesh majumder
# Unakoti | 70/84
# Anganwadi School Netajipalli
# Unakoti | 71/84
# Ujjivan Small Finance Bank - Kumarghat Branch
# Unakoti | 72/84
# Kachari Cherra S. B. School
# Unakoti | 73/84
# DARCHAWI ST GIRLS HOSTEL
# Unakoti | 74/84
# Singharam bari s b school
# Unakoti | 75/84
# Sidhongcherra S.B school
# Backup Saved
# Unakoti | 76/84
# Ambedkar College ,Fatikroy
# Unakoti | 77/84
# WCCS (COMPUTER TRAINING INSTITUTE, FATIKROY)
# Unakoti | 78/84
# Deshbandhu Chittaranjan Club
# Unakoti | 79/84
# Saidarpar High School
# Unakoti | 80/84
# IIFL Gold Loan
# Unakoti | 81/84
# Sushi instant English medium school
# Unakoti | 82/84
# Sukanta Malakar
# Unakoti | 83/84
# Ahoj Chakma
# Unakoti | 84/84
# Ashis das
#
# Searching: schools in West Tripura Tripura
# Search Submitted
# West Tripura | schools | Scroll 1 -> 14
# West Tripura | schools | Scroll 2 -> 20
# West Tripura | schools | Scroll 3 -> 27
# West Tripura | schools | Scroll 4 -> 34
# West Tripura | schools | Scroll 5 -> 40
# West Tripura | schools | Scroll 6 -> 47
# West Tripura | schools | Scroll 7 -> 54
# West Tripura | schools | Scroll 8 -> 60
# West Tripura | schools | Scroll 9 -> 67
# West Tripura | schools | Scroll 10 -> 74
# West Tripura | schools | Scroll 11 -> 80
# West Tripura | schools | Scroll 12 -> 87
# West Tripura | schools | Scroll 13 -> 94
# West Tripura | schools | Scroll 14 -> 100
# West Tripura | schools | Scroll 15 -> 107
# West Tripura | schools | Scroll 16 -> 114
# West Tripura | schools | Scroll 17 -> 120
# West Tripura | schools | Scroll 18 -> 120
# West Tripura | schools | Scroll 19 -> 120
# West Tripura | schools | Scroll 20 -> 120
# West Tripura | schools | Scroll 21 -> 120
# Collected 89 links
# West Tripura | 1/89
# Modern Higher Secondary School
# West Tripura | 2/89
# Sri Krishna Mission School
# West Tripura | 3/89
# Berimura H.S. school
# West Tripura | 4/89
# Pragati Higher Secondary School
# West Tripura | 5/89
# Shiksha Niketan H.S. School
# West Tripura | 6/89
# Baldakhal S B School
# West Tripura | 7/89
# DR B.R AMBEDKAR HIGH SCHOOL
# West Tripura | 8/89
# Nalanda English Medium School
# West Tripura | 9/89
# Hapania H.S. School
# West Tripura | 10/89
# Kendriya Vidyalaya Kunjaban, Agartala No.1
# West Tripura | 11/89
# Ananda Marga H.S. School
# West Tripura | 12/89
# SUBRAI VIDYA MANDIR
# West Tripura | 13/89
# Mahatma Gandhi Memorial School
# West Tripura | 14/89
# Kamini Kumar Singha Memorial H.S. School
# West Tripura | 15/89
# Maharani Tulsibati Girls' Higher Secondary School
# West Tripura | 16/89
# Kshudiram Basu English Medium School
# West Tripura | 17/89
# Abhaynagar Nazrul Smriti Vidyalaya
# West Tripura | 18/89
# NOAGAON KRISHNANAGAR HIGH SCHOOL
# West Tripura | 19/89
# Antioch School Tripura
# West Tripura | 20/89
# Charipara Higher Secondary School
# West Tripura | 21/89
# Step Up Western Dance Academy & Fitness Zone
# West Tripura | 22/89
# Swami Dhananjoy Das Kathia Mission School
# West Tripura | 23/89
# TRIPURA FINE ARTS ACADEMY
# West Tripura | 24/89
# EuroKids PreSchool in Joynagar, Agartala
# West Tripura | 25/89
# TOTELL SCHOOL OF LEARNING
# West Tripura | 26/89
# Patunagar Higher secondary School
# West Tripura | 27/89
# Reshambagan H.S School
# West Tripura | 28/89
# The Agartala International School
# West Tripura | 29/89
# Sakhicharan HSS
# West Tripura | 30/89
# KIDS VALLEY PRE SCHOOL
# West Tripura | 31/89
# Ramakrishna Mission Vidyalaya
# West Tripura | 32/89
# BIRENDRA NAGAR H.S SCHOOL
# West Tripura | 33/89
# Delhi World Public School, Agartala
# West Tripura | 34/89
# Rajnagar Higher Secondary School
# West Tripura | 35/89
# Standard English School Kisong
# West Tripura | 36/89
