# %%
import pandas as pd

# %%
df = pd.read_csv("meghalaya_schools.csv")

# %%
df.shape
# Out:
# (1174, 8)

# %%
df = df[
    df["Phone"].notna() & 
    (df["Phone"].astype(str).str.strip() != "")
    ]
df.shape
# Out:
# (66, 8)

# %%
df = df[
    df["School Name"].notna()
    ]

df = df[
    df["School Name"].str.strip() != ""
    ]
df.shape
# Out:
# (66, 8)

# %%
# CLEAN PHONE COLUMNS
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]","",regex=True)
    .str.strip()
)

display(df[["Phone"]].head())
# Out:
#             Phone
# 1   03658 220 370
# 2    097743 40358
# 8   03658 295 016
# 29   094363 31278
# 42   094361 10344

# %%
# SAVE CLEANED FILE
df.to_csv(
    "megahalya_schools_cleaned.csv",
    index=False
)
