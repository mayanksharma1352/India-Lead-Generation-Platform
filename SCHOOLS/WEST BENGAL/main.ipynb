# %%
import time
import random
import pandas as pd

from datetime import datetime

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.service import Service

from webdriver_manager.chrome import ChromeDriverManager


districts = [

    "Hooghly",
    "Howrah",
    "Jalpaiguri",
    "Jhargram",
    "Kalimpong",
    "Kolkata",
    "Malda",
    "Murshidabad",
    "Nadia",
    "North 24 Parganas",
    "Paschim Bardhaman",
    "Paschim Medinipur",
    "Purba Bardhaman",
    "Purba Medinipur",
    "Purulia",
    "South 24 Parganas",
    "Uttar Dinajpur"
]



search_types = [
    "schools"
]


options = webdriver.ChromeOptions()

options.add_argument("--start-maximized")

options.add_argument(
    "--disable-blink-features=AutomationControlled"
)

options.add_argument("--disable-notifications")


driver = webdriver.Chrome(

    service=Service(
        ChromeDriverManager().install()
    ),

    options=options
)



driver.get("https://www.google.com/maps")

print("Opening Google Maps...")

time.sleep(15)

print("Google Maps Loaded")




all_data = []

visited_links = set()



def get_search_box():

    selectors = [

        '//input[@id="searchboxinput"]',
        '//input[contains(@placeholder,"Search")]',
        '//input[contains(@aria-label,"Search")]',
        '//input'

    ]

    for selector in selectors:

        try:

            box = driver.find_element(
                By.XPATH,
                selector
            )

            return box

        except:
            pass

    return None



def extract_school_data():

    try:


        try:
            name = driver.find_element(
                By.TAG_NAME,
                "h1"
            ).text
        except:
            name = ""


        try:
            address = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"address")]'
            ).text
        except:
            address = ""

        try:
            phone = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"phone")]'
            ).text
        except:
            phone = ""

        try:
            website = driver.find_element(
                By.XPATH,
                '//a[contains(@data-item-id,"authority")]'
            ).get_attribute("href")
        except:
            website = ""
        try:
            rating = driver.find_element(
                By.XPATH,
                '//div[@role="img"]'
            ).get_attribute("aria-label")
        except:
            rating = ""

        return {

            "School Name": name,
            "Address": address,
            "Phone": phone,
            "Website": website,
            "Rating": rating,
            "Google Maps URL": driver.current_url

        }

    except:

        return None



for district in districts:

    for search_type in search_types:

        try:

            query = (
                f"{search_type} "
                f"in {district} West Bengal"
            )

            print(f"\nSearching: {query}")

   


            search_box = get_search_box()

            if not search_box:

                print("Search Box Not Found")

                continue

            ActionChains(driver).move_to_element(
                search_box
            ).click().perform()

            time.sleep(1)

            search_box.send_keys(
                Keys.CONTROL + "a"
            )

            time.sleep(1)

            search_box.send_keys(Keys.DELETE)

            time.sleep(1)


            for char in query:

                search_box.send_keys(char)

                time.sleep(0.03)

            search_box.send_keys(Keys.ENTER)

            print("Search Submitted")

            time.sleep(8)



            try:

                scrollable_div = driver.find_element(
                    By.XPATH,
                    '//div[@role="feed"]'
                )

                previous_count = 0

                stagnant = 0

                for i in range(100):

                    driver.execute_script(
                        """
                        arguments[0].scrollTop =
                        arguments[0].scrollHeight
                        """,
                        scrollable_div
                    )

                    time.sleep(4)

                    listings = driver.find_elements(
                        By.XPATH,
                        '//a[contains(@href,"/maps/place/")]'
                    )

                    current_count = len(listings)

                    print(
                        f"{district} | "
                        f"{search_type} | "
                        f"Scroll {i+1} -> "
                        f"{current_count}"
                    )

                    if current_count == previous_count:

                        stagnant += 1

                    else:

                        stagnant = 0

                    if stagnant >= 4:

                        break

                    previous_count = current_count

            except Exception as e:

                print(f"Scrolling Error: {e}")

    
            listings = driver.find_elements(
                By.XPATH,
                '//a[contains(@href,"/maps/place/")]'
            )

            links = []

            for listing in listings:

                try:

                    link = listing.get_attribute("href")

                    if (
                        link
                        and link not in visited_links
                    ):

                        links.append(link)

                        visited_links.add(link)

                except:
                    pass

            print(f"Collected {len(links)} links")

 

            for index, link in enumerate(links):

                try:

                    print(
                        f"{district} | "
                        f"{index+1}/{len(links)}"
                    )

                    driver.get(link)

                    time.sleep(
                        random.uniform(2, 3)
                    )

                    data = extract_school_data()

                    if data:

                        data["District"] = district

                        data["Search Type"] = search_type

                        all_data.append(data)

                        print(data["School Name"])



                    if len(all_data) % 100 == 0:

                        backup_df = pd.DataFrame(
                            all_data
                        )

                        backup_df.drop_duplicates(
                            subset=[
                                "School Name",
                                "Google Maps URL"
                            ],
                            inplace=True
                        )

                        backup_df.to_csv(
                            "westbengal_schools_backup.csv",
                            index=False
                        )

                        print("Backup Saved")

                except Exception as e:

                    print(
                        f"School Error: {e}"
                    )

        except Exception as e:

            print(
                f"District Error: {e}"
            )


new_df = pd.DataFrame(all_data)

new_df.drop_duplicates(

    subset=[
        "School Name",
        "Google Maps URL"
    ],

    inplace=True
)



old_file = "westbengal_schools.csv"

try:
    old_df = "westbengal_schools.csv"

    final_df = pd.concat(
        [old_df, new_df],
        ignore_index=True
    )

    final_df = drop.duplicates(
        subset=[
            "School Name",
            "Google Maps URL"
        ],

        inplace=True
    )
except:
    final_df = new_df


final_df.to_csv(
    old_file,
    index=False
)

print("\nExtraction Completed")

print(
    f"Total Schools Extracted: {len(df)}"
)

print(f"\nSaved File: {filename}")

driver.quit()
# Out:
# Opening Google Maps...
# Google Maps Loaded
#
# Searching: schools in Hooghly West Bengal
# Search Submitted
# Hooghly | schools | Scroll 1 -> 14
# Hooghly | schools | Scroll 2 -> 20
# Hooghly | schools | Scroll 3 -> 27
# Hooghly | schools | Scroll 4 -> 34
# Hooghly | schools | Scroll 5 -> 40
# Hooghly | schools | Scroll 6 -> 47
# Hooghly | schools | Scroll 7 -> 54
# Hooghly | schools | Scroll 8 -> 60
# Hooghly | schools | Scroll 9 -> 67
# Hooghly | schools | Scroll 10 -> 74
# Hooghly | schools | Scroll 11 -> 80
# Hooghly | schools | Scroll 12 -> 82
# Hooghly | schools | Scroll 13 -> 82
# Hooghly | schools | Scroll 14 -> 82
# Hooghly | schools | Scroll 15 -> 82
# Hooghly | schools | Scroll 16 -> 82
# Collected 82 links
# Hooghly | 1/82
# Techno India Group Public School
# Hooghly | 2/82
# ST. JOHN'S H S SCHOOL
# Hooghly | 3/82
# The Pride International School (Co-Ed , English Medium, CBSE Curriculum)-Best CBSE School in Baidyabati ,Hooghly
# Hooghly | 4/82
# Hooghly Collegiate School
# Hooghly | 5/82
# H.M. Education Centre
# Hooghly | 6/82
# Chinsurah Deshbandhu Memorial High School (Estd-1926)
# Hooghly | 7/82
# Pearl Rosary School
# Hooghly | 60/82
# Disha Public School
# Hooghly | 61/82
# Gospel Home School
# Hooghly | 62/82
# Sugandhya Higher Secondary School
# Hooghly | 63/82
# HIRALAL MODEL ENGLISH MEDIUM SCHOOL
# Hooghly | 64/82
# TECHNO INDIA GROUP PUBLIC SCHOOL
# Hooghly | 65/82
# Garbati High School
# Hooghly | 66/82
# Springfields Academy
# Hooghly | 67/82
# Bansberia LITTLE FLOWER SCHOOL
# Hooghly | 68/82
# EuroKids PreSchool in Barabazar - Chandannagar, Hooghly
# Hooghly | 69/82
# 1 No KAPASDANGA PRIMARY SCHOOL
# Hooghly | 70/82
# TECHNO COLLEGE HOOGHLY
# Hooghly | 71/82
# Mother International School
# Hooghly | 72/82
# Dasghara High School
# Hooghly | 73/82
# Narayana School - Rishra
# Hooghly | 74/82
# Serampore Vivekananda Academy
# Hooghly | 75/82
# Bikramnagar Haranath Nirada Sundar Ghosh Vidyamandir
# Hooghly | 76/82
# St Thomas Public School
# Hooghly | 77/82
# Hooghly rail sharmik primary Hindi vidyapith
# Hooghly | 78/82
# St Joseph's Convent School
# Hooghly | 79/82
# Chandernagore Kanailal Vidyamandir (English Section)
# Hooghly | 80/82
# Hooghly Government Madrasah
# Hooghly | 81/82
# S.A.C.S HIGH SCHOOL
# Hooghly | 82/82
# Axuluam HS school Bandel Charch Hooghly district West Bengal India
#
# Searching: schools in Howrah West Bengal
# Search Submitted
# Howrah | schools | Scroll 1 -> 14
# Howrah | schools | Scroll 2 -> 20
# Howrah | schools | Scroll 3 -> 27
# Howrah | schools | Scroll 4 -> 34
# Howrah | schools | Scroll 5 -> 40
# Howrah | schools | Scroll 6 -> 47
# Howrah | schools | Scroll 7 -> 54
# Howrah | schools | Scroll 8 -> 60
# Howrah | schools | Scroll 9 -> 67
# Howrah | schools | Scroll 10 -> 74
# Howrah | schools | Scroll 11 -> 80
# Howrah | schools | Scroll 12 -> 87
# Howrah | schools | Scroll 13 -> 94
# Howrah | schools | Scroll 14 -> 100
# Howrah | schools | Scroll 15 -> 107
# Howrah | schools | Scroll 16 -> 114
# Howrah | schools | Scroll 17 -> 120
# Howrah | schools | Scroll 18 -> 120
# Howrah | schools | Scroll 19 -> 120
# Howrah | schools | Scroll 20 -> 120
# Howrah | schools | Scroll 21 -> 120
# Collected 120 links
# Howrah | 1/120
# Podar International School Howrah - West Bengal (CBSE)
# Howrah | 2/120
# Sudhir Memorial Institute Liluah | Best CBSE English Medium School in Howrah
# Howrah | 3/120
# Shree Jain Vidyalaya
# Howrah | 4/120
# Narayana School - Howrah
# Howrah | 5/120
# The Kolkata International school
# Howrah | 6/120
# Doon Techno School | Best cbse School in Howrah | Best English Medium School in Howrah | Top cbse School in Howrah
# Howrah | 7/120
# Indian Public School - Best CBSE School in Howrah
# Howrah | 8/120
# Asian International School
# Howrah | 9/120
# Howrah Zilla School
# Howrah | 10/120
# Howrah St. John's High School
# Howrah | 11/120
# Turning Point Public School I Best Preschool Primary School I Prenursery to Class IV
# Howrah | 12/120
# St. Thomas' Church School, Howrah
# Howrah | 13/120
# Jalpaiguri | schools | Scroll 8 -> 60
# Jalpaiguri | schools | Scroll 9 -> 67
# Jalpaiguri | schools | Scroll 10 -> 74
# Jalpaiguri | schools | Scroll 11 -> 80
# Jalpaiguri | schools | Scroll 12 -> 87
# Jalpaiguri | schools | Scroll 13 -> 94
# Jalpaiguri | schools | Scroll 14 -> 100
# Jalpaiguri | schools | Scroll 15 -> 102
# Jalpaiguri | schools | Scroll 16 -> 102
# Jalpaiguri | schools | Scroll 17 -> 102
# Jalpaiguri | schools | Scroll 18 -> 102
# Jalpaiguri | schools | Scroll 19 -> 102
# Collected 102 links
# Jalpaiguri | 1/102
# Jalpaiguri Zilla School
# Jalpaiguri | 2/102
# La Bimala Academy
# Jalpaiguri | 3/102
# Saint Paul's School
# Jalpaiguri | 4/102
# Techno India Group Public School, Jalpaiguri
# Jalpaiguri | 5/102
# Jalpaiguri High School
# Jalpaiguri | 6/102
# Jalpaiguri Higher Secondary School
# Jalpaiguri | 7/102
# My Chhota School
# Jalpaiguri | 8/102
# Holy Child School
# Jalpaiguri | 9/102
# Ashalata Basu Vidyalaya
# Jalpaiguri | 10/102
# Anandam Kinder Days Jalpaiguri
# Jalpaiguri | 11/102
# Kendriya Vidyalaya B.S.F. Raninagar, Jalpaiguri
# Jalpaiguri | 12/102
# Sonaulla Higher Secondary School
# Jalpaiguri | 13/102
# St. John Mary's School, Jalpaiguri
# Jalpaiguri | 14/102
# Career Wings & Kidz Wings School Jalpaiguri
# Jalpaiguri | 15/102
# Ananda Model High School
# Jalpaiguri | 16/102
# Jalpaiguri Public School
# Jalpaiguri | 17/102
# Al-Ameen Mission Academy Jalpaiguri
# Jalpaiguri | 18/102
# Khela Ghar Montessori School
# Jalpaiguri | 19/102
# Sunitibala Sadar Girls' high school
# Jalpaiguri | 20/102
# Jalpaiguri Hindi High School
# Jalpaiguri | 21/102
# Aravinda Madhyamik Vidyalay
# Jalpaiguri | 22/102
# Central Girls' High School
# Jalpaiguri | 23/102
# Government Girls' High School
# Jalpaiguri | 24/102
# FANINDRA DEB INSTITUTION (FDI)
# Jalpaiguri | 25/102
# Sishuniketan Preparatory School
# Jalpaiguri | 26/102
# Teachers’ Corner
# Jalpaiguri | 27/102
# Kadamtala Girl's High School
# Jalpaiguri | 28/102
# Raninagar St paul English School Jalpaiguri
# Jalpaiguri | 29/102
# GD Goenka Toddler House Jalpaiguri
# Jalpaiguri | 30/102
# MELODY MUSIC ACADEMY
# Jalpaiguri | 31/102
# Debnagar Satish Lahiri High School
# Jalpaiguri | 32/102
# St. Ambrose Vidyalaya
# Jalpaiguri | 33/102
# THE RISING SUN PUBLIC SCHOOL
# Jalpaiguri | 34/102
# AIMS EDUCATIONAL GROUP
# Jalpaiguri | 35/102
# Sonali Girls' High School
# Jalpaiguri | 36/102
# Kaliaganj Uttameswar High School (H.S.)
# Jalpaiguri | 37/102
# Tuition CBSE ICSE
# Jalpaiguri | 38/102
# SAR PUBLIC SCHOOL
# Jalpaiguri | 39/102
# SCA Abacus & Brain Gym
# Jalpaiguri | 40/102
# Jalpaiguri | 93/102
# Howrah South Point Handicapped Children Home, Mohitnagar
# Jalpaiguri | 94/102
# Patlakhawa High School
# Jalpaiguri | 95/102
# বিবেকানন্দ প্রাথমিক বিদ্যালয়, Vivekananda primary school
# Jalpaiguri | 96/102
# G.D. Goenka Public School
# Jalpaiguri | 97/102
# St. James' School, Binnaguri
# Jalpaiguri | 98/102
# Domino's Pizza | Ukilpara, Jalpaiguri
# Backup Saved
# Jalpaiguri | 99/102
# Chengmari (W.M.E.) High School
# Jalpaiguri | 100/102
# Morning Star School
# Jalpaiguri | 101/102
# Jogomaya Girls High School
# Jalpaiguri | 102/102
# Kharija Berubari High School
#
# Searching: schools in Jhargram West Bengal
# Search Submitted
# Jhargram | schools | Scroll 1 -> 14
# Jhargram | schools | Scroll 2 -> 20
# Jhargram | schools | Scroll 3 -> 27
# Jhargram | schools | Scroll 4 -> 34
# Jhargram | schools | Scroll 5 -> 40
# Jhargram | schools | Scroll 6 -> 47
# Jhargram | schools | Scroll 7 -> 54
# Jhargram | schools | Scroll 8 -> 60
# Jhargram | schools | Scroll 9 -> 67
# Jhargram | schools | Scroll 10 -> 74
# Jhargram | schools | Scroll 11 -> 80
# Jhargram | schools | Scroll 12 -> 87
# Jhargram | schools | Scroll 13 -> 94
# Jhargram | schools | Scroll 14 -> 100
# Jhargram | schools | Scroll 15 -> 107
# Jhargram | schools | Scroll 16 -> 114
# Jhargram | schools | Scroll 17 -> 120
# Jhargram | schools | Scroll 18 -> 120
# Jhargram | schools | Scroll 19 -> 120
# Jhargram | schools | Scroll 20 -> 120
# Jhargram | schools | Scroll 21 -> 120
# Collected 120 links
# Jhargram | 1/120
# Jhargram Kumud Kumari Institution
# Jhargram | 2/120
# West End High School
# Jhargram | 3/120
# Jhargram Lions Model School
# Jhargram | 4/120
# Kidzee Jhargram
# Jhargram | 5/120
# Tantamount Public School, Jhargram
# Jhargram | 6/120
# West End High School (Nursery to LKG)
# Jhargram | 7/120
# Jhargram Nanibala Vidyalaya
# Jhargram | 8/120
# Jhargram Banitirtha High School
# Jhargram | 9/120
# Sunny Point School
# Jhargram | 10/120
# West End High School Office
# Jhargram | 11/120
# Bosco Juniors
# Jhargram | 12/120
# Jhargram Ashok Vidyapith (H.S)
# Jhargram | 13/120
# Eklavya Adarsha Abasik School, Jhargram
# Jhargram | 14/120
# Netaji Adarsha Hindi High School
# Jhargram | 15/120
# SRI RAMKRISHNA SARADAPITH GIRLS HIGH SCHOOL
# Jhargram | 16/120
# Holy Trinity School
# Jhargram | 17/120
# BRIGHTMINDS ENGLISH ACADEMY
# Jhargram | 18/120
# C.F. Andrews Memorial School
# Jhargram | 19/120
# Art Academy
# Jhargram | 20/120
# Jhargram Banitirtha High School Ground
# Jhargram | 21/120
# EuroKids PreSchool in Madhuban More, Jhargram
# Jhargram | 22/120
# Rani Benode Manjari Govt. Girls' School
# Jhargram | 23/120
# Sevayatan Vidyalaya (H.S)
# Jhargram | 24/120
# Jangalkhas Jr. High School(English Medium)
# Jhargram | 25/120
# Akash Music School
# Jhargram | 26/120
# Jhargram | 80/120
# Apll Jhargram Computer Center
# Jhargram | 81/120
# Raghunathpur Kiranbala Primary School
# Jhargram | 82/120
# DAMA SAREN MENORIAL SCHOOL
# Jhargram | 83/120
# RICE Education, Jhargram
# Jhargram | 84/120
# Netaji International School, Junior
# Jhargram | 85/120
# RABINDRANATH PRY SCHOOL
# Jhargram | 86/120
# Pranavananda Sishutirtha Prathamik Vidyalay
# Jhargram | 87/120
# Coaching centre. CBSE ISC WbJEE mathematics and physics
# Jhargram | 88/120
# Khanakul Junior High School
# Jhargram | 89/120
# Jhargram PMK National Youth Computer Centre
# Jhargram | 90/120
# B.M MOTOR Driving School
# Jhargram | 91/120
# Perfect Beauty Salon & Academy
# Jhargram | 92/120
# Orion Beauty Academy
# Jhargram | 93/120
# Holy Trinity Church,Jhargram.
# Jhargram | 94/120
# Chhatrabandhu
# Jhargram | 95/120
# National Computer Saksharta Mission Jhargram
# Jhargram | 96/120
# Jhargram public School
# Backup Saved
# Jhargram | 97/120
# Roy's spoken English classes
# Jhargram | 98/120
# Sagarmal Baijnath kedia Bhawan School Primary
# Jhargram | 99/120
# POLITICAL SCIENCE JHARGRAM
# Jhargram | 100/120
# Subhaspally
# Jhargram | 101/120
# The British Institutes
# Jhargram | 102/120
# Sevayatan Kalyan kendra
# Jhargram | 103/120
# R.B.M Play Ground
# Jhargram | 104/120
# Jhargram Silpitirtha Siksha Niketan
# Jhargram | 105/120
# Takshashila coaching centre
# Jhargram | 106/120
# PARADISE BIRYANI
# Jhargram | 107/120
# Sharmistha yoga Studio
# Jhargram | 108/120
# Fashion House Uniforms & Army Store
# Jhargram | 109/120
# Sabitri Pustakalaya
# Jhargram | 110/120
# Kanika Book Stall
# Jhargram | 111/120
# Niribili HomeStay Jhargram
# Jhargram | 112/120
# Venus Parlour & Makeup Studio
# Jhargram | 113/120
# JANA Sir Memorial
# Jhargram | 114/120
# Dr Partha Pratim Ghosh
# Jhargram | 115/120
# Banjara Garden Restaurant
# Jhargram | 116/120
# Nrityankan silpa samsad & Gm makeover's
# Jhargram | 117/120
# Jhargram Creative Dance Academy
# Jhargram | 118/120
# Som Tiles Jhargram
# Jhargram | 119/120
# Cake-O-Pie
# Jhargram | 120/120
# JHARGRAM PAPERMART
#
# Searching: schools in Kalimpong West Bengal
# Search Submitted
# Kalimpong | schools | Scroll 1 -> 14
# Kalimpong | schools | Scroll 2 -> 20
# Kalimpong | schools | Scroll 3 -> 27
# Kalimpong | schools | Scroll 4 -> 34
# Kalimpong | schools | Scroll 5 -> 40
# Kalimpong | schools | Scroll 6 -> 47
# Kalimpong | schools | Scroll 7 -> 54
# Kalimpong | schools | Scroll 8 -> 60
# Kalimpong | schools | Scroll 9 -> 67
# Kalimpong | schools | Scroll 10 -> 74
# Kalimpong | schools | Scroll 11 -> 80
# Kalimpong | schools | Scroll 12 -> 87
# Kalimpong | schools | Scroll 13 -> 94
# Kalimpong | schools | Scroll 14 -> 100
# Kalimpong | schools | Scroll 15 -> 105
# Kalimpong | schools | Scroll 16 -> 105
# Kalimpong | schools | Scroll 17 -> 105
# Kalimpong | schools | Scroll 18 -> 105
# Kalimpong | schools | Scroll 19 -> 105
# Collected 105 links
# Kalimpong | 1/105
# Rockvale Academy
# Kalimpong | 2/105
# Narayana School - Kalimpong
# Kalimpong | 3/105
# St. Augustine's School, Kalimpong
# Kalimpong | 4/105
# Dr. Graham's Homes School
# Kalimpong | 5/105
# Kalimpong Girls' High/Higher Secondary School
# Kalimpong | 6/105
# Kalimpong Jubilee Higher Secondary School
# Kalimpong | 7/105
# St. Joseph’s Convent
# Kalimpong | 8/105
# Paramount School
# Kalimpong | 9/105
# Vrindavan School, Kalimpong
# Kalimpong | 10/105
# Kumudini Homes Higher Secondary School
# Kalimpong | 11/105
# Pranami Balika Vidya Mandir
# Kalimpong | 12/105
# Kendriya Vidyalaya, Kalimpong
# Kalimpong | 13/105
# Kalimpong Govt. High School
# Kalimpong | 14/105
# Gandhi Ashram School (New Campus)
# Kalimpong | 15/105
# EAST POINT MODEL SCHOOL
# Kalimpong | 16/105
# Gandhi Ashram School (Old)
# Kalimpong | 17/105
# Don Bosco Technical School
# Kalimpong | 18/105
# DON BOSCO SCHOOL KALIMPONG
# Kalimpong | 19/105
# Indo Tibetan Higher Sec School
# Kalimpong | 20/105
# Saptashri Gyanpeeth
# Kalimpong | 21/105
# Sambhota Tibetan School, Kalimpong
# Kalimpong | 22/105
# Seventh Day Adventist School
# Kalimpong | 23/105
# Narayana School - Kalimpong 12th Mile
# Kalimpong | 24/105
# The Scottish Universities’ Mission Institution
# Kalimpong | 25/105
# St. Philomena’s Girls High School
# Kalimpong | 26/105
# Army Public School
# Kalimpong | 27/105
# Sai Institute Of Education and Research(Kamal Jyoti Vidhya Peeth)
# Kalimpong | 28/105
# Springdale Academy
# Kalimpong | 29/105
# Toddlers Preparatory School
# Kalimpong | 30/105
# ELIM MELODY ACADEMY KALIMPONG ( MUSIC SCHOOL)
# Kalimpong | 31/105
# Vidhya Boarding House
# Kalimpong | 32/105
# Good Start Montessori School
# Kalimpong | 33/105
# Kalimpong Sakya Monastery
# Kalimpong | 34/105
# Ganesh High School
# Kalimpong | 35/105
# Kalimpong College
# Kalimpong | 36/105
# Eklavya Model Residential School, Kalimpong.
# Kalimpong | 37/105
# North Point School
# Kalimpong | 38/105
# Gloria Kindergarten School
# Kalimpong | 39/105
# First step kindergarden
# Kalimpong | 40/105
# Prasanthi Academy
# Kalimpong | 41/105
# East Main Road Primary School
# Kalimpong | 42/105
# Mona Primary School, Kalimpong
# Kalimpong | 43/105
# Gangotri High School
# Kalimpong | 44/105
# St. Xavier's School
# Kalimpong | 45/105
# Bright Life Academy
# Kalimpong | 46/105
# Seed Farm High School
# Kalimpong | 47/105
# Durpin Monastery
# Kalimpong | 48/105
# The Salvation Army, Mary Scott Home & School for the Blind
# Kalimpong | 49/105
# Pioneer Preparatory School, Sindebong
# Kalimpong | 50/105
# Bethany School
# Kalimpong | 51/105
# The Sangam Homestay, 7th Mile, Near View Point, Rishi Road, Kalimpong
# Kalimpong | 52/105
# Tashiding Primary School
# Kalimpong | 53/105
# Jamgon Kongtrul Memorial School
# Kalimpong | 54/105
# Albella Boys Home
# Kalimpong | 55/105
# Purbong Primary School
# Kalimpong | 56/105
# Mani memorial school
# Kalimpong | 57/105
# Saraswati Primary School
# Kalimpong | 58/105
# St. Stephens School
# Kalimpong | 59/105
# Harijan Primary School
# Kalimpong | 60/105
# Kamal Jyoti Vidhya Peeth
# Kalimpong | 61/105
# Rockvale Academy Junior Block
# Kalimpong | 62/105
# Poshyore Primary School
# Kalimpong | 63/105
# CHIBBO PRIMARY SCHOOL
# Kalimpong | 64/105
# Kalimpong
# Kalimpong | 65/105
# BSA (Old Gandhi Ashram School)
# Kalimpong | 66/105
# 9 mile
# Kalimpong | 67/105
# Rahul
# Kalimpong | 68/105
# Kalimpong P.W.D. Children Park
# Kalimpong | 69/105
# Champamaya Junior Basic School
# Kalimpong | 70/105
# District Inspector of School secondary education kalimpong District
# Kalimpong | 71/105
# Cluny Women's College
# Kalimpong | 72/105
# Mela Ground ᤔᤣᤘᤠ ᤃᤠᤷᤀᤢᤍ
# Kalimpong | 73/105
# BETHLEHEM ACADEMY SCHOOL
# Kalimpong | 74/105
# Hanabi Institute of Japanese Language and Culture
# Kalimpong | 75/105
# Secondary Staffroom SAS
# Kalimpong | 76/105
# Kashi Nath and Sons
# Backup Saved
# Kalimpong | 77/105
# Prakash Book Store
# Kalimpong | 78/105
# Snow White
# Kalimpong | 79/105
# Development Primary School, Mangal Dara
# Kalimpong | 80/105
# St. Stephen's Academy
# Kalimpong | 81/105
# Sushan's Karate-Do Academy
# Kalimpong | 82/105
# Eastar Dance Studio Kalimpong
# Kalimpong | 83/105
# Cafe Kalimpong
# Kalimpong | 84/105
# OmShree Nursery School
# Kalimpong | 85/105
# The Chibbo Inn
# Kalimpong | 86/105
# Hotel ARMS
# Kalimpong | 87/105
# Kalimpong tours and travels, JUN HOMESTAY
# Kalimpong | 88/105
# Div Chowk upper chibobasti
# Kalimpong | 89/105
# Soureni Gaon Bara Bhalukhop SSK.
# Kalimpong | 90/105
# Grey Dove HomeStay
# Kalimpong | 91/105
# Association of Heads of Listed ICSE Schools
# Kalimpong | 92/105
# SB Vacation, Offbeat Homestay in Kalimpong
# Kalimpong | 93/105
# NEXT ROUTE
# Kalimpong | 94/105
# Gaondhoj pry.school
# Kalimpong | 95/105
# 360 View Home Stay
# Kalimpong | 96/105
# Studio Kalimpong
# Kalimpong | 97/105
# BLUE SAGE RESTAURANT
# Kalimpong | 98/105
# St. Georges Higher Secondary School
# Kalimpong | 99/105
# IIHM Rockvale Kalimpong
# Kalimpong | 100/105
# Paying guest available for girls
# Kalimpong | 101/105
# Kalimpong Municipal Office
# Kalimpong | 102/105
# English class in kalimpong
# Kalimpong | 103/105
# Astrologer Ganesh Khatiwada
# Kalimpong | 104/105
# The Oracles
# Kalimpong | 105/105
# Tours and Travels Kalimpong
#
# Searching: schools in Kolkata West Bengal
# Search Submitted
# Kolkata | schools | Scroll 1 -> 14
# Kolkata | schools | Scroll 2 -> 20
# Kolkata | schools | Scroll 3 -> 27
# Kolkata | schools | Scroll 4 -> 34
# Kolkata | schools | Scroll 5 -> 40
# Kolkata | schools | Scroll 6 -> 47
# Kolkata | schools | Scroll 7 -> 54
# Kolkata | schools | Scroll 8 -> 60
# Kolkata | schools | Scroll 9 -> 67
# Kolkata | schools | Scroll 10 -> 74
# Kolkata | schools | Scroll 11 -> 80
# Kolkata | schools | Scroll 12 -> 87
# Kolkata | schools | Scroll 13 -> 94
# Kolkata | schools | Scroll 14 -> 100
# Kolkata | schools | Scroll 15 -> 107
# Kolkata | schools | Scroll 16 -> 114
# Kolkata | schools | Scroll 17 -> 120
# Kolkata | schools | Scroll 18 -> 120
# Kolkata | schools | Scroll 19 -> 120
# Kolkata | schools | Scroll 20 -> 120
# Kolkata | schools | Scroll 21 -> 120
# Collected 119 links
# Kolkata | 1/119
# Orchids The International School
# Kolkata | 2/119
# St. James' School
# Kolkata | 3/119
# Cambridge Academy- Best CBSE School in Kolkata
# Kolkata | 4/119
# Nopany High
# Kolkata | 5/119
# Saini International School Maheshtala - Best CBSE School in Kolkata
# Kolkata | 6/119
# St. Joseph's College
# Kolkata | 7/119
# Adamas International School ICSE, IGCSE, ISC (Nursery to XII) School in Kolkata
# Kolkata | 8/119
# Calcutta International School
# Kolkata | 9/119
# Shree Jain Vidyalaya (SJV)
# Kolkata | 10/119
# ORCHIDS The International School - ICSE School in Joka
# Kolkata | 11/119
# St. Thomas' Day School
# Kolkata | 12/119
# The Park English School
# Kolkata | 13/119
# Calcutta Boys' School
# Kolkata | 14/119
# Delhi Public School Ruby Park Kolkata Junior School
# Kolkata | 15/119
# Ruby Park Public School
# Kolkata | 16/119
# Aditya Academy Secondary
# Kolkata | 17/119
# Jodhpur Park Boys School
# Kolkata | 18/119
# LA MARTINIERE FOR BOYS'
# Kolkata | 19/119
# The BSS School
# Kolkata | 20/119
# Shree Maheshwari Vidyalaya
# Kolkata | 21/119
# New Horizon English School (West Bengal board)
# Kolkata | 22/119
# St. Lawrence High School
# Kolkata | 23/119
# Hindu School
# Kolkata | 24/119
# South Point High School
# Kolkata | 25/119
# D. A. V. Public School
# Kolkata | 26/119
# St. Nicholas School, Kolkata
# Kolkata | 27/119
# Don Bosco School
# Kolkata | 28/119
# South City International School (SCIS)
# Kolkata | 29/119
# St. Peter's High School
# Kolkata | 30/119
# little memorial school
# Kolkata | 31/119
# Ashok Hall Girls' Higher Secondary School (Senior Section)
# Kolkata | 32/119
# La Martiniere for Girls School
# Kolkata | 33/119
# The Heritage School
# Kolkata | 34/119
# Little Stars High School - Park Street
# Kolkata | 35/119
# The Scottish Church Collegiate School Secondary/Higher Secondary Section
# Kolkata | 36/119
# Modern High School for Girls
# Kolkata | 37/119
# Nava Nalanda Group of Schools
# Kolkata | 38/119
# ABHINAV BHARATI HIGH SCHOOL
# Kolkata | 39/119
# Tantia High School
# Kolkata | 40/119
# Shri Gandhi Vidyalaya High
# Kolkata | 41/119
# St. Clare School
# Kolkata | 42/119
# Md Jan High School (H.S.)
# Kolkata | 43/119
# St. Xavier's Collegiate School
# Kolkata | 44/119
# St. John's Diocesan Girls' Higher Secondary School
# Kolkata | 101/119
# Akshar School
# Kolkata | 102/119
# Jibreil International School
# Kolkata | 103/119
# St Patterson's Day School
# Kolkata | 104/119
# Kendriya Vidyalaya No.1, Salt Lake
# Kolkata | 105/119
# A.K. Ghosh Memorial School
# Kolkata | 106/119
# Kolkata School
# Kolkata | 107/119
# St. Paul's Mission School
# Kolkata | 108/119
# Hariyana Public School
# Kolkata | 109/119
# South Pioneer Academy
# Kolkata | 110/119
# Elliot Day School
# Kolkata | 111/119
# Young Horizons School
# Kolkata | 112/119
# Islamia High School
# Kolkata | 113/119
# Baitulmal Kelabagan High School
# Kolkata | 114/119
# Loreto Convent Entally
# Kolkata | 115/119
# St Paul's Mission School
# Kolkata | 116/119
# S V S English School
# Kolkata | 117/119
# KL Sen KG School
# Kolkata | 118/119
# Sri Ram Narayan Singh Memorial High School
# Kolkata | 119/119
# Calcutta Childrens School
#
# Searching: schools in Malda West Bengal
# Search Submitted
# Malda | schools | Scroll 1 -> 14
# Malda | schools | Scroll 2 -> 20
# Malda | schools | Scroll 3 -> 27
# Malda | schools | Scroll 4 -> 34
# Malda | schools | Scroll 5 -> 40
# Malda | schools | Scroll 6 -> 47
# Malda | schools | Scroll 7 -> 54
# Malda | schools | Scroll 8 -> 60
# Malda | schools | Scroll 9 -> 67
# Malda | schools | Scroll 10 -> 74
# Malda | schools | Scroll 11 -> 80
# Malda | schools | Scroll 12 -> 87
# Malda | schools | Scroll 13 -> 94
# Malda | schools | Scroll 14 -> 100
# Malda | schools | Scroll 15 -> 107
# Malda | schools | Scroll 16 -> 111
# Malda | schools | Scroll 17 -> 111
# Malda | schools | Scroll 18 -> 111
# Malda | schools | Scroll 19 -> 111
# Malda | schools | Scroll 20 -> 111
# Collected 111 links
# Malda | 1/111
# Holy Child English Academy, Malda
# Malda | 2/111
# Malda Zilla School
# Malda | 3/111
# The St. Xavier's School, Malda
# Malda | 4/111
#
# Malda | 5/111
# St. Mary's School, Malda
# Malda | 6/111
# Usha Martin School, Malda
# Malda | 7/111
# Daffodils English Academy
# Malda | 8/111
# Little Angels School
# Malda | 9/111
# EuroKids PreSchool in English Bazar, Malda
# Malda | 10/111
# Delhi World Public School, Malda, West Bengal.
# Malda | 11/111
# Malda Town High School (H.S.)
# Malda | 12/111
# Prof. S Bagchi Sir's CBSE & ICSE Maths Classes
# Malda | 13/111
# Emmanuel English School
# Malda | 14/111
# Leela English academy
# Malda | 15/111
# Kendriya Vidyalaya Malda
# Malda | 16/111
# Kidzee English Bazar Malda
# Malda | 17/111
# Malda Academy High School
# Malda | 18/111
# Little Gurukul Play School Malda
# Malda | 19/111
# Akrurmoni Coronation Institution (H.S), Malda
# Malda | 20/111
# Jingle Bell English School, Malda
# Malda | 21/111
# Dolna School
# Malda | 22/111
# Malda Girls' High School
# Malda | 23/111
# Kidzee Gour Road, Malda
# Malda | 24/111
# GOOD MORNING SCHOOL, Malda.
# Malda | 25/111
# City Public School
# Malda | 26/111
# Malda Kanya Sikshalaya High School
# Malda | 27/111
#
# Malda | 28/111
# Malda Railway High School (H.S.)
# Malda | 86/111
#
# Malda | 87/111
# TECHNO INDIA GROUP WORLD School
# Malda | 88/111
# Sabuj Abujh Shishu Angan
# Malda | 89/111
# Thakur Anukul Chandra Balika Vidyamandir
# Malda | 90/111
# Dragon Martial Art Academy
# Malda | 91/111
# SATSANG VIHAR MALDA(SKMHN)
# Malda | 92/111
# Taekwondo Camp of Bengal Area- Malda
# Malda | 93/111
# MADHUVANTI MUSIC ACADEMY
# Malda | 94/111
# Sahapur High School (H.S)
# Malda | 95/111
# USHA MARTIN JUNIORS MALDA
# Malda | 96/111
# Dam's Tutorial Study Room
# Malda | 97/111
# Raigram High School (H.S.)
# Malda | 98/111
# Barlow Girls’ High School
# Malda | 99/111
# CrackIt
# Malda | 100/111
# Sultanganj High School (H.S)
# Malda | 101/111
# Malda Aneek Shangha Club
# Malda | 102/111
# Baba Bhayankarnath Motor Training School
# Malda | 103/111
# 🥋🇮🇳🥋Gazole Sewchand Parameswari Vidyamandir, Gazole, Malda
# Malda | 104/111
# Jote Arapur P.N. High School(H.S.)
# Malda | 105/111
# Osmania High Madrasah (H.S.)
# Malda | 106/111
# Pratik Dance Kingdom
# Malda | 107/111
# Railway Lakshman Sen Out door Stadium, Malda
# Malda | 108/111
# Divine Dance Studio
# Malda | 109/111
# Khutadaha R.C. High School (H.S.)
# Malda | 110/111
# Jalalpur High School
# Malda | 111/111
# Ybot Shiksha Sadan
#
# Searching: schools in Murshidabad West Bengal
# Search Submitted
# Murshidabad | schools | Scroll 1 -> 14
# Murshidabad | schools | Scroll 2 -> 20
# Murshidabad | schools | Scroll 3 -> 27
# Murshidabad | schools | Scroll 4 -> 34
# Murshidabad | schools | Scroll 5 -> 40
# Murshidabad | schools | Scroll 6 -> 47
# Murshidabad | schools | Scroll 7 -> 54
# Murshidabad | schools | Scroll 8 -> 60
# Murshidabad | schools | Scroll 9 -> 67
# Murshidabad | schools | Scroll 10 -> 74
# Murshidabad | schools | Scroll 11 -> 80
# Murshidabad | schools | Scroll 12 -> 87
# Murshidabad | schools | Scroll 13 -> 94
# Murshidabad | schools | Scroll 14 -> 100
# Murshidabad | schools | Scroll 15 -> 107
# Murshidabad | schools | Scroll 16 -> 114
# Murshidabad | schools | Scroll 17 -> 120
# Murshidabad | schools | Scroll 18 -> 120
# Murshidabad | schools | Scroll 19 -> 120
# Murshidabad | schools | Scroll 20 -> 120
# Murshidabad | schools | Scroll 21 -> 120
# Collected 120 links
# Murshidabad | 1/120
# Narayana School - Berhampore
# Murshidabad | 2/120
# Krishnath College School
# Murshidabad | 3/120
# Lalbagh Singhi High School
# Murshidabad | 4/120
# Murshidabad District Primary School Council
# Murshidabad | 5/120
# MURSHIDABAD MODERN ACADEMY
# Murshidabad | 6/120
# LMET INTERNATIONAL SCHOOL
# Murshidabad | 7/120
# MURSHIDABAD KIDS’G PUBLIC SCHOOL
# Murshidabad | 8/120
# Mary Immaculate School
# Murshidabad | 9/120
# Lalbagh Sri Sri Ramkrishna Vidya pith school
# Murshidabad | 10/120
#
# Murshidabad | 11/120
# Purulia | 67/91
# Haripada Sahitya Mandir
# Purulia | 68/91
# KISHORE BHARATI ASHRAM VIDYALAYA
# Purulia | 69/91
#
# Purulia | 70/91
# Sri Ramkrishna Tarak Math High School
# Purulia | 71/91
# Rhythm Dance Academy
# Purulia | 72/91
# Sri Ramakrishna Universal shrine , Ramakrishna Mission Vidyapith- Purulia
# Purulia | 73/91
# School of Karate
# Purulia | 74/91
# PM Shri Kendriya Vidyalaya Adra
# Purulia | 75/91
# Sainik School Purulia Office
# Purulia | 76/91
# Star Dance Class (Studio)
# Purulia | 77/91
# Lagda High School
# Purulia | 78/91
# The Pride Cricket Academy
# Purulia | 79/91
# Bongabari Girls High School
# Purulia | 80/91
# Angels of God School
# Purulia | 81/91
# Vidyasagar Siksha Niketan
# Purulia | 82/91
# Jana Xerox Centre
# Purulia | 83/91
# Bina Motor Training School
# Purulia | 84/91
# Sri Aurobindo Kendra Purulia
# Purulia | 85/91
# Kangsabati Motor Training School
# Purulia | 86/91
# Raghabpur harijan school
# Purulia | 87/91
# Dorodih H.G.K Vidyapith
# Purulia | 88/91
# APLL PURULIA center
# Purulia | 89/91
# G.D.Lang Institution (Gobinda Das Lang Institution)
# Purulia | 90/91
# Ra sa Mess(Students)
# Purulia | 91/91
# Pooja School Uniform
#
# Searching: schools in South 24 Parganas West Bengal
# Search Submitted
# South 24 Parganas | schools | Scroll 1 -> 14
# South 24 Parganas | schools | Scroll 2 -> 20
# South 24 Parganas | schools | Scroll 3 -> 27
# South 24 Parganas | schools | Scroll 4 -> 34
# South 24 Parganas | schools | Scroll 5 -> 40
# South 24 Parganas | schools | Scroll 6 -> 47
# South 24 Parganas | schools | Scroll 7 -> 54
# South 24 Parganas | schools | Scroll 8 -> 60
# South 24 Parganas | schools | Scroll 9 -> 67
# South 24 Parganas | schools | Scroll 10 -> 74
# South 24 Parganas | schools | Scroll 11 -> 80
# South 24 Parganas | schools | Scroll 12 -> 87
# South 24 Parganas | schools | Scroll 13 -> 94
# South 24 Parganas | schools | Scroll 14 -> 100
# South 24 Parganas | schools | Scroll 15 -> 107
# South 24 Parganas | schools | Scroll 16 -> 114
# South 24 Parganas | schools | Scroll 17 -> 120
# South 24 Parganas | schools | Scroll 18 -> 120
# South 24 Parganas | schools | Scroll 19 -> 120
# South 24 Parganas | schools | Scroll 20 -> 120
# South 24 Parganas | schools | Scroll 21 -> 120
# Collected 111 links
# South 24 Parganas | 1/111
# St Montfort's Senior Secondary School (Affiliated to CBSE, New Delhi)
# South 24 Parganas | 2/111
# Narayana School - Sonarpur
# South 24 Parganas | 3/111
# DPSC South 24 Parganas
# South 24 Parganas | 4/111
# ZENITH WORLD SCHOOL | Best CBSE School in Diamond Harbour | Admission open for 2026-27
# South 24 Parganas | 5/111
# Baruipur High School
# South 24 Parganas | 6/111
# Delhi Public School (Joka ) South Kolkata
# South 24 Parganas | 7/111
# SGS International School
# South 24 Parganas | 8/111
# Holy Cross School
# South 24 Parganas | 9/111
# VSSU International School
# South 24 Parganas | 10/111
# Chalantika Nursery & K.G. School
# South 24 Parganas | 11/111
# SANKARDAHA ADARSHA ABYATANIK PRIMARY VIDYALAYA
# South 24 Parganas | 111/111
# Badam tola school
#
# Searching: schools in Uttar Dinajpur West Bengal
# Search Submitted
# Uttar Dinajpur | schools | Scroll 1 -> 14
# Uttar Dinajpur | schools | Scroll 2 -> 20
# Uttar Dinajpur | schools | Scroll 3 -> 27
# Uttar Dinajpur | schools | Scroll 4 -> 34
# Uttar Dinajpur | schools | Scroll 5 -> 40
# Uttar Dinajpur | schools | Scroll 6 -> 47
# Uttar Dinajpur | schools | Scroll 7 -> 54
# Uttar Dinajpur | schools | Scroll 8 -> 60
# Uttar Dinajpur | schools | Scroll 9 -> 67
# Uttar Dinajpur | schools | Scroll 10 -> 74
# Uttar Dinajpur | schools | Scroll 11 -> 80
# Uttar Dinajpur | schools | Scroll 12 -> 87
# Uttar Dinajpur | schools | Scroll 13 -> 94
# Uttar Dinajpur | schools | Scroll 14 -> 100
# Uttar Dinajpur | schools | Scroll 15 -> 107
# Uttar Dinajpur | schools | Scroll 16 -> 114
# Uttar Dinajpur | schools | Scroll 17 -> 120
# Uttar Dinajpur | schools | Scroll 18 -> 120
# Uttar Dinajpur | schools | Scroll 19 -> 120
# Uttar Dinajpur | schools | Scroll 20 -> 120
# Uttar Dinajpur | schools | Scroll 21 -> 120
# Collected 118 links
# Uttar Dinajpur | 1/118
# ST. XAVIER’S School
# Uttar Dinajpur | 2/118
# Jawahar Navodaya Vidyalaya, Uttar Dinajpur, West
# Uttar Dinajpur | 3/118
# Jawahar Navodaya Vidyalaya,Uttar Dinajpur
# Uttar Dinajpur | 4/118
# Bethany Mission School
# Uttar Dinajpur | 5/118
# Raiganj Mohanbati High School
# Uttar Dinajpur | 6/118
# Karnajora High School
# Uttar Dinajpur | 7/118
# Kadihat Belbari High School
# Uttar Dinajpur | 8/118
# DANGRAM I.C. HIGH SCHOOL (H.S)
# Uttar Dinajpur | 9/118
# Surjapur High School
# Uttar Dinajpur | 10/118
# Kendriya Vidyalaya Raiganj BSF Govindpur
# Uttar Dinajpur | 11/118
# LITTLE STARS SMART SCHOOL
# Backup Saved
# Uttar Dinajpur | 12/118
# Kunoir K.C. High School
# Uttar Dinajpur | 13/118
# Raiganj Coronation High School
# Uttar Dinajpur | 14/118
# Sudarshanpur Dwarika Prashad Uchcha Vidyachakra
# Uttar Dinajpur | 15/118
# ALTAPUR HIGH SCHOOL
# Uttar Dinajpur | 16/118
# SUNFORD INTERNATIONAL SCHOOL
# Uttar Dinajpur | 17/118
# Dalkhola High School
# Uttar Dinajpur | 18/118
# Kaliyaganj Parbati Sundari High School (Estd-1931)
# Uttar Dinajpur | 19/118
# Goalpokher Lodhan High School
# Uttar Dinajpur | 20/118
# Solpara High School
# Uttar Dinajpur | 21/118
# SB School of Nursing
# Uttar Dinajpur | 22/118
# Kichaktola High School
# Uttar Dinajpur | 23/118
# Raiganj Girls High School
# Uttar Dinajpur | 24/118
# Hatia High School (H.S.)
# Uttar Dinajpur | 25/118
# Blue Bells Model School
# Uttar Dinajpur | 26/118
# Holy Cross 🏫
