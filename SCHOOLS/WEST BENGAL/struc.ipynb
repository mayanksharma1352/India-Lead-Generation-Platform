# %%
import pandas as pd

# %%
df = pd.read_csv("westbengal_schools.csv")

# %%
df.shape
# Out:
# (1807, 8)

# %%
duplicate_count = df.duplicated(
    subset=["School Name", "Google Maps URL"]
).sum()
duplicate_count
# Out:
# np.int64(0)

# %%
df = df[
    df["Phone"].notna() & 
    (df["Phone"].astype(str).str.strip() != "")
    ]
df.shape
# Out:
# (101, 8)

# %%
df = df[
    df["School Name"].notna()
    ]

df = df[
    df["School Name"].str.strip() != ""
    ]
df.shape
# Out:
# (101, 8)

# %%
# CLEAN PHONE COLUMNS
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]","",regex=True)
    .str.strip()
)

display(df[["Phone"]].head())
# Out:
#             Phone
# 19  033 6455 8097
# 24   089109 33157
# 26  033 2631 7919
# 30   096747 70714
# 62   098306 92624

# %%
# SAVE CLEANED FILE
df.to_csv(
    "westbengal_schools_cleaned.csv",
    index=False
)
