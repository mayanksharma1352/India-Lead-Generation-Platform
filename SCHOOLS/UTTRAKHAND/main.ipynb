# %%
pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-4.44.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting certifi>=2026.2.25 (from selenium)
#   Downloading certifi-2026.4.22-py3-none-any.whl.metadata (2.5 kB)
# Collecting trio<1.0,>=0.31.0 (from selenium)
#   Downloading trio-0.33.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket<1.0,>=0.12.2 (from selenium)
#   Downloading trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: typing_extensions<5.0,>=4.15.0 in c:\users\office\anaconda3\lib\site-packages (from selenium) (4.15.0)
# Collecting urllib3<3.0,>=2.6.3 (from urllib3[socks]<3.0,>=2.6.3->selenium)
#   Downloading urllib3-2.7.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: websocket-client<2.0,>=1.8.0 in c:\users\office\anaconda3\lib\site-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\office\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (25.4.0)
# Requirement already satisfied: sortedcontainers in c:\users\office\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\office\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (3.11)
# Collecting outcome (from trio<1.0,>=0.31.0->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\office\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\office\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (2.0.0)
# Collecting wsproto>=0.14 (from trio-websocket<1.0,>=0.12.2->selenium)
#   Downloading wsproto-1.3.2-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\office\anaconda3\lib\site-packages (from urllib3[socks]<3.0,>=2.6.3->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\office\anaconda3\lib\site-packages (from cffi>=1.14->trio<1.0,>=0.31.0->selenium) (2.23)
# Requirement already satisfied: h11<1,>=0.16.0 in c:\users\office\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket<1.0,>=0.12.2->selenium) (0.16.0)
# Downloading selenium-4.44.0-py3-none-any.whl (9.7 MB)
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ----- ---------------------------------- 1.3/9.7 MB 7.8 MB/s eta 0:00:02
#    --------------- ------------------------ 3.7/9.7 MB 9.4 MB/s eta 0:00:01
#    --------------------------- ------------ 6.6/9.7 MB 10.9 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.7 MB 12.2 MB/s eta 0:00:01
#    ---------------------------------------- 9.7/9.7 MB 10.2 MB/s  0:00:00
# Downloading trio-0.33.0-py3-none-any.whl (510 kB)
# Downloading trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Downloading urllib3-2.7.0-py3-none-any.whl (131 kB)
# Downloading certifi-2026.4.22-py3-none-any.whl (135 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading wsproto-1.3.2-py3-none-any.whl (24 kB)
# Installing collected packages: wsproto, urllib3, outcome, certifi, trio, trio-websocket, selenium
#
#    ---------------------------------------- 0/7 [wsproto]
#   Attempting uninstall: urllib3
#    ---------------------------------------- 0/7 [wsproto]
#     Found existing installation: urllib3 2.5.0
#    ---------------------------------------- 0/7 [wsproto]
#     Uninstalling urllib3-2.5.0:
#    ---------------------------------------- 0/7 [wsproto]
#       Successfully uninstalled urllib3-2.5.0
#    ---------------------------------------- 0/7 [wsproto]
#    ----- ---------------------------------- 1/7 [urllib3]
#    ----- ---------------------------------- 1/7 [urllib3]
#    ----------- ---------------------------- 2/7 [outcome]
#   Attempting uninstall: certifi
#    ----------- ---------------------------- 2/7 [outcome]
#    ----------------- ---------------------- 3/7 [certifi]
#     Found existing installation: certifi 2025.11.12
#    ----------------- ---------------------- 3/7 [certifi]
#     Uninstalling certifi-2025.11.12:
#    ----------------- ---------------------- 3/7 [certifi]
#       Successfully uninstalled certifi-2025.11.12
#    ----------------- ---------------------- 3/7 [certifi]
#    ----------------- ---------------------- 3/7 [certifi]
#    ---------------------- ----------------- 4/7 [trio]
#    ---------------------- ----------------- 4/7 [trio]
#    ---------------------- ----------------- 4/7 [trio]
#    ---------------------- ----------------- 4/7 [trio]
#    ---------------------- ----------------- 4/7 [trio]
#    ---------------------- ----------------- 4/7 [trio]
#    ---------------------------- ----------- 5/7 [trio-websocket]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------------- 7/7 [selenium]
#
# Successfully installed certifi-2026.4.22 outcome-1.3.0.post0 selenium-4.44.0 trio-0.33.0 trio-websocket-0.12.2 urllib3-2.7.0 wsproto-1.3.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\office\anaconda3\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\office\anaconda3\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\office\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\office\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\office\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\office\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install webdriver-manager
# Out:
# Collecting webdriver-manager
#   Downloading webdriver_manager-4.0.2-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: requests in c:\users\office\anaconda3\lib\site-packages (from webdriver-manager) (2.32.5)
# Requirement already satisfied: python-dotenv in c:\users\office\anaconda3\lib\site-packages (from webdriver-manager) (1.1.0)
# Requirement already satisfied: packaging in c:\users\office\anaconda3\lib\site-packages (from webdriver-manager) (25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\office\anaconda3\lib\site-packages (from requests->webdriver-manager) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\office\anaconda3\lib\site-packages (from requests->webdriver-manager) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\office\anaconda3\lib\site-packages (from requests->webdriver-manager) (2.7.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\office\anaconda3\lib\site-packages (from requests->webdriver-manager) (2026.4.22)
# Downloading webdriver_manager-4.0.2-py2.py3-none-any.whl (27 kB)
# Installing collected packages: webdriver-manager
# Successfully installed webdriver-manager-4.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import time
import random
import pandas as pd

from datetime import datetime

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.service import Service

from webdriver_manager.chrome import ChromeDriverManager


# UTTARAKHAND DISTRICTS
districts = [

    "Almora",
    "Bageshwar",
    "Chamoli",
    "Champawat",
    "Dehradun",
    "Haridwar",
    "Nainital",
    "Pauri Garhwal",
    "Pithoragarh",
    "Rudraprayag",
    "Tehri Garhwal",
    "Udham Singh Nagar",
    "Uttarkashi"

]


# SEARCH TYPES

search_types = [

    "schools",
    "CBSE schools",
    "government schools",
    "private schools"

]

# CHROME OPTIONS

options = webdriver.ChromeOptions()

options.add_argument("--start-maximized")

options.add_argument(
    "--disable-blink-features=AutomationControlled"
)

options.add_argument("--disable-notifications")

# START DRIVER

driver = webdriver.Chrome(

    service=Service(
        ChromeDriverManager().install()
    ),

    options=options
)


# OPEN GOOGLE MAPS

driver.get("https://www.google.com/maps")

print("Opening Google Maps...")

time.sleep(15)

print("Google Maps Loaded")


# STORAGE


all_data = []

visited_links = set()


# SEARCH BOX FUNCTION


def get_search_box():

    selectors = [

        '//input[@id="searchboxinput"]',
        '//input[contains(@placeholder,"Search")]',
        '//input[contains(@aria-label,"Search")]',
        '//input'

    ]

    for selector in selectors:

        try:

            box = driver.find_element(
                By.XPATH,
                selector
            )

            return box

        except:
            pass

    return None

# EXTRACT SCHOOL DATA

def extract_school_data():

    try:

        # SCHOOL NAME
        try:
            name = driver.find_element(
                By.TAG_NAME,
                "h1"
            ).text
        except:
            name = ""

        # ADDRESS
        try:
            address = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"address")]'
            ).text
        except:
            address = ""

        # PHONE
        try:
            phone = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"phone")]'
            ).text
        except:
            phone = ""

        # WEBSITE
        try:
            website = driver.find_element(
                By.XPATH,
                '//a[contains(@data-item-id,"authority")]'
            ).get_attribute("href")
        except:
            website = ""

        # RATING
        try:
            rating = driver.find_element(
                By.XPATH,
                '//div[@role="img"]'
            ).get_attribute("aria-label")
        except:
            rating = ""

        return {

            "School Name": name,
            "Address": address,
            "Phone": phone,
            "Website": website,
            "Rating": rating,
            "Google Maps URL": driver.current_url

        }

    except:

        return None


# START EXTRACTION

for district in districts:

    for search_type in search_types:

        try:

            query = (
                f"{search_type} "
                f"in {district} Uttarakhand"
            )

            print(f"\nSearching: {query}")

   
            # SEARCH

            search_box = get_search_box()

            if not search_box:

                print("Search Box Not Found")

                continue

            ActionChains(driver).move_to_element(
                search_box
            ).click().perform()

            time.sleep(1)

            search_box.send_keys(
                Keys.CONTROL + "a"
            )

            time.sleep(1)

            search_box.send_keys(Keys.DELETE)

            time.sleep(1)

            # TYPE SLOWLY
            for char in query:

                search_box.send_keys(char)

                time.sleep(0.03)

            search_box.send_keys(Keys.ENTER)

            print("Search Submitted")

            time.sleep(8)

            # SCROLL RESULTS

            try:

                scrollable_div = driver.find_element(
                    By.XPATH,
                    '//div[@role="feed"]'
                )

                previous_count = 0

                stagnant = 0

                for i in range(100):

                    driver.execute_script(
                        """
                        arguments[0].scrollTop =
                        arguments[0].scrollHeight
                        """,
                        scrollable_div
                    )

                    time.sleep(4)

                    listings = driver.find_elements(
                        By.XPATH,
                        '//a[contains(@href,"/maps/place/")]'
                    )

                    current_count = len(listings)

                    print(
                        f"{district} | "
                        f"{search_type} | "
                        f"Scroll {i+1} -> "
                        f"{current_count}"
                    )

                    if current_count == previous_count:

                        stagnant += 1

                    else:

                        stagnant = 0

                    if stagnant >= 4:

                        break

                    previous_count = current_count

            except Exception as e:

                print(f"Scrolling Error: {e}")

            # GET LINK

            listings = driver.find_elements(
                By.XPATH,
                '//a[contains(@href,"/maps/place/")]'
            )

            links = []

            for listing in listings:

                try:

                    link = listing.get_attribute("href")

                    if (
                        link
                        and link not in visited_links
                    ):

                        links.append(link)

                        visited_links.add(link)

                except:
                    pass

            print(f"Collected {len(links)} links")

            # VISIT EACH SCHOOL

            for index, link in enumerate(links):

                try:

                    print(
                        f"{district} | "
                        f"{index+1}/{len(links)}"
                    )

                    driver.get(link)

                    time.sleep(
                        random.uniform(2, 3)
                    )

                    data = extract_school_data()

                    if data:

                        data["District"] = district

                        data["Search Type"] = search_type

                        all_data.append(data)

                        print(data["School Name"])

   
                    # BACKUP SAVE

                    if len(all_data) % 100 == 0:

                        backup_df = pd.DataFrame(
                            all_data
                        )

                        backup_df.drop_duplicates(
                            subset=[
                                "School Name",
                                "Google Maps URL"
                            ],
                            inplace=True
                        )

                        backup_df.to_csv(
                            "uttarakhand_schools_backup.csv",
                            index=False
                        )

                        print("Backup Saved")

                except Exception as e:

                    print(
                        f"School Error: {e}"
                    )

        except Exception as e:

            print(
                f"District Error: {e}"
            )

# FINAL SAVE


df = pd.DataFrame(all_data)

df.drop_duplicates(

    subset=[
        "School Name",
        "Google Maps URL"
    ],

    inplace=True
)

# UNIQUE FILE NAME

filename = (
    f"uttarakhand_schools.csv"
)

df.to_csv(
    filename,
    index=False
)

print("\nExtraction Completed")

print(
    f"Total Schools Extracted: {len(df)}"
)

print(f"\nSaved File: {filename}")

driver.quit()
# Out:
# Opening Google Maps...
# Google Maps Loaded
#
# Searching: schools in Almora Uttarakhand
# Search Submitted
# Almora | schools | Scroll 1 -> 14
# Almora | schools | Scroll 2 -> 20
# Almora | schools | Scroll 3 -> 27
# Almora | schools | Scroll 4 -> 34
# Almora | schools | Scroll 5 -> 40
# Almora | schools | Scroll 6 -> 47
# Almora | schools | Scroll 7 -> 50
# Almora | schools | Scroll 8 -> 50
# Almora | schools | Scroll 9 -> 50
# Almora | schools | Scroll 10 -> 50
# Almora | schools | Scroll 11 -> 50
# Collected 49 links
# Almora | 1/49
# Sharda Public School
# Almora | 2/49
# Spring Dales School
# Almora | 3/49
# Beersheba Sr. Sec. School Almora
# Almora | 4/49
# HOLY ANGEL PUBLIC SCHOOL, Almora
# Almora | 5/49
# Kendriya Vidyalaya Almora
# Almora | 6/49
# Koormanchal Academy
# Almora | 7/49
# C M Memorial School Almora
# Almora | 8/49
# Maharishi Vidya Mandir
# Almora | 9/49
# Sai International convent junior high school Almora
# Almora | 10/49
# Green Field Public School
# Almora | 11/49
# Beersheba Senior Secondary School
# Almora | 12/49
# Takshila School of Excellence
# Almora | 13/49
# Beersheba Sr. Sec School Almora
# Almora | 14/49
# NBU International School
# Almora | 15/49
# Tav Academy
# Almora | 16/49
# Atal utkrist Government Inter College, mall road Almora
# Almora | 17/49
# Little Millennium Preschool - Kholta, Almora
# Almora | 18/49
# Manas public school
# Almora | 19/49
# Malvika Junior High School
# Almora | 20/49
# GGIC Almora
# Almora | 21/49
# St.Paul School Almora
# Almora | 22/49
# Beershiva School
# Almora | 23/49
# Arya Government Girls Inter College
# Almora | 24/49
# G.D. Birla Memorial School, Ranikhet
# Almora | 25/49
# SUCCESS POINT ALMORA
# Almora | 26/49
# Ramsay Government Inter College
# Almora | 27/49
# Jai Shri College
# Almora | 28/49
# Grace Public junior High school
# Almora | 29/49
# Adams Girls Inter College
# Almora | 30/49
# Army Public School
# Almora | 31/49
# Daksh English Institute
# Almora | 32/49
# Skill Byte Academy
# Almora | 33/49
# D'SHADOW performing arts academy
# Almora | 34/49
# Jack n Jill
# Almora | 35/49
# Almora Kitab Ghar
# Almora | 36/49
# Ashok Hall Girls' Residential School
# Almora | 37/49
# Soban Singh Jeena Government Institute of Medical Science & Research
# Almora | 38/49
# Holy Child Public School Golna Karadiya
# Almora | 39/49
# Sunshien cricket academy almora
# Almora | 40/49
# Almora city library
# Almora | 41/49
# CCIS Academy for Advance Studies
# Almora | 42/49
# Vivekanand Inter College
# Almora | 43/49
# K-Tigers Taekwondo Academy
# Almora | 44/49
# Mangal Deep Vidya Mandir
# Almora | 45/49
# Radhey Shyam Institute Of Technology
# Almora | 46/49
# Kumaon Public School
# Almora | 47/49
# विवेकानंद बालिका विद्या मंदिर जीवनधाम अल्मोड़ा
# Almora | 48/49
# Minerva rays children academy
# Almora | 49/49
# PM Shri Kendriya Vidyalaya, Ranikhet
#
# Searching: CBSE schools in Almora Uttarakhand
# Search Submitted
# Almora | CBSE schools | Scroll 1 -> 14
# Almora | CBSE schools | Scroll 2 -> 20
# Almora | CBSE schools | Scroll 3 -> 27
# Almora | CBSE schools | Scroll 4 -> 34
# Almora | CBSE schools | Scroll 5 -> 34
# Almora | CBSE schools | Scroll 6 -> 34
# Almora | CBSE schools | Scroll 7 -> 34
# Almora | CBSE schools | Scroll 8 -> 34
# Collected 9 links
# Almora | 1/9
# Jawahar Navodaya Vidhyalaya
# Almora | 2/9
# New Inspiration Public School
# Almora | 3/9
# Sharda Public School
# Almora | 4/9
# Birla Vidya Mandir, Nainital
# Almora | 5/9
# JNV NTL Exam
# Almora | 6/9
# GD GOENKA International School, Nainital
# Almora | 7/9
# Army Public School (Ranikhet)
# Almora | 8/9
# Rajiv Gandhi Navodaya Vidyalaya, Chanoliya, Almora
# Almora | 9/9
# Holy Hans public school
#
# Searching: government schools in Almora Uttarakhand
# Search Submitted
# Almora | government schools | Scroll 1 -> 14
# Almora | government schools | Scroll 2 -> 20
# Almora | government schools | Scroll 3 -> 27
# Almora | government schools | Scroll 4 -> 34
# Almora | government schools | Scroll 5 -> 40
# Almora | government schools | Scroll 6 -> 47
# Almora | government schools | Scroll 7 -> 54
# Almora | government schools | Scroll 8 -> 60
# Almora | government schools | Scroll 9 -> 67
# Almora | government schools | Scroll 10 -> 74
# Almora | government schools | Scroll 11 -> 80
# Almora | government schools | Scroll 12 -> 87
# Almora | government schools | Scroll 13 -> 94
# Almora | government schools | Scroll 14 -> 100
# Almora | government schools | Scroll 15 -> 107
# Almora | government schools | Scroll 16 -> 114
# Almora | government schools | Scroll 17 -> 119
# Almora | government schools | Scroll 18 -> 119
# Almora | government schools | Scroll 19 -> 119
# Almora | government schools | Scroll 20 -> 119
# Almora | government schools | Scroll 21 -> 119
# Collected 85 links
# Almora | 1/85
# Government Higher Secondary School thuwasimal lamgada almora
# Almora | 2/85
# ITI Almora
# Almora | 3/85
# Raja Anand singh goverment girls school
# Almora | 4/85
# Government Primary School
# Almora | 5/85
# Government Primary School, Kherda
# Almora | 6/85
# Government Primary School
# Almora | 7/85
# Government Primary School
# Almora | 8/85
# Government Nursing College
# Almora | 9/85
# S.S.J CAMPUS ALMORA
# Almora | 10/85
# Government Primary School,
# Almora | 11/85
# District Hospital Almora
# Almora | 12/85
# Government Junior High School
# Almora | 13/85
# Government Higher Secondary School, Dhaura
# Almora | 14/85
# Almora Inter college Almora
# Almora | 15/85
# Government Polytechnic Malla Salam Uttarakhand
# Almora | 16/85
# Government Model Primary School,Khankar, Lamgara, Almora
# Almora | 17/85
# Government Primary School
# राजकीय बालिका इंटर कालेज जलना लमगड़ा (Government Girls Inter College Jalna Lamgada)
# Almora | 77/85
# Dr Ramesh Singh Pal
# Almora | 78/85
# Government Inter College
# Almora | 79/85
# Navjeevan Ayurveda & Panchkarma Clinic
# Almora | 80/85
# K D Memorial Public school
# Almora | 81/85
# Bamanswal
# Almora | 82/85
# Paltan Bazar
# Almora | 83/85
# Mountain Driving School, Indo Tibetan Border Police
# Almora | 84/85
# Shree Kalyanika Himalaya Devsathanam Ashram
# Almora | 85/85
# SBM Toilet
#
# Searching: private schools in Almora Uttarakhand
# Search Submitted
# Almora | private schools | Scroll 1 -> 14
# Almora | private schools | Scroll 2 -> 17
# Almora | private schools | Scroll 3 -> 17
# Almora | private schools | Scroll 4 -> 17
# Almora | private schools | Scroll 5 -> 17
# Almora | private schools | Scroll 6 -> 17
# Collected 0 links
#
# Searching: schools in Bageshwar Uttarakhand
# Search Submitted
# Bageshwar | schools | Scroll 1 -> 14
# Bageshwar | schools | Scroll 2 -> 20
# Bageshwar | schools | Scroll 3 -> 27
# Bageshwar | schools | Scroll 4 -> 34
# Bageshwar | schools | Scroll 5 -> 40
# Bageshwar | schools | Scroll 6 -> 47
# Bageshwar | schools | Scroll 7 -> 48
# Bageshwar | schools | Scroll 8 -> 48
# Bageshwar | schools | Scroll 9 -> 48
# Bageshwar | schools | Scroll 10 -> 48
# Bageshwar | schools | Scroll 11 -> 48
# Collected 47 links
# Bageshwar | 1/47
# Countrywide Public School Bageshwar
# Bageshwar | 2/47
# GAYATRI VIDYA MANDIR, BAGESHWAR, UTTARAKHAND, INDIA
# Bageshwar | 3/47
# Mandalsera, bageshwar
# Bageshwar | 4/47
# Jim Corbett International School, Bageshwar
# Bageshwar | 5/47
# Himalayan Central School
# Bageshwar | 6/47
# Maharishi Vidya Mandir Bageshwar Uttarakhand
# Bageshwar | 7/47
# anandi academy bageshwar
# Bageshwar | 8/47
# Anandi Academy ,Mandalshera
# Bageshwar | 9/47
# KVS BAGESHWAR
# Bageshwar | 10/47
# Government Model Primary School Bageshwar
# Bageshwar | 11/47
# Saint Joseph Primary School
# Bageshwar | 12/47
# Mission Inter College, Bageshwar
# Bageshwar | 13/47
# Future Classes
# Bageshwar | 14/47
# Govt Inter College Bageshwar
# Bageshwar | 15/47
# Sainik High School
# Bageshwar | 16/47
# Vivekanand Vidya Mandir Inter College
# Bageshwar | 17/47
# Elite Academy
# Bageshwar | 18/47
# COUNTRYWIDE PUBLIC SCHOOL
# Bageshwar | 19/47
# KPB International school
# Bageshwar | 20/47
# Maharishi Vidya Mandir
# Bageshwar | 21/47
# Maharishi Vidya Mandir
# Bageshwar | 22/47
# Countrywide Public School
# Bageshwar | 23/47
# St. Adams Public School
# Bageshwar | 24/47
# Vivekanand school
# Bageshwar | 25/47
# Victor Mohan Joshi Memorial Government Inter College
# Bageshwar | 26/47
# Arjun music stage work academy Bageshwar Uttarakhand
# Bageshwar | 27/47
# Rajkiya Uchtar Madhyamik Vidyalaya
# Bageshwar | 28/47
# Unique Academy, Bilona Bageshwar
# Bageshwar | 29/47
# Jawahar Navoday Vidhyalaya
# Bageshwar | 30/47
# Sahas Sangeet Vidhyalaya Bageshwar
# Bageshwar | 31/47
# Stars Light Nursery School
# Bageshwar | 32/47
# Kindergarten
# Bageshwar | 33/47
# Nav Jyoti Public School
# Bageshwar | 34/47
# Government Primary School
# Bageshwar | 35/47
# Government Junior High School
# Bageshwar | 36/47
# Country wide public school, kathpuriya china, bageshwar
# Bageshwar | 37/47
# Hridiyansh Taekwondo academy bageshwar
# Bageshwar | 38/47
# Bagnath Coaching Center
# Bageshwar | 39/47
# राजकीय प्राथमिक विद्यालय मेहनरबूंगा
# Bageshwar | 40/47
# Abdial Public School, Kanda
# Bageshwar | 41/47
# Kathayatbar
# Bageshwar | 42/47
# Gic Mandalsera Bageshwar
# Bageshwar | 43/47
# गोल्डन वैली पब्लिक स्कूल
# Bageshwar | 44/47
# Saraswati Shishu Mandir Inter College, Chaurasi
# Bageshwar | 45/47
# Kendriya Vidyalaya
# Bageshwar | 46/47
# Himalayan Children Academy
# Bageshwar | 47/47
# A T S Bageshwar
#
# Searching: CBSE schools in Bageshwar Uttarakhand
# Search Submitted
# Bageshwar | CBSE schools | Scroll 1 -> 14
# Bageshwar | CBSE schools | Scroll 2 -> 20
# Bageshwar | CBSE schools | Scroll 3 -> 22
# Bageshwar | CBSE schools | Scroll 4 -> 22
# Bageshwar | CBSE schools | Scroll 5 -> 22
# Bageshwar | CBSE schools | Scroll 6 -> 22
# Bageshwar | CBSE schools | Scroll 7 -> 22
# Collected 0 links
#
# Searching: government schools in Bageshwar Uttarakhand
# Search Submitted
# Bageshwar | government schools | Scroll 1 -> 14
# Bageshwar | government schools | Scroll 2 -> 20
# Bageshwar | government schools | Scroll 3 -> 27
# Bageshwar | government schools | Scroll 4 -> 34
# Bageshwar | government schools | Scroll 5 -> 40
# Bageshwar | government schools | Scroll 6 -> 40
# Bageshwar | government schools | Scroll 7 -> 40
# Bageshwar | government schools | Scroll 8 -> 40
# Bageshwar | government schools | Scroll 9 -> 40
# Collected 18 links
# Bageshwar | 1/18
# Government Primary School, Jagthana
# Bageshwar | 2/18
# Government Primary School,
# Bageshwar | 3/18
# Government Primary School
# Bageshwar | 4/18
# Kendriya Vidhyalaya
# Bageshwar | 5/18
# Government Primary School, Malujhal
# Bageshwar | 6/18
# GOVT HIGHER SECONDARY SCHOOL JAGTHANA
# Bageshwar | 7/18
# Rajkiya Uchtar Madhyamik Vidyalaya
# Bageshwar | 8/18
# Government Primary School
# Bageshwar | 9/18
# Government Primary School, Riyuni Lakhmar
# Bageshwar | 10/18
# Government Inter College
# Backup Saved
# Bageshwar | 11/18
# Government Primary School
# Bageshwar | 12/18
# Government Primary School, Basani
# Bageshwar | 13/18
# Government Junior High School, Bamrari
# Bageshwar | 14/18
# Government Primary School
# Bageshwar | 15/18
# Government Primary School, Rawaikhal
# Bageshwar | 16/18
# Primary School, Malsuna, Bageshwar
# Bageshwar | 17/18
# Garur bageshwar
# Bageshwar | 18/18
# R G N V Bahuli Bageshwar
#
# Searching: private schools in Bageshwar Uttarakhand
# Search Submitted
# Bageshwar | private schools | Scroll 1 -> 14
# Bageshwar | private schools | Scroll 2 -> 20
# Bageshwar | private schools | Scroll 3 -> 20
# Bageshwar | private schools | Scroll 4 -> 20
# Bageshwar | private schools | Scroll 5 -> 20
# Bageshwar | private schools | Scroll 6 -> 20
# Collected 2 links
# Bageshwar | 1/2
# UTTRAYAN ACADEMY
# Bageshwar | 2/2
# Gayatri Vidhya Mandir
#
# Searching: schools in Chamoli Uttarakhand
# Search Submitted
# Chamoli | schools | Scroll 1 -> 9
# Chamoli | schools | Scroll 2 -> 9
# Chamoli | schools | Scroll 3 -> 9
# Chamoli | schools | Scroll 4 -> 9
# Chamoli | schools | Scroll 5 -> 9
# Collected 8 links
# Chamoli | 1/8
# Peace Public School
# Chamoli | 2/8
# Adarsh Vidhya Mandir
# Chamoli | 3/8
# Primary school chamoli
# Chamoli | 4/8
# Shri Nanda Valley Public School
# Chamoli | 5/8
# Uttarakhand Public School, Gopeshwar
# Chamoli | 6/8
# Adarsh Vidya Mandir
# Chamoli | 7/8
# Shri Guru Ram Rai Public School
# Chamoli | 8/8
# Kendriya Vidyalaya Gopeshwar
#
# Searching: CBSE schools in Chamoli Uttarakhand
# Search Submitted
# Chamoli | CBSE schools | Scroll 1 -> 10
# Chamoli | CBSE schools | Scroll 2 -> 10
# Chamoli | CBSE schools | Scroll 3 -> 10
# Chamoli | CBSE schools | Scroll 4 -> 10
# Chamoli | CBSE schools | Scroll 5 -> 10
# Collected 5 links
# Chamoli | 1/5
# James Academy
# Chamoli | 2/5
# Jawahar Navodaya Vidyalaya Pipalkoti
# Chamoli | 3/5
# Government Inter College
# Chamoli | 4/5
# Subodh Vidya Mandir-Chamoli
# Chamoli | 5/5
# Kendriya Vidyalaya Joshimath
#
# Searching: government schools in Chamoli Uttarakhand
# Search Submitted
# Chamoli | government schools | Scroll 1 -> 13
# Chamoli | government schools | Scroll 2 -> 13
# Chamoli | government schools | Scroll 3 -> 13
# Chamoli | government schools | Scroll 4 -> 13
# Chamoli | government schools | Scroll 5 -> 13
# Collected 9 links
# Chamoli | 1/9
# Government Inter College
# Chamoli | 2/9
# Government Primary School Ravigram
# Chamoli | 3/9
# Saraswati Vidya Mandir Inter College Joshimath
# Chamoli | 4/9
# Government Girls Inter College
# Chamoli | 5/9
# Government Inter College
# Chamoli | 6/9
# Dev Bhoomi Public High School
# Chamoli | 7/9
# Jyoti Vidyalaya School
# Chamoli | 8/9
# Institute of Technology Gopeshwar
# Chamoli | 9/9
# Atal Utkrist Government Inter College, Urgam, Chamoli
#
# Searching: private schools in Chamoli Uttarakhand
# Search Submitted
# Chamoli | private schools | Scroll 1 -> 2
# Chamoli | private schools | Scroll 2 -> 2
# Chamoli | private schools | Scroll 3 -> 2
# Chamoli | private schools | Scroll 4 -> 2
# Chamoli | private schools | Scroll 5 -> 2
# Collected 1 links
# Chamoli | 1/1
# CARWE Children's Academy
#
# Searching: schools in Champawat Uttarakhand
# Search Submitted
# Champawat | schools | Scroll 1 -> 14
# Champawat | schools | Scroll 2 -> 20
# Champawat | schools | Scroll 3 -> 23
# Champawat | schools | Scroll 4 -> 23
# Champawat | schools | Scroll 5 -> 23
# Champawat | schools | Scroll 6 -> 23
# Champawat | schools | Scroll 7 -> 23
# Collected 23 links
# Champawat | 1/23
# Angels Academy
# Champawat | 2/23
# Jawahar Navodaya Vidyalaya Champawat
# Champawat | 3/23
# Holy Faith School, Champawat
# Champawat | 4/23
# A.B.C. Alma Mater School
# Champawat | 5/23
# New Beersheba School, Champawat
# Champawat | 6/23
# Holy Wisdom School
# Champawat | 7/23
# Indus National School, Champawat
# Champawat | 8/23
# Mallikarjun School Champawat
# Champawat | 9/23
# Mount Carmel School
# Champawat | 10/23
# Primary School Champawat
# Champawat | 11/23
# Gurukulam Academy Champawat
# Champawat | 12/23
# The Asian Academy, champawat
# Champawat | 13/23
# Sun Shine School, Champawat
# Champawat | 14/23
# Government Girls Inter College
# Champawat | 15/23
# Modern Inter College, Champawat
# Champawat | 16/23
# Chaitanya Academy
# Champawat | 17/23
# Universal Public School
# Champawat | 18/23
# Anand Bal Vidhya Mandir
# Champawat | 19/23
# Alpine Convent School
# Champawat | 20/23
# Udayan International School
# Champawat | 21/23
# Shri Baleshwar Temple, Champawat
# Champawat | 22/23
# Government Girls Upper School, Champawat
# Champawat | 23/23
# Universal Inter College, Champawat
#
# Searching: CBSE schools in Champawat Uttarakhand
# Search Submitted
# Champawat | CBSE schools | Scroll 1 -> 14
# Champawat | CBSE schools | Scroll 2 -> 16
# Champawat | CBSE schools | Scroll 3 -> 16
# Champawat | CBSE schools | Scroll 4 -> 16
# Champawat | CBSE schools | Scroll 5 -> 16
# Champawat | CBSE schools | Scroll 6 -> 16
# Collected 3 links
# Champawat | 1/3
# Kendriya Vidyalaya 5 TH BN SSB Champawat
# Champawat | 2/3
# Kendriya Vidyalaya, Lohaghat
# Champawat | 3/3
# Oakland Public School
#
# Searching: government schools in Champawat Uttarakhand
# Search Submitted
# Champawat | government schools | Scroll 1 -> 14
# Champawat | government schools | Scroll 2 -> 20
# Champawat | government schools | Scroll 3 -> 23
# Champawat | government schools | Scroll 4 -> 23
# Champawat | government schools | Scroll 5 -> 23
# Champawat | government schools | Scroll 6 -> 23
# Champawat | government schools | Scroll 7 -> 23
# Collected 7 links
# Champawat | 1/7
# Govt. P.G. College
# Champawat | 2/7
# Govt. Primary School Laluwapani
# Champawat | 3/7
# Government Inter College, Sukhidhang
# Champawat | 4/7
# Happy Valley School Champawat
# Champawat | 5/7
# Government primary school Birgul Champawat
# Champawat | 6/7
# Government Polytechnic, Lohaghat
# Champawat | 7/7
# Government Polytechnic Champawat
#
# Searching: private schools in Champawat Uttarakhand
# Search Submitted
# Champawat | private schools | Scroll 1 -> 2
# Champawat | private schools | Scroll 2 -> 2
# Champawat | private schools | Scroll 3 -> 2
# Champawat | private schools | Scroll 4 -> 2
# Champawat | private schools | Scroll 5 -> 2
# Collected 0 links
#
# Searching: schools in Dehradun Uttarakhand
# Search Submitted
# Dehradun | schools | Scroll 1 -> 14
# Dehradun | schools | Scroll 2 -> 20
# Dehradun | schools | Scroll 3 -> 27
# Dehradun | schools | Scroll 4 -> 34
# Dehradun | schools | Scroll 5 -> 40
# Dehradun | schools | Scroll 6 -> 47
# Dehradun | schools | Scroll 7 -> 54
# Dehradun | schools | Scroll 8 -> 60
# Dehradun | schools | Scroll 9 -> 67
# Dehradun | schools | Scroll 10 -> 74
# Dehradun | schools | Scroll 11 -> 80
# Dehradun | schools | Scroll 12 -> 87
# Dehradun | schools | Scroll 13 -> 94
# Dehradun | schools | Scroll 14 -> 100
# Dehradun | schools | Scroll 15 -> 107
# Dehradun | schools | Scroll 16 -> 114
# Dehradun | schools | Scroll 17 -> 120
# Dehradun | schools | Scroll 18 -> 120
# Dehradun | schools | Scroll 19 -> 120
# Dehradun | schools | Scroll 20 -> 120
# Dehradun | schools | Scroll 21 -> 120
# Collected 120 links
# Dehradun | 1/120
# Le Grand International - Best ICSE School in Dehradun
# Dehradun | 2/120
# Doon World School | Best CBSE School in Dehradun
# Dehradun | 3/120
# Banyan tree World School
# Dehradun | 4/120
# Doon Global School - Best CBSE School in Dehradun
# Dehradun | 5/120
# Maple Bear School Dehradun
# Dehradun | 6/120
# Doon International School
# Dehradun | 7/120
# The Poly Kids Dalanwala | Best Pre School In Dehradun | Top Preschool in Dehradun
# Dehradun | 8/120
# Rose Mount School - English Medium School In Dehradun
# Dehradun | 9/120
# The Asian School
# Dehradun | 10/120
# The Heritage School
# Dehradun | 11/120
# Manava Bharti India International School-best school in dehradun
# Dehradun | 12/120
# Col. Brown Cambridge School
# Dehradun | 13/120
# Kasiga School | CBSE International Boarding School in Dehradun
# Dehradun | 14/120
# The Doon School
# Dehradun | 15/120
# Apollo International School
# Dehradun | 16/120
# St. Joseph's Academy
# Dehradun | 17/120
# Doon Heritage School - Top Best CBSE School in Dehradun, Premnagar, Uttarakhand | English Medium School
# Dehradun | 18/120
# Edify World School Dehradun
# Dehradun | 19/120
# Delhi Public School, Dehradun
# Dehradun | 20/120
# Doon Defence International School - Best CBSE School
# Dehradun | 21/120
# Army Public School , Birpur Dehradun
# Dehradun | 22/120
# Doon International School Riverside Campus
# Dehradun | 23/120
# Doon Imperial School Dehradun
# Dehradun | 24/120
# The TonsBridge School | Best Day & Residential School
# Dehradun | 25/120
# The Indian Public School
# Dehradun | 26/120
# Ann Mary School Dehradun
# Dehradun | 27/120
# Kelvin International School Dehradun
# Dehradun | 28/120
# Summer Valley School
# Dehradun | 29/120
# Doon Cambridge School
# Dehradun | 30/120
# D.A.V Public School
# Dehradun | 31/120
# Marshall School
# Dehradun | 32/120
# Dehradun | private schools | Scroll 6 -> 47
# Dehradun | private schools | Scroll 7 -> 54
# Dehradun | private schools | Scroll 8 -> 60
# Dehradun | private schools | Scroll 9 -> 67
# Dehradun | private schools | Scroll 10 -> 74
# Dehradun | private schools | Scroll 11 -> 80
# Dehradun | private schools | Scroll 12 -> 87
# Dehradun | private schools | Scroll 13 -> 94
# Dehradun | private schools | Scroll 14 -> 100
# Dehradun | private schools | Scroll 15 -> 104
# Dehradun | private schools | Scroll 16 -> 104
# Dehradun | private schools | Scroll 17 -> 104
# Dehradun | private schools | Scroll 18 -> 104
# Dehradun | private schools | Scroll 19 -> 104
# Collected 21 links
# Dehradun | 1/21
# Shiwalik Hills Academy Junior High School
# Dehradun | 2/21
# Birla Open Minds International School Dehradun
# Dehradun | 3/21
# Shemrock Rainbow
# Dehradun | 4/21
# THE POLY KIDS RAJPUR ROAD
# Dehradun | 5/21
# Little Wonder School
# Dehradun | 6/21
# Eduminatti
# Dehradun | 7/21
# Future Space Kids World International School,Dehradun
# Dehradun | 8/21
# Shikshankur Doon ( Kindergarten )
# Dehradun | 9/21
# Tiny Wings PreSchool & Daycare
# Dehradun | 10/21
# MOUNT BISHOP SCHOOL - OF INTEGRATED LEARNING
# Dehradun | 11/21
# Institute of Technology & Management (ITM), Dehradun
# Dehradun | 12/21
# Boarding School Assosiation of India
# Dehradun | 13/21
# Quantum University, Dehradun
# Dehradun | 14/21
# Kukreja Institute | Best College in Dehradun, Uttarakhand
# Dehradun | 15/21
# Vatsa Vatacharaya - tutorials
# Dehradun | 16/21
# Home tutor for kids (Vasugoel)
# Dehradun | 17/21
# HIT Dehradun College of MBA I Hotel Management l BBA l BCA l BSc IT l Agriculture l Himalayan Institute of Technology
# Dehradun | 18/21
# schools in dehradun
# Dehradun | 19/21
# Viverly Public School
# Dehradun | 20/21
# Doon Sarla Academy
# Dehradun | 21/21
# The Cambridge Senior Secondary School Dehradun
#
# Searching: schools in Haridwar Uttarakhand
# Search Submitted
# Haridwar | schools | Scroll 1 -> 14
# Haridwar | schools | Scroll 2 -> 20
# Haridwar | schools | Scroll 3 -> 27
# Haridwar | schools | Scroll 4 -> 34
# Haridwar | schools | Scroll 5 -> 40
# Haridwar | schools | Scroll 6 -> 47
# Haridwar | schools | Scroll 7 -> 54
# Haridwar | schools | Scroll 8 -> 60
# Haridwar | schools | Scroll 9 -> 67
# Haridwar | schools | Scroll 10 -> 74
# Haridwar | schools | Scroll 11 -> 80
# Haridwar | schools | Scroll 12 -> 87
# Haridwar | schools | Scroll 13 -> 94
# Haridwar | schools | Scroll 14 -> 100
# Haridwar | schools | Scroll 15 -> 107
# Haridwar | schools | Scroll 16 -> 114
# Haridwar | schools | Scroll 17 -> 120
# Haridwar | schools | Scroll 18 -> 120
# Haridwar | schools | Scroll 19 -> 120
# Haridwar | schools | Scroll 20 -> 120
# Haridwar | schools | Scroll 21 -> 120
# Collected 120 links
# Haridwar | 1/120
# Shemrock Riverdale Play School Haridwar .. The best play school in Haridwar
# Udham Singh Nagar | private schools | Scroll 8 -> 60
# Udham Singh Nagar | private schools | Scroll 9 -> 67
# Udham Singh Nagar | private schools | Scroll 10 -> 74
# Udham Singh Nagar | private schools | Scroll 11 -> 80
# Udham Singh Nagar | private schools | Scroll 12 -> 87
# Udham Singh Nagar | private schools | Scroll 13 -> 88
# Udham Singh Nagar | private schools | Scroll 14 -> 88
# Udham Singh Nagar | private schools | Scroll 15 -> 88
# Udham Singh Nagar | private schools | Scroll 16 -> 88
# Udham Singh Nagar | private schools | Scroll 17 -> 88
# Collected 27 links
# Udham Singh Nagar | 1/27
# Samajotthan School
# Udham Singh Nagar | 2/27
# Mother Sitara Academy
# Udham Singh Nagar | 3/27
# Knowledge Park School
# Udham Singh Nagar | 4/27
# Jai Arihant International School
# Udham Singh Nagar | 5/27
# DEVSTHALI VIDYAPEETH
# Udham Singh Nagar | 6/27
# Trinity Modern School
# Udham Singh Nagar | 7/27
# Holy Sapience School
# Udham Singh Nagar | 8/27
# Modern ITI
# Udham Singh Nagar | 9/27
# Jai Arihant Academic Institute
# Udham Singh Nagar | 10/27
# Dev international school rudrapur uttarakhand
# Udham Singh Nagar | 11/27
# CHARLIE--DAANU--HOMTOWN
# Udham Singh Nagar | 12/27
# Droan Group Of Colleges
# Udham Singh Nagar | 13/27
# Bright Future Convent School, Balaji Vihar, Kiratpur
# Udham Singh Nagar | 14/27
# Vidyashree Group of Colleges
# Udham Singh Nagar | 15/27
# Shah Shishu Neketan School
# Udham Singh Nagar | 16/27
# MSK Academy Dineshpur
# Udham Singh Nagar | 17/27
# Prarambha Public School
# Udham Singh Nagar | 18/27
# Kids Paramount school (Kidzee)
# Udham Singh Nagar | 19/27
# Shri Sanatan Dharam Degree College
# Udham Singh Nagar | 20/27
# S.B.Public School
# Udham Singh Nagar | 21/27
# Saraswati Group Of Institutions,Rudrapur
# Udham Singh Nagar | 22/27
# College of Veterinary and Animal Sciences
# Udham Singh Nagar | 23/27
# Shri Guru Teg Bahadur Public School
# Udham Singh Nagar | 24/27
# Global Konnect Aviation Services Pvt Ltd
# Udham Singh Nagar | 25/27
# UCMAS Uttarakhand
# Udham Singh Nagar | 26/27
# NATIONAL BOARD OF COMPUTER EDUCATION (NBCE) KICHHA
# Udham Singh Nagar | 27/27
# Dr Bhabha Bal Shiksha Niketan
#
# Searching: schools in Uttarkashi Uttarakhand
# Search Submitted
# Uttarkashi | schools | Scroll 1 -> 14
# Uttarkashi | schools | Scroll 2 -> 20
# Uttarkashi | schools | Scroll 3 -> 27
# Uttarkashi | schools | Scroll 4 -> 34
# Uttarkashi | schools | Scroll 5 -> 40
# Uttarkashi | schools | Scroll 6 -> 47
# Uttarkashi | schools | Scroll 7 -> 54
# Uttarkashi | schools | Scroll 8 -> 60
# Uttarkashi | schools | Scroll 9 -> 64
# Uttarkashi | schools | Scroll 10 -> 64
# Uttarkashi | schools | Scroll 11 -> 64
# Uttarkashi | schools | Scroll 12 -> 64
# Uttarkashi | 50/63
# Shiv Shakti Sansthan & Computer Education
# Uttarkashi | 51/63
# AADHYA SHANKRACHARYA SHIKSHA SANSTHAN INTER COLLEGE JOSIYARA
# Uttarkashi | 52/63
# KMT Vocational Institute
# Uttarkashi | 53/63
# Azim Premji Foundation District Institute
# Uttarkashi | 54/63
# कोटबगला उत्तरकाशी
# Uttarkashi | 55/63
# Government Inter College
# Uttarkashi | 56/63
# Mary Mata School Chinyalisaur
# Uttarkashi | 57/63
# Ghoomo Uttarakhand | Travel Agency | Char Dham Yatra
# Uttarkashi | 58/63
# Gurji & Sons
# Uttarkashi | 59/63
# Tiny Tots Play School
# Uttarkashi | 60/63
# Joshi Provison Store
# Uttarkashi | 61/63
# Tekhla Rock Climbing Area (NIM)
# Uttarkashi | 62/63
# Swami Vivekananda Foundation School Ganeshpur Uttarkashi
# Uttarkashi | 63/63
# Sai mandir
#
# Searching: CBSE schools in Uttarkashi Uttarakhand
# Search Submitted
# Uttarkashi | CBSE schools | Scroll 1 -> 14
# Uttarkashi | CBSE schools | Scroll 2 -> 17
# Uttarkashi | CBSE schools | Scroll 3 -> 17
# Uttarkashi | CBSE schools | Scroll 4 -> 17
# Uttarkashi | CBSE schools | Scroll 5 -> 17
# Uttarkashi | CBSE schools | Scroll 6 -> 17
# Collected 1 links
# Uttarkashi | 1/1
# Happy by Nature School
#
# Searching: government schools in Uttarkashi Uttarakhand
# Search Submitted
# Uttarkashi | government schools | Scroll 1 -> 14
# Uttarkashi | government schools | Scroll 2 -> 20
# Uttarkashi | government schools | Scroll 3 -> 27
# Uttarkashi | government schools | Scroll 4 -> 29
# Uttarkashi | government schools | Scroll 5 -> 29
# Uttarkashi | government schools | Scroll 6 -> 29
# Uttarkashi | government schools | Scroll 7 -> 29
# Uttarkashi | government schools | Scroll 8 -> 29
# Collected 11 links
# Uttarkashi | 1/11
# Government Primary School
# Uttarkashi | 2/11
# Government Higher Secondary School राजकीय उच्चतर माध्यमिक विद्यालय. (उतरौं-उत्तरकाशी, उत्तराखंड)
# Uttarkashi | 3/11
# Government Primary School, Jaspur
# Uttarkashi | 4/11
# Government Girls Junior High School
# Uttarkashi | 5/11
# Govt. I.T.I Dunda
# Uttarkashi | 6/11
# G I C Sald Uttarkashi
# Uttarkashi | 7/11
# Government Inter College
# Uttarkashi | 8/11
# Govt. Primary School
# Uttarkashi | 9/11
# Government primary school, Bhailuda
# Uttarkashi | 10/11
# Government Primary School, Aleth
# Uttarkashi | 11/11
# PM Shri Govt. Model Inter College Maneri , Uttarkashi
#
# Searching: private schools in Uttarkashi Uttarakhand
# Search Submitted
# Uttarkashi | private schools | Scroll 1 -> 13
# Uttarkashi | private schools | Scroll 2 -> 13
# Uttarkashi | private schools | Scroll 3 -> 13
# Uttarkashi | private schools | Scroll 4 -> 13
# Uttarkashi | private schools | Scroll 5 -> 13
# Collected 0 links
#
# Extraction Completed
# Total Schools Extracted: 1539
#
# Saved File: uttarakhand_schools.csv
