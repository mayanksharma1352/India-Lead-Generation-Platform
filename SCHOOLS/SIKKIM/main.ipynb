# %%
import time
import random
import pandas as pd

from datetime import datetime

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.service import Service

from webdriver_manager.chrome import ChromeDriverManager


districts = [
        "Gangtok",
        "Mangan",
        "Namchi",
        "Pakyong",
        "Soreng",
        "Gyalshing"
]


search_types = [
    "schools"
]


options = webdriver.ChromeOptions()

options.add_argument("--start-maximized")

options.add_argument(
    "--disable-blink-features=AutomationControlled"
)

options.add_argument("--disable-notifications")


driver = webdriver.Chrome(

    service=Service(
        ChromeDriverManager().install()
    ),

    options=options
)


driver.get("https://www.google.com/maps")

print("Opening Google Maps...")

time.sleep(15)

print("Google Maps Loaded")




all_data = []

visited_links = set()


def get_search_box():

    selectors = [

        '//input[@id="searchboxinput"]',
        '//input[contains(@placeholder,"Search")]',
        '//input[contains(@aria-label,"Search")]',
        '//input'

    ]

    for selector in selectors:

        try:

            box = driver.find_element(
                By.XPATH,
                selector
            )

            return box

        except:
            pass

    return None


def extract_school_data():

    try:


        try:
            name = driver.find_element(
                By.TAG_NAME,
                "h1"
            ).text
        except:
            name = ""

        try:
            address = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"address")]'
            ).text
        except:
            address = ""

    
        try:
            phone = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"phone")]'
            ).text
        except:
            phone = ""

        try:
            website = driver.find_element(
                By.XPATH,
                '//a[contains(@data-item-id,"authority")]'
            ).get_attribute("href")
        except:
            website = ""

        try:
            rating = driver.find_element(
                By.XPATH,
                '//div[@role="img"]'
            ).get_attribute("aria-label")
        except:
            rating = ""

        return {

            "School Name": name,
            "Address": address,
            "Phone": phone,
            "Website": website,
            "Rating": rating,
            "Google Maps URL": driver.current_url

        }

    except:

        return None



for district in districts:

    for search_type in search_types:

        try:

            query = (
                f"{search_type} "
                f"in {district} Sikkim"
            )

            print(f"\nSearching: {query}")


            search_box = get_search_box()

            if not search_box:

                print("Search Box Not Found")

                continue

            ActionChains(driver).move_to_element(
                search_box
            ).click().perform()

            time.sleep(1)

            search_box.send_keys(
                Keys.CONTROL + "a"
            )

            time.sleep(1)

            search_box.send_keys(Keys.DELETE)

            time.sleep(1)

         
            for char in query:

                search_box.send_keys(char)

                time.sleep(0.03)

            search_box.send_keys(Keys.ENTER)

            print("Search Submitted")

            time.sleep(8)

  

            try:

                scrollable_div = driver.find_element(
                    By.XPATH,
                    '//div[@role="feed"]'
                )

                previous_count = 0

                stagnant = 0

                for i in range(100):

                    driver.execute_script(
                        """
                        arguments[0].scrollTop =
                        arguments[0].scrollHeight
                        """,
                        scrollable_div
                    )

                    time.sleep(4)

                    listings = driver.find_elements(
                        By.XPATH,
                        '//a[contains(@href,"/maps/place/")]'
                    )

                    current_count = len(listings)

                    print(
                        f"{district} | "
                        f"{search_type} | "
                        f"Scroll {i+1} -> "
                        f"{current_count}"
                    )

                    if current_count == previous_count:

                        stagnant += 1

                    else:

                        stagnant = 0

                    if stagnant >= 4:

                        break

                    previous_count = current_count

            except Exception as e:

                print(f"Scrolling Error: {e}")


            listings = driver.find_elements(
                By.XPATH,
                '//a[contains(@href,"/maps/place/")]'
            )

            links = []

            for listing in listings:

                try:

                    link = listing.get_attribute("href")

                    if (
                        link
                        and link not in visited_links
                    ):

                        links.append(link)

                        visited_links.add(link)

                except:
                    pass

            print(f"Collected {len(links)} links")

 

            for index, link in enumerate(links):

                try:

                    print(
                        f"{district} | "
                        f"{index+1}/{len(links)}"
                    )

                    driver.get(link)

                    time.sleep(
                        random.uniform(2, 3)
                    )

                    data = extract_school_data()

                    if data:

                        data["District"] = district

                        data["Search Type"] = search_type

                        all_data.append(data)

                        print(data["School Name"])



                    if len(all_data) % 100 == 0:

                        backup_df = pd.DataFrame(
                            all_data
                        )

                        backup_df.drop_duplicates(
                            subset=[
                                "School Name",
                                "Google Maps URL"
                            ],
                            inplace=True
                        )

                        backup_df.to_csv(
                            "sikkim_schools_backup.csv",
                            index=False
                        )

                        print("Backup Saved")

                except Exception as e:

                    print(
                        f"School Error: {e}"
                    )

        except Exception as e:

            print(
                f"District Error: {e}"
            )




df = pd.DataFrame(all_data)

df.drop_duplicates(

    subset=[
        "School Name",
        "Google Maps URL"
    ],

    inplace=True
)

filename = (
    f"sikkim_schools.csv"
)

df.to_csv(
    filename,
    index=False
)

print("\nExtraction Completed")

print(
    f"Total Schools Extracted: {len(df)}"
)

print(f"\nSaved File: {filename}")

driver.quit()
# Out:
# Opening Google Maps...
# Google Maps Loaded
#
# Searching: schools in Gangtok Sikkim
# Search Submitted
# Gangtok | schools | Scroll 1 -> 14
# Gangtok | schools | Scroll 2 -> 20
# Gangtok | schools | Scroll 3 -> 27
# Gangtok | schools | Scroll 4 -> 34
# Gangtok | schools | Scroll 5 -> 40
# Gangtok | schools | Scroll 6 -> 47
# Gangtok | schools | Scroll 7 -> 54
# Gangtok | schools | Scroll 8 -> 60
# Gangtok | schools | Scroll 9 -> 67
# Gangtok | schools | Scroll 10 -> 68
# Gangtok | schools | Scroll 11 -> 68
# Gangtok | schools | Scroll 12 -> 68
# Gangtok | schools | Scroll 13 -> 68
# Gangtok | schools | Scroll 14 -> 68
# Collected 68 links
# Gangtok | 1/68
# Tashi Namgyal Academy
# Gangtok | 2/68
# Rey Valley International School
# Gangtok | 3/68
# Sir Tashi Namgyal Senior Secondary School
# Gangtok | 4/68
# Paljor Namgyal Girls' School
# Gangtok | 5/68
# West Point Senior Secondary School
# Gangtok | 6/68
# Greendale Senior Secondary School
# Gangtok | 7/68
# Taktse International School
# Gangtok | 8/68
# Army Public School
# Gangtok | 9/68
# Holy Cross School
# Gangtok | 10/68
# Manjusri Public School
# Gangtok | 11/68
# KENDRIYA VIDYALAYA GANGTOK
# Gangtok | 12/68
# Daffodils Home Secondary School
# Gangtok | 13/68
# Bahá'í school
# Gangtok | 14/68
# Amitabha School
# Gangtok | 15/68
# Little Pixies International School
# Gangtok | 16/68
# Pentagon Academy Bhanu Gram
# Gangtok | 17/68
# Modern Government Sr. Sec. School
# Gangtok | 18/68
# Taktse International School
# Gangtok | 19/68
# Neil Tara Academy
# Gangtok | 20/68
# Tathangchen Secondary School
# Gangtok | 21/68
# AVM School, Asmita Vidhya Mandir School
# Gangtok | 22/68
# Kyi De Khang Sr Secondary School
# Gangtok | 23/68
# Prashanti Vidya Mandir
# Mangan | 5/9
# Marigold Public School Mangshila ( North- Sikkim)
# Mangan | 6/9
# Eklavya Model Residential School
# Mangan | 7/9
# Govt Sr. Secondary School
# Mangan | 8/9
# Government Girls Senior Secondary School
# Mangan | 9/9
# GovtSecondary School
#
# Searching: schools in Namchi Sikkim
# Search Submitted
# Namchi | schools | Scroll 1 -> 14
# Namchi | schools | Scroll 2 -> 14
# Namchi | schools | Scroll 3 -> 14
# Namchi | schools | Scroll 4 -> 14
# Namchi | schools | Scroll 5 -> 14
# Collected 14 links
# Namchi | 1/14
# Ark Academy, Namchi
# Namchi | 2/14
# Below New Light Academy School, Near ht. Montana V
# Namchi | 3/14
# NAmchi Public School
# Namchi | 4/14
# Tendong Educational Institute
# Namchi | 5/14
# Mount Carmel School
# Namchi | 6/14
# NAMCHI VIDHYA NILAYAM SCHOOL
# Namchi | 7/14
# J M K Memorial School
# Namchi | 8/14
# Seven Hills School
# Namchi | 9/14
# Goverment Senior Secondary School, Namchi
# Namchi | 10/14
# Bethany School, Kazitar Namchi S. Sikkim
# Namchi | 11/14
# UDICHI ELEMENTARY SCHOOL
# Namchi | 12/14
# Government Primary School
# Namchi | 13/14
# BETHEL ACADEMY, Boomtar, Namchi
# Namchi | 14/14
# Government Girls Senior Secondary School
#
# Searching: schools in Pakyong Sikkim
# Search Submitted
# Pakyong | schools | Scroll 1 -> 10
# Pakyong | schools | Scroll 2 -> 15
# Pakyong | schools | Scroll 3 -> 20
# Pakyong | schools | Scroll 4 -> 25
# Pakyong | schools | Scroll 5 -> 27
# Pakyong | schools | Scroll 6 -> 27
# Pakyong | schools | Scroll 7 -> 27
# Pakyong | schools | Scroll 8 -> 27
# Pakyong | schools | Scroll 9 -> 27
# Collected 24 links
# Pakyong | 1/24
# St. Xaviers School
# Pakyong | 2/24
# School
# Pakyong | 3/24
# Ark Academy Namcheybong
# Pakyong | 4/24
# Pundarika Public School
# Pakyong | 5/24
# Gurukul School Pakyong
# Pakyong | 6/24
# Samsing Primary School
# Pakyong | 7/24
# Pakyong Bazar Government Secondary School
# Pakyong | 8/24
# El Bethel Academy
# Pakyong | 9/24
# chalamthang I.C.D.S
# Backup Saved
# Pakyong | 10/24
# Jawahar Navodaya Vidyalaya East Sikkim
# Pakyong | 11/24
# Puspanjali Vidyalaya
# Pakyong | 12/24
# Pakyong Music Institute
# Pakyong | 13/24
# Dugalakha school
# Pakyong | 14/24
# Government Primary School, Lower Bering
# Pakyong | 15/24
# Pakyong Market
# Pakyong | 16/24
# Pachey samsing pry school
# Pakyong | 17/24
# Studio Maato, Pakyong
# Pakyong | 18/24
# Pakyong
# Pakyong | 19/24
# Kartok Primary School
# Pakyong | 20/24
# 4th mile
# Pakyong | 21/24
# Government Senior Secondary School
# Pakyong | 22/24
# Budang Central pendam ,Pakyong district
# Pakyong | 23/24
# Education
# Pakyong | 24/24
# Ralung ICDS
#
# Searching: schools in Soreng Sikkim
# Search Submitted
# Soreng | schools | Scroll 1 -> 14
# Soreng | schools | Scroll 2 -> 15
# Soreng | schools | Scroll 3 -> 15
# Soreng | schools | Scroll 4 -> 15
# Soreng | schools | Scroll 5 -> 15
# Soreng | schools | Scroll 6 -> 15
# Collected 15 links
# Soreng | 1/15
# Soreng Senior Secondary School
# Soreng | 2/15
# Tender Feet Academy
# Soreng | 3/15
# Soreng District
# Soreng | 4/15
# Khaneysirbong school
# Soreng | 5/15
# Singling Junior High School
# Soreng | 6/15
# Sikkim Government B.Ed College, Soreng
# Soreng | 7/15
# Soreng SSS Playground
# Soreng | 8/15
# Ken High School
# Soreng | 9/15
# GOVERNMENT PRIMARY SCHOOL MOONEW
# Soreng | 10/15
# Soreng Singling
# Soreng | 11/15
# pahalman kami
# Soreng | 12/15
# Near lillium acadamy primary school singling
# Soreng | 13/15
# Government Junior High School
# Soreng | 14/15
# Woodstock High School
# Soreng | 15/15
# Hoogoaw, mangalbarey
#
# Searching: schools in Gyalshing Sikkim
# Search Submitted
# Gyalshing | schools | Scroll 1 -> 14
# Gyalshing | schools | Scroll 2 -> 20
# Gyalshing | schools | Scroll 3 -> 22
# Gyalshing | schools | Scroll 4 -> 22
# Gyalshing | schools | Scroll 5 -> 22
# Gyalshing | schools | Scroll 6 -> 22
# Gyalshing | schools | Scroll 7 -> 22
# Collected 22 links
# Gyalshing | 1/22
# Middle Gyalshing Sec School
# Gyalshing | 2/22
# Government Secondary School
# Gyalshing | 3/22
# Girls' Senior Secondary School, Kyongsha
# Gyalshing | 4/22
# Byadung School
# Gyalshing | 5/22
# Nova Bliss English School
# Gyalshing | 6/22
# Geyzing Malbassey Primary School
# Gyalshing | 7/22
# Legship Senior Secondary school
# Gyalshing | 8/22
# St Marys Convent School
# Gyalshing | 9/22
# Noble English School
# Gyalshing | 10/22
# Government Industrial Training Institute
# Gyalshing | 11/22
# Langang Secondary School
# Gyalshing | 12/22
# St. Xavier's English Medium School Tikjuk Zero Point West Sikkim
# Gyalshing | 13/22
# Govt. Senior Secondary School Kamling
# Gyalshing | 14/22
# Govt. Primary school, Toyang
# Gyalshing | 15/22
# CHUMANG PRIMARY SCHOOL
# Gyalshing | 16/22
# Geyzing Malbassey Ps
# Gyalshing | 17/22
# Omchung Junior High School
# Gyalshing | 18/22
# Govt. Senior Secondary School, Geyzing
# Gyalshing | 19/22
# Govt. Senior Secondary School
# Gyalshing | 20/22
# Kidzee Pre School
# Gyalshing | 21/22
# RAY OF HOPE ACADEMY, Thingling
# Gyalshing | 22/22
# Kidzee Globus International Schoo
#
# Extraction Completed
# Total Schools Extracted: 152
#
# Saved File: sikkim_schools.csv
