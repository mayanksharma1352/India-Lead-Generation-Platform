# %%
import pandas as pd

# %%
df = pd.read_csv("sikkim_schools.csv")

# %%
df.shape
# Out:
# (152, 8)

# %%
duplicate_count = df.duplicated(
    subset=["School Name", "Google Maps URL"]
).sum()
duplicate_count
# Out:
# np.int64(0)

# %%
df = df[
    df["Phone"].notna() & 
    (df["Phone"].astype(str).str.strip() != "")
    ]
df.shape
# Out:
# (11, 8)

# %%
df = df[
    df["School Name"].notna()
    ]

df = df[
    df["School Name"].str.strip() != ""
    ]

# %%
df.shape
# Out:
# (11, 8)

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]","",regex=True)
    .str.strip()
)

display(df[["Phone"]].head())
# Out:
#             Phone
# 10  03592 232 646
# 23   097331 87407
# 43   093325 21226
# 48  03592 284 518
# 60   098320 12883

# %%
df.to_csv(
    "sikkim_schools_cleaned.csv",
    index=False
)
