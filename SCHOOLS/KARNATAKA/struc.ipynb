# %%
import pandas as pd

# %%
df = pd.read_csv("karnataka_schools.csv")

# %%
df.shape
# Out:
# (1433, 8)

# %%
duplicate_count = df.duplicated(
    subset=["School Name", "Google Maps URL"]
).sum()
duplicate_count
# Out:
# np.int64(0)

# %%
df = df[
    df["Phone"].notna() & 
    (df["Phone"].astype(str).str.strip() != "")
    ]
df.shape
# Out:
# (486, 8)

# %%
df = df[
    df["School Name"].notna()
    ]

df = df[
    df["School Name"].str.strip() != ""
    ]
df.shape
# Out:
# (486, 8)

# %%
# CLEAN PHONE COLUMNS
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]","",regex=True)
    .str.strip()
)

display(df[["Phone"]].head())
# Out:
#           Phone
# 1  083752 36915
# 2  083752 36618
# 3  095131 88749
# 4  089040 20309
# 5  094806 96165

# %%
# SAVE CLEANED FILE
df.to_csv(
    "karnataka_schools_cleaned.csv",
    index=False
)
