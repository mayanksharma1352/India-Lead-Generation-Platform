# %%
import time
import random
import pandas as pd

from datetime import datetime

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.service import Service

from webdriver_manager.chrome import ChromeDriverManager


districts = [
    
    "Tumakuru",
    "Udupi",
    "Uttara Kannada",
    "Vijayapura",
    "Yadgir"
]
  


search_types = [
    "schools"
]


options = webdriver.ChromeOptions()

options.add_argument("--start-maximized")

options.add_argument(
    "--disable-blink-features=AutomationControlled"
)

options.add_argument("--disable-notifications")

driver = webdriver.Chrome(

    service=Service(
        ChromeDriverManager().install()
    ),

    options=options
)


driver.get("https://www.google.com/maps")

print("Opening Google Maps...")

time.sleep(15)

print("Google Maps Loaded")


all_data = []

visited_links = set()




def get_search_box():

    selectors = [

        '//input[@id="searchboxinput"]',
        '//input[contains(@placeholder,"Search")]',
        '//input[contains(@aria-label,"Search")]',
        '//input'

    ]

    for selector in selectors:

        try:

            box = driver.find_element(
                By.XPATH,
                selector
            )

            return box

        except:
            pass

    return None


def extract_school_data():

    try:

        try:
            name = driver.find_element(
                By.TAG_NAME,
                "h1"
            ).text
        except:
            name = ""

        try:
            address = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"address")]'
            ).text
        except:
            address = ""

 
        try:
            phone = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"phone")]'
            ).text
        except:
            phone = ""

    
        try:
            website = driver.find_element(
                By.XPATH,
                '//a[contains(@data-item-id,"authority")]'
            ).get_attribute("href")
        except:
            website = ""

        try:
            rating = driver.find_element(
                By.XPATH,
                '//div[@role="img"]'
            ).get_attribute("aria-label")
        except:
            rating = ""

        return {

            "School Name": name,
            "Address": address,
            "Phone": phone,
            "Website": website,
            "Rating": rating,
            "Google Maps URL": driver.current_url

        }

    except:

        return None



for district in districts:

    for search_type in search_types:

        try:

            query = (
                f"{search_type} "
                f"in {district} Karnataka"
            )

            print(f"\nSearching: {query}")



            search_box = get_search_box()

            if not search_box:

                print("Search Box Not Found")

                continue

            ActionChains(driver).move_to_element(
                search_box
            ).click().perform()

            time.sleep(1)

            search_box.send_keys(
                Keys.CONTROL + "a"
            )

            time.sleep(1)

            search_box.send_keys(Keys.DELETE)

            time.sleep(1)

            for char in query:

                search_box.send_keys(char)

                time.sleep(0.03)

            search_box.send_keys(Keys.ENTER)

            print("Search Submitted")

            time.sleep(8)


            try:

                scrollable_div = driver.find_element(
                    By.XPATH,
                    '//div[@role="feed"]'
                )

                previous_count = 0

                stagnant = 0

                for i in range(100):

                    driver.execute_script(
                        """
                        arguments[0].scrollTop =
                        arguments[0].scrollHeight
                        """,
                        scrollable_div
                    )

                    time.sleep(4)

                    listings = driver.find_elements(
                        By.XPATH,
                        '//a[contains(@href,"/maps/place/")]'
                    )

                    current_count = len(listings)

                    print(
                        f"{district} | "
                        f"{search_type} | "
                        f"Scroll {i+1} -> "
                        f"{current_count}"
                    )

                    if current_count == previous_count:

                        stagnant += 1

                    else:

                        stagnant = 0

                    if stagnant >= 4:

                        break

                    previous_count = current_count

            except Exception as e:

                print(f"Scrolling Error: {e}")


            listings = driver.find_elements(
                By.XPATH,
                '//a[contains(@href,"/maps/place/")]'
            )

            links = []

            for listing in listings:

                try:

                    link = listing.get_attribute("href")

                    if (
                        link
                        and link not in visited_links
                    ):

                        links.append(link)

                        visited_links.add(link)

                except:
                    pass

            print(f"Collected {len(links)} links")


            for index, link in enumerate(links):

                try:

                    print(
                        f"{district} | "
                        f"{index+1}/{len(links)}"
                    )

                    driver.get(link)

                    time.sleep(
                        random.uniform(2, 3)
                    )

                    data = extract_school_data()

                    if data:

                        data["District"] = district

                        data["Search Type"] = search_type

                        all_data.append(data)

                        print(data["School Name"])


                    if len(all_data) % 100 == 0:

                        backup_df = pd.DataFrame(
                            all_data
                        )

                        backup_df.drop_duplicates(
                            subset=[
                                "School Name",
                                "Google Maps URL"
                            ],
                            inplace=True
                        )

                        backup_df.to_csv(
                            "karnataka_schools_backup.csv",
                            index=False
                        )

                        print("Backup Saved")

                except Exception as e:

                    print(
                        f"School Error: {e}"
                    )

        except Exception as e:

            print(
                f"District Error: {e}"
            )



new_df = pd.DataFrame(all_data)

new_df.drop_duplicates(

    subset=[
        "School Name",
        "Google Maps URL"
    ],

    inplace=True
)



old_file = (
    f"karnataka_schools.csv"
)

try:
    old_df = pd.read_csv(old_file)

    final_df = pd.concat(
        [old_df, new_df],
        ignore_index=True
    )

    final_df.drop_duplicates(
        subset=[
            "School Name",
            "Google Maps URL"
        ],
        inplace=True
    )
except:
    final_df = new_df
            

final_df.to_csv(
    old_file,
    index=False
)

print("\nExtraction Completed")

print(
    f"Total Schools Extracted: {len(final_df)}"
)

print(f"\nSaved File: {filename}")

driver.quit()
# Out:
# Opening Google Maps...
# Google Maps Loaded
#
# Searching: schools in Tumakuru Karnataka
# Search Submitted
# Tumakuru | schools | Scroll 1 -> 14
# Tumakuru | schools | Scroll 2 -> 20
# Tumakuru | schools | Scroll 3 -> 27
# Tumakuru | schools | Scroll 4 -> 34
# Tumakuru | schools | Scroll 5 -> 40
# Tumakuru | schools | Scroll 6 -> 47
# Tumakuru | schools | Scroll 7 -> 54
# Tumakuru | schools | Scroll 8 -> 60
# Tumakuru | schools | Scroll 9 -> 67
# Tumakuru | schools | Scroll 10 -> 74
# Tumakuru | schools | Scroll 11 -> 80
# Tumakuru | schools | Scroll 12 -> 87
# Tumakuru | schools | Scroll 13 -> 94
# Tumakuru | schools | Scroll 14 -> 100
# Tumakuru | schools | Scroll 15 -> 107
# Tumakuru | schools | Scroll 16 -> 114
# Tumakuru | schools | Scroll 17 -> 120
# Tumakuru | schools | Scroll 18 -> 120
# Tumakuru | schools | Scroll 19 -> 120
# Tumakuru | schools | Scroll 20 -> 120
# Tumakuru | schools | Scroll 21 -> 120
# Collected 120 links
# Tumakuru | 1/120
# ORCHIDS The International School - Tumkur - CBSE - Affiliation No. 831628
# Tumakuru | 2/120
# Narayana eTechno (CBSE) School - Tumkur
# Tumakuru | 3/120
# Podar International School Tumakuru (CBSE)
# Tumakuru | 4/120
# Arivu International school | I.D.S.M.T Layout | Tumakuru
# Tumakuru | 5/120
# Clarence English School
# Tumakuru | 6/120
# Jain Public School Tumkur
# Tumakuru | 7/120
# Maruthi International School || Siddaganga Extension || Thumkur
# Tumakuru | 8/120
# Toddler's Castle Pre School || Ring Road || Tumakuru
# Tumakuru | 9/120
# Anikethana Vidya Mandira, Behind Jain Temple, Sira Gate, Tumkuru
# Tumakuru | 10/120
# Bachpan Play School, Tumakuru
# Tumakuru | 11/120
# Bishop Sargant School & College
# Tumakuru | 12/120
# EuroKids PreSchool in Adarashanagara, Tumakuru
# Tumakuru | 13/120
# Sri Chaitanya Techno School
# Tumakuru | 14/120
# Jawahar Navodaya Vidyalaya Tumakuru
# Tumakuru | 15/120
# Vidya College || Tumkur
# Tumakuru | 16/120
# Empress Girls Govt. High School
# Tumakuru | 17/120
# Siddaganga High School || Ward No 18 || Thumkur
# Tumakuru | 18/120
# Varin International Residential school and college
# Tumakuru | 19/120
# Daffodils English School || Siddalingaihna Palya || Thumkur
# Tumakuru | 20/120
# Kids Universe Pre School And Day Care
# Tumakuru | 21/120
# Little Millennium Preschool - Tumkur, Tumakuru
# Tumakuru | 22/120
# Podar Prep Preschool And Daycare Ashoka Nagar, Tumkur | Best Preschool In Ashoka Nagar
# Tumakuru | 23/120
# Maruthi Public School - best school Tumkur city
# Tumakuru | 24/120
# Vidyaniketan Nursery and Primary School || Near Railway Station || Thumkur
# Tumakuru | 25/120
# Prudence International School
# Tumakuru | 26/120
# Chethana Vidya Mandira || Horpet || Thumkur
# Tumakuru | 27/120
# Austin Kidz School || Shrinidhi Layout || Thumkur
# Tumakuru | 28/120
# Ali Public School || Jamia Nagar || Tumakuru
# Tumakuru | 29/120
# Tumkur School of Music
# Tumakuru | 30/120
# Shri Basaveshwara Public School || Kyathasandra || Thumkur
# Tumakuru | 31/120
# Kendriya Vidyalaya
# Tumakuru | 32/120
# Green Berg International School || Bugudanahalli || Thumkur
# Tumakuru | 33/120
# Junior Toes International Pre School - Tumkur Adarsha Nagar
# Tumakuru | 34/120
# Mathi Play School || Sapthagiri Extension || Thumkur
# Tumakuru | 35/120
# EuroKids PreSchool in Dasappa Garden, Tumakuru
# Tumakuru | 36/120
# Kids International School || Daasappa Garden || Thumkur
# Tumakuru | 37/120
# Nalanda Convent & High School
# Tumakuru | 38/120
# S.V.S Public School Tumkur
# Tumakuru | 39/120
# Kids International School, Bellavi, TUMKUR
# Tumakuru | 40/120
# FirstCry Intellitots Preschool & Daycare - Ashok Nagar 8th Cross Road Tumkur, Tumkur
# Tumakuru | 41/120
# EuroKids Sharadadevi Nagar, Tumkur
# Tumakuru | 42/120
# Hello Kids - Chanakya, Upparahalli, Tumakuru
# Tumakuru | 43/120
# Aryan High School || Mandipet || Thumkur
# Tumakuru | 44/120
# Sri Chaitanya School
# Tumakuru | 45/120
# Chethana Vidya Mandira, Batawadi
# Tumakuru | 46/120
# Saint Mary's CBSE Senior Secondary School || A.P.M.C Yard || Batawadi
# Tumakuru | 47/120
# Castle School Of Life Skills || Siddaganga Extension || Thumkur
# Tumakuru | 48/120
# THE NEW PUBLIC SCHOOL
# Tumakuru | 49/120
# TVS School, Pandithanahlli
# Tumakuru | 50/120
# Sri Chaitanya school
# Tumakuru | 51/120
# Bapuji High School || Ward No 18 || Thumkur
# Tumakuru | 52/120
# Shri Renuka Vidya Peetha School || Ward No 18 || Thumkur
# Tumakuru | 53/120
# Government Primary School || Ward No 18 || Thumkur
# Tumakuru | 54/120
# Govt Junior College Tumkur
# Tumakuru | 55/120
# Sofiya English School || Upparahalli || Tumkuru
# Tumakuru | 56/120
# Bharath Matha English Medium School || Thumkur
# Tumakuru | 57/120
# Kempegowda Residential School || Belagumba Road || Thumkur
# Tumakuru | 58/120
# Government High School
# Tumakuru | 59/120
# Siraa Get Tumkur Hindustan High School
# Tumakuru | 60/120
# The Presidency Public School
# Tumakuru | 61/120
# SGR English Medium School
# Tumakuru | 62/120
# Shubhodaya Higher Primary School Horpet Tumkur
# Tumakuru | 63/120
# Sarvodaya Boys High School || S.S Puram || Thumkur
# Tumakuru | 64/120
# Wow Kids Gurukul || Ashok Nagar || Tumakur
# Tumakuru | 65/120
# Orkids Preschool & Higher Primary School
# Tumakuru | 66/120
# Sri SathyaSai International School
# Tumakuru | 67/120
# BALC BH Road Tumkur Computer Education Center.
# Tumakuru | 68/120
# Vivekananda English School
# Tumakuru | 69/120
# Sacred Heart International Science & Techno School Dhobhighat
# Tumakuru | 70/120
# Prudence Pre School
# Tumakuru | 71/120
# Sheshadhri Puram School || Jayanagar South || Thumkur
# Tumakuru | 72/120
# Indira Higher Primary and High School
# Tumakuru | 73/120
# IDES Pre-School
# Tumakuru | 74/120
# CREATIVE BOX ART STUDIO
# Tumakuru | 75/120
# Someshwara Girls High School || C.B Nagar || Thumkur
# Tumakuru | 76/120
# Roots Abacus Learning School
# Tumakuru | 77/120
# Shri Siddhartha Residential School || P.H Colony || Thumkur
# Tumakuru | 78/120
# A.R English School
# Tumakuru | 79/120
# Government School
# Tumakuru | 80/120
# TUMKUR BADMINTON ACADEMY
# Tumakuru | 81/120
# Time Kids Pre School || Upparahalli Extension || Thumkur
# Tumakuru | 82/120
# Kaveri School || Shanthi Nagar || Thumkur
# Tumakuru | 83/120
# Lil Light House Pre School || Tapovanam || Thumkur
# Tumakuru | 84/120
# Step Up Tumkur
# Tumakuru | 85/120
# Sarvodaya Nursery & Primary School || Vijaynagar || Thumkur
# Tumakuru | 86/120
# Kalarava montessori school
# Tumakuru | 87/120
# Valmiky High school
# Tumakuru | 88/120
# Saint Moses English School || Hanumanthapura || Thumkur
# Tumakuru | 89/120
# TUMKUR CHESS Academy
# Tumakuru | 90/120
# Sri Raghavendra International School
# Tumakuru | 91/120
# Sacred Heart School || Upparahalli || Thumkur
# Tumakuru | 92/120
# Sri Chaitanya PU College
# Tumakuru | 93/120
# American Concept Pr School
# Tumakuru | 94/120
# S.V.K High school || S.S Puram || Thumkur
# Tumakuru | 95/120
# Oxford School || Devaraaya Pattana || Thumkur
# Tumakuru | 96/120
# Benaka Dresses | School Uniforms | Uniform Shop in Tumkur
# Tumakuru | 97/120
# Lourdumatha Public School || Ward No 18 || Thumkur
# Tumakuru | 98/120
# Kannada Primary School
# Tumakuru | 99/120
# BASAVE GOWDA GC SS PURAM TUMAKURU
# Tumakuru | 100/120
# Government High School || C.S.I Layout || Thumkur
# Backup Saved
# Tumakuru | 101/120
# Sangeeth School of Music || Instrumental Store Recording Studio || Thumkur
# Tumakuru | 102/120
# GHPS Upparahalli - Tumkur Round Table 173 School
# Tumakuru | 103/120
# Urdu School Main Road 1cross Shirani Garden
# Tumakuru | 104/120
# Sri Ranga Vidya Mandira, Primary, Higher Primary, High School (ENGLISH MEDIUM)
# Tumakuru | 105/120
# Kalarava Kids Zone
# Tumakuru | 106/120
# Carmel English School || Batawadi || Thumkur
# Tumakuru | 107/120
# Sarvodaya High School Field
# Tumakuru | 108/120
# Sri Siddi Vinayaka Driving school Ashoka nagara 9 th cross opp RTO office road Down B H road tumakur
# Tumakuru | 109/120
# Sree siddaganga rural high school
# Tumakuru | 110/120
# Akshay Sunil's Rhythm Nation Dance & Fitness Studio
# Tumakuru | 111/120
# Sree Siddaganga Education Society(R)
# Tumakuru | 112/120
# Silver jublee memorable demonstration high school
# Tumakuru | 113/120
# Maruthi Vidya Kendra Belagumba
# Tumakuru | 114/120
# PONI KIDS pre primary school
# Tumakuru | 115/120
# Green Kids
# Tumakuru | 116/120
# Success Academy
# Tumakuru | 117/120
# Cordial international school. Day and residential.
# Tumakuru | 118/120
# SMART CLASSROOM - Government High School
# Tumakuru | 119/120
# Sri Banashankari Motor Driving School
# Tumakuru | 120/120
# Government high Primary school Kotithopu
#
# Searching: schools in Udupi Karnataka
# Search Submitted
# Udupi | schools | Scroll 1 -> 14
# Udupi | schools | Scroll 2 -> 20
# Udupi | schools | Scroll 3 -> 27
# Udupi | schools | Scroll 4 -> 34
# Udupi | schools | Scroll 5 -> 40
# Udupi | schools | Scroll 6 -> 47
# Udupi | schools | Scroll 7 -> 54
# Udupi | schools | Scroll 8 -> 60
# Udupi | schools | Scroll 9 -> 67
# Udupi | schools | Scroll 10 -> 74
# Udupi | schools | Scroll 11 -> 80
# Udupi | schools | Scroll 12 -> 87
# Udupi | schools | Scroll 13 -> 94
# Udupi | schools | Scroll 14 -> 100
# Udupi | schools | Scroll 15 -> 107
# Udupi | schools | Scroll 16 -> 114
# Udupi | schools | Scroll 17 -> 120
# Udupi | schools | Scroll 18 -> 120
# Udupi | schools | Scroll 19 -> 120
# Udupi | schools | Scroll 20 -> 120
# Udupi | schools | Scroll 21 -> 120
# Collected 120 links
# Udupi | 1/120
# Podar International School Udupi (CBSE)
# Udupi | 2/120
# Lords International Residential School
# Udupi | 3/120
# Silas International School
# Udupi | 4/120
# Kadiyali English Medium School
# Udupi | 5/120
# G M Global School
# Udupi | 6/120
# St Mary's English Medium (CBSE) School, Udupi
# Udupi | 7/120
# School Book Udupi
# Udupi | 8/120
# Sharada Residential School, Kunjibettu
# Udupi | 9/120
# Ishna Playschool
# Udupi | 10/120
# Eurokids Pre-School Udupi
# Udupi | 11/120
# Madhava Kripa School
# Udupi | 12/120
# Uttara Kannada | 91/94
# Vidyasannidhi Tutorials
# Uttara Kannada | 92/94
# Shriram Motor Driving School Sirsi
# Uttara Kannada | 93/94
# Morarji Desai Residential School Kalathur Kuthyaru
# Uttara Kannada | 94/94
# stanthony primary school
#
# Searching: schools in Vijayapura Karnataka
# Search Submitted
# Vijayapura | schools | Scroll 1 -> 14
# Vijayapura | schools | Scroll 2 -> 20
# Vijayapura | schools | Scroll 3 -> 27
# Vijayapura | schools | Scroll 4 -> 34
# Vijayapura | schools | Scroll 5 -> 40
# Vijayapura | schools | Scroll 6 -> 47
# Vijayapura | schools | Scroll 7 -> 54
# Vijayapura | schools | Scroll 8 -> 60
# Vijayapura | schools | Scroll 9 -> 67
# Vijayapura | schools | Scroll 10 -> 74
# Vijayapura | schools | Scroll 11 -> 80
# Vijayapura | schools | Scroll 12 -> 87
# Vijayapura | schools | Scroll 13 -> 94
# Vijayapura | schools | Scroll 14 -> 100
# Vijayapura | schools | Scroll 15 -> 107
# Vijayapura | schools | Scroll 16 -> 114
# Vijayapura | schools | Scroll 17 -> 120
# Vijayapura | schools | Scroll 18 -> 120
# Vijayapura | schools | Scroll 19 -> 120
# Vijayapura | schools | Scroll 20 -> 120
# Vijayapura | schools | Scroll 21 -> 120
# Collected 120 links
# Vijayapura | 1/120
# PRARTHANA PUBLIC SCHOOL
# Vijayapura | 2/120
# Shantiniketan International School (CBSE)
# Vijayapura | 3/120
# Nalanda School Of Intellectuals
# Vijayapura | 4/120
# Sainik School Bijapur
# Vijayapura | 5/120
# ACT Sharada Public School Vijayapur
# Vijayapura | 6/120
# Kendriya Vidyalaya Vijayapura
# Vijayapura | 7/120
# St Josephs School
# Vijayapura | 8/120
# SHRI GURUDEV INTERNATIONAL PUBLIC SCHOOL
# Vijayapura | 9/120
# Delhi Public School Vijayapura
# Vijayapura | 10/120
# BIJAPUR MONTESSORI SCHOOL
# Vijayapura | 11/120
# Cubs-The Pre School
# Vijayapura | 12/120
# Cubs-The Pre School, Jalnagar Branch
# Vijayapura | 13/120
# Tungal Independent PU Science College & CBSE Schools
# Vijayapura | 14/120
# ARJ International - The Futuristic School, (School Campus)
# Vijayapura | 15/120
# Prerana Public School | Prerana Group of Institutions
# Vijayapura | 16/120
# EuroKids Pre-School Athani Road
# Vijayapura | 17/120
# Sri B. M. Patil Public School
# Vijayapura | 18/120
# Seva Academy
# Vijayapura | 19/120
# Little Elly - Preschool in Vijayapura, Bengaluru
# Vijayapura | 20/120
# Anubhav The play school
# Vijayapura | 21/120
# Banjara High School
# Vijayapura | 22/120
# VB Darbar Campus
# Vijayapura | 23/120
# Shri Sanganabasava Shishuniketana School
# Vijayapura | 24/120
# Shri Rukmangada High School
# Vijayapura | 25/120
# SB WISDOM CAREER ACADEMY VIJAYAPUR
# Vijayapura | 26/120
# Kalidas School And College
# Vijayapura | 27/120
# HELLO KIDS - HAPPY PRE SCHOOL
# Vijayapura | 28/120
# Shriram Vidyaniketan School Bijapur
# Vijayapura | 29/120
# Geetanjali English Medium High School
# WOW KIDS Busy Bees
# Vijayapura | 83/120
# Excellent PU Science College Vijayapura
# Vijayapura | 84/120
# Fatimah International English Medium CBSe School
# Vijayapura | 85/120
# VED ACADEMY ENGLISH MEDIUM HIGH SCHOOL
# Vijayapura | 86/120
# Shri rabindranath tagore school and PU Science college vijaypur
# Vijayapura | 87/120
# Iris Wisdom Academy - Kindergarten, Pre- Primary & Primary School
# Vijayapura | 88/120
# Little orchids international pre school
# Vijayapura | 89/120
# Padmavati School Vijayapura
# Vijayapura | 90/120
# ROYAL KIDS PUBLIC SCHOOL
# Vijayapura | 91/120
# Opal School ( education for both worlds )
# Vijayapura | 92/120
# Jyotsna Vidya Kendra
# Vijayapura | 93/120
# Kittle Public School
# Vijayapura | 94/120
# Iqra School
# Vijayapura | 95/120
# Noble Vision School vijayapura
# Vijayapura | 96/120
# Parivarthan School
# Vijayapura | 97/120
# AL-HASNAT URDU PRIMARY,HIGH SCHOOL&COLLEGE VIJAYAPUR.
# Vijayapura | 98/120
# Rabindranath Tagore School And College
# Vijayapura | 99/120
# Tungal CBSE School
# Vijayapura | 100/120
# Little Moon Pre-School Vijayapur
# Vijayapura | 101/120
# Sanskriti Pre-primary school
# Vijayapura | 102/120
# Vidya Vikas Mandir English and Kannada Medium School
# Vijayapura | 103/120
# PDJ High School Play Ground
# Vijayapura | 104/120
# SRI SAI HI- TECH PRIMARY SCHOOL
# Vijayapura | 105/120
# Hello Kids - Dreamland Preschool
# Vijayapura | 106/120
# KB School No. 6
# Vijayapura | 107/120
# Pooja Driving School
# Vijayapura | 108/120
# Vishwa vidyaniketan school
# Vijayapura | 109/120
# Government Muslim Residential School, Bijapur
# Vijayapura | 110/120
# Hamsadwani Music Academy
# Vijayapura | 111/120
# Banjara Independent Pu college Vijayapur
# Vijayapura | 112/120
# Secab Secondary Urdu Medium School — اردو سکول
# Vijayapura | 113/120
# S KUMAR'S SARASWATI ENGLISH MEDIUM
# Vijayapura | 114/120
# Morarji desai government residential school
# Vijayapura | 115/120
# Government First Grade College ,Navabag, Vijayapura.
# Vijayapura | 116/120
# Loyola Institutions
# Vijayapura | 117/120
# ARJ International ( City Office)
# Vijayapura | 118/120
# SS PU COLLEGE IN VIJAYAPUR
# Vijayapura | 119/120
# Kidz Kingdom
# Vijayapura | 120/120
# J.E.S Paradiise Public School, ಜೆ.ಇ.ಎಸ್ ಪ್ಯಾರಾಡೈಸ್ ಪಬ್ಲಿಕ್ ಸ್ಕೂಲ್
#
# Searching: schools in Yadgir Karnataka
# Search Submitted
# Yadgir | schools | Scroll 1 -> 14
# Yadgir | schools | Scroll 2 -> 20
# Yadgir | schools | Scroll 3 -> 27
# Yadgir | schools | Scroll 4 -> 34
# Yadgir | schools | Scroll 5 -> 40
# Yadgir | schools | Scroll 6 -> 47
# Yadgir | schools | Scroll 7 -> 47
# Yadgir | schools | Scroll 8 -> 47
# Yadgir | schools | Scroll 9 -> 47
# Yadgir | schools | Scroll 10 -> 47
# Collected 47 links
# Yadgir | 1/47
# Centurion International School
# Yadgir | 2/47
# Khandelwal English Medium School Yadgir
# Yadgir | 3/47
# SRI VIDYARANYA INTERNATIONAL SCHOOL, YADGIRI
# Yadgir | 4/47
# Aryabhatta International Academy || Best ICSE School in Karnataka || Residential School in Yadgiri
# Yadgir | 5/47
# Azim Premji School And Foundation, Yadgir
# Yadgir | 6/47
# Shantiniketan Pre Primary English Medium School Yadgir
# Yadgir | 7/47
# Aryabhatta Kids School
# Yadgir | 8/47
# UNAIDED D DEVARAJ URS HPS & HS
# Yadgir | 9/47
# Sri Sai Public School
# Yadgir | 10/47
# Murarji School Sahara Colony Hosalli Cross
# Yadgir | 11/47
# Don Bosco School
# Yadgir | 12/47
# Ankurum Kidzee Pre-primary School Yadgiri -585202
# Yadgir | 13/47
# Indian Public School Yadgir
# Yadgir | 14/47
# Chiranjeevi Methodist High School
# Yadgir | 15/47
# RV School
# Yadgir | 16/47
# Sri Puranmal Shrenikraj Dhoka Jain school
# Yadgir | 17/47
# Bachpan Play School in Yadgir Karnatka | Best Preschool Near Me | Nursery School & Kindergarten for Your Child’s Bright Start
# Yadgir | 18/47
# Vignyana Jyothi High School & Science PU College
# Yadgir | 19/47
# Mahatma Gandhi High School
# Yadgir | 20/47
# ADARSH VIDYALAYA[R.M.S.A] YADGIR
# Yadgir | 21/47
# Akshara English Medium Pre Primary School, Yadgiri
# Yadgir | 22/47
# Koliwada high school
# Yadgir | 23/47
# City Convent Higher Primary English Medium School Asar Mohalla Yadgir
# Yadgir | 24/47
# Damasaada Vidyaniketan English Medium School
# Yadgir | 25/47
# Little Angels Higher Primary School
# Yadgir | 26/47
# don bosco center for social action
# Yadgir | 27/47
# Vision P U college yadgir
# Yadgir | 28/47
# Divangata Timmanna Hedgimadri English Medium School Yadgiri
# Yadgir | 29/47
# Shanti Sadan English Medium School
# Yadgir | 30/47
# Saba P. U. College
# Yadgir | 31/47
# Rathnam English Medium School
# Yadgir | 32/47
# Noori Motor Driving School
# Yadgir | 33/47
# Vamsak Complex
# Yadgir | 34/47
# Dhoka English Medium School
# Yadgir | 35/47
# Basaveshwara English Medium School.
# Yadgir | 36/47
# Rajeshwari Higher Primary School
# Yadgir | 37/47
# Twinkle Bell Preschool
# Yadgir | 38/47
# Don Bosco Degree College and B.Ed College/ AICTE Approved
# Yadgir | 39/47
# Jawahar Navodaya Vidyalaya, Hothpet
# Yadgir | 40/47
# MRM high school
# Yadgir | 41/47
# PCC Tuition
# Yadgir | 42/47
# RV PU College
# Yadgir | 43/47
# Adarsh Vidyalaya RMSA, Yadgir
# Yadgir | 44/47
# Aryabhatta Residential PU College
# Yadgir | 45/47
# Ideal Global School
# Yadgir | 46/47
# Sahyadri PU College
# Backup Saved
# Yadgir | 47/47
# S J M PRE PRIMARY SCHOOL YADGIR
#
# Extraction Completed
# Total Schools Extracted: 1433
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 431
#     425 print("\nExtraction Completed")
#     427 print(
#     428     f"Total Schools Extracted: {len(final_df)}"
#     429 )
# --> 431 print(f"\nSaved File: {filename}")
#     433 driver.quit()
#
# NameError: name 'filename' is not defined
