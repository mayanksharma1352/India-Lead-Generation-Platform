# %%
import pandas as pd

# %%
df = pd.read_csv("bihar_schools.csv")

# %%
df.shape
# Out:
# (2393, 8)

# %%
duplicate_count = df.duplicated(
    subset=["School Name", "Google Maps URL"]
).sum()
duplicate_count
# Out:
# np.int64(0)

# %%
df = df[
    df["Phone"].notna() & 
    (df["Phone"].astype(str).str.strip() != "")
    ]
df.shape
# Out:
# (388, 8)

# %%
df = df[
    df["School Name"].notna()
    ]

df = df[
    df["School Name"].str.strip() != ""
    ]

# %%
df.shape
# Out:
# (386, 8)

# %%
# CLEAN PHONE COLUMNS
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]","",regex=True)
    .str.strip()
)

display(df[["Phone"]].head())
# Out:
#            Phone
# 20  094302 65033
# 21  082716 21797
# 29  080021 60050
# 61  075639 44484
# 88  098350 10513

# %%
# SAVE CLEANED FILE
df.to_csv(
    "bihar_schools_cleaned.csv",
    index=False
)
