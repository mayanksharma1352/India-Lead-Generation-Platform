# %%
import time
import random
import pandas as pd

from datetime import datetime

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.service import Service

from webdriver_manager.chrome import ChromeDriverManager


# MIZORAM DISTRICTS

districts = [
        "Aizawl",
        "Champhai",
        "Hnahthial",
        "Khawzawl",
        "Kolasib",
        "Lawngtlai",
        "Lunglei",
        "Mamit",
        "Saitual",
        "Serchhip",
        "Saiha"
    ]


# SEARCH TYPES

search_types = [
    "schools"
]

# CHROME OPTIONS

options = webdriver.ChromeOptions()

options.add_argument("--start-maximized")

options.add_argument(
    "--disable-blink-features=AutomationControlled"
)

options.add_argument("--disable-notifications")

# START DRIVER

driver = webdriver.Chrome(

    service=Service(
        ChromeDriverManager().install()
    ),

    options=options
)


# OPEN GOOGLE MAPS

driver.get("https://www.google.com/maps")

print("Opening Google Maps...")

time.sleep(15)

print("Google Maps Loaded")


# STORAGE


all_data = []

visited_links = set()


# SEARCH BOX FUNCTION


def get_search_box():

    selectors = [

        '//input[@id="searchboxinput"]',
        '//input[contains(@placeholder,"Search")]',
        '//input[contains(@aria-label,"Search")]',
        '//input'

    ]

    for selector in selectors:

        try:

            box = driver.find_element(
                By.XPATH,
                selector
            )

            return box

        except:
            pass

    return None

# EXTRACT SCHOOL DATA

def extract_school_data():

    try:

        # SCHOOL NAME
        try:
            name = driver.find_element(
                By.TAG_NAME,
                "h1"
            ).text
        except:
            name = ""

        # ADDRESS
        try:
            address = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"address")]'
            ).text
        except:
            address = ""

        # PHONE
        try:
            phone = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"phone")]'
            ).text
        except:
            phone = ""

        # WEBSITE
        try:
            website = driver.find_element(
                By.XPATH,
                '//a[contains(@data-item-id,"authority")]'
            ).get_attribute("href")
        except:
            website = ""

        # RATING
        try:
            rating = driver.find_element(
                By.XPATH,
                '//div[@role="img"]'
            ).get_attribute("aria-label")
        except:
            rating = ""

        return {

            "School Name": name,
            "Address": address,
            "Phone": phone,
            "Website": website,
            "Rating": rating,
            "Google Maps URL": driver.current_url

        }

    except:

        return None


# START EXTRACTION

for district in districts:

    for search_type in search_types:

        try:

            query = (
                f"{search_type} "
                f"in {district} Mizoram"
            )

            print(f"\nSearching: {query}")

   
            # SEARCH

            search_box = get_search_box()

            if not search_box:

                print("Search Box Not Found")

                continue

            ActionChains(driver).move_to_element(
                search_box
            ).click().perform()

            time.sleep(1)

            search_box.send_keys(
                Keys.CONTROL + "a"
            )

            time.sleep(1)

            search_box.send_keys(Keys.DELETE)

            time.sleep(1)

            # TYPE SLOWLY
            for char in query:

                search_box.send_keys(char)

                time.sleep(0.03)

            search_box.send_keys(Keys.ENTER)

            print("Search Submitted")

            time.sleep(8)

            # SCROLL RESULTS

            try:

                scrollable_div = driver.find_element(
                    By.XPATH,
                    '//div[@role="feed"]'
                )

                previous_count = 0

                stagnant = 0

                for i in range(100):

                    driver.execute_script(
                        """
                        arguments[0].scrollTop =
                        arguments[0].scrollHeight
                        """,
                        scrollable_div
                    )

                    time.sleep(4)

                    listings = driver.find_elements(
                        By.XPATH,
                        '//a[contains(@href,"/maps/place/")]'
                    )

                    current_count = len(listings)

                    print(
                        f"{district} | "
                        f"{search_type} | "
                        f"Scroll {i+1} -> "
                        f"{current_count}"
                    )

                    if current_count == previous_count:

                        stagnant += 1

                    else:

                        stagnant = 0

                    if stagnant >= 4:

                        break

                    previous_count = current_count

            except Exception as e:

                print(f"Scrolling Error: {e}")

            # GET LINK

            listings = driver.find_elements(
                By.XPATH,
                '//a[contains(@href,"/maps/place/")]'
            )

            links = []

            for listing in listings:

                try:

                    link = listing.get_attribute("href")

                    if (
                        link
                        and link not in visited_links
                    ):

                        links.append(link)

                        visited_links.add(link)

                except:
                    pass

            print(f"Collected {len(links)} links")

            # VISIT EACH SCHOOL

            for index, link in enumerate(links):

                try:

                    print(
                        f"{district} | "
                        f"{index+1}/{len(links)}"
                    )

                    driver.get(link)

                    time.sleep(
                        random.uniform(2, 3)
                    )

                    data = extract_school_data()

                    if data:

                        data["District"] = district

                        data["Search Type"] = search_type

                        all_data.append(data)

                        print(data["School Name"])

   
                    # BACKUP SAVE

                    if len(all_data) % 100 == 0:

                        backup_df = pd.DataFrame(
                            all_data
                        )

                        backup_df.drop_duplicates(
                            subset=[
                                "School Name",
                                "Google Maps URL"
                            ],
                            inplace=True
                        )

                        backup_df.to_csv(
                            "mizoram_schools_backup.csv",
                            index=False
                        )

                        print("Backup Saved")

                except Exception as e:

                    print(
                        f"School Error: {e}"
                    )

        except Exception as e:

            print(
                f"District Error: {e}"
            )

# FINAL SAVE


df = pd.DataFrame(all_data)

df.drop_duplicates(

    subset=[
        "School Name",
        "Google Maps URL"
    ],

    inplace=True
)

# UNIQUE FILE NAME

filename = (
    f"mizoram_schools.csv"
)

df.to_csv(
    filename,
    index=False
)

print("\nExtraction Completed")

print(
    f"Total Schools Extracted: {len(df)}"
)

print(f"\nSaved File: {filename}")

driver.quit()
# Out:
# Opening Google Maps...
# Google Maps Loaded
#
# Searching: schools in Aizawl Mizoram
# Search Submitted
# Aizawl | schools | Scroll 1 -> 14
# Aizawl | schools | Scroll 2 -> 20
# Aizawl | schools | Scroll 3 -> 27
# Aizawl | schools | Scroll 4 -> 34
# Aizawl | schools | Scroll 5 -> 40
# Aizawl | schools | Scroll 6 -> 47
# Aizawl | schools | Scroll 7 -> 54
# Aizawl | schools | Scroll 8 -> 60
# Aizawl | schools | Scroll 9 -> 67
# Aizawl | schools | Scroll 10 -> 74
# Aizawl | schools | Scroll 11 -> 80
# Aizawl | schools | Scroll 12 -> 87
# Aizawl | schools | Scroll 13 -> 94
# Aizawl | schools | Scroll 14 -> 100
# Aizawl | schools | Scroll 15 -> 107
# Aizawl | schools | Scroll 16 -> 114
# Aizawl | schools | Scroll 17 -> 120
# Aizawl | schools | Scroll 18 -> 120
# Aizawl | schools | Scroll 19 -> 120
# Aizawl | 113/119
# Home Mission School Science Stream
# Aizawl | 114/119
# Drop Doubt School Of Music John Tetea
# Aizawl | 115/119
# Pushpak Primary School
# Aizawl | 116/119
# Shining star special school
# Aizawl | 117/119
# Genesis English School
# Aizawl | 118/119
# Apollo School of Nursing
# Aizawl | 119/119
# Springdale School
#
# Searching: schools in Champhai Mizoram
# Search Submitted
# Champhai | schools | Scroll 1 -> 14
# Champhai | schools | Scroll 2 -> 20
# Champhai | schools | Scroll 3 -> 27
# Champhai | schools | Scroll 4 -> 34
# Champhai | schools | Scroll 5 -> 40
# Champhai | schools | Scroll 6 -> 47
# Champhai | schools | Scroll 7 -> 54
# Champhai | schools | Scroll 8 -> 59
# Champhai | schools | Scroll 9 -> 59
# Champhai | schools | Scroll 10 -> 59
# Champhai | schools | Scroll 11 -> 59
# Champhai | schools | Scroll 12 -> 59
# Collected 59 links
# Champhai | 1/59
#
# Champhai | 2/59
# K.V School, Champhai, Mizoram
# Champhai | 3/59
# Roseland School
# Champhai | 4/59
# Govt Gandhi Memorial HSS, Champhai Vengsang
# Champhai | 5/59
# BC Lalthlamuana English Academy, Champhai
# Champhai | 6/59
# Champhai Higher Secondary School
# Champhai | 7/59
# Holy Cross School, Champhai Vengthar
# Champhai | 8/59
# Academy of Arts and Sciences, Champhai
# Champhai | 9/59
# Government Champhai College
# Champhai | 10/59
#
# Champhai | 11/59
#
# Champhai | 12/59
#
# Champhai | 13/59
#
# Champhai | 14/59
#
# Champhai | 15/59
#
# Champhai | 16/59
#
# Champhai | 17/59
#
# Champhai | 18/59
#
# Champhai | 19/59
#
# Champhai | 20/59
#
# Champhai | 21/59
# Holy Mission School
# Champhai | 22/59
# Govt Bethel Middle School, Champhai
# Champhai | 23/59
# Mount Carmel School
# Champhai | 24/59
# Govt. Champhai Primary School - I
# Champhai | 25/59
# Govt GM High School, Champhai Vengsang
# Champhai | 26/59
# Govt. Champhai Primary School - II
# Champhai | 27/59
# Pine Hill Academy
# Champhai | 28/59
# Govt.Comprehensive Middle School Venglai
# Champhai | 29/59
# Govt School
# Champhai | 30/59
# Cambridge Montessori Preschool and Daycare, Champhai
# Champhai | 31/59
# DM HIGHER SECONDARY SCHOOL
# Champhai | 32/59
# Einstein Elementary school, Champhai
# Champhai | 33/59
# Venglai High school
# Champhai | 34/59
# Govt Middle School, Champhai Vengthar
# Champhai | 35/59
# Govt. LM Middle School
# Champhai | 36/59
# Govt Kanan Middle School, Champhai
# Champhai | 37/59
# Govt R.Hranga High School, Champhai Kanan
# Champhai | 38/59
# AGAPE ACADEMY
# Champhai | 39/59
# Nextgen Computer Institute, Kanan Veng, Champhai
# Champhai | 40/59
# Govt Hmunhmelṭha High School
# Champhai | 41/59
# Presbyterian English Medium School
# Champhai | 42/59
# Govt. Jail P/S
# Champhai | 43/59
# Vengthar Primary School
# Champhai | 44/59
# Govt Hmunhmelṭha Primary School
# Champhai | 45/59
# Govt Ruantlang High School
# Khawzawl | 17/27
# Grace Foundation School
# Khawzawl | 18/27
# Govt. Middle School II Khawzawl
# Khawzawl | 19/27
# Kawnzar kohhran sunday school hall
# Khawzawl | 20/27
# Zaingen Anganwadi
# Khawzawl | 21/27
# Govt Chawngtlai High School
# Khawzawl | 22/27
# Little Learners Pre-School and Daycare
# Khawzawl | 23/27
# Far East Experimental
# Khawzawl | 24/27
# St.Joseph High School Basketball Court
# Khawzawl | 25/27
# Old Sunday School Building – Khawzawl Venglai Presbyterian Church
# Khawzawl | 26/27
# Anganwadi centre XIII
# Khawzawl | 27/27
# Government Khawzawl College
#
# Searching: schools in Kolasib Mizoram
# Search Submitted
# Kolasib | schools | Scroll 1 -> 14
# Kolasib | schools | Scroll 2 -> 20
# Kolasib | schools | Scroll 3 -> 27
# Kolasib | schools | Scroll 4 -> 34
# Kolasib | schools | Scroll 5 -> 40
# Kolasib | schools | Scroll 6 -> 47
# Kolasib | schools | Scroll 7 -> 49
# Kolasib | schools | Scroll 8 -> 49
# Kolasib | schools | Scroll 9 -> 49
# Kolasib | schools | Scroll 10 -> 49
# Kolasib | schools | Scroll 11 -> 49
# Collected 49 links
# Kolasib | 1/49
# St. John's Higher Secondary School
# Kolasib | 2/49
# St. James, Kolasib.
# Kolasib | 3/49
# Govt Diakkawn High School, Kolasib
# Kolasib | 4/49
# Govt. Kolasib High School
# Kolasib | 5/49
# St. Maria Goretti's School
# Kolasib | 6/49
# Cosmopolitan School
# Kolasib | 7/49
# Springfield Academy School
# Kolasib | 8/49
# The Salvation Army School For The Blind
# Kolasib | 9/49
# Home Missions School — Kolasib, New Diakkawn
# Kolasib | 10/49
# Hmar Veng High School
# Kolasib | 11/49
# Hmarveng RMSA High School
# Kolasib | 12/49
# LTM Upper Primary School
# Kolasib | 13/49
# CM High School
# Kolasib | 14/49
# Vengthar RMSA Sec. School
# Kolasib | 15/49
# Adventist English School
# Kolasib | 16/49
# Integrated School
# Kolasib | 17/49
# Jawahar Navodaya Vidyalaya – Kolasib, Thingdawl
# Kolasib | 18/49
# Kolasib AWC-IV
# Kolasib | 19/49
# HT High School
# Kolasib | 20/49
# St. Aloysios School
# Kolasib | 21/49
# Govt Kolasib Vengthar Middle School
# Kolasib | 22/49
# Kolasib AWC-V
# Kolasib | 23/49
# Susanne Downs Boarding School, Khuangpuilam
# Kolasib | 24/49
# Govt. Primary School IV
# Kolasib | 25/49
# Govt Selluaii Middle School
# Kolasib | 26/49
# Govt Diakkawn Middle School II
# Kolasib | 27/49
# RENGTEKAWN HIGH SCHOOL
# Kolasib | 28/49
# Holy Heart Academy
# Kolasib | 29/49
# Govt. Khianga Middle school
# Kolasib | 30/49
# Government Kolasib College
# Kolasib | 31/49
# Saidan Primary School
# Kolasib | 32/49
# Govt Gorkha Middle School, Electric Veng Kolasib
# Kolasib | 33/49
# KIDS ZONE EDUCATION CENTRE
# Kolasib | 34/49
# Shalom Primary School
# Kolasib | 35/49
# Lawngtlai | 31/40
# Sparkle Elementary school
# Lawngtlai | 32/40
# Primary And Middle School
# Lawngtlai | 33/40
# Govt. Southern Standard Middle School (LADC)
# Lawngtlai | 34/40
# Opposite, Harvard higher academy Matrix Computer Centre
# Lawngtlai | 35/40
# High school playground
# Backup Saved
# Lawngtlai | 36/40
# Matrix Computer Centre
# Lawngtlai | 37/40
# J&E Memorial English School
# Lawngtlai | 38/40
# Volley ball court
# Lawngtlai | 39/40
# Lawngtlai Primary School I
# Lawngtlai | 40/40
# Polytechnic
#
# Searching: schools in Lunglei Mizoram
# Search Submitted
# Lunglei | schools | Scroll 1 -> 14
# Lunglei | schools | Scroll 2 -> 20
# Lunglei | schools | Scroll 3 -> 27
# Lunglei | schools | Scroll 4 -> 34
# Lunglei | schools | Scroll 5 -> 40
# Lunglei | schools | Scroll 6 -> 47
# Lunglei | schools | Scroll 7 -> 54
# Lunglei | schools | Scroll 8 -> 60
# Lunglei | schools | Scroll 9 -> 67
# Lunglei | schools | Scroll 10 -> 74
# Lunglei | schools | Scroll 11 -> 80
# Lunglei | schools | Scroll 12 -> 87
# Lunglei | schools | Scroll 13 -> 94
# Lunglei | schools | Scroll 14 -> 100
# Lunglei | schools | Scroll 15 -> 107
# Lunglei | schools | Scroll 16 -> 113
# Lunglei | schools | Scroll 17 -> 113
# Lunglei | schools | Scroll 18 -> 113
# Lunglei | schools | Scroll 19 -> 113
# Lunglei | schools | Scroll 20 -> 113
# Collected 112 links
# Lunglei | 1/112
# Silver Mount School
# Lunglei | 2/112
# Government High School, Lunglei
# Lunglei | 3/112
# Eklavya Model Residential School, EMRS Pukpui, Lunglei
# Lunglei | 4/112
# Kendriya Vidyalaya Lunglei
# Lunglei | 5/112
# Govt Lunglei Higher Secondary School
# Lunglei | 6/112
# Loroto School
# Lunglei | 7/112
# Chanmari High School, Lunglei
# Lunglei | 8/112
# Sacred Heart School
# Lunglei | 9/112
# Bethesda Higher Secondary School
# Lunglei | 10/112
# Government Venglai Middle School, Lunglei
# Lunglei | 11/112
# Government Leitlangpui Higher Secondary School Lunglei
# Lunglei | 12/112
# Adventist English School
# Lunglei | 13/112
# Stairway Higher Academy
# Lunglei | 14/112
# Holy Faith School
# Lunglei | 15/112
# District Institute of Education and Training Lunglei
# Lunglei | 16/112
# Venghlun High School (GIA)
# Lunglei | 17/112
# FAITH HILL SCHOOL OF ARTS
# Lunglei | 18/112
# Southern Flower School
# Lunglei | 19/112
# Government Venglai High School
# Lunglei | 20/112
# Gov't Pukpui Primary School I
# Lunglei | 21/112
# Graceland English School
# Lunglei | 22/112
# CEC School
# Lunglei | 23/112
# Government Bazar High School
# Lunglei | 24/112
# Little Nest Montessori
# Lunglei | 25/112
# Zotlang Higher Secondary School
# Lunglei | 26/112
# Gov't Bazar Veng Middle School
# Lunglei | 27/112
# LKM School
# Lunglei | 28/112
# R.S.M.S School
# Lunglei | 29/112
# Solomons Higher Seconday School, Lunglei bazar veng
# Lunglei | 30/112
# Gov't Primary School, Sethlun
# Lunglei | 31/112
# Kids Care School
# Lunglei | 32/112
# Onyx Special School
# Lunglei | 33/112
# Govt Primary School, Kikawn Lunglei
# Lunglei | 34/112
# Baptist Higher Secondary School, Serkawn
# Lunglei | 35/112
# The Playstop, Play School and Day Care
# Lunglei | 36/112
# Electric Veng primary 1 School, Lunglei
# Lunglei | 37/112
# Govt Ramthar High School, Lunglei
# Lunglei | 38/112
# Govt Middle School, Zohnuai
# Lunglei | 39/112
# R. M. S. A Hrangchalkawn
# Lunglei | 40/112
# One heart academy
# Lunglei | 41/112
# Jawahar Navodaya Vidyalaya, Pukpui
# Lunglei | 42/112
# Pukpui High School
# Lunglei | 43/112
# Saphranga Memorial School
# Lunglei | 44/112
# Zobawm Montessori School
# Lunglei | 45/112
# Govt Zohnuai High School, Lunglei
# Lunglei | 46/112
# Govt DM High School, Theiriat
# Lunglei | 47/112
# Baptist English School, Serkawn
# Lunglei | 48/112
# Jawaharlal Nehru Memorial School
# Lunglei | 49/112
# Rowing School
# Lunglei | 50/112
# Rowing School
# Lunglei | 51/112
# Narrow Road Academy
# Lunglei | 52/112
# Govt Theiriat Middle School
# Lunglei | 53/112
# Garden Primary School
# Lunglei | 54/112
# Zotlang High School
# Lunglei | 55/112
# Government J. Buana College
# Lunglei | 56/112
# Rachel
# Lunglei | 57/112
# Govt Darphawka Memorial Middle School
# Lunglei | 58/112
# Chhimtlang Higher Academy
# Lunglei | 59/112
# Govt Liantawna High School Lunglawn
# Lunglei | 60/112
# Gospel Centenary School, Rahsi Veng Lunglei
# Lunglei | 61/112
# PK Middle School, Chanmari
# Lunglei | 62/112
# Serkawn Sikulpui
# Lunglei | 63/112
# Government Primary School
# Lunglei | 64/112
# Jubilee Bible School
# Lunglei | 65/112
# CMS School
# Lunglei | 66/112
# Govt Theiriat Primary School - I
# Lunglei | 67/112
# Middle School I
# Lunglei | 68/112
# St bruno Hostel
# Lunglei | 69/112
# Govt. Pukpui Middle School-I
# Lunglei | 70/112
# Nightingale School, Bazar Veng
# Lunglei | 71/112
# ITI, Lunglei
# Lunglei | 72/112
# Lunglei Science Center
# Lunglei | 73/112
# Govt. Bazar Primary school
# Lunglei | 74/112
# Gov't Sethlun Middle School
# Lunglei | 75/112
# Mizoram Polytechnic Lunglei
# Lunglei | 76/112
# Govt Primary School, Lungpuizawl
# Lunglei | 77/112
# Missionary Road, Rahsiveng, Lunglei
# Lunglei | 78/112
# Presbyterian English School
# Lunglei | 79/112
# Lungpuizawl Middle School
# Lunglei | 80/112
# Govt Electric Ps II
# Lunglei | 81/112
# LOROTO PLAY SCHOOL
# Lunglei | 82/112
# Rahsiveng Middle School II
# Lunglei | 83/112
# Govt. Hrangchalkawn Primary School
# Lunglei | 84/112
# Government Primary School-II, Theiriat
# Lunglei | 85/112
# Standard Middle School (SMS), Bazar Veng
# Lunglei | 86/112
# Govt. Hrangchalkawn Middle School
# Lunglei | 87/112
# Mt. Hermon Middle School
# Lunglei | 88/112
# Govt Luangmual M/S
# Lunglei | 89/112
# OES | NGO in Lunglei | NGO in Lunglei for Education | Skill Development Programmes & Sustainable Livelihood
# Lunglei | 90/112
# Zakhuma Memorial School, Theiriat
# Lunglei | 91/112
# Jehova Nissi School
# Lunglei | 92/112
# Zotlang P/S 1
# Lunglei | 93/112
# Govt Primary School, Salem
# Lunglei | 94/112
# Serkawn Primary School
# Lunglei | 95/112
# D&D Higher Secondary School
# Backup Saved
# Lunglei | 96/112
# Serkawn Middle School
# Lunglei | 97/112
# Bazar veng aganwadi center 2
# Lunglei | 98/112
# Government Primary School, Farm Veng
# Lunglei | 99/112
# MYOS computer training institute
# Lunglei | 100/112
# Govt. P/S-ii
# Lunglei | 101/112
# GOVERNMENT MIDDLE SCHOOL SAZAIKAWN
# Lunglei | 102/112
# Govt. Middle School Zotlang
# Lunglei | 103/112
# City Garden Lunglei
# Lunglei | 104/112
# BCM Church, Chanmari Lunglei
# Lunglei | 105/112
# Lunglei
# Lunglei | 106/112
# Faith Institute of Paramedical Technology
# Lunglei | 107/112
# Anganwadi Centre – I, Bazar Veng
# Lunglei | 108/112
# Nursing School
# Lunglei | 109/112
# Pipe Store
# Lunglei | 110/112
# Primary School I, Chanmari Lunglei
# Lunglei | 111/112
# SCM Music Academy
# Lunglei | 112/112
# Govt Chhimchhawng Middle School Lunglawn
#
# Searching: schools in Mamit Mizoram
# Search Submitted
# Mamit | schools | Scroll 1 -> 14
# Mamit | schools | Scroll 2 -> 17
# Mamit | schools | Scroll 3 -> 17
# Mamit | schools | Scroll 4 -> 17
# Mamit | schools | Scroll 5 -> 17
# Mamit | schools | Scroll 6 -> 17
# Collected 17 links
# Mamit | 1/17
# Govt. Mamit High School
# Mamit | 2/17
# St Francis of Asissi Primary School
# Mamit | 3/17
# Gov't Mamit Higher Secondary School
# Mamit | 4/17
# Mamit residential school
# Mamit | 5/17
# Govt Primary School – II, Mamit
# Mamit | 6/17
# RMSA Secondary School New Mamit
# Mamit | 7/17
# Govt Primary School I, Mamit
# Mamit | 8/17
# Govt Agape Middle School
# Mamit | 9/17
# JNV LUANGPAWL, MAMIT, MIZORAM
# Mamit | 10/17
# PES – Mamit
# Mamit | 11/17
# Little Angels Academy
# Mamit | 12/17
# Govt Model Primary School, Mamit Dinthar
# Mamit | 13/17
# Mamit H/S II
# Mamit | 14/17
# Government Primary School VI
# Mamit | 15/17
# Light of life academy school
# Mamit | 16/17
# Govt M/S- I, Mamit
# Mamit | 17/17
# Health Worker Training School, Mamit
#
# Searching: schools in Saitual Mizoram
# Search Submitted
# Saitual | schools | Scroll 1 -> 14
# Saitual | schools | Scroll 2 -> 20
# Saitual | schools | Scroll 3 -> 20
# Saitual | schools | Scroll 4 -> 20
# Saitual | schools | Scroll 5 -> 20
# Saitual | schools | Scroll 6 -> 20
# Collected 20 links
# Saitual | 1/20
# Saitual High School
