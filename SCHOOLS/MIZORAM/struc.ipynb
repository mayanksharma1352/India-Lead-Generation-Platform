# %%
import pandas as pd

# %%
df = pd.read_csv("mizoram_schools.csv")

# %%
df.shape
# Out:
# (535, 8)

# %%
duplicate_count = df.duplicated(
    subset=["School Name", "Google Maps URL"]
).sum()
duplicate_count
# Out:
# np.int64(0)

# %%
df = df[
    df["Phone"].notna() & 
    (df["Phone"].astype(str).str.strip() != "")
    ]
df.shape
# Out:
# (65, 8)

# %%
df = df[
    df["School Name"].notna()
    ]

df = df[
    df["School Name"].str.strip() != ""
    ]
df.shape
# Out:
# (65, 8)

# %%
# CLEAN PHONE COLUMNS
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]","",regex=True)
    .str.strip()
)

display(df[["Phone"]].head())
# Out:
#            Phone
# 2   069097 12503
# 3  0389 234 1213
# 5   094361 40458
# 7   095121 31959
# 9   060097 49674

# %%
# SAVE CLEANED FILE
df.to_csv(
    "mizoram_schools_cleaned.csv",
    index=False
)
