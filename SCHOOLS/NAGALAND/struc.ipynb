# %%
import pandas as pd

# %%
df = pd.read_csv("nagaland_schools.csv")

# %%
df.shape
# Out:
# (561, 8)

# %%
duplicate_count = df.duplicated(
    subset=["School Name", "Google Maps URL"]
).sum()
duplicate_count
# Out:
# np.int64(0)

# %%
df = df[
    df["Phone"].notna() & 
    (df["Phone"].astype(str).str.strip() != "")
    ]
df.shape
# Out:
# (46, 8)

# %%
df = df[
    df["School Name"].notna()
    ]

df = df[
    df["School Name"].str.strip() != ""
    ]

# %%
df.shape
# Out:
# (46, 8)

# %%
# CLEAN PHONE COLUMNS
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]","",regex=True)
    .str.strip()
)

display(df[["Phone"]].head())
# Out:
#             Phone
# 2    070059 46652
# 10   098565 12476
# 14  03862 240 346
# 24  03862 240 787
# 57   087299 96605

# %%
# SAVE CLEANED FILE
df.to_csv(
    "nagaland_schools_cleaned.csv",
    index=False
)
