# %%
import time
import random
import pandas as pd

from datetime import datetime

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.service import Service

from webdriver_manager.chrome import ChromeDriverManager


districts = [
        "Chümoukedima",
        "Dimapur",
        "Kiphire",
        "Kohima",
        "Longleng",
        "Mokokchung",
        "Mon",
        "Niuland",
        "Noklak",
        "Peren",
        "Phek",
        "Shamator",
        "Tseminyü",
        "Tuensang",
        "Wokha",
        "Zunheboto"
]


search_types = [
    "schools"
]



options = webdriver.ChromeOptions()

options.add_argument("--start-maximized")

options.add_argument(
    "--disable-blink-features=AutomationControlled"
)

options.add_argument("--disable-notifications")


driver = webdriver.Chrome(

    service=Service(
        ChromeDriverManager().install()
    ),

    options=options
)


driver.get("https://www.google.com/maps")

print("Opening Google Maps...")

time.sleep(15)

print("Google Maps Loaded")


all_data = []

visited_links = set()



def get_search_box():

    selectors = [

        '//input[@id="searchboxinput"]',
        '//input[contains(@placeholder,"Search")]',
        '//input[contains(@aria-label,"Search")]',
        '//input'

    ]

    for selector in selectors:

        try:

            box = driver.find_element(
                By.XPATH,
                selector
            )

            return box

        except:
            pass

    return None


def extract_school_data():

    try:


        try:
            name = driver.find_element(
                By.TAG_NAME,
                "h1"
            ).text
        except:
            name = ""


        try:
            address = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"address")]'
            ).text
        except:
            address = ""

        try:
            phone = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"phone")]'
            ).text
        except:
            phone = ""

        try:
            website = driver.find_element(
                By.XPATH,
                '//a[contains(@data-item-id,"authority")]'
            ).get_attribute("href")
        except:
            website = ""


        try:
            rating = driver.find_element(
                By.XPATH,
                '//div[@role="img"]'
            ).get_attribute("aria-label")
        except:
            rating = ""

        return {

            "School Name": name,
            "Address": address,
            "Phone": phone,
            "Website": website,
            "Rating": rating,
            "Google Maps URL": driver.current_url

        }

    except:

        return None


for district in districts:

    for search_type in search_types:

        try:

            query = (
                f"{search_type} "
                f"in {district} Nagaland"
            )

            print(f"\nSearching: {query}")


            search_box = get_search_box()

            if not search_box:

                print("Search Box Not Found")

                continue

            ActionChains(driver).move_to_element(
                search_box
            ).click().perform()

            time.sleep(1)

            search_box.send_keys(
                Keys.CONTROL + "a"
            )

            time.sleep(1)

            search_box.send_keys(Keys.DELETE)

            time.sleep(1)

            for char in query:

                search_box.send_keys(char)

                time.sleep(0.03)

            search_box.send_keys(Keys.ENTER)

            print("Search Submitted")

            time.sleep(8)



            try:

                scrollable_div = driver.find_element(
                    By.XPATH,
                    '//div[@role="feed"]'
                )

                previous_count = 0

                stagnant = 0

                for i in range(100):

                    driver.execute_script(
                        """
                        arguments[0].scrollTop =
                        arguments[0].scrollHeight
                        """,
                        scrollable_div
                    )

                    time.sleep(4)

                    listings = driver.find_elements(
                        By.XPATH,
                        '//a[contains(@href,"/maps/place/")]'
                    )

                    current_count = len(listings)

                    print(
                        f"{district} | "
                        f"{search_type} | "
                        f"Scroll {i+1} -> "
                        f"{current_count}"
                    )

                    if current_count == previous_count:

                        stagnant += 1

                    else:

                        stagnant = 0

                    if stagnant >= 4:

                        break

                    previous_count = current_count

            except Exception as e:

                print(f"Scrolling Error: {e}")

    
            listings = driver.find_elements(
                By.XPATH,
                '//a[contains(@href,"/maps/place/")]'
            )

            links = []

            for listing in listings:

                try:

                    link = listing.get_attribute("href")

                    if (
                        link
                        and link not in visited_links
                    ):

                        links.append(link)

                        visited_links.add(link)

                except:
                    pass

            print(f"Collected {len(links)} links")

       

            for index, link in enumerate(links):

                try:

                    print(
                        f"{district} | "
                        f"{index+1}/{len(links)}"
                    )

                    driver.get(link)

                    time.sleep(
                        random.uniform(2, 3)
                    )

                    data = extract_school_data()

                    if data:

                        data["District"] = district

                        data["Search Type"] = search_type

                        all_data.append(data)

                        print(data["School Name"])


                    if len(all_data) % 100 == 0:

                        backup_df = pd.DataFrame(
                            all_data
                        )

                        backup_df.drop_duplicates(
                            subset=[
                                "School Name",
                                "Google Maps URL"
                            ],
                            inplace=True
                        )

                        backup_df.to_csv(
                            "nagaland_schools_backup.csv",
                            index=False
                        )

                        print("Backup Saved")

                except Exception as e:

                    print(
                        f"School Error: {e}"
                    )

        except Exception as e:

            print(
                f"District Error: {e}"
            )



df = pd.DataFrame(all_data)

df.drop_duplicates(

    subset=[
        "School Name",
        "Google Maps URL"
    ],

    inplace=True
)


filename = (
    f"nagaland_schools.csv"
)

df.to_csv(
    filename,
    index=False
)

print("\nExtraction Completed")

print(
    f"Total Schools Extracted: {len(df)}"
)

print(f"\nSaved File: {filename}")

driver.quit()
# Out:
# Opening Google Maps...
# Google Maps Loaded
#
# Searching: schools in Chümoukedima Nagaland
# Search Submitted
# Chümoukedima | schools | Scroll 1 -> 14
# Chümoukedima | schools | Scroll 2 -> 20
# Chümoukedima | schools | Scroll 3 -> 27
# Chümoukedima | schools | Scroll 4 -> 34
# Chümoukedima | schools | Scroll 5 -> 40
# Chümoukedima | schools | Scroll 6 -> 47
# Chümoukedima | schools | Scroll 7 -> 54
# Chümoukedima | schools | Scroll 8 -> 60
# Chümoukedima | schools | Scroll 9 -> 67
# Chümoukedima | schools | Scroll 10 -> 74
# Chümoukedima | schools | Scroll 11 -> 80
# Chümoukedima | schools | Scroll 12 -> 87
# Chümoukedima | schools | Scroll 13 -> 94
# Chümoukedima | schools | Scroll 14 -> 100
# Chümoukedima | schools | Scroll 15 -> 107
# Chümoukedima | schools | Scroll 16 -> 109
# Chümoukedima | schools | Scroll 17 -> 109
# Chümoukedima | schools | Scroll 18 -> 109
# Chümoukedima | schools | Scroll 19 -> 109
# Chümoukedima | schools | Scroll 20 -> 109
# Collected 109 links
# Chümoukedima | 1/109
# Government Higher Secondary School
# Chümoukedima | 2/109
# Unity Christian Higher Secondary School
# Chümoukedima | 3/109
# Immanuel school
# Chümoukedima | 4/109
# St. Joseph School, Chümoukedima
# Chümoukedima | 5/109
# Cedar School
# Chümoukedima | 6/109
# Agape Higher Secondary School
# Chümoukedima | 7/109
# Gonyü Memorial School (Montessori attached)
# Chümoukedima | 8/109
# North Town Higher Secondary School
# Chümoukedima | 9/109
# Little Flower School, Chümoukedima
# Chümoukedima | 10/109
# Seeds Of Hope Hr. Sec. School, Chümoukedima
# Chümoukedima | 11/109
# Shekinah School
# Chümoukedima | 12/109
# Daeshin Academy
# Chümoukedima | 69/109
# Nagaland Police Central Workshop
# Chümoukedima | 70/109
# IITE Computer Institute
# Chümoukedima | 71/109
# S Driving School
# Chümoukedima | 72/109
# Kalam Ali
# Chümoukedima | 73/109
# Driving institute
# Chümoukedima | 74/109
# Little Star Higher Secondary School
# Chümoukedima | 75/109
# Mount Mary College
# Chümoukedima | 76/109
# Little woods Montessori
# Chümoukedima | 77/109
# Star Excellence school
# Chümoukedima | 78/109
# GPS Chakhesang colony E/W & N/W
# Chümoukedima | 79/109
# PM SHRI School Jawahar Navodaya Vidyalaya Niuland
# Chümoukedima | 80/109
# Don Bosco Higher Secondary School, Dimapur
# Chümoukedima | 81/109
# Govt middle school.
# Chümoukedima | 82/109
# Chümoukedima
# Chümoukedima | 83/109
# IACT Computer Institute, Chümoukedima (Reg: Under Govt of INDIA )
# Chümoukedima | 84/109
# Tuyitu Foundation School
# Chümoukedima | 85/109
# Christian School
# Chümoukedima | 86/109
# Little Daffodils Hr.Sec School , Doyapur
# Chümoukedima | 87/109
# St. Joseph's Church, Chümoukedima
# Chümoukedima | 88/109
# Eden Higher Secondary School
# Chümoukedima | 89/109
# Bethesda Higher Secondary School
# Chümoukedima | 90/109
# Noah's ark international school
# Chümoukedima | 91/109
# Chümoukedima Saturday Market
# Chümoukedima | 92/109
# Colina FC Academy
# Chümoukedima | 93/109
# DIMAPUR MISSION HIGHER SECONDARY SCHOOL
# Chümoukedima | 94/109
# Pillar School
# Chümoukedima | 95/109
# NST Driving Institute
# Chümoukedima | 96/109
# KinderGarden PreSchool & Daycare,Dimapur
# Chümoukedima | 97/109
# Chümoukedima Sangtam Baptist Church
# Chümoukedima | 98/109
# DOLCE PIANO STUDIO
# Chümoukedima | 99/109
# 7th Mile chumukedima neissr college
# Chümoukedima | 100/109
# Spring Corner
# Backup Saved
# Chümoukedima | 101/109
# North East Institute Of Social Sciences & Research
# Chümoukedima | 102/109
# First ladder pre-school
# Chümoukedima | 103/109
# Riverine Public Higher Secondary School, Urra Village
# Chümoukedima | 104/109
# VD Rental, Chümoukedima
# Chümoukedima | 105/109
# Office of the Police Training School
# Chümoukedima | 106/109
# Sigma Coaching Centre
# Chümoukedima | 107/109
# 3Q Abacus
# Chümoukedima | 108/109
# Police Training School
# Chümoukedima | 109/109
# Evara Music Academy
#
# Searching: schools in Dimapur Nagaland
# Search Submitted
# Dimapur | schools | Scroll 1 -> 14
# Dimapur | schools | Scroll 2 -> 20
# Dimapur | schools | Scroll 3 -> 27
# Dimapur | schools | Scroll 4 -> 34
# Dimapur | schools | Scroll 5 -> 40
# Dimapur | schools | Scroll 6 -> 47
# Dimapur | schools | Scroll 7 -> 54
# Dimapur | schools | Scroll 8 -> 60
# Dimapur | schools | Scroll 9 -> 67
# Dimapur | schools | Scroll 10 -> 74
# Dimapur | schools | Scroll 11 -> 80
# Dimapur | schools | Scroll 12 -> 87
# Dimapur | schools | Scroll 13 -> 94
# Dimapur | schools | Scroll 14 -> 100
# Dimapur | schools | Scroll 15 -> 107
# Dimapur | schools | Scroll 16 -> 114
# Dimapur | schools | Scroll 17 -> 120
# Vidhya Bhawan Higher Secondary School
# Dimapur | 60/87
# Don Bosco Vocational Training Center (First driving school of Dimapur)
# Dimapur | 61/87
# Carewell School, Duncan
# Dimapur | 62/87
# Government Higher Secondary School
# Dimapur | 63/87
# St Peter School
# Dimapur | 64/87
# Dimapur Railway High School
# Dimapur | 65/87
# Grace Fountain School
# Dimapur | 66/87
# St. Anthony High School Tenyiphe I
# Dimapur | 67/87
# SEWAK NURSERY SCHOOL
# Dimapur | 68/87
# St. Clare School Dimapur
# Dimapur | 69/87
# Cornerstone Higher Secondary School
# Dimapur | 70/87
# Christina Memorial Hr. Sec. School
# Dimapur | 71/87
# Kin High School
# Dimapur | 72/87
# Great Commission Hr. Secondary School
# Dimapur | 73/87
# Star Kids
# Dimapur | 74/87
# St. John School
# Dimapur | 75/87
# Evershine High School
# Dimapur | 76/87
# Herbert spencer School
# Dimapur | 77/87
# River Belt School
# Dimapur | 78/87
# Liz Woodland School
# Dimapur | 79/87
# GOVERNMENT HIGH SCHOOL SOVIMA
# Dimapur | 80/87
# Government High School
# Dimapur | 81/87
# Holy Child School
# Dimapur | 82/87
# Shofar Music Academy, Dimapur
# Dimapur | 83/87
# Oracle School Dimapur
# Dimapur | 84/87
# 1St Steer Driving School
# Dimapur | 85/87
# Shemrock & Shemford
# Dimapur | 86/87
# RiverLife School
# Dimapur | 87/87
# CHITRANKAN SCHOOL OF FINE ART & CRAFT
#
# Searching: schools in Kiphire Nagaland
# Search Submitted
# Kiphire | schools | Scroll 1 -> 11
# Kiphire | schools | Scroll 2 -> 11
# Kiphire | schools | Scroll 3 -> 11
# Kiphire | schools | Scroll 4 -> 11
# Kiphire | schools | Scroll 5 -> 11
# Collected 11 links
# Kiphire | 1/11
# Agape Higher Secondary School, Kiphire
# Kiphire | 2/11
# Loyola Higher Secondary School, Kiphire
# Kiphire | 3/11
# Good Shepherd School
# Kiphire | 4/11
# Cambridge High School
# Backup Saved
# Kiphire | 5/11
# El Beth School,Kiphire
# Kiphire | 6/11
# Eastern Christian School
# Kiphire | 7/11
# Saramati View High School
# Kiphire | 8/11
# Govt Higher Secondary School
# Kiphire | 9/11
# Jawahar Navodaya Vidyalaya, Kiphire
# Kiphire | 10/11
# Kichang School compound
# Kiphire | 11/11
# GMS PHED
#
# Searching: schools in Kohima Nagaland
# Search Submitted
# Kohima | schools | Scroll 1 -> 14
# Kohima | schools | Scroll 2 -> 20
# Kohima | schools | Scroll 3 -> 27
# Kohima | schools | Scroll 4 -> 34
# Kohima | schools | Scroll 5 -> 40
# Kohima | schools | Scroll 6 -> 47
# Kohima | schools | Scroll 7 -> 54
# Kohima | schools | Scroll 8 -> 60
# Kohima | schools | Scroll 9 -> 67
# Kohima | schools | Scroll 10 -> 74
# Kohima | schools | Scroll 11 -> 80
# Kohima | schools | Scroll 12 -> 87
# Kohima | schools | Scroll 13 -> 94
# Kohima | schools | Scroll 14 -> 100
# Kohima | schools | Scroll 15 -> 107
# Kohima | schools | Scroll 16 -> 114
# Kohima | schools | Scroll 17 -> 120
# Kohima | schools | Scroll 18 -> 120
# Kohima | schools | Scroll 19 -> 120
# Longleng | schools | Scroll 4 -> 19
# Longleng | schools | Scroll 5 -> 19
# Longleng | schools | Scroll 6 -> 19
# Collected 19 links
# Longleng | 1/19
# Vision Vale School
# Longleng | 2/19
# St. Joseph High School
# Longleng | 3/19
# High school
# Longleng | 4/19
# Tiny Tots Pre-School
# Longleng | 5/19
# High School Ward Junction, Longleng
# Longleng | 6/19
# Shamakok Mission School (SMS)
# Longleng | 7/19
# Govt High School Nyenching
# Longleng | 8/19
# Yingli College
# Longleng | 9/19
# BGHSS
# Longleng | 10/19
# Jawahar Navodaya Vidyalaya
# Longleng | 11/19
# Govt. Primary School B
# Longleng | 12/19
# Government primary school, Nyenching, Longleng
# Longleng | 13/19
# Good Shepherd School
# Longleng | 14/19
# stepping stone hostel
# Longleng | 15/19
# FOOTPRINTS PRESCHOOL Nyengching ward
# Longleng | 16/19
# Blooming Buds School
# Longleng | 17/19
# Baütüng Memorial Hr. Sec. School, Longleng
# Longleng | 18/19
# Nyenching High School
# Longleng | 19/19
# Block School
#
# Searching: schools in Mokokchung Nagaland
# Search Submitted
# Mokokchung | schools | Scroll 1 -> 14
# Mokokchung | schools | Scroll 2 -> 20
# Mokokchung | schools | Scroll 3 -> 27
# Mokokchung | schools | Scroll 4 -> 34
# Mokokchung | schools | Scroll 5 -> 40
# Mokokchung | schools | Scroll 6 -> 47
# Mokokchung | schools | Scroll 7 -> 54
# Mokokchung | schools | Scroll 8 -> 55
# Mokokchung | schools | Scroll 9 -> 55
# Mokokchung | schools | Scroll 10 -> 55
# Mokokchung | schools | Scroll 11 -> 55
# Mokokchung | schools | Scroll 12 -> 55
# Collected 55 links
# Mokokchung | 1/55
# EDEN ACADEMY
# Mokokchung | 2/55
# Queen Mary Higher Secondary School.
# Mokokchung | 3/55
# Assam Rifles High School
# Mokokchung | 4/55
# Straightway Higher Secondary school, Mokokchung
# Mokokchung | 5/55
# Ladybird School
# Mokokchung | 6/55
# Canaan Christian Higher Secondary School
# Mokokchung | 7/55
# Town Higher Secondary School
# Mokokchung | 8/55
# Jubilee Memorial Higher Secondary School
# Mokokchung | 9/55
# Soul House Academy
# Mokokchung | 10/55
# Govt High School, Dilong
# Mokokchung | 11/55
# Mokokchung Driving School
# Mokokchung | 12/55
# Edith Douglas Higher Secondary School
# Mokokchung | 13/55
# Note Grid school of music
# Mokokchung | 14/55
# Mayangnokcha Govt. Hr. Sec. School
# Mokokchung | 15/55
# Government Sumi High School, Majakong Ward
# Mokokchung | 16/55
# Tongdentsuyong Ward Govt.school Mokokchung ,nagaland
# Mokokchung | 17/55
# Jubilee Memorial College
# Mokokchung | 18/55
# Government Middle School Mokokchung Town
# Mokokchung | 19/55
# Christian residential higher secondary school
# Mokokchung | 20/55
# NCRS, Artang Ward
# Mokokchung | 21/55
# Hills Night High School
# Mokokchung | 22/55
# Senayangba Govt. Hr. Sec. School
# Mokokchung | 23/55
# Govt middle school
# Mokokchung | 24/55
# School
# Mokokchung | 25/55
# Model Higher Secondary School
# Mokokchung | 26/55
# A&B sunday school
# Mokokchung | 27/55
# Govt high School Mokokchung village
# Mokokchung | 28/55
# Mount Moriah School
# Mokokchung | 29/55
# Government Middle School, Alempang
# Mokokchung | 30/55
# H&A Arms Incorporation Japanese school
# Mokokchung | 31/55
# Government middle school
# Mokokchung | 32/55
# Government Primary School Yimtsungda
# Mokokchung | 33/55
# Govt Middle School Salangtem
# Mokokchung | 34/55
# Nivukhu High School
# Mokokchung | 35/55
# Blossom Pre School
# Mokokchung | 36/55
# Arujuma Primary School
# Mokokchung | 37/55
# The Ramp modelling academy
# Mokokchung | 38/55
# Senkalemba Government Middle School
# Mokokchung | 39/55
# Chumukedima
# Mokokchung | 40/55
# Bethesda School
# Mokokchung | 41/55
# Nagaland Bible College
# Mokokchung | 42/55
# Kichutip Primary School
# Mokokchung | 43/55
# Edith Douglas Hr. Sec. School. K.L.BLOCK
# Mokokchung | 44/55
# Jubilee Memorial School
# Mokokchung | 45/55
# Main Police Point
# Mokokchung | 46/55
# Entreat Boarding
# Mokokchung | 47/55
# The Nest
# Mokokchung | 48/55
# Fazl Ali College
# Mokokchung | 49/55
# Mongsenbai Ward
# Mokokchung | 50/55
# Mokokchung
# Mokokchung | 51/55
# Kendriya Vidyalaya Tuli, Nagaland
# Mokokchung | 52/55
# Whetstone High, Yimyu Ward
# Mokokchung | 53/55
# GOVT. HIGH SCHOOL NOKSEN; TUENSANG; NAGALAND
# Mokokchung | 54/55
# G.P.S Moalenden
# Mokokchung | 55/55
# Sungkomen Middle School
# Backup Saved
#
# Searching: schools in Mon Nagaland
# Search Submitted
# Mon | schools | Scroll 1 -> 7
# Mon | schools | Scroll 2 -> 7
# Mon | schools | Scroll 3 -> 7
# Mon | schools | Scroll 4 -> 7
# Mon | schools | Scroll 5 -> 7
# Collected 6 links
# Mon | 1/6
# Government Higher Secondary School
# Mon | 2/6
# GHSS Mon Town D
# Mon | 3/6
# St. John's Hr Sec School, Mon
# Mon | 4/6
# Jawahar Navodaya Vidyalaya, Mon
# Mon | 5/6
# Don Bosco Higher Secondary School
# Mon | 6/6
# Edith Douglas School,Mon
#
# Searching: schools in Niuland Nagaland
# Search Submitted
# Niuland | schools | Scroll 1 -> 9
# Niuland | schools | Scroll 2 -> 9
# Niuland | schools | Scroll 3 -> 9
# Niuland | schools | Scroll 4 -> 9
# Niuland | schools | Scroll 5 -> 9
# Collected 8 links
# Niuland | 1/8
# GHSS NIULAND
# Niuland | 2/8
# Modern School
# Niuland | 3/8
# Reginald Hughes Shaw Memorial school
# Niuland | 4/8
# St Joseph's school Niuland
# Niuland | 5/8
# Kiyezu A Village GMS school
# Niuland | 6/8
# Shepherd Montessori School
# Niuland | 7/8
# GPS New Showuba Loyir
# Niuland | 8/8
# Shokhevi Village
#
# Searching: schools in Noklak Nagaland
# Search Submitted
# Noklak | schools | Scroll 1 -> 12
# Noklak | schools | Scroll 2 -> 12
# Noklak | schools | Scroll 3 -> 12
# Noklak | schools | Scroll 4 -> 12
# Noklak | schools | Scroll 5 -> 12
# Collected 12 links
# Noklak | 1/12
# Govt High School Noklak Village.
# Noklak | 2/12
# St,Paul School Noklak
# Noklak | 3/12
# Noklak Govt Higher Secondary School
# Noklak | 4/12
# Holy Angel's School
# Noklak | 5/12
# Christian Higher Secondary School
# Noklak | 6/12
# Model Higher Secondary School
# Noklak | 7/12
# Govt Middle School
# Noklak | 8/12
# Government Primary School Wansoi
# Noklak | 9/12
# Govt.Primary School, Kusong village
# Noklak | 10/12
# GMS Nokyan, Noklak
# Noklak | 11/12
# High school sector'B
# Noklak | 12/12
# OFFICE OF MIRACULLUM SOCIETY NAGALAND
#
# Searching: schools in Peren Nagaland
# Search Submitted
# Peren | schools | Scroll 1 -> 7
# Peren | schools | Scroll 2 -> 7
# Peren | schools | Scroll 3 -> 7
# Peren | schools | Scroll 4 -> 7
# Peren | schools | Scroll 5 -> 7
# Collected 7 links
# Peren | 1/7
# All Saints Hr. Sec. School
# Peren | 2/7
# Govt Higher Secondary
# Peren | 3/7
# Peren Nagaland
# Peren | 4/7
# Peren Government pre School
# Peren | 5/7
# GHS DC COLONY PEREN TOWN
# Peren | 6/7
# L.M. Higher Secondary School, Mhainamtsi
# Peren | 7/7
# Baptist Higher Secondary School, Peren
#
# Searching: schools in Phek Nagaland
# Search Submitted
# Phek | schools | Scroll 1 -> 11
# Phek | schools | Scroll 2 -> 11
# Phek | schools | Scroll 3 -> 11
# Phek | schools | Scroll 4 -> 11
# Phek | schools | Scroll 5 -> 11
# Collected 11 links
# Phek | 1/11
# Baptist Mission High School
# Phek | 2/11
# Royal foundation school phek
# Phek | 3/11
# New life school
# Phek | 4/11
# Bishop Abraham Memorial High School
# Phek | 5/11
# Govt. Middle school
# Phek | 6/11
# Government primary school
# Phek | 7/11
# Christian Mission Higher Secondary School
# Phek | 8/11
# Phek Government College
# Phek | 9/11
# Phek town nagaland
# Phek | 10/11
# Shilloi School
# Phek | 11/11
# Little Angel Pre- School
#
# Searching: schools in Shamator Nagaland
# Search Submitted
# Shamator | schools | Scroll 1 -> 5
# Shamator | schools | Scroll 2 -> 5
# Shamator | schools | Scroll 3 -> 5
# Shamator | schools | Scroll 4 -> 5
# Shamator | schools | Scroll 5 -> 5
# Collected 5 links
# Shamator | 1/5
# Christian High School, Shamator
# Shamator | 2/5
# St. Xavier higher secondary school
# Shamator | 3/5
# GHSS Shamator
# Shamator | 4/5
# Sangto Christain School, Chessore
# Shamator | 5/5
# Primary School
#
# Searching: schools in Tseminyü Nagaland
# Search Submitted
# Tseminyü | schools | Scroll 1 -> 4
# Tseminyü | schools | Scroll 2 -> 4
# Tseminyü | schools | Scroll 3 -> 4
# Tseminyü | schools | Scroll 4 -> 4
# Tseminyü | schools | Scroll 5 -> 4
# Collected 4 links
# Tseminyü | 1/4
# Baptist Higher Secondary School, Tseminyü
# Tseminyü | 2/4
# Govt Primary school
# Tseminyü | 3/4
# Govt. Primary School Zisunyu
# Tseminyü | 4/4
# GHS Tseminyu New Town
#
# Searching: schools in Tuensang Nagaland
# Search Submitted
# Tuensang | schools | Scroll 1 -> 14
# Tuensang | schools | Scroll 2 -> 20
# Tuensang | schools | Scroll 3 -> 27
# Tuensang | schools | Scroll 4 -> 34
# Tuensang | schools | Scroll 5 -> 39
# Tuensang | schools | Scroll 6 -> 39
# Tuensang | schools | Scroll 7 -> 39
# Tuensang | schools | Scroll 8 -> 39
# Tuensang | schools | Scroll 9 -> 39
# Collected 38 links
# Tuensang | 1/38
# St. John's Higher Secondary School
# Tuensang | 2/38
# Akum Imlong School
# Tuensang | 3/38
# Eklavya Model Residential School
# Tuensang | 4/38
# Government Higher Secondary School
# Tuensang | 5/38
# NAP School, Tuensang
# Tuensang | 6/38
# Baptist Thangyen Hr. Sec. School
# Tuensang | 7/38
# Wela foundation school
# Tuensang | 8/38
# St. Joseph's School
# Tuensang | 9/38
# Holy Angel School
# Tuensang | 10/38
# GHSS. Thangjam Tuensang
# Tuensang | 11/38
# Chaolu Sector Chaba School
# Tuensang | 12/38
# Assam Rifles School
# Tuensang | 13/38
# GOvt. High School, Hakushang
# Tuensang | 14/38
# Trinity Academy Tuensang
# Tuensang | 15/38
# School of Nursing Tuensang
# Tuensang | 16/38
# Thangjam govt.hr sc school
# Tuensang | 17/38
# St Johns School
# Tuensang | 18/38
# Driving School Tuensang
# Tuensang | 19/38
# Elite Driving School Tuensang Nagaland
# Tuensang | 20/38
# Bethesda School
# Tuensang | 21/38
# Govt Chaba High School
# Tuensang | 22/38
# Government middle school sangchen village
# Tuensang | 23/38
# Holy Cross High School
# Tuensang | 24/38
# Christ King High School
# Tuensang | 25/38
# Government Middle School
# Tuensang | 26/38
# Sedem GMS
# Tuensang | 27/38
# govt high school kuthur
# Tuensang | 28/38
# Aliya STM
# Tuensang | 29/38
# GMS Ngangpong
# Tuensang | 30/38
# Chopzz
# Tuensang | 31/38
# Star kids montessori
# Tuensang | 32/38
# Govt Primary School (GPS)
# Tuensang | 33/38
# wapher Village
# Tuensang | 34/38
# High School
# Tuensang | 35/38
# Government Primary School
# Tuensang | 36/38
# GMS 3rd NAP Saksi
# Tuensang | 37/38
# St Xavier's High School
# Tuensang | 38/38
# Chana school
#
# Searching: schools in Wokha Nagaland
# Search Submitted
# Wokha | schools | Scroll 1 -> 14
# Wokha | schools | Scroll 2 -> 20
# Wokha | schools | Scroll 3 -> 27
# Wokha | schools | Scroll 4 -> 34
# Wokha | schools | Scroll 5 -> 34
# Wokha | schools | Scroll 6 -> 34
# Wokha | schools | Scroll 7 -> 34
# Wokha | schools | Scroll 8 -> 34
# Collected 34 links
# Wokha | 1/34
# FERNBROOK SCHOOL
# Wokha | 2/34
# SMBE High School
# Wokha | 3/34
# PERENNIAL SCHOOL, Etsutchukha Colony,WOKHA
# Wokha | 4/34
# Don Bosco Higher Secondary School Wokha
# Wokha | 5/34
# Christian Model High School
# Wokha | 6/34
# Isaiah Ability School
# Wokha | 7/34
# Santsuo School
# Wokha | 8/34
# Libemo Memorial School
# Wokha | 9/34
# Government Higher Secondary School
# Backup Saved
# Wokha | 10/34
# Springdale School
# Wokha | 11/34
# Pine Wood School
# Wokha | 12/34
# Grace School
# Wokha | 13/34
# Cistus School
# Wokha | 14/34
# EuroKids Preschool in Blue Hill Colony, Wokha
# Wokha | 15/34
# BETHEL HIGH SCHOOL
# Wokha | 16/34
# Assam Rifles Public School
# Wokha | 17/34
# Government Primary School Midland Wokha
# Wokha | 18/34
# Perennial School Wokha
# Wokha | 19/34
