# %%
import pandas as pd

# %%
df = pd.read_csv("chhattisgarh_schools.csv")

# %%
df.head()
# Out:
#                                          School Name  \
# 0                               Gurukul School Balod
# 1                               Sanskar Shala School
# 2                     Mahaveer English Medium School
# 3                                Kanha Public School
# 4  Junior DPS Balod - Play Group, Nursery, LKG an...
#
#                                         Address            Phone  \
# 0       \nP6H2+4QM, Balod, Chhattisgarh 491226              NaN
# 1       \nP5FX+XV6, Balod, Chhattisgarh 491226  \n099819 86989
# 2       \nP6J5+VC7, Balod, Chhattisgarh 491226              NaN
# 3       \nP6M3+RPP, Balod, Chhattisgarh 491226              NaN
# 4  \nSindhu Bhawan, Balod, Chhattisgarh 491226              NaN
#
#                                     Website     Rating  \
# 0               http://gurukul.imiracle.in/        NaN
# 1                                       NaN  4.6 stars
# 2                                       NaN        NaN
# 3                                       NaN  3.8 stars
# 4  https://www.facebook.com/JuniorDPSBalod/  5.0 stars
#
#                                      Google Maps URL District Search Type
# 0  https://www.google.com/maps/place/Gurukul+Scho...    Balod     schools
# 1  https://www.google.com/maps/place/Sanskar+Shal...    Balod     schools
# 2  https://www.google.com/maps/place/Mahaveer+Eng...    Balod     schools
# 3  https://www.google.com/maps/place/Kanha+Public...    Balod     schools
# 4  https://www.google.com/maps/place/Junior+DPS+B...    Balod     schools

# %%
df.shape
# Out:
# (1659, 8)

# %%
duplicate_count = df.duplicated(
    subset=["School Name", "Google Maps URL"]
).sum()
duplicate_count
# Out:
# np.int64(0)

# %%
df = df[
    df["Phone"].notna() & 
    (df["Phone"].astype(str).str.strip() != "")
    ]

# %%
df.shape
# Out:
# (411, 8)

# %%
# CLEAN PHONE COLUMNS
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]","",regex=True)
    .str.strip()
)

display(df[["Phone"]].head())
# Out:
#            Phone
# 1   099819 86989
# 12  094255 61084
# 14  077492 22076
# 15  099817 96438
# 16  062630 79778

# %%
# SAVE CLEANED FILE
df.to_csv(
    "chhattisgarh_schools_cleaned.csv",
    index=False
)
