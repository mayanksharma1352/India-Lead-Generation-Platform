# %%
import time
import random
import pandas as pd

from datetime import datetime

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.service import Service

from webdriver_manager.chrome import ChromeDriverManager


# CHATTISGARH DISTRICTS

districts = [
    "Balod",
    "Baloda Bazar",
    "Balrampur",
    "Bastar",
    "Bemetara",
    "Bijapur",
    "Bilaspur",
    "Dantewada",
    "Dhamtari",
    "Durg",
    "Gariaband",
    "Gaurela-Pendra-Marwahi",
    "Janjgir-Champa",
    "Jashpur",
    "Kabirdham",
    "Kanker",
    "Khairagarh-Chhuikhadan-Gandai",
    "Kondagaon",
    "Korba",
    "Korea",
    "Mahasamund",
    "Manendragarh-Chirmiri-Bharatpur",
    "Mohla-Manpur-Ambagarh Chowki",
    "Mungeli",
    "Narayanpur",
    "Raigarh",
    "Raipur",
    "Rajnandgaon",
    "Sakti",
    "Sarangarh-Bilaigarh",
    "Sukma",
    "Surajpur",
    "Surguja"
]


# SEARCH TYPES

search_types = [
    "schools"
]

# CHROME OPTIONS

options = webdriver.ChromeOptions()

options.add_argument("--start-maximized")

options.add_argument(
    "--disable-blink-features=AutomationControlled"
)

options.add_argument("--disable-notifications")

# START DRIVER

driver = webdriver.Chrome(

    service=Service(
        ChromeDriverManager().install()
    ),

    options=options
)


# OPEN GOOGLE MAPS

driver.get("https://www.google.com/maps")

print("Opening Google Maps...")

time.sleep(15)

print("Google Maps Loaded")


# STORAGE


all_data = []

visited_links = set()


# SEARCH BOX FUNCTION


def get_search_box():

    selectors = [

        '//input[@id="searchboxinput"]',
        '//input[contains(@placeholder,"Search")]',
        '//input[contains(@aria-label,"Search")]',
        '//input'

    ]

    for selector in selectors:

        try:

            box = driver.find_element(
                By.XPATH,
                selector
            )

            return box

        except:
            pass

    return None

# EXTRACT SCHOOL DATA

def extract_school_data():

    try:

        # SCHOOL NAME
        try:
            name = driver.find_element(
                By.TAG_NAME,
                "h1"
            ).text
        except:
            name = ""

        # ADDRESS
        try:
            address = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"address")]'
            ).text
        except:
            address = ""

        # PHONE
        try:
            phone = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"phone")]'
            ).text
        except:
            phone = ""

        # WEBSITE
        try:
            website = driver.find_element(
                By.XPATH,
                '//a[contains(@data-item-id,"authority")]'
            ).get_attribute("href")
        except:
            website = ""

        # RATING
        try:
            rating = driver.find_element(
                By.XPATH,
                '//div[@role="img"]'
            ).get_attribute("aria-label")
        except:
            rating = ""

        return {

            "School Name": name,
            "Address": address,
            "Phone": phone,
            "Website": website,
            "Rating": rating,
            "Google Maps URL": driver.current_url

        }

    except:

        return None


# START EXTRACTION

for district in districts:

    for search_type in search_types:

        try:

            query = (
                f"{search_type} "
                f"in {district} Chhattisgarh"
            )

            print(f"\nSearching: {query}")

   
            # SEARCH

            search_box = get_search_box()

            if not search_box:

                print("Search Box Not Found")

                continue

            ActionChains(driver).move_to_element(
                search_box
            ).click().perform()

            time.sleep(1)

            search_box.send_keys(
                Keys.CONTROL + "a"
            )

            time.sleep(1)

            search_box.send_keys(Keys.DELETE)

            time.sleep(1)

            # TYPE SLOWLY
            for char in query:

                search_box.send_keys(char)

                time.sleep(0.03)

            search_box.send_keys(Keys.ENTER)

            print("Search Submitted")

            time.sleep(8)

            # SCROLL RESULTS

            try:

                scrollable_div = driver.find_element(
                    By.XPATH,
                    '//div[@role="feed"]'
                )

                previous_count = 0

                stagnant = 0

                for i in range(100):

                    driver.execute_script(
                        """
                        arguments[0].scrollTop =
                        arguments[0].scrollHeight
                        """,
                        scrollable_div
                    )

                    time.sleep(4)

                    listings = driver.find_elements(
                        By.XPATH,
                        '//a[contains(@href,"/maps/place/")]'
                    )

                    current_count = len(listings)

                    print(
                        f"{district} | "
                        f"{search_type} | "
                        f"Scroll {i+1} -> "
                        f"{current_count}"
                    )

                    if current_count == previous_count:

                        stagnant += 1

                    else:

                        stagnant = 0

                    if stagnant >= 4:

                        break

                    previous_count = current_count

            except Exception as e:

                print(f"Scrolling Error: {e}")

            # GET LINK

            listings = driver.find_elements(
                By.XPATH,
                '//a[contains(@href,"/maps/place/")]'
            )

            links = []

            for listing in listings:

                try:

                    link = listing.get_attribute("href")

                    if (
                        link
                        and link not in visited_links
                    ):

                        links.append(link)

                        visited_links.add(link)

                except:
                    pass

            print(f"Collected {len(links)} links")

            # VISIT EACH SCHOOL

            for index, link in enumerate(links):

                try:

                    print(
                        f"{district} | "
                        f"{index+1}/{len(links)}"
                    )

                    driver.get(link)

                    time.sleep(
                        random.uniform(2, 3)
                    )

                    data = extract_school_data()

                    if data:

                        data["District"] = district

                        data["Search Type"] = search_type

                        all_data.append(data)

                        print(data["School Name"])

   
                    # BACKUP SAVE

                    if len(all_data) % 100 == 0:

                        backup_df = pd.DataFrame(
                            all_data
                        )

                        backup_df.drop_duplicates(
                            subset=[
                                "School Name",
                                "Google Maps URL"
                            ],
                            inplace=True
                        )

                        backup_df.to_csv(
                            "chhattisgarh_schools_backup.csv",
                            index=False
                        )

                        print("Backup Saved")

                except Exception as e:

                    print(
                        f"School Error: {e}"
                    )

        except Exception as e:

            print(
                f"District Error: {e}"
            )

# FINAL SAVE


df = pd.DataFrame(all_data)

df.drop_duplicates(

    subset=[
        "School Name",
        "Google Maps URL"
    ],

    inplace=True
)

# UNIQUE FILE NAME

filename = (
    f"chhattisgarh_schools.csv"
)

df.to_csv(
    filename,
    index=False
)

print("\nExtraction Completed")

print(
    f"Total Schools Extracted: {len(df)}"
)

print(f"\nSaved File: {filename}")

driver.quit()
# Out:
# Opening Google Maps...
# Google Maps Loaded
#
# Searching: schools in Balod Chhattisgarh
# Search Submitted
# Balod | schools | Scroll 1 -> 14
# Balod | schools | Scroll 2 -> 20
# Balod | schools | Scroll 3 -> 22
# Balod | schools | Scroll 4 -> 22
# Balod | schools | Scroll 5 -> 22
# Balod | schools | Scroll 6 -> 22
# Balod | schools | Scroll 7 -> 22
# Collected 22 links
# Balod | 1/22
# Gurukul School Balod
# Balod | 2/22
# Sanskar Shala School
# Balod | 3/22
# Mahaveer English Medium School
# Balod | 4/22
# Kanha Public School
# Balod | 5/22
# Junior DPS Balod - Play Group, Nursery, LKG and UKG
# Balod | 6/22
# Arihant Academy Balod
# Balod | 7/22
# Swami Atmanand english Medium School, Balod
# Balod | 8/22
# Blaze Academy Balod
# Balod | 9/22
# Jawahar Navodaya Vidyalaya Balod
# Balod | 10/22
# Sarswati Shishu Mandir
# Balod | 11/22
# Govt. Boys School Balod
# Balod | 12/22
# Excellent Public School
# Balod | 13/22
# Govt.Girls School Balod
# Balod | 14/22
# Govt High School,Amapara
# Balod | 15/22
# Govt. Ghanshyam Singh Gupt P.G. College Balod
# Balod | 16/22
# SANTOSHI COMPUTER CENTER
# Balod | 17/22
# ST. KABIR’S PUBLIC SCHOOL
# Balod | 18/22
# Sure Success Pvt. iti Balod
# Balod | 19/22
# GOVT. EKLAVYA MODEL RESIDENTIAL SCHOOL DONDI,DALLI RAJHARA,BALOD,(C.G.)
# Balod | 20/22
# Dream India School Balod
# Balod | 21/22
# SHRI HARI PUBLIC SCHOOL
# Balod | 22/22
# Bhengari
#
# Searching: schools in Baloda Bazar Chhattisgarh
# Search Submitted
# Baloda Bazar | schools | Scroll 1 -> 14
# Baloda Bazar | schools | Scroll 2 -> 20
# Baloda Bazar | schools | Scroll 3 -> 27
# Baloda Bazar | schools | Scroll 4 -> 34
# Baloda Bazar | schools | Scroll 5 -> 40
# Baloda Bazar | schools | Scroll 6 -> 47
# Baloda Bazar | schools | Scroll 7 -> 54
# Baloda Bazar | schools | Scroll 8 -> 60
# Baloda Bazar | schools | Scroll 9 -> 67
# Baloda Bazar | schools | Scroll 10 -> 74
# Baloda Bazar | schools | Scroll 11 -> 80
# Baloda Bazar | schools | Scroll 12 -> 87
# Baloda Bazar | schools | Scroll 13 -> 94
# Baloda Bazar | schools | Scroll 14 -> 95
# Baloda Bazar | schools | Scroll 15 -> 95
# Baloda Bazar | schools | Scroll 16 -> 95
# Baloda Bazar | schools | Scroll 17 -> 95
# Baloda Bazar | schools | Scroll 18 -> 95
# Collected 95 links
# Baloda Bazar | 1/95
# Pathshala, English Medium School
# Baloda Bazar | 2/95
# Gurukul EMS School Baloda Bazar
# Baloda Bazar | 3/95
# Sacred Heart High School
# Baloda Bazar | 4/95
# Kids Express School
# Baloda Bazar | 5/95
# R.K.G. Higher Secondary School , Baloda Bazar
# Baloda Bazar | 6/95
# ADARSH PUBLIC SCHOOL
# Baloda Bazar | 7/95
# Dream India School, Balodabazar
# Baloda Bazar | 8/95
# Bachpan Play School in Gaurav Path Baloda Bazar | Best Preschool Near Me | Nursery School for Your Child’s Bright Start
# Baloda Bazar | 9/95
# VARDHMAN VIDYA PEETH
# Baloda Bazar | 10/95
# Makoons pre-school Baloda Bazar
# Baloda Bazar | 11/95
# SHUKLA STUDY CENTER
# Baloda Bazar | 12/95
# District Education Office Balodabazar
# Baloda Bazar | 13/95
# Bilaspur psc academy ,Baloda bazar (c. g.)
# Baloda Bazar | 14/95
# Government Basic Primary School Baloda Bazar
# Baloda Bazar | 15/95
# Pt. L.P.T. Govt Girls' Higher Secondary School Baodabazar
# Baloda Bazar | 16/95
# Extraordinary World Class School
# Baloda Bazar | 17/95
# ASKIT!
# Baloda Bazar | 18/95
# Baloda Bazar | 67/95
# Gudiya Beauty Parlour ks
# Baloda Bazar | 68/95
# Ambuja Vidya Peeth
# Baloda Bazar | 69/95
# M.D.V. Utkrisht Vidyalay
# Baloda Bazar | 70/95
# The Aditya Birla Public School
# Baloda Bazar | 71/95
# Ps बालक शाला
# Baloda Bazar | 72/95
# Bhupendra Markande
# Baloda Bazar | 73/95
# Om Sai Cakes and Baking Classes
# Baloda Bazar | 74/95
# Preeti
# Baloda Bazar | 75/95
# powertech solar construction
# Baloda Bazar | 76/95
# Zila Panchayat Balodabazar
# Baloda Bazar | 77/95
# high school garden
# Baloda Bazar | 78/95
# Ayush Diagnostic Pathology Lab
# Backup Saved
# Baloda Bazar | 79/95
# Bake By Day
# Baloda Bazar | 80/95
# Shri Ram Printers
# Baloda Bazar | 81/95
# DAV Mukhyamantri Public School Chharchhed
# Baloda Bazar | 82/95
# Mahatma Gandhi little garden
# Baloda Bazar | 83/95
# Anupam Bazar
# Baloda Bazar | 84/95
# DAV MUKHYAMANTRI PUBLIC SCHOOL
# Baloda Bazar | 85/95
# Foodcosta Baloda Bazar
# Baloda Bazar | 86/95
# Scoop N Delight
# Baloda Bazar | 87/95
# Panchsheel Nagar
# Baloda Bazar | 88/95
# BHOOMI MOBILE & SALES
# Baloda Bazar | 89/95
# Govt.Primary School Sonpuri
# Baloda Bazar | 90/95
# Zaika Restro
# Baloda Bazar | 91/95
# Mareen Drive Balodabazar
# Baloda Bazar | 92/95
# Rajiv Nagar
# Baloda Bazar | 93/95
# Tulsi sadan
# Baloda Bazar | 94/95
# The MUSIC academy
# Baloda Bazar | 95/95
# VIDYARTHI ONLINE CENTER
#
# Searching: schools in Balrampur Chhattisgarh
# Search Submitted
# Balrampur | schools | Scroll 1 -> 7
# Balrampur | schools | Scroll 2 -> 7
# Balrampur | schools | Scroll 3 -> 7
# Balrampur | schools | Scroll 4 -> 7
# Balrampur | schools | Scroll 5 -> 7
# Collected 7 links
# Balrampur | 1/7
# SHRI DURGA GURUKULAM SCHOOL
# Balrampur | 2/7
# St. Xavier's Sr. Sec. School Balrampur
# Balrampur | 3/7
# Eklavya Model Residential School Bhelwadih Balrampur
# Balrampur | 4/7
# City Montessori Inter College
# Balrampur | 5/7
# Laurel Convent Academy English Medium school
# Balrampur | 6/7
# New Era Public School
# Balrampur | 7/7
# SAGES, BALRAMPUR
#
# Searching: schools in Bastar Chhattisgarh
# Search Submitted
# Bastar | schools | Scroll 1 -> 3
# Bastar | schools | Scroll 2 -> 3
# Bastar | schools | Scroll 3 -> 3
# Bastar | schools | Scroll 4 -> 3
# Bastar | schools | Scroll 5 -> 3
# Collected 3 links
# Bastar | 1/3
# Jagatu Mahara Govt. Multipurpose H.S. School, Jagdalpur (Bastar High School)
# Bastar | 2/3
# Bastar Valley English Medium School
# Bastar | 3/3
# Sanskar - The Gurukul International School
#
# Searching: schools in Bemetara Chhattisgarh
# Search Submitted
# Bemetara | schools | Scroll 1 -> 14
# Bemetara | schools | Scroll 2 -> 16
# Bemetara | schools | Scroll 3 -> 16
# Bemetara | schools | Scroll 4 -> 16
# Bemetara | schools | Scroll 5 -> 16
# Bemetara | schools | Scroll 6 -> 16
# Collected 16 links
# Bemetara | 1/16
# Academic World School.
# Bemetara | 2/16
# Gyanoday Public School
# Bemetara | 3/16
# Allons Public School
# Bemetara | 4/16
# Shree Public School
# Bemetara | 5/16
# Mind's Eye International School Bemetara
# Bemetara | 6/16
# Ambo Public School
# Bemetara | 7/16
# Indian Puplic Higher Secondary School
# Bemetara | 8/16
# Bemetara Middle High School
# Bemetara | 9/16
# CSC Bal Vidyalaya
# Bemetara | 10/16
# Swami atmanand English medium Govt school
# Bemetara | 11/16
# Prerana Vidyalaya
# Bemetara | 12/16
# BDSPublic School
# Bemetara | 13/16
# Dream India School Bemetara
# Bemetara | 14/16
# DAV MUKHYAMANTRI PUBLIC SCHOOL
# Bemetara | 15/16
# PM Shri Jawahar Navodaya Vidyalaya-Bahera (Kusmi), Bemetara
# Bemetara | 16/16
# S.G.M. Public School Bemetara {Hindi & English Medium School}
#
# Searching: schools in Bijapur Chhattisgarh
# Search Submitted
# Bijapur | schools | Scroll 1 -> 10
# Bijapur | schools | Scroll 2 -> 10
# Bijapur | schools | Scroll 3 -> 10
# Bijapur | schools | Scroll 4 -> 10
# Bijapur | schools | Scroll 5 -> 10
# Collected 10 links
# Bijapur | 1/10
# S.T. THOMAS SCHOOL BIJAPUR CHHATTISGARH
# Bijapur | 2/10
# ADESHWAR PUBLIC SCHOOL BIJAPUR CHHATTISGARH
# Bijapur | 3/10
# Alfa English Medium School Bijapur Chhattisgarh
# Bijapur | 4/10
# BLESING ENGLISH MEDIUM SCHOOL
# Bijapur | 5/10
# GOVERNMENT HIGH SCHOOL BIJAPUR CHHATTISGARH
# Bijapur | 6/10
# Kendriya Vidyalaya, Bijapur C.G.
# Bijapur | 7/10
# Govt CBSE English Medium Middle School chhinnakodepal(Shanti Nagar)
# Bijapur | 8/10
# Swami Atmanand Govt. English School, Bijapur Chhattisgarh
# Bijapur | 9/10
# Jawahar Navodaya Vidyalya Bijapur CG
# Bijapur | 10/10
# Ever Blooming School
#
# Searching: schools in Bilaspur Chhattisgarh
# Search Submitted
# Bilaspur | schools | Scroll 1 -> 14
# Bilaspur | schools | Scroll 2 -> 20
# Bilaspur | schools | Scroll 3 -> 27
# Bilaspur | schools | Scroll 4 -> 30
# Bilaspur | schools | Scroll 5 -> 30
# Bilaspur | schools | Scroll 6 -> 30
# Bilaspur | schools | Scroll 7 -> 30
# Bilaspur | schools | Scroll 8 -> 30
# Collected 30 links
# Bilaspur | 1/30
# Delhi Public School, Bilaspur
# Bilaspur | 2/30
# Narayana eTechno (CBSE) School - Bilaspur
# Bilaspur | 3/30
# Arpa River Valley International School Bilaspur, Chhattisgarh
# Bilaspur | 4/30
# The Jain International School, Bilaspur
# Bilaspur | 5/30
# Aadharshila Vidya Mandir
# Bilaspur | 6/30
# Burgess English School
# Bilaspur | 7/30
# Sandipani Public School - Best CBSE School in Bilaspur
# Bilaspur | 8/30
# Loyola School Bilaspur
# Bilaspur | 9/30
# Winners Valley English School
# Bilaspur | 10/30
# MGM Public School, CBSE Affiliated, Ghuru, Bilaspur
# Bilaspur | 11/30
# The New India Higher Secondary School
# Bilaspur | 12/30
# Shikha Public School
# Bilaspur | 13/30
# Akshay Gurukul
# Bilaspur | 14/30
# Brilliant Public School, Mission Hospital Road
# Bilaspur | 15/30
# HSM Global Public School
# Bilaspur | 16/30
# Holy Cross Higher Secondary School
# Bilaspur | 17/30
# Colonels Academy of Radiant Education Public School
# Bilaspur | 18/30
# Prayas Academy Bilaspur
# Bilaspur | 19/30
# St. Joseph Hindi Medium School
# Bilaspur | 20/30
# Andhra Samaj
# Bilaspur | 21/30
# Trimurty Public School
# Bilaspur | 22/30
# nav chetan play school
# Bilaspur | 23/30
# CHILDREN VALLEY SCHOOL
# Bilaspur | 24/30
# Government Higher Secondary School
# Bilaspur | 25/30
# Higher Secondary School
# Bilaspur | 26/30
# Maharani Laxmi Bai Govt. High School
# Bilaspur | 27/30
# burgees higher secondary school
# Bilaspur | 28/30
# Aditya Birla school in Bilaspur city Chhattisgarh
# Bilaspur | 29/30
# Prayas Residential School Bilaspur
# Bilaspur | 30/30
# Maharishi Vidya Mandir, Mangla, Bilaspur
#
# Searching: schools in Dantewada Chhattisgarh
# Search Submitted
# Dantewada | schools | Scroll 1 -> 5
# Dantewada | schools | Scroll 2 -> 5
# Dantewada | schools | Scroll 3 -> 5
# Dantewada | schools | Scroll 4 -> 5
# Dantewada | schools | Scroll 5 -> 5
# Collected 5 links
# Dantewada | 1/5
# Arunodaya Public School
# Dantewada | 2/5
# Near Aatmanand Hindi medium school Dantewada
# Dantewada | 3/5
# Govt. H S S, Dantewada
# Dantewada | 4/5
# Eklavya model residential school dantewada
# Dantewada | 5/5
# Kendriya Vidyalaya Dantewada
#
# Searching: schools in Dhamtari Chhattisgarh
# Search Submitted
# Dhamtari | schools | Scroll 1 -> 14
# Dhamtari | schools | Scroll 2 -> 20
# Dhamtari | schools | Scroll 3 -> 27
# Dhamtari | schools | Scroll 4 -> 34
# Dhamtari | schools | Scroll 5 -> 40
# Dhamtari | schools | Scroll 6 -> 47
# Dhamtari | schools | Scroll 7 -> 54
# Dhamtari | schools | Scroll 8 -> 60
# Dhamtari | schools | Scroll 9 -> 67
# Dhamtari | schools | Scroll 10 -> 74
# Dhamtari | schools | Scroll 11 -> 80
# Dhamtari | schools | Scroll 12 -> 87
# Dhamtari | schools | Scroll 13 -> 94
# Dhamtari | schools | Scroll 14 -> 94
# Dhamtari | schools | Scroll 15 -> 94
# Dhamtari | schools | Scroll 16 -> 94
# Dhamtari | schools | Scroll 17 -> 94
# Collected 94 links
# Dhamtari | 1/94
# Ryan International School, Dhamtari - ICSE
# Dhamtari | 2/94
# Mennonite Eng. Sr. Sec. School
# Dhamtari | 3/94
# St. Mary's English Medium School
# Dhamtari | 4/94
# Vidhya Kunj Memorial School
# Dhamtari | 5/94
# Millennium School, Best Preschool in Dhamtari, Best Primary School in Dhamtari, Swimming Skating Classes in Dhamtari
# Dhamtari | 6/94
# Dr. Shobha Ram Dewangan Government Higher Secondary School
# Dhamtari | 7/94
# Dhamtari | 56/94
# DHAMTARI COLLEGE OF NURSING
# Dhamtari | 57/94
# Vidhya Kunj Kids, Shivaji Nagar
# Dhamtari | 58/94
# Govt. Girls H. S. School Dhamtari
# Dhamtari | 59/94
# Jalampur Middle School.
# Dhamtari | 60/94
# Government School,Civil Lines
# Dhamtari | 61/94
# Government Girls School for Hearing Impaired Dhamtari
# Dhamtari | 62/94
# KG Building Dhamtari
# Dhamtari | 63/94
# Hatkeshwar school
# Dhamtari | 64/94
# EIC CLASSES
# Dhamtari | 65/94
# Govt. Primary School Arjuni
# Dhamtari | 66/94
# School/institute
# Dhamtari | 67/94
# Swami Atmanand English Medium school Scheme Gokulpur
# Dhamtari | 68/94
# Govt. High School SoridBhat
# Dhamtari | 69/94
# Gyan Amrit Primary School
# Dhamtari | 70/94
# Aadhar shila Play school rudri,Dhamtari
# Dhamtari | 71/94
# R3 रिदम राग रंग एकेडमी (school of music & art's)
# Dhamtari | 72/94
# Afzal sir commerce class
# Dhamtari | 73/94
# Pace Hospitality Training Center Dhamtari (chhattisgarh)
# Dhamtari | 74/94
# vandemataram English Medium School
# Dhamtari | 75/94
# ANAND MARG SCHOOL DHAMTARI
# Dhamtari | 76/94
# Govt. Middle school JODHAPUR
# Dhamtari | 77/94
# Nutan Higher Secondary School
# Dhamtari | 78/94
# Mahadev Agency
# Dhamtari | 79/94
# Deepak Electronics
# Dhamtari | 80/94
# Dial dhamtari
# Dhamtari | 81/94
# Kosta para
# Dhamtari | 82/94
# KV Dance Company
# Dhamtari | 83/94
# Mahaveer prajapati
# Dhamtari | 84/94
# Inventure Education Public School
# Dhamtari | 85/94
# Kendriya Vidyalaya Dhamtari
# Dhamtari | 86/94
# Genius Public School Nagri
# Dhamtari | 87/94
# Govt Primary And Higher Secandry School hatkeshar
# Dhamtari | 88/94
# Swami atmananda english Medical school scheme
# Dhamtari | 89/94
# Shiv Singh Verma Govt Hr Sec School Dhamtari
# Dhamtari | 90/94
# Ken Academy
# Dhamtari | 91/94
# saraswati gyan mandir high school
# Dhamtari | 92/94
# CG SGM ENGLISH SCHOOL DHAMTARI
# Dhamtari | 93/94
# P.M. S.H.R.I. Jawahar Navodaya Vidyalaya
# Dhamtari | 94/94
# Shri Ritu Agency
#
# Searching: schools in Durg Chhattisgarh
# Search Submitted
# Durg | schools | Scroll 1 -> 14
# Durg | schools | Scroll 2 -> 20
# Durg | schools | Scroll 3 -> 27
# Durg | schools | Scroll 4 -> 34
# Durg | schools | Scroll 5 -> 40
# Durg | schools | Scroll 6 -> 47
# Durg | schools | Scroll 7 -> 54
# Durg | schools | Scroll 8 -> 60
# Durg | schools | Scroll 9 -> 67
# Durg | schools | Scroll 10 -> 74
# Durg | schools | Scroll 11 -> 80
# Durg | schools | Scroll 12 -> 87
# Durg | schools | Scroll 13 -> 94
# Durg | schools | Scroll 14 -> 100
# Durg | schools | Scroll 15 -> 107
# Durg | schools | Scroll 16 -> 114
# Durg | schools | Scroll 17 -> 120
# Durg | schools | Scroll 18 -> 120
# Durg | schools | Scroll 19 -> 120
# Durg | schools | Scroll 20 -> 120
# Vardan Patni's Physics Classes
# Durg | 116/119
# Krishna Public School Utai-Bhilai
# Durg | 117/119
# Mirza's Academy Of English
# Durg | 118/119
# zooom driving school bhilai
# Backup Saved
# Durg | 119/119
# Rungta Play School
#
# Searching: schools in Gariaband Chhattisgarh
# Search Submitted
# Gariaband | schools | Scroll 1 -> 10
# Gariaband | schools | Scroll 2 -> 15
# Gariaband | schools | Scroll 3 -> 16
# Gariaband | schools | Scroll 4 -> 16
# Gariaband | schools | Scroll 5 -> 16
# Gariaband | schools | Scroll 6 -> 16
# Gariaband | schools | Scroll 7 -> 16
# Collected 16 links
# Gariaband | 1/16
# Dronacharya Public School Gariyaband
# Gariaband | 2/16
# Shraddha Public School
# Gariaband | 3/16
# Angels Anglo Public School
# Gariaband | 4/16
# Girl's Higher Secondary School Gariyaband
# Gariaband | 5/16
# Disha computer education
# Gariaband | 6/16
# School
# Gariaband | 7/16
# Government Higher Secondary High School
# Gariaband | 8/16
# Saraswati shishu mandir
# Gariaband | 9/16
# Dav Mukhyamantri Public School
# Gariaband | 10/16
# Government Veer Surendra Sai P G College Gariaband
# Gariaband | 11/16
# Lochan
# Gariaband | 12/16
# JAWAHAR NAVODAYA VIDYALAY
# Gariaband | 13/16
# Kokadachheda
# Gariaband | 14/16
# Gariyaband
# Gariaband | 15/16
# Dav Mukhyamantri Public School
# Gariaband | 16/16
# महाड़िक निवास गरियाबंद
#
# Searching: schools in Gaurela-Pendra-Marwahi Chhattisgarh
# Search Submitted
# Gaurela-Pendra-Marwahi | schools | Scroll 1 -> 14
# Gaurela-Pendra-Marwahi | schools | Scroll 2 -> 20
# Gaurela-Pendra-Marwahi | schools | Scroll 3 -> 27
# Gaurela-Pendra-Marwahi | schools | Scroll 4 -> 34
# Gaurela-Pendra-Marwahi | schools | Scroll 5 -> 40
# Gaurela-Pendra-Marwahi | schools | Scroll 6 -> 47
# Gaurela-Pendra-Marwahi | schools | Scroll 7 -> 51
# Gaurela-Pendra-Marwahi | schools | Scroll 8 -> 51
# Gaurela-Pendra-Marwahi | schools | Scroll 9 -> 51
# Gaurela-Pendra-Marwahi | schools | Scroll 10 -> 51
# Gaurela-Pendra-Marwahi | schools | Scroll 11 -> 51
# Collected 51 links
# Gaurela-Pendra-Marwahi | 1/51
# Maa Kalyanika Public School
# Gaurela-Pendra-Marwahi | 2/51
# A.S.N. English Medium School
# Gaurela-Pendra-Marwahi | 3/51
# St. Mary's School
# Gaurela-Pendra-Marwahi | 4/51
# Multipurpose
# Gaurela-Pendra-Marwahi | 5/51
# Omeena Kindergaten English Medium School Pendra Road
# Gaurela-Pendra-Marwahi | 6/51
# Government Middle School Darripara,(Pankota),Pendra, Gaurela-Pendra-Marwahi(GPM) ,(Chhattisgarh)
# Gaurela-Pendra-Marwahi | 7/51
# Saraswati Shishu Mandir School
# Gaurela-Pendra-Marwahi | 8/51
# Play Way Mixed Medium High School pendra
# Gaurela-Pendra-Marwahi | 9/51
# High school tikarkhurd gaurella
# Gaurela-Pendra-Marwahi | 10/51
# Goverment primary school bagra
# Gaurela-Pendra-Marwahi | 11/51
# शासकीय प्राथमिक शाला करचापारा,नवागांव
# Gaurela-Pendra-Marwahi | 49/51
# Narmada School of Secondary Education
# Gaurela-Pendra-Marwahi | 50/51
# Oxford public school Pendraroad
# Gaurela-Pendra-Marwahi | 51/51
# Kerala English Medium School Pendra
#
# Searching: schools in Janjgir-Champa Chhattisgarh
# Search Submitted
# Janjgir-Champa | schools | Scroll 1 -> 14
# Janjgir-Champa | schools | Scroll 2 -> 20
# Janjgir-Champa | schools | Scroll 3 -> 27
# Janjgir-Champa | schools | Scroll 4 -> 34
# Janjgir-Champa | schools | Scroll 5 -> 40
# Janjgir-Champa | schools | Scroll 6 -> 47
# Janjgir-Champa | schools | Scroll 7 -> 54
# Janjgir-Champa | schools | Scroll 8 -> 60
# Janjgir-Champa | schools | Scroll 9 -> 67
# Janjgir-Champa | schools | Scroll 10 -> 71
# Janjgir-Champa | schools | Scroll 11 -> 71
# Janjgir-Champa | schools | Scroll 12 -> 71
# Janjgir-Champa | schools | Scroll 13 -> 71
# Janjgir-Champa | schools | Scroll 14 -> 71
# Collected 71 links
# Janjgir-Champa | 1/71
# Delhi Public School, Janjgir-Champa | DPS | Best school in Janjgir | Best school in Champa
# Janjgir-Champa | 2/71
# Brilliant Public School - Best CBSE School in Janjgir. Top School in Jangir-Champa.
# Janjgir-Champa | 3/71
# Gurukul International School Janjgir
# Janjgir-Champa | 4/71
# Hariram Gattani Memorial Jay Bharat English Medium School , janjgir
# Janjgir-Champa | 5/71
# Gyandeep Hr. Sec. School Janjgir
# Janjgir-Champa | 6/71
# Lotus Public School, Janjgir
# Janjgir-Champa | 7/71
# Government Higher Secondary School No.1 JANJGIR
# Janjgir-Champa | 8/71
# Vivekanand Vidyalaya Janjgir
# Janjgir-Champa | 9/71
# Shemrock late Pavansingh Yadav Memorial Next Generation Play school
# Janjgir-Champa | 10/71
# GyanBharti Hr. Sec. School JANJGIR
# Janjgir-Champa | 11/71
# HASDEO PUBLIC SCHOOL, CHAMPA
# Janjgir-Champa | 12/71
# Gyanjyoti Higher Secondary School Janjgir
# Janjgir-Champa | 13/71
# Jay Bharat School
# Janjgir-Champa | 14/71
# Lions D.A.V. Public School, Akaltara
# Janjgir-Champa | 15/71
# Manka Public School Champa
# Janjgir-Champa | 16/71
# Gyanoday Janjgir
# Janjgir-Champa | 17/71
# DESTINATION ENGLISH MEDIUM SCHOOL, PENDRI BRANCH, JANJGIR
# Janjgir-Champa | 18/71
# Government Girls Higher Secondary School Janjgir
# Janjgir-Champa | 19/71
# Vidyasagar Academic Public School
# Janjgir-Champa | 20/71
# LOTUS PUBLIC SCHOOL
# Janjgir-Champa | 21/71
# Indian Public School Janjgir
# Janjgir-Champa | 22/71
# Government Girls School, Janjgir
# Janjgir-Champa | 23/71
# Lines English Medium School, Janjgir, Chhattisgarh, India
# Janjgir-Champa | 24/71
# CGM Jay Bharat Public School Janjgir
# Janjgir-Champa | 25/71
# High School Ground
# Janjgir-Champa | 26/71
# Gyanbharti English Medium School JANJGIR
# Janjgir-Champa | 27/71
# DIVINE PUBLIC SCHOOL
# Janjgir-Champa | 28/71
# Jupiter Word English Medium School
#
# Searching: schools in Jashpur Chhattisgarh
# Search Submitted
# Jashpur | schools | Scroll 1 -> 9
# Jashpur | schools | Scroll 2 -> 9
# Jashpur | schools | Scroll 3 -> 9
# Jashpur | schools | Scroll 4 -> 9
# Jashpur | schools | Scroll 5 -> 9
# Collected 9 links
# Jashpur | 1/9
# Jashpuranchal English School
# Jashpur | 2/9
# Dev Public School
# Jashpur | 3/9
# Govt Model Higher Secondary School
# Jashpur | 4/9
# holycross english medium school, gholeng, jashpur
# Jashpur | 5/9
# DPS Primary School
# Jashpur | 6/9
# Mlb girls School
# Jashpur | 7/9
# Kendriya Vidyalaya Jashpur
# Jashpur | 8/9
# s m d jain high school
# Jashpur | 9/9
# District Education office
#
# Searching: schools in Kabirdham Chhattisgarh
# Search Submitted
# Kabirdham | schools | Scroll 1 -> 14
# Kabirdham | schools | Scroll 2 -> 20
# Kabirdham | schools | Scroll 3 -> 27
# Kabirdham | schools | Scroll 4 -> 34
# Kabirdham | schools | Scroll 5 -> 40
# Kabirdham | schools | Scroll 6 -> 47
# Kabirdham | schools | Scroll 7 -> 54
# Kabirdham | schools | Scroll 8 -> 60
# Kabirdham | schools | Scroll 9 -> 67
# Kabirdham | schools | Scroll 10 -> 74
# Kabirdham | schools | Scroll 11 -> 80
# Kabirdham | schools | Scroll 12 -> 87
# Kabirdham | schools | Scroll 13 -> 94
# Kabirdham | schools | Scroll 14 -> 100
# Kabirdham | schools | Scroll 15 -> 107
# Kabirdham | schools | Scroll 16 -> 109
# Kabirdham | schools | Scroll 17 -> 109
# Kabirdham | schools | Scroll 18 -> 109
# Kabirdham | schools | Scroll 19 -> 109
# Kabirdham | schools | Scroll 20 -> 109
# Collected 108 links
# Kabirdham | 1/108
# Holy Kingdom English Higher Secondary School
# Kabirdham | 2/108
# Abhyuday School
# Kabirdham | 3/108
# Delhi Public School Kawardha
# Kabirdham | 4/108
# Gurukul Public School
# Kabirdham | 5/108
# ADARSH PUBLIC ENGLISH MEDIUM SCHOOL KAWARDHA
# Kabirdham | 6/108
# Swami Karpatri Ji Government Higher Secondary School Kawardha
# Kabirdham | 7/108
# Shri Ramkrishna Public School
# Kabirdham | 8/108
# SWAMI ATMANAND GOVT. ENGLISH MEDIUM SCHOOL, KAWARDHA C.G.
# Kabirdham | 9/108
# KENDRIYA VIDYALAYA MAHARAJPUR, KAWARDHA
# Kabirdham | 10/108
# Govt. Higher Secondary School Khairbana Kala
# Kabirdham | 11/108
# Sanskar Public School Kawardha
# Kabirdham | 12/108
# Ambition Public school
# Kabirdham | 13/108
# IMPERIAL AMENITY SCHOOL ( IAS)
# Kabirdham | 14/108
# Makoons Kids Unplugged, Kawardha
# Kabirdham | 15/108
# NAMITA PUBLIC SCHOOL
# Kabirdham | 16/108
# Ashoka Public School
# Kabirdham | 17/108
# Sunrise Public School Pandaria
# Kabirdham | 18/108
# ASHOKA PUBLIC SCHOOL
# Kabirdham | 19/108
# Government Primary School, Khailtukri, Kabirdham, Chhattisgarh 491559
# Kabirdham | 20/108
# Government High School
# Kabirdham | 21/108
# Kabirdham | 71/108
# Goverment higher secondary school Rajanawagaon
# Kabirdham | 72/108
# Kabirdham
# Kabirdham | 73/108
# Primary school sukhatal
# Kabirdham | 74/108
# GOVT.HS SCHOOL
# Kabirdham | 75/108
# Primary School Of Khursipar
# Kabirdham | 76/108
# Higher secondary school
# Kabirdham | 77/108
# Navin high school minminiya maidan
# Kabirdham | 78/108
# Government school Amroudi
# Kabirdham | 79/108
# Malikram
# Kabirdham | 80/108
# Praymri school motiyari
# Kabirdham | 81/108
# Kawardha
# Kabirdham | 82/108
# GOVT. HIGH SCHOOL SUKHATAL
# Kabirdham | 83/108
# Govt. High school sonbarsa
# Kabirdham | 84/108
# Palace Kawardha
# Kabirdham | 85/108
# GOVT H S SCHOOL JEVDAN KHURD
# Kabirdham | 86/108
# Khanti para
# Kabirdham | 87/108
# SPARDHA PUBLIC SCHOOL JEWADAN KHURD
# Kabirdham | 88/108
# भाई राम पटेल गुलाब मोहल्ला
# Kabirdham | 89/108
# Kusumghta
# Kabirdham | 90/108
# High School Newari
# Kabirdham | 91/108
# Govt Primary School Lalpur Kala
# Kabirdham | 92/108
# नवा बिहान
# Kabirdham | 93/108
# Govt. H.S.S. Kusumghata
# Kabirdham | 94/108
# Banjare bhai bhaluchuwa
# Kabirdham | 95/108
# Govt High School Ghongha
# Kabirdham | 96/108
# GAYATRI GURUKUL HIGHER SECONDARY SCHOOL LENJAKHAR (HINDI & ENGLISH MEDIUM)
# Kabirdham | 97/108
# Yashoda kumari sahu
# Kabirdham | 98/108
# Sumit patil's home
# Kabirdham | 99/108
# Prahlad Verma
# Kabirdham | 100/108
# Pradum verma
# Kabirdham | 101/108
# Kawardha Chhattisgarh
# Kabirdham | 102/108
# Krishi Vigyan Kendra, Kawardha
# Kabirdham | 103/108
# शासकीय पूर्व माध्यमिक शाला,मुड़ियापारा
# Kabirdham | 104/108
# शासकीय प्राथमिक एवं माध्यमिक शाला सिंघनपुरी जंगल
# Kabirdham | 105/108
# Subhash Meravi
# Kabirdham | 106/108
# JIGAR HOUSE
# Kabirdham | 107/108
# Inspire Academy, Kawardha
# Kabirdham | 108/108
# College Of Fisheries ,Sewaikachhar Kawardha
#
# Searching: schools in Kanker Chhattisgarh
# Search Submitted
# Kanker | schools | Scroll 1 -> 9
# Kanker | schools | Scroll 2 -> 9
# Kanker | schools | Scroll 3 -> 9
# Kanker | schools | Scroll 4 -> 9
# Kanker | schools | Scroll 5 -> 9
# Collected 9 links
# Kanker | 1/9
# PARADISE SCHOOL KANKER
# Kanker | 2/9
# St. Michael's Higher Secondary School
# Kanker | 3/9
# JP International School
# Kanker | 4/9
# J.s public higher secondary school kanker chhattisgarh
# Kanker | 5/9
# Govt. Narhardev English Medium H.S. School of Excellence
# Kanker | 6/9
# SCHOOL IN KANKER | DURGA DEVI PUBLIC SCHOOL
# Kanker | 7/9
# Suryoday Vidyalay
# Kanker | 8/9
# Prayas Aavasiya Vidyalaya
# Kanker | 9/9
# Dream India School
#
# Searching: schools in Khairagarh-Chhuikhadan-Gandai Chhattisgarh
# Search Submitted
# Chavara Higher Secondary School Kondagaon
# Kondagaon | 30/44
# Karandi school para
# Kondagaon | 31/44
# Govt Primary School Aadka Chepda
# Kondagaon | 32/44
# School Ground
# Kondagaon | 33/44
# WeDesi (A Multi Cuisine Eatery)
# Kondagaon | 34/44
# Kondagaon
# Kondagaon | 35/44
# Swami Atmanand Govt.Tahsil Para School
# Kondagaon | 36/44
# N.K.Electricls and Electronic
# Kondagaon | 37/44
# N मदरसा गुलशने सिब्तैन कोंडागांव
# Kondagaon | 38/44
# Kondagaon
# Kondagaon | 39/44
# Chavara Convent
# Kondagaon | 40/44
# Government Model Residential Girls College, Kondagaon 494226
# Kondagaon | 41/44
# CSC BAL VIDYALAYA DIGITAL NURSERY SCHOOL GANDHI CHOWK KONDAGAON
# Kondagaon | 42/44
# K.N.H HOSPITAL
# Kondagaon | 43/44
# आंगनबाड़ी शीतलापारा क्रमांक १
# Kondagaon | 44/44
# Madrasa Gulshan-e-Sibtain
#
# Searching: schools in Korba Chhattisgarh
# Search Submitted
# Korba | schools | Scroll 1 -> 14
# Korba | schools | Scroll 2 -> 20
# Korba | schools | Scroll 3 -> 27
# Korba | schools | Scroll 4 -> 34
# Korba | schools | Scroll 5 -> 40
# Korba | schools | Scroll 6 -> 47
# Korba | schools | Scroll 7 -> 54
# Korba | schools | Scroll 8 -> 60
# Korba | schools | Scroll 9 -> 67
# Korba | schools | Scroll 10 -> 74
# Korba | schools | Scroll 11 -> 80
# Korba | schools | Scroll 12 -> 87
# Korba | schools | Scroll 13 -> 94
# Korba | schools | Scroll 14 -> 98
# Korba | schools | Scroll 15 -> 98
# Korba | schools | Scroll 16 -> 98
# Korba | schools | Scroll 17 -> 98
# Korba | schools | Scroll 18 -> 98
# Collected 98 links
# Korba | 1/98
# St. Xaviers Public School Korba
# Korba | 2/98
# Brilliant Public School – CBSE School in Korba
# Korba | 3/98
# Delhi Public School, Jamnipali,Korba
# Korba | 4/98
# New Era Progressive School
# Korba | 5/98
# DAV Public School
# Korba | 6/98
# Career Public School
# Korba | 7/98
# Saraswati Higher Secondary School
# Korba | 8/98
# DDM Public School
# Korba | 9/98
# Jain Public School
# ...
# Raipur Convent School Khamtarai
# Raipur | 70/120
# Deshbandhu School
# Raipur | 71/120
# C G Educational Academy
# Raipur | 72/120
# Swami Vivekananda Senior Secondary School
# Raipur | 73/120
# Mother's Pride Senior Secondary School
# Raipur | 74/120
# Ananda Marga High School
# Raipur | 75/120
# Saraswati Shishu Mandir Higher Secondary School
# Raipur | 76/120
# Mata Sundari Public School
# Raipur | 77/120
# MM Junior School (Choubey Colony)
# Raipur | 78/120
# Nakshatra School Kids Academy
# Raipur | 79/120
# Kaanger Valley Academy
# Raipur | 80/120
# The digital school
# Raipur | 81/120
# Rising-Sun English High School
# Raipur | 82/120
# Mm Junior School (Devendra Nagar)
# Raipur | 83/120
# Panchjanya Vidhya Mandir (New School)
# Raipur | 84/120
# SHISHU NIKETAN Higher Secondary School
# Raipur | 85/120
# Indian Public Hr. Sec. School, Chhattisgarh Nagar, Raipur
# Raipur | 86/120
# Nutan Higher Secondary School
# Raipur | 87/120
# Tagore English Med School
# Raipur | 88/120
# Bharat Mata Higher Secondary School Tatibandh
# Raipur | 89/120
# Raipur Convent Higher Secondary School
# Raipur | 90/120
# Jyoti School Raipur
# Raipur | 91/120
# R D Tiwari School
# Raipur | 92/120
# Dr. Radhakrishnan School
# Raipur | 93/120
# Jingle Bell Premier Pre School Raipur
# Raipur | 94/120
# Ashoka Public School
# Raipur | 95/120
# Bansal Public School
# Raipur | 96/120
# Shantiniketan public school and College
# Raipur | 97/120
# SREE NARAYANA KIDS ACADEMY
# Raipur | 98/120
# JR Naidu Govt. School
# Raipur | 99/120
# Harinath Academy (New Campus)
# Raipur | 100/120
# Shri Balaji Vidya Mandir
# Raipur | 101/120
# vindhya public high school
# Raipur | 102/120
# Model English Hr. Sec. School
# Raipur | 103/120
# J.R.Dani Girls School
# Raipur | 104/120
# DECENT WORLD SCHOOL
# Raipur | 105/120
# Tilak Bharati Higher Secondary School
# Raipur | 106/120
# Dazzle Public School
# Raipur | 107/120
# Vikramshila Kids Academy| Best Play & Nursery School Raipur
# Raipur | 108/120
# JAIN PUBLIC SCHOOL
# Raipur | 109/120
# Ashirwad Hr. Sec.English School
# Raipur | 110/120
# Holy Cross School Shailendra Nagar (Part Of Holy Cross Byron Bazar)
# Raipur | 111/120
# SANSKAAR PUBLIC SCHOOL
# Raipur | 112/120
# Rise N Shine Play School Raipur
# Raipur | 113/120
# Royal Public School
# Raipur | 114/120
# Govt. Higher secondary school
# Raipur | 115/120
# Krishna Kids Academy | Best Play school in Raipur
# Raipur | 116/120
# Gyan Ganga Educational Academy
# Raipur | 117/120
# B.P. Pujari Govt English School
# Raipur | 118/120
# Kidzee Devendra Nagar
# Raipur | 119/120
# Yippee Play School
# Raipur | 120/120
# Aastha Public School professor colony
#
# Searching: schools in Rajnandgaon Chhattisgarh
# Search Submitted
# Rajnandgaon | schools | Scroll 1 -> 14
# Rajnandgaon | schools | Scroll 2 -> 20
# Rajnandgaon | schools | Scroll 3 -> 27
# Rajnandgaon | schools | Scroll 4 -> 34
# Rajnandgaon | schools | Scroll 5 -> 40
# Rajnandgaon | schools | Scroll 6 -> 47
# Rajnandgaon | schools | Scroll 7 -> 54
# Rajnandgaon | schools | Scroll 8 -> 60
# Rajnandgaon | schools | Scroll 9 -> 63
# Rajnandgaon | schools | Scroll 10 -> 63
# Rajnandgaon | schools | Scroll 11 -> 63
# Rajnandgaon | schools | Scroll 12 -> 63
# Rajnandgaon | schools | Scroll 13 -> 63
# Collected 63 links
# Rajnandgaon | 1/63
# Bachpan Play School in Rajnandgaon | Best Preschool Near Me | Nursery School & Kindergarten for Your Child’s Bright Start
# Rajnandgaon | 2/63
# JMJ Navjeevan School
# Rajnandgaon | 3/63
# Government Multipurpose Higher Secondary School ( new eng. Med. CBSE middle school) (State High School) Rajnandgaon
# Rajnandgaon | 4/63
# Neeraj Public School
# Rajnandgaon | 5/63
# Delhi Public School
# Rajnandgaon | 6/63
# Yugantar Public School
# Rajnandgaon | 7/63
# BIRLA OPEN MINDS PRE SCHOOL , RAJNANDGAON(C.G.)
# Rajnandgaon | 8/63
# Little Millennium Preschool - Rajnandgaon, Gurunanak Chowk
# Rajnandgaon | 9/63
# Shri Gurunanak Higher Secondary School
# Rajnandgaon | 10/63
# FirstCry Intellitots Preschool & Daycare - Anupam Nagar, Rajnandgaon
# Rajnandgaon | 11/63
# MGM School Rajnandgaon
# Rajnandgaon | 12/63
# Saraswati Hr. Sec. School
# Rajnandgaon | 13/63
# Royal Kids Convent
# Rajnandgaon | 14/63
# Wesleyan Hindi Medium School
# Rajnandgaon | 15/63
# SHEELA THIESSEN MEMORIAL HIGH SCHOOL
# Rajnandgaon | 16/63
# Simna Public School
# Rajnandgaon | 17/63
# Dream India School,Rajnandgaon
# Rajnandgaon | 18/63
# Weidner Memorial Senior Secondary School
# Rajnandgaon | 19/63
# Bright Beginning Kids School
# Rajnandgaon | 20/63
# Bal Bharti Public School
# Rajnandgaon | 21/63
# Advaita Public School
# Rajnandgaon | 22/63
# H.S.SCHOOL SHANKARPUR RAJNANDGAON
# Rajnandgaon | 23/63
# Sanskar City International School
# Rajnandgaon | 24/63
# Thakur Pyarelal Singh Higher Secendary School Rajnandgaon
# Rajnandgaon | 25/63
# Gujrati Higher Secondary School
# Rajnandgaon | 26/63
# SCHOLAR'S INSTITUTE
# Rajnandgaon | 27/63
# Lakshya Public School Rajnandgaon
# Rajnandgaon | 28/63
# Aadarsh Vidya Mandir School
# Rajnandgaon | 29/63
# Sai Kripa Car Driving School
# Rajnandgaon | 30/63
# Rajeshwari Karuna Hr. Sec. School
# Rajnandgaon | 31/63
# Govt Maharani girls School
# Rajnandgaon | 32/63
# Swami Vivekanand School
# Rajnandgaon | 33/63
# Deepika Vidya Mandir Hr. Sec. English Medium School
# Rajnandgaon | 34/63
# DPS SAINIK SCHOOL RAJNANDGAON
# Rajnandgaon | 35/63
# Neeraj Foundation School
# Rajnandgaon | 36/63
# SITA Computer Education Rajnandgaon
# Rajnandgaon | 37/63
# Basantpur School
# Rajnandgaon | 38/63
# Royal Kids' Convent
# Rajnandgaon | 39/63
# NEERAJ VIDYA MANDIR
# Rajnandgaon | 40/63
# MATH ACADEMY
# Rajnandgaon | 41/63
# Sarveswar Das Municipal High School (swami atmanand eng. med. school)
# Rajnandgaon | 42/63
# Parrikala school
# Rajnandgaon | 43/63
# Atharva Academy
# Backup Saved
# Rajnandgaon | 44/63
# M.L.B. Girls School
# Rajnandgaon | 45/63
# Dr. Baldev Prasad Mishra HS School
# Rajnandgaon | 46/63
# Padumlal Punalal Bakshi (swami atmanand) Hr. School
# Rajnandgaon | 47/63
# Wesleyan English medium h.s. school
# Rajnandgaon | 48/63
# JLM Gayatri Vidya Peeth CG English Medium
# Rajnandgaon | 49/63
# RHYTHM REVOLUTION DANCE AND FITNESS CLASS
# Rajnandgaon | 50/63
# CHANAKYA LIBRARY
# Rajnandgaon | 51/63
# Sumeet Fashion
# Rajnandgaon | 52/63
# Royal College
# Rajnandgaon | 53/63
# Confluence College of Higher Education
# Rajnandgaon | 54/63
# Kendriya Vidyalaya Rajnandgaon
# Rajnandgaon | 55/63
# Asha Library Cum Reading Room
# Rajnandgaon | 56/63
# DR. J.B. SINGH MEMORIAL SENIOR SECONDARY SCHOOL
# Rajnandgaon | 57/63
# Jai Shakti Driving School
# Rajnandgaon | 58/63
# Lakshya Public School
# Rajnandgaon | 59/63
# Sai Kripa Student's Hostel
# Rajnandgaon | 60/63
# Pragya Computer Education Classes
# Rajnandgaon | 61/63
# NEERAJ PARENTS PRIDE SCHOOL
# Rajnandgaon | 62/63
# Neeraj School
# Rajnandgaon | 63/63
# Jawahar Navodaya Vidyalaya Dongargarh
#
# Searching: schools in Sakti Chhattisgarh
# Search Submitted
# Sakti | schools | Scroll 1 -> 9
# Sakti | schools | Scroll 2 -> 9
# Sakti | schools | Scroll 3 -> 9
# Sakti | schools | Scroll 4 -> 9
# Sakti | schools | Scroll 5 -> 9
# Collected 9 links
# Sakti | 1/9
# Anunay Convent School
# Sakti | 2/9
# Little flower School sakti
# Sakti | 3/9
# Parmeshwari Public School
# Sakti | 4/9
# Jindal World School
# Sakti | 5/9
# GUNJAN HIGHER SECONDARY SCHOOL SAKTI
# Sakti | 6/9
# Sanskar Public School
# Sakti | 7/9
# Ml Jain School
# Sakti | 8/9
# NAV JEEVAN MOOK BADHIR SCHOOL
# Sakti | 9/9
# Sanskar Public School, Sakti
#
# Searching: schools in Sarangarh-Bilaigarh Chhattisgarh
# Search Submitted
# Sarangarh-Bilaigarh | schools | Scroll 1 -> 14
# Sarangarh-Bilaigarh | schools | Scroll 2 -> 20
# Sarangarh-Bilaigarh | schools | Scroll 3 -> 27
# Sarangarh-Bilaigarh | schools | Scroll 4 -> 34
# Sarangarh-Bilaigarh | schools | Scroll 5 -> 40
# Sarangarh-Bilaigarh | schools | Scroll 6 -> 47
# Sarangarh-Bilaigarh | schools | Scroll 7 -> 54
# Sarangarh-Bilaigarh | schools | Scroll 8 -> 60
# Sarangarh-Bilaigarh | schools | Scroll 9 -> 61
# Sarangarh-Bilaigarh | schools | Scroll 10 -> 61
# Sarangarh-Bilaigarh | schools | Scroll 11 -> 61
# Sarangarh-Bilaigarh | schools | Scroll 12 -> 61
# Sarangarh-Bilaigarh | schools | Scroll 13 -> 61
# Collected 60 links
# Sarangarh-Bilaigarh | 1/60
# BRILLIANT PUBLIC SCHOOL KOSIR SARANGARH-BILAIGARH
# Sarangarh-Bilaigarh | 2/60
# My Chhota School Sarangarh
# Sarangarh-Bilaigarh | 3/60
# Govt. Multi.higher Sec. School Sarangarh
# Sarangarh-Bilaigarh | 4/60
# Mona Modern English Medium School, Sarangarh
# Sarangarh-Bilaigarh | 5/60
# Cpm Higher Secondary School Sarangarh District Sarangarh - Bilaigarh
# Sarangarh-Bilaigarh | 6/60
# Eklavya Public School
# Sarangarh-Bilaigarh | 7/60
# Bataupali High School
# Sarangarh-Bilaigarh | 8/60
# Saraswati Shishu Mandir H. S. School Sarangarh
# Sarangarh-Bilaigarh | 9/60
# Swami Atmanand English Medium School, Sarangarh
# Sarangarh-Bilaigarh | 10/60
# Nagar Palika Higher Secondri School Sarangarh
# Sarangarh-Bilaigarh | 11/60
# SHRIJA ROYAL SCHOOL ,KOSIR
# Sarangarh-Bilaigarh | 12/60
# ST Thomas Hindi Medium School
# Sarangarh-Bilaigarh | 13/60
# CPM Arts & Science College,Dansara, Sarangarh
# Sarangarh-Bilaigarh | 14/60
# Govt. Primary School Birsingdih
# Sarangarh-Bilaigarh | 15/60
# Sagar School Bhatgaon
# Sarangarh-Bilaigarh | 16/60
# MONA MODERN H.S. SCHOOL, SARANGARH
# Sarangarh-Bilaigarh | 17/60
# Mona Modern School Baramkela
# Sarangarh-Bilaigarh | 18/60
# Mona Group Of Education
# Sarangarh-Bilaigarh | 19/60
# Govt. Girls Higher Secondary School Sarangarh
# Sarangarh-Bilaigarh | 20/60
# ST. Thomas English Medium School
# Sarangarh-Bilaigarh | 21/60
# DK COACHING CLASSES
# Sarangarh-Bilaigarh | 22/60
# Middle school Salhe
# Sarangarh-Bilaigarh | 23/60
# Primary School CNP
# Sarangarh-Bilaigarh | 24/60
# SWAMI ATMANANDA GOVERNMENT ENGLISH MEDIUM SCHOOL BILAIGARH
# Sarangarh-Bilaigarh | 25/60
# Middle school tengnapali sarangarh
# Sarangarh-Bilaigarh | 26/60
# Raja Para
# Sarangarh-Bilaigarh | 27/60
# Abhi King
# Sarangarh-Bilaigarh | 28/60
# Govt. Primary school bhojpur sarangarh
# Sarangarh-Bilaigarh | 29/60
# Government High school Kateli Sarangarh
# Sarangarh-Bilaigarh | 30/60
# (प्राथमिक विद्यालय रांपागुला Primary School Rampagula , Sarangarh, Chattisgarh
# Sarangarh-Bilaigarh | 31/60
# "pawan" Mona School Hostel
# Sarangarh-Bilaigarh | 32/60
# माध्यमिक विद्यालय Middle School, Rampagula, Sarangarh, Chattisgarh
# Sarangarh-Bilaigarh | 33/60
# GURUKUL COMPUTER ACADEMY
# Sarangarh-Bilaigarh | 34/60
# CG Expert Motor Driving School
# Sarangarh-Bilaigarh | 35/60
# Government primary school, Dumardih
# Sarangarh-Bilaigarh | 36/60
# शासकीय प्राथमिक शाला पचपेड़ी (government primary school pachpedi)
# Sarangarh-Bilaigarh | 37/60
# Hemant maitri
# Sarangarh-Bilaigarh | 38/60
# शासकीय प्राथमिक शाला भैऺजनार
# Sarangarh-Bilaigarh | 39/60
# Aanganbadi Kendr-03
# Sarangarh-Bilaigarh | 40/60
# Government Industrial Training Institute Sarangarh
# Sarangarh-Bilaigarh | 41/60
# bilaigarh school
# Sarangarh-Bilaigarh | 42/60
# Navin Govt. School
# Sarangarh-Bilaigarh | 43/60
# Pranjal Welfare Foundation
# Sarangarh-Bilaigarh | 44/60
# Pradeep Niwas
# Sarangarh-Bilaigarh | 45/60
# Guru kripa coaching classes commerce
# Sarangarh-Bilaigarh | 46/60
# FULJHARIYA PARA WARD No. 12
# Sarangarh-Bilaigarh | 47/60
# kateli panchyat sarangarh
# Sarangarh-Bilaigarh | 48/60
# Vinayak School Madhaibhatha
# Sarangarh-Bilaigarh | 49/60
# City Cinema Sarangarh
# Sarangarh-Bilaigarh | 50/60
# Primary school Amlipali b
# Sarangarh-Bilaigarh | 51/60
# एम्बीसन पब्लिक स्कूल खैरहा
# Sarangarh-Bilaigarh | 52/60
# Career Point National School Bhatgaon
# Sarangarh-Bilaigarh | 53/60
# Goverment higer secendry school
# Sarangarh-Bilaigarh | 54/60
# District Education Office Sarangarh-Bilaigarh
# Sarangarh-Bilaigarh | 55/60
# Sarangarh
# Sarangarh-Bilaigarh | 56/60
# शासकीय प्राथमिक शाला-बुटीपारा(सारंगढ़) जिला-रायगढ़ (छ.ग.)
# Sarangarh-Bilaigarh | 57/60
# Pragya Public English Medium School
# Sarangarh-Bilaigarh | 58/60
# Rajshree Modern School
# Sarangarh-Bilaigarh | 59/60
# ITI Trade School
# Sarangarh-Bilaigarh | 60/60
# VISION IIT CLASSES
#
# Searching: schools in Sukma Chhattisgarh
# Search Submitted
# Sukma | schools | Scroll 1 -> 9
# Sukma | schools | Scroll 2 -> 9
# Sukma | schools | Scroll 3 -> 9
# Sukma | schools | Scroll 4 -> 9
# Sukma | schools | Scroll 5 -> 9
# Collected 9 links
# Sukma | 1/9
# Shemrock School Sukma
# Sukma | 2/9
# EMRS, SUKMA,CHHATTISGARH, INDIA
# Sukma | 3/9
# JNV Sukma
# Sukma | 4/9
# Kendriya Vidyalaya Sukma
# Sukma | 5/9
# Primary school
# Sukma | 6/9
# Govt. Shahid Bapu Rao College, Sukma
# Sukma | 7/9
# Govt Middle School Sukma
# Sukma | 8/9
# DAV MUKHYAMANTRI PUBLIC SCHOOL
# Sukma | 9/9
# MOTHER TERESA SCHOOL,SUKMA
#
# Searching: schools in Surajpur Chhattisgarh
# Search Submitted
# Surajpur | schools | Scroll 1 -> 7
# Surajpur | schools | Scroll 2 -> 7
# Surajpur | schools | Scroll 3 -> 7
# Surajpur | schools | Scroll 4 -> 7
# Surajpur | schools | Scroll 5 -> 7
# Collected 6 links
# Surajpur | 1/6
# Sadhu Ram Vidya Mandir
# Surajpur | 2/6
# Global Public School
# Backup Saved
# Surajpur | 3/6
# D.A.V. Mukhyamantri Public School
# Surajpur | 4/6
# J s convent school
# Surajpur | 5/6
# RHS DIGITAL SCHOOL
# Surajpur | 6/6
# KENDRIYA VIDYALAYA (CENTRAL SCHOOL)
#
# Searching: schools in Surguja Chhattisgarh
# Search Submitted
# Surguja | schools | Scroll 1 -> 14
# Surguja | schools | Scroll 2 -> 20
# Surguja | schools | Scroll 3 -> 27
# Surguja | schools | Scroll 4 -> 34
# Surguja | schools | Scroll 5 -> 40
# Surguja | schools | Scroll 6 -> 47
# Surguja | schools | Scroll 7 -> 54
# Surguja | schools | Scroll 8 -> 56
# Surguja | schools | Scroll 9 -> 56
# Surguja | schools | Scroll 10 -> 56
# Surguja | schools | Scroll 11 -> 56
# Surguja | schools | Scroll 12 -> 56
# Collected 55 links
# Surguja | 1/55
# SHRI SAI BABA SCHOOL
# Surguja | 2/55
# Govt. Higher Secondary School
# Surguja | 3/55
# Holy Cross Convent Sr. Sec. School,Ambikapur
# Surguja | 4/55
# Montfort School
# Surguja | 5/55
# Milestones School
# Surguja | 6/55
# St. John's Hr. Sec. School
