# %%
import pandas as pd

# %%
df = pd.read_csv("tamilnadu_schools.csv")

# %%
df.shape
# Out:
# (3673, 8)

# %%
duplicate_count = df.duplicated(
    subset=["School Name", "Google Maps URL"]
).sum()
duplicate_count
# Out:
# np.int64(0)

# %%
df = df[
    df["Phone"].notna() & 
    (df["Phone"].astype(str).str.strip() != "")
    ]
df.shape
# Out:
# (717, 8)

# %%
df = df[
    df["School Name"].notna()
    ]

df = df[
    df["School Name"].str.strip() != ""
    ]
df.shape
# Out:
# (712, 8)

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]","",regex=True)
    .str.strip()
)

display(df[["Phone"]].head())
# Out:
#            Phone
# 0   096557 75353
# 1  04329 296 433
# 2   090925 70030
# 4   090956 20825
# 5   089395 93399

# %%
df.to_csv(
    "tamilnadu_schools_cleaned.csv",
    index=False
)
