# %%
import time
import random
import pandas as pd

from datetime import datetime

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.service import Service

from webdriver_manager.chrome import ChromeDriverManager


districts = [
    "Niwari",
    "Pandhurna",
    "Panna",
    "Raisen",
    "Rajgarh",
    "Ratlam",
    "Rewa",
    "Sagar",
    "Satna",
    "Sehore",
    "Seoni",
    "Shahdol",
    "Shajapur",
    "Sheopur",
    "Shivpuri",
    "Sidhi",
    "Singrauli",
    "Tikamgarh",
    "Ujjain",
    "Umaria",
    "Vidisha"
]


search_types = [
    "software companies",
]



options = webdriver.ChromeOptions()

options.add_argument("--start-maximized")

options.add_argument(
    "--disable-blink-features=AutomationControlled"
)

options.add_argument("--disable-notifications")


driver = webdriver.Chrome(

    service=Service(
        ChromeDriverManager().install()
    ),

    options=options
)



driver.get("https://www.google.com/maps")

print("Opening Google Maps...")

time.sleep(15)

print("Google Maps Loaded")

all_data = []

visited_links = set()



def get_search_box():

    selectors = [

        '//input[@id="searchboxinput"]',
        '//input[contains(@placeholder,"Search")]',
        '//input[contains(@aria-label,"Search")]',
        '//input'

    ]

    for selector in selectors:

        try:

            box = driver.find_element(
                By.XPATH,
                selector
            )

            return box

        except:
            pass

    return None



def extract_school_data():

    try:


        try:

            name = driver.find_element(
                By.TAG_NAME,
                "h1"
            ).text

        except:

            name = ""



        try:

            address = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"address")]'
            ).text

        except:

            address = ""



        phone = ""

        try:

            phone_xpaths = [

                '//button[contains(@data-item-id,"phone")]',

                '//a[contains(@href,"tel:")]',

                '//button[contains(@aria-label,"Phone")]',

                '//button[contains(text(),"+91")]',
                '//div[contains(text(),"+91")]',
                '//span[contains(text(),"+91")]'

            ]

            for xpath in phone_xpaths:

                try:

                    elements = driver.find_elements(
                        By.XPATH,
                        xpath
                    )

                    for element in elements:

                        text = element.text.strip()

                        href = (
                            element.get_attribute("href")
                            or ""
                        )


                        if "tel:" in href:

                            phone = href.replace(
                                "tel:",
                                ""
                            ).strip()

    
                        elif text:

                            phone = text

                        phone = (

                            phone.replace("", "")
                            .replace(" ", "")
                            .replace("-", "")
                            .replace("(", "")
                            .replace(")", "")
                            .replace("\n", "")
                            .strip()

                        )


                        digits = ''.join(
                            filter(str.isdigit, phone)
                        )

                        if len(digits) >= 10:

                            break

                    if phone:
                        break

                except:
                    pass

        except Exception as e:

            print(f"Phone Error: {e}")

        try:

            website = driver.find_element(
                By.XPATH,
                '//a[contains(@data-item-id,"authority")]'
            ).get_attribute("href")

        except:

            website = ""


        try:

            rating = driver.find_element(
                By.XPATH,
                '//div[@role="img"]'
            ).get_attribute("aria-label")

        except:

            rating = ""

        return {

            "Company Name": name,
            "Address": address,
            "Phone": phone,
            "Website": website,
            "Rating": rating,
            "Google Maps URL": driver.current_url

        }

    except:

        return None


for district in districts:

    for search_type in search_types:

        try:

            query = (
                f"{search_type} "
                f"in {district} Madhya Pradesh"
            )

            print(f"\nSearching: {query}")

            search_box = get_search_box()

            if not search_box:

                print("Search Box Not Found")

                continue

            ActionChains(driver).move_to_element(
                search_box
            ).click().perform()

            time.sleep(1)

            search_box.send_keys(
                Keys.CONTROL + "a"
            )

            time.sleep(1)

            search_box.send_keys(Keys.DELETE)

            time.sleep(1)

  

            for char in query:

                search_box.send_keys(char)

                time.sleep(0.03)

            search_box.send_keys(Keys.ENTER)

            print("Search Submitted")

            time.sleep(8)



            try:

                scrollable_div = driver.find_element(
                    By.XPATH,
                    '//div[@role="feed"]'
                )

                previous_count = 0

                stagnant = 0

                for i in range(100):

                    driver.execute_script(
                        """
                        arguments[0].scrollTop =
                        arguments[0].scrollHeight
                        """,
                        scrollable_div
                    )

                    time.sleep(4)

                    listings = driver.find_elements(
                        By.XPATH,
                        '//a[contains(@href,"/maps/place/")]'
                    )

                    current_count = len(listings)

                    print(
                        f"{district} | "
                        f"{search_type} | "
                        f"Scroll {i+1} -> "
                        f"{current_count}"
                    )

                    if current_count == previous_count:

                        stagnant += 1

                    else:

                        stagnant = 0

                    if stagnant >= 4:

                        break

                    previous_count = current_count

            except Exception as e:

                print(f"Scrolling Error: {e}")

            # GET LINKS

            listings = driver.find_elements(
                By.XPATH,
                '//a[contains(@href,"/maps/place/")]'
            )

            links = []

            for listing in listings:

                try:

                    link = listing.get_attribute("href")

                    if (
                        link
                        and link not in visited_links
                    ):

                        links.append(link)

                        visited_links.add(link)

                except:
                    pass

            print(f"Collected {len(links)} links")



            for index, link in enumerate(links):

                try:

                    print(
                        f"{district} | "
                        f"{index+1}/{len(links)}"
                    )

                    driver.get(link)

                    time.sleep(
                        random.uniform(2, 3)
                    )

                    data = extract_school_data()

                    if data:

                        data["District"] = district

                        data["Search Type"] = search_type

                        all_data.append(data)

                        print(data["Company Name"])

                        print(
                            f"Phone: {data['Phone']}"
                        )

           

                    if len(all_data) % 100 == 0:

                        backup_df = pd.DataFrame(
                            all_data
                        )

                        backup_df.drop_duplicates(
                            subset=[
                                "Company Name",
                                "Google Maps URL"
                            ],
                            inplace=True
                        )

                        backup_df.to_csv(
                            "madhya_pradesh_companies_backup.csv",
                            index=False
                        )

                        print("Backup Saved")

                except Exception as e:

                    print(
                        f"Company Error: {e}"
                    )

        except Exception as e:

            print(
                f"District Error: {e}"
            )


df = pd.DataFrame(all_data)

df.drop_duplicates(

    subset=[
        "Company Name",
        "Google Maps URL"
    ],

    inplace=True
)

filename = "madhya_pradesh_companies.csv"

df.to_csv(
    filename,
    index=False
)

print("\nExtraction Completed")

print(
    f"Total Companies Extracted: {len(df)}"
)

print(f"\nSaved File: {filename}")

driver.quit()
# Out:
# Opening Google Maps...
# Google Maps Loaded
#
# Searching: software companies in Niwari Madhya Pradesh
# Search Submitted
# Niwari | software companies | Scroll 1 -> 14
# Niwari | software companies | Scroll 2 -> 20
# Niwari | software companies | Scroll 3 -> 27
# Niwari | software companies | Scroll 4 -> 31
# Niwari | software companies | Scroll 5 -> 31
# Niwari | software companies | Scroll 6 -> 31
# Niwari | software companies | Scroll 7 -> 31
# Niwari | software companies | Scroll 8 -> 31
# Rajgarh | software companies | Scroll 6 -> 24
# Rajgarh | software companies | Scroll 7 -> 24
# Collected 22 links
# Rajgarh | 1/22
# Green Web Software Development Pvt. Ltd.
# Phone: 09329914739
# Rajgarh | 2/22
# OA Developers - Mobile Application | Website / Software Development Company in Jirapur, Rajgarh MP
# Phone: 08839437101
# Rajgarh | 3/22
# Nilman Computer and Mobile store
# Phone: 08103681753
# Rajgarh | 4/22
# Swayam Infotech
# Phone: 07000575749
# Rajgarh | 5/22
# SHOBHA COMPUTER
# Phone: 09424403358
# Rajgarh | 6/22
# Cognito Infotech – Best IT Solutions & Services in india
# Phone:
# Rajgarh | 7/22
# PrimeSoul Web Solutions
# Phone:
# Rajgarh | 8/22
# MARCAID Institute of Technical Education MITE
# Phone: 09111311911
# Rajgarh | 9/22
# MG DIGITAL SOLUTION
# Phone: 07000901498
# Rajgarh | 10/22
# Cyber Crime Law Consulting and Internet Services
# Phone: 09109101759
# Rajgarh | 11/22
# Verma Reliable Security Services
# Phone: 07440506008
# Rajgarh | 12/22
# Saarel Infotech
# Phone: 08889888309
# Rajgarh | 13/22
# Total services & Event's
# Phone: 08982521475
# Rajgarh | 14/22
# Soluzione IT Services | Software Development Company
# Phone: 09302980560
# Rajgarh | 15/22
# Trisha Digital Solution – IT Services, Digital Solutions & Business Software Provider
# Phone:
# Rajgarh | 16/22
# Mohanpura Dam, Rajgarh Project
# Phone:
# Rajgarh | 17/22
# Young Decade IT Software Solution
# Phone: 07987611372
# Rajgarh | 18/22
# Sunrise Development
# Phone: 07987782679
# Rajgarh | 19/22
# Dev Computer
# Phone: 09660181522
# Rajgarh | 20/22
# Mitra Computer Biaora
# Phone: 06266870922
# Rajgarh | 21/22
# SHREE SANWARIYA FINANCE AND ONLINE SERVICES
# Phone: 09425418957
# Rajgarh | 22/22
# Tailar
# Phone: 08103379775
#
# Searching: software companies in Ratlam Madhya Pradesh
# Search Submitted
# Ratlam | software companies | Scroll 1 -> 14
# Ratlam | software companies | Scroll 2 -> 20
# Ratlam | software companies | Scroll 3 -> 27
# Ratlam | software companies | Scroll 4 -> 34
# Ratlam | software companies | Scroll 5 -> 40
# Ratlam | software companies | Scroll 6 -> 47
# Ratlam | software companies | Scroll 7 -> 54
# Ratlam | software companies | Scroll 8 -> 60
# Ratlam | software companies | Scroll 9 -> 67
# Ratlam | software companies | Scroll 10 -> 74
# Ratlam | software companies | Scroll 11 -> 80
# Ratlam | software companies | Scroll 12 -> 87
# Ratlam | software companies | Scroll 13 -> 94
# Ratlam | software companies | Scroll 14 -> 100
# Ratlam | software companies | Scroll 15 -> 107
# Ratlam | software companies | Scroll 16 -> 114
# Ratlam | software companies | Scroll 17 -> 120
# Ratlam | software companies | Scroll 18 -> 120
# Ratlam | software companies | Scroll 19 -> 120
# Ratlam | software companies | Scroll 20 -> 120
# Ratlam | software companies | Scroll 21 -> 120
# Collected 118 links
# Ratlam | 1/118
# Bytelabs Infotech
# Phone: 08770902424
# Ratlam | 2/118
# 𝗧𝗔𝗣 𝗦𝗧𝗛𝗔𝗟 𝗙𝗢𝗥 𝗡𝗘𝗘𝗧 𝗨𝗚- Physic/Chemistry/Biology for NEET/Best Library/Best Neet Teacher/Best NEET Coaching Centre in Rewa
# Phone: 07987015744
# Rewa | 65/87
# IT Centre Rewa
# Phone: 09302811106
# Rewa | 66/87
# BIKE & CAR RENTALS SERVICES (BHAGAT TRADINGS AND COMPANY)
# Phone: 09111722200
# Rewa | 67/87
# Rewa M.P.
# Phone:
# Rewa | 68/87
# Tanishq Jewellery - Rewa
# Phone: 09516660111
# Rewa | 69/87
# Sanat Dynamo Solutions
# Phone:
# Rewa | 70/87
# IDA - International Design Academy
# Phone: 07879057482
# Rewa | 71/87
# Tansen complex
# Phone:
# Rewa | 72/87
# Satna Express Transport Corporation
# Phone: 09827324691
# Rewa | 73/87
# MAA Polypacks Industries (IND) Pvt Ltd.
# Phone: 07440440561
# Rewa | 74/87
# 360 Web Services
# Phone:
# Rewa | 75/87
# SDC Event Wedding Planner
# Phone: 08770456919
# Rewa | 76/87
# EPSON AUTHORISED SERVICE CENTRE - Computer Care
# Phone: 09513446569
# Rewa | 77/87
# Eco Park Rewa | Adventure Park | Hotel | Banquet | Restaurant | Café | Lawn
# Phone: 09796964242
# Rewa | 78/87
# Arbaaz Computers
# Phone:
# Rewa | 79/87
# Aryan Taxi Service
# Phone: 07900012502
# Rewa | 80/87
# Candere - A Kalyan Company - Rewa
# Phone: 09037450033
# Rewa | 81/87
# Rewa taxi booking - mpcabs.com
# Phone: 09174567461
# Rewa | 82/87
# INBS EVENTS & DECORATORS REWA
# Phone: 09301890444
# Rewa | 83/87
# Mi Service
# Phone:
# Rewa | 84/87
# SHOOTSBYAMAN { AMAN KHANDELWAL PHOTOGRAPHY }
# Phone: 07869330778
# Rewa | 85/87
# TechyEra Consultancy Services
# Phone:
# Rewa | 86/87
# ULTRASOFT TECHNOLOGIES
# Phone:
# Rewa | 87/87
# Data Park Enterprises
# Phone:
#
# Searching: software companies in Sagar Madhya Pradesh
# Search Submitted
# Sagar | software companies | Scroll 1 -> 14
# Sagar | software companies | Scroll 2 -> 20
# Sagar | software companies | Scroll 3 -> 27
# Sagar | software companies | Scroll 4 -> 34
# Sagar | software companies | Scroll 5 -> 40
# Sagar | software companies | Scroll 6 -> 47
# Sagar | software companies | Scroll 7 -> 54
# Sagar | software companies | Scroll 8 -> 60
# Sagar | software companies | Scroll 9 -> 67
# Sagar | software companies | Scroll 10 -> 74
# Sagar | software companies | Scroll 11 -> 79
# Sagar | software companies | Scroll 12 -> 79
# Sagar | software companies | Scroll 13 -> 79
# Sagar | software companies | Scroll 14 -> 79
# Sagar | software companies | Scroll 15 -> 79
# Collected 77 links
# Sagar | 1/77
# Xansa IT Solutions
# Phone: 08770480826
# Sagar | 2/77
# Success Computerized Accounting Solutions
# Phone: 09479742066
# Sagar | 3/77
# WithAspire Netexis Private Limited
# Phone:
# Sagar | 4/77
# Madquick - Web Development Company
# Phone: 08962674385
# Sagar | 5/77
# OyeCommerz (Shopify Plus Agency)
# Trekon Technology Sagar
# Phone: 09329702400
# Sagar | 45/77
# ACCOUNTING & INVENTORY SOFTWARE IN SAGAR
# Phone: 07974069174
# Sagar | 46/77
# Solver Solutions Software Company
# Phone:
# Sagar | 47/77
# Solver solutions GST ERP software company
# Phone: 09302777484
# Sagar | 48/77
# Advance Computers
# Phone: 09329470585
# Sagar | 49/77
# DV Web Studio
# Phone:
# Sagar | 50/77
# Sagarsoft (India) Limited
# Phone: 04067191000
# Sagar | 51/77
# Ajay Dry Cleaners
# Phone: 09752327654
# Sagar | 52/77
# Dubey Travels cab
# Phone: 07440749466
# Sagar | 53/77
# New Rajkamal computers
# Phone: 09303083030
# Sagar | 54/77
# Sagar Tech - Web Development & Digital Marketing Agency in Mumbai
# Phone: 09820133303
# Sagar | 55/77
# Sagar Informatics Pvt Ltd
# Phone: 01146048550
# Sagar | 56/77
# NIKET JAIN & ASSOCIATES
# Phone: 08319034879
# Sagar | 57/77
# Gopala Shrinivasam
# Phone: 08770670107
# Sagar | 58/77
# Chartered Bus, Moti Nagar, Sagar, Madhya Pradesh
# Phone:
# Sagar | 59/77
# LG Best Shop-ANIL & CO.
# Phone: 09826126125
# Sagar | 60/77
# Saumitra Dixit
# Phone: 07697454396
# Sagar | 61/77
# Muthoot Finance Gold Loan
# Phone: 18001202838
# Sagar | 62/77
# Jio Point , Jio store , Jio office , Jio service centre, jio
# Phone:
# Sagar | 63/77
# SURESH RADIO & ELECTRONICS
# Phone: 08817010171
# Sagar | 64/77
# Gadget Zone
# Phone: 09977442388
# Sagar | 65/77
# Bramhi
# Phone:
# Sagar | 66/77
# Manappuram Finance Limited – Gold Loan
# Phone: 08044925751
# Sagar | 67/77
# D.K Machinery Stores texmo dealer taro dealer reliance pipe dealer and l&t ltlk dealer
# Phone: 09425655148
# Sagar | 68/77
# Jay Appliances & Instruments Co.
# Phone: 09827284841
# Sagar | 69/77
# Creme stories by mahi | Jain Cakes 🍰
# Phone:
# Sagar | 70/77
# M/S Big Boss Agency
# Phone: 07582404009
# Sagar | 71/77
# Chouksey Travels
# Phone: 09425614677
# Sagar | 72/77
# Gujarati Lavi | JETHA BHAI & SONS FOODS & SNACKS PVT. LTD.
# Phone: 09425170635
# Sagar | 73/77
# CosmosCodeVerse
# Phone: 08989225210
# Sagar | 74/77
# Smart Gym Sagar
# Phone: 08269696969
# Sagar | 75/77
# ITSagar Solutions Pvt Ltd - Best Web Design Company - Best Software Development Company - Kurukshetra
# Phone: 07206630663
# Sagar | 76/77
# DEEP VACATIONS
# Phone: 07470718290
# Sagar | 77/77
# Subdha Menu
# Phone:
#
# Searching: software companies in Satna Madhya Pradesh
# Search Submitted
# Satna | software companies | Scroll 1 -> 14
# Satna | software companies | Scroll 2 -> 20
# Satna | software companies | Scroll 3 -> 27
# Satna | software companies | Scroll 4 -> 34
# Satna | software companies | Scroll 5 -> 40
# Satna | software companies | Scroll 6 -> 47
# Satna | software companies | Scroll 7 -> 54
# Satna | software companies | Scroll 8 -> 60
# Satna | software companies | Scroll 9 -> 67
# Satna | software companies | Scroll 10 -> 74
# Satna | software companies | Scroll 11 -> 80
# Satna | software companies | Scroll 12 -> 87
# Satna | software companies | Scroll 13 -> 93
# Satna | software companies | Scroll 14 -> 93
# Satna | software companies | Scroll 15 -> 93
# Satna | software companies | Scroll 16 -> 93
# Satna | software companies | Scroll 17 -> 93
# Collected 91 links
# Satna | 1/91
# Dream Filler Software Solution Private Limited
# Phone:
# Satna | 2/91
# Mangalam Softech
# Phone: 08109865682
# Satna | 3/91
# SPAN Technologies -Auth. Partner TallyPrime, Bizanalyst, Teachmint X Digital Panel, Asus Laptop Desktop,
# Phone: 09425173269
# Satna | 4/91
# TFP Technologies
# Phone:
# Satna | 5/91
# DS ART
# Phone: 08878871333
# Satna | 6/91
# RustyStick Technologies
# Phone: 08305200226
# Satna | 7/91
# Ashpin technologies Pvt Ltd
# Phone: 08800412764
# Satna | 8/91
# Expert Computers Satna I best computer shop in satna
# Phone: 09827008581
# Satna | 9/91
# WebSoft Global IT Services
# Phone: 07000450481
# Satna | 10/91
# The Digi Ghost - Best Digital Marketing Agency | Best Website Development | Best Software Development | Satna
# Phone: 08839476750
# Satna | 11/91
# Satna Software Solutions
# Phone:
# Satna | 12/91
# Developers Life - Website Development in Satna
# Phone: 06261092434
# Satna | 13/91
# Aicorzen-Braynexa-Technologies (OPC) Pvt. Ltd.
# Phone: 08643089591
# Satna | 14/91
# The Computer Admin
# Phone: 09981695252
# Satna | 15/91
# StarWebtek
# Phone:
# Satna | 16/91
# NoblesseTech
# Phone:
# Satna | 17/91
# Zytherra Quantum
# Phone:
# Satna | 18/91
# Reliance Digital
# Phone: 08037002766
# Satna | 19/91
# Mangalam Softech CCTV Solution
# Phone: 09582320243
# Satna | 20/91
# Darkhole
# Phone: 08319390851
# Satna | 21/91
# THE COMPUTER HOUSE SATNA / Best computer repair services
# Phone: 07489075286
# Satna | 22/91
# Proactive'I' an Education & Innovation Company
# Phone: 09999919986
# Satna | 23/91
# 360 Web Services
# Phone: 08120323313
# Satna | 24/91
# PNC & TRADING COMPANY
# Phone:
# Satna | 25/91
# Prompt Computer Services- Best computer shop in Satna
# Phone: 09893391144
# Satna | 26/91
# HP World - Satna
# Phone: 08657568638
# Satna | 27/91
# InnoStellar
# Phone:
# Satna | 28/91
# Sarkaar Infotech
# Phone: 07809777957
# Satna | 29/91
# Web solution & digital marketing Satna | Digital Marketing Agency in Satna | Website Development in Satna
# Phone: 09584471422
# Satna | 30/91
# Techharvest Solutions
# Phone: 08700451046
# Satna | 31/91
# Croma - Satna
# Phone: 09311138725
# Satna | 32/91
# SG IT SOLUTION
# Phone:
# Satna | 33/91
# Computer Planet Tech Solutions Pvt Ltd
# Phone: 09425426325
# Satna | 34/91
# Narmada Packers And Movers Satna
# Phone: 09826828456
# Backup Saved
# Satna | 35/91
# Mynavodayans Online Services Private Limited
# Phone:
# Satna | 36/91
# Innolvex labs
# Phone:
# Satna | 37/91
# SHREE COMPUTERS & ONLINE
# Satna | 83/91
# SHIV SADAN ONLINE
# Phone:
# Satna | 84/91
# Software engineer
# Phone:
# Satna | 85/91
# VITS Satna
# Phone: 08966903524
# Satna | 86/91
# Rama Advertising
# Phone: 09131073008
# Satna | 87/91
# Darkhole
# Phone: 08319390851
# Satna | 88/91
# ProTech SAP Training Institute.
# Phone:
# Satna | 89/91
# Shri balaji accounting company Satna
# Phone: 09000085258
# Satna | 90/91
# Jhankar takies
# Phone:
# Satna | 91/91
# TRUST TECH SOLUTIONS
# Phone:
#
# Searching: software companies in Sehore Madhya Pradesh
# Search Submitted
# Sehore | software companies | Scroll 1 -> 14
# Sehore | software companies | Scroll 2 -> 20
# Sehore | software companies | Scroll 3 -> 27
# Sehore | software companies | Scroll 4 -> 32
# Sehore | software companies | Scroll 5 -> 32
# Sehore | software companies | Scroll 6 -> 32
# Sehore | software companies | Scroll 7 -> 32
# Sehore | software companies | Scroll 8 -> 32
# Collected 32 links
# Sehore | 1/32
# Arpana Infotech Solution Pvt Ltd
# Phone: 06267117249
# Sehore | 2/32
# Arpana Softwares Solution
# Phone: 06267117249
# Sehore | 3/32
# Techno Titan Infotech Digital marketing , complete web solution
# Phone: 09806631980
# Sehore | 4/32
# EMINENCE TALLY
# Phone: 07562490655
# Sehore | 5/32
# VIGYAM GBK LEARN & TECH
# Phone: 09862787401
# Sehore | 6/32
# Arpana Infotech Solution Pvt Ltd
# Phone:
# Sehore | 7/32
# G-INFOSOFT TECHNOLOGIES : Mobile App Deveopment company in Bhopal | Website,AI ML Software development Compnay in Bhopal
# Phone: 09039015374
# Sehore | 8/32
# Lapcom Digital
# Phone: 08818840001
# Sehore | 9/32
# CloudCrums
# Phone: 08962821290
# Sehore | 10/32
# Munna lal verma
# Phone:
# Sehore | 11/32
# e-Suvidha Technologies - Bhopal’s Best IT Services | Website, Software & Digital Marketing in Bhopal
# Phone: 09630608544
# Sehore | 12/32
# Badshah Tech Solutions
# Phone:
# Sehore | 13/32
# Hv Solution computer shop
# Phone: 09977991684
# Sehore | 14/32
# Siddharth Sun Tech Sehore - Rooftop Solar Installation
# Phone: 09644209934
# Sehore | 15/32
# CloudWingsHost
# Phone: 08577066351
# Sehore | 16/32
# HackerKernel
# Phone: 08982017052
# Sehore | 17/32
# Desk Computer Services
# Phone: 09826322605
# Sehore | 18/32
# DAYMA ENTERPRISES SEHORE (Computer Repairing Shop)
# Phone: 08269848437
# Sehore | 19/32
# Netlink Software Private Limited
# Phone: 07556671931
# Sehore | 20/32
# Dezven software solution
# Phone: 07554255941
# Sehore | 21/32
# Authorised Samsung Service Center - Skynet Electronic Service
# Phone: 09827763416
# Sehore | 22/32
# XtraNet Technologies Limited
# Phone: 07554229295
# Sehore | 23/32
# Techhelper Technologies
# Phone: 07223061806
# Sehore | 24/32
# SSS Technologies
# Phone: 09131823248
# Sehore | 25/32
# ITSC Technologies Pvt. Ltd.
# Phone: 07552767785
# Sehore | 26/32
# ISoft InfoTech
# Phone: 09111231311
# Sehore | 27/32
# Shivaay Mp Online
# Phone: 09584023787
# Seoni | 30/41
# JABALI CIRCLE ️
# Phone: 08602767996
# Seoni | 31/41
# Lakhera Computers
# Phone: 09425426741
# Seoni | 32/41
# Blue Dart Express Limited
# Phone:
# Seoni | 33/41
# KAMLESH MP ONLINE
# Phone: 09425662588
# Seoni | 34/41
# Prime Creation - Graphic Design & Motion Graphic Design
# Phone: 07581818109
# Seoni | 35/41
# School Diary Portal
# Phone: 07000166118
# Seoni | 36/41
# Perfume house - Best perfume house in seoni
# Phone:
# Seoni | 37/41
# Soni Computers
# Phone: 08435626732
# Seoni | 38/41
# Vijay Nagar Seoni
# Phone:
# Seoni | 39/41
# Commerce Cabin
# Phone: 08818811362
# Seoni | 40/41
# Ecoavenstra Hr Infotech Pvt. Ltd
# Phone:
# Seoni | 41/41
# House
# Phone:
#
# Searching: software companies in Shahdol Madhya Pradesh
# Search Submitted
# Shahdol | software companies | Scroll 1 -> 7
# Shahdol | software companies | Scroll 2 -> 7
# Shahdol | software companies | Scroll 3 -> 7
# Shahdol | software companies | Scroll 4 -> 7
# Shahdol | software companies | Scroll 5 -> 7
# Collected 7 links
# Shahdol | 1/7
# Apluran Technologies
# Phone: 07869035645
# Shahdol | 2/7
# SWASTIK CONSULTANCY MARG ACCOUNTIG SOLUTION
# Phone: 09713912755
# Shahdol | 3/7
# Ashbit soft
# Phone:
# Shahdol | 4/7
# Tech Anusiya
# Phone:
# Shahdol | 5/7
# Marg Software Shahdol
# Phone: 08319910031
# Shahdol | 6/7
# Maan Computers Sale & Services
# Phone: 09926004025
# Shahdol | 7/7
# White Circle Group
# Phone: 07509759872
#
# Searching: software companies in Shajapur Madhya Pradesh
# Search Submitted
# Shajapur | software companies | Scroll 1 -> 14
# Shajapur | software companies | Scroll 2 -> 20
# Shajapur | software companies | Scroll 3 -> 25
# Shajapur | software companies | Scroll 4 -> 25
# Shajapur | software companies | Scroll 5 -> 25
# Shajapur | software companies | Scroll 6 -> 25
# Shajapur | software companies | Scroll 7 -> 25
# Collected 22 links
# Shajapur | 1/22
# Harvex Studio
# Phone:
# Shajapur | 2/22
# DISHA INFOTECH
# Phone: 09425084688
# Shajapur | 3/22
# QUICK COMPUTER'S
# Phone: 09827553399
# Shajapur | 4/22
# Hindustan Techno
# Phone:
# Shajapur | 5/22
# CCTV Camera | Rv security system |cp plus| Hikvision | Dahua | Shajapur
# Phone: 07509821848
# Shajapur | 6/22
# Sahaj Computers
# Phone: 09826399877
# Shajapur | 7/22
# PARTH INFOTECH
# Phone: 06266601706
# Shajapur | 8/22
# Riya computers & CCTV Camera
# Phone: 09669919888
# Shajapur | 9/22
# RATHORE ENTERPRISES
# Phone: 07974631318
# Shajapur | 10/22
# Tata croma electronics store
# Phone: 08319262180
# Shajapur | 11/22
# APNA COMPUTERS AND CAMERAS SECURITY
# Phone: 07880250923
# Shajapur | 12/22
# Yashsoft Solution – Website & Mobile App Development in Jabalpur, Madhya Pradesh
# Phone: 08818855762
# Shajapur | 13/22
# Integration IT Services Private Limited
# Phone: 08319494921
# Shajapur | 14/22
# Mahankal Cyber Avem Online
# Phone: 09827441799
# Shajapur | 15/22
# Corda Infotech
# Phone:
# Shajapur | 16/22
# Solmeyvn software development company
# Phone: 09630500706
# Shajapur | 17/22
# Susana Tech
# Phone:
# Shajapur | 18/22
# PATIDAR SALES AND SERVICES
# Phone: 09399405412
# Shajapur | 19/22
# YESCOM TECHNOLOGY PRIVATE LIMITED
# Phone: 08792076935
# Shajapur | 20/22
# Ankit Dewda
# Phone: 09575238824
# Shajapur | 21/22
# Engineer
# Phone: 09301789498
# Shajapur | 22/22
# PARTH INFOTECH
# Phone:
#
# Searching: software companies in Sheopur Madhya Pradesh
# Search Submitted
# Sheopur | software companies | Scroll 1 -> 14
# Sheopur | software companies | Scroll 2 -> 20
# Sheopur | software companies | Scroll 3 -> 20
# Sheopur | software companies | Scroll 4 -> 20
# Sheopur | software companies | Scroll 5 -> 20
# Sheopur | software companies | Scroll 6 -> 20
# Collected 20 links
# Sheopur | 1/20
# Royal computer
# Phone:
# Sheopur | 2/20
# Excel Computers
# Phone: 09826761425
# Sheopur | 3/20
# Manish Solution
# Phone: 08989480854
# Sheopur | 4/20
# Shree Shyam Online Center
# Phone: 08602341328
# Sheopur | 5/20
# CSC Online Centre
# Phone: 08871352324
# Sheopur | 6/20
# Agrawal productions house
# Phone: 09131046264
# Sheopur | 7/20
# Divyansh Online Computers
# Phone: 09691237322
# Sheopur | 8/20
# Gauttam Computer
# Phone: 08889387173
# Sheopur | 9/20
# Agrawal tour & travels
# Phone: 08959851980
# Sheopur | 10/20
# mavion solutions
# Phone:
# Sheopur | 11/20
# The muscle factory gym sheopur
# Phone: 07987899836
# Sheopur | 12/20
# Ashbit soft
# Phone: 09691207533
# Sheopur | 13/20
# FCI Godown
# Phone:
# Sheopur | 14/20
# OCTA COMPUTERS AND SOFTWARES
# Phone:
# Sheopur | 15/20
# Oread
# Phone: 07489777851
# Sheopur | 16/20
# All Hindi Tech
# Phone:
# Sheopur | 17/20
# JDMK Technologies Private Limites
# Phone:
# Sheopur | 18/20
# Online Business
# Phone: 08462877841
# Sheopur | 19/20
# Deepak
# Phone: 08349856007
# Sheopur | 20/20
# Sk Digital Seva
# Phone: 07509224041
#
# Searching: software companies in Shivpuri Madhya Pradesh
# Search Submitted
# Shivpuri | software companies | Scroll 1 -> 14
# Shivpuri | software companies | Scroll 2 -> 18
# Shivpuri | software companies | Scroll 3 -> 18
# Shivpuri | software companies | Scroll 4 -> 18
# Shivpuri | software companies | Scroll 5 -> 18
# Shivpuri | software companies | Scroll 6 -> 18
# Collected 18 links
# Shivpuri | 1/18
# Itxperts | Best Software Development Company in India
# Phone: 08871873164
# Shivpuri | 2/18
# Tection Infotech Private Limited
# Phone: 09479307492
# Shivpuri | 3/18
# Infrashyom Nexus Private Limited.
# Phone: 08839001289
# Shivpuri | 4/18
# MMI Softwares Pvt Ltd
# Phone: 05657153333
# Shivpuri | 5/18
# SISODIYA COMPUTERS
# Phone: 08269990000
# Shivpuri | 6/18
# Lalmani sharma home town
# Phone: 07223040682
# Shivpuri | 7/18
# GOIT360 - Best Digital Marketing Agency in Shivpuri
# Phone:
# Shivpuri | 8/18
# Computer World
# Phone: 09827215972
# Shivpuri | 9/18
# Raghav Medical Agencies
# Phone: 09827228524
# Shivpuri | 10/18
# AI POWER SOLUTIONS
# Phone: 07610620046
# Shivpuri | 11/18
# Software Company Flynkey
# Phone:
# Shivpuri | 12/18
# Sky Line Systems Services
# Phone: 09826265053
# Shivpuri | 13/18
# CGUARD SECURITY SOLUTION
# Phone:
# Shivpuri | 14/18
# Carbon track pro
# Phone:
# Shivpuri | 15/18
# OMGURU SOFTWARE PVT LTD
# Phone: 08349696444
# Shivpuri | 16/18
# sameer khan (Inayat Infotech)
# Phone:
# Shivpuri | 17/18
# Softwares
# Phone:
# Shivpuri | 18/18
# Atlik Websoft Pravite Limited
# Phone:
#
# Searching: software companies in Sidhi Madhya Pradesh
# Search Submitted
# Sidhi | software companies | Scroll 1 -> 12
# Sidhi | software companies | Scroll 2 -> 12
# Sidhi | software companies | Scroll 3 -> 12
# Sidhi | software companies | Scroll 4 -> 12
# Sidhi | software companies | Scroll 5 -> 12
# Collected 12 links
# Sidhi | 1/12
# Marg Software Sidhi | Billing Accounting & GST Software
# Phone: 07722883139
# Sidhi | 2/12
# Webkar Digital Solution
# Phone: 08463077803
# Sidhi | 3/12
# Ragini Computers | Digital Signature Certificate | DSC |
# Phone: 09425909031
# Backup Saved
# Sidhi | 4/12
# MASUK COMPUTER
# Phone: 09826118977
# Sidhi | 5/12
# Manya Associates
# Phone: 08080635921
# Sidhi | 6/12
# TECH-FILL SOLUTION PRIVATE LIMITED COMPANY
# Phone:
# Sidhi | 7/12
# RASHI COMPUTERS & PERIPHERALS
# Phone: 09993256885
# Sidhi | 8/12
# Innovation Technology Services
# Phone:
# Sidhi | 9/12
# AS SOLUTION
# Phone: 07415223576
# Sidhi | 10/12
# MP53 Digital Solutions
# Phone:
# Sidhi | 11/12
# KSANDI TECHNOLOGIES PVT LTD
# Phone:
# Sidhi | 12/12
# Akash IT Solutions
# Phone:
#
# Searching: software companies in Singrauli Madhya Pradesh
# Search Submitted
# Singrauli | software companies | Scroll 1 -> 2
# Singrauli | software companies | Scroll 2 -> 2
# Singrauli | software companies | Scroll 3 -> 2
# Singrauli | software companies | Scroll 4 -> 2
# Singrauli | software companies | Scroll 5 -> 2
# Collected 2 links
# Singrauli | 1/2
# Mpencil Software Solutions
# Phone: 09009888333
# Singrauli | 2/2
# PKS Software Private Limited
# Phone: 09425497450
#
# Searching: software companies in Tikamgarh Madhya Pradesh
# Search Submitted
# Tikamgarh | software companies | Scroll 1 -> 9
# Tikamgarh | software companies | Scroll 2 -> 9
# Tikamgarh | software companies | Scroll 3 -> 9
# Tikamgarh | software companies | Scroll 4 -> 9
# Tikamgarh | software companies | Scroll 5 -> 9
# Collected 9 links
# Tikamgarh | 1/9
# Phone: 09302269212
# Ujjain | 96/114
# Gauransh Infotech and Solar Energy
# Phone:
# Ujjain | 97/114
# Gati School
# Phone: 07000546005
# Ujjain | 98/114
# Tower Chowk (Tower Square)
# Phone: 09238249811
# Ujjain | 99/114
# Vakil Matrix
# Phone:
# Ujjain | 100/114
# BL Gupta & Company
# Phone: 09977818877
# Ujjain | 101/114
# Digigain | Best Digital Marketing Service in Ujjain
# Phone: 08965917082
# Ujjain | 102/114
# Alphabetica Traders And Services LLP - TVS Electronics Ltd
# Phone: 07941057690
# Ujjain | 103/114
# Silicon tech solution
# Phone: 09669454554
# Ujjain | 104/114
# Software Solutions
# Phone:
# Ujjain | 105/114
# For You Holidays, MP Tourism Office, Ujjain
# Phone: 08269611111
# Ujjain | 106/114
# Chartered Bus – Ujjain Bus & Parcel Booking Office
# Phone: 07024162445
# Ujjain | 107/114
# Kshipra & Company (P) Ltd - Hero MotoCorp
# Phone: 09289922354
# Ujjain | 108/114
# Vakil matrix
# Phone:
# Ujjain | 109/114
# Logmetix
# Phone:
# Ujjain | 110/114
# SAPNA SOFTWARE AND SYSTEMS SOLUTIONS
# Phone:
# Ujjain | 111/114
# MyPixel
# Phone: 09009086854
# Ujjain | 112/114
# Nexup Labs
# Phone:
# Ujjain | 113/114
# Ratlamwala
# Phone: 09993736333
# Ujjain | 114/114
# Girje Publisher
# Phone:
#
# Searching: software companies in Umaria Madhya Pradesh
# Search Submitted
# Umaria | software companies | Scroll 1 -> 5
# Umaria | software companies | Scroll 2 -> 5
# Umaria | software companies | Scroll 3 -> 5
# Umaria | software companies | Scroll 4 -> 5
# Umaria | software companies | Scroll 5 -> 5
# Collected 5 links
# Umaria | 1/5
# VibTish Ventures
# Phone:
# Umaria | 2/5
# UTKARSH COMPUTERS
# Phone: 09424753313
# Umaria | 3/5
# Vipin Computer Sales And Sarvice
# Phone: 09893798839
# Umaria | 4/5
# Prasar Computers
# Phone:
# Umaria | 5/5
# Pradeep computers
# Phone: 07869779176
#
# Searching: software companies in Vidisha Madhya Pradesh
# Search Submitted
# Vidisha | software companies | Scroll 1 -> 14
# Vidisha | software companies | Scroll 2 -> 20
# Vidisha | software companies | Scroll 3 -> 27
# Vidisha | software companies | Scroll 4 -> 34
# Vidisha | software companies | Scroll 5 -> 40
# Vidisha | software companies | Scroll 6 -> 47
# Vidisha | software companies | Scroll 7 -> 50
# Vidisha | software companies | Scroll 8 -> 50
# Vidisha | software companies | Scroll 9 -> 50
# Vidisha | software companies | Scroll 10 -> 50
# Vidisha | software companies | Scroll 11 -> 50
# Collected 47 links
# Vidisha | 1/47
# Dits Company India Private Limited- Vidisha Branch
# Phone:
# Vidisha | 2/47
# Hellbent Software & Educational Services LLP
# Phone: 07389075284
# Vidisha | 3/47
# ML Web Solution
# Phone: 08085573004
# Vidisha | 4/47
# Prashant Raghuwanshi
# Phone: 08770785849
# Vidisha | 5/47
# Code Scanner IT Solutions
# Phone: 07000755537
# Vidisha | 6/47
# Soft Tech
