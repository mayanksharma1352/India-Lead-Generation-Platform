# %%
import time
import random
import pandas as pd

from datetime import datetime

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.service import Service

from webdriver_manager.chrome import ChromeDriverManager



districts = [
    "Bishnupur",
    "Chandel",
    "Churachandpur",
    "Imphal East",
    "Imphal West",
    "Jiribam",
    "Kakching",
    "Kamjong",
    "Kangpokpi",
    "Noney",
    "Pherzawl",
    "Senapati",
    "Tamenglong",
    "Tengnoupal",
    "Thoubal",
    "Ukhrul"
]



search_types = [
    "software companies",
    "IT companies"
]


options = webdriver.ChromeOptions()

options.add_argument("--start-maximized")

options.add_argument(
    "--disable-blink-features=AutomationControlled"
)

options.add_argument("--disable-notifications")



driver = webdriver.Chrome(

    service=Service(
        ChromeDriverManager().install()
    ),

    options=options
)


driver.get("https://www.google.com/maps")

print("Opening Google Maps...")

time.sleep(15)

print("Google Maps Loaded")



all_data = []

visited_links = set()



def get_search_box():

    selectors = [

        '//input[@id="searchboxinput"]',
        '//input[contains(@placeholder,"Search")]',
        '//input[contains(@aria-label,"Search")]',
        '//input'

    ]

    for selector in selectors:

        try:

            box = driver.find_element(
                By.XPATH,
                selector
            )

            return box

        except:
            pass

    return None


def extract_school_data():

    try:


        try:

            name = driver.find_element(
                By.TAG_NAME,
                "h1"
            ).text

        except:

            name = ""


        try:

            address = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"address")]'
            ).text

        except:

            address = ""


        phone = ""

        try:

            phone_xpaths = [


                '//button[contains(@data-item-id,"phone")]',


                '//a[contains(@href,"tel:")]',

   
                '//button[contains(@aria-label,"Phone")]',


                '//button[contains(text(),"+91")]',
                '//div[contains(text(),"+91")]',
                '//span[contains(text(),"+91")]'

            ]

            for xpath in phone_xpaths:

                try:

                    elements = driver.find_elements(
                        By.XPATH,
                        xpath
                    )

                    for element in elements:

                        text = element.text.strip()

                        href = (
                            element.get_attribute("href")
                            or ""
                        )

                        if "tel:" in href:

                            phone = href.replace(
                                "tel:",
                                ""
                            ).strip()

                        elif text:

                            phone = text

                        phone = (

                            phone.replace("", "")
                            .replace(" ", "")
                            .replace("-", "")
                            .replace("(", "")
                            .replace(")", "")
                            .replace("\n", "")
                            .strip()

                        )


                        digits = ''.join(
                            filter(str.isdigit, phone)
                        )

                        if len(digits) >= 10:

                            break

                    if phone:
                        break

                except:
                    pass

        except Exception as e:

            print(f"Phone Error: {e}")


        try:

            website = driver.find_element(
                By.XPATH,
                '//a[contains(@data-item-id,"authority")]'
            ).get_attribute("href")

        except:

            website = ""


        try:

            rating = driver.find_element(
                By.XPATH,
                '//div[@role="img"]'
            ).get_attribute("aria-label")

        except:

            rating = ""

        return {

            "Company Name": name,
            "Address": address,
            "Phone": phone,
            "Website": website,
            "Rating": rating,
            "Google Maps URL": driver.current_url

        }

    except:

        return None



for district in districts:

    for search_type in search_types:

        try:

            query = (
                f"{search_type} "
                f"in {district} Manipur"
            )

            print(f"\nSearching: {query}")



            search_box = get_search_box()

            if not search_box:

                print("Search Box Not Found")

                continue

            ActionChains(driver).move_to_element(
                search_box
            ).click().perform()

            time.sleep(1)

            search_box.send_keys(
                Keys.CONTROL + "a"
            )

            time.sleep(1)

            search_box.send_keys(Keys.DELETE)

            time.sleep(1)

  

            for char in query:

                search_box.send_keys(char)

                time.sleep(0.03)

            search_box.send_keys(Keys.ENTER)

            print("Search Submitted")

            time.sleep(8)


            try:

                scrollable_div = driver.find_element(
                    By.XPATH,
                    '//div[@role="feed"]'
                )

                previous_count = 0

                stagnant = 0

                for i in range(100):

                    driver.execute_script(
                        """
                        arguments[0].scrollTop =
                        arguments[0].scrollHeight
                        """,
                        scrollable_div
                    )

                    time.sleep(4)

                    listings = driver.find_elements(
                        By.XPATH,
                        '//a[contains(@href,"/maps/place/")]'
                    )

                    current_count = len(listings)

                    print(
                        f"{district} | "
                        f"{search_type} | "
                        f"Scroll {i+1} -> "
                        f"{current_count}"
                    )

                    if current_count == previous_count:

                        stagnant += 1

                    else:

                        stagnant = 0

                    if stagnant >= 4:

                        break

                    previous_count = current_count

            except Exception as e:

                print(f"Scrolling Error: {e}")



            listings = driver.find_elements(
                By.XPATH,
                '//a[contains(@href,"/maps/place/")]'
            )

            links = []

            for listing in listings:

                try:

                    link = listing.get_attribute("href")

                    if (
                        link
                        and link not in visited_links
                    ):

                        links.append(link)

                        visited_links.add(link)

                except:
                    pass

            print(f"Collected {len(links)} links")

  

            for index, link in enumerate(links):

                try:

                    print(
                        f"{district} | "
                        f"{index+1}/{len(links)}"
                    )

                    driver.get(link)

                    time.sleep(
                        random.uniform(2, 3)
                    )

                    data = extract_school_data()

                    if data:

                        data["District"] = district

                        data["Search Type"] = search_type

                        all_data.append(data)

                        print(data["Company Name"])

                        print(
                            f"Phone: {data['Phone']}"
                        )

    

                    if len(all_data) % 100 == 0:

                        backup_df = pd.DataFrame(
                            all_data
                        )

                        backup_df.drop_duplicates(
                            subset=[
                                "Company Name",
                                "Google Maps URL"
                            ],
                            inplace=True
                        )

                        backup_df.to_csv(
                            "manipur_companies_backup.csv",
                            index=False
                        )

                        print("Backup Saved")

                except Exception as e:

                    print(
                        f"Company Error: {e}"
                    )

        except Exception as e:

            print(
                f"District Error: {e}"
            )



df = pd.DataFrame(all_data)

df.drop_duplicates(

    subset=[
        "Company Name",
        "Google Maps URL"
    ],

    inplace=True
)

filename = "manipur_companies.csv"

df.to_csv(
    filename,
    index=False
)

print("\nExtraction Completed")

print(
    f"Total Companies Extracted: {len(df)}"
)

print(f"\nSaved File: {filename}")

driver.quit()
# Out:
# Opening Google Maps...
# Google Maps Loaded
#
# Searching: software companies in Bishnupur Manipur
# Search Submitted
# Bishnupur | software companies | Scroll 1 -> 14
# Bishnupur | software companies | Scroll 2 -> 20
# Bishnupur | software companies | Scroll 3 -> 20
# Bishnupur | software companies | Scroll 4 -> 20
# Bishnupur | software companies | Scroll 5 -> 20
# Bishnupur | software companies | Scroll 6 -> 20
# Collected 20 links
# Bishnupur | 1/20
# Echel
# Phone: 07011482679
# Bishnupur | 2/20
# it solution
# Phone: 08014387815
# Bishnupur | 3/20
# IT Center Bishnupur
# Phone:
# Bishnupur | 4/20
# Phone: 08787800085
# Bishnupur | 19/24
# Thoiba Computer
# Phone: 09856752229
# Bishnupur | 20/24
# K Bon Moirang
# Phone: 08787664095
# Bishnupur | 21/24
# Nganthoi CyberSec
# Phone:
# Bishnupur | 22/24
# Kombirei IT Solutions
# Phone:
# Bishnupur | 23/24
# MANIYAI NINGTHOUJAM
# Phone: 07005155825
# Bishnupur | 24/24
# HAYUM SIDABA
# Phone: 07005875043
#
# Searching: software companies in Chandel Manipur
# Search Submitted
# Chandel | software companies | Scroll 1 -> 14
# Chandel | software companies | Scroll 2 -> 14
# Chandel | software companies | Scroll 3 -> 14
# Chandel | software companies | Scroll 4 -> 14
# Chandel | software companies | Scroll 5 -> 14
# Collected 8 links
# Chandel | 1/8
# Networkmaster Software Solutions Pvt. Ltd.
# Phone: 07308082886
# Chandel | 2/8
# CODEXP
# Phone: 07005776416
# Chandel | 3/8
# LMK Computer
# Phone: 08131051140
# Chandel | 4/8
# Globizs Web Solutions Pvt Ltd
# Phone: 08448447720
# Chandel | 5/8
# ML Cyber Cafe (Common Service Centre)
# Phone: 08787498489
# Chandel | 6/8
# PILIN INFOTECH
# Phone: 09612102861
# Chandel | 7/8
# CSC Kumbi
# Phone: 09862212341
# Chandel | 8/8
# Amenrō variety store / Bekly shop
# Phone: 09233104387
#
# Searching: IT companies in Chandel Manipur
# Search Submitted
# Chandel | IT companies | Scroll 1 -> 14
# Chandel | IT companies | Scroll 2 -> 20
# Chandel | IT companies | Scroll 3 -> 27
# Chandel | IT companies | Scroll 4 -> 34
# Chandel | IT companies | Scroll 5 -> 40
# Chandel | IT companies | Scroll 6 -> 47
# Chandel | IT companies | Scroll 7 -> 54
# Chandel | IT companies | Scroll 8 -> 60
# Chandel | IT companies | Scroll 9 -> 67
# Chandel | IT companies | Scroll 10 -> 74
# Chandel | IT companies | Scroll 11 -> 75
# Chandel | IT companies | Scroll 12 -> 75
# Chandel | IT companies | Scroll 13 -> 75
# Chandel | IT companies | Scroll 14 -> 75
# Chandel | IT companies | Scroll 15 -> 75
# Collected 65 links
# Chandel | 1/65
# hemba.
# Phone: 06009419961
# Chandel | 2/65
#
# Phone:
# Chandel | 3/65
# BASELINE TECHNOLOGIES MANIPUR
# Phone: 09366224241
# Chandel | 4/65
# Xingu Technologies Private Limited
# Phone: 07005123256
# Chandel | 5/65
# KHA Pvt Ltd
# Phone:
# Chandel | 6/65
# Eastern Lily Industries Private Limited
# Phone: 09863473655
# Chandel | 7/65
# SKYNET TECHNOLOGIES - IT, Software's , CCTV, LAN/ WAN IT Services
# Phone: 08894977223
# Chandel | 8/65
# DHAN Infotech
# Phone: 09612441274
# Chandel | 9/65
# GR Infraprojects Ltd
# Phone: 01246435000
# Chandel | 10/65
# UYOKCHING FOODS
# Phone:
# Chandel | 11/65
# Jasha Computer Centre
# Phone: 08974514452
# Chandel | 12/65
# DK Store
# Phone:
# Chandel | 13/65
# LINGJEN ENTERPRISES
# Phone:
# Chandel | 14/65
# Sawmas Computer Works
# Phone: 09366641159
# Phone: 08885910394
# Chandel | 62/65
# ROBINSON COMPUTER CUM JOB CENTER, HEIROK LAIMAYUM
# Phone:
# Chandel | 63/65
# Ngongo Digital Works
# Phone:
# Chandel | 64/65
# Bikash Interprises
# Phone: 08575389630
# Chandel | 65/65
# Aboy Electronics Wangjing Bazar
# Phone:
#
# Searching: software companies in Churachandpur Manipur
# Search Submitted
# Churachandpur | software companies | Scroll 1 -> 9
# Churachandpur | software companies | Scroll 2 -> 9
# Churachandpur | software companies | Scroll 3 -> 9
# Churachandpur | software companies | Scroll 4 -> 9
# Churachandpur | software companies | Scroll 5 -> 9
# Collected 8 links
# Churachandpur | 1/8
# Bits World
# Phone: 09791449981
# Churachandpur | 2/8
# Tongdam Computer Training Centre
# Phone: 08974840121
# Churachandpur | 3/8
# Siam Computer
# Phone: 09612478153
# Churachandpur | 4/8
# Tunnu Engineering and Consultancy
# Phone: 08131808713
# Churachandpur | 5/8
# Software developer Android
# Phone: 07005867613
# Churachandpur | 6/8
# Ngaihte Multiverse
# Phone: 08575121331
# Churachandpur | 7/8
# DK Infotech
# Phone:
# Churachandpur | 8/8
# ZIVA INFOTECH
# Phone: 09383070707
#
# Searching: IT companies in Churachandpur Manipur
# Search Submitted
# Churachandpur | IT companies | Scroll 1 -> 11
# Churachandpur | IT companies | Scroll 2 -> 11
# Churachandpur | IT companies | Scroll 3 -> 11
# Churachandpur | IT companies | Scroll 4 -> 11
# Churachandpur | IT companies | Scroll 5 -> 11
# Collected 8 links
# Churachandpur | 1/8
# NIELIT Extension Centre, Churachandpur
# Phone:
# Churachandpur | 2/8
# L Margareth & Associates
# Phone: 09612455481
# Churachandpur | 3/8
# CSC B AIJALON
# Phone:
# Churachandpur | 4/8
# APUCHI COMPUTER
# Phone: 07085818600
# Churachandpur | 5/8
# inspiring csc
# Phone:
# Churachandpur | 6/8
# Lamka Digital Service
# Phone:
# Churachandpur | 7/8
# Damsel Computer
# Phone:
# Churachandpur | 8/8
# Elite Digitech
# Phone:
#
# Searching: software companies in Imphal East Manipur
# Search Submitted
# Imphal East | software companies | Scroll 1 -> 14
# Imphal East | software companies | Scroll 2 -> 20
# Imphal East | software companies | Scroll 3 -> 27
# Imphal East | software companies | Scroll 4 -> 34
# Imphal East | software companies | Scroll 5 -> 40
# Imphal East | software companies | Scroll 6 -> 47
# Imphal East | software companies | Scroll 7 -> 54
# Imphal East | software companies | Scroll 8 -> 60
# Imphal East | software companies | Scroll 9 -> 67
# Imphal East | software companies | Scroll 10 -> 74
# Imphal East | software companies | Scroll 11 -> 80
# Imphal East | software companies | Scroll 12 -> 87
# Imphal East | software companies | Scroll 13 -> 91
# Imphal East | software companies | Scroll 14 -> 91
# Imphal East | software companies | Scroll 15 -> 91
# Imphal East | software companies | Scroll 16 -> 91
# Imphal East | software companies | Scroll 17 -> 91
# Collected 80 links
# Imphal East | 1/80
# Korou Technologies
# Phone:
# Imphal East | 2/80
# KokSamLai Solutions
# Phone: 03853500420
# Imphal East | 3/80
# SaiyoniX Pvt Ltd
# Endeavor Thangal Bazar
# Phone: 07005179306
# Imphal East | 49/80
# kangla computer
# Phone:
# Imphal East | 50/80
# Foxbeta
# Phone:
# Imphal East | 51/80
# State Academy Of Training,
# Phone: 07097269350
# Imphal East | 52/80
# Thangjing Technologies
# Phone:
# Imphal East | 53/80
# Tech and games
# Phone: 06009965344
# Imphal East | 54/80
# Software Reviews
# Phone:
# Imphal East | 55/80
# Manipur State Power Company Limited (MSPCL)
# Phone:
# Imphal East | 56/80
# Easy Computer
# Phone:
# Imphal East | 57/80
# ZA Travels Agency
# Phone: 07085991003
# Imphal East | 58/80
# GITCS
# Phone:
# Imphal East | 59/80
# hemba.
# Phone: 06009419961
# Imphal East | 60/80
# Yum Tech Warehouse
# Phone:
# Imphal East | 61/80
# Samsung Experience Store Paona Bazar
# Phone: 09615399788
# Imphal East | 62/80
# JENISHENTERPRISES
# Phone:
# Imphal East | 63/80
# Nongthang Technologies
# Phone:
# Imphal East | 64/80
# Sintha Infotech
# Phone: 09863795001
# Imphal East | 65/80
# DIGITAL SEVA KHURAI KONGPAL NINGTHOUBUNG LEIKAI JENSENTS
# Phone:
# Imphal East | 66/80
# Yum Tech Advanced Home Solutions
# Phone:
# Imphal East | 67/80
# Big Engine Marketing LLP
# Phone:
# Backup Saved
# Imphal East | 68/80
# Rojen Leimapokpam
# Phone:
# Imphal East | 69/80
# HARI COMPUTECH
# Phone: 09862008724
# Imphal East | 70/80
# Manipur Handloom & Handicrafts Development Corporation Ltd.
# Phone: 03852442381
# Imphal East | 71/80
# SHAH ENTERPRISE
# Phone: 06395082395
# Imphal East | 72/80
# Nngtw Studio
# Phone: 09366969149
# Imphal East | 73/80
# Clerical manipur secretariat
# Phone:
# Imphal East | 74/80
# Department of Information Technology
# Phone:
# Imphal East | 75/80
# MT Solutions
# Phone: 07005790837
# Imphal East | 76/80
# mobile app
# Phone:
# Imphal East | 77/80
# Build Your Career with ShinePoints – Sales Jobs Hiring Now
# Phone:
# Imphal East | 78/80
# Oinam Internet
# Phone:
# Imphal East | 79/80
# MinersHub Manipur
# Phone:
# Imphal East | 80/80
# Trend Tech Solution
# Phone:
#
# Searching: IT companies in Imphal East Manipur
# Search Submitted
# Imphal East | IT companies | Scroll 1 -> 14
# Imphal East | IT companies | Scroll 2 -> 20
# Imphal East | IT companies | Scroll 3 -> 27
# Imphal East | IT companies | Scroll 4 -> 34
# Imphal East | IT companies | Scroll 5 -> 40
# Imphal East | IT companies | Scroll 6 -> 47
# Imphal East | IT companies | Scroll 7 -> 54
# Imphal East | IT companies | Scroll 8 -> 60
# Imphal East | IT companies | Scroll 9 -> 67
# Imphal East | IT companies | Scroll 10 -> 74
# Imphal East | IT companies | Scroll 11 -> 80
# Imphal East | IT companies | Scroll 12 -> 87
# Imphal East | IT companies | Scroll 13 -> 94
# Imphal East | IT companies | Scroll 14 -> 100
# Imphal East | IT companies | Scroll 15 -> 107
# Imphal East | IT companies | Scroll 16 -> 114
# Imphal East | IT companies | Scroll 17 -> 120
# Imphal East | IT companies | Scroll 18 -> 120
# Schneider Electric - Sony Electrical Centre
# Phone: 08071331078
# Imphal East | 84/97
# Sika Shop
# Phone: 09436039949
# Imphal East | 85/97
# HOME 2 TRAVEL - Best Travel Agent in Imphal, Manipur | Tour Operator in Imphal, Manipur
# Phone: 07477777771
# Imphal East | 86/97
# Cicada Productions Private Limited
# Phone: 07995362081
# Imphal East | 87/97
# D.K. Steel
# Phone: 03852440244
# Backup Saved
# Imphal East | 88/97
# EdisonMangang
# Phone: 07005346599
# Imphal East | 89/97
# PUJA TRADING COMPANY.
# Phone: 09366256424
# Imphal East | 90/97
# Sangai laundry service
# Phone: 09167402217
# Imphal East | 91/97
# B.H. ELECTRICALS
# Phone: 09366671590
# Imphal East | 92/97
# Imphal Hospital & Research Centre
# Phone: 07085233242
# Imphal East | 93/97
# Pureit Water Purifier - Angana Store
# Phone: 09619532344
# Imphal East | 94/97
# Imphal Public Library
# Phone:
# Imphal East | 95/97
# Shree Tirupati Courier Service P Ltd
# Phone: 08937891109
# Imphal East | 96/97
# Tongbram chinglemba lalambung
# Phone:
# Imphal East | 97/97
# MANGAL MEDICAL STORE
# Phone: 06909690086
#
# Searching: software companies in Imphal West Manipur
# Search Submitted
# Imphal West | software companies | Scroll 1 -> 14
# Imphal West | software companies | Scroll 2 -> 20
# Imphal West | software companies | Scroll 3 -> 27
# Imphal West | software companies | Scroll 4 -> 34
# Imphal West | software companies | Scroll 5 -> 40
# Imphal West | software companies | Scroll 6 -> 47
# Imphal West | software companies | Scroll 7 -> 54
# Imphal West | software companies | Scroll 8 -> 60
# Imphal West | software companies | Scroll 9 -> 67
# Imphal West | software companies | Scroll 10 -> 74
# Imphal West | software companies | Scroll 11 -> 75
# Imphal West | software companies | Scroll 12 -> 75
# Imphal West | software companies | Scroll 13 -> 75
# Imphal West | software companies | Scroll 14 -> 75
# Imphal West | software companies | Scroll 15 -> 75
# Collected 32 links
# Imphal West | 1/32
# Rajya Consultancy Services
# Phone: 09436008277
# Imphal West | 2/32
# Hhcits_pvt.ltd
# Phone:
# Imphal West | 3/32
# Sangai Services Pvt Ltd
# Phone: 07005071707
# Imphal West | 4/32
# Dotcom Computer
# Phone: 07627923631
# Imphal West | 5/32
# ISLC - Integrated software Learning and Coaching
# Phone: 08837092731
# Imphal West | 6/32
# BEFCS
# Phone:
# Imphal West | 7/32
# Eartheners
# Phone: 08415921324
# Imphal West | 8/32
# Global IT Mart
# Phone: 09366519783
# Imphal West | 9/32
# Lenovo Service Center - Biswas Udyog
# Phone: 08048247457
# Imphal West | 10/32
# THOIBI AGENCY - Best Electronics and Home appliances Store in Imphal, Refrigerator ,Washing Machine ,TV, AC, Oven etc .
# Phone: 07005560043
# Imphal West | 11/32
# Yash Electronics
# Phone:
# Imphal West | 12/32
# BCS Peripherals
# Phone: 09612159530
# Imphal West | 13/32
# BlueStone Jewellery Kabo Leikai West, Imphal
# Phone: 08655859260
# Imphal West | 14/32
# Mangang Enterprises
# Phone: 07005008960
# Imphal West | 15/32
# SUNRISE ENTERPRISES
# Phone: 07005209719
# Imphal West | 16/32
# Digix
# Phone:
# Imphal West | 17/32
# Samsung SmartPlaza - D.S. Electronics
# Phone: 07039002390
# Imphal West | 18/32
# Robert Naorem Studio & Academy
# Phone: 08257861793
# Imphal West | 19/32
# JBJ CONSTRUCTION
# Phone: 06909558880
# Imphal West | 20/32
# ISTV NETWORK
# Phone: 03852459564
# Imphal West | 21/32
# ATC TRANSPORT (IMPHAL)
# Phone: 03852461625
# Imphal West | 22/32
# Lamjingba Management Services Pvt. Ltd.
# Phone: 07085831502
# Imphal West | 23/32
# VIRGIN ISLAND IMPHAL
# Phone:
# Imphal West | 24/32
# Chengjelspan private limited
# Phone: 08798197367
# Imphal West | 25/32
# Manipur University
# Phone: 03852435276
# Imphal West | 26/32
# Media Computer & Electronics
# Phone: 09615049742
# Imphal West | 27/32
# SaleDepot (Krishna Singh)
# Phone:
# Imphal West | 28/32
# SR ENTERPRISE
# Phone: 07005683217
# Imphal West | 29/32
# BINU Mayum Digital empire
# Phone:
# Imphal West | 30/32
# DTDC
# Phone:
# Imphal West | 31/32
# RINGO SALES AND SERVICE
# Phone: 06909854283
# Imphal West | 32/32
# Korounganbi It Solution
# Phone: 09366128882
#
# Searching: IT companies in Imphal West Manipur
# Search Submitted
# Imphal West | IT companies | Scroll 1 -> 14
# Imphal West | IT companies | Scroll 2 -> 20
# Imphal West | IT companies | Scroll 3 -> 27
# Imphal West | IT companies | Scroll 4 -> 34
# Imphal West | IT companies | Scroll 5 -> 40
# Imphal West | IT companies | Scroll 6 -> 47
# Imphal West | IT companies | Scroll 7 -> 54
# Imphal West | IT companies | Scroll 8 -> 60
# Imphal West | IT companies | Scroll 9 -> 67
# Imphal West | IT companies | Scroll 10 -> 74
# Imphal West | IT companies | Scroll 11 -> 80
# Imphal West | IT companies | Scroll 12 -> 87
# Imphal West | IT companies | Scroll 13 -> 94
# Imphal West | IT companies | Scroll 14 -> 100
# Imphal West | IT companies | Scroll 15 -> 107
# Imphal West | IT companies | Scroll 16 -> 114
# Imphal West | IT companies | Scroll 17 -> 120
# Imphal West | IT companies | Scroll 18 -> 120
# Imphal West | IT companies | Scroll 19 -> 120
# Imphal West | IT companies | Scroll 20 -> 120
# Imphal West | IT companies | Scroll 21 -> 120
# Collected 31 links
# Imphal West | 1/31
# Malang Internet (Malang Solutions Pvt. Ltd.)
# Phone: 09856177334
# Imphal West | 2/31
# Eapmanipur Ring Road
# Phone:
# Imphal West | 3/31
# Khushi Computers
# Phone: 09856160157
# Imphal West | 4/31
# eKeithel - Best Electronics Store in Imphal, Best Refrigerator Store & Washing Machine in Imphal, Manipur
# Phone: 03857964555
# Imphal West | 5/31
# BIO CLEAN WATER CARE SERVICE(OPC) PRIVATE LIMITED
# Phone: 08787803079
# Imphal West | 6/31
# Air India Office, Imphal, Manipur
# Phone: 03852450199
# Imphal West | 7/31
# TRAVEL SOLUTIONS Car Rental Service
# Phone: 08119950161
# Imphal West | 8/31
# Zudio - Thangal Bazaar, Imphal
# Phone: 08655610963
# Imphal West | 9/31
# Blue Dart Booking Counter
# Phone: 03852401036
# Imphal West | 10/31
# Siroi Financial Consultancy Pvt. Ltd.
# Phone:
# Imphal West | 11/31
# MAJORKHUL GATE
# Phone: 08837422654
# Imphal West | 12/31
# Tata AIA Life Insurance Company Limited
# Phone: 18602669966
# Imphal West | 13/31
# Manipur CAB
# Phone:
# Imphal West | 14/31
# Mamta Electricals
# Phone: 07627971329
# Imphal West | 15/31
# IMPHAL TAXI SERVICE
# Phone: 08787335099
# Imphal West | 16/31
# M/s Maheshwari Kumar & Co, Chartered Accountants, CA in Imphal – Consulting in GST, Income Tax, Audit & Compliances.
# Phone: 09632332850
# Imphal West | 17/31
# ELITE TV
# Phone:
# Imphal West | 18/31
# Haorongbam Leikai
# Phone:
# Imphal West | 19/31
# Van Heusen - Pauna Bzr, Imphal
# Phone: 03852447291
# Imphal West | 20/31
# MANIPUR MEDICOS
# Phone:
# Imphal West | 21/31
# Raja kumar
# Phone: 08413961136
# Imphal West | 22/31
# Mangalam Sanitary Mart
# Phone: 09612326655
# Imphal West | 23/31
# Koupalu Business Centre
# Phone:
# Imphal West | 24/31
# Jain Automobiles - Tata , Eicher , AMW, Mahindra and Ashok Leyland parts Exide Amaron
# Phone: 08414818922
# Imphal West | 25/31
# House of Sujata Authorised Dealer- Naman Electricals
# Phone: 09862008346
# Imphal West | 26/31
# United India Insurance Co. Ltd.
# Phone: 03852451813
# Imphal West | 27/31
# Future Hospital Group
# Phone:
# Imphal West | 28/31
# Kajaria Tiles Authorised Showroom - Manipur Build Mart
# Phone: 09366169635
# Imphal West | 29/31
# Pareek enterprises
# Phone: 06033893419
# Imphal West | 30/31
# Manipur Arms & Ammunition
# Phone: 07003310569
# Imphal West | 31/31
# edisonmangang
# Phone:
#
# Searching: software companies in Jiribam Manipur
# Search Submitted
# Scrolling Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@role="feed"]"}
#   (Session info: chrome=148.0.7778.168); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 	chromedriver!GetHandleVerifier [0xbfb593+105d3]
# 	chromedriver!GetHandleVerifier [0xbfb6c4+10704]
# 	chromedriver!(No symbol) [0xa01ea0]
# 	chromedriver!(No symbol) [0xa4b28a]
# 	chromedriver!(No symbol) [0xa4b52b]
# 	chromedriver!(No symbol) [0xa8d052]
# 	chromedriver!(No symbol) [0xa6d7c4]
# 	chromedriver!(No symbol) [0xa8a936]
# 	chromedriver!(No symbol) [0xa6d516]
# 	chromedriver!(No symbol) [0xa408e9]
# 	chromedriver!(No symbol) [0xa416a4]
# 	chromedriver!GetHandleVerifier [0xe83014+298054]
# 	chromedriver!GetHandleVerifier [0xe7e603+293643]
# 	chromedriver!GetHandleVerifier [0xe9ea05+2b3a45]
# 	chromedriver!GetHandleVerifier [0xc154e8+2a528]
# 	chromedriver!GetHandleVerifier [0xc1cd1d+31d5d]
# 	chromedriver!GetHandleVerifier [0xc03e68+18ea8]
# 	chromedriver!GetHandleVerifier [0xc04015+19055]
# 	chromedriver!GetHandleVerifier [0xbed65f+269f]
# 	KERNEL32!BaseThreadInitThunk [0x75c9fcc9+19]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x77a082ae+11e]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x77a0827e+ee]
#
# Collected 0 links
#
# Searching: IT companies in Jiribam Manipur
# Search Submitted
# Jiribam | IT companies | Scroll 1 -> 14
# Jiribam | IT companies | Scroll 2 -> 14
# Jiribam | IT companies | Scroll 3 -> 14
# Jiribam | IT companies | Scroll 4 -> 14
# Jiribam | IT companies | Scroll 5 -> 14
# Collected 7 links
# Jiribam | 1/7
#
# Phone:
# Jiribam | 2/7
#
# Phone: 09862809357
# Jiribam | 3/7
#
# Phone: 08787316021
# Jiribam | 4/7
#
# Phone:
# Jiribam | 5/7
#
# Phone:
# Jiribam | 6/7
#
# Phone: 08732831847
# Jiribam | 7/7
#
# Phone:
#
# Searching: software companies in Kakching Manipur
# Search Submitted
# Scrolling Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@role="feed"]"}
#   (Session info: chrome=148.0.7778.168); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 	chromedriver!GetHandleVerifier [0xbfb593+105d3]
# 	chromedriver!GetHandleVerifier [0xbfb6c4+10704]
# 	chromedriver!(No symbol) [0xa01ea0]
# 	chromedriver!(No symbol) [0xa4b28a]
# 	chromedriver!(No symbol) [0xa4b52b]
# 	chromedriver!(No symbol) [0xa8d052]
# 	chromedriver!(No symbol) [0xa6d7c4]
# 	chromedriver!(No symbol) [0xa8a936]
# 	chromedriver!(No symbol) [0xa6d516]
# 	chromedriver!(No symbol) [0xa408e9]
# 	chromedriver!(No symbol) [0xa416a4]
# 	chromedriver!GetHandleVerifier [0xe83014+298054]
# 	chromedriver!GetHandleVerifier [0xe7e603+293643]
# 	chromedriver!GetHandleVerifier [0xe9ea05+2b3a45]
# 	chromedriver!GetHandleVerifier [0xc154e8+2a528]
# 	chromedriver!GetHandleVerifier [0xc1cd1d+31d5d]
# 	chromedriver!GetHandleVerifier [0xc03e68+18ea8]
# 	chromedriver!GetHandleVerifier [0xc04015+19055]
# 	chromedriver!GetHandleVerifier [0xbed65f+269f]
# 	KERNEL32!BaseThreadInitThunk [0x75c9fcc9+19]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x77a082ae+11e]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x77a0827e+ee]
#
# Collected 0 links
#
# Searching: IT companies in Kakching Manipur
# Search Submitted
# Scrolling Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@role="feed"]"}
#   (Session info: chrome=148.0.7778.168); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 	chromedriver!GetHandleVerifier [0xbfb593+105d3]
# 	chromedriver!GetHandleVerifier [0xbfb6c4+10704]
# 	chromedriver!(No symbol) [0xa01ea0]
# 	chromedriver!(No symbol) [0xa4b28a]
# 	chromedriver!(No symbol) [0xa4b52b]
# 	chromedriver!(No symbol) [0xa8d052]
# 	chromedriver!(No symbol) [0xa6d7c4]
# 	chromedriver!(No symbol) [0xa8a936]
# 	chromedriver!(No symbol) [0xa6d516]
# 	chromedriver!(No symbol) [0xa408e9]
# 	chromedriver!(No symbol) [0xa416a4]
# 	chromedriver!GetHandleVerifier [0xe83014+298054]
# 	chromedriver!GetHandleVerifier [0xe7e603+293643]
# 	chromedriver!GetHandleVerifier [0xe9ea05+2b3a45]
# 	chromedriver!GetHandleVerifier [0xc154e8+2a528]
# 	chromedriver!GetHandleVerifier [0xc1cd1d+31d5d]
# 	chromedriver!GetHandleVerifier [0xc03e68+18ea8]
# 	chromedriver!GetHandleVerifier [0xc04015+19055]
# 	chromedriver!GetHandleVerifier [0xbed65f+269f]
# 	KERNEL32!BaseThreadInitThunk [0x75c9fcc9+19]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x77a082ae+11e]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x77a0827e+ee]
#
# Collected 0 links
#
# Searching: software companies in Kamjong Manipur
# Search Submitted
# Kamjong | software companies | Scroll 1 -> 11
# Kamjong | software companies | Scroll 2 -> 11
# Kamjong | software companies | Scroll 3 -> 11
# Kamjong | software companies | Scroll 4 -> 11
# Kamjong | software companies | Scroll 5 -> 11
# Collected 2 links
# Kamjong | 1/2
# Munna Sha
# Phone: 08538918232
# Kamjong | 2/2
# CSC Kamjong
# Phone:
#
# Searching: IT companies in Kamjong Manipur
# Search Submitted
# Kamjong | IT companies | Scroll 1 -> 14
# Kamjong | IT companies | Scroll 2 -> 20
# Kamjong | IT companies | Scroll 3 -> 27
# Kamjong | IT companies | Scroll 4 -> 34
# Kamjong | IT companies | Scroll 5 -> 40
# Kamjong | IT companies | Scroll 6 -> 47
# Kamjong | IT companies | Scroll 7 -> 52
# Kamjong | IT companies | Scroll 8 -> 52
# Kamjong | IT companies | Scroll 9 -> 52
# Kamjong | IT companies | Scroll 10 -> 52
# Kamjong | IT companies | Scroll 11 -> 52
# Collected 40 links
# Kamjong | 1/40
# Shangs Official Store
# Phone: 07085778750
# Kamjong | 2/40
# Zingsui Village
# Phone:
# Kamjong | 3/40
# CHASSAD VILLAGE
# Phone:
# Kamjong | 4/40
# SDO Office
# Phone:
# Kamjong | 5/40
# Helam te inn
# Phone:
# Kamjong | 6/40
# 33 kV kamjong
# Phone:
# Kamjong | 7/40
# Giginn Haokip
# Phone:
# Kamjong | 8/40
# JC
# Phone:
# Kamjong | 9/40
# Lhunlhing Inn
# Phone:
# Kamjong | 10/40
# Hp_jajo
# Phone:
# Kamjong | 11/40
# Nanao Shaiza ark
# Phone:
# Kamjong | 12/40
# Sampui Hungdangram (Junction)
# Phone:
# Kamjong | 13/40
# Tammi Hungyo
# Phone:
# Kamjong | 14/40
# Glex Haoneo Road
# Phone:
# Kamjong | 15/40
# Lendemocracy Inn
# Phone:
# Kamjong | 16/40
# D Thangkholen Haokip
# Phone:
# Kamjong | 17/40
# Pa Holkhokhai te inn
# Phone:
# Kamjong | 18/40
# Khoikai Junction (Waiting Sheed)
# Phone:
# Backup Saved
# Kamjong | 19/40
# Langli,main village
# Phone:
# Kamjong | 20/40
# Designgama
# Phone: 07005408798
# Kamjong | 21/40
# Mobile Care
# Phone: 08132026895
# Kamjong | 22/40
# Kasomwoshi
# Phone:
# Kamjong | 23/40
# KS COMPUTER, KAMJONG
# Phone:
# Kamjong | 24/40
# village shine
# Phone:
# Kamjong | 25/40
# Thangminlen villa
# Phone:
# Kamjong | 26/40
# Lhingkhoneng Residence
# Phone:
# Kamjong | 27/40
# Khamsaphy Shimray Residence
# Phone:
# Kamjong | 28/40
# Paokai te inn
# Phone:
# Kamjong | 29/40
# Woryar Travels
# Phone:
# Kamjong | 30/40
# Jangminchon te In
# Phone:
# Kamjong | 31/40
# Indane - Bingpa Gramin Vitrak
# Phone: 09862133840
# Kamjong | 32/40
# Lamjing IT Solutions Pvt. Ltd
# Phone: 08285695488
# Kamjong | 33/40
# Sharp Duidang
# Phone:
# Kamjong | 34/40
# Sanalok River, Chatric
# Phone:
# Kamjong | 35/40
# Khoikai Footpath Junction
# Phone:
# Kamjong | 36/40
# Khaps farm
# Phone:
# Kamjong | 37/40
# Yurthiungla Handloom Weaver
# Phone:
# Kamjong | 38/40
# Chuimila Handloom Weaver
# Phone:
# Kamjong | 39/40
# Avinao Handloom Weaver
# Phone:
# Kamjong | 40/40
# Luisomla Handloom Weaver
# Phone:
#
# Searching: software companies in Kangpokpi Manipur
# Search Submitted
# Kangpokpi | software companies | Scroll 1 -> 14
# Kangpokpi | software companies | Scroll 2 -> 20
# Kangpokpi | software companies | Scroll 3 -> 26
# Kangpokpi | software companies | Scroll 4 -> 26
# Kangpokpi | software companies | Scroll 5 -> 26
# Kangpokpi | software companies | Scroll 6 -> 26
# Kangpokpi | software companies | Scroll 7 -> 26
# Collected 15 links
# Kangpokpi | 1/15
# Kangpokpi
# Phone:
# Kangpokpi | 2/15
# Mycampus Pro
# Phone: 08974682796
# Kangpokpi | 3/15
# Hegou Hangsing
# Phone: 09366355059
# Kangpokpi | 4/15
# NG.ALEX FARM
# Phone: 08732059206
# Kangpokpi | 5/15
# Gautam books and stationery - book store / book shop In kangpokpi
# Phone:
# Kangpokpi | 6/15
# D G Hardware store
# Phone: 09366312686
# Kangpokpi | 7/15
# MDC's Residential Quarter
# Phone:
# Kangpokpi | 8/15
# Indane - Js Service
# Phone: 09383276845
# Kangpokpi | 9/15
# White Haven
# Phone:
# Kangpokpi | 10/15
# Mangboi singhol
# Phone:
# Kangpokpi | 11/15
# Marco softs
# Phone: 07838282931
# Kangpokpi | 12/15
# momon computer center
# Phone: 08730093707
# Kangpokpi | 13/15
# COMPUTER
# Phone:
# Kangpokpi | 14/15
# Alfa Enterprise
# Phone:
# Kangpokpi | 15/15
# ENVISION HOSTEL
# Phone: 08132051300
#
# Searching: IT companies in Kangpokpi Manipur
# Search Submitted
# Kangpokpi | IT companies | Scroll 1 -> 14
# Kangpokpi | IT companies | Scroll 2 -> 20
# Kangpokpi | IT companies | Scroll 3 -> 25
# Kangpokpi | IT companies | Scroll 4 -> 25
# Kangpokpi | IT companies | Scroll 5 -> 25
# Kangpokpi | IT companies | Scroll 6 -> 25
# Kangpokpi | IT companies | Scroll 7 -> 25
# Collected 6 links
# Kangpokpi | 1/6
# J. Songtun Village
# Phone:
# Kangpokpi | 2/6
# KTS Computer Centre
# Phone: 09077758239
# Kangpokpi | 3/6
# Victor Internet Service Provider (VISP)
# Phone: 09612005716
# Kangpokpi | 4/6
# H K COMPUTER
# Phone: 08794544983
# Kangpokpi | 5/6
# Khushi Mobile
# Phone: 07005180150
# Kangpokpi | 6/6
# Phailengkot Village Sadar Hills (W) Kangpokpi District.
# Phone:
#
# Searching: software companies in Noney Manipur
# Search Submitted
# Noney | software companies | Scroll 1 -> 3
# Noney | software companies | Scroll 2 -> 3
# Noney | software companies | Scroll 3 -> 3
# Noney | software companies | Scroll 4 -> 3
# Noney | software companies | Scroll 5 -> 3
# Collected 1 links
# Noney | 1/1
# AK Rummy
# Phone: 07544090631
#
# Searching: IT companies in Noney Manipur
# Search Submitted
# Noney | IT companies | Scroll 1 -> 14
# Noney | IT companies | Scroll 2 -> 20
# Noney | IT companies | Scroll 3 -> 27
# Noney | IT companies | Scroll 4 -> 34
# Noney | IT companies | Scroll 5 -> 40
# Noney | IT companies | Scroll 6 -> 47
# Noney | IT companies | Scroll 7 -> 54
# Noney | IT companies | Scroll 8 -> 60
# Noney | IT companies | Scroll 9 -> 67
# Noney | IT companies | Scroll 10 -> 74
# Noney | IT companies | Scroll 11 -> 80
# Noney | IT companies | Scroll 12 -> 85
# Noney | IT companies | Scroll 13 -> 85
# Noney | IT companies | Scroll 14 -> 85
# Noney | IT companies | Scroll 15 -> 85
# Noney | IT companies | Scroll 16 -> 85
# Collected 75 links
# Noney | 1/75
# DAINEL ENTEPRISE
# Phone:
# Noney | 2/75
# COLORS
# Phone: 07005287554
# Noney | 3/75
# My business
# Phone:
# Noney | 4/75
# LT Computer Institute
# Phone:
# Noney | 5/75
# Nianjeijang
# Phone:
# Noney | 6/75
# Noney Community Hall
# Phone:
# Noney | 7/75
# Khumji V
# Phone:
# Noney | 8/75
# Namkhuangam Phaomei
# Phone:
# Noney | 9/75
# Dikoy Golmei
# Phone:
# Noney | 10/75
# T.K SAW MILL
# Phone:
# Noney | 11/75
# CK PRINTING SOLUTION
# Phone: 07629019486
# Noney | 12/75
# Namkhuangam Cottage
# Phone:
# Noney | 13/75
# Dynamic Computer/OURS
# Phone: 07085334859
# Noney | 14/75
# THOMSON INDANE AGENCY
# Phone:
# Noney | 15/75
# Kuku Hostel
# Phone:
# Noney | 16/75
# Longmai chingkao Jengthek kai( rest-house)
# Phone:
# Noney | 17/75
# Blessed Home
# Phone:
# Noney | 18/75
# Longmai Noney Bazar
# Phone: 09362836530
# Noney | 19/75
# Healing compound
# Phone:
# Noney | 20/75
# WBS Printing
# Phone:
# Noney | 21/75
# Longmai 3
# Phone:
# Noney | 22/75
# Three brothers semion Lanjik Meihondai residents
# Phone:
# Noney | 23/75
# Godown, Noney Indane Gramin Vitrak
# Phone:
# Noney | 24/75
# Niamei Gonmei
# Phone:
# Noney | 25/75
# Dove Valley
# Phone:
# Noney | 26/75
# DC office Noney
# Phone:
# Noney | 27/75
# Khumji3
# Phone:
# Noney | 28/75
# Dr.MK Chun Residence
# Phone: 08731986154
# Noney | 29/75
# DAINEL ENTEPRISE
# Phone:
# Noney | 30/75
# PG Haopou
# Phone: 08414994366
# Noney | 31/75
# Lobo
# Phone:
# Noney | 32/75
# Nka House
# Phone:
# Noney | 33/75
# Gonmei
# Phone:
# Noney | 34/75
# Elltone's Enterprise
# Phone:
# Noney | 35/75
# Namdourei Inpui's Inn
# Phone:
# Noney | 36/75
# Inkah's Inn
# Phone: 08132010842
# Noney | 37/75
# Katapou Pamei
# Phone:
# Noney | 38/75
# CK PHOTOGRAPHY
# Phone:
# Noney | 39/75
# Dijingam
# Phone:
# Noney | 40/75
# LIBRA-STONE OFFICE
# Phone:
# Noney | 41/75
# Namthuibuan kamei farm
# Phone:
# Noney | 42/75
# Ijei river(Aga-RA-AH)
# Phone:
# Noney | 43/75
# Diphungai
# Phone:
# Noney | 44/75
# LOVESON RESIDENT
# Phone:
# Noney | 45/75
# Polungchui
# Phone:
# Noney | 46/75
# Alupuang Fish Centre
# Phone: 08974839315
# Noney | 47/75
# Damchuilung
# Phone:
# Noney | 48/75
# Tanky- pung
# Phone:
# Noney | 49/75
# Gracy Girl's Hostel
# Phone:
# Noney | 50/75
# Indane - Noney Gramin Vitrak
# Phone: 09436236551
# Noney | 51/75
# Jyanpu Ruangmei
# Phone:
# Noney | 52/75
# Gondaisin/gondaimei
# Phone:
# Noney | 53/75
# NAMTHUINBUAN Tree farm
# Phone:
# Noney | 54/75
# Thuingam Home
# Phone: 08798785917
# Noney | 55/75
# Heatherwoods
# Phone:
# Noney | 56/75
# Carolinas house
# Phone:
# Backup Saved
# Noney | 57/75
# Lanjik Building
# Phone:
# Noney | 58/75
# Pourei kamei house
# Phone:
# Noney | 59/75
# Manoj Variety Store
# Phone: 07085270101
# Noney | 60/75
# Elite Sports by KP Enterprise
# Phone:
# Noney | 61/75
# Melody Riamei
# Phone:
# Noney | 62/75
# Lungshingthuan Kamei
# Phone:
# Noney | 63/75
# LY. Gonmei
# Phone:
# Noney | 64/75
# ABCI CAMP
# Phone:
# Noney | 65/75
# Dam & Jang construction
# Phone:
# Noney | 66/75
# KG gangmei
# Phone:
# Noney | 67/75
# Gaipanrei’s Residence
# Phone:
# Noney | 68/75
# Lanjik fishery pond
# Phone:
# Noney | 69/75
# ANIL STORE
# Phone:
# Noney | 70/75
# GD Gaithuan
# Phone:
# Noney | 71/75
# YAFIRA, women’s accessories store
# Phone:
# Noney | 72/75
# Ngamxinlung Gonxon Tech
# Phone:
# Noney | 73/75
# Panmei Residence
# Phone:
# Noney | 74/75
# RIAMEI RESIDENCE
# Phone:
# Noney | 75/75
# Paddy field
# Phone:
#
# Searching: software companies in Pherzawl Manipur
# Search Submitted
# Pherzawl | software companies | Scroll 1 -> 7
# Pherzawl | software companies | Scroll 2 -> 7
# Pherzawl | software companies | Scroll 3 -> 7
# Pherzawl | software companies | Scroll 4 -> 7
# Pherzawl | software companies | Scroll 5 -> 7
# Collected 1 links
# Pherzawl | 1/1
# Pherzawl DC Office Complex
# Phone:
#
# Searching: IT companies in Pherzawl Manipur
# Search Submitted
# Pherzawl | IT companies | Scroll 1 -> 14
# Pherzawl | IT companies | Scroll 2 -> 20
# Pherzawl | IT companies | Scroll 3 -> 27
# Pherzawl | IT companies | Scroll 4 -> 34
# Pherzawl | IT companies | Scroll 5 -> 37
# Pherzawl | IT companies | Scroll 6 -> 37
# Pherzawl | IT companies | Scroll 7 -> 37
# Pherzawl | IT companies | Scroll 8 -> 37
# Pherzawl | IT companies | Scroll 9 -> 37
# Collected 30 links
# Pherzawl | 1/30
# Songate Enterprise
# Phone: 07085245123
# Pherzawl | 2/30
# Aadhaar Enrolment Centre, Pherzawl
# Phone:
# Pherzawl | 3/30
# Pherzawl EAC Pastor Quarter
# Phone:
# Pherzawl | 4/30
# RuongleVaisuo
# Phone:
# Pherzawl | 5/30
# Lalsiemvel In
# Phone:
# Pherzawl | 6/30
# Thangzo Home
# Phone:
# Pherzawl | 7/30
# Pherzawl WMCEI Pastor quarter
# Phone:
# Pherzawl | 8/30
# Jephany
# Phone:
# Pherzawl | 9/30
# IRCA Pherzawl (REHAB)
# Phone:
# Pherzawl | 10/30
# Kan in
# Phone:
# Pherzawl | 11/30
# Upa Lalthlamuong
# Phone:
# Pherzawl | 12/30
# FIMZAHLEI HRANNGUL
# Phone:
# Pherzawl | 13/30
# Tieulien Manipur
# Phone:
# Pherzawl | 14/30
# Refound Children for Boys
# Phone:
# Pherzawl | 15/30
# Ezra house
# Phone:
# Pherzawl | 16/30
# Fiber team Room-Thanlon
# Phone:
# Pherzawl | 17/30
# JDtau Villa
# Phone:
# Pherzawl | 18/30
# PANGAMTE RÛN
# Phone:
# Pherzawl | 19/30
# Block Development Officer Quarter
# Phone:
# Pherzawl | 20/30
# Tunglut Innpi
# Phone:
# Pherzawl | 21/30
# Jephany house
# Phone:
# Pherzawl | 22/30
# Thanlon SCDP Lianchungii
# Phone:
# Pherzawl | 23/30
# Thanlon SCDP Pauhounem
# Phone:
# Pherzawl | 24/30
# Hausa te inn
# Phone:
# Pherzawl | 25/30
# Lalngilnei
# Phone:
# Pherzawl | 26/30
# Kalia Saulim
# Phone:
# Pherzawl | 27/30
# LH Dawnglien house
# Phone:
# Pherzawl | 28/30
# Thangkhanmoi guite
# Phone:
# Pherzawl | 29/30
# Lalzawmlien Khawbung
# Phone:
# Pherzawl | 30/30
# Ngullienthang house
# Phone:
#
# Searching: software companies in Senapati Manipur
# Search Submitted
# Senapati | software companies | Scroll 1 -> 14
# Senapati | software companies | Scroll 2 -> 17
# Senapati | software companies | Scroll 3 -> 17
# Senapati | software companies | Scroll 4 -> 17
# Senapati | software companies | Scroll 5 -> 17
# Senapati | software companies | Scroll 6 -> 17
# Collected 13 links
# Senapati | 1/13
# Noney
# Phone: 08258020535
# Senapati | 2/13
# S S Infotech, RGYCSM COMPUTER SENAPATI
# Phone: 08787466130
# Senapati | 3/13
# PCD Print Hub, Manipur
# Phone: 09383105527
# Senapati | 4/13
# Job Centre (Senapati)
# Phone: 08732855656
# Senapati | 5/13
# TECH HUT SENAPATI
# Phone: 09871152119
# Senapati | 6/13
# SaCyc
# Phone: 09612902168
# Senapati | 7/13
# LS COMPUTER WORLD
# Phone: 08732855656
# Senapati | 8/13
# Dianthe Private Limited
# Phone: 07085274011
# Senapati | 9/13
# Airtel Store
# Phone: 07836002861
# Senapati | 10/13
# Om Narayan Gupta
# Phone: 09199626545
# Senapati | 11/13
# BLUE DART EXPRESS
# Phone:
# Senapati | 12/13
# Nivia Sports Store
# Phone:
# Senapati | 13/13
# Tech Com Offset
# Phone:
#
# Searching: IT companies in Senapati Manipur
# Search Submitted
# Senapati | IT companies | Scroll 1 -> 14
# Senapati | IT companies | Scroll 2 -> 20
# Senapati | IT companies | Scroll 3 -> 27
# Senapati | IT companies | Scroll 4 -> 34
# Senapati | IT companies | Scroll 5 -> 37
# Senapati | IT companies | Scroll 6 -> 37
# Senapati | IT companies | Scroll 7 -> 37
# Senapati | IT companies | Scroll 8 -> 37
# Senapati | IT companies | Scroll 9 -> 37
# Collected 19 links
# Senapati | 1/19
# RIDAM INFOTECH
# Phone: 08416005038
# Senapati | 2/19
# Hiimai (Purul) Taphou
# Phone:
# Senapati | 3/19
# Senapati Washmart
# Phone: 08730004364
# Senapati | 4/19
# Senapati Water Supply
# Phone:
# Senapati | 5/19
# IRKIM
# Phone: 08974506310
# Senapati | 6/19
# DIGITAL ELECTRONIC
# Phone: 08974167369
# Senapati | 7/19
# 3D Hotel
# Phone: 09667567837
# Senapati | 8/19
# Christian Literature Center
# Phone:
# Senapati | 9/19
# Network Boys' Hostel
# Phone:
# Senapati | 10/19
# Times of Senapati
# Phone: 09233002887
# Senapati | 11/19
# The Old R'ich A'le ORA
# Phone: 09366976691
# Senapati | 12/19
# Apfii Saliki
# Phone:
# Senapati | 13/19
# Kshetrapati Industries Pvt Ltd
# Phone: 08669123909
# Senapati | 14/19
# B.C.General store (Carpet,Matress,Doormat,Ceiling plastic, All Gas & Pressure cooker PARTS)
# Phone:
# Senapati | 15/19
# Flipkart Office,Vakho ,Senapati
# Phone:
# Senapati | 16/19
# Senapati
# Phone:
# Senapati | 17/19
# TRENDS
# Phone: 09148971029
# Senapati | 18/19
# IndianOil
# Phone: 06909561824
# Senapati | 19/19
# Th Customer Point
# Phone: 09612408413
#
# Searching: software companies in Tamenglong Manipur
# Search Submitted
# Tamenglong | software companies | Scroll 1 -> 14
# Tamenglong | software companies | Scroll 2 -> 15
# Tamenglong | software companies | Scroll 3 -> 15
# Tamenglong | software companies | Scroll 4 -> 15
# Tamenglong | software companies | Scroll 5 -> 15
# Tamenglong | software companies | Scroll 6 -> 15
# Collected 7 links
# Tamenglong | 1/7
# Thiam Studio
# Phone:
# Tamenglong | 2/7
# Times Services
# Phone: 09862877725
# Tamenglong | 3/7
# Grace BnB Home Stay, Tamenglong
# Phone:
# Tamenglong | 4/7
# MK ELECTRONIC & MOBILE
# Phone: 08974897985
# Tamenglong | 5/7
# Mark Pamei Resident
# Phone:
# Tamenglong | 6/7
# Brothersoft Computer Works
# Phone:
# Tamenglong | 7/7
# Nano Tech
# Phone:
#
# Searching: IT companies in Tamenglong Manipur
# Search Submitted
# Tamenglong | IT companies | Scroll 1 -> 10
# Tamenglong | IT companies | Scroll 2 -> 10
# Tamenglong | IT companies | Scroll 3 -> 10
# Tamenglong | IT companies | Scroll 4 -> 10
# Tamenglong | IT companies | Scroll 5 -> 10
# Collected 0 links
#
# Searching: software companies in Tengnoupal Manipur
# Search Submitted
# Tengnoupal | software companies | Scroll 1 -> 8
# Tengnoupal | software companies | Scroll 2 -> 8
# Tengnoupal | software companies | Scroll 3 -> 8
# Tengnoupal | software companies | Scroll 4 -> 8
# Tengnoupal | software companies | Scroll 5 -> 8
# Collected 2 links
# Tengnoupal | 1/2
# ADDBLE SOLUTIONS PRIVATE LIMITED
# Phone: 07085097856
# Tengnoupal | 2/2
# MoshiL TecH
# Phone: 07005053106
#
# Searching: IT companies in Tengnoupal Manipur
# Search Submitted
# Tengnoupal | IT companies | Scroll 1 -> 8
# Tengnoupal | IT companies | Scroll 2 -> 8
# Tengnoupal | IT companies | Scroll 3 -> 8
# Tengnoupal | IT companies | Scroll 4 -> 8
# Tengnoupal | IT companies | Scroll 5 -> 8
# Collected 1 links
# Tengnoupal | 1/1
# Gaby's Cafe and Resort, Imphal
# Phone:
#
# Searching: software companies in Thoubal Manipur
# Search Submitted
# Thoubal | software companies | Scroll 1 -> 14
# Thoubal | software companies | Scroll 2 -> 20
# Thoubal | software companies | Scroll 3 -> 23
# Thoubal | software companies | Scroll 4 -> 23
# Thoubal | software companies | Scroll 5 -> 23
# Thoubal | software companies | Scroll 6 -> 23
# Thoubal | software companies | Scroll 7 -> 23
# Collected 9 links
# Thoubal | 1/9
# Public Prints and Enterprises Ltd
# Phone: 07005298475
# Thoubal | 2/9
# Techno Care Institute (TCI), Thoubal
# Phone: 09612249401
# Thoubal | 3/9
# Flipkart & Myntra Thoubal
# Phone:
# Thoubal | 4/9
# SSSM COMPUTER
# Phone:
# Thoubal | 5/9
# My Jio Store
# Phone: 09326940454
# Thoubal | 6/9
# Imariya Computer Training Centre [I.C.T.C]
# Phone:
# Thoubal | 7/9
# ALex
# Phone:
# Thoubal | 8/9
# Create Origins
# Phone:
# Backup Saved
# Thoubal | 9/9
# Mangang Computer
# Phone:
#
# Searching: IT companies in Thoubal Manipur
# Search Submitted
# Scrolling Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@role="feed"]"}
#   (Session info: chrome=148.0.7778.168); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 	chromedriver!GetHandleVerifier [0xbfb593+105d3]
# 	chromedriver!GetHandleVerifier [0xbfb6c4+10704]
# 	chromedriver!(No symbol) [0xa01ea0]
# 	chromedriver!(No symbol) [0xa4b28a]
# 	chromedriver!(No symbol) [0xa4b52b]
# 	chromedriver!(No symbol) [0xa8d052]
# 	chromedriver!(No symbol) [0xa6d7c4]
# 	chromedriver!(No symbol) [0xa8a936]
# 	chromedriver!(No symbol) [0xa6d516]
# 	chromedriver!(No symbol) [0xa408e9]
# 	chromedriver!(No symbol) [0xa416a4]
# 	chromedriver!GetHandleVerifier [0xe83014+298054]
# 	chromedriver!GetHandleVerifier [0xe7e603+293643]
# 	chromedriver!GetHandleVerifier [0xe9ea05+2b3a45]
# 	chromedriver!GetHandleVerifier [0xc154e8+2a528]
# 	chromedriver!GetHandleVerifier [0xc1cd1d+31d5d]
# 	chromedriver!GetHandleVerifier [0xc03e68+18ea8]
# 	chromedriver!GetHandleVerifier [0xc04015+19055]
# 	chromedriver!GetHandleVerifier [0xbed65f+269f]
# 	KERNEL32!BaseThreadInitThunk [0x75c9fcc9+19]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x77a082ae+11e]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x77a0827e+ee]
#
# Collected 0 links
#
# Searching: software companies in Ukhrul Manipur
# Search Submitted
# Ukhrul | software companies | Scroll 1 -> 9
# Ukhrul | software companies | Scroll 2 -> 9
# Ukhrul | software companies | Scroll 3 -> 9
# Ukhrul | software companies | Scroll 4 -> 9
# Ukhrul | software companies | Scroll 5 -> 9
# Collected 9 links
# Ukhrul | 1/9
# Yurs Enterprise(Aadhaar Enrolment Center)
# Phone:
# Ukhrul | 2/9
# Sachiri Enterprise
# Phone: 09612936753
# Ukhrul | 3/9
# Valins Computer Aadhaar Enrollment Centre
# Phone: 09863002105
# Ukhrul | 4/9
# TheMoments Studio
# Phone: 08877007743
# Ukhrul | 5/9
# Vibrance Computer Works
# Phone: 03870265103
# Ukhrul | 6/9
# Lengkot Tech Solutions
# Phone:
# Ukhrul | 7/9
# AS Mashun
# Phone:
# Ukhrul | 8/9
# Hao Software Training Centre, Ukhrul
# Phone: 08256934667
# Ukhrul | 9/9
# Rs
# Phone:
#
# Searching: IT companies in Ukhrul Manipur
# Search Submitted
# Ukhrul | IT companies | Scroll 1 -> 14
# Ukhrul | IT companies | Scroll 2 -> 20
# Ukhrul | IT companies | Scroll 3 -> 27
# Ukhrul | IT companies | Scroll 4 -> 34
# Ukhrul | IT companies | Scroll 5 -> 40
# Ukhrul | IT companies | Scroll 6 -> 47
# Ukhrul | IT companies | Scroll 7 -> 47
# Ukhrul | IT companies | Scroll 8 -> 47
# Ukhrul | IT companies | Scroll 9 -> 47
# Ukhrul | IT companies | Scroll 10 -> 47
# Collected 28 links
# Ukhrul | 1/28
# AREN'S CSC
# Phone: 08415032735
# Ukhrul | 2/28
# Hao Computer Works
# Phone: 09366694691
# Ukhrul | 3/28
# DROPEE
# Phone:
# Ukhrul | 4/28
# NEXT_GEN OFFICIAL
# Phone:
# Ukhrul | 5/28
# viewland zone 3
# Phone: 08416051995
# Ukhrul | 6/28
# Marison Entertainment
# Phone:
# Ukhrul | 7/28
# CLYDE AGRO MARKETING
# Phone:
# Ukhrul | 8/28
# DreamTech Ukhrul 2014
# Phone:
# Ukhrul | 9/28
# Dungrei Junction Hungpung
# Phone:
# Ukhrul | 10/28
# Wolorim Manor
# Phone:
# Ukhrul | 11/28
# Magen Hills
# Phone: 06909994149
# Ukhrul | 12/28
# Tuikhar family area
# Phone:
# Ukhrul | 13/28
# Hamleikhong D Block
# Phone:
# Ukhrul | 14/28
# District Transport Office
# Phone:
# Ukhrul | 15/28
# Lungshang Kong
# Phone:
# Ukhrul | 16/28
# Majan Tala
# Phone:
# Ukhrul | 17/28
# DownTown Cafe - Ukhrul Hungpung
# Phone: 09233592212
# Ukhrul | 18/28
# 25 Degree North Hotel and Restaurant ukhrul
# Phone: 09089355756
# Ukhrul | 19/28
# Ukhrul IT Centre
# Phone:
# Ukhrul | 20/28
# Lunghar Baptist Church (LBC)
# Phone:
# Ukhrul | 21/28
# Vishal Mega Mart
# Phone: 07005337399
# Ukhrul | 22/28
# Autonomous District Council
# Phone:
# Ukhrul | 23/28
# NIC Ukhrul
# Phone:
# Ukhrul | 24/28
# 3 in 1 Hotel
# Phone:
# Ukhrul | 25/28
# Invictus
# Phone:
# Ukhrul | 26/28
# Mobile legend hack skin
# Phone:
# Ukhrul | 27/28
# M Peak Stone Works
# Phone:
# Ukhrul | 28/28
# KAHING FASHION TAILOR
# Phone: 07629949814
#
# Extraction Completed
# Total Companies Extracted: 638
#
# Saved File: manipur_companies.csv
