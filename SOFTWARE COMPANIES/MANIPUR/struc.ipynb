# %%
import pandas as pd

# %%
df = pd.read_csv("manipur_companies.csv")

# %%
df.shape
# Out:
# (638, 8)

# %%
df = df[
    df["Phone"].notna() & 
    (df["Phone"].astype(str).str.strip() != "")
    ]
df.shape
# Out:
# (331, 8)

# %%
df = df[
    df["Company Name"].notna()
    ]

df = df[
    df["Company Name"].str.strip() != ""
    ]
df.shape
# Out:
# (328, 8)

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]","",regex=True)
    .str.strip()
)

display(df[["Phone"]].head())
# Out:
#          Phone
# 0  70114826790
# 1  80143878150
# 3  70053200860
# 4  96123419680
# 5  83850944080

# %%
df.to_csv(
    "manipur_companies_cleaned.csv",
    index=False
)
