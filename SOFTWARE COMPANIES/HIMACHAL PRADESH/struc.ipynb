# %%
import pandas as pd

# %%
df = pd.read_csv("himachal_pradesh_companies.csv")

# %%
df.shape
# Out:
# (861, 8)

# %%
df = df[
    df["Phone"].notna() & 
    (df["Phone"].astype(str).str.strip() != "")
    ]
df.shape
# Out:
# (652, 8)

# %%
df = df[
    df["Company Name"].notna()
    ]

df = df[
    df["Company Name"].str.strip() != ""
    ]
df.shape
# Out:
# (651, 8)

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]","",regex=True)
    .str.strip()
)

display(df[["Phone"]].head())
# Out:
#          Phone
# 0  98578780820
# 1  96259443610
# 2  94189665950
# 5  94180310500
# 6  93577052220

# %%
df.to_csv(
    "himachal_pradesh_companies_cleaned.csv",
    index=False
)
