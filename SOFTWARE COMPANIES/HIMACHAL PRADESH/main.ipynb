# %%
import time
import random
import pandas as pd

from datetime import datetime

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.service import Service

from webdriver_manager.chrome import ChromeDriverManager


districts = [
    "Bilaspur",
    "Chamba",
    "Hamirpur",
    "Kangra",
    "Kinnaur",
    "Kullu",
    "Lahaul and Spiti",
    "Mandi",
    "Shimla",
    "Sirmaur",
    "Solan",
    "Una"
]



search_types = [
    "software companies",
    "IT companies"
]


options = webdriver.ChromeOptions()

options.add_argument("--start-maximized")

options.add_argument(
    "--disable-blink-features=AutomationControlled"
)

options.add_argument("--disable-notifications")


driver = webdriver.Chrome(

    service=Service(
        ChromeDriverManager().install()
    ),

    options=options
)


driver.get("https://www.google.com/maps")

print("Opening Google Maps...")

time.sleep(15)

print("Google Maps Loaded")


all_data = []

visited_links = set()


def get_search_box():

    selectors = [

        '//input[@id="searchboxinput"]',
        '//input[contains(@placeholder,"Search")]',
        '//input[contains(@aria-label,"Search")]',
        '//input'

    ]

    for selector in selectors:

        try:

            box = driver.find_element(
                By.XPATH,
                selector
            )

            return box

        except:
            pass

    return None


def extract_school_data():

    try:


        try:

            name = driver.find_element(
                By.TAG_NAME,
                "h1"
            ).text

        except:

            name = ""


        try:

            address = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"address")]'
            ).text

        except:

            address = ""

    
        phone = ""

        try:

            phone_xpaths = [

                '//button[contains(@data-item-id,"phone")]',

                '//a[contains(@href,"tel:")]',

                '//button[contains(@aria-label,"Phone")]',

                '//button[contains(text(),"+91")]',
                '//div[contains(text(),"+91")]',
                '//span[contains(text(),"+91")]'

            ]

            for xpath in phone_xpaths:

                try:

                    elements = driver.find_elements(
                        By.XPATH,
                        xpath
                    )

                    for element in elements:

                        text = element.text.strip()

                        href = (
                            element.get_attribute("href")
                            or ""
                        )


                        if "tel:" in href:

                            phone = href.replace(
                                "tel:",
                                ""
                            ).strip()

                        elif text:

                            phone = text

                        phone = (

                            phone.replace("", "")
                            .replace(" ", "")
                            .replace("-", "")
                            .replace("(", "")
                            .replace(")", "")
                            .replace("\n", "")
                            .strip()

                        )

                        digits = ''.join(
                            filter(str.isdigit, phone)
                        )

                        if len(digits) >= 10:

                            break

                    if phone:
                        break

                except:
                    pass

        except Exception as e:

            print(f"Phone Error: {e}")



        try:

            website = driver.find_element(
                By.XPATH,
                '//a[contains(@data-item-id,"authority")]'
            ).get_attribute("href")

        except:

            website = ""



        try:

            rating = driver.find_element(
                By.XPATH,
                '//div[@role="img"]'
            ).get_attribute("aria-label")

        except:

            rating = ""

        return {

            "Company Name": name,
            "Address": address,
            "Phone": phone,
            "Website": website,
            "Rating": rating,
            "Google Maps URL": driver.current_url

        }

    except:

        return None



for district in districts:

    for search_type in search_types:

        try:

            query = (
                f"{search_type} "
                f"in {district} Himachal Pradesh"
            )

            print(f"\nSearching: {query}")



            search_box = get_search_box()

            if not search_box:

                print("Search Box Not Found")

                continue

            ActionChains(driver).move_to_element(
                search_box
            ).click().perform()

            time.sleep(1)

            search_box.send_keys(
                Keys.CONTROL + "a"
            )

            time.sleep(1)

            search_box.send_keys(Keys.DELETE)

            time.sleep(1)



            for char in query:

                search_box.send_keys(char)

                time.sleep(0.03)

            search_box.send_keys(Keys.ENTER)

            print("Search Submitted")

            time.sleep(8)



            try:

                scrollable_div = driver.find_element(
                    By.XPATH,
                    '//div[@role="feed"]'
                )

                previous_count = 0

                stagnant = 0

                for i in range(100):

                    driver.execute_script(
                        """
                        arguments[0].scrollTop =
                        arguments[0].scrollHeight
                        """,
                        scrollable_div
                    )

                    time.sleep(4)

                    listings = driver.find_elements(
                        By.XPATH,
                        '//a[contains(@href,"/maps/place/")]'
                    )

                    current_count = len(listings)

                    print(
                        f"{district} | "
                        f"{search_type} | "
                        f"Scroll {i+1} -> "
                        f"{current_count}"
                    )

                    if current_count == previous_count:

                        stagnant += 1

                    else:

                        stagnant = 0

                    if stagnant >= 4:

                        break

                    previous_count = current_count

            except Exception as e:

                print(f"Scrolling Error: {e}")



            listings = driver.find_elements(
                By.XPATH,
                '//a[contains(@href,"/maps/place/")]'
            )

            links = []

            for listing in listings:

                try:

                    link = listing.get_attribute("href")

                    if (
                        link
                        and link not in visited_links
                    ):

                        links.append(link)

                        visited_links.add(link)

                except:
                    pass

            print(f"Collected {len(links)} links")



            for index, link in enumerate(links):

                try:

                    print(
                        f"{district} | "
                        f"{index+1}/{len(links)}"
                    )

                    driver.get(link)

                    time.sleep(
                        random.uniform(2, 3)
                    )

                    data = extract_school_data()

                    if data:

                        data["District"] = district

                        data["Search Type"] = search_type

                        all_data.append(data)

                        print(data["Company Name"])

                        print(
                            f"Phone: {data['Phone']}"
                        )



                    if len(all_data) % 100 == 0:

                        backup_df = pd.DataFrame(
                            all_data
                        )

                        backup_df.drop_duplicates(
                            subset=[
                                "Company Name",
                                "Google Maps URL"
                            ],
                            inplace=True
                        )

                        backup_df.to_csv(
                            "himachal_pradesh_companies_backup.csv",
                            index=False
                        )

                        print("Backup Saved")

                except Exception as e:

                    print(
                        f"Company Error: {e}"
                    )

        except Exception as e:

            print(
                f"District Error: {e}"
            )



df = pd.DataFrame(all_data)

df.drop_duplicates(

    subset=[
        "Company Name",
        "Google Maps URL"
    ],

    inplace=True
)

filename = "himachal_pradesh_companies.csv"

df.to_csv(
    filename,
    index=False
)

print("\nExtraction Completed")

print(
    f"Total Companies Extracted: {len(df)}"
)

print(f"\nSaved File: {filename}")

driver.quit()
# Out:
# Opening Google Maps...
# Google Maps Loaded
#
# Searching: software companies in Bilaspur Himachal Pradesh
# Search Submitted
# Bilaspur | software companies | Scroll 1 -> 14
# Bilaspur | software companies | Scroll 2 -> 20
# Bilaspur | software companies | Scroll 3 -> 27
# Bilaspur | software companies | Scroll 4 -> 34
# Bilaspur | software companies | Scroll 5 -> 40
# Bilaspur | software companies | Scroll 6 -> 47
# Bilaspur | software companies | Scroll 7 -> 54
# Bilaspur | software companies | Scroll 8 -> 60
# Bilaspur | software companies | Scroll 9 -> 67
# Bilaspur | software companies | Scroll 10 -> 74
# Bilaspur | software companies | Scroll 11 -> 80
# Bilaspur | software companies | Scroll 12 -> 85
# Paramount Infotech
# Phone: 09817611621
# Bilaspur | 39/85
# CHIRAG TECH HUB
# Phone: 08894820610
# Bilaspur | 40/85
# Shiva Institute of Engineering and Technology
# Phone: 09418000903
# Bilaspur | 41/85
# Tirupati Technologies | Laser cutting and Robotic Kits manufacturers
# Phone: 08920477097
# Bilaspur | 42/85
# CSR Solutions
# Phone: 09816160016
# Bilaspur | 43/85
# Vasu Packers & Movers
# Phone: 09810736651
# Bilaspur | 44/85
# Codeinator Technologies
# Phone:
# Bilaspur | 45/85
# My Faces Productions
# Phone: 07018947047
# Bilaspur | 46/85
# Apple Plants in India - Rajat Biotech
# Phone: 07018039923
# Bilaspur | 47/85
# Avinnia
# Phone:
# Bilaspur | 48/85
# Bgrow Spark - Digital Marketing & Design Agency in India
# Phone:
# Bilaspur | 49/85
# Habigrow
# Phone: 07559721016
# Bilaspur | 50/85
# RSK Tech Labs - Digital marketing, Social media marketing, Website development, Billing Software, Posiflex, Nukkad Shops
# Phone: 08219229233
# Bilaspur | 51/85
# IT Zone Star Academy
# Phone:
# Bilaspur | 52/85
# Master Solvers
# Phone: 07009218289
# Bilaspur | 53/85
# Ultratech Cement, Baga
# Phone:
# Bilaspur | 54/85
# CeliSoftware
# Phone: 09770599354
# Bilaspur | 55/85
# Daksh Designs
# Phone: 09816030320
# Bilaspur | 56/85
# Devender Chandel
# Phone: 09459526222
# Bilaspur | 57/85
# Soft Computers
# Phone: 09039171745
# Bilaspur | 58/85
# Delhivery Office
# Phone:
# Bilaspur | 59/85
# A1 Traders
# Phone: 09817714321
# Bilaspur | 60/85
# Sobti Tech
# Phone:
# Bilaspur | 61/85
# BMR IT Solution
# Phone: 09817010025
# Bilaspur | 62/85
# Ultratech Cement Grinding & Blending Unit
# Phone:
# Bilaspur | 63/85
# HAWK P SECURITY SERVICES / cctv camera repair & dealer
# Phone: 08219311775
# Bilaspur | 64/85
# Bansi Lal Duni Chand ( BLDC )
# Phone: 09816050235
# Bilaspur | 65/85
# ANM Info
# Phone:
# Bilaspur | 66/85
# Government Hydro Engineering College Bandla, Bilaspur, HP
# Phone: 09882347597
# Bilaspur | 67/85
# Inocrypt Infosoft | best software company in Jabalpur | best programming institute in Jabalpur
# Phone: 09131519101
# Bilaspur | 68/85
# Bhatti Info Tech and Ex Servicemen Service Center
# Phone: 09682384805
# Bilaspur | 69/85
# KD Soft Solutions
# Phone:
# Bilaspur | 70/85
# Vishwakarma Infotech Services
# Phone: 09971211405
# Bilaspur | 71/85
# Harman Computers
# Phone: 09888648362
# Bilaspur | 72/85
# MLM Software Company in Himachal Pradesh
# Phone:
# Bilaspur | 73/85
# Motilal Oswal Financial Services Limited
# Phone: 09821511945
# Bilaspur | 74/85
# Code Waves IT Solutions
# Phone:
# Bilaspur | 75/85
# VRG ENTERPRISES
# Phone: 09857032211
# Bilaspur | 76/85
# DRDA BILASPUR
# Phone:
# Bilaspur | 77/85
# Datyaltech
# Phone: 09817904261
# Bilaspur | 78/85
# GAUTAM INSTITUTE OF VOCATIONAL TRAINING
# Phone: 07018027992
# Bilaspur | 79/85
# Trends Creator Web Developers
# Phone: 07580061620
# Bilaspur | 80/85
# Kuldeep kumar
# Phone: 08580663107
# Bilaspur | 81/85
# Baijnath computers and institute
# Phone:
# Bilaspur | 82/85
# Marvelx
# Phone:
# Bilaspur | 83/85
# PV TECH SOLUTIONS
# Phone:
# Bilaspur | 84/85
# Computer hardware software and CCTV
# Phone:
# Bilaspur | 85/85
# Bhazon.com
# Phone:
#
# Searching: IT companies in Bilaspur Himachal Pradesh
# Search Submitted
# Bilaspur | IT companies | Scroll 1 -> 14
# Bilaspur | IT companies | Scroll 2 -> 20
# Bilaspur | IT companies | Scroll 3 -> 27
# Bilaspur | IT companies | Scroll 4 -> 34
# Bilaspur | IT companies | Scroll 5 -> 40
# Bilaspur | IT companies | Scroll 6 -> 45
# Bilaspur | IT companies | Scroll 7 -> 45
# Bilaspur | IT companies | Scroll 8 -> 45
# Bilaspur | IT companies | Scroll 9 -> 45
# Bilaspur | IT companies | Scroll 10 -> 45
# Collected 32 links
# Bilaspur | 1/32
# Advocate Abhishek Sharma Income Tax Gst Services and supported legal services
# Phone: 09816267555
# Bilaspur | 2/32
# Aadarsh Infotech
# Phone: 08219259960
# Bilaspur | 3/32
# IFB point - Bilaspur
# Phone: 07018803645
# Bilaspur | 4/32
# Vinee Electronics
# Phone: 09816024597
# Bilaspur | 5/32
# Bilaspur bus stand
# Phone:
# Bilaspur | 6/32
# Ashwani Opticals Bilaspur
# Phone: 07018479704
# Bilaspur | 7/32
# Blue Dart Express Limited
# Phone:
# Bilaspur | 8/32
# PRIYUMS
# Phone: 09857558000
# Bilaspur | 9/32
# RESEARCH TREND (PUBLICATION) www.researchtrend.net
# Phone: 09868001440
# Bilaspur | 10/32
# AIIMS Bilaspur
# Phone: 01978280456
# Bilaspur | 11/32
# Ganpati Trading Company
# Phone: 09817584929
# Bilaspur | 12/32
# Dogra Sports Wears And Goods (factory & retail store )
# Phone: 09816375037
# Bilaspur | 13/32
# Tumbledry Dry Clean & Laundry Service
# Phone: 07677250250
# Bilaspur | 14/32
# Hungama Foods Bilaspur - Best Foods In Bilaspur
# Phone: 07876308290
# Bilaspur | 15/32
# Ultrafresh Modular Solutions Powered By Prestige - Bilaspur, Himachal Pradesh
# Phone: 09816538507
# Backup Saved
# Bilaspur | 16/32
# Modern Arch Infra Service Provider
# Phone: 07018757834
# Bilaspur | 17/32
# Bilaspur city Taxi service
# Phone: 07018899656
# Bilaspur | 18/32
# Cybersense +
# Phone: 06230926491
# Bilaspur | 19/32
# Adv ROHIT SHARMA
# Phone: 09418624606
# Bilaspur | 20/32
# Tattwix- Digital Marketing & Design Agency in India
# Phone:
# Bilaspur | 21/32
# Advocate Piyush Sharma
# Phone:
# Bilaspur | 22/32
# VK Education Services
# Phone: 07807820051
# Bilaspur | 23/32
# SEJAL HI TECH Computer Institute
# Phone: 09816656734
# Bilaspur | 24/32
# eXpert iT Services : Website, Software, Android Apps, iOS, Web Application Development
# Phone: 07722944377
# Bilaspur | 25/32
# Advocate Rahul Sharma GST & Tax Consultant
# Phone: 09816640400
# Bilaspur | 26/32
# Suzu Travels
# Phone: 07307404461
# Bilaspur | 27/32
# Goldi HP Bilaspur taxi service
# Phone:
# Bilaspur | 28/32
# LOK MITRA KENDRA BILASPUR - NEW BABA COLLECTIONS & PLAYSTATION GAMING ZONE PS( NBC )
# Phone:
# Bilaspur | 29/32
# Gaurav Thakur Advocate Distt. Court Bilaspur H.P.
# Phone: 09418806764
# Bilaspur | 30/32
# Advocate Anku Gautam
# Phone: 07018672447
# Bilaspur | 31/32
# Kahlur Adventures India
# Phone: 08588846600
# Bilaspur | 32/32
# Tanisha mobile planet
# Phone: 09816024596
#
# Searching: software companies in Chamba Himachal Pradesh
# Search Submitted
# Chamba | software companies | Scroll 1 -> 7
# Chamba | software companies | Scroll 2 -> 7
# Chamba | software companies | Scroll 3 -> 7
# Chamba | software companies | Scroll 4 -> 7
# Chamba | software companies | Scroll 5 -> 7
# Collected 7 links
# Chamba | 1/7
# STAFFI CYBER MAGIC
# Phone: 09418474760
# Chamba | 2/7
# TopRanko
# Phone: 09015022758
# Chamba | 3/7
# Next Gen Computers
# Phone: 09418004938
# Chamba | 4/7
# PLAH Infotech ZCA
# Phone: 09459836081
# Chamba | 5/7
# Your Last Minute Helper
# Phone: 08894352517
# Chamba | 6/7
# Tech Cloud
# Phone: 08894240844
# Chamba | 7/7
# WebinShot Private Limited
# Phone:
#
# Searching: IT companies in Chamba Himachal Pradesh
# Search Submitted
# Chamba | IT companies | Scroll 1 -> 14
# Chamba | IT companies | Scroll 2 -> 20
# Chamba | IT companies | Scroll 3 -> 27
# Chamba | IT companies | Scroll 4 -> 34
# Chamba | IT companies | Scroll 5 -> 40
# Chamba | IT companies | Scroll 6 -> 47
# Chamba | IT companies | Scroll 7 -> 54
# Chamba | IT companies | Scroll 8 -> 60
# Chamba | IT companies | Scroll 9 -> 67
# Chamba | IT companies | Scroll 10 -> 69
# Chamba | IT companies | Scroll 11 -> 69
# Chamba | IT companies | Scroll 12 -> 69
# Chamba | IT companies | Scroll 13 -> 69
# Chamba | IT companies | Scroll 14 -> 69
# Collected 64 links
# Chamba | 1/64
# HARI OM COMPUTERS
# Phone: 09816076076
# Chamba | 2/64
# Jamwal Infotech – CCTV & IT Solutions
# Phone: 09818208525
# Chamba | 3/64
# Sambyal Enterprises
# Phone: 09817398790
# Chamba | 4/64
# Website design and development
# Phone: 07307275732
# Chamba | 5/64
# The Gadget Store Chamba
# Phone:
# Chamba | 6/64
# Techsoft Digital
# Phone: 07018807038
# Chamba | 7/64
# CCTV Camera Computer Shop
# Phone: 08647900019
# Chamba | 8/64
# Daksh Cyber Cafe & Lok Mitra Kendra
# Phone: 09625671471
# Chamba | 9/64
# LOK MITRA KENDRA CHAMBA
# Phone: 09418499912
# Chamba | 10/64
# Tumbledry Dry Clean & Laundry Service
# Phone: 07677250250
# Chamba | 11/64
# Sharma Trader – Electronics & Home Appliances Store
# Phone: 08968795698
# Chamba | 12/64
# Novelty Corner
# Phone: 09459233641
# Chamba | 13/64
# Nexus iT, Tax and Insure Services
# Phone: 09805720201
# Chamba | 14/64
# Cholamandalam Investment and Finance Company Limited
# Phone: 08044464998
# Chamba | 15/64
# Dhauladhar Transit Chamba
# Phone: 07650002743
# Chamba | 16/64
# ICT Solutions
# Phone: 08894729965
# Chamba | 17/64
# Tri Devi Tours And Travels
# Phone: 08219553895
# Chamba | 18/64
# Anki infotech
# Phone: 09717924201
# Chamba | 19/64
# Bhuri Singh Power House Chamba
# Phone:
# Chamba | 20/64
# Sai Furnishers & Electronics
# Phone: 09816117515
# Chamba | 21/64
# Mountain Vedic (ayurvedic herbal soap) manufacturer
# Phone: 08219528484
# Chamba | 22/64
# GOVT ITI CHAMBA
# Phone:
# Chamba | 23/64
# Thakur Color Lab
# Phone:
# Chamba | 24/64
# Downtown Restaurant and Banquets
# Phone: 07876583134
# Chamba | 25/64
# OPPO | OnePlus Authorized Service Center - Chamba
# Phone: 01899223836
# Chamba | 26/64
# Alphanzo Technology Private Limited
# Phone: 08889859180
# Chamba | 27/64
# DKTour Book&Taxi services
# Phone: 08580750346
# Chamba | 28/64
# Patiyal Infotech Pvt Ltd
# Phone: 08360297896
# Chamba | 29/64
# Maa Kalka Tour and Travels
# Phone: 08091761006
# Chamba | 30/64
# Chamera Power Station-2 Office
# Phone:
# Chamba | 31/64
# Himalayan Orchard Huts
# Phone: 09418991475
# Chamba | 32/64
# Bakshi Enterprises
# Phone: 07650021000
# Chamba | 33/64
# Balaji Medical Hall Chamba , Medicine Wholesale Distributors (Insulin, Nephrology, Anti-Cancer , OTCs & Generics Hub)
# Phone:
# Chamba | 34/64
# Roopniketan Appartments Lala Saudagar Mal Estate
# Phone: 07807266418
# Chamba | 35/64
# Mani Mahesh Travels
# Phone:
# Chamba | 36/64
# Chamera Power Station-3 Residencial Colony
# Phone:
# Chamba | 37/64
# Echor Alpine Meadows Khajjiar Dalhousie
# Phone: 09501221124
# Chamba | 38/64
# Kalatop Wildlife Sanctuary
# Phone: 08219747425
# Chamba | 39/64
# Puri recovery van service chamba
# Phone: 09816095536
# Chamba | 40/64
# DTDC Courier
# Phone:
# Chamba | 41/64
# Get your edit - Best Wedding Photographers in Chamba | Photo Studio | Video Editing | Photo Frames
# Phone: 08580731564
# Chamba | 42/64
# Amit tour and travel chamba
# Phone: 08219769053
# Chamba | 43/64
# Noxdox Studio | Web Development & Application Development Agency In Chamba, Himachal Pradesh
# Phone:
# Chamba | 44/64
# Government Degree College, Chamba
# Phone: 01899222207
# Chamba | 45/64
# Fashion World 22
# Phone: 07470000220
# Chamba | 46/64
# Rankdriven Digital Solutions
# Phone: 09816608796
# Chamba | 47/64
# Bite & Bliss
# Phone: 08226000006
# Chamba | 48/64
# De Baker's Heaven
# Phone: 08894665544
# Chamba | 49/64
# Kapoor Tour & Travels
# Phone: 09816784848
# Chamba | 50/64
# Ghumo Ji
# Phone:
# Chamba | 51/64
# Virtuoso Design
# Phone: 08628081616
# Chamba | 52/64
# Panchtatva
# Phone: 08575182222
# Chamba | 53/64
# Artisan's Light
# Phone: 09805138939
# Hamirpur | 23/24
# Digital Info Softwares
# Phone:
# Hamirpur | 24/24
# Sviamiprimonraj
# Phone: 08988967111
#
# Searching: IT companies in Hamirpur Himachal Pradesh
# Search Submitted
# Hamirpur | IT companies | Scroll 1 -> 14
# Hamirpur | IT companies | Scroll 2 -> 20
# Hamirpur | IT companies | Scroll 3 -> 21
# Hamirpur | IT companies | Scroll 4 -> 21
# Hamirpur | IT companies | Scroll 5 -> 21
# Hamirpur | IT companies | Scroll 6 -> 21
# Hamirpur | IT companies | Scroll 7 -> 21
# Collected 8 links
# Hamirpur | 1/8
# DigitalWebdia - Digital Marketing & Website Designing Agency
# Phone: 07018268698
# Hamirpur | 2/8
# SN SERVICES Hamirpur
# Phone: 09805991999
# Hamirpur | 3/8
# Sarthak Technologies
# Phone: 09322804849
# Hamirpur | 4/8
# SWAGAT ASSOCIAT
# Phone: 07807699070
# Hamirpur | 5/8
# Computer Centre
# Phone:
# Hamirpur | 6/8
# Concept Grow IT Solutions Pvt. Ltd.
# Phone: 07355090488
# Hamirpur | 7/8
# Career Point University, Hamirpur
# Phone: 07807833302
# Hamirpur | 8/8
# Sunshine group And company hamirpur
# Phone: 08580413341
#
# Searching: software companies in Kangra Himachal Pradesh
# Search Submitted
# Kangra | software companies | Scroll 1 -> 14
# Kangra | software companies | Scroll 2 -> 17
# Kangra | software companies | Scroll 3 -> 17
# Kangra | software companies | Scroll 4 -> 17
# Kangra | software companies | Scroll 5 -> 17
# Kangra | software companies | Scroll 6 -> 17
# Collected 17 links
# Kangra | 1/17
# DevPeak Innovations
# Phone:
# Kangra | 2/17
# Cybermagic Tech. Pvt. & Ltd.
# Phone: 01892293483
# Kangra | 3/17
# Billing Accounting Software Himachal | ERP EXPERT | Marg Erp
# Phone: 06230112700
# Kangra | 4/17
# Trigarta Infotech
# Phone:
# Kangra | 5/17
# Expert Solution
# Phone: 08352851005
# Kangra | 6/17
# iConcept Kangra (Apple Authorised Reseller)
# Phone: 07807007078
# Kangra | 7/17
# Laptop services kangra and computer repair
# Phone: 07009794383
# Kangra | 8/17
# Tech Shakeel
# Phone: 08894628317
# Kangra | 9/17
# OnePlus Experience Store
# Phone: 09218080801
# Kangra | 10/17
# NexRise Skills
# Phone:
# Kangra | 11/17
# Caddcraft technologies kangra
# Phone:
# Kangra | 12/17
# Xwebdevelopers Himachal Pardesh
# Phone: 09418366387
# Kangra | 13/17
# NETCOM COMPUTERS
# Phone: 09418247455
# Kangra | 14/17
# Grover Brothers
# Phone: 07018100918
# Kangra | 15/17
# CAD CENTRE KANGRA
# Phone: 07018251531
# Kangra | 16/17
# Disha It Lab Kangra
# Phone:
# Kangra | 17/17
# Easytechinfo
# Phone: 07814976130
#
# Searching: IT companies in Kangra Himachal Pradesh
# Search Submitted
# Kangra | IT companies | Scroll 1 -> 14
# Kangra | IT companies | Scroll 2 -> 20
# Kangra | IT companies | Scroll 3 -> 27
# Kangra | IT companies | Scroll 4 -> 31
# Kangra | IT companies | Scroll 5 -> 31
# Kangra | IT companies | Scroll 6 -> 31
# Kangra | IT companies | Scroll 7 -> 31
# Kangra | IT companies | Scroll 8 -> 31
# Collected 18 links
# Kangra | 1/18
# Samsung SmartPlaza - Soami Electronics
# Phone: 07039003649
# Kangra | 2/18
# Apex Computer and Technical Education Pvt. Ltd.
# Phone:
# Kangra | 3/18
# Bharti Infosolution
# Phone: 07650807979
# Kangra | 4/18
# Unmetered Technologies LLP
# Phone: 06230005354
# Kangra | 5/18
# Himachal Flour Mills (P) Ltd
# Phone: 08894265041
# Kangra | 6/18
# AVS Enterprises
# Phone: 07018143481
# Kangra | 7/18
# The Amritsar Transport Company Pvt. Ltd.Kangra
# Phone:
# Kangra | 8/18
# Exotic Phone Accessories & Repair Private Limited
# Phone: 08070707400
# Kangra | 9/18
# Tanishq Jewellery - Kangra
# Phone: 08091699088
# Kangra | 10/18
# A One Bakers Kangra
# Phone: 09418869090
# Kangra | 11/18
# Epic Management Group
# Phone:
# Kangra | 12/18
# Himkhand Consultants Private Limited
# Phone: 01892295700
# Kangra | 13/18
# CA in Kangra / GST Returns / Tax Consultents / Income Tax / Company Registration
# Phone: 09817182000
# Kangra | 14/18
# Divyansh Sood Web Developer
# Phone:
# Kangra | 15/18
# Malhotra Refrigeration Works- Electronics Goods Showroom|Commercial kitchen equipment Supplier.
# Phone: 09816074202
# Kangra | 16/18
# The Amritsar Transport Company Pvt. Ltd.
# Phone: 01892265639
# Kangra | 17/18
# Perfect Mobile &Computer Repair
# Phone: 09857556418
# Kangra | 18/18
# Anuj infotech Kangra
# Phone: 08896900005
#
# Searching: software companies in Kinnaur Himachal Pradesh
# Search Submitted
# Kinnaur | software companies | Scroll 1 -> 14
# Kinnaur | software companies | Scroll 2 -> 20
# Kinnaur | software companies | Scroll 3 -> 27
# Kinnaur | software companies | Scroll 4 -> 34
# Kinnaur | software companies | Scroll 5 -> 40
# Kinnaur | software companies | Scroll 6 -> 47
# Kinnaur | software companies | Scroll 7 -> 54
# Kinnaur | software companies | Scroll 8 -> 60
# Kinnaur | software companies | Scroll 9 -> 67
# Kinnaur | software companies | Scroll 10 -> 74
# Kinnaur | software companies | Scroll 11 -> 80
# Kinnaur | software companies | Scroll 12 -> 87
# Kinnaur | software companies | Scroll 13 -> 94
# Kinnaur | software companies | Scroll 14 -> 95
# Kinnaur | software companies | Scroll 15 -> 95
# Kinnaur | software companies | Scroll 16 -> 95
# Kinnaur | software companies | Scroll 17 -> 95
# Kinnaur | software companies | Scroll 18 -> 95
# Collected 92 links
# Kinnaur | 1/92
# Naveen Infocom
# Phone: 09805202555
# Kinnaur | 2/92
# D-Tech Computer Solution
# Phone:
# Kinnaur | 3/92
# Reliable Trading Company
# Phone: 09816091002
# Kinnaur | 4/92
# 7weboceans
# Phone: 09872465144
# Kinnaur | 5/92
# Chankum Orchard
# Phone: 07018912009
# Kinnaur | 6/92
# Zostel Kalpa (Kinnaur)
# Phone: 01141169303
# Kinnaur | 7/92
# Zostel Sangla
# Phone: 01141169657
# Kinnaur | 8/92
# TIDONG Power Generation Private Limited
# Phone:
# Kinnaur | 9/92
# Kinnaur | IT companies | Scroll 4 -> 34
# Kinnaur | IT companies | Scroll 5 -> 40
# Kinnaur | IT companies | Scroll 6 -> 47
# Kinnaur | IT companies | Scroll 7 -> 54
# Kinnaur | IT companies | Scroll 8 -> 60
# Kinnaur | IT companies | Scroll 9 -> 67
# Kinnaur | IT companies | Scroll 10 -> 74
# Kinnaur | IT companies | Scroll 11 -> 80
# Kinnaur | IT companies | Scroll 12 -> 87
# Kinnaur | IT companies | Scroll 13 -> 94
# Kinnaur | IT companies | Scroll 14 -> 100
# Kinnaur | IT companies | Scroll 15 -> 107
# Kinnaur | IT companies | Scroll 16 -> 114
# Kinnaur | IT companies | Scroll 17 -> 120
# Kinnaur | IT companies | Scroll 18 -> 120
# Kinnaur | IT companies | Scroll 19 -> 120
# Kinnaur | IT companies | Scroll 20 -> 120
# Kinnaur | IT companies | Scroll 21 -> 120
# Collected 42 links
# Kinnaur | 1/42
# Tech Sprinters Pvt Ltd | IT Company in Shimla
# Phone: 01772645994
# Kinnaur | 2/42
# Akshit Homestay
# Phone: 09418800096
# Kinnaur | 3/42
# Maa Chandike Durga Ji Temple Kothi
# Phone:
# Kinnaur | 4/42
# Pranshi Home Stay Kalpa
# Phone:
# Kinnaur | 5/42
# Kanishka home stay Maki marag road reckong peo kinnour hp
# Phone: 09817580025
# Kinnaur | 6/42
# Kinneer Kailash Tour & Travels
# Phone: 07876123050
# Kinnaur | 7/42
# Pawan Tent House
# Phone: 07018347710
# Kinnaur | 8/42
# KinVatika Homestay
# Phone: 09953493171
# Kinnaur | 9/42
# HPTDC Hotel The Kinner Kailash
# Phone:
# Kinnaur | 10/42
# Wanderers Homestay - All mountain facing rooms
# Phone: 08219275493
# Kinnaur | 11/42
# Yulla Kanda (Lord Krishna Temple)
# Phone:
# Kinnaur | 12/42
# The Monk Cottages kalpa
# Phone: 09816737004
# Kinnaur | 13/42
# Yulla kanda Kin camps and cafe
# Phone: 07807533102
# Kinnaur | 14/42
# Igloo nature camp
# Phone: 08860294119
# Kinnaur | 15/42
# Norling Homestay Nako
# Phone: 07876586374
# Kinnaur | 16/42
# CAFE EILISH AND RETREAT(CAFE,ROOMS & DORMITORY)
# Phone: 09888885077
# Kinnaur | 17/42
# Fayul Retreat
# Phone: 07807411180
# Kinnaur | 18/42
# Maa Bhagwati Home stay
# Phone: 07876020084
# Kinnaur | 19/42
# Himtenz homestay Nako
# Phone: 09805100035
# Kinnaur | 20/42
# Mannat Home Stay
# Phone: 09817957773
# Kinnaur | 21/42
# Homestay - TOKNYA HILLTOP
# Phone:
# Kinnaur | 22/42
# Hango village
# Phone: 09459242634
# Kinnaur | 23/42
# MOUNTAIN HOMESTAY , RECKONG PEO
# Phone: 07018451917
# Kinnaur | 24/42
# Rudra Homestays
# Phone:
# Kinnaur | 25/42
# Gian Complex Tapri
# Phone:
# Kinnaur | 26/42
# Avika home stay
# Phone: 07876066405
# Kinnaur | 27/42
# Baspa Valley
# Phone:
# Kinnaur | 28/42
# Baspa (Stage 2) Dam
# Phone: 02242861000
# Kinnaur | 29/42
# Nikhil's Villa
# Phone:
# Kinnaur | 30/42
# Norbu house cafe tabo
# Phone: 08580496606
# Kinnaur | 31/42
# Lake View Resort, kafnoo
# Phone: 07807554615
# Kinnaur | 32/42
# Shruti Guest House
# Phone:
# Kinnaur | 33/42
# ओसिया रंगनू राक्छम रिट्रीट
# Phone:
# Kinnaur | 34/42
# DEEPAK HOME STAY KALPA
# Phone:
# Kinnaur | 35/42
# Khosh Dhaba Hotel and Homestay
# Phone: 09418070316
# Kinnaur | 36/42
# Hotel Destination
# Phone: 09418939421
# Kinnaur | 37/42
# Hotel snow Hill view
# Phone:
# Kinnaur | 38/42
# Hotel Inner Tukpa
# Phone: 01786223077
# Kinnaur | 39/42
# Kalpa Biz resort
# Phone:
# Kinnaur | 40/42
# Hotel KINNAUR
# Phone:
# Kinnaur | 41/42
# Jorkanden
# Phone:
# Kinnaur | 42/42
# HOTEL ROCK VIEW
# Phone: 09816545005
#
# Searching: software companies in Kullu Himachal Pradesh
# Search Submitted
# Kullu | software companies | Scroll 1 -> 14
# Kullu | software companies | Scroll 2 -> 20
# Kullu | software companies | Scroll 3 -> 27
# Kullu | software companies | Scroll 4 -> 34
# Kullu | software companies | Scroll 5 -> 40
# Kullu | software companies | Scroll 6 -> 41
# Kullu | software companies | Scroll 7 -> 41
# Kullu | software companies | Scroll 8 -> 41
# Kullu | software companies | Scroll 9 -> 41
# Kullu | software companies | Scroll 10 -> 41
# Collected 40 links
# Kullu | 1/40
# Uncle Tech
# Phone: 08988338989
# Kullu | 2/40
# Techmarbles Web Solution Pvt. Ltd. Kullu
# Phone:
# Kullu | 3/40
# City computers
# Phone: 07018228805
# Kullu | 4/40
# Kullu I.T.Hub
# Phone: 09418033681
# Kullu | 5/40
# Alps Computer Institute-Govt.Auth.Center-Best Computer Training & Fashion Designing Institute Valid for all GOVT. JOBS
# Phone: 08181832000
# Kullu | 6/40
# COMPUTER WORLD KULLU
# Phone: 09459518777
# Kullu | 7/40
# Sanskriti Tech
# Phone: 09418550126
# Kullu | 8/40
# Ekubera Technologies Pvt. Ltd.
# Phone: 09418543744
# Kullu | 9/40
# Rupi World Technologies
# Phone:
# Kullu | 10/40
# Raj Intra Tech
# Phone: 01902292477
# Kullu | 11/40
# DSM infotech
# Phone: 09418005133
# Backup Saved
# Kullu | 12/40
# NAGENDRA INFOSOFT PRIVATE LIMITED
# Phone: 09816473007
# Kullu | 13/40
# ProWebPort
# Phone: 09625963800
# Kullu | 14/40
# Kullu Computer House
# Phone: 09816407373
# Kullu | 15/40
# KM Digital Solution Co.
# Phone:
# Kullu | 16/40
# Kullu Design Hub
# Phone: 07018254526
# Kullu | 17/40
# HP World - Kullu
# Phone: 08657903778
# Kullu | 18/40
# RK COMPUTER SOLUTIONS
# Phone: 09418490537
# Kullu | 19/40
# DEV STUDIO CAMERA STORE
# Phone: 09736200400
# Kullu | 20/40
# M/S DrabDigital - Designers | Developers | Digital Marketers
# Phone: 08219271827
# Kullu | 21/40
# ITES Education Centre- Govt. Approved Center-Computer Training Institute, Tally Institute Valid for GOVT. Jobs
# Phone: 09418790766
# Kullu | 22/40
# Prashar Web Technology
# Phone: 09459910899
# Kullu | 23/40
# Web developer @Yourgeekhelp/ @upwork(Freelance)
# Phone:
# Kullu | 24/40
# Shella Webtech
# Phone: 07347474545
# Kullu | 25/40
# Hilly Basket Local Produce
# Phone: 09418555519
# Kullu | 26/40
# HIM RECHARGE
# Phone:
# Kullu | 27/40
# Dell Exclusive Store - The Computer Store
# Phone: 09418025952
# Kullu | 28/40
# Kullu Manali Computers
# Phone:
# Kullu | 29/40
# Prasoon Agro Solutions
# Phone: 09613079000
# Kullu | 30/40
# Baethar Co-working space
# Phone: 09717990270
# Kullu | 31/40
# Swiss Times.Apple iPhone Authorized Store
# Phone: 09418820000
# Kullu | 32/40
# Spiritual tech services
# Phone:
# Kullu | 33/40
# Krishna Computer Hub, CCTV Camera Dealer/Installation in Kullu , Inverter Battery , Solar Battery , Computer Accessories ,
# Phone: 08894574196
# Kullu | 34/40
# The Page Studios
# Phone: 07832007088
# Kullu | 35/40
# Nitya Tour & Adventure
# Phone: 07018023879
# Kullu | 36/40
# Triptrego | #1 Travel Company in Himachal
# Phone: 07018938400
# Kullu | 37/40
# Anand Electronics
# Phone: 07018700554
# Kullu | 38/40
# PC Point
# Phone: 09459300545
# Kullu | 39/40
# Narayana IT Solutions
# Phone: 08219685090
# Kullu | 40/40
# ConnectSingularity
# Phone:
#
# Searching: IT companies in Kullu Himachal Pradesh
# Search Submitted
# Kullu | IT companies | Scroll 1 -> 14
# Kullu | IT companies | Scroll 2 -> 17
# Kullu | IT companies | Scroll 3 -> 17
# Kullu | IT companies | Scroll 4 -> 17
# Kullu | IT companies | Scroll 5 -> 17
# Kullu | IT companies | Scroll 6 -> 17
# Collected 5 links
# Kullu | 1/5
# INFOSOFT SOLUTIONS
# Phone: 09418024252
# Kullu | 2/5
# Digital Smart Research
# Phone: 08091003483
# Kullu | 3/5
# V & V Creations - One Plus Service Centre / Realme Service Centre
# Phone: 09780017986
# Kullu | 4/5
# Over Head Tank (Complaint Office I&PH)
# Phone: 01902225510
# Kullu | 5/5
# Reliance Jio Center,Dhalpur,Kullu
# Phone:
#
# Searching: software companies in Lahaul and Spiti Himachal Pradesh
# Search Submitted
# Lahaul and Spiti | software companies | Scroll 1 -> 14
# Lahaul and Spiti | software companies | Scroll 2 -> 20
# Lahaul and Spiti | software companies | Scroll 3 -> 23
# Lahaul and Spiti | software companies | Scroll 4 -> 23
# Lahaul and Spiti | software companies | Scroll 5 -> 23
# Lahaul and Spiti | software companies | Scroll 6 -> 23
# Lahaul and Spiti | software companies | Scroll 7 -> 23
# Collected 3 links
# Lahaul and Spiti | 1/3
# Summerhill Technologies Pvt Ltd
# Phone: 08708398227
# Lahaul and Spiti | 2/3
# Ninexus Solutions
# Phone: 09736012339
# Lahaul and Spiti | 3/3
# Coderootz
# Phone:
#
# Searching: IT companies in Lahaul and Spiti Himachal Pradesh
# Search Submitted
# Lahaul and Spiti | IT companies | Scroll 1 -> 14
# Lahaul and Spiti | IT companies | Scroll 2 -> 20
# Lahaul and Spiti | IT companies | Scroll 3 -> 22
# Lahaul and Spiti | IT companies | Scroll 4 -> 22
# Lahaul and Spiti | IT companies | Scroll 5 -> 22
# Lahaul and Spiti | IT companies | Scroll 6 -> 22
# Lahaul and Spiti | IT companies | Scroll 7 -> 22
# Collected 14 links
# Lahaul and Spiti | 1/14
# LEO Software Private Limited
# Phone: 09418077480
# Lahaul and Spiti | 2/14
# JTN Teknet Private Limited
# Phone: 07018545154
# Lahaul and Spiti | 3/14
# Technologies World
# Phone: 09625476777
# Lahaul and Spiti | 4/14
# Vashisht Tech Solution
# Phone:
# Lahaul and Spiti | 5/14
# Web Pioneer Solutions (Computer Institute & IT Company )
# Phone: 07973872040
# Lahaul and Spiti | 6/14
# Honsol
# Phone: 09816242893
# Lahaul and Spiti | 7/14
# Eligo Creative Services Pvt. Ltd.- Website | Custom CRM | eCommerce & App Development Services
# Phone: 09317215300
# Lahaul and Spiti | 8/14
# Spiti Leh adventure tour
# Phone: 08544778313
# Lahaul and Spiti | 9/14
# Sattelite Computers and Electronics ( HP World)
# Phone: 01772628591
# Lahaul and Spiti | 10/14
# GEEKTOPIA
# Phone: 07590070070
# Lahaul and Spiti | 11/14
# HIMTRON IT SOLUTION
# Phone: 09418020686
# Lahaul and Spiti | 12/14
# SDM Office
# Phone: 01906222302
# Lahaul and Spiti | 13/14
# Techneteip software ites services
# Phone: 01978240051
# Lahaul and Spiti | 14/14
# TechSayvy
# Phone:
#
# Searching: software companies in Mandi Himachal Pradesh
# Search Submitted
# Mandi | software companies | Scroll 1 -> 14
# Mandi | software companies | Scroll 2 -> 20
# Mandi | software companies | Scroll 3 -> 27
# Mandi | software companies | Scroll 4 -> 34
# Mandi | software companies | Scroll 5 -> 40
# Mandi | software companies | Scroll 6 -> 47
# Mandi | software companies | Scroll 7 -> 54
# Mandi | software companies | Scroll 8 -> 60
# Mandi | software companies | Scroll 9 -> 67
# Mandi | software companies | Scroll 10 -> 74
# Mandi | software companies | Scroll 11 -> 80
# Mandi | software companies | Scroll 12 -> 81
# Mandi | software companies | Scroll 13 -> 81
# Mandi | software companies | Scroll 14 -> 81
# Mandi | software companies | Scroll 15 -> 81
# Mandi | software companies | Scroll 16 -> 81
# Collected 76 links
# Mandi | 1/76
# Kynet Web Solutions Pvt. Ltd.
# Phone: 09459050795
# Mandi | 2/76
# AMZing Data Cloud LLP
# Phone: 08447649836
# Mandi | 3/76
# BotDigit – Web, AI & App Development Company
# Phone: 08091176400
# Mandi | 4/76
# HP World- Pathania Infotech Systems
# Phone: 08657568567
# Mandi | 5/76
# TD Technologies
# Phone: 07657947310
# Mandi | 6/76
# Cloveode Technologies
# Phone: 08628892998
# Mandi | 7/76
# 1OWL Technologies Pvt Ltd
# Phone:
# Mandi | 8/76
# Divine Computers
# Phone: 09418000609
# Mandi | 9/76
# Plaxonic Technologies
# Phone: 01204211120
# Mandi | 10/76
# Computer's Villa
# Phone: 07018306412
# Mandi | 11/76
# Namdhari Infotech
# Phone: 09218646526
# Mandi | 12/76
# OPPO | OnePlus Authorized Service Center - Mandi
# Phone: 01905221191
# Mandi | 56/76
# Amity web solutions
# Phone: 09736603314
# Mandi | 57/76
# Jai Maa Chamunda Annapurna Tiffin & PG Service
# Phone:
# Mandi | 58/76
# Make My HIMACHAL trips(taxi Mandi)
# Phone: 09418682632
# Mandi | 59/76
# Gaman Grover films
# Phone: 08679316169
# Mandi | 60/76
# SAMSUNG DEALER STORE @ RAMA ELECTRONIC MANDI
# Phone:
# Mandi | 61/76
# COINCAB
# Phone: 09625002338
# Mandi | 62/76
# Advocate Puneet Thakur | Lawyer in Mandi
# Phone: 07018315804
# Mandi | 63/76
# Chandan Electronics
# Phone: 09882550056
# Mandi | 64/76
# AMBIKA INFOTECH
# Phone: 07018877595
# Mandi | 65/76
# Narayan Art Printers
# Phone: 01905223217
# Mandi | 66/76
# Team Chhoti Kashi
# Phone: 08988190789
# Mandi | 67/76
# hr architects
# Phone: 09817966644
# Mandi | 68/76
# Common Service Centre (LMK Kehnwal Road)
# Phone: 08076467232
# Mandi | 69/76
# Rental Apartment Mandi
# Phone: 09418664764
# Mandi | 70/76
# BEDI ROADSIDE ASSITANCE TOWING VAN SERVICES
# Phone:
# Mandi | 71/76
# Anand Books And Stationers
# Phone: 09816014009
# Mandi | 72/76
# Bluedart Office Mandi
# Phone:
# Mandi | 73/76
# Penta-4 Computer Education & Research Centre
# Phone:
# Mandi | 74/76
# Mandav Consultancy
# Phone:
# Mandi | 75/76
# Sunbird eSolutions
# Phone: 07807010759
# Mandi | 76/76
# Webdynamics India
# Phone:
#
# Searching: IT companies in Mandi Himachal Pradesh
# Search Submitted
# Mandi | IT companies | Scroll 1 -> 14
# Mandi | IT companies | Scroll 2 -> 20
# Mandi | IT companies | Scroll 3 -> 27
# Mandi | IT companies | Scroll 4 -> 34
# Mandi | IT companies | Scroll 5 -> 40
# Mandi | IT companies | Scroll 6 -> 47
# Mandi | IT companies | Scroll 7 -> 54
# Mandi | IT companies | Scroll 8 -> 60
# Mandi | IT companies | Scroll 9 -> 67
# Mandi | IT companies | Scroll 10 -> 74
# Mandi | IT companies | Scroll 11 -> 80
# Mandi | IT companies | Scroll 12 -> 87
# Mandi | IT companies | Scroll 13 -> 94
# Mandi | IT companies | Scroll 14 -> 100
# Mandi | IT companies | Scroll 15 -> 107
# Mandi | IT companies | Scroll 16 -> 114
# Mandi | IT companies | Scroll 17 -> 115
# Mandi | IT companies | Scroll 18 -> 115
# Mandi | IT companies | Scroll 19 -> 115
# Mandi | IT companies | Scroll 20 -> 115
# Mandi | IT companies | Scroll 21 -> 115
# Collected 44 links
# Mandi | 1/44
# IIT Mandi Catalyst
# Phone: 01905267926
# Mandi | 2/44
# 3D Mafia
# Phone: 09418287387
# Mandi | 3/44
# Indian Institute of Technology Mandi
# Phone: 01905267015
# Mandi | 4/44
# Sahib Complex
# Phone:
# Mandi | 5/44
# Jigyasa Institute of Technology
# Phone: 09218098000
# Mandi | 6/44
# Industrial Training Institute -Mandi
# Phone: 01970266572
# Mandi | 7/44
# Hill queen fruit wine shop
# Phone:
# Mandi | 8/44
# IIT-Mandi (North Campus)
# Phone: 01905267015
# Mandi | 9/44
# Tata AIG General Insurance Company Limited
# Phone: 18002667780
# Mandi | 10/44
# Paras Udyog
# Phone: 09317311156
# Mandi | 11/44
# Kitchen
# Phone: 09882560002
# Mandi | 12/44
# DevBhoomi Library Mandi
# Phone:
# Mandi | 13/44
# ACE ACADEMY MANDI
# Phone: 09990239100
# Mandi | 14/44
# Munish Resorts
# Phone: 09418050269
# Mandi | 15/44
# Bedi Crene Serviecs
# Phone: 09625000015
# Mandi | 16/44
# Him White Cabs
# Phone: 09418156918
# Mandi | 17/44
# American institute-IELTS Coaching Institute in Mandi
# Phone: 09816067177
# Mandi | 18/44
# Batra
# Phone: 09418629200
# Mandi | 19/44
# SP Office mandi
# Phone:
# Mandi | 20/44
# Northern Films
# Phone: 09459594595
# Mandi | 21/44
# HRTC Bus Ticket Booking Office
# Phone:
# Mandi | 22/44
# BSNL Colony
# Phone:
# Mandi | 23/44
# Annpurna bakery
# Phone:
# Mandi | 24/44
# Advocate Gaurav Rana
# Phone: 08219656929
# Mandi | 25/44
# V.K Enterprises
# Phone: 09418053520
# Mandi | 26/44
#
# Phone: 09459766527
# Mandi | 27/44
# Namdhari City Centre
# Phone: 09816400088
# Mandi | 28/44
# Indus Global School, Mandi
# Phone: 01905223577
# Mandi | 29/44
# Shiv Shakti Stationers
# Phone: 09816000053
# Mandi | 30/44
# Abhishek Automobile
# Phone: 07018354623
# Mandi | 31/44
# PUBLIC LIBRARY
# Phone: 07018271103
# Mandi | 32/44
# Hotel Sangam
# Phone: 01905222009
# Mandi | 33/44
# Krishna Wool
# Phone: 09958803654
# Mandi | 34/44
# City Library 24 Seven, Mandi
# Phone:
# Mandi | 35/44
# Ram Traders Mandi
# Phone:
# Mandi | 36/44
# Saini Frozen Foods
# Phone: 09418000821
# Mandi | 37/44
# HIMACHALONEWAYTAXI
# Phone: 09418495578
# Mandi | 38/44
# Azad dyers and dry cleaners
# Phone: 09418300004
# Mandi | 39/44
# Himachal Oneway Taxi
# Phone: 09129400059
# Mandi | 40/44
# Kashyap Tour And Travels-
# Phone: 09418000971
# Mandi | 41/44
# HDB FINANCIAL SERVICES LTD
# Phone: 04442984541
# Mandi | 42/44
# Fusion cab
# Phone: 07018400154
# Mandi | 43/44
# Siddhi Vinayak Travels
# Phone:
# Mandi | 44/44
# Amar Traders
# Phone: 09418035672
#
# Searching: software companies in Shimla Himachal Pradesh
# Search Submitted
# Shimla | software companies | Scroll 1 -> 14
# Shimla | software companies | Scroll 2 -> 20
# Shimla | software companies | Scroll 3 -> 27
# Shimla | software companies | Scroll 4 -> 34
# Shimla | software companies | Scroll 5 -> 40
# Shimla | software companies | Scroll 6 -> 47
# Shimla | software companies | Scroll 7 -> 54
# Shimla | software companies | Scroll 8 -> 60
# Shimla | software companies | Scroll 9 -> 62
# Shimla | software companies | Scroll 10 -> 62
# Shimla | software companies | Scroll 11 -> 62
# Shimla | software companies | Scroll 12 -> 62
# Shimla | software companies | Scroll 13 -> 62
# Collected 53 links
# Shimla | 1/53
# Gashwa Technologies Private Limited
# Phone: 09805034219
# Shimla | 2/53
# Netgen IT Solutions Private limited
# Phone: 09736433738
# Shimla | 3/53
# SaturnovaTechnologies
# Phone: 07018614969
# Shimla | 4/53
# Ishan Domains Private Limited
# Phone: 09418191081
# Shimla | 5/53
# High Alt Info Solutions Pvt Ltd
# Phone: 07018389234
# Shimla | 6/53
# Sharma InfoSys
# Phone: 09816617143
# Shimla | 7/53
# Saraswati Dot Com Private Limited
# Phone: 01772628912
# Shimla | 8/53
# CHANDER THAKUR
# Phone: 08262003300
# Shimla | 9/53
# Web Tech Masters - Shimla
# Phone: 09736351324
# Shimla | 10/53
# Zasya Solutions
# Phone: 08988406911
# Shimla | 11/53
# Ugra
# Phone: 09625794932
# Shimla | 12/53
# InGen Software & Networking
# Phone: 01772844842
# Shimla | 13/53
# Myntra IT Solutions
# Phone: 09817352440
# Shimla | 14/53
# SDPI Tally Shimla Nielit O level (Sai Digitech Professional Institute)
# Phone: 09418060666
# Shimla | 15/53
# Nerdsbyte Solutions
# Phone: 07310677174
# Shimla | 16/53
# Websterrs
# Phone: 08091009009
# Shimla | 17/53
# IICE COMPUTER EDUCATION - Digital Marketing/Web Designing/Graphic Designing/Full Stack Developer/DCA/ADCA/Tally/Course Shimla
# Phone: 09816211278
# Shimla | 18/53
# LeadPeak Travel CRM
# Phone: 09015486032
# Shimla | 19/53
# Svaksha
# Phone: 09817803513
# Shimla | 20/53
# Pansofic Solutions | Best Digital Marketing, Web Development & Web Designing Services Company In Shimla
# Phone:
# Shimla | 21/53
# Excel Marketing Corporation Shimla, Himachal Pradesh
# Phone: 08091113330
# Shimla | 22/53
# Website/Software & SEO Solutions - Himachal Wale
# Phone:
# Shimla | 23/53
# Tcipher Technologies
# Phone:
# Shimla | 24/53
# Best Travel CRM in Shimla
# Phone: 07018001298
# Shimla | 25/53
# India Digital Marketing Expert Shimla
# Phone: 07018431826
# Shimla | 26/53
# DeployDash
# Phone:
# Shimla | 27/53
# Digital Shimla
# Phone: 07307778884
# Shimla | 28/53
# Lebnoy
# Phone:
# Shimla | 29/53
# CADD CAREER CENTER ( Shimla ,HP)
# Phone: 09805777901
# Backup Saved
# Shimla | 30/53
# Sumisoft
# Phone:
# Shimla | 31/53
# MANAV SAMPADA
# Phone: 01772624045
# Shimla | 32/53
# Shimla Brewing Company
# Phone: 08447825855
# Shimla | 33/53
# Impact Hives IT Solutions
# Phone: 06230220226
# Shimla | 34/53
# Chandel It care & solutions
# Phone: 09736003067
# Shimla | 35/53
# Sanjeev K & Company- Samsung smart plaza
# Phone: 09816050707
# Shimla | 36/53
# Verma Digital
# Phone:
# Shimla | 37/53
# SearchEngineAce
# Phone: 08580541322
# Shimla | 38/53
# Track Itinerary - Travel Agency CRM Solution | Travel CRM | Best Travel CRM For Travel Agency & Tour Operator
# Phone: 09317215305
# Shimla | 39/53
# High Altitude Education Solutions Private Limited
# Phone:
# Shimla | 40/53
# LG Best Shop-CONNEXIONS ARCADE
# Phone: 09816045550
# Shimla | 41/53
# Van Chum Computers Creators
# Phone: 09418218759
# Shimla | 42/53
# Kamaksha Power Projects & Construction Pvt. Ltd.
# Phone:
# Shimla | 43/53
# Milleynium Soft
# Phone: 09459820876
# Shimla | 44/53
# The Himalayan Calling
# Phone: 08261831595
# Shimla | 45/53
# Prime Computer Associates Pvt Ltd.
# Phone:
# Shimla | 46/53
# Himachal Packers and Movers
# Phone: 09463184077
# Shimla | 47/53
# Saraswati Accountants Software Pvt Ltd
# Phone:
# Shimla | 48/53
# High Altitude Education Solutions
# Phone: 07018389234
# Shimla | 49/53
# ABH Infosystems
# Phone: 01772807419
# Shimla | 50/53
# Seven Eight Technologies
# Phone: 08988787878
# Shimla | 51/53
# Kamakhya, New Shimla
# Phone:
# Shimla | 52/53
# MountainKid
# Phone: 07832980824
# Shimla | 53/53
# ShinePoints Recruitment Hub – Field Sales Roles
# Phone:
#
# Searching: IT companies in Shimla Himachal Pradesh
# Search Submitted
# Shimla | IT companies | Scroll 1 -> 14
# Shimla | IT companies | Scroll 2 -> 18
# Shimla | IT companies | Scroll 3 -> 18
# Shimla | IT companies | Scroll 4 -> 18
# Shimla | IT companies | Scroll 5 -> 18
# Shimla | IT companies | Scroll 6 -> 18
# Collected 2 links
# Shimla | 1/2
# Reliance Corporate IT Park Ltd
# Phone: 01776612100
# Shimla | 2/2
# Mavtecq
# Phone: 07018085161
#
# Searching: software companies in Sirmaur Himachal Pradesh
# Search Submitted
# Sirmaur | software companies | Scroll 1 -> 3
# Sirmaur | software companies | Scroll 2 -> 3
# Sirmaur | software companies | Scroll 3 -> 3
# Sirmaur | software companies | Scroll 4 -> 3
# Sirmaur | software companies | Scroll 5 -> 3
# Collected 2 links
# Sirmaur | 1/2
# JumpStart Inc. Nahan
# Phone: 08860079011
# Sirmaur | 2/2
# Operce Technologies Pvt Ltd
# Phone: 01702222224
#
# Searching: IT companies in Sirmaur Himachal Pradesh
# ...
# Sirmaur | IT companies | Scroll 20 -> 120
# Sirmaur | IT companies | Scroll 21 -> 120
# Collected 116 links
# Sirmaur | 1/116
# Hipernova Technologies | Website & App Development Services | Digital Marketing Company in Himachal
# Phone: 09882476440
# Sirmaur | 2/116
# Integrated Laboratories Pvt. Ltd.
# Phone: 09996957169
# Sirmaur | 3/116
# Systole Remedies Private Limited
# Phone: 07009076709
# Sirmaur | 4/116
# ALPS COMMUNICATION PVT LTD
# Phone: 09254124143
# Sirmaur | 5/116
# Alencure Biotech Pvt. Ltd.
# Phone: 07876892834
# Sirmaur | 6/116
# M.B.C INDUSTRIES
# Phone:
# Sirmaur | 7/116
# Sai Corporation
# Phone:
# Sirmaur | 8/116
# Saitech Medicare Pvt Ltd
# Phone: 08219682830
# Sirmaur | 9/116
# SIRMOUR HERBOLIFE PVT LTD
# Phone: 09882282236
# Sirmaur | 10/116
# Symbiosis Pharmaceuticals Pvt. Ltd
# Phone: 09812810325
# Sirmaur | 11/116
# Watran Pharmaceuticals Pvt LTD
# Phone: 09817706997
# Sirmaur | 12/116
# NIBVIR PHARMA
# Atomiqx Technologies
# Phone: 05165709812
# Solan | 8/40
# Vihaas Design Technologies
# Phone: 07876429243
# Solan | 9/40
# GIGO Bytes-The biggest Computers and Mobile Store
# Phone: 09816022999
# Solan | 10/40
# Qdagrw
# Phone: 07696636036
# Solan | 11/40
# I T Solutions
# Phone:
# Solan | 12/40
# BG IT Solutions
# Phone: 06239992423
# Solan | 13/40
# Kashish Technologies
# Phone: 09418176248
# Solan | 14/40
# UT Mart - Kashish Complex
# Phone: 1800180018
# Solan | 15/40
# Secure-Net Technologies (Solan)
# Phone: 01792221769
# Solan | 16/40
# JM LABORATORIES
# Phone: 07087983437
# Solan | 17/40
# Simran IT Services
# Phone: 09418722224
# Solan | 18/40
# TANZIN TECH SOLUTIONS
# Phone: 09816441839
# Solan | 19/40
# DMT CREATOLOGY
# Phone:
# Solan | 20/40
# ArcsCare Bio-Pharmaceuticals Inc.
# Phone:
# Solan | 21/40
# H.G.O. STOCK SERVICES COMPANY
# Phone: 08350860002
# Solan | 22/40
# New Age Logic Systems
# Phone:
# Solan | 23/40
# Meridian Medicare Limited
# Phone: 01792229839
# Solan | 24/40
# Blessings Healthcare Private Limited
# Phone:
# Solan | 25/40
# Soft Touch Pharmaceuticals India Limited
# Phone: 09218513546
# Solan | 26/40
# Unicorn, Apple Authorised Reseller
# Phone: 08427775583
# Solan | 27/40
# Chiros Pharma
# Phone:
# Solan | 28/40
# Mount Woods Studio Pvt. Ltd
# Phone: 09545002419
# Solan | 29/40
# Lenovo Exclusive Store - Gigo Byte
# Phone: 08048158519
# Solan | 30/40
# Tech Software
# Phone:
# Solan | 31/40
# Dell Exclusive Store - Solan
# Phone: 08048006597
# Solan | 32/40
# Jivinc Technologies Pvt Ltd
# Phone: 08626940988
# Solan | 33/40
# PhibuzZ | Digital Marketing Company
# Phone: 09056928644
# Solan | 34/40
# Kaps Techcom Solutions
# Phone: 07807577770
# Solan | 35/40
# LG Best Shop - Maini Electronics
# Phone: 09900560640
# Solan | 36/40
# Travel Pandit
# Phone:
# Solan | 37/40
# Storelize Private Limited
# Phone: 07807859078
# Solan | 38/40
# Under ground owl kitchen
# Phone:
# Solan | 39/40
# OrreryHIM
# Phone: 09459000093
# Solan | 40/40
# SAP Computers
# Phone: 09418003625
#
# Searching: IT companies in Solan Himachal Pradesh
# Search Submitted
# Solan | IT companies | Scroll 1 -> 14
# Solan | IT companies | Scroll 2 -> 20
# Solan | IT companies | Scroll 3 -> 27
# Solan | IT companies | Scroll 4 -> 34
# Solan | IT companies | Scroll 5 -> 40
# Solan | IT companies | Scroll 6 -> 47
# Solan | IT companies | Scroll 7 -> 54
# Solan | IT companies | Scroll 8 -> 60
# Solan | IT companies | Scroll 9 -> 67
# Solan | IT companies | Scroll 10 -> 74
# Solan | IT companies | Scroll 11 -> 79
# Solan | IT companies | Scroll 12 -> 79
# Solan | IT companies | Scroll 13 -> 79
# Solan | IT companies | Scroll 14 -> 79
# Solan | IT companies | Scroll 15 -> 79
# Collected 59 links
# Solan | 1/59
# Reliance Digital
# Phone: 08071889999
# New Era Concepts
# Phone: 09817113053
# Solan | 45/59
# SAI PG/HOSTEL FOR FEMALE SOLAN
# Phone: 09816009500
# Solan | 46/59
# Time n Tune
# Phone: 01792223606
# Solan | 47/59
# Enigma Atelier
# Phone: 09816187633
# Solan | 48/59
# Gupta Prateek & Associates (Chartered Accountants)
# Phone: 09882512344
# Solan | 49/59
# The Jawahar Park - Solan District, Himachal Pradesh, India
# Phone: 07807660000
# Solan | 50/59
# BlueStone Jewellery Mall Road, Solan
# Phone: 08655424760
# Solan | 51/59
# Titan Eye+ at RG Road, Solan (Buy 1 Get 1 Free)
# Phone: 09317426518
# Solan | 52/59
# Premjee's
# Phone: 01792222434
# Solan | 53/59
# DAANG AVENUE
# Phone: 01792222206
# Solan | 54/59
# Renault Solan
# Phone: 08448389688
# Solan | 55/59
# HP State Electricity Board
# Phone: 18001808060
# Solan | 56/59
# M/s Sood Abhay & Associates
# Phone: 09816533015
# Solan | 57/59
# Shoolini Events
# Phone: 09882112966
# Solan | 58/59
# Jai Art Service
# Phone: 09817575175
# Solan | 59/59
# Happy House
# Phone: 09805151160
#
# Searching: software companies in Una Himachal Pradesh
# Search Submitted
# Una | software companies | Scroll 1 -> 14
# Una | software companies | Scroll 2 -> 20
# Una | software companies | Scroll 3 -> 25
# Una | software companies | Scroll 4 -> 25
# Una | software companies | Scroll 5 -> 25
# Una | software companies | Scroll 6 -> 25
# Una | software companies | Scroll 7 -> 25
# Collected 18 links
# Una | 1/18
# smdwebsolutions private limited
# Phone: 09817384700
# Una | 2/18
# Sybase Computer Education - Tally Institute and Services in UNA
# Phone: 09816900704
# Una | 3/18
# TheDataVue Technologies
# Phone: 07307269991
# Una | 4/18
# Infosoft Solutions
# Phone: 07650812700
# Una | 5/18
# Indo Web Technologies Private Limited
# Phone: 08894891890
# Una | 6/18
# Numerogen
# Phone: 08882621373
# Una | 7/18
# Reliance Digital
# Phone: 08071890019
# Una | 8/18
# Synergy Soft India
# Phone: 08628870622
# Una | 9/18
# Aryansh Technology
# Phone: 07889176554
# Una | 10/18
# HIND IT
# Phone: 09318504216
# Una | 11/18
# Dell Exclusive Store - Nangal Road, Una
# Phone: 08048006600
# Una | 12/18
# Kairos Coders LLP
# Phone: 08894023394
# Una | 13/18
# Sarashman Hi-Tech Solution Enterprises
# Phone: 08628986229
# Una | 14/18
# Anselsoft IT Solutions
# Phone: 09023794560
# Una | 15/18
# Dipm Relocation Service
# Phone: 09041968221
# Una | 16/18
# Samsung SmartPlaza - Kathuria Electronics
# Phone: 07039002793
# Una | 17/18
# Tej Info
# Phone: 09882125500
# Una | 18/18
# SMD Websolutions Pvt. Ltd.
# Phone:
#
# Searching: IT companies in Una Himachal Pradesh
# Search Submitted
# Una | IT companies | Scroll 1 -> 10
# Una | IT companies | Scroll 2 -> 10
# Una | IT companies | Scroll 3 -> 10
# Una | IT companies | Scroll 4 -> 10
# Una | IT companies | Scroll 5 -> 10
# Collected 0 links
#
# Extraction Completed
# Total Companies Extracted: 861
#
# Saved File: himachal_pradesh_companies.csv
