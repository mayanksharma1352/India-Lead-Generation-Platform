# %%
import time
import random
import pandas as pd

from datetime import datetime

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.service import Service

from webdriver_manager.chrome import ChromeDriverManager

districts = [
    "Chumoukedima",
    "Dimapur",
    "Kiphire",
    "Kohima",
    "Longleng",
    "Mokokchung",
    "Mon",
    "Niuland",
    "Noklak",
    "Peren",
    "Phek",
    "Shamator",
    "Tseminyu",
    "Tuensang",
    "Wokha",
    "Zunheboto"
]



search_types = [
    "software companies",
    "IT companies"
]



options = webdriver.ChromeOptions()

options.add_argument("--start-maximized")

options.add_argument(
    "--disable-blink-features=AutomationControlled"
)

options.add_argument("--disable-notifications")



driver = webdriver.Chrome(

    service=Service(
        ChromeDriverManager().install()
    ),

    options=options
)



driver.get("https://www.google.com/maps")

print("Opening Google Maps...")

time.sleep(15)

print("Google Maps Loaded")



all_data = []

visited_links = set()


def get_search_box():

    selectors = [

        '//input[@id="searchboxinput"]',
        '//input[contains(@placeholder,"Search")]',
        '//input[contains(@aria-label,"Search")]',
        '//input'

    ]

    for selector in selectors:

        try:

            box = driver.find_element(
                By.XPATH,
                selector
            )

            return box

        except:
            pass

    return None



def extract_school_data():

    try:

        try:

            name = driver.find_element(
                By.TAG_NAME,
                "h1"
            ).text

        except:

            name = ""


        try:

            address = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"address")]'
            ).text

        except:

            address = ""

        phone = ""

        try:

            phone_xpaths = [

                '//button[contains(@data-item-id,"phone")]',

                '//a[contains(@href,"tel:")]',

                '//button[contains(@aria-label,"Phone")]',

                '//button[contains(text(),"+91")]',
                '//div[contains(text(),"+91")]',
                '//span[contains(text(),"+91")]'

            ]

            for xpath in phone_xpaths:

                try:

                    elements = driver.find_elements(
                        By.XPATH,
                        xpath
                    )

                    for element in elements:

                        text = element.text.strip()

                        href = (
                            element.get_attribute("href")
                            or ""
                        )


                        if "tel:" in href:

                            phone = href.replace(
                                "tel:",
                                ""
                            ).strip()

                        elif text:

                            phone = text

                        phone = (

                            phone.replace("", "")
                            .replace(" ", "")
                            .replace("-", "")
                            .replace("(", "")
                            .replace(")", "")
                            .replace("\n", "")
                            .strip()

                        )

                        digits = ''.join(
                            filter(str.isdigit, phone)
                        )

                        if len(digits) >= 10:

                            break

                    if phone:
                        break

                except:
                    pass

        except Exception as e:

            print(f"Phone Error: {e}")

        # WEBSITE

        try:

            website = driver.find_element(
                By.XPATH,
                '//a[contains(@data-item-id,"authority")]'
            ).get_attribute("href")

        except:

            website = ""


        try:

            rating = driver.find_element(
                By.XPATH,
                '//div[@role="img"]'
            ).get_attribute("aria-label")

        except:

            rating = ""

        return {

            "Company Name": name,
            "Address": address,
            "Phone": phone,
            "Website": website,
            "Rating": rating,
            "Google Maps URL": driver.current_url

        }

    except:

        return None



for district in districts:

    for search_type in search_types:

        try:

            query = (
                f"{search_type} "
                f"in {district} Nagaland"
            )

            print(f"\nSearching: {query}")


            search_box = get_search_box()

            if not search_box:

                print("Search Box Not Found")

                continue

            ActionChains(driver).move_to_element(
                search_box
            ).click().perform()

            time.sleep(1)

            search_box.send_keys(
                Keys.CONTROL + "a"
            )

            time.sleep(1)

            search_box.send_keys(Keys.DELETE)

            time.sleep(1)



            for char in query:

                search_box.send_keys(char)

                time.sleep(0.03)

            search_box.send_keys(Keys.ENTER)

            print("Search Submitted")

            time.sleep(8)



            try:

                scrollable_div = driver.find_element(
                    By.XPATH,
                    '//div[@role="feed"]'
                )

                previous_count = 0

                stagnant = 0

                for i in range(100):

                    driver.execute_script(
                        """
                        arguments[0].scrollTop =
                        arguments[0].scrollHeight
                        """,
                        scrollable_div
                    )

                    time.sleep(4)

                    listings = driver.find_elements(
                        By.XPATH,
                        '//a[contains(@href,"/maps/place/")]'
                    )

                    current_count = len(listings)

                    print(
                        f"{district} | "
                        f"{search_type} | "
                        f"Scroll {i+1} -> "
                        f"{current_count}"
                    )

                    if current_count == previous_count:

                        stagnant += 1

                    else:

                        stagnant = 0

                    if stagnant >= 4:

                        break

                    previous_count = current_count

            except Exception as e:

                print(f"Scrolling Error: {e}")

     
            listings = driver.find_elements(
                By.XPATH,
                '//a[contains(@href,"/maps/place/")]'
            )

            links = []

            for listing in listings:

                try:

                    link = listing.get_attribute("href")

                    if (
                        link
                        and link not in visited_links
                    ):

                        links.append(link)

                        visited_links.add(link)

                except:
                    pass

            print(f"Collected {len(links)} links")



            for index, link in enumerate(links):

                try:

                    print(
                        f"{district} | "
                        f"{index+1}/{len(links)}"
                    )

                    driver.get(link)

                    time.sleep(
                        random.uniform(2, 3)
                    )

                    data = extract_school_data()

                    if data:

                        data["District"] = district

                        data["Search Type"] = search_type

                        all_data.append(data)

                        print(data["Company Name"])

                        print(
                            f"Phone: {data['Phone']}"
                        )

            

                    if len(all_data) % 100 == 0:

                        backup_df = pd.DataFrame(
                            all_data
                        )

                        backup_df.drop_duplicates(
                            subset=[
                                "Company Name",
                                "Google Maps URL"
                            ],
                            inplace=True
                        )

                        backup_df.to_csv(
                            "nagaland_companies_backup.csv",
                            index=False
                        )

                        print("Backup Saved")

                except Exception as e:

                    print(
                        f"Company Error: {e}"
                    )

        except Exception as e:

            print(
                f"District Error: {e}"
            )



df = pd.DataFrame(all_data)

df.drop_duplicates(

    subset=[
        "Company Name",
        "Google Maps URL"
    ],

    inplace=True
)

filename = "nagaland_companies.csv"

df.to_csv(
    filename,
    index=False
)

print("\nExtraction Completed")

print(
    f"Total Companies Extracted: {len(df)}"
)

print(f"\nSaved File: {filename}")

driver.quit()
# Out:
# Opening Google Maps...
# Google Maps Loaded
#
# Searching: software companies in Chumoukedima Nagaland
# Search Submitted
# Chumoukedima | software companies | Scroll 1 -> 16
# Chumoukedima | software companies | Scroll 2 -> 20
# Chumoukedima | software companies | Scroll 3 -> 20
# Chumoukedima | software companies | Scroll 4 -> 20
# Chumoukedima | software companies | Scroll 5 -> 20
# Chumoukedima | software companies | Scroll 6 -> 20
# Collected 20 links
# Chumoukedima | 1/20
# Excellogics Tech Solutions Pvt Ltd
# Phone: 08730029961
# Chumoukedima | 2/20
# Techno Park Computer Institute
# Phone: 08132031900
# Chumoukedima | 3/20
# fingerprint Nagaland
# Phone: 09233645987
# Chumoukedima | 4/20
# Akum Online Tech Solution For Both Android & IOS
# Phone:
# Chumoukedima | 5/20
# Tech zone
# Phone:
# Chumoukedima | 6/20
# IITE Computer Institute
# Phone: 08730040725
# Chumoukedima | 7/20
# Core Tech Computer Training Institute
# Phone: 07085834508
# Chumoukedima | 8/20
# Case Construction Equipment - Hi-tech Constructions
# Phone: 08082009219
# Chumoukedima | 9/20
# instudia - Computer Education and Training Center
# Phone: 08798587779
# Chumoukedima | 10/20
# Excel Printing Press (EPP)
# Phone: 08259014781
# Chumoukedima | 11/20
# Bright Printer
# Phone:
# Chumoukedima | 12/20
# Cine Rec Production
# Phone: 08730026615
# Chumoukedima | 13/20
# nagacolors
# Phone: 09089719228
# Chumoukedima | 14/20
# BSNL Office Chumukedima
# Phone: 18003451500
# Chumoukedima | 15/20
# Jome Foods Private Limited
# Phone: 06909675858
# Chumoukedima | 16/20
# National Institute of Technology Nagaland
# Phone: 03862241802
# Chumoukedima | 17/20
# Kapai Architects
# Phone:
# Chumoukedima | 18/20
# Xpressbees courier service (Chumukedima )
# Phone:
# Chumoukedima | 19/20
# Ataur Rahaman
# Phone: 06002257242
# Chumoukedima | 20/20
# Naga all in one
# Phone: 07629094092
#
# Searching: IT companies in Chumoukedima Nagaland
# Search Submitted
# Chumoukedima | IT companies | Scroll 1 -> 16
# Chumoukedima | IT companies | Scroll 2 -> 20
# Chumoukedima | IT companies | Scroll 3 -> 28
# Chumoukedima | IT companies | Scroll 4 -> 36
# Chumoukedima | IT companies | Scroll 5 -> 40
# Chumoukedima | IT companies | Scroll 6 -> 48
# Chumoukedima | IT companies | Scroll 7 -> 56
# Chumoukedima | IT companies | Scroll 8 -> 60
# Chumoukedima | IT companies | Scroll 9 -> 68
# Chumoukedima | IT companies | Scroll 10 -> 76
# Chumoukedima | IT companies | Scroll 11 -> 80
# Chumoukedima | IT companies | Scroll 12 -> 88
# Chumoukedima | IT companies | Scroll 13 -> 96
# Chumoukedima | IT companies | Scroll 14 -> 100
# Chumoukedima | IT companies | Scroll 15 -> 108
# Chumoukedima | IT companies | Scroll 16 -> 116
# Chumoukedima | IT companies | Scroll 17 -> 118
# Chumoukedima | IT companies | Scroll 18 -> 118
# Chumoukedima | IT companies | Scroll 19 -> 118
# Chumoukedima | IT companies | Scroll 20 -> 118
# Chumoukedima | IT companies | Scroll 21 -> 118
# Collected 103 links
# Chumoukedima | 1/103
# CSC CHÜMOUKEDIMA (R T COMMUNICATION & SERVICES)
# Phone: 07085752023
# Chumoukedima | 2/103
# Site 1 ABCI
# Phone:
# Chumoukedima | 3/103
# Aadhaar Card Office Chümoukedima
# Phone:
# Chumoukedima | 4/103
# Mark Makers Consultancy Services Pvt Ltd
# Phone: 09871338333
# Chumoukedima | 5/103
# MINI PRINT (W SHAMLAO CSC)
# Phone: 08119819434
# Chumoukedima | 6/103
# Havells Fan SmartHub - Naga Electricals & Housing
# Phone: 08071265527
# Chumoukedima | 7/103
# Electrical office chumukedima
# Phone:
# Chumoukedima | 8/103
# Esalim Village
# Phone:
# Chumoukedima | 9/103
# ITECH COMPUTER INSTITUTE CHUMUKEDIMA
# Phone: 09862868190
# Chumoukedima | 10/103
# HomeLane Chumukedima, Interior Design Studio
# Phone: 07941057305
# Chumoukedima | 11/103
# Imna
# Phone:
# Chumoukedima | 12/103
# Odyuo,s Farm
# Phone:
# Chumoukedima | 13/103
# Imlisunep Jamir Building
# Phone:
# Chumoukedima | 14/103
# Vicky bricks
# Phone:
# Chumoukedima | 15/103
# Print Point
# Phone: 08730826489
# Chumoukedima | 16/103
# IC COMPUTER
# Phone: 08837447645
# Chumoukedima | 17/103
# Kernel Computer Education
# Phone: 08974448521
# Chumoukedima | 18/103
# Jack & Jill
# Phone:
# Chumoukedima | 19/103
# JK COMPUTER POINT
# Phone: 07005361362
# Chumoukedima | 20/103
# T.Lkr. Printers
# Phone:
# Chumoukedima | 21/103
# Arshad Stone crusher
# Phone: 07481810089
# Chumoukedima | 22/103
# C Chingbah Phom
# Phone:
# Chumoukedima | 23/103
# Tamara Enterprise
# Phone: 07005750211
# Chumoukedima | 24/103
# ELMECHENT
# Phone:
# Chumoukedima | 25/103
# Bamboo resort
# Phone:
# Chumoukedima | 26/103
# Zen Apartment
# Phone:
# Chumoukedima | 27/103
# Eastman Dealer
# Phone: 08068932365
# Chumoukedima | 28/103
# Indane - Chumukedima Gas Agency
# Phone: 08787427511
# Chumoukedima | 29/103
# Feels Home PG
# Phone:
# Chumoukedima | 30/103
# DOUBLETON TOOLS & ELECTRICALS
# Phone:
# Chumoukedima | 31/103
# YouthNet Dimapur Office
# Phone: 09362193492
# Chumoukedima | 32/103
# Akuolie Nguzhulie
# Phone:
# Chumoukedima | 33/103
# Neisa Home Poultry Farm
# Phone: 08575089853
# Chumoukedima | 34/103
# Eureka Forbes Ltd
# Phone: 02262277493
# Chumoukedima | 35/103
# Kem's Cyber
# Phone:
# Chumoukedima | 36/103
# Computer N Communication Center
# Phone: 03862359010
# Chumoukedima | 37/103
# Eden Home PG/ Boys/Girls
# Phone: 07005955835
# Chumoukedima | 38/103
# TechnoSoft Service
# Phone: 07005727089
# Chumoukedima | 39/103
# R ENTERPRISE H2O Water Solution
# Phone: 07085973738
# Chumoukedima | 40/103
# Lkr Signage
# Phone: 08414074846
# Chumoukedima | 41/103
# Laxmi Trading Company
# Phone: 09436003290
# Chumoukedima | 42/103
# Renu Enterprise
# Phone: 07085103563
# Chumoukedima | 43/103
# Vibu y
# Phone:
# Chumoukedima | 44/103
# White House
# Phone:
# Chumoukedima | 45/103
# Repench Gorlosa
# Phone:
# Chumoukedima | 46/103
# Andrew Website Development
# Phone:
# Chumoukedima | 47/103
# Chumo
# Phone:
# Chumoukedima | 48/103
# LIC of India, Mini Office
# Phone:
# Chumoukedima | 49/103
# ICTV SOLUTIONS
# Phone:
# Chumoukedima | 50/103
# ENIR INFOTECH
# Phone: 09436032686
# Chumoukedima | 51/103
# Indikraft Services
# Phone:
# Chumoukedima | 52/103
# Razhaphe
# Phone:
# Chumoukedima | 53/103
# BSNL Store
# Phone: 09402922363
# Chumoukedima | 54/103
# Kelechutuo house
# Phone:
# Chumoukedima | 55/103
# BONHOMIE HOSTEL/P.G.
# Phone: 07005365217
# Chumoukedima | 56/103
# Naga Kitchen Essentials
# Phone:
# Chumoukedima | 57/103
# Seithekebasa
# Phone:
# Chumoukedima | 58/103
# Peace mission compound
# Phone:
# Chumoukedima | 59/103
# Theophilus Singson/ house no. 227
# Phone:
# Chumoukedima | 60/103
# Seithekebasa
# Phone:
# Chumoukedima | 61/103
# Sri Sai Electricals
# Phone: 08754963244
# Chumoukedima | 62/103
# DEBOL MARKET WARD 5 LANE 5
# Phone:
# Chumoukedima | 63/103
# Chungmirs
# Phone:
# Chumoukedima | 64/103
# Sashi Apartment
# Phone:
# Chumoukedima | 65/103
# Programming hub
# Phone: 07085896175
# Chumoukedima | 66/103
# Jubilant Tent House
# Phone:
# Chumoukedima | 67/103
# Rev. Akhüm’s Residence
# Phone:
# Chumoukedima | 68/103
# Satyajit bora
# Phone:
# Chumoukedima | 69/103
# DAS ELOCTRONIC
# Phone: 07005101227
# Chumoukedima | 70/103
# Moran's Ki
# Phone:
# Chumoukedima | 71/103
# Liaki Stay
# Phone:
# Chumoukedima | 72/103
# Chumukidima to Kohima Taxi Stand
# Phone:
# Chumoukedima | 73/103
# Kuiyichu Sharu Residence
# Phone:
# Chumoukedima | 74/103
# Poiema Hostel/PG
# Phone: 08132909436
# Chumoukedima | 75/103
# Theyo Enterprise
# Phone: 07005862912
# Chumoukedima | 76/103
# Miponger’s house
# Phone:
# Chumoukedima | 77/103
# TRENDS
# Phone:
# Chumoukedima | 78/103
# AMICT Seluophe
# Phone: 09863286928
# Chumoukedima | 79/103
# Kedi Hieme's villa
# Phone:
# Chumoukedima | 80/103
# John Yimchunger
# Phone:
# Backup Saved
# Chumoukedima | 81/103
# Rilance mahila building
# Phone:
# Chumoukedima | 82/103
# Hotel Crown
# Phone:
# Chumoukedima | 83/103
# Chumoukedima town ward-4
# Phone:
# Chumoukedima | 84/103
# Tiala Ozukum
# Phone:
# Chumoukedima | 85/103
# K.Luho's Apartment
# Phone:
# Chumoukedima | 86/103
# City furniture
# Phone:
# Chumoukedima | 87/103
# Piphema Apartment
# Phone:
# Chumoukedima | 88/103
# Nath Repairing Shop
# Phone: 08761045203
# Chumoukedima | 89/103
# T. Temsu Pongen Residence
# Phone:
# Chumoukedima | 90/103
# Iloto House
# Phone:
# Chumoukedima | 91/103
# Fila Singson
# Phone:
# Chumoukedima | 92/103
# Changsang
# Phone:
# Chumoukedima | 93/103
# Homelane Dimapur ,Interior Design Studio
# Phone:
# Chumoukedima | 94/103
# T.Z Angami Steel Fabrication
# Phone:
# Chumoukedima | 95/103
# V Medoze Building, Chumoukedima, Dimapur
# Phone:
# Chumoukedima | 96/103
# Fusion Business
# Phone: 07005341282
# Chumoukedima | 97/103
# Kuda Marble & Granite
# Phone:
# Chumoukedima | 98/103
# Gratia PG
# Phone:
# Chumoukedima | 99/103
# Jordan Home Chumoukedima
# Phone:
# Chumoukedima | 100/103
# iCompute Solutions
# Phone:
# Chumoukedima | 101/103
# Seiruzha, Medoze Apartment
# South Indian Bank - Dimapur Branch
# Phone: 03862224917
# Dimapur | 40/43
# Hotel Acacia
# Phone: 03862364972
# Dimapur | 41/43
# EPSON CERTIFIED CHANNEL PARTNER - Computer Communication
# Phone: 07065035266
# Dimapur | 42/43
# The Black Sheep
# Phone:
# Dimapur | 43/43
# Avon Cycles
# Phone: 09436012098
#
# Searching: software companies in Kiphire Nagaland
# Search Submitted
# Kiphire | software companies | Scroll 1 -> 6
# Kiphire | software companies | Scroll 2 -> 6
# Kiphire | software companies | Scroll 3 -> 6
# Kiphire | software companies | Scroll 4 -> 6
# Kiphire | software companies | Scroll 5 -> 6
# Collected 5 links
# Kiphire | 1/5
# NK Square Infotech Private Limited
# Phone: 09402976259
# Kiphire | 2/5
# Kiphire Printing Press
# Phone: 09612857578
# Kiphire | 3/5
# Neospec Services private Limited
# Phone: 09863532041
# Kiphire | 4/5
# Software Technology Park Of India, Kohima
# Phone:
# Kiphire | 5/5
# Come
# Phone:
#
# Searching: IT companies in Kiphire Nagaland
# Search Submitted
# Kiphire | IT companies | Scroll 1 -> 12
# Kiphire | IT companies | Scroll 2 -> 18
# Kiphire | IT companies | Scroll 3 -> 20
# Kiphire | IT companies | Scroll 4 -> 26
# Kiphire | IT companies | Scroll 5 -> 32
# Kiphire | IT companies | Scroll 6 -> 38
# Kiphire | IT companies | Scroll 7 -> 39
# Kiphire | IT companies | Scroll 8 -> 39
# Kiphire | IT companies | Scroll 9 -> 39
# Kiphire | IT companies | Scroll 10 -> 39
# Kiphire | IT companies | Scroll 11 -> 39
# Collected 32 links
# Kiphire | 1/32
# Ramietech Computer Solutions
# Phone:
# Kiphire | 2/32
# Tsalipi Sangtam Private
# Phone:
# Kiphire | 3/32
# Kiphire
# Phone:
# Kiphire | 4/32
# Kiphire Nagaland
# Phone:
# Kiphire | 5/32
# LUMROLI Y SANGTAM
# Phone:
# Kiphire | 6/32
# Sangtsoze Village
# Phone:
# Kiphire | 7/32
# Food and Civil Supplies New Godown, Kiphire Hq.
# Phone:
# Kiphire | 8/32
# Anar Store
# Phone:
# Kiphire | 9/32
# KS-PIRPL SITE OFFICE
# Phone:
# Kiphire | 10/32
# BSNL Store
# Phone: 09402923670
# Kiphire | 11/32
# Hospital
# Phone:
# Kiphire | 12/32
# Rudy naga house
# Phone:
# Kiphire | 13/32
# S.Sepithrong Sangtam
# Phone:
# Kiphire | 14/32
# Seroba Langkizz cottage
# Phone:
# Kiphire | 15/32
# Ranjan
# Phone:
# Kiphire | 16/32
# Lums home
# Phone:
# Kiphire | 17/32
# Atsikeh Events
# Phone: 09863002106
# Kiphire | 18/32
# Mongzar
# Phone:
# Kiphire | 19/32
# Heyday Printing
# Phone: 08974104139
# Kiphire | 20/32
# Selithrong R Thonger
# Phone:
# Kiphire | 21/32
# VICHIMBA & ADISU cottage
# Phone:
# Kiphire | 22/32
# P.S THONGER'S ABODE
# Phone:
# Kiphire | 23/32
# Akum Longnliue
# Phone:
# Kiphire | 24/32
# RFO Quarter
# Phone:
# Kiphire | 25/32
# Acham residence
# Phone:
# Kiphire | 26/32
# Tetseo Pickles & Spices
# Phone:
# Backup Saved
# Kiphire | 27/32
# Santosh carriage
# Phone:
# Kiphire | 28/32
# Computer Network
# Phone:
# Kiphire | 29/32
# Henry Online service
# Phone:
# Kiphire | 30/32
# Amity hostel
# Phone:
# Kiphire | 31/32
# Tsalong House
# Phone:
# Kiphire | 32/32
# Pauls Home
# Phone:
#
# Searching: software companies in Kohima Nagaland
# Search Submitted
# Kohima | software companies | Scroll 1 -> 16
# Kohima | software companies | Scroll 2 -> 20
# Kohima | software companies | Scroll 3 -> 28
# Kohima | software companies | Scroll 4 -> 36
# Kohima | software companies | Scroll 5 -> 40
# Kohima | software companies | Scroll 6 -> 41
# Kohima | software companies | Scroll 7 -> 41
# Kohima | software companies | Scroll 8 -> 41
# Kohima | software companies | Scroll 9 -> 41
# Kohima | software companies | Scroll 10 -> 41
# Collected 37 links
# Kohima | 1/37
# Eastern Computer Agencies (Head Office)
# Phone: 09402988686
# Kohima | 2/37
# Tabernacle Technologies Private Limited
# Phone: 07005426278
# Kohima | 3/37
# ReDimension Games Pvt Ltd
# Phone: 09862495209
# Kohima | 4/37
# Datamation - Kohima
# Phone: 07637031525
# Kohima | 5/37
# KERA'S TECH SOLUTION
# Phone:
# Kohima | 6/37
# Eastern Computer Agencies (North Branch Office)
# Phone: 08794054263
# Kohima | 7/37
# TRAX COMPUTER SYSTEM
# Phone: 03702290124
# Kohima | 8/37
# M/S VIMERHA CORPORATE
# Phone:
# Kohima | 9/37
# INIzen Tech
# Phone:
# Kohima | 10/37
# Matrix Enterprise - Best Price & Service Guaranteed, Kohima
# Phone:
# Kohima | 11/37
# One Bit
# Phone: 08794041777
# Kohima | 12/37
# COMPUTER SEVA
# Phone: 07005351962
# Kohima | 13/37
# NAGABOTS
# Phone: 09366594691
# Kohima | 14/37
# Kohima Computer Center
# Phone:
# Kohima | 15/37
# SymBios Creations Private Limited (Kohima Office)
# Phone: 18001209737
# Kohima | 16/37
# MAGDALINE COACHING CENTRE
# Phone: 07005402371
# Kohima | 17/37
# DIGITAL
# Phone: 03703575202
# Kohima | 18/37
# NETTEC COMPUTERS
# Phone: 03702950325
# Kohima | 19/37
# Theja Group
# Phone:
# Kohima | 20/37
# Imprint- The Creative Workshop
# Phone:
# Kohima | 21/37
# Mike Care "A Complete Computer Solutions"
# Phone: 03702260174
# Kohima | 22/37
# Été Coffee Roasters, Headquarters
# Phone: 08794942181
# Kohima | 23/37
# Kohima digital electronics
# Phone:
# Kohima | 24/37
# NIELIT Kohima
# Phone: 09436215243
# Kohima | 25/37
# EVIOH Nagaland
# Phone: 07005857214
# Kohima | 26/37
# Vizon Collective
# Phone:
# Kohima | 27/37
# Beat Devices Pvt Ltd
# Phone: 09485276196
# Kohima | 28/37
# iMe...
# Phone: 07005305707
# Kohima | 29/37
# Blue Dart Express Limited
# Phone:
# Kohima | 30/37
# Alder Tours and Travels
# Phone: 09862246498
# Kohima | 31/37
# Été Coffee Roasters, Main Town Branch
# Phone:
# Kohima | 32/37
# TCreate Technologies Private Limited
# Phone:
# Kohima | 33/37
# Eastern Computer Agencies (South Branch Office)
# Phone: 06009775519
# Kohima | 34/37
# Go tech enterprise
# Phone: 09856711970
# Kohima | 35/37
# Lore Life
# Phone:
# Kohima | 36/37
# DeliTec Computer Service
# Phone:
# Kohima | 37/37
# LITTLE SOLUTION
# Phone:
#
# Searching: IT companies in Kohima Nagaland
# Search Submitted
# Kohima | IT companies | Scroll 1 -> 12
# Kohima | IT companies | Scroll 2 -> 18
# Kohima | IT companies | Scroll 3 -> 20
# Kohima | IT companies | Scroll 4 -> 26
# Kohima | IT companies | Scroll 5 -> 32
# Kohima | IT companies | Scroll 6 -> 38
# Kohima | IT companies | Scroll 7 -> 40
# Kohima | IT companies | Scroll 8 -> 46
# Kohima | IT companies | Scroll 9 -> 52
# Kohima | IT companies | Scroll 10 -> 58
# Kohima | IT companies | Scroll 11 -> 60
# Kohima | IT companies | Scroll 12 -> 66
# Kohima | IT companies | Scroll 13 -> 72
# Kohima | IT companies | Scroll 14 -> 78
# Kohima | IT companies | Scroll 15 -> 80
# Kohima | IT companies | Scroll 16 -> 86
# Kohima | IT companies | Scroll 17 -> 92
# Kohima | IT companies | Scroll 18 -> 92
# Kohima | IT companies | Scroll 19 -> 92
# Kohima | IT companies | Scroll 20 -> 92
# Kohima | IT companies | Scroll 21 -> 92
# Collected 61 links
# Kohima | 1/61
# Smart techies Service
# Phone: 09366340691
# Kohima | 2/61
# Impact
# Phone: 09089123003
# Kohima | 3/61
# Online Express Nagaland
# Phone:
# Kohima | 4/61
# B.S.N.L
# Phone: 18003451500
# Kohima | 5/61
# Old Ministers'Hill, Kohima
# Phone:
# Kohima | 6/61
# Zienuo Badze
# Phone:
# Kohima | 7/61
# Jio Office, Kohima
# Phone:
# Kohima | 8/61
# Titan World - New Market, Kohima
# Phone: 08062914497
# Kohima | 9/61
# S D Electrical
# Phone: 07005632875
# Kohima | 10/61
# DTDC courier
# Phone: 08414094402
# Kohima | 11/61
# Daily Bread
# Phone:
# Kohima | 12/61
# EGC (Elite Gaming Client)
# Phone:
# Kohima | 13/61
# Blackberrys
# Phone: 09619048716
# Kohima | 14/61
# Nagaland Power Solutions & Machineries
# Phone: 07005260396
# Kohima | 15/61
# Rent A Bike/Car Kohima (RAB-K/RAC-K)
# Phone: 08787889275
# Kohima | 16/61
# Federal Bank
# Phone: 18004201199
# Kohima | 17/61
# Lower PWD colony kohima
# Phone:
# Kohima | 18/61
# YouthNet Head Office
# Phone:
# Kohima | 19/61
# Central Plaza, Urban Multi Storey Complex
# Phone:
# Kohima | 20/61
# Shadowfax Kohima
# Phone:
# Kohima | 21/61
# Concept Flux LLP
# Phone: 07005426278
# Kohima | 22/61
# Nestflex (Men's P.G)
# Phone:
# Kohima | 23/61
# DTDC Courier
# Phone:
# Kohima | 24/61
# Mato Complex
# Phone:
# Kohima | 25/61
# Directorate of Information Technology & Communication, Kohima
# Phone:
# Kohima | 26/61
# MI Service Center (Flex)
# Phone: 03702290253
# Kohima | 27/61
# NEXUSCIPHERGUARD India (OPC) Private Limited
# Phone: 08256997411
# Kohima | 28/61
# Digital I.T Traders
# Phone:
# Kohima | 29/61
# Nagaland Post
# Phone: 09856275559
# Kohima | 30/61
# Phone fix
# Phone: 07005160477
# Kohima | 31/61
# Truly Naga
# Phone:
# Kohima | 32/61
# Genesis Publishers
# Phone: 09774078059
# Kohima | 33/61
# Gg
# Phone:
# Kohima | 34/61
# Pretty Planet Tours & Travels Kohima
# Phone:
# Kohima | 35/61
# Shah Electronics Shop A45
# Phone:
# Kohima | 36/61
# All India Radio (FM Tragopan)
# Phone:
# Kohima | 37/61
# STORE TECHNOLOGY
# Phone:
# Kohima | 38/61
# Delhivery Warehouse
# Phone:
# Kohima | 39/61
# Tumbledry Dry Clean & Laundry Service
# Phone: 07677250250
# Kohima | 40/61
# Overnight Express
# Phone: 03702222451
# Kohima | 41/61
# Bharat Travels
# Phone: 08119069747
# Kohima | 42/61
# LIC of India, Branch Office
# Phone: 01812480918
# Kohima | 43/61
# Alchemy Boys Hostel
# Phone:
# Kohima | 44/61
# Doordarshan Kendra Jotsoma (DDK Kohima)
# Phone:
# Kohima | 45/61
# Sakhrie Park
# Phone:
# Kohima | 46/61
# KOHIMA NCC STORE
# Phone: 07410757615
# Kohima | 47/61
# Educentre Career Counselling
# Phone: 08787391139
# Kohima | 48/61
# Mao Market
# Phone:
# Kohima | 49/61
# Le Koco Bakery
# Phone:
# Kohima | 50/61
# Crossword
# Phone:
# Kohima | 51/61
# BSNL Store
# Phone: 09402921159
# Kohima | 52/61
# India Post Office
# Phone: 03702290929
# Kohima | 53/61
# Puliebadze, Jotsoma Village
# Phone:
# Kohima | 54/61
# Pinotravels_kohima
# Phone: 09862644100
# Kohima | 55/61
# War cemetery quater
# Phone:
# Kohima | 56/61
# SA.Grocery
# Phone: 09612245762
# Kohima | 57/61
# La Colline Resort
# Phone: 07086426527
# Backup Saved
# Kohima | 58/61
# K.A.K.
# Phone: 09366469120
# Kohima | 59/61
# MULTIPLEX Print Solution
# Phone: 03703567079
# Kohima | 60/61
# New Police Reserve Kohima India
# Phone:
# Kohima | 61/61
# M/S Belho Gas Service
# Phone: 03702242027
#
# Searching: software companies in Longleng Nagaland
# Search Submitted
# Longleng | software companies | Scroll 1 -> 5
# Longleng | software companies | Scroll 2 -> 5
# Longleng | software companies | Scroll 3 -> 5
# Longleng | software companies | Scroll 4 -> 5
# Longleng | software companies | Scroll 5 -> 5
# Collected 3 links
# Longleng | 1/3
# APP & Company
# Phone:
# Longleng | 2/3
# Fast Tech (Printing & Services)
# Phone:
# Longleng | 3/3
# My Recharge Pvt Ltd
# Phone:
#
# Searching: IT companies in Longleng Nagaland
# Search Submitted
# Longleng | IT companies | Scroll 1 -> 7
# Longleng | IT companies | Scroll 2 -> 7
# Longleng | IT companies | Scroll 3 -> 7
# Longleng | IT companies | Scroll 4 -> 7
# Longleng | IT companies | Scroll 5 -> 7
# Collected 3 links
# Longleng | 1/3
# IACT Longleng
# Phone: 01122472020
# Longleng | 2/3
# S . A Bricks and Concrete Factory
# Phone:
# Longleng | 3/3
# TIEN TIEN
# Phone:
#
# Searching: software companies in Mokokchung Nagaland
# Search Submitted
# Mokokchung | software companies | Scroll 1 -> 13
# Mokokchung | software companies | Scroll 2 -> 13
# Mokokchung | software companies | Scroll 3 -> 13
# Mokokchung | software companies | Scroll 4 -> 13
# Mokokchung | software companies | Scroll 5 -> 13
# Collected 10 links
# Mokokchung | 1/10
# Amazon office
# Phone:
# Mokokchung | 2/10
# Longpok Offset Press
# Phone: 08014975018
# Mokokchung | 3/10
# NETTEC COMPUTERS
# Phone: 03697962828
# Mokokchung | 4/10
# Blue Dart Express Limited
# Phone:
# Mokokchung | 5/10
# Tumbledry Dry Clean & Laundry Service
# Phone: 07677250250
# Mokokchung | 6/10
# Wa Complex
# Phone:
# Mokokchung | 7/10
# Alino Travel For Dimapur
# Phone:
# Mokokchung | 8/10
# Metsüben Resort and Organic Farm
# Phone: 03692226373
# Mokokchung | 9/10
# Jio Point
# Phone: 18608933333
# Mokokchung | 10/10
# Epada YDSC CSC (Common Service Centre)
# Phone: 09402424983
#
# Searching: IT companies in Mokokchung Nagaland
# Search Submitted
# Mokokchung | IT companies | Scroll 1 -> 16
# Mokokchung | IT companies | Scroll 2 -> 20
# Mokokchung | IT companies | Scroll 3 -> 28
# Mokokchung | IT companies | Scroll 4 -> 36
# Mokokchung | IT companies | Scroll 5 -> 40
# Mokokchung | IT companies | Scroll 6 -> 48
# Mokokchung | IT companies | Scroll 7 -> 55
# Mokokchung | IT companies | Scroll 8 -> 55
# Mokokchung | IT companies | Scroll 9 -> 55
# Mokokchung | IT companies | Scroll 10 -> 55
# Mokokchung | IT companies | Scroll 11 -> 55
# Collected 43 links
# Mokokchung | 1/43
# Digital Hub
# Phone:
# Mokokchung | 2/43
# PC GARAGE
# Phone: 07005124821
# Mokokchung | 3/43
# Institute of Computer Science & Technology (ICST) Mokokchung
# Phone: 09233993353
# Mokokchung | 4/43
# All India Radio
# Phone:
# Mokokchung | 5/43
# Ken Hostel
# Phone:
# Mokokchung | 6/43
# MMC Shopping Complex
# Phone:
# Mokokchung | 7/43
# Lim Travels
# Phone: 08119052160
# Mokokchung | 8/43
# Nature Park Ungma
# Phone:
# Mokokchung | 9/43
# LIC of India, Branch Office
# Phone:
# Mokokchung | 10/43
# KHR OINAM Digital Marketing
# Phone:
# Mokokchung | 11/43
# Whispering Winds
# Phone:
# Mokokchung | 12/43
# Nathan Memorial Hostel
# Phone:
# Mokokchung | 13/43
# Vishal Mega Mart
# Phone: 08011170205
# Mokokchung | 14/43
# El Dora
# Phone:
# Mokokchung | 15/43
# iphix mokokchung
# Phone: 08837400643
# Mokokchung | 16/43
# Etiben Tea Factory
# Phone:
# Mokokchung | 17/43
# BN Resto
# Phone:
# Mokokchung | 18/43
# Kapayong ward
# Phone:
# Mokokchung | 19/43
# District Computer Centre
# Phone:
# Mokokchung | 20/43
# National Informatics Centre
# Phone: 1800111555
# Mokokchung | 21/43
# BEAMS CAFE
# Phone:
# Mokokchung | 22/43
# LINK SOLUTION POINT
# Phone:
# Mokokchung | 23/43
# Sijak restro
# Phone:
# Mokokchung | 24/43
# LONGKUMER GENERAL STORE.
# Phone:
# Mokokchung | 25/43
# Rajasthan Restaurant With Lodging
# Phone: 09402403020
# Mokokchung | 26/43
# The Restaurant- 2
# Phone:
# Mokokchung | 27/43
# Elysian Girls Hostel
# Phone:
# Mokokchung | 28/43
# GANPATI ENTERPRISES MKG
# Phone:
# Mokokchung | 29/43
# Farmers' Innovation Centre
# Phone: 09402433681
# Mokokchung | 30/43
# Mobile clinic
# Phone:
# Mokokchung | 31/43
# Faculty Quarters ICIT Mokokchung
# Phone:
# Mokokchung | 32/43
# Staff Quarter, Department of Economics & Statistics, Marepkong ward, Mokokchung, Nagaland
# Phone:
# Mokokchung | 33/43
# Lemtu Su-it Tea Factory
# Phone:
# Mokokchung | 34/43
# Techno Realm
# Phone:
# Mokokchung | 35/43
# office of the superindenting engineer mokokchung electrical circle
# Phone:
# Mokokchung | 36/43
# Superintending Engineer, PWD (R&B), Mokokchung Circle
# Phone:
# Mokokchung | 37/43
# INFOTECH CSC
# Phone:
# Mokokchung | 38/43
# Power Grid Corporation of India ltd.
# Phone: 01242571700
# Mokokchung | 39/43
# Power House
# Phone:
# Mokokchung | 40/43
# STAR FISHERIES (Longmikaba Sector, Japu Village)
# Phone: 08415869568
# Mokokchung | 41/43
# Mokokchung
# Phone:
# Mokokchung | 42/43
# Naga_Infotech
# Phone: 09894962909
# Mokokchung | 43/43
# JPS MOKOKCHUNG
# Phone: 09436205788
#
# Searching: software companies in Mon Nagaland
# Search Submitted
# Mon | software companies | Scroll 1 -> 3
# Mon | software companies | Scroll 2 -> 3
# Mon | software companies | Scroll 3 -> 3
# Mon | software companies | Scroll 4 -> 3
# Mon | software companies | Scroll 5 -> 3
# Collected 0 links
#
# Searching: IT companies in Mon Nagaland
# Search Submitted
# Scrolling Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@role="feed"]"}
#   (Session info: chrome=148.0.7778.168); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 	chromedriver!GetHandleVerifier [0x76b593+105d3]
# 	chromedriver!GetHandleVerifier [0x76b6c4+10704]
# 	chromedriver!(No symbol) [0x571ea0]
# 	chromedriver!(No symbol) [0x5bb28a]
# 	chromedriver!(No symbol) [0x5bb52b]
# 	chromedriver!(No symbol) [0x5fd052]
# 	chromedriver!(No symbol) [0x5dd7c4]
# 	chromedriver!(No symbol) [0x5fa936]
# 	chromedriver!(No symbol) [0x5dd516]
# 	chromedriver!(No symbol) [0x5b08e9]
# 	chromedriver!(No symbol) [0x5b16a4]
# 	chromedriver!GetHandleVerifier [0x9f3014+298054]
# 	chromedriver!GetHandleVerifier [0x9ee603+293643]
# 	chromedriver!GetHandleVerifier [0xa0ea05+2b3a45]
# 	chromedriver!GetHandleVerifier [0x7854e8+2a528]
# 	chromedriver!GetHandleVerifier [0x78cd1d+31d5d]
# 	chromedriver!GetHandleVerifier [0x773e68+18ea8]
# 	chromedriver!GetHandleVerifier [0x774015+19055]
# 	chromedriver!GetHandleVerifier [0x75d65f+269f]
# 	KERNEL32!BaseThreadInitThunk [0x75a3fcc9+19]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x773782ae+11e]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x7737827e+ee]
#
# Collected 0 links
#
# Searching: software companies in Niuland Nagaland
# Search Submitted
# Niuland | software companies | Scroll 1 -> 2
# Niuland | software companies | Scroll 2 -> 2
# Niuland | software companies | Scroll 3 -> 2
# Niuland | software companies | Scroll 4 -> 2
# Niuland | software companies | Scroll 5 -> 2
# Collected 0 links
#
# Searching: IT companies in Niuland Nagaland
# Search Submitted
# Niuland | IT companies | Scroll 1 -> 16
# Niuland | IT companies | Scroll 2 -> 20
# Niuland | IT companies | Scroll 3 -> 28
# Niuland | IT companies | Scroll 4 -> 36
# Niuland | IT companies | Scroll 5 -> 39
# Niuland | IT companies | Scroll 6 -> 39
# Niuland | IT companies | Scroll 7 -> 39
# Niuland | IT companies | Scroll 8 -> 39
# Niuland | IT companies | Scroll 9 -> 39
# Collected 23 links
# Niuland | 1/23
# Ona Naga Pickle
# Phone:
# Niuland | 2/23
# K.kiba Residence
# Phone:
# Niuland | 3/23
# S.vihuto Yeptho
# Phone:
# Niuland | 4/23
# Modern Myriad Branding Private Limited
# Phone: 08119889282
# Niuland | 5/23
# Pukhato
# Phone:
# Niuland | 6/23
# Naga estate
# Phone:
# Niuland | 7/23
# Rose's plot
# Phone:
# Niuland | 8/23
# Highland Dawn Media & Nagaland Cornerstone TV
# Phone: 08132907882
# Niuland | 9/23
# S.A stone crusher
# Phone: 07085841028
# Niuland | 10/23
# GB RESIDENCE K NITOVI ACHUMI
# Phone:
# Niuland | 11/23
# Nihoto
# Phone:
# Niuland | 12/23
# NAGALAND STATE MINERAL DEVELOPMENT CORPORATION LIMITED (NSMDCL) HEAD OFFICE, Kohima
# Phone:
# Niuland | 13/23
# Zuhokhu Awomi residence
# Phone:
# Niuland | 14/23
# CraftSite Studio
# Phone:
# Niuland | 15/23
# Wildwood mansion
# Phone:
# Niuland | 16/23
# NST Garage
# Phone:
# Niuland | 17/23
# Z. Yekuto Sema
# Phone:
# Niuland | 18/23
# The Entrepreneurs Associates (tEA)
# Phone: 07641008033
# Niuland | 19/23
# Pastor residence
# Phone:
# Niuland | 20/23
# Niuland Color Xerox
# Phone: 08787687727
# Niuland | 21/23
# North Eastern Foods India
# Phone:
# Niuland | 22/23
# Phutoli Farm
# Phone:
# Niuland | 23/23
# Nithin Sai Constructions, Chedema
# Phone:
#
# Searching: software companies in Noklak Nagaland
# Search Submitted
# Noklak | software companies | Scroll 1 -> 4
# Noklak | software companies | Scroll 2 -> 4
# Noklak | software companies | Scroll 3 -> 4
# Noklak | software companies | Scroll 4 -> 4
# Noklak | software companies | Scroll 5 -> 4
# Collected 1 links
# Noklak | 1/1
# THM Tech
# Phone:
#
# Searching: IT companies in Noklak Nagaland
# Search Submitted
# Noklak | IT companies | Scroll 1 -> 16
# Noklak | IT companies | Scroll 2 -> 20
# Noklak | IT companies | Scroll 3 -> 28
# Noklak | IT companies | Scroll 4 -> 36
# Noklak | IT companies | Scroll 5 -> 40
# Noklak | IT companies | Scroll 6 -> 48
# Noklak | IT companies | Scroll 7 -> 56
# Noklak | IT companies | Scroll 8 -> 60
# Noklak | IT companies | Scroll 9 -> 68
# Noklak | IT companies | Scroll 10 -> 75
# Noklak | IT companies | Scroll 11 -> 75
# Noklak | IT companies | Scroll 12 -> 75
# Noklak | IT companies | Scroll 13 -> 75
# Noklak | IT companies | Scroll 14 -> 75
# Collected 70 links
# Noklak | 1/70
# Poultry farm, Noklak
# Phone:
# Noklak | 2/70
# Bakha Media Service Centre Noklak
# Phone:
# Noklak | 3/70
# Meshu's Residence
# Phone:
# Noklak | 4/70
# P Peshing Villa
# Phone:
# Noklak | 5/70
# Liang K,Lam
# Phone:
# Noklak | 6/70
# Khaikho ntn lam
# Phone:
# Noklak | 7/70
# Jungyam Fishery Farm Guest House
# Phone: 08837338223
# Noklak | 8/70
# Zeao Konghiao
# Phone:
# Noklak | 9/70
# M.Thangou KTC President
# Phone:
# Noklak | 10/70
# Nk Enterpress
# Phone: 09612179251
# Noklak | 11/70
# M M Electronics
# Phone: 08974048075
# Noklak | 12/70
# Penglang Lam
# Phone:
# Noklak | 13/70
# Tangsoi p
# Phone:
# Backup Saved
# Noklak | 14/70
#
# Phone:
# Noklak | 15/70
# 67 N.Lam residency
# Phone:
# Noklak | 16/70
# Qumniu po
# Phone:
# Noklak | 17/70
# Penshe sector
# Phone:
# Noklak | 18/70
# Mee Luzo Lam
# Phone:
# Noklak | 19/70
# Lam's Cottage Noklak
# Phone:
# Noklak | 20/70
# Chicken and feeds centre Noklak
# Phone:
# Noklak | 21/70
# Sethem Khiamniungan
# Phone:
# Noklak | 22/70
# Khuming. Y
# Phone:
# Noklak | 23/70
# Grace Cottage
# Phone:
# Noklak | 24/70
# Longshen sheu
# Phone:
# Noklak | 25/70
# Shiu's home
# Phone:
# Noklak | 26/70
# Treasurer Residence Koungao Sector
# Phone:
# Noklak | 27/70
# Indane - Tangsoi Gramin Vitrak
# Phone: 09612666130
# Noklak | 28/70
# Ns Apong Computer Centre Noklak
# Phone:
# Noklak | 29/70
# Noklak feeds centre
# Phone: 09366724549
# Noklak | 30/70
# SAMO (Puthai po)
# Phone:
# Noklak | 31/70
# Wiz Computer
# Phone:
# Noklak | 32/70
# Langs Resident
# Phone:
# Noklak | 33/70
# Puhe Thai
# Phone:
# Noklak | 34/70
# Musho place
# Phone:
# Noklak | 35/70
# Medical sector
# Phone:
# Noklak | 36/70
# Power Office
# Phone:
# Noklak | 37/70
# Ningpao
# Phone:
# Noklak | 38/70
# Treasurer Residence Koungao Sector
# Phone:
# Noklak | 39/70
# VCC RESIDENCE
# Phone:
# Noklak | 40/70
# Chang Residence
# Phone:
# Noklak | 41/70
# Shou Residence
# Phone:
# Noklak | 42/70
# Priyangshu web
# Phone:
# Noklak | 43/70
# Lamdem hydro-project
# Phone:
# Noklak | 44/70
# Hem's Residence
# Phone:
# Noklak | 45/70
# Blacksmith centre (yethsan)
# Phone:
# Noklak | 46/70
# Abci company
# Phone:
# Noklak | 47/70
# Khengo Residence
# Phone:
# Noklak | 48/70
# Chingmak Resident
# Phone:
# Noklak | 49/70
# Beyan's house
# Phone:
# Noklak | 50/70
# A.K.M Computer Networking
# Phone:
# Noklak | 51/70
# I Ngaku
# Phone:
# Noklak | 52/70
# Thangpong Laga House
# Phone:
# Noklak | 53/70
# Nokyan 'A'
# Phone:
# Noklak | 54/70
# L.K farm house
# Phone:
# Noklak | 55/70
# Shingnya
# Phone:
# Noklak | 56/70
# Thangmeng Teacher Residence
# Phone:
# Noklak | 57/70
# Lushing place
# Phone:
# Noklak | 58/70
# MH Electronics
# Phone: 07002116491
# Noklak | 59/70
# Koi’s Residence
# Phone:
# Noklak | 60/70
# Narayan stationery
# Phone:
# Noklak | 61/70
# CSC NEW PANGSHA, Digital Pangsha
# Phone:
# Noklak | 62/70
# mongkochollen's home
# Phone:
# Noklak | 63/70
# Aadhar Enrolment Centre Noklak
# Phone: 08974935805
# Noklak | 64/70
# M.P. Thai & son's
# Phone:
# Noklak | 65/70
# N S Pangom Residence
# Phone:
# Noklak | 66/70
# ReDefine Solutions
# Phone: 09535858887
# Noklak | 67/70
# Shri Peshia S khiamniungan
# Phone: 08119856477
# Noklak | 68/70
# Thokloumei Integrated Farm
# Phone:
# Noklak | 69/70
# Thokloumei Integrated Farm
# Phone:
# Noklak | 70/70
# Thokloumei Integrated Farm
# Phone:
#
# Searching: software companies in Peren Nagaland
# Search Submitted
# Peren | software companies | Scroll 1 -> 3
# Peren | software companies | Scroll 2 -> 3
# Peren | software companies | Scroll 3 -> 3
# Peren | software companies | Scroll 4 -> 3
# Peren | software companies | Scroll 5 -> 3
# Collected 2 links
# Peren | 1/2
# Heragijang National Highway 129A
# Phone: 08837053481
# Peren | 2/2
# IC DigiTech Solutions
# Phone:
#
# Searching: IT companies in Peren Nagaland
# Search Submitted
# Peren | IT companies | Scroll 1 -> 16
# Peren | IT companies | Scroll 2 -> 19
# Peren | IT companies | Scroll 3 -> 19
# Peren | IT companies | Scroll 4 -> 19
# Peren | IT companies | Scroll 5 -> 19
# Peren | IT companies | Scroll 6 -> 19
# Collected 9 links
# Peren | 1/9
# VithoTech
# Phone:
# Peren | 2/9
# District Computer Centre, Peren Town, Nagaland
# Phone:
# Peren | 3/9
# I.K ENTERPRISES "Love To Serve"
# Phone: 08575872512
# Peren | 4/9
# Holiday Inn
# Phone: 06009382366
# Peren | 5/9
# Northeast Job Seekers Consultancy
# Phone:
# Peren | 6/9
# K Enterprises
# Phone: 09402812723
# Peren | 7/9
# AE Ventures
# Phone:
# Peren | 8/9
# Website Development in Nagaland
# Phone:
# Peren | 9/9
# AYz
# Phone:
#
# Searching: software companies in Phek Nagaland
# Search Submitted
# Phek | software companies | Scroll 1 -> 13
# Phek | software companies | Scroll 2 -> 13
# Phek | software companies | Scroll 3 -> 13
# Phek | software companies | Scroll 4 -> 13
# Phek | software companies | Scroll 5 -> 13
# Collected 6 links
# Phek | 1/6
# IACT Education Phek
# Phone: 01122472020
# Phek | 2/6
# Native Prints
# Phone: 09862859303
# Phek | 3/6
# Chizami Town
# Phone:
# Phek | 4/6
# Computer sales and repair
# Phone: 09233668466
# Phek | 5/6
# pikonik
# Phone: 07005002205
# Phek | 6/6
# Neilo Koza
# Phone:
#
# Searching: IT companies in Phek Nagaland
# Search Submitted
# Phek | IT companies | Scroll 1 -> 16
# Phek | IT companies | Scroll 2 -> 20
# Phek | IT companies | Scroll 3 -> 28
# Phek | IT companies | Scroll 4 -> 36
# Phek | IT companies | Scroll 5 -> 40
# Phek | IT companies | Scroll 6 -> 48
# Phek | IT companies | Scroll 7 -> 56
# Phek | IT companies | Scroll 8 -> 60
# Phek | IT companies | Scroll 9 -> 64
# Phek | IT companies | Scroll 10 -> 64
# Phek | IT companies | Scroll 11 -> 64
# Phek | IT companies | Scroll 12 -> 64
# Phek | IT companies | Scroll 13 -> 64
# Collected 51 links
# Phek | 1/51
# Kiwi Farm
# Phone:
# Phek | 2/51
# Pick a Book, Street Library, Phek
# Phone:
# Phek | 3/51
# James Piggery Farm.
# Phone:
# Phek | 4/51
# Observation home phek
# Phone:
# Phek | 5/51
# Mero's Solution Enterprises
# Phone:
# Phek | 6/51
# All India Radio - Phek
# Phone:
# Phek | 7/51
# Zhopo’s Enterprise-Ultratech Cement
# Phone: 09366685820
# Phek | 8/51
# Xerography
# Phone:
# Phek | 9/51
# The fruit basket
# Phone:
# Phek | 10/51
# Micro Hydel Project, Thuvopisu
# Phone:
# Phek | 11/51
# Zumi's
# Phone:
# Phek | 12/51
# Kedupa Residence
# Phone:
# Phek | 13/51
# Ezo's Residency
# Phone:
# Phek | 14/51
# NK Akami
# Phone:
# Phek | 15/51
# Mutsuba khel
# Phone:
# Phek | 16/51
# Khutsa Village
# Phone:
# Phek | 17/51
# Ak Nienu
# Phone:
# Phek | 18/51
# Phek Local taxi, CAB
# Phone:
# Phek | 19/51
# Ak Nienu residence
# Phone:
# Phek | 20/51
# Vese Home
# Phone:
# Phek | 21/51
# Losami VDB Building
# Phone:
# Phek | 22/51
# Vese Residence
# Phone:
# Phek | 23/51
# Vekrokho Swuro Piggery Farm
# Phone:
# Phek | 24/51
# K.T.Z Khel
# Phone:
# Phek | 25/51
# Selhuta Nyekha
# Phone:
# Phek | 26/51
# Lt. Kachuno Nuh Residence
# Phone:
# Backup Saved
# Phek | 27/51
# Rhakho's Residency
# Phone:
# Phek | 28/51
# Nuzelu House
# Phone:
# Phek | 29/51
# Che tsho
# Phone:
# Phek | 30/51
# Doctors' Quarters
# Phone:
# Phek | 31/51
# Aite Lohe
# Phone:
# Phek | 32/51
# Ngotsoyi Sapuh
# Phone:
# Phek | 33/51
# Sakhozo residence
# Phone:
# Phek | 34/51
# Khotsozo's Phuba
# Phone:
# Phek | 35/51
# Veba khesoh
# Phone:
# Phek | 36/51
# Elahs Resident
# Phone:
# Phek | 37/51
# SP Residence
# Phone:
# Phek | 38/51
# Kutisu
# Phone:
# Phek | 39/51
# PEWE MEKRISUH
# Phone:
# Phek | 40/51
# Late Tunyeveyi Naro
# Phone:
# Phek | 41/51
# Kohima
# Phone:
# Phek | 42/51
# Apra Khusoh
# Phone:
# Phek | 43/51
# Shekhopa Residence
# Phone:
# Phek | 44/51
# Vilalhou residence
# Phone:
# Phek | 45/51
# Achele house
# Phone:
# Phek | 46/51
# Soho
# Phone:
# Phek | 47/51
# Soho Store
# Phone: 08798129485
# Phek | 48/51
# Emerald Home
# Phone:
# Phek | 49/51
# Mukhayi Chuzho Residence
# Phone:
# Phek | 50/51
# Rizo R R
# Phone:
# Phek | 51/51
# Election Officer Quarter, Jericho Ward
# Phone:
#
# Searching: software companies in Shamator Nagaland
# Search Submitted
# Scrolling Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@role="feed"]"}
#   (Session info: chrome=148.0.7778.168); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 	chromedriver!GetHandleVerifier [0x76b593+105d3]
# 	chromedriver!GetHandleVerifier [0x76b6c4+10704]
# 	chromedriver!(No symbol) [0x571ea0]
# 	chromedriver!(No symbol) [0x5bb28a]
# 	chromedriver!(No symbol) [0x5bb52b]
# 	chromedriver!(No symbol) [0x5fd052]
# 	chromedriver!(No symbol) [0x5dd7c4]
# 	chromedriver!(No symbol) [0x5fa936]
# 	chromedriver!(No symbol) [0x5dd516]
# 	chromedriver!(No symbol) [0x5b08e9]
# 	chromedriver!(No symbol) [0x5b16a4]
# 	chromedriver!GetHandleVerifier [0x9f3014+298054]
# 	chromedriver!GetHandleVerifier [0x9ee603+293643]
# 	chromedriver!GetHandleVerifier [0xa0ea05+2b3a45]
# 	chromedriver!GetHandleVerifier [0x7854e8+2a528]
# 	chromedriver!GetHandleVerifier [0x78cd1d+31d5d]
# 	chromedriver!GetHandleVerifier [0x773e68+18ea8]
# 	chromedriver!GetHandleVerifier [0x774015+19055]
# 	chromedriver!GetHandleVerifier [0x75d65f+269f]
# 	KERNEL32!BaseThreadInitThunk [0x75a3fcc9+19]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x773782ae+11e]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x7737827e+ee]
#
# Collected 0 links
#
# Searching: IT companies in Shamator Nagaland
# Search Submitted
# Shamator | IT companies | Scroll 1 -> 11
# Shamator | IT companies | Scroll 2 -> 11
# Shamator | IT companies | Scroll 3 -> 11
# Shamator | IT companies | Scroll 4 -> 11
# Shamator | IT companies | Scroll 5 -> 11
# Collected 5 links
# Shamator | 1/5
# Kihomong (monkhs)
# Phone:
# Shamator | 2/5
# Lato Janger -Gadgets- Near Upper Traffic Point
# Phone:
# Shamator | 3/5
# Shamator town
# Phone:
# Shamator | 4/5
# VICE- VisualTech Institute of Computer Education, Shamator Branch
# Phone: 09366434621
# Shamator | 5/5
# Deputy Commissioner Residence
# Phone:
#
# Searching: software companies in Tseminyu Nagaland
# Search Submitted
# Tseminyu | software companies | Scroll 1 -> 3
# Tseminyu | software companies | Scroll 2 -> 3
# Tseminyu | software companies | Scroll 3 -> 3
# Tseminyu | software companies | Scroll 4 -> 3
# Tseminyu | software companies | Scroll 5 -> 3
# Collected 0 links
#
# Searching: IT companies in Tseminyu Nagaland
# Search Submitted
# Tseminyu | IT companies | Scroll 1 -> 16
# Tseminyu | IT companies | Scroll 2 -> 17
# Tseminyu | IT companies | Scroll 3 -> 17
# Tseminyu | IT companies | Scroll 4 -> 17
# Tseminyu | IT companies | Scroll 5 -> 17
# Tseminyu | IT companies | Scroll 6 -> 17
# Collected 4 links
# Tseminyu | 1/4
# Sub Treasury Tseminyu
# Phone:
# Tseminyu | 2/4
# Youthnet
# Phone: 08256923961
# Tseminyu | 3/4
# Fira Tech
# Phone:
# Tseminyu | 4/4
# New Tech Computer Training Centre
# Phone: 08787687949
#
# Searching: software companies in Tuensang Nagaland
# Search Submitted
# Tuensang | software companies | Scroll 1 -> 10
# Tuensang | software companies | Scroll 2 -> 10
# Tuensang | software companies | Scroll 3 -> 10
# Tuensang | software companies | Scroll 4 -> 10
# Tuensang | software companies | Scroll 5 -> 10
# Collected 8 links
# Tuensang | 1/8
# Tuensang Nagaland
# Phone: 09863758632
# Tuensang | 2/8
# ICTE Tuensang
# Phone:
# Tuensang | 3/8
# Nagaland State Transport
# Phone:
# Tuensang | 4/8
# Serene Hostel
# Phone:
# Tuensang | 5/8
# SMARY COMPUTER
# Phone:
# Tuensang | 6/8
# SymBios Creation PVT. LTD
# Phone:
# Tuensang | 7/8
# HighTech Computer
# Phone:
# Tuensang | 8/8
# CMAC TUENSANG
# Phone: 09862615300
#
# Searching: IT companies in Tuensang Nagaland
# Search Submitted
# Tuensang | IT companies | Scroll 1 -> 16
# Tuensang | IT companies | Scroll 2 -> 20
# Tuensang | IT companies | Scroll 3 -> 28
# Tuensang | IT companies | Scroll 4 -> 36
# Tuensang | IT companies | Scroll 5 -> 40
# Tuensang | IT companies | Scroll 6 -> 48
# Tuensang | IT companies | Scroll 7 -> 56
# Tuensang | IT companies | Scroll 8 -> 60
# Tuensang | IT companies | Scroll 9 -> 68
# Tuensang | IT companies | Scroll 10 -> 76
# ...
# Tuensang | IT companies | Scroll 21 -> 120
# Collected 103 links
# Tuensang | 1/103
# DIGITAL MORUNG
# Phone: 08787885455
# Tuensang | 2/103
# Ex-Servicemen Guest House
# Phone:
# Tuensang | 3/103
# Delhivery
# Phone:
# Tuensang | 4/103
# Ms Electronics Tuensang
# Phone: 08837313955
# Tuensang | 5/103
# P. Month am khiam
# Phone:
# Tuensang | 6/103
# Alex kingdom
# Phone:
# Tuensang | 7/103
# Public Ground
# Phone: 07005752230
# Tuensang | 8/103
# Rent House Tuensang
# Phone:
# Tuensang | 9/103
# Janger Apartment
# Phone:
# Tuensang | 10/103
# District Computer Centre,
# Phone:
# Tuensang | 11/103
# Tuensang Network Counter
# Phone:
# Tuensang | 12/103
# Naong
# Phone:
# Tuensang | 13/103
# Jingba Kuh
# Phone:
# Tuensang | 14/103
# S. Thungti
# Phone:
# Tuensang | 15/103
# S. Thungti
# Phone:
# Tuensang | 16/103
# S Phom
# Phone:
# Tuensang | 17/103
# Navinn Lodge And Restaurant
# Phone:
# Tuensang | 18/103
# TUENSANG village kangshou khel
# Phone:
# Tuensang | 19/103
# Joseph jàm
# Phone:
# Tuensang | 20/103
# Lümsü Village
# Phone:
# Tuensang | 21/103
# Will come gate village
# Phone:
# Tuensang | 22/103
# O TIA, RESIDENCE
# Phone:
# Tuensang | 23/103
# Bus service
# Phone:
# Tuensang | 24/103
# Microtech CSC
# Phone: 09077483819
# Tuensang | 25/103
# INFOFIX CSC
# Phone:
# Tuensang | 26/103
# Taxi Station
# Phone: 08787886021
# Tuensang | 27/103
# I L Chang
# Phone:
# Tuensang | 28/103
# Shang Company
# Phone: 08837310695
# Tuensang | 29/103
# Deputy Commissioner's Office
# Phone:
# Tuensang | 30/103
# Lanu house
# Phone:
# Tuensang | 31/103
# BSNL Store
# Phone: 09402923681
# Tuensang | 32/103
# Saha's House
# Phone:
# Tuensang | 33/103
# Melopong jam
# Phone:
# Tuensang | 34/103
# Industrial Training Institute
# Phone:
# Tuensang | 35/103
# Kiumühean RCC
# Phone:
# Tuensang | 36/103
# BSNL Store
# Phone: 09436643333
# Tuensang | 37/103
# MongLen
# Phone:
# Tuensang | 38/103
# Indane - Hangba Gas Agency
# Phone: 08732073904
# Tuensang | 39/103
# Home
# Phone:
# Tuensang | 40/103
# ASA Corner CSC, Common Service Centre
# Phone:
# Tuensang | 41/103
# Tsutsoi. Tuensang Town
# Phone:
# Tuensang | 42/103
# HAIMEI XEROX POINT
# Phone:
# Tuensang | 43/103
# Toi villa
# Phone:
# Tuensang | 44/103
# Tk Chang
# Phone:
# Tuensang | 45/103
# Hoam
# Phone:
# Tuensang | 46/103
# Town Meat Centre
# Phone:
# Tuensang | 47/103
# Y Hongen DB
# Phone:
# Tuensang | 48/103
# The Tiger
# Phone:
# Tuensang | 49/103
# CMO quarters
# Phone:
# Tuensang | 50/103
# Hanjishung residance
# Phone:
# Tuensang | 51/103
# Unique Printers
# Phone: 06009472090
# Tuensang | 52/103
# Limawati H Chang
# Phone:
# Tuensang | 53/103
# SCOSS VAL
# Phone:
# Tuensang | 54/103
# Alex Resthome
# Phone:
# Tuensang | 55/103
# APOLLO TRDERS
# Phone:
# Tuensang | 56/103
# Home
# Phone:
# Tuensang | 57/103
# T N Somba
# Phone:
# Tuensang | 58/103
# Khuku Residential
# Phone:
# Backup Saved
# Tuensang | 59/103
# ENPO Guest Room
# Phone:
# Tuensang | 60/103
# PWD Office
# Phone:
# Tuensang | 61/103
# Taku Chang
# Phone:
# Tuensang | 62/103
# A K Henry
# Phone:
# Tuensang | 63/103
# ADC's Residence
# Phone:
# Tuensang | 64/103
# New photo studio
# Phone:
# Tuensang | 65/103
# YN Typing Zone Wakching Mon Nagaland
# Phone: 09612289100
# Tuensang | 66/103
# Setiu Khiam
# Phone:
# Tuensang | 67/103
# Thechum's residence
# Phone:
# Tuensang | 68/103
# KECHING LIMZ
# Phone:
# Tuensang | 69/103
# L .Thea residences
# Phone:
# Tuensang | 70/103
# Laiket lembiu
# Phone:
# Tuensang | 71/103
# PBCTT Staff Quarters
# Phone:
# Tuensang | 72/103
# Longtang Village, Tuensang, Nagaland
# Phone:
# Tuensang | 73/103
# Cholichem's Residence
# Phone:
# Tuensang | 74/103
# Thangpong residents
# Phone:
# Tuensang | 75/103
# Health Clinic
# Phone:
# Tuensang | 76/103
# Quinn's Meat
# Phone: 09862053812
# Tuensang | 77/103
# Kinglise resident
# Phone:
# Tuensang | 78/103
# BENCHOLLEN
# Phone:
# Tuensang | 79/103
# Home
# Phone:
# Tuensang | 80/103
# B. N. Farm
# Phone:
# Tuensang | 81/103
# Achy Grazia
# Phone:
# Tuensang | 82/103
# Purna
# Phone:
# Tuensang | 83/103
# Lanumoa's residence
# Phone:
# Tuensang | 84/103
# Power Station
# Phone:
# Tuensang | 85/103
# Pharmacy
# Phone:
# Tuensang | 86/103
# SETIU khiam
# Phone:
# Tuensang | 87/103
# Taxi Parking, Tuensang Civil Hospital
# Phone:
# Tuensang | 88/103
# Holong Sangtam
# Phone:
# Tuensang | 89/103
# Indane - Nefa Gas Agency
# Phone: 08787700423
# Tuensang | 90/103
# Tolen resident
# Phone:
# Tuensang | 91/103
# Longdise Mongzar
# Phone:
# Tuensang | 92/103
# Comfort Stop
# Phone:
# Tuensang | 93/103
# Polounyu selounyu colony
# Phone:
# Tuensang | 94/103
# Department Of Power
# Phone:
# Tuensang | 95/103
# Tuesang bazar b
# Phone:
# Tuensang | 96/103
# SP's Residence
# Phone:
# Tuensang | 97/103
# Tisa residence
# Phone: 09366132941
# Tuensang | 98/103
# Thangpong Resident
# Phone:
# Tuensang | 99/103
# Soenzchang
# Phone:
# Tuensang | 100/103
# Pixel Studio Tuensang
# Phone:
# Tuensang | 101/103
# Visali Z Sangtam
# Phone:
# Tuensang | 102/103
# Pooja Yarns Store
# Phone:
# Tuensang | 103/103
# C. Thongpang Residence
# Phone:
#
# Searching: software companies in Wokha Nagaland
# Search Submitted
# Scrolling Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@role="feed"]"}
#   (Session info: chrome=148.0.7778.168); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 	chromedriver!GetHandleVerifier [0x76b593+105d3]
# 	chromedriver!GetHandleVerifier [0x76b6c4+10704]
# 	chromedriver!(No symbol) [0x571ea0]
# 	chromedriver!(No symbol) [0x5bb28a]
# 	chromedriver!(No symbol) [0x5bb52b]
# 	chromedriver!(No symbol) [0x5fd052]
# 	chromedriver!(No symbol) [0x5dd7c4]
# 	chromedriver!(No symbol) [0x5fa936]
# 	chromedriver!(No symbol) [0x5dd516]
# 	chromedriver!(No symbol) [0x5b08e9]
# 	chromedriver!(No symbol) [0x5b16a4]
# 	chromedriver!GetHandleVerifier [0x9f3014+298054]
# 	chromedriver!GetHandleVerifier [0x9ee603+293643]
# 	chromedriver!GetHandleVerifier [0xa0ea05+2b3a45]
# 	chromedriver!GetHandleVerifier [0x7854e8+2a528]
# 	chromedriver!GetHandleVerifier [0x78cd1d+31d5d]
# 	chromedriver!GetHandleVerifier [0x773e68+18ea8]
# 	chromedriver!GetHandleVerifier [0x774015+19055]
# 	chromedriver!GetHandleVerifier [0x75d65f+269f]
# 	KERNEL32!BaseThreadInitThunk [0x75a3fcc9+19]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x773782ae+11e]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x7737827e+ee]
#
# Collected 0 links
#
# Searching: IT companies in Wokha Nagaland
# Search Submitted
# Wokha | IT companies | Scroll 1 -> 16
# Wokha | IT companies | Scroll 2 -> 20
# Wokha | IT companies | Scroll 3 -> 28
# Wokha | IT companies | Scroll 4 -> 36
# Wokha | IT companies | Scroll 5 -> 40
# Wokha | IT companies | Scroll 6 -> 48
# Wokha | IT companies | Scroll 7 -> 56
# Wokha | IT companies | Scroll 8 -> 60
# Wokha | IT companies | Scroll 9 -> 68
# Wokha | IT companies | Scroll 10 -> 76
# Wokha | IT companies | Scroll 11 -> 80
# Wokha | IT companies | Scroll 12 -> 88
# Wokha | IT companies | Scroll 13 -> 96
# Wokha | IT companies | Scroll 14 -> 100
# Wokha | IT companies | Scroll 15 -> 108
# Wokha | IT companies | Scroll 16 -> 116
# Wokha | IT companies | Scroll 17 -> 118
# Wokha | IT companies | Scroll 18 -> 118
# jenn lotha
# Phone: 08787699798
# Wokha | 108/115
# Zuch murry home
# Phone:
# Wokha | 109/115
# Bajaj Finance Branch
# Phone: 02241804799
# Wokha | 110/115
# Ngullie's House
# Phone:
# Wokha | 111/115
# M.Kikon Furniture
# Phone:
# Wokha | 112/115
# Pipen Recharge Booth
# Phone:
# Wokha | 113/115
# PRINT HOUSE
# Phone: 08413861375
# Wokha | 114/115
# M.K woodworks
# Phone: 08787593743
# Wokha | 115/115
# Three Tsanglao Brother's
# Phone:
#
# Searching: software companies in Zunheboto Nagaland
# Search Submitted
# Zunheboto | software companies | Scroll 1 -> 7
# Zunheboto | software companies | Scroll 2 -> 7
# Zunheboto | software companies | Scroll 3 -> 7
# Zunheboto | software companies | Scroll 4 -> 7
# Zunheboto | software companies | Scroll 5 -> 7
# Collected 6 links
# Zunheboto | 1/6
# Zunheboto Sumo Counter
# Phone:
# Zunheboto | 2/6
# Oriflame Zunheboto
# Phone: 07005732882
# Zunheboto | 3/6
# PayNearBy Zunheboto
# Phone:
# Zunheboto | 4/6
# BSNL Office
# Phone: 18003451500
# Zunheboto | 5/6
# Multimedia House
# Phone:
# Zunheboto | 6/6
# X-ELEMENTS
# Phone:
#
# Searching: IT companies in Zunheboto Nagaland
# Search Submitted
# Zunheboto | IT companies | Scroll 1 -> 12
# Zunheboto | IT companies | Scroll 2 -> 18
# Zunheboto | IT companies | Scroll 3 -> 20
# Zunheboto | IT companies | Scroll 4 -> 26
# Zunheboto | IT companies | Scroll 5 -> 32
# Zunheboto | IT companies | Scroll 6 -> 38
# Zunheboto | IT companies | Scroll 7 -> 40
# Zunheboto | IT companies | Scroll 8 -> 46
# Zunheboto | IT companies | Scroll 9 -> 52
# Zunheboto | IT companies | Scroll 10 -> 58
# Zunheboto | IT companies | Scroll 11 -> 60
# Zunheboto | IT companies | Scroll 12 -> 66
# Zunheboto | IT companies | Scroll 13 -> 72
# Zunheboto | IT companies | Scroll 14 -> 72
# Zunheboto | IT companies | Scroll 15 -> 72
# Zunheboto | IT companies | Scroll 16 -> 72
# Zunheboto | IT companies | Scroll 17 -> 72
# Collected 65 links
# Zunheboto | 1/65
# Zunheboto
# Phone:
# Zunheboto | 2/65
# Khekiho Achumi
# Phone:
# Zunheboto | 3/65
# Zunheboto
# Phone:
# Zunheboto | 4/65
# District Computer Centre Zunheboto
# Phone:
# Zunheboto | 5/65
# Siblings Home
# Phone:
# Zunheboto | 6/65
#
# Phone:
# Zunheboto | 7/65
# Zhekiye village
# Phone:
# Zunheboto | 8/65
# Swu's Residence
# Phone:
# Zunheboto | 9/65
# Anpau ixathi
# Phone:
# Zunheboto | 10/65
# Kaviho Zhimo Ki
# Phone:
# Zunheboto | 11/65
#
# Phone:
# Zunheboto | 12/65
# K Yeptho
# Phone:
# Zunheboto | 13/65
# Vikaho.T.Zhimomi
# Phone:
# Zunheboto | 14/65
# Zunheboto
# Phone:
# Zunheboto | 15/65
# Z. Kheshiho Yepthomi, G.B Sukhalu Village
# Phone:
# Zunheboto | 16/65
# Happy club conclave
# Phone:
