# %%
import pandas as pd

# %%
df = pd.read_csv("nagaland_companies.csv")

# %%
df.shape
# Out:
# (931, 8)

# %%
df = df[
    df["Phone"].notna() &
    (df["Phone"].astype(str).str.strip() != "")
    ]
df.shape
# Out:
# (306, 8)

# %%
df = df[
    df["Company Name"].notna()
    ]
df = df[
    df["Company Name"].str.strip() != ""
    ]
df.shape
# Out:
# (306, 8)

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]","",regex=True)
    .str.strip()
)
display(df[["Phone"]].head())
# Out:
#          Phone
# 0  87300299610
# 1  81320319000
# 2  92336459870
# 5  87300407250
# 6  70858345080

# %%
df.to_csv(
    "nagaland_companies_cleaned.csv",
    index=False
)
