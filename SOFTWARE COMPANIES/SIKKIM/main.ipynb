# %%
import time
import random
import pandas as pd

from datetime import datetime

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.service import Service

from webdriver_manager.chrome import ChromeDriverManager

districts = [
    "Gangtok",
    "Gyalshing",
    "Mangan",
    "Namchi",
    "Pakyong",
    "Soreng"
]



search_types = [
    "software companies",
    "IT companies"
]



options = webdriver.ChromeOptions()

options.add_argument("--start-maximized")

options.add_argument(
    "--disable-blink-features=AutomationControlled"
)

options.add_argument("--disable-notifications")



driver = webdriver.Chrome(

    service=Service(
        ChromeDriverManager().install()
    ),

    options=options
)

# OPEN GOOGLE MAPS

driver.get("https://www.google.com/maps")

print("Opening Google Maps...")

time.sleep(15)

print("Google Maps Loaded")



all_data = []

visited_links = set()

# SEARCH BOX FUNCTION

def get_search_box():

    selectors = [

        '//input[@id="searchboxinput"]',
        '//input[contains(@placeholder,"Search")]',
        '//input[contains(@aria-label,"Search")]',
        '//input'

    ]

    for selector in selectors:

        try:

            box = driver.find_element(
                By.XPATH,
                selector
            )

            return box

        except:
            pass

    return None



def extract_school_data():

    try:

        try:

            name = driver.find_element(
                By.TAG_NAME,
                "h1"
            ).text

        except:

            name = ""


        try:

            address = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"address")]'
            ).text

        except:

            address = ""


        phone = ""

        try:

            phone_xpaths = [

                '//button[contains(@data-item-id,"phone")]',

                '//a[contains(@href,"tel:")]',

                '//button[contains(@aria-label,"Phone")]',

                '//button[contains(text(),"+91")]',
                '//div[contains(text(),"+91")]',
                '//span[contains(text(),"+91")]'

            ]

            for xpath in phone_xpaths:

                try:

                    elements = driver.find_elements(
                        By.XPATH,
                        xpath
                    )

                    for element in elements:

                        text = element.text.strip()

                        href = (
                            element.get_attribute("href")
                            or ""
                        )

           
                        if "tel:" in href:

                            phone = href.replace(
                                "tel:",
                                ""
                            ).strip()

                
                        elif text:

                            phone = text


                        phone = (

                            phone.replace("", "")
                            .replace(" ", "")
                            .replace("-", "")
                            .replace("(", "")
                            .replace(")", "")
                            .replace("\n", "")
                            .strip()

                        )


                        digits = ''.join(
                            filter(str.isdigit, phone)
                        )

                        if len(digits) >= 10:

                            break

                    if phone:
                        break

                except:
                    pass

        except Exception as e:

            print(f"Phone Error: {e}")



        try:

            website = driver.find_element(
                By.XPATH,
                '//a[contains(@data-item-id,"authority")]'
            ).get_attribute("href")

        except:

            website = ""


        try:

            rating = driver.find_element(
                By.XPATH,
                '//div[@role="img"]'
            ).get_attribute("aria-label")

        except:

            rating = ""

        return {

            "Company Name": name,
            "Address": address,
            "Phone": phone,
            "Website": website,
            "Rating": rating,
            "Google Maps URL": driver.current_url

        }

    except:

        return None


for district in districts:

    for search_type in search_types:

        try:

            query = (
                f"{search_type} "
                f"in {district} Sikkim"
            )

            print(f"\nSearching: {query}")



            search_box = get_search_box()

            if not search_box:

                print("Search Box Not Found")

                continue

            ActionChains(driver).move_to_element(
                search_box
            ).click().perform()

            time.sleep(1)

            search_box.send_keys(
                Keys.CONTROL + "a"
            )

            time.sleep(1)

            search_box.send_keys(Keys.DELETE)

            time.sleep(1)



            for char in query:

                search_box.send_keys(char)

                time.sleep(0.03)

            search_box.send_keys(Keys.ENTER)

            print("Search Submitted")

            time.sleep(8)



            try:

                scrollable_div = driver.find_element(
                    By.XPATH,
                    '//div[@role="feed"]'
                )

                previous_count = 0

                stagnant = 0

                for i in range(100):

                    driver.execute_script(
                        """
                        arguments[0].scrollTop =
                        arguments[0].scrollHeight
                        """,
                        scrollable_div
                    )

                    time.sleep(4)

                    listings = driver.find_elements(
                        By.XPATH,
                        '//a[contains(@href,"/maps/place/")]'
                    )

                    current_count = len(listings)

                    print(
                        f"{district} | "
                        f"{search_type} | "
                        f"Scroll {i+1} -> "
                        f"{current_count}"
                    )

                    if current_count == previous_count:

                        stagnant += 1

                    else:

                        stagnant = 0

                    if stagnant >= 4:

                        break

                    previous_count = current_count

            except Exception as e:

                print(f"Scrolling Error: {e}")



            listings = driver.find_elements(
                By.XPATH,
                '//a[contains(@href,"/maps/place/")]'
            )

            links = []

            for listing in listings:

                try:

                    link = listing.get_attribute("href")

                    if (
                        link
                        and link not in visited_links
                    ):

                        links.append(link)

                        visited_links.add(link)

                except:
                    pass

            print(f"Collected {len(links)} links")

 

            for index, link in enumerate(links):

                try:

                    print(
                        f"{district} | "
                        f"{index+1}/{len(links)}"
                    )

                    driver.get(link)

                    time.sleep(
                        random.uniform(2, 3)
                    )

                    data = extract_school_data()

                    if data:

                        data["District"] = district

                        data["Search Type"] = search_type

                        all_data.append(data)

                        print(data["Company Name"])

                        print(
                            f"Phone: {data['Phone']}"
                        )

   

                    if len(all_data) % 100 == 0:

                        backup_df = pd.DataFrame(
                            all_data
                        )

                        backup_df.drop_duplicates(
                            subset=[
                                "Company Name",
                                "Google Maps URL"
                            ],
                            inplace=True
                        )

                        backup_df.to_csv(
                            "sikkim_companies_backup.csv",
                            index=False
                        )

                        print("Backup Saved")

                except Exception as e:

                    print(
                        f"Company Error: {e}"
                    )

        except Exception as e:

            print(
                f"District Error: {e}"
            )



df = pd.DataFrame(all_data)

df.drop_duplicates(

    subset=[
        "Company Name",
        "Google Maps URL"
    ],

    inplace=True
)

filename = "sikkim_companies.csv"

df.to_csv(
    filename,
    index=False
)

print("\nExtraction Completed")

print(
    f"Total Companies Extracted: {len(df)}"
)

print(f"\nSaved File: {filename}")

driver.quit()
# Out:
# Opening Google Maps...
# Google Maps Loaded
#
# Searching: software companies in Gangtok Sikkim
# Search Submitted
# Gangtok | software companies | Scroll 1 -> 14
# Gangtok | software companies | Scroll 2 -> 20
# Gangtok | software companies | Scroll 3 -> 27
# Gangtok | software companies | Scroll 4 -> 34
# Gangtok | software companies | Scroll 5 -> 40
# Gangtok | software companies | Scroll 6 -> 47
# Gangtok | software companies | Scroll 7 -> 54
# Gangtok | software companies | Scroll 8 -> 60
# Gangtok | software companies | Scroll 9 -> 67
# Gangtok | software companies | Scroll 10 -> 67
# Gangtok | software companies | Scroll 11 -> 67
# Gangtok | software companies | Scroll 12 -> 67
# Gangtok | software companies | Scroll 13 -> 67
# Collected 67 links
# Gangtok | 1/67
# Bolds Innovation Pvt. Ltd.
# Phone: 09635930947
# Gangtok | 2/67
# Tech Waglogy LLP
# Phone: 09733814168
# Gangtok | 3/67
# Emeyc Private Limited
# Phone:
# Gangtok | 4/67
# Rumtek Technologies
# Phone:
# Gangtok | 5/67
# Elevate Web
# Phone: 06294547323
# Gangtok | 6/67
# Pradhanbros Pvt. Ltd.
# Phone: 09647871467
# Gangtok | 7/67
# Aaron Technologies Sikkim
# Phone: 09007946444
# Gangtok | 8/67
# Technoxy
# Phone: 07478986851
# Gangtok | 9/67
# Bytesberry Technologies
# Phone: 08597355169
# Gangtok | 10/67
# Netspeq Solutions
# Phone:
# Gangtok | 11/67
# Freelance Software Developer with 20yrs exp
# Phone: 06005268037
# Gangtok | 12/67
# EASY TECH
# Phone: 09851933977
# Gangtok | 13/67
# STPI - Software Technology Park's of India
# Phone:
# Gangtok | 14/67
# Pradeepna Electronic Security & IT Solutions (PDESIS)
# Phone: 09999845174
# Gangtok | 15/67
# Techie Panda
# Phone:
# Gangtok | 16/67
# Sikkim Electronics Sales and Services
# Phone: 08101910025
# Gangtok | 17/67
# Sikkim IT Enterprises
# Phone: 08900188412
# Gangtok | 18/67
# Placewell Retail
# Phone: 09333693337
# Gangtok | 19/67
# iDestiny -  Apple Authorised Reseller, Gangtok
# Phone: 08069199817
# Gangtok | 20/67
# Sibin Group
# Phone: 03592206999
# Gangtok | 21/67
# NETSPEQ SOLUTIONS
# Phone:
# Gangtok | 22/67
# Cyber Help India
# Phone: 08906736717
# Gangtok | 23/67
# ADVANTAGE NETWORK
# Phone: 08372899595
# Gangtok | 24/67
# B S A & Company | Chartered Accountant | CA in Gangtok , Sikkim
# Phone: 08101056230
# Gangtok | 25/67
# Senigma Tech Pvt Ltd
# Phone: 07551038435
# Gangtok | 26/67
# Cyber Sikkim
# Phone: 09641426662
# Gangtok | 27/67
# ASUS Premium Retailer - Click 10
# Phone: 09800300300
# Gangtok | 28/67
# Get Set Go Tours, Travels & Adventures
# Phone: 09555750965
# Gangtok | 29/67
# Shape IT | Software Company
# Phone: 08101652485
# Gangtok | 30/67
# MojoPx
# Phone: 08240324124
# Gangtok | 31/67
# Netspeq Solutions
# Phone:
# Gangtok | 32/67
# OffbeatDestination Travels - Sikkim, Darjeeling and Bhutan tour packages
# Phone: 06296102341
# Gangtok | 33/67
# North Sikkim Sharing Tour Company
# Phone: 07699112177
# Gangtok | 34/67
# Studio Interweave
# Phone:
# Gangtok | 35/67
# Connecting Northeast
# Phone:
# Gangtok | 36/67
# E Enterprises
# Phone: 07699414699
# Gangtok | 37/67
# Fab Cab Tours & Travels
# Phone: 09734031079
# Gangtok | 38/67
# Zomsa Tours and Travels Gangtok Sikkim
# Phone: 07866040703
# Gangtok | 39/67
# Ease Tours and Treks
# Phone: 09593267846
# Gangtok | 40/67
# Mountain milestone tours & travels- travel agency in sikkim
# Phone: 09064185176
# Gangtok | 41/67
# Best and Affordable Printing Services in Gangtok | Drishti Enterprise
# Phone: 08348754234
# Gangtok | 42/67
# 4 Clef Studio
# Phone:
# Gangtok | 43/67
# Kokkivo Clothing
# Phone: 08116631090
# Gangtok | 44/67
# TourGenie
# Phone: 07047892407
# Gangtok | 45/67
# The Sherpa - Tours & Stays
# Phone:
# Gangtok | 46/67
# Tech WEB developer meer
# Phone:
# Gangtok | 47/67
# Hathway Digital Ltd
# Phone: 09434204444
# Gangtok | 48/67
# Ecom Express
# Phone: 08376888888
# Gangtok | 49/67
# Galaxy Tours & Treks
# Phone: 09475012777
# Gangtok | 50/67
# Neepun Tours and Travels
# Phone: 09434407535
# Gangtok | 51/67
# Sikkim Peak Tours and Travels/Sikkim Trekking
# Phone: 09832544375
# Gangtok | 52/67
# Vista Sikkim
# Phone: 09614103102
# Gangtok | 53/67
# Computer Repair (Hardware & Software) and Network (LAN, WAN), CCTV Services
# Phone:
# Gangtok | 54/67
# we care holidays
# Phone: 07076784742
# Gangtok | 55/67
# Your Trip Planner Sikkim
# Phone: 07585971503
# Gangtok | 56/67
# Sikkim NH10 Tours & Travels
# Phone: 09609704654
# Gangtok | 57/67
# S'yuo Cha
# Phone:
# Gangtok | 58/67
# SIKKIM LIT TRAVEL
# Phone: 09883841149
# Gangtok | 59/67
# Titan Eye+ at MG Marg, Gangtok (Buy 1 Get 1 Free)
# Phone: 07029975414
# Gangtok | 60/67
# Udaan Silk Route Tours & Travels
# Phone: 08927056974
# Gangtok | 61/67
# Travelouge Services
# Phone: 09735055161
# Gangtok | 62/67
# Sikkim Trips Tours and Travels
# Phone: 08116664446
# Gangtok | 63/67
# Sunflower TravelGangtok
# Phone: 09733311217
# Gangtok | 64/67
# Sikkim on Wheels
# Phone: 07679024355
# Gangtok | 65/67
# JBL Partner Store - MG Marg, Gangtok
# Phone: 08071325576
# Gangtok | 66/67
# Luitel Technology
# Phone:
# Gangtok | 67/67
# HimalayasWeb
# Phone: 09897874521
#
# Searching: IT companies in Gangtok Sikkim
# Search Submitted
# Gangtok | IT companies | Scroll 1 -> 14
# Gangtok | IT companies | Scroll 2 -> 20
# Gangtok | IT companies | Scroll 3 -> 27
# Gangtok | IT companies | Scroll 4 -> 30
# Gangtok | IT companies | Scroll 5 -> 30
# Gangtok | IT companies | Scroll 6 -> 30
# Gangtok | IT companies | Scroll 7 -> 30
# Gangtok | IT companies | Scroll 8 -> 30
# Collected 4 links
# Gangtok | 1/4
# S VSolutions
# Phone: 07310495151
# Gangtok | 2/4
# Titan World - Arithang, Gangtok
# Phone: 08062914196
# Gangtok | 3/4
# Service Support for Repair Shop Of Printers Xerox,Cpu Laptops Dvr And Cameras Aceriosses India
# Phone: 09832618809
# Gangtok | 4/4
# HIMALAYAN SHOPPE c/o Krishna Company
# Phone: 09233419361
#
# Searching: software companies in Gyalshing Sikkim
# Search Submitted
# Gyalshing | software companies | Scroll 1 -> 14
# Gyalshing | software companies | Scroll 2 -> 17
# Gyalshing | software companies | Scroll 3 -> 17
# Gyalshing | software companies | Scroll 4 -> 17
# Gyalshing | software companies | Scroll 5 -> 17
# Gyalshing | software companies | Scroll 6 -> 17
# Collected 11 links
# Gyalshing | 1/11
# ELECTRODADA Geyzing
# Phone: 07031146711
# Gyalshing | 2/11
# Yangtey
# Phone:
# Gyalshing | 3/11
# The Cherry Grand
# Phone: 09733235441
# Gyalshing | 4/11
# Kyongsha Ground, Gyalshing.
# Phone:
# Gyalshing | 5/11
# Rabdentse Ruins
# Phone: 09676182003
# Gyalshing | 6/11
# Geyzing Taxi Stand
# Phone:
# Gyalshing | 7/11
# Loop
# Phone:
# Gyalshing | 8/11
# Oak Valley Retreat homestay hostel cafe
# Phone: 09775470255
# Gyalshing | 9/11
# TEESTA VI HYDRO POWER PROJECT, NHPC, SIRWANI
# Phone:
# Gyalshing | 10/11
# Sun Pharma, Sikkim, Unit-2
# Phone:
# Gyalshing | 11/11
# SikkimTech Solutions - All IT Solutions
# Phone: 09734156506
#
# Searching: IT companies in Gyalshing Sikkim
# Search Submitted
# Gyalshing | IT companies | Scroll 1 -> 14
# Gyalshing | IT companies | Scroll 2 -> 20
# Gyalshing | IT companies | Scroll 3 -> 27
# Gyalshing | IT companies | Scroll 4 -> 34
# Gyalshing | IT companies | Scroll 5 -> 40
# Gyalshing | IT companies | Scroll 6 -> 47
# Gyalshing | IT companies | Scroll 7 -> 50
# Gyalshing | IT companies | Scroll 8 -> 50
# Gyalshing | IT companies | Scroll 9 -> 50
# Gyalshing | IT companies | Scroll 10 -> 50
# Gyalshing | IT companies | Scroll 11 -> 50
# Collected 38 links
# Gyalshing | 1/38
# C.one computer institute
# Phone: 07602945097
# Gyalshing | 2/38
# Government Industrial Training Institute
# Phone: 09734321620
# Gyalshing | 3/38
# Mankind Pharma Limited
# Phone:
# Gyalshing | 4/38
# IPCA Laboratories Ltd
# Phone:
# Gyalshing | 5/38
# Gyalshing west sikkim
# Phone:
# Gyalshing | 6/38
# InstinctandAnalysis
# Phone:
# Gyalshing | 7/38
# Incredible Himalaya Tours and Travel
# Phone: 09734932565
# Gyalshing | 8/38
# INFORMATICS COMPUTER INSTITUTE
# Phone: 08391912067
# Gyalshing | 9/38
# Yangthang Farms
# Phone:
# Gyalshing | 10/38
# Mankind Pharma
# Phone:
# Gyalshing | 11/38
# 𝐆𝐥𝐚𝐜𝐢𝐞𝐫 𝐓𝐫𝐞𝐤𝐬 𝐚𝐧𝐝 𝐀𝐝𝐯𝐞𝐧𝐭𝐮𝐫𝐞
# Phone: 07407248200
# Gyalshing | 12/38
# Upper Langang Village
# Phone:
# Gyalshing | 13/38
# Sukham Nest Yamphung Residency
# Phone: 07003137597
# Gyalshing | 14/38
# Ravitej Projects
# Phone:
# Gyalshing | 15/38
# Geyzing town and bazar
# Phone:
# Gyalshing | 16/38
# Daara Pari
# Phone: 09832730711
# Gyalshing | 17/38
# Explore Sikkim cab service
# Phone: 09775670010
# Gyalshing | 18/38
# Bauer Engineering - NHPC TLDP VI Project
# Phone:
# Backup Saved
# Gyalshing | 19/38
# Sky Walk Pelling Sikkim
# Phone: 03592209090
# Gyalshing | 20/38
# Sikkim Cab Service
# Phone: 07557888672
# Gyalshing | 21/38
# Best Travel Agency in Sikkim -Blue Mountains Tours and Travels
# Phone: 08101641917
# Gyalshing | 22/38
# Sanu Homestay
# Phone: 09635060062
# Gyalshing | 23/38
# Hiddenparadise Adventure Tours
# Phone: 08348468878
# Gyalshing | 24/38
# Ralong Hot Springs
# Phone:
# Gyalshing | 25/38
# Chuchay Dhunga/Titanic View Point Ralong Namlung
# Phone: 09593988564
# Gyalshing | 26/38
# SIKKIM TRAVELs EXPERTs co.
# Phone: 09339935161
# Gyalshing | 27/38
# Mandavya Homestay
# Phone: 09832122302
# Gyalshing | 28/38
# Holiday Hype Tours & Travels - Sikkim
# Phone: 07001713972
# Gyalshing | 29/38
# Let's go tour and travels
# Phone: 09733018237
# Gyalshing | 30/38
# Temi Tea Factory (Estd. 1969)
# Phone:
# Gyalshing | 31/38
# Kenaz treks and adventure
# Phone: 09609878378
# Gyalshing | 32/38
# Black Yak Expeditions
# Phone: 09734190190
# Gyalshing | 33/38
# Sikkim Diaries Tours & Treks
# Phone: 06295198565
# Gyalshing | 34/38
# Sikkim Yetis
# Phone: 06239235581
# Gyalshing | 35/38
# Sonam Mega Mart
# Phone: 08918126811
# Gyalshing | 36/38
# Skywalk Ropeway (Under construction)
# Phone:
# Gyalshing | 37/38
# SMARTTRIPPARTNER.COM
# Phone: 09732619883
# Gyalshing | 38/38
# SPREADD
# Phone: 06295970798
#
# Searching: software companies in Mangan Sikkim
# Search Submitted
# Mangan | software companies | Scroll 1 -> 11
# Mangan | software companies | Scroll 2 -> 11
# Mangan | software companies | Scroll 3 -> 11
# Mangan | software companies | Scroll 4 -> 11
# Mangan | software companies | Scroll 5 -> 11
# Collected 8 links
# Mangan | 1/8
# S S Electronics
# Phone: 09002008007
# Mangan | 2/8
# CITI COMPUTERS
# Phone: 08116119557
# Mangan | 3/8
# The ginger house
# Phone: 08972923390
# Mangan | 4/8
# MALAWLEE HOME STAY
# Phone:
# Mangan | 5/8
# North Point Tours & Travels
# Phone:
# Mangan | 6/8
# RNB North Sikkim Tours and Travels
# Phone: 07584917717
# Mangan | 7/8
# Puntong Lee
# Phone:
# Mangan | 8/8
# Heuristic Learning Institute
# Phone:
#
# Searching: IT companies in Mangan Sikkim
# Search Submitted
# Mangan | IT companies | Scroll 1 -> 14
# Mangan | IT companies | Scroll 2 -> 20
# Mangan | IT companies | Scroll 3 -> 27
# Mangan | IT companies | Scroll 4 -> 34
# Mangan | IT companies | Scroll 5 -> 40
# Mangan | IT companies | Scroll 6 -> 47
# Mangan | IT companies | Scroll 7 -> 54
# Mangan | IT companies | Scroll 8 -> 60
# Mangan | IT companies | Scroll 9 -> 67
# Mangan | IT companies | Scroll 10 -> 74
# Mangan | IT companies | Scroll 11 -> 80
# Mangan | IT companies | Scroll 12 -> 80
# Mangan | IT companies | Scroll 13 -> 80
# Mangan | IT companies | Scroll 14 -> 80
# Mangan | IT companies | Scroll 15 -> 80
# Collected 68 links
# Mangan | 1/68
# Google Maps can't reach the internet
# Phone:
# Mangan | 2/68
# Google Maps can't reach the internet
# Phone:
# Mangan | 3/68
# Google Maps can't reach the internet
# Phone:
# Mangan | 4/68
# Rumknownlee Building
# Phone:
# Mangan | 5/68
# Cafe Yangla
# Phone: 09733985732
# Mangan | 6/68
# The Planter's Home
# Phone: 09832508442
# Mangan | 7/68
# Destiny Farm
# Phone: 07479318131
# Mangan | 8/68
# Juthi Village
# Phone:
# Mangan | 9/68
# Ambica
# Phone: 09800067167
# Mangan | 10/68
# DigiTech Mangan, Computer services point.
# Phone:
# Mangan | 11/68
# Bajaj Finance Branch
# Phone: 02241804799
# Mangan | 12/68
# BSNL Store
# Phone: 08900437116
# Mangan | 13/68
# theviraltone
# Phone:
# Mangan | 14/68
# B.K ELECTRONICS & FURNITURE
# Phone: 09733996988
# Mangan | 15/68
# HOMEFURNICA STUDIO
# Phone: 09647003149
# Mangan | 16/68
# MRF CENTRE MANGAN
# Phone:
# Mangan | 17/68
# BSNL Store
# Phone: 08900437131
# Mangan | 18/68
# Upper mangshila
# Phone:
# Mangan | 19/68
# Purna Electronics
# Phone: 08158977999
# Mangan | 20/68
# Lal Bazar
# Phone:
# Mangan | 21/68
# Deepal Restaurant Food Wine Bar & Lodge
# Phone: 07797001118
# Mangan | 22/68
# Ayongong lee homestay
# Phone:
# Mangan | 23/68
# Power colony,mangan ,north sikkim
# Phone:
# Mangan | 24/68
# My Den
# Phone:
# Mangan | 25/68
# BSNL Store
# Phone: 08900201447
# Mangan | 26/68
# Munlom Nature Resort
# Phone: 08906120300
# Mangan | 27/68
# Public Library
# Phone:
# Mangan | 28/68
# Car Fare
# Phone: 09474351856
# Mangan | 29/68
# Kamal Kunj, Malling
# Phone:
# Mangan | 30/68
# Mangan Nagar Panchayat
# Phone:
# Mangan | 31/68
# Taryang Lee
# Phone:
# Mangan | 32/68
# T.B JEWELLERS
# Phone: 09679100184
# Mangan | 33/68
# HDFC Bank
# Phone: 18001601
# Mangan | 34/68
# Mr Kee
# Phone:
# Mangan | 35/68
# Amit mobile store
# Phone:
# Mangan | 36/68
# Ganga Restaurant & Bar
# Phone:
# Mangan | 37/68
# Samar House
# Phone:
# Mangan | 38/68
# Himalayan Building
# Phone:
# Mangan | 39/68
# Chandra's House
# Phone:
# Mangan | 40/68
# Rangrang
# Phone:
# Mangan | 41/68
# Noom
# Phone:
# Mangan | 42/68
# Kotong
# Phone:
# Mangan | 43/68
# Lucksom house
# Phone:
# Mangan | 44/68
# Jonah House
# Phone:
# Mangan | 45/68
# Dipak's residency
# Phone:
# Mangan | 46/68
# Beena stores [student shop ]
# Phone:
# Mangan | 47/68
# Rongyong Adventure Dzongu (RAD) | River Rafting | Camping | Trekking | Hiking | Bird Watching | Fishing
# Phone: 09002980973
# Mangan | 48/68
# Sillinglee Homestay
# Phone:
# Mangan | 49/68
# Nampatam
# Phone:
# Mangan | 50/68
# Roy house
# Phone:
# Mangan | 51/68
# Pema 's parking alto
# Phone:
# Mangan | 52/68
# Lakaz Projects
# Phone:
# Mangan | 53/68
# Mr karki's
# Phone:
# Mangan | 54/68
# Dara Dokan
# Phone:
# Mangan | 55/68
# Chokpa lachenpa
# Phone:
# Mangan | 56/68
# Power Control Room, Upper Dzongu, North Sikkim, Mangan
# Phone:
# Mangan | 57/68
# Assam
# Phone:
# Mangan | 58/68
# Namsang thegim
# Phone:
# Mangan | 59/68
# Malling Dzong Khoti, upper singshik
# Phone:
# Mangan | 60/68
# Bijay Laxmi Devi Prasad
# Phone:
# Mangan | 61/68
# Ratul Puri Oragic Fram
# Phone:
# Mangan | 62/68
# Ghising Lha Dhim
# Phone:
# Mangan | 63/68
# North Sikkim, District Court
# Phone:
# Mangan | 64/68
# Tista River Sikkim
# Phone: 01716619094
# Mangan | 65/68
# Punam’s sweets Home
# Phone:
# Mangan | 66/68
# Gurung (Tamu'z) House
# Phone:
# Mangan | 67/68
# Kimrong village
# Phone:
# Mangan | 68/68
# NIMA TSH BHUTIA
# Phone:
#
# Searching: software companies in Namchi Sikkim
# Search Submitted
# Namchi | software companies | Scroll 1 -> 14
# Namchi | software companies | Scroll 2 -> 20
# Namchi | software companies | Scroll 3 -> 24
# Namchi | software companies | Scroll 4 -> 24
# Namchi | software companies | Scroll 5 -> 24
# Namchi | software companies | Scroll 6 -> 24
# Namchi | software companies | Scroll 7 -> 24
# Collected 22 links
# Namchi | 1/22
# TRINITY COMPUTER INSTITUTE NAMCHI CUM COACHING CENTRE
# Phone: 09883963241
# Namchi | 2/22
# Nimble Tech
# Phone:
# Namchi | 3/22
# PC CARE (NAMCHI)
# Phone: 07864004432
# Namchi | 4/22
# Microinfotech
# Phone: 09609049969
# Backup Saved
# Namchi | 5/22
# KOHINOOR ELECTRONICS
# Phone: 09883039933
# Namchi | 6/22
# The Namchi Perch
# Phone:
# Namchi | 7/22
# Ekart logistics
# Phone:
# Namchi | 8/22
# Dumbos Advertising Agency
# Phone: 07479262468
# Namchi | 9/22
# Trust The Locals
# Phone: 08080611841
# Namchi | 10/22
# Escape To Trip Tours and travels Sikkim
# Phone: 07001898428
# Namchi | 11/22
# KeyOrigin
# Phone:
# Namchi | 12/22
# J PANI SERVICE
# Phone: 07063289279
# Namchi | 13/22
# National Informatics Centre - Namchi
# Phone: 03595263216
# Namchi | 14/22
# Tumbledry Dry Clean & Laundry Service
# Phone: 07677250250
# Namchi | 15/22
# SAJILO PRINT
# Phone: 08597745987
# Namchi | 16/22
# Satellite Xpress Limited
# Phone:
# Namchi | 17/22
# Move Himalayas
# Phone:
# Namchi | 18/22
# Smart City Tours & Travels
# Phone: 09734049525
# Namchi | 19/22
# Namchi tourist cab
# Phone: 08906638099
# Namchi | 20/22
# Namchi hill cab service
# Phone: 06296555713
# Namchi | 21/22
# Sikkim Tranquil Tours
# Phone: 09332403377
# Namchi | 22/22
# WooDY Store
# Phone:
#
# Searching: IT companies in Namchi Sikkim
# Search Submitted
# Namchi | IT companies | Scroll 1 -> 14
# Namchi | IT companies | Scroll 2 -> 20
# Namchi | IT companies | Scroll 3 -> 27
# Namchi | IT companies | Scroll 4 -> 34
# Namchi | IT companies | Scroll 5 -> 40
# Namchi | IT companies | Scroll 6 -> 47
# Namchi | IT companies | Scroll 7 -> 54
# Namchi | IT companies | Scroll 8 -> 56
# Namchi | IT companies | Scroll 9 -> 56
# Namchi | IT companies | Scroll 10 -> 56
# Namchi | IT companies | Scroll 11 -> 56
# Namchi | IT companies | Scroll 12 -> 56
# Collected 29 links
# Namchi | 1/29
# DIGITAL HUB
# Phone: 09609401726
# Namchi | 2/29
# AlphaBytes Institutes
# Phone: 09339723812
# Namchi | 3/29
# Manju Ama store
# Phone: 07047898008
# Namchi | 4/29
# Future Tech Sikkim
# Phone: 09800425132
# Namchi | 5/29
# namchi tea garden
# Phone:
# Namchi | 6/29
# Mainaam Garden Nursery
# Phone: 08927072022
# Namchi | 7/29
# V-Guard Industries LTD.
# Phone:
# Namchi | 8/29
# Valhalla - The Rooftop Restaurant
# Phone: 09635718165
# Namchi | 9/29
# Shree Maruti Courier Service - Bhanjyang Road
# Phone: 09242107794
# Namchi | 10/29
# R.P ELECTRONICS
# Phone: 08597772444
# Namchi | 11/29
# The Hidden Cottage Namchi
# Phone: 07679051254
# Namchi | 12/29
# OMTRD Dance Studio, Namchi
# Phone:
# Namchi | 13/29
# KAZITAR HOMES
# Phone:
# Namchi | 14/29
# Cherry Resort
# Phone: 09800013666
# Namchi | 15/29
# Banari Regency By Summit
# Phone: 07812032524
# Namchi | 16/29
# Namchi
# Phone:
# Namchi | 17/29
# CHORTEN STORE NAMCHI
# Phone: 09609928087
# Namchi | 18/29
# Torrent Pharmaceutical Limited Sikkim Unit III
# Phone:
# Namchi | 19/29
# Luitel residency and namchi cabs service
# Phone: 09609244315
# Namchi | 20/29
# Jeyaul Electronics
# Phone:
# Namchi | 21/29
# Jameel Electronics Apple Authorised Store Since 1st dec 1998
# Phone: 09933834747
# Namchi | 22/29
# Dungmali Heritage Village Resort
# Phone: 09734126039
# Namchi | 23/29
# Namchi Taxi Stand
# Phone: 08016469634
# Namchi | 24/29
# Alkem Health Science Pvt. Ltd. Samardung Plant
# Phone: 08343915551
# Namchi | 25/29
# Hotel Maenamla, Namchi
# Phone: 08293777845
# Namchi | 26/29
# The Divisional Engineer Office
# Phone:
# Namchi | 27/29
# DANS Energy pvt.ltd. Power House
# Phone:
# Namchi | 28/29
# Zydus Healthcare Ltd.
# Phone: 08016099901
# Namchi | 29/29
# Quick Laundry Service
# Phone:
#
# Searching: software companies in Pakyong Sikkim
# Search Submitted
# Pakyong | software companies | Scroll 1 -> 14
# Pakyong | software companies | Scroll 2 -> 20
# Pakyong | software companies | Scroll 3 -> 27
# Pakyong | software companies | Scroll 4 -> 34
# Pakyong | software companies | Scroll 5 -> 40
# Pakyong | software companies | Scroll 6 -> 47
# Pakyong | software companies | Scroll 7 -> 54
# Pakyong | software companies | Scroll 8 -> 60
# Pakyong | software companies | Scroll 9 -> 62
# Pakyong | software companies | Scroll 10 -> 62
# Pakyong | software companies | Scroll 11 -> 62
# Pakyong | software companies | Scroll 12 -> 62
# Pakyong | software companies | Scroll 13 -> 62
# Collected 49 links
# Pakyong | 1/49
# Etown Testing Business
# Phone: 08927249938
# Pakyong | 2/49
# Vivanta Sikkim, Pakyong
# Phone: 03592350100
# Pakyong | 3/49
# Rudransh Tech Solutions
# Phone: 09800262915
# Pakyong | 4/49
# Guddu Electronic
# Phone: 09800102679
# Pakyong | 5/49
# Greenfield Sikkim Travels
# Phone: 09593770092
# Pakyong | 6/49
# Alkem Laboratories Ltd.
# Phone: 07310992531
# Pakyong | 7/49
# Sikkim Viramma Retreat
# Phone: 09434003400
# Pakyong | 8/49
# Travel Geniee Tours & Travels
# Phone: 08250155585
# Pakyong | 9/49
# Olyfox Web Solutions
# Phone:
# Pakyong | 10/49
# SWISS GARNIER GENEXIAA SCIENCES PRIVATE LIMITED UNIT 1
# Phone: 04442927700
# Pakyong | 11/49
# Sun Packmet Pvt Ltd
# Phone: 09817434442
# Pakyong | 12/49
# INDRA TECH
# Phone:
# Pakyong | 13/49
# Aaron Computer Solutions
# Phone:
# Pakyong | 14/49
# Aishwarya Healthcare Sikkim
# Phone: 09817110281
# Pakyong | 15/49
# Wai Wai Factory
# Phone:
# Pakyong | 16/49
# Sikkim Garib Aawas Yojana (SGAY) Project Office
# Phone:
# Pakyong | 17/49
# Sikkim IFFCO Organics Limited
# Phone:
# Pakyong | 18/49
# Intas Pharmaceutical Ltd.
# Phone: 08170028481
# Pakyong | 19/49
# ICAR-National Research Centre For Orchids
# Phone: 03592257954
# Pakyong | 20/49
# Sikkim Travel Hub
# Phone: 09126412265
# Pakyong | 21/49
# Savi Health Science
# Phone: 09083283621
# Pakyong | 22/49
# Zydus Wellness Products Ltd
# Phone: 07971800000
# Pakyong | 23/49
# mangertoursandtravels.com
# Phone: 09890263866
# Pakyong | 24/49
# BAM BAM ELECTRONICS
# Phone: 09933725125
# Pakyong | 25/49
# SBL pharma
# Phone:
# Pakyong | 26/49
# IBM Rangpo
# Phone:
# Pakyong | 27/49
# CodeUgly
# Phone:
# Pakyong | 28/49
# Dahal Niwas
# Phone:
# Pakyong | 29/49
# Zydus Healthcare LtdUnit -II
# Phone:
# Pakyong | 30/49
# The Voice of Sikkim
# Phone: 09002128380
# Pakyong | 31/49
# Micro Labs Ltd. (Pharmaceutical Formulation Unit)
# Phone:
# Pakyong | 32/49
# Sikkim Manipal Institute of Technology(Sikkim Manipal University)
# Phone: 09732947000
# Pakyong | 33/49
# Yata Tech Solution
# Phone:
# Pakyong | 34/49
# JEREMY TRAVELS
# Phone: 08016827608
# Pakyong | 35/49
# Daami Event
# Phone: 09635908358
# Pakyong | 36/49
# Pappu Electronic
# Phone: 09733446784
# Pakyong | 37/49
# ApiCare
# Phone: 07908090298
# Pakyong | 38/49
# Huhtamaki-PPL Ltd.
# Phone:
# Pakyong | 39/49
# Idichemie Health Specialties pvt Ltd Unit-II
# Phone:
# Pakyong | 40/49
# Safe Travels Sikkim
# Phone: 08942927997
# Pakyong | 41/49
# MacLeod pharma
# Phone:
# Pakyong | 42/49
# Students Point
# Phone:
# Pakyong | 43/49
# ICAR Quarter (Housing)
# Phone:
# Pakyong | 44/49
# Gladiolus Language Nectar
# Phone: 09635319656
# Pakyong | 45/49
# Software Engineer
# Phone:
# Pakyong | 46/49
# Prime Spectres
# Phone:
# Pakyong | 47/49
# Dev website designer
# Phone: 08327390662
# Pakyong | 48/49
# Pristine Life Sciences
# Phone: 03592233202
# Pakyong | 49/49
# Naz Enterprise
# Phone: 09800239113
#
# Searching: IT companies in Pakyong Sikkim
# Search Submitted
# Pakyong | IT companies | Scroll 1 -> 14
# Pakyong | IT companies | Scroll 2 -> 20
# Pakyong | IT companies | Scroll 3 -> 27
# Pakyong | IT companies | Scroll 4 -> 34
# Pakyong | IT companies | Scroll 5 -> 40
# Pakyong | IT companies | Scroll 6 -> 47
# Pakyong | IT companies | Scroll 7 -> 54
# Pakyong | IT companies | Scroll 8 -> 60
# Pakyong | IT companies | Scroll 9 -> 67
# Pakyong | IT companies | Scroll 10 -> 74
# Pakyong | IT companies | Scroll 11 -> 78
# Pakyong | IT companies | Scroll 12 -> 78
# Pakyong | IT companies | Scroll 13 -> 78
# Pakyong | IT companies | Scroll 14 -> 78
# Pakyong | IT companies | Scroll 15 -> 78
# Collected 30 links
# Pakyong | 1/30
# Macleods Pharmaceuticals Ltd.
# Phone: 08768995032
# Pakyong | 2/30
# Pakyong Market
# Phone:
# Pakyong | 3/30
# Torrent Pharmaceuticals Ltd. Unit I
# Phone: 09735986618
# Pakyong | 4/30
# Lupin ltd.
# Phone: 02266408237
# Backup Saved
# Pakyong | 5/30
# Pakyong Sikkim tour and travels
# Phone: 09339727733
# Pakyong | 6/30
# Yakten Village Homestay Sikkim
# Phone: 09933406136
# Pakyong | 7/30
# Glenmark Pharmaceuticals Ltd
# Phone: 08250322073
# Pakyong | 8/30
# Sun Pharma Plant 1
# Phone:
# Pakyong | 9/30
# National Institute of Electronics & Information Technology
# Phone: 03592205610
# Pakyong | 10/30
# Zuventus Healthcare Ltd.
# Phone:
# Pakyong | 11/30
# Cipla unit II
# Phone:
# Pakyong | 12/30
# REGAL HEALTHCARE LTD.
# Phone: 06122674838
# Pakyong | 13/30
# Heba Pharmaceiutica LLP
# Phone:
# Pakyong | 14/30
# TraveLuxe Sikkim- Travel Agency in gangtok
# Phone: 09832333404
# Pakyong | 15/30
# TCI EXPRESS LIMITED - GANGTOK
# Phone: 18002000977
# Pakyong | 16/30
# Affordable Cab Sikkim by Neekesh
# Phone: 08918201764
# Pakyong | 17/30
# BIBEK CENTRE MAMRING CSC e-Governance Services India Limited
# Phone: 09064457204
# Pakyong | 18/30
# Dinesh Acharya's House
# Phone:
# Pakyong | 19/30
# om logistics rangpo
# Phone: 01145970303
# Pakyong | 20/30
# Astrologer Kamal Sapkota
# Phone:
# Pakyong | 21/30
#
# Phone:
# Pakyong | 22/30
#
# Phone:
# Pakyong | 23/30
# AYM TOURS (Aarohan Yatra Mitra)
# Phone: 08116247471
# Pakyong | 24/30
# Atal Setu
# Phone:
# Pakyong | 25/30
# Modular kitchen Sikkim
# Phone: 09635106239
# Pakyong | 26/30
# Jaso Enterprise crane service
# Phone: 07001991008
# Pakyong | 27/30
# AIC-SMUTBI
# Phone: 03592246622
# Pakyong | 28/30
# Sikkim Boy
# Phone: 07863990845
# Pakyong | 29/30
# Gairigoan
# Phone:
# Pakyong | 30/30
# Pakyong road
# Phone:
#
# Searching: software companies in Soreng Sikkim
# Search Submitted
# Soreng | software companies | Scroll 1 -> 4
# Soreng | software companies | Scroll 2 -> 4
# Soreng | software companies | Scroll 3 -> 4
# Soreng | software companies | Scroll 4 -> 4
# Soreng | software companies | Scroll 5 -> 4
# Collected 3 links
# Soreng | 1/3
# Tech Bunker, Soreng Bazar
# Phone: 06296740311
# Soreng | 2/3
# L & P, Optical & Eye Care
# Phone: 09733377052
# Soreng | 3/3
# Oceverse Infotech West Sikkim
# Phone:
#
# Searching: IT companies in Soreng Sikkim
# Search Submitted
# Soreng | IT companies | Scroll 1 -> 14
# Soreng | IT companies | Scroll 2 -> 20
# Soreng | IT companies | Scroll 3 -> 27
# Soreng | IT companies | Scroll 4 -> 28
# Soreng | IT companies | Scroll 5 -> 28
# Soreng | IT companies | Scroll 6 -> 28
# Soreng | IT companies | Scroll 7 -> 28
# Soreng | IT companies | Scroll 8 -> 28
# Collected 15 links
# Soreng | 1/15
# Soreng District
# Phone:
# Soreng | 2/15
# District Administration Centre, Soreng
# Phone:
# Soreng | 3/15
# District & Sessions Court, Soreng
# Phone:
# Soreng | 4/15
# Dhital SURYA Niwas
# Phone: 09609929510
# Soreng | 5/15
# Mangalbaria Bazar
# Phone:
# Soreng | 6/15
# Benazir Electronics [DilHasan] 👉(more than 50+ year's of service)🎖️
# Phone:
# Soreng | 7/15
# Sungnima
# Phone: 08101010107
# Soreng | 8/15
# Pine Village Retreat kaluk
# Phone: 09064461907
# Soreng | 9/15
#
# Phone: 09611228931
# Soreng | 10/15
#
# Phone:
# Soreng | 11/15
#
# Phone: 09735725081
# Soreng | 12/15
#
# Phone: 07001714052
# Soreng | 13/15
#
# Phone:
# Soreng | 14/15
#
# Phone:
# Soreng | 15/15
#
# Phone: 06296244980
#
# Extraction Completed
# Total Companies Extracted: 344
#
# Saved File: sikkim_companies.csv
