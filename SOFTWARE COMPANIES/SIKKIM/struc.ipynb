# %%
import pandas as pd

# %%
df = pd.read_csv("sikkim_companies.csv")

# %%
df.shape
# Out:
# (344, 8)

# %%
df = df[
    df["Phone"].notna() & 
    (df["Phone"].astype(str).str.strip() != "")
    ]
df.shape
# Out:
# (198, 8)

# %%
df = df[
    df["Company Name"].notna()
    ]

df = df[
    df["Company Name"].str.strip() != ""
    ]
df.shape
# Out:
# (194, 8)

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]","",regex=True)
    .str.strip()
)

display(df[["Phone"]].head())
# Out:
#          Phone
# 0  96359309470
# 1  97338141680
# 4  62945473230
# 5  96478714670
# 6  90079464440

# %%
df.to_csv(
    "sikkim_companies_cleaned.csv",
    index=False
)
