# %%
import pandas as pd

# %%
df = pd.read_csv("andhra_pradesh_companies.csv")

# %%
df.shape
# Out:
# (2584, 8)

# %%
df = df[
    df["Phone"].notna() & 
    (df["Phone"].astype(str).str.strip() != "")
    ]
df.shape
# Out:
# (1842, 8)

# %%
df = df[
    df["Company Name"].notna()
    ]

df = df[
    df["Company Name"].str.strip() != ""
    ]
df.shape
# Out:
# (1823, 8)

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]","",regex=True)
    .str.strip()
)

display(df[["Phone"]].head())
# Out:
#          Phone
# 0  73311899990
# 1  86624340020
# 2  63026510440
# 3  81429296910
# 4  93900093970

# %%
df.to_csv(
    "andhra_pradesh_companies_cleaned.csv",
    index=False
)
