# %%
import pandas as pd

# %%
df = pd.read_csv("assam_companies.csv")

# %%
df.shape
# Out:
# (3210, 8)

# %%
df = df[
    df["Phone"].notna() & 
    (df["Phone"].astype(str).str.strip() != "")
    ]
df.shape
# Out:
# (2073, 8)

# %%
df = df[
    df["Company Name"].notna()
    ]

df = df[
    df["Company Name"].str.strip() != ""
    ]
df.shape
# Out:
# (2049, 8)

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]","",regex=True)
    .str.strip()
)

display(df[["Phone"]].head())
# Out:
#          Phone
# 0  06002552415
# 1  09435040041
# 2  07035868367
# 3  07086038472
# 4  18001233230

# %%
df.to_csv(
    "assam_companies_cleaned.csv",
    index=False
)
