# %%
import pandas as pd

# %%
df = pd.read_csv("meghalaya_companies.csv")

# %%
df.shape
# Out:
# (604, 8)

# %%
df = df[
    df["Phone"].notna() &
    (df["Phone"].astype(str).str.strip() != "")
    ]
df.shape
# Out:
# (383, 8)

# %%
df = df[
    df["Company Name"].notna()
    ]
df = df[
    df["Company Name"].str.strip() != ""
    ]
df.shape
# Out:
# (382, 8)

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]","",regex=True)
    .str.strip()
)
display(df[["Phone"]].head())
# Out:
#          Phone
# 0  98625429830
# 1  88374390960
# 2  82579278060
# 3  89749831440
# 4  79803691400

# %%
df.to_csv(
    "meghalaya_companies_cleaned.csv",
    index=False
)
