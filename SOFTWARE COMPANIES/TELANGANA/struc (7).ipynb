# %%
import pandas as pd

# %%
df = pd.read_csv("telangana_companies.csv")

# %%
df.shape
# Out:
# (837, 8)

# %%
df = df[
    df["Phone"].notna() &
    (df["Phone"].astype(str).str.strip() != "")
    ]
df.shape
# Out:
# (519, 8)

# %%
df = df[
    df["Company Name"].notna()
    ]
df = df[
    df["Company Name"].str.strip() != ""
    ]
df.shape
# Out:
# (519, 8)

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]","",regex=True)
    .str.strip()
)
display(df[["Phone"]].head())
# Out:
#          Phone
# 0  91105856780
# 1  97001000370
# 2  90630796390
# 4  94313239030
# 5  76679883620

# %%
df.to_csv(
    "telangana_companies_cleaned.csv",
    index=False
)
