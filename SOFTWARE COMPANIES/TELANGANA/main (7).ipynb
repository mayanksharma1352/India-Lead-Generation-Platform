# %%
import time
import random
import pandas as pd

from datetime import datetime

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.service import Service

from webdriver_manager.chrome import ChromeDriverManager

districts = [
    "Adilabad",
    "Bhadradri Kothagudem",
    "Hanamkonda",
    "Hyderabad",
    "Jagtial",
    "Jangaon",
    "Jayashankar Bhupalpally",
    "Jogulamba Gadwal",
    "Kamareddy",
    "Karimnagar",
    "Khammam",
    "Komaram Bheem Asifabad",
    "Mahabubabad",
    "Mahabubnagar",
    "Mancherial",
    "Medak",
    "Medchal-Malkajgiri",
    "Mulugu",
    "Nagarkurnool",
    "Nalgonda",
    "Narayanpet",
    "Nirmal",
    "Nizamabad",
    "Peddapalli",
    "Rajanna Sircilla",
    "Ranga Reddy",
    "Sangareddy",
    "Siddipet",
    "Suryapet",
    "Vikarabad",
    "Wanaparthy",
    "Warangal",
    "Yadadri Bhuvanagiri"
]



search_types = [
    "software companies",
    "IT companies"
]

options = webdriver.ChromeOptions()

options.add_argument("--start-maximized")

options.add_argument(
    "--disable-blink-features=AutomationControlled"
)

options.add_argument("--disable-notifications")



driver = webdriver.Chrome(

    service=Service(
        ChromeDriverManager().install()
    ),

    options=options
)



driver.get("https://www.google.com/maps")

print("Opening Google Maps...")

time.sleep(15)

print("Google Maps Loaded")


all_data = []

visited_links = set()



def get_search_box():

    selectors = [

        '//input[@id="searchboxinput"]',
        '//input[contains(@placeholder,"Search")]',
        '//input[contains(@aria-label,"Search")]',
        '//input'

    ]

    for selector in selectors:

        try:

            box = driver.find_element(
                By.XPATH,
                selector
            )

            return box

        except:
            pass

    return None



def extract_school_data():

    try:

        try:

            name = driver.find_element(
                By.TAG_NAME,
                "h1"
            ).text

        except:

            name = ""



        try:

            address = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"address")]'
            ).text

        except:

            address = ""


        phone = ""

        try:

            phone_xpaths = [

                '//button[contains(@data-item-id,"phone")]',

                '//a[contains(@href,"tel:")]',

                '//button[contains(@aria-label,"Phone")]',

                '//button[contains(text(),"+91")]',
                '//div[contains(text(),"+91")]',
                '//span[contains(text(),"+91")]'

            ]

            for xpath in phone_xpaths:

                try:

                    elements = driver.find_elements(
                        By.XPATH,
                        xpath
                    )

                    for element in elements:

                        text = element.text.strip()

                        href = (
                            element.get_attribute("href")
                            or ""
                        )

          
                        if "tel:" in href:

                            phone = href.replace(
                                "tel:",
                                ""
                            ).strip()

             
                        elif text:

                            phone = text

                        phone = (

                            phone.replace("", "")
                            .replace(" ", "")
                            .replace("-", "")
                            .replace("(", "")
                            .replace(")", "")
                            .replace("\n", "")
                            .strip()

                        )

                        digits = ''.join(
                            filter(str.isdigit, phone)
                        )

                        if len(digits) >= 10:

                            break

                    if phone:
                        break

                except:
                    pass

        except Exception as e:

            print(f"Phone Error: {e}")


        try:

            website = driver.find_element(
                By.XPATH,
                '//a[contains(@data-item-id,"authority")]'
            ).get_attribute("href")

        except:

            website = ""


        try:

            rating = driver.find_element(
                By.XPATH,
                '//div[@role="img"]'
            ).get_attribute("aria-label")

        except:

            rating = ""

        return {

            "Company Name": name,
            "Address": address,
            "Phone": phone,
            "Website": website,
            "Rating": rating,
            "Google Maps URL": driver.current_url

        }

    except:

        return None


for district in districts:

    for search_type in search_types:

        try:

            query = (
                f"{search_type} "
                f"in {district} Jharkhand"
            )

            print(f"\nSearching: {query}")

       

            search_box = get_search_box()

            if not search_box:

                print("Search Box Not Found")

                continue

            ActionChains(driver).move_to_element(
                search_box
            ).click().perform()

            time.sleep(1)

            search_box.send_keys(
                Keys.CONTROL + "a"
            )

            time.sleep(1)

            search_box.send_keys(Keys.DELETE)

            time.sleep(1)



            for char in query:

                search_box.send_keys(char)

                time.sleep(0.03)

            search_box.send_keys(Keys.ENTER)

            print("Search Submitted")

            time.sleep(8)



            try:

                scrollable_div = driver.find_element(
                    By.XPATH,
                    '//div[@role="feed"]'
                )

                previous_count = 0

                stagnant = 0

                for i in range(100):

                    driver.execute_script(
                        """
                        arguments[0].scrollTop =
                        arguments[0].scrollHeight
                        """,
                        scrollable_div
                    )

                    time.sleep(4)

                    listings = driver.find_elements(
                        By.XPATH,
                        '//a[contains(@href,"/maps/place/")]'
                    )

                    current_count = len(listings)

                    print(
                        f"{district} | "
                        f"{search_type} | "
                        f"Scroll {i+1} -> "
                        f"{current_count}"
                    )

                    if current_count == previous_count:

                        stagnant += 1

                    else:

                        stagnant = 0

                    if stagnant >= 4:

                        break

                    previous_count = current_count

            except Exception as e:

                print(f"Scrolling Error: {e}")



            listings = driver.find_elements(
                By.XPATH,
                '//a[contains(@href,"/maps/place/")]'
            )

            links = []

            for listing in listings:

                try:

                    link = listing.get_attribute("href")

                    if (
                        link
                        and link not in visited_links
                    ):

                        links.append(link)

                        visited_links.add(link)

                except:
                    pass

            print(f"Collected {len(links)} links")



            for index, link in enumerate(links):

                try:

                    print(
                        f"{district} | "
                        f"{index+1}/{len(links)}"
                    )

                    driver.get(link)

                    time.sleep(
                        random.uniform(2, 3)
                    )

                    data = extract_school_data()

                    if data:

                        data["District"] = district

                        data["Search Type"] = search_type

                        all_data.append(data)

                        print(data["Company Name"])

                        print(
                            f"Phone: {data['Phone']}"
                        )

  

                    if len(all_data) % 100 == 0:

                        backup_df = pd.DataFrame(
                            all_data
                        )

                        backup_df.drop_duplicates(
                            subset=[
                                "Company Name",
                                "Google Maps URL"
                            ],
                            inplace=True
                        )

                        backup_df.to_csv(
                            "jharkhand_companies_backup.csv",
                            index=False
                        )

                        print("Backup Saved")

                except Exception as e:

                    print(
                        f"Company Error: {e}"
                    )

        except Exception as e:

            print(
                f"District Error: {e}"
            )


df = pd.DataFrame(all_data)

df.drop_duplicates(

    subset=[
        "Company Name",
        "Google Maps URL"
    ],

    inplace=True
)

filename = "jharkhand_companies.csv"

df.to_csv(
    filename,
    index=False
)

print("\nExtraction Completed")

print(
    f"Total Companies Extracted: {len(df)}"
)

print(f"\nSaved File: {filename}")

driver.quit()
# Out:
# Opening Google Maps...
# Google Maps Loaded
#
# Searching: software companies in Adilabad Jharkhand
# Search Submitted
# Adilabad | software companies | Scroll 1 -> 2
# Adilabad | software companies | Scroll 2 -> 2
# Adilabad | software companies | Scroll 3 -> 2
# Adilabad | software companies | Scroll 4 -> 2
# Adilabad | software companies | Scroll 5 -> 2
# Collected 2 links
# Adilabad | 1/2
# Tectonixindia
# Phone: 09110585678
# Adilabad | 2/2
# CLEARBIZ SOFTWARE SOLUTIONS PRIVATE LIMITED
# Phone: 09700100037
#
# Searching: IT companies in Adilabad Jharkhand
# Search Submitted
# Adilabad | IT companies | Scroll 1 -> 2
# Adilabad | IT companies | Scroll 2 -> 2
# Adilabad | IT companies | Scroll 3 -> 2
# Adilabad | IT companies | Scroll 4 -> 2
# Adilabad | IT companies | Scroll 5 -> 2
# Collected 1 links
# Adilabad | 1/1
# AeroByte Innovations Pvt Ltd & Sketch Computers
# Phone: 09063079639
#
# Searching: software companies in Bhadradri Kothagudem Jharkhand
# Search Submitted
# Bhadradri Kothagudem | software companies | Scroll 1 -> 6
# Bhadradri Kothagudem | software companies | Scroll 2 -> 6
# Bhadradri Kothagudem | software companies | Scroll 3 -> 6
# Bhadradri Kothagudem | software companies | Scroll 4 -> 6
# Bhadradri Kothagudem | software companies | Scroll 5 -> 6
# Collected 6 links
# Bhadradri Kothagudem | 1/6
# Buck Softech Private Limited
# Phone:
# Bhadradri Kothagudem | 2/6
# Wipenex IT Private Limited
# Phone: 09431323903
# Bhadradri Kothagudem | 3/6
# Techcoder Software Service OPC Private Limited| Best Software Company in Jamshedpur
# Phone: 07667988362
# Bhadradri Kothagudem | 4/6
# Brightcode Software Services Pvt. Ltd.
# Phone: 09386806214
# Bhadradri Kothagudem | 5/6
# Horizon IT Consultancy Services Pvt. Ltd.
# Phone: 09308199900
# Bhadradri Kothagudem | 6/6
# Murmu Software Infotech
# Phone: 09110176498
#
# Searching: IT companies in Bhadradri Kothagudem Jharkhand
# Search Submitted
# Bhadradri Kothagudem | IT companies | Scroll 1 -> 16
# Bhadradri Kothagudem | IT companies | Scroll 2 -> 20
# Bhadradri Kothagudem | IT companies | Scroll 3 -> 28
# Bhadradri Kothagudem | IT companies | Scroll 4 -> 36
# Bhadradri Kothagudem | IT companies | Scroll 5 -> 40
# Bhadradri Kothagudem | IT companies | Scroll 6 -> 48
# Bhadradri Kothagudem | IT companies | Scroll 7 -> 56
# Bhadradri Kothagudem | IT companies | Scroll 8 -> 60
# Bhadradri Kothagudem | IT companies | Scroll 9 -> 68
# Bhadradri Kothagudem | IT companies | Scroll 10 -> 76
# Bhadradri Kothagudem | IT companies | Scroll 11 -> 80
# Bhadradri Kothagudem | IT companies | Scroll 12 -> 88
# Bhadradri Kothagudem | IT companies | Scroll 13 -> 96
# Bhadradri Kothagudem | IT companies | Scroll 14 -> 100
# Bhadradri Kothagudem | IT companies | Scroll 15 -> 108
# Bhadradri Kothagudem | IT companies | Scroll 16 -> 110
# Bhadradri Kothagudem | IT companies | Scroll 17 -> 110
# Bhadradri Kothagudem | IT companies | Scroll 18 -> 110
# Bhadradri Kothagudem | IT companies | Scroll 19 -> 110
# Phone:
# Bhadradri Kothagudem | 101/103
# R.K EARTHMOVERS
# Phone:
# Bhadradri Kothagudem | 102/103
# Soft Line Infotech
# Phone:
# Bhadradri Kothagudem | 103/103
# Ayushi Computer
# Phone: 09835095227
#
# Searching: software companies in Hanamkonda Jharkhand
# Search Submitted
# Hanamkonda | software companies | Scroll 1 -> 16
# Hanamkonda | software companies | Scroll 2 -> 20
# Hanamkonda | software companies | Scroll 3 -> 21
# Hanamkonda | software companies | Scroll 4 -> 21
# Hanamkonda | software companies | Scroll 5 -> 21
# Hanamkonda | software companies | Scroll 6 -> 21
# Hanamkonda | software companies | Scroll 7 -> 21
# Collected 18 links
# Hanamkonda | 1/18
# Deepthi Software Solutions
# Phone:
# Hanamkonda | 2/18
# eshuzo Global Technologies Private Limited - Software Company
# Phone: 08709736707
# Hanamkonda | 3/18
# Svapps Soft Solutions Pvt Ltd | Digital Marketing Agency | Web Design Company | Software Development Warangal, Hanamkonda
# Phone: 09573999985
# Hanamkonda | 4/18
# MATROP-Software Company in Ranchi,Software Company,Website Designer in Ranchi,School Management Software,Bulk SMS,IT Company
# Phone: 09430106005
# Hanamkonda | 5/18
# Ventois Software Solutions Private Limited
# Phone: 07893889950
# Hanamkonda | 6/18
# KAKATIYA IT SOLUTIONS
# Phone: 09390807611
# Hanamkonda | 7/18
# Quadrant Technologies India Private Limited
# Phone:
# Hanamkonda | 8/18
# RSG Software Services Pvt Ltd
# Phone: 09608903749
# Hanamkonda | 9/18
# Lotus Wave Software Solutions Pvt Ltd.
# Phone: 04085690443
# Hanamkonda | 10/18
# ECS : Web Design, Mobile App , Software Decelopment Company
# Phone: 09631916590
# Hanamkonda | 11/18
# INFEXIAL SOFTWARE SOLUTIONS (warangal)
# Phone: 09912169561
# Hanamkonda | 12/18
# Samadhan
# Phone: 06512331882
# Hanamkonda | 13/18
# Cloud Software & IT Services
# Phone: 07488610215
# Hanamkonda | 14/18
# SEM Technologies India Pvt Ltd - Amazon Marketing, AI Automation, Digital Marketing & Branding
# Phone: 08826427272
# Hanamkonda | 15/18
# Raks IT Solutions
# Phone: 09010591950
# Hanamkonda | 16/18
# MLM Software Company In Jharkhand | Investment Plan Software Development
# Phone: 09953119957
# Hanamkonda | 17/18
# Enlavour IT Solutions | Website Development Company in Ranchi-India
# Phone: 07050809319
# Hanamkonda | 18/18
# Salon & Spa Management Software
# Phone:
#
# Searching: IT companies in Hanamkonda Jharkhand
# Search Submitted
# Hanamkonda | IT companies | Scroll 1 -> 16
# Hanamkonda | IT companies | Scroll 2 -> 20
# Hanamkonda | IT companies | Scroll 3 -> 28
# Hanamkonda | IT companies | Scroll 4 -> 32
# Hanamkonda | IT companies | Scroll 5 -> 32
# Hanamkonda | IT companies | Scroll 6 -> 32
# Hanamkonda | IT companies | Scroll 7 -> 32
# Hanamkonda | IT companies | Scroll 8 -> 32
# Collected 19 links
# Hanamkonda | 1/19
# RodeK IT solutions Pvt Ltd
# Phone:
# Hanamkonda | 2/19
# Phone: 04023183585
# Hyderabad | 65/91
# Foreclosure India
# Phone: 08142000062
# Hyderabad | 66/91
# Vihari Grand Co-Living & PG
# Phone: 09347244849
# Hyderabad | 67/91
# Grus & Grade Private Limited
# Phone:
# Hyderabad | 68/91
# Swarna Jayanti Complex
# Phone:
# Hyderabad | 69/91
# Royal Industrial Corporation
# Phone: 09391026019
# Hyderabad | 70/91
# A to Z Chamak Cleaner
# Phone: 09390272178
# Hyderabad | 71/91
# Pappu jharkhand
# Phone:
# Hyderabad | 72/91
# Portea Medical
# Phone: 07995553684
# Hyderabad | 73/91
# VIVO Lifesciences Pvt. Ltd.
# Phone: 04027017100
# Hyderabad | 74/91
# United Thread
# Phone: 07207307407
# Hyderabad | 75/91
# www.ignifycareers.com ( Interview preparation Platform)
# Phone: 08973061111
# Hyderabad | 76/91
# Freshers Jobs
# Phone:
# Hyderabad | 77/91
# ATC Packers and movers
# Phone: 07416957621
# Hyderabad | 78/91
# UTI Infrastructure Technology And Services Limited
# Phone: 04024731627
# Hyderabad | 79/91
# Adamantine Marketing
# Phone: 09444794328
# Hyderabad | 80/91
# Green Line Packers and Movers
# Phone: 09951572530
# Hyderabad | 81/91
# Malabar Group Regional Office - Hyderabad
# Phone: 04023407916
# Hyderabad | 82/91
# Disha Newspaper
# Phone: 04048546963
# Hyderabad | 83/91
# Sri Sai Cargo Packers & Movers
# Phone: 07675808924
# Hyderabad | 84/91
# Leo Line Packers and Movers - Packers and movers in Hyderabad
# Phone: 09000248308
# Hyderabad | 85/91
# Vignan Schools Hyderabad – CBSE School in Nizampet
# Phone: 09701933455
# Hyderabad | 86/91
# AARTHI SCANS & LABS | KARKHANA | DIAGNOSTIC CENTER
# Phone: 07669976699
# Hyderabad | 87/91
# Kartik International Packers and Movers
# Phone: 09828643581
# Hyderabad | 88/91
# DTDC - Kattedan
# Phone: 09246191846
# Hyderabad | 89/91
# M k Enterprise jeevan praman center(Door step)
# Phone: 08019418625
# Hyderabad | 90/91
# Skyway Networks
# Phone: 09052508444
# Hyderabad | 91/91
# ICAR-Directorate of Poultry Research
# Phone: 04024015651
#
# Searching: software companies in Jagtial Jharkhand
# Search Submitted
# Scrolling Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@role="feed"]"}
#   (Session info: chrome=148.0.7778.168); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 	chromedriver!GetHandleVerifier [0xdfb593+105d3]
# 	chromedriver!GetHandleVerifier [0xdfb6c4+10704]
# 	chromedriver!(No symbol) [0xc01ea0]
# 	chromedriver!(No symbol) [0xc4b28a]
# 	chromedriver!(No symbol) [0xc4b52b]
# 	chromedriver!(No symbol) [0xc8d052]
# 	chromedriver!(No symbol) [0xc6d7c4]
# 	chromedriver!(No symbol) [0xc8a936]
# 	chromedriver!(No symbol) [0xc6d516]
# 	chromedriver!(No symbol) [0xc408e9]
# 	chromedriver!(No symbol) [0xc416a4]
# 	chromedriver!GetHandleVerifier [0x1083014+298054]
# 	chromedriver!GetHandleVerifier [0x107e603+293643]
# 	chromedriver!GetHandleVerifier [0x109ea05+2b3a45]
# 	chromedriver!GetHandleVerifier [0xe154e8+2a528]
# 	chromedriver!GetHandleVerifier [0xe1cd1d+31d5d]
# 	chromedriver!GetHandleVerifier [0xe03e68+18ea8]
# 	chromedriver!GetHandleVerifier [0xe04015+19055]
# 	chromedriver!GetHandleVerifier [0xded65f+269f]
# 	KERNEL32!BaseThreadInitThunk [0x75a3fcc9+19]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x773782ae+11e]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x7737827e+ee]
#
# Collected 0 links
#
# Searching: IT companies in Jagtial Jharkhand
# Search Submitted
# Jagtial | IT companies | Scroll 1 -> 16
# Jagtial | IT companies | Scroll 2 -> 20
# Jagtial | IT companies | Scroll 3 -> 22
# Jagtial | IT companies | Scroll 4 -> 22
# Jagtial | IT companies | Scroll 5 -> 22
# Jagtial | IT companies | Scroll 6 -> 22
# Jagtial | IT companies | Scroll 7 -> 22
# Collected 15 links
# Jagtial | 1/15
# SpinTek Solutions
# Phone: 07680059901
# Jagtial | 2/15
# Cloud Tek
# Phone: 09431164991
# Jagtial | 3/15
# M Tech Computers
# Phone: 09440057100
# Jagtial | 4/15
# Csharptek
# Phone: 09334646668
# Jagtial | 5/15
# Eltanin Technologies Pvt Ltd
# Phone: 09948046445
# Jagtial | 6/15
# JOHNSON COMPUTERS
# Phone: 09849845642
# Jagtial | 7/15
# ENCODERS SOFTWARE PRIVATE LIMITED.
# Phone:
# Jagtial | 8/15
# Yashaswi Online Sevices
# Phone: 09493471450
# Jagtial | 9/15
# TECHNIX INDIA
# Phone: 09386013146
# Jagtial | 10/15
# Eagle Technology
# Phone: 09661522005
# Jagtial | 11/15
# MIMEC IT PARK PVT. LTD.
# Phone:
# Jagtial | 12/15
# Tech Infra & VR Solutions Pvt Ltd
# Phone: +97741524821
# Jagtial | 13/15
# AKHILAGYA TECHNOLOGIES
# Phone: 09431948792
# Jagtial | 14/15
# V tech Computers
# Phone: 09030352575
# Jagtial | 15/15
# Jay's Technologie's
# Phone:
#
# Searching: software companies in Jangaon Jharkhand
# Search Submitted
# Scrolling Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@role="feed"]"}
#   (Session info: chrome=148.0.7778.168); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 	chromedriver!GetHandleVerifier [0xdfb593+105d3]
# 	chromedriver!GetHandleVerifier [0xdfb6c4+10704]
# 	chromedriver!(No symbol) [0xc01ea0]
# 	chromedriver!(No symbol) [0xc4b28a]
# 	chromedriver!(No symbol) [0xc4b52b]
# 	chromedriver!(No symbol) [0xc8d052]
# 	chromedriver!(No symbol) [0xc6d7c4]
# 	chromedriver!(No symbol) [0xc8a936]
# 	chromedriver!(No symbol) [0xc6d516]
# 	chromedriver!(No symbol) [0xc408e9]
# 	chromedriver!(No symbol) [0xc416a4]
# 	chromedriver!GetHandleVerifier [0x1083014+298054]
# 	chromedriver!GetHandleVerifier [0x107e603+293643]
# 	chromedriver!GetHandleVerifier [0x109ea05+2b3a45]
# 	chromedriver!GetHandleVerifier [0xe154e8+2a528]
# 	chromedriver!GetHandleVerifier [0xe1cd1d+31d5d]
# 	chromedriver!GetHandleVerifier [0xe03e68+18ea8]
# 	chromedriver!GetHandleVerifier [0xe04015+19055]
# 	chromedriver!GetHandleVerifier [0xded65f+269f]
# 	KERNEL32!BaseThreadInitThunk [0x75a3fcc9+19]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x773782ae+11e]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0
# Jayashankar Bhupalpally | IT companies | Scroll 8 -> 60
# Jayashankar Bhupalpally | IT companies | Scroll 9 -> 68
# Jayashankar Bhupalpally | IT companies | Scroll 10 -> 76
# Jayashankar Bhupalpally | IT companies | Scroll 11 -> 80
# Jayashankar Bhupalpally | IT companies | Scroll 12 -> 88
# Jayashankar Bhupalpally | IT companies | Scroll 13 -> 96
# Jayashankar Bhupalpally | IT companies | Scroll 14 -> 100
# Jayashankar Bhupalpally | IT companies | Scroll 15 -> 108
# Jayashankar Bhupalpally | IT companies | Scroll 16 -> 116
# Jayashankar Bhupalpally | IT companies | Scroll 17 -> 120
# Jayashankar Bhupalpally | IT companies | Scroll 18 -> 120
# Jayashankar Bhupalpally | IT companies | Scroll 19 -> 120
# Jayashankar Bhupalpally | IT companies | Scroll 20 -> 120
# Jayashankar Bhupalpally | IT companies | Scroll 21 -> 120
# Collected 90 links
# Jayashankar Bhupalpally | 1/90
# DigiHelp IT Services LLP
# Phone: 09693232675
# Jayashankar Bhupalpally | 2/90
# Kunal i Technology Lab
# Phone: 09470312947
# Jayashankar Bhupalpally | 3/90
# AYCreation It Services
# Phone:
# Jayashankar Bhupalpally | 4/90
# Webaikon Infotech
# Phone: 07209189151
# Jayashankar Bhupalpally | 5/90
# Tech Support | Best Software company
# Phone:
# Jayashankar Bhupalpally | 6/90
# Stackweb Technology Private Limited
# Phone:
# Jayashankar Bhupalpally | 7/90
# Ionfirm Corporation
# Phone: 08310473451
# Jayashankar Bhupalpally | 8/90
# Home
# Phone:
# Jayashankar Bhupalpally | 9/90
# Jaya Infotech
# Phone:
# Jayashankar Bhupalpally | 10/90
# Computer solution
# Phone:
# Jayashankar Bhupalpally | 11/90
# Software Technology Company
# Phone: 07488187309
# Jayashankar Bhupalpally | 12/90
# WEBD!B IT Services
# Phone: 08093837632
# Jayashankar Bhupalpally | 13/90
# Computer Solution
# Phone:
# Jayashankar Bhupalpally | 14/90
# Raj tech support
# Phone:
# Jayashankar Bhupalpally | 15/90
# Codeskitter Technically Data and Software Solution LLP
# Phone:
# Jayashankar Bhupalpally | 16/90
# Technoverse
# Phone:
# Jayashankar Bhupalpally | 17/90
# Md. Jafirul
# Phone:
# Jayashankar Bhupalpally | 18/90
# Kalicharan khalkho
# Phone:
# Jayashankar Bhupalpally | 19/90
# Sujal bansal
# Phone:
# Jayashankar Bhupalpally | 20/90
# Single line
# Phone:
# Jayashankar Bhupalpally | 21/90
# Parvati Bhawan
# Phone:
# Jayashankar Bhupalpally | 22/90
# NAUSHAD MALLIK LAND
# Phone:
# Jayashankar Bhupalpally | 23/90
# SAI ELECTRIC & TRADING CO. (P) LTD
# Phone:
# Jayashankar Bhupalpally | 24/90
# PAHAN TOLA
# Phone:
# Jayashankar Bhupalpally | 25/90
# Software
# Phone:
# Jayashankar Bhupalpally | 26/90
# Shubh laxmi Enterprises
# Phone:
# Jayashankar Bhupalpally | 27/90
# Jaher Ghutu
# Phone:
# Jayashankar Bhupalpally | 28/90
# Mk Automobiles
# Jayashankar Bhupalpally | 66/90
# Saurav Agarwal शहीद निर्मल महतो मार्ग पुराना बाजार कुजू
# Phone:
# Jayashankar Bhupalpally | 67/90
# Indrajeet singh, Chief Controller, Barkakana
# Phone:
# Jayashankar Bhupalpally | 68/90
# Techally Labs - IT & Software Development Company
# Phone: 09985202223
# Jayashankar Bhupalpally | 69/90
# Ankit plot nabinagar
# Phone:
# Jayashankar Bhupalpally | 70/90
# RITESH HOME
# Phone:
# Jayashankar Bhupalpally | 71/90
# Ray bazar main road
# Phone:
# Jayashankar Bhupalpally | 72/90
# Poresnath temple
# Phone:
# Jayashankar Bhupalpally | 73/90
# Prakash Mobile Centar
# Phone: 07004468191
# Jayashankar Bhupalpally | 74/90
# Gowala toli
# Phone:
# Jayashankar Bhupalpally | 75/90
# Softpal Technologies Pvt Ltd (Corporate Office)
# Phone: 09652168221
# Jayashankar Bhupalpally | 76/90
# Sonu KM
# Phone:
# Jayashankar Bhupalpally | 77/90
# Matuk band party(Prem Kumar)
# Phone:
# Jayashankar Bhupalpally | 78/90
# N.L Singh B.K Singh Bunglow Shekhar
# Phone:
# Jayashankar Bhupalpally | 79/90
# N.Munda House
# Phone:
# Backup Saved
# Jayashankar Bhupalpally | 80/90
# JP's Palace
# Phone:
# Jayashankar Bhupalpally | 81/90
#
# Phone:
# Jayashankar Bhupalpally | 82/90
# TravelX World
# Phone:
# Jayashankar Bhupalpally | 83/90
# Shamshad ansari home
# Phone:
# Jayashankar Bhupalpally | 84/90
# Hasan hose
# Phone:
# Jayashankar Bhupalpally | 85/90
# Jamnidih
# Phone:
# Jayashankar Bhupalpally | 86/90
# Jagdish Bediya Home
# Phone:
# Jayashankar Bhupalpally | 87/90
# Sanjay
# Phone:
# Jayashankar Bhupalpally | 88/90
# Sitan Saw Home
# Phone:
# Jayashankar Bhupalpally | 89/90
# Sahu Dhabha and Indian Chineese
# Phone:
# Jayashankar Bhupalpally | 90/90
# CHIEF HOUSE DOTALLA,sayal
# Phone:
#
# Searching: software companies in Jogulamba Gadwal Jharkhand
# Search Submitted
# Jogulamba Gadwal | software companies | Scroll 1 -> 13
# Jogulamba Gadwal | software companies | Scroll 2 -> 13
# Jogulamba Gadwal | software companies | Scroll 3 -> 13
# Jogulamba Gadwal | software companies | Scroll 4 -> 13
# Jogulamba Gadwal | software companies | Scroll 5 -> 13
# Collected 8 links
# Jogulamba Gadwal | 1/8
# Symbosys - Software Company in Ranchi
# Phone: 07992202650
# Jogulamba Gadwal | 2/8
# Soft Software Development
# Phone: 09631575741
# Jogulamba Gadwal | 3/8
# NP Softhub Solutions pvt ltd
# Phone: 09431328027
# Jogulamba Gadwal | 4/8
# Dryft Dynamics (Head Office)
# Phone: 09709045796
# Jogulamba Gadwal | 5/8
# Ten Software
# Phone: 09234434490
# Jogulamba Gadwal | 6/8
# Biyoans PVT. LTD
# Phone:
# Jogulamba Gadwal | 7/8
# Savoir(Explore Technology)
# Phone: 09334326671
# Jogulamba Gadwal | 8/8
# Jaihind Software
# Phone: 09939755135
#
# Searching: IT companies in Jogulamba Gadwal Jharkhand
# Search Submitted
# Jogulamba Gadwal | IT companies | Scroll 1 -> 16
# Jogulamba Gadwal | IT companies | Scroll 2 -> 20
# Jogulamba Gadwal | IT companies | Scroll 3 -> 28
# Jogulamba Gadwal | IT companies | Scroll 4 -> 28
# Jogulamba Gadwal | IT companies | Scroll 5 -> 28
# Jogulamba Gadwal | IT companies | Scroll 6 -> 28
# Jogulamba Gadwal | IT companies | Scroll 7 -> 28
# Collected 14 links
# Jogulamba Gadwal | 1/14
# WEBOTAL IT GLOBAL PRIVATE LIMITED
# Phone: 08789776787
# Jogulamba Gadwal | 2/14
# Paythrough Softwares and Solutions Pvt Ltd,
# Phone: 08298539539
# Jogulamba Gadwal | 3/14
# NathCorp
# Phone: 06512240348
# Jogulamba Gadwal | 4/14
# Uinfo technology pvt. ltd.
# Phone: 08207774444
# Jogulamba Gadwal | 5/14
# RV web
# Phone: 09031777877
# Jogulamba Gadwal | 6/14
# Srijan Services
# Phone: 09576409795
# Jogulamba Gadwal | 7/14
# Aeronspire Technology
# Phone: 07762820555
# Jogulamba Gadwal | 8/14
# REXEON SOLUTIONS - Food & Water Testing Company In Dhanbad
# Phone: 09661480713
# Jogulamba Gadwal | 9/14
# Rk tech solutions
# Phone:
# Jogulamba Gadwal | 10/14
# Mahvish Techline
# Phone: 08986711508
# Jogulamba Gadwal | 11/14
# Hindusthan Mining Research and Development Pvt. Ltd
# Phone:
# Jogulamba Gadwal | 12/14
# ADMK & Associates - Chartered Accountant in Dhanbad/ CA in Dhanbad/ CA Firm
# Phone: 07677708889
# Jogulamba Gadwal | 13/14
# RP Digital Marketing Solutions
# Phone:
# Jogulamba Gadwal | 14/14
# SBHUB Online– Website Designer in Dhanbad
# Phone: 09123426393
#
# Searching: software companies in Kamareddy Jharkhand
# Search Submitted
# Kamareddy | software companies | Scroll 1 -> 14
# Kamareddy | software companies | Scroll 2 -> 14
# Kamareddy | software companies | Scroll 3 -> 14
# Kamareddy | software companies | Scroll 4 -> 14
# Kamareddy | software companies | Scroll 5 -> 14
# Collected 3 links
# Kamareddy | 1/3
# AbhiTech Solutions
# Phone: 06206782017
# Kamareddy | 2/3
# Dryft Dynamics (Ranchi Branch Office)
# Phone: 07079252889
# Kamareddy | 3/3
# Jaihind Software
# Phone: 09939755135
#
# Searching: IT companies in Kamareddy Jharkhand
# Search Submitted
# Kamareddy | IT companies | Scroll 1 -> 3
# Kamareddy | IT companies | Scroll 2 -> 3
# Kamareddy | IT companies | Scroll 3 -> 3
# Kamareddy | IT companies | Scroll 4 -> 3
# Kamareddy | IT companies | Scroll 5 -> 3
# Collected 2 links
# Kamareddy | 1/2
# EXIST TECH COMPUTERS
# Phone: 08008070500
# Kamareddy | 2/2
# Exist Tech Computers
# Phone:
#
# Searching: software companies in Karimnagar Jharkhand
# Search Submitted
# Karimnagar | software companies | Scroll 1 -> 14
# Karimnagar | software companies | Scroll 2 -> 14
# Karimnagar | software companies | Scroll 3 -> 14
# Karimnagar | software companies | Scroll 4 -> 14
# Karimnagar | software companies | Scroll 5 -> 14
# Collected 14 links
# Karimnagar | 1/14
# Aspectsites Technologies Pvt Ltd
# Phone: 09949705555
# Karimnagar | 2/14
# Twelve it solutions
# Phone: 09885531674
# Karimnagar | 3/14
# Elite Idea Solutions India Private Limited
# Phone: 09052800005
# Karimnagar | 4/14
# Cyrostack It Solutions (OPC) Pvt Ltd
# Phone: 08919682031
# Karimnagar | 5/14
# Vita Technologies
# Phone: 08008890270
# Karimnagar | 6/14
# arky technologies | vARKY TECHNOLOGY SOLUTIONS PVT LTD
# Phone: 08106594769
# Karimnagar | 7/14
# VARAHA SOFTWARE SOLUTIONS
# Phone: 09030605446
# Karimnagar | 8/14
# Praveen Nayak technologies Pvt Ltd
# Phone: 08008877585
# Karimnagar | 9/14
# Executive Softway Guild India Pvt Ltd
# Phone: 09739555537
# Karimnagar | 10/14
# Falcon Informatics
# Phone:
# Karimnagar | 11/14
# Annexacc software solutions india private limited
# Phone: 08446800143
# Karimnagar | 12/14
# CloudBridge Software Solutions
# Phone: 09705165116
# Karimnagar | 13/14
# SVAPPS SOFT SOLUTIONS PVT. LTD.
# Phone:
# Karimnagar | 14/14
# Softtech Systems
# Phone:
#
# Searching: IT companies in Karimnagar Jharkhand
# Search Submitted
# Karimnagar | IT companies | Scroll 1 -> 13
# Karimnagar | IT companies | Scroll 2 -> 13
# Karimnagar | IT companies | Scroll 3 -> 13
# Karimnagar | IT companies | Scroll 4 -> 13
# Karimnagar | IT companies | Scroll 5 -> 13
# Collected 2 links
# Karimnagar | 1/2
# Tek Genie Services Private Limited
# Phone: 09063793929
# Karimnagar | 2/2
# ClusterIT business solutions
# Phone: 07569816025
#
# Searching: software companies in Khammam Jharkhand
# Search Submitted
# Khammam | software companies | Scroll 1 -> 11
# Khammam | software companies | Scroll 2 -> 11
# Khammam | software companies | Scroll 3 -> 11
# Khammam | software companies | Scroll 4 -> 11
# Khammam | software companies | Scroll 5 -> 11
# Collected 11 links
# Khammam | 1/11
# T-hub it solutions
# Phone: 09966407407
# Khammam | 2/11
# Thara Info Tech Solutions Pvt. Ltd.
# Phone: 09502131327
# Khammam | 3/11
# Technogen India Pvt Ltd - Khammam
# Phone: 09100088093
# Khammam | 4/11
# Suvidha Software Solutions
# Phone: 09492512345
# Khammam | 5/11
# Lithan Technologies
# Phone: 07416417634
# Khammam | 6/11
# IT Hub Khammam
# Phone:
# Khammam | 7/11
# Neoistone Technologies LLP
# Phone: 07981490056
# Khammam | 8/11
# Vardhan Systems
# Phone:
# Khammam | 9/11
# Solvency Software Solutions
# Phone:
# Khammam | 10/11
# KK IT Solutions
# Phone: 07386740494
# Khammam | 11/11
# PVR Tec Software Solutions
# Phone: 07075330758
#
# Searching: IT companies in Khammam Jharkhand
# Search Submitted
# Khammam | IT companies | Scroll 1 -> 16
# Khammam | IT companies | Scroll 2 -> 20
# Khammam | IT companies | Scroll 3 -> 28
# Khammam | IT companies | Scroll 4 -> 34
# Khammam | IT companies | Scroll 5 -> 34
# Khammam | IT companies | Scroll 6 -> 34
# Khammam | IT companies | Scroll 7 -> 34
# Khammam | IT companies | Scroll 8 -> 34
# Collected 20 links
# Khammam | 1/20
# Vistawave Technologies - Web Design & Digital Marketing Services in Khammam
# Phone: 09133626666
# Khammam | 2/20
# Roshni Software Solutions
# Phone:
# Khammam | 3/20
# V2 IT Solutions Pvt Ltd
# Phone: 09492368806
# Khammam | 4/20
# Venkys Computers
# Phone: 08886661964
# Khammam | 5/20
# Techwave
# Phone:
# Khammam | 6/20
# Cluster IT Solutions Pvt Ltd
# Phone: 07095601275
# Khammam | 7/20
# KARTHIKA SOFTWARE SOLUTION
# Phone: 09581412453
# Khammam | 8/20
# Techwave
# Phone:
# Khammam | 9/20
# Bit Computers
# Phone: 09059101016
# Khammam | 10/20
# IT Solutions
# Phone:
# Khammam | 11/20
# INeptunex Outsourcing Solutions
# Phone:
# Khammam | 12/20
# MS Computers
# Phone:
# Khammam | 13/20
# Battineni’s Technopolis
# Phone:
# Khammam | 14/20
# MEsoftech IT Services
# Phone:
# Khammam | 15/20
# DTDC COURIER KHAMMAM INTERNATIONAL
# Phone: 08742226001
# Khammam | 16/20
# VS Internet
# Phone: 09866870171
# Khammam | 17/20
# Amit Dumka
# Phone: 07739219114
# Khammam | 18/20
# Sunil Computer Job Works
# Phone: 07386123578
# Khammam | 19/20
# Techqflow Software Khammam
# Phone: 09121167471
# Khammam | 20/20
# Nestha IT Services Pvt. Ltd.
# Phone:
#
# Searching: software companies in Komaram Bheem Asifabad Jharkhand
# Search Submitted
# Komaram Bheem Asifabad | software companies | Scroll 1 -> 9
# Komaram Bheem Asifabad | software companies | Scroll 2 -> 9
# Komaram Bheem Asifabad | software companies | Scroll 3 -> 9
# Komaram Bheem Asifabad | software companies | Scroll 4 -> 9
# Komaram Bheem Asifabad | software companies | Scroll 5 -> 9
# Collected 3 links
# Komaram Bheem Asifabad | 1/3
# InnoBzeetech Technologies Pvt. Ltd.
# Phone: 06201560301
# Komaram Bheem Asifabad | 2/3
# ISESoftWorld - Web Design | Website Design | Mobile App Development Company in Jamshedpur
# Phone: 08789232696
# Komaram Bheem Asifabad | 3/3
# A software company
# Phone:
#
# Searching: IT companies in Komaram Bheem Asifabad Jharkhand
# Search Submitted
# Komaram Bheem Asifabad | IT companies | Scroll 1 -> 16
# Komaram Bheem Asifabad | IT companies | Scroll 2 -> 20
# Komaram Bheem Asifabad | IT companies | Scroll 3 -> 28
# Komaram Bheem Asifabad | IT companies | Scroll 4 -> 36
# Komaram Bheem Asifabad | IT companies | Scroll 5 -> 40
# Komaram Bheem Asifabad | IT companies | Scroll 6 -> 48
# Komaram Bheem Asifabad | IT companies | Scroll 7 -> 56
# Komaram Bheem Asifabad | IT companies | Scroll 8 -> 60
# Komaram Bheem Asifabad | IT companies | Scroll 9 -> 68
# Komaram Bheem Asifabad | IT companies | Scroll 10 -> 76
# Komaram Bheem Asifabad | IT companies | Scroll 11 -> 80
# Komaram Bheem Asifabad | IT companies | Scroll 12 -> 83
# Komaram Bheem Asifabad | IT companies | Scroll 13 -> 83
# Komaram Bheem Asifabad | IT companies | Scroll 14 -> 83
# Komaram Bheem Asifabad | IT companies | Scroll 15 -> 83
# Komaram Bheem Asifabad | IT companies | Scroll 16 -> 83
# Collected 64 links
# Komaram Bheem Asifabad | 1/64
# IQ Software Technology - Website Design & Mobile Application Development
# Phone: 08002182249
# Komaram Bheem Asifabad | 2/64
# Hyper Web Solution
# Phone: 07779990599
# Komaram Bheem Asifabad | 3/64
# Appizum Technologies
# Phone: 07827249199
# Komaram Bheem Asifabad | 4/64
# Naim Sheikh
# Phone:
# Komaram Bheem Asifabad | 5/64
# RIZWAN HOUSE(Baghpinjra)
# Phone:
# Komaram Bheem Asifabad | 6/64
# Arambh Softech
# Phone: 06207753704
# Komaram Bheem Asifabad | 7/64
# Government
# Phone:
# ...
# Nizamabad | IT companies | Scroll 6 -> 39
# Nizamabad | IT companies | Scroll 7 -> 39
# Nizamabad | IT companies | Scroll 8 -> 39
# Nizamabad | IT companies | Scroll 9 -> 39
# Collected 25 links
# Nizamabad | 1/25
# USA SOFT SYSTEMS India Pvt Ltd
# Phone: 09912860391
# Nizamabad | 2/25
# Zetratech IT Solutions
# Phone: 08790014396
# Nizamabad | 3/25
# osss consulting services india pvt. ltd
# Phone:
# Nizamabad | 4/25
# SHREES TECHNOLOGIES & COMPUTER TRAINING CENTRE
# Phone: 09848751051
# Nizamabad | 5/25
# Premier IT Solutions
# Phone: 07893536500
# Nizamabad | 6/25
# IT HUB Nizamabad
# Phone:
# Nizamabad | 7/25
# ATS Computers
# Phone: 08686605143
# Nizamabad | 8/25
# LINK COMPUTERS
# Phone: 09849074389
# Nizamabad | 9/25
# iNet
# Phone: 09395528881
# Nizamabad | 10/25
# Future Tech Computers
# Phone: 09885657321
# Nizamabad | 11/25
# LINK COMPUTERS (Kanteshwar Branch)
# Phone: 09849074389
# Nizamabad | 12/25
# Hi-Tech Mahadev Computer Sales&Services
# Phone: 08309686247
# Nizamabad | 13/25
# NIZAMABAD Online
# Phone:
# Nizamabad | 14/25
# Yendala Towers
# Phone:
# Nizamabad | 15/25
# Nitya Technical and computer Institute
# Phone:
# Nizamabad | 16/25
# Navadurga online service &DTP job works
# Phone: 09603662226
# Nizamabad | 17/25
# SKT COMPUTERS
# Phone: 09866969899
# Nizamabad | 18/25
# SRR INFOTECH
# Phone:
# Nizamabad | 19/25
# 9 Technology Services
# Phone: 09291331751
# Nizamabad | 20/25
# VISHAL COMPUTER SERVICES
# Phone: 09346031384
# Nizamabad | 21/25
# SV COMPUTERS
# Phone: 08639137500
# Nizamabad | 22/25
# Online Services Centre
# Phone: 09494782809
# Nizamabad | 23/25
# COMPUTER SALES AND SERVICE
# Phone: 08096762658
# Nizamabad | 24/25
# iTechTrends Soft Solutions
# Phone: 07780383818
# Nizamabad | 25/25
# Web orders
# Phone:
#
# Searching: software companies in Peddapalli Jharkhand
# Search Submitted
# Peddapalli | software companies | Scroll 1 -> 9
# Peddapalli | software companies | Scroll 2 -> 9
# Peddapalli | software companies | Scroll 3 -> 9
# Peddapalli | software companies | Scroll 4 -> 9
# Peddapalli | software companies | Scroll 5 -> 9
# Collected 0 links
#
# Searching: IT companies in Peddapalli Jharkhand
# Search Submitted
# Peddapalli | IT companies | Scroll 1 -> 8
# Peddapalli | IT companies | Scroll 2 -> 8
# Peddapalli | IT companies | Scroll 3 -> 8
# Peddapalli | IT companies | Scroll 4 -> 8
# Peddapalli | IT companies | Scroll 5 -> 8
# Collected 2 links
# Peddapalli | 1/2
# RCK Infosystem Private Limited
# Phone: 07992486102
# Peddapalli | 2/2
# IT Maniacs
# Phone: 09608333033
#
# Searching: software companies in Rajanna Sircilla Jharkhand
# Search Submitted
# Rajanna Sircilla | software companies | Scroll 1 -> 12
# Rajanna Sircilla | software companies | Scroll 2 -> 12
# Rajanna Sircilla | software companies | Scroll 3 -> 12
# Rajanna Sircilla | software companies | Scroll 4 -> 12
# Rajanna Sircilla | software companies | Scroll 5 -> 12
# Collected 0 links
#
# Searching: IT companies in Rajanna Sircilla Jharkhand
# Search Submitted
# Rajanna Sircilla | IT companies | Scroll 1 -> 16
# Rajanna Sircilla | IT companies | Scroll 2 -> 20
# Rajanna Sircilla | IT companies | Scroll 3 -> 28
# Rajanna Sircilla | IT companies | Scroll 4 -> 36
# Rajanna Sircilla | IT companies | Scroll 5 -> 40
# Rajanna Sircilla | IT companies | Scroll 6 -> 42
# Rajanna Sircilla | IT companies | Scroll 7 -> 42
# Rajanna Sircilla | IT companies | Scroll 8 -> 42
# Rajanna Sircilla | IT companies | Scroll 9 -> 42
# Rajanna Sircilla | IT companies | Scroll 10 -> 42
# Collected 8 links
# Rajanna Sircilla | 1/8
# Citizen Technology IT Services and Solution
# Phone: 06201272901
# Rajanna Sircilla | 2/8
# Ranchi IT Services
# Phone: 08789453656
# Rajanna Sircilla | 3/8
# IT Firm (Complete IT Solution Provider)
# Phone: 09354255998
# Rajanna Sircilla | 4/8
# S R TECHNICAL SERVICES
# Phone: 07970806349
# Rajanna Sircilla | 5/8
# Technoshila IT Services
# Phone: 08651019018
# Rajanna Sircilla | 6/8
# Shidhharth Infotech
# Phone: 08810228809
# Rajanna Sircilla | 7/8
# Srijan IT Solution
# Phone:
# Rajanna Sircilla | 8/8
# IT SOLUTION
# Phone: 09430380551
#
# Searching: software companies in Ranga Reddy Jharkhand
# Search Submitted
# Ranga Reddy | software companies | Scroll 1 -> 16
# Ranga Reddy | software companies | Scroll 2 -> 20
# Ranga Reddy | software companies | Scroll 3 -> 22
# Ranga Reddy | software companies | Scroll 4 -> 22
# Ranga Reddy | software companies | Scroll 5 -> 22
# Ranga Reddy | software companies | Scroll 6 -> 22
# Ranga Reddy | software companies | Scroll 7 -> 22
# Collected 2 links
# Ranga Reddy | 1/2
# BHIPRA SOFTWARE SOLUTION PVT LTD
# Phone: 07004951559
# Ranga Reddy | 2/2
# Dzinex Technologies : Internship program/ full stack development
# Phone: 07091771074
#
# Searching: IT companies in Ranga Reddy Jharkhand
# Search Submitted
# Ranga Reddy | IT companies | Scroll 1 -> 16
# Ranga Reddy | IT companies | Scroll 2 -> 20
# Ranga Reddy | IT companies | Scroll 3 -> 28
# Ranga Reddy | IT companies | Scroll 4 -> 36
# Ranga Reddy | IT companies | Scroll 5 -> 40
# Ranga Reddy | IT companies | Scroll 6 -> 48
# Ranga Reddy | IT companies | Scroll 7 -> 56
# Ranga Reddy | IT companies | Scroll 8 -> 60
# Ranga Reddy | IT companies | Scroll 9 -> 60
# Ranga Reddy | IT companies | Scroll 10 -> 60
# Ranga Reddy | IT companies | Scroll 11 -> 60
# Ranga Reddy | IT companies | Scroll 12 -> 60
# Collected 22 links
# Ranga Reddy | 1/22
# The Rogue Pixxel IT Solutions
# Phone: 09608808008
# Ranga Reddy | 2/22
# Hands In Next Tech Pvt. Ltd
# Phone: 08235493083
# Ranga Reddy | 3/22
# RaghuvarTech
# Phone: 09810375969
# Ranga Reddy | 4/22
# Jharkhand Technology Pvt. Ltd.
# Phone: 09431581700
# Ranga Reddy | 5/22
# TechXquad
# Phone: 08987646658
# Ranga Reddy | 6/22
# Ranchi Technosolutions Pvt Ltd - System Integrator and Service Provider in Ranchi
# Phone: 06512223454
# Ranga Reddy | 7/22
# RELUHASH.AI PVT LTD
# Phone: 09415856400
# Ranga Reddy | 8/22
# Web Developer Rana
# Phone: 07296057110
# Ranga Reddy | 9/22
# RIWEBS Web Solution Company
# Phone: 09304296671
# Ranga Reddy | 10/22
# Rig Infotech
# Phone:
# Ranga Reddy | 11/22
# RAMTECH SOFTWARE SOLUTIONS LTD(NETWORKING )
# Phone:
# Ranga Reddy | 12/22
# Vishvena Techno Solutions
# Phone: 09663089241
# Backup Saved
# Ranga Reddy | 13/22
# Rajasri Infotech
# Phone: 04040246809
# Ranga Reddy | 14/22
# Ray Software Pvt. Ltd.
# Phone: 09001751074
# Ranga Reddy | 15/22
# RAN INFOTECH
# Phone: 08582082212
# Ranga Reddy | 16/22
# Raghav IT Solution Service
# Phone: 09570805386
# Ranga Reddy | 17/22
# RG Infotech: Top Website & Mobile App Development Company in Jaipur, India
# Phone: 06376061123
# Ranga Reddy | 18/22
# RBS INFOTECH SOLUTIONS
# Phone:
# Ranga Reddy | 19/22
# InfoStretch Corporation (India) Pvt. Ltd
# Phone: 02067287800
# Ranga Reddy | 20/22
# Mitroz Technologies
# Phone: 08793726418
# Ranga Reddy | 21/22
# Raiver infotech pvt ltd
# Phone:
# Ranga Reddy | 22/22
# Radiant Infosystems
# Phone: 08102209700
#
# Searching: software companies in Sangareddy Jharkhand
# Search Submitted
# Sangareddy | software companies | Scroll 1 -> 3
# Sangareddy | software companies | Scroll 2 -> 3
# Sangareddy | software companies | Scroll 3 -> 3
# Sangareddy | software companies | Scroll 4 -> 3
# Sangareddy | software companies | Scroll 5 -> 3
# Collected 1 links
# Sangareddy | 1/1
# TechBridge Technologies
# Phone: 09666622269
#
# Searching: IT companies in Sangareddy Jharkhand
# Search Submitted
# Sangareddy | IT companies | Scroll 1 -> 6
# Sangareddy | IT companies | Scroll 2 -> 6
# Sangareddy | IT companies | Scroll 3 -> 6
# Sangareddy | IT companies | Scroll 4 -> 6
# Sangareddy | IT companies | Scroll 5 -> 6
# Collected 1 links
# Sangareddy | 1/1
# IT SERVICES
# Phone:
#
# Searching: software companies in Siddipet Jharkhand
# Search Submitted
# Siddipet | software companies | Scroll 1 -> 3
# Siddipet | software companies | Scroll 2 -> 3
# Siddipet | software companies | Scroll 3 -> 3
# Siddipet | software companies | Scroll 4 -> 3
# Siddipet | software companies | Scroll 5 -> 3
# Collected 2 links
# Siddipet | 1/2
# Techyz Innovative Trainings Pv. Ltd.
# Phone: 08555830959
# Siddipet | 2/2
# Citrux Technologies
# Phone: 09640960696
#
# Searching: IT companies in Siddipet Jharkhand
# Search Submitted
# Siddipet | IT companies | Scroll 1 -> 8
# Siddipet | IT companies | Scroll 2 -> 8
# Siddipet | IT companies | Scroll 3 -> 8
# Siddipet | IT companies | Scroll 4 -> 8
# Siddipet | IT companies | Scroll 5 -> 8
# Collected 4 links
# Siddipet | 1/4
# ShivNet Technology
# Phone: 09102635333
# Siddipet | 2/4
# Siddsoft IT Solutions Pvt Ltd
# Phone: 09962788029
# Siddipet | 3/4
# Siddipet IT tower
# Phone: 08121202646
# Siddipet | 4/4
# SPY IT SOLUTIONS
# Phone:
#
# Searching: software companies in Suryapet Jharkhand
# Search Submitted
# Suryapet | software companies | Scroll 1 -> 16
# Suryapet | software companies | Scroll 2 -> 17
# Suryapet | software companies | Scroll 3 -> 17
# Suryapet | software companies | Scroll 4 -> 17
# Suryapet | software companies | Scroll 5 -> 17
# Suryapet | software companies | Scroll 6 -> 17
# Collected 1 links
# Suryapet | 1/1
# Solver solutions GST ERP software company
# Phone: 08986889657
#
# Searching: IT companies in Suryapet Jharkhand
# Search Submitted
# Suryapet | IT companies | Scroll 1 -> 3
# Suryapet | IT companies | Scroll 2 -> 3
# Suryapet | IT companies | Scroll 3 -> 3
# Suryapet | IT companies | Scroll 4 -> 3
# Suryapet | IT companies | Scroll 5 -> 3
# Collected 1 links
# Suryapet | 1/1
# AYAN COMPUTER'S
# Phone:
#
# Searching: software companies in Vikarabad Jharkhand
# Search Submitted
# Scrolling Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@role="feed"]"}
#   (Session info: chrome=148.0.7778.168); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 	chromedriver!GetHandleVerifier [0xdfb593+105d3]
# 	chromedriver!GetHandleVerifier [0xdfb6c4+10704]
# 	chromedriver!(No symbol) [0xc01ea0]
# 	chromedriver!(No symbol) [0xc4b28a]
# 	chromedriver!(No symbol) [0xc4b52b]
# 	chromedriver!(No symbol) [0xc8d052]
# 	chromedriver!(No symbol) [0xc6d7c4]
# 	chromedriver!(No symbol) [0xc8a936]
# 	chromedriver!(No symbol) [0xc6d516]
# 	chromedriver!(No symbol) [0xc408e9]
# 	chromedriver!(No symbol) [0xc416a4]
# 	chromedriver!GetHandleVerifier [0x1083014+298054]
# 	chromedriver!GetHandleVerifier [0x107e603+293643]
# 	chromedriver!GetHandleVerifier [0x109ea05+2b3a45]
# 	chromedriver!GetHandleVerifier [0xe154e8+2a528]
# 	chromedriver!GetHandleVerifier [0xe1cd1d+31d5d]
# 	chromedriver!GetHandleVerifier [0xe03e68+18ea8]
# 	chromedriver!GetHandleVerifier [0xe04015+19055]
# 	chromedriver!GetHandleVerifier [0xded65f+269f]
# 	KERNEL32!BaseThreadInitThunk [0x75a3fcc9+19]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x773782ae+11e]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x7737827e+ee]
#
# Collected 0 links
#
# Searching: IT companies in Vikarabad Jharkhand
# Search Submitted
# Scrolling Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@role="feed"]"}
#   (Session info: chrome=148.0.7778.168); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 	chromedriver!GetHandleVerifier [0xdfb593+105d3]
# 	chromedriver!GetHandleVerifier [0xdfb6c4+10704]
# 	chromedriver!(No symbol) [0xc01ea0]
# 	chromedriver!(No symbol) [0xc4b28a]
# 	chromedriver!(No symbol) [0xc4b52b]
# 	chromedriver!(No symbol) [0xc8d052]
# 	chromedriver!(No symbol) [0xc6d7c4]
# 	chromedriver!(No symbol) [0xc8a936]
# 	chromedriver!(No symbol) [0xc6d516]
# 	chromedriver!(No symbol) [0xc408e9]
# 	chromedriver!(No symbol) [0xc416a4]
# 	chromedriver!GetHandleVerifier [0x1083014+298054]
# 	chromedriver!GetHandleVerifier [0x107e603+293643]
# 	chromedriver!GetHandleVerifier [0x109ea05+2b3a45]
# 	chromedriver!GetHandleVerifier [0xe154e8+2a528]
# 	chromedriver!GetHandleVerifier [0xe1cd1d+31d5d]
# 	chromedriver!GetHandleVerifier [0xe03e68+18ea8]
# 	chromedriver!GetHandleVerifier [0xe04015+19055]
# 	chromedriver!GetHandleVerifier [0xded65f+269f]
# 	KERNEL32!BaseThreadInitThunk [0x75a3fcc9+19]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x773782ae+11e]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x7737827e+ee]
#
# Collected 0 links
#
# Searching: software companies in Wanaparthy Jharkhand
# Search Submitted
# Wanaparthy | software companies | Scroll 1 -> 12
# Wanaparthy | software companies | Scroll 2 -> 12
# Wanaparthy | software companies | Scroll 3 -> 12
# Wanaparthy | software companies | Scroll 4 -> 12
# Wanaparthy | software companies | Scroll 5 -> 12
# Collected 0 links
#
# Searching: IT companies in Wanaparthy Jharkhand
# Search Submitted
# Scrolling Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@role="feed"]"}
#   (Session info: chrome=148.0.7778.168); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 	chromedriver!GetHandleVerifier [0xdfb593+105d3]
# 	chromedriver!GetHandleVerifier [0xdfb6c4+10704]
# 	chromedriver!(No symbol) [0xc01ea0]
# 	chromedriver!(No symbol) [0xc4b28a]
# 	chromedriver!(No symbol) [0xc4b52b]
# 	chromedriver!(No symbol) [0xc8d052]
# 	chromedriver!(No symbol) [0xc6d7c4]
# 	chromedriver!(No symbol) [0xc8a936]
# 	chromedriver!(No symbol) [0xc6d516]
# 	chromedriver!(No symbol) [0xc408e9]
# 	chromedriver!(No symbol) [0xc416a4]
# 	chromedriver!GetHandleVerifier [0x1083014+298054]
# 	chromedriver!GetHandleVerifier [0x107e603+293643]
# 	chromedriver!GetHandleVerifier [0x109ea05+2b3a45]
# 	chromedriver!GetHandleVerifier [0xe154e8+2a528]
# 	chromedriver!GetHandleVerifier [0xe1cd1d+31d5d]
# 	chromedriver!GetHandleVerifier [0xe03e68+18ea8]
# 	chromedriver!GetHandleVerifier [0xe04015+19055]
# 	chromedriver!GetHandleVerifier [0xded65f+269f]
# 	KERNEL32!BaseThreadInitThunk [0x75a3fcc9+19]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x773782ae+11e]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x7737827e+ee]
#
# Collected 0 links
#
# Searching: software companies in Warangal Jharkhand
# Search Submitted
# Warangal | software companies | Scroll 1 -> 9
# Warangal | software companies | Scroll 2 -> 9
# Warangal | software companies | Scroll 3 -> 9
# Warangal | software companies | Scroll 4 -> 9
# Warangal | software companies | Scroll 5 -> 9
# Collected 1 links
# Warangal | 1/1
# Webcrics IT Solutions
# Phone: 07675025996
#
# Searching: IT companies in Warangal Jharkhand
# Search Submitted
# Warangal | IT companies | Scroll 1 -> 16
# Warangal | IT companies | Scroll 2 -> 20
# Warangal | IT companies | Scroll 3 -> 28
# Warangal | IT companies | Scroll 4 -> 33
# Warangal | IT companies | Scroll 5 -> 33
# Warangal | IT companies | Scroll 6 -> 33
# Warangal | IT companies | Scroll 7 -> 33
# Warangal | IT companies | Scroll 8 -> 33
# Collected 15 links
# Warangal | 1/15
# Digiyoda IT Hub Warangal
# Phone:
# Warangal | 2/15
# Logicview IT Solutions Pvt Ltd
# Phone: 07207853825
# Warangal | 3/15
# Arete IT Services Pvt Ltd
# Phone: 09390009397
# Warangal | 4/15
# Magnify IT Private Limited
# Phone: 08886663643
# Warangal | 5/15
# SRUVI IT SOLUTIONS PRIVATE LIMITED
# Phone:
# Warangal | 6/15
# MarrsElite InfoSystems Pvt Ltd
# Phone: 08707965141
# Warangal | 7/15
# FUTECH IT SOFTWARE SOLUTIONS PVT LTD
# Phone: 09347165927
# Warangal | 8/15
# Ignite Labs
# Phone: 09494644848
# Warangal | 9/15
# SPACE INTERNET
# Phone: 08686023231
# Warangal | 10/15
# VM Software Solutions
# Phone: 09703757270
# Warangal | 11/15
# Gadgetz Tech Solution
# Phone:
# Warangal | 12/15
# RK Packers & Movers Warangal
# Phone: 08179310451
# Warangal | 13/15
# Srisaicomputers and online services
# Phone: 09493040958
# Warangal | 14/15
# Ankosoft Technologies Warangal
# Phone: 07755538316
# Warangal | 15/15
# AV Infosys
# Phone:
#
# Searching: software companies in Yadadri Bhuvanagiri Jharkhand
# Search Submitted
# Yadadri Bhuvanagiri | software companies | Scroll 1 -> 3
# Yadadri Bhuvanagiri | software companies | Scroll 2 -> 3
# Yadadri Bhuvanagiri | software companies | Scroll 3 -> 3
# Yadadri Bhuvanagiri | software companies | Scroll 4 -> 3
# Yadadri Bhuvanagiri | software companies | Scroll 5 -> 3
# Collected 1 links
# Yadadri Bhuvanagiri | 1/1
# HEXIRE INFORMATICS PVT LTD
# Phone: 09654348543
#
# Searching: IT companies in Yadadri Bhuvanagiri Jharkhand
# Search Submitted
# Yadadri Bhuvanagiri | IT companies | Scroll 1 -> 3
# Yadadri Bhuvanagiri | IT companies | Scroll 2 -> 3
# Yadadri Bhuvanagiri | IT companies | Scroll 3 -> 3
# Yadadri Bhuvanagiri | IT companies | Scroll 4 -> 3
# Yadadri Bhuvanagiri | IT companies | Scroll 5 -> 3
# Collected 0 links
#
# Extraction Completed
# Total Companies Extracted: 837
#
# Saved File: jharkhand_companies.csv
