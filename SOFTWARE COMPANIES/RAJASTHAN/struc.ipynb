# %%
import pandas as pd

# %%
df1 = pd.read_csv("rajasthan_companies0.csv")
df2 = pd.read_csv("rajasthan_companies.csv")
df=pd.concat([df1,df2], ignore_index=True)

# %%
df.shape
# Out:
# (4299, 8)

# %%
df = df[
    df["Phone"].notna() & 
    (df["Phone"].astype(str).str.strip() != "")
    ]
df.shape
# Out:
# (3211, 8)

# %%
df = df[
    df["Company Name"].notna()
    ]

df = df[
    df["Company Name"].str.strip() != ""
    ]
df.shape
# Out:
# (3160, 8)

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]","",regex=True)
    .str.strip()
)

display(df[["Phone"]].head())
# Out:
#          Phone
# 0  09214839374
# 1  09252089089
# 2  09829152312
# 3  09166638749
# 4  08690693835

# %%
df.to_csv(
    "rajasthan_companies_cleaned.csv",
    index=False
)
