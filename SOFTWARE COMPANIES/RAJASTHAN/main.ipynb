# %%
import time
import random
import pandas as pd

from datetime import datetime

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.service import Service

from webdriver_manager.chrome import ChromeDriverManager


districts = [
    "Phalodi",
    "Pratapgarh",
    "Rajsamand",
    "Salumbar",
    "Sanchore",
    "Sawai Madhopur",
    "Shahpura",
    "Sikar",
    "Sirohi",
    "Sri Ganganagar",
    "Tonk",
    "Udaipur"
]



search_types = [
    "software companies",
    "IT companies"
]

options = webdriver.ChromeOptions()

options.add_argument("--start-maximized")

options.add_argument(
    "--disable-blink-features=AutomationControlled"
)

options.add_argument("--disable-notifications")


driver = webdriver.Chrome(

    service=Service(
        ChromeDriverManager().install()
    ),

    options=options
)

driver.get("https://www.google.com/maps")

print("Opening Google Maps...")

time.sleep(15)

print("Google Maps Loaded")


all_data = []

visited_links = set()


def get_search_box():

    selectors = [

        '//input[@id="searchboxinput"]',
        '//input[contains(@placeholder,"Search")]',
        '//input[contains(@aria-label,"Search")]',
        '//input'

    ]

    for selector in selectors:

        try:

            box = driver.find_element(
                By.XPATH,
                selector
            )

            return box

        except:
            pass

    return None



def extract_school_data():

    try:

        try:

            name = driver.find_element(
                By.TAG_NAME,
                "h1"
            ).text

        except:

            name = ""


        try:

            address = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"address")]'
            ).text

        except:

            address = ""


        phone = ""

        try:

            phone_xpaths = [

     
                '//button[contains(@data-item-id,"phone")]',

 
                '//a[contains(@href,"tel:")]',

   
                '//button[contains(@aria-label,"Phone")]',


                '//button[contains(text(),"+91")]',
                '//div[contains(text(),"+91")]',
                '//span[contains(text(),"+91")]'

            ]

            for xpath in phone_xpaths:

                try:

                    elements = driver.find_elements(
                        By.XPATH,
                        xpath
                    )

                    for element in elements:

                        text = element.text.strip()

                        href = (
                            element.get_attribute("href")
                            or ""
                        )


                        if "tel:" in href:

                            phone = href.replace(
                                "tel:",
                                ""
                            ).strip()

            
                        elif text:

                            phone = text

     
                        phone = (

                            phone.replace("", "")
                            .replace(" ", "")
                            .replace("-", "")
                            .replace("(", "")
                            .replace(")", "")
                            .replace("\n", "")
                            .strip()

                        )

                        digits = ''.join(
                            filter(str.isdigit, phone)
                        )

                        if len(digits) >= 10:

                            break

                    if phone:
                        break

                except:
                    pass

        except Exception as e:

            print(f"Phone Error: {e}")



        try:

            website = driver.find_element(
                By.XPATH,
                '//a[contains(@data-item-id,"authority")]'
            ).get_attribute("href")

        except:

            website = ""



        try:

            rating = driver.find_element(
                By.XPATH,
                '//div[@role="img"]'
            ).get_attribute("aria-label")

        except:

            rating = ""

        return {

            "Company Name": name,
            "Address": address,
            "Phone": phone,
            "Website": website,
            "Rating": rating,
            "Google Maps URL": driver.current_url

        }

    except:

        return None


for district in districts:

    for search_type in search_types:

        try:

            query = (
                f"{search_type} "
                f"in {district} Rajasthan"
            )

            print(f"\nSearching: {query}")
 
            search_box = get_search_box()

            if not search_box:

                print("Search Box Not Found")

                continue

            ActionChains(driver).move_to_element(
                search_box
            ).click().perform()

            time.sleep(1)

            search_box.send_keys(
                Keys.CONTROL + "a"
            )

            time.sleep(1)

            search_box.send_keys(Keys.DELETE)

            time.sleep(1)


            for char in query:

                search_box.send_keys(char)

                time.sleep(0.03)

            search_box.send_keys(Keys.ENTER)

            print("Search Submitted")

            time.sleep(8)


            try:

                scrollable_div = driver.find_element(
                    By.XPATH,
                    '//div[@role="feed"]'
                )

                previous_count = 0

                stagnant = 0

                for i in range(100):

                    driver.execute_script(
                        """
                        arguments[0].scrollTop =
                        arguments[0].scrollHeight
                        """,
                        scrollable_div
                    )

                    time.sleep(4)

                    listings = driver.find_elements(
                        By.XPATH,
                        '//a[contains(@href,"/maps/place/")]'
                    )

                    current_count = len(listings)

                    print(
                        f"{district} | "
                        f"{search_type} | "
                        f"Scroll {i+1} -> "
                        f"{current_count}"
                    )

                    if current_count == previous_count:

                        stagnant += 1

                    else:

                        stagnant = 0

                    if stagnant >= 4:

                        break

                    previous_count = current_count

            except Exception as e:

                print(f"Scrolling Error: {e}")



            listings = driver.find_elements(
                By.XPATH,
                '//a[contains(@href,"/maps/place/")]'
            )

            links = []

            for listing in listings:

                try:

                    link = listing.get_attribute("href")

                    if (
                        link
                        and link not in visited_links
                    ):

                        links.append(link)

                        visited_links.add(link)

                except:
                    pass

            print(f"Collected {len(links)} links")

  

            for index, link in enumerate(links):

                try:

                    print(
                        f"{district} | "
                        f"{index+1}/{len(links)}"
                    )

                    driver.get(link)

                    time.sleep(
                        random.uniform(2, 3)
                    )

                    data = extract_school_data()

                    if data:

                        data["District"] = district

                        data["Search Type"] = search_type

                        all_data.append(data)

                        print(data["Company Name"])

                        print(
                            f"Phone: {data['Phone']}"
                        )

              

                    if len(all_data) % 100 == 0:

                        backup_df = pd.DataFrame(
                            all_data
                        )

                        backup_df.drop_duplicates(
                            subset=[
                                "Company Name",
                                "Google Maps URL"
                            ],
                            inplace=True
                        )

                        backup_df.to_csv(
                            "rajasthan_companies_backup.csv",
                            index=False
                        )

                        print("Backup Saved")

                except Exception as e:

                    print(
                        f"Company Error: {e}"
                    )

        except Exception as e:

            print(
                f"District Error: {e}"
            )

# FINAL SAVE

df = pd.DataFrame(all_data)

df.drop_duplicates(

    subset=[
        "Company Name",
        "Google Maps URL"
    ],

    inplace=True
)

filename = "rajasthan_companies.csv"

df.to_csv(
    filename,
    index=False
)

print("\nExtraction Completed")

print(
    f"Total Companies Extracted: {len(df)}"
)

print(f"\nSaved File: {filename}")

driver.quit()
# Out:
# Opening Google Maps...
# Google Maps Loaded
#
# Searching: software companies in Phalodi Rajasthan
# Search Submitted
# Phalodi | software companies | Scroll 1 -> 14
# Phalodi | software companies | Scroll 2 -> 15
# Phalodi | software companies | Scroll 3 -> 15
# Phalodi | software companies | Scroll 4 -> 15
# Phalodi | software companies | Scroll 5 -> 15
# Phalodi | software companies | Scroll 6 -> 15
# Collected 15 links
# Phalodi | 1/15
# Geekybuddha Technologies Pvt. Ltd.
# Phone:
# Phalodi | 2/15
# Mahalaxmi Computers
# Phone: 09983052873
# Phalodi | 3/15
# CTechno Multi Brand Computer Outlet
# Phone:
# Phalodi | 4/15
# Gs Computer Tech And Stationary Store
# Phone: 09799411329
# Phalodi | 5/15
# Ramsnahey Enterprises || Siyol Weighing Scale Manufacturer, Weighbridge Manufacturer, Weight Load Cell Manufacturers
# Phone: 09829295951
# Phalodi | 6/15
# CYBERTECH Group of Computer Education
# Phone: 09414410448
# Phalodi | 7/15
# P C COMPUTER PHALODI
# Phone: 07410957235
# Phalodi | 8/15
# Techoniq Fusion IT Solutions Private Limited
# Phone: 09799699692
# Phalodi | 9/15
# Adiyogi Technosoft Pvt. Ltd. - IT Company in Jodhpur
# Phone: 09529681128
# Phalodi | 10/15
# Krishna Computer Center,Phalodi
# Phone:
# Phalodi | 11/15
# Krishna Telecom
# Phone:
# Phalodi | 12/15
# Tata Voltas Brand Store
# Phone: 08058382119
# Phalodi | 13/15
# Shree Paliwal Computer Centre
# Phone: 09667524546
# Phalodi | 14/15
# M.M Kothari
# Phone: 09460214969
# Phalodi | 15/15
# Punam Mobile
# Phone: 08386876563
#
# Searching: IT companies in Phalodi Rajasthan
# Search Submitted
# Phalodi | IT companies | Scroll 1 -> 10
# Phalodi | IT companies | Scroll 2 -> 15
# Phalodi | IT companies | Scroll 3 -> 16
# Phalodi | IT companies | Scroll 4 -> 16
# Phalodi | IT companies | Scroll 5 -> 16
# Phalodi | IT companies | Scroll 6 -> 16
# Phalodi | IT companies | Scroll 7 -> 16
# Collected 4 links
# Phalodi | 1/4
# Central Bus Stand Phalodi
# Phone:
# Phalodi | 2/4
# BASANT WATCH COMPANY
# Phone: 09772902938
# Phalodi | 3/4
# SHREE AMBE ELECTRONICS
# Phone: 08769268772
# Phalodi | 4/4
# Mahadev Computer sales and service
# Phone: 09784532925
#
# Searching: software companies in Pratapgarh Rajasthan
# Search Submitted
# Pratapgarh | software companies | Scroll 1 -> 14
# Pratapgarh | software companies | Scroll 2 -> 20
# Pratapgarh | software companies | Scroll 3 -> 25
# Pratapgarh | software companies | Scroll 4 -> 25
# Pratapgarh | software companies | Scroll 5 -> 25
# Pratapgarh | software companies | Scroll 6 -> 25
# Pratapgarh | software companies | Scroll 7 -> 25
# Collected 25 links
# Pratapgarh | 1/25
# Royal Computer Technology
# Phone:
# Pratapgarh | 2/25
# Alpine Software Pvt. Ltd.
# Phone: 08078687192
# Pratapgarh | 3/25
# SaifTech Solutions
# Phone:
# Pratapgarh | 4/25
# i5Software Pvt Ltd
# Phone: 09461050614
# Pratapgarh | 5/25
# Kapil Computer & E-Mitra
# Phone:
# Pratapgarh | 6/25
# NOI Technologies LLC
# Phone: 08385094408
# Pratapgarh | 7/25
# Fzeetechz private limited
# Phone: 08005682862
# Pratapgarh | 8/25
# Soni Online Pratapgarh
# Phone:
# Pratapgarh | 9/25
# Pawan Computers & Infoteh
# Phone: 07976498054
# Pratapgarh | 10/25
# Future Profilez
# Phone: 09983333334
# Pratapgarh | 11/25
# Decipher Zone - Top Software Development Company in India
# Rajsamand | software companies | Scroll 10 -> 55
# Rajsamand | software companies | Scroll 11 -> 55
# Rajsamand | software companies | Scroll 12 -> 55
# Collected 47 links
# Rajsamand | 1/47
# BITCODEVS DIGITAL PVT LTD
# Phone: 09602740090
# Rajsamand | 2/47
# Bhavesh Naveen Shrimali
# Phone: 07239942833
# Rajsamand | 3/47
# Neeyat AI
# Phone:
# Rajsamand | 4/47
# Pixel PropX Solutions
# Phone:
# Rajsamand | 5/47
# M K Emitra
# Phone: 06375548882
# Rajsamand | 6/47
# Monika Infotech
# Phone: 09672795444
# Rajsamand | 7/47
# Maheshwari Computer Service
# Phone:
# Backup Saved
# Rajsamand | 8/47
# Digi Amigo - Digital Marketing & Web Design Service in India
# Phone: 08764461003
# Rajsamand | 9/47
# Dell Exclusive Store - Kankroli
# Phone: 08048008271
# Rajsamand | 10/47
# PC Planet
# Phone: 09929398077
# Rajsamand | 11/47
# Aarambh StarTechnology
# Phone:
# Rajsamand | 12/47
# Shivayan Computer
# Phone: 07610038246
# Rajsamand | 13/47
# KAIRA TECHNOLOGIES
# Phone:
# Rajsamand | 14/47
# Kistechnosoftware | software, web, mobile app, custom software development company
# Phone: 01413571731
# Rajsamand | 15/47
# InfraRise Tech
# Phone:
# Rajsamand | 16/47
# Pratham Software
# Phone: 01416690000
# Rajsamand | 17/47
# MANSARUP
# Phone:
# Rajsamand | 18/47
# Groot Software AI-Powered Web & App Development, Digital Marketing & Internship Company
# Phone: 09610967825
# Rajsamand | 19/47
# Krishna Padam IT Solution- KPIS Pvt. Ltd. | AI Software & Mobile App Development Company
# Phone: 06350359218
# Rajsamand | 20/47
# SWASTIK PC SOLUTION CCTV
# Phone: 07737817035
# Rajsamand | 21/47
# Yantrigo
# Phone: 07357446466
# Rajsamand | 22/47
# COMPUTECH
# Phone: 09413094042
# Rajsamand | 23/47
# Zedologic Softwares
# Phone: 09587047844
# Rajsamand | 24/47
# Computer repair shop, SHRINATH INFOTECH
# Phone: 09413953842
# Rajsamand | 25/47
# OnEven Tech
# Phone:
# Rajsamand | 26/47
# Paradise Electronics & Mobile Shop
# Phone: 09414171837
# Rajsamand | 27/47
# ccsoft
# Phone: 07727865055
# Rajsamand | 28/47
# Ollosoft Technologies Private Limited
# Phone:
# Rajsamand | 29/47
# B N Mobile & Computer
# Phone: 09414935868
# Rajsamand | 30/47
# WebSenor Private Limited
# Phone: 09950834560
# Rajsamand | 31/47
# Vashisht Library
# Phone: 08003106661
# Rajsamand | 32/47
# AleaIT Solutions Pvt Ltd
# Phone: 07727940359
# Rajsamand | 33/47
#
# Phone:
# Rajsamand | 34/47
# EduManag IT Solution Private Limited
# Phone: 09252089089
# Rajsamand | 35/47
# True Value Infosoft I App Development I Software I AI
# Phone: 09057801818
# Rajsamand | 36/47
# PUSHPAK COURIER KANKROLI
# Phone: 09214060515
# Rajsamand | 37/47
# Motilal Oswal Financial Services Limited
# Phone: 09611718390
# Rajsamand | 38/47
# Maa Metal Laser Cutting
# Phone: 09702150100
# Rajsamand | 39/47
# Andro Games Infotech Private Limited
# Phone:
# Rajsamand | 40/47
# Clover IT Services Pvt Ltd
# Phone: 09057799799
# Rajsamand | 41/47
# DreamSoft4u Pvt. Ltd.
# Phone: 09694422233
# Rajsamand | 42/47
# Lavish Honda
# Phone: 09314571777
# Rajsamand | 43/47
# माँ करणी लाईब्रेरी
# Phone: 07742317310
# Rajsamand | 44/47
# Ekoved LLP
# Phone:
# Rajsamand | 45/47
# Rexsoft Pvt.Ltd.
# Phone: 08561884488
# Rajsamand | 46/47
# KRISHAN SOFTECH
# Phone:
# Rajsamand | 47/47
# MKBiNFO Digital Solutions
# Phone:
#
# Searching: IT companies in Rajsamand Rajasthan
# Search Submitted
# Rajsamand | IT companies | Scroll 1 -> 14
# Rajsamand | IT companies | Scroll 2 -> 20
# Rajsamand | IT companies | Scroll 3 -> 27
# Rajsamand | IT companies | Scroll 4 -> 34
# Rajsamand | IT companies | Scroll 5 -> 40
# Rajsamand | IT companies | Scroll 6 -> 47
# Rajsamand | IT companies | Scroll 7 -> 54
# Rajsamand | IT companies | Scroll 8 -> 60
# Rajsamand | IT companies | Scroll 9 -> 67
# Rajsamand | IT companies | Scroll 10 -> 74
# Rajsamand | IT companies | Scroll 11 -> 80
# Rajsamand | IT companies | Scroll 12 -> 87
# Rajsamand | IT companies | Scroll 13 -> 94
# Rajsamand | IT companies | Scroll 14 -> 100
# Rajsamand | IT companies | Scroll 15 -> 107
# Rajsamand | IT companies | Scroll 16 -> 114
# Rajsamand | IT companies | Scroll 17 -> 120
# Rajsamand | IT companies | Scroll 18 -> 120
# Rajsamand | IT companies | Scroll 19 -> 120
# Rajsamand | IT companies | Scroll 20 -> 120
# Rajsamand | IT companies | Scroll 21 -> 120
# Collected 105 links
# Rajsamand | 1/105
# Startups saarthi One stop solution (India) Private Limited
# Phone: 07597979491
# Rajsamand | 2/105
# Yellow Pillar
# Phone: 09610518999
# Rajsamand | 3/105
# B N COMPUTERS
# Phone: 08696318834
# Rajsamand | 4/105
# Shivani infotech,rajsamand
# Phone: 09414659641
# Rajsamand | 5/105
# Arduino hub
# Phone: 06376857004
# Rajsamand | 6/105
# MitraBlends
# Phone: 08000441968
# Rajsamand | 7/105
# Doctor Digitalize
# Phone:
# Rajsamand | 8/105
# compunet computer
# Phone: 07014996572
# Rajsamand | 9/105
# Gayatri e mitra & general store
# Phone: 08003637776
# Rajsamand | 10/105
# Quick And Quick Services
# Phone:
# Rajsamand | 11/105
# NESTED DESIGNER - Designing and Printing shop
# Phone: 07340013988
# Rajsamand | 12/105
# Vinay Computers
# Phone:
# Rajsamand | 13/105
# Entartica Seaworld (Rajsamand Lake, Rajasthan)
# Phone: 09429691418
# Rajsamand | 14/105
# InfiSolar Power
# Phone: 09166305555
# Rajsamand | 15/105
# Shree Dwarkadhish Computer & EMitra Kankroli
# Phone:
# Rajsamand | 16/105
# Manoj Telecom
# Phone: 09829556410
# Rajsamand | 17/105
# Nandini Graphics
# Phone: 08561846724
# Rajsamand | 18/105
# JK Tyre & Industries Ltd-Kankroli Tyre Plant
# Phone: 02952302400
# Rajsamand | 19/105
# First cafe
# Phone: 09256390033
# Rajsamand | 20/105
# Muthoot FinCorp Gold Loan
# Phone: 09289049559
# Rajsamand | 21/105
# SUNCITY COMPLEX
# Phone: 08875750123
# Rajsamand | 22/105
# R D K S & CO
# Phone:
# Rajsamand | 23/105
# CEAT Shoppe, Arunoday Tyres
# Phone: 09731108993
# Rajsamand | 24/105
# KK FARMS
# Phone: 09024660337
# Rajsamand | 25/105
# Enlightenment Consultancy
# Phone: 09460574928
# Rajsamand | 26/105
# S. N. Print Technology
# Phone: 09588084664
# Rajsamand | 27/105
# Lakshya engineering works
# Phone: 09460029022
# Rajsamand | 28/105
# Natraj Marble & Granite Ind.
# Phone: 09414174646
# Rajsamand | 29/105
# Royal City
# Phone:
# Rajsamand | 30/105
# Akashganga Motors Pvt Ltd - Hero MotoCorp
# Phone: 09289922477
# Rajsamand | 31/105
# Advocate prakash chandra banjara lawyer in rajsamand
# Phone: 08014666699
# Rajsamand | 32/105
# CCTV SECURE RAJSAMAND
# Phone:
# Rajsamand | 33/105
# Dinesh Kherodia & Associates
# Phone:
# Rajsamand | 34/105
# VDTV Live
# Phone:
# Rajsamand | 35/105
# ANAND QUALITY PRODUCTS PVT. LTD (Granite unit) || best granite dealer in Rajsamand | marble dealer in Rajsamand | black stone
# Phone: 08068499991
# Rajsamand | 36/105
# Rawla Paridhan - The Wedding Store
# Phone: 09887973995
# Rajsamand | 37/105
# G.N.mobile & Computer
# Phone:
# Rajsamand | 38/105
# Bherunath Enterprises
# Phone: 09772129191
# Rajsamand | 39/105
# Advocate Lokesh Joshi advocate in Rajsamand
# Phone: 08104647374
# Rajsamand | 40/105
# Hindustan marble
# Phone: 07742924876
# Rajsamand | 41/105
# RAMAWAT TEA
# Phone: 07737894029
# Rajsamand | 42/105
# Purbia Couriers
# Phone: 09351411122
# Rajsamand | 43/105
# Jatan Sansthan
# Phone: 08764107533
# Rajsamand | 44/105
# Darshan Travels
# Phone:
# Rajsamand | 45/105
# Shine Compuers
# Phone:
# Rajsamand | 46/105
# Bharat Pustak Bhandar
# Phone:
# Rajsamand | 47/105
# MPS The Tea Room Cafe and Restaurant
# Phone:
# Rajsamand | 48/105
# Shiv Shakti Enterprises
# Phone: 07424970705
# Rajsamand | 49/105
# Shrinath Travel Agency Pvt.Ltd
# Phone: 02952220440
# Rajsamand | 50/105
# Jenpure water purifier systems
# Phone: 09414659725
# Rajsamand | 51/105
# Money Roots
# Phone: 09582428548
# Rajsamand | 52/105
# Dev Villa Resort & Wedding Venue
# Phone: 08854967766
# Rajsamand | 53/105
# Bharat e-Filing
# Phone:
# Rajsamand | 54/105
# SMFG India Credit Co. Ltd. - Bhawani Nagar (Branch)
# Phone: 18001036001
# Rajsamand | 55/105
# Shri Parshwanath Gold Pvt Ltd
# Phone: 09887113188
# Rajsamand | 56/105
# Shiv CNC Point
# Phone: 08279286770
# Rajsamand | 57/105
# Laxmi Nivas
# Phone:
# Rajsamand | 58/105
# Nakoda marbles
# Phone: 08890198328
# Rajsamand | 59/105
# Just wedding
# Phone: 08401462484
# Rajsamand | 60/105
# Jaluram engineering works Rajsamand
# Phone: 09413423195
# Backup Saved
# Rajsamand | 61/105
# Oryon Media and consultancy
# Phone:
# Rajsamand | 62/105
# The Chashmish Photographer
# Phone: 08233762281
# Rajsamand | 63/105
# Mahindra Tractors - Kardhar Automobiles
# Phone: 08071639336
# Rajsamand | 64/105
# Advocate Anil Kumawat
# Phone: 08769174243
# Rajsamand | 65/105
# Piparda Rajsamand
# Phone:
# Rajsamand | 66/105
# Kumawat Samaj Kankroli
# Phone:
# Rajsamand | 67/105
# Ummeed Housing Finance Pvt Ltd - Rajsamand
# Phone: 08069867525
# Rajsamand | 68/105
# Shastri Market
# Phone:
# Rajsamand | 69/105
# Dev stud farm
# Phone: 09414171602
# Rajsamand | 70/105
# UTL Solar Shoppe | Solar Inverter | Solar Panel - Sangam Battery & Solar Service
# Phone: 09250885885
# Rajsamand | 71/105
# South India Transport
# Phone:
# Rajsamand | 72/105
# Paliwal Market
# Phone:
# Rajsamand | 73/105
# TRAVELBUG HOLIDAYS
# Phone: 09257483169
# Rajsamand | 74/105
# Bherunath mobile kankroli
# Phone:
# Rajsamand | 75/105
# श्री गणगौर Library
# Phone: 09462672576
# Rajsamand | 76/105
# Shree Balaji Infotech
# Phone: 09414632320
# Rajsamand | 77/105
# Preksha Jewellery
# Phone: 09460402070
# Rajsamand | 78/105
# Sunrise Motor Driving School
# Phone: 09950889977
# Rajsamand | 79/105
# TRENDING PHOTOGRAPHY
# Phone: 09079173570
# Rajsamand | 80/105
# Soham Events & Hotel
# Phone:
# Rajsamand | 81/105
# Airtel Store - Kankroli
# Phone: 09810012345
# Rajsamand | 82/105
# Akashganga Motors
# Phone:
# Rajsamand | 83/105
# Shree Ji Rajj
# Phone:
# Rajsamand | 84/105
# Asian Paints Colourideas - Shree Dwarkesh Paints
# Phone: 08422872935
# Rajsamand | 85/105
# Angel One Ltd. - Future Traders
# Phone: 08037467811
# Rajsamand | 86/105
# Bharat Petroleum, Petrol and CNG Pump -Shrinath Filling Station
# Phone: 09549464601
# Rajsamand | 87/105
# Natraj Namkeen - Best Sweet Shop In Rajsamand | Best Namkeen Shop In Rajsamand | Best Fresh Mithai Shop | Best Dessert Shop
# Phone: 09414220815
# Rajsamand | 88/105
# Jawahar Navodaya Vidyalya, Rajsamand
# Phone:
# Rajsamand | 89/105
# Badola Hyundai Car dealer
# Phone: 08696939332
# Rajsamand | 90/105
# Hotel Keshav Inn
# Phone: 07014065500
# Rajsamand | 91/105
# The ColorSpace Films
# Phone: 06377850173
# Rajsamand | 92/105
# Lake City library
# Phone:
# Rajsamand | 93/105
# Shri Charbhuja Marble Industries
# Phone: 08239940399
# Rajsamand | 94/105
# Mahi library
# Phone: 09602205123
# Rajsamand | 95/105
# Swati Nrityashala 💃
# Phone: 06375368284
# Rajsamand | 96/105
# Charbhuja Computers
# Phone:
# Rajsamand | 97/105
# Sai shraddha Cycle
# Phone: 09782065065
# Rajsamand | 98/105
# Shree traders
# Phone: 08386962269
# Rajsamand | 99/105
# Chandi Marbles Pvt Ltd
# Phone: 09414174847
# Rajsamand | 100/105
# PRM Salon -Makeup Salon |Beauty Salon in Rajsamand |Unisex Salon in Rajsamand
# Phone: 09672244881
# Rajsamand | 101/105
# Happy Birthday Bakery Mall & Café
# Phone: 07597764737
# Rajsamand | 102/105
# IDFC FIRST Bank - Rajsamand Branch
# Phone: 180010888
# Rajsamand | 103/105
# FLAVOURS POCKET FOOD COURT
# Phone: 07665500776
# Rajsamand | 104/105
# Alphonic Network Solutions Pvt Ltd
# Phone: 08005670910
# Rajsamand | 105/105
# Rishabh exotic jewellery llp
# Phone: 08003268549
#
# Searching: software companies in Salumbar Rajasthan
# Search Submitted
# Salumbar | software companies | Scroll 1 -> 9
# Salumbar | software companies | Scroll 2 -> 9
# Salumbar | software companies | Scroll 3 -> 9
# Salumbar | software companies | Scroll 4 -> 9
# Salumbar | software companies | Scroll 5 -> 9
# Collected 9 links
# Salumbar | 1/9
# Salumbar Industries
# Phone: 09114008004
# Salumbar | 2/9
# STWIN SPARX PVT LTD | IT COMPANY IN UDAIPUR | SOFTWARE COMPANY IN UDAIPUR
# Phone: 07738384009
# Salumbar | 3/9
# VT creative studio salumber
# Phone:
# Salumbar | 4/9
# Burhani infotech
# Phone: 08440071565
# Salumbar | 5/9
# Kansoft Pvt. Ltd.
# Phone: 07627092336
# Salumbar | 6/9
# PC STORE Computer Sales, Service Shop Salumber
# Phone: 08003040510
# Salumbar | 7/9
# Jrockhub
# Phone:
# Salumbar | 8/9
# Soni Software
# Phone: 08769999969
# Salumbar | 9/9
# Erica Mobile
# Phone: 09001252414
#
# Searching: IT companies in Salumbar Rajasthan
# Search Submitted
# Salumbar | IT companies | Scroll 1 -> 14
# Salumbar | IT companies | Scroll 2 -> 14
# Salumbar | IT companies | Scroll 3 -> 14
# Salumbar | IT companies | Scroll 4 -> 14
# Salumbar | IT companies | Scroll 5 -> 14
# Collected 7 links
# Salumbar | 1/7
# JIIT COMPUTERS & EDUCATION DINESH JOSHI
# Phone: 09982717471
# Salumbar | 2/7
# Param Sai enterprises
# Phone: 09552104444
# Salumbar | 3/7
# Go-Tech Solution| Web Development Company in Udaipur, IT Company in Udaipur
# Phone: 08769365375
# Salumbar | 4/7
# GOKUL PALACE
# Phone: 08955911146
# Salumbar | 5/7
# Modern Printer's salumber
# Phone: 07232042808
# Salumbar | 6/7
# IT UNION SALUMBAR
# Phone:
# Salumbar | 7/7
# Dynamite Web - Digital Marketing Services
# Phone: 06378015107
#
# Searching: software companies in Sanchore Rajasthan
# Search Submitted
# Sanchore | software companies | Scroll 1 -> 10
# Sanchore | software companies | Scroll 2 -> 11
# Sanchore | software companies | Scroll 3 -> 11
# Sanchore | software companies | Scroll 4 -> 11
# Sanchore | software companies | Scroll 5 -> 11
# Sanchore | software companies | Scroll 6 -> 11
# Collected 11 links
# Sanchore | 1/11
# Sezpo - Best Website Designer & Billing Software In Sanchore
# Phone: 09649001105
# Sanchore | 2/11
# Devops Technologies
# Phone: 09772795757
# Sanchore | 3/11
# The Tech Query
# Phone: 08290255610
# Sanchore | 4/11
# Accno Solution
# Phone: 09468781166
# Sanchore | 5/11
# NABRIYA INFOTEK
# Phone: 09928585755
# Sanchore | 6/11
# Webify computer Sanchore - Computer Sale And Service Shop, Computer Accessories
# Phone: 07297987219
# Sanchore | 7/11
# JYOTI COMPUTER & E-Mitra
# Phone: 09828926251
# Sanchore | 8/11
# SWASTIK INFOCOM
# Phone: 09587781166
# Sanchore | 9/11
# SHREE RAM INFOTECH
# Phone: 09660047612
# Sanchore | 10/11
# CHARBHUJA COMPUTER AND HARDWARE CENTRE
# Phone: 09983952025
# Sanchore | 11/11
# Gayatri Softech Sanchore
# Phone: 09649106546
#
# Searching: IT companies in Sanchore Rajasthan
# Search Submitted
# Sanchore | IT companies | Scroll 1 -> 14
# Sanchore | IT companies | Scroll 2 -> 20
# Sanchore | IT companies | Scroll 3 -> 27
# Sanchore | IT companies | Scroll 4 -> 34
# Sanchore | IT companies | Scroll 5 -> 40
# Sanchore | IT companies | Scroll 6 -> 47
# Sanchore | IT companies | Scroll 7 -> 51
# Sanchore | IT companies | Scroll 8 -> 51
# Sanchore | IT companies | Scroll 9 -> 51
# Sanchore | IT companies | Scroll 10 -> 51
# Sanchore | IT companies | Scroll 11 -> 51
# Collected 41 links
# Sanchore | 1/41
# SAI INFOTECH
# Phone: 09873645446
# Sanchore | 2/41
# One Touch Computer sanchore
# Phone: 09574295986
# Sanchore | 3/41
# GAYATRI INFOTECH
# Phone:
# Sanchore | 4/41
# Mahashakti Computers & Printing
# Phone: 09982335536
# Sanchore | 5/41
# Latiyal Gps Sanchore (Authorised Retail Outlet)
# Phone: 09571162121
# Sanchore | 6/41
# Shri Balaji Softech Sanchore - Best Computer Institute in Sanchore , Best RS-CIT Course in Sanchore , Best Computer Faculty
# Phone: 08562848589
# Sanchore | 7/41
# Sanchore RSRTC BUS terminal
# Phone:
# Sanchore | 8/41
# LIC of India, Branch Office
# Phone:
# Sanchore | 9/41
# ADARSH COMPUTER
# Phone: 09571537454
# Sanchore | 10/41
# Jigar photography
# Phone: 08875235532
# Sanchore | 11/41
# City centre Sanchore
# Phone: 09929535319
# Sanchore | 12/41
# SATYAPUR E SERVICES SANCHORE
# Phone: 08696699496
# Sanchore | 13/41
# RR Studio sanchore
# Phone: 08094758737
# Sanchore | 14/41
# Sanchore
# Phone: 09829269532
# Sanchore | 15/41
# Jay Bajrang Travels Agency
# Phone: 09983195936
# Sanchore | 16/41
# RADHE KRISHNA COMPUTER
# Phone: 07689959118
# Sanchore | 17/41
# Rapid Organic Pvt. Ltd.
# Phone: 09549892293
# Sanchore | 18/41
# G M TELECOM SANCHORE
# Phone: 08080801730
# Search Submitted
# Sikar | software companies | Scroll 1 -> 14
# Sikar | software companies | Scroll 2 -> 20
# Sikar | software companies | Scroll 3 -> 27
# Sikar | software companies | Scroll 4 -> 34
# Sikar | software companies | Scroll 5 -> 40
# Sikar | software companies | Scroll 6 -> 47
# Sikar | software companies | Scroll 7 -> 54
# Sikar | software companies | Scroll 8 -> 60
# Sikar | software companies | Scroll 9 -> 67
# Sikar | software companies | Scroll 10 -> 74
# Sikar | software companies | Scroll 11 -> 80
# Sikar | software companies | Scroll 12 -> 87
# Sikar | software companies | Scroll 13 -> 94
# Sikar | software companies | Scroll 14 -> 100
# Sikar | software companies | Scroll 15 -> 107
# Sikar | software companies | Scroll 16 -> 114
# Sikar | software companies | Scroll 17 -> 119
# Sikar | software companies | Scroll 18 -> 119
# Sikar | software companies | Scroll 19 -> 119
# Sikar | software companies | Scroll 20 -> 119
# Sikar | software companies | Scroll 21 -> 119
# Collected 118 links
# Sikar | 1/118
# Rajasthan Future Tech - Digital Marketing & IT Solutions in Sikar
# Phone: 09549214344
# Sikar | 2/118
# Sikar Infotech
# Phone: 08619306970
# Sikar | 3/118
# Softonexa Web Solution private limited
# Phone: 09521103832
# Sikar | 4/118
# ADKORA tech pvt. ltd.
# Phone: 09680264828
# Sikar | 5/118
# Codevenz
# Phone:
# Sikar | 6/118
# MLM Software Company in Sikar
# Phone:
# Sikar | 7/118
# Venomweb Studios Pvt. Ltd.
# Phone: 07597772395
# Sikar | 8/118
# Sunrise Web Solution
# Phone: 09667426556
# Sikar | 9/118
# Akvira Technologies
# Phone: 09587795444
# Sikar | 10/118
# JR Infotech Services
# Phone: 08003416434
# Sikar | 11/118
# Raj Web Services
# Phone: 09024600420
# Sikar | 12/118
# Digital Desh
# Phone: 08432000008
# Sikar | 13/118
# TechHelio IT Service | Custom Software, Web & Mobile App Development Sikar
# Phone: 09079817263
# Sikar | 14/118
# The Bharat Groups
# Phone: 09680621496
# Sikar | 15/118
# Websikar Technologies Private Limited
# Phone: 07357841115
# Sikar | 16/118
# Balaji Online
# Phone: 09982388388
# Sikar | 17/118
# mycslab
# Phone: 06378535557
# Sikar | 18/118
# SSIT GROUP
# Phone: 09672246200
# Sikar | 19/118
# CADD Centre
# Phone: 08104399979
# Sikar | 20/118
# eNest IT Solutions
# Phone: 07877556789
# Sikar | 21/118
# Acadewise
# Phone: 09257660411
# Sikar | 22/118
# Smart Typing Solution
# Phone: 09413428971
# Sikar | 23/118
# p4logics technologies pvt ltd
# Phone:
# Sikar | 24/118
# CADDESK CENTRE
# Phone: 09352499979
# Sikar | 25/118
# BeanByte Softwares Pvt Ltd
# Phone: 08824948049
# Sikar | 26/118
# FlowPXL - Creative web development agency
# Phone: 08000905834
# Sikar | 27/118
# Stake binary
# Phone: 09462562043
# Sikar | 28/118
# ROYAL COMPUTERS & CCTV CAMERA SIKAR
# Phone: 08003600546
# Sikar | 29/118
# Alphatech
# Phone: 06378099963
# Sikar | 30/118
# SSIT Computer Education
# Phone: 09672246200
# Sikar | 31/118
# Wave Surge Technologies Hub
# Phone: 07889361285
# Sikar | 32/118
# Sinfode - Best Digital Marketing, Data Science, Web Development Institute in Sikar
# Phone: 08619306970
# Backup Saved
# Sikar | 33/118
# VAST WEB INDIA PRIVATE LIMITED
# Phone: 01573355555
# Sikar | 34/118
# UnixWave Private Limited
# Phone:
# Sikar | 35/118
# Lenovo Exclusive Store - Jalan Computers
# Phone: 08048045515
# Sikar | 36/118
# Samyak Computer Classes, Piprali Road Sikar
# Phone: 07413836777
# Sikar | 37/118
# one click e-services
# Phone: 08094547112
# Sikar | 38/118
# My Digital Desh
# Phone: 08432000003
# Sikar | 39/118
# Khichad Technologies
# Phone:
# Sikar | 40/118
# Hostingrt Web Services
# Phone: 09610120145
# Sikar | 41/118
# best web developer & Digital Marketing Company Sikar || HyphenTech Solution
# Phone: 07877989296
# Sikar | 42/118
# MKS Computers
# Phone: 09660311775
# Sikar | 43/118
# IICE Computer Centre, Tally GST Centre
# Phone: 09351256215
# Sikar | 44/118
# HP World - Sikar
# Phone: 08657568479
# Sikar | 45/118
# GEIT SOLUTIONS
# Phone: 09521666006
# Sikar | 46/118
# Reliance Digital
# Phone: 08071890050
# Sikar | 47/118
# Pedestal Academy
# Phone: 09929903430
# Sikar | 48/118
# Global Computers
# Phone: 09314860665
# Sikar | 49/118
# kalpana global technologies
# Phone:
# Sikar | 50/118
# Sharda Computers
# Phone:
# Sikar | 51/118
# Stackora
# Phone:
# Sikar | 52/118
# Laptech Repair
# Phone: 09782494718
# Sikar | 53/118
# SQAD SOFTWARE SOLUTIONS
# Phone: 09204633162
# Sikar | 54/118
# Microseft Computer & Typing Center
# Phone: 09509680333
# Sikar | 55/118
# RAJSA Infotech
# Phone: 06375796563
# Sikar | 56/118
# Amar Laxmi Vision
# Phone: 09829328657
# Sikar | 57/118
# Zoomtrax Technologies
# Phone: 09414681061
# Sikar | 58/118
# Jalan computers
# Phone: 09828118703
# Sikar | 59/118
# Prince Computer
# Phone: 09829888908
# Sikar | 60/118
# Dell Exclusive Store - Sikar
# Phone: 08048008280
# Sikar | 61/118
# CodeStreax Technologies
# Phone: 08529858566
# Sikar | 62/118
# Opin Infotech
# Phone: 09664223048
# Sikar | 63/118
# Computer Target institute
# Phone: 08003033312
# Sikar | 64/118
# Annpurna Laptop Reparing
# Phone: 09199279777
# Sikar | 65/118
# Infinity Corporation
# Phone:
# Sikar | 66/118
# CSC & E-Mitra (Career Consultancy) And Computronix solution center
# Phone: 08005818008
# Sikar | 67/118
# B2D Cyber Cafe & Gaming Zone
# Phone: 09660730063
# Sikar | 68/118
# Dalip Krishniya Tax Consultants, GST Solution & Tally Business Accounts
# Phone: 08209484776
# Sikar | 69/118
# Digital World
# Phone: 09667373888
# Sikar | 70/118
# Paharia Tower
# Phone: 09748911032
# Sikar | 71/118
# TMS Computer classes
# Phone: 07073122768
# Sikar | 72/118
# Zadon Technology, Website Design Company
# Phone:
# Sikar | 73/118
# Tally GST Training Institute
# Phone: 09521874719
# Sikar | 74/118
# DIGI CODEWEB CREATORS
# Phone:
# Sikar | 75/118
# Imagine Apple Premium Reseller, Sikar
# Phone: 08287482874
# Sikar | 76/118
# Netefie Solutions Private Limited
# Phone: 09667271205
# Sikar | 77/118
# Choudhary Trading Company, Inverter,Battery, Solar
# Phone: 09460557874
# Sikar | 78/118
# Shree Shyam Computer
# Phone: 09414663693
# Sikar | 79/118
# BidSmart AI
# Phone:
# Sikar | 80/118
# TITAN - Indian Watch Company
# Phone: 09672430003
# Sikar | 81/118
# Dreamzone Sikar
# Phone: 08058866333
# Sikar | 82/118
# Swastik Watch Company
# Phone: 09694421667
# Sikar | 83/118
# Gaincafe technologies
# Phone:
# Sikar | 84/118
# Rise Skill Academy - Digital Marketing, Data Science & Web Development Institute in Sikar
# Phone: 08058214344
# Sikar | 85/118
# Strident info tech
# Phone:
# Sikar | 86/118
# Indian Computer & CCTV
# Phone: 09982990654
# Sikar | 87/118
# Karni Computers
# Phone: 09414036954
# Sikar | 88/118
# Motilal Oswal Financial Services Limited
# Phone: 07665409971
# Sikar | 89/118
# Hind Sports sikar
# Phone: 08233357335
# Sikar | 90/118
# Solution Computer & Services
# Phone: 09414424123
# Sikar | 91/118
# Sushil And Company - Mi Store
# Phone: 07597556016
# Sikar | 92/118
# Tirupati Software Infotech Pvt Ltd
# Phone: 09588840007
# Sikar | 93/118
# CAD CAM Experts
# Phone: 08432200339
# Sikar | 94/118
# Lapcare
# Phone: 09660311775
# Sikar | 95/118
# Poojara Telecom, Sikar, Rajasthan
# Phone: 09887480156
# Sikar | 96/118
# Shree Dwarka's JK Apple Repair Center
# Phone:
# Sikar | 97/118
# Anisant
# Phone:
# Sikar | 98/118
# TECHZONE COMPUTER
# Phone:
# Sikar | 99/118
# Titan Eye+ at Station Road, Sikar
# Phone: 01572256256
# Sikar | 100/118
# Shree ram high tech nasary
# Phone:
# Sikar | 101/118
# TVS Electronics Ltd-Jalan Compuworld
# Phone: 08045687944
# Sikar | 102/118
# Hi-tech focus english training academy ,sikar
# Phone: 09214335327
# Sikar | 103/118
# Samsung Experience Store Station Road
# Phone: 07737439969
# Sikar | 104/118
# JAGDAMBA LAPTOP CARE
# Phone: 09828404084
# Sikar | 105/118
# Advocate Sandeep Saini | Advocate in Sikar
# Phone: 09785358808
# Sikar | 106/118
# Tech Zone Computer
# Phone:
# Sikar | 107/118
# A2 Technosoft Company
# Phone: 07340010077
# Sikar | 108/118
# RatingFlow.in
# Phone:
# Sikar | 109/118
# vivo & iQOO Authorised Service Center
# Phone: 07412091312
# Sikar | 110/118
# My Jio Store
# Phone: 09082702644
# Sikar | 111/118
# Asian Paints Colourideas - Goyal Timber Trading Company
# Phone: 08071499740
# Sikar | 112/118
# Motilal Oswal Financial Services Limited
# Phone: 09731115146
# Sikar | 113/118
# Shree Balaji Computers & Repairing Center
# Phone: 09413338173
# Sikar | 114/118
# Airtel Store - Bus Stand Sikar
# Phone: 09810012345
# Sikar | 115/118
# Sikar Railway Station - Junction
# Phone:
# Sikar | 116/118
# Bhaag Gaadi Bhaag - The Moral Creations
# Phone: 08875540605
# Sikar | 117/118
# The Comeback Coder
# Phone:
# Sikar | 118/118
# DAY TECH INFIINITY SIKAR-Best Refurbished Laptop and desktops
# Phone:
#
# Searching: IT companies in Sikar Rajasthan
# Search Submitted
# Sikar | IT companies | Scroll 1 -> 14
# Sikar | IT companies | Scroll 2 -> 20
# Sikar | IT companies | Scroll 3 -> 27
# Sikar | IT companies | Scroll 4 -> 34
# Sikar | IT companies | Scroll 5 -> 40
# Sikar | IT companies | Scroll 6 -> 47
# Sikar | IT companies | Scroll 7 -> 54
# Sikar | IT companies | Scroll 8 -> 55
# Sikar | IT companies | Scroll 9 -> 55
# Sikar | IT companies | Scroll 10 -> 55
# Sikar | IT companies | Scroll 11 -> 55
# Sikar | IT companies | Scroll 12 -> 55
# Collected 16 links
# Sikar | 1/16
# B4 Dev
# Phone: 08003006602
# Sikar | 2/16
# Gale technical services private limited
# Phone: 09660389001
# Sikar | 3/16
# Aapno Digital Studio
# Phone: 09799493608
# Sikar | 4/16
# Sushil Sales Corporation
# Phone: 09309080001
# Sikar | 5/16
# SHEKHAWATI SOLUTION SERVICES PVT LTD
# Phone: 09828917776
# Sikar | 6/16
# Panwar Projects Pvt Ltd
# Phone: 09414039548
# Sikar | 7/16
# Designing Point
# Phone: 07737378739
# Sikar | 8/16
# DMW - Best Digital Marketing Agency in Sikar
# Phone: 09166615597
# Sikar | 9/16
# Satyendra Saini
# Phone: 09462337208
# Sikar | 10/16
# Pro Indies
# Phone: 09664305874
# Sikar | 11/16
# A.I. Space Designers & Construction – Best Architect, Engineer, interior & Home Designers In sikar
# Phone: 07891858430
# Sikar | 12/16
# Pakka Sauda Real Estate
# Phone: 09414036671
# Sikar | 13/16
# WE PRINT AND PRESS
# Phone: 09309363077
# Sikar | 14/16
# Vwraps, Sikar
# Phone: 09828283869
# Backup Saved
# Sikar | 15/16
# Indian Academy
# Phone: 09414314368
# Sikar | 16/16
# Dsuccessed - Best Digital Marketing AI Institute Sikar
# Phone:
#
# Searching: software companies in Sirohi Rajasthan
# Search Submitted
# Sirohi | software companies | Scroll 1 -> 14
# Sirohi | software companies | Scroll 2 -> 15
# Sirohi | software companies | Scroll 3 -> 15
# Sirohi | software companies | Scroll 4 -> 15
# ...
# Ekart Logistics
# Phone:
# Tonk | 28/65
# JBC Tonk - Royal Enfield Showroom
# Phone: 09773387002
# Tonk | 29/65
# Sarvatra Energy
# Phone: 08619495060
# Tonk | 30/65
# V-Mart - Tonk-Jaipur Road
# Phone: 07303486447
# Backup Saved
# Tonk | 31/65
# KAIZEN INNOVATION:C,C++,DSA,PYTHON,JAVA,PHP,FULLSTACK,AI,ML,AUTOCAD,3DSMAX,REVIT,SOLIDWORKS,CREO,PLC,SCADA,CODING, NEAR ME
# Phone: 09610992220
# Tonk | 32/65
# Rajasthan TV Center
# Phone: 09214363238
# Tonk | 33/65
