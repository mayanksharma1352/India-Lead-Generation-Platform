# %%
import pandas as pd

# %%
df = pd.read_csv("gujarat_companies.csv")

# %%
df.shape
# Out:
# (4081, 8)

# %%
df = df[
    df["Phone"].notna() & 
    (df["Phone"].astype(str).str.strip() != "")
    ]
df.shape
# Out:
# (3152, 8)

# %%
df = df[
    df["Company Name"].notna()
    ]

df = df[
    df["Company Name"].str.strip() != ""
    ]
df.shape
# Out:
# (3081, 8)

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]","",regex=True)
    .str.strip()
)

display(df[["Phone"]].head())
# Out:
#          Phone
# 0  72279061170
# 1  90990398450
# 2  78628497590
# 3  90999760340
# 4  76220812340

# %%
df.to_csv(
    "gujarat_companies_cleaned.csv",
    index=False
)
