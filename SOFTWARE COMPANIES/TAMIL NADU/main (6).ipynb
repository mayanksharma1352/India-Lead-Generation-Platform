# %%
import time
import random
import pandas as pd

from datetime import datetime

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.service import Service

from webdriver_manager.chrome import ChromeDriverManager



districts = [
    "Vellore",
    "Viluppuram",
    "Virudhunagar"
]



search_types = [
    "software companies",
    "IT companies"
]

options = webdriver.ChromeOptions()

options.add_argument("--start-maximized")

options.add_argument(
    "--disable-blink-features=AutomationControlled"
)

options.add_argument("--disable-notifications")


driver = webdriver.Chrome(

    service=Service(
        ChromeDriverManager().install()
    ),

    options=options
)


driver.get("https://www.google.com/maps")

print("Opening Google Maps...")

time.sleep(15)

print("Google Maps Loaded")



all_data = []

visited_links = set()


def get_search_box():

    selectors = [

        '//input[@id="searchboxinput"]',
        '//input[contains(@placeholder,"Search")]',
        '//input[contains(@aria-label,"Search")]',
        '//input'

    ]

    for selector in selectors:

        try:

            box = driver.find_element(
                By.XPATH,
                selector
            )

            return box

        except:
            pass

    return None


def extract_school_data():

    try:
        try:

            name = driver.find_element(
                By.TAG_NAME,
                "h1"
            ).text

        except:

            name = ""

  

        try:

            address = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"address")]'
            ).text

        except:

            address = ""

     

        phone = ""

        try:

            phone_xpaths = [

                '//button[contains(@data-item-id,"phone")]',

 
                '//a[contains(@href,"tel:")]',

  
                '//button[contains(@aria-label,"Phone")]',

                '//button[contains(text(),"+91")]',
                '//div[contains(text(),"+91")]',
                '//span[contains(text(),"+91")]'

            ]

            for xpath in phone_xpaths:

                try:

                    elements = driver.find_elements(
                        By.XPATH,
                        xpath
                    )

                    for element in elements:

                        text = element.text.strip()

                        href = (
                            element.get_attribute("href")
                            or ""
                        )

        
                        if "tel:" in href:

                            phone = href.replace(
                                "tel:",
                                ""
                            ).strip()

                        elif text:

                            phone = text

                        phone = (

                            phone.replace("", "")
                            .replace(" ", "")
                            .replace("-", "")
                            .replace("(", "")
                            .replace(")", "")
                            .replace("\n", "")
                            .strip()

                        )

                        digits = ''.join(
                            filter(str.isdigit, phone)
                        )

                        if len(digits) >= 10:

                            break

                    if phone:
                        break

                except:
                    pass

        except Exception as e:

            print(f"Phone Error: {e}")

        # WEBSITE

        try:

            website = driver.find_element(
                By.XPATH,
                '//a[contains(@data-item-id,"authority")]'
            ).get_attribute("href")

        except:

            website = ""



        try:

            rating = driver.find_element(
                By.XPATH,
                '//div[@role="img"]'
            ).get_attribute("aria-label")

        except:

            rating = ""

        return {

            "Company Name": name,
            "Address": address,
            "Phone": phone,
            "Website": website,
            "Rating": rating,
            "Google Maps URL": driver.current_url

        }

    except:

        return None



for district in districts:

    for search_type in search_types:

        try:

            query = (
                f"{search_type} "
                f"in {district} Tamil Nadu"
            )

            print(f"\nSearching: {query}")


            search_box = get_search_box()

            if not search_box:

                print("Search Box Not Found")

                continue

            ActionChains(driver).move_to_element(
                search_box
            ).click().perform()

            time.sleep(1)

            search_box.send_keys(
                Keys.CONTROL + "a"
            )

            time.sleep(1)

            search_box.send_keys(Keys.DELETE)

            time.sleep(1)



            for char in query:

                search_box.send_keys(char)

                time.sleep(0.03)

            search_box.send_keys(Keys.ENTER)

            print("Search Submitted")

            time.sleep(8)



            try:

                scrollable_div = driver.find_element(
                    By.XPATH,
                    '//div[@role="feed"]'
                )

                previous_count = 0

                stagnant = 0

                for i in range(100):

                    driver.execute_script(
                        """
                        arguments[0].scrollTop =
                        arguments[0].scrollHeight
                        """,
                        scrollable_div
                    )

                    time.sleep(4)

                    listings = driver.find_elements(
                        By.XPATH,
                        '//a[contains(@href,"/maps/place/")]'
                    )

                    current_count = len(listings)

                    print(
                        f"{district} | "
                        f"{search_type} | "
                        f"Scroll {i+1} -> "
                        f"{current_count}"
                    )

                    if current_count == previous_count:

                        stagnant += 1

                    else:

                        stagnant = 0

                    if stagnant >= 4:

                        break

                    previous_count = current_count

            except Exception as e:

                print(f"Scrolling Error: {e}")

    

            listings = driver.find_elements(
                By.XPATH,
                '//a[contains(@href,"/maps/place/")]'
            )

            links = []

            for listing in listings:

                try:

                    link = listing.get_attribute("href")

                    if (
                        link
                        and link not in visited_links
                    ):

                        links.append(link)

                        visited_links.add(link)

                except:
                    pass

            print(f"Collected {len(links)} links")

     

            for index, link in enumerate(links):

                try:

                    print(
                        f"{district} | "
                        f"{index+1}/{len(links)}"
                    )

                    driver.get(link)

                    time.sleep(
                        random.uniform(2, 3)
                    )

                    data = extract_school_data()

                    if data:

                        data["District"] = district

                        data["Search Type"] = search_type

                        all_data.append(data)

                        print(data["Company Name"])

                        print(
                            f"Phone: {data['Phone']}"
                        )
         
                    if len(all_data) % 100 == 0:

                        backup_df = pd.DataFrame(
                            all_data
                        )

                        backup_df.drop_duplicates(
                            subset=[
                                "Company Name",
                                "Google Maps URL"
                            ],
                            inplace=True
                        )

                        backup_df.to_csv(
                            "tamil_nadu_companies_backup.csv",
                            index=False
                        )

                        print("Backup Saved")

                except Exception as e:

                    print(
                        f"Company Error: {e}"
                    )

        except Exception as e:

            print(
                f"District Error: {e}"
            )

df = pd.DataFrame(all_data)

df.drop_duplicates(

    subset=[
        "Company Name",
        "Google Maps URL"
    ],

    inplace=True
)

filename = "tamil_nadu_companies.csv"

df.to_csv(
    filename,
    index=False
)

print("\nExtraction Completed")

print(
    f"Total Companies Extracted: {len(df)}"
)

print(f"\nSaved File: {filename}")

driver.quit()
# Out:
# Opening Google Maps...
# Google Maps Loaded
#
# Searching: software companies in Vellore Tamil Nadu
# Search Submitted
# Vellore | software companies | Scroll 1 -> 16
# Vellore | software companies | Scroll 2 -> 20
# Vellore | software companies | Scroll 3 -> 28
# Vellore | software companies | Scroll 4 -> 36
# Vellore | software companies | Scroll 5 -> 40
# Vellore | software companies | Scroll 6 -> 48
# Vellore | software companies | Scroll 7 -> 56
# Vellore | software companies | Scroll 8 -> 60
# Vellore | software companies | Scroll 9 -> 68
# Vellore | software companies | Scroll 10 -> 76
# Vellore | software companies | Scroll 11 -> 80
# Vellore | software companies | Scroll 12 -> 80
# Vellore | software companies | Scroll 13 -> 80
# Vellore | software companies | Scroll 14 -> 80
# Vellore | software companies | Scroll 15 -> 80
# Collected 80 links
# Vellore | 1/80
# Redback IT Solutions Private Limited
# Phone: 08189985559
# Vellore | 2/80
# Mckbytes Technologies
# Phone: 09994555962
# Vellore | 3/80
# Phone: 09840893294
# Vellore | 47/80
# Infolynx
# Phone: 08925093057
# Vellore | 48/80
# Zhee Tech Solutions
# Phone: 09710404234
# Vellore | 49/80
# 𝐂-𝐓𝐞𝐜𝐡 𝐄𝐧𝐠𝐢𝐧𝐞𝐞𝐫𝐢𝐧𝐠
# Phone: 07708844229
# Vellore | 50/80
# Bee's Media Tech
# Phone: 09843846400
# Vellore | 51/80
# Sun Computers 🖥
# Phone: 09944725975
# Vellore | 52/80
# KAYATech
# Phone: 09994821177
# Vellore | 53/80
# Vellore Institute of Technology
# Phone: 04446277555
# Vellore | 54/80
# SDOT TECHNOLOGIES
# Phone: 07402279989
# Vellore | 55/80
# POPULAR COMPUTER
# Phone: 09843822484
# Vellore | 56/80
# SEM TECH SOLUTION
# Phone: 09043424277
# Vellore | 57/80
# Vasavi Computers
# Phone: 09487527205
# Vellore | 58/80
# Noon Computers
# Phone: 08015606071
# Vellore | 59/80
# Stack app developers
# Phone:
# Vellore | 60/80
# Namma Vellore
# Phone:
# Vellore | 61/80
# Software Development Company in Vellore
# Phone: 09444254011
# Vellore | 62/80
# Hindustan Software Ltd
# Phone:
# Vellore | 63/80
# Kuberan Software Pvt Ltd
# Phone: 09677079222
# Vellore | 64/80
# DP Systems
# Phone:
# Vellore | 65/80
#
# Phone:
# Vellore | 66/80
# Blue Express Packers and Movers vellore - Top Packers and movers vellore
# Phone: 09787388142
# Vellore | 67/80
# Orchestrix AI
# Phone:
# Vellore | 68/80
# Menaka Card - Vellore(Company Outlet)
# Phone: 06385743334
# Vellore | 69/80
# San-Tech Service Centre
# Phone: 09994919876
# Vellore | 70/80
# Srinidhi Tours & Travels Vellore
# Phone: 09994268089
# Vellore | 71/80
# Unimoni Financial Services Ltd, Vellore
# Phone: 07594003166
# Vellore | 72/80
# Havells Galaxy - S M Trading Company
# Phone: 06746745364
# Vellore | 73/80
# BALAJI CAPRO EQUIPMENTS
# Phone: 09943471256
# Vellore | 74/80
# SRI VIGNESHWARA NET ZONE
# Phone: 09498849288
# Vellore | 75/80
# Poorvika Appliances Vellore. Buy Home & Kitchen Appliances, Ac, Tv, Fridge, Washing Machine, Laptops, Mobiles etc.
# Phone: 04443666666
# Vellore | 76/80
# SKYTRACK24X7 (Gps Vehicle Tracking, Security)
# Phone:
# Vellore | 77/80
# SMP Rock Salt
# Phone:
# Vellore | 78/80
# WildWolf'sTip LLP
# Phone: 09363088805
# Vellore | 79/80
# FINAL YEAR PROJECTS- NANO TECH, Vellore
# Phone: 09940990092
# Vellore | 80/80
# Zenstrix IT Consulting Services LLP
# Phone:
#
# Searching: IT companies in Vellore Tamil Nadu
# Search Submitted
# Vellore | IT companies | Scroll 1 -> 16
# Vellore | IT companies | Scroll 2 -> 20
# Vellore | IT companies | Scroll 3 -> 28
# Vellore | IT companies | Scroll 4 -> 36
# Vellore | IT companies | Scroll 5 -> 40
# Vellore | IT companies | Scroll 6 -> 48
# Vellore | IT companies | Scroll 7 -> 56
# Vellore | IT companies | Scroll 8 -> 60
# Vellore | IT companies | Scroll 9 -> 68
# Vellore | IT companies | Scroll 10 -> 76
# BUILDING DOCTOR VELLORE
# Phone: 09342911630
# Vellore | 36/65
# Nippon India Mutual Fund
# Phone: 18602660111
# Vellore | 37/65
# MKM TOURIST BUS Vellore
# Phone: 08610110638
# Vellore | 38/65
# T.S.Solar Power System
# Phone: 07708773300
# Vellore | 39/65
# New Star Doors
# Phone: 09842149993
# Vellore | 40/65
# Good Time Service
# Phone: 07339733909
# Vellore | 41/65
# Malabar Gold and Diamonds - Vellore
# Phone: 04162971916
# Vellore | 42/65
# Maya Call Taxi
# Phone: 04162224455
# Vellore | 43/65
# Sri Murugan Electricals- vellore texmo authorized dealer
# Phone: 09443327312
# Vellore | 44/65
# Titan Eye+ at Krishna Nagar, Vellore (Buy 1 Get 1 Free)
# Phone: 09150097744
# Vellore | 45/65
# VRK PVC DOORS
# Phone: 09894814104
# Vellore | 46/65
# VELLORE old bus stand
# Phone:
# Vellore | 47/65
# Infinity Building Solutions | Construction Chemicals | Waterproofing & Gypsum Plastering Services in Vellore
# Phone: 09047525154
# Vellore | 48/65
# NAUKRI.COM
# Phone: 09003036035
# Vellore | 49/65
# VSY Gold Loan
# Phone: 04162997704
# Vellore | 50/65
# SPARK SIGN
# Phone: 08110000274
# Vellore | 51/65
# Magnum Cookware Company
# Phone: 09688212222
# Vellore | 52/65
# JewelOne Vellore
# Phone: 08220017614
# Vellore | 53/65
# NEXT STEP ACADEMY-NEET & IIT-JEE TRAINERS
# Phone: 09952823627
# Vellore | 54/65
# Sindu Screens & Graphics
# Phone: 04162224555
# Vellore | 55/65
# Hanuman Call Taxi Vellore - Taxi Services in Vellore
# Phone: 04162999669
# Vellore | 56/65
# G.K.POWER
# Phone: 07904090106
# Vellore | 57/65
# Step Stone Construction
# Phone: 09902512600
# Vellore | 58/65
# JEYVANTH SILKS & SAREES
# Phone: 09976242542
# Vellore | 59/65
# Sri Lakshmi Fire and safety equipments Vellore
# Phone: 09600725981
# Vellore | 60/65
# Prasannaa Tradings Vellore
# Phone: 09488533999
# Vellore | 61/65
# Babyhug Store Vellore Officers Line
# Phone: 07397861194
# Vellore | 62/65
# KP PRINTSET
# Phone: 04164204114
# Vellore | 63/65
# Tamil Matrimony, part of Matrimony Group - Vellore
# Phone: 06366528210
# Vellore | 64/65
# SRI SIVAM SHAKTHI
# Phone: 09014883435
# Vellore | 65/65
# Aadwell Advertising Agencies Private Limited
# Phone:
#
# Searching: software companies in Viluppuram Tamil Nadu
# Search Submitted
# Viluppuram | software companies | Scroll 1 -> 16
# Viluppuram | software companies | Scroll 2 -> 20
# Viluppuram | software companies | Scroll 3 -> 28
# Viluppuram | software companies | Scroll 4 -> 36
# Viluppuram | software companies | Scroll 5 -> 40
# Viluppuram | software companies | Scroll 6 -> 48
# Viluppuram | software companies | Scroll 7 -> 49
# Viluppuram | software companies | Scroll 8 -> 49
# Viluppuram | software companies | Scroll 9 -> 49
# Viluppuram | software companies | Scroll 10 -> 49
# Viluppuram | software companies | Scroll 11 -> 49
# Collected 49 links
# Viluppuram | 1/49
# Vaazhi Software Solutions Pvt Ltd OPC
# Phone: 04146350351
# Viluppuram | 2/49
# Simplita AI Technologies Private Limited
# Phone: 09944000542
# Viluppuram | 45/49
# Godwins infotech
# Phone:
# Viluppuram | 46/49
# Dell Exclusive Store - Villupuram
# Phone: 08048008554
# Viluppuram | 47/49
# wolfa tech
# Phone:
# Viluppuram | 48/49
# Microbotware Technology
# Phone: 09443097602
# Viluppuram | 49/49
# Z3 Med Pvt Ltd
# Phone: 09884437137
#
# Searching: IT companies in Viluppuram Tamil Nadu
# Search Submitted
# Viluppuram | IT companies | Scroll 1 -> 16
# Viluppuram | IT companies | Scroll 2 -> 20
# Viluppuram | IT companies | Scroll 3 -> 28
# Viluppuram | IT companies | Scroll 4 -> 36
# Viluppuram | IT companies | Scroll 5 -> 36
# Viluppuram | IT companies | Scroll 6 -> 36
# Viluppuram | IT companies | Scroll 7 -> 36
# Viluppuram | IT companies | Scroll 8 -> 36
# Collected 6 links
# Viluppuram | 1/6
# Poorvika Mobiles Villupuram - Opposite Veeravazhi Amman Temple
# Phone: 04443666666
# Viluppuram | 2/6
# Darling Retail - Electronics, Mobile & Furniture Shop - Villupuram
# Phone: 08220864444
# Viluppuram | 3/6
# Aqua engineering services
# Phone: 06369410298
# Viluppuram | 4/6
# Deccan Iservices
# Phone:
# Viluppuram | 5/6
# Darling Retail
# Phone: 08220864444
# Viluppuram | 6/6
# INNOVOTRONICS
# Phone: 09655244999
# Backup Saved
#
# Searching: software companies in Virudhunagar Tamil Nadu
# Search Submitted
# Virudhunagar | software companies | Scroll 1 -> 16
# Virudhunagar | software companies | Scroll 2 -> 20
# Virudhunagar | software companies | Scroll 3 -> 28
# Virudhunagar | software companies | Scroll 4 -> 36
# Virudhunagar | software companies | Scroll 5 -> 40
# Virudhunagar | software companies | Scroll 6 -> 48
# Virudhunagar | software companies | Scroll 7 -> 56
# Virudhunagar | software companies | Scroll 8 -> 60
# Virudhunagar | software companies | Scroll 9 -> 68
# Virudhunagar | software companies | Scroll 10 -> 76
# Virudhunagar | software companies | Scroll 11 -> 80
# Virudhunagar | software companies | Scroll 12 -> 88
# Virudhunagar | software companies | Scroll 13 -> 94
# Virudhunagar | software companies | Scroll 14 -> 94
# Virudhunagar | software companies | Scroll 15 -> 94
# Virudhunagar | software companies | Scroll 16 -> 94
# Virudhunagar | software companies | Scroll 17 -> 94
# Collected 94 links
# Virudhunagar | 1/94
# LAMDA Tech Softics
# Phone: 08220086261
# Virudhunagar | 2/94
# Barbikan Technologies Private Limited
# Phone: 08807976266
# Virudhunagar | 3/94
# ZENTEXUS TECHNOLOGIES
# Phone: 09042222080
# Virudhunagar | 4/94
# TINY INFO TECH
# Phone:
# Virudhunagar | 5/94
# Kamaraj Software Solutions
# Phone: 09486823701
# Virudhunagar | 6/94
# Software development and graphic design
# Phone: 07339541406
# Virudhunagar | 7/94
# Balabros Software Solutions
# Phone: 09442661650
# Virudhunagar | 8/94
# SuperBotics MultiTech Private Limited
# Phone: 09488723118
# Virudhunagar | 9/94
# Pg Analytics Virudhunagar
# Phone: 07200011777
# Virudhunagar | 10/94
# Tally BoT & AD soft Tech
# Phone: 08248440191
# Virudhunagar | 11/94
# Rohil Technologies
# Phone:
# Virudhunagar | 12/94
# Virudhunagar | 92/94
# Mindapt
# Phone:
# Virudhunagar | 93/94
# Hi Tech Buildres
# Phone:
# Virudhunagar | 94/94
# HiTECH
# Phone:
#
# Searching: IT companies in Virudhunagar Tamil Nadu
# Search Submitted
# Virudhunagar | IT companies | Scroll 1 -> 16
# Virudhunagar | IT companies | Scroll 2 -> 20
# Virudhunagar | IT companies | Scroll 3 -> 28
# Virudhunagar | IT companies | Scroll 4 -> 36
# Virudhunagar | IT companies | Scroll 5 -> 40
# Virudhunagar | IT companies | Scroll 6 -> 48
# Virudhunagar | IT companies | Scroll 7 -> 56
# Virudhunagar | IT companies | Scroll 8 -> 60
# Virudhunagar | IT companies | Scroll 9 -> 68
# Virudhunagar | IT companies | Scroll 10 -> 68
# Virudhunagar | IT companies | Scroll 11 -> 68
# Virudhunagar | IT companies | Scroll 12 -> 68
# Virudhunagar | IT companies | Scroll 13 -> 68
# Collected 22 links
# Virudhunagar | 1/22
# Sathya Agencies, Virudhunagar1- Electronics and Home Appliances Store - Buy Latest Mobiles, AC, LED TV, Washing Machine etc.
# Phone: 07305956985
# Virudhunagar | 2/22
# Bala Electronics
# Phone: 08220335536
# Virudhunagar | 3/22
# Titan World - Sivagami Puram, Virudhunagar
# Phone: 08062914407
# Virudhunagar | 4/22
# Sathya Agencies, Virudhunagar2 - Electronics and Home Appliances Store - Buy Latest Mobiles, AC, LED TV, Washing Machine etc.
# Phone: 09994948985
# Virudhunagar | 5/22
# Maami Foods Private Limited
# Phone: 04562267838
# Virudhunagar | 6/22
# VVV & SONS EDIBLE OILS LIMITED
# Phone: 09750955446
# Backup Saved
# Virudhunagar | 7/22
# Thillais Masala
# Phone: 04562245024
# Virudhunagar | 8/22
# Idhayam sesame plant 1
# Phone: 09443755789
# Virudhunagar | 9/22
# A2L Engineering Consultants
# Phone: 08098070670
# Virudhunagar | 10/22
# SPC - Senthil Plastic Containers Private Limited
# Phone: 08903286199
# Virudhunagar | 11/22
# V.D.G. STEEL AGENCY (Salladai Company, Sieves Manufacturer)
# Phone: 09366611009
# Virudhunagar | 12/22
# Xpress Digital Marketing
# Phone: 08220128611
# Virudhunagar | 13/22
# Adshub Media | Best Digital Marketing Company | Best Social Media Marketing Company
# Phone: 07708998536
# Virudhunagar | 14/22
# THE PENINSULAR EXPORT COMPANY
# Phone: 09500722911
# Virudhunagar | 15/22
# SPT GLOBAL TELECOM SERVIES
# Phone: 08300131417
# Virudhunagar | 16/22
# Aambal Agricultural Solutions
# Phone: 09626661000
# Virudhunagar | 17/22
# SK BUILDERS & ARCHITECT
# Phone: 09942449498
# Virudhunagar | 18/22
# PASUMARK - Edible Oil Manufacturers
# Phone: 04562243575
# Virudhunagar | 19/22
# Cosmo Graphix
# Phone:
# Virudhunagar | 20/22
# Mercury fibre internet
# Phone: 09092925450
# Virudhunagar | 21/22
# Titan Eye+ at Aruppukkottai Road, Virudhunagar (Buy 1 Get 1 Free)
# Phone: 07339296096
# Virudhunagar | 22/22
# Anand & Co(T.V & Furniture's)
# Phone: 09487517114
#
# Extraction Completed
# Total Companies Extracted: 316
#
# Saved File: tamil_nadu_companies.csv
