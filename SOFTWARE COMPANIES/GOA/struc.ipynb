# %%
import pandas as pd

# %%
df = pd.read_csv("goa_companies.csv")

# %%
df.shape
# Out:
# (188, 8)

# %%
df = df[
    df["Phone"].notna() & 
    (df["Phone"].astype(str).str.strip() != "")
    ]
df.shape
# Out:
# (121, 8)

# %%
df = df[
    df["Company Name"].notna()
    ]

df = df[
    df["Company Name"].str.strip() != ""
    ]
df.shape
# Out:
# (119, 8)

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]","",regex=True)
    .str.strip()
)

display(df[["Phone"]].head())
# Out:
#          Phone
# 0  91452464640
# 1  95454106960
# 2  91371771620
# 3  98221225510
# 4  97654100200

# %%
df.to_csv(
    "goa_companies_cleaned.csv",
    index=False
)
