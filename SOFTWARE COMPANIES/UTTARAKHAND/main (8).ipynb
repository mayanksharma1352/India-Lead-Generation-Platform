# %%
import time
import random
import pandas as pd

from datetime import datetime

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.service import Service

from webdriver_manager.chrome import ChromeDriverManager


districts = [

    "Almora",
    "Bageshwar",
    "Chamoli",
    "Champawat",
    "Dehradun",
    "Haridwar",
    "Nainital",
    "Pauri Garhwal",
    "Pithoragarh",
    "Rudraprayag",
    "Tehri Garhwal",
    "Udham Singh Nagar",
    "Uttarkashi"

]



search_types = [
    "software companies",
    "IT companies"
]


options = webdriver.ChromeOptions()

options.add_argument("--start-maximized")

options.add_argument(
    "--disable-blink-features=AutomationControlled"
)

options.add_argument("--disable-notifications")


driver = webdriver.Chrome(

    service=Service(
        ChromeDriverManager().install()
    ),

    options=options
)


driver.get("https://www.google.com/maps")

print("Opening Google Maps...")

time.sleep(15)

print("Google Maps Loaded")



all_data = []

visited_links = set()

# SEARCH BOX FUNCTION

def get_search_box():

    selectors = [

        '//input[@id="searchboxinput"]',
        '//input[contains(@placeholder,"Search")]',
        '//input[contains(@aria-label,"Search")]',
        '//input'

    ]

    for selector in selectors:

        try:

            box = driver.find_element(
                By.XPATH,
                selector
            )

            return box

        except:
            pass

    return None


def extract_school_data():

    try:
        try:

            name = driver.find_element(
                By.TAG_NAME,
                "h1"
            ).text

        except:

            name = ""


        try:

            address = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"address")]'
            ).text

        except:

            address = ""



        phone = ""

        try:

            phone_xpaths = [

                '//button[contains(@data-item-id,"phone")]',

                '//a[contains(@href,"tel:")]',

                '//button[contains(@aria-label,"Phone")]',

                '//button[contains(text(),"+91")]',
                '//div[contains(text(),"+91")]',
                '//span[contains(text(),"+91")]'

            ]

            for xpath in phone_xpaths:

                try:

                    elements = driver.find_elements(
                        By.XPATH,
                        xpath
                    )

                    for element in elements:

                        text = element.text.strip()

                        href = (
                            element.get_attribute("href")
                            or ""
                        )

                        if "tel:" in href:

                            phone = href.replace(
                                "tel:",
                                ""
                            ).strip()

                        elif text:

                            phone = text

                        phone = (

                            phone.replace("", "")
                            .replace(" ", "")
                            .replace("-", "")
                            .replace("(", "")
                            .replace(")", "")
                            .replace("\n", "")
                            .strip()

                        )

                        digits = ''.join(
                            filter(str.isdigit, phone)
                        )

                        if len(digits) >= 10:

                            break

                    if phone:
                        break

                except:
                    pass

        except Exception as e:

            print(f"Phone Error: {e}")


        try:

            website = driver.find_element(
                By.XPATH,
                '//a[contains(@data-item-id,"authority")]'
            ).get_attribute("href")

        except:

            website = ""

        try:

            rating = driver.find_element(
                By.XPATH,
                '//div[@role="img"]'
            ).get_attribute("aria-label")

        except:

            rating = ""

        return {

            "Company Name": name,
            "Address": address,
            "Phone": phone,
            "Website": website,
            "Rating": rating,
            "Google Maps URL": driver.current_url

        }

    except:

        return None

for district in districts:

    for search_type in search_types:

        try:

            query = (
                f"{search_type} "
                f"in {district} Uttarakhand"
            )

            print(f"\nSearching: {query}")

 

            search_box = get_search_box()

            if not search_box:

                print("Search Box Not Found")

                continue

            ActionChains(driver).move_to_element(
                search_box
            ).click().perform()

            time.sleep(1)

            search_box.send_keys(
                Keys.CONTROL + "a"
            )

            time.sleep(1)

            search_box.send_keys(Keys.DELETE)

            time.sleep(1)

 
            for char in query:

                search_box.send_keys(char)

                time.sleep(0.03)

            search_box.send_keys(Keys.ENTER)

            print("Search Submitted")

            time.sleep(8)



            try:

                scrollable_div = driver.find_element(
                    By.XPATH,
                    '//div[@role="feed"]'
                )

                previous_count = 0

                stagnant = 0

                for i in range(100):

                    driver.execute_script(
                        """
                        arguments[0].scrollTop =
                        arguments[0].scrollHeight
                        """,
                        scrollable_div
                    )

                    time.sleep(4)

                    listings = driver.find_elements(
                        By.XPATH,
                        '//a[contains(@href,"/maps/place/")]'
                    )

                    current_count = len(listings)

                    print(
                        f"{district} | "
                        f"{search_type} | "
                        f"Scroll {i+1} -> "
                        f"{current_count}"
                    )

                    if current_count == previous_count:

                        stagnant += 1

                    else:

                        stagnant = 0

                    if stagnant >= 4:

                        break

                    previous_count = current_count

            except Exception as e:

                print(f"Scrolling Error: {e}")

       
            listings = driver.find_elements(
                By.XPATH,
                '//a[contains(@href,"/maps/place/")]'
            )

            links = []

            for listing in listings:

                try:

                    link = listing.get_attribute("href")

                    if (
                        link
                        and link not in visited_links
                    ):

                        links.append(link)

                        visited_links.add(link)

                except:
                    pass

            print(f"Collected {len(links)} links")



            for index, link in enumerate(links):

                try:

                    print(
                        f"{district} | "
                        f"{index+1}/{len(links)}"
                    )

                    driver.get(link)

                    time.sleep(
                        random.uniform(2, 3)
                    )

                    data = extract_school_data()

                    if data:

                        data["District"] = district

                        data["Search Type"] = search_type

                        all_data.append(data)

                        print(data["Company Name"])

                        print(
                            f"Phone: {data['Phone']}"
                        )

     

                    if len(all_data) % 100 == 0:

                        backup_df = pd.DataFrame(
                            all_data
                        )

                        backup_df.drop_duplicates(
                            subset=[
                                "Company Name",
                                "Google Maps URL"
                            ],
                            inplace=True
                        )

                        backup_df.to_csv(
                            "uttarakhand_companies_backup.csv",
                            index=False
                        )

                        print("Backup Saved")

                except Exception as e:

                    print(
                        f"Company Error: {e}"
                    )

        except Exception as e:

            print(
                f"District Error: {e}"
            )



df = pd.DataFrame(all_data)

df.drop_duplicates(

    subset=[
        "Company Name",
        "Google Maps URL"
    ],

    inplace=True
)

filename = "uttarakhand_companies.csv"

df.to_csv(
    filename,
    index=False
)

print("\nExtraction Completed")

print(
    f"Total Companies Extracted: {len(df)}"
)

print(f"\nSaved File: {filename}")

driver.quit()
# Out:
# Opening Google Maps...
# Google Maps Loaded
#
# Searching: software companies in Almora Uttarakhand
# Search Submitted
# Almora | software companies | Scroll 1 -> 16
# Almora | software companies | Scroll 2 -> 20
# Almora | software companies | Scroll 3 -> 20
# Almora | software companies | Scroll 4 -> 20
# Almora | software companies | Scroll 5 -> 20
# Almora | software companies | Scroll 6 -> 20
# Collected 20 links
# Almora | 1/20
# CAPSCOM TECHNOLOGY Private Limited
# Phone: 07579237515
# Almora | 2/20
# Tech Features
# Phone:
# Almora | 3/20
# Webgear Techno Services LLP
# Phone: 09690545965
# Almora | 4/20
# SARASUK TECH PRIVATE LIMITED
# Phone:
# Almora | 5/20
# Jan Milap Computer Education Centre Almora
# Phone: 09411794388
# Almora | 6/20
# Gurudev Kripa Computech
# Phone: 08394866779
# Almora | 7/20
# Website Development, IT Support in Almora
# Phone: 08938041557
# Almora | 8/20
# H C Fulara Technologies
# Phone: 09129784584
# Almora | 9/20
# AlmoraStore.com
# Phone:
# Almora | 10/20
# Arohar Technologies Private Limited
# Phone: 07017179208
# Almora | 11/20
# OM COMPUTERS
# Phone: 05962232825
# Almora | 12/20
# Rural Broadband Pvt Ltd (AirJaldi Almora)
# Phone: 08580941413
# Almora | 13/20
# Auris Studio®
# Phone:
# Almora | 14/20
# Highpolar Softwares
# Phone: 08218295677
# Almora | 15/20
# Freelancer Rajat Adhikari
# Phone:
# Almora | 16/20
# SAI INSTITUTE OF ADVANCE STUDIES ALMORA
# Phone: 09410160704
# Almora | 17/20
# Motilal Oswal Financial Services Limited
# Phone: 09731021139
# Almora | 18/20
# GN Radar
# Phone:
# Almora | 19/20
# Total Software Solution
# Phone:
# Almora | 20/20
# ICONIC SOFTWARE SOLUTION
# Phone: 07060582117
#
# Searching: IT companies in Almora Uttarakhand
# Search Submitted
# Almora | IT companies | Scroll 1 -> 16
# Almora | IT companies | Scroll 2 -> 20
# Almora | IT companies | Scroll 3 -> 28
# Almora | IT companies | Scroll 4 -> 36
# Almora | IT companies | Scroll 5 -> 40
# Almora | IT companies | Scroll 6 -> 48
# Almora | IT companies | Scroll 7 -> 56
# Almora | IT companies | Scroll 8 -> 60
# Almora | IT companies | Scroll 9 -> 68
# Almora | IT companies | Scroll 10 -> 76
# Almora | IT companies | Scroll 11 -> 80
# Almora | IT companies | Scroll 12 -> 88
# Almora | IT companies | Scroll 13 -> 96
# Almora | IT companies | Scroll 14 -> 96
# Almora | IT companies | Scroll 15 -> 96
# Almora | IT companies | Scroll 16 -> 96
# Almora | IT companies | Scroll 17 -> 96
# Collected 87 links
# Almora | 1/87
# NAV UDAY EDUVERSITY
# Phone: 07466065927
# Almora | 2/87
# Baba Agrotech | The BIO Valley Experiential Store | Startup Adda | Mushroom store
# Phone: 09718497425
# Almora | 3/87
# Gupta Electronics
# Phone: 07895887544
# Almora | 4/87
# Srigar Infra
# Phone: 09634028615
# Almora | 5/87
# the insight trips
# Phone: 09997946307
# Almora | 6/87
# Aanjaneya Printers
# Phone: 09411118814
# Almora | 7/87
# Sijwali complex
# Phone: 09411333222
# Almora | 8/87
# NSEIT Almora
# Phone:
# Almora | 9/87
# Tumbledry Dry Clean & Laundry Service
# Phone: 07677250250
# Almora | 10/87
# K M O U Ltd.
# Phone: 09410501878
# Almora | 11/87
# SOS Organics Natural Cosmetics And Organic Health Food
# Phone: 09719849569
# Almora | 12/87
# UTTRA NEWS (उत्तरा न्यूज ) number one web portal in uttarakhand
# Phone: 09412976939
# Almora | 13/87
# Zen Oaks Home Stay
# Phone: 07579105105
# Bageshwar | 8/24
# MAJILA CSC CENTER
# Phone: 07617695572
# Bageshwar | 9/24
# Tumbledry Dry Clean & Laundry Service
# Phone: 07677250250
# Bageshwar | 10/24
# Dev_bhumi_ pixel photo studio
# Phone: 07037899195
# Bageshwar | 11/24
# CCiT COMPUTER
# Phone: 09456397680
# Bageshwar | 12/24
# Dayal Joshi traders deep agency
# Phone: 09719833877
# Bageshwar | 13/24
# Hemuinfotech
# Phone:
# Bageshwar | 14/24
# Bageshwar Taxi Services
# Phone: 09012390565
# Bageshwar | 15/24
# Balaji Electronics and Musical Store
# Phone:
# Bageshwar | 16/24
# The Pahadi Pixel
# Phone: 09761370016
# Bageshwar | 17/24
# Cynoteck Technology Solutions
# Phone: 01352608366
# Bageshwar | 18/24
# Hotel Prashant Bageshwar
# Phone: 09927787777
# Bageshwar | 19/24
# Evon Technologies
# Phone: 08266041801
# Bageshwar | 20/24
# Rubico IT Private Limited
# Phone: 08077294237
# Bageshwar | 21/24
# Shikhar Study Centre & Digital Library
# Phone: 08393831234
# Bageshwar | 22/24
# Raysteeds Infotech Private Limited - Leading Global IT Services Provider Company
# Phone: 09389950561
# Bageshwar | 23/24
# TERC (टीआरसी)
# Phone: 08439142759
# Bageshwar | 24/24
# Lithionix Software
# Phone: 09627941300
#
# Searching: IT companies in Bageshwar Uttarakhand
# Search Submitted
# Bageshwar | IT companies | Scroll 1 -> 16
# Bageshwar | IT companies | Scroll 2 -> 20
# Bageshwar | IT companies | Scroll 3 -> 26
# Bageshwar | IT companies | Scroll 4 -> 26
# Bageshwar | IT companies | Scroll 5 -> 26
# Bageshwar | IT companies | Scroll 6 -> 26
# Bageshwar | IT companies | Scroll 7 -> 26
# Collected 8 links
# Bageshwar | 1/8
# SAINIK COMPUTER CENTRE (CSC)
# Phone: 08057431987
# Bageshwar | 2/8
# Mayank Hardware and Software Solutions
# Phone: 09557616459
# Bageshwar | 3/8
# Bagnath Temple, Bageshwar
# Phone:
# Bageshwar | 4/8
# Rawal Csc Centre & Repairing Centre
# Phone: 08218086118
# Bageshwar | 5/8
# TRENDS
# Phone: 09958783684
# Bageshwar | 6/8
# ISHT DEV JAN SEVA KENDRA
# Phone: 07457011083
# Bageshwar | 7/8
# Omaira Beauty Hub , beauty Parlour Bageshwar
# Phone: 08006353804
# Bageshwar | 8/8
# Bageshwar Bus Station
# Phone:
#
# Searching: software companies in Chamoli Uttarakhand
# Search Submitted
# Chamoli | software companies | Scroll 1 -> 7
# Chamoli | software companies | Scroll 2 -> 7
# Chamoli | software companies | Scroll 3 -> 7
# Chamoli | software companies | Scroll 4 -> 7
# Chamoli | software companies | Scroll 5 -> 7
# Collected 4 links
# Chamoli | 1/4
# Rubico IT Private Limited
# Phone: 07078707722
# Chamoli | 2/4
# Shad Mobile Repair
# Phone:
# Chamoli | 3/4
# Crux Sphere Technologies Private Limited
# Phone:
# Chamoli | 4/4
# Tech services Computer
# Phone:
#
# Searching: IT companies in Chamoli Uttarakhand
# Chamoli | 80/83
# Fernweh Fair Travel
# Phone: +4915151141261
# Chamoli | 81/83
# Shrijakhprinting&boxnirman
# Phone:
# Chamoli | 82/83
# Himalayan Dona pattal
# Phone:
# Chamoli | 83/83
# AMBEY HARDWARE & PAINTS
# Phone:
#
# Searching: software companies in Champawat Uttarakhand
# Search Submitted
# Champawat | software companies | Scroll 1 -> 16
# Champawat | software companies | Scroll 2 -> 20
# Champawat | software companies | Scroll 3 -> 20
# Champawat | software companies | Scroll 4 -> 20
# Champawat | software companies | Scroll 5 -> 20
# Champawat | software companies | Scroll 6 -> 20
# Collected 17 links
# Champawat | 1/17
# Smart computer point Champawat
# Phone: 09720990163
# Champawat | 2/17
# SAI INFOCOM COMPUTER & IT SALES SHOP
# Phone: 09012222299
# Champawat | 3/17
# UttaraOnline
# Phone: 09675306989
# Champawat | 4/17
# The champawat wale (Sony rechage point) MI store
# Phone:
# Champawat | 5/17
# Customized Gift Solution
# Phone: 08475943719
# Champawat | 6/17
# Bus Station Champawat
# Phone:
# Champawat | 7/17
# Tiwari Electro World
# Phone: 09897559912
# Champawat | 8/17
# 83MQ+74P Champawat, Uttarakhand
# Phone:
# Champawat | 9/17
# Durga Shakti Crockery Center(DSCC)
# Phone: 07253808884
# Champawat | 10/17
# Gaurav Electricals
# Phone: 09410567504
# Champawat | 11/17
# Thwal Electricals and Electronics
# Phone: 08700533512
# Champawat | 12/17
# Telephone Exchange
# Phone:
# Champawat | 13/17
# Block colony Champawat
# Phone:
# Champawat | 14/17
# Gaurav Furniture
# Phone: 09837320356
# Champawat | 15/17
# Mehta Travels
# Phone:
# Champawat | 16/17
# Delhivery Courier Service
# Phone:
# Champawat | 17/17
# Prince Joshi
# Phone: 07668187737
#
# Searching: IT companies in Champawat Uttarakhand
# Search Submitted
# Champawat | IT companies | Scroll 1 -> 16
# Champawat | IT companies | Scroll 2 -> 18
# Champawat | IT companies | Scroll 3 -> 18
# Champawat | IT companies | Scroll 4 -> 18
# Champawat | IT companies | Scroll 5 -> 18
# Champawat | IT companies | Scroll 6 -> 18
# Collected 7 links
# Champawat | 1/7
# Narmada Infosys
# Phone: +9779849849525
# Champawat | 2/7
# Sahayog Multistate - CHAMPAWAT BRANCH
# Phone: 08327278888
# Champawat | 3/7
# MAA BARAHI COMPUTER ZONE
# Phone: 08171694051
# Champawat | 4/7
# Henry Waterfall
# Phone: 08882549020
# Champawat | 5/7
# RAJPURA
# Phone: 08882483910
# Champawat | 6/7
# COMPUTER POINT I.T.WORLD
# Phone: 09412929975
# Champawat | 7/7
# Max Digital Solutions
# Phone:
#
# Searching: software companies in Dehradun Uttarakhand
# Search Submitted
# Dehradun | software companies | Scroll 1 -> 16
# Dehradun | software companies | Scroll 2 -> 20
# Dehradun | software companies | Scroll 3 -> 28
# Dehradun | software companies | Scroll 4 -> 36
# Dehradun | software companies | Scroll 5 -> 40
# Dehradun | software companies | Scroll 6 -> 48
# Dehradun | software companies | Scroll 7 -> 56
# Dehradun | software companies | Scroll 8 -> 60
# Dehradun | 16/18
# The Reallsters-Property Dealers
# Phone: 09412051495
# Dehradun | 17/18
# LLOYD Dehradun
# Phone:
# Dehradun | 18/18
# BDot Techmech Management & Multiservices Pvt Ltd.
# Phone: 08273972333
#
# Searching: software companies in Haridwar Uttarakhand
# Search Submitted
# Haridwar | software companies | Scroll 1 -> 16
# Haridwar | software companies | Scroll 2 -> 20
# Haridwar | software companies | Scroll 3 -> 28
# Haridwar | software companies | Scroll 4 -> 36
# Haridwar | software companies | Scroll 5 -> 40
# Haridwar | software companies | Scroll 6 -> 45
# Haridwar | software companies | Scroll 7 -> 45
# Haridwar | software companies | Scroll 8 -> 45
# Haridwar | software companies | Scroll 9 -> 45
# Haridwar | software companies | Scroll 10 -> 45
# Collected 39 links
# Haridwar | 1/39
# Digital Global Solutions
# Phone: 09412903399
# Haridwar | 2/39
# Website Designing, Development & E-Commerce Portal Development Haridwar - Modi Infotech Services IT Company
# Phone: 09897482222
# Haridwar | 3/39
# Techpyro | web design | web development | app development | app design | Devops | web hosting company
# Phone: 07300639790
# Haridwar | 4/39
# Website Designer in Haridwar | Digital Marketing Service in Haridwar | Zolonix Infosoft
# Phone: 09068472032
# Haridwar | 5/39
# Tech Yard Labs | Best Digital Marketing, Website Development & SEO Company in Haridwar
# Phone: 07668821011
# Haridwar | 6/39
# NICE SOFT TECH
# Phone: 09917773111
# Haridwar | 7/39
# IT Visual Solutions
# Phone: 08535020107
# Haridwar | 8/39
# Limelox Technologies
# Phone: 08791055110
# Haridwar | 9/39
# Bill Dev
# Phone: 08588808388
# Haridwar | 10/39
# ✅𝗢𝗡𝗦 𝗜𝗻𝘁𝗲𝗿𝗮𝗰𝘁𝗶𝘃𝗲 | Best Digital Marketing Agency | IT Company | Website Development | Advertisement | SEO
# Phone: 08923431450
# Haridwar | 11/39
# Baba Deep Singh infotech(BDS Infotech)
# Phone:
# Haridwar | 12/39
# Concientech IT Solutions LLP
# Phone: 09899636902
# Haridwar | 13/39
# Webasterix Technologies
# Phone: 08077812747
# Haridwar | 14/39
# OM IT WORKS (omitworks.in) - Website, ERP, CRM, SEO, SMO, PPC Online Promotion and Digital Marketing
# Phone:
# Haridwar | 15/39
# COMPROG TECNOLOGY PVT LTD
# Phone: 09368788889
# Haridwar | 16/39
# Sawariya Web Solution
# Phone: 09458170111
# Haridwar | 17/39
# CloudOps Innovation
# Phone:
# Backup Saved
# Haridwar | 18/39
# Rantox Digital | Website Designing, Software & Mobile Apps Development, Digital Marketing Company in Haridwar
# Phone: 09627605151
# Haridwar | 19/39
# Digilopment
# Phone: 09411164084
# Haridwar | 20/39
# MASCOT HEALTH SERIES PVT LTD
# Phone: 01334239586
# Haridwar | 21/39
# Pil Pharmaceuticals Limited
# Phone: 01334660800
# Haridwar | 22/39
# Ftechiz Solutions Pvt Ltd
# Phone: 07895372337
# Haridwar | 23/39
# Tech Yard Academy | Best Digital Marketing Institute, Website Development Institute in Haridwar
# Phone: 07668821011
# Haridwar | 24/39
# Nainital | 9/9
# Join ShinePoints Team – Sales Manager Vacancies Open
# Phone:
#
# Searching: IT companies in Nainital Uttarakhand
# Search Submitted
# Nainital | IT companies | Scroll 1 -> 4
# Nainital | IT companies | Scroll 2 -> 4
# Nainital | IT companies | Scroll 3 -> 4
# Nainital | IT companies | Scroll 4 -> 4
# Nainital | IT companies | Scroll 5 -> 4
# Collected 2 links
# Nainital | 1/2
# CSC Center Nainital VIBGYOR CYBER DEN
# Phone:
# Nainital | 2/2
# Evershine Computers, Nainital
# Phone: 09412040300
#
# Searching: software companies in Pauri Garhwal Uttarakhand
# Search Submitted
# Pauri Garhwal | software companies | Scroll 1 -> 11
# Pauri Garhwal | software companies | Scroll 2 -> 11
# Pauri Garhwal | software companies | Scroll 3 -> 11
# Pauri Garhwal | software companies | Scroll 4 -> 11
# Pauri Garhwal | software companies | Scroll 5 -> 11
# Collected 5 links
# Pauri Garhwal | 1/5
# CupCube Technology IT - Website/ Mobile App and Digital Marketing Service Provider
# Phone: 09520216187
# Pauri Garhwal | 2/5
# Bhaiji Computers
# Phone: 09871642404
# Pauri Garhwal | 3/5
# KiranaApp Technologies Private Limited
# Phone: 08979708046
# Pauri Garhwal | 4/5
# Infotech computer center pauri
# Phone:
# Pauri Garhwal | 5/5
# Baudhik Sampada
# Phone: 07906913184
#
# Searching: IT companies in Pauri Garhwal Uttarakhand
# Search Submitted
# Pauri Garhwal | IT companies | Scroll 1 -> 16
# Pauri Garhwal | IT companies | Scroll 2 -> 20
# Pauri Garhwal | IT companies | Scroll 3 -> 28
# Pauri Garhwal | IT companies | Scroll 4 -> 36
# Pauri Garhwal | IT companies | Scroll 5 -> 40
# Pauri Garhwal | IT companies | Scroll 6 -> 48
# Pauri Garhwal | IT companies | Scroll 7 -> 56
# Pauri Garhwal | IT companies | Scroll 8 -> 60
# Pauri Garhwal | IT companies | Scroll 9 -> 62
# Pauri Garhwal | IT companies | Scroll 10 -> 62
# Pauri Garhwal | IT companies | Scroll 11 -> 62
# Pauri Garhwal | IT companies | Scroll 12 -> 62
# Pauri Garhwal | IT companies | Scroll 13 -> 62
# Collected 51 links
# Pauri Garhwal | 1/51
# Sparsh Communication
# Phone: 09997338956
# Pauri Garhwal | 2/51
# Kandoliya Park
# Phone:
# Pauri Garhwal | 3/51
# Dobhal Electricals
# Phone: 09897272883
# Pauri Garhwal | 4/51
# Negi Tour And Travels Pauri Garhwal
# Phone: 08979520081
# Pauri Garhwal | 5/51
# Nitin Computers.
# Phone:
# Pauri Garhwal | 6/51
# RAWAT ELECTRICAL
# Phone: 09557875721
# Pauri Garhwal | 7/51
# Blue Dart Courier,Civil Lines,Pauri Garhwal
# Phone:
# Pauri Garhwal | 8/51
# Sumangal Pvt. Ltd.
# Phone: 08126846334
# Pauri Garhwal | 9/51
# Molkhandi
# Phone:
# Pauri Garhwal | 10/51
# LIC of India, Satellite Office
# Phone: 01368222814
# Pauri Garhwal | 11/51
# Rawat computers
# Phone:
# Pauri Garhwal | 12/51
# LIC Premium Saving Office C/O - S.S. Rawat
# Phone:
# Pauri Garhwal | 13/51
# Shri Kandoliya thakur taxi service (Pauri Garhwal)
# Phone:
# Pauri Garhwal | 14/51
# Uttarakhand Cement and iron Store
# Phone: 09412111417
# Pauri Garhwal | 15/51
# Fuel Company
# Phone:
# Pauri Garhwal | 16/51
# Paudi paudi
# Phone:
# Pauri Garhwal | 17/51
# Bhandari enterprises
# Phone: 09536910666
# Pauri Garhwal | 18/51
# Taxi Stand Pauri
# Phone: 07895256078
# Backup Saved
# Pauri Garhwal | 19/51
# Bisht Taxi Service Pauri Garhwal
# Phone: 09557761682
# Pauri Garhwal | 20/51
# Daul
# Phone:
# Pauri Garhwal | 21/51
# Jio Point
# Phone: 18608933333
# Pauri Garhwal | 22/51
# BSNL Store
# Phone: 07579288803
# Pauri Garhwal | 23/51
# Indane - Garhwal Gas Service
# Phone: 08057912507
# Pauri Garhwal | 24/51
# Kiran Cable Center
# Phone: 01368222832
# Pauri Garhwal | 25/51
# Kinaash Studios (Kinaash Official)
# Phone:
# Pauri Garhwal | 26/51
# PG in Pauri New
# Phone:
# Pauri Garhwal | 27/51
# Ridhaan Multi Services & Adhaar Correction Point
# Phone: 07895477267
# Pauri Garhwal | 28/51
# BSNL Store
# Phone: 07579294154
# Pauri Garhwal | 29/51
# Tara lodge, Tehsil road Pauri Garhwal
# Phone:
# Pauri Garhwal | 30/51
# Pauri
# Phone:
# Pauri Garhwal | 31/51
# Wee
# Phone:
# Pauri Garhwal | 32/51
# Vijay raturi
# Phone:
# Pauri Garhwal | 33/51
# Advocate district court Pauri gharwal
# Phone:
# Pauri Garhwal | 34/51
# Tolbadi
# Phone:
# Pauri Garhwal | 35/51
# Pr house
# Phone:
# Pauri Garhwal | 36/51
# Pauri Market
# Phone:
# Pauri Garhwal | 37/51
# Swiss Watch company & Bangle Store
# Phone:
# Pauri Garhwal | 38/51
# MAKEOVERS BY HRITVIK
# Phone: 07088080789
# Pauri Garhwal | 39/51
# BHATTISERA
# Phone:
# Pauri Garhwal | 40/51
# sachin sadan,Nitin kaintyura
# Phone:
# Pauri Garhwal | 41/51
# Sai Enterprises
# Phone: 09634575417
# Pauri Garhwal | 42/51
# Raiwala
# Phone:
# Pauri Garhwal | 43/51
# Om TVS (Rauthan's Devbhoomi Motors)
# Phone: 09760784748
# Pauri Garhwal | 44/51
# Jhatkandi
# Phone:
# Pauri Garhwal | 45/51
# Yin Yang Media (yinyangpositives)
# Phone: 08171357814
# Pauri Garhwal | 46/51
# KAAFILA TRAVELS Pauri
# Phone:
# Pauri Garhwal | 47/51
# Star computer and communication
# Phone: 07088687507
# Pauri Garhwal | 48/51
# Swastik Printer's & Stationers
# Phone: 09760355729
# Pauri Garhwal | 49/51
# Pauri Garhwal
# Phone:
# Pauri Garhwal | 50/51
# suraj taxi stand pauri
# Phone:
# Pauri Garhwal | 51/51
# Shivam CSC centre and photography
# Phone:
#
# Searching: software companies in Pithoragarh Uttarakhand
# Search Submitted
# Pithoragarh | software companies | Scroll 1 -> 4
# Pithoragarh | software companies | Scroll 2 -> 4
# Pithoragarh | software companies | Scroll 3 -> 4
# Pithoragarh | software companies | Scroll 4 -> 4
# Pithoragarh | software companies | Scroll 5 -> 4
# Collected 4 links
# Pithoragarh | 1/4
# DITOz SOFTWARES AND SERVICES
# Phone: 08979445829
# Pithoragarh | 2/4
# Prarambh Infotech
# Phone: 05964264100
# Pithoragarh | 3/4
# Lal Bahadur Shastri Training Institute Pithoragarh
# Phone: 08449366721
# Pithoragarh | 4/4
# Daju Info Tech
# Phone: 09915330878
#
# Searching: IT companies in Pithoragarh Uttarakhand
# Search Submitted
# Pithoragarh | IT companies | Scroll 1 -> 16
# Pithoragarh | IT companies | Scroll 2 -> 20
# Pithoragarh | IT companies | Scroll 3 -> 28
# Pithoragarh | IT companies | Scroll 4 -> 36
# Pithoragarh | IT companies | Scroll 5 -> 40
# Pithoragarh | IT companies | Scroll 6 -> 48
# Pithoragarh | IT companies | Scroll 7 -> 56
# Pithoragarh | IT companies | Scroll 8 -> 60
# Pithoragarh | IT companies | Scroll 9 -> 68
# Pithoragarh | IT companies | Scroll 10 -> 76
# Pithoragarh | IT companies | Scroll 11 -> 80
# Pithoragarh | IT companies | Scroll 12 -> 88
# Pithoragarh | IT companies | Scroll 13 -> 96
# Pithoragarh | IT companies | Scroll 14 -> 100
# Pithoragarh | IT companies | Scroll 15 -> 108
# Pithoragarh | IT companies | Scroll 16 -> 116
# Pithoragarh | IT companies | Scroll 17 -> 120
# Pithoragarh | IT companies | Scroll 18 -> 120
# Pithoragarh | IT companies | Scroll 19 -> 120
# Pithoragarh | IT companies | Scroll 20 -> 120
# Pithoragarh | IT companies | Scroll 21 -> 120
# Collected 116 links
# Pithoragarh | 1/116
# ITDA CALC PITHORAGARH
# Phone:
# Pithoragarh | 2/116
# Bibha Computers
# Phone: 09897816787
# Pithoragarh | 3/116
# THE UNITED DESIGN STUDIO
# Phone:
# Pithoragarh | 4/116
# Delhivery Office
# Phone:
# Pithoragarh | 5/116
# PPTech Computer & Cyber
# Phone: 09548887639
# Pithoragarh | 6/116
# Kumaon Digital Pithoragarh | Best Electronic Store | Home Appliances | Best Mobile Store
# Phone: 09837778870
# Pithoragarh | 7/116
# Mehta tech services
# Phone: 08650947093
# Pithoragarh | 8/116
# PANT CREATIVE
# Phone: 09897783868
# Pithoragarh | 9/116
# COMPLETE BUSINESS SOLUTIONS (CBS)
# Phone: 09639493290
# Pithoragarh | 10/116
# M C Pandey & Company
# Phone:
# Pithoragarh | 11/116
# ANCHAL CYBER
# Phone: 09997425631
# Pithoragarh | 12/116
# ESSCO Authorised Dealer - B. Saran & Company
# Phone: 08046985608
# Pithoragarh | 13/116
# KUMAON NAMKEEN UDHYOG
# Phone:
# Pithoragarh | 14/116
# JD ENTERPRISES (CCTV security solution, RO water Purifier, Laptop and desktop sale in best price , and fire extinguisher )
# Phone: 09891518971
# Pithoragarh | 15/116
# Adi kailash tourism (friends tour)
# Phone:
# Pithoragarh | 56/116
# The Himalayan Hive
# Phone:
# Pithoragarh | 57/116
# Uttarakhand Power Corporation Limited
# Phone:
# Pithoragarh | 58/116
# Dk Electronic
# Phone:
# Pithoragarh | 59/116
# Pithoragarh Decoration Event's Balloon Decor
# Phone:
# Pithoragarh | 60/116
# Adi Kailash & Mansarovar Tours (Original)
# Phone: 09568092257
# Pithoragarh | 61/116
# Devbhumi udhmita startup
# Phone:
# Pithoragarh | 62/116
# Adi Kailash Tourism (SHIV DARSHAN)
# Phone: 08126622341
# Pithoragarh | 63/116
# Travel Sifar - Best Travel Agency in Uttarakhand
# Phone: 07409184133
# Backup Saved
# Pithoragarh | 64/116
# V Virus dance studio
# Phone: 07078731317
# Pithoragarh | 65/116
# Yatra To Adi Kailash
# Phone: 08439870767
# Pithoragarh | 66/116
# Ceragem Pithoragarh
# Phone: 09520628359
# Pithoragarh | 67/116
# Lapcare Authorised Service Centre
# Phone: 09897785906
# Pithoragarh | 68/116
# Shree Tour and Travels
# Phone: 08449056251
# Pithoragarh | 69/116
# The Lion's Tour & Travels
# Phone: 08171411466
# Pithoragarh | 70/116
# b.com gaadi wala
# Phone: 08171790847
# Pithoragarh | 71/116
# Pithoragarh District Court
# Phone: 09766899899
# Pithoragarh | 72/116
# MND Travels
# Phone: 08937054400
# Pithoragarh | 73/116
# ARU GRAMODYOG
# Phone: 06399962252
# Pithoragarh | 74/116
# Govind Lal Jewellers
# Phone: 09897964936
# Pithoragarh | 75/116
# Jai Kali Travels
# Phone: 09897438572
# Pithoragarh | 76/116
# Black and White cafe and homestay
# Phone: 08266831804
# Pithoragarh | 77/116
# 𝗛𝗶𝗹𝗹𝗸𝗶𝗻𝗴 𝗢𝗿𝗴𝗮𝗻𝗶𝗰𝘀
# Phone: 09557300825
# Pithoragarh | 78/116
# HIMAL ENTERPRISES
# Phone: 09627199991
# Pithoragarh | 79/116
# Takana Teas
# Phone:
# ...
# Mahadev mohalla
# Phone:
# Rudraprayag | 83/114
# Chamola house
# Phone:
# Rudraprayag | 84/114
# Deundi house
# Phone:
# Rudraprayag | 85/114
#
# Phone:
# Rudraprayag | 86/114
#
# Phone:
# Rudraprayag | 87/114
#
# Phone:
# Rudraprayag | 88/114
# Salil Dobhal
# Phone:
# Rudraprayag | 89/114
# Water resource
# Phone:
# Rudraprayag | 90/114
# Ramdikhana rooms
# Phone:
# Rudraprayag | 91/114
# Virtuemantra Technologies
# Phone: 09756359898
# Rudraprayag | 92/114
# Manish
# Phone:
# Rudraprayag | 93/114
# Uttarakhand Gramin Bank
# Phone: 01364233616
# Rudraprayag | 94/114
# maruti suzuki rudraprayag
# Phone:
# Rudraprayag | 95/114
# Gaje Singh Negi Niwas
# Phone:
# Rudraprayag | 96/114
# Garhwal Hotel And Restaurant
# Phone: 06395224994
# Rudraprayag | 97/114
# New Akash Medical Store
# Phone: 08057708900
# Rudraprayag | 98/114
#
# Phone:
# Rudraprayag | 99/114
#
# Phone:
# Rudraprayag | 100/114
# KANDARI MEDICAL STORE
# Phone: 09412913074
# Rudraprayag | 101/114
#
# Phone:
# Rudraprayag | 102/114
# Kagoth
# Phone:
# Rudraprayag | 103/114
# Bhagwati harshbharti house
# Phone:
# Rudraprayag | 104/114
# Gopal Butola
# Phone:
# Rudraprayag | 105/114
# दुर्गा ज्योति निवास
# Phone: 07466971555
# Rudraprayag | 106/114
# Amartona
# Phone:
# Rudraprayag | 107/114
# Anisha
# Phone:
# Rudraprayag | 108/114
# VAISHNAVI CSC
# Phone: 08755675463
# Rudraprayag | 109/114
# Seldhar
# Phone:
# Rudraprayag | 110/114
# IndusInd Bank
# Phone: 18602677777
# Rudraprayag | 111/114
# Garh Maati Enterprises
# Phone: 06398141605
# Rudraprayag | 112/114
# Mandakini Steel Since 1987
# Phone: 09761698080
# Rudraprayag | 113/114
#
# Phone: 09997285517
# Rudraprayag | 114/114
# Samgum hardware
# Phone:
#
# Searching: software companies in Tehri Garhwal Uttarakhand
# Search Submitted
# Tehri Garhwal | software companies | Scroll 1 -> 16
# Tehri Garhwal | software companies | Scroll 2 -> 20
# Tehri Garhwal | software companies | Scroll 3 -> 28
# Tehri Garhwal | software companies | Scroll 4 -> 36
# Tehri Garhwal | software companies | Scroll 5 -> 40
# Tehri Garhwal | software companies | Scroll 6 -> 48
# Tehri Garhwal | software companies | Scroll 7 -> 56
# Tehri Garhwal | software companies | Scroll 8 -> 60
# Tehri Garhwal | software companies | Scroll 9 -> 68
# Tehri Garhwal | software companies | Scroll 10 -> 76
# Tehri Garhwal | software companies | Scroll 11 -> 80
# Tehri Garhwal | software companies | Scroll 12 -> 88
# Tehri Garhwal | software companies | Scroll 13 -> 96
# Tehri Garhwal | software companies | Scroll 14 -> 100
# Tehri Garhwal | software companies | Scroll 15 -> 108
# Tehri Garhwal | software companies | Scroll 16 -> 116
# Tehri Garhwal | software companies | Scroll 17 -> 116
# Tehri Garhwal | software companies | Scroll 18 -> 116
# Tehri Garhwal | software companies | Scroll 19 -> 116
# Tehri Garhwal | software companies | Scroll 20 -> 116
# Collected 102 links
# Tehri Garhwal | 1/102
# ColoredCow Consulting Pvt Ltd - Tehri
# Phone:
# Tehri Garhwal | 2/102
# Fluwid Technologies
# Phone: 07830753454
# Tehri Garhwal | 3/102
# COVBEC | RED TEAM Assessment | VAPT | Cyber Security Services
# Phone: 09368016106
# Tehri Garhwal | 4/102
# Systrait - AI Digital Transformation & B2B Company
# Phone: 07042381996
# Tehri Garhwal | 5/102
# OpenStair Technologies
# Phone:
# Tehri Garhwal | 6/102
#
# Phone:
# Tehri Garhwal | 7/102
# Computer Land
# Phone: 09410519280
# Tehri Garhwal | 8/102
# ScanKar
# Phone: 09997977257
# Tehri Garhwal | 9/102
# Shiv Comtech Enterprises
# Phone: 08532886311
# Tehri Garhwal | 10/102
# Mythova
# Phone: 08267078212
# Tehri Garhwal | 11/102
# Dreamvessels Technology Private Limited
# Phone: 09501266615
# Tehri Garhwal | 12/102
# iGeek Squad Bay Pvt. Ltd.
# Phone: 07253826009
# Tehri Garhwal | 13/102
# NH Networks
# Phone:
# Tehri Garhwal | 14/102
# Aivora Technologies
# Phone: 08890048472
# Tehri Garhwal | 15/102
# AIVORA Lab
# Phone: 07983551280
# Tehri Garhwal | 16/102
# eZee Technosys Pvt Ltd
# Phone: 09758333568
# Tehri Garhwal | 17/102
#
# Phone:
# Tehri Garhwal | 18/102
# Khatri online services
# Phone:
# Tehri Garhwal | 19/102
# Tech214 Software & Web Services
# Phone: 09120392390
# Tehri Garhwal | 20/102
# SOS Services
# Phone:
# Tehri Garhwal | 21/102
# Doon Portal Services
# Phone: 09897977555
# Tehri Garhwal | 22/102
# A Plus Infology
# Phone: 08745089049
# Tehri Garhwal | 23/102
# Faxcom Systems
# Phone: 08468951759
# Tehri Garhwal | 24/102
# HI-TECH COMPUTER - Chamba (Tehri Garhwal)
# Phone: 07500314325
# Tehri Garhwal | 25/102
# aonetech
# Phone: 09897976962
# Tehri Garhwal | 26/102
# VG Tech Solutions | Best Solar Energy Company in Dehradun | Solar Rooftop Company in Uttarakhand
# Phone: 09557185350
# Tehri Garhwal | 27/102
# Jhattse Business Hotel and Restaurant Software
# Phone:
# Tehri Garhwal | 28/102
# Restaurant Billing Software By Jhattse Business
# Phone: 09634410412
# Tehri Garhwal | 29/102
# Indradhanush Software India
# Phone: 07607011100
# Tehri Garhwal | 30/102
# Jhattse Business Software
# Phone: 09634410412
# Tehri Garhwal | 31/102
# Tech Guardian
# Phone: 08266859015
# Backup Saved
# Tehri Garhwal | 32/102
# Software Company
# Phone: 07355192682
# Tehri Garhwal | 33/102
# Scholar's I.T. Academy
# Phone:
# Tehri Garhwal | 34/102
# Softechwhiz Technologies Pvt.Ltd.
# Phone:
# Tehri Garhwal | 35/102
# Vairagi15 Tech-Veda | Digital & IT Solutions
# Phone:
# Tehri Garhwal | 36/102
# Naveen Worldwide Solution
# Phone:
# Tehri Garhwal | 37/102
# ONEwAY EDU SOLUTION
# Phone: 09045610802
# Tehri Garhwal | 38/102
# Homie World
# Phone: 06399973888
# Tehri Garhwal | 39/102
# Pahadi tech mobile accessories
# Phone: 07906089802
# Tehri Garhwal | 40/102
# TriDevSofts
# Phone:
# Tehri Garhwal | 41/102
# Oflox® - Digital Marketing Agency in Dehradun
# Phone: 09720703787
# Tehri Garhwal | 42/102
# NewbieGet
# Phone:
# Tehri Garhwal | 43/102
# Robral Technologies
# Phone:
# Tehri Garhwal | 44/102
# inSri Tech Solutions Pvt. Ltd.
# Phone: 09557709326
# Tehri Garhwal | 45/102
# Towais
# Phone: 09411187503
# Tehri Garhwal | 46/102
# The Zonzo
# Phone:
# Tehri Garhwal | 47/102
# Himalayas Properties and Construction | Plots & Land for Sale in Tehri, Uttarakhand
# Phone: 07617648450
# Tehri Garhwal | 48/102
# Xyvro Entertainment
# Phone:
# Tehri Garhwal | 49/102
# PRIME TECH AUTOMATION
# Phone:
# Tehri Garhwal | 50/102
# Ashish Communication & Stationers
# Phone: 08126068958
# Tehri Garhwal | 89/102
# FortyBits
# Phone:
# Tehri Garhwal | 90/102
# ANYA SOFTEK CONSULTANCY SERVICES PVT LTD
# Phone: 07454802551
# Tehri Garhwal | 91/102
# ReveonAI Lifesciences Solutions Private Limited
# Phone: 09084373424
# Tehri Garhwal | 92/102
# TECHNIFIERS
# Phone:
# Tehri Garhwal | 93/102
# Dehradun Web Solutions
# Phone:
# Tehri Garhwal | 94/102
# CubePos - POS application for Restaurant and Grocery Store
# Phone:
# Tehri Garhwal | 95/102
# BanspTech
# Phone: 07017517366
# Tehri Garhwal | 96/102
# Busy Accounting Software
# Phone: 09837008488
# Tehri Garhwal | 97/102
# CortexBloom
# Phone:
# Tehri Garhwal | 98/102
# SOFTWARE SANSKRITI
# Phone: 08755744838
# Tehri Garhwal | 99/102
# Tech Ace Services
# Phone:
# Tehri Garhwal | 100/102
# Techwithgaurav
# Phone:
# Tehri Garhwal | 101/102
# Utsav Poster – Festival & Business Branding App
# Phone:
# Tehri Garhwal | 102/102
# Digibyte technologies
# Phone:
#
# Searching: IT companies in Tehri Garhwal Uttarakhand
# Search Submitted
# Tehri Garhwal | IT companies | Scroll 1 -> 7
# Tehri Garhwal | IT companies | Scroll 2 -> 7
# Tehri Garhwal | IT companies | Scroll 3 -> 7
# Tehri Garhwal | IT companies | Scroll 4 -> 7
# Tehri Garhwal | IT companies | Scroll 5 -> 7
# Collected 2 links
# Tehri Garhwal | 1/2
# Bhagirathi Puram Tehri Garhwal
# Phone:
# Tehri Garhwal | 2/2
# Tehri Dam View Point
# Phone: 01352559898
#
# Searching: software companies in Udham Singh Nagar Uttarakhand
# Search Submitted
# Udham Singh Nagar | software companies | Scroll 1 -> 16
# Udham Singh Nagar | software companies | Scroll 2 -> 20
# Udham Singh Nagar | software companies | Scroll 3 -> 28
# Udham Singh Nagar | software companies | Scroll 4 -> 35
# Udham Singh Nagar | software companies | Scroll 5 -> 35
# Udham Singh Nagar | software companies | Scroll 6 -> 35
# Udham Singh Nagar | software companies | Scroll 7 -> 35
# Udham Singh Nagar | software companies | Scroll 8 -> 35
# Collected 31 links
# Udham Singh Nagar | 1/31
# Sunrise IT Solutions
# Phone: 09410777557
# Udham Singh Nagar | 2/31
# Harish Software Developer
# Phone: 08630217581
# Udham Singh Nagar | 3/31
# CodeSource IT services Private Limited
# Phone:
# Udham Singh Nagar | 4/31
# INFO TECH AUTOMATION
# Phone: 08171444076
# Udham Singh Nagar | 5/31
# Industry 4.0 Barcode and QR Code Traceability Solutions
# Phone:
# Udham Singh Nagar | 6/31
# SF SOFTWARE
# Phone: 07060960080
# Udham Singh Nagar | 7/31
# Info Web Software Technology
# Phone: 09627407876
# Udham Singh Nagar | 8/31
# HSV SOFTWARES TECHNOLOGIES
# Phone: 09105560701
# Udham Singh Nagar | 9/31
# Lines of Logic
# Phone: 08445522002
# Udham Singh Nagar | 10/31
# Tulipshree Infotech, Uttrakhand
# Phone: 07007147007
# Jai Gurudev Industries
# Phone: 07535016007
# Udham Singh Nagar | 6/26
# Krishna and Company
# Phone:
# Udham Singh Nagar | 7/26
# Sahanubhuti Engineering & Metals Pvt Ltd
# Phone: 08077728501
# Udham Singh Nagar | 8/26
# Tez Infotech
# Phone: 09568001113
# Udham Singh Nagar | 9/26
# Rudrapur Solvents Pvt. Ltd.
# Phone: 08077186332
# Udham Singh Nagar | 10/26
# Minda Corporation Limited - SSD, Rudrapur
# Phone:
# Udham Singh Nagar | 11/26
# StandGlobe Enterprises
# Phone: 09389700625
# Udham Singh Nagar | 12/26
# Daaman Buildcon Pvt. Ltd
# Phone: 07060098200
# Udham Singh Nagar | 13/26
# A K DESIRE CONSTRUCTION
# Phone: 09761985148
# Udham Singh Nagar | 14/26
# Dev Homes
# Phone: 07500456677
# Udham Singh Nagar | 15/26
# P.L.A FOODS PVT. LTD.
# Phone: 07500354006
# Udham Singh Nagar | 16/26
# Tata Yazaki Autocomp Limited
# Phone: 09559912536
# Udham Singh Nagar | 17/26
# Tata Motors Ltd pantnagar
# Phone:
# Udham Singh Nagar | 18/26
# Mahindra & Mahindra Tractor plant
# Phone: 18002100700
# Udham Singh Nagar | 19/26
# Bregano
# Phone: 09012143222
# Udham Singh Nagar | 20/26
# Victor Mount Elevator I Lift Service provider I Lift and Elevator Manufacturing Company
# Phone: 08307567214
# Udham Singh Nagar | 21/26
# Tanishq Jewellery - Rudrapur - Udham Singh Nagar
# Phone: 05944240172
# Udham Singh Nagar | 22/26
# VRL Logistics Ltd - Rudrapur
# Phone: 18005997800
# Udham Singh Nagar | 23/26
# Bhagwati Products Limited
# Phone: 08171710162
# Udham Singh Nagar | 24/26
# MAA SHEETLA VENTURES LTD (BTC INDUSTRIES LTD)
# Phone: 09837006366
# Udham Singh Nagar | 25/26
# Muskan Construction
# Phone: 08859337999
# Udham Singh Nagar | 26/26
# Blue Dart Express Limited
# Phone: 02240611234
#
# Searching: software companies in Uttarkashi Uttarakhand
# Search Submitted
# Uttarkashi | software companies | Scroll 1 -> 3
# Uttarkashi | software companies | Scroll 2 -> 3
# Uttarkashi | software companies | Scroll 3 -> 3
# Uttarkashi | software companies | Scroll 4 -> 3
# Uttarkashi | software companies | Scroll 5 -> 3
# Collected 3 links
# Uttarkashi | 1/3
# Vigo Technologies
# Phone: 08630362217
# Uttarkashi | 2/3
# Wings technologies Uttarkashi
# Phone:
# Uttarkashi | 3/3
# Soft Tech It Services ,Uttarkashi
# Phone: 06398842112
#
# Searching: IT companies in Uttarkashi Uttarakhand
# Search Submitted
# Uttarkashi | IT companies | Scroll 1 -> 4
# Uttarkashi | IT companies | Scroll 2 -> 4
# Uttarkashi | IT companies | Scroll 3 -> 4
# Uttarkashi | IT companies | Scroll 4 -> 4
# Uttarkashi | IT companies | Scroll 5 -> 4
# Collected 1 links
# Uttarkashi | 1/1
# Shub Tech
# Phone: 07253079221
#
# Extraction Completed
# Total Companies Extracted: 934
#
# Saved File: uttarakhand_companies.csv
