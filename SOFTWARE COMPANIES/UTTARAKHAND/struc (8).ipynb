# %%
import pandas as pd

# %%
df = pd.read_csv("uttarakhand_companies.csv")

# %%
df.shape
# Out:
# (934, 8)

# %%
df = df[
    df["Phone"].notna() &
    (df["Phone"].astype(str).str.strip() != "")
    ]
df.shape
# Out:
# (603, 8)

# %%
df = df[
    df["Company Name"].notna()
    ]
df = df[
    df["Company Name"].str.strip() != ""
    ]
df.shape
# Out:
# (597, 8)

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]","",regex=True)
    .str.strip()
)
display(df[["Phone"]].head())
# Out:
#          Phone
# 0  75792375150
# 2  96905459650
# 4  94117943880
# 5  83948667790
# 6  89380415570

# %%
df.to_csv(
    "uttarakhand_companies_cleaned.csv",
    index=False
)
