# %%
import pandas as pd

# %%
df = pd.read_csv("mizoram_companies.csv")

# %%
df.shape
# Out:
# (779, 8)

# %%
df = df[
    df["Phone"].notna() & 
    (df["Phone"].astype(str).str.strip() != "")
    ]
df.shape
# Out:
# (217, 8)

# %%
df = df[
    df["Company Name"].notna()
    ]

df = df[
    df["Company Name"].str.strip() != ""
    ]
df.shape
# Out:
# (215, 8)

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]","",regex=True)
    .str.strip()
)

display(df[["Phone"]].head())
# Out:
#          Phone
# 0  80711883300
# 1  84159669750
# 3  38923503370
# 4  87875986210
# 5  98638129430

# %%
df.to_csv(
    "mizoram_companies_cleaned.csv",
    index=False
)
