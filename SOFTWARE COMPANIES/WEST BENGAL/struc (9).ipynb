# %%
import pandas as pd

# %%
df = pd.read_csv("west_bengal_companies.csv")

# %%
df.shape
# Out:
# (2632, 8)

# %%
df = df[
    df["Phone"].notna() &
    (df["Phone"].astype(str).str.strip() != "")
    ]
df.shape
# Out:
# (1919, 8)

# %%
df = df[
    df["Company Name"].notna()
    ]
df = df[
    df["Company Name"].str.strip() != ""
    ]
df.shape
# Out:
# (1914, 8)

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]","",regex=True)
    .str.strip()
)
display(df[["Phone"]].head())
# Out:
#          Phone
# 0  96796132710
# 1  84366624280
# 2  98324374930
# 3  81166983290
# 4  89272703020

# %%
df.to_csv(
    "west_bengal_companies_cleaned.csv",
    index=False
)
