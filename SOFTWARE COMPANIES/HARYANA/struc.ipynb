# %%
import pandas as pd

# %%
df = pd.read_csv("haryana_companies.csv")

# %%
df.shape
# Out:
# (2506, 8)

# %%
df = df[
    df["Phone"].notna() & 
    (df["Phone"].astype(str).str.strip() != "")
    ]
df.shape
# Out:
# (1986, 8)

# %%
df = df[
    df["Company Name"].notna()
    ]

df = df[
    df["Company Name"].str.strip() != ""
    ]
df.shape
# Out:
# (1984, 8)

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]","",regex=True)
    .str.strip()
)

display(df[["Phone"]].head())
# Out:
#          Phone
# 0  98963084930
# 1  97291220600
# 2  96466888220
# 3  94166394450
# 4  94664096600

# %%
df.to_csv(
    "haryana_companies_cleaned.csv",
    index=False
)
