# %%
import time
import random
import pandas as pd

from datetime import datetime

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.service import Service

from webdriver_manager.chrome import ChromeDriverManager

districts = [

    "Kendrapara",
    "Kendujhar",
    "Khordha",
    "Koraput",
    "Malkangiri",
    "Mayurbhanj",
    "Nabarangpur",
    "Nayagarh",
    "Nuapada",
    "Puri",
    "Rayagada",
    "Sambalpur",
    "Subarnapur",
    "Sundargarh"
]



search_types = [
    "software companies",
    "IT companies"
]


options = webdriver.ChromeOptions()

options.add_argument("--start-maximized")

options.add_argument(
    "--disable-blink-features=AutomationControlled"
)

options.add_argument("--disable-notifications")



driver = webdriver.Chrome(

    service=Service(
        ChromeDriverManager().install()
    ),

    options=options
)


driver.get("https://www.google.com/maps")

print("Opening Google Maps...")

time.sleep(15)

print("Google Maps Loaded")



all_data = []

visited_links = set()



def get_search_box():

    selectors = [

        '//input[@id="searchboxinput"]',
        '//input[contains(@placeholder,"Search")]',
        '//input[contains(@aria-label,"Search")]',
        '//input'

    ]

    for selector in selectors:

        try:

            box = driver.find_element(
                By.XPATH,
                selector
            )

            return box

        except:
            pass

    return None



def extract_school_data():

    try:

        try:

            name = driver.find_element(
                By.TAG_NAME,
                "h1"
            ).text

        except:

            name = ""



        try:

            address = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"address")]'
            ).text

        except:

            address = ""



        phone = ""

        try:

            phone_xpaths = [

                '//button[contains(@data-item-id,"phone")]',

                '//a[contains(@href,"tel:")]',

                '//button[contains(@aria-label,"Phone")]',

                '//button[contains(text(),"+91")]',
                '//div[contains(text(),"+91")]',
                '//span[contains(text(),"+91")]'

            ]

            for xpath in phone_xpaths:

                try:

                    elements = driver.find_elements(
                        By.XPATH,
                        xpath
                    )

                    for element in elements:

                        text = element.text.strip()

                        href = (
                            element.get_attribute("href")
                            or ""
                        )

     
                        if "tel:" in href:

                            phone = href.replace(
                                "tel:",
                                ""
                            ).strip()

                        elif text:

                            phone = text

                        phone = (

                            phone.replace("", "")
                            .replace(" ", "")
                            .replace("-", "")
                            .replace("(", "")
                            .replace(")", "")
                            .replace("\n", "")
                            .strip()

                        )

            
                        digits = ''.join(
                            filter(str.isdigit, phone)
                        )

                        if len(digits) >= 10:

                            break

                    if phone:
                        break

                except:
                    pass

        except Exception as e:

            print(f"Phone Error: {e}")

        # WEBSITE

        try:

            website = driver.find_element(
                By.XPATH,
                '//a[contains(@data-item-id,"authority")]'
            ).get_attribute("href")

        except:

            website = ""


        try:

            rating = driver.find_element(
                By.XPATH,
                '//div[@role="img"]'
            ).get_attribute("aria-label")

        except:

            rating = ""

        return {

            "Company Name": name,
            "Address": address,
            "Phone": phone,
            "Website": website,
            "Rating": rating,
            "Google Maps URL": driver.current_url

        }

    except:

        return None


for district in districts:

    for search_type in search_types:

        try:

            query = (
                f"{search_type} "
                f"in {district} Odisha"
            )

            print(f"\nSearching: {query}")

     
            search_box = get_search_box()

            if not search_box:

                print("Search Box Not Found")

                continue

            ActionChains(driver).move_to_element(
                search_box
            ).click().perform()

            time.sleep(1)

            search_box.send_keys(
                Keys.CONTROL + "a"
            )

            time.sleep(1)

            search_box.send_keys(Keys.DELETE)

            time.sleep(1)


            for char in query:

                search_box.send_keys(char)

                time.sleep(0.03)

            search_box.send_keys(Keys.ENTER)

            print("Search Submitted")

            time.sleep(8)


            try:

                scrollable_div = driver.find_element(
                    By.XPATH,
                    '//div[@role="feed"]'
                )

                previous_count = 0

                stagnant = 0

                for i in range(100):

                    driver.execute_script(
                        """
                        arguments[0].scrollTop =
                        arguments[0].scrollHeight
                        """,
                        scrollable_div
                    )

                    time.sleep(4)

                    listings = driver.find_elements(
                        By.XPATH,
                        '//a[contains(@href,"/maps/place/")]'
                    )

                    current_count = len(listings)

                    print(
                        f"{district} | "
                        f"{search_type} | "
                        f"Scroll {i+1} -> "
                        f"{current_count}"
                    )

                    if current_count == previous_count:

                        stagnant += 1

                    else:

                        stagnant = 0

                    if stagnant >= 4:

                        break

                    previous_count = current_count

            except Exception as e:

                print(f"Scrolling Error: {e}")


            listings = driver.find_elements(
                By.XPATH,
                '//a[contains(@href,"/maps/place/")]'
            )

            links = []

            for listing in listings:

                try:

                    link = listing.get_attribute("href")

                    if (
                        link
                        and link not in visited_links
                    ):

                        links.append(link)

                        visited_links.add(link)

                except:
                    pass

            print(f"Collected {len(links)} links")

  

            for index, link in enumerate(links):

                try:

                    print(
                        f"{district} | "
                        f"{index+1}/{len(links)}"
                    )

                    driver.get(link)

                    time.sleep(
                        random.uniform(2, 3)
                    )

                    data = extract_school_data()

                    if data:

                        data["District"] = district

                        data["Search Type"] = search_type

                        all_data.append(data)

                        print(data["Company Name"])

                        print(
                            f"Phone: {data['Phone']}"
                        )


                    if len(all_data) % 100 == 0:

                        backup_df = pd.DataFrame(
                            all_data
                        )

                        backup_df.drop_duplicates(
                            subset=[
                                "Company Name",
                                "Google Maps URL"
                            ],
                            inplace=True
                        )

                        backup_df.to_csv(
                            "odisha_companies_backup.csv",
                            index=False
                        )

                        print("Backup Saved")

                except Exception as e:

                    print(
                        f"Company Error: {e}"
                    )

        except Exception as e:

            print(
                f"District Error: {e}"
            )

df = pd.DataFrame(all_data)

df.drop_duplicates(

    subset=[
        "Company Name",
        "Google Maps URL"
    ],

    inplace=True
)

filename = "odisha_companies.csv"

df.to_csv(
    filename,
    index=False
)

print("\nExtraction Completed")

print(
    f"Total Companies Extracted: {len(df)}"
)

print(f"\nSaved File: {filename}")

driver.quit()
# Out:
# Opening Google Maps...
# Google Maps Loaded
#
# Searching: software companies in Kendrapara Odisha
# Search Submitted
# Kendrapara | software companies | Scroll 1 -> 11
# Kendrapara | software companies | Scroll 2 -> 11
# Kendrapara | software companies | Scroll 3 -> 11
# Kendrapara | software companies | Scroll 4 -> 11
# Kendrapara | software companies | Scroll 5 -> 11
# Collected 11 links
# Kendrapara | 1/11
# AspireIdeas Software Solutions Pvt Ltd
# Phone: 07978948738
# Kendrapara | 2/11
# SP Global Soft
# Phone: 08763762778
# Kendrapara | 3/11
# AskVilash: Ask Anything Anytime
# Phone: 09938884440
# Kendrapara | 4/11
# Digitex Solution
# Phone: 08169864614
# Kendrapara | 5/11
# Byte Master (iT) Solutions
# Phone: 08480884816
# Kendrapara | 6/11
# Megabyte Computer, Kendrapara
# Phone: 09337448837
# Kendrapara | 7/11
# M2 Tech Laptop Solutions
# Phone: 07977050485
# Kendrapara | 8/11
# Baisakhi Computers and Services
# Phone: 07008502076
# Kendrapara | 9/11
# JBML Solutions , CRM , ERP , Security
# Phone: 07666945496
# Kendrapara | 10/11
# Anadi & Manjusha Home(Muduli Families)
# Phone:
# Kendrapara | 11/11
# SMARTCARE Solutions Pvt. Ltd.
# Phone:
#
# Searching: IT companies in Kendrapara Odisha
# Search Submitted
# Kendrapara | IT companies | Scroll 1 -> 16
# Kendrapara | IT companies | Scroll 2 -> 20
# Kendrapara | IT companies | Scroll 3 -> 20
# Kendrapara | IT companies | Scroll 4 -> 36
# Kendrapara | IT companies | Scroll 5 -> 36
# Kendrapara | IT companies | Scroll 6 -> 36
# Kendrapara | IT companies | Scroll 7 -> 36
# Kendrapara | IT companies | Scroll 8 -> 36
# Collected 30 links
# Kendrapara | 1/30
# TRIBHAMA ENERGY PVT LTD (Solar Energy Kendrapara)
# Phone: 08249653502
# Kendrapara | 2/30
# Googal computer and services
# Phone:
# Kendrapara | 3/30
# Flavorharvest Creations Private Limited
# Phone: 07381738169
# Kendrapara | 4/30
# Sai Computer
# Phone:
# Kendrapara | 5/30
#
# Phone:
# Kendrapara | 6/30
# Kusum Computech
# Phone: 08249837367
# Kendrapara | 7/30
# Lakshmi Internet
# Phone: 08895559058
# Kendrapara | 8/30
# Nigama Computers and Services
# Phone: 06727220867
# Kendrapara | 9/30
# Sahoo Enterprisers
# Phone:
# Kendrapara | 10/30
# Tumbledry Dry Clean & Laundry Service
# Phone: 07677250250
# Kendrapara | 11/30
# STYLE BAAZAR KENDRAPARA
# Phone: 09147006155
# Kendrapara | 12/30
# Shree Saitech Solution
# Phone: 09777175559
# Kendrapara | 13/30
# B N Developers (p) Ltd
# Phone: 06727220812
# Kendrapara | 14/30
# Digital Communication
# Phone: 09114041402
# Kendrapara | 15/30
# KRANTI FLEX PRINT
# Phone: 09937070443
# Kendrapara | 16/30
# DIRGHAYU COLDPRESS OIL MILL.
# Phone:
# Kendrapara | 17/30
# SARANGI DISTRIBUTOR EXIDE CARE
# Phone: 09827252746
# Kendrapara | 18/30
# CityKart Kendrapara
# Phone: 09650407082
# Kendrapara | 19/30
# Sahoo Electronics
# Phone: 09337610839
# Kendrapara | 20/30
# ADGLOB INFOSYSTEM PVT LTD
# Phone: 08480000488
# Kendrapara | 21/30
# Baazar Kolkata - Kendrapara
# Phone: 08093693574
# Kendrapara | 22/30
# SRD Enegrgy Tree Pvt Ltd
# Phone: 09853466701
# Kendrapara | 23/30
# Bsnl Office
# Phone: 18003451500
# Kendrapara | 24/30
# B B TRADING CO
# Phone: 09437068422
# Kendrapara | 25/30
# GOLDEN BULLET TEA SHOP
# Phone:
# Kendrapara | 26/30
# Maa Bimbalai Computer
# Phone:
# Kendrapara | 27/30
# Jio Centre
# Phone: 06000860008
# Kendrapara | 28/30
# Khatija rcc humepipe factory & cement works
# Phone: 07751050429
# Kendrapara | 29/30
# Baldevjew HP Gas Agency
# Phone: 09437089454
# Kendrapara | 30/30
# Authorised Samsung Service Center - Gopinath Electronics
# Phone: 09777580207
#
# Searching: software companies in Kendujhar Odisha
# Search Submitted
# Kendujhar | software companies | Scroll 1 -> 16
# Kendujhar | software companies | Scroll 2 -> 20
# Kendujhar | software companies | Scroll 3 -> 28
# Kendujhar | software companies | Scroll 4 -> 36
# Kendujhar | software companies | Scroll 5 -> 40
# Kendujhar | software companies | Scroll 6 -> 48
# Kendujhar | software companies | Scroll 7 -> 56
# Kendujhar | software companies | Scroll 8 -> 60
# Kendujhar | software companies | Scroll 9 -> 63
# Kendujhar | software companies | Scroll 10 -> 63
# Kendujhar | software companies | Scroll 11 -> 63
# Kendujhar | software companies | Scroll 12 -> 63
# Kendujhar | software companies | Scroll 13 -> 63
# Collected 63 links
# Kendujhar | 1/63
# Narayan Technologies
# Phone: 09861605225
# Kendujhar | 2/63
# Mehanstark
# Phone: 07848964926
# Kendujhar | 3/63
# Shiv Shankar Bhandar
# Phone: 09040153575
# Kendujhar | 4/63
# HEMBRAM IT SOLUTIONS PVT. LTD
# Phone: 08895464569
# Kendujhar | 5/63
# Utkal Computer Care
# Phone: 07735692136
# Kendujhar | 6/63
# iNature
# Phone: 07077703370
# Kendujhar | 7/63
# Mukta Infotech
# Phone:
# Kendujhar | 8/63
# Netizen computer-laptop and computer cctv shop
# Phone: 07008750936
# Kendujhar | 9/63
# Autostudio
# Phone:
# Kendujhar | 10/63
# Patra Electronics - Keonjhar
# Phone: 09861024244
# Kendujhar | 11/63
# M/S DIGITAL WEIGHING SYSTEM
# Phone: 07978452218
# Kendujhar | 12/63
# Smart Computer Educational Trust
# Phone: 07978278322
# Kendujhar | 13/63
# JOY SMART SOLUTIONS
# Phone:
# Kendujhar | 14/63
# Creative Computers
# Phone: 09556525819
# Kendujhar | 15/63
# Samsung SmartPlaza - SS Enterprises
# Phone: 07039003430
# Kendujhar | 16/63
# Ardent Steel Limited
# Phone: 06766258382
# Kendujhar | 17/63
# Dell Exclusive Store - Kendujhar
# Phone: 08048007871
# Kendujhar | 18/63
# Triction Media
# Phone:
# Kendujhar | 19/63
# AURORA EXIM | A TRUSTED EXPORTER OF INDIA |
# Phone:
# Kendujhar | 20/63
# A1 Computer Solution-(Computer Sales and Service)
# Phone: 08895744541
# Kendujhar | 21/63
# NETIZEN INFOTECH
# Phone: 07008259541
# Kendujhar | 22/63
# Mital Electronics
# Phone: 09090351987
# Kendujhar | 23/63
# Kashvi Group
# Phone: 06742549944
# Kendujhar | 24/63
# Go Trendy Media
# Phone: 07978764085
# Kendujhar | 25/63
# Tanishq Jewellery - Kendujhar
# Eastman Batteries - Basudev Electricals
# Phone: 07008927037
# Kendujhar | 33/39
# Hariomm dresses babulal colony keonjhar
# Phone: 08328800868
# Kendujhar | 34/39
# Exide Care - Kalinga Supply Agencies
# Phone: 08069351776
# Kendujhar | 35/39
# Adyasha Enterprises
# Phone:
# Kendujhar | 36/39
# Jayanti Nivas
# Phone:
# Kendujhar | 37/39
# Tata AIA Life Insurance Company Limited
# Phone: 18602669966
# Kendujhar | 38/39
# NARAYAN AGENCIES
# Phone: 09853321560
# Kendujhar | 39/39
# ARN MEDIA Complex
# Phone: 09437086122
#
# Searching: software companies in Khordha Odisha
# Search Submitted
# Khordha | software companies | Scroll 1 -> 16
# Khordha | software companies | Scroll 2 -> 20
# Khordha | software companies | Scroll 3 -> 28
# Khordha | software companies | Scroll 4 -> 36
# Khordha | software companies | Scroll 5 -> 40
# Khordha | software companies | Scroll 6 -> 48
# Khordha | software companies | Scroll 7 -> 56
# Khordha | software companies | Scroll 8 -> 60
# Khordha | software companies | Scroll 9 -> 68
# Khordha | software companies | Scroll 10 -> 73
# Khordha | software companies | Scroll 11 -> 73
# Khordha | software companies | Scroll 12 -> 73
# Khordha | software companies | Scroll 13 -> 73
# Khordha | software companies | Scroll 14 -> 73
# Collected 69 links
# Khordha | 1/69
# HARI SOFTSHINE TECHNOLOGY PVT LTD
# Phone: 09853536749
# Khordha | 2/69
# Dewsoft Computer Education
# Phone: 09237536004
# Khordha | 3/69
# Saurav Pattanaik Residence
# Phone: 09938090634
# Khordha | 4/69
# Josh solution
# Phone:
# Khordha | 5/69
# Rangeshine Technology
# Phone: 08249009583
# Khordha | 6/69
# Dork Industry
# Phone: 08210792477
# Khordha | 7/69
# PrismXp Technologies Pvt Ltd
# Phone: 08457072447
# Khordha | 8/69
# MSC HIRETECH
# Phone: 09692207167
# Khordha | 9/69
# Techzex Software Private Limited
# Phone: 09777780688
# Khordha | 10/69
# Secuodsoft Technologies Private Limited
# Phone: 06742968780
# Khordha | 11/69
# L&P Tech Solutions
# Phone: 08457918004
# Khordha | 12/69
# Beehood Private Limited
# Phone: 07077033700
# Khordha | 13/69
# TechTSS
# Phone: 09776995797
# Khordha | 14/69
# Hexaphor Technologies Pvt Ltd.
# Phone: 08260123233
# Khordha | 15/69
# Silan Software
# Phone: 09439202111
# Khordha | 16/69
# PB COMPUTER WORLD
# Phone: 07008180779
# Khordha | 17/69
# Lyncdigit Technologies Pvt Ltd
# Phone:
# Khordha | 18/69
# Firstcode Technology
# Phone: 08895052764
# Khordha | 19/69
# The Tech Eye
# Phone: 07205046996
# Khordha | 20/69
# Cyber Solution & Consultancy Services
# Phone: 08328941629
# Khordha | 21/69
# Infomatic Labs
# Phone: 08018698206
# Khordha | 22/69
# I-Tech Solutions
# Phone:
# Khordha | 23/69
# Khordha Industrial Estate, Khordha
# Phone:
# Khordha | 24/69
# Hindustan cocacola beverages private limited (HCCB)
# Phone:
# Khordha | 25/69
# justforfun
# Phone: 09078690408
# Khordha | 66/69
# NET INFOTECH PVT. LTD.
# Phone: 06742491410
# Khordha | 67/69
# Utkala newzen solution
# Phone:
# Khordha | 68/69
# Upfynd
# Phone: 07608026602
# Khordha | 69/69
# SEESPL
# Phone: 09437030026
#
# Searching: IT companies in Khordha Odisha
# Search Submitted
# Khordha | IT companies | Scroll 1 -> 15
# Khordha | IT companies | Scroll 2 -> 15
# Khordha | IT companies | Scroll 3 -> 15
# Khordha | IT companies | Scroll 4 -> 15
# Khordha | IT companies | Scroll 5 -> 15
# Collected 8 links
# Khordha | 1/8
# MedPlus Khordha
# Phone:
# Khordha | 2/8
# Stellar Digital Lab
# Phone: 09437881033
# Khordha | 3/8
# NARAYANA COMPUTER
# Phone: 09853346229
# Khordha | 4/8
# Wipro Technologies
# Phone: 06743008020
# Khordha | 5/8
# AABSyS Information Technology Private Limited
# Phone: 06743514008
# Khordha | 6/8
# Centuary Fibre Company Rd, Jagannathpur, Khordha, Odisha 752057
# Phone:
# Khordha | 7/8
# CSM Technologies
# Phone: 06746635900
# Khordha | 8/8
# Dreamplot Infratech Pvt Ltd (Branch Office)
# Phone: 07008788633
#
# Searching: software companies in Koraput Odisha
# Search Submitted
# Koraput | software companies | Scroll 1 -> 16
# Koraput | software companies | Scroll 2 -> 20
# Koraput | software companies | Scroll 3 -> 28
# Koraput | software companies | Scroll 4 -> 34
# Koraput | software companies | Scroll 5 -> 34
# Koraput | software companies | Scroll 6 -> 34
# Koraput | software companies | Scroll 7 -> 34
# Koraput | software companies | Scroll 8 -> 34
# Collected 32 links
# Koraput | 1/32
# ManbiTech Private Limited
# Phone: 07303455420
# Koraput | 2/32
# A Digital Solutions (Jana Seva Kendra)
# Phone:
# Koraput | 3/32
# RCM PUC KORAPUT
# Phone: 08280620550
# Koraput | 4/32
# Rohan's Tech
# Phone:
# Koraput | 5/32
# MM HD FLEX
# Phone: 07684960143
# Koraput | 6/32
# Koraput tour and taxi service
# Phone: 08280340540
# Koraput | 7/32
# Kprintz
# Phone: 08093998836
# Koraput | 8/32
# Biswasrai Travels
# Phone: 07683976474
# Koraput | 9/32
# KORAPUT TOURS AND TRAVELS( TAXI SERVICE)
# Phone: 06370309511
# Koraput | 10/32
# S M Print & Promotion
# Phone: 09348480428
# Koraput | 11/32
# KORAPUT TOURIST SOLUTION
# Phone: 07438007687
# Koraput | 12/32
# i-Comp Solution
# Phone: 08895082675
# Koraput | 13/32
# URLSHRT | URL shortener
# Phone:
# Koraput | 14/32
# Usha tavalis
# Phone: 08249470520
# Koraput | 15/32
# Rana travels koraput
# Phone:
# Koraput | 16/32
# Lovekoraput Bike Rental & Car Rental
# Phone: 07788823332
# Koraput | 17/32
# Ashima Travels
# Phone: 09348888202
# Koraput | 18/32
# Krishna Travels
# Phone: 09937740183
# Koraput | 19/32
# KORAPUT TAXI SERVICE
# Phone: 08280602089
# Koraput | 20/32
# LIC Colony
# Phone:
# Koraput | 21/32
# Om HD Flex and Studio
# Phone: 09439288320
# Koraput | 22/32
# MAA ANNAPURNA TRAVELS
# Phone:
# Koraput | 23/32
# Deomali Travel Agency
# Phone: 09937796807
# Koraput | 24/32
# Koraput Mehek Tour & Travels
# Phone: 08917374925
# Koraput | 25/32
# Neelakantha Printing Press
# Phone: 09437109246
# Koraput | 26/32
# Om sai ram travels
# Phone: 09337094290
# Koraput | 27/32
# Koraput Diaries Bike Rental & Car Rental
# Phone: 07008439296
# Koraput | 28/32
# Webworld
# Phone: 09937079336
# Koraput | 29/32
# Senapati travel agency
# Phone: 09348627471
# Koraput | 30/32
# GK Photography
# Phone: 07008345870
# Koraput | 31/32
# ManbiTech
# Phone:
# Koraput | 32/32
# SATYAM TECH
# Phone:
#
# Searching: IT companies in Koraput Odisha
# Search Submitted
# Koraput | IT companies | Scroll 1 -> 16
# Koraput | IT companies | Scroll 2 -> 20
# Koraput | IT companies | Scroll 3 -> 28
# Koraput | IT companies | Scroll 4 -> 36
# Koraput | IT companies | Scroll 5 -> 40
# Koraput | IT companies | Scroll 6 -> 48
# Koraput | IT companies | Scroll 7 -> 56
# Koraput | IT companies | Scroll 8 -> 60
# Koraput | IT companies | Scroll 9 -> 68
# Koraput | IT companies | Scroll 10 -> 76
# Koraput | IT companies | Scroll 11 -> 80
# Koraput | IT companies | Scroll 12 -> 80
# Koraput | IT companies | Scroll 13 -> 80
# Koraput | IT companies | Scroll 14 -> 80
# Koraput | IT companies | Scroll 15 -> 80
# Collected 54 links
# Koraput | 1/54
# Hindustan Aeronautics Limited, Koraput
# Phone:
# Koraput | 2/54
# Ekayani Farms
# Phone: 07799550001
# Koraput | 3/54
# Koraput Bus stand
# Phone:
# Koraput | 4/54
# Innovus Hub Private Limited
# Phone: 18008903550
# Koraput | 5/54
# Sputnik electrical godown
# Phone:
# Koraput | 6/54
# MEGHA TOWNSHIP, MEGHRAJ BUILDCONS
# Phone: 09937115589
# Koraput | 7/54
# MAA THAKURANI TOUR AND TRAVELS KORAPUT.CAR RENTAL & TAXI SERVICE IN KORAPUT ODISHA
# Phone: 09439434094
# Koraput | 8/54
# KORAPUT COFFEE
# Phone:
# Koraput | 9/54
# Koraput Nature Camp [Pine Resorts]
# Phone:
# Koraput | 10/54
# Abinas Maa mangala travels koraput
# Phone: 07735318182
# Koraput | 11/54
# Laxman TOURS & TRAVELS KORAPUT TAXI SERVICES
# Phone:
# Koraput | 12/54
# AISECT SKILL DEVELOPMENT CENTER KORAPUT
# Phone:
# Koraput | 13/54
# RIGHT CHOICE TOUR AND TRAVELS
# Phone: 08328948594
# Koraput | 14/54
# KHILO NIVAS
# Phone: 09937796807
# Koraput | 15/54
# Sputnik Electrical & Electronics ( M R ENTERPRISES )
# Phone: 09937112341
# Koraput | 16/54
# Koraput Dairy
# Phone: 06852252125
# Koraput | 17/54
# KORAPUT HOLIDAYS (Best Travel Agency In Koraput)
# Phone: 06261915122
# Koraput | 18/54
# Lalu tour and travels koraput
# Phone: 09337855287
# Koraput | 19/54
# Koraput Heritage Tour & Travels
# Phone: 08984492336
# Koraput | 20/54
# Dream Hill Coffee (Saptagiri Plantation - Koraput)
# Phone: 09337507044
# Koraput | 21/54
# KORAPUT TRAVELS (TAXI HUB)✨
# Phone: 08144250077
# Koraput | 22/54
# gokoraput
# Phone: 08064523200
# Koraput | 23/54
# Krishna Homestay
# Phone: 09438471777
# Koraput | 24/54
# Taxilotrip - Koraput Travels agency & Koraput Taxi Services
# Phone: 09403890798
# Koraput | 25/54
# JK Tyre Steel Wheels, Auto Scan
# Phone: 09619762707
# Koraput | 26/54
# Gearup Rental (Koraput)
# Phone:
# Koraput | 27/54
# K V Gifts and Bangles
# Phone:
# Koraput | 28/54
# Training & Development Institute
# Phone:
# Koraput | 29/54
# Shanti Guest House
# Phone:
# Koraput | 30/54
# HKGN Travels
# Phone: 08249866822
# Koraput | 31/54
# Hotel MM Residency
# Phone:
# Koraput | 32/54
# Kushh travel
# Phone: 07978524229
# Koraput | 33/54
# God Gift Tour And Travels Koraput Semlilguda
# Phone: 08861100772
# Koraput | 34/54
# KORAPUT TOUR AND TRAVELS
# Phone: 09658822666
# Koraput | 35/54
# Muthoot FinCorp Gold Loan
# Phone: 09289053098
# Koraput | 36/54
# ଆମ କୋରାପୁଟ ପାର୍କ Ama Koraput Park
# Phone:
# Koraput | 37/54
# Koraput Stadium
# Phone:
# Koraput | 38/54
# OMM TRAVELS
# Phone:
# Koraput | 39/54
# Bikash Diagnostic Centre and Hospital Koraput
# Phone: 08280297000
# Koraput | 40/54
# Raj Residency
# Phone: 08658868288
# Koraput | 41/54
# Hotel Aurovalley
# Phone: 07849020206
# Koraput | 42/54
# The Vintage Kitchen
# Phone: 07008201755
# Koraput | 43/54
# FOOTHILLS RETREAT (Niruvan Stays)
# Phone: 07008097978
# Koraput | 44/54
# Koraput Ride ( Taxi Services )
# Phone: 07986953552
# Koraput | 45/54
# Bhagyabati Resturant
# Phone: 09665304603
# Koraput | 46/54
# One Solution
# Phone: 07008004274
# Koraput | 47/54
# Main road gumma Rayagada odisha
# Phone:
# Koraput | 48/54
# Rushikesh Communication
# Phone:
# Backup Saved
# Koraput | 49/54
# RK PHOTOGRAPHY
# Phone: 08093998836
# Koraput | 50/54
# Kechala
# Phone: 08658828871
# Koraput | 51/54
# Indusind bank CSP point
# Phone:
# Koraput | 52/54
# Muthoot Finance Gold Loan
# Phone: 18001202838
# Koraput | 53/54
# Meenakshi Jewellers
# Phone:
# Koraput | 54/54
# SS TECHNOLOGY
# Phone:
#
# Searching: software companies in Malkangiri Odisha
# Search Submitted
# Malkangiri | software companies | Scroll 1 -> 16
# Malkangiri | software companies | Scroll 2 -> 20
# Malkangiri | software companies | Scroll 3 -> 28
# Malkangiri | software companies | Scroll 4 -> 36
# Malkangiri | software companies | Scroll 5 -> 40
# Malkangiri | software companies | Scroll 6 -> 48
# Malkangiri | software companies | Scroll 7 -> 56
# Malkangiri | software companies | Scroll 8 -> 60
# Malkangiri | 38/57
# Web Lluminity Technology Private Limited
# Phone: 08984097445
# Malkangiri | 39/57
# Airtel Store
# Phone: 08658756611
# Malkangiri | 40/57
# JAYNAGAR COLONY
# Phone:
# Malkangiri | 41/57
# Wayindia Software Solution Pvt. Ltd.
# Phone: 06742567899
# Malkangiri | 42/57
# District library malkangiri
# Phone:
# Malkangiri | 43/57
# Ajatus Software
# Phone: 09090890909
# Malkangiri | 44/57
# New Alankar Jewellers
# Phone: 09437748194
# Malkangiri | 45/57
# Raj Jewellers
# Phone: 09437206994
# Malkangiri | 46/57
# HOMOEOPATHY MEDICAL STORE(M/S SWAPNA HOMOEOPATHY)
# Phone: 08455944574
# Malkangiri | 47/57
# SHYAM ALANKAR JEWELLERS
# Phone: 08018329777
# Malkangiri | 48/57
# VIVO Exclusive Store
# Phone: 09439090039
# Malkangiri | 49/57
# The palace of Madhi dynasty....
# Phone:
# Malkangiri | 50/57
# Hoozor Tech Services - HTS
# Phone: 08142929691
# Malkangiri | 51/57
# Tech Service
# Phone:
# Malkangiri | 52/57
# Portal Computer
# Phone: 08763308594
# Malkangiri | 53/57
# ROZY CSC CENTRE
# Phone: 08249827901
# Malkangiri | 54/57
# Tech Service
# Phone: 07684865330
# Malkangiri | 55/57
# IT Hub Malkangiri
# Phone: 08895713965
# Malkangiri | 56/57
# RAJA MOBILE
# Phone: 09348000986
# Malkangiri | 57/57
# Rama Computer
# Phone: 08118010879
#
# Searching: IT companies in Malkangiri Odisha
# Search Submitted
# Malkangiri | IT companies | Scroll 1 -> 16
# Malkangiri | IT companies | Scroll 2 -> 20
# Malkangiri | IT companies | Scroll 3 -> 28
# Malkangiri | IT companies | Scroll 4 -> 36
# Malkangiri | IT companies | Scroll 5 -> 40
# Malkangiri | IT companies | Scroll 6 -> 48
# Malkangiri | IT companies | Scroll 7 -> 56
# Malkangiri | IT companies | Scroll 8 -> 57
# Malkangiri | IT companies | Scroll 9 -> 57
# Malkangiri | IT companies | Scroll 10 -> 57
# Malkangiri | IT companies | Scroll 11 -> 57
# Malkangiri | IT companies | Scroll 12 -> 57
# Collected 15 links
# Malkangiri | 1/15
# COMPLETE IT ZONE
# Phone: 09438577997
# Malkangiri | 2/15
# GOSWAMI ENTERPRISES
# Phone:
# Malkangiri | 3/15
# Apollo tyres, MALKANGIRI
# Phone: 18002127070
# Malkangiri | 4/15
# GUNGUN'S KITCHEN
# Phone: 07682906044
# Malkangiri | 5/15
# GRILL INN
# Phone: 07894813575
# Malkangiri | 6/15
# TRENDS
# Phone: 09861714428
# Malkangiri | 7/15
# Resturant Malkangiri.In
# Phone: 09937073809
# Malkangiri | 8/15
# TechLearnExpert IT solution
# Phone:
# Malkangiri | 9/15
# S R DAIRY FARM
# Phone: 09885372182
# Malkangiri | 10/15
# Quest Global Engineering Services Private Limited
# Phone: 06746617200
# Malkangiri | 11/15
# IT Solution
# Phone: 09777944849
# Malkangiri | 12/15
# SYAM FLYASH BRICKS (MS SHYAM SUNDAR BRICKS & TILES)
# Phone: 07735566135
# Malkangiri | 13/15
# PK COMMUNICATION
# Phone: 07735791506
# Malkangiri | 14/15
# SMART IT SOLUTIONS,bhubaneswar,odisha
# Phone: 08018075615
# Malkangiri | 15/15
# Holy Earth Impex Pvt. Ltd.
# Phone: 08763620077
#
# Searching: software companies in Mayurbhanj Odisha
# Search Submitted
# Mayurbhanj | software companies | Scroll 1 -> 8
# Mayurbhanj | software companies | Scroll 2 -> 8
# Mayurbhanj | software companies | Scroll 3 -> 8
# Mayurbhanj | software companies | Scroll 4 -> 8
# Mayurbhanj | software companies | Scroll 5 -> 8
# Collected 4 links
# Mayurbhanj | 1/4
# MBJ SOFT TECHNOLOGIES
# Phone: 07064043940
# Mayurbhanj | 2/4
# Infocreatives Services Pvt Ltd
# Phone: 09861343329
# Mayurbhanj | 3/4
# ODISHA TECHNO SOFT
# Phone: 08926298889
# Mayurbhanj | 4/4
# Get2Net Academic & Computer Study Center
# Phone: 08249920383
#
# Searching: IT companies in Mayurbhanj Odisha
# Search Submitted
# Mayurbhanj | IT companies | Scroll 1 -> 16
# Mayurbhanj | IT companies | Scroll 2 -> 20
# Mayurbhanj | IT companies | Scroll 3 -> 28
# Mayurbhanj | IT companies | Scroll 4 -> 36
# Mayurbhanj | IT companies | Scroll 5 -> 40
# Mayurbhanj | IT companies | Scroll 6 -> 48
# Mayurbhanj | IT companies | Scroll 7 -> 51
# Mayurbhanj | IT companies | Scroll 8 -> 51
# Mayurbhanj | IT companies | Scroll 9 -> 51
# Mayurbhanj | IT companies | Scroll 10 -> 51
# Mayurbhanj | IT companies | Scroll 11 -> 51
# Collected 47 links
# Mayurbhanj | 1/47
# Maa Kali Communication
# Phone: 08093387018
# Mayurbhanj | 2/47
# Hi-Tech Technology
# Phone: 07385997576
# Mayurbhanj | 3/47
# Maa Ambica e-World
# Phone: 09338811175
# Mayurbhanj | 4/47
# Patra Electronics
# Phone:
# Mayurbhanj | 5/47
# VAISHNAVI ENTERPRISES
# Phone: 07008470187
# Mayurbhanj | 6/47
# Blackterminal Computer institute (OS-CIT Center)
# Phone: 07008186187
# Mayurbhanj | 7/47
# LG Best Shop-ASTIK ELECTRONICS
# Phone: 09861382857
# Mayurbhanj | 8/47
# SOILVEDA
# Phone: 09337000750
# Mayurbhanj | 9/47
# SHAW TECH TRAINING & SERVICES
# Phone: 09692114127
# Mayurbhanj | 10/47
# EPSON CERTIFIED CHANNEL PARTNER - Shivam Computers
# Phone: 07065050972
# Mayurbhanj | 11/47
# District Employment Exchange Office, Baripada
# Phone:
# Mayurbhanj | 12/47
# Rs Cybervilla
# Phone:
# Mayurbhanj | 13/47
# Infinity Graphics
# Phone: 08260200345
# Mayurbhanj | 14/47
# IICS COMPUTER SALES & SERVICES
# Phone:
# Mayurbhanj | 15/47
# C-Net Computer Education
# Phone: 09861310378
# Mayurbhanj | 16/47
# MAHAKUD STEEL & CEMENTS
# Phone: 09853820219
# Mayurbhanj | 17/47
# GIS LYF
# Phone:
# Mayurbhanj | 18/47
# S.Ram Digital Marketing services
# Phone: 06371834524
# Backup Saved
# Mayurbhanj | 19/47
# KANIKA TECHNOLOGY CITY OFFICE
# Phone: 06792295080
# Mayurbhanj | 20/47
# SRL PACKERS & MOVERS
# Phone: 07606888856
# Mayurbhanj | 21/47
# Swati Ladies Mess
# Phone: 09437444233
# Mayurbhanj | 22/47
# SNB DIGI-SOLITION
# Phone: 07853868684
# Mayurbhanj | 23/47
# Gagan Boy's Mess
# Phone: 07789012442
# Mayurbhanj | 24/47
# Electrician ( Srikanta)
# Phone: 07064706473
# Mayurbhanj | 25/47
# SHIBUMI MEDIA
# Phone: 09337139008
# Mayurbhanj | 26/47
# Snehali Vilas Boy's Mess
# Phone: 09438434734
# Mayurbhanj | 27/47
# ARYAVART BOYS MESS
# Phone: 07205070132
# Mayurbhanj | 28/47
# Lucky Boys Mess
# Phone: 06370084418
# Mayurbhanj | 29/47
# Domain Station - Domains, Hosting, and IT Solutions in Baripada
# Phone: 09090606053
# Mayurbhanj | 30/47
# SAHA & COMPANY, SERVICE CENTRE
# Phone: 06371634327
# Mayurbhanj | 31/47
# DENICS ENTERPRISES (JIO Sales & TATA PLAY Sales and Service Center)
# Phone: 07992511511
# Mayurbhanj | 32/47
# INTERTECH COMPUTER EDUCATION(OS-CIT)
# Phone: 09861119744
# Mayurbhanj | 33/47
# Senco Gold & Diamonds- Baripada
# Phone: 06372500144
# Mayurbhanj | 34/47
# MEDIA CREATION
# Phone: 07008004670
# Mayurbhanj | 35/47
# Softsys computer education
# Phone: 09040909131
# Mayurbhanj | 36/47
# Color X Printing Solution
# Phone: 07008660563
# Mayurbhanj | 37/47
# Dev kundo
# Phone:
# Mayurbhanj | 38/47
# Manas Communication (Csc Center)
# Phone:
# Mayurbhanj | 39/47
# Takatpur Square
# Phone:
# Mayurbhanj | 40/47
# Ideal Cottage Boy's Mess
# Phone:
# Mayurbhanj | 41/47
# RAJA MESS
# Phone:
# Mayurbhanj | 42/47
# Debanshi Agency
# Phone:
# Mayurbhanj | 43/47
# Mi Service Center, Mayurbhanj, Baripada, Odisha (Qdigi)
# Phone: 09776742640
# Mayurbhanj | 44/47
# trimurtionline
# Phone:
# Mayurbhanj | 45/47
# Mayurbhanj Travels SIMLIPAL A1
# Phone:
# Mayurbhanj | 46/47
# Computer Expert Group
# Phone:
# Mayurbhanj | 47/47
# SriKrishna Boys mess
# Phone:
#
# Searching: software companies in Nabarangpur Odisha
# Search Submitted
# Nabarangpur | software companies | Scroll 1 -> 5
# Nabarangpur | software companies | Scroll 2 -> 5
# Nabarangpur | software companies | Scroll 3 -> 5
# Nabarangpur | software companies | Scroll 4 -> 5
# Nabarangpur | software companies | Scroll 5 -> 5
# Collected 5 links
# Nabarangpur | 1/5
# MBG Digitech Pvt Ltd
# Phone: 08339090002
# Nabarangpur | 2/5
# IT SPOT
# Phone: 08280003222
# Nabarangpur | 3/5
# Meem Infotech
# Trinath Lakh Workshop & Sales
# Phone: 07205123435
# Nabarangpur | 32/35
# Motilal Oswal Financial Services Limited
# Phone: 09731140290
# Nabarangpur | 33/35
# FCI FSD NOWARANGPUR
# Phone:
# Nabarangpur | 34/35
# Insure Glink Merchandiser
# Phone: 07008487345
# Nabarangpur | 35/35
# IIFL Gold Loan
# Phone: 02271072447
#
# Searching: software companies in Nayagarh Odisha
# Search Submitted
# Nayagarh | software companies | Scroll 1 -> 13
# Nayagarh | software companies | Scroll 2 -> 13
# Nayagarh | software companies | Scroll 3 -> 13
# Nayagarh | software companies | Scroll 4 -> 13
# Nayagarh | software companies | Scroll 5 -> 13
# Collected 13 links
# Nayagarh | 1/13
# BHAVISHYA IT SOLUTION , NAYAGARH, Computer Sails And Service
# Phone: 07377612076
# Nayagarh | 2/13
# Gupta Distributors, Nayagarh | Best Electronics Store
# Phone: 06742421749
# Nayagarh | 3/13
# SP IT SOLUTIONS, NAYAGARH
# Phone:
# Nayagarh | 4/13
# SYSTEM IT SOLUTION
# Phone: 07978114848
# Nayagarh | 5/13
# GLOBAL IT SOLUTIONS
# Phone: 09777971045
# Nayagarh | 6/13
# SEMIOTIC COMPUTER EDUCATION,NAYAGARH(ALC-OSCIT, OSCIT A, A+)
# Phone: 08908952155
# Nayagarh | 7/13
# BABUL IT SOLUTION
# Phone: 09439573757
# Nayagarh | 8/13
# SIET COMPUTER (NIELIT CENTER )
# Phone: 09437107503
# Nayagarh | 9/13
# Subham Electronics
# Phone: 09437107598
# Nayagarh | 10/13
# Best Website Design, E-commerce, Digital Marketing Services in Naygarh
# Phone:
# Nayagarh | 11/13
# MunaRetail Pvt Ltd
# Phone: 09668593551
# Nayagarh | 12/13
# DevOps
# Phone:
# Nayagarh | 13/13
# SAI SOFTWARE SOLUTION
# Phone: 07008900035
#
# Searching: IT companies in Nayagarh Odisha
# Search Submitted
# Nayagarh | IT companies | Scroll 1 -> 16
# Nayagarh | IT companies | Scroll 2 -> 20
# Nayagarh | IT companies | Scroll 3 -> 28
# Nayagarh | IT companies | Scroll 4 -> 36
# Nayagarh | IT companies | Scroll 5 -> 40
# Nayagarh | IT companies | Scroll 6 -> 48
# Nayagarh | IT companies | Scroll 7 -> 56
# Nayagarh | IT companies | Scroll 8 -> 60
# Nayagarh | IT companies | Scroll 9 -> 68
# Nayagarh | IT companies | Scroll 10 -> 76
# Nayagarh | IT companies | Scroll 11 -> 79
# Nayagarh | IT companies | Scroll 12 -> 79
# Nayagarh | IT companies | Scroll 13 -> 79
# Nayagarh | IT companies | Scroll 14 -> 79
# Nayagarh | IT companies | Scroll 15 -> 79
# Collected 67 links
# Nayagarh | 1/67
# TP Central Odisha Distribution Limited
# Phone: 18003457122
# Nayagarh | 2/67
# AMBIKA INFOTECH
# Phone: 09439580884
# Nayagarh | 3/67
# LIC office Nayagarh
# Phone:
# Nayagarh | 4/67
#
# Phone:
# Nayagarh | 5/67
#
# Phone:
# Nayagarh | 6/67
#
# Phone:
# Nayagarh | 7/67
#
# Phone:
# Nayagarh | 8/67
# Google Maps can't reach the internet
# Phone:
# Nayagarh | 9/67
# Company Error: HTTPConnectionPool(host='localhost', port=54927): Read timed out. (read timeout=120)
# Nayagarh | 10/67
# Company Error: HTTPConnectionPool(host='localhost', port=54927): Read timed out. (read timeout=120)
# Nayagarh | 11/67
# Amazon Care
# Phone:
# Nayagarh | 12/67
# Secure Technologies
# Phone: 09438847097
# Nayagarh | 13/67
#
# Phone:
# Nayagarh | 14/67
# Nayagarh Darpan
# Phone: 09938824509
# Nayagarh | 15/67
# Tumbledry Dry Clean & Laundry Service
# Phone: 07677250250
# Nayagarh | 16/67
# ACHYUTA NAGAR
# Phone:
# Nayagarh | 17/67
# System World
# Phone: 09778477143
# Nayagarh | 18/67
# Patra Drug House
# Phone: 09439587287
# Nayagarh | 19/67
# Nayagarh Jadumani Hostel
# Phone:
# Nayagarh | 20/67
# Panasonic Preferred Partner Laxmi Basan Bhandar
# Phone: 09438424522
# Backup Saved
# Nayagarh | 21/67
# S. S. Dash & Associates
# Phone: 08018730301
# Nayagarh | 22/67
# KUMAR SAI PVT LTD
# Phone:
# Nayagarh | 23/67
# NC Tutorial Boy's Hostel
# Phone:
# Nayagarh | 24/67
# MADHUSUDAN BIHAR
# Phone:
# Nayagarh | 25/67
# Prabhukrupa Agarbatti Udyog
# Phone:
# Nayagarh | 26/67
# Bajaj Life Insurance
# Phone: 02067121212
# Nayagarh | 27/67
# Matrushakti Travels
# Phone: 08599888862
# Nayagarh | 28/67
# Jio Point
# Phone:
# Nayagarh | 29/67
# Sai Seba Gas
# Phone: 06753252577
# Nayagarh | 30/67
# Dynamic hostel nayagarh
# Phone:
# Nayagarh | 31/67
# City Life Fashion Mall
# Phone: 08260537325
# Nayagarh | 32/67
# Collectorate Nayagarh
# Phone:
# Nayagarh | 33/67
# Bahadajhola Market Commete RMC Nayagarh
# Phone:
# Nayagarh | 34/67
# Chandi Bhandar
# Phone:
# Nayagarh | 35/67
# vivo & iQOO Authorised Service Center
# Phone: 09777574819
# Nayagarh | 36/67
# D H ENTERPRISES
# Phone: 09937213383
# Nayagarh | 37/67
# Subudhi Jewellers(Nayagarh)
# Phone: 07585955625
# Nayagarh | 38/67
# Amarendra Market(ଅମରେନ୍ଦ୍ର ବଜାର)
# Phone:
# Nayagarh | 39/67
# JIO DISTRIBUTOR OFFICE
# Phone:
# Nayagarh | 40/67
# JBS PAINTING SOLUTION
# Phone: 09090002030
# Nayagarh | 41/67
# V2 Retail - Nayagarh
# Phone: 08130907705
# Nayagarh | 42/67
# Bhagabati Jewels
# Phone: 07606033394
# Nayagarh | 43/67
# Jadumani Nagar
# Phone:
# Nayagarh | 44/67
# vivo India Service Center
# Phone: 06753252554
# Nayagarh | 45/67
# Boyanika
# Phone: 06742530230
# Nayagarh | 46/67
# Balloons and flower decoration in nayagarh
# Phone: 07684963390
# Nayagarh | 47/67
# SMFG India Credit Co. Ltd. - Debottar Colony (Branch)
# Phone: 18001036001
# Nayagarh | 48/67
# Door Planet
# Phone: 09776400333
# Nayagarh | 49/67
# Bk water supply (Apna Pio)
# Phone: 08337994653
# Nayagarh | 50/67
# Lenkudipada, Nayagarh
# Phone:
# Nayagarh | 51/67
# Mahindra Tractor-Raj Automotive
# Phone: 07008870019
# Nayagarh | 52/67
# Hot pot
# Phone: 06370152789
# Nayagarh | 53/67
# Bajarangi Traders
# Phone: 07749085580
# Nayagarh | 54/67
# Gopinath Travels
# Phone:
# Nayagarh | 55/67
# District Library, Nayagarh
# Phone:
# Nayagarh | 56/67
# NAYAK XEROX
# Phone: 08658141542
# Nayagarh | 57/67
# Jio-bp
# Phone: 07978444056
# Nayagarh | 58/67
# Padhi Boys' Hostel
# Phone:
# Nayagarh | 59/67
# Muthoot Finance Gold Loan
# Phone: 18001202838
# Nayagarh | 60/67
# Manamohini Enterprises, Medicine & Surgical
# Phone: 09438297131
# Nayagarh | 61/67
# Bajaj Auto Credit | MSB Automotive Chetak | Two Wheeler Loan
# Phone: 08806008806
# Nayagarh | 62/67
# Rishi’s Home
# Phone:
# Nayagarh | 63/67
# KTM MART
# Phone: 08657180658
# Nayagarh | 64/67
# Hotel Prince Nayagarh
# Phone: 09853811192
# Nayagarh | 65/67
# DAS RESIDENCY
# Phone: 07656098037
# Nayagarh | 66/67
# Oxford Girl's Hostel
# Phone: 09437232611
# Nayagarh | 67/67
# Achyut Kumar Sahoo
# Phone:
#
# Searching: software companies in Nuapada Odisha
# Search Submitted
# Nuapada | software companies | Scroll 1 -> 16
# Nuapada | software companies | Scroll 2 -> 17
# Nuapada | software companies | Scroll 3 -> 17
# Nuapada | software companies | Scroll 4 -> 17
# Nuapada | software companies | Scroll 5 -> 17
# Nuapada | software companies | Scroll 6 -> 17
# Collected 15 links
# Nuapada | 1/15
# Odyssey
# Phone: 07606019792
# Nuapada | 2/15
# RD COMPUTER
# Phone: 09556888857
# Nuapada | 3/15
# SSR GREEN TECH ENERGY
# Phone: 06678221055
# Nuapada | 4/15
# Speed Master Solution, The Computer Store
# Phone: 09438416660
# Nuapada | 5/15
# KGNT Computer education Institute
# Phone: 09437623938
# Nuapada | 6/15
# Kamlesh Computers & Mobile
# Phone:
# Nuapada | 7/15
# Shivani Computer
# Phone: 08409385391
# Nuapada | 8/15
# Sahu electronic
# Phone: 09668592872
# Nuapada | 9/15
# SHIPRA DIGITAL WORLD
# Phone:
# Nuapada | 10/15
# P.R.PATTNAIK & ASSOCIATES,NUAPADA
# Phone: 09556209604
# Nuapada | 11/15
# Megha Hotel Nuapada
# Phone: 07077280444
# Nuapada | 12/15
# Ecom Express Courier Office
# Phone: 08826398220
# Nuapada | 13/15
#
# Phone:
# Nuapada | 14/15
# Motilal Oswal Financial Services Limited
# Phone: 07942727549
# Nuapada | 15/15
# Shivani Computer
# Phone: 08409385391
#
# Searching: IT companies in Nuapada Odisha
# Search Submitted
# Nuapada | IT companies | Scroll 1 -> 16
# Nuapada | IT companies | Scroll 2 -> 19
# Nuapada | IT companies | Scroll 3 -> 19
# Nuapada | IT companies | Scroll 4 -> 19
# Nuapada | IT companies | Scroll 5 -> 19
# Nuapada | IT companies | Scroll 6 -> 19
# Collected 9 links
# Nuapada | 1/9
# GK Computer Sales & Service
# Phone: 08458082828
# Nuapada | 2/9
# Sight Tech
# Phone: 07683866046
# Nuapada | 3/9
# Sumit Bazaar
# Phone:
# Nuapada | 4/9
# PRATEEKSHA NGO
# Phone: 09853110066
# Nuapada | 5/9
# Indane - Nuapada Gramin Vitrak
# Phone: 09438204832
# Nuapada | 6/9
# Kuber Mobile & computers
# Phone: 09938079999
# Nuapada | 7/9
# Padhi Residence
# Phone:
# Nuapada | 8/9
# Jagannath Computer
# Phone:
# Nuapada | 9/9
# RAMIZ COMPUTER
# Phone: 72055223375
#
# Searching: software companies in Puri Odisha
# Search Submitted
# Puri | software companies | Scroll 1 -> 16
# Puri | software companies | Scroll 2 -> 20
# Puri | software companies | Scroll 3 -> 28
# Puri | software companies | Scroll 4 -> 36
# Puri | software companies | Scroll 5 -> 40
# Puri | software companies | Scroll 6 -> 48
# Puri | software companies | Scroll 7 -> 56
# Puri | software companies | Scroll 8 -> 60
# Puri | software companies | Scroll 9 -> 67
# Puri | software companies | Scroll 10 -> 67
# Puri | software companies | Scroll 11 -> 67
# Puri | software companies | Scroll 12 -> 67
# Puri | software companies | Scroll 13 -> 67
# Collected 56 links
# Puri | 1/56
# Asish tech web solutions
# Phone: 07846857629
# Puri | 2/56
# IT CONCEPT
# Phone: 09437419500
# Puri | 3/56
# Mahavir Tech Web Solutions
# Phone:
# Puri | 4/56
# Digitomesh
# Phone: 09124205577
# Puri | 5/56
#
# Phone:
# Puri | 6/56
#
# Phone:
# Puri | 7/56
# ALLQH Digital Mart
# Phone:
# Puri | 8/56
# Best Website & App Developer
# Phone:
# Puri | 9/56
# RconSoft Services
# Phone:
# Puri | 10/56
# Utkal Nexgen
# Phone:
# Puri | 11/56
# Digital Creation IT & Business Solutions
# Phone: 09938114873
# Puri | 12/56
# Gupta Distributors, Puri | Best Electronics Store
# Phone: 07008989310
# Puri | 13/56
# Maa dakhinakali IT HUB
# Phone: 07008894611
# Puri | 14/56
# MV Tech Web solutions
# Phone:
# Puri | 15/56
# Graphh | Web Design Solutions
# Phone: 07854948678
# Puri | 16/56
# SB CODEX
# Phone:
# Puri | 17/56
# AVR Enterprises
# Phone: 08887688699
# Puri | 18/56
# Sahinayak Technologies
# Phone:
# Puri | 19/56
# WEBINFOSURF TECHNOLOGIES
# Phone: 09178492336
# Puri | 20/56
# Maa Sarala Computer
# Phone: 09338740107
# Puri | 21/56
# Sibishnu Tech
# Phone:
# Puri | 22/56
# Shopweb
# Phone: 09861408954
# Puri | 23/56
# SS IT ZONE
# Phone: 08280083495
# Puri | 24/56
# Shree Ganapati Build Tech
# Phone: 09778162621
# Puri | 25/56
# CELLO CITY
# Phone: 09776086506
# Puri | 26/56
# PURI ADS
# Phone: 07008315231
# Puri | 27/56
# Cyber.Dot
# Phone: 08249739488
# Puri | 28/56
# Guru Gauranga Travels
# Phone: 09090606071
# Puri | 29/56
# OM EDUCATION & CSC CENTRE
# Phone: 07606957520
# Backup Saved
# Puri | 30/56
# My Puri Darshan Trip
# Phone: 09338601070
# Puri | 31/56
# puriland
# Phone:
# Puri | 32/56
# NILACHAKRA GST SUVIDHA KENDRA
# Phone:
# Puri | 33/56
# Infinite Event and Promotion Private Limited
# Phone: 09853716941
# Puri | 34/56
# Tech Biswa construction( House planing and design with vastu) and heigh quality construction work
# Phone: 07008951149
# Puri | 35/56
# Samsung Experience Store VIP Road
# Phone: 09937071770
# Puri | 36/56
# Upasana Engineerings
# Phone:
# Puri | 37/56
# Hitech Weghing Scales, Puri
# Phone:
# Puri | 38/56
# Priyanshi Graphics
# Phone: 07894684770
# Puri | 39/56
# Alishan Odisha Handlooms- V.I.P Road
# Phone: 08458035907
# Puri | 40/56
# Water Solution
# Phone: 09861451980
# Puri | 41/56
# Tanishq Jewellery - Puri
# Phone: 08339071111
# Puri | 42/56
# Water World
# Phone: 09078941701
# Puri | 43/56
# One call travel agency in puri - Best tour and travel Puri/Best taxi services in puri/Best cab service in Puri
# Phone: 09668818747
# Puri | 44/56
# ଆବଂସ୍ Aabans
# Phone:
# Puri | 45/56
# Event Dose
# Phone: 08280282222
# Puri | 46/56
# Adarsh Flex Print in Puri
# Phone: 09124717071
# Puri | 47/56
# Puri Jagannath Dham
# Phone: 09437614200
# Puri | 48/56
# Brothers Animator
# Phone: 09937002565
# Puri | 49/56
# Qlith Innovation Private Limited
# Phone:
# Puri | 50/56
# TRAVELS IN PURI
# Phone: 07008890564
# Puri | 51/56
# Sahoo Rental
# Phone:
# Puri | 52/56
# Airtel Xstream Fiber
# Phone: 07381822070
# Puri | 53/56
# Nexpro Softwares Pvt Ltd
# Phone: 07789041588
# Puri | 54/56
# Jagannath ballav parking
# Phone:
# Puri | 55/56
# GROW Centre, Puri
# Phone: 09281448059
# Puri | 56/56
# Acceze Technology
# Phone:
#
# Searching: IT companies in Puri Odisha
# Search Submitted
# Puri | IT companies | Scroll 1 -> 16
# Puri | IT companies | Scroll 2 -> 20
# Puri | IT companies | Scroll 3 -> 28
# Puri | IT companies | Scroll 4 -> 36
# Puri | IT companies | Scroll 5 -> 40
# Puri | IT companies | Scroll 6 -> 48
# Puri | IT companies | Scroll 7 -> 53
# Puri | IT companies | Scroll 8 -> 53
# Puri | IT companies | Scroll 9 -> 53
# Puri | IT companies | Scroll 10 -> 53
# Puri | IT companies | Scroll 11 -> 53
# Collected 26 links
# Puri | 1/26
# Red Panther
# Phone:
# Puri | 2/26
# Parallel Panda puri
# Phone:
# Puri | 3/26
# ACS & CO, Chartered Accountants
# Phone: 07655990811
# Puri | 4/26
# M/S. YOUNGSTAR SECURITY SERVICES
# Phone: 08249848824
# Puri | 5/26
# Shreehari Constructions
# Phone: 09439537644
# Puri | 6/26
# PURI ELECTRICAL DIVISION
# Phone: 06752223521
# Puri | 7/26
# NCC Limited Office
# Phone:
# Puri | 8/26
# The Lutetium- Website Designing, Digital Marketing & Graphics Designing Company at Puri
# Phone: 07377304321
# Puri | 9/26
# Zebmeoo
# Phone: 09114493630
# Puri | 10/26
# Hierarchy Designs Pvt. Ltd.
# Phone: 08117859229
# Puri | 11/26
# MS Digital World
# Phone:
# Puri | 12/26
# Iconic Pixel Studios
# Phone: 09348417097
# Puri | 13/26
# Shree Lokanath Priya Heritage,Puri
# Phone:
# Puri | 14/26
# BINAYAK CONSTRUCTIONS Pvt. Ltd.
# Phone: 08249867287
# Puri | 15/26
# Shrisam Developers
# Phone:
# Puri | 16/26
# CLIXYS | Digital Marketing Agency Puri | SEO Puri | Digital Agency Puri
# Phone:
# Puri | 17/26
# Rudrashreeansh Construction
# Phone: 08093717973
# Puri | 18/26
# SAMARTH WEB SERVICES PVT LTD
# Phone: 07381090625
# Puri | 19/26
# RS construction
# Phone: 09353504915
# Puri | 20/26
# CHINUMINU BUILDERS PRIVATE LIMITED
# Phone:
# Puri | 21/26
# Digital Creation IT & Business Solutions
# Phone:
# Puri | 22/26
# PIT Services Pvt. Ltd.
# Phone: 09439363745
# Puri | 23/26
# Rans Engineering & Chemicals Pvt Ltd
# Phone: 07669211993
# Puri | 24/26
# T-REX
# Phone:
# Puri | 25/26
# ...
# Sambalpur | software companies | Scroll 1 -> 16
# Sambalpur | software companies | Scroll 2 -> 20
# Sambalpur | software companies | Scroll 3 -> 28
# Sambalpur | software companies | Scroll 4 -> 36
# Sambalpur | software companies | Scroll 5 -> 36
# Sambalpur | software companies | Scroll 6 -> 36
# Sambalpur | software companies | Scroll 7 -> 36
# Sambalpur | software companies | Scroll 8 -> 36
# Collected 36 links
# Sambalpur | 1/36
# Indev Consultancy Pvt. Ltd.
# Phone: 09938146677
# Sambalpur | 2/36
# Keshav Computers |GST BILLING SOFTWARE |ACCOUNTING SOFTWARE IN ODISHA
# Phone: 07008690307
# Sambalpur | 3/36
# Sambalbhoomi Tech Pvt Ltd
# Phone: 08121066624
# Sambalpur | 4/36
# Phoenix software solutions
# Phone: 07540990216
# Sambalpur | 5/36
# SMHKS DIGISOFT PVT. LTD
# Phone: 07682829586
# Sambalpur | 6/36
# Nexgen Technologies
# Phone: 07008765861
# Sambalpur | 7/36
# Arsayan Global Private Limited
# Phone:
# Sambalpur | 8/36
# Neurabit Solution LLP
# Phone:
# Sambalpur | 9/36
# Sigitek Software Services
# Phone: 06633554452
# Sambalpur | 10/36
# LINKING TECH SOFTWARE
# Phone: 09337236580
# Sambalpur | 11/36
# MYWEB SOLUTIONS
# Phone: 09937253528
# Sambalpur | 12/36
# Microbot India
# Phone: 06370761820
# Sambalpur | 13/36
# AI Chat Support
# Phone: 09937253528
# Sambalpur | 14/36
# BESTSERVE COMPUTERS
# Phone: 09861142849
# Sambalpur | 15/36
# Nexgen Communication
# Phone: 09437055351
# Sambalpur | 16/36
# iEaonTech Solutions
# Phone: 06632541541
# Sambalpur | 17/36
# Web Bonding - Digital marketing and Web Development Agency
# Phone: 07008540955
# Sambalpur | 18/36
# YS3 Solutions
# Phone: 09438000736
# Sambalpur | 19/36
# Skyrel Corporation
# Phone: 09777760600
# Sambalpur | 20/36
# OCA Computer Academy Sambalpur
# Phone: 08908031231
# Sambalpur | 21/36
# Has Systems
# Phone: 07789920203
# Sambalpur | 22/36
# digiTX Computer Technology
# Phone: 09937743083
# Sambalpur | 23/36
# PARESH- computer and printers REPAIRING shop
# Phone: 07978722055
# Sambalpur | 24/36
# HP World - Sambalpur
# Phone: 07039073257
# Sambalpur | 25/36
# IT-Expert sbp
# Phone: 09818250788
# Sambalpur | 26/36
# Reliance Digital
# Phone: 08071889553
# Sambalpur | 27/36
# iDestiny -  Apple Authorised Reseller, Sambalpur
# Phone: 08069199817
# Sambalpur | 28/36
# PowerTech Solutions - TATA Power Solaroof
# Phone: 07849006611
# Sambalpur | 29/36
# Shreetech Solution
# Phone: 09437241284
# Sambalpur | 30/36
# True & Fair Accounting Solutions
# Phone: 08338833633
# Sambalpur | 31/36
# Mahamaya Computers
# Phone: 07008271823
# Sambalpur | 32/36
# Hardwarefix. Laptop repair and parts
# Phone: 09040065716
# Sambalpur | 33/36
# Lenovo Service Centre
# Phone: 09438006935
# Sambalpur | 34/36
# Sybex Technology
# Phone: 09437423441
# Sambalpur | 35/36
# Alternate Technologies
# Phone: 09818203583
# Sambalpur | 36/36
# Obify Consulting Services Pvt Ltd
# Phone: 08456862476
#
# Searching: IT companies in Sambalpur Odisha
# Search Submitted
# Sambalpur | IT companies | Scroll 1 -> 16
# Sambalpur | IT companies | Scroll 2 -> 20
# Sambalpur | IT companies | Scroll 3 -> 28
# Sambalpur | IT companies | Scroll 4 -> 36
# Sambalpur | IT companies | Scroll 5 -> 40
# Sambalpur | IT companies | Scroll 6 -> 48
# Sambalpur | IT companies | Scroll 7 -> 56
# Sambalpur | IT companies | Scroll 8 -> 60
# Sambalpur | IT companies | Scroll 9 -> 68
# Sambalpur | IT companies | Scroll 10 -> 76
# Sambalpur | IT companies | Scroll 11 -> 80
# Sambalpur | IT companies | Scroll 12 -> 86
# Sambalpur | IT companies | Scroll 13 -> 86
# Sambalpur | IT companies | Scroll 14 -> 86
# Sambalpur | IT companies | Scroll 15 -> 86
# Sambalpur | IT companies | Scroll 16 -> 86
# Collected 72 links
# Sambalpur | 1/72
# Infinity Solutions
# Phone: 09938446518
# Sambalpur | 2/72
# Mahanadi Coalfields Limited Headquarters
# Phone: 06632542855
# Sambalpur | 3/72
# EPSON CERTIFIED CHANNEL PARTNER - Welcomp System
# Phone: 08375000554
# Sambalpur | 4/72
# Sambalpur University Institute of Information Technology (SUIIT), Burla
# Phone: 06632113254
# Sambalpur | 5/72
# ORBIT COMMUNICATION AND MEDIA
# Phone: 09861660379
# Sambalpur | 6/72
#
# Phone: 07978170396
# Sambalpur | 7/72
#
# SOLAR CHANNEL PARTNER OF ORB ENERGY , - SJ Enterprises, Sakhipada , Sambalpur
# Phone:
# Sambalpur | 55/72
# Sri mina nivas
# Phone:
# Sambalpur | 56/72
# Amity University Online | Sambalpur
# Phone: 18001023434
# Sambalpur | 57/72
# Surya pharmaceutical
# Phone:
# Sambalpur | 58/72
# saikrupa nivas
# Phone:
# Sambalpur | 59/72
# My Home
# Phone:
# Sambalpur | 60/72
# Jagadamba Residency
# Phone:
# Sambalpur | 61/72
# Shree maa Boys Chamber
# Phone:
# Sambalpur | 62/72
# Sameer behera
# Phone:
# Sambalpur | 63/72
# Sabitri tower
# Phone:
# Sambalpur | 64/72
# Sujit's Home
# Phone:
# Sambalpur | 65/72
# Hitech digital job hub
# Phone:
# Sambalpur | 66/72
# FUTURETECH
# Phone:
# Sambalpur | 67/72
# Quality Services
# Phone: 09437201563
# Sambalpur | 68/72
# IT Solutions
# Phone:
# Sambalpur | 69/72
# Star Chamber
# Phone:
# Sambalpur | 70/72
# Computer Hardware service
# Phone:
# Sambalpur | 71/72
# Pintu
# Phone:
# Sambalpur | 72/72
# DIGITAL SOLUTION
# Phone: 09938164882
#
# Searching: software companies in Subarnapur Odisha
# Search Submitted
# Subarnapur | software companies | Scroll 1 -> 16
# Subarnapur | software companies | Scroll 2 -> 20
# Subarnapur | software companies | Scroll 3 -> 28
# Subarnapur | software companies | Scroll 4 -> 36
# Subarnapur | software companies | Scroll 5 -> 36
# Subarnapur | software companies | Scroll 6 -> 36
# Subarnapur | software companies | Scroll 7 -> 36
# Subarnapur | software companies | Scroll 8 -> 36
# Collected 28 links
# Subarnapur | 1/28
# ESCRAA PVT LTD
# Phone: 06654355351
# Subarnapur | 2/28
# ESCRAA PVT LTD
# Phone: 09439119089
# Subarnapur | 3/28
# IT SOLUTION
# Phone: 08280725297
# Subarnapur | 4/28
# CELL WORLD Group Of Digital World
# Phone: 09438056144
# Subarnapur | 5/28
# OCA Computer Academy Sonepur
# Phone: 08908031231
# Subarnapur | 6/28
# Jogamaya Computer , State Bank Of India CSP
# Phone: 09937705735
# Subarnapur | 7/28
# The Computer Shop
# Phone: 09777609077
# Subarnapur | 8/28
# Sapient Computech
# Phone: 09437130485
# Subarnapur | 9/28
# Ms SAS INFOTECH
# Phone:
# Subarnapur | 10/28
# PATRA ELECTRONICS
# Phone:
# Subarnapur | 11/28
# PADHAN COMPUTERS
# Phone: 09438056159
# Subarnapur | 12/28
# Star Health & Allied Insurance - Sonepur, Odisha
# Phone:
# Subarnapur | 13/28
# SMFG India Credit Co. Ltd. - Ramjee Nagar (Branch)
# Phone: 18001036001
# Subarnapur | 14/28
# Ashis Electronics
# Phone: 09437329639
# Subarnapur | 15/28
# DS COLD STORE
# Phone:
# Subarnapur | 16/28
# BLUE DART DELIVERY OFFICE
# Phone:
# Subarnapur | 17/28
# DEVTEK MART(CSC CENTER)
# Phone:
# Subarnapur | 18/28
# CENTRAL MOBILE ,SONEPUR(WHOLESALE & RETAIL)
# Phone: 09439435323
# Subarnapur | 19/28
# BSNL Telephone Exchange
# Phone: 06654220000
# Subarnapur | 20/28
# Syflex Techno Solution Pvt. Ltd.
# Phone: 09937506028
# Subarnapur | 21/28
# PRABHAT KUMAR TRIPATHY
# Phone: 07735156777
# Subarnapur | 22/28
# Sonepur, Odisha
# Phone:
# Subarnapur | 23/28
# TM FRUITS & COLD STORE
# Phone: 09937265629
# Subarnapur | 24/28
# Ananda Mayee Bhaban
# Phone:
# Subarnapur | 25/28
# MINERVA TVS 2 WHEELER SHOWROOM SONEPUR
# Phone: 06370700733
# Subarnapur | 26/28
# SyncLedger
# Phone:
# Subarnapur | 27/28
# Bhoi Online Solution
# Phone: 09692183935
# Subarnapur | 28/28
# EPSON CERTIFIED CHANNEL PARTNER - Cell World It & Electronics
# Phone: 08506064187
#
# Searching: IT companies in Subarnapur Odisha
# Search Submitted
# Subarnapur | IT companies | Scroll 1 -> 16
# Subarnapur | IT companies | Scroll 2 -> 20
# Subarnapur | IT companies | Scroll 3 -> 28
# Subarnapur | IT companies | Scroll 4 -> 28
# Subarnapur | IT companies | Scroll 5 -> 28
# Subarnapur | IT companies | Scroll 6 -> 28
# Subarnapur | IT companies | Scroll 7 -> 28
# Collected 6 links
# Subarnapur | 1/6
# Horticulture Office
# Phone:
# Subarnapur | 2/6
# MEHERS MOBILE, Sonepur
# Phone: 09853200607
# Subarnapur | 3/6
# Jayaguru Complex
# Phone: 09658178128
# Subarnapur | 4/6
# Tentuli Ghat Sonepur
# Phone: 07978864711
# Subarnapur | 5/6
# VENKATESH OPTICALS
# Phone: 07978025450
# Subarnapur | 6/6
# OPTCL sonepur 132/33 Kv Sub station
# Phone:
#
# Searching: software companies in Sundargarh Odisha
# Search Submitted
# Sundargarh | software companies | Scroll 1 -> 16
# Sundargarh | software companies | Scroll 2 -> 20
# Sundargarh | software companies | Scroll 3 -> 28
# Sundargarh | software companies | Scroll 4 -> 36
# Sundargarh | software companies | Scroll 5 -> 40
# Sundargarh | software companies | Scroll 6 -> 48
# Sundargarh | software companies | Scroll 7 -> 56
# Sundargarh | software companies | Scroll 8 -> 57
# Sundargarh | software companies | Scroll 9 -> 57
# Sundargarh | software companies | Scroll 10 -> 57
# Sundargarh | software companies | Scroll 11 -> 57
# Sundargarh | software companies | Scroll 12 -> 57
# Collected 54 links
# Sundargarh | 1/54
# Reliance Digital
# Phone: 08071889558
# Sundargarh | 2/54
# HI-Tech Computers
# Phone: 09438490390
# Sundargarh | 3/54
# IT SUPPORTS
# Phone: 08144258774
# Sundargarh | 4/54
# Solution Explorer
# Phone: 09438490390
# Sundargarh | 5/54
# Pay for Graphics
# Phone: 08249874258
# Sundargarh | 6/54
# Delhivery
# Phone:
# Sundargarh | 7/54
# NEWTECH COMPUTER
# Phone: 07008200468
# Sundargarh | 8/54
# BharatPicks Private Limited
# Phone: 07440000844
# Sundargarh | 9/54
# Calling Bell Systems
# Phone:
# Sundargarh | 10/54
# Trangle Computer Point
# Phone: 08093116526
# Phone: 07087497184
# Sundargarh | 51/54
# IT-ZONE SERVICES
# Phone: 09337942103
# Sundargarh | 52/54
# Neotech Academy of IT & Management
# Phone:
# Sundargarh | 53/54
# Sketch Brain
# Phone:
# Sundargarh | 54/54
# BHARTI SHARE MARKET
# Phone:
#
# Searching: IT companies in Sundargarh Odisha
# Search Submitted
# Sundargarh | IT companies | Scroll 1 -> 16
# Sundargarh | IT companies | Scroll 2 -> 20
# Sundargarh | IT companies | Scroll 3 -> 28
# Sundargarh | IT companies | Scroll 4 -> 36
# Sundargarh | IT companies | Scroll 5 -> 40
# Sundargarh | IT companies | Scroll 6 -> 48
# Sundargarh | IT companies | Scroll 7 -> 56
# Sundargarh | IT companies | Scroll 8 -> 60
# Sundargarh | IT companies | Scroll 9 -> 68
# Sundargarh | IT companies | Scroll 10 -> 69
# Sundargarh | IT companies | Scroll 11 -> 69
# Sundargarh | IT companies | Scroll 12 -> 69
# Sundargarh | IT companies | Scroll 13 -> 69
# Sundargarh | IT companies | Scroll 14 -> 69
# Collected 24 links
# Sundargarh | 1/24
# Infoage Computer Academy for OSCIT Computer Centre Best Computer Centre in Sundargarh
# Phone: 09692330617
# Sundargarh | 2/24
# Logos Computer Center
# Phone: 08658703106
# Sundargarh | 3/24
# Bright Future Information Academy Sundargarh-770073 Odisha
# Phone: 09777367053
# Sundargarh | 4/24
# Sundargarh Toll Gate
# Phone:
# Sundargarh | 5/24
# Reliance SMART Superstore
# Phone: 18008910001
# Sundargarh | 6/24
# Meghmallahar Building ମେଘମଲହାର
# Phone:
# Sundargarh | 7/24
# MAA BANADURGA INTERNET PARLOUR
# Phone: 08342996946
# Sundargarh | 8/24
# SATYABHAMA CONSTRUCTION
# Phone: 08456865977
# Sundargarh | 9/24
# Tusar Complex
# Phone:
# Sundargarh | 10/24
# Adarshnagar, Sundargarh
# Phone:
# Sundargarh | 11/24
# ODISSI JEWELLERS-SUNDARGARH
# Phone: 07399115544
# Sundargarh | 12/24
# Prasad Jewellers | Best Jewellery Shop In Sundergarh
# Phone: 09668512873
# Sundargarh | 13/24
# Bittu Radium Point
# Phone: 07788909292
# Sundargarh | 14/24
# Aamba Residency
# Phone: 09090606037
# Sundargarh | 15/24
# V2 Kart Retail
# Phone:
# Sundargarh | 16/24
# Sujata Shoppe
# Phone: 06622273747
# Sundargarh | 17/24
# Sundargarh Truck Owners Association
# Phone: 06622274497
# Sundargarh | 18/24
# Raj Tour and Travels
# Phone: 08658882005
# Sundargarh | 19/24
# NTPC DARLIPALI - Sundargarh District, Odisha, India
# Phone:
# Sundargarh | 20/24
# Bajaj Life Insurance
# Phone: 02067121212
# Sundargarh | 21/24
# Chandi Bhandar
# Phone: 09124626683
# Sundargarh | 22/24
# Ancoax Technologies
# Phone: 09776447875
# Sundargarh | 23/24
# badabusiness sundargarh
# Phone:
# Sundargarh | 24/24
# A K Software Solution
# Phone:
#
# Extraction Completed
# Total Companies Extracted: 961
#
# Saved File: odisha_companies.csv
