# %%
import pandas as pd

# %%
df = pd.read_csv("maharashtra_companies.csv")

# %%
df.shape
# Out:
# (4375, 8)

# %%
df = df[
    df["Phone"].notna() &
    (df["Phone"].astype(str).str.strip() != "")
    ]
df.shape
# Out:
# (3517, 8)

# %%
df = df[
    df["Company Name"].notna()
    ]
df = df[
    df["Company Name"].str.strip() != ""
    ]
df.shape
# Out:
# (3516, 8)

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]","",regex=True)
    .str.strip()
)
display(df[["Phone"]].head())
# Out:
#          Phone
# 0  90111449200
# 1  86004361630
# 2  91194319840
# 3  24124239760
# 4  93700229680

# %%
df.to_csv(
    "maharashtracompanies_cleaned.csv",
    index=False
)
