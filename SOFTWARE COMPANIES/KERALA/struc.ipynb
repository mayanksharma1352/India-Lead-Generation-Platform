# %%
import pandas as pd

# %%
df = pd.read_csv("kerala_companies.csv")

# %%
df.shape
# Out:
# (1547, 8)

# %%
df = df[
    df["Phone"].notna() & 
    (df["Phone"].astype(str).str.strip() != "")
    ]
df.shape
# Out:
# (1309, 8)

# %%
df = df[
    df["Company Name"].notna()
    ]

df = df[
    df["Company Name"].str.strip() != ""
    ]
df.shape
# Out:
# (1305, 8)

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]","",regex=True)
    .str.strip()
)

display(df[["Phone"]].head())
# Out:
#          Phone
# 0  85939777730
# 1  94966041010
# 2  98471419940
# 3  91888331230
# 4  90611500050

# %%
df.to_csv(
    "kerala_companies_cleaned.csv",
    index=False
)
