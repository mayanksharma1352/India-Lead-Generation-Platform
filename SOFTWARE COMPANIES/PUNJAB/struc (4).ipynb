# %%
import pandas as pd

# %%
df = pd.read_csv("punjab_companies.csv")

# %%
df.shape
# Out:
# (1811, 8)

# %%
df = df[
    df["Phone"].notna() &
    (df["Phone"].astype(str).str.strip() != "")
    ]
df.shape
# Out:
# (1499, 8)

# %%
df = df[
    df["Company Name"].notna()
    ]
df = df[
    df["Company Name"].str.strip() != ""
    ]
df.shape
# Out:
# (1490, 8)

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]","",regex=True)
    .str.strip()
)
display(df[["Phone"]].head())
# Out:
#          Phone
# 0  98885535250
# 1  85270580890
# 2  74115730250
# 3  82838092410
# 4  73476136590

# %%
df.to_csv(
    "punjab_companies_cleaned.csv",
    index=False
)
