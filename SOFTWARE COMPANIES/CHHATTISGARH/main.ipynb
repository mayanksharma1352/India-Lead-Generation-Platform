# %%
import time
import random
import pandas as pd

from datetime import datetime

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.service import Service

from webdriver_manager.chrome import ChromeDriverManager



districts = [
    "Balod",
    "Baloda Bazar",
    "Balrampur",
    "Bastar",
    "Bemetara",
    "Bijapur",
    "Bilaspur",
    "Dantewada",
    "Dhamtari",
    "Durg",
    "Gariaband",
    "Gaurela-Pendra-Marwahi",
    "Janjgir-Champa",
    "Jashpur",
    "Kabirdham",
    "Kanker",
    "Khairagarh-Chhuikhadan-Gandai",
    "Kondagaon",
    "Korba",
    "Korea",
    "Mahasamund",
    "Manendragarh-Chirmiri-Bharatpur",
    "Mohla-Manpur-Ambagarh Chowki",
    "Mungeli",
    "Narayanpur",
    "Raigarh",
    "Raipur",
    "Rajnandgaon",
    "Sakti",
    "Sarangarh-Bilaigarh",
    "Sukma",
    "Surajpur",
    "Surguja"
]

search_types = [
    "software companies",
    "IT companies"
]


options = webdriver.ChromeOptions()

options.add_argument("--start-maximized")

options.add_argument(
    "--disable-blink-features=AutomationControlled"
)

options.add_argument("--disable-notifications")


driver = webdriver.Chrome(

    service=Service(
        ChromeDriverManager().install()
    ),

    options=options
)


driver.get("https://www.google.com/maps")

print("Opening Google Maps...")

time.sleep(15)

print("Google Maps Loaded")


all_data = []

visited_links = set()


def get_search_box():

    selectors = [

        '//input[@id="searchboxinput"]',
        '//input[contains(@placeholder,"Search")]',
        '//input[contains(@aria-label,"Search")]',
        '//input'

    ]

    for selector in selectors:

        try:

            box = driver.find_element(
                By.XPATH,
                selector
            )

            return box

        except:
            pass

    return None


def extract_school_data():

    try:

        try:

            name = driver.find_element(
                By.TAG_NAME,
                "h1"
            ).text

        except:

            name = ""


        try:

            address = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"address")]'
            ).text

        except:

            address = ""


        phone = ""

        try:

            phone_xpaths = [


                '//button[contains(@data-item-id,"phone")]',


                '//a[contains(@href,"tel:")]',


                '//button[contains(@aria-label,"Phone")]',

 
                '//button[contains(text(),"+91")]',
                '//div[contains(text(),"+91")]',
                '//span[contains(text(),"+91")]'

            ]

            for xpath in phone_xpaths:

                try:

                    elements = driver.find_elements(
                        By.XPATH,
                        xpath
                    )

                    for element in elements:

                        text = element.text.strip()

                        href = (
                            element.get_attribute("href")
                            or ""
                        )

  
                        if "tel:" in href:

                            phone = href.replace(
                                "tel:",
                                ""
                            ).strip()


                        elif text:

                            phone = text

                        phone = (

                            phone.replace("", "")
                            .replace(" ", "")
                            .replace("-", "")
                            .replace("(", "")
                            .replace(")", "")
                            .replace("\n", "")
                            .strip()

                        )


                        digits = ''.join(
                            filter(str.isdigit, phone)
                        )

                        if len(digits) >= 10:

                            break

                    if phone:
                        break

                except:
                    pass

        except Exception as e:

            print(f"Phone Error: {e}")



        try:

            website = driver.find_element(
                By.XPATH,
                '//a[contains(@data-item-id,"authority")]'
            ).get_attribute("href")

        except:

            website = ""



        try:

            rating = driver.find_element(
                By.XPATH,
                '//div[@role="img"]'
            ).get_attribute("aria-label")

        except:

            rating = ""

        return {

            "Company Name": name,
            "Address": address,
            "Phone": phone,
            "Website": website,
            "Rating": rating,
            "Google Maps URL": driver.current_url

        }

    except:

        return None



for district in districts:

    for search_type in search_types:

        try:

            query = (
                f"{search_type} "
                f"in {district} Chhattisgarh"
            )

            print(f"\nSearching: {query}")



            search_box = get_search_box()

            if not search_box:

                print("Search Box Not Found")

                continue

            ActionChains(driver).move_to_element(
                search_box
            ).click().perform()

            time.sleep(1)

            search_box.send_keys(
                Keys.CONTROL + "a"
            )

            time.sleep(1)

            search_box.send_keys(Keys.DELETE)

            time.sleep(1)


            for char in query:

                search_box.send_keys(char)

                time.sleep(0.03)

            search_box.send_keys(Keys.ENTER)

            print("Search Submitted")

            time.sleep(8)


            try:

                scrollable_div = driver.find_element(
                    By.XPATH,
                    '//div[@role="feed"]'
                )

                previous_count = 0

                stagnant = 0

                for i in range(100):

                    driver.execute_script(
                        """
                        arguments[0].scrollTop =
                        arguments[0].scrollHeight
                        """,
                        scrollable_div
                    )

                    time.sleep(4)

                    listings = driver.find_elements(
                        By.XPATH,
                        '//a[contains(@href,"/maps/place/")]'
                    )

                    current_count = len(listings)

                    print(
                        f"{district} | "
                        f"{search_type} | "
                        f"Scroll {i+1} -> "
                        f"{current_count}"
                    )

                    if current_count == previous_count:

                        stagnant += 1

                    else:

                        stagnant = 0

                    if stagnant >= 4:

                        break

                    previous_count = current_count

            except Exception as e:

                print(f"Scrolling Error: {e}")


            listings = driver.find_elements(
                By.XPATH,
                '//a[contains(@href,"/maps/place/")]'
            )

            links = []

            for listing in listings:

                try:

                    link = listing.get_attribute("href")

                    if (
                        link
                        and link not in visited_links
                    ):

                        links.append(link)

                        visited_links.add(link)

                except:
                    pass

            print(f"Collected {len(links)} links")


            for index, link in enumerate(links):

                try:

                    print(
                        f"{district} | "
                        f"{index+1}/{len(links)}"
                    )

                    driver.get(link)

                    time.sleep(
                        random.uniform(2, 3)
                    )

                    data = extract_school_data()

                    if data:

                        data["District"] = district

                        data["Search Type"] = search_type

                        all_data.append(data)

                        print(data["Company Name"])

                        print(
                            f"Phone: {data['Phone']}"
                        )


                    if len(all_data) % 100 == 0:

                        backup_df = pd.DataFrame(
                            all_data
                        )

                        backup_df.drop_duplicates(
                            subset=[
                                "Company Name",
                                "Google Maps URL"
                            ],
                            inplace=True
                        )

                        backup_df.to_csv(
                            "chhattisgarh_companies_backup.csv",
                            index=False
                        )

                        print("Backup Saved")

                except Exception as e:

                    print(
                        f"Company Error: {e}"
                    )

        except Exception as e:

            print(
                f"District Error: {e}"
            )


df = pd.DataFrame(all_data)

df.drop_duplicates(

    subset=[
        "Company Name",
        "Google Maps URL"
    ],

    inplace=True
)

filename = "chhattisgarh_companies.csv"

df.to_csv(
    filename,
    index=False
)

print("\nExtraction Completed")

print(
    f"Total Companies Extracted: {len(df)}"
)

print(f"\nSaved File: {filename}")

driver.quit()
# Out:
# Opening Google Maps...
# Google Maps Loaded
#
# Searching: software companies in Balod Chhattisgarh
# Search Submitted
# Balod | software companies | Scroll 1 -> 14
# Balod | software companies | Scroll 2 -> 14
# Balod | software companies | Scroll 3 -> 14
# Balod | software companies | Scroll 4 -> 14
# Balod | software companies | Scroll 5 -> 14
# Collected 14 links
# Balod | 1/14
# Pratiksha Infotech Balod
# Phone: 09399793592
# Balod | 2/14
# IT CARE & Services BALOD
# Phone:
# Balod | 3/14
# AKSHAYANI IT SOLUTIONS PRIVATE LIMITED ( Premier & Best Software Company in Raipur, Chhattisgarh, India)
# Phone: 09713665118
# Balod | 4/14
# Sumeet Bazaar Balod Chhattisgarh
# Phone: 07000790838
# Balod | 5/14
# जैन ऑप्टिकल चश्मा दुकान बालोद
# Phone:
# Balod | 6/14
# P.N.Nursery and Bio Agro. Product
# Phone:
# Balod | 7/14
# Arihant mobile and computers balod
# Phone: 09770566222
# Balod | 8/14
# Tumbledry Dry Clean & Laundry Service
# Phone: 07677250250
# Balod | 9/14
# LAKSHYA LIBRARY BALOD
# Phone: 09643264438
# Balod | 10/14
# TECHNODARK INDIA PRISM LLP
# Phone: 09691696699
# Balod | 11/14
# Gic Computer
# Phone: 08109379061
# Balod | 12/14
# LIC of India, Satellite Office
# Phone:
# Balod | 13/14
# LNS IT SOLUTION
# Phone: 09754214667
# Balod | 14/14
# .
# Phone:
#
# Searching: IT companies in Balod Chhattisgarh
# Search Submitted
# Balod | IT companies | Scroll 1 -> 14
# Balod | IT companies | Scroll 2 -> 17
# Balod | IT companies | Scroll 3 -> 17
# Balod | IT companies | Scroll 4 -> 17
# Balod | IT companies | Scroll 5 -> 17
# Balod | IT companies | Scroll 6 -> 17
# Collected 5 links
# Balod | 1/5
# TOP LIC AGENT BALOD AJIT SAHU, HEALTH INSURANCE, SIP, MUTUAL FUND, CAR BIKE INSURANCE
# Phone: 09993051384
# Balod | 2/5
# Indane - Govind
# Phone: 09406320000
# Balod | 3/5
# German drycleaners
# Phone:
# Balod | 4/5
# Shekhar Dewangan
# Phone:
# Balod | 5/5
# Gauransh Computer's
# Phone: 09669840008
#
# Searching: software companies in Baloda Bazar Chhattisgarh
# Search Submitted
# Baloda Bazar | software companies | Scroll 1 -> 14
# Baloda Bazar | software companies | Scroll 2 -> 20
# Baloda Bazar | software companies | Scroll 3 -> 20
# Baloda Bazar | software companies | Scroll 4 -> 20
# Baloda Bazar | software companies | Scroll 5 -> 20
# Baloda Bazar | software companies | Scroll 6 -> 20
# Collected 19 links
# Baloda Bazar | 1/19
# Earth technologies & Mobile
# Phone: 09424124434
# Baloda Bazar | 2/19
# verma computer sales & service
# Phone: 09691917858
# Baloda Bazar | 3/19
# Neha Computers
# Phone: 09826300075
# Baloda Bazar | 4/19
# Kanchan Steel & Cooler
# Phone: 07415266902
# Baloda Bazar | 5/19
# Globus Computers Balodabazar
# Phone: 09753164153
# Baloda Bazar | 6/19
# Hanumanta Computers
# Phone: 08461084640
# Baloda Bazar | 7/19
# Rigyasa Technologies - IT Company, Website Design, Software and Mobile (Android/ iOS) App Development Company in Raipur
# Phone: 08889555393
# Baloda Bazar | 8/19
# Aditya Vardhan’s Mansion And Apartments
# Phone: 08888882096
# Baloda Bazar | 9/19
# Rajesh Time Centre
# Phone: 09826306306
# Baloda Bazar | 10/19
# Krishana Apartment
# Phone: 09826104028
# Baloda Bazar | 11/19
# Tumbledry Dry Clean & Laundry Service
# Phone: 07677250250
# Baloda Bazar | 12/19
# PREM CCTV & IT SOLUTION
# Phone: 09753993023
# Baloda Bazar | 13/19
# Maheshwari Buildcon
# Phone:
# Baloda Bazar | 14/19
# Samsung Experience Store Lawan Road
# Phone: 09826122940
# Baloda Bazar | 15/19
# Fabrico Laundry & Dry Clean Service
# Phone: 01206824455
# Baloda Bazar | 16/19
# Raman cycle company
# Phone: 08889898003
# Baloda Bazar | 17/19
# valecha marketing
# Phone:
# Baloda Bazar | 18/19
# softwere engnear
# Phone: 07089340017
# Baloda Bazar | 19/19
# Swastik Buildcon
# Phone: 09926670336
#
# Searching: IT companies in Baloda Bazar Chhattisgarh
# Search Submitted
# Baloda Bazar | IT companies | Scroll 1 -> 14
# Baloda Bazar | IT companies | Scroll 2 -> 20
# Baloda Bazar | IT companies | Scroll 3 -> 27
# Baloda Bazar | IT companies | Scroll 4 -> 34
# Baloda Bazar | IT companies | Scroll 5 -> 40
# Baloda Bazar | IT companies | Scroll 6 -> 47
# Baloda Bazar | IT companies | Scroll 7 -> 54
# Baloda Bazar | IT companies | Scroll 8 -> 60
# Baloda Bazar | IT companies | Scroll 9 -> 67
# Baloda Bazar | IT companies | Scroll 10 -> 74
# Baloda Bazar | IT companies | Scroll 11 -> 80
# Baloda Bazar | IT companies | Scroll 12 -> 87
# Baloda Bazar | IT companies | Scroll 13 -> 94
# Baloda Bazar | IT companies | Scroll 14 -> 100
# Baloda Bazar | IT companies | Scroll 15 -> 107
# Baloda Bazar | IT companies | Scroll 16 -> 114
# Baloda Bazar | IT companies | Scroll 17 -> 120
# Baloda Bazar | IT companies | Scroll 18 -> 120
# Baloda Bazar | IT companies | Scroll 19 -> 120
# Baloda Bazar | IT companies | Scroll 20 -> 120
# Baloda Bazar | IT companies | Scroll 21 -> 120
# Collected 109 links
# Baloda Bazar | 1/109
# valecha Systems baloda bazar
# Phone:
# Baloda Bazar | 2/109
# Dhruw Analytics & Services
# Phone:
# Baloda Bazar | 3/109
# Hemant
# Phone:
# Baloda Bazar | 4/109
# Prem Computers Online Centre
# Phone:
# Baloda Bazar | 5/109
# Idea Office
# Phone:
# Baloda Bazar | 6/109
# AISECT COMPUTERS PRASHIKSHAN KENDRA BALODA BAZAR
# Phone: 09165602202
# Baloda Bazar | 7/109
# REPAIR ZONE
# Phone: 09644907481
# Baloda Bazar | 8/109
# BSNL FRANCHISEE IN BALODA BAZAR TERRITORY
# Phone: 09479098900
# Baloda Bazar | 9/109
# Laxmi mobile
# Phone:
# Baloda Bazar | 10/109
# Rituraj printer ऋतुराज प्रिंटर
# Phone:
# Baloda Bazar | 11/109
# Shri Ram Printers
# Phone: 09926480181
# Baloda Bazar | 12/109
# Jio Point
# Phone: 18608933333
# Baloda Bazar | 13/109
# BHOOMI MOBILE & SALES
# Phone: 07697121230
# Baloda Bazar | 14/109
# Vj Video Mixing -Best Studio in Baloda Bazar Chhattisgarh | Best Photographer in Chhattisgarh
# Phone: 07869504624
# Vikas jewellers masjid complex Sadar road Baloda Bazar (CG)
# Phone:
# Baloda Bazar | 99/109
# Kanchanjangha colony Dheeraj sahu
# Phone:
# Baloda Bazar | 100/109
# lakhesh sahu
# Phone:
# Baloda Bazar | 101/109
# Shiv tour and travels
# Phone:
# Baloda Bazar | 102/109
# Sree ram tractor
# Phone:
# Baloda Bazar | 103/109
# Purani Basti Shiv Chauk (Vikas Patel)
# Phone:
# Baloda Bazar | 104/109
# ByOS IT Services | Digital Marketing, SEO, Web Design and Development Company in Raipur
# Phone: 09713904500
# Baloda Bazar | 105/109
# Shri Ram Jewellers
# Phone:
# Baloda Bazar | 106/109
# Mangal bhavan balodabazar
# Phone:
# Baloda Bazar | 107/109
# The New India Assurance Company Limited
# Phone: 07727222784
# Baloda Bazar | 108/109
# VIDYARTHI ONLINE CENTER
# Phone:
# Baloda Bazar | 109/109
# A R C PARCEL SERVICE PRIVATE LIMITED
# Phone: 07727222116
#
# Searching: software companies in Balrampur Chhattisgarh
# Search Submitted
# Balrampur | software companies | Scroll 1 -> 14
# Balrampur | software companies | Scroll 2 -> 20
# Balrampur | software companies | Scroll 3 -> 23
# Balrampur | software companies | Scroll 4 -> 23
# Balrampur | software companies | Scroll 5 -> 23
# Balrampur | software companies | Scroll 6 -> 23
# Balrampur | software companies | Scroll 7 -> 23
# Collected 20 links
# Balrampur | 1/20
# Shri Ram Computer
# Phone: 06266312510
# Balrampur | 2/20
# BHARAT COMPUTERS & CCTV CAMERA
# Phone: 08966994403
# Balrampur | 3/20
# Mahamaya Computer And Printer
# Phone: 09111611361
# Balrampur | 4/20
# Shri Ram Computer 2
# Phone: 06266312510
# Balrampur | 5/20
# KLEARNY MARKETING PRIVATE LIMITED
# Phone: 08305499293
# Balrampur | 6/20
# Shri Ram Suvidha Kendra
# Phone: 07974444133
# Balrampur | 7/20
# Mahindra Tractors - Mahamaya Tractors
# Phone: 08071639122
# Balrampur | 8/20
# Mahamaya Mobile Shop
# Phone: 09644464501
# Balrampur | 9/20
# TrueNet IT Solutions Balrampur
# Phone: 09589691992
# Balrampur | 10/20
# Focus Media #1 Software Company in Chhattisgarh | Mobile App Development | Website Development | Software Development
# Phone: 09575126240
# Balrampur | 11/20
# Aanandi TechnoSoft - Top Mobile App Development Company | Hire Custom iOS & Android App Developers
# Phone: 09713846846
# Balrampur | 12/20
# Jain Software
# Phone: 09111554999
# Balrampur | 13/20
# Manpushp Software LLP.
# Phone: 07714013599
# Balrampur | 14/20
# Dunga Printing Press
# Phone: 06263076902
# Balrampur | 15/20
# Axis Bank Branch
# Phone: 18605005555
# Balrampur | 16/20
# ABH COMPUTER AND SERVICE
# Phone:
# Balrampur | 17/20
# EZ Soft tech
# Phone: 08962370822
# Balrampur | 18/20
# Tata Motors Cars Showroom - Sunil Auto Cars, Ramanujganj Road
# Phone: 08291142365
# Balrampur | 19/20
# Online work center
# Phone:
# Balrampur | 20/20
# Secure computer solution Balrampur
# Phone:
#
# Searching: IT companies in Balrampur Chhattisgarh
# Search Submitted
# Balrampur | IT companies | Scroll 1 -> 14
# Balrampur | IT companies | Scroll 2 -> 18
# Balrampur | IT companies | Scroll 3 -> 18
# Balrampur | IT companies | Scroll 4 -> 18
# Balrampur | IT companies | Scroll 5 -> 18
# Balrampur | IT companies | Scroll 6 -> 18
# Collected 6 links
# Balrampur | 1/6
# Web development
# Phone: 09589691992
# Balrampur | 2/6
# Aragahi Coldstorage, Aragahi Balrampur
# Phone: 08770953171
# Balrampur | 3/6
# Anand offset printers
# Phone:
# Balrampur | 4/6
# CSC ONLINE SERVICES CENTRE
# Phone: 09131178347
# Balrampur | 5/6
# PANKAJ
# Phone: 09827606337
# Balrampur | 6/6
# Sandip Mandal
# Phone: 09301473613
#
# Searching: software companies in Bastar Chhattisgarh
# Search Submitted
# Bastar | software companies | Scroll 1 -> 3
# Bastar | software companies | Scroll 2 -> 3
# Bastar | software companies | Scroll 3 -> 3
# Bastar | software companies | Scroll 4 -> 3
# Bastar | software companies | Scroll 5 -> 3
# Collected 2 links
# Bastar | 1/2
# Company Error: HTTPConnectionPool(host='localhost', port=55433): Read timed out. (read timeout=120)
# Bastar | 2/2
# Company Error: HTTPConnectionPool(host='localhost', port=55433): Read timed out. (read timeout=120)
#
# Searching: IT companies in Bastar Chhattisgarh
# Search Box Not Found
#
# Searching: software companies in Bemetara Chhattisgarh
# Search Box Not Found
#
# Searching: IT companies in Bemetara Chhattisgarh
# Search Box Not Found
#
# Searching: software companies in Bijapur Chhattisgarh
# Search Box Not Found
#
# Searching: IT companies in Bijapur Chhattisgarh
# Search Box Not Found
#
# Searching: software companies in Bilaspur Chhattisgarh
# Search Box Not Found
#
# Searching: IT companies in Bilaspur Chhattisgarh
# Search Box Not Found
#
# Searching: software companies in Dantewada Chhattisgarh
# Search Box Not Found
#
# Searching: IT companies in Dantewada Chhattisgarh
# Search Box Not Found
#
# Searching: software companies in Dhamtari Chhattisgarh
# Search Box Not Found
#
# Searching: IT companies in Dhamtari Chhattisgarh
# Search Box Not Found
#
# Searching: software companies in Durg Chhattisgarh
# Search Box Not Found
#
# Searching: IT companies in Durg Chhattisgarh
# Search Box Not Found
#
# Searching: software companies in Gariaband Chhattisgarh
# Search Box Not Found
#
# Searching: IT companies in Gariaband Chhattisgarh
# Search Box Not Found
#
# Searching: software companies in Gaurela-Pendra-Marwahi Chhattisgarh
# Search Box Not Found
#
# Searching: IT companies in Gaurela-Pendra-Marwahi Chhattisgarh
# Search Box Not Found
#
# Searching: software companies in Janjgir-Champa Chhattisgarh
# Search Box Not Found
#
# Searching: IT companies in Janjgir-Champa Chhattisgarh
# Search Box Not Found
#
# Searching: software companies in Jashpur Chhattisgarh
# Search Box Not Found
#
# Searching: IT companies in Jashpur Chhattisgarh
# Search Box Not Found
#
# Searching: software companies in Kabirdham Chhattisgarh
# Search Box Not Found
#
# Searching: IT companies in Kabirdham Chhattisgarh
# Search Box Not Found
#
# Searching: software companies in Kanker Chhattisgarh
# Search Box Not Found
#
# Searching: IT companies in Kanker Chhattisgarh
# Search Box Not Found
#
# Searching: software companies in Khairagarh-Chhuikhadan-Gandai Chhattisgarh
# Search Box Not Found
#
# Searching: IT companies in Khairagarh-Chhuikhadan-Gandai Chhattisgarh
# Search Box Not Found
#
# Searching: software companies in Kondagaon Chhattisgarh
# Search Box Not Found
#
# Searching: IT companies in Kondagaon Chhattisgarh
# Search Box Not Found
#
# Searching: software companies in Korba Chhattisgarh
# Search Box Not Found
#
# Searching: IT companies in Korba Chhattisgarh
# Search Box Not Found
#
# Searching: software companies in Korea Chhattisgarh
# Search Box Not Found
#
# Searching: IT companies in Korea Chhattisgarh
# Search Box Not Found
#
# Searching: software companies in Mahasamund Chhattisgarh
# Search Box Not Found
#
# Searching: IT companies in Mahasamund Chhattisgarh
# Search Box Not Found
#
# Searching: software companies in Manendragarh-Chirmiri-Bharatpur Chhattisgarh
# Search Box Not Found
#
# Searching: IT companies in Manendragarh-Chirmiri-Bharatpur Chhattisgarh
# Search Box Not Found
#
# Searching: software companies in Mohla-Manpur-Ambagarh Chowki Chhattisgarh
# Search Box Not Found
#
# Searching: IT companies in Mohla-Manpur-Ambagarh Chowki Chhattisgarh
# Search Box Not Found
#
# Searching: software companies in Mungeli Chhattisgarh
# Search Box Not Found
#
# Searching: IT companies in Mungeli Chhattisgarh
# Search Box Not Found
#
# Searching: software companies in Narayanpur Chhattisgarh
# Search Box Not Found
#
# Searching: IT companies in Narayanpur Chhattisgarh
# Search Box Not Found
#
# Searching: software companies in Raigarh Chhattisgarh
# Search Submitted
# Scrolling Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@role="feed"]"}
#   (Session info: chrome=148.0.7778.168); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 	chromedriver!GetHandleVerifier [0xa7b593+105d3]
# 	chromedriver!GetHandleVerifier [0xa7b6c4+10704]
# 	chromedriver!(No symbol) [0x881ea0]
# 	chromedriver!(No symbol) [0x8cb28a]
# 	chromedriver!(No symbol) [0x8cb52b]
# 	chromedriver!(No symbol) [0x90d052]
# 	chromedriver!(No symbol) [0x8ed7c4]
# 	chromedriver!(No symbol) [0x90a936]
# 	chromedriver!(No symbol) [0x8ed516]
# 	chromedriver!(No symbol) [0x8c08e9]
# 	chromedriver!(No symbol) [0x8c16a4]
# 	chromedriver!GetHandleVerifier [0xd03014+298054]
# 	chromedriver!GetHandleVerifier [0xcfe603+293643]
# 	chromedriver!GetHandleVerifier [0xd1ea05+2b3a45]
# 	chromedriver!GetHandleVerifier [0xa954e8+2a528]
# 	chromedriver!GetHandleVerifier [0xa9cd1d+31d5d]
# 	chromedriver!GetHandleVerifier [0xa83e68+18ea8]
# 	chromedriver!GetHandleVerifier [0xa84015+19055]
# 	chromedriver!GetHandleVerifier [0xa6d65f+269f]
# 	KERNEL32!BaseThreadInitThunk [0x75c9fcc9+19]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x77a082ae+11e]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x77a0827e+ee]
#
# Collected 0 links
#
# Searching: IT companies in Raigarh Chhattisgarh
# Search Submitted
# Raigarh | IT companies | Scroll 1 -> 10
# Raigarh | IT companies | Scroll 2 -> 15
# Raigarh | IT companies | Scroll 3 -> 20
# Raigarh | IT companies | Scroll 4 -> 25
# Raigarh | IT companies | Scroll 5 -> 30
# Raigarh | IT companies | Scroll 6 -> 35
# Raigarh | IT companies | Scroll 7 -> 40
# Raigarh | IT companies | Scroll 8 -> 45
# Raigarh | IT companies | Scroll 9 -> 50
# Raigarh | IT companies | Scroll 10 -> 55
# Raigarh | IT companies | Scroll 11 -> 60
# Raigarh | IT companies | Scroll 12 -> 65
# Raigarh | IT companies | Scroll 13 -> 70
# Raigarh | IT companies | Scroll 14 -> 75
# Raigarh | IT companies | Scroll 15 -> 80
# Raigarh | IT companies | Scroll 16 -> 82
# Raigarh | IT companies | Scroll 17 -> 82
# Raigarh | IT companies | Scroll 18 -> 82
# Raigarh | IT companies | Scroll 19 -> 82
# Raigarh | IT companies | Scroll 20 -> 82
# Collected 81 links
# Raigarh | 1/81
# SunGround Technologies Pvt Ltd
# Phone: 07000391261
# Raigarh | 2/81
# Infowt
# Phone: 09644772226
# Raigarh | 3/81
# IT Junkies
# Phone:
# Raigarh | 4/81
# Reliance Digital
# Phone: 08071890110
# Raigarh | 5/81
# Unique Computer Systems
# Phone: 09425251500
# Raigarh | 6/81
# TULSI DIGITAL COMPANY
# Phone: 09692576629
# Raigarh | 7/81
# HARDNET I.T.
# Phone: 07974993870
# Raigarh | 8/81
# Asharam Technologies (CCTV Camera)
# Phone: 08435600036
# Raigarh | 9/81
# KK Computer Hub
# Phone: 09752993963
# Raigarh | 10/81
# Priyanshu Agrawal
# Phone:
# Raigarh | 11/81
# Virus Computers
# Phone: 09993287777
# Raigarh | 12/81
# Shree Digital Services
# Phone: 07354979223
# Raigarh | 13/81
# Sahyog Website And Software
# Phone: 08966817281
# Raigarh | 14/81
# CompuTech Solutions
# Phone: 08878585632
# Raigarh | 15/81
# Anjani Computers - Laptop Repair Specialist
# Phone: 09827118868
# Raigarh | 16/81
# NICE Technology
# Phone: 09893195163
# Raigarh | 17/81
# Jainx Laptop & Computer Raigarh- Exclusive Store|Best Laptop & Computer Shop Near Raigarh|Gaming Laptop Dealer (ASUS,HP)DELL
# Phone: 09303030335
# Raigarh | 18/81
# SuryaGrid Energy Raigarh
# Phone:
# Raigarh | 19/81
# Pc Aventure
# Phone: 09827194840
# Raigarh | 20/81
# Rohit Cellcom
# Phone: 08770013985
# Raigarh | 21/81
# Mahendra Computers
# Phone: 09301010287
# Raigarh | 22/81
# KKR Packers and Movers
# Phone: 07415509912
# Raigarh | 23/81
# Net computers- Best Computer Repair & Services in Raigarh/ Best Computer & Laptop Dealer near Ramniwas Talkies Chowk Raigarh/ Top Printer Dealer in Raigarh
# Phone: 09425570330
# Raigarh | 24/81
# Cholamandalam Investment and Finance Company Limited
# Phone: 08044465675
# Raigarh | 25/81
# Manoj Communication,Megha System & Security Solutions,Raigarh
# Phone: 09893051590
# Raigarh | 26/81
# Sanskar Advertizer, Printers & Hosiery Raigarh
# Phone: 08871749500
# Raigarh | 27/81
# Teli Organics
# Phone: 09893282444
# Backup Saved
# Raigarh | 28/81
# ANUPAM ELECTRONICS
# Phone: 09981166103
# Raigarh | 29/81
# HP World - Raigarh
# Phone: 08291925598
# Raigarh | 30/81
# Yash Printers | Flex, Digital, Multi-colour Offset Printing & 3D LED Letters
# Phone: 09920303089
# Raigarh | 31/81
# ADITYA BUSINESS PARK
# Phone: 07762223425
# Raigarh | 32/81
# Sudarshan Solar
# Phone: 09926599997
# Raigarh | 33/81
# Raipur | 25/39
# Avinash Group
# Phone: 09098222444
# Raipur | 26/39
# F1 Infosolutions & Services Pvt Ltd - Raipur
# Phone: 07714035375
# Raipur | 27/39
# Renown Infotech
# Phone: 08319132469
# Raipur | 28/39
# Sunita Developers by SGL
# Phone: 07714061122
# Raipur | 29/39
# Technowild
# Phone: 679240856
# Raipur | 30/39
# ITM University, Raipur
# Phone: 09826598201
# Raipur | 31/39
# Singhania Buildcon Pvt. Ltd
# Phone: 09827321321
# Raipur | 32/39
# Starshine - Smart TV, Washing Machine, Mixer Grinder, Fans, Air Coolers
# Phone:
# Raipur | 33/39
# Sangyaa PR
# Phone: 09827985386
# Raipur | 34/39
# G.D. CONSTRUCTIONS AND CONSULTANCY
# Phone:
# Raipur | 35/39
# 24x7 IT HUB
# Phone: 07770876217
# Backup Saved
# Raipur | 36/39
# Singhania IT Solutions
# Phone: 09109901160
# Raipur | 37/39
# XHITIZ IT SOLUTION
# Phone: 07714090218
# Raipur | 38/39
# Manasvi Info Tech
# Phone: 07828711116
# Raipur | 39/39
# Info Byte IT Services
# Phone:
#
# Searching: software companies in Rajnandgaon Chhattisgarh
# Search Submitted
# Rajnandgaon | software companies | Scroll 1 -> 14
# Rajnandgaon | software companies | Scroll 2 -> 20
# Rajnandgaon | software companies | Scroll 3 -> 27
# Rajnandgaon | software companies | Scroll 4 -> 32
# Rajnandgaon | software companies | Scroll 5 -> 32
# Rajnandgaon | software companies | Scroll 6 -> 32
# Rajnandgaon | software companies | Scroll 7 -> 32
# Rajnandgaon | software companies | Scroll 8 -> 32
# Collected 32 links
# Rajnandgaon | 1/32
# iColab Softwares Pvt. Ltd.
# Phone: 08817788188
# Rajnandgaon | 2/32
# Shah Tally Solutions
# Phone: 09329745797
# Rajnandgaon | 3/32
# Website Designing Company Rajnandgaon Chhattisgarh
# Phone: 08962921153
# Rajnandgaon | 4/32
# Tact4Tech Infosystems Pvt. Ltd.
# Phone: 09589593300
# Rajnandgaon | 5/32
# IamChhattisgarh.Com - Digital marketing Company
# Phone: 08839555031
# Rajnandgaon | 6/32
# EVERDEMY
# Phone: 08448444149
# Rajnandgaon | 7/32
# Lenovo Exclusive Store - Arihant Computers
# Phone: 08048045560
# Rajnandgaon | 8/32
# Arihant Computers
# Phone: 07788997611
# Rajnandgaon | 9/32
# Romsan It Services Private Limited
# Phone:
# Rajnandgaon | 10/32
# Dell Exclusive Store - Rajnandgaon
# Phone: 09513631770
# Rajnandgaon | 11/32
# Pro Wizards Inc.
# Phone: 07744225223
# Rajnandgaon | 12/32
# Ample Computer Institute
# Phone: 09827033291
# Rajnandgaon | 13/32
# Rk Enterprises & CCTV Camera Computer IT Networking
# Phone: 06263252519
# Rajnandgaon | 14/32
# NN COMPUTER SHOP
# Phone: 09200053819
# Rajnandgaon | 15/32
# Kalptaru
# Phone: 09770727600
# Rajnandgaon | 16/32
# SINGH Computers - Best Computer Store In Rajnandgaon | Best Laptop & CCTV Camera Store | Best Computer Accessories Store
# Phone: 09827195345
# Rajnandgaon | 17/32
# SUMIT COMPUTER
# Phone: 08103380993
# Rajnandgaon | 18/32
# Croma - Rajnandgaon
# Phone: 09311153129
# Rajnandgaon | 19/32
# Bech De Kharid Le
# Phone: 07338899485
# Rajnandgaon | 20/32
# PECON
# Phone:
# Rajnandgaon | 21/32
# COMPUTER SOLUTION
# Phone: 09301524693
# Rajnandgaon | 22/32
# Interior Tech Interior Designing Studio
# Phone: 09755977779
# Rajnandgaon | 23/32
# Honey Choice Center
# Phone:
# Rajnandgaon | 24/32
# Arosys Technologies Private Limited
# Phone: 08223962409
# Rajnandgaon | 25/32
# Veshro Tech
# Phone:
# Rajnandgaon | 26/32
# Mahi Infotech , Rajnandgaon Software company
# Phone: 09098350946
# Rajnandgaon | 27/32
# Solver solutions GST ERP software company
# Phone: 08817788188
# Rajnandgaon | 28/32
# MINATECHLABS PRIVATE LIMITED
# Phone:
# Rajnandgaon | 29/32
# Hive Five SaaS Solutions
# Phone:
# Rajnandgaon | 30/32
# Trackmygaddi
# Phone: 07440767000
# Rajnandgaon | 31/32
# UBACODE TECHNOLOGIES
# Phone: 09244116399
# Rajnandgaon | 32/32
# Shree Computers
# Phone: 09425244504
#
# Searching: IT companies in Rajnandgaon Chhattisgarh
# Search Submitted
# Rajnandgaon | IT companies | Scroll 1 -> 12
# Rajnandgaon | IT companies | Scroll 2 -> 12
# Rajnandgaon | IT companies | Scroll 3 -> 12
# Rajnandgaon | IT companies | Scroll 4 -> 12
# Rajnandgaon | IT companies | Scroll 5 -> 12
# Collected 3 links
# Rajnandgaon | 1/3
# Shri Shanti Poha Udyog
# Phone: 09827197300
# Rajnandgaon | 2/3
# Swastik Solar- ONGrid Solar Power Plant
# Phone: 09294509900
# Rajnandgaon | 3/3
# Media Infotech
# Phone: 09826190298
#
# Searching: software companies in Sakti Chhattisgarh
# Search Submitted
# Sakti | software companies | Scroll 1 -> 10
# Sakti | software companies | Scroll 2 -> 10
# Sakti | software companies | Scroll 3 -> 10
# Sakti | software companies | Scroll 4 -> 10
# Sakti | software companies | Scroll 5 -> 10
# Collected 8 links
# Sakti | 1/8
# Kshiti Technologies
# Phone:
# Sakti | 2/8
# Shekhar Computers
# Phone: 09302295415
# Sakti | 3/8
# Rekixo
# Phone:
# Sakti | 4/8
# Vijay Computer AI
# Phone: 09244355855
# Sakti | 5/8
# Infotech Solution
# Phone:
# Sakti | 6/8
# Krishna K Tiwari ( Web Developer in SAKTI )
# Phone:
# Sakti | 7/8
# OnlineKiyaKya Digital Marketing Agency in Sakti Chhattisgarh
# Phone: 09718876817
# Sakti | 8/8
# Today 360
# Phone:
#
# Searching: IT companies in Sakti Chhattisgarh
# Search Submitted
# Sakti | IT companies | Scroll 1 -> 7
# Sakti | IT companies | Scroll 2 -> 7
# Sakti | IT companies | Scroll 3 -> 7
# Sakti | IT companies | Scroll 4 -> 7
# Sakti | IT companies | Scroll 5 -> 7
# Collected 4 links
# Sakti | 1/4
# Vandana Trailors and Body Mfg Pvt Ltd
# Phone: 08085966240
# Sakti | 2/4
# Jio Point
# Phone:
# Sakti | 3/4
# leela sales & electronic
# Phone: 09329606263
# Sakti | 4/4
# Sakti E Seva Kendra
# Phone: 07898905273
#
# Searching: software companies in Sarangarh-Bilaigarh Chhattisgarh
# Search Submitted
# Sarangarh-Bilaigarh | software companies | Scroll 1 -> 4
# Sarangarh-Bilaigarh | software companies | Scroll 2 -> 4
# Sarangarh-Bilaigarh | software companies | Scroll 3 -> 4
# Sarangarh-Bilaigarh | software companies | Scroll 4 -> 4
# Sarangarh-Bilaigarh | software companies | Scroll 5 -> 4
# Collected 2 links
# Sarangarh-Bilaigarh | 1/2
# केडिया मार्केटिंग
# Phone: 09300634757
# Sarangarh-Bilaigarh | 2/2
# iNFOSOFT Computers Services
# Phone:
#
# Searching: IT companies in Sarangarh-Bilaigarh Chhattisgarh
# Search Submitted
# Sarangarh-Bilaigarh | IT companies | Scroll 1 -> 14
# Sarangarh-Bilaigarh | IT companies | Scroll 2 -> 20
# Sarangarh-Bilaigarh | IT companies | Scroll 3 -> 27
# Sarangarh-Bilaigarh | IT companies | Scroll 4 -> 34
# Sarangarh-Bilaigarh | IT companies | Scroll 5 -> 40
# Sarangarh-Bilaigarh | IT companies | Scroll 6 -> 47
# Sarangarh-Bilaigarh | IT companies | Scroll 7 -> 54
# Sarangarh-Bilaigarh | IT companies | Scroll 8 -> 60
# Sarangarh-Bilaigarh | IT companies | Scroll 9 -> 67
# Sarangarh-Bilaigarh | IT companies | Scroll 10 -> 74
# Sarangarh-Bilaigarh | IT companies | Scroll 11 -> 80
# Sarangarh-Bilaigarh | IT companies | Scroll 12 -> 87
# Sarangarh-Bilaigarh | IT companies | Scroll 13 -> 94
# Sarangarh-Bilaigarh | IT companies | Scroll 14 -> 99
# Sarangarh-Bilaigarh | IT companies | Scroll 15 -> 99
# Sarangarh-Bilaigarh | IT companies | Scroll 16 -> 99
# Sarangarh-Bilaigarh | IT companies | Scroll 17 -> 99
# Sarangarh-Bilaigarh | IT companies | Scroll 18 -> 99
# Collected 95 links
# Sarangarh-Bilaigarh | 1/95
# SARANGARH COMPUTERS
# Phone: 09630121666
# Sarangarh-Bilaigarh | 2/95
# My Computer Care
# Phone: 09691596496
# Sarangarh-Bilaigarh | 3/95
# shankar computer
# Phone:
# Sarangarh-Bilaigarh | 4/95
# Kamla nagar (barpali)
# Phone:
# Sarangarh-Bilaigarh | 5/95
# Jai Malhotra CSC Center
# Phone:
# Sarangarh-Bilaigarh | 6/95
# BSNL Office
# Phone: 18003451500
# Sarangarh-Bilaigarh | 7/95
# UrjaCon Infratech Pvt Ltd
# Phone:
# Sarangarh-Bilaigarh | 8/95
# RAJVEER INDUSTRIES
# Phone: 09937331887
# Sarangarh-Bilaigarh | 9/95
# Chaurasiya Electronics
# Phone: 09300959770
# Sarangarh-Bilaigarh | 10/95
# Maa durga fruit company
# Phone: 09993244240
# Sarangarh-Bilaigarh | 11/95
# Zee Electronics
# Phone: 09827881666
# Sarangarh-Bilaigarh | 12/95
# Jio Point
# Phone: 08770591339
# Sarangarh-Bilaigarh | 13/95
# Shazliya Construction & Consultants
# Phone:
# Sarangarh-Bilaigarh | 14/95
# Travophilic
# Phone: 09981949056
# Sarangarh-Bilaigarh | 15/95
# कुटेला सारंगढ़ छत्तीसगढ़
# Phone:
# Sarangarh-Bilaigarh | 16/95
# Aaryan Computer and lok seva Kendra sarangarh
# Phone: 06263237123
# Sarangarh-Bilaigarh | 17/95
# Upkar crane service
# Phone:
# Sarangarh-Bilaigarh | 18/95
# Xpress Printing
# Phone: 09752535500
# Sarangarh-Bilaigarh | 19/95
# Amit Radio Sarangarh
# Phone: 09098540808
# Sarangarh-Bilaigarh | 20/95
# REST HOUSE SARANGARH
# Phone:
# Sarangarh-Bilaigarh | 21/95
# Bhojpur, Ulkhar road Sarangarh
# Phone:
# Sarangarh-Bilaigarh | 22/95
# Maa Bhawani Printers &Flex
# Phone:
# Sarangarh-Bilaigarh | 23/95
# Suvan Electricals
# Phone: 08319172301
# Sarangarh-Bilaigarh | 24/95
# Mahindra Finance - Sarangarh Branch
# Phone: 08042782488
# Sarangarh-Bilaigarh | 25/95
#
# Phone:
# Sarangarh-Bilaigarh | 26/95
# Raja Electronic/Electricals
# Phone: 09425573545
# Sarangarh-Bilaigarh | 27/95
# Government hospital colony sarangarh
# Phone:
# Sarangarh-Bilaigarh | 28/95
# Shree ram traders sarangarh
# Phone: 09302068877
# Sarangarh-Bilaigarh | 29/95
# Shriram Finance Limited
# Phone: 18004107711
# Sarangarh-Bilaigarh | 30/95
# BSNL Store
# Phone: 07768233400
# Sarangarh-Bilaigarh | 31/95
# Chaurasiya Electronics
# Phone:
# Sarangarh-Bilaigarh | 32/95
# Pihu-Pooja Niwas
# Phone:
# Sarangarh-Bilaigarh | 33/95
# Karni traders sarangarh करणी ट्रेडर्स (पृथ्वी चूड़ी दुकान)
# Phone: 07000907941
# Sarangarh-Bilaigarh | 34/95
# YUVRAJ DUBEY ( LIC AGENT ) LIC OF.INDIA
# Phone: 09329666872
# Sarangarh-Bilaigarh | 35/95
# Anupam Jewellers
# Phone:
# Sarangarh-Bilaigarh | 36/95
# Bajaj Finance Branch
# Phone: 02241804799
# Sarangarh-Bilaigarh | 37/95
# KRISHAK SEWA KENDRA SARANGARH
# Phone:
# Sarangarh-Bilaigarh | 38/95
# Eicher Tractors Dealerships - Botalda Motors
# Phone: 08120451111
# Sarangarh-Bilaigarh | 39/95
# Laxman patel niwas
# Phone:
# Sarangarh-Bilaigarh | 40/95
# Ansh computer
# Phone:
# Sarangarh-Bilaigarh | 41/95
# नया बस्ती नौघटा
# Phone:
# Sarangarh-Bilaigarh | 42/95
# pixelium
# Phone:
# Sarangarh-Bilaigarh | 43/95
# Kailash Agrawal & Associates
# Phone: 09770634222
# Sarangarh-Bilaigarh | 44/95
# Mona Atta Chakki
# Phone:
# Sarangarh-Bilaigarh | 45/95
# Satya r.o sarangarh
# Phone: 08319019068
# Sarangarh-Bilaigarh | 46/95
# ISHWAR FRUIT COMPANY IFC & KISAN SABZI BHANDAR
# Phone: 07999999144
# Sarangarh-Bilaigarh | 47/95
# Kirodimal.nagar
# Phone:
# Backup Saved
# Sarangarh-Bilaigarh | 48/95
# Alka Jewellers(gaya sao dukan)
# Phone:
# Sarangarh-Bilaigarh | 49/95
# Saurabh Sharma Insurance Advisor
# Phone: 09399111988
# Sarangarh-Bilaigarh | 50/95
# Tiwari Online
# Phone: 09340485599
# Sarangarh-Bilaigarh | 51/95
# Shankar electranic
# Phone:
# Sarangarh-Bilaigarh | 52/95
# Ganesh traders sarangarh
# Phone:
# Sarangarh-Bilaigarh | 53/95
# चौरसिया गली सारंगढ
# Phone:
# Sarangarh-Bilaigarh | 54/95
# Saksham
# Phone:
# Sarangarh-Bilaigarh | 55/95
# Manas Sahu
# Phone:
# Sarangarh-Bilaigarh | 56/95
# Harikumar
# Phone:
# Sarangarh-Bilaigarh | 57/95
# अंगिरा सदन
# Phone:
# Sarangarh-Bilaigarh | 58/95
# SANGITA SALES
# Phone:
# Sarangarh-Bilaigarh | 59/95
# Akshyay devangan
# Phone:
# Sarangarh-Bilaigarh | 60/95
# Maa Samleshwari Rice Mill
# Phone: 09300610933
# Sarangarh-Bilaigarh | 61/95
# Mayank bhagau Jewellers ( bhagau sao)
# Phone:
# Sarangarh-Bilaigarh | 62/95
# Krish patel Amathi 512
# Phone:
# Sarangarh-Bilaigarh | 63/95
# Yash miri
# Phone:
# Sarangarh-Bilaigarh | 64/95
# Pooja Jewellers gaya sao dukan
# Phone: 08871053258
# Sarangarh-Bilaigarh | 65/95
# Murli Jewellers
# Phone: 08889966666
# Sarangarh-Bilaigarh | 66/95
# Manas sahu
# Phone:
# Sarangarh-Bilaigarh | 67/95
# Ram Kumar Thawait
# Phone:
# Sarangarh-Bilaigarh | 68/95
# Old Age Home
# Phone:
# Sarangarh-Bilaigarh | 69/95
# Kirti pipe and machinery
# Phone:
# Sarangarh-Bilaigarh | 70/95
# Chhattisgarh Agrovet Private Limited
# Phone:
# Sarangarh-Bilaigarh | 71/95
# KGN TYRE SHOP
# Phone: 08839786557
# Sarangarh-Bilaigarh | 72/95
# Thakur biryani centre
# Phone:
# Sarangarh-Bilaigarh | 73/95
# KGF
# Phone:
# Sarangarh-Bilaigarh | 74/95
# suneel yadav(yadav bhawan)
# Phone:
# Sarangarh-Bilaigarh | 75/95
# Alka jewellery
# Phone:
# Sarangarh-Bilaigarh | 76/95
# Sudama Auto Mobile
# Phone:
# Sarangarh-Bilaigarh | 77/95
# Shankar mobile sarangarh
# Phone:
# Sarangarh-Bilaigarh | 78/95
# Designdynamoindia Digital Marketing
# Phone:
# Sarangarh-Bilaigarh | 79/95
# Deepak agrwal
# Phone:
# Sarangarh-Bilaigarh | 80/95
# देव लॉन्ड्री प्रेस दुकान
# Phone:
# Sarangarh-Bilaigarh | 81/95
# Surat Saree Bazar Sarangarh
# Phone: 09799410011
# Sarangarh-Bilaigarh | 82/95
# Sarangarh
# Phone:
# Sarangarh-Bilaigarh | 83/95
# Saraswati Medical Store
# Phone:
# Sarangarh-Bilaigarh | 84/95
# Pratap Yadav Home
# Phone:
# Sarangarh-Bilaigarh | 85/95
# db mobile and computer
# Phone: 07877708494
# Sarangarh-Bilaigarh | 86/95
# Gaya sao ki dukan गया साव की असली दुकान
# Phone:
# Sarangarh-Bilaigarh | 87/95
# Torch Herd
# Phone: 09669412666
# Sarangarh-Bilaigarh | 88/95
# Kuldeep sidar
# Phone:
# Sarangarh-Bilaigarh | 89/95
# GauntiaIndian Gas Office
# Phone:
# Sarangarh-Bilaigarh | 90/95
# Mustakim Mobile And Photography
# Phone: 07898931782
# Sarangarh-Bilaigarh | 91/95
# Sarangarh
# Phone:
# Sarangarh-Bilaigarh | 92/95
# Suresh Kumar Izardar
# Phone: 08839384446
# Sarangarh-Bilaigarh | 93/95
# Telegram
# Phone:
# Sarangarh-Bilaigarh | 94/95
# अमन गृह निवास
# Phone:
# Sarangarh-Bilaigarh | 95/95
# Shubham Tiwari Home
# Phone:
#
# Searching: software companies in Sukma Chhattisgarh
# Search Submitted
# Scrolling Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@role="feed"]"}
#   (Session info: chrome=148.0.7778.168); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 	chromedriver!GetHandleVerifier [0xa7b593+105d3]
# 	chromedriver!GetHandleVerifier [0xa7b6c4+10704]
# 	chromedriver!(No symbol) [0x881ea0]
# 	chromedriver!(No symbol) [0x8cb28a]
# 	chromedriver!(No symbol) [0x8cb52b]
# 	chromedriver!(No symbol) [0x90d052]
# 	chromedriver!(No symbol) [0x8ed7c4]
# 	chromedriver!(No symbol) [0x90a936]
# 	chromedriver!(No symbol) [0x8ed516]
# 	chromedriver!(No symbol) [0x8c08e9]
# 	chromedriver!(No symbol) [0x8c16a4]
# 	chromedriver!GetHandleVerifier [0xd03014+298054]
# 	chromedriver!GetHandleVerifier [0xcfe603+293643]
# 	chromedriver!GetHandleVerifier [0xd1ea05+2b3a45]
# 	chromedriver!GetHandleVerifier [0xa954e8+2a528]
# 	chromedriver!GetHandleVerifier [0xa9cd1d+31d5d]
# 	chromedriver!GetHandleVerifier [0xa83e68+18ea8]
# 	chromedriver!GetHandleVerifier [0xa84015+19055]
# 	chromedriver!GetHandleVerifier [0xa6d65f+269f]
# 	KERNEL32!BaseThreadInitThunk [0x75c9fcc9+19]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x77a082ae+11e]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x77a0827e+ee]
#
# Collected 0 links
#
# Searching: IT companies in Sukma Chhattisgarh
# Search Submitted
# Sukma | IT companies | Scroll 1 -> 14
# Sukma | IT companies | Scroll 2 -> 20
# Sukma | IT companies | Scroll 3 -> 27
# Sukma | IT companies | Scroll 4 -> 34
# Sukma | IT companies | Scroll 5 -> 40
# Sukma | IT companies | Scroll 6 -> 47
# Sukma | IT companies | Scroll 7 -> 54
# Sukma | IT companies | Scroll 8 -> 60
# Sukma | IT companies | Scroll 9 -> 67
# Sukma | IT companies | Scroll 10 -> 74
# Sukma | IT companies | Scroll 11 -> 80
# Sukma | IT companies | Scroll 12 -> 87
# Sukma | IT companies | Scroll 13 -> 94
# Sukma | IT companies | Scroll 14 -> 100
# Sukma | IT companies | Scroll 15 -> 104
# Sukma | IT companies | Scroll 16 -> 104
# Sukma | IT companies | Scroll 17 -> 104
# Sukma | IT companies | Scroll 18 -> 104
# Sukma | IT companies | Scroll 19 -> 104
# Collected 103 links
# Sukma | 1/103
# Taj Computers & Photo Copiers
# Phone: 09424290867
# Sukma | 2/103
# Cholamandalam Investment and Finance Company Limited
# Phone: 08044464937
# Sukma | 3/103
# Royal Gas Agency
# Phone: 08521078653
# Sukma | 4/103
# Surajpur | software companies | Scroll 2 -> 13
# Surajpur | software companies | Scroll 3 -> 13
# Surajpur | software companies | Scroll 4 -> 13
# Surajpur | software companies | Scroll 5 -> 13
# Collected 7 links
# Surajpur | 1/7
# Raj Computer's
# Phone: 09753734919
# Surajpur | 2/7
# Nahata Computers (नाहटा कम्प्यूटर्स)
# Phone: 09406166555
# Surajpur | 3/7
# Shri Ram Computers
# Phone: 09617445500
# Surajpur | 4/7
# Indian Book Depot
# Phone: 09826162907
# Surajpur | 5/7
# Sirmor Software Solution
# Phone: 09691255251
# Surajpur | 6/7
# Star Health & Allied Insurance - Surajpur, Chhattisgarh
# Phone: 18004252255
# Surajpur | 7/7
# Laxmi computers Surajpur
# Phone: 08871372550
#
# Searching: IT companies in Surajpur Chhattisgarh
# Search Submitted
# Surajpur | IT companies | Scroll 1 -> 14
# Surajpur | IT companies | Scroll 2 -> 20
# Surajpur | IT companies | Scroll 3 -> 27
# Surajpur | IT companies | Scroll 4 -> 30
# Surajpur | IT companies | Scroll 5 -> 30
# Surajpur | IT companies | Scroll 6 -> 30
# Surajpur | IT companies | Scroll 7 -> 30
# Surajpur | IT companies | Scroll 8 -> 30
# Collected 25 links
# Surajpur | 1/25
# Aditya Agencies
# Phone: 09713160160
# Surajpur | 2/25
# TOO GOOD COMPUTER SHOP SALE & SERVICE
# Phone: 08269896204
# Surajpur | 3/25
# Alpha Computers
# Phone:
# Surajpur | 4/25
# Ramesh Computers & IT World
# Phone: 09617567675
# Surajpur | 5/25
# Mahindra Tractors - Shastri Agro Industries
# Phone: 08071639126
# Surajpur | 6/25
# Aishwaryam Residency
# Phone: 09039553888
# Surajpur | 7/25
# Ashok Radio Center
# Phone:
# Surajpur | 8/25
# GOLU FOOTWEAR SURAJPUR
# Phone: 09009000241
# Surajpur | 9/25
# OP CHOICE CENTER
# Phone:
# Surajpur | 10/25
# PRA Apartment
# Phone:
# Surajpur | 11/25
# Hira Lal Sadhu Ram Seva Kunj
# Phone:
# Surajpur | 12/25
# Nehru Park
# Phone:
# Surajpur | 13/25
# TRENDS
# Phone: 09889630779
# Surajpur | 14/25
# Physics Wallah Coaching Center Helpline Surajpur | IIT JEE, NEET Classes
# Phone: 07428890305
# Surajpur | 15/25
# Post Office Surajpur
# Phone:
# Surajpur | 16/25
# Anand Rihandam
# Phone:
# Surajpur | 17/25
# Yadav Online Store
# Phone: 07582816666
# Surajpur | 18/25
# Mahamaya Fashion
# Phone: 08770561744
# Surajpur | 19/25
# Muthoot Finance Gold Loan
# Phone: 18001202838
# Surajpur | 20/25
# eXpert iT Services : Website, Software, Android Apps, iOS, Web Application Development
# Phone: 07722944377
# Surajpur | 21/25
# Raj Cake Studio Surajpur
# Phone: 09039401006
# Surajpur | 22/25
# Kenapara Boating and Fishing Point
# Phone:
# Surajpur | 23/25
# Jama Masjid Bishrampur
# Phone: 09302897702
# Surajpur | 24/25
# Jain Hardware
# Phone: 07089663053
# Surajpur | 25/25
# MOHAMMAD IRFAN AHAMAD
# Phone:
#
# Searching: software companies in Surguja Chhattisgarh
# Search Submitted
# Surguja | software companies | Scroll 1 -> 14
# Surguja | software companies | Scroll 2 -> 20
# Surguja | software companies | Scroll 3 -> 25
# Surguja | software companies | Scroll 4 -> 25
# Surguja | software companies | Scroll 5 -> 25
# Surguja | software companies | Scroll 6 -> 25
# Surguja | software companies | Scroll 7 -> 25
# Collected 24 links
# Surguja | 1/24
# Ancoax Technologies
# Phone: 09329120222
# Surguja | 2/24
# SOFTWARE SOLUTION
# Phone:
# Surguja | 3/24
# BillingSutra – GST Billing & ERP Software
# Phone:
# Surguja | 4/24
# Pocket IT Solutions
# Phone: 09844125644
# Surguja | 5/24
# anekiya technologies
# Phone: 09926948035
# Surguja | 6/24
# NOVENTRA GLOBAL TECHNOLOGIES PRIVATE LIMITED
# Phone:
# Surguja | 7/24
# Genesis solutions
# Phone: 09311194555
# Surguja | 8/24
# Delema Software & IoT Solution
# Phone:
# Surguja | 9/24
# WebApster
# Phone: 07747865886
# Surguja | 10/24
# Mandal Computer & Electronics
# Phone: 09669120073
# Surguja | 11/24
# Computer solution
# Phone: 07000515159
# Surguja | 12/24
# Digi Tool Mart
# Phone:
# Surguja | 13/24
#
# Phone:
# Surguja | 14/24
#
# Phone:
# Surguja | 15/24
# Akshay IT Services
# Phone: 07000616442
# Surguja | 16/24
# HaveIT Creations
# Phone: 08427224636
# Surguja | 17/24
# Titan World - Banaras Chowk, Ambikapur
# Phone: 08062914077
# Backup Saved
# Surguja | 18/24
# Grippy B2IT solutions
# Phone: 09981552219
# Surguja | 19/24
# NETAJI COMPANY
# Phone: 09926172000
# Surguja | 20/24
# AVTAR INFOTECH
# Phone:
# Surguja | 21/24
# Lapcare
# Phone: 09826238757
# Surguja | 22/24
# Billing software
# Phone:
# Surguja | 23/24
# Marg ERP ambikapur
# Phone:
# Surguja | 24/24
# coded world
# Phone:
#
# Searching: IT companies in Surguja Chhattisgarh
# Search Submitted
# Surguja | IT companies | Scroll 1 -> 14
# Surguja | IT companies | Scroll 2 -> 20
# Surguja | IT companies | Scroll 3 -> 27
# Surguja | IT companies | Scroll 4 -> 34
# Surguja | IT companies | Scroll 5 -> 40
# Surguja | IT companies | Scroll 6 -> 47
# Surguja | IT companies | Scroll 7 -> 54
# Surguja | IT companies | Scroll 8 -> 56
# Surguja | IT companies | Scroll 9 -> 56
# Surguja | IT companies | Scroll 10 -> 56
# Surguja | IT companies | Scroll 11 -> 56
# Surguja | IT companies | Scroll 12 -> 56
# Collected 47 links
# Surguja | 1/47
# Reliance Digital
# Phone: 08071890075
# Surguja | 2/47
# Company Bazar
# Phone:
# Surguja | 3/47
# Trust Computer Services- Best COMPUTER SUPPLIER / Best D-LINK Network Router Dealer in Ambikapur/ Wireless USB Adapter/ Print Server/ Network Router/ Network Modem/ Network Switch/ LAPTOP REPAIRING /PRINTER REPAIRING
# Phone: 09826238757
# Surguja | 4/47
# SONY COMPUTER
# Phone: 09826135957
# Surguja | 5/47
# New Version Choice Center
# Phone: 09685859444
# Surguja | 6/47
# Gurukripa Advertisers- Best Flax print in Ambikapur
# Phone: 09977004101
