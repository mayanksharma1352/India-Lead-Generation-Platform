# %%
import pandas as pd

# %%
df = pd.read_csv("chhattisgarh_companies.csv")

# %%
df.shape
# Out:
# (754, 8)

# %%
df = df[
    df["Phone"].notna() & 
    (df["Phone"].astype(str).str.strip() != "")
    ]
df.shape
# Out:
# (471, 8)

# %%
df = df[
    df["Company Name"].notna()
    ]

df = df[
    df["Company Name"].str.strip() != ""
    ]
df.shape
# Out:
# (471, 8)

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]","",regex=True)
    .str.strip()
)

display(df[["Phone"]].head())
# Out:
#          Phone
# 0  93997935920
# 2  97136651180
# 3  70007908380
# 6  97705662220
# 7  76772502500

# %%
df.to_csv(
    "chhattisgarh_companies_cleaned.csv",
    index=False
)
