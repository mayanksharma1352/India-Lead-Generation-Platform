# %%
import pandas as pd

# %%
df = pd.read_csv("tripura_companies.csv")

# %%
df.shape
# Out:
# (823, 8)

# %%
df = df[
    df["Phone"].notna() & 
    (df["Phone"].astype(str).str.strip() != "")
    ]
df.shape
# Out:
# (556, 8)

# %%
df = df[
    df["Company Name"].notna()
    ]

df = df[
    df["Company Name"].str.strip() != ""
    ]
df.shape
# Out:
# (549, 8)

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]","",regex=True)
    .str.strip()
)

display(df[["Phone"]].head())
# Out:
#          Phone
# 0  97745158470
# 1  98633230960
# 2  98626625320
# 3  94850690710
# 4  97749040280

# %%
df.to_csv(
    "tripura_companies_cleaned.csv",
    index=False
)
