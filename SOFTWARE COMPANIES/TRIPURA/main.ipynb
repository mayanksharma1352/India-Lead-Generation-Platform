# %%
import time
import random
import pandas as pd

from datetime import datetime

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.service import Service

from webdriver_manager.chrome import ChromeDriverManager


districts = [
    "Dhalai",
    "Gomati",
    "Khowai",
    "North Tripura",
    "Sepahijala",
    "South Tripura",
    "Unakoti",
    "West Tripura"
]



search_types = [
    "software companies",
    "IT companies"
]


options = webdriver.ChromeOptions()

options.add_argument("--start-maximized")

options.add_argument(
    "--disable-blink-features=AutomationControlled"
)

options.add_argument("--disable-notifications")



driver = webdriver.Chrome(

    service=Service(
        ChromeDriverManager().install()
    ),

    options=options
)



driver.get("https://www.google.com/maps")

print("Opening Google Maps...")

time.sleep(15)

print("Google Maps Loaded")


all_data = []

visited_links = set()



def get_search_box():

    selectors = [

        '//input[@id="searchboxinput"]',
        '//input[contains(@placeholder,"Search")]',
        '//input[contains(@aria-label,"Search")]',
        '//input'

    ]

    for selector in selectors:

        try:

            box = driver.find_element(
                By.XPATH,
                selector
            )

            return box

        except:
            pass

    return None



def extract_school_data():

    try:

        try:

            name = driver.find_element(
                By.TAG_NAME,
                "h1"
            ).text

        except:

            name = ""


        try:

            address = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"address")]'
            ).text

        except:

            address = ""


        phone = ""

        try:

            phone_xpaths = [


                '//button[contains(@data-item-id,"phone")]',


                '//a[contains(@href,"tel:")]',


                '//button[contains(@aria-label,"Phone")]',

                '//button[contains(text(),"+91")]',
                '//div[contains(text(),"+91")]',
                '//span[contains(text(),"+91")]'

            ]

            for xpath in phone_xpaths:

                try:

                    elements = driver.find_elements(
                        By.XPATH,
                        xpath
                    )

                    for element in elements:

                        text = element.text.strip()

                        href = (
                            element.get_attribute("href")
                            or ""
                        )

                        # TEL LINK
                        if "tel:" in href:

                            phone = href.replace(
                                "tel:",
                                ""
                            ).strip()

   
                        elif text:

                            phone = text


                        phone = (

                            phone.replace("", "")
                            .replace(" ", "")
                            .replace("-", "")
                            .replace("(", "")
                            .replace(")", "")
                            .replace("\n", "")
                            .strip()

                        )

                        digits = ''.join(
                            filter(str.isdigit, phone)
                        )

                        if len(digits) >= 10:

                            break

                    if phone:
                        break

                except:
                    pass

        except Exception as e:

            print(f"Phone Error: {e}")


        try:

            website = driver.find_element(
                By.XPATH,
                '//a[contains(@data-item-id,"authority")]'
            ).get_attribute("href")

        except:

            website = ""


        try:

            rating = driver.find_element(
                By.XPATH,
                '//div[@role="img"]'
            ).get_attribute("aria-label")

        except:

            rating = ""

        return {

            "Company Name": name,
            "Address": address,
            "Phone": phone,
            "Website": website,
            "Rating": rating,
            "Google Maps URL": driver.current_url

        }

    except:

        return None



for district in districts:

    for search_type in search_types:

        try:

            query = (
                f"{search_type} "
                f"in {district} Tripura"
            )

            print(f"\nSearching: {query}")

        
            search_box = get_search_box()

            if not search_box:

                print("Search Box Not Found")

                continue

            ActionChains(driver).move_to_element(
                search_box
            ).click().perform()

            time.sleep(1)

            search_box.send_keys(
                Keys.CONTROL + "a"
            )

            time.sleep(1)

            search_box.send_keys(Keys.DELETE)

            time.sleep(1)



            for char in query:

                search_box.send_keys(char)

                time.sleep(0.03)

            search_box.send_keys(Keys.ENTER)

            print("Search Submitted")

            time.sleep(8)



            try:

                scrollable_div = driver.find_element(
                    By.XPATH,
                    '//div[@role="feed"]'
                )

                previous_count = 0

                stagnant = 0

                for i in range(100):

                    driver.execute_script(
                        """
                        arguments[0].scrollTop =
                        arguments[0].scrollHeight
                        """,
                        scrollable_div
                    )

                    time.sleep(4)

                    listings = driver.find_elements(
                        By.XPATH,
                        '//a[contains(@href,"/maps/place/")]'
                    )

                    current_count = len(listings)

                    print(
                        f"{district} | "
                        f"{search_type} | "
                        f"Scroll {i+1} -> "
                        f"{current_count}"
                    )

                    if current_count == previous_count:

                        stagnant += 1

                    else:

                        stagnant = 0

                    if stagnant >= 4:

                        break

                    previous_count = current_count

            except Exception as e:

                print(f"Scrolling Error: {e}")

            # GET LINKS

            listings = driver.find_elements(
                By.XPATH,
                '//a[contains(@href,"/maps/place/")]'
            )

            links = []

            for listing in listings:

                try:

                    link = listing.get_attribute("href")

                    if (
                        link
                        and link not in visited_links
                    ):

                        links.append(link)

                        visited_links.add(link)

                except:
                    pass

            print(f"Collected {len(links)} links")



            for index, link in enumerate(links):

                try:

                    print(
                        f"{district} | "
                        f"{index+1}/{len(links)}"
                    )

                    driver.get(link)

                    time.sleep(
                        random.uniform(2, 3)
                    )

                    data = extract_school_data()

                    if data:

                        data["District"] = district

                        data["Search Type"] = search_type

                        all_data.append(data)

                        print(data["Company Name"])

                        print(
                            f"Phone: {data['Phone']}"
                        )


                    if len(all_data) % 100 == 0:

                        backup_df = pd.DataFrame(
                            all_data
                        )

                        backup_df.drop_duplicates(
                            subset=[
                                "Company Name",
                                "Google Maps URL"
                            ],
                            inplace=True
                        )

                        backup_df.to_csv(
                            "tripura_companies_backup.csv",
                            index=False
                        )

                        print("Backup Saved")

                except Exception as e:

                    print(
                        f"Company Error: {e}"
                    )

        except Exception as e:

            print(
                f"District Error: {e}"
            )



df = pd.DataFrame(all_data)

df.drop_duplicates(

    subset=[
        "Company Name",
        "Google Maps URL"
    ],

    inplace=True
)

filename = "tripura_companies.csv"

df.to_csv(
    filename,
    index=False
)

print("\nExtraction Completed")

print(
    f"Total Companies Extracted: {len(df)}"
)

print(f"\nSaved File: {filename}")

driver.quit()
# Out:
# Opening Google Maps...
# Google Maps Loaded
#
# Searching: software companies in Dhalai Tripura
# Search Submitted
# Dhalai | software companies | Scroll 1 -> 14
# Dhalai | software companies | Scroll 2 -> 20
# Dhalai | software companies | Scroll 3 -> 27
# Dhalai | software companies | Scroll 4 -> 34
# Dhalai | software companies | Scroll 5 -> 40
# Dhalai | software companies | Scroll 6 -> 47
# Dhalai | software companies | Scroll 7 -> 48
# Dhalai | software companies | Scroll 8 -> 48
# Dhalai | software companies | Scroll 9 -> 48
# Dhalai | software companies | Scroll 10 -> 48
# Dhalai | software companies | Scroll 11 -> 48
# Collected 48 links
# Dhalai | 1/48
# Ignite Software Technology
# Phone: 09774515847
# Dhalai | 2/48
# SN Corporates
# Dhalai | 46/48
# Sini It SOLUTION & XEROX & PHOTO
# Phone: 08787655886
# Dhalai | 47/48
# Abhi Debnath
# Phone: 09612373595
# Dhalai | 48/48
# Saptarsi Debbarma
# Phone: 09612253063
#
# Searching: IT companies in Dhalai Tripura
# Search Submitted
# Dhalai | IT companies | Scroll 1 -> 14
# Dhalai | IT companies | Scroll 2 -> 20
# Dhalai | IT companies | Scroll 3 -> 27
# Dhalai | IT companies | Scroll 4 -> 34
# Dhalai | IT companies | Scroll 5 -> 40
# Dhalai | IT companies | Scroll 6 -> 47
# Dhalai | IT companies | Scroll 7 -> 54
# Dhalai | IT companies | Scroll 8 -> 60
# Dhalai | IT companies | Scroll 9 -> 63
# Dhalai | IT companies | Scroll 10 -> 63
# Dhalai | IT companies | Scroll 11 -> 63
# Dhalai | IT companies | Scroll 12 -> 63
# Dhalai | IT companies | Scroll 13 -> 63
# Collected 41 links
# Dhalai | 1/41
# Emon VA Solutions
# Phone: +8801759207681
# Dhalai | 2/41
# Joyguru Computer
# Phone: 09863631979
# Dhalai | 3/41
# Rainbow Electronics
# Phone: 08974747695
# Dhalai | 4/41
# Blue Dart Express Limited
# Phone:
# Dhalai | 5/41
# Bablu Net Zone & Dreamline Travels
# Phone: 08787769379
# Dhalai | 6/41
# SHIBANI DEB CABLE MANU GHAT
# Phone:
# Dhalai | 7/41
# AP DIGITAL ZONE
# Phone: 08787588964
# Dhalai | 8/41
# Swarna Kutir
# Phone:
# Dhalai | 9/41
# M/S Joy Shiv Sankar Varieties & Cabinet
# Phone: 09612265647
# Dhalai | 10/41
# I.T.I Ambassa
# Phone:
# Dhalai | 11/41
# Pabitra Das House
# Phone: 08974110181
# Dhalai | 12/41
# ITI,KAMALPUR
# Phone:
# Dhalai | 13/41
# Shiv Shakti Computer & Verities
# Phone:
# Dhalai | 14/41
# Sobuj Prantar Plant Nursery
# Phone: 09436990026
# Dhalai | 15/41
# Go North East Travel Agency | Tour Advisors
# Phone:
# Dhalai | 16/41
# Ujjal Studio
# Phone: 09366154870
# Dhalai | 17/41
# Advocate Debasis Debnath
# Phone: 08014255843
# Dhalai | 18/41
# Upgrite Computer Academy (Khowai Branch)
# Phone: 09436317131
# Dhalai | 19/41
# AG DIGITAL SERVICE
# Phone: 09863144538
# Dhalai | 20/41
# Hansel xerox shop
# Phone: 08415914663
# Dhalai | 21/41
# DAS COMPUTER
# Phone: 08415001652
# Dhalai | 22/41
# Agni Systems Sreemangal
# Phone: +8801328778190
# Dhalai | 23/41
# WebZenta
# Phone: +8801715898294
# Dhalai | 24/41
# Tirthankar Das
# Phone: 08014376311
# Dhalai | 25/41
# Chakraborty Siber Cap
# Phone: 07640981377
# Dhalai | 26/41
# Pramila Guest House & Palace
# Phone: 07005918584
# Dhalai | 27/41
# J.D Varieties
# Phone:
# Dhalai | 28/41
# District Composite Live Stock Farm
# Phone:
# Dhalai | 29/41
# W3 Relations
# Phone: +8801581110103
# Dhalai | 30/41
# Way to Natun Bazar/ Ratan Mani Ashram.
# Phone:
# Dhalai | 31/41
# Nageswar Chakma
# Phone: 09366576931
# Dhalai | 32/41
# Maa Mani Electronics
# Phone: 09402342249
# Dhalai | 33/41
# R D It Group
# Phone: +8801739215884
# Dhalai | 34/41
# The Computer Point Khowai
# Phone: 09436129960
# Dhalai | 35/41
# Ruong Mog
# Phone: 09366304738
# Dhalai | 36/41
# CSC Baralutma
# Phone: 07908857108
# Dhalai | 37/41
# Corporate Care Solution
# Phone: 08414999909
# Dhalai | 38/41
# SUVRA DAS
# Phone: 08837275850
# Dhalai | 39/41
# ST. JOHN'S HOSTEL, DHUMACHERRA
# Phone:
# Dhalai | 40/41
# Antar Varities
# Phone: 09863876010
# Dhalai | 41/41
# Kalpana Shop
# Phone: 06909262588
#
# Searching: software companies in Gomati Tripura
# Search Submitted
# Gomati | software companies | Scroll 1 -> 14
# Gomati | software companies | Scroll 2 -> 20
# Gomati | software companies | Scroll 3 -> 27
# Gomati | software companies | Scroll 4 -> 34
# Gomati | software companies | Scroll 5 -> 40
# Gomati | software companies | Scroll 6 -> 47
# Gomati | software companies | Scroll 7 -> 54
# Gomati | software companies | Scroll 8 -> 60
# Gomati | software companies | Scroll 9 -> 67
# Gomati | software companies | Scroll 10 -> 74
# Gomati | software companies | Scroll 11 -> 75
# Gomati | software companies | Scroll 12 -> 75
# Gomati | software companies | Scroll 13 -> 75
# Gomati | software companies | Scroll 14 -> 75
# Gomati | software companies | Scroll 15 -> 75
# Collected 71 links
# Gomati | 1/71
# Arknox Technology
# Phone: 09366662076
# Gomati | 2/71
# Hembro Infotech Private Limited
# Phone: 08794831399
# Gomati | 3/71
# Meta Mint Private Limited
# Phone: 09366744376
# Gomati | 4/71
# MAA LAXMI COMPUTER
# Phone: 07005650569
# Gomati | 5/71
# Insider Global Services
# Phone:
# Gomati | 6/71
# Estamp Paper
# Phone:
# Gomati | 7/71
# Local Growth IT Services
# Phone:
# Gomati | 8/71
# Shri Hridoy Computer & Varieties
# Phone: 08415965937
# Gomati | 9/71
# THE COMPUTER CORNER
# Phone: 08257030520
# Gomati | 10/71
# NexGen IT Tech Solution
# Phone:
# Gomati | 11/71
# APLL
# Phone:
# Backup Saved
# Gomati | 12/71
# JOB NOTIFICATION
# Phone:
# Gomati | 13/71
# COMPUTER INFOTECH
# Phone: 08787807817
# Gomati | 14/71
# CCTV AND NETWORKING ALL OVER TRIPURA
# Phone:
# Gomati | 15/71
# Computer Care Expert
# Phone:
# Gomati | 16/71
# RM Computer And Vocational Training Academy
# Phone: 09402358259
# Gomati | 17/71
# PERFECT SOLUTION
# Phone: 09863144014
# Gomati | 18/71
# Lapcare
# Phone: 09774133707
# Gomati | 19/71
# ONGC Tripura Power Company Limited
# Phone: 06909519554
# Gomati | 20/71
# Vrodia
# Phone:
# Gomati | 21/71
# Computer Graphics
# Phone: 09856419509
# Gomati | 22/71
# ARATI TRAVELS & VARIETIES
# Phone: 09436189651
# Gomati | 23/71
# Ompi R.D. Block
# Phone:
# Gomati | 24/71
# EDITORGRAPHY & PHOTOGRAPHY
# Phone:
# Gomati | 25/71
# QIDREVO
# Phone:
# Gomati | 26/71
# Maa Computer & CSC Centre
# Phone: 08787548943
# Gomati | 27/71
# Amarpur Gomati Tripura
# Phone:
# Gomati | 28/71
# Tripura state Rifles 7 battalion company headquarter
# Phone:
# Gomati | 29/71
# Bagma Agri Producer Company Limited
# Phone: 09862020763
# Gomati | 30/71
# SK Technologies
# Phone: 08787602116
# Gomati | 31/71
# Digital sanjoy store
# Phone: 08415881573
# Gomati | 32/71
# Electric Business
# Phone: 09485017015
# Gomati | 33/71
# সাহা বুক বাইন্ডিং
# Phone:
# Gomati | 34/71
# Gomati Yatri Niwas
# Phone:
# Gomati | 35/71
# South murapara
# Phone:
# Gomati | 36/71
# MOBILE CITY
# Phone: 06909297195
# Gomati | 37/71
# Titan Eye+ at Central Road, Udaipur (Buy 1 Get 1 Free)
# Phone: 06909371018
# Gomati | 38/71
# Sal Xerox
# Phone: 08974761309
# Gomati | 39/71
# PALASH COMPUTER
# Phone: 06033399241
# Gomati | 40/71
# Das Varieties
# Phone: 09366494595
# Gomati | 41/71
# Need Recharge
# Phone: 09863798638
# Gomati | 42/71
# Blue Dart Express Limited
# Phone:
# Gomati | 43/71
# Prabhati Bhattacharjee - Health & Term Insurance Advisor
# Phone: 07005343997
# Gomati | 44/71
# Sukanta Dey
# Phone:
# Gomati | 45/71
# Dhuptali Bazar ( Dhuptali Hati)
# Phone:
# Gomati | 46/71
# All Recharge Sale- Web Development Company
# Phone:
# Gomati | 47/71
# Chameli Tripura
# Phone:
# Gomati | 48/71
# Xerox & Computer Centre
# Phone: 09436491094
# Gomati | 49/71
# Biva Mineral Water
# Phone:
# Gomati | 50/71
# Milestones Institute of Pharmaceutical Sciences
# Phone: 09480018001
# Gomati | 51/71
# Hi -Tech Media
# Phone: 09862988961
# Gomati | 52/71
# Tumbledry Dry Clean & Laundry Service
# Phone: 07677250250
# Gomati | 53/71
# Loknath Xerox And Computer
# Phone: 08794679001
# Gomati | 54/71
# Tripurasundari Shaktipeeth (Matabari Temple)
# Phone: 09863126399
# Gomati | 55/71
# Airtel Store
# Phone: 09362250065
# Gomati | 56/71
# THEME MERCHANT
# Phone: 07630033415
# Gomati | 57/71
# Directorate Of Information Technology
# Phone: 03812355751
# Gomati | 58/71
# Ripan Computer
# Phone: 07628858475
# Gomati | 59/71
# A to Z COMPUTER SERVICES
# Phone:
# Gomati | 60/71
# Debnath Computer Technology
# Phone: 09233897353
# Gomati | 61/71
# Ultra Bot (BHARAT)
# Phone:
# Gomati | 62/71
# Softskill Solution
# Phone: 03821222174
# Gomati | 63/71
# Software Center
# Phone:
# Gomati | 64/71
# Barnik Enterprise
# Phone: 07005822908
# Gomati | 65/71
# SUNNY DEY
# Phone:
# Gomati | 66/71
# Royal Computer
# Phone: 09612695999
# Gomati | 67/71
# Jonayat molla
# Phone:
# Gomati | 68/71
# AKTER TRAVELS & CSC
# Phone: 08837288565
# Gomati | 69/71
# LOKNATH DIGITAL PARISEVA
# Phone: 09862448404
# Gomati | 70/71
# Austin Computer
# Phone: 07630079544
# Gomati | 71/71
# CSC Center
# Phone: 09863183669
#
# Searching: IT companies in Gomati Tripura
# Search Submitted
# Gomati | IT companies | Scroll 1 -> 14
# Gomati | IT companies | Scroll 2 -> 20
# Gomati | IT companies | Scroll 3 -> 27
# Gomati | IT companies | Scroll 4 -> 34
# Gomati | IT companies | Scroll 5 -> 40
# Gomati | IT companies | Scroll 6 -> 47
# Gomati | IT companies | Scroll 7 -> 54
# Gomati | IT companies | Scroll 8 -> 60
# Gomati | IT companies | Scroll 9 -> 67
# Gomati | IT companies | Scroll 10 -> 74
# Gomati | IT companies | Scroll 11 -> 75
# Gomati | IT companies | Scroll 12 -> 75
# Gomati | IT companies | Scroll 13 -> 75
# Gomati | IT companies | Scroll 14 -> 75
# Gomati | IT companies | Scroll 15 -> 75
# Collected 25 links
# Gomati | 1/25
# DM office,Gomati Tripura
# Phone:
# Gomati | 2/25
# TRIPURA MEGA FOOD PARK
# Phone:
# Gomati | 3/25
# Vestige Marketing Private Limited
# Phone:
# Gomati | 4/25
# Twimuk
# Phone:
# Gomati | 5/25
# Gomati District Vehicle Office
# Phone:
# Gomati | 6/25
# SPORTS HUT
# Phone: 07005015537
# Gomati | 7/25
# Jamatia Travels and Transport
# Phone: 08837220273
# Gomati | 8/25
# Parimal Sarkar
# Phone: 07005568812
# Gomati | 9/25
# BINOD DEAF HOME
# Phone:
# Gomati | 10/25
# Swarnakamal Jewellers, Udaipur স্বর্ণকমল জুয়েলার্স -উদয়পুর
# Phone: 08794277509
# Gomati | 11/25
# HATHAI KITING KAMI
# Phone: 07005935676
# Gomati | 12/25
# Beltali udai sangho,Uttar Chandrapur-Matabari Road
# Phone: 09862310985
# Gomati | 13/25
# Maharani Hydro Power Plant
# Phone:
# Gomati | 14/25
# EasyPay
# Phone: 06009894841
# Gomati | 15/25
# Peter's aquaculture
# Phone:
# Gomati | 16/25
# Bajaj Life Insurance
# Phone: 02067121212
# Gomati | 17/25
# Bajaj Auto Credit | Sengupta Motors Udaipur | Two Wheeler Loan
# Phone: 08806008806
# Gomati | 18/25
# Radha Krishna Jewellery - Udaipur, Tripura
# Phone: 07005044301
# Gomati | 19/25
# HMM AVENUE
# Phone:
# Gomati | 20/25
# Udaipur Railway Colony,
# Phone:
# Gomati | 21/25
# Komla bagan
# Phone:
# Gomati | 22/25
# Maa Purnima Computer
# Phone: 08974662563
# Gomati | 23/25
# Sakulum Jamatia
# Phone: 06009037994
# Gomati | 24/25
# Sourav Chandra Das
# Phone: 08798604861
# Gomati | 25/25
# BC COMPUTER
# Phone: 08014566745
#
# Searching: software companies in Khowai Tripura
# Search Submitted
# Khowai | software companies | Scroll 1 -> 14
# Khowai | software companies | Scroll 2 -> 20
# Khowai | software companies | Scroll 3 -> 26
# Khowai | software companies | Scroll 4 -> 26
# Khowai | software companies | Scroll 5 -> 26
# Khowai | software companies | Scroll 6 -> 26
# Khowai | software companies | Scroll 7 -> 26
# Collected 20 links
# Khowai | 1/20
# ANJALI COMPUTER & CSC CENTER
# Phone: 07005176268
# Khowai | 2/20
# Computer Hub
# Phone:
# Khowai | 3/20
# Wing
# Phone: 08974257871
# Khowai | 4/20
# Good Luck Copy Corner & CSC Center
# Phone: 09436340141
# Khowai | 5/20
# COPY MART
# Phone: 09436513898
# Khowai | 6/20
# Airtel Store
# Phone: 08974014986
# Khowai | 7/20
#
# Phone:
# Khowai | 8/20
# Google Maps can't reach the internet
# Phone:
# Khowai | 9/20
# Google Maps can't reach the internet
# Phone:
# Khowai | 10/20
# Google Maps can't reach the internet
# Phone:
# Khowai | 11/20
# Google Maps can't reach the internet
# Phone:
# Khowai | 12/20
# Google Maps can't reach the internet
# Phone:
# Khowai | 13/20
# Google Maps can't reach the internet
# Phone:
# Khowai | 14/20
# Google Maps can't reach the internet
# Phone:
# Khowai | 15/20
# Google Maps can't reach the internet
# Phone:
# Backup Saved
# Khowai | 16/20
# Google Maps can't reach the internet
# Phone:
# Khowai | 17/20
# Google Maps can't reach the internet
# Phone:
# Khowai | 18/20
# Sumi'z Beauty Heaven
# Phone: 07085745038
# Khowai | 19/20
#
# Phone:
# Khowai | 20/20
# Om Computer
# Phone: 09863098218
#
# Searching: IT companies in Khowai Tripura
# Search Submitted
# Khowai | IT companies | Scroll 1 -> 14
# Khowai | IT companies | Scroll 2 -> 20
# Khowai | IT companies | Scroll 3 -> 27
# Khowai | IT companies | Scroll 4 -> 31
# Khowai | IT companies | Scroll 5 -> 31
# Khowai | IT companies | Scroll 6 -> 31
# Khowai | IT companies | Scroll 7 -> 31
# Khowai | IT companies | Scroll 8 -> 31
# Collected 5 links
# Khowai | 1/5
# Hirak Guest House
# Phone:
# Khowai | 2/5
# TRENDS
# Phone: 09774715762
# Khowai | 3/5
# M Baazar Khowai
# Phone: 07604006630
# Khowai | 4/5
# Hriday Restaurant (Ranjit)
# Phone: 09436168029
# Khowai | 5/5
# M/S Nandu....... Khowai Subhashpark
# Phone:
#
# Searching: software companies in North Tripura Tripura
# Search Submitted
# North Tripura | software companies | Scroll 1 -> 14
# North Tripura | software companies | Scroll 2 -> 20
# North Tripura | software companies | Scroll 3 -> 27
# North Tripura | software companies | Scroll 4 -> 34
# North Tripura | software companies | Scroll 5 -> 40
# North Tripura | software companies | Scroll 6 -> 47
# North Tripura | software companies | Scroll 7 -> 54
# North Tripura | software companies | Scroll 8 -> 60
# North Tripura | software companies | Scroll 9 -> 67
# North Tripura | software companies | Scroll 10 -> 74
# North Tripura | software companies | Scroll 11 -> 80
# North Tripura | software companies | Scroll 12 -> 80
# North Tripura | software companies | Scroll 13 -> 80
# North Tripura | software companies | Scroll 14 -> 80
# North Tripura | software companies | Scroll 15 -> 80
# Collected 52 links
# North Tripura | 1/52
# Epagecity Pvt Ltd
# Phone: 03822350087
# North Tripura | 2/52
# Nathians Creations Pvt. Ltd.
# Phone: 08856876393
# North Tripura | 3/52
# ADRITECH
# Phone: 02269622575
# North Tripura | 4/52
# Prasanjit Das
# Phone: 09612146092
# North Tripura | 5/52
# North Tripura | 26/56
# West Padmabil
# Phone:
# North Tripura | 27/56
# THE ROYAL MANSION (Building Planner & Architects)
# Phone: 08131073722
# North Tripura | 28/56
# Home
# Phone:
# North Tripura | 29/56
# Vyonika
# Phone: 08287212183
# North Tripura | 30/56
# Panisagar BSNL Exchange
# Phone: 18003451500
# North Tripura | 31/56
# Ajit Das
# Phone: 08132963622
# North Tripura | 32/56
# Home
# Phone:
# North Tripura | 33/56
# Nothing Yet
# Phone:
# North Tripura | 34/56
# Eden Tourist Lodge, Vanghmun, Jampui Hill
# Phone: 03824290888
# North Tripura | 35/56
# Bhatt Para
# Phone:
# North Tripura | 36/56
# Indane - Joyram Gas Agency
# Phone: 08731869810
# North Tripura | 37/56
# Sarma Kutir
# Phone:
# North Tripura | 38/56
# Debabrata Rentals
# Phone:
# Backup Saved
# North Tripura | 39/56
# Mahindra Finance - Dharmanagar Branch
# Phone: 08069680186
# North Tripura | 40/56
# Sanjit Debnath Home
# Phone:
# North Tripura | 41/56
# Nadiapur
# Phone:
# North Tripura | 42/56
# Suraj vegetable shop
# Phone:
# North Tripura | 43/56
# Graphics Corner, Art & Stickering
# Phone: 09863773567
# North Tripura | 44/56
# Sky Chalet
# Phone:
# North Tripura | 45/56
# Jubel Home 🏠
# Phone:
# North Tripura | 46/56
# Unakoti Mart Dharmanagar
# Phone: 07642902044
# North Tripura | 47/56
# MIDDLE KANGRAI, Dhananjoy Para
# Phone:
# North Tripura | 48/56
# Residence of CK Sailo family
# Phone:
# North Tripura | 49/56
# Cakes & Buns
# Phone: 09366848118
# North Tripura | 50/56
# Nabaratna's House
# Phone:
# North Tripura | 51/56
# DTDC Courier service
# Phone: 07005664554
# North Tripura | 52/56
# CREATION,S MOBILE REPAIRING
# Phone: 08974227584
# North Tripura | 53/56
# TPS SOLUTION
# Phone: 08787847945
# North Tripura | 54/56
# Digital Printer
# Phone: 06009494018
# North Tripura | 55/56
# Advocate Mainak Roy, B.A, LL.B(Hon's), LL.M.
# Phone: 06909775986
# North Tripura | 56/56
# JR Arts
# Phone: 09485097951
#
# Searching: software companies in Sepahijala Tripura
# Search Submitted
# Sepahijala | software companies | Scroll 1 -> 14
# Sepahijala | software companies | Scroll 2 -> 20
# Sepahijala | software companies | Scroll 3 -> 27
# Sepahijala | software companies | Scroll 4 -> 34
# Sepahijala | software companies | Scroll 5 -> 40
# Sepahijala | software companies | Scroll 6 -> 47
# Sepahijala | software companies | Scroll 7 -> 54
# Sepahijala | software companies | Scroll 8 -> 60
# Sepahijala | software companies | Scroll 9 -> 67
# Sepahijala | software companies | Scroll 10 -> 74
# Sepahijala | software companies | Scroll 11 -> 80
# Sepahijala | software companies | Scroll 12 -> 86
# Sepahijala | software companies | Scroll 13 -> 86
# Sepahijala | software companies | Scroll 14 -> 86
# Sepahijala | software companies | Scroll 15 -> 86
# Sepahijala | software companies | Scroll 16 -> 86
# Collected 67 links
# Sepahijala | 1/67
# Quantum research And Software Company .Ltd
# Phone:
# Sepahijala | 2/67
# Banik Varieties Electronics & Electric
# Phone: +8801888075702
# Sepahijala | 45/67
# EliteCord Services
# Phone: +8801888075702
# Sepahijala | 46/67
# Das Mentioned
# Phone:
# Sepahijala | 47/67
# Suleman Hossen
# Phone: 09856636818
# Sepahijala | 48/67
# HEALTHY FARM FOOD - best farm food deliver at home
# Phone:
# Sepahijala | 49/67
# Freelance it Hub
# Phone: +8801711136529
# Sepahijala | 50/67
# Harishnagar Tea Garden
# Phone:
# Sepahijala | 51/67
# Ashis Chandra Bhakta
# Phone: 09774739847
# Sepahijala | 52/67
# Sahidul Islam
# Phone:
# Sepahijala | 53/67
# Synthetic Latex Rb Produce
# Phone:
# Sepahijala | 54/67
# Sarada Bajaj
# Phone: 09774508057
# Sepahijala | 55/67
# BISHALGARH BSNL FTTH
# Phone:
# Sepahijala | 56/67
# Saiyadul Alam Bhuiyan
# Phone: +8801639872359
# Sepahijala | 57/67
# JKD Tech Consult
# Phone:
# Sepahijala | 58/67
# Aditya Event Planner
# Phone: 09615955656
# Sepahijala | 59/67
# NR web solution bd
# Phone: +8801628092602
# Sepahijala | 60/67
# M/S Chayan Saha
# Phone: 06009964449
# Sepahijala | 61/67
# Quick Fix Centre
# Phone: 06009895427
# Sepahijala | 62/67
# Swapan Sutradhar
# Phone: 09862068178
# Sepahijala | 63/67
# Singha Computer Store
# Phone:
# Sepahijala | 64/67
# MAA SANDHYA COMPUTER
# Phone: 07085097597
# Sepahijala | 65/67
# Malik hafa
# Phone: 08131047128
# Sepahijala | 66/67
# Sree Ramkrishna Electronics
# Phone: 09862390143
# Sepahijala | 67/67
# Delivery Courier Bishalgarh
# Phone:
#
# Searching: IT companies in Sepahijala Tripura
# Search Submitted
# Sepahijala | IT companies | Scroll 1 -> 14
# Sepahijala | IT companies | Scroll 2 -> 20
# Sepahijala | IT companies | Scroll 3 -> 27
# Sepahijala | IT companies | Scroll 4 -> 34
# Sepahijala | IT companies | Scroll 5 -> 40
# Sepahijala | IT companies | Scroll 6 -> 47
# Sepahijala | IT companies | Scroll 7 -> 54
# Sepahijala | IT companies | Scroll 8 -> 60
# Sepahijala | IT companies | Scroll 9 -> 67
# Sepahijala | IT companies | Scroll 10 -> 74
# Sepahijala | IT companies | Scroll 11 -> 80
# Sepahijala | IT companies | Scroll 12 -> 87
# Sepahijala | IT companies | Scroll 13 -> 94
# Sepahijala | IT companies | Scroll 14 -> 100
# Sepahijala | IT companies | Scroll 15 -> 107
# Sepahijala | IT companies | Scroll 16 -> 107
# Sepahijala | IT companies | Scroll 17 -> 107
# Sepahijala | IT companies | Scroll 18 -> 107
# Sepahijala | IT companies | Scroll 19 -> 107
# Collected 65 links
# Sepahijala | 1/65
# Sumanta Das
# Phone: 09774888581
# Sepahijala | 2/65
# DEVANSH INTEGRATE TECHNOLOGY
# Phone: 03812910469
# Sepahijala | 3/65
# ONGC Konaban GCS
# Phone:
# Sepahijala | 4/65
# Agartala Plastics Pvt. Ltd.
# Phone:
# Sepahijala | 5/65
# NADIA XEROX AND VERAITIC
# Phone:
# Sepahijala | 6/65
# Unakoti | software companies | Scroll 4 -> 34
# Unakoti | software companies | Scroll 5 -> 40
# Unakoti | software companies | Scroll 6 -> 47
# Unakoti | software companies | Scroll 7 -> 54
# Unakoti | software companies | Scroll 8 -> 60
# Unakoti | software companies | Scroll 9 -> 67
# Unakoti | software companies | Scroll 10 -> 70
# Unakoti | software companies | Scroll 11 -> 70
# Unakoti | software companies | Scroll 12 -> 70
# Unakoti | software companies | Scroll 13 -> 70
# Unakoti | software companies | Scroll 14 -> 70
# Collected 33 links
# Unakoti | 1/33
# KII Group & Company
# Phone: 09774638866
# Unakoti | 2/33
# JS INFOTECH
# Phone: 09383124893
# Unakoti | 3/33
# HIVE SOLUTION CORPORATION
# Phone: 08787604954
# Unakoti | 4/33
# URBNMIST COMPANY
# Phone: 09362136098
# Unakoti | 5/33
# SWAPNA VARIETIES
# Phone:
# Unakoti | 6/33
# JOY GURU COMPUTER INFORMATION CENTER
# Phone: 08787831505
# Unakoti | 7/33
# IACT KAILASHAHAR
# Phone: 09436130605
# Unakoti | 8/33
# CBCE (Computer Education Centre)
# Phone: 09862764117
# Unakoti | 9/33
# LICI PREMIUM POINT
# Phone: 09436465469
# Unakoti | 10/33
# Ghosh Computer
# Phone: 07640922957
# Unakoti | 11/33
# Unakoti Tourist Lodge
# Phone:
# Unakoti | 12/33
# Revolution Led
# Phone:
# Unakoti | 13/33
# Unakoti Mart | Online Food Delivery App
# Phone: 07640902044
# Unakoti | 14/33
# Murticherra Tea Estate
# Phone:
# Unakoti | 15/33
# WCCS (COMPUTER TRAINING INSTITUTE, FATIKROY)
# Phone: 07005148860
# Unakoti | 16/33
# TERABAND NETWORK PVT LTD
# Phone:
# Unakoti | 17/33
# MRS COMPUTER EDUCATION
# Phone: 09863500200
# Unakoti | 18/33
# Aryavart International University
# Phone: 09355822001
# Unakoti | 19/33
# Madhukar Enterprise
# Phone: 09612139388
# Unakoti | 20/33
# Manuvalley Tea Estate
# Phone:
# Backup Saved
# Unakoti | 21/33
# Rice Shop
# Phone: 08132094254
# Unakoti | 22/33
# Srimaa Travels Car Hire
# Phone: 08974225774
# Unakoti | 23/33
# ADHIRAJ CYBER ZONE
# Phone: 09366454807
# Unakoti | 24/33
# kumarghat unakoti taxi car service all car
# Phone: 07005245387
# Unakoti | 25/33
# Blue Dart
# Phone:
# Unakoti | 26/33
# Spy Earpiece Smallest Bluetooth Earphones Wifi CCTV Cameras
# Phone: 09774638866
# Unakoti | 27/33
# Abit Xerox
# Phone: 09862299282
# Unakoti | 28/33
# ARATI BEEJ BHANDER
# Phone: 09436583599
# Unakoti | 29/33
# LIC of India, Satellite Office
# Phone:
# Unakoti | 30/33
# BSNL Office
# Phone: 18003451500
# Unakoti | 31/33
# WebDev Solutions Hub
# Phone:
# Unakoti | 32/33
# GRAPHIXIO
# Phone:
# Unakoti | 33/33
# ONLINE Work & Printing Hub
# Phone: 09077312476
#
# Searching: IT companies in Unakoti Tripura
# Search Submitted
# Unakoti | IT companies | Scroll 1 -> 14
# Unakoti | IT companies | Scroll 2 -> 20
# Unakoti | IT companies | Scroll 3 -> 27
# Unakoti | IT companies | Scroll 4 -> 34
# Unakoti | IT companies | Scroll 5 -> 40
# Unakoti | IT companies | Scroll 6 -> 47
# Unakoti | IT companies | Scroll 7 -> 54
# Unakoti | IT companies | Scroll 8 -> 60
# Unakoti | IT companies | Scroll 9 -> 67
# Unakoti | IT companies | Scroll 10 -> 74
# Unakoti | IT companies | Scroll 11 -> 80
# Unakoti | IT companies | Scroll 12 -> 87
# Unakoti | IT companies | Scroll 13 -> 94
# Unakoti | IT companies | Scroll 14 -> 100
# Unakoti | IT companies | Scroll 15 -> 107
# Unakoti | IT companies | Scroll 16 -> 112
# Unakoti | IT companies | Scroll 17 -> 112
# Unakoti | IT companies | Scroll 18 -> 112
# Unakoti | IT companies | Scroll 19 -> 112
# Unakoti | IT companies | Scroll 20 -> 112
# Collected 49 links
# Unakoti | 1/49
# Unakoti.in
# Phone: 09362672848
# Unakoti | 2/49
# Unakoti Rock Carvings Tripura
# Phone:
# Unakoti | 3/49
# Unakoti Eco Park
# Phone:
# Unakoti | 4/49
# Unakoti District Public Library
# Phone:
# Unakoti | 5/49
# DTDC Courier
# Phone:
# Unakoti | 6/49
# MS WORLD TRAVEL SERVICES
# Phone: 08974938289
# Unakoti | 7/49
# Air Fiber Airtel
# Phone:
# Unakoti | 8/49
# Taxi 24x7 Kumarghat /Car rental service Kumarghat/Best taxi service & travel agency in North & Unakoti Tripura & jampui hills
# Phone: 08787463727
# Unakoti | 9/49
# Hotel Unakoti
# Phone: 09862116699
# Unakoti | 10/49
# Dewan Para
# Phone:
# Unakoti | 11/49
# Kalyan Ashram
# Phone:
# Unakoti | 12/49
# Raja lokei, bisnupriya manipuri
# Phone:
# Unakoti | 13/49
# Travel Agency
# Phone:
# Unakoti | 14/49
# Monoranjan Debnath Niwas
# Phone:
# Unakoti | 15/49
# Rupam Sinha
# Phone: 06909229460
# Unakoti | 16/49
# Asit Sinha's Residence
# Phone:
# Unakoti | 17/49
# Green Park Industries
# Phone: 08629992059
# Unakoti | 18/49
# Patron Consultancy Services
# Phone:
# Unakoti | 19/49
# SIAMTHARA DARLONG
# Phone: 09362889902
# Unakoti | 20/49
# F.M. ELECTRONICS
# Phone: 07085469619
# Unakoti | 21/49
# Maa Durga Mobile Centre
# Phone: 08974623712
# Unakoti | 22/49
# East Yeazekhowra Panchayat
# Phone:
# Unakoti | 23/49
# #Tarun jewellery
# Phone: 09436906958
# Unakoti | 24/49
# Rupam home
# Phone:
# Unakoti | 25/49
# It's pagals house
# Phone:
# Unakoti | 26/49
# Happy parivar residency
# Phone:
# Unakoti | 27/49
# M/S FATIKROY INDANE GRAMIN VITRAK
# Phone: 03824291552
# Unakoti | 28/49
# AMARALAY (BHATTACHARYA BHAWAN)
# Phone:
# Unakoti | 29/49
# DC Traders, Bajaj Showroom
# Phone: 09366255980
# Unakoti | 30/49
# Moin Uddin House
# Phone:
# Unakoti | 31/49
# Jalai Radio Station
# Phone:
# Unakoti | 32/49
# Taxi service kumarghat/car rental service kumarghat/best taxi service and travel
# Phone: 07005243411
# Unakoti | 33/49
# Deb Collection
# Phone: 06909969942
# Unakoti | 34/49
# Dhar Varieties
# Phone: 09436509606
# Unakoti | 35/49
# Fastdorcourier Service Dhalai Tripura
# Phone:
# Unakoti | 36/49
# Joy Guru Decorators
# Phone: 09612020682
# Unakoti | 37/49
# Cakes & Buns
# Phone: 07628983535
# Unakoti | 38/49
# P.C.Bazar
# Phone:
# Unakoti | 39/49
# Joyshree bazer
# Phone:
# Unakoti | 40/49
# Nadiapur bazaar
# Phone:
# Unakoti | 41/49
# Roy Digital
# Phone: 07005180456
# Unakoti | 42/49
# Rahul Enterprise
# Phone: 07005539478
# Unakoti | 43/49
# Mahindra Finance - Kumarghat Branch
# Phone: 08044953461
# Unakoti | 44/49
# Kumarghat
# Phone:
# Unakoti | 45/49
# Dreamline Tour And Travels
# Phone:
# Unakoti | 46/49
# SUNNY TRADERS
# Phone:
# Unakoti | 47/49
# Patron Consultancy Services
# Phone:
# Unakoti | 48/49
# House of Nilkanta Sinha
# Phone:
# Unakoti | 49/49
# J.L STORE
# Phone: 09862810076
#
# Searching: software companies in West Tripura Tripura
# Search Submitted
# West Tripura | software companies | Scroll 1 -> 14
# West Tripura | software companies | Scroll 2 -> 20
# West Tripura | software companies | Scroll 3 -> 27
# West Tripura | software companies | Scroll 4 -> 34
# West Tripura | software companies | Scroll 5 -> 40
# West Tripura | software companies | Scroll 6 -> 47
# West Tripura | software companies | Scroll 7 -> 54
# West Tripura | software companies | Scroll 8 -> 60
# West Tripura | software companies | Scroll 9 -> 67
# West Tripura | software companies | Scroll 10 -> 74
# West Tripura | software companies | Scroll 11 -> 80
# West Tripura | software companies | Scroll 12 -> 87
# West Tripura | software companies | Scroll 13 -> 94
# West Tripura | software companies | Scroll 14 -> 100
# West Tripura | software companies | Scroll 15 -> 107
# West Tripura | software companies | Scroll 16 -> 113
# West Tripura | software companies | Scroll 17 -> 113
# West Tripura | software companies | Scroll 18 -> 113
# West Tripura | software companies | Scroll 19 -> 113
# West Tripura | software companies | Scroll 20 -> 113
# Collected 90 links
# West Tripura | 1/90
# Stackkaroo - Explorogent International Services Private Limited
# Phone: 07085548881
# West Tripura | 2/90
# Ark Informatics Pvt Ltd
# Phone: 03812301707
# West Tripura | 3/90
# MODIFIED
# Phone: 08787680567
# West Tripura | 4/90
# Kyma AI Innovations
# Phone: 08132022566
# West Tripura | 5/90
# Lumina logic - a Best IT Company in India
# Phone: 06009949457
# West Tripura | 6/90
# It Hub
# Phone: 07005227299
# West Tripura | 7/90
# GstSof
# Phone: 09090905047
# West Tripura | 8/90
# TECH IT SOLUTION
# Phone: 08787482900
# West Tripura | 9/90
# Bluesky Technology
# Phone: 09774525701
# West Tripura | 10/90
# Rapid Softlabs
# Phone:
# West Tripura | 11/90
# SuperSecureSystem
# Phone:
# West Tripura | 12/90
# World Tech
# Phone: 08837045486
# West Tripura | 13/90
# Adryon Digital Media Pvt Ltd | Best Digital Marketing Company in Agartala | Best Digital Marketing Courses in Agartala
