# %%
import pandas as pd

# %%
df = pd.read_csv("bihar_companies.csv")

# %%
df.shape
# Out:
# (3981, 8)

# %%
df = df[
    df["Phone"].notna() & 
    (df["Phone"].astype(str).str.strip() != "")
    ]
df.shape
# Out:
# (2910, 8)

# %%
df = df[
    df["Company Name"].notna()
    ]

df = df[
    df["Company Name"].str.strip() != ""
    ]
df.shape
# Out:
# (2881, 8)

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]","",regex=True)
    .str.strip()
)

display(df[["Phone"]].head())
# Out:
#          Phone
# 0  79035547670
# 1  97710011890
# 4  84275845070
# 5  98017922070
# 6  93089938990

# %%
df.to_csv(
    "bihar_companies_cleaned.csv",
    index=False
)
