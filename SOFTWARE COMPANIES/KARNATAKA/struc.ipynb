# %%
import pandas as pd

# %%
df = pd.read_csv("karnataka_companies.csv")

# %%
df.shape
# Out:
# (2157, 8)

# %%
df = df[
    df["Phone"].notna() & 
    (df["Phone"].astype(str).str.strip() != "")
    ]
df.shape
# Out:
# (1655, 8)

# %%
df = df[
    df["Company Name"].notna()
    ]

df = df[
    df["Company Name"].str.strip() != ""
    ]
df.shape
# Out:
# (1645, 8)

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]","",regex=True)
    .str.strip()
)

display(df[["Phone"]].head())
# Out:
#          Phone
# 0  91415554440
# 1  74060835490
# 2  63637409430
# 3  99027007290
# 6  91084200010

# %%
df.to_csv(
    "karnataka_companies_cleaned.csv",
    index=False
)
