# %%
import pandas as pd

# %%
df = pd.read_csv("arunachal_pradesh_companies.csv")

# %%
df.shape
# Out:
# (1023, 8)

# %%
df = df[
    df["Phone"].notna() & 
    (df["Phone"].astype(str).str.strip() != "")
    ]
df.shape
# Out:
# (420, 8)

# %%
df = df[
    df["Company Name"].notna()
    ]

df = df[
    df["Company Name"].str.strip() != ""
    ]
df.shape
# Out:
# (420, 8)

# %%
df["Phone"] = (
    df["Phone"]
    .astype(str)
    .str.replace(r"[^\d\s]","",regex=True)
    .str.strip()
)

display(df[["Phone"]].head())
# Out:
#          Phone
# 0  90977289090
# 1  88374284570
# 2  92896767370
# 3  22696468700
# 6  75489188110

# %%
df.to_csv(
    "arunachal_pradesh_companies_cleaned.csv",
    index=False
)
