# %%
import time
import random
import pandas as pd

from datetime import datetime

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager




districts = [
    "Anjaw",
    "Bichom",
    "Changlang",
    "Dibang Valley",
    "East Kameng",
    "East Siang",
    "Kamle",
    "Kra Daadi",
    "Kurung Kumey",
    "Leparada",
    "Lohit",
    "Longding",
    "Lower Dibang Valley",
    "Lower Siang",
    "Lower Subansiri",
    "Namsai",
    "Pakke-Kessang",
    "Papum Pare",
    "Shi Yomi",
    "Siang",
    "Tawang",
    "Tirap",
    "Upper Siang",
    "Upper Subansiri",
    "West Kameng",
    "West Siang",
    "Keyi Panyor"
]



search_types = [
    "software companies",
    "IT companies"
]

options = webdriver.ChromeOptions()

options.add_argument("--start-maximized")

options.add_argument(
    "--disable-blink-features=AutomationControlled"
)

options.add_argument("--disable-notifications")



driver = webdriver.Chrome(

    service=Service(
        ChromeDriverManager().install()
    ),

    options=options
)



driver.get("https://www.google.com/maps")

print("Opening Google Maps...")

time.sleep(15)

print("Google Maps Loaded")


all_data = []

visited_links = set()


def get_search_box():

    selectors = [

        '//input[@id="searchboxinput"]',
        '//input[contains(@placeholder,"Search")]',
        '//input[contains(@aria-label,"Search")]',
        '//input'

    ]

    for selector in selectors:

        try:

            box = driver.find_element(
                By.XPATH,
                selector
            )

            return box

        except:
            pass

    return None



def extract_school_data():

    try:


        try:

            name = driver.find_element(
                By.TAG_NAME,
                "h1"
            ).text

        except:

            name = ""

        try:

            address = driver.find_element(
                By.XPATH,
                '//button[contains(@data-item-id,"address")]'
            ).text

        except:

            address = ""


        phone = ""

        try:

            phone_xpaths = [

       
                '//button[contains(@data-item-id,"phone")]',

    
                '//a[contains(@href,"tel:")]',

                '//button[contains(@aria-label,"Phone")]',

                '//button[contains(text(),"+91")]',
                '//div[contains(text(),"+91")]',
                '//span[contains(text(),"+91")]'

            ]

            for xpath in phone_xpaths:

                try:

                    elements = driver.find_elements(
                        By.XPATH,
                        xpath
                    )

                    for element in elements:

                        text = element.text.strip()

                        href = (
                            element.get_attribute("href")
                            or ""
                        )

                        if "tel:" in href:

                            phone = href.replace(
                                "tel:",
                                ""
                            ).strip()

                        elif text:

                            phone = text

                        phone = (

                            phone.replace("", "")
                            .replace(" ", "")
                            .replace("-", "")
                            .replace("(", "")
                            .replace(")", "")
                            .replace("\n", "")
                            .strip()

                        )

                        digits = ''.join(
                            filter(str.isdigit, phone)
                        )

                        if len(digits) >= 10:

                            break

                    if phone:
                        break

                except:
                    pass

        except Exception as e:

            print(f"Phone Error: {e}")

        # WEBSITE

        try:

            website = driver.find_element(
                By.XPATH,
                '//a[contains(@data-item-id,"authority")]'
            ).get_attribute("href")

        except:

            website = ""

        # RATING

        try:

            rating = driver.find_element(
                By.XPATH,
                '//div[@role="img"]'
            ).get_attribute("aria-label")

        except:

            rating = ""

        return {

            "Company Name": name,
            "Address": address,
            "Phone": phone,
            "Website": website,
            "Rating": rating,
            "Google Maps URL": driver.current_url

        }

    except:

        return None


for district in districts:

    for search_type in search_types:

        try:

            query = (
                f"{search_type} "
                f"in {district} Arunachal Pradesh"
            )

            print(f"\nSearching: {query}")


            search_box = get_search_box()

            if not search_box:

                print("Search Box Not Found")

                continue

            ActionChains(driver).move_to_element(
                search_box
            ).click().perform()

            time.sleep(1)

            search_box.send_keys(
                Keys.CONTROL + "a"
            )

            time.sleep(1)

            search_box.send_keys(Keys.DELETE)

            time.sleep(1)


            for char in query:

                search_box.send_keys(char)

                time.sleep(0.03)

            search_box.send_keys(Keys.ENTER)

            print("Search Submitted")

            time.sleep(8)


            try:

                scrollable_div = driver.find_element(
                    By.XPATH,
                    '//div[@role="feed"]'
                )

                previous_count = 0

                stagnant = 0

                for i in range(100):

                    driver.execute_script(
                        """
                        arguments[0].scrollTop =
                        arguments[0].scrollHeight
                        """,
                        scrollable_div
                    )

                    time.sleep(4)

                    listings = driver.find_elements(
                        By.XPATH,
                        '//a[contains(@href,"/maps/place/")]'
                    )

                    current_count = len(listings)

                    print(
                        f"{district} | "
                        f"{search_type} | "
                        f"Scroll {i+1} -> "
                        f"{current_count}"
                    )

                    if current_count == previous_count:

                        stagnant += 1

                    else:

                        stagnant = 0

                    if stagnant >= 4:

                        break

                    previous_count = current_count

            except Exception as e:

                print(f"Scrolling Error: {e}")

            # GET LINKS

            listings = driver.find_elements(
                By.XPATH,
                '//a[contains(@href,"/maps/place/")]'
            )

            links = []

            for listing in listings:

                try:

                    link = listing.get_attribute("href")

                    if (
                        link
                        and link not in visited_links
                    ):

                        links.append(link)

                        visited_links.add(link)

                except:
                    pass

            print(f"Collected {len(links)} links")


            for index, link in enumerate(links):

                try:

                    print(
                        f"{district} | "
                        f"{index+1}/{len(links)}"
                    )

                    driver.get(link)

                    time.sleep(
                        random.uniform(2, 3)
                    )

                    data = extract_school_data()

                    if data:

                        data["District"] = district

                        data["Search Type"] = search_type

                        all_data.append(data)

                        print(data["Company Name"])

                        print(
                            f"Phone: {data['Phone']}"
                        )


                    if len(all_data) % 100 == 0:

                        backup_df = pd.DataFrame(
                            all_data
                        )

                        backup_df.drop_duplicates(
                            subset=[
                                "Company Name",
                                "Google Maps URL"
                            ],
                            inplace=True
                        )

                        backup_df.to_csv(
                            "arunachal_pradesh_companies_backup.csv",
                            index=False
                        )

                        print("Backup Saved")

                except Exception as e:

                    print(
                        f"Company Error: {e}"
                    )

        except Exception as e:

            print(
                f"District Error: {e}"
            )


df = pd.DataFrame(all_data)

df.drop_duplicates(

    subset=[
        "Company Name",
        "Google Maps URL"
    ],

    inplace=True
)

filename = "arunachal_pradesh_companies.csv"

df.to_csv(
    filename,
    index=False
)

print("\nExtraction Completed")

print(
    f"Total Companies Extracted: {len(df)}"
)

print(f"\nSaved File: {filename}")

driver.quit()
# Out:
# Opening Google Maps...
# Google Maps Loaded
#
# Searching: software companies in Anjaw Arunachal Pradesh
# Search Submitted
# Anjaw | software companies | Scroll 1 -> 9
# Anjaw | software companies | Scroll 2 -> 9
# Anjaw | software companies | Scroll 3 -> 9
# Anjaw | software companies | Scroll 4 -> 9
# Anjaw | software companies | Scroll 5 -> 9
# Collected 9 links
# Anjaw | 1/9
# Websofto Technologies
# Phone: 09097728909
# Anjaw | 2/9
# Xvariate
# Phone: 08837428457
# Anjaw | 3/9
# Samnic Tech - AR ( Itanagar )
# Phone: 09289676737
# Anjaw | 4/9
# Juluku technology
# Phone: 02269646870
# Anjaw | 5/9
# Cyber World
# Phone:
# Anjaw | 6/9
# Rayair Tech
# Phone:
# Anjaw | 7/9
# POINT TECH COMPUTERS, ROCK LAND
# Phone: 07548918811
# Anjaw | 8/9
# DIGITALMIIND
# Phone:
# Anjaw | 9/9
# Jenbum Apps (opc) Pvt Ltd
# Phone:
#
# Searching: IT companies in Anjaw Arunachal Pradesh
# Search Submitted
# Anjaw | IT companies | Scroll 1 -> 5
# Anjaw | IT companies | Scroll 2 -> 5
# Anjaw | IT companies | Scroll 3 -> 5
# Anjaw | IT companies | Scroll 4 -> 5
# Anjaw | IT companies | Scroll 5 -> 5
# Collected 2 links
# Anjaw | 1/2
# Delhivery courier office
# Phone:
# Anjaw | 2/2
# Dong Valley Sunrise View Point
# Phone: 01123715084
#
# Searching: software companies in Bichom Arunachal Pradesh
# Search Submitted
# Bichom | software companies | Scroll 1 -> 3
# Bichom | software companies | Scroll 2 -> 3
# Bichom | software companies | Scroll 3 -> 3
# Bichom | software companies | Scroll 4 -> 3
# Bichom | software companies | Scroll 5 -> 3
# Collected 1 links
# Bichom | 1/1
# Qudisol Consulting Services
# Phone: 07044116778
#
# Searching: IT companies in Bichom Arunachal Pradesh
# Search Submitted
# Bichom | IT companies | Scroll 1 -> 14
# Bichom | IT companies | Scroll 2 -> 17
# Bichom | IT companies | Scroll 3 -> 17
# Bichom | IT companies | Scroll 4 -> 17
# Bichom | IT companies | Scroll 5 -> 17
# Bichom | IT companies | Scroll 6 -> 17
# Collected 15 links
# Bichom | 1/15
# Electronic Hub
# Phone: 07085874499
# Bichom | 2/15
# Quick Digital Solution (Computer Dealer)
# Phone: 07044116778
# Bichom | 3/15
# Waibaz Computer
# Phone: 09696959528
# Bichom | 4/15
# FUSIONS
# Phone: 08729881666
# Bichom | 5/15
# Jojo Cyber Bomdila
# Phone: 08258875750
# Bichom | 6/15
# Bichom
# Phone:
# Bichom | 7/15
# NIMAZ Computer SHOP
# Phone: 07629866666
# Bichom | 8/15
# REPAIRING HUB
# Phone: 07085722608
# Bichom | 9/15
# Cyber Zone
# Phone: 07630808166
# Bichom | 10/15
# M/s- Regisow Enterprises
# Phone:
# Bichom | 11/15
# M/s G.K. Construction
# Phone:
# Bichom | 12/15
# M/S Jaya Nyima Chorten Trade
# Phone: 09862922441
# Bichom | 13/15
# Website Development in Westkameng - Oacer web services
# Phone:
# Bichom | 14/15
# Hybrid Internet
# Phone:
# Bichom | 15/15
# Gandhi jongthens Estate
# Phone:
#
# Searching: software companies in Changlang Arunachal Pradesh
# Search Submitted
# Scrolling Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@role="feed"]"}
#   (Session info: chrome=148.0.7778.168); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 	chromedriver!GetHandleVerifier [0xbfb593+105d3]
# 	chromedriver!GetHandleVerifier [0xbfb6c4+10704]
# 	chromedriver!(No symbol) [0xa01ea0]
# 	chromedriver!(No symbol) [0xa4b28a]
# 	chromedriver!(No symbol) [0xa4b52b]
# 	chromedriver!(No symbol) [0xa8d052]
# 	chromedriver!(No symbol) [0xa6d7c4]
# 	chromedriver!(No symbol) [0xa8a936]
# 	chromedriver!(No symbol) [0xa6d516]
# 	chromedriver!(No symbol) [0xa408e9]
# 	chromedriver!(No symbol) [0xa416a4]
# 	chromedriver!GetHandleVerifier [0xe83014+298054]
# 	chromedriver!GetHandleVerifier [0xe7e603+293643]
# 	chromedriver!GetHandleVerifier [0xe9ea05+2b3a45]
# 	chromedriver!GetHandleVerifier [0xc154e8+2a528]
# 	chromedriver!GetHandleVerifier [0xc1cd1d+31d5d]
# 	chromedriver!GetHandleVerifier [0xc03e68+18ea8]
# 	chromedriver!GetHandleVerifier [0xc04015+19055]
# 	chromedriver!GetHandleVerifier [0xbed65f+269f]
# 	KERNEL32!BaseThreadInitThunk [0x75c9fcc9+19]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x77a082ae+11e]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x77a0827e+ee]
#
# Collected 0 links
#
# Searching: IT companies in Changlang Arunachal Pradesh
# Search Submitted
# Changlang | IT companies | Scroll 1 -> 3
# Changlang | IT companies | Scroll 2 -> 3
# Changlang | IT companies | Scroll 3 -> 3
# Changlang | IT companies | Scroll 4 -> 3
# Changlang | IT companies | Scroll 5 -> 3
# Collected 2 links
# Changlang | 1/2
# Galaxy Infotech
# Phone:
# Changlang | 2/2
# IT Firm
# Phone: 08119962463
#
# Searching: software companies in Dibang Valley Arunachal Pradesh
# Search Submitted
# Dibang Valley | software companies | Scroll 1 -> 5
# Dibang Valley | software companies | Scroll 2 -> 5
# Dibang Valley | software companies | Scroll 3 -> 5
# Dibang Valley | software companies | Scroll 4 -> 5
# Dibang Valley | software companies | Scroll 5 -> 5
# Collected 4 links
# Dibang Valley | 1/4
# Blue Hills Group Anini
# Phone: 08729982307
# Dibang Valley | 2/4
# 🌥️God's drink | Sen-Carletto🌿 Traditional mishmi wine & juice
# Phone:
# Dibang Valley | 3/4
# Maruchiya Soft
# Phone: 08035842934
# Dibang Valley | 4/4
# T.S. CYBER CAFE
# Phone: 09233997384
#
# Searching: IT companies in Dibang Valley Arunachal Pradesh
# Search Submitted
# Dibang Valley | IT companies | Scroll 1 -> 10
# Dibang Valley | IT companies | Scroll 2 -> 15
# Dibang Valley | IT companies | Scroll 3 -> 20
# Dibang Valley | IT companies | Scroll 4 -> 25
# Dibang Valley | IT companies | Scroll 5 -> 30
# Dibang Valley | IT companies | Scroll 6 -> 35
# Dibang Valley | IT companies | Scroll 7 -> 40
# Dibang Valley | IT companies | Scroll 8 -> 45
# Dibang Valley | IT companies | Scroll 9 -> 50
# Dibang Valley | IT companies | Scroll 10 -> 55
# Dibang Valley | IT companies | Scroll 11 -> 60
# Dibang Valley | IT companies | Scroll 12 -> 65
# Dibang Valley | IT companies | Scroll 13 -> 70
# Dibang Valley | IT companies | Scroll 14 -> 75
# Phone: 08132092820
# East Kameng | 26/27
# Help Tech
# Phone:
# East Kameng | 27/27
# Bladnaston Store
# Phone: 09864999408
#
# Searching: IT companies in East Kameng Arunachal Pradesh
# Search Submitted
# East Kameng | IT companies | Scroll 1 -> 14
# East Kameng | IT companies | Scroll 2 -> 14
# East Kameng | IT companies | Scroll 3 -> 14
# East Kameng | IT companies | Scroll 4 -> 14
# East Kameng | IT companies | Scroll 5 -> 14
# Collected 1 links
# East Kameng | 1/1
# VD Computer
# Phone:
#
# Searching: software companies in East Siang Arunachal Pradesh
# Search Submitted
# East Siang | software companies | Scroll 1 -> 14
# East Siang | software companies | Scroll 2 -> 15
# East Siang | software companies | Scroll 3 -> 15
# East Siang | software companies | Scroll 4 -> 15
# East Siang | software companies | Scroll 5 -> 15
# East Siang | software companies | Scroll 6 -> 15
# Collected 9 links
# East Siang | 1/9
# AB,s cyber cafe
# Phone: 09612745266
# East Siang | 2/9
# Matrix Solution
# Phone:
# East Siang | 3/9
# ASQUARE ENTERPRISES
# Phone: 09862489089
# East Siang | 4/9
# Siang Computer Academy
# Phone:
# East Siang | 5/9
# M/s Infonet Solution
# Phone: 08257993288
# East Siang | 6/9
# ANE SIANG COMPUTER ACADEMY
# Phone: 08119896771
# East Siang | 7/9
# ULTIMA CAREER TRAINING INSTITUTE
# Phone: 08135084922
# East Siang | 8/9
# the impex solutions
# Phone:
# East Siang | 9/9
# Apex Professional University (APU)
# Phone: 08800838839
#
# Searching: IT companies in East Siang Arunachal Pradesh
# Search Submitted
# East Siang | IT companies | Scroll 1 -> 14
# East Siang | IT companies | Scroll 2 -> 20
# East Siang | IT companies | Scroll 3 -> 27
# East Siang | IT companies | Scroll 4 -> 34
# East Siang | IT companies | Scroll 5 -> 40
# East Siang | IT companies | Scroll 6 -> 47
# East Siang | IT companies | Scroll 7 -> 54
# East Siang | IT companies | Scroll 8 -> 60
# East Siang | IT companies | Scroll 9 -> 67
# East Siang | IT companies | Scroll 10 -> 74
# East Siang | IT companies | Scroll 11 -> 78
# East Siang | IT companies | Scroll 12 -> 78
# East Siang | IT companies | Scroll 13 -> 78
# East Siang | IT companies | Scroll 14 -> 78
# East Siang | IT companies | Scroll 15 -> 78
# Collected 60 links
# East Siang | 1/60
# M/s Dana Enterprises
# Phone:
# East Siang | 2/60
# M/S Asii Enterprise
# Phone: 09366078138
# East Siang | 3/60
# TECHNICAL RAHUL
# Phone: 08132012970
# East Siang | 4/60
# AB Cyber Cafe
# Phone: 08794429389
# East Siang | 5/60
# LIC of India, Branch Office
# Phone:
# East Siang | 6/60
# Yangki cyber cafe
# Phone: 08119027268
# East Siang | 7/60
# Gooogle Cyber Cafe
# Phone:
# East Siang | 8/60
# DIGITAL WORLD
# Phone: 07005088390
# East Siang | 9/60
# Siang River, Pasighat
# Phone:
# East Siang | 10/60
# WELCOME CYBER CAFE
# Phone: 06000049240
# East Siang | 11/60
# NomadNest
# Phone:
# East Siang | 12/60
# My Jio Store
# Phone: 08928443472
# Library
# Phone: 08787554553
# East Siang | 58/60
# Cyberzone X
# Phone: 07628935926
# East Siang | 59/60
# HD GRAPHICS PASIGHAT
# Phone:
# East Siang | 60/60
# Cyber Zone Psg
# Phone:
#
# Searching: software companies in Kamle Arunachal Pradesh
# Search Submitted
# Kamle | software companies | Scroll 1 -> 9
# Kamle | software companies | Scroll 2 -> 9
# Kamle | software companies | Scroll 3 -> 9
# Kamle | software companies | Scroll 4 -> 9
# Kamle | software companies | Scroll 5 -> 9
# Collected 6 links
# Kamle | 1/6
# ADRP Computer (P) Ltd.
# Phone: 09707044172
# Kamle | 2/6
# Grass Root System
# Phone: 08974225556
# Kamle | 3/6
# Ganesh Computer
# Phone: 07085355262
# Kamle | 4/6
# Relin Center
# Phone:
# Kamle | 5/6
# Zenforto Softs
# Phone: 07905469688
# Kamle | 6/6
# Pranab Bora
# Phone: 08486891210
#
# Searching: IT companies in Kamle Arunachal Pradesh
# Search Submitted
# Kamle | IT companies | Scroll 1 -> 14
# Kamle | IT companies | Scroll 2 -> 20
# Kamle | IT companies | Scroll 3 -> 22
# Kamle | IT companies | Scroll 4 -> 22
# Kamle | IT companies | Scroll 5 -> 22
# Kamle | IT companies | Scroll 6 -> 22
# Kamle | IT companies | Scroll 7 -> 22
# Collected 16 links
# Kamle | 1/16
# RANGANADI BUILDPRO CONSTRUCTION PRIVATE LIMITED
# Phone:
# Kamle | 2/16
# Kenya Apartment
# Phone:
# Kamle | 3/16
# P.R. Enterprise
# Phone: 08794588905
# Kamle | 4/16
# Bachelor's Quarter
# Phone:
# Kamle | 5/16
# Marami Store
# Phone: 09854871817
# Kamle | 6/16
# Borah Pc Center
# Phone: 08471916242
# Kamle | 7/16
# G. B House
# Phone:
# Kamle | 8/16
# Raga-3
# Phone:
# Kamle | 9/16
# Lakeside Homestay
# Phone: 09436059165
# Kamle | 10/16
# Residence of Singku Maga
# Phone:
# Kamle | 11/16
# Rasidul Multi Store
# Phone:
# Kamle | 12/16
# Indane - Stary Gramin Vitrak
# Phone: 07085755359
# Kamle | 13/16
# The Voice of Kamle
# Phone:
# Kamle | 14/16
# Yada
# Phone:
# Kamle | 15/16
# N.M.Cyber Raga-III
# Phone:
# Kamle | 16/16
# Choudhary Store
# Phone: 09402811185
#
# Searching: software companies in Kra Daadi Arunachal Pradesh
# Search Submitted
# Kra Daadi | software companies | Scroll 1 -> 5
# Kra Daadi | software companies | Scroll 2 -> 5
# Kra Daadi | software companies | Scroll 3 -> 5
# Kra Daadi | software companies | Scroll 4 -> 5
# Kra Daadi | software companies | Scroll 5 -> 5
# Collected 1 links
# Kra Daadi | 1/1
# Sangai infosys
# Phone:
#
# Searching: IT companies in Kra Daadi Arunachal Pradesh
# Search Submitted
# Kra Daadi | IT companies | Scroll 1 -> 13
# Kra Daadi | IT companies | Scroll 2 -> 13
# Kra Daadi | IT companies | Scroll 3 -> 13
# Kra Daadi | IT companies | Scroll 4 -> 13
# Kra Daadi | IT companies | Scroll 5 -> 13
# Indane - B T Indane Gas Agency
# Phone: 08399904824
# Kurung Kumey | 23/51
# CRPF Line
# Phone:
# Kurung Kumey | 24/51
# Horticulture complex
# Phone:
# Kurung Kumey | 25/51
# Tarang Namlo
# Phone:
# Kurung Kumey | 26/51
# Bengia Tabin house
# Phone:
# Kurung Kumey | 27/51
# Aake
# Phone:
# Kurung Kumey | 28/51
# AK CYBER CAFE
# Phone: 08974944758
# Kurung Kumey | 29/51
# BSNL Store
# Phone: 09402832088
# Kurung Kumey | 30/51
# Hydro power plant
# Phone:
# Kurung Kumey | 31/51
# Bengia Luruk residence
# Phone:
# Kurung Kumey | 32/51
# Bamang Tadu
# Phone:
# Kurung Kumey | 33/51
# Ginnya Mayi HGB residential
# Phone:
# Kurung Kumey | 34/51
# D.R.D. Enterprise
# Phone: 09863116090
# Kurung Kumey | 35/51
# D.K Jerjo Cyber Cafe (CSC) cum Tee-Splash Prints
# Phone: 08730025834
# Kurung Kumey | 36/51
# Odo Taku
# Phone:
# Kurung Kumey | 37/51
# Ma Pyae Phyo Hlaing
# Phone:
# Kurung Kumey | 38/51
# Bengia yadung
# Phone:
# Kurung Kumey | 39/51
# ATO TARO-TAPA NAMLO
# Phone:
# Kurung Kumey | 40/51
# St.Mary’s Residential School Koloriang
# Phone:
# Kurung Kumey | 41/51
# ASHA STUDIO
# Phone: 09402275209
# Kurung Kumey | 42/51
# Taro koyang residency
# Phone:
# Backup Saved
# Kurung Kumey | 43/51
# Nangram Sima’s residence
# Phone:
# Kurung Kumey | 44/51
# SP Bungalow, Koloriang
# Phone:
# Kurung Kumey | 45/51
# Jill Residents
# Phone:
# Kurung Kumey | 46/51
# DENGA BENGIA
# Phone:
# Kurung Kumey | 47/51
# Dongda tata
# Phone:
# Kurung Kumey | 48/51
# AE UD official Resident
# Phone:
# Kurung Kumey | 49/51
# Kundan Store
# Phone: 07970702701
# Kurung Kumey | 50/51
# Nikja Family (Chape)
# Phone:
# Kurung Kumey | 51/51
# Cattering service
# Phone: 06909447215
#
# Searching: software companies in Leparada Arunachal Pradesh
# Search Submitted
# Leparada | software companies | Scroll 1 -> 6
# Leparada | software companies | Scroll 2 -> 6
# Leparada | software companies | Scroll 3 -> 6
# Leparada | software companies | Scroll 4 -> 6
# Leparada | software companies | Scroll 5 -> 6
# Collected 4 links
# Leparada | 1/4
# Virtual Tech
# Phone: 08794796816
# Leparada | 2/4
# Samyak Computer Classes, Aalo, Arunachal Pradesh
# Phone: 07413926777
# Leparada | 3/4
# lisum computer seal an service
# Phone: 08974606031
# Leparada | 4/4
# MultiCloud Service Arunachal
# Phone: 09362371801
#
# Searching: IT companies in Leparada Arunachal Pradesh
# Search Submitted
# Leparada | IT companies | Scroll 1 -> 14
# Leparada | IT companies | Scroll 2 -> 20
# Leparada | IT companies | Scroll 3 -> 22
# Leparada | IT companies | Scroll 4 -> 22
# Leparada | IT companies | Scroll 5 -> 22
# Leparada | IT companies | Scroll 6 -> 22
# Leparada | IT companies | Scroll 7 -> 22
# Collected 18 links
# Leparada | 1/18
# Material Recovery Facility
# Phone:
# Leparada | 2/18
# Dipa village
# Phone:
# Leparada | 3/18
# Shyan Computers & Travels
# Phone:
# Leparada | 4/18
# E-SYSTEM
# Phone: 09402044005
# Leparada | 5/18
# Rivera Homestay, Aalo
# Phone: 08729825830
# Leparada | 6/18
# G.K Enterprises
# Phone: 08132972304
# Leparada | 7/18
# North East Frontier Technical University
# Phone: 03783222444
# Leparada | 8/18
# Chapter 42 study library
# Phone:
# Leparada | 9/18
# EAC OFFICE, Tirbin
# Phone:
# Leparada | 10/18
# RUTI HOUSE
# Phone:
# Leparada | 11/18
# MITA Restaurant Cum Resort
# Phone: 08132895488
# Leparada | 12/18
# Gamlin Residence
# Phone:
# Leparada | 13/18
# Agam pig farm
# Phone:
# Leparada | 14/18
# AALO NEW MARKET
# Phone: 09233647636
# Leparada | 15/18
# HIKER GUMIN (LOWER)
# Phone:
# Leparada | 16/18
# Dolma Group of Hotels
# Phone: 03794223271
# Leparada | 17/18
# Tali Csp
# Phone: 08131940710
# Leparada | 18/18
# YOM Fishery
# Phone: 07005665460
#
# Searching: software companies in Lohit Arunachal Pradesh
# Search Submitted
# Lohit | software companies | Scroll 1 -> 13
# Lohit | software companies | Scroll 2 -> 13
# Lohit | software companies | Scroll 3 -> 13
# Lohit | software companies | Scroll 4 -> 13
# Lohit | software companies | Scroll 5 -> 13
# Collected 8 links
# Lohit | 1/8
# S-Tech Zone
# Phone: 09127496055
# Lohit | 2/8
# TechFix Computers
# Phone: 07628064053
# Lohit | 3/8
# Office of the Executive Engineer
# Phone:
# Lohit | 4/8
# Shree Ji Enterprises
# Phone: 09863831833
# Lohit | 5/8
# M/s Mac Computers
# Phone: 09612852523
# Lohit | 6/8
# Pradip web solution
# Phone:
# Lohit | 7/8
# saikiacode
# Phone:
# Lohit | 8/8
# Newtech Computers
# Phone: 09436058855
#
# Searching: IT companies in Lohit Arunachal Pradesh
# Search Submitted
# Lohit | IT companies | Scroll 1 -> 14
# Lohit | IT companies | Scroll 2 -> 20
# Lohit | IT companies | Scroll 3 -> 27
# Lohit | IT companies | Scroll 4 -> 34
# Lohit | IT companies | Scroll 5 -> 40
# Lohit | IT companies | Scroll 6 -> 47
# Lohit | IT companies | Scroll 7 -> 54
# Lohit | IT companies | Scroll 8 -> 60
# Lohit | IT companies | Scroll 9 -> 67
# Lohit | IT companies | Scroll 10 -> 74
# Lohit | IT companies | Scroll 11 -> 79
# Lohit | IT companies | Scroll 12 -> 79
# Lohit | IT companies | Scroll 13 -> 79
# Lohit | IT companies | Scroll 14 -> 79
# Lohit | IT companies | Scroll 15 -> 79
# Collected 69 links
# Lohit | 1/69
# AETHER BREWERIES LLP
# Phone:
# Lohit | 2/69
# Towsik Complex
# Phone:
# Lohit | 3/69
# 25BN ITBP FORCE CAMPUS
# Phone:
# Lohit | 4/69
# ALC Land,Tezu
# Phone:
# Lohit | 5/69
# S K Electronics Tezu
# Healthy Habits Juice Bar
# Phone:
# Lohit | 52/69
# PUCC- Pollution Centre, Lekang Circle
# Phone:
# Lohit | 53/69
# Kasik Kompa Payum
# Phone:
# Lohit | 54/69
# Sharma Sales & Service
# Phone:
# Lohit | 55/69
# KM Roing Taxi/Cab Services
# Phone: 09136060001
# Lohit | 56/69
# SBI Branch Tezu
# Phone: 18001234
# Lohit | 57/69
# K K TRAVEL
# Phone: 07005428061
# Lohit | 58/69
# Bamboosa Library
# Phone:
# Lohit | 59/69
# Kanchi charali
# Phone:
# Lohit | 60/69
# Wakro Eco Resort
# Phone: 08415895427
# Lohit | 61/69
# Golden Pagoda Eco Resort
# Phone: 08262848992
# Backup Saved
# Lohit | 62/69
# MANJIT STORE
# Phone: 08787710600
# Lohit | 63/69
# Innao Khamti
# Phone: 08119984829
# Lohit | 64/69
# Car rental services pintu rai
# Phone: 07002496735
# Lohit | 65/69
# Taxi service center roing
# Phone:
# Lohit | 66/69
# Borang Homestay
# Phone:
# Lohit | 67/69
# Tabitha Girl's Hostel
# Phone:
# Lohit | 68/69
# Mice Computer Education
# Phone: 07005802894
# Lohit | 69/69
# Bk Cyber Cafe
# Phone:
#
# Searching: software companies in Longding Arunachal Pradesh
# Search Submitted
# Longding | software companies | Scroll 1 -> 6
# Longding | software companies | Scroll 2 -> 6
# Longding | software companies | Scroll 3 -> 6
# Longding | software companies | Scroll 4 -> 6
# Longding | software companies | Scroll 5 -> 6
# Collected 4 links
# Longding | 1/4
# Circuit house, Longding
# Phone:
# Longding | 2/4
# WW Enterprise
# Phone: 08414863682
# Longding | 3/4
# Poiham Cyber Longding Pvt.Ltd
# Phone: 09233723072
# Longding | 4/4
# Xerox
# Phone: 07629930285
#
# Searching: IT companies in Longding Arunachal Pradesh
# Search Submitted
# Longding | IT companies | Scroll 1 -> 10
# Longding | IT companies | Scroll 2 -> 15
# Longding | IT companies | Scroll 3 -> 20
# Longding | IT companies | Scroll 4 -> 25
# Longding | IT companies | Scroll 5 -> 30
# Longding | IT companies | Scroll 6 -> 35
# Longding | IT companies | Scroll 7 -> 40
# Longding | IT companies | Scroll 8 -> 45
# Longding | IT companies | Scroll 9 -> 50
# Longding | IT companies | Scroll 10 -> 55
# Longding | IT companies | Scroll 11 -> 60
# Longding | IT companies | Scroll 12 -> 65
# Longding | IT companies | Scroll 13 -> 67
# Longding | IT companies | Scroll 14 -> 67
# Longding | IT companies | Scroll 15 -> 67
# Longding | IT companies | Scroll 16 -> 67
# Longding | IT companies | Scroll 17 -> 67
# Collected 61 links
# Longding | 1/61
# Longding View point
# Phone:
# Longding | 2/61
# PG-Niwas
# Phone:
# Longding | 3/61
# Tanuam Kaam
# Phone:
# Longding | 4/61
# Tissa River
# Phone:
# Longding | 5/61
# Ngissa village
# Phone:
# Longding | 6/61
# BALAJI GROCERY SHOP
# Phone: 08258054829
# Longding | 7/61
# Longding
# Phone:
# Longding | 8/61
# DAPSAHAM ENTERPRISE
# Phone: 09395603048
# M/S James stone crushers
# Phone:
# Longding | 61/61
# Mnalai M.L
# Phone:
#
# Searching: software companies in Lower Dibang Valley Arunachal Pradesh
# Search Submitted
# Lower Dibang Valley | software companies | Scroll 1 -> 14
# Lower Dibang Valley | software companies | Scroll 2 -> 20
# Lower Dibang Valley | software companies | Scroll 3 -> 27
# Lower Dibang Valley | software companies | Scroll 4 -> 34
# Lower Dibang Valley | software companies | Scroll 5 -> 34
# Lower Dibang Valley | software companies | Scroll 6 -> 34
# Lower Dibang Valley | software companies | Scroll 7 -> 34
# Lower Dibang Valley | software companies | Scroll 8 -> 34
# Collected 2 links
# Lower Dibang Valley | 1/2
# M/s Dibang Enterprises Roing
# Phone: 08974876665
# Lower Dibang Valley | 2/2
# Linggi Xerox Centre
# Phone:
#
# Searching: IT companies in Lower Dibang Valley Arunachal Pradesh
# Search Submitted
# Lower Dibang Valley | IT companies | Scroll 1 -> 14
# Lower Dibang Valley | IT companies | Scroll 2 -> 20
# Lower Dibang Valley | IT companies | Scroll 3 -> 27
# Lower Dibang Valley | IT companies | Scroll 4 -> 34
# Lower Dibang Valley | IT companies | Scroll 5 -> 40
# Lower Dibang Valley | IT companies | Scroll 6 -> 47
# Lower Dibang Valley | IT companies | Scroll 7 -> 54
# Lower Dibang Valley | IT companies | Scroll 8 -> 60
# Lower Dibang Valley | IT companies | Scroll 9 -> 67
# Lower Dibang Valley | IT companies | Scroll 10 -> 74
# Lower Dibang Valley | IT companies | Scroll 11 -> 80
# Lower Dibang Valley | IT companies | Scroll 12 -> 87
# Lower Dibang Valley | IT companies | Scroll 13 -> 94
# Lower Dibang Valley | IT companies | Scroll 14 -> 100
# Lower Dibang Valley | IT companies | Scroll 15 -> 107
# Lower Dibang Valley | IT companies | Scroll 16 -> 114
# Lower Dibang Valley | IT companies | Scroll 17 -> 120
# Lower Dibang Valley | IT companies | Scroll 18 -> 120
# Lower Dibang Valley | IT companies | Scroll 19 -> 120
# Lower Dibang Valley | IT companies | Scroll 20 -> 120
# Lower Dibang Valley | IT companies | Scroll 21 -> 120
# Collected 90 links
# Lower Dibang Valley | 1/90
# STAR ENTERPRISE
# Phone: 08974784103
# Lower Dibang Valley | 2/90
# Pulu Chamber
# Phone:
# Lower Dibang Valley | 3/90
# Nextgen Electronics
# Phone: 09435702810
# Lower Dibang Valley | 4/90
# M/s Ritu Electronics
# Phone: 07208025271
# Lower Dibang Valley | 5/90
# Kera ati Village, Roing, Lower Dibang Valley District, Arunachal Pradesh
# Phone:
# Lower Dibang Valley | 6/90
# Taxi Services Roing (MD)
# Phone:
# Lower Dibang Valley | 7/90
# Cheta-II
# Phone:
# Lower Dibang Valley | 8/90
# M/s Watch Centre
# Phone:
# Lower Dibang Valley | 9/90
# Abhi Electronic
# Phone: 07640823300
# Lower Dibang Valley | 10/90
# JK Tyre Xpress Wheels, Y N Wheels
# Phone: 08879052432
# Lower Dibang Valley | 11/90
# Upper Market
# Phone: 08257074645
# Lower Dibang Valley | 12/90
# LinkZen - Website & Software Development Centre in Dibrugarh
# Phone:
#
# Searching: IT companies in Lower Siang Arunachal Pradesh
# Search Submitted
# Lower Siang | IT companies | Scroll 1 -> 14
# Lower Siang | IT companies | Scroll 2 -> 20
# Lower Siang | IT companies | Scroll 3 -> 27
# Lower Siang | IT companies | Scroll 4 -> 34
# Lower Siang | IT companies | Scroll 5 -> 40
# Lower Siang | IT companies | Scroll 6 -> 47
# Lower Siang | IT companies | Scroll 7 -> 54
# Lower Siang | IT companies | Scroll 8 -> 60
# Lower Siang | IT companies | Scroll 9 -> 67
# Lower Siang | IT companies | Scroll 10 -> 74
# Lower Siang | IT companies | Scroll 11 -> 75
# Lower Siang | IT companies | Scroll 12 -> 75
# Lower Siang | IT companies | Scroll 13 -> 75
# Lower Siang | IT companies | Scroll 14 -> 75
# Lower Siang | IT companies | Scroll 15 -> 75
# Collected 66 links
# Lower Siang | 1/66
# RILU Village , Arunachal Pradesh
# Phone:
# Lower Siang | 2/66
# Liru B likabali.Lower Siang
# Phone:
# Lower Siang | 3/66
# Miniso Likabali
# Phone: 07085124376
# Lower Siang | 4/66
# Bigo Param Residential
# Phone:
# Lower Siang | 5/66
# M/s Yumpe & Company
# Phone: 08811819510
# Lower Siang | 6/66
# Blessing house
# Phone:
# Lower Siang | 7/66
# Bagra House
# Phone:
# Lower Siang | 8/66
# Dpo quater Henge Riba
# Phone:
# Lower Siang | 9/66
# Tumbledry Dry Clean & Laundry Service
# Phone: 07677250250
# Lower Siang | 10/66
# Pasighat Smart City Development Corporation Limited
# Phone: 02020772325
# Lower Siang | 11/66
# Bijar kamcham
# Phone:
# Lower Siang | 12/66
# Tojo Village
# Phone:
# Lower Siang | 13/66
# Pakmi Ruti private House
# Phone:
# Lower Siang | 14/66
# M/S SIANG PRINTING PRESS
# Phone: 07005300035
# Lower Siang | 15/66
# Village - Lumpo / Nari , Lower siang district .
# Phone:
# Lower Siang | 16/66
# Yomjum lombi residential Lombi Private Land
# Phone:
# Lower Siang | 17/66
# Ngopi Ruti Village
# Phone:
# Lower Siang | 18/66
# Rent House 2BHK
# Phone:
# Lower Siang | 19/66
# BSNL Store
# Phone: 09402832183
# Lower Siang | 20/66
# Residence of Tom Taju
# Phone:
# Lower Siang | 21/66
# Upper colony
# Phone:
# Lower Siang | 22/66
# 1033 (I) ESLP, Project Arunank (GREF)
# Phone:
# Lower Siang | 23/66
# Likabali
# Phone:
# Lower Siang | 24/66
# M/S blackbird enterprise
# Phone: 08974658696
# Lower Siang | 25/66
# Tapik Bui residence
# Phone:
# Lower Siang | 26/66
# Miki Digital Printing House
# Phone:
# Lower Siang | 27/66
# TORI NGULOM ESTATE
# Phone:
# Lower Siang | 28/66
# Bajar Sora residence
# Phone:
# Lower Siang | 29/66
# Dokar Dini Residence
# Phone:
# Lower Siang | 30/66
# BSNL Store
# Phone: 09436075631
# Lower Siang | 31/66
# BSNL Store
# Phone: 09402833485
# Lower Siang | 32/66
# Chimo Taipodia
# Phone:
# Lower Siang | 33/66
# Residence of Komkar Dini
# Phone:
# Backup Saved
# Lower Siang | 34/66
# Lt. Raja Rallen
# Phone:
# Lower Siang | 35/66
# Lt. Edar Taipodia Residence
# Phone:
# Lower Siang | 36/66
# Bui House
# Phone:
# Lower Siang | 37/66
# LIGE RIBA RESIDENT
# Phone:
# Lower Siang | 38/66
# Cicada 3301
# Phone:
# Lower Siang | 39/66
# Dikta Taipodia
# Phone:
# Lower Siang | 40/66
# Hento Taipodia
# Phone:
# Lower Siang | 41/66
# Kargil Gara resistance
# Phone:
# Lower Siang | 42/66
# Yummi Gibi Land
# Phone:
# Lower Siang | 43/66
# Nyori complex
# Phone:
# Lower Siang | 44/66
# Tshering tamang
# Phone:
# Lower Siang | 45/66
# Tagun Nika quarter
# Phone:
# Lower Siang | 46/66
# Ego village
# Phone:
# Lower Siang | 47/66
# Pakge Nyori resident
# Phone:
# Lower Siang | 48/66
# Duri Taipodia
# Phone:
# Lower Siang | 49/66
# Dirchi Dolu
# Phone:
# Lower Siang | 50/66
# Marbom Riba Residence
# Phone:
# Lower Siang | 51/66
# Doke Building
# Phone: 08731810676
# Lower Siang | 52/66
# Ijip taso Garden
# Phone:
# Lower Siang | 53/66
# Residence Rikli Taipodia
# Phone:
# Lower Siang | 54/66
# Jumyir House
# Phone:
# Lower Siang | 55/66
# Ngomle Residence
# Phone:
# Lower Siang | 56/66
# J. K
# Phone:
# Lower Siang | 57/66
# Henrik Dini's Resident
# Phone:
# Lower Siang | 58/66
# Karli riba Lipu village, resident
# Phone:
# Lower Siang | 59/66
# Jummer Tacha
# Phone:
# Lower Siang | 60/66
# Nimo Koyu Residence
# Phone:
# Lower Siang | 61/66
# Villa of Karya Nada
# Phone:
# Lower Siang | 62/66
# M/s Ijip Taso
# Phone:
# Lower Siang | 63/66
# Puja Infotech
# Phone: 07002593868
# Lower Siang | 64/66
# Ligin Rallen's Land
# Phone:
# Lower Siang | 65/66
# WRC, Gijum Taipodia
# Phone:
# Lower Siang | 66/66
# Likabali forest colony
# Phone:
#
# Searching: software companies in Lower Subansiri Arunachal Pradesh
# Search Submitted
# Lower Subansiri | software companies | Scroll 1 -> 13
# Lower Subansiri | software companies | Scroll 2 -> 13
# Lower Subansiri | software companies | Scroll 3 -> 13
# Lower Subansiri | software companies | Scroll 4 -> 13
# Lower Subansiri | software companies | Scroll 5 -> 13
# Collected 6 links
# Lower Subansiri | 1/6
# ATO Cyber
# Phone: 08415899497
# Lower Subansiri | 2/6
# ONE NET Internet Service Ziro
# Phone:
# Lower Subansiri | 3/6
# Suchusi Homestay, Ziro, Arunachal Pradesh
# Phone: 08974954810
# Lower Subansiri | 4/6
# SEEH LAKE, Biirii, Ziro
# Phone:
# Lower Subansiri | 5/6
# Gyati A³ Residence
# Phone:
# Lower Subansiri | 6/6
# UClean Laundry
# Phone: 09999759911
#
# Searching: IT companies in Lower Subansiri Arunachal Pradesh
# Search Submitted
# Lower Subansiri | IT companies | Scroll 1 -> 14
# M/s DT TRADERS
# Phone:
# Tawang | 98/103
# M/S RAVI STORE
# Phone:
# Tawang | 99/103
# Monage tours and travels
# Phone: 09871578852
# Tawang | 100/103
# Classic collection
# Phone:
# Tawang | 101/103
# Rasidul eletrician
# Phone: 08943923725
# Tawang | 102/103
# Stone Crusher Mago
# Phone:
# Tawang | 103/103
# Rikor Treks and Tours
# Phone:
#
# Searching: software companies in Tirap Arunachal Pradesh
# Search Submitted
# Scrolling Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@role="feed"]"}
#   (Session info: chrome=148.0.7778.168); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 	chromedriver!GetHandleVerifier [0xbfb593+105d3]
# 	chromedriver!GetHandleVerifier [0xbfb6c4+10704]
# 	chromedriver!(No symbol) [0xa01ea0]
# 	chromedriver!(No symbol) [0xa4b28a]
# 	chromedriver!(No symbol) [0xa4b52b]
# 	chromedriver!(No symbol) [0xa8d052]
# 	chromedriver!(No symbol) [0xa6d7c4]
# 	chromedriver!(No symbol) [0xa8a936]
# 	chromedriver!(No symbol) [0xa6d516]
# 	chromedriver!(No symbol) [0xa408e9]
# 	chromedriver!(No symbol) [0xa416a4]
# 	chromedriver!GetHandleVerifier [0xe83014+298054]
# 	chromedriver!GetHandleVerifier [0xe7e603+293643]
# 	chromedriver!GetHandleVerifier [0xe9ea05+2b3a45]
# 	chromedriver!GetHandleVerifier [0xc154e8+2a528]
# 	chromedriver!GetHandleVerifier [0xc1cd1d+31d5d]
# 	chromedriver!GetHandleVerifier [0xc03e68+18ea8]
# 	chromedriver!GetHandleVerifier [0xc04015+19055]
# 	chromedriver!GetHandleVerifier [0xbed65f+269f]
# 	KERNEL32!BaseThreadInitThunk [0x75c9fcc9+19]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x77a082ae+11e]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x77a0827e+ee]
#
# Collected 0 links
#
# Searching: IT companies in Tirap Arunachal Pradesh
# Search Submitted
# Scrolling Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@role="feed"]"}
#   (Session info: chrome=148.0.7778.168); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 	chromedriver!GetHandleVerifier [0xbfb593+105d3]
# 	chromedriver!GetHandleVerifier [0xbfb6c4+10704]
# 	chromedriver!(No symbol) [0xa01ea0]
# 	chromedriver!(No symbol) [0xa4b28a]
# 	chromedriver!(No symbol) [0xa4b52b]
# 	chromedriver!(No symbol) [0xa8d052]
# 	chromedriver!(No symbol) [0xa6d7c4]
# 	chromedriver!(No symbol) [0xa8a936]
# 	chromedriver!(No symbol) [0xa6d516]
# 	chromedriver!(No symbol) [0xa408e9]
# 	chromedriver!(No symbol) [0xa416a4]
# 	chromedriver!GetHandleVerifier [0xe83014+298054]
# 	chromedriver!GetHandleVerifier [0xe7e603+293643]
# 	chromedriver!GetHandleVerifier [0xe9ea05+2b3a45]
# 	chromedriver!GetHandleVerifier [0xc154e8+2a528]
# 	chromedriver!GetHandleVerifier [0xc1cd1d+31d5d]
# 	chromedriver!GetHandleVerifier [0xc03e68+18ea8]
# 	chromedriver!GetHandleVerifier [0xc04015+19055]
# 	chromedriver!GetHandleVerifier [0xbed65f+269f]
# 	KERNEL32!BaseThreadInitThunk [0x75c9fcc9+19]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x77a082ae+11e]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x77a0827e+ee]
#
# Collected 0 links
#
# Searching: software companies in Upper Siang Arunachal Pradesh
# Search Submitted
# Upper Siang | software companies | Scroll 1 -> 14
# Upper Siang | software companies | Scroll 2 -> 20
# Upper Siang | software companies | Scroll 3 -> 23
# Upper Siang | software companies | Scroll 4 -> 23
# Upper Siang | software companies | Scroll 5 -> 23
# Upper Siang | software companies | Scroll 6 -> 23
# Upper Siang | software companies | Scroll 7 -> 23
# Collected 1 links
# Upper Siang | 1/1
# PaljorTech
# Phone:
#
# Searching: IT companies in Upper Siang Arunachal Pradesh
# Search Submitted
# Upper Siang | IT companies | Scroll 1 -> 14
# Upper Siang | IT companies | Scroll 2 -> 20
# Upper Siang | IT companies | Scroll 3 -> 27
# Upper Siang | IT companies | Scroll 4 -> 33
# Upper Siang | IT companies | Scroll 5 -> 33
# Upper Siang | IT companies | Scroll 6 -> 33
# Upper Siang | IT companies | Scroll 7 -> 33
# Upper Siang | IT companies | Scroll 8 -> 33
# Collected 0 links
#
# Searching: software companies in Upper Subansiri Arunachal Pradesh
# Search Submitted
# Upper Subansiri | software companies | Scroll 1 -> 14
# Upper Subansiri | software companies | Scroll 2 -> 20
# Upper Subansiri | software companies | Scroll 3 -> 27
# Upper Subansiri | software companies | Scroll 4 -> 34
# Upper Subansiri | software companies | Scroll 5 -> 40
# Upper Subansiri | software companies | Scroll 6 -> 47
# Upper Subansiri | software companies | Scroll 7 -> 48
# Upper Subansiri | software companies | Scroll 8 -> 48
# Upper Subansiri | software companies | Scroll 9 -> 48
# Upper Subansiri | software companies | Scroll 10 -> 48
# Upper Subansiri | software companies | Scroll 11 -> 48
# Collected 29 links
# Upper Subansiri | 1/29
# Subansiri Technologies
# Phone:
# Upper Subansiri | 2/29
# Innovatyx Technohub Pvt Ltd
# Phone: 09435442525
# Upper Subansiri | 3/29
# Saiph Technologies Pvt. Ltd.
# Phone: 06002464768
# Upper Subansiri | 4/29
# HQ 23 BRTF. Border Road Organization
# Phone:
# Upper Subansiri | 5/29
# Pink Span
# Phone:
# Upper Subansiri | 6/29
# Subansiri Dam
# Phone:
# Upper Subansiri | 7/29
# DC Office
# Phone: 03792223223
# Upper Subansiri | 8/29
# IIIANA STUDIO PVT. LTD
# Phone: 06901262862
# Upper Subansiri | 9/29
# Hemrom Solution (OPC) Private Limited
# Phone: 06901674867
# Upper Subansiri | 10/29
# NHPC Powerhouse (Lower Subansiri)
# Phone:
# Upper Subansiri | 11/29
# Handsome Game Zone
# Phone: 07642033346
# Upper Subansiri | 12/29
#
# Phone:
# Upper Subansiri | 13/29
# Auisa
# Phone:
# Upper Subansiri | 14/29
# Clarity Technologies / Clarity Tech
# Phone: 08074541706
# Upper Subansiri | 15/29
# SIZONE Info
# Phone:
# Upper Subansiri | 16/29
# Hunaru One Private Limited
# Phone: 09220773021
# Upper Subansiri | 17/29
# Tech Support North Lakhimpur
# Phone: 08486295184
# Upper Subansiri | 18/29
# NewGenWP
# Phone:
# Upper Subansiri | 19/29
# Arunachal Institute of Computer Learning
# Phone:
# Upper Subansiri | 20/29
# Business Frond
# Phone:
# Upper Subansiri | 21/29
# dekaruSys
# Phone:
# Upper Subansiri | 22/29
# GrantSense AI
# Phone:
# Upper Subansiri | 23/29
# CAS Computers
# Phone: 06901256631
# Upper Subansiri | 24/29
# Arunachal Ivory and Ornaments Pvt. Ltd.
# Phone: 06033833795
# Upper Subansiri | 25/29
# IT Solution
# Phone: 07002654901
# Upper Subansiri | 26/29
# Dolen Deori
# Phone:
# Upper Subansiri | 27/29
# One Planet Digital
# Phone: 08011956830
# Upper Subansiri | 28/29
# Zenforto Softs
# Phone: 07905469688
# Upper Subansiri | 29/29
# IslamStore
# Phone: 07002019795
#
# Searching: IT companies in Upper Subansiri Arunachal Pradesh
# Search Submitted
# Upper Subansiri | IT companies | Scroll 1 -> 14
# Upper Subansiri | IT companies | Scroll 2 -> 15
# Upper Subansiri | IT companies | Scroll 3 -> 15
# Upper Subansiri | IT companies | Scroll 4 -> 15
# Upper Subansiri | IT companies | Scroll 5 -> 15
# Upper Subansiri | IT companies | Scroll 6 -> 15
# Collected 1 links
# Upper Subansiri | 1/1
# urban tech
# Phone:
#
# Searching: software companies in West Kameng Arunachal Pradesh
# Search Submitted
# West Kameng | software companies | Scroll 1 -> 14
# West Kameng | software companies | Scroll 2 -> 14
# West Kameng | software companies | Scroll 3 -> 14
# West Kameng | software companies | Scroll 4 -> 14
# West Kameng | software companies | Scroll 5 -> 14
# Collected 3 links
# West Kameng | 1/3
# A TO Z SOLUTION
# Phone: 06009096665
# West Kameng | 2/3
# Quick Repairing Mobile & Computer
# Phone:
# West Kameng | 3/3
# PRITAM ONLINE SERVICES
# Phone: 09101919487
#
# Searching: IT companies in West Kameng Arunachal Pradesh
# Search Submitted
# West Kameng | IT companies | Scroll 1 -> 5
# West Kameng | IT companies | Scroll 2 -> 5
# West Kameng | IT companies | Scroll 3 -> 5
# West Kameng | IT companies | Scroll 4 -> 5
# West Kameng | IT companies | Scroll 5 -> 5
# Collected 0 links
#
# Searching: software companies in West Siang Arunachal Pradesh
# Search Submitted
# West Siang | software companies | Scroll 1 -> 5
# West Siang | software companies | Scroll 2 -> 5
# West Siang | software companies | Scroll 3 -> 5
# West Siang | software companies | Scroll 4 -> 5
# West Siang | software companies | Scroll 5 -> 5
# Collected 0 links
#
# Searching: IT companies in West Siang Arunachal Pradesh
# Search Submitted
# West Siang | IT companies | Scroll 1 -> 10
# West Siang | IT companies | Scroll 2 -> 15
# West Siang | IT companies | Scroll 3 -> 20
# West Siang | IT companies | Scroll 4 -> 25
# West Siang | IT companies | Scroll 5 -> 30
# West Siang | IT companies | Scroll 6 -> 35
# West Siang | IT companies | Scroll 7 -> 40
# West Siang | IT companies | Scroll 8 -> 45
# West Siang | IT companies | Scroll 9 -> 50
# West Siang | IT companies | Scroll 10 -> 53
# West Siang | IT companies | Scroll 11 -> 53
# West Siang | IT companies | Scroll 12 -> 53
# West Siang | IT companies | Scroll 13 -> 53
# West Siang | IT companies | Scroll 14 -> 53
# Collected 28 links
# West Siang | 1/28
# Kai Arjy
# Phone: 08731008332
# West Siang | 2/28
# J&K cyber
# Phone:
# West Siang | 3/28
# Doyam complex
# Phone:
# West Siang | 4/28
# Bene Village
# Phone:
# West Siang | 5/28
# Ashutosh Computer & Mobile
# Phone:
# West Siang | 6/28
# Indane - Siang Gas Agency
# Phone: 08414801343
# West Siang | 7/28
# West Siang
# Phone:
# West Siang | 8/28
# Aalo News Today office
# Phone: 08798913654
# West Siang | 9/28
# Elum Pagmen Home
# Phone:
# West Siang | 10/28
# Abu Bari Residential
# Phone:
# West Siang | 11/28
# PAL-MORI DIGBAK
# Phone:
# West Siang | 12/28
# Urban Water Daporijo
# Phone:
# West Siang | 13/28
#
# Phone:
# Backup Saved
# West Siang | 14/28
# JBaya Romin Kapen Village
# Phone:
# West Siang | 15/28
# Malen Hali Commercial building
# Phone:
# West Siang | 16/28
# LB Gamezone / Cyber Cafe
# Phone:
# West Siang | 17/28
# MICROSOFTECH COMPUTER CENTER ITANAGAR
# Phone: 09862215892
# West Siang | 18/28
# Sigin -iii
# Phone:
# West Siang | 19/28
# R T Lukjen Lida
# Phone:
# West Siang | 20/28
# Don Basti
# Phone:
# West Siang | 21/28
# Power Grid
# Phone: 01242571700
# West Siang | 22/28
# M/S Jagygy Enterprises
# Phone:
# West Siang | 23/28
# LEPARADA AGRO FARMERS PRODUCER COMPANY LIMITED
# Phone:
# West Siang | 24/28
# ESET Consultancy & Allied
# Phone:
# West Siang | 25/28
# Ms Nyumge Rege cyber
# Phone:
# West Siang | 26/28
# TMY ENTERPRISES
# Phone: 07642821053
# West Siang | 27/28
# Das Enterprises
# Phone: 08876549624
# West Siang | 28/28
# Daniel's Art
# Phone: 09362101573
#
# Searching: software companies in Keyi Panyor Arunachal Pradesh
# Search Submitted
# Keyi Panyor | software companies | Scroll 1 -> 6
# Keyi Panyor | software companies | Scroll 2 -> 6
# Keyi Panyor | software companies | Scroll 3 -> 6
# Keyi Panyor | software companies | Scroll 4 -> 6
# Keyi Panyor | software companies | Scroll 5 -> 6
# Collected 1 links
# Keyi Panyor | 1/1
# Yachuli (HQ of Keyi Panyor district)
# Phone:
#
# Searching: IT companies in Keyi Panyor Arunachal Pradesh
# Search Submitted
# Keyi Panyor | IT companies | Scroll 1 -> 12
# Keyi Panyor | IT companies | Scroll 2 -> 12
# Keyi Panyor | IT companies | Scroll 3 -> 12
# Keyi Panyor | IT companies | Scroll 4 -> 12
# Keyi Panyor | IT companies | Scroll 5 -> 12
# Collected 7 links
# Keyi Panyor | 1/7
# Tao Techi (Yaho)
# Phone:
# Keyi Panyor | 2/7
# Abu Namlo
# Phone:
# Keyi Panyor | 3/7
# Delhivery courier service centre
# Phone: 08069856101
# Keyi Panyor | 4/7
# Tumbledry Dry Clean & Laundry Service
# Phone: 07677250250
# Keyi Panyor | 5/7
# CSC YAZALI
# Phone: 08794762204
# Keyi Panyor | 6/7
# Click Growth
# Phone:
# Keyi Panyor | 7/7
# Simply Answer
# Phone: 07628842027
#
# Extraction Completed
# Total Companies Extracted: 1023
#
# Saved File: arunachal_pradesh_companies.csv
